# %%
from flowstar.reachability import Reach, Poly

# %% [markdown]
# ## Example 1

# %%
varsc = [b't', b'x']
pt = Poly(1, 't', 0, varsc)
px = Poly(-1, 'x', 1, varsc)
print "t' = {}\nx' = {}".format(pt, px)
# Out:
# t' = (([1.0000000000e+00 , 1.0000000000e+00]))
# x' = (([-1.0000000000e+00 , -1.0000000000e+00] * x))

# %%
C = Reach(
    varsc,
    [pt, px],
    [(0,0), (5,5)],
    5,
    0.5,
    order=10,
)

# %%
C.res
# Out:
# 2

# %%
C.num_flowpipes
# Out:
# 10

# %%
C.wplot('t', 'x')
# Out:
# <wand.image.Image: 5dd6d65 'PS' (720x504)>

# %%
C.sage_plot_manual('x', 0.05)
# Out:
# Graphics object consisting of 400 graphics primitives

# %%
C.sage_plot('x', 0.05)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
_, (lo, hi) = C(RIF(0.2,1.1))

# %%
   C.sage_plot('x', 0.05) \
 + C.sage_plot('x') \
 + line([(0.2, lo), (1.1, lo)]) \
 + line([(0.2, hi), (1.1, hi)], color='#3bcc00')
# Out:
# Graphics object consisting of 6 graphics primitives

# %%
C.sage_tube_plot('t', 'x', 0.03, joins=False) #, plot_angle=float(pi/2))
# Out:
# Graphics object consisting of 330 graphics primitives

# %%
C.sage_tube_plot('t', 'x', 0.03, joins=False, plot_angle=float(pi/2))
# Out:
# Graphics object consisting of 330 graphics primitives

# %% [markdown]
# ## Example 2

# %%
varsd = [b't', b'x', b'y']
qt = Poly(1, 't', 0, varsd)
qx = Poly(-1, 'y', 1, varsd)
qy = Poly(1, 'x', 1, varsd)
print "t' = {}\nx' = {}\ny' = {}".format(qt, qx, qy)
# Out:
# t' = (([1.0000000000e+00 , 1.0000000000e+00]))
# x' = (([-1.0000000000e+00 , -1.0000000000e+00] * y))
# y' = (([1.0000000000e+00 , 1.0000000000e+00] * x))

# %%
D = Reach(
    varsd,
    [qt, qx, qy],
    [(0,0), (4,5), (1,2)],
    10,
    0.1,
    order=5,
)

# %%
D.res
# Out:
# 2

# %%
D.wplot(b't', b'x')
# Out:
# <wand.image.Image: 5dffb4e 'PS' (720x504)>

# %%
D.sage_plot('x')
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
D.wplot(b't', b'y')
# Out:
# <wand.image.Image: 584dd44 'PS' (720x504)>

# %%
D.sage_plot(b'y')
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
D.wplot(b'x', b'y')
# Out:
# <wand.image.Image: 3030ee8 'PS' (720x504)>

# %%
def f(t):
    return RIF(D(t)[1]).center()

# %%
def g(t):
    return RIF(D(t)[2]).center()

# %%
  parametric_plot((f, g), (0,10), color='red') \
+ D.sage_interval_plot('x', 'y')
# Out:
# Graphics object consisting of 101 graphics primitives

# %%
D.sage_tube_plot('x', 'y')
# Out:
# Graphics object consisting of 298 graphics primitives

# %%
D.sage_tube_plot('t', 'x', 0.4,arrows=True)
# Out:
# Graphics object consisting of 121 graphics primitives

# %%
D.sage_tube_plot('t', 'x', 0.2) + D.sage_interval_plot('t', 'x', 0.2)
# Out:
# Graphics object consisting of 198 graphics primitives

# %%
D.sage_tube_plot('t', 'x', 0.4, plot_angle=float(pi/2)) + D.sage_interval_plot('t', 'x', 0.4)
# Out:
# Graphics object consisting of 98 graphics primitives

# %%
D.sage_tube_plot('t', 'x', 0.5, plot_angle=float(pi/2),joins=False) \
 + D.sage_plot('x')
# Out:
# Graphics object consisting of 40 graphics primitives

# %%
D.sage_tube_plot('x', 'y',0.5) + D.sage_interval_plot('x', 'y', 0.5)
# Out:
# Graphics object consisting of 78 graphics primitives

# %%
D.sage_tube_plot('x', 'y',0.5, tight=True)\
+ D.sage_interval_plot('x', 'y', 0.5)
# Out:
# Graphics object consisting of 78 graphics primitives

# %%
D.sage_tube_plot('x', 'y',0.1,joins=False) + \
    D.sage_interval_plot('x', 'y', 0.1)
# Out:
# Graphics object consisting of 298 graphics primitives

# %%
D.sage_tube_plot('x', 'y',0.01,joins=False)
# Out:
# Graphics object consisting of 1998 graphics primitives

# %%
E = Reach(
    varsd,
    [qt, qx, qy],
    [(0,0), (4,5), (1,2)],
    float(2*pi),
    0.5,
    order=10,
)

# %%
E.res
# Out:
# 2

# %%
E.sage_tube_plot('x', 'y',0.01,joins=False)
# Out:
# Graphics object consisting of 1254 graphics primitives
