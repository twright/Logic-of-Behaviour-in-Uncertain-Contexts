# %%
# %matplotlib inline
from genetic_oscillator_benchmarking_futures_four_core import *

# %% [markdown]
# ## Properties

# %%
P = Atomic(var("x6") > 1)
P
# Out:
# Atomic(x6 > 1)

# %%
def prop(k):
    return (500/4)**2*(var("x4") - 0.003)**2 + 3*(var("x6") - 0.5)**2 < k

# %%
Q = Atomic(prop(0.032)); Q
# Out:
# Atomic(15625.0*(x4 - 0.003)^2 + 3*(x6 - 0.5)^2 < 0.032)

# %%
I = RIF(3, 3.5)

# %% [markdown]
# ## Launch Runs

# %%
num_runs = 10
duration = 0

# %%
our_property = G(RIF(0,1), P | G(RIF(3, 3.5), Q))

# %%
our_property_reversed = G(RIF(0,1), P | G(RIF(3, 3.5), Q))

# %%
results_upfront[0]['future'].result()[2].print()
# Out:
# ran "Precomposing Contexts" 1 times in 0.00029158592224121094
# ran "restoring globals" 16 times in 0.0016891956329345703
# ran "precomposing taylor models" 1 times in 0.11809945106506348
# ran "capturing globals [on exit]" 16 times in 0.0006480216979980469
# ran "Running Flow*" 1 times in 109.23899984359741
# ran "mask intersect check" 3002 times in 0.0072841644287109375
# ran "composing flowpipe" 3003 times in 101.35144376754761
# ran "whole domain eval" 3002 times in 6.662598133087158
# ran "post retrieve" 1020 times in 0.016840219497680664
# ran "root detection" 1020 times in 5.7078704833984375
# ran "root amalgamation" 1020 times in 0.003879070281982422
# ran "prepare in check" 4 times in 3.123283386230469e-05
# ran "check boolean [unguarded]" 4 times in 0.006696224212646484
# ran "observer.check" 4 times in 0.00768589973449707
# ran "Monitoring atomic x6 > 1" 1 times in 105.46877264976501
# ran "Monitoring atomic 15625.0*(x4 - 0.003)^2 + 3*(x6 - 0.5)^2 < 0.032" 1 times in 8.563345670700073
# ran "Monitoring Signal for G([0 .. 1], x6 > 1 | G([3.0000000000000000 .. 3.5000000000000000], 15625.0*(x4 - 0.003)^2 + 3*(x6 - 0.5)^2 < 0.032))" 1 times in 115.9589512348175

# %%
results_upfront = gen_results(
    num_runs,
    our_property,
    duration,
    task_description='Unmasked P | F(Q)',
    use_masks=False,
    symbolic_composition=False,
    tentative_unpreconditioning=False,
    selective_unpreconditioning=False,
    precompose_taylor_models=True,
)
# Out:
# /usr/lib64/python3.8/multiprocessing/queues.py:116: DeprecationWarning: PY_SSIZE_T_CLEAN will be required for '#' formats
#   return _ForkingPickler.loads(res)
# /usr/lib64/python3.8/multiprocessing/queues.py:116: DeprecationWarning: PY_SSIZE_T_CLEAN will be required for '#' formats
#   return _ForkingPickler.loads(res)
# /usr/lib64/python3.8/multiprocessing/queues.py:116: DeprecationWarning: PY_SSIZE_T_CLEAN will be required for '#' formats
#   return _ForkingPickler.loads(res)
# /usr/lib64/python3.8/multiprocessing/queues.py:116: DeprecationWarning: PY_SSIZE_T_CLEAN will be required for '#' formats
#   return _ForkingPickler.loads(res)
# include_derivs = True
# include_derivs = True
# include_derivs = True
# phi variables sfs = {x6, x4}
# include_derivs = True
# phi variables sfs = {x6, x4}
# phi variables sfs = {x6, x4}
# system sfs = System(R, (x1, x2, x3, x4, x5, x6, x7, x8, x9), [[0.97999999999999998 .. 1.0200000000000001], [1.2799999999999998 .. 1.3200000000000001], [0.079999999999999987 .. 0.12000000000000001], [0.079999999999999987 .. 0.12000000000000001], [0.079999999999999987 .. 0.12000000000000001], [1.2799999999999998 .. 1.3200000000000001], [2.4799999999999999 .. 2.5200000000000001], [0.57999999999999996 .. 0.62000000000000011], [1.2799999999999998 .. 1.3200000000000001]], (-0.10000000000000000?*x1*x6 + 50*x3, -x1*x2 + 100*x4, 0.10000000000000000?*x1*x6 - 50*x3, x2*x6 - 100*x4, 0.50000000000000000?*x1 + 5*x3 - 10*x5, -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6, 0.01000000000000000?*x2 + 50*x4 - 0.50000000000000000?*x7, -2*x6*x8 + 0.50000000000000000?*x7 - 0.2000000000000000?*x8 + x9, 2*x6*x8 - x9), varmap=bidict({'x1': x1, 'x2': x2, 'x3': x3, 'x4': x4, 'x5': x5, 'x6': x6, 'x7': x7, 'x8': x8, 'x9': x9}))
# system sfs = System(R, (x1, x2, x3, x4, x5, x6, x7, x8, x9), [[0.97999999999999998 .. 1.0200000000000001], [1.2799999999999998 .. 1.3200000000000001], [0.079999999999999987 .. 0.12000000000000001], [0.079999999999999987 .. 0.12000000000000001], [0.079999999999999987 .. 0.12000000000000001], [1.2799999999999998 .. 1.3200000000000001], [2.4799999999999999 .. 2.5200000000000001], [0.57999999999999996 .. 0.62000000000000011], [1.2799999999999998 .. 1.3200000000000001]], (-0.10000000000000000?*x1*x6 + 50*x3, -x1*x2 + 100*x4, 0.10000000000000000?*x1*x6 - 50*x3, x2*x6 - 100*x4, 0.50000000000000000?*x1 + 5*x3 - 10*x5, -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6, 0.01000000000000000?*x2 + 50*x4 - 0.50000000000000000?*x7, -2*x6*x8 + 0.50000000000000000?*x7 - 0.2000000000000000?*x8 + x9, 2*x6*x8 - x9), varmap=bidict({'x1': x1, 'x2': x2, 'x3': x3, 'x4': x4, 'x5': x5, 'x6': x6, 'x7': x7, 'x8': x8, 'x9': x9}))
# phi variables sfs = {x6, x4}
# calling reach with y0 = ['[0.97999999999999998 .. 1.0200000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[2.4799999999999999 .. 2.5200000000000001]', '[0.57999999999999996 .. 0.62000000000000011]', '[1.2799999999999998 .. 1.3200000000000001]']
# calling reach with y0 = ['[0.97999999999999998 .. 1.0200000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[2.4799999999999999 .. 2.5200000000000001]', '[0.57999999999999996 .. 0.62000000000000011]', '[1.2799999999999998 .. 1.3200000000000001]']
# system sfs = System(R, (x1, x2, x3, x4, x5, x6, x7, x8, x9), [[0.97999999999999998 .. 1.0200000000000001], [1.2799999999999998 .. 1.3200000000000001], [0.079999999999999987 .. 0.12000000000000001], [0.079999999999999987 .. 0.12000000000000001], [0.079999999999999987 .. 0.12000000000000001], [1.2799999999999998 .. 1.3200000000000001], [2.4799999999999999 .. 2.5200000000000001], [0.57999999999999996 .. 0.62000000000000011], [1.2799999999999998 .. 1.3200000000000001]], (-0.10000000000000000?*x1*x6 + 50*x3, -x1*x2 + 100*x4, 0.10000000000000000?*x1*x6 - 50*x3, x2*x6 - 100*x4, 0.50000000000000000?*x1 + 5*x3 - 10*x5, -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6, 0.01000000000000000?*x2 + 50*x4 - 0.50000000000000000?*x7, -2*x6*x8 + 0.50000000000000000?*x7 - 0.2000000000000000?*x8 + x9, 2*x6*x8 - x9), varmap=bidict({'x1': x1, 'x2': x2, 'x3': x3, 'x4': x4, 'x5': x5, 'x6': x6, 'x7': x7, 'x8': x8, 'x9': x9}))
# ode in polynomial ring
# system sfs = System(R, (x1, x2, x3, x4, x5, x6, x7, x8, x9), [[0.97999999999999998 .. 1.0200000000000001], [1.2799999999999998 .. 1.3200000000000001], [0.079999999999999987 .. 0.12000000000000001], [0.079999999999999987 .. 0.12000000000000001], [0.079999999999999987 .. 0.12000000000000001], [1.2799999999999998 .. 1.3200000000000001], [2.4799999999999999 .. 2.5200000000000001], [0.57999999999999996 .. 0.62000000000000011], [1.2799999999999998 .. 1.3200000000000001]], (-0.10000000000000000?*x1*x6 + 50*x3, -x1*x2 + 100*x4, 0.10000000000000000?*x1*x6 - 50*x3, x2*x6 - 100*x4, 0.50000000000000000?*x1 + 5*x3 - 10*x5, -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6, 0.01000000000000000?*x2 + 50*x4 - 0.50000000000000000?*x7, -2*x6*x8 + 0.50000000000000000?*x7 - 0.2000000000000000?*x8 + x9, 2*x6*x8 - x9), varmap=bidict({'x1': x1, 'x2': x2, 'x3': x3, 'x4': x4, 'x5': x5, 'x6': x6, 'x7': x7, 'x8': x8, 'x9': x9}))
# ode in polynomial ring
# calling reach with y0 = ['[0.97999999999999998 .. 1.0200000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[2.4799999999999999 .. 2.5200000000000001]', '[0.57999999999999996 .. 0.62000000000000011]', '[1.2799999999999998 .. 1.3200000000000001]']
# calling reach with y0 = ['[0.97999999999999998 .. 1.0200000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[2.4799999999999999 .. 2.5200000000000001]', '[0.57999999999999996 .. 0.62000000000000011]', '[1.2799999999999998 .. 1.3200000000000001]']
# crude_roots = False
# ode in polynomial ring
# crude_roots = False
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# crude_roots = False
# _handle_initials called!
# vars = [x1, x2, x3, x4, x5, x6, x7, x8, x9]
# vars = [x1, x2, x3, x4, x5, x6, x7, x8, x9]
# C = [0.98..1.02]
# C = [0.98..1.02]
# C = [1.2799999999999998..1.32]
# C = [1.2799999999999998..1.32]
# _handle_initials called!
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# vars = [x1, x2, x3, x4, x5, x6, x7, x8, x9]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# _handle_initials called!
# C = [0.98..1.02]
# C = [0.07999999999999999..0.12000000000000001]
# vars = [x1, x2, x3, x4, x5, x6, x7, x8, x9]
# C = [1.2799999999999998..1.32]
# C = [0.07999999999999999..0.12000000000000001]
# C = [1.2799999999999998..1.32]
# C = [0.98..1.02]
# C = [0.07999999999999999..0.12000000000000001]
# C = [1.2799999999999998..1.32]
# C = [2.48..2.52]
# C = [1.2799999999999998..1.32]
# C = [0.58..0.6200000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [1.2799999999999998..1.32]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# assigning system with dimension 9
# C = [1.2799999999999998..1.32]
# C = [0.07999999999999999..0.12000000000000001]
# C = [2.48..2.52]
# resulting system has dimension 9
# C = [1.2799999999999998..1.32]
# C = [2.48..2.52]
# C = [0.58..0.6200000000000001]
# C = [2.48..2.52]
# run within tmv args
# C = [0.58..0.6200000000000001]
# C = [0.58..0.6200000000000001]
# C = [1.2799999999999998..1.32]
# integrationScheme = 7
# C = [1.2799999999999998..1.32]
# C = [1.2799999999999998..1.32]
# assigning system with dimension 9
# resulting system has dimension 9
# assigning system with dimension 9
# assigning system with dimension 9
# resulting system has dimension 9
# run within tmv args
# integrationScheme = 7
# run within tmv args
# resulting system has dimension 9
# integrationScheme = 7
# run within tmv args
# integrationScheme = 7
# Computed 1501 flowpipes in 99.25893046101555 sec
# In G.signal
# Computed 1501 flowpipes in 99.98423681003624 sec
# In G.signal
# PolyObserver(x6 - 1, <flowstar.reachability.Reach object at 0x7f7a35103480>, -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6, symbolic_composition=False, symbolic_composition_order=4, tentative_unpreconditioning=False, mask=None)
# fprime = -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6
# symbolic_composition=False,symbolic_composition_order=4, tentative_unpreconditioning=False,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# PolyObserver(x6 - 1, <flowstar.reachability.Reach object at 0x7f7a35103480>, -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6, symbolic_composition=False, symbolic_composition_order=4, tentative_unpreconditioning=False, mask=None)
# fprime = -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6
# symbolic_composition=False,symbolic_composition_order=4, tentative_unpreconditioning=False,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# Computed 1501 flowpipes in 107.03230724000605 sec
# In G.signal
# PolyObserver(x6 - 1, <flowstar.reachability.Reach object at 0x7f7a35103480>, -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6, symbolic_composition=False, symbolic_composition_order=4, tentative_unpreconditioning=False, mask=None)
# fprime = -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6
# symbolic_composition=False,symbolic_composition_order=4, tentative_unpreconditioning=False,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# Computed 1501 flowpipes in 109.25637726899004 sec
# In G.signal
# PolyObserver(x6 - 1, <flowstar.reachability.Reach object at 0x7f7a35103480>, -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6, symbolic_composition=False, symbolic_composition_order=4, tentative_unpreconditioning=False, mask=None)
# fprime = -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6
# symbolic_composition=False,symbolic_composition_order=4, tentative_unpreconditioning=False,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 104.36 seconds
# roots = [[0.86562109364728989 .. 1.2973760412304721]]
# domain = [0.0000000000000000 .. 4.5020000000000007]
# roots = [[0.86562109364728989 .. 1.2973760412304721]]
# seg_domain = [0.0000000000000000 .. 4.5020000000000007]
# roots = [[0.86562109364728989 .. 1.2973760412304721]]
# signal given bool roots: 1 items in 0.01 seconds
# In G.signal
# PolyObserver(-15625*x4^2 - 3*x6^2 + 93.75000000000001?*x4 + 3*x6 - 0.858625000000000?, <flowstar.reachability.Reach object at 0x7f7a35103480>, -31250*x2*x4*x6 + 0.600000000000000?*x1*x6^2 + 6*x2*x6^2 + 12*x6^2*x8 + 3125000*x4^2 - 0.3000000000000000?*x1*x6 + 90.750000000000000?*x2*x6 - 300*x3*x6 - 600*x4*x6 - 300*x5*x6 + 6*x6^2 - 6*x6*x8 + 150*x3 - 9075*x4 + 150*x5 - 3*x6, symbolic_composition=False, symbolic_composition_order=4, tentative_unpreconditioning=False, mask=None)
# fprime = -31250*x2*x4*x6 + 0.600000000000000?*x1*x6^2 + 6*x2*x6^2 + 12*x6^2*x8 + 3125000*x4^2 - 0.3000000000000000?*x1*x6 + 90.750000000000000?*x2*x6 - 300*x3*x6 - 600*x4*x6 - 300*x5*x6 + 6*x6^2 - 6*x6*x8 + 150*x3 - 9075*x4 + 150*x5 - 3*x6
# symbolic_composition=False,symbolic_composition_order=4, tentative_unpreconditioning=False,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 108.03 seconds
# roots = [[0.86562109364728989 .. 1.2973760412304721]]
# domain = [0.0000000000000000 .. 4.5020000000000007]
# roots = [[0.86562109364728989 .. 1.2973760412304721]]
# seg_domain = [0.0000000000000000 .. 4.5020000000000007]
# roots = [[0.86562109364728989 .. 1.2973760412304721]]
# signal given bool roots: 1 items in 0.02 seconds
# In G.signal
# PolyObserver(-15625*x4^2 - 3*x6^2 + 93.75000000000001?*x4 + 3*x6 - 0.858625000000000?, <flowstar.reachability.Reach object at 0x7f7a35103480>, -31250*x2*x4*x6 + 0.600000000000000?*x1*x6^2 + 6*x2*x6^2 + 12*x6^2*x8 + 3125000*x4^2 - 0.3000000000000000?*x1*x6 + 90.750000000000000?*x2*x6 - 300*x3*x6 - 600*x4*x6 - 300*x5*x6 + 6*x6^2 - 6*x6*x8 + 150*x3 - 9075*x4 + 150*x5 - 3*x6, symbolic_composition=False, symbolic_composition_order=4, tentative_unpreconditioning=False, mask=None)
# fprime = -31250*x2*x4*x6 + 0.600000000000000?*x1*x6^2 + 6*x2*x6^2 + 12*x6^2*x8 + 3125000*x4^2 - 0.3000000000000000?*x1*x6 + 90.750000000000000?*x2*x6 - 300*x3*x6 - 600*x4*x6 - 300*x5*x6 + 6*x6^2 - 6*x6*x8 + 150*x3 - 9075*x4 + 150*x5 - 3*x6
# symbolic_composition=False,symbolic_composition_order=4, tentative_unpreconditioning=False,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 104.31 seconds
# roots = [[0.86562109364728989 .. 1.2973760412304721]]
# domain = [0.0000000000000000 .. 4.5020000000000007]
# roots = [[0.86562109364728989 .. 1.2973760412304721]]
# seg_domain = [0.0000000000000000 .. 4.5020000000000007]
# roots = [[0.86562109364728989 .. 1.2973760412304721]]
# signal given bool roots: 1 items in 0.01 seconds
# In G.signal
# PolyObserver(-15625*x4^2 - 3*x6^2 + 93.75000000000001?*x4 + 3*x6 - 0.858625000000000?, <flowstar.reachability.Reach object at 0x7f7a35103480>, -31250*x2*x4*x6 + 0.600000000000000?*x1*x6^2 + 6*x2*x6^2 + 12*x6^2*x8 + 3125000*x4^2 - 0.3000000000000000?*x1*x6 + 90.750000000000000?*x2*x6 - 300*x3*x6 - 600*x4*x6 - 300*x5*x6 + 6*x6^2 - 6*x6*x8 + 150*x3 - 9075*x4 + 150*x5 - 3*x6, symbolic_composition=False, symbolic_composition_order=4, tentative_unpreconditioning=False, mask=None)
# fprime = -31250*x2*x4*x6 + 0.600000000000000?*x1*x6^2 + 6*x2*x6^2 + 12*x6^2*x8 + 3125000*x4^2 - 0.3000000000000000?*x1*x6 + 90.750000000000000?*x2*x6 - 300*x3*x6 - 600*x4*x6 - 300*x5*x6 + 6*x6^2 - 6*x6*x8 + 150*x3 - 9075*x4 + 150*x5 - 3*x6
# symbolic_composition=False,symbolic_composition_order=4, tentative_unpreconditioning=False,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 8.58 seconds
# roots = [[1.8802545744613263 .. 4.5030000000001343]]
# domain = [0.0000000000000000 .. 4.5020000000000007]
# roots = [[1.8802545744613263 .. 4.5030000000001343]]
# seg_domain = [0.0000000000000000 .. 4.5020000000000007]
# roots = [[1.8802545744613263 .. 4.5030000000001343]]
# 0 at 4.50200000000001
# signal given bool roots: 1 items in 0.02 seconds
# ran "Precomposing Contexts" 1 times in 0.0002777576446533203
# ran "restoring globals" 16 times in 0.0014278888702392578
# ran "precomposing taylor models" 1 times in 0.14045214653015137
# ran "capturing globals [on exit]" 16 times in 0.0007348060607910156
# ran "Running Flow*" 1 times in 99.24652099609375
# ran "mask intersect check" 3002 times in 0.00734710693359375
# ran "composing flowpipe" 3003 times in 100.24767112731934
# ran "whole domain eval" 3002 times in 6.6316118240356445
# ran "post retrieve" 1020 times in 0.016522884368896484
# ran "root detection" 1020 times in 5.798308610916138
# ran "root amalgamation" 1020 times in 0.0038013458251953125
# ran "prepare in check" 4 times in 3.24249267578125e-05
# ran "check boolean [unguarded]" 4 times in 0.006757020950317383
# ran "observer.check" 4 times in 0.00771641731262207
# ran "Monitoring atomic x6 > 1" 1 times in 104.37926054000854
# ran "Monitoring atomic 15625.0*(x4 - 0.003)^2 + 3*(x6 - 0.5)^2 < 0.032" 1 times in 8.603285074234009
# ran "Monitoring Signal for G([0 .. 1], x6 > 1 | G([3.0000000000000000 .. 3.5000000000000000], 15625.0*(x4 - 0.003)^2 + 3*(x6 - 0.5)^2 < 0.032))" 1 times in 115.30240201950073
# Run done in 214.62119674682617 sec
# options: {'instrumentor': <flowstar.instrumentation.AggregateMetric object at 0x7f7cb07cf1c0>, 'use_masks': False, 'symbolic_composition': False, 'tentative_unpreconditioning': False, 'selective_unpreconditioning': False, 'precompose_taylor_models': True}
# include_derivs = True
# phi variables sfs = {x6, x4}
# system sfs = System(R, (x1, x2, x3, x4, x5, x6, x7, x8, x9), [[0.97999999999999998 .. 1.0200000000000001], [1.2799999999999998 .. 1.3200000000000001], [0.079999999999999987 .. 0.12000000000000001], [0.079999999999999987 .. 0.12000000000000001], [0.079999999999999987 .. 0.12000000000000001], [1.2799999999999998 .. 1.3200000000000001], [2.4799999999999999 .. 2.5200000000000001], [0.57999999999999996 .. 0.62000000000000011], [1.2799999999999998 .. 1.3200000000000001]], (-0.10000000000000000?*x1*x6 + 50*x3, -x1*x2 + 100*x4, 0.10000000000000000?*x1*x6 - 50*x3, x2*x6 - 100*x4, 0.50000000000000000?*x1 + 5*x3 - 10*x5, -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6, 0.01000000000000000?*x2 + 50*x4 - 0.50000000000000000?*x7, -2*x6*x8 + 0.50000000000000000?*x7 - 0.2000000000000000?*x8 + x9, 2*x6*x8 - x9), varmap=bidict({'x1': x1, 'x2': x2, 'x3': x3, 'x4': x4, 'x5': x5, 'x6': x6, 'x7': x7, 'x8': x8, 'x9': x9}))
# calling reach with y0 = ['[0.97999999999999998 .. 1.0200000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[2.4799999999999999 .. 2.5200000000000001]', '[0.57999999999999996 .. 0.62000000000000011]', '[1.2799999999999998 .. 1.3200000000000001]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x1, x2, x3, x4, x5, x6, x7, x8, x9]
# C = [0.98..1.02]
# C = [1.2799999999999998..1.32]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [1.2799999999999998..1.32]
# C = [2.48..2.52]
# C = [0.58..0.6200000000000001]
# C = [1.2799999999999998..1.32]
# assigning system with dimension 9
# resulting system has dimension 9
# run within tmv args
# integrationScheme = 7
# top-level root detection: 1 items in 105.45 seconds
# roots = [[0.86562109364728989 .. 1.2973760412304721]]
# domain = [0.0000000000000000 .. 4.5020000000000007]
# roots = [[0.86562109364728989 .. 1.2973760412304721]]
# seg_domain = [0.0000000000000000 .. 4.5020000000000007]
# roots = [[0.86562109364728989 .. 1.2973760412304721]]
# signal given bool roots: 1 items in 0.01 seconds
# In G.signal
# PolyObserver(-15625*x4^2 - 3*x6^2 + 93.75000000000001?*x4 + 3*x6 - 0.858625000000000?, <flowstar.reachability.Reach object at 0x7f7a35103480>, -31250*x2*x4*x6 + 0.600000000000000?*x1*x6^2 + 6*x2*x6^2 + 12*x6^2*x8 + 3125000*x4^2 - 0.3000000000000000?*x1*x6 + 90.750000000000000?*x2*x6 - 300*x3*x6 - 600*x4*x6 - 300*x5*x6 + 6*x6^2 - 6*x6*x8 + 150*x3 - 9075*x4 + 150*x5 - 3*x6, symbolic_composition=False, symbolic_composition_order=4, tentative_unpreconditioning=False, mask=None)
# fprime = -31250*x2*x4*x6 + 0.600000000000000?*x1*x6^2 + 6*x2*x6^2 + 12*x6^2*x8 + 3125000*x4^2 - 0.3000000000000000?*x1*x6 + 90.750000000000000?*x2*x6 - 300*x3*x6 - 600*x4*x6 - 300*x5*x6 + 6*x6^2 - 6*x6*x8 + 150*x3 - 9075*x4 + 150*x5 - 3*x6
# symbolic_composition=False,symbolic_composition_order=4, tentative_unpreconditioning=False,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 9.21 seconds
# roots = [[1.8802545744613263 .. 4.5030000000001343]]
# domain = [0.0000000000000000 .. 4.5020000000000007]
# roots = [[1.8802545744613263 .. 4.5030000000001343]]
# seg_domain = [0.0000000000000000 .. 4.5020000000000007]
# roots = [[1.8802545744613263 .. 4.5030000000001343]]
# 0 at 4.50200000000001
# signal given bool roots: 1 items in 0.01 seconds
# ran "Precomposing Contexts" 1 times in 0.0003101825714111328
# ran "restoring globals" 16 times in 0.0018084049224853516
# ran "precomposing taylor models" 1 times in 0.1406557559967041
# ran "capturing globals [on exit]" 16 times in 0.0007855892181396484
# ran "Running Flow*" 1 times in 99.96973872184753
# ran "mask intersect check" 3002 times in 0.007775068283081055
# ran "composing flowpipe" 3003 times in 103.76917743682861
# ran "whole domain eval" 3002 times in 7.077871799468994
# ran "post retrieve" 1020 times in 0.0178377628326416
# ran "root detection" 1020 times in 6.110957860946655
# ran "root amalgamation" 1020 times in 0.0037391185760498047
# ran "prepare in check" 4 times in 3.910064697265625e-05
# ran "check boolean [unguarded]" 4 times in 0.006791591644287109
# ran "observer.check" 4 times in 0.008005142211914062
# ran "Monitoring atomic x6 > 1" 1 times in 108.05184841156006
# ran "Monitoring atomic 15625.0*(x4 - 0.003)^2 + 3*(x6 - 0.5)^2 < 0.032" 1 times in 9.235936403274536
# ran "Monitoring Signal for G([0 .. 1], x6 > 1 | G([3.0000000000000000 .. 3.5000000000000000], 15625.0*(x4 - 0.003)^2 + 3*(x6 - 0.5)^2 < 0.032))" 1 times in 119.64583849906921
# Run done in 219.6592025756836 sec
# options: {'instrumentor': <flowstar.instrumentation.AggregateMetric object at 0x7f7cb07cf1c0>, 'use_masks': False, 'symbolic_composition': False, 'tentative_unpreconditioning': False, 'selective_unpreconditioning': False, 'precompose_taylor_models': True}
# include_derivs = True
# phi variables sfs = {x6, x4}
# system sfs = System(R, (x1, x2, x3, x4, x5, x6, x7, x8, x9), [[0.97999999999999998 .. 1.0200000000000001], [1.2799999999999998 .. 1.3200000000000001], [0.079999999999999987 .. 0.12000000000000001], [0.079999999999999987 .. 0.12000000000000001], [0.079999999999999987 .. 0.12000000000000001], [1.2799999999999998 .. 1.3200000000000001], [2.4799999999999999 .. 2.5200000000000001], [0.57999999999999996 .. 0.62000000000000011], [1.2799999999999998 .. 1.3200000000000001]], (-0.10000000000000000?*x1*x6 + 50*x3, -x1*x2 + 100*x4, 0.10000000000000000?*x1*x6 - 50*x3, x2*x6 - 100*x4, 0.50000000000000000?*x1 + 5*x3 - 10*x5, -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6, 0.01000000000000000?*x2 + 50*x4 - 0.50000000000000000?*x7, -2*x6*x8 + 0.50000000000000000?*x7 - 0.2000000000000000?*x8 + x9, 2*x6*x8 - x9), varmap=bidict({'x1': x1, 'x2': x2, 'x3': x3, 'x4': x4, 'x5': x5, 'x6': x6, 'x7': x7, 'x8': x8, 'x9': x9}))
# calling reach with y0 = ['[0.97999999999999998 .. 1.0200000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[2.4799999999999999 .. 2.5200000000000001]', '[0.57999999999999996 .. 0.62000000000000011]', '[1.2799999999999998 .. 1.3200000000000001]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x1, x2, x3, x4, x5, x6, x7, x8, x9]
# C = [0.98..1.02]
# C = [1.2799999999999998..1.32]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [1.2799999999999998..1.32]
# C = [2.48..2.52]
# C = [0.58..0.6200000000000001]
# C = [1.2799999999999998..1.32]
# assigning system with dimension 9
# resulting system has dimension 9
# run within tmv args
# integrationScheme = 7
# top-level root detection: 1 items in 9.01 seconds
# roots = [[1.8802545744613263 .. 4.5030000000001343]]
# domain = [0.0000000000000000 .. 4.5020000000000007]
# roots = [[1.8802545744613263 .. 4.5030000000001343]]
# seg_domain = [0.0000000000000000 .. 4.5020000000000007]
# roots = [[1.8802545744613263 .. 4.5030000000001343]]
# 0 at 4.50200000000001
# signal given bool roots: 1 items in 0.01 seconds
# ran "Precomposing Contexts" 1 times in 0.0002791881561279297
# ran "restoring globals" 16 times in 0.0014562606811523438
# ran "precomposing taylor models" 1 times in 0.12064743041992188
# ran "capturing globals [on exit]" 16 times in 0.0006871223449707031
# ran "Running Flow*" 1 times in 107.01224732398987
# ran "mask intersect check" 3002 times in 0.007842540740966797
# ran "composing flowpipe" 3003 times in 100.18818783760071
# ran "whole domain eval" 3002 times in 7.0458292961120605
# ran "post retrieve" 1020 times in 0.016200542449951172
# ran "root detection" 1020 times in 5.814358472824097
# ran "root amalgamation" 1020 times in 0.0035288333892822266
# ran "prepare in check" 4 times in 2.8133392333984375e-05
# ran "check boolean [unguarded]" 4 times in 0.00705409049987793
# ran "observer.check" 4 times in 0.007949113845825195
# ran "Monitoring atomic x6 > 1" 1 times in 104.32249522209167
# ran "Monitoring atomic 15625.0*(x4 - 0.003)^2 + 3*(x6 - 0.5)^2 < 0.032" 1 times in 9.035564661026001
# ran "Monitoring Signal for G([0 .. 1], x6 > 1 | G([3.0000000000000000 .. 3.5000000000000000], 15625.0*(x4 - 0.003)^2 + 3*(x6 - 0.5)^2 < 0.032))" 1 times in 115.33475017547607
# Run done in 222.39605903625488 sec
# options: {'instrumentor': <flowstar.instrumentation.AggregateMetric object at 0x7f7cb07cf1c0>, 'use_masks': False, 'symbolic_composition': False, 'tentative_unpreconditioning': False, 'selective_unpreconditioning': False, 'precompose_taylor_models': True}
# include_derivs = True
# phi variables sfs = {x6, x4}
# system sfs = System(R, (x1, x2, x3, x4, x5, x6, x7, x8, x9), [[0.97999999999999998 .. 1.0200000000000001], [1.2799999999999998 .. 1.3200000000000001], [0.079999999999999987 .. 0.12000000000000001], [0.079999999999999987 .. 0.12000000000000001], [0.079999999999999987 .. 0.12000000000000001], [1.2799999999999998 .. 1.3200000000000001], [2.4799999999999999 .. 2.5200000000000001], [0.57999999999999996 .. 0.62000000000000011], [1.2799999999999998 .. 1.3200000000000001]], (-0.10000000000000000?*x1*x6 + 50*x3, -x1*x2 + 100*x4, 0.10000000000000000?*x1*x6 - 50*x3, x2*x6 - 100*x4, 0.50000000000000000?*x1 + 5*x3 - 10*x5, -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6, 0.01000000000000000?*x2 + 50*x4 - 0.50000000000000000?*x7, -2*x6*x8 + 0.50000000000000000?*x7 - 0.2000000000000000?*x8 + x9, 2*x6*x8 - x9), varmap=bidict({'x1': x1, 'x2': x2, 'x3': x3, 'x4': x4, 'x5': x5, 'x6': x6, 'x7': x7, 'x8': x8, 'x9': x9}))
# calling reach with y0 = ['[0.97999999999999998 .. 1.0200000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[2.4799999999999999 .. 2.5200000000000001]', '[0.57999999999999996 .. 0.62000000000000011]', '[1.2799999999999998 .. 1.3200000000000001]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x1, x2, x3, x4, x5, x6, x7, x8, x9]
# C = [0.98..1.02]
# C = [1.2799999999999998..1.32]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [1.2799999999999998..1.32]
# C = [2.48..2.52]
# C = [0.58..0.6200000000000001]
# C = [1.2799999999999998..1.32]
# assigning system with dimension 9
# resulting system has dimension 9
# run within tmv args
# integrationScheme = 7
# top-level root detection: 1 items in 8.54 seconds
# roots = [[1.8802545744613263 .. 4.5030000000001343]]
# domain = [0.0000000000000000 .. 4.5020000000000007]
# roots = [[1.8802545744613263 .. 4.5030000000001343]]
# seg_domain = [0.0000000000000000 .. 4.5020000000000007]
# roots = [[1.8802545744613263 .. 4.5030000000001343]]
# 0 at 4.50200000000001
# signal given bool roots: 1 items in 0.02 seconds
# ran "Precomposing Contexts" 1 times in 0.00029158592224121094
# ran "restoring globals" 16 times in 0.0016891956329345703
# ran "precomposing taylor models" 1 times in 0.11809945106506348
# ran "capturing globals [on exit]" 16 times in 0.0006480216979980469
# ran "Running Flow*" 1 times in 109.23899984359741
# ran "mask intersect check" 3002 times in 0.0072841644287109375
# ran "composing flowpipe" 3003 times in 101.35144376754761
# ran "whole domain eval" 3002 times in 6.662598133087158
# ran "post retrieve" 1020 times in 0.016840219497680664
# ran "root detection" 1020 times in 5.7078704833984375
# ran "root amalgamation" 1020 times in 0.003879070281982422
# ran "prepare in check" 4 times in 3.123283386230469e-05
# ran "check boolean [unguarded]" 4 times in 0.006696224212646484
# ran "observer.check" 4 times in 0.00768589973449707
# ran "Monitoring atomic x6 > 1" 1 times in 105.46877264976501
# ran "Monitoring atomic 15625.0*(x4 - 0.003)^2 + 3*(x6 - 0.5)^2 < 0.032" 1 times in 8.563345670700073
# ran "Monitoring Signal for G([0 .. 1], x6 > 1 | G([3.0000000000000000 .. 3.5000000000000000], 15625.0*(x4 - 0.003)^2 + 3*(x6 - 0.5)^2 < 0.032))" 1 times in 115.9589512348175
# Run done in 225.25850868225098 sec
# options: {'instrumentor': <flowstar.instrumentation.AggregateMetric object at 0x7f7cb07cf1c0>, 'use_masks': False, 'symbolic_composition': False, 'tentative_unpreconditioning': False, 'selective_unpreconditioning': False, 'precompose_taylor_models': True}
# include_derivs = True
# phi variables sfs = {x6, x4}
# system sfs = System(R, (x1, x2, x3, x4, x5, x6, x7, x8, x9), [[0.97999999999999998 .. 1.0200000000000001], [1.2799999999999998 .. 1.3200000000000001], [0.079999999999999987 .. 0.12000000000000001], [0.079999999999999987 .. 0.12000000000000001], [0.079999999999999987 .. 0.12000000000000001], [1.2799999999999998 .. 1.3200000000000001], [2.4799999999999999 .. 2.5200000000000001], [0.57999999999999996 .. 0.62000000000000011], [1.2799999999999998 .. 1.3200000000000001]], (-0.10000000000000000?*x1*x6 + 50*x3, -x1*x2 + 100*x4, 0.10000000000000000?*x1*x6 - 50*x3, x2*x6 - 100*x4, 0.50000000000000000?*x1 + 5*x3 - 10*x5, -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6, 0.01000000000000000?*x2 + 50*x4 - 0.50000000000000000?*x7, -2*x6*x8 + 0.50000000000000000?*x7 - 0.2000000000000000?*x8 + x9, 2*x6*x8 - x9), varmap=bidict({'x1': x1, 'x2': x2, 'x3': x3, 'x4': x4, 'x5': x5, 'x6': x6, 'x7': x7, 'x8': x8, 'x9': x9}))
# calling reach with y0 = ['[0.97999999999999998 .. 1.0200000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[2.4799999999999999 .. 2.5200000000000001]', '[0.57999999999999996 .. 0.62000000000000011]', '[1.2799999999999998 .. 1.3200000000000001]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x1, x2, x3, x4, x5, x6, x7, x8, x9]
# C = [0.98..1.02]
# C = [1.2799999999999998..1.32]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [1.2799999999999998..1.32]
# C = [2.48..2.52]
# C = [0.58..0.6200000000000001]
# C = [1.2799999999999998..1.32]
# assigning system with dimension 9
# resulting system has dimension 9
# run within tmv args
# integrationScheme = 7
# Computed 1501 flowpipes in 90.53936693203286 sec
# In G.signal
# PolyObserver(x6 - 1, <flowstar.reachability.Reach object at 0x7f7a35103480>, -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6, symbolic_composition=False, symbolic_composition_order=4, tentative_unpreconditioning=False, mask=None)
# fprime = -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6
# symbolic_composition=False,symbolic_composition_order=4, tentative_unpreconditioning=False,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# Computed 1501 flowpipes in 86.01919064903632 sec
# In G.signal
# PolyObserver(x6 - 1, <flowstar.reachability.Reach object at 0x7f7a35103480>, -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6, symbolic_composition=False, symbolic_composition_order=4, tentative_unpreconditioning=False, mask=None)
# fprime = -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6
# symbolic_composition=False,symbolic_composition_order=4, tentative_unpreconditioning=False,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# Computed 1501 flowpipes in 86.93698527303059 sec
# In G.signal
# PolyObserver(x6 - 1, <flowstar.reachability.Reach object at 0x7f7a35103480>, -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6, symbolic_composition=False, symbolic_composition_order=4, tentative_unpreconditioning=False, mask=None)
# fprime = -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6
# symbolic_composition=False,symbolic_composition_order=4, tentative_unpreconditioning=False,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# Computed 1501 flowpipes in 93.49093591302517 sec
# In G.signal
# PolyObserver(x6 - 1, <flowstar.reachability.Reach object at 0x7f7a35103480>, -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6, symbolic_composition=False, symbolic_composition_order=4, tentative_unpreconditioning=False, mask=None)
# fprime = -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6
# symbolic_composition=False,symbolic_composition_order=4, tentative_unpreconditioning=False,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 105.64 seconds
# roots = [[0.86562109364728989 .. 1.2973760412304721]]
# domain = [0.0000000000000000 .. 4.5020000000000007]
# roots = [[0.86562109364728989 .. 1.2973760412304721]]
# seg_domain = [0.0000000000000000 .. 4.5020000000000007]
# roots = [[0.86562109364728989 .. 1.2973760412304721]]
# signal given bool roots: 1 items in 0.01 seconds
# In G.signal
# PolyObserver(-15625*x4^2 - 3*x6^2 + 93.75000000000001?*x4 + 3*x6 - 0.858625000000000?, <flowstar.reachability.Reach object at 0x7f7a35103480>, -31250*x2*x4*x6 + 0.600000000000000?*x1*x6^2 + 6*x2*x6^2 + 12*x6^2*x8 + 3125000*x4^2 - 0.3000000000000000?*x1*x6 + 90.750000000000000?*x2*x6 - 300*x3*x6 - 600*x4*x6 - 300*x5*x6 + 6*x6^2 - 6*x6*x8 + 150*x3 - 9075*x4 + 150*x5 - 3*x6, symbolic_composition=False, symbolic_composition_order=4, tentative_unpreconditioning=False, mask=None)
# fprime = -31250*x2*x4*x6 + 0.600000000000000?*x1*x6^2 + 6*x2*x6^2 + 12*x6^2*x8 + 3125000*x4^2 - 0.3000000000000000?*x1*x6 + 90.750000000000000?*x2*x6 - 300*x3*x6 - 600*x4*x6 - 300*x5*x6 + 6*x6^2 - 6*x6*x8 + 150*x3 - 9075*x4 + 150*x5 - 3*x6
# symbolic_composition=False,symbolic_composition_order=4, tentative_unpreconditioning=False,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 107.98 seconds
# roots = [[0.86562109364728989 .. 1.2973760412304721]]
# domain = [0.0000000000000000 .. 4.5020000000000007]
# roots = [[0.86562109364728989 .. 1.2973760412304721]]
# seg_domain = [0.0000000000000000 .. 4.5020000000000007]
# roots = [[0.86562109364728989 .. 1.2973760412304721]]
# signal given bool roots: 1 items in 0.01 seconds
# In G.signal
# PolyObserver(-15625*x4^2 - 3*x6^2 + 93.75000000000001?*x4 + 3*x6 - 0.858625000000000?, <flowstar.reachability.Reach object at 0x7f7a35103480>, -31250*x2*x4*x6 + 0.600000000000000?*x1*x6^2 + 6*x2*x6^2 + 12*x6^2*x8 + 3125000*x4^2 - 0.3000000000000000?*x1*x6 + 90.750000000000000?*x2*x6 - 300*x3*x6 - 600*x4*x6 - 300*x5*x6 + 6*x6^2 - 6*x6*x8 + 150*x3 - 9075*x4 + 150*x5 - 3*x6, symbolic_composition=False, symbolic_composition_order=4, tentative_unpreconditioning=False, mask=None)
# fprime = -31250*x2*x4*x6 + 0.600000000000000?*x1*x6^2 + 6*x2*x6^2 + 12*x6^2*x8 + 3125000*x4^2 - 0.3000000000000000?*x1*x6 + 90.750000000000000?*x2*x6 - 300*x3*x6 - 600*x4*x6 - 300*x5*x6 + 6*x6^2 - 6*x6*x8 + 150*x3 - 9075*x4 + 150*x5 - 3*x6
# symbolic_composition=False,symbolic_composition_order=4, tentative_unpreconditioning=False,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 107.80 seconds
# roots = [[0.86562109364728989 .. 1.2973760412304721]]
# domain = [0.0000000000000000 .. 4.5020000000000007]
# roots = [[0.86562109364728989 .. 1.2973760412304721]]
# seg_domain = [0.0000000000000000 .. 4.5020000000000007]
# roots = [[0.86562109364728989 .. 1.2973760412304721]]
# signal given bool roots: 1 items in 0.01 seconds
# In G.signal
# PolyObserver(-15625*x4^2 - 3*x6^2 + 93.75000000000001?*x4 + 3*x6 - 0.858625000000000?, <flowstar.reachability.Reach object at 0x7f7a35103480>, -31250*x2*x4*x6 + 0.600000000000000?*x1*x6^2 + 6*x2*x6^2 + 12*x6^2*x8 + 3125000*x4^2 - 0.3000000000000000?*x1*x6 + 90.750000000000000?*x2*x6 - 300*x3*x6 - 600*x4*x6 - 300*x5*x6 + 6*x6^2 - 6*x6*x8 + 150*x3 - 9075*x4 + 150*x5 - 3*x6, symbolic_composition=False, symbolic_composition_order=4, tentative_unpreconditioning=False, mask=None)
# fprime = -31250*x2*x4*x6 + 0.600000000000000?*x1*x6^2 + 6*x2*x6^2 + 12*x6^2*x8 + 3125000*x4^2 - 0.3000000000000000?*x1*x6 + 90.750000000000000?*x2*x6 - 300*x3*x6 - 600*x4*x6 - 300*x5*x6 + 6*x6^2 - 6*x6*x8 + 150*x3 - 9075*x4 + 150*x5 - 3*x6
# symbolic_composition=False,symbolic_composition_order=4, tentative_unpreconditioning=False,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 8.41 seconds
# roots = [[1.8802545744613263 .. 4.5030000000001343]]
# domain = [0.0000000000000000 .. 4.5020000000000007]
# roots = [[1.8802545744613263 .. 4.5030000000001343]]
# seg_domain = [0.0000000000000000 .. 4.5020000000000007]
# roots = [[1.8802545744613263 .. 4.5030000000001343]]
# 0 at 4.50200000000001
# signal given bool roots: 1 items in 0.02 seconds
# ran "Precomposing Contexts" 1 times in 4.220008850097656e-05
# ran "restoring globals" 16 times in 0.002627134323120117
# ran "precomposing taylor models" 1 times in 0.13075518608093262
# ran "capturing globals [on exit]" 16 times in 0.003633737564086914
# ran "Running Flow*" 1 times in 86.013916015625
# ran "mask intersect check" 3002 times in 0.00737309455871582
# ran "composing flowpipe" 3003 times in 101.37088060379028
# ran "whole domain eval" 3002 times in 6.750364780426025
# ran "post retrieve" 1020 times in 0.016367435455322266
# ran "root detection" 1020 times in 5.6716272830963135
# ran "root amalgamation" 1020 times in 0.0035452842712402344
# ran "prepare in check" 4 times in 3.075599670410156e-05
# ran "check boolean [unguarded]" 4 times in 0.007506132125854492
# ran "observer.check" 4 times in 0.008429765701293945
# ran "Monitoring atomic x6 > 1" 1 times in 105.65726375579834
# ran "Monitoring atomic 15625.0*(x4 - 0.003)^2 + 3*(x6 - 0.5)^2 < 0.032" 1 times in 8.44593596458435
# ran "Monitoring Signal for G([0 .. 1], x6 > 1 | G([3.0000000000000000 .. 3.5000000000000000], 15625.0*(x4 - 0.003)^2 + 3*(x6 - 0.5)^2 < 0.032))" 1 times in 114.24083542823792
# Run done in 200.3019835948944 sec
# options: {'instrumentor': <flowstar.instrumentation.AggregateMetric object at 0x7f7cb0810680>, 'use_masks': False, 'symbolic_composition': False, 'tentative_unpreconditioning': False, 'selective_unpreconditioning': False, 'precompose_taylor_models': True}
# include_derivs = True
# phi variables sfs = {x6, x4}
# system sfs = System(R, (x1, x2, x3, x4, x5, x6, x7, x8, x9), [[0.97999999999999998 .. 1.0200000000000001], [1.2799999999999998 .. 1.3200000000000001], [0.079999999999999987 .. 0.12000000000000001], [0.079999999999999987 .. 0.12000000000000001], [0.079999999999999987 .. 0.12000000000000001], [1.2799999999999998 .. 1.3200000000000001], [2.4799999999999999 .. 2.5200000000000001], [0.57999999999999996 .. 0.62000000000000011], [1.2799999999999998 .. 1.3200000000000001]], (-0.10000000000000000?*x1*x6 + 50*x3, -x1*x2 + 100*x4, 0.10000000000000000?*x1*x6 - 50*x3, x2*x6 - 100*x4, 0.50000000000000000?*x1 + 5*x3 - 10*x5, -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6, 0.01000000000000000?*x2 + 50*x4 - 0.50000000000000000?*x7, -2*x6*x8 + 0.50000000000000000?*x7 - 0.2000000000000000?*x8 + x9, 2*x6*x8 - x9), varmap=bidict({'x1': x1, 'x2': x2, 'x3': x3, 'x4': x4, 'x5': x5, 'x6': x6, 'x7': x7, 'x8': x8, 'x9': x9}))
# calling reach with y0 = ['[0.97999999999999998 .. 1.0200000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[2.4799999999999999 .. 2.5200000000000001]', '[0.57999999999999996 .. 0.62000000000000011]', '[1.2799999999999998 .. 1.3200000000000001]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x1, x2, x3, x4, x5, x6, x7, x8, x9]
# C = [0.98..1.02]
# C = [1.2799999999999998..1.32]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [1.2799999999999998..1.32]
# C = [2.48..2.52]
# C = [0.58..0.6200000000000001]
# C = [1.2799999999999998..1.32]
# assigning system with dimension 9
# resulting system has dimension 9
# run within tmv args
# integrationScheme = 7
# top-level root detection: 1 items in 8.47 seconds
# roots = [[1.8802545744613263 .. 4.5030000000001343]]
# domain = [0.0000000000000000 .. 4.5020000000000007]
# roots = [[1.8802545744613263 .. 4.5030000000001343]]
# seg_domain = [0.0000000000000000 .. 4.5020000000000007]
# roots = [[1.8802545744613263 .. 4.5030000000001343]]
# 0 at 4.50200000000001
# signal given bool roots: 1 items in 0.02 seconds
# ran "Precomposing Contexts" 1 times in 5.364418029785156e-05
# ran "restoring globals" 16 times in 0.0020422935485839844
# ran "precomposing taylor models" 1 times in 0.10979890823364258
# ran "capturing globals [on exit]" 16 times in 0.0008363723754882812
# ran "Running Flow*" 1 times in 90.53350973129272
# ran "mask intersect check" 3002 times in 0.007404327392578125
# ran "composing flowpipe" 3003 times in 103.6315712928772
# ran "whole domain eval" 3002 times in 6.740252733230591
# ran "post retrieve" 1020 times in 0.016913175582885742
# ran "root detection" 1020 times in 5.81001877784729
# ran "root amalgamation" 1020 times in 0.003678560256958008
# ran "prepare in check" 4 times in 3.886222839355469e-05
# ran "check boolean [unguarded]" 4 times in 0.007807493209838867
# ran "observer.check" 4 times in 0.009027481079101562
# ran "Monitoring atomic x6 > 1" 1 times in 108.00022220611572
# ran "Monitoring atomic 15625.0*(x4 - 0.003)^2 + 3*(x6 - 0.5)^2 < 0.032" 1 times in 8.495091676712036
# ran "Monitoring Signal for G([0 .. 1], x6 > 1 | G([3.0000000000000000 .. 3.5000000000000000], 15625.0*(x4 - 0.003)^2 + 3*(x6 - 0.5)^2 < 0.032))" 1 times in 116.62775945663452
# Run done in 207.19815063476562 sec
# options: {'instrumentor': <flowstar.instrumentation.AggregateMetric object at 0x7f7cb0810e80>, 'use_masks': False, 'symbolic_composition': False, 'tentative_unpreconditioning': False, 'selective_unpreconditioning': False, 'precompose_taylor_models': True}
# include_derivs = True
# phi variables sfs = {x6, x4}
# system sfs = System(R, (x1, x2, x3, x4, x5, x6, x7, x8, x9), [[0.97999999999999998 .. 1.0200000000000001], [1.2799999999999998 .. 1.3200000000000001], [0.079999999999999987 .. 0.12000000000000001], [0.079999999999999987 .. 0.12000000000000001], [0.079999999999999987 .. 0.12000000000000001], [1.2799999999999998 .. 1.3200000000000001], [2.4799999999999999 .. 2.5200000000000001], [0.57999999999999996 .. 0.62000000000000011], [1.2799999999999998 .. 1.3200000000000001]], (-0.10000000000000000?*x1*x6 + 50*x3, -x1*x2 + 100*x4, 0.10000000000000000?*x1*x6 - 50*x3, x2*x6 - 100*x4, 0.50000000000000000?*x1 + 5*x3 - 10*x5, -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6, 0.01000000000000000?*x2 + 50*x4 - 0.50000000000000000?*x7, -2*x6*x8 + 0.50000000000000000?*x7 - 0.2000000000000000?*x8 + x9, 2*x6*x8 - x9), varmap=bidict({'x1': x1, 'x2': x2, 'x3': x3, 'x4': x4, 'x5': x5, 'x6': x6, 'x7': x7, 'x8': x8, 'x9': x9}))
# calling reach with y0 = ['[0.97999999999999998 .. 1.0200000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[2.4799999999999999 .. 2.5200000000000001]', '[0.57999999999999996 .. 0.62000000000000011]', '[1.2799999999999998 .. 1.3200000000000001]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x1, x2, x3, x4, x5, x6, x7, x8, x9]
# C = [0.98..1.02]
# C = [1.2799999999999998..1.32]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [1.2799999999999998..1.32]
# C = [2.48..2.52]
# C = [0.58..0.6200000000000001]
# C = [1.2799999999999998..1.32]
# assigning system with dimension 9
# resulting system has dimension 9
# run within tmv args
# integrationScheme = 7
# top-level root detection: 1 items in 105.81 seconds
# roots = [[0.86562109364728989 .. 1.2973760412304721]]
# domain = [0.0000000000000000 .. 4.5020000000000007]
# roots = [[0.86562109364728989 .. 1.2973760412304721]]
# seg_domain = [0.0000000000000000 .. 4.5020000000000007]
# roots = [[0.86562109364728989 .. 1.2973760412304721]]
# signal given bool roots: 1 items in 0.01 seconds
# In G.signal
# PolyObserver(-15625*x4^2 - 3*x6^2 + 93.75000000000001?*x4 + 3*x6 - 0.858625000000000?, <flowstar.reachability.Reach object at 0x7f7a35103480>, -31250*x2*x4*x6 + 0.600000000000000?*x1*x6^2 + 6*x2*x6^2 + 12*x6^2*x8 + 3125000*x4^2 - 0.3000000000000000?*x1*x6 + 90.750000000000000?*x2*x6 - 300*x3*x6 - 600*x4*x6 - 300*x5*x6 + 6*x6^2 - 6*x6*x8 + 150*x3 - 9075*x4 + 150*x5 - 3*x6, symbolic_composition=False, symbolic_composition_order=4, tentative_unpreconditioning=False, mask=None)
# fprime = -31250*x2*x4*x6 + 0.600000000000000?*x1*x6^2 + 6*x2*x6^2 + 12*x6^2*x8 + 3125000*x4^2 - 0.3000000000000000?*x1*x6 + 90.750000000000000?*x2*x6 - 300*x3*x6 - 600*x4*x6 - 300*x5*x6 + 6*x6^2 - 6*x6*x8 + 150*x3 - 9075*x4 + 150*x5 - 3*x6
# symbolic_composition=False,symbolic_composition_order=4, tentative_unpreconditioning=False,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 8.64 seconds
# roots = [[1.8802545744613263 .. 4.5030000000001343]]
# domain = [0.0000000000000000 .. 4.5020000000000007]
# roots = [[1.8802545744613263 .. 4.5030000000001343]]
# seg_domain = [0.0000000000000000 .. 4.5020000000000007]
# roots = [[1.8802545744613263 .. 4.5030000000001343]]
# 0 at 4.50200000000001
# signal given bool roots: 1 items in 0.03 seconds
# ran "Precomposing Contexts" 1 times in 3.647804260253906e-05
# ran "restoring globals" 16 times in 0.001590728759765625
# ran "precomposing taylor models" 1 times in 0.1055145263671875
# ran "capturing globals [on exit]" 16 times in 0.0008878707885742188
# ran "Running Flow*" 1 times in 86.93208289146423
# ran "mask intersect check" 3002 times in 0.007298946380615234
# ran "composing flowpipe" 3003 times in 103.48396468162537
# ran "whole domain eval" 3002 times in 6.772651195526123
# ran "post retrieve" 1020 times in 0.01665782928466797
# ran "root detection" 1020 times in 5.9080939292907715
# ran "root amalgamation" 1020 times in 0.0038170814514160156
# ran "prepare in check" 4 times in 3.24249267578125e-05
# ran "check boolean [unguarded]" 4 times in 0.007965564727783203
# ran "observer.check" 4 times in 0.008877992630004883
# ran "Monitoring atomic x6 > 1" 1 times in 107.82827162742615
# ran "Monitoring atomic 15625.0*(x4 - 0.003)^2 + 3*(x6 - 0.5)^2 < 0.032" 1 times in 8.670982837677002
# ran "Monitoring Signal for G([0 .. 1], x6 > 1 | G([3.0000000000000000 .. 3.5000000000000000], 15625.0*(x4 - 0.003)^2 + 3*(x6 - 0.5)^2 < 0.032))" 1 times in 116.6394248008728
# Run done in 203.60908675193787 sec
# options: {'instrumentor': <flowstar.instrumentation.AggregateMetric object at 0x7f7cb0810780>, 'use_masks': False, 'symbolic_composition': False, 'tentative_unpreconditioning': False, 'selective_unpreconditioning': False, 'precompose_taylor_models': True}
# include_derivs = False
# phi variables sfs = {x6, x4}
# ...
# calling reach with y0 = ['[0.97999999999999998 .. 1.0200000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[2.4799999999999999 .. 2.5200000000000001]', '[0.57999999999999996 .. 0.62000000000000011]', '[1.2799999999999998 .. 1.3200000000000001]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x1, x2, x3, x4, x5, x6, x7, x8, x9]
# C = [0.98..1.02]
# C = [1.2799999999999998..1.32]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [1.2799999999999998..1.32]
# C = [2.48..2.52]
# C = [0.58..0.6200000000000001]
# C = [1.2799999999999998..1.32]
# assigning system with dimension 9
# resulting system has dimension 9
# unpreconditioning_orders = [4, 4, 4, 4, 4, 4, -1, 4, -1]
# run within tmv args
# integrationScheme = 7
# top-level root detection: 1 items in 6.81 seconds
# roots = [[1.8802545744613263 .. 4.5030000000001343]]
# domain = [0.0000000000000000 .. 4.5020000000000007]
# roots = [[1.8802545744613263 .. 4.5030000000001343]]
# seg_domain = [0.0000000000000000 .. 4.5020000000000007]
# roots = [[1.8802545744613263 .. 4.5030000000001343]]
# 0 at 4.50200000000001
# signal given bool roots: 1 items in 0.01 seconds
# ran "Precomposing Contexts" 1 times in 5.3882598876953125e-05
# ran "restoring globals" 16 times in 0.001331329345703125
# ran "precomposing taylor models" 1 times in 0.11683487892150879
# ran "capturing globals [on exit]" 16 times in 0.0008087158203125
# ran "Running Flow*" 1 times in 87.2457959651947
# ran "mask intersect check" 3002 times in 0.006955385208129883
# ran "composing flowpipe" 3003 times in 73.78175759315491
# ran "whole domain eval" 3002 times in 5.028204441070557
# ran "post retrieve" 1020 times in 0.018832683563232422
# ran "root detection" 1020 times in 4.531353235244751
# ran "root amalgamation" 1020 times in 0.0038192272186279297
# ran "prepare in check" 4 times in 3.0279159545898438e-05
# ran "check boolean [unguarded]" 4 times in 0.006251811981201172
# ran "observer.check" 4 times in 0.006971597671508789
# ran "Monitoring atomic x6 > 1" 1 times in 76.79159569740295
# ran "Monitoring atomic 15625.0*(x4 - 0.003)^2 + 3*(x6 - 0.5)^2 < 0.032" 1 times in 6.833740234375
# ran "Monitoring Signal for G([0 .. 1], x6 > 1 | G([3.0000000000000000 .. 3.5000000000000000], 15625.0*(x4 - 0.003)^2 + 3*(x6 - 0.5)^2 < 0.032))" 1 times in 83.73642420768738
# Run done in 171.03797006607056 sec
# options: {'instrumentor': <flowstar.instrumentation.AggregateMetric object at 0x7f7cc351c100>, 'use_masks': False, 'symbolic_composition': False, 'tentative_unpreconditioning': False, 'selective_unpreconditioning': True, 'precompose_taylor_models': True}
# include_derivs = True
# phi variables sfs = {x6, x4}
# system sfs = System(R, (x1, x2, x3, x4, x5, x6, x7, x8, x9), [[0.97999999999999998 .. 1.0200000000000001], [1.2799999999999998 .. 1.3200000000000001], [0.079999999999999987 .. 0.12000000000000001], [0.079999999999999987 .. 0.12000000000000001], [0.079999999999999987 .. 0.12000000000000001], [1.2799999999999998 .. 1.3200000000000001], [2.4799999999999999 .. 2.5200000000000001], [0.57999999999999996 .. 0.62000000000000011], [1.2799999999999998 .. 1.3200000000000001]], (-0.10000000000000000?*x1*x6 + 50*x3, -x1*x2 + 100*x4, 0.10000000000000000?*x1*x6 - 50*x3, x2*x6 - 100*x4, 0.50000000000000000?*x1 + 5*x3 - 10*x5, -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6, 0.01000000000000000?*x2 + 50*x4 - 0.50000000000000000?*x7, -2*x6*x8 + 0.50000000000000000?*x7 - 0.2000000000000000?*x8 + x9, 2*x6*x8 - x9), varmap=bidict({'x1': x1, 'x2': x2, 'x3': x3, 'x4': x4, 'x5': x5, 'x6': x6, 'x7': x7, 'x8': x8, 'x9': x9}))
# calling reach with y0 = ['[0.97999999999999998 .. 1.0200000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[2.4799999999999999 .. 2.5200000000000001]', '[0.57999999999999996 .. 0.62000000000000011]', '[1.2799999999999998 .. 1.3200000000000001]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x1, x2, x3, x4, x5, x6, x7, x8, x9]
# C = [0.98..1.02]
# C = [1.2799999999999998..1.32]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [1.2799999999999998..1.32]
# C = [2.48..2.52]
# C = [0.58..0.6200000000000001]
# C = [1.2799999999999998..1.32]
# assigning system with dimension 9
# resulting system has dimension 9
# unpreconditioning_orders = [4, 4, 4, 4, 4, 4, -1, 4, -1]
# run within tmv args
# integrationScheme = 7
# top-level root detection: 1 items in 8.50 seconds
# roots = [[1.8802545744613263 .. 4.5030000000001343]]
# domain = [0.0000000000000000 .. 4.5020000000000007]
# roots = [[1.8802545744613263 .. 4.5030000000001343]]
# seg_domain = [0.0000000000000000 .. 4.5020000000000007]
# roots = [[1.8802545744613263 .. 4.5030000000001343]]
# 0 at 4.50200000000001
# signal given bool roots: 1 items in 0.03 seconds
# ran "Precomposing Contexts" 1 times in 4.100799560546875e-05
# ran "restoring globals" 16 times in 0.0022423267364501953
# ran "precomposing taylor models" 1 times in 0.10738992691040039
# ran "capturing globals [on exit]" 16 times in 0.0008866786956787109
# ran "Running Flow*" 1 times in 89.95677042007446
# ran "mask intersect check" 3002 times in 0.007670879364013672
# ran "composing flowpipe" 3003 times in 76.15826869010925
# ran "whole domain eval" 3002 times in 5.848912000656128
# ran "post retrieve" 1020 times in 0.01904153823852539
# ran "root detection" 1020 times in 5.492558479309082
# ran "root amalgamation" 1020 times in 0.0038504600524902344
# ran "prepare in check" 4 times in 3.337860107421875e-05
# ran "check boolean [unguarded]" 4 times in 0.006579875946044922
# ran "observer.check" 4 times in 0.007284402847290039
# ran "Monitoring atomic x6 > 1" 1 times in 79.28334212303162
# ran "Monitoring atomic 15625.0*(x4 - 0.003)^2 + 3*(x6 - 0.5)^2 < 0.032" 1 times in 8.531804084777832
# ran "Monitoring Signal for G([0 .. 1], x6 > 1 | G([3.0000000000000000 .. 3.5000000000000000], 15625.0*(x4 - 0.003)^2 + 3*(x6 - 0.5)^2 < 0.032))" 1 times in 87.93558096885681
# Run done in 177.9468433856964 sec
# options: {'instrumentor': <flowstar.instrumentation.AggregateMetric object at 0x7f7a359ef540>, 'use_masks': False, 'symbolic_composition': False, 'tentative_unpreconditioning': False, 'selective_unpreconditioning': True, 'precompose_taylor_models': True}
# top-level root detection: 1 items in 7.88 seconds
# roots = [[1.8802545744613263 .. 4.5030000000001343]]
# domain = [0.0000000000000000 .. 4.5020000000000007]
# roots = [[1.8802545744613263 .. 4.5030000000001343]]
# seg_domain = [0.0000000000000000 .. 4.5020000000000007]
# roots = [[1.8802545744613263 .. 4.5030000000001343]]
# 0 at 4.50200000000001
# signal given bool roots: 1 items in 0.01 seconds
# ran "Precomposing Contexts" 1 times in 4.267692565917969e-05
# ran "restoring globals" 16 times in 0.0014736652374267578
# ran "precomposing taylor models" 1 times in 0.11127114295959473
# ran "capturing globals [on exit]" 16 times in 0.0007650852203369141
# ran "Running Flow*" 1 times in 90.34192705154419
# ran "mask intersect check" 3002 times in 0.0073699951171875
# ran "composing flowpipe" 3003 times in 72.80102252960205
# ran "whole domain eval" 3002 times in 5.492109298706055
# ran "post retrieve" 1020 times in 0.017963409423828125
# ran "root detection" 1020 times in 5.106618881225586
# ran "root amalgamation" 1020 times in 0.0037131309509277344
# ran "prepare in check" 4 times in 3.147125244140625e-05
# ran "check boolean [unguarded]" 4 times in 0.006416797637939453
# ran "observer.check" 4 times in 0.00715947151184082
# ran "Monitoring atomic x6 > 1" 1 times in 75.7868721485138
# ran "Monitoring atomic 15625.0*(x4 - 0.003)^2 + 3*(x6 - 0.5)^2 < 0.032" 1 times in 7.908429384231567
# ran "Monitoring Signal for G([0 .. 1], x6 > 1 | G([3.0000000000000000 .. 3.5000000000000000], 15625.0*(x4 - 0.003)^2 + 3*(x6 - 0.5)^2 < 0.032))" 1 times in 83.81104898452759
# Run done in 174.21545696258545 sec
# options: {'instrumentor': <flowstar.instrumentation.AggregateMetric object at 0x7f7c90e8a800>, 'use_masks': False, 'symbolic_composition': False, 'tentative_unpreconditioning': False, 'selective_unpreconditioning': True, 'precompose_taylor_models': True}
# Computed 1501 flowpipes in 77.67603030602913 sec
# In G.signal
# PolyObserver(x6 - 1, <flowstar.reachability.Reach object at 0x7f7a35103480>, -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6, symbolic_composition=False, symbolic_composition_order=4, tentative_unpreconditioning=False, mask=None)
# fprime = -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6
# symbolic_composition=False,symbolic_composition_order=4, tentative_unpreconditioning=False,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# Computed 1501 flowpipes in 74.79545155100641 sec
# In G.signal
# PolyObserver(x6 - 1, <flowstar.reachability.Reach object at 0x7f7a35103480>, -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6, symbolic_composition=False, symbolic_composition_order=4, tentative_unpreconditioning=False, mask=None)
# fprime = -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6
# symbolic_composition=False,symbolic_composition_order=4, tentative_unpreconditioning=False,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 64.98 seconds
# roots = [[0.86562109364728989 .. 1.2973760412304721]]
# domain = [0.0000000000000000 .. 4.5020000000000007]
# roots = [[0.86562109364728989 .. 1.2973760412304721]]
# seg_domain = [0.0000000000000000 .. 4.5020000000000007]
# roots = [[0.86562109364728989 .. 1.2973760412304721]]
# signal given bool roots: 1 items in 0.01 seconds
# In G.signal
# PolyObserver(-15625*x4^2 - 3*x6^2 + 93.75000000000001?*x4 + 3*x6 - 0.858625000000000?, <flowstar.reachability.Reach object at 0x7f7a35103480>, -31250*x2*x4*x6 + 0.600000000000000?*x1*x6^2 + 6*x2*x6^2 + 12*x6^2*x8 + 3125000*x4^2 - 0.3000000000000000?*x1*x6 + 90.750000000000000?*x2*x6 - 300*x3*x6 - 600*x4*x6 - 300*x5*x6 + 6*x6^2 - 6*x6*x8 + 150*x3 - 9075*x4 + 150*x5 - 3*x6, symbolic_composition=False, symbolic_composition_order=4, tentative_unpreconditioning=False, mask=None)
# fprime = -31250*x2*x4*x6 + 0.600000000000000?*x1*x6^2 + 6*x2*x6^2 + 12*x6^2*x8 + 3125000*x4^2 - 0.3000000000000000?*x1*x6 + 90.750000000000000?*x2*x6 - 300*x3*x6 - 600*x4*x6 - 300*x5*x6 + 6*x6^2 - 6*x6*x8 + 150*x3 - 9075*x4 + 150*x5 - 3*x6
# symbolic_composition=False,symbolic_composition_order=4, tentative_unpreconditioning=False,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 66.42 seconds
# roots = [[0.86562109364728989 .. 1.2973760412304721]]
# domain = [0.0000000000000000 .. 4.5020000000000007]
# roots = [[0.86562109364728989 .. 1.2973760412304721]]
# seg_domain = [0.0000000000000000 .. 4.5020000000000007]
# roots = [[0.86562109364728989 .. 1.2973760412304721]]
# signal given bool roots: 1 items in 0.01 seconds
# In G.signal
# PolyObserver(-15625*x4^2 - 3*x6^2 + 93.75000000000001?*x4 + 3*x6 - 0.858625000000000?, <flowstar.reachability.Reach object at 0x7f7a35103480>, -31250*x2*x4*x6 + 0.600000000000000?*x1*x6^2 + 6*x2*x6^2 + 12*x6^2*x8 + 3125000*x4^2 - 0.3000000000000000?*x1*x6 + 90.750000000000000?*x2*x6 - 300*x3*x6 - 600*x4*x6 - 300*x5*x6 + 6*x6^2 - 6*x6*x8 + 150*x3 - 9075*x4 + 150*x5 - 3*x6, symbolic_composition=False, symbolic_composition_order=4, tentative_unpreconditioning=False, mask=None)
# fprime = -31250*x2*x4*x6 + 0.600000000000000?*x1*x6^2 + 6*x2*x6^2 + 12*x6^2*x8 + 3125000*x4^2 - 0.3000000000000000?*x1*x6 + 90.750000000000000?*x2*x6 - 300*x3*x6 - 600*x4*x6 - 300*x5*x6 + 6*x6^2 - 6*x6*x8 + 150*x3 - 9075*x4 + 150*x5 - 3*x6
# symbolic_composition=False,symbolic_composition_order=4, tentative_unpreconditioning=False,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 5.80 seconds
# roots = [[1.8802545744613263 .. 4.5030000000001343]]
# domain = [0.0000000000000000 .. 4.5020000000000007]
# roots = [[1.8802545744613263 .. 4.5030000000001343]]
# seg_domain = [0.0000000000000000 .. 4.5020000000000007]
# roots = [[1.8802545744613263 .. 4.5030000000001343]]
# 0 at 4.50200000000001
# signal given bool roots: 1 items in 0.01 seconds
# ran "Precomposing Contexts" 1 times in 3.9577484130859375e-05
# ran "restoring globals" 16 times in 0.0015816688537597656
# ran "precomposing taylor models" 1 times in 0.11167550086975098
# ran "capturing globals [on exit]" 16 times in 0.0008933544158935547
# ran "Running Flow*" 1 times in 77.6504316329956
# ran "mask intersect check" 3002 times in 0.0061490535736083984
# ran "composing flowpipe" 3003 times in 62.396074533462524
# ran "whole domain eval" 3002 times in 4.363999605178833
# ran "post retrieve" 1020 times in 0.013468742370605469
# ran "root detection" 1020 times in 3.8182692527770996
# ran "root amalgamation" 1020 times in 0.0025191307067871094
# ran "prepare in check" 4 times in 3.170967102050781e-05
# ran "check boolean [unguarded]" 4 times in 0.005368709564208984
# ran "observer.check" 4 times in 0.006100893020629883
# ran "Monitoring atomic x6 > 1" 1 times in 64.99645233154297
# ran "Monitoring atomic 15625.0*(x4 - 0.003)^2 + 3*(x6 - 0.5)^2 < 0.032" 1 times in 5.815869092941284
# ran "Monitoring Signal for G([0 .. 1], x6 > 1 | G([3.0000000000000000 .. 3.5000000000000000], 15625.0*(x4 - 0.003)^2 + 3*(x6 - 0.5)^2 < 0.032))" 1 times in 70.90336537361145
# Run done in 148.60102820396423 sec
# options: {'instrumentor': <flowstar.instrumentation.AggregateMetric object at 0x7f7cb0822900>, 'use_masks': False, 'symbolic_composition': False, 'tentative_unpreconditioning': False, 'selective_unpreconditioning': True, 'precompose_taylor_models': True}
# top-level root detection: 1 items in 5.27 seconds
# roots = [[1.8802545744613263 .. 4.5030000000001343]]
# domain = [0.0000000000000000 .. 4.5020000000000007]
# roots = [[1.8802545744613263 .. 4.5030000000001343]]
# seg_domain = [0.0000000000000000 .. 4.5020000000000007]
# roots = [[1.8802545744613263 .. 4.5030000000001343]]
# 0 at 4.50200000000001
# signal given bool roots: 1 items in 0.01 seconds
# ran "Precomposing Contexts" 1 times in 5.1021575927734375e-05
# ran "restoring globals" 16 times in 0.0020940303802490234
# ran "precomposing taylor models" 1 times in 0.1219480037689209
# ran "capturing globals [on exit]" 16 times in 0.0008494853973388672
# ran "Running Flow*" 1 times in 74.74348139762878
# ran "mask intersect check" 3002 times in 0.00606226921081543
# ran "composing flowpipe" 3003 times in 63.7620530128479
# ran "whole domain eval" 3002 times in 4.209063291549683
# ran "post retrieve" 1020 times in 0.011559009552001953
# ran "root detection" 1020 times in 3.5234012603759766
# ran "root amalgamation" 1020 times in 0.0023758411407470703
# ran "prepare in check" 4 times in 3.600120544433594e-05
# ran "check boolean [unguarded]" 4 times in 0.005732536315917969
# ran "observer.check" 4 times in 0.0065631866455078125
# ran "Monitoring atomic x6 > 1" 1 times in 66.4399847984314
# ran "Monitoring atomic 15625.0*(x4 - 0.003)^2 + 3*(x6 - 0.5)^2 < 0.032" 1 times in 5.28465723991394
# ran "Monitoring Signal for G([0 .. 1], x6 > 1 | G([3.0000000000000000 .. 3.5000000000000000], 15625.0*(x4 - 0.003)^2 + 3*(x6 - 0.5)^2 < 0.032))" 1 times in 71.82398533821106
# Run done in 146.64499306678772 sec
# options: {'instrumentor': <flowstar.instrumentation.AggregateMetric object at 0x7f7a35853a00>, 'use_masks': False, 'symbolic_composition': False, 'tentative_unpreconditioning': False, 'selective_unpreconditioning': True, 'precompose_taylor_models': True}

# %%
results_upfront_selective = gen_results(
    num_runs,
    our_property,
    duration,
    task_description='Unmasked P | F(Q)',
    use_masks=False,
    symbolic_composition=False,
    tentative_unpreconditioning=False,
    selective_unpreconditioning=True,
    precompose_taylor_models=True,
)

# %%
results_upfront
# Out:
# [{'prop': G([0 .. 1], Or([Atomic(x6 > 1), G([3.0000000000000000 .. 3.5000000000000000], Atomic(15625.0*(x4 - 0.003)^2 + 3*(x6 - 0.5)^2 < 0.032))])),
#   'duration': 0,
#   'kwargs': {'use_masks': False,
#    'symbolic_composition': False,
#    'tentative_unpreconditioning': False,
#    'selective_unpreconditioning': False,
#    'precompose_taylor_models': True},
#   'future': <Future at 0x7f7cb08029d0 state=running>}]

# %%
results_upfront[0]['future'].result()[2].print()
# Out:
# ran "Precomposing Contexts" 1 times in 0.00031948089599609375
# ran "restoring globals" 16 times in 0.0016009807586669922
# ran "precomposing taylor models" 1 times in 0.14720630645751953
# ran "capturing globals [on exit]" 16 times in 0.0007693767547607422
# ran "Running Flow*" 1 times in 80.97084188461304
# ran "mask intersect check" 3002 times in 0.006283283233642578
# ran "composing flowpipe" 3003 times in 87.9956226348877
# ran "whole domain eval" 3002 times in 5.671474456787109
# ran "post retrieve" 1020 times in 0.010930776596069336
# ran "root detection" 1020 times in 4.564533233642578
# ran "root amalgamation" 1020 times in 0.0020542144775390625
# ran "prepare in check" 4 times in 3.123283386230469e-05
# ran "check boolean [unguarded]" 4 times in 0.007435798645019531
# ran "observer.check" 4 times in 0.00832819938659668
# ran "Monitoring atomic x6 > 1" 1 times in 91.66810250282288
# ran "Monitoring atomic 15625.0*(x4 - 0.003)^2 + 3*(x6 - 0.5)^2 < 0.032" 1 times in 6.798948049545288
# ran "Monitoring Signal for G([0 .. 1], x6 > 1 | G([3.0000000000000000 .. 3.5000000000000000], 15625.0*(x4 - 0.003)^2 + 3*(x6 - 0.5)^2 < 0.032))" 1 times in 100.6131100654602

# %%
results_unmasked[0]['future'].result()[2].print()
# Out:
# ran "Precomposing Contexts" 1 times in 4.100799560546875e-05
# ran "restoring globals" 16 times in 0.0013077259063720703
# ran "capturing globals [on exit]" 16 times in 0.011174678802490234
# ran "Running Flow*" 1 times in 94.82592558860779
# ran "mask intersect check" 3002 times in 0.007522106170654297
# ran "tentative eval" 2852 times in 3.563162326812744
# ran "composing flowpipe" 1232 times in 33.73382592201233
# ran "whole domain eval" 1229 times in 0.9744613170623779
# ran "post retrieve" 1020 times in 179.65458631515503
# ran "root detection" 1020 times in 0.05224752426147461
# ran "root amalgamation" 1020 times in 0.002878904342651367
# ran "prepare in check" 6 times in 0.0002009868621826172
# ran "check boolean [unguarded]" 6 times in 0.853543758392334
# ran "observer.check" 6 times in 0.9008610248565674
# ran "Monitoring atomic x6 > 1" 1 times in 13.564356565475464
# ran "Monitoring atomic 15625.0*(x4 - 0.003)^2 + 3*(x6 - 0.5)^2 < 0.032" 1 times in 205.59868741035461
# ran "Monitoring Signal for G([0 .. 1], x6 > 1 | G([3.0000000000000000 .. 3.5000000000000000], 15625.0*(x4 - 0.003)^2 + 3*(x6 - 0.5)^2 < 0.032))" 1 times in 219.2965853214264

# %%
results_masked[0]['future'].result()[2].print()
# Out:
# ran "Precomposing Contexts" 1 times in 3.838539123535156e-05
# ran "restoring globals" 16 times in 0.0014164447784423828
# ran "capturing globals [on exit]" 16 times in 0.012829780578613281
# ran "Running Flow*" 1 times in 84.2414300441742
# ran "mask intersect check" 3002 times in 0.009309530258178711
# ran "tentative eval" 537 times in 0.5782957077026367
# ran "composing flowpipe" 255 times in 8.412822008132935
# ran "whole domain eval" 252 times in 0.20586895942687988
# ran "post retrieve" 249 times in 55.982003688812256
# ran "root detection" 249 times in 0.01728200912475586
# ran "root amalgamation" 249 times in 0.0006272792816162109
# ran "prepare in check" 3 times in 3.170967102050781e-05
# ran "check boolean [unguarded]" 3 times in 0.4142189025878906
# ran "observer.check" 3 times in 0.4196441173553467
# ran "Monitoring atomic x6 > 1" 1 times in 4.450966835021973
# ran "Monitoring atomic 15625.0*(x4 - 0.003)^2 + 3*(x6 - 0.5)^2 < 0.032" 1 times in 61.28880429267883
# ran "Monitoring Signal for G([0 .. 1], x6 > 1 | G([3.0000000000000000 .. 3.5000000000000000], 15625.0*(x4 - 0.003)^2 + 3*(x6 - 0.5)^2 < 0.032))" 1 times in 65.85427856445312

# %%
results_two_pass[0]['future'].result()[1]
# Out:
# 93.11413216590881

# %%
results_masked0[0]['future'].result()[1]
# Out:
# 115.2804765701294

# %%
results_two_pass[0]['future'].result()[0]
# Out:
# Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=Mask([0.0000000000000000 .. -0.0000000000000000], [[0.0000000000000000 .. -0.0000000000000000]]))

# %%
results_masked0[0]['future'].result()[0]
# Out:
# Signal([0.0000000000000000 .. -0.0000000000000000], [([0.0000000000000000 .. -0.0000000000000000], True)], mask=Mask([0.0000000000000000 .. -0.0000000000000000], [[0.0000000000000000 .. -0.0000000000000000]]))

# %%
results_two_pass = gen_results(
    num_runs,
    our_property,
    duration,
    task_description='Unmasked P | F(Q)',
    use_masks=True,
    two_pass_masks=True,
    symbolic_composition=True,
)

# %%
results_unmasked = gen_results(
    num_runs,
    our_property,
    duration,
    task_description='Unmasked P | F(Q)',
    use_masks=False,
    symbolic_composition=True,
)

# %%
results_masked = gen_results(
    num_runs,
    our_property,
    duration,
    task_description='Masked P | F(Q)',
    use_masks=True,
    symbolic_composition=True,
)

# %%
results_masked_symbolic_low_order = gen_results(
    num_runs,
    our_property,
    duration,
    task_description='Masked P | F(Q)',
    use_masks=True,
    symbolic_composition=True,
    symbolic_composition_order=2,
#    unpreconditioning_order=2,
)

# %%
results_masked_low_unprec_order = gen_results(
    num_runs,
    our_property,
    duration,
    task_description='Masked P | F(Q)',
    use_masks=True,
    symbolic_composition=True,
#    symbolic_composition_order=2,
    unpreconditioning_order=2,
)

# %%
results_masked_no_symbolic = gen_results(
    num_runs,
    our_property,
    duration,
    task_description='Masked P | F(Q)',
    use_masks=True,
    symbolic_composition=False,
)

# %%
results_unmasked_no_symbolic = gen_results(
    num_runs,
    our_property,
    duration,
    task_description='Unmasked P | F(Q)',
    use_masks=False,
    symbolic_composition=False,
)

# %%
results_masked_no_symbolic_no_selective = gen_results(
    num_runs,
    our_property,
    duration,
    task_description='Masked P | F(Q) no sym no sel',
    use_masks=True,
    symbolic_composition=False,
    selective_unpreconditioning=False,
    
)

# %%
results_masked_no_selective = gen_results(
    num_runs,
    our_property,
    duration,
    task_description='Masked P | F(Q) no sel',
    use_masks=True,
    symbolic_composition=True,
    selective_unpreconditioning=False,
    
)

# %%
results_unmasked_reversed = gen_results(
    num_runs,
    our_property_reversed,
    duration,
    task_description='Unmasked F(Q) | P',
    use_masks=False,
    symbolic_composition=True,
)

# %%
results_unmasked_reversed0
# Out:
# [{'prop': G([0 .. 1], Or([Atomic(x6 > 1), G([3.0000000000000000 .. 3.5000000000000000], Atomic(15625.0*(x4 - 0.003)^2 + 3*(x6 - 0.5)^2 < 0.032))])),
#   'duration': 0,
#   'kwargs': {'use_masks': False, 'symbolic_composition': True},
#   'future': <Future at 0x7ff0aa019fa0 state=running>}]

# %%
results_masked_reversed = gen_results(
    num_runs,
    our_property_reversed,
    duration,
    task_description='Masked F(Q) & P',
    use_masks=True,
    symbolic_composition=True,
)

# %% [markdown]
# # Analysis

# %%
import pandas as pd

# %%
def total_time_for_key(inst, ks):
    if isinstance(ks, str):
        ks = [ks]

    return sum(inst.total_time(k)
               for k in ks)


def total_times(results, keys, keys_short=None):
    ress = [
        f.result() for f in futures(results)
    ]
    if keys_short is None:
        keys_short = keys
    data = pd.DataFrame({
        short_key: [total_time_for_key(r[2], key) for r in ress]
        for short_key, key in zip(keys_short, keys)
    })
    data.insert(len(keys), 'Total',
                [r[1] for r in ress])
    return data

# %%
results_masked_no_symbolic_no_selective[0]['future'].result()[2].events
# Out:
# ['Precomposing Contexts',
#  'restoring globals',
#  'capturing globals [on exit]',
#  'Running Flow*',
#  'mask intersect check',
#  'tentative eval',
#  'composing flowpipe',
#  'whole domain eval',
#  'post retrieve',
#  'root detection',
#  'root amalgamation',
#  'prepare in check',
#  'check boolean [unguarded]',
#  'observer.check',
#  'Monitoring atomic x6 > 1',
#  'Monitoring atomic 15625.0*(x4 - 0.003)^2 + 3*(x6 - 0.5)^2 < 0.032',
#  'Monitoring Signal for G([0 .. 1], x6 > 1 | G([3.0000000000000000 .. 3.5000000000000000], 15625.0*(x4 - 0.003)^2 + 3*(x6 - 0.5)^2 < 0.032))']

# %%
results_upfront[0]['future'].result()[2].print()
# Out:
# ran "Precomposing Contexts" 1 times in 0.00029158592224121094
# ran "restoring globals" 16 times in 0.0016891956329345703
# ran "precomposing taylor models" 1 times in 0.11809945106506348
# ran "capturing globals [on exit]" 16 times in 0.0006480216979980469
# ran "Running Flow*" 1 times in 109.23899984359741
# ran "mask intersect check" 3002 times in 0.0072841644287109375
# ran "composing flowpipe" 3003 times in 101.35144376754761
# ran "whole domain eval" 3002 times in 6.662598133087158
# ran "post retrieve" 1020 times in 0.016840219497680664
# ran "root detection" 1020 times in 5.7078704833984375
# ran "root amalgamation" 1020 times in 0.003879070281982422
# ran "prepare in check" 4 times in 3.123283386230469e-05
# ran "check boolean [unguarded]" 4 times in 0.006696224212646484
# ran "observer.check" 4 times in 0.00768589973449707
# ran "Monitoring atomic x6 > 1" 1 times in 105.46877264976501
# ran "Monitoring atomic 15625.0*(x4 - 0.003)^2 + 3*(x6 - 0.5)^2 < 0.032" 1 times in 8.563345670700073
# ran "Monitoring Signal for G([0 .. 1], x6 > 1 | G([3.0000000000000000 .. 3.5000000000000000], 15625.0*(x4 - 0.003)^2 + 3*(x6 - 0.5)^2 < 0.032))" 1 times in 115.9589512348175

# %%
cols_full = [
    'Running Flow*',
    'precomposing taylor models',
    f'Monitoring atomic {P}',
    f'Monitoring atomic {Q}',
    [
        f'Monitoring Signal for {our_property}',
        f'Monitoring Signal for {our_property_reversed}',
    ],
    'tentative eval',
    'root detection',
    'composing flowpipe',
    'post retrieve',
]
cols_short = [
    'Flow*', 'Unpreconditioning',
    'P', 'Q', 'G(P | G(Q))',
    'tentative eval',
    'root detection',
    'composing flowpipe',
    'composing atomic',
]

# %% [markdown]
# ## Raw results

# %%
total_times(
    results_upfront,
    cols_full,
    cols_short,
)
# Out:
#         Flow*  Unpreconditioning           P         Q  G(P | G(Q))  \
# 0  109.239000           0.118099  105.468773  8.563346   231.917902
# 1  107.012247           0.120647  104.322495  9.035565   230.669500
# 2   99.246521           0.140452  104.379261  8.603285   230.604804
# 3   99.969739           0.140656  108.051848  9.235936   239.291677
# 4   90.533510           0.109799  108.000222  8.495092   233.255519
# 5   86.013916           0.130755  105.657264  8.445936   228.481671
# 6   86.932083           0.105515  107.828272  8.670983   233.278850
# 7   93.474801           0.112296  105.821365  9.043494   229.987893
# 8   90.714642           0.118332  110.970428  9.351387   240.935416
# 9   89.110667           0.113012  109.071407  8.805023   236.063622
#
#    tentative eval  root detection  composing flowpipe  composing atomic  \
# 0             0.0        5.707870          101.351444          0.016840
# 1             0.0        5.814358          100.188188          0.016201
# 2             0.0        5.798309          100.247671          0.016523
# 3             0.0        6.110958          103.769177          0.017838
# 4             0.0        5.810019          103.631571          0.016913
# 5             0.0        5.671627          101.370881          0.016367
# 6             0.0        5.908094          103.483965          0.016658
# 7             0.0        6.030920          101.661645          0.017554
# 8             0.0        6.282030          106.448163          0.019056
# 9             0.0        6.081074          104.586216          0.018182
#
#         Total
# 0  225.258509
# 1  222.396059
# 2  214.621197
# 3  219.659203
# 4  207.198151
# 5  200.301984
# 6  203.609087
# 7  208.518154
# 8  211.260768
# 9  207.223966

# %%
times_unmasked['Flow*'].std()
# Out:
# 1.4042072544035247

# %% [markdown]
# ## Export Data

# %%
series = [
    'masked',
    'masked_no_symbolic',
    'masked_no_symbolic_no_selective',
    'masked_no_selective',
    'masked_symbolic_low_order',
    'unmasked',
    'unmasked_no_symbolic',
    'upfront',
    'upfront_selective',
    'masked_reversed',
    'unmasked_reversed',
]
# total_timess = {
#    s: pd.load_csv(f'data/analysis3_raw_{s}.csv')
#    for s in series 
# }
total_timess = {
    s: total_times(eval(f'results_{s}'), cols_full, cols_short)
    for s in series 
}

# %%
for s, d in total_timess.items():
    d.to_csv(f'data/benchmark_{s}.csv', index_label=False)
