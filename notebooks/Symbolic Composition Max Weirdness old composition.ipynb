# %% [markdown]
# # Tests

# %% [markdown]
# ## Example 1: Simple

# %%
import sys

sys.path.insert(0, "/home/twright/Documents/PhD/Notebooks")

from flowstar.reachability import Reach
from flowstar.poly import Poly
from ulbc import *

# %%
kwargs = {
    'symbolic_composition': True,
}

# %%
R.<t,x,y> = RIF[]

# %%
odes = [
    R(1),
    -y,
    x,
]
initials = [(0,0), (4,5), (1,2)]
system = System(
    R,
    [t, x, y],
    initials,
    odes,
)
reach = system.reach(2*pi, step=0.1, order=10,
              precompose_taylor_models=False,
              symbolic_composition=False)
reach_sc = system.reach(2*pi, step=0.1, order=10,
              precompose_taylor_models=False,
              symbolic_composition=True)
# Out:
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.0000000000000000 .. 5.0000000000000000]', '[1.0000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.0..5.0]
# C = [1.0..2.0]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.0000000000000000 .. 5.0000000000000000]', '[1.0000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.0..5.0]
# C = [1.0..2.0]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2

# %%
def plot_signal(sig):
    return sig.to_domain(RIF(0,2*pi)).plot().show(
        ticks=[pi/2, 1], tick_formatter=pi, aspect_ratio=2/3)

# %%
reach.res
# Out:
# 2

# %%
S = Atomic(3 - y**2 + y + x**5 + x**3*y**6); S
# Out:
# Atomic(x^3*y^6 + x^5 - y^2 + y + 3)

# %%
p1 = S.sage_plot(reach); p1
# Out:
# PolyObserver(x^3*y^6 + x^5 - y^2 + y + 3, <flowstar.reachability.Reach object at 0x7fe72e3ddd60>, 6*x^4*y^5 - 3*x^2*y^7 - 5*x^4*y - 2*x*y + x, symbolic_composition=False, tentative_unpreconditioning=True, mask=None)
# fprime = 6*x^4*y^5 - 3*x^2*y^7 - 5*x^4*y - 2*x*y + x
# /usr/lib64/python3.8/site-packages/numpy/core/getlimits.py:400: UserWarning: Signature b'\x99\x99\x99\x99\x99\x99\xb9\xbf' for <class 'numpy.float64'> does not match any known type: falling back to type probe function
#   machar = _get_machar(dtype)
# Graphics object consisting of 3 graphics primitives

# %%
p2 = S.sage_plot(reach, symbolic_composition=True,
                color=('orange', 'orange'),
                fillcolor=('orange',)); p2
# Out:
# PolyObserver(x^3*y^6 + x^5 - y^2 + y + 3, <flowstar.reachability.Reach object at 0x7fe72e3ddd60>, 6*x^4*y^5 - 3*x^2*y^7 - 5*x^4*y - 2*x*y + x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 6*x^4*y^5 - 3*x^2*y^7 - 5*x^4*y - 2*x*y + x
# Graphics object consisting of 3 graphics primitives

# %%
p1+p2
# Out:
# Graphics object consisting of 6 graphics primitives

# %%
sig1 = S.signal_for_system(system, 2*pi, symbolic_composition=False)
sig2 = S.signal_for_system(system, 2*pi, symbolic_composition=True)

graphics_array([
    sig1.plot(),
    sig2.plot(),
], ncols=1)
# Out:
# Precomposing Contexts: 1 items in 0.00 seconds
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.0000000000000000 .. 5.0000000000000000]', '[1.0000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.0..5.0]
# C = [1.0..2.0]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# Running Flow*: 1 items in 0.07 seconds
# Computed 63 flowpipes in 0.07481760304654017 sec
# PolyObserver(x^3*y^6 + x^5 - y^2 + y + 3, <flowstar.reachability.Reach object at 0x7fe726887f20>, 6*x^4*y^5 - 3*x^2*y^7 - 5*x^4*y - 2*x*y + x, symbolic_composition=False, tentative_unpreconditioning=True, mask=None)
# fprime = 6*x^4*y^5 - 3*x^2*y^7 - 5*x^4*y - 2*x*y + x
# symbolic_composition=False, tentative_unpreconditioning=True,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.13 seconds
# roots = [[1.0500091210691917 .. 1.4000000000000011], [4.1999999999999770 .. 4.6000000000000068]]
# domain = [0.0000000000000000 .. 6.2851853071795869]
# roots = [[1.0500091210691917 .. 1.4000000000000011],
#  [4.1999999999999770 .. 4.6000000000000068]]
# seg_domain = [0.0000000000000000 .. 6.2851853071795869]
# roots = [[1.0500091210691917 .. 1.4000000000000011],
#  [4.1999999999999770 .. 4.6000000000000068]]
# signal given bool roots: 1 items in 0.00 seconds
# Monitoring atomic x^3*y^6 + x^5 - y^2 + y + 3 > 0: 1 items in 0.14 seconds
# Monitoring Signal for x^3*y^6 + x^5 - y^2 + y + 3 > 0: 1 items in 0.15 seconds
# ran "restoring globals" 9 times in 0.00017070770263671875
# ran "capturing globals [on exit]" 9 times in 0.00012040138244628906
# ran "mask intersect check" 63 times in 0.0001773834228515625
# ran "tentative eval" 63 times in 0.015947341918945312
# ran "composing flowpipe" 8 times in 0.020186424255371094
# ran "whole domain eval" 8 times in 0.0026247501373291016
# ran "post retrieve" 8 times in 8.440017700195312e-05
# ran "root detection" 8 times in 0.08315753936767578
# ran "root amalgamation" 8 times in 3.5762786865234375e-05
# ran "prepare in check" 3 times in 2.7894973754882812e-05
# ran "check boolean [unguarded]" 3 times in 6.198883056640625e-05
# ran "observer.check" 3 times in 0.0003039836883544922
# Precomposing Contexts: 1 items in 0.00 seconds
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.0000000000000000 .. 5.0000000000000000]', '[1.0000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.0..5.0]
# C = [1.0..2.0]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# Running Flow*: 1 items in 0.06 seconds
# Computed 63 flowpipes in 0.05583154904888943 sec
# PolyObserver(x^3*y^6 + x^5 - y^2 + y + 3, <flowstar.reachability.Reach object at 0x7fe724653f20>, 6*x^4*y^5 - 3*x^2*y^7 - 5*x^4*y - 2*x*y + x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 6*x^4*y^5 - 3*x^2*y^7 - 5*x^4*y - 2*x*y + x
# symbolic_composition=True, tentative_unpreconditioning=True,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 5.97 seconds
# roots = [[0.99999999999999900 .. 1.4000000000000011], [4.1999999999999770 .. 4.6000000000000068]]
# domain = [0.0000000000000000 .. 6.2851853071795869]
# roots = [[0.99999999999999900 .. 1.4000000000000011],
#  [4.1999999999999770 .. 4.6000000000000068]]
# seg_domain = [0.0000000000000000 .. 6.2851853071795869]
# roots = [[0.99999999999999900 .. 1.4000000000000011],
#  [4.1999999999999770 .. 4.6000000000000068]]
# signal given bool roots: 1 items in 0.00 seconds
# Monitoring atomic x^3*y^6 + x^5 - y^2 + y + 3 > 0: 1 items in 5.97 seconds
# Monitoring Signal for x^3*y^6 + x^5 - y^2 + y + 3 > 0: 1 items in 5.99 seconds
# ran "restoring globals" 9 times in 0.00016021728515625
# ran "capturing globals [on exit]" 9 times in 0.0001270771026611328
# ran "mask intersect check" 63 times in 0.0002205371856689453
# ran "tentative eval" 63 times in 0.016808748245239258
# ran "composing flowpipe" 8 times in 0.005065441131591797
# ran "whole domain eval" 8 times in 0.002635478973388672
# ran "post retrieve" 8 times in 5.9419190883636475
# ran "root detection" 8 times in 0.00055694580078125
# ran "root amalgamation" 8 times in 3.24249267578125e-05
# ran "prepare in check" 3 times in 4.029273986816406e-05
# ran "check boolean [unguarded]" 3 times in 4.8160552978515625e-05
# ran "observer.check" 3 times in 0.00021600723266601562
# Deallocing CReach
# Deallocing CReach
# Graphics Array of size 2 x 1

# %%
sig1
# Out:
# Signal([0.0000000000000000 .. 6.2831853071795872], [([0.0000000000000000 .. 1.0500091210691918], True), ([1.4000000000000010 .. 4.1999999999999771], False), ([4.6000000000000067 .. 6.2831853071795872], True)], mask=None)

# %%
sig2
# Out:
# Signal([0.0000000000000000 .. 6.2831853071795872], [([0.0000000000000000 .. 0.99999999999999901], True), ([1.4000000000000010 .. 4.1999999999999771], False), ([4.6000000000000067 .. 6.2831853071795872], True)], mask=None)
