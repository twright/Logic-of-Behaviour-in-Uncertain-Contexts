# %% [markdown]
# # Tests

# %% [markdown]
# ## Example 1: Simple

# %%
import sys

sys.path.insert(0, "/home/twright/Documents/PhD/Notebooks")

from flowstar.reachability import Reach
from flowstar.poly import Poly
from ulbc import *

# %%
kwargs = {
    'symbolic_composition': True,
}

# %%
R.<t,x,y> = RIF[]

# %%
TM_ORDER = 10
UNPRECONDITIONING_ORDER = 2

# %%
odes = [
    R(1),
    -y,
    x,
]
initials = [(0,0), (4,5), (1,2)]
system = System(
    R,
    [t, x, y],
    initials,
    odes,
)
reach = system.reach(2*pi, step=0.8, order=TM_ORDER,
              precompose_taylor_models=False,
              unpreconditioning_order=UNPRECONDITIONING_ORDER,
              symbolic_composition=False)
reach_superfine = system.reach(2*pi, step=0.01, order=TM_ORDER,
              precompose_taylor_models=False,
              symbolic_composition=False)
# Out:
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.0000000000000000 .. 5.0000000000000000]', '[1.0000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.0..5.0]
# C = [1.0..2.0]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.0000000000000000 .. 5.0000000000000000]', '[1.0000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.0..5.0]
# C = [1.0..2.0]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2

# %%
[4 + x for x in srange(0, 1, 0.1, include_endpoint=True)]
# Out:
# [4.00000000000000,
#  4.10000000000000,
#  4.20000000000000,
#  4.30000000000000,
#  4.40000000000000,
#  4.50000000000000,
#  4.60000000000000,
#  4.70000000000000,
#  4.80000000000000,
#  4.90000000000000,
#  5.00000000000000]

# %%
reach_points = [system.with_y0([(0,0), (4 + k), (1 + k)]).reach(2*pi, step=0.01, order=TM_ORDER,
              precompose_taylor_models=False,
              symbolic_composition=False)
    for k in srange(0, 1, 0.1, include_endpoint=True)]
reach_bands = [system.with_y0([(0,0), (4 + k, 4.1 + k), (1 + k, 1.1 + k)]).reach(2*pi, step=0.01, order=TM_ORDER,
               precompose_taylor_models=False,
               symbolic_composition=False)
     for k in srange(0, 1, 0.1, include_endpoint=False)]
# Out:
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.0000000000000000 .. 4.0000000000000000]', '[1.0000000000000000 .. 1.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.0..4.0]
# C = [1.0..1.0]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.0999999999999996 .. 4.0999999999999997]', '[1.1000000000000000 .. 1.1000000000000001]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.1..4.1]
# C = [1.1..1.1]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.2000000000000001 .. 4.2000000000000002]', '[1.1999999999999999 .. 1.2000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.2..4.2]
# C = [1.2..1.2]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.2999999999999998 .. 4.2999999999999999]', '[1.3000000000000000 .. 1.3000000000000001]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.3..4.3]
# C = [1.3..1.3]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.4000000000000003 .. 4.4000000000000004]', '[1.3999999999999999 .. 1.4000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.4..4.4]
# C = [1.4..1.4]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.5000000000000000 .. 4.5000000000000000]', '[1.5000000000000000 .. 1.5000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.5..4.5]
# C = [1.5..1.5]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.5999999999999996 .. 4.5999999999999997]', '[1.6000000000000000 .. 1.6000000000000001]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.6..4.6]
# C = [1.6..1.6]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.7000000000000001 .. 4.7000000000000002]', '[1.6999999999999999 .. 1.7000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.7..4.7]
# C = [1.7..1.7]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.7999999999999998 .. 4.7999999999999999]', '[1.7999999999999998 .. 1.7999999999999999]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.8..4.8]
# C = [1.7999999999999998..1.7999999999999998]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.9000000000000003 .. 4.9000000000000004]', '[1.8999999999999999 .. 1.9000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.9..4.9]
# C = [1.9..1.9]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[5.0000000000000000 .. 5.0000000000000000]', '[2.0000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [5.0..5.0]
# C = [2.0..2.0]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.0000000000000000 .. 4.0999999999999997]', '[1.0000000000000000 .. 1.1000000000000001]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.0..4.1]
# C = [1.0..1.1]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.0999999999999996 .. 4.1999999999999993]', '[1.1000000000000000 .. 1.2000000000000002]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.1..4.199999999999999]
# C = [1.1..1.2000000000000002]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.2000000000000001 .. 4.2999999999999999]', '[1.1999999999999999 .. 1.3000000000000001]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.2..4.3]
# C = [1.2..1.3]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.2999999999999998 .. 4.3999999999999995]', '[1.3000000000000000 .. 1.4000000000000002]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.3..4.3999999999999995]
# C = [1.3..1.4000000000000001]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.4000000000000003 .. 4.5000000000000000]', '[1.3999999999999999 .. 1.5000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.4..4.5]
# C = [1.4..1.5]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.5000000000000000 .. 4.5999999999999997]', '[1.5000000000000000 .. 1.6000000000000001]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.5..4.6]
# C = [1.5..1.6]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.5999999999999996 .. 4.6999999999999993]', '[1.6000000000000000 .. 1.7000000000000002]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.6..4.699999999999999]
# C = [1.6..1.7000000000000002]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.7000000000000001 .. 4.7999999999999999]', '[1.6999999999999999 .. 1.8000000000000001]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.7..4.8]
# C = [1.7..1.8]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.7999999999999998 .. 4.8999999999999995]', '[1.7999999999999998 .. 1.9000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.8..4.8999999999999995]
# C = [1.7999999999999998..1.9]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.9000000000000003 .. 5.0000000000000000]', '[1.8999999999999999 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.9..5.0]
# C = [1.9..2.0]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2

# %%
def plot_signal(sig):
    return sig.to_domain(RIF(0,2*pi)).plot().show(
        ticks=[pi/2, 1], tick_formatter=pi, aspect_ratio=2/3)

# %%
reach.res
# Out:
# 2

# %%
#S = Atomic(x + 1); S

# %%
S = Atomic(7 - (x + 1)**2 + y + x); S
# Out:
# Atomic(-x^2 - x + y + 6)

# %%
#S = Atomic(3 - y**2 + y); S

# %%
# Very Weird S
#S = Atomic(3 - y**2 + y + x**5 + x**3*y**6); S

# %%
p_points = sum([
    S.sage_plot(r, symbolic_composition=False,
                color=('black', 'black'),
                fillcolor=('black',))
    for r in reach_points
], Graphics())
# p_points += sum([
#     S.sage_plot(r, symbolic_composition=False,
#                 color=('grey', 'grey'),
#                 fillcolor=('grey',))
#     for r in reach_bands
# ], Graphics())
p_points
# Out:
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7f00a8475480>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7f00a8475590>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7f00a84756a0>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7f00a84757b0>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7f00a84758c0>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7f00a84759d0>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7f00a8475ae0>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7f00a8475bf0>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7f00a8475d00>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7f00a8475e10>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7f00a83dd040>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# Graphics object consisting of 33 graphics primitives

# %%
p1 = S.sage_plot(reach); p1 + p_points
# Out:
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7f00a8475150>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=2, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# Graphics object consisting of 36 graphics primitives

# %%
SYMBOLIC_COMPOSITION_ORDER = None

# %%
p2 = S.sage_plot(
    reach, symbolic_composition=True,
    symbolic_composition_order=SYMBOLIC_COMPOSITION_ORDER,
    color=('orange', 'orange'),
    fillcolor=('orange',),
)
p2 + p_points
# Out:
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7f00a8475150>, 2*x*y + x + y, symbolic_composition=True, symbolic_composition_order=2, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# Graphics object consisting of 36 graphics primitives

# %%
p1+p2+p_points
# Out:
# Graphics object consisting of 39 graphics primitives

# %%
SELECTIVE_UNPRECONDITIONING = True

# %%
from functools import reduce

# %%
combined_signal = reduce(
    lambda a, b: a & b,
    (S.signal(r, symbolic_composition=False)
     for r in reach_bands),
)
combined_signal.plot()
# Out:
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7f00a83dd150>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# symbolic_composition=False,symbolic_composition_order=10, tentative_unpreconditioning=True,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.46 seconds
# roots = [[0.62791369907788041 .. 0.67211372988242580], [2.2541501400618710 .. 2.3100000000000090], [3.8934898090738916 .. 3.9568519971007814], [4.6757251763164164 .. 4.7124714978029374]]
# domain = [0.0000000000000000 .. 6.2831853071795863]
# roots = [[0.62791369907788041 .. 0.67211372988242580],
#  [2.2541501400618710 .. 2.3100000000000090],
#  [3.8934898090738916 .. 3.9568519971007814],
#  [4.6757251763164164 .. 4.7124714978029374]]
# seg_domain = [0.0000000000000000 .. 6.2831853071795863]
# roots = [[0.62791369907788041 .. 0.67211372988242580],
#  [2.2541501400618710 .. 2.3100000000000090],
#  [3.8934898090738916 .. 3.9568519971007814],
#  [4.6757251763164164 .. 4.7124714978029374]]
# signal given bool roots: 1 items in 0.00 seconds
# Monitoring atomic -x^2 - x + y + 6 > 0: 1 items in 0.47 seconds
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7f00a83dd260>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# symbolic_composition=False,symbolic_composition_order=10, tentative_unpreconditioning=True,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.47 seconds
# roots = [[0.62782451729606125 .. 0.67031570749736125], [2.2100952666443545 .. 2.2630012022123643], [3.9092381706334142 .. 3.9700000000000473], [4.6406878119917767 .. 4.6781092209874249]]
# domain = [0.0000000000000000 .. 6.2831853071795863]
# roots = [[0.62782451729606125 .. 0.67031570749736125],
#  [2.2100952666443545 .. 2.2630012022123643],
#  [3.9092381706334142 .. 3.9700000000000473],
#  [4.6406878119917767 .. 4.6781092209874249]]
# seg_domain = [0.0000000000000000 .. 6.2831853071795863]
# roots = [[0.62782451729606125 .. 0.67031570749736125],
#  [2.2100952666443545 .. 2.2630012022123643],
#  [3.9092381706334142 .. 3.9700000000000473],
#  [4.6406878119917767 .. 4.6781092209874249]]
# signal given bool roots: 1 items in 0.00 seconds
# Monitoring atomic -x^2 - x + y + 6 > 0: 1 items in 0.48 seconds
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7f00a83dd370>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# symbolic_composition=False,symbolic_composition_order=10, tentative_unpreconditioning=True,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.38 seconds
# roots = [[0.62778287164931234 .. 0.66910243319835506], [2.1694591052698370 .. 2.2192274061760205], [3.9240675002036962 .. 3.9817104962516528], [4.6078318966568119 .. 4.6449079943719358]]
# domain = [0.0000000000000000 .. 6.2831853071795863]
# roots = [[0.62778287164931234 .. 0.66910243319835506],
#  [2.1694591052698370 .. 2.2192274061760205],
#  [3.9240675002036962 .. 3.9817104962516528],
#  [4.6078318966568119 .. 4.6449079943719358]]
# seg_domain = [0.0000000000000000 .. 6.2831853071795863]
# roots = [[0.62778287164931234 .. 0.66910243319835506],
#  [2.1694591052698370 .. 2.2192274061760205],
#  [3.9240675002036962 .. 3.9817104962516528],
#  [4.6078318966568119 .. 4.6449079943719358]]
# signal given bool roots: 1 items in 0.00 seconds
# Monitoring atomic -x^2 - x + y + 6 > 0: 1 items in 0.38 seconds
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7f00a83dd480>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# symbolic_composition=False,symbolic_composition_order=10, tentative_unpreconditioning=True,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.36 seconds
# roots = [[0.62778302452084289 .. 0.66757863656932959], [2.1307656306113247 .. 2.1779539725683997], [3.9378471906630205 .. 3.9934703190188992], [4.5761962448740529 .. 4.6131698604191298]]
# domain = [0.0000000000000000 .. 6.2831853071795863]
# roots = [[0.62778302452084289 .. 0.66757863656932959],
#  [2.1307656306113247 .. 2.1779539725683997],
#  [3.9378471906630205 .. 3.9934703190188992],
#  [4.5761962448740529 .. 4.6131698604191298]]
# seg_domain = [0.0000000000000000 .. 6.2831853071795863]
# roots = [[0.62778302452084289 .. 0.66757863656932959],
#  [2.1307656306113247 .. 2.1779539725683997],
#  [3.9378471906630205 .. 3.9934703190188992],
#  [4.5761962448740529 .. 4.6131698604191298]]
# signal given bool roots: 1 items in 0.00 seconds
# Monitoring atomic -x^2 - x + y + 6 > 0: 1 items in 0.37 seconds
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7f00a83dd590>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# symbolic_composition=False,symbolic_composition_order=10, tentative_unpreconditioning=True,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.36 seconds
# roots = [[0.62782002169215578 .. 0.66619356245231521], [2.0949222513871079 .. 2.1392770955973748], [3.9509538073266199 .. 4.0046877121013794], [4.5457939290196067 .. 4.5827414763616555]]
# domain = [0.0000000000000000 .. 6.2831853071795863]
# roots = [[0.62782002169215578 .. 0.66619356245231521],
#  [2.0949222513871079 .. 2.1392770955973748],
#  [3.9509538073266199 .. 4.0046877121013794],
#  [4.5457939290196067 .. 4.5827414763616555]]
# seg_domain = [0.0000000000000000 .. 6.2831853071795863]
# roots = [[0.62782002169215578 .. 0.66619356245231521],
#  [2.0949222513871079 .. 2.1392770955973748],
#  [3.9509538073266199 .. 4.0046877121013794],
#  [4.5457939290196067 .. 4.5827414763616555]]
# signal given bool roots: 1 items in 0.00 seconds
# Monitoring atomic -x^2 - x + y + 6 > 0: 1 items in 0.36 seconds
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7f00a83dd6a0>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# symbolic_composition=False,symbolic_composition_order=10, tentative_unpreconditioning=True,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.39 seconds
# roots = [[0.62788956655213501 .. 0.66493935789183778], [2.0604460752430484 .. 2.1026558055426792], [3.9637287199174462 .. 4.0157824566980294], [4.5164801966147454 .. 4.5534830547390524]]
# domain = [0.0000000000000000 .. 6.2831853071795863]
# roots = [[0.62788956655213501 .. 0.66493935789183778],
#  [2.0604460752430484 .. 2.1026558055426792],
#  [3.9637287199174462 .. 4.0157824566980294],
#  [4.5164801966147454 .. 4.5534830547390524]]
# seg_domain = [0.0000000000000000 .. 6.2831853071795863]
# roots = [[0.62788956655213501 .. 0.66493935789183778],
#  [2.0604460752430484 .. 2.1026558055426792],
#  [3.9637287199174462 .. 4.0157824566980294],
#  [4.5164801966147454 .. 4.5534830547390524]]
# signal given bool roots: 1 items in 0.00 seconds
# Monitoring atomic -x^2 - x + y + 6 > 0: 1 items in 0.40 seconds
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7f00a83dd7b0>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# symbolic_composition=False,symbolic_composition_order=10, tentative_unpreconditioning=True,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.35 seconds
# roots = [[0.62798791755829685 .. 0.66389618966119857], [2.0284774025523786 .. 2.0684169333821121], [3.9758498435917775 .. 4.0267498863258036], [4.4881215408549106 .. 4.5252578865571334]]
# domain = [0.0000000000000000 .. 6.2831853071795863]
# roots = [[0.62798791755829685 .. 0.66389618966119857],
#  [2.0284774025523786 .. 2.0684169333821121],
#  [3.9758498435917775 .. 4.0267498863258036],
#  [4.4881215408549106 .. 4.5252578865571334]]
# seg_domain = [0.0000000000000000 .. 6.2831853071795863]
# roots = [[0.62798791755829685 .. 0.66389618966119857],
#  [2.0284774025523786 .. 2.0684169333821121],
#  [3.9758498435917775 .. 4.0267498863258036],
#  [4.4881215408549106 .. 4.5252578865571334]]
# signal given bool roots: 1 items in 0.00 seconds
# Monitoring atomic -x^2 - x + y + 6 > 0: 1 items in 0.36 seconds
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7f00a83dd8c0>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# symbolic_composition=False,symbolic_composition_order=10, tentative_unpreconditioning=True,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.35 seconds
# roots = [[0.62811180411586853 .. 0.66291318062111627], [1.9980008762210670 .. 2.0358613379788966], [3.9877988909551498 .. 4.0376533138695976], [4.4601319481322763 .. 4.4979696507852048]]
# domain = [0.0000000000000000 .. 6.2831853071795863]
# roots = [[0.62811180411586853 .. 0.66291318062111627],
#  [1.9980008762210670 .. 2.0358613379788966],
#  [3.9877988909551498 .. 4.0376533138695976],
#  [4.4601319481322763 .. 4.4979696507852048]]
# seg_domain = [0.0000000000000000 .. 6.2831853071795863]
# roots = [[0.62811180411586853 .. 0.66291318062111627],
#  [1.9980008762210670 .. 2.0358613379788966],
#  [3.9877988909551498 .. 4.0376533138695976],
#  [4.4601319481322763 .. 4.4979696507852048]]
# signal given bool roots: 1 items in 0.00 seconds
# Monitoring atomic -x^2 - x + y + 6 > 0: 1 items in 0.35 seconds
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7f00a83dd9d0>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# symbolic_composition=False,symbolic_composition_order=10, tentative_unpreconditioning=True,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.36 seconds
# roots = [[0.62825835714841304 .. 0.66198724869043591], [1.9691101630241583 .. 2.0051083745133487], [3.9995562274620826 .. 4.0486530804768855], [4.4337642036542295 .. 4.4710361835445749]]
# domain = [0.0000000000000000 .. 6.2831853071795863]
# roots = [[0.62825835714841304 .. 0.66198724869043591],
#  [1.9691101630241583 .. 2.0051083745133487],
#  [3.9995562274620826 .. 4.0486530804768855],
#  [4.4337642036542295 .. 4.4710361835445749]]
# seg_domain = [0.0000000000000000 .. 6.2831853071795863]
# roots = [[0.62825835714841304 .. 0.66198724869043591],
#  [1.9691101630241583 .. 2.0051083745133487],
#  [3.9995562274620826 .. 4.0486530804768855],
#  [4.4337642036542295 .. 4.4710361835445749]]
# signal given bool roots: 1 items in 0.00 seconds
# Monitoring atomic -x^2 - x + y + 6 > 0: 1 items in 0.36 seconds
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7f00a83ddae0>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# symbolic_composition=False,symbolic_composition_order=10, tentative_unpreconditioning=True,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.35 seconds
# roots = [[0.62842505146896010 .. 0.66114434420739799], [1.9415029379521331 .. 1.9760074426461345], [4.0111975978527434 .. 4.0599420282428716], [4.4075312300306039 .. 4.4450639412730677]]
# domain = [0.0000000000000000 .. 6.2831853071795863]
# roots = [[0.62842505146896010 .. 0.66114434420739799],
#  [1.9415029379521331 .. 1.9760074426461345],
#  [4.0111975978527434 .. 4.0599420282428716],
#  [4.4075312300306039 .. 4.4450639412730677]]
# seg_domain = [0.0000000000000000 .. 6.2831853071795863]
# roots = [[0.62842505146896010 .. 0.66114434420739799],
#  [1.9415029379521331 .. 1.9760074426461345],
#  [4.0111975978527434 .. 4.0599420282428716],
#  [4.4075312300306039 .. 4.4450639412730677]]
# signal given bool roots: 1 items in 0.00 seconds
# Monitoring atomic -x^2 - x + y + 6 > 0: 1 items in 0.35 seconds
# Graphics object consisting of 2 graphics primitives

# %%
INCLUDE_DERIVS = None

# %%
sig1 = S.signal_for_system(system, 2*pi, symbolic_composition=False,
    selective_unpreconditioning=False,
    unpreconditioning_order=UNPRECONDITIONING_ORDER,
    unpreconditioning_include_derivs=INCLUDE_DERIVS)
sig2 = S.signal_for_system(
    system, 2*pi, symbolic_composition=True,
    symbolic_composition_order=SYMBOLIC_COMPOSITION_ORDER,
    unpreconditioning_order=UNPRECONDITIONING_ORDER,
    selective_unpreconditioning=False,
    unpreconditioning_include_derivs=INCLUDE_DERIVS,
)
sig3 = S.signal_for_system(system, 2*pi, symbolic_composition=False,
    selective_unpreconditioning=True,
    unpreconditioning_order=UNPRECONDITIONING_ORDER,
    selective_unpreconditioning_include_derivs=INCLUDE_DERIVS)
sig4 = S.signal_for_system(
    system, 2*pi, symbolic_composition=True,
    symbolic_composition_order=SYMBOLIC_COMPOSITION_ORDER,
    selective_unpreconditioning=True,
    unpreconditioning_order=UNPRECONDITIONING_ORDER,
    unpreconditioning_include_derivs=INCLUDE_DERIVS
)

g = graphics_array([
    sig1.plot(),
    sig2.plot(),
    sig3.plot(),
    sig4.plot(),
    combined_signal.plot(),
], ncols=1)
g.show(aspect_ratio=1/6)
# Out:
# Precomposing Contexts: 1 items in 0.00 seconds
# include_derivs = True
# phi variables sfs = {x, y}
# system sfs = System(R, (t, x, y), [0, [4 .. 5], [1 .. 2]], (1, -y, x), varmap=bidict({'t': t, 'x': x, 'y': y}))
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.0000000000000000 .. 5.0000000000000000]', '[1.0000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.0..5.0]
# C = [1.0..2.0]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# Running Flow*: 1 items in 0.09 seconds
# Computed 63 flowpipes in 0.09002788600628264 sec
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7f009ca2f260>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=2, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# symbolic_composition=False,symbolic_composition_order=2, tentative_unpreconditioning=True,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.07 seconds
# roots = [[0.45096500683837437 .. 0.84116964364295533], [1.8999999999999959 .. 2.3790557924748393], [3.6858498226790512 .. 4.2455090593679997], [4.2999999999999758 .. 4.7181223820180707]]
# domain = [0.0000000000000000 .. 6.2851853071795861]
# roots = [[0.45096500683837437 .. 0.84116964364295533],
#  [1.8999999999999959 .. 2.3790557924748393],
#  [3.6858498226790512 .. 4.2455090593679997],
#  [4.2999999999999758 .. 4.7181223820180707]]
# seg_domain = [0.0000000000000000 .. 6.2851853071795861]
# roots = [[0.45096500683837437 .. 0.84116964364295533],
#  [1.8999999999999959 .. 2.3790557924748393],
#  [3.6858498226790512 .. 4.2455090593679997],
#  [4.2999999999999758 .. 4.7181223820180707]]
# signal given bool roots: 1 items in 0.00 seconds
# Monitoring atomic -x^2 - x + y + 6 > 0: 1 items in 0.07 seconds
# Monitoring Signal for -x^2 - x + y + 6 > 0: 1 items in 0.08 seconds
# ran "restoring globals" 9 times in 0.0002930164337158203
# ran "capturing globals [on exit]" 9 times in 0.00017023086547851562
# ran "mask intersect check" 63 times in 0.00011420249938964844
# ran "tentative eval" 63 times in 0.031154394149780273
# ran "composing flowpipe" 23 times in 0.027737855911254883
# ran "whole domain eval" 22 times in 0.0012543201446533203
# ran "post retrieve" 22 times in 0.00011515617370605469
# ran "root detection" 22 times in 0.003719329833984375
# ran "root amalgamation" 22 times in 7.271766662597656e-05
# ran "prepare in check" 5 times in 2.6941299438476562e-05
# ran "check boolean [unguarded]" 5 times in 0.0002834796905517578
# ran "observer.check" 5 times in 0.00044846534729003906
# Precomposing Contexts: 1 items in 0.00 seconds
# include_derivs = False
# phi variables sfs = {x, y}
# system sfs = System(R, (t, x, y), [0, [4 .. 5], [1 .. 2]], (1, -y, x), varmap=bidict({'t': t, 'x': x, 'y': y}))
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.0000000000000000 .. 5.0000000000000000]', '[1.0000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.0..5.0]
# C = [1.0..2.0]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# Running Flow*: 1 items in 0.10 seconds
# Computed 63 flowpipes in 0.09676891400886234 sec
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7f009ca2f480>, 2*x*y + x + y, symbolic_composition=True, symbolic_composition_order=2, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# symbolic_composition=True,symbolic_composition_order=2, tentative_unpreconditioning=True,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.08 seconds
# roots = [[0.42781876372057958 .. 0.80791763794276306], [1.9408154388129712 .. 2.3532033084119624], [3.6723543708094634 .. 4.2000000000000047], [4.2556841157080844 .. 4.3000000000000052], [4.3510778392460629 .. 4.7370139187454897]]
# domain = [0.0000000000000000 .. 6.2851853071795861]
# roots = [[0.42781876372057958 .. 0.80791763794276306],
#  [1.9408154388129712 .. 2.3532033084119624],
#  [3.6723543708094634 .. 4.2000000000000047],
#  [4.2556841157080844 .. 4.3000000000000052],
#  [4.3510778392460629 .. 4.7370139187454897]]
# seg_domain = [0.0000000000000000 .. 6.2851853071795861]
# roots = [[0.42781876372057958 .. 0.80791763794276306],
#  [1.9408154388129712 .. 2.3532033084119624],
#  [3.6723543708094634 .. 4.2000000000000047],
#  [4.2556841157080844 .. 4.3000000000000052],
#  [4.3510778392460629 .. 4.7370139187454897]]
# signal given bool roots: 1 items in 0.00 seconds
# Monitoring atomic -x^2 - x + y + 6 > 0: 1 items in 0.08 seconds
# Monitoring Signal for -x^2 - x + y + 6 > 0: 1 items in 0.09 seconds
# ran "restoring globals" 9 times in 0.00021910667419433594
# ran "capturing globals [on exit]" 9 times in 0.0001685619354248047
# ran "mask intersect check" 63 times in 0.00011801719665527344
# ran "tentative eval" 63 times in 0.03461003303527832
# ran "composing flowpipe" 24 times in 0.031907081604003906
# ran "whole domain eval" 22 times in 0.001371145248413086
# ran "post retrieve" 22 times in 0.00982809066772461
# ran "root detection" 22 times in 0.0005879402160644531
# ran "root amalgamation" 22 times in 9.059906005859375e-05
# ran "prepare in check" 6 times in 2.765655517578125e-05
# ran "check boolean [unguarded]" 6 times in 0.0002810955047607422
# ran "observer.check" 6 times in 0.0004611015319824219
# Precomposing Contexts: 1 items in 0.00 seconds
# include_derivs = True
# phi variables sfs = {x, y}
# system sfs = System(R, (t, x, y), [0, [4 .. 5], [1 .. 2]], (1, -y, x), varmap=bidict({'t': t, 'x': x, 'y': y}))
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.0000000000000000 .. 5.0000000000000000]', '[1.0000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.0..5.0]
# C = [1.0..2.0]
# assigning system with dimension 3
# resulting system has dimension 3
# unpreconditioning_orders = [-1, 2, 2]
# run within tmv args
# integrationScheme = 2
# Running Flow*: 1 items in 0.09 seconds
# Computed 63 flowpipes in 0.09185689299192745 sec
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7f009ca2f370>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=2, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# symbolic_composition=False,symbolic_composition_order=2, tentative_unpreconditioning=True,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.06 seconds
# roots = [[0.45096500683837437 .. 0.84116964364295533], [1.8999999999999959 .. 2.3790557924748393], [3.6858498226790512 .. 4.2455090593679997], [4.2999999999999758 .. 4.7181223820180707]]
# domain = [0.0000000000000000 .. 6.2851853071795861]
# roots = [[0.45096500683837437 .. 0.84116964364295533],
#  [1.8999999999999959 .. 2.3790557924748393],
#  [3.6858498226790512 .. 4.2455090593679997],
#  [4.2999999999999758 .. 4.7181223820180707]]
# seg_domain = [0.0000000000000000 .. 6.2851853071795861]
# roots = [[0.45096500683837437 .. 0.84116964364295533],
#  [1.8999999999999959 .. 2.3790557924748393],
#  [3.6858498226790512 .. 4.2455090593679997],
#  [4.2999999999999758 .. 4.7181223820180707]]
# signal given bool roots: 1 items in 0.00 seconds
# Monitoring atomic -x^2 - x + y + 6 > 0: 1 items in 0.06 seconds
# Monitoring Signal for -x^2 - x + y + 6 > 0: 1 items in 0.07 seconds
# ran "restoring globals" 9 times in 0.0002353191375732422
# ran "capturing globals [on exit]" 9 times in 0.00013256072998046875
# ran "mask intersect check" 63 times in 0.00011444091796875
# ran "tentative eval" 63 times in 0.027051210403442383
# ran "composing flowpipe" 23 times in 0.026604890823364258
# ran "whole domain eval" 22 times in 0.0011332035064697266
# ran "post retrieve" 22 times in 0.00011110305786132812
# ran "root detection" 22 times in 0.0035114288330078125
# ran "root amalgamation" 22 times in 8.20159912109375e-05
# ran "prepare in check" 5 times in 2.6941299438476562e-05
# ran "check boolean [unguarded]" 5 times in 0.00029015541076660156
# ran "observer.check" 5 times in 0.0004420280456542969
# Precomposing Contexts: 1 items in 0.00 seconds
# include_derivs = False
# phi variables sfs = {x, y}
# system sfs = System(R, (t, x, y), [0, [4 .. 5], [1 .. 2]], (1, -y, x), varmap=bidict({'t': t, 'x': x, 'y': y}))
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.0000000000000000 .. 5.0000000000000000]', '[1.0000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.0..5.0]
# C = [1.0..2.0]
# assigning system with dimension 3
# resulting system has dimension 3
# unpreconditioning_orders = [-1, 2, 2]
# run within tmv args
# integrationScheme = 2
# Running Flow*: 1 items in 0.09 seconds
# Computed 63 flowpipes in 0.08795289500267245 sec
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7f009ca2f150>, 2*x*y + x + y, symbolic_composition=True, symbolic_composition_order=2, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# symbolic_composition=True,symbolic_composition_order=2, tentative_unpreconditioning=True,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.07 seconds
# roots = [[0.42781876372057958 .. 0.80791763794276306], [1.9408154388129712 .. 2.3532033084119624], [3.6723543708094634 .. 4.2000000000000047], [4.2556841157080844 .. 4.3000000000000052], [4.3510778392460629 .. 4.7370139187454897]]
# domain = [0.0000000000000000 .. 6.2851853071795861]
# roots = [[0.42781876372057958 .. 0.80791763794276306],
#  [1.9408154388129712 .. 2.3532033084119624],
#  [3.6723543708094634 .. 4.2000000000000047],
#  [4.2556841157080844 .. 4.3000000000000052],
#  [4.3510778392460629 .. 4.7370139187454897]]
# seg_domain = [0.0000000000000000 .. 6.2851853071795861]
# roots = [[0.42781876372057958 .. 0.80791763794276306],
#  [1.9408154388129712 .. 2.3532033084119624],
#  [3.6723543708094634 .. 4.2000000000000047],
#  [4.2556841157080844 .. 4.3000000000000052],
#  [4.3510778392460629 .. 4.7370139187454897]]
# signal given bool roots: 1 items in 0.00 seconds
# Monitoring atomic -x^2 - x + y + 6 > 0: 1 items in 0.07 seconds
# Monitoring Signal for -x^2 - x + y + 6 > 0: 1 items in 0.08 seconds
# ran "restoring globals" 9 times in 0.0002410411834716797
# ran "capturing globals [on exit]" 9 times in 0.00015616416931152344
# ran "mask intersect check" 63 times in 0.00011229515075683594
# ran "tentative eval" 63 times in 0.027994871139526367
# ran "composing flowpipe" 24 times in 0.02807164192199707
# ran "whole domain eval" 22 times in 0.0012309551239013672
# ran "post retrieve" 22 times in 0.008129596710205078
# ran "root detection" 22 times in 0.0005161762237548828
# ran "root amalgamation" 22 times in 8.535385131835938e-05
# ran "prepare in check" 6 times in 3.218650817871094e-05
# ran "check boolean [unguarded]" 6 times in 0.0002300739288330078
# ran "observer.check" 6 times in 0.0004100799560546875
# Graphics Array of size 5 x 1

# %%
sig1
# Out:
# Signal([0.0000000000000000 .. 6.2831853071795872], [([0.0000000000000000 .. 0.45096500683837438], False), ([0.84116964364295532 .. 1.8999999999999960], True), ([2.3790557924748392 .. 3.6858498226790513], False), ([4.2455090593679996 .. 4.2999999999999759], True), ([4.7181223820180706 .. 6.2831853071795872], False)], mask=None)

# %%
sig2
# Out:
# Signal([0.0000000000000000 .. 6.2831853071795872], [([0.0000000000000000 .. 0.42781876372057959], False), ([0.80791763794276305 .. 1.9408154388129713], True), ([2.3532033084119623 .. 3.6723543708094635], False), ([4.2000000000000046 .. 4.2556841157080845], True), ([4.3000000000000051 .. 4.3510778392460630], True), ([4.7370139187454896 .. 6.2831853071795872], False)], mask=None)
