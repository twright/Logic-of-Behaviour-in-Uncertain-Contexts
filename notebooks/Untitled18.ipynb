# %%
x1 = SR.var("x1"); x1
# Out:
# x1

# %%
dir(x1)
# Out:
# ['Order',
#  'WZ_certificate',
#  '__abs__',
#  '__add__',
#  '__bool__',
#  '__call__',
#  '__class__',
#  '__complex__',
#  '__copy__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getmetaclass__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__pari__',
#  '__pos__',
#  '__pow__',
#  '__pyx_vtable__',
#  '__radd__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmod__',
#  '__rmul__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__weakref__',
#  '__xor__',
#  '_act_on_',
# ...

# %%
x1.arguments()
# Out:
# (x1,)

# %%
x1 = SR.symbol("this is a test"); x1
# Out:
# this is a test

# %%
x1
# Out:
# this is a test
