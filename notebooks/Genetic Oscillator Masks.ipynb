# %%
# %display latex
from ulbc import *
from flowstar import *
from ulbc.bondcalculus import *

# %%
R.<x1,x2,x3,x4,x5,x6,x7,x8,x9> = RIF[]

# %%
y = vector([
    10*x3 - RIF('0.1')*x1*x6,
    100*x4 - x1*x2,
    RIF('0.1')*x1*x6 - 50*x3,
    x2*x6 - 100*x4,
    5*x3 + RIF('0.5')*x1 - 10*x5,
    50*x5 + 50*x3 + 100*x4 - x6*(RIF('0.1')*x1 + x2 + 2*x8 + 1),
    50*x4 + RIF('0.01')*x2 - RIF('0.5')*x7,
    RIF('0.5')*x7 - 2*x6*x8 + x9 - RIF('0.2')*x8,
    2*x6*x8 - x9,
])

# %%
y
# Out:
# (-0.10000000000000000?*x1*x6 + 10*x3, -x1*x2 + 100*x4, 0.10000000000000000?*x1*x6 - 50*x3, x2*x6 - 100*x4, 0.50000000000000000?*x1 + 5*x3 - 10*x5, -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6, 0.01000000000000000?*x2 + 50*x4 - 0.50000000000000000?*x7, -2*x6*x8 + 0.50000000000000000?*x7 - 0.2000000000000000?*x8 + x9, 2*x6*x8 - x9)

# %%
table([[yi] for yi in y])
# Out:
#   -0.10000000000000000?*x1*x6 + 10*x3
#   -x1*x2 + 100*x4
#   0.10000000000000000?*x1*x6 - 50*x3
#   x2*x6 - 100*x4
#   0.50000000000000000?*x1 + 5*x3 - 10*x5
#   -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6
#   0.01000000000000000?*x2 + 50*x4 - 0.50000000000000000?*x7
#   -2*x6*x8 + 0.50000000000000000?*x7 - 0.2000000000000000?*x8 + x9
#   2*x6*x8 - x9

# %%
y0 = [
    RIF('[0.98, 1.02]'),
    RIF('[1.28, 1.32]'),
    RIF('[0.08, 0.12]'),
    RIF('[0.08, 0.12]'), # x4
    RIF('[0.08, 0.12]'),
    RIF('[1.28, 1.32]'), # x6
    RIF('[2.48, 2.52]'),
    RIF('[0.58, 0.62]'),
    RIF('[1.28, 1.32]'),
]

# %%
table([y0i.endpoints() for y0i in y0])
# Out:
#   0.979999999999999    1.02000000000001
#   1.27999999999999     1.32000000000001
#   0.0799999999999999   0.120000000000001
#   0.0799999999999999   0.120000000000001
#   0.0799999999999999   0.120000000000001
#   1.27999999999999     1.32000000000001
#   2.47999999999999     2.52000000000001
#   0.579999999999999    0.620000000000001
#   1.27999999999999     1.32000000000001

# %%
R
# Out:
# Multivariate Polynomial Ring in x1, x2, x3, x4, x5, x6, x7, x8, x9 over Real Interval Field with 53 bits of precision

# %%
sys = System(R, R.gens(), y0, y); sys
# Out:
# System(R, (x1, x2, x3, x4, x5, x6, x7, x8, x9), [[0.97999999999999998 .. 1.0200000000000001], [1.2799999999999998 .. 1.3200000000000001], [0.079999999999999987 .. 0.12000000000000001], [0.079999999999999987 .. 0.12000000000000001], [0.079999999999999987 .. 0.12000000000000001], [1.2799999999999998 .. 1.3200000000000001], [2.4799999999999999 .. 2.5200000000000001], [0.57999999999999996 .. 0.62000000000000011], [1.2799999999999998 .. 1.3200000000000001]], (-0.10000000000000000?*x1*x6 + 10*x3, -x1*x2 + 100*x4, 0.10000000000000000?*x1*x6 - 50*x3, x2*x6 - 100*x4, 0.50000000000000000?*x1 + 5*x3 - 10*x5, -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6, 0.01000000000000000?*x2 + 50*x4 - 0.50000000000000000?*x7, -2*x6*x8 + 0.50000000000000000?*x7 - 0.2000000000000000?*x8 + x9, 2*x6*x8 - x9), varmap=bidict({'x1': x1, 'x2': x2, 'x3': x3, 'x4': x4, 'x5': x5, 'x6': x6, 'x7': x7, 'x8': x8, 'x9': x9}))

# %%
RReal = RR['x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8', 'x9']

# %%
RReal(sys.y[2])
# Out:
# 0.100000000000000*x1*x6 - 50.0000000000000*x3

# %%
sys_real = System(
    RReal,
    RReal.gens(),
    [y0i.center() for y0i in sys.y0],
    [RReal(yi) for yi in sys.y],
)
sys_real
# Out:
# System(R, (x1, x2, x3, x4, x5, x6, x7, x8, x9), [1, [1.2999999999999998 .. 1.2999999999999999], [0.10000000000000000 .. 0.10000000000000001], [0.10000000000000000 .. 0.10000000000000001], [0.10000000000000000 .. 0.10000000000000001], [1.2999999999999998 .. 1.2999999999999999], [2.5000000000000000 .. 2.5000000000000000], [0.60000000000000008 .. 0.60000000000000009], [1.2999999999999998 .. 1.2999999999999999]], (-0.100000000000000*x1*x6 + 10.0000000000000*x3, -x1*x2 + 100.000000000000*x4, 0.100000000000000*x1*x6 - 50.0000000000000*x3, x2*x6 - 100.000000000000*x4, 0.500000000000000*x1 + 5.00000000000000*x3 - 10.0000000000000*x5, -0.100000000000000*x1*x6 - x2*x6 - 2.00000000000000*x6*x8 + 50.0000000000000*x3 + 100.000000000000*x4 + 50.0000000000000*x5 - x6, 0.0100000000000000*x2 + 50.0000000000000*x4 - 0.500000000000000*x7, -2.00000000000000*x6*x8 + 0.500000000000000*x7 - 0.200000000000000*x8 + x9, 2.00000000000000*x6*x8 - x9), varmap=bidict({'x1': x1, 'x2': x2, 'x3': x3, 'x4': x4, 'x5': x5, 'x6': x6, 'x7': x7, 'x8': x8, 'x9': x9}))

# %%
y0_real = [y0i.center() for y0i in sys.y0]
table([[y0i] for y0i in y0_real])
# Out:
#   1.00000000000000
#   1.30000000000000
#   0.100000000000000
#   0.100000000000000
#   0.100000000000000
#   1.30000000000000
#   2.50000000000000
#   0.600000000000000
#   1.30000000000000

# %%
timepoints = srange(0,10,0.1)

# %%
sln = desolve_odeint(sys_real.y, y0_real, timepoints, list(sys_real.x))

# %%
points(zip(timepoints, [yi[1] for yi in sln]))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
from scipy.integrate import solve_ivp
from ulbc.matricies import vec_to_numpy, mat_to_numpy, convert_vec, sympy_gens

# %%
f = vec_to_numpy(RReal, sys_real.y)
jac = mat_to_numpy(RReal, sage.jacobian(sys_real.y, sys_real.x))

# %%
sln = solve_ivp(f,
                (0, 10),
                y0_real,
                method='LSODA',
                jac=jac,
                vectorized=True,
                dense_output=True)

# %%
plot(lambda t: sln.sol(t)[1], (0, 10))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
import time
t0 = time.time()
r = sys.reach(
    3, order=4, step=0.003,
    precondition=1,
    estimation=1e-1,
    max_remainder_queue=200,
    integration_method=IntegrationMethod.ONLY_PICARD_SYMB,
    cutoff_threshold=1e-6)
t1 = time.time()
print(f"Reachability done in {t1 - t0}")
# Out:
# calling reach with y0 = ['[0.97999999999999998 .. 1.0200000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[2.4799999999999999 .. 2.5200000000000001]', '[0.57999999999999996 .. 0.62000000000000011]', '[1.2799999999999998 .. 1.3200000000000001]']
# ode in polynomial ring
# entering managed function _init_args
# entering global manager
# num_flowpipes: 0
# swapping variables
# === before ===
# global: 0 dim
# local: 0 dim
# global: 0 flowpipes
# stored: 0 flowpipes
# === after ===
# global: 0 dim
# local: 0 dim
# global: 0 flowpipes
# stored: 0 flowpipes
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# crude_roots = False
# _handle_initials called!
# vars = [x1, x2, x3, x4, x5, x6, x7, x8, x9]
# C = [0.98..1.02]
# C = [1.2799999999999998..1.32]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [1.2799999999999998..1.32]
# C = [2.48..2.52]
# C = [0.58..0.6200000000000001]
# C = [1.2799999999999998..1.32]
# entering managed function run
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# integrationScheme = 7
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# swapping variables
# === before ===
# global: 0 dim
# local: 0 dim
# global: 0 flowpipes
# stored: 0 flowpipes
# === after ===
# global: 0 dim
# local: 0 dim
# global: 0 flowpipes
# stored: 0 flowpipes
# stack: []
# Reachability done in 35.27117347717285

# %%
r.num_flowpipes
# Out:
# entering global manager
# num_flowpipes: 0
# swapping variables
# === before ===
# global: 0 dim
# local: 0 dim
# global: 0 flowpipes
# stored: 0 flowpipes
# === after ===
# global: 0 dim
# local: 0 dim
# global: 0 flowpipes
# stored: 0 flowpipes
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# swapping variables
# === before ===
# global: 0 dim
# local: 0 dim
# global: 0 flowpipes
# stored: 0 flowpipes
# === after ===
# global: 0 dim
# local: 0 dim
# global: 0 flowpipes
# stored: 0 flowpipes
# stack: []
# 1000

# %%
r.sage_interval_plot('x3', 'x5', 0.01)
# Out:
# entering managed function sage_interval_plot
# entering global manager
# num_flowpipes: 0
# swapping variables
# === before ===
# global: 0 dim
# local: 0 dim
# global: 0 flowpipes
# stored: 0 flowpipes
# === after ===
# global: 0 dim
# local: 0 dim
# global: 0 flowpipes
# stored: 0 flowpipes
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# var_id_x = -1
# var_id_y = -1
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# ...
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# swapping variables
# === before ===
# global: 0 dim
# local: 0 dim
# global: 0 flowpipes
# stored: 0 flowpipes
# === after ===
# global: 0 dim
# local: 0 dim
# global: 0 flowpipes
# stored: 0 flowpipes
# stack: []
# Graphics object consisting of 300 graphics primitives

# %%
out = r.sage_interval_plot('x4', 'x6', 0.01)
out.set_aspect_ratio(1/18)
out
# Out:
# entering managed function sage_interval_plot
# entering global manager
# num_flowpipes: 0
# swapping variables
# === before ===
# global: 0 dim
# local: 0 dim
# global: 0 flowpipes
# stored: 0 flowpipes
# === after ===
# global: 0 dim
# local: 0 dim
# global: 0 flowpipes
# stored: 0 flowpipes
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# var_id_x = -1
# var_id_y = -1
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# ...
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# entering managed function __call__
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# entering managed function prepare
# entering global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# num_flowpipes: 0
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>, <flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# stack: [<flowstar.global_manager.FlowstarGlobalManager object at 0x7f2e9886bd60>]
# exiting global manager
# num_flowpipes: 0
# swapping variables
# === before ===
# global: 0 dim
# local: 0 dim
# global: 0 flowpipes
# stored: 0 flowpipes
# === after ===
# global: 0 dim
# local: 0 dim
# global: 0 flowpipes
# stored: 0 flowpipes
# stack: []
# Graphics object consisting of 300 graphics primitives

# %%
r.wplot('x3', 'x5')

# %%
r.wplot('x4', 'x6')

# %%
sys_real.varmap
# Out:
# bidict({'x1': x1, 'x2': x2, 'x3': x3, 'x4': x4, 'x5': x5, 'x6': x6, 'x7': x7, 'x8': x8, 'x9': x9})

# %%
fl = lambda t: r(RIF(t))[5].lower()
fu = lambda t: r(RIF(t))[5].upper()
gl = lambda t: r(RIF(t))[3].lower()
gu = lambda t: r(RIF(t))[3].upper()

# %%
fl(0), fu(0)
# Out:
# (1.27994857010101, 1.32005885676383)

# %%
gl(0), gu(0)
# Out:
# (0.0799454261676199, 0.120047556972802)

# %%
plot((fl, fu), (0, 3), plot_points=30, adaptive_recursion=0, randomize=False)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
plot((gl, gu), (0, 3), plot_points=50, adaptive_recursion=0, randomize=False)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
from flowstar.instrumentation import AggregateMetric

# %%
agg = AggregateMetric()

# %%
from time import sleep
import instrument

with instrument.block(name='test', metric=agg.metric):
    print("test A ...")
    sleep(2)

with instrument.block(name='test', metric=agg.metric):
    print("test B ...")
    sleep(3)
    
agg.print()
# Out:
# test A ...
# test B ...
# ran "test" 2 times in 5.004337787628174

# %%
sig = F([0, 0.5], Atomic(var("x6") > 1.4) & G([0, 0.1], Atomic(var("x6") < 1.8)  & F([0, 1], Atomic(var("x6") < 1) & Atomic(var("x4") < 0.02)))).signal(r)
sig
# Out:
# PolyObserver(x6 - 1.4000000000000000?, <flowstar.reachability.Reach object at 0x55d72da76800>, -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6 symbolic_composition=False, tentative_unpreconditioning=True, mask=None)
# symbolic_composition=False, tentative_unpreconditioning=True
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = []
# domain = [0.0000000000000000 .. 2.9990000000000002]
# roots = []
# seg_domain = [0.0000000000000000 .. 2.9990000000000002]
# roots = []
# In G.signal
# PolyObserver(-x6 + 1.8000000000000001?, <flowstar.reachability.Reach object at 0x55d72da76800>, 0.10000000000000000?*x1*x6 + x2*x6 + 2*x6*x8 - 50*x3 - 100*x4 - 50*x5 + x6 symbolic_composition=False, tentative_unpreconditioning=True, mask=None)
# symbolic_composition=False, tentative_unpreconditioning=True
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = []
# domain = [0.0000000000000000 .. 2.9990000000000002]
# roots = []
# seg_domain = [0.0000000000000000 .. 2.9990000000000002]
# roots = []
# PolyObserver(-x6 + 1, <flowstar.reachability.Reach object at 0x55d72da76800>, 0.10000000000000000?*x1*x6 + x2*x6 + 2*x6*x8 - 50*x3 - 100*x4 - 50*x5 + x6 symbolic_composition=False, tentative_unpreconditioning=True, mask=None)
# symbolic_composition=False, tentative_unpreconditioning=True
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = []
# domain = [0.0000000000000000 .. 2.9990000000000002]
# roots = []
# seg_domain = [0.0000000000000000 .. 2.9990000000000002]
# roots = []
# PolyObserver(-x4 + 0.020000000000000001?, <flowstar.reachability.Reach object at 0x55d72da76800>, -x2*x6 + 100*x4 symbolic_composition=False, tentative_unpreconditioning=True, mask=None)
# symbolic_composition=False, tentative_unpreconditioning=True
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = []
# domain = [0.0000000000000000 .. 2.9990000000000002]
# roots = []
# seg_domain = [0.0000000000000000 .. 2.9990000000000002]
# roots = []
# Signal([0.0000000000000000 .. 2.9990000000000002], [([0.0000000000000000 .. 2.4990000000000002], False)], mask=None)

# %%
r.instrumentor.print()
# Out:
# ran "composing flowpipe" 3004 times in 47.40074443817139
# ran "mask intersect check" 4000 times in 0.004580020904541016

# %%
sig.plot()
# Out:
# /usr/lib64/python3.7/site-packages/sage/plot/contour_plot.py:205: UserWarning: No contour levels were found within the data range.
#   linewidths=linewidths, linestyles=linestyles)
# Graphics object consisting of 2 graphics primitives

# %%
def test_monitoring(prop, duration, **kwargs):
    t0 = time.time()
    sig = prop.signal_for_system(sys,
    duration, order=4, step=0.003,
    precondition=1,
    estimation=1e-1,
    max_remainder_queue=100,
    integration_method=IntegrationMethod.ONLY_PICARD_SYMB,
    cutoff_threshold=1e-6,
    **kwargs)
    t1 = time.time()
    print(f"Run done in {t1 - t0} sec\noptions: {repr(kwargs)}")
    return t1 - t0, sig

# %%
prop = F([0, 0.5], Atomic(var("x6") > 1.4) & G([0, 0.1], Atomic(var("x6") < 1.8)  & F([0, 1], Atomic(var("x6") < 1) & Atomic(var("x4") < 0.02))))
prop
# Out:
# F([0.0000000000000000 .. 0.50000000000000000], And([Atomic(x6 > 1.40000000000000), G([0.0000000000000000 .. 0.10000000000000001], And([Atomic(x6 < 1.80000000000000), F([0 .. 1], And([Atomic(x6 < 1), Atomic(x4 < 0.0200000000000000)]))]))]))

# %%
test_monitoring(prop, 4, use_masks=False)[1].plot()
# Out:
# Precomposing Contexts: 1 items in 0.00 seconds
# calling reach with y0 = ['[0.97999999999999998 .. 1.0200000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[2.4799999999999999 .. 2.5200000000000001]', '[0.57999999999999996 .. 0.62000000000000011]', '[1.2799999999999998 .. 1.3200000000000001]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x1, x2, x3, x4, x5, x6, x7, x8, x9]
# C = [0.98..1.02]
# C = [1.2799999999999998..1.32]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [1.2799999999999998..1.32]
# C = [2.48..2.52]
# C = [0.58..0.6200000000000001]
# C = [1.2799999999999998..1.32]
# integrationScheme = 7
# Running Flow*: 1 items in 72.61 seconds
# Computed 1867 flowpipes in 72.60710761402152 sec
# PolyObserver(x6 - 1.4000000000000000?, <flowstar.reachability.Reach object at 0x55d72ec80790>, -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6 symbolic_composition=False, tentative_unpreconditioning=True, mask=None)
# symbolic_composition=False, tentative_unpreconditioning=True
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.01 seconds
# roots = []
# domain = [0.0000000000000000 .. 5.6000000000000015]
# roots = []
# seg_domain = [0.0000000000000000 .. 5.6000000000000015]
# roots = []
# In G.signal
# PolyObserver(-x6 + 1.8000000000000001?, <flowstar.reachability.Reach object at 0x55d72ec80790>, 0.10000000000000000?*x1*x6 + x2*x6 + 2*x6*x8 - 50*x3 - 100*x4 - 50*x5 + x6 symbolic_composition=False, tentative_unpreconditioning=True, mask=None)
# symbolic_composition=False, tentative_unpreconditioning=True
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.01 seconds
# roots = []
# domain = [0.0000000000000000 .. 5.6000000000000015]
# roots = []
# seg_domain = [0.0000000000000000 .. 5.6000000000000015]
# roots = []
# PolyObserver(-x6 + 1, <flowstar.reachability.Reach object at 0x55d72ec80790>, 0.10000000000000000?*x1*x6 + x2*x6 + 2*x6*x8 - 50*x3 - 100*x4 - 50*x5 + x6 symbolic_composition=False, tentative_unpreconditioning=True, mask=None)
# symbolic_composition=False, tentative_unpreconditioning=True
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.01 seconds
# roots = []
# domain = [0.0000000000000000 .. 5.6000000000000015]
# roots = []
# seg_domain = [0.0000000000000000 .. 5.6000000000000015]
# roots = []
# PolyObserver(-x4 + 0.020000000000000001?, <flowstar.reachability.Reach object at 0x55d72ec80790>, -x2*x6 + 100*x4 symbolic_composition=False, tentative_unpreconditioning=True, mask=None)
# symbolic_composition=False, tentative_unpreconditioning=True
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.01 seconds
# roots = []
# domain = [0.0000000000000000 .. 5.6000000000000015]
# roots = []
# seg_domain = [0.0000000000000000 .. 5.6000000000000015]
# roots = []
# Monitoring Signal for F([0.0000000000000000 .. 0.50000000000000000], x6 > 1.40000000000000 & G([0.0000000000000000 .. 0.10000000000000001], x6 < 1.80000000000000 & F([0 .. 1], x6 < 1 & x4 < 0.0200000000000000))): 1 items in 1.44 seconds
# Monitored signal in 1.4418497299484443 sec
# ran "composing flowpipe" 4 times in 0.06049013137817383
# ran "mask intersect check" 7468 times in 0.009359598159790039
# Run done in 74.34903931617737 sec
# options: {'use_masks': False}
# /usr/lib64/python3.7/site-packages/sage/plot/contour_plot.py:205: UserWarning: No contour levels were found within the data range.
#   linewidths=linewidths, linestyles=linestyles)
# Graphics object consisting of 2 graphics primitives

# %%
test_monitoring(prop, 4, use_masks=True)[1].plot()
# Out:
# Precomposing Contexts: 1 items in 0.00 seconds
# calling reach with y0 = ['[0.97999999999999998 .. 1.0200000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[2.4799999999999999 .. 2.5200000000000001]', '[0.57999999999999996 .. 0.62000000000000011]', '[1.2799999999999998 .. 1.3200000000000001]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x1, x2, x3, x4, x5, x6, x7, x8, x9]
# C = [0.98..1.02]
# C = [1.2799999999999998..1.32]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [1.2799999999999998..1.32]
# C = [2.48..2.52]
# C = [0.58..0.6200000000000001]
# C = [1.2799999999999998..1.32]
# integrationScheme = 7
# Running Flow*: 1 items in 76.22 seconds
# Computed 1867 flowpipes in 76.22183655301342 sec
# PolyObserver(x6 - 1.4000000000000000?, <flowstar.reachability.Reach object at 0x55d75cfcfb10>, -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6 symbolic_composition=False, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 5.6010000000000009], [[0.0000000000000000 .. 4.5010000000000004]]))
# symbolic_composition=False, tentative_unpreconditioning=True
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 11.13 seconds
# roots = [[0.0048028783727901138 .. 0.020435765977123051], [0.20345478283219919 .. 0.48300000000000043], [5.4779999999985058 .. 5.6010000000001759]]
# domain = [0.0000000000000000 .. 5.6000000000000015]
# roots = [[0.0048028783727901138 .. 0.020435765977123051],
#  [0.20345478283219919 .. 0.48300000000000043],
#  [5.4779999999985058 .. 5.6010000000001759]]
# seg_domain = [0.0000000000000000 .. 4.5010000000000004]
# roots = [[0.0048028783727901138 .. 0.020435765977123051],
#  [0.20345478283219919 .. 0.48300000000000043],
#  [5.4779999999985058 .. 5.6010000000001759]]
# In G.signal
# PolyObserver(-x6 + 1.8000000000000001?, <flowstar.reachability.Reach object at 0x55d75cfcfb10>, 0.10000000000000000?*x1*x6 + x2*x6 + 2*x6*x8 - 50*x3 - 100*x4 - 50*x5 + x6 symbolic_composition=False, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 5.6010000000000009], [[0.0048028783727901138 .. 0.58300000000000052], [4.5010000000000003 .. 4.6010000000000009]]))
# symbolic_composition=False, tentative_unpreconditioning=True
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 2.25 seconds
# roots = [[5.5379999999984725 .. 5.6010000000001759]]
# domain = [0.0000000000000000 .. 5.6000000000000015]
# roots = [[5.5379999999984725 .. 5.6010000000001759]]
# seg_domain = [0.0048028783727901138 .. 0.58300000000000052]
# roots = [[5.5379999999984725 .. 5.6010000000001759]]
# seg_domain = [4.5010000000000003 .. 4.6010000000000009]
# roots = [[5.5379999999984725 .. 5.6010000000001759]]
# PolyObserver(-x6 + 1, <flowstar.reachability.Reach object at 0x55d75cfcfb10>, 0.10000000000000000?*x1*x6 + x2*x6 + 2*x6*x8 - 50*x3 - 100*x4 - 50*x5 + x6 symbolic_composition=False, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 5.6010000000000009], [[0.0048028783727901138 .. 1.5830000000000007], [4.5010000000000003 .. 5.6010000000000009]]))
# symbolic_composition=False, tentative_unpreconditioning=True
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 10.15 seconds
# roots = [[0.71099999999997254 .. 0.96745983959350124], [5.3549999999985740 .. 5.6010000000001759]]
# domain = [0.0000000000000000 .. 5.6000000000000015]
# roots = [[0.71099999999997254 .. 0.96745983959350124],
#  [5.3549999999985740 .. 5.6010000000001759]]
# seg_domain = [0.0048028783727901138 .. 1.5830000000000007]
# roots = [[0.71099999999997254 .. 0.96745983959350124],
#  [5.3549999999985740 .. 5.6010000000001759]]
# seg_domain = [4.5010000000000003 .. 5.6010000000000009]
# roots = [[0.71099999999997254 .. 0.96745983959350124],
#  [5.3549999999985740 .. 5.6010000000001759]]
# 0 at 5.60100000000001
# PolyObserver(-x4 + 0.020000000000000001?, <flowstar.reachability.Reach object at 0x55d75cfcfb10>, -x2*x6 + 100*x4 symbolic_composition=False, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 5.6010000000000009], [[0.0048028783727901138 .. 0.0048028783727901139], [0.71099999999997254 .. 1.5830000000000007], [4.5010000000000003 .. 5.6010000000000009]]))
# symbolic_composition=False, tentative_unpreconditioning=True
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 14.17 seconds
# roots = [[0.038530722578615367 .. 0.039000000000000028], [0.040516218919408222 .. 0.10200000000000010], [0.25351103272975694 .. 1.1010000000000047], [5.5289999999984775 .. 5.6010000000001759]]
# domain = [0.0000000000000000 .. 5.6000000000000015]
# roots = [[0.038530722578615367 .. 0.039000000000000028],
#  [0.040516218919408222 .. 0.10200000000000010],
#  [0.25351103272975694 .. 1.1010000000000047],
#  [5.5289999999984775 .. 5.6010000000001759]]
# seg_domain = [0.0048028783727901138 .. 0.0048028783727901139]
# roots = [[0.038530722578615367 .. 0.039000000000000028],
#  [0.040516218919408222 .. 0.10200000000000010],
#  [0.25351103272975694 .. 1.1010000000000047],
#  [5.5289999999984775 .. 5.6010000000001759]]
# seg_domain = [0.71099999999997254 .. 1.5830000000000007]
# roots = [[0.038530722578615367 .. 0.039000000000000028],
#  [0.040516218919408222 .. 0.10200000000000010],
#  [0.25351103272975694 .. 1.1010000000000047],
#  [5.5289999999984775 .. 5.6010000000001759]]
# seg_domain = [4.5010000000000003 .. 5.6010000000000009]
# roots = [[0.038530722578615367 .. 0.039000000000000028],
#  [0.040516218919408222 .. 0.10200000000000010],
#  [0.25351103272975694 .. 1.1010000000000047],
#  [5.5289999999984775 .. 5.6010000000001759]]
# 0 at 5.60100000000001
# Monitoring Signal for F([0.0000000000000000 .. 0.50000000000000000], x6 > 1.40000000000000 & G([0.0000000000000000 .. 0.10000000000000001], x6 < 1.80000000000000 & F([0 .. 1], x6 < 1 & x4 < 0.0200000000000000))): 1 items in 41.13 seconds
# Monitored signal in 41.13109319398063 sec
# ran "composing flowpipe" 1055 times in 25.713378190994263
# ran "whole domain eval" 1053 times in 2.0650839805603027
# ran "tentative eval" 6909 times in 6.896109342575073
# ran "root detection" 659 times in 2.8252735137939453
# ran "root amalgamation" 659 times in 0.0007410049438476562
# ran "mask intersect check" 7468 times in 0.006497859954833984
# ran "post retrieve" 659 times in 0.0038547515869140625
# Run done in 117.71948170661926 sec
# options: {'use_masks': True}
# Graphics object consisting of 2 graphics primitives

# %%
test_monitoring(prop, 1, use_masks=False)[1].plot()
# Out:
# Precomposing Contexts: 1 items in 0.00 seconds
# calling reach with y0 = ['[0.97999999999999998 .. 1.0200000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[2.4799999999999999 .. 2.5200000000000001]', '[0.57999999999999996 .. 0.62000000000000011]', '[1.2799999999999998 .. 1.3200000000000001]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x1, x2, x3, x4, x5, x6, x7, x8, x9]
# C = [0.98..1.02]
# C = [1.2799999999999998..1.32]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [1.2799999999999998..1.32]
# C = [2.48..2.52]
# C = [0.58..0.6200000000000001]
# C = [1.2799999999999998..1.32]
# integrationScheme = 7
# Running Flow*: 1 items in 37.89 seconds
# Computed 867 flowpipes in 37.88708438700996 sec
# PolyObserver(x6 - 1.4000000000000000?, <flowstar.reachability.Reach object at 0x55d764299e40>, -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6 symbolic_composition=False, tentative_unpreconditioning=True, mask=None)
# symbolic_composition=False, tentative_unpreconditioning=True
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = []
# domain = [0.0000000000000000 .. 2.6000000000000006]
# roots = []
# seg_domain = [0.0000000000000000 .. 2.6000000000000006]
# roots = []
# In G.signal
# PolyObserver(-x6 + 1.8000000000000001?, <flowstar.reachability.Reach object at 0x55d764299e40>, 0.10000000000000000?*x1*x6 + x2*x6 + 2*x6*x8 - 50*x3 - 100*x4 - 50*x5 + x6 symbolic_composition=False, tentative_unpreconditioning=True, mask=None)
# symbolic_composition=False, tentative_unpreconditioning=True
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = []
# domain = [0.0000000000000000 .. 2.6000000000000006]
# roots = []
# seg_domain = [0.0000000000000000 .. 2.6000000000000006]
# roots = []
# PolyObserver(-x6 + 1, <flowstar.reachability.Reach object at 0x55d764299e40>, 0.10000000000000000?*x1*x6 + x2*x6 + 2*x6*x8 - 50*x3 - 100*x4 - 50*x5 + x6 symbolic_composition=False, tentative_unpreconditioning=True, mask=None)
# symbolic_composition=False, tentative_unpreconditioning=True
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = []
# domain = [0.0000000000000000 .. 2.6000000000000006]
# roots = []
# seg_domain = [0.0000000000000000 .. 2.6000000000000006]
# roots = []
# PolyObserver(-x4 + 0.020000000000000001?, <flowstar.reachability.Reach object at 0x55d764299e40>, -x2*x6 + 100*x4 symbolic_composition=False, tentative_unpreconditioning=True, mask=None)
# symbolic_composition=False, tentative_unpreconditioning=True
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = []
# domain = [0.0000000000000000 .. 2.6000000000000006]
# roots = []
# seg_domain = [0.0000000000000000 .. 2.6000000000000006]
# roots = []
# Monitoring Signal for F([0.0000000000000000 .. 0.50000000000000000], x6 > 1.40000000000000 & G([0.0000000000000000 .. 0.10000000000000001], x6 < 1.80000000000000 & F([0 .. 1], x6 < 1 & x4 < 0.0200000000000000))): 1 items in 1.60 seconds
# Monitored signal in 1.6031174949603155 sec
# ran "composing flowpipe" 4 times in 0.06307172775268555
# ran "mask intersect check" 3468 times in 0.004083156585693359
# Run done in 39.74675750732422 sec
# options: {'use_masks': False}
# /usr/lib64/python3.7/site-packages/sage/plot/contour_plot.py:205: UserWarning: No contour levels were found within the data range.
#   linewidths=linewidths, linestyles=linestyles)
# Graphics object consisting of 2 graphics primitives

# %%
test_monitoring(prop, 1, use_masks=True)[1].plot()
# Out:
# Precomposing Contexts: 1 items in 0.00 seconds
# calling reach with y0 = ['[0.97999999999999998 .. 1.0200000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[2.4799999999999999 .. 2.5200000000000001]', '[0.57999999999999996 .. 0.62000000000000011]', '[1.2799999999999998 .. 1.3200000000000001]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x1, x2, x3, x4, x5, x6, x7, x8, x9]
# C = [0.98..1.02]
# C = [1.2799999999999998..1.32]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [1.2799999999999998..1.32]
# C = [2.48..2.52]
# C = [0.58..0.6200000000000001]
# C = [1.2799999999999998..1.32]
# integrationScheme = 7
# Running Flow*: 1 items in 37.32 seconds
# Computed 867 flowpipes in 37.3233252390346 sec
# PolyObserver(x6 - 1.4000000000000000?, <flowstar.reachability.Reach object at 0x55d764299e40>, -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6 symbolic_composition=False, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 2.6010000000000005], [[0.0000000000000000 .. 1.5010000000000002]]))
# symbolic_composition=False, tentative_unpreconditioning=True
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 5.62 seconds
# roots = [[0.0048028783727901138 .. 0.020435765977123051], [0.20345478283219919 .. 0.48300000000000043]]
# domain = [0.0000000000000000 .. 2.6000000000000006]
# roots = [[0.0048028783727901138 .. 0.020435765977123051],
#  [0.20345478283219919 .. 0.48300000000000043]]
# seg_domain = [0.0000000000000000 .. 1.5010000000000002]
# roots = [[0.0048028783727901138 .. 0.020435765977123051],
#  [0.20345478283219919 .. 0.48300000000000043]]
# In G.signal
# PolyObserver(-x6 + 1.8000000000000001?, <flowstar.reachability.Reach object at 0x55d764299e40>, 0.10000000000000000?*x1*x6 + x2*x6 + 2*x6*x8 - 50*x3 - 100*x4 - 50*x5 + x6 symbolic_composition=False, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 2.6010000000000005], [[0.0048028783727901138 .. 0.58300000000000052], [1.5010000000000001 .. 1.6010000000000003]]))
# symbolic_composition=False, tentative_unpreconditioning=True
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 1.00 seconds
# roots = []
# domain = [0.0000000000000000 .. 2.6000000000000006]
# roots = []
# seg_domain = [0.0048028783727901138 .. 0.58300000000000052]
# roots = []
# seg_domain = [1.5010000000000001 .. 1.6010000000000003]
# roots = []
# PolyObserver(-x6 + 1, <flowstar.reachability.Reach object at 0x55d764299e40>, 0.10000000000000000?*x1*x6 + x2*x6 + 2*x6*x8 - 50*x3 - 100*x4 - 50*x5 + x6 symbolic_composition=False, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 2.6010000000000005], [[0.0048028783727901138 .. 2.6010000000000005]]))
# symbolic_composition=False, tentative_unpreconditioning=True
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 6.49 seconds
# roots = [[0.71099999999997254 .. 0.96745983959350124]]
# domain = [0.0000000000000000 .. 2.6000000000000006]
# roots = [[0.71099999999997254 .. 0.96745983959350124]]
# seg_domain = [0.0048028783727901138 .. 2.6010000000000005]
# roots = [[0.71099999999997254 .. 0.96745983959350124]]
# PolyObserver(-x4 + 0.020000000000000001?, <flowstar.reachability.Reach object at 0x55d764299e40>, -x2*x6 + 100*x4 symbolic_composition=False, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 2.6010000000000005], [[0.0048028783727901138 .. 0.0048028783727901139], [0.71099999999997254 .. 2.6010000000000005]]))
# symbolic_composition=False, tentative_unpreconditioning=True
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 13.56 seconds
# roots = [[0.038530722578615367 .. 0.039000000000000028], [0.040516218919408222 .. 0.10200000000000010], [0.25351103272975694 .. 1.1010000000000047]]
# domain = [0.0000000000000000 .. 2.6000000000000006]
# roots = [[0.038530722578615367 .. 0.039000000000000028],
#  [0.040516218919408222 .. 0.10200000000000010],
#  [0.25351103272975694 .. 1.1010000000000047]]
# seg_domain = [0.0048028783727901138 .. 0.0048028783727901139]
# roots = [[0.038530722578615367 .. 0.039000000000000028],
#  [0.040516218919408222 .. 0.10200000000000010],
#  [0.25351103272975694 .. 1.1010000000000047]]
# seg_domain = [0.71099999999997254 .. 2.6010000000000005]
# roots = [[0.038530722578615367 .. 0.039000000000000028],
#  [0.040516218919408222 .. 0.10200000000000010],
#  [0.25351103272975694 .. 1.1010000000000047]]
# Monitoring Signal for F([0.0000000000000000 .. 0.50000000000000000], x6 > 1.40000000000000 & G([0.0000000000000000 .. 0.10000000000000001], x6 < 1.80000000000000 & F([0 .. 1], x6 < 1 & x4 < 0.0200000000000000))): 1 items in 28.38 seconds
# Monitored signal in 28.38259835797362 sec
# ran "composing flowpipe" 807 times in 19.641998529434204
# ran "whole domain eval" 807 times in 1.6946232318878174
# ran "tentative eval" 3073 times in 2.9647977352142334
# ran "root detection" 491 times in 2.2688090801239014
# ran "root amalgamation" 491 times in 0.0005466938018798828
# ran "mask intersect check" 3468 times in 0.002962827682495117
# ran "post retrieve" 491 times in 0.003038644790649414
# Run done in 65.9184947013855 sec
# options: {'use_masks': True}
# Graphics object consisting of 2 graphics primitives

# %%
test_monitoring(prop, 0, use_masks=False)[1](0)
# Out:
# Precomposing Contexts: 1 items in 0.00 seconds
# calling reach with y0 = ['[0.97999999999999998 .. 1.0200000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[2.4799999999999999 .. 2.5200000000000001]', '[0.57999999999999996 .. 0.62000000000000011]', '[1.2799999999999998 .. 1.3200000000000001]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x1, x2, x3, x4, x5, x6, x7, x8, x9]
# C = [0.98..1.02]
# C = [1.2799999999999998..1.32]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [1.2799999999999998..1.32]
# C = [2.48..2.52]
# C = [0.58..0.6200000000000001]
# C = [1.2799999999999998..1.32]
# integrationScheme = 7
# Running Flow*: 1 items in 23.43 seconds
# Computed 534 flowpipes in 23.434050789044704 sec
# PolyObserver(x6 - 1.4000000000000000?, <flowstar.reachability.Reach object at 0x55d75b701d70>, -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6 symbolic_composition=False, tentative_unpreconditioning=True, mask=None)
# symbolic_composition=False, tentative_unpreconditioning=True
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = []
# domain = [0.0000000000000000 .. 1.6000000000000004]
# roots = []
# seg_domain = [0.0000000000000000 .. 1.6000000000000004]
# roots = []
# In G.signal
# PolyObserver(-x6 + 1.8000000000000001?, <flowstar.reachability.Reach object at 0x55d75b701d70>, 0.10000000000000000?*x1*x6 + x2*x6 + 2*x6*x8 - 50*x3 - 100*x4 - 50*x5 + x6 symbolic_composition=False, tentative_unpreconditioning=True, mask=None)
# symbolic_composition=False, tentative_unpreconditioning=True
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = []
# domain = [0.0000000000000000 .. 1.6000000000000004]
# roots = []
# seg_domain = [0.0000000000000000 .. 1.6000000000000004]
# roots = []
# PolyObserver(-x6 + 1, <flowstar.reachability.Reach object at 0x55d75b701d70>, 0.10000000000000000?*x1*x6 + x2*x6 + 2*x6*x8 - 50*x3 - 100*x4 - 50*x5 + x6 symbolic_composition=False, tentative_unpreconditioning=True, mask=None)
# symbolic_composition=False, tentative_unpreconditioning=True
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = []
# domain = [0.0000000000000000 .. 1.6000000000000004]
# roots = []
# seg_domain = [0.0000000000000000 .. 1.6000000000000004]
# roots = []
# 0 at 1.60000000000001
# PolyObserver(-x4 + 0.020000000000000001?, <flowstar.reachability.Reach object at 0x55d75b701d70>, -x2*x6 + 100*x4 symbolic_composition=False, tentative_unpreconditioning=True, mask=None)
# symbolic_composition=False, tentative_unpreconditioning=True
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = []
# domain = [0.0000000000000000 .. 1.6000000000000004]
# roots = []
# seg_domain = [0.0000000000000000 .. 1.6000000000000004]
# roots = []
# 0 at 1.60000000000001
# Monitoring Signal for F([0.0000000000000000 .. 0.50000000000000000], x6 > 1.40000000000000 & G([0.0000000000000000 .. 0.10000000000000001], x6 < 1.80000000000000 & F([0 .. 1], x6 < 1 & x4 < 0.0200000000000000))): 1 items in 0.87 seconds
# Monitored signal in 0.8724024159891997 sec
# ran "composing flowpipe" 4 times in 0.05335068702697754
# ran "mask intersect check" 2136 times in 0.002527475357055664
# Run done in 24.434986114501953 sec
# options: {'use_masks': False}
# False

# %%
test_monitoring(prop, 0, use_masks=True)[1](0)
# Out:
# Precomposing Contexts: 1 items in 0.00 seconds
# calling reach with y0 = ['[0.97999999999999998 .. 1.0200000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[2.4799999999999999 .. 2.5200000000000001]', '[0.57999999999999996 .. 0.62000000000000011]', '[1.2799999999999998 .. 1.3200000000000001]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x1, x2, x3, x4, x5, x6, x7, x8, x9]
# C = [0.98..1.02]
# C = [1.2799999999999998..1.32]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [1.2799999999999998..1.32]
# C = [2.48..2.52]
# C = [0.58..0.6200000000000001]
# C = [1.2799999999999998..1.32]
# integrationScheme = 7
# Running Flow*: 1 items in 21.24 seconds
# Computed 534 flowpipes in 21.23675852501765 sec
# PolyObserver(x6 - 1.4000000000000000?, <flowstar.reachability.Reach object at 0x55d75b701d70>, -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6 symbolic_composition=False, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 1.6010000000000003], [[0.0000000000000000 .. 0.50100000000000001]]))
# symbolic_composition=False, tentative_unpreconditioning=True
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 5.60 seconds
# roots = [[0.0048028783727901138 .. 0.020435765977123051], [0.20345478283219919 .. 0.48300000000000043]]
# domain = [0.0000000000000000 .. 1.6000000000000004]
# roots = [[0.0048028783727901138 .. 0.020435765977123051],
#  [0.20345478283219919 .. 0.48300000000000043]]
# seg_domain = [0.0000000000000000 .. 0.50100000000000001]
# roots = [[0.0048028783727901138 .. 0.020435765977123051],
#  [0.20345478283219919 .. 0.48300000000000043]]
# In G.signal
# PolyObserver(-x6 + 1.8000000000000001?, <flowstar.reachability.Reach object at 0x55d75b701d70>, 0.10000000000000000?*x1*x6 + x2*x6 + 2*x6*x8 - 50*x3 - 100*x4 - 50*x5 + x6 symbolic_composition=False, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 1.6010000000000003], [[0.0048028783727901138 .. 0.60100000000000009]]))
# symbolic_composition=False, tentative_unpreconditioning=True
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.57 seconds
# roots = []
# domain = [0.0000000000000000 .. 1.6000000000000004]
# roots = []
# seg_domain = [0.0048028783727901138 .. 0.60100000000000009]
# roots = []
# PolyObserver(-x6 + 1, <flowstar.reachability.Reach object at 0x55d75b701d70>, 0.10000000000000000?*x1*x6 + x2*x6 + 2*x6*x8 - 50*x3 - 100*x4 - 50*x5 + x6 symbolic_composition=False, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 1.6010000000000003], [[0.0048028783727901138 .. 1.6010000000000003]]))
# symbolic_composition=False, tentative_unpreconditioning=True
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 5.82 seconds
# roots = [[0.71099999999997254 .. 0.96745983959350124]]
# domain = [0.0000000000000000 .. 1.6000000000000004]
# roots = [[0.71099999999997254 .. 0.96745983959350124]]
# seg_domain = [0.0048028783727901138 .. 1.6010000000000003]
# roots = [[0.71099999999997254 .. 0.96745983959350124]]
# PolyObserver(-x4 + 0.020000000000000001?, <flowstar.reachability.Reach object at 0x55d75b701d70>, -x2*x6 + 100*x4 symbolic_composition=False, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 1.6010000000000003], [[0.0048028783727901138 .. 0.0048028783727901139], [0.71099999999997254 .. 1.6010000000000003]]))
# symbolic_composition=False, tentative_unpreconditioning=True
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 13.13 seconds
# roots = [[0.038530722578615367 .. 0.039000000000000028], [0.040516218919408222 .. 0.10200000000000010], [0.25351103272975694 .. 1.1010000000000047]]
# domain = [0.0000000000000000 .. 1.6000000000000004]
# roots = [[0.038530722578615367 .. 0.039000000000000028],
#  [0.040516218919408222 .. 0.10200000000000010],
#  [0.25351103272975694 .. 1.1010000000000047]]
# seg_domain = [0.0048028783727901138 .. 0.0048028783727901139]
# roots = [[0.038530722578615367 .. 0.039000000000000028],
#  [0.040516218919408222 .. 0.10200000000000010],
#  [0.25351103272975694 .. 1.1010000000000047]]
# seg_domain = [0.71099999999997254 .. 1.6010000000000003]
# roots = [[0.038530722578615367 .. 0.039000000000000028],
#  [0.040516218919408222 .. 0.10200000000000010],
#  [0.25351103272975694 .. 1.1010000000000047]]
# Monitoring Signal for F([0.0000000000000000 .. 0.50000000000000000], x6 > 1.40000000000000 & G([0.0000000000000000 .. 0.10000000000000001], x6 < 1.80000000000000 & F([0 .. 1], x6 < 1 & x4 < 0.0200000000000000))): 1 items in 26.04 seconds
# Monitored signal in 26.040824472962413 sec
# ran "composing flowpipe" 807 times in 19.595552444458008
# ran "whole domain eval" 807 times in 1.6097984313964844
# ran "tentative eval" 1741 times in 1.5993406772613525
# ran "root detection" 491 times in 2.236006736755371
# ran "root amalgamation" 491 times in 0.0005176067352294922
# ran "mask intersect check" 2136 times in 0.0017266273498535156
# ran "post retrieve" 491 times in 0.002813100814819336
# Run done in 47.40993571281433 sec
# options: {'use_masks': True}
# True

# %% [markdown]
# # Optimizing and speedup

# %%
P = Atomic(var("x6") > 1.4); P
# Out:
# Atomic(x6 > 1.40000000000000)

# %%
sigP = test_monitoring(P, 4, use_masks=False)[1]
sigP.plot()
# Out:
# Precomposing Contexts: 1 items in 0.00 seconds
# calling reach with y0 = ['[0.97999999999999998 .. 1.0200000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[2.4799999999999999 .. 2.5200000000000001]', '[0.57999999999999996 .. 0.62000000000000011]', '[1.2799999999999998 .. 1.3200000000000001]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x1, x2, x3, x4, x5, x6, x7, x8, x9]
# C = [0.98..1.02]
# C = [1.2799999999999998..1.32]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [1.2799999999999998..1.32]
# C = [2.48..2.52]
# C = [0.58..0.6200000000000001]
# C = [1.2799999999999998..1.32]
# integrationScheme = 7
# Running Flow*: 1 items in 50.71 seconds
# Computed 1334 flowpipes in 50.707516577036586 sec
# PolyObserver(x6 - 1.4000000000000000?, <flowstar.reachability.Reach object at 0x55d75b701d70>, -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6 symbolic_composition=False, tentative_unpreconditioning=True, mask=None)
# symbolic_composition=False, tentative_unpreconditioning=True
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.01 seconds
# roots = []
# domain = [0.0000000000000000 .. 3.9999999999999996]
# roots = []
# seg_domain = [0.0000000000000000 .. 3.9999999999999996]
# roots = []
# Monitoring Signal for x6 > 1.40000000000000: 1 items in 0.37 seconds
# Monitored signal in 0.3651981039729435 sec
# ran "composing flowpipe" 1 times in 0.06116151809692383
# ran "mask intersect check" 1334 times in 0.00167083740234375
# Run done in 51.35841250419617 sec
# options: {'use_masks': False}
# /usr/lib64/python3.7/site-packages/sage/plot/contour_plot.py:205: UserWarning: No contour levels were found within the data range.
#   linewidths=linewidths, linestyles=linestyles)
# Graphics object consisting of 2 graphics primitives

# %%
sigP.to_mask_and().plot()
# Out:
# /usr/lib64/python3.7/site-packages/sage/plot/contour_plot.py:205: UserWarning: No contour levels were found within the data range.
#   linewidths=linewidths, linestyles=linestyles)
# Graphics object consisting of 2 graphics primitives

# %%
Q = Atomic(var("x6") < 1); Q
# Out:
# Atomic(x6 < 1)

# %%
sigQ = test_monitoring(Q, 4, use_masks=False)[1]
sigQ.plot()
# Out:
# Precomposing Contexts: 1 items in 0.00 seconds
# calling reach with y0 = ['[0.97999999999999998 .. 1.0200000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[2.4799999999999999 .. 2.5200000000000001]', '[0.57999999999999996 .. 0.62000000000000011]', '[1.2799999999999998 .. 1.3200000000000001]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x1, x2, x3, x4, x5, x6, x7, x8, x9]
# C = [0.98..1.02]
# C = [1.2799999999999998..1.32]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [1.2799999999999998..1.32]
# C = [2.48..2.52]
# C = [0.58..0.6200000000000001]
# C = [1.2799999999999998..1.32]
# integrationScheme = 7
# Running Flow*: 1 items in 55.87 seconds
# Computed 1334 flowpipes in 55.870879006019095 sec
# PolyObserver(-x6 + 1, <flowstar.reachability.Reach object at 0x55d765fa3f70>, 0.10000000000000000?*x1*x6 + x2*x6 + 2*x6*x8 - 50*x3 - 100*x4 - 50*x5 + x6 symbolic_composition=False, tentative_unpreconditioning=True, mask=None)
# symbolic_composition=False, tentative_unpreconditioning=True
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.01 seconds
# roots = []
# domain = [0.0000000000000000 .. 3.9999999999999996]
# roots = []
# seg_domain = [0.0000000000000000 .. 3.9999999999999996]
# roots = []
# Monitoring Signal for x6 < 1: 1 items in 0.36 seconds
# Monitored signal in 0.3649824809690472 sec
# ran "composing flowpipe" 1 times in 0.05974888801574707
# ran "mask intersect check" 1334 times in 0.001575469970703125
# Run done in 56.49214434623718 sec
# options: {'use_masks': False}
# /usr/lib64/python3.7/site-packages/sage/plot/contour_plot.py:205: UserWarning: No contour levels were found within the data range.
#   linewidths=linewidths, linestyles=linestyles)
# Graphics object consisting of 2 graphics primitives

# %%
sigQ = test_monitoring(Q, 4, mask=sigP.to_mask_and())[1]
sigQ.plot()
# Out:
# Precomposing Contexts: 1 items in 0.00 seconds
# calling reach with y0 = ['[0.97999999999999998 .. 1.0200000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[2.4799999999999999 .. 2.5200000000000001]', '[0.57999999999999996 .. 0.62000000000000011]', '[1.2799999999999998 .. 1.3200000000000001]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x1, x2, x3, x4, x5, x6, x7, x8, x9]
# C = [0.98..1.02]
# C = [1.2799999999999998..1.32]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [1.2799999999999998..1.32]
# C = [2.48..2.52]
# C = [0.58..0.6200000000000001]
# C = [1.2799999999999998..1.32]
# integrationScheme = 7
# Running Flow*: 1 items in 53.40 seconds
# Computed 1334 flowpipes in 53.40442393600824 sec
# PolyObserver(-x6 + 1, <flowstar.reachability.Reach object at 0x55d76bdd5b70>, 0.10000000000000000?*x1*x6 + x2*x6 + 2*x6*x8 - 50*x3 - 100*x4 - 50*x5 + x6 symbolic_composition=False, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 4.0000000000000000], [[3.9999999999999995 .. 4.0000000000000000]]))
# symbolic_composition=False, tentative_unpreconditioning=True
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 7.60 seconds
# roots = [[0.71099999999997254 .. 0.96745983959350124]]
# domain = [0.0000000000000000 .. 3.9999999999999996]
# roots = [[0.71099999999997254 .. 0.96745983959350124]]
# seg_domain = [3.9999999999999995 .. 4.0000000000000000]
# roots = [[0.71099999999997254 .. 0.96745983959350124]]
# Monitoring Signal for x6 < 1: 1 items in 7.92 seconds
# Monitored signal in 7.916285254963441 sec
# ran "composing flowpipe" 89 times in 5.256388902664185
# ran "whole domain eval" 89 times in 0.2021186351776123
# ran "tentative eval" 1334 times in 1.6829676628112793
# ran "root detection" 86 times in 0.40193700790405273
# ran "root amalgamation" 86 times in 0.0001366138458251953
# ran "mask intersect check" 1334 times in 0.0016889572143554688
# ran "post retrieve" 86 times in 0.0007302761077880859
# Run done in 61.59556317329407 sec
# options: {'mask': Mask([0.0000000000000000 .. 4.0000000000000000], [[3.9999999999999995 .. 4.0000000000000000]])}
# /usr/lib64/python3.7/site-packages/sage/plot/contour_plot.py:205: UserWarning: No contour levels were found within the data range.
#   linewidths=linewidths, linestyles=linestyles)
# Graphics object consisting of 2 graphics primitives

# %%
sigPQ = test_monitoring(P & Q, 4, use_masks=False)[1]
sigPQ.plot()
# Out:
# Precomposing Contexts: 1 items in 0.00 seconds
# calling reach with y0 = ['[0.97999999999999998 .. 1.0200000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[2.4799999999999999 .. 2.5200000000000001]', '[0.57999999999999996 .. 0.62000000000000011]', '[1.2799999999999998 .. 1.3200000000000001]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x1, x2, x3, x4, x5, x6, x7, x8, x9]
# C = [0.98..1.02]
# C = [1.2799999999999998..1.32]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [1.2799999999999998..1.32]
# C = [2.48..2.52]
# C = [0.58..0.6200000000000001]
# C = [1.2799999999999998..1.32]
# integrationScheme = 7
# Running Flow*: 1 items in 53.49 seconds
# Computed 1334 flowpipes in 53.48597311403137 sec
# PolyObserver(x6 - 1.4000000000000000?, <flowstar.reachability.Reach object at 0x55d76f6d1d20>, -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6 symbolic_composition=False, tentative_unpreconditioning=True, mask=None)
# symbolic_composition=False, tentative_unpreconditioning=True
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.01 seconds
# roots = []
# domain = [0.0000000000000000 .. 3.9999999999999996]
# roots = []
# seg_domain = [0.0000000000000000 .. 3.9999999999999996]
# roots = []
# PolyObserver(-x6 + 1, <flowstar.reachability.Reach object at 0x55d76f6d1d20>, 0.10000000000000000?*x1*x6 + x2*x6 + 2*x6*x8 - 50*x3 - 100*x4 - 50*x5 + x6 symbolic_composition=False, tentative_unpreconditioning=True, mask=None)
# symbolic_composition=False, tentative_unpreconditioning=True
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.01 seconds
# roots = []
# domain = [0.0000000000000000 .. 3.9999999999999996]
# roots = []
# seg_domain = [0.0000000000000000 .. 3.9999999999999996]
# roots = []
# Monitoring Signal for x6 > 1.40000000000000 & x6 < 1: 1 items in 0.81 seconds
# Monitored signal in 0.806361302966252 sec
# ran "composing flowpipe" 2 times in 0.058979034423828125
# ran "mask intersect check" 2668 times in 0.003483295440673828
# Run done in 54.5643253326416 sec
# options: {'use_masks': False}
# /usr/lib64/python3.7/site-packages/sage/plot/contour_plot.py:205: UserWarning: No contour levels were found within the data range.
#   linewidths=linewidths, linestyles=linestyles)
# Graphics object consisting of 2 graphics primitives

# %%
sigPQ = test_monitoring(P & Q, 4, use_masks=True)[1]
sigPQ.plot()
# Out:
# Precomposing Contexts: 1 items in 0.00 seconds
# calling reach with y0 = ['[0.97999999999999998 .. 1.0200000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[2.4799999999999999 .. 2.5200000000000001]', '[0.57999999999999996 .. 0.62000000000000011]', '[1.2799999999999998 .. 1.3200000000000001]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x1, x2, x3, x4, x5, x6, x7, x8, x9]
# C = [0.98..1.02]
# C = [1.2799999999999998..1.32]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [1.2799999999999998..1.32]
# C = [2.48..2.52]
# C = [0.58..0.6200000000000001]
# C = [1.2799999999999998..1.32]
# integrationScheme = 7
# Running Flow*: 1 items in 52.32 seconds
# Computed 1334 flowpipes in 52.322946256026626 sec
# PolyObserver(x6 - 1.4000000000000000?, <flowstar.reachability.Reach object at 0x55d773052c40>, -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6 symbolic_composition=False, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 4.0009999999999995], [[0.0000000000000000 .. 4.0009999999999995]]))
# symbolic_composition=False, tentative_unpreconditioning=True
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 5.01 seconds
# roots = [[0.0048028783727901138 .. 0.020435765977123051], [0.20345478283219919 .. 0.48300000000000043]]
# domain = [0.0000000000000000 .. 3.9999999999999996]
# roots = [[0.0048028783727901138 .. 0.020435765977123051],
#  [0.20345478283219919 .. 0.48300000000000043]]
# seg_domain = [0.0000000000000000 .. 4.0009999999999995]
# roots = [[0.0048028783727901138 .. 0.020435765977123051],
#  [0.20345478283219919 .. 0.48300000000000043]]
# PolyObserver(-x6 + 1, <flowstar.reachability.Reach object at 0x55d773052c40>, 0.10000000000000000?*x1*x6 + x2*x6 + 2*x6*x8 - 50*x3 - 100*x4 - 50*x5 + x6 symbolic_composition=False, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 4.0009999999999995], [[0.0048028783727901138 .. 0.48300000000000043]]))
# symbolic_composition=False, tentative_unpreconditioning=True
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 5.36 seconds
# roots = [[0.71099999999997254 .. 0.96745983959350124]]
# domain = [0.0000000000000000 .. 3.9999999999999996]
# roots = [[0.71099999999997254 .. 0.96745983959350124]]
# seg_domain = [0.0048028783727901138 .. 0.48300000000000043]
# roots = [[0.71099999999997254 .. 0.96745983959350124]]
# Monitoring Signal for x6 > 1.40000000000000 & x6 < 1: 1 items in 11.44 seconds
# Monitored signal in 11.44282896295772 sec
# ran "composing flowpipe" 293 times in 7.325237989425659
# ran "whole domain eval" 293 times in 0.48752856254577637
# ran "tentative eval" 2566 times in 1.888807773590088
# ran "root detection" 186 times in 0.6254703998565674
# ran "root amalgamation" 186 times in 0.0001685619354248047
# ran "mask intersect check" 2668 times in 0.0015339851379394531
# ran "post retrieve" 186 times in 0.0011820793151855469
# Run done in 64.11067938804626 sec
# options: {'use_masks': True}
# /usr/lib64/python3.7/site-packages/sage/plot/contour_plot.py:205: UserWarning: No contour levels were found within the data range.
#   linewidths=linewidths, linestyles=linestyles)
# Graphics object consisting of 2 graphics primitives
