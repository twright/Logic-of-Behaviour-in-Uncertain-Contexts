# %%
# %display latex

# %%
var("t")
# Out:
# t

# %%
x, y = vs = function("x")(t), function("y")(t)

# %%
v = vector([derivative(x, t) == -y, derivative(y, t) == x]); v
# Out:
# (diff(x(t), t) == -y(t), diff(y(t), t) == x(t))

# %%
desolve_system(v, vs)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /usr/lib64/python3.8/site-packages/sage/interfaces/interface.py in __init__(self, parent, value, is_name, name)
#     717             try:
# --> 718                 self._name = parent._create(value, name=name)
#     719             except (TypeError, RuntimeError, ValueError) as x:
#
# /usr/lib64/python3.8/site-packages/sage/interfaces/maxima_lib.py in _create(self, value, name)
#     604             else:
# --> 605                 self.set(name, value)
#     606         except RuntimeError as error:
#
# /usr/lib64/python3.8/site-packages/sage/interfaces/maxima_lib.py in set(self, var, value)
#     513         cmd = '%s : %s$'%(var, value.rstrip(';'))
# --> 514         self.eval(cmd)
#     515
#
# /usr/lib64/python3.8/site-packages/sage/interfaces/maxima_lib.py in _eval_line(self, line, locals, reformat, **kwds)
# ...
