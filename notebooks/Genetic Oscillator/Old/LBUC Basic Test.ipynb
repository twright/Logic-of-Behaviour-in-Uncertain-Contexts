# %% [markdown]
# # Tests

# %% [markdown]
# ## Example 1: Simple

# %%
import sys

sys.path.insert(0, "/home/twright/Documents/PhD/Notebooks")

from flowstar.reachability import Reach
from flowstar.poly import Poly
from lbuc import *

# %%
kwargs = {
    'symbolic_composition': True,
}

# %%
R.<t,x,y> = RIF[]

# %%
odes = [
    R(1),
    -y,
    x,
]
initials = [(0,0), (4,5), (1,2)]
system = System(
    R,
    [t, x, y],
    initials,
    odes,
)
reach = system.reach(2*pi, step=0.1, order=10,
              precompose_taylor_models=False,
              symbolic_composition=False)
reach_sc = system.reach(2*pi, step=0.1, order=10,
              precompose_taylor_models=False,
              symbolic_composition=True)
# Out:
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.0000000000000000 .. 5.0000000000000000]', '[1.0000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.0..5.0]
# C = [1.0..2.0]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# Deallocing CReach
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.0000000000000000 .. 5.0000000000000000]', '[1.0000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.0..5.0]
# C = [1.0..2.0]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2

# %%
def plot_signal(sig):
    return sig.to_domain(RIF(0,2*pi)).plot().show(
        ticks=[pi/2, 1], tick_formatter=pi, aspect_ratio=2/3)

# %%
reach.res
# Out:
# 2

# %%
P = Atomic(x - 3); P
# Out:
# Atomic(x - 3)

# %%
P.signal(reach).plot() + P.sage_plot(reach)
# Out:
# PolyObserver(x - 3, <flowstar.reachability.Reach object at 0x7f10a9a08740>, -y, symbolic_composition=False, tentative_unpreconditioning=True, mask=None)
# fprime = -y
# symbolic_composition=False, tentative_unpreconditioning=True,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.04 seconds
# roots = [[0.36442391108285426 .. 0.75322999900880539], [4.9094498886889716 .. 5.3000000000000105]]
# domain = [0.0000000000000000 .. 6.2831853071795863]
# roots = [[0.36442391108285426 .. 0.75322999900880539],
#  [4.9094498886889716 .. 5.3000000000000105]]
# seg_domain = [0.0000000000000000 .. 6.2831853071795863]
# roots = [[0.36442391108285426 .. 0.75322999900880539],
#  [4.9094498886889716 .. 5.3000000000000105]]
# signal given bool roots: 1 items in 0.00 seconds
# Monitoring atomic x - 3 > 0: 1 items in 0.04 seconds
# ...

# %%
plot_signal( P.signal_for_system(system, 2*pi, **kwargs) )
# Out:
# Precomposing Contexts: 1 items in 0.00 seconds
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.0000000000000000 .. 5.0000000000000000]', '[1.0000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.0..5.0]
# C = [1.0..2.0]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# Running Flow*: 1 items in 0.04 seconds
# Computed 63 flowpipes in 0.042706038046162575 sec
# PolyObserver(x - 3, <flowstar.reachability.Reach object at 0x7f10a9a09f20>, -y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -y
# symbolic_composition=True, tentative_unpreconditioning=True,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.03 seconds
# ...

# %%
Q = Atomic(3 - y); Q
# Out:
# Atomic(-y + 3)

# %%
Q.signal(reach).plot() + Q.sage_plot(reach)
# Out:
# PolyObserver(-y + 3, <flowstar.reachability.Reach object at 0x7f10a9a08740>, -x, symbolic_composition=False, tentative_unpreconditioning=True, mask=None)
# fprime = -x
# symbolic_composition=False, tentative_unpreconditioning=True,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.05 seconds
# roots = [[0.19999999999999995 .. 0.58848494710426814], [1.9311141906428892 .. 2.3182023568246275]]
# domain = [0.0000000000000000 .. 6.2831853071795863]
# roots = [[0.19999999999999995 .. 0.58848494710426814],
#  [1.9311141906428892 .. 2.3182023568246275]]
# seg_domain = [0.0000000000000000 .. 6.2831853071795863]
# roots = [[0.19999999999999995 .. 0.58848494710426814],
#  [1.9311141906428892 .. 2.3182023568246275]]
# signal given bool roots: 1 items in 0.00 seconds
# Monitoring atomic -y + 3 > 0: 1 items in 0.05 seconds
# ...

# %%
plot_signal( Q.signal_for_system(system, 2*pi, **kwargs) )
# Out:
# Precomposing Contexts: 1 items in 0.00 seconds
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.0000000000000000 .. 5.0000000000000000]', '[1.0000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.0..5.0]
# C = [1.0..2.0]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# Running Flow*: 1 items in 0.07 seconds
# Computed 63 flowpipes in 0.07016302703414112 sec
# PolyObserver(-y + 3, <flowstar.reachability.Reach object at 0x7f10a999c2e0>, -x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -x
# symbolic_composition=True, tentative_unpreconditioning=True,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.04 seconds
# ...

# %%
S = Atomic(3 - y**2 + y); S
# Out:
# Atomic(-y^2 + y + 3)

# %%
plot_signal( S.signal_for_system(system, 2*pi, **kwargs) )
# Out:
# Precomposing Contexts: 1 items in 0.00 seconds
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.0000000000000000 .. 5.0000000000000000]', '[1.0000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.0..5.0]
# C = [1.0..2.0]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# Running Flow*: 1 items in 0.05 seconds
# Computed 63 flowpipes in 0.04743535304442048 sec
# PolyObserver(-y^2 + y + 3, <flowstar.reachability.Reach object at 0x7f10a999cc80>, -2*x*y + x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -2*x*y + x
# symbolic_composition=True, tentative_unpreconditioning=True,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.09 seconds
# ...

# %%
plot_signal( S.signal_for_system(system, 2*pi, symbolic_composition=False) )
# Out:
# Precomposing Contexts: 1 items in 0.00 seconds
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.0000000000000000 .. 5.0000000000000000]', '[1.0000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.0..5.0]
# C = [1.0..2.0]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# Running Flow*: 1 items in 0.03 seconds
# Computed 63 flowpipes in 0.025789263076148927 sec
# PolyObserver(-y^2 + y + 3, <flowstar.reachability.Reach object at 0x7f10a959a4a0>, -2*x*y + x, symbolic_composition=False, tentative_unpreconditioning=True, mask=None)
# fprime = -2*x*y + x
# symbolic_composition=False, tentative_unpreconditioning=True,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.03 seconds
# ...

# %%
S.sage_plot(reach)
# Out:
# PolyObserver(-y^2 + y + 3, <flowstar.reachability.Reach object at 0x7f10a9a08740>, -2*x*y + x, symbolic_composition=False, tentative_unpreconditioning=True, mask=None)
# fprime = -2*x*y + x
# Graphics object consisting of 3 graphics primitives

# %%
S.sage_plot(reach, symbolic_composition=True)
# Out:
# PolyObserver(-y^2 + y + 3, <flowstar.reachability.Reach object at 0x7f10aba95820>, -2*x*y + x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -2*x*y + x
# Graphics object consisting of 3 graphics primitives

# %%
graphics_array([
    S.signal_for_system(system, 2*pi, symbolic_composition=False).plot(),
    S.signal_for_system(system, 2*pi, symbolic_composition=True).plot(),
], ncols=1)
# Out:
# Precomposing Contexts: 1 items in 0.00 seconds
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.0000000000000000 .. 5.0000000000000000]', '[1.0000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.0..5.0]
# C = [1.0..2.0]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# Running Flow*: 1 items in 0.03 seconds
# Computed 63 flowpipes in 0.02548943302826956 sec
# PolyObserver(-y^2 + y + 3, <flowstar.reachability.Reach object at 0x7f10a959ac80>, -2*x*y + x, symbolic_composition=False, tentative_unpreconditioning=True, mask=None)
# fprime = -2*x*y + x
# symbolic_composition=False, tentative_unpreconditioning=True,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.03 seconds
# ...

# %%
plot_signal( G(RIF(1,1.2), P).signal_for_system(system, 2*pi, **kwargs) )
# Out:
# Precomposing Contexts: 1 items in 0.00 seconds
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.0000000000000000 .. 5.0000000000000000]', '[1.0000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.0..5.0]
# C = [1.0..2.0]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# Running Flow*: 1 items in 0.03 seconds
# Computed 75 flowpipes in 0.03194125305162743 sec
# In G.signal
# PolyObserver(x - 3, <flowstar.reachability.Reach object at 0x7f10a9260200>, -y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -y
# symbolic_composition=True, tentative_unpreconditioning=True,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.02 seconds
# ...
