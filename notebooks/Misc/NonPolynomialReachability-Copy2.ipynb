# %%
from IPython.display import Image

def display_graphics(g):
    g.save("/tmp/test.png")
    return Image("/tmp/test.png")

#latex.add_to_preamble(r"\usepackage{amsmath}")
from matplotlib import rc
rc('text', usetex=True)
rc('text.latex', preamble=r'\usepackage{amsmath}')
from contextlib import contextmanager
import sys, os

@contextmanager
def suppress_stdout():
    with open(os.devnull, "w") as devnull:
        old_stdout = sys.stdout
        sys.stdout = devnull
        try:  
            yield
        finally:
            sys.stdout = old_stdout
            
            
import warnings
            
@contextmanager
def suppress_warnings():
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        yield

# %%
from flowstar.reachability import *
# flowstar.reachability must be imported before sage otherwise
# sage breaks the flow* yacc parser

# %%
import sage.all as sg

# %%
from ulbc.bondcalculus import *

# %%
t, x = sg.SR.var('t, x')
s = System(
    sg.SR,
    (t, x),
    (sg.RIF(0), sg.RIF(1, 2)),
    (1, 1/(x + 1)),
    {'t': t, 'x': x},
)
s
# Out:
# System(R, (t, x), [0, [1 .. 2]], (1, 1/(x + 1)), varmap={'t': t, 'x': x})

# %%
r = s.reach(5, step=0.01); r.successful
# Out:
# ode in symbolic ring
# str_odes = ['[1.00000000000000 , 1.00000000000000]', '[1 , 1]/(x + [1.00000000000000 , 1.00000000000000])']
# run = True
# var = t type(var) = <class 'str'> var_str = t
# var = x type(var) = <class 'str'> var_str = x
# initials = (0, 2.?)
# True

# %%
#r(3)

# %%
#with suppress_stdout():
#    g = r.sage_time_tube_plot(s.n("x"), 0.2, t=s.n('t'))
    
#display_graphics(g)

# %%
#r.wplot(s.n('t'), s.n("x"))

# %%
from flowstar.observers import SageObserver

# %%
observer = SageObserver(t, r)
# Out:
# SageObserver(t, <flowstar.reachability.Reach object at 0x563ccaf37a38>, symbolic_composition=False, tentative_unpreconditioning=False, mask=None)
# make_interval_fn with f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe0d0>
# make_interval_fn with f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe268>

# %%
observer(2.5)
# Out:
# args = [2.50000000000?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe0d0>
# y_py = 2.50000000000?
# args = [2.50000000000?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe0d0>
# y_py = 2.50000000000?
# 2.50000000000?

# %%
observer.roots()
# Out:
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# args = [0.01?, 1.?e1]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 1.?e1
# args = [0.02?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.03?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.1?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.1?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.1?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.1?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.1?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.1?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.1?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.1?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.2?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.2?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.2?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.2?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.2?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.2?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.2?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.2?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.2?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.2?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.3?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.3?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.3?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.3?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.3?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.3?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.3?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.3?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.3?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.3?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.4?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.4?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.4?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.4?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.4?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.4?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.4?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.4?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.4?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.4?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.5?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.5?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.5?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.5?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.5?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.5?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.5?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.5?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.5?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.5?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.6?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.6?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.6?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.6?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.6?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.6?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.6?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.6?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.6?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.6?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.7?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.7?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.7?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.7?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.7?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.7?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.7?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.7?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.7?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.7?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.8?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.8?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.8?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.8?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.8?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.8?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.8?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.8?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.8?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.8?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.9?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.9?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.9?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.9?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.9?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.9?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.9?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.9?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.9?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [0.9?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.0?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.0?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.0?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.0?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.0?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.0?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.0?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.0?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.0?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.0?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.1?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.1?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.1?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.1?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.1?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.1?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.1?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.1?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.1?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.1?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.2?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.2?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.2?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.2?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.2?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.2?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.2?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.2?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.2?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.2?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.3?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.3?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.3?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.3?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.3?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.3?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.3?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.3?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.3?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.3?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.4?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.4?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.4?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.4?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.4?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.4?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.4?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.4?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.4?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.4?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.5?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.5?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.5?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.5?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.5?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.5?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.5?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.5?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.5?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.5?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.6?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.6?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.6?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.6?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.6?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.6?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.6?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.6?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.6?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.6?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.7?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.7?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.7?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.7?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.7?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.7?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.7?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.7?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.7?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.7?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.8?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.8?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.8?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.8?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.8?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.8?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.8?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.8?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.8?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.8?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.9?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.9?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.9?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.9?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.9?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.9?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.9?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.9?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.9?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [1.9?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.0?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.0?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.0?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.0?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.0?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.0?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.0?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.0?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.0?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.0?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.1?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.1?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.1?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.1?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.1?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.1?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.1?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.1?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.1?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.1?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.2?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.2?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.2?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.2?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.2?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.2?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.2?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.2?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.2?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.2?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.3?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.3?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.3?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.3?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.3?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.3?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.3?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.3?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.3?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.3?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.4?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.4?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.4?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.4?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.4?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.4?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.4?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.4?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.4?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.4?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.5?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.5?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.5?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.5?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.5?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.5?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.5?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.5?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.5?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.5?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.6?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.6?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.6?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.6?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.6?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.6?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [2.6?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [2.6?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [2.6?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [2.6?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [2.7?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [2.7?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [2.7?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [2.7?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [2.7?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [2.7?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [2.7?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [2.7?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [2.7?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [2.7?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [2.8?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [2.8?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [2.8?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [2.8?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [2.8?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [2.8?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [2.8?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [2.8?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [2.8?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [2.8?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [2.9?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [2.9?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [2.9?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [2.9?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [2.9?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [2.9?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [2.9?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [2.9?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [2.9?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [2.9?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.0?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.0?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.0?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.0?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.0?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.0?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.0?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.0?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.0?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.0?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.1?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.1?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.1?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.1?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.1?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.1?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.1?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.1?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.1?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.1?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.2?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.2?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.2?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.2?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.2?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.2?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.2?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.2?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.2?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.2?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.3?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.3?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.3?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.3?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.3?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.3?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.3?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.3?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.3?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.3?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.4?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.4?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.4?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.4?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.4?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.4?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.4?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.4?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.4?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.4?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.5?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.5?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.5?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.5?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.5?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.5?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.5?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.5?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.5?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.5?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.6?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.6?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.6?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.6?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.6?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.6?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.6?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.6?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.6?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.6?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.7?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.7?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.7?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.7?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.7?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.7?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.7?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.7?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.7?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.7?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.8?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.8?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.8?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.8?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.8?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.8?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.8?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.8?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.8?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.8?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.9?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.9?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.9?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.9?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.9?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.9?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.9?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.9?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.9?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [3.9?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.0?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.0?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.0?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.0?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.0?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.0?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.0?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.0?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.0?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.0?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.1?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.1?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.1?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.1?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.1?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.1?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.1?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.1?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.1?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.1?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.2?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.2?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.2?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.2?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.2?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.2?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.2?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.2?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.2?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.2?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.3?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.3?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.3?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.3?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.3?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.3?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.3?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.3?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.3?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.3?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.4?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.4?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.4?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.4?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.4?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.4?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.4?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.4?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.4?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.4?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.5?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.5?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.5?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.5?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.5?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.5?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.5?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.5?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.5?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.5?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.6?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.6?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.6?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.6?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.6?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.6?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.6?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.6?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.6?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.6?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.7?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.7?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.7?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.7?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.7?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.7?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.7?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.7?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.7?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.7?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.8?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.8?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.8?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.8?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.8?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.8?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.8?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.8?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.8?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.8?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.9?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.9?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.9?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.9?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.9?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.9?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.9?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.9?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.9?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [4.9?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [5.0?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [5.0?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [5.0?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [5.0?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [5.0?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [5.0?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [5.0?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [5.0?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# args = [5.0?, 3.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 3.?
# roots = []
# []

# %%
observer = SageObserver(x, r)
# Out:
# SageObserver(x, <flowstar.reachability.Reach object at 0x563ccaf37a38>, symbolic_composition=False, tentative_unpreconditioning=False, mask=None)
# make_interval_fn with f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# make_interval_fn with f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc29990a048>

# %%
observer(2.5)
# Out:
# args = [2.50000000000?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# args = [2.50000000000?, 2.?]
# f = <sage.ext.interpreters.wrapper_el.Wrapper_el object at 0x7fc2998fe840>
# y_py = 2.?
# 2.?

# %%
observer.roots()
# Out:
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# roots = []
# []

# %%
from ulbc.logic import *

# %%
at = Atomic(sg.sin(t) > 0.5)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-19-d0d8eee157d0> in <module>()
# ----> 1 at = Atomic(sg.sin(t) > 0.5)
#
# /home/twright/Drive/Documents/PhD/Notebooks/ulbc/logic.py in __init__(self, p)
#     231     duration = 0
#     232
# --> 233     def __init__(self, p):
#     234         super(Atomic, self).__init__(p.parent())
#     235         self._p = p
#
# /home/twright/Drive/Documents/PhD/Notebooks/ulbc/logic.py in __init__(self, arg)
#      33     def __init__(self, arg):
#      34         if hasattr(arg, 'gens'):
# ---> 35             self._R = arg
#      36             self._vars = OrderedDict((str(x), x) for x in arg.gens())
#      37         else:
#
# /usr/lib64/python3.7/site-packages/sage/structure/parent_gens.pyx in sage.structure.parent_gens.ParentWithGens.gens (build/cythonized/sage/structure/parent_gens.c:2423)()
#     123        else:
#     124            v = []
# --> 125            n = self.ngens()
#     126            for i from 0 <= i < n:
#     127                v.append(self.gen(i))
#
# /usr/lib64/python3.7/site-packages/sage/structure/parent_gens.pyx in sage.structure.parent_gens.ParentWithGens.ngens (build/cythonized/sage/structure/parent_gens.c:2171)()
#     105     # Derived class *must* define ngens method.
#     106     def ngens(self):
# --> 107         check_old_coerce(self)
#     108         raise NotImplementedError("Number of generators not known.")
#     109
#
# /usr/lib64/python3.7/site-packages/sage/structure/parent_gens.pyx in sage.structure.parent_gens.check_old_coerce (build/cythonized/sage/structure/parent_gens.c:1909)()
#      81 cdef inline check_old_coerce(parent.Parent p):
#      82     if p._element_constructor is not None:
# ---> 83         raise RuntimeError("%s still using old coercion framework" % p)
#      84
#      85
#
# RuntimeError: Symbolic Ring still using old coercion framework
