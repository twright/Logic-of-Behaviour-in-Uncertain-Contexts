# %% [markdown]
# # STL monitoring over interval functions

# %%
from functools import partial, reduce

# %% [markdown]
# ## Interval newton

# %%
load('interval_utils.py')

# %% [markdown]
# ### Interval operations

# %%
interval([1,2,5]).str(style='brackets')
# Out:
# '[1.0000000000000000 .. 5.0000000000000000]'

# %%
RIF(-1,2).intersection(RIF(1,3)).str(style='brackets')
# Out:
# '[1.0000000000000000 .. 2.0000000000000000]'

# %%
isub(RIF(0,2), RIF(-1,1)).str(style='brackets')
# Out:
# '[1.0000000000000000 .. 2.0000000000000000]'

# %%
isub(RIF(0,2), RIF(0.5,1.5)).str(style='brackets')
# Out:
# '[0.00000000000000000 .. 2.0000000000000000]'

# %%
isub(RIF(0,2), RIF(1,2)).str(style='brackets')
# Out:
# '[0.00000000000000000 .. 1.0000000000000000]'

# %%
extdiv(RIF(3,4), RIF(1,2), RIF(1,5)).str(style='brackets')
# Out:
# '[1.5000000000000000 .. 4.0000000000000000]'

# %%
extdiv(RIF(3,4), RIF(0,2), RIF(1,5)).str(style='brackets')
# Out:
# '[1.0000000000000000 .. 1.5000000000000000]'

# %%
RIF(1,2).center()
# Out:
# 1.50000000000000

# %%
def newton(f, fprime, x0, n):
    x = RIF(x0)
    for i in range(n):
        xc = RIF(x.center())
#         x = (xc - f(xc)/fprime(x)).intersection(x)
        x = xc + extdiv(-f(xc), fprime(x), x - xc)
        print "f({}) = {}".format(i, x.str(style='brackets')
                                  if x.diameter() > 0.1 else x)
    return x

# %% [markdown]
# ### Example: finding $\sqrt{2}$

# %%
f      = lambda x: x**2 - 2
fprime = lambda x: 2*x

# %%
sqrt(2.0)
# Out:
# 1.41421356237310

# %%
newton(f, fprime, RIF(1.4,1.45), 15)
# Out:
# f(0) = 1.415?
# f(1) = 1.41421356?
# f(2) = 1.414213562373095?
# f(3) = 1.414213562373095?
# f(4) = 1.414213562373095?
# f(5) = 1.414213562373095?
# f(6) = 1.414213562373095?
# f(7) = 1.414213562373095?
# f(8) = 1.414213562373095?
# f(9) = 1.414213562373095?
# f(10) = 1.414213562373095?
# f(11) = 1.414213562373095?
# f(12) = 1.414213562373095?
# f(13) = 1.414213562373095?
# f(14) = 1.414213562373095?
# 1.414213562373095?

# %% [markdown]
# ### Example: enclosing 0 crossings

# %%
def lower(f, I, x):
    return float(RIF(f(x + I)).endpoints()[0])
def upper(f, I, x):
    return float(RIF(f(x + I)).endpoints()[1])

# %%
I = RIF(-0.3,0.3)

# %%
g = lambda x: sin(x+I)
gprime = lambda x: cos(x+I)

# %%
x0 = newton(g, gprime, RIF(-pi/4,pi/4),15)
# Out:
# f(0) = [-0.63340159272047103 .. 0.63340159272047103]
# f(1) = [-0.49658603143445352 .. 0.49658603143445352]
# f(2) = [-0.42268397111483092 .. 0.42268397111483092]
# f(3) = [-0.39400947238022361 .. 0.39400947238022361]
# f(4) = [-0.38444771270454759 .. 0.38444771270454759]
# f(5) = [-0.38143040832528236 .. 0.38143040832528236]
# f(6) = [-0.38049526589605954 .. 0.38049526589605954]
# f(7) = [-0.38020707230770845 .. 0.38020707230770845]
# f(8) = [-0.38011841133911179 .. 0.38011841133911179]
# f(9) = [-0.38009115000821859 .. 0.38009115000821859]
# f(10) = [-0.38008276912492040 .. 0.38008276912492040]
# f(11) = [-0.38008019274181105 .. 0.38008019274181105]
# f(12) = [-0.38007940074341390 .. 0.38007940074341390]
# f(13) = [-0.38007915727867303 .. 0.38007915727867303]
# f(14) = [-0.38007908243635936 .. 0.38007908243635936]

# %%
x1 = newton(g, gprime, RIF(3*pi/4,5*pi/4),15)
# Out:
# f(0) = [2.5081910608693198 .. 3.7749942463102660]
# f(1) = [2.6450066221553374 .. 3.6381786850242493]
# f(2) = [2.7189086824749604 .. 3.5642766247046259]
# f(3) = [2.7475831812095683 .. 3.5356021259700184]
# f(4) = [2.7571449408852446 .. 3.5260403662943421]
# f(5) = [2.7601622452645098 .. 3.5230230619150765]
# f(6) = [2.7610973876937330 .. 3.5220879194858537]
# f(7) = [2.7613855812820840 .. 3.5217997258975027]
# f(8) = [2.7614742422506806 .. 3.5217110649289061]
# f(9) = [2.7615015035815737 .. 3.5216838035980130]
# f(10) = [2.7615098844648717 .. 3.5216754227147145]
# f(11) = [2.7615124608479812 .. 3.5216728463316054]
# f(12) = [2.7615132528463783 .. 3.5216720543332083]
# f(13) = [2.7615134963111191 .. 3.5216718108684671]
# f(14) = [2.7615135711534328 .. 3.5216717360261534]

# %%
x2 = newton(g, gprime, RIF(7*pi/4,9*pi/4),15)
# Out:
# f(0) = [5.6497837144591107 .. 6.9165868999000609]
# f(1) = [5.7865992757451278 .. 6.7797713386140455]
# f(2) = [5.8605013360647513 .. 6.7058692782944212]
# f(3) = [5.8891758347993601 .. 6.6771947795598133]
# f(4) = [5.8987375944750359 .. 6.6676330198841365]
# f(5) = [5.9017548988543016 .. 6.6646157155048709]
# f(6) = [5.9026900412835248 .. 6.6636805730756486]
# f(7) = [5.9029782348718757 .. 6.6633923794872976]
# f(8) = [5.9030668958404728 .. 6.6633037185187006]
# f(9) = [5.9030941571713659 .. 6.6632764571878074]
# f(10) = [5.9031025380546635 .. 6.6632680763045090]
# f(11) = [5.9031051144377730 .. 6.6632654999213994]
# f(12) = [5.9031059064361706 .. 6.6632647079230028]
# f(13) = [5.9031061499009114 .. 6.6632644644582620]
# f(14) = [5.9031062247432251 .. 6.6632643896159483]

# %%
x3 = newton(g, gprime, RIF(11*pi/4,13*pi/4),15)
# Out:
# f(0) = [8.7913763680489029 .. 10.058179553489858]
# f(1) = [8.9281919293349201 .. 9.9213639922038404]
# f(2) = 10.?
# f(3) = 10.?
# f(4) = 10.?
# f(5) = 10.?
# f(6) = 10.?
# f(7) = 10.?
# f(8) = 10.?
# f(9) = 10.?
# f(10) = 10.?
# f(11) = 10.?
# f(12) = 10.?
# f(13) = 10.?
# f(14) = 10.?

# %%
p = plot([partial(lower, sin, I), sin, partial(upper, sin, I)], 
         xmin=0, xmax=3*pi,
         color=['blue', 'blue', 'blue', 'green', 'green', 'green'],
         linestyle=['--', '-', '--', '--', '-', '--'],
         ticks=(pi/2,0.5), tick_formatter=pi)
p += point((x0.endpoints()[1], 0), marker='X', size=100)
p += point((x1.endpoints()[0], 0), marker='X', size=100)
p += point((x1.endpoints()[1], 0), marker='X', size=100)
p += point((x2.endpoints()[0], 0), marker='X', size=100)
p += point((x2.endpoints()[1], 0), marker='X', size=100)
p += point((x3.endpoints()[0], 0), marker='X', size=100)
p
# Out:
# Graphics object consisting of 9 graphics primitives

# %% [markdown]
# ## Example: time shifted sin function

# %%
def shift_plot(t0, I=RIF(-0.3,0.3)):
    t0 = RIF(t0)
    I = RIF(-0.3,0.3)
    def shift_sin_c(t):
        return sin((t + t0).center())
        
    shift_sin = lambda t: sin(t + t0)
    
    p = plot([partial(lower, shift_sin, I),
              (lambda t: sin(t + t0.lower())),
              (lambda t: sin(t + t0.upper())),
              partial(upper, shift_sin, I)], 
         xmin=0, xmax=3*pi,
         color=['grey', 'blue', 'orange', 'grey'],
         linestyle=['--', '-', '-', '--'],
         ticks=(pi/2,0.5), tick_formatter=pi)
    return p

# %%
shift_plot(RIF(pi/4))
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
shift_plot(RIF(0,pi/5))
# Out:
# Graphics object consisting of 4 graphics primitives

# %% [markdown]
# ## Three-valued signals

# %%
load('interval_signals.py')

# %% [markdown]
# ### Example: merging overlapping

# %%
Signal(RIF(0,pi), [(RIF(0,3*pi/4), True), (RIF(pi/4,pi), True)])
# Out:
# Signal([0.00000000000000000 .. 3.1415926535897936], [([0.00000000000000000 .. 3.1415926535897936], True)])

# %%
Signal(RIF(0,pi), [(RIF(0,pi/2), True), (RIF(pi/2), True)])
# Out:
# Signal([0.00000000000000000 .. 3.1415926535897936], [([0.00000000000000000 .. 1.5707963267948968], True)])

# %%
Signal(RIF(0,pi), [(RIF(0,3*pi/4), False), (RIF(pi/4,pi), False)])
# Out:
# Signal([0.00000000000000000 .. 3.1415926535897936], [([0.00000000000000000 .. 3.1415926535897936], False)])

# %%
try:
    Signal(RIF(0,pi), [(RIF(0,3*pi/4), True), (RIF(pi/4,pi), False)])
except Exception as e:
    print e
# Out:
# Inconsitient intervals [0.00000000000000000 .. 2.3561944901923453] (True) and [0.78539816339744827 .. 3.1415926535897936] (False) in signal!

# %% [markdown]
# ### Example: sin signal

# %%
sig = Signal(RIF(0,3*pi),
             [(RIF(x0.endpoints()[1], x1.endpoints()[0]),True),
              (RIF(x1.endpoints()[1], x2.endpoints()[0]),False),
              (RIF(x2.endpoints()[1], x3.endpoints()[0]),True)])
sig
# Out:
# Signal([0.00000000000000000 .. 9.4247779607693812], [([0.38007908243635935 .. 2.7615135711534329], True), ([3.5216717360261533 .. 5.9031062247432252], False), ([6.6632643896159482 .. 9.0446988783330174], True)])

# %%
sig.plot(ticks=(pi/2,0.5), tick_formatter=pi)
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# #### Negation:

# %%
~sig
# Out:
# Signal([0.00000000000000000 .. 9.4247779607693812], [([0.38007908243635935 .. 2.7615135711534329], False), ([3.5216717360261533 .. 5.9031062247432252], True), ([6.6632643896159482 .. 9.0446988783330174], False)])

# %%
(~sig).plot(ticks=(pi/2,0.5), tick_formatter=pi)
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# #### Backshifting:

# %%
sig.F(pi/2).plot()
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
shift_plot(RIF(pi/2)) + sig.F(pi/2).plot(ticks=(pi/2,0.5), tick_formatter=pi)
# Out:
# Graphics object consisting of 6 graphics primitives

# %%
shift_plot(RIF(0,pi/2)) + sig.F(RIF(0,pi/2)).plot(ticks=(pi/2,0.5), tick_formatter=pi)
# Out:
# Graphics object consisting of 6 graphics primitives

# %%
shift_plot(RIF(0,pi/2)) + sig.G(RIF(0,pi/2)).plot(ticks=(pi/2,0.5), tick_formatter=pi)
# Out:
# Graphics object consisting of 6 graphics primitives

# %%
shift_plot(RIF(0,pi/2)) + (~(~sig).F(RIF(0,pi/2))).plot(ticks=(pi/2,0.5), tick_formatter=pi)
# Out:
# Graphics object consisting of 6 graphics primitives

# %% [markdown]
# #### Intersection:

# %%
(sig & sig.F((7/4)*pi)).plot(ticks=(pi/2,0.5), tick_formatter=pi)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
shift_plot(0) + shift_plot((7/4)*pi) + (sig & sig.F((7/4)*pi)).plot(ticks=(pi/2,0.5), tick_formatter=pi)
# Out:
# Graphics object consisting of 10 graphics primitives

# %% [markdown]
# #### Union:

# %%
shift_plot((7/4)*pi) + (~sig.F((7/4)*pi)).plot(ticks=(pi/2,0.5), tick_formatter=pi)
# Out:
# Graphics object consisting of 6 graphics primitives

# %% [markdown]
# #### Truth value:

# %%
sig.plot(ticks=(pi/2,0.5), tick_formatter=pi)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
bool(sig)
# Out:
# False

# %%
sig(pi/2)
# Out:
# True

# %%
sig(pi)

# %%
sig(3/2*pi)
# Out:
# False

# %% [markdown]
# #### Until

# %% [markdown]
# signal for $-\sin(x)$

# %%
sig2 = ~sig
sig2
# Out:
# Signal([0.00000000000000000 .. 9.4247779607693812], [([0.38007908243635935 .. 2.7615135711534329], False), ([3.5216717360261533 .. 5.9031062247432252], True), ([6.6632643896159482 .. 9.0446988783330174], False)])

# %%
sig.plot(ticks=(pi/2,0.5), tick_formatter=pi)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
sig2.plot(ticks=(pi/2,0.5), tick_formatter=pi)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
sig.U(RIF([0,pi/3]), sig2).plot(ticks=(pi/2,0.5), tick_formatter=pi)
# Out:
# /usr/lib64/python2.7/site-packages/matplotlib/contour.py:1230: UserWarning: No contour levels were found within the data range.
#   warnings.warn("No contour levels were found"
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# Check $\mathrel{{\mathbf F}_{[a,b]}} \varphi \equiv \mathrm{true} \mathrel{{\mathbf U}_{[a,b]}} \varphi$:

# %%
sig.F(RIF(pi/4,pi/2)).to_domain(RIF(0,11*pi/4)).plot(ticks=(pi/2,0.5), tick_formatter=pi)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
true_signal(RIF(0,3*pi)).U(RIF(pi/4,pi/2), sig).plot(ticks=(pi/2,0.5), tick_formatter=pi)
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# ## Taylor models

# %%
load('taylor_models.py')

# %%
R.<x> = QQ[]

# %% [markdown]
# ### Example: Sine Taylor model

# %%
sinTM = TM(x - (1/factorial(3))*x**3 + (1/factorial(5))*x**5 - (1/factorial(7))*x**7,
           (1/factorial(9))*sin(RIF(-pi,pi))*RIF(-pi,pi)**9)
str(sinTM)
#type(sinTM(1))
#sinTM(1).str(style='brackets')
# Out:
# '-1/5040*x^7 + 1/120*x^5 - 1/6*x^3 + x + [-0.082145886611128358 .. 0.082145886611128358]'

# %%
plot(sin, xmin=-pi, xmax=pi, color='green') + sinTM.plot(-pi, pi, ticks=(pi/4,0.5), tick_formatter=pi)
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
sinTM.f(x-RIF(0,pi/2))
# Out:
# -0.0001984126984126985?*x^7 + 0.01?*x^6 + 0.00?*x^5 + 0.0?*x^4 + 0.?*x^3 + 0.?*x^2 + 0.?e1*x - 1.?

# %% [markdown]
# #### Taylor model multiplication:

# %%
sinTM.mul(sinTM, RIF(-pi,pi), 15).plot(-pi, pi) + plot(sin(x)*sin(x), (x, -pi, pi), color='green')
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
sinTM.mul(sinTM, RIF(-pi,pi), 13).plot(-pi, pi) + plot(sin(x)*sin(x), (x, -pi, pi), color='green')
# Out:
# Graphics object consisting of 4 graphics primitives

# %% [markdown]
# #### Root detection:

# %%
a, b = newton(sinTM, sinTM.derivative(), RIF(-pi/4,pi/4), 10).endpoints()
a,b
# Out:
# f(0) = [-0.13846788869053892 .. 0.13846788869053892]
# f(1) = [-0.090443926172562750 .. 0.090443926172562750]
# f(2) = [-0.089898630057776500 .. 0.089898630057776500]
# f(3) = [-0.089893786260804979 .. 0.089893786260804979]
# f(4) = [-0.089893743367904914 .. 0.089893743367904914]
# f(5) = [-0.089893742988089276 .. 0.089893742988089276]
# f(6) = [-0.089893742984726008 .. 0.089893742984726008]
# f(7) = [-0.089893742984696227 .. 0.089893742984696227]
# f(8) = [-0.089893742984695963 .. 0.089893742984695963]
# f(9) = [-0.089893742984695963 .. 0.089893742984695963]
# (-0.0898937429846960, 0.0898937429846960)

# %%
p = sinTM.plot(-pi, pi, ticks=(pi/4,0.5), tick_formatter=pi)
p += point((a, 0), marker='X', size=100)
p += point((b, 0), marker='X', size=100)
p
# Out:
# Graphics object consisting of 5 graphics primitives

# %% [markdown]
# ## Piecewise Taylor model

# %% [markdown]
# ### Example: piecewise sine

# %%
seq = TMSeq([(RIF(0,1), sinTM), (RIF(1,2), sinTM.mul(TM(x, RIF(0)), RIF(1,2)))])
seq
# Out:
# TMSeq([(1.?, TM(-1/5040*x^7 + 1/120*x^5 - 1/6*x^3 + x, 0.0?)), (2.?, TM(-1/5040*x^8 + 1/120*x^6 - 1/6*x^4 + x^2, 0.?))])

# %%
seq.plot()
# Out:
# Graphics object consisting of 6 graphics primitives

# %%
seq2 = seq.map(lambda x: x - 0.8)
plt = seq2.plot()
plt
# Out:
# Graphics object consisting of 6 graphics primitives

# %% [markdown]
# #### Root detection:

# %%
a, b = newton(seq2, seq2.map(lambda x: x.derivative()), RIF(0.5,1.5), 10).endpoints()
a,b
# Out:
# f(0) = [0.51916639450203383 .. 1.2870221024425228]
# f(1) = [0.74589867691294509 .. 1.1291219405363536]
# f(2) = [0.74589867691294509 .. 1.1102710529171778]
# f(3) = [0.74589867691294509 .. 1.1102710529171778]
# f(4) = [0.74589867691294509 .. 1.1102710529171778]
# f(5) = [0.74589867691294509 .. 1.1102710529171778]
# f(6) = [0.74589867691294509 .. 1.1102710529171778]
# f(7) = [0.74589867691294509 .. 1.1102710529171778]
# f(8) = [0.74589867691294509 .. 1.1102710529171778]
# f(9) = [0.74589867691294509 .. 1.1102710529171778]
# (0.745898676912945, 1.11027105291718)

# %%
plt += point((a, 0), marker='X', size=100)
plt += point((b, 0), marker='X', size=100)
plt
# Out:
# Graphics object consisting of 8 graphics primitives

# %% [markdown]
# ## Signal generation

# %%
load('interval_root_isolation.py')

# %%
plot(sin(x) + cos(1.6*x), (x,0,40))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
g(x) = sin(x) + cos(1.6*x)
g
# Out:
# x |--> cos(1.60000000000000*x) + sin(x)

# %%
h(x) = sin(x+RIF(0,0.2)) + cos(1.6*(x+RIF(0,0.2)))
h
# Out:
# x |--> cos(1.60000000000000*x + 1.?) + sin(x + 1.?)

# %%
plot([(lambda x: RIF(h(x)).lower()), h, (lambda x: RIF(h(x)).upper())], 
         xmin=0, xmax=40,
         color=['blue', 'blue', 'blue', 'green', 'green', 'green'],
         linestyle=['--', '-', '--'])
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
g.derivative()
# Out:
# x |--> cos(x) - 1.60000000000000*sin(1.60000000000000*x)

# %%
int_dist(RIF(1,2), RIF(3 + 1/3,4))
# Out:
# 2.33333333333334

# %%
ta = search_zero(g, g.derivative(), RIF(0,40))
ta.str(style='brackets')
# Out:
# t = [0.00000000000000000 .. 40.000000000000000]
# b = 0.?e1
# t = [0.38461538461538463 .. 40.000000000000000]
# b = 0.?e1
# t = [0.84298235669719434 .. 40.000000000000000]
# b = 0.?e1
# t = [1.2148421071808785 .. 40.000000000000000]
# b = 0.?e1
# t = [1.4352071807962092 .. 40.000000000000000]
# b = 0.?e1
# t = [1.5610863921072322 .. 40.000000000000000]
# b = 0.?e1
# t = [1.6380728918527696 .. 40.000000000000000]
# b = 0.?e1
# t = [1.6881708565255457 .. 40.000000000000000]
# b = 0.?e1
# t = [1.7222436090318271 .. 40.000000000000000]
# b = 0.?e1
# t = [1.7461407002099318 .. 40.000000000000000]
# b = 0.?e1
# t = [1.7632678705983457 .. 40.000000000000000]
# b = 0.?e1
# t = [1.7757346511305671 .. 40.000000000000000]
# b = 0.?e1
# t = [1.7849117381787857 .. 40.000000000000000]
# b = 0.?e1
# t = [1.7917231520698615 .. 40.000000000000000]
# b = 0.?e1
# t = [1.7968096695042874 .. 40.000000000000000]
# b = 0.?e1
# t = [1.8006254079860171 .. 40.000000000000000]
# b = 0.?e1
# t = [1.8034976116494791 .. 40.000000000000000]
# b = 0.?e1
# t = [1.8056651316725198 .. 40.000000000000000]
# b = 0.?e1
# t = [1.8073040172016612 .. 40.000000000000000]
# b = 0.?e1
# t = [1.8085450031676559 .. 40.000000000000000]
# b = 0.?e1
# t = [1.8094857308071434 .. 40.000000000000000]
# b = 0.?e1
# t = [1.8101994439300830 .. 40.000000000000000]
# b = 0.?e1
# t = [1.8107412683222143 .. 40.000000000000000]
# b = 0.?e1
# t = [1.8111527989814417 .. 40.000000000000000]
# b = 0.?e1
# t = [1.8114654820531683 .. 40.000000000000000]
# b = 0.?e1
# t = [1.8117031261185707 .. 40.000000000000000]
# b = 0.?e1
# t = [1.8118837774190788 .. 40.000000000000000]
# b = 0.?e1
# t = [1.8120211261882455 .. 40.000000000000000]
# b = 0.?e1
# t = [1.8121255648585095 .. 40.000000000000000]
# b = 0.?e1
# t = [1.8122049863619658 .. 40.000000000000000]
# b = 0.?e1
# t = [1.8122653875457144 .. 40.000000000000000]
# b = 0.?e1
# t = [1.8123113259651189 .. 40.000000000000000]
# b = 0.?e1
# t = [1.8123462660801934 .. 40.000000000000000]
# b = 0.?e1
# t = [1.8123728418628672 .. 40.000000000000000]
# b = 0.?e1
# t = [1.8123930561311982 .. 40.000000000000000]
# b = 0.?e1
# t = [1.8124084319329332 .. 40.000000000000000]
# b = 0.?e1
# t = [1.8124201275578775 .. 40.000000000000000]
# b = 0.?e1
# found lower bound!
# t = [1.8124290239434561 .. 1.8306533141828907]
# b = -0.6?
# t = [1.8124290239434561 .. 1.8133542337892970]
# b = -0.62?
# t = [1.8124550174126168 .. 1.8124596325768081]
# b = -0.62222?
# found upper bound!
# '[1.8124573001245383 .. 1.8124573001843374]'

# %%
tb = search_zero(g, g.derivative(), RIF(ta.upper('RNDU')+0.0001,40), 1e-9, 0.001, 0.0000001)
tb.str(style='brackets')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-74-0d1ba0d22988> in <module>()
# ----> 1 tb = search_zero(g, g.derivative(), RIF(ta.upper('RNDU')+RealNumber('0.0001'),Integer(40)), RealNumber('1e-9'), RealNumber('0.001'), RealNumber('0.0000001'))
#       2 tb.str(style='brackets')
#
# NameError: name 'ta' is not defined

# %%
search_zero(g, g.derivative(), RIF(0,1))
# Out:
# t = [0.00000000000000000 .. 1.0000000000000000]
# b = 0.?e1
# t = [0.94366535431525422 .. 1.0000000000000000]
# b = -1.1?
# stopping since presumed converged
# t = [0.94366535431525422 .. 1.0000000000000000], fprime(t) = [-1.0596976941318606 .. -1.0102066920815750]

# %%
g(23.543737610469488+0.3)
# Out:
# -0.0604894014118164

# %%
zs = list(isolate_roots(g, g.derivative(), RIF(0,23), 0.001))
zs
# Out:
# t = [0.00000000000000000 .. 23.000000000000000]
# b = 0.?e1
# t = [0.38461538461538463 .. 23.000000000000000]
# b = 0.?e1
# t = [0.84298235669719434 .. 23.000000000000000]
# b = 0.?e1
# t = [1.2148421071808785 .. 23.000000000000000]
# b = 0.?e1
# t = [1.4352071807962092 .. 23.000000000000000]
# b = 0.?e1
# t = [1.5610863921072322 .. 23.000000000000000]
# b = 0.?e1
# t = [1.6380728918527696 .. 23.000000000000000]
# b = 0.?e1
# t = [1.6881708565255457 .. 23.000000000000000]
# b = 0.?e1
# t = [1.7222436090318271 .. 23.000000000000000]
# b = 0.?e1
# t = [1.7461407002099318 .. 23.000000000000000]
# b = 0.?e1
# t = [1.7632678705983457 .. 23.000000000000000]
# b = 0.?e1
# t = [1.7757346511305671 .. 23.000000000000000]
# b = 0.?e1
# t = [1.7849117381787857 .. 23.000000000000000]
# b = 0.?e1
# t = [1.7917231520698615 .. 23.000000000000000]
# b = 0.?e1
# t = [1.7968096695042874 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8006254079860171 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8034976116494791 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8056651316725198 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8073040172016612 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8085450031676559 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8094857308071434 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8101994439300830 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8107412683222143 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8111527989814417 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8114654820531683 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8117031261185707 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8118837774190788 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8120211261882455 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8121255648585095 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8122049863619658 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8122653875457144 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8123113259651189 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8123462660801934 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8123728418628672 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8123930561311982 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8124084319329332 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8124201275578775 .. 23.000000000000000]
# b = 0.?e1
# found lower bound!
# t = [1.8124290239434561 .. 1.8306533141828907]
# b = -0.6?
# t = [1.8124290239434561 .. 1.8133542337892970]
# b = -0.62?
# t = [1.8124550174126168 .. 1.8124596325768081]
# b = -0.62222?
# found upper bound!
# t = [1.8134573001843374 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8136963244966748 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8139923951117313 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8143590806882718 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8148131525232706 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8153753272500334 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8160711746716691 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8169322236029865 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8179973029960623 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8193141593102228 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8209413930128508 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8229507555711239 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8254298406650069 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8284851855896211 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8322457649858723 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8368668007021076 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8425337172658138 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8494659274644627 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8579199199606859 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8681908247342275 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8806112451364820 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8955456839832418 .. 23.000000000000000]
# b = 0.?e1
# t = [1.9133784219151328 .. 23.000000000000000]
# b = 0.?e1
# t = [1.9344923843023260 .. 23.000000000000000]
# b = 0.?e1
# t = [1.9592366460014407 .. 23.000000000000000]
# b = 0.?e1
# t = [1.9878812142469639 .. 23.000000000000000]
# b = 0.?e1
# t = [2.0205601356111602 .. 23.000000000000000]
# b = 0.?e1
# t = [2.0572081787647515 .. 23.000000000000000]
# b = 0.?e1
# t = [2.0975020739315755 .. 23.000000000000000]
# b = 0.?e1
# t = [2.1408229266937883 .. 23.000000000000000]
# b = 0.?e1
# t = [2.1862586956786982 .. 23.000000000000000]
# b = 0.?e1
# t = [2.2326605933441370 .. 23.000000000000000]
# b = 0.?e1
# t = [2.2787532000799761 .. 23.000000000000000]
# b = 0.?e1
# t = [2.3232787790036275 .. 23.000000000000000]
# b = 0.?e1
# t = [2.3651412040573536 .. 23.000000000000000]
# b = 0.?e1
# t = [2.4035135564432157 .. 23.000000000000000]
# b = 0.?e1
# t = [2.4378875055130340 .. 23.000000000000000]
# b = 0.?e1
# t = [2.4680639021458934 .. 23.000000000000000]
# b = 0.?e1
# t = [2.4941010321158980 .. 23.000000000000000]
# b = 0.?e1
# t = [2.5162432406971539 .. 23.000000000000000]
# b = 0.?e1
# t = [2.5348493257955202 .. 23.000000000000000]
# b = 0.?e1
# t = [2.5503324205840693 .. 23.000000000000000]
# b = 0.?e1
# t = [2.5631157187947382 .. 23.000000000000000]
# b = 0.?e1
# t = [2.5736034985931199 .. 23.000000000000000]
# b = 0.?e1
# t = [2.5821645728793498 .. 23.000000000000000]
# b = 0.?e1
# t = [2.5891247403935131 .. 23.000000000000000]
# b = 0.?e1
# t = [2.5947651778062081 .. 23.000000000000000]
# b = 0.?e1
# t = [2.5993244034508831 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6030021402383116 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6059639795806424 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6083461729821189 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6102601705962467 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6117967167371789 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6130294303478165 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6140178673560039 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6148100990071010 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6154448576470259 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6159533070319214 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6163604932034383 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6166865275061095 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6169475473778596 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6171564942426717 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6173237417906252 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6174576024474416 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6175647350309674 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6176504724787572 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6177190850668097 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6177739916566222 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6178179291296665 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6178530882198245 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6178812223658174 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6179037349158122 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6179217489722468 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6179361633217204 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6179476972151616 .. 23.000000000000000]
# b = 0.?e1
# found lower bound!
# t = [2.6179569262165074 .. 2.6442364954786722]
# b = 0.6?
# t = [2.6179569262165074 .. 2.6190613322995904]
# b = 0.520?
# t = [2.6179918289202475 .. 2.6179958592402728]
# b = 0.51962?
# found upper bound!
# t = [2.6189938780021240 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6191938798485923 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6194339183428252 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6197220238545200 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6200678443754052 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6204829744052959 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6209813520301659 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6215797389042654 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6222983012653524 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6231613144218819 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6241980186241296 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6254436612329610 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6269407691264650 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6287407070143635 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6309055926951985 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6335106605778588 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6366471917751019 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6404261652202256 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6449828329447928 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6504824885094704 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6571277868114258 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6651680941798758 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6749115097033784 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6867404126775547 .. 23.000000000000000]
# b = 0.?e1
# t = [2.7011316642637215 .. 23.000000000000000]
# b = 0.?e1
# t = [2.7186829173340729 .. 23.000000000000000]
# b = 0.?e1
# t = [2.7401468199584657 .. 23.000000000000000]
# b = 0.?e1
# t = [2.7664750845290759 .. 23.000000000000000]
# b = 0.?e1
# t = [2.7988740383446417 .. 23.000000000000000]
# b = 0.?e1
# t = [2.8388714100169472 .. 23.000000000000000]
# b = 0.?e1
# t = [2.8883885443736287 .. 23.000000000000000]
# b = 0.?e1
# t = [2.9497982689020574 .. 23.000000000000000]
# b = 0.?e1
# t = [3.0259170645495445 .. 23.000000000000000]
# b = 0.?e1
# t = [3.1198162863098679 .. 23.000000000000000]
# b = 0.?e1
# t = [3.2342293263931733 .. 23.000000000000000]
# b = 0.?e1
# t = [3.3702190861201759 .. 23.000000000000000]
# b = 0.?e1
# t = [3.5248818627488733 .. 23.000000000000000]
# b = 0.?e1
# t = [3.6887676447183435 .. 23.000000000000000]
# b = 0.?e1
# t = [3.8456745962099319 .. 23.000000000000000]
# b = 0.?e1
# t = [3.9780645191153287 .. 23.000000000000000]
# b = 0.?e1
# t = [4.0759027331310342 .. 23.000000000000000]
# b = 0.?e1
# t = [4.1403493208635699 .. 23.000000000000000]
# b = 0.?e1
# t = [4.1793866813656510 .. 23.000000000000000]
# b = 0.?e1
# t = [4.2018005346880036 .. 23.000000000000000]
# b = 0.?e1
# t = [4.2142713841156105 .. 23.000000000000000]
# b = 0.?e1
# t = [4.2210886265157974 .. 23.000000000000000]
# b = 0.?e1
# t = [4.2247793913154749 .. 23.000000000000000]
# b = 0.?e1
# t = [4.2267670627011302 .. 23.000000000000000]
# b = 0.?e1
# t = [4.2278345054813328 .. 23.000000000000000]
# b = 0.?e1
# t = [4.2284068860750068 .. 23.000000000000000]
# b = 0.?e1
# t = [4.2287135561565367 .. 23.000000000000000]
# b = 0.?e1
# t = [4.2288777921547655 .. 23.000000000000000]
# b = 0.?e1
# t = [4.2289657275618806 .. 23.000000000000000]
# b = 0.?e1
# t = [4.2290128041354044 .. 23.000000000000000]
# b = 0.?e1
# t = [4.2290380050795004 .. 23.000000000000000]
# b = 0.?e1
# t = [4.2290514951182931 .. 23.000000000000000]
# b = 0.?e1
# found lower bound!
# t = [4.2290587161831743 .. 4.2714493033450057]
# b = -2.?
# t = [4.2290587161831743 .. 4.2312063092187833]
# b = -1.21?
# t = [4.2290610223923081 .. 4.2290729879833995]
# b = -1.2083?
# found upper bound!
# t = [4.2300670337510437 .. 23.000000000000000]
# b = 0.?e1
# t = [4.2305320224417259 .. 23.000000000000000]
# b = 0.?e1
# t = [4.2312134062966864 .. 23.000000000000000]
# b = 0.?e1
# t = [4.2322120976516819 .. 23.000000000000000]
# b = 0.?e1
# t = [4.2336763045543692 .. 23.000000000000000]
# b = 0.?e1
# t = [4.2358239681893792 .. 23.000000000000000]
# b = 0.?e1
# t = [4.2389761531895588 .. 23.000000000000000]
# b = 0.?e1
# t = [4.2436070852252738 .. 23.000000000000000]
# b = 0.?e1
# t = [4.2504198730352475 .. 23.000000000000000]
# b = 0.?e1
# t = [4.2604626534378029 .. 23.000000000000000]
# b = 0.?e1
# t = [4.2753099856771923 .. 23.000000000000000]
# b = 0.?e1
# t = [4.2973528290057920 .. 23.000000000000000]
# b = 0.?e1
# t = [4.3302754460227657 .. 23.000000000000000]
# b = 0.?e1
# t = [4.3798648375228035 .. 23.000000000000000]
# b = 0.?e1
# t = [4.4554247393416002 .. 23.000000000000000]
# b = 0.?e1
# t = [4.5722726089777578 .. 23.000000000000000]
# b = 0.?e1
# t = [4.7559201381159104 .. 23.000000000000000]
# b = 0.?e1
# t = [5.0470633342372011 .. 23.000000000000000]
# b = 0.?e1
# t = [5.4947689678103746 .. 23.000000000000000]
# b = 0.?e1
# t = [6.0776177521744312 .. 23.000000000000000]
# b = 0.?e1
# t = [6.5236305780327299 .. 23.000000000000000]
# b = 0.?e1
# t = [6.6356138295825211 .. 23.000000000000000]
# b = 0.?e1
# t = [6.6450117563217112 .. 23.000000000000000]
# b = 0.?e1
# t = [6.6456335051671491 .. 23.000000000000000]
# b = 0.?e1
# t = [6.6456739556800084 .. 23.000000000000000]
# b = 0.?e1
# found lower bound!
# t = [6.6456765845046072 .. 6.7122333503496528]
# b = 2.5?
# t = [6.6456765845046072 .. 6.6466675780850118]
# b = 2.431?
# t = [6.6456765845046072 .. 6.6456770215836621]
# b = 2.431042?
# found upper bound!
# t = [6.6466767672092021 .. 23.000000000000000]
# b = 0.?e1
# t = [6.6476118895279059 .. 23.000000000000000]
# b = 0.?e1
# t = [6.6494216564802171 .. 23.000000000000000]
# b = 0.?e1
# t = [6.6529246646426596 .. 23.000000000000000]
# b = 0.?e1
# t = [6.6597070385201408 .. 23.000000000000000]
# b = 0.?e1
# t = [6.6728456663423543 .. 23.000000000000000]
# b = 0.?e1
# t = [6.6983214115443763 .. 23.000000000000000]
# b = 0.?e1
# t = [6.7477950482382000 .. 23.000000000000000]
# b = 0.?e1
# t = [6.8440583513917108 .. 23.000000000000000]
# b = 0.?e1
# t = [7.0313122087980008 .. 23.000000000000000]
# b = 0.?e1
# t = [7.3897941390000880 .. 23.000000000000000]
# b = 0.?e1
# t = [8.0170367980822785 .. 23.000000000000000]
# b = 0.?e1
# t = [8.7681510962948845 .. 23.000000000000000]
# b = 0.?e1
# t = [9.0444446522178267 .. 23.000000000000000]
# b = 0.?e1
# t = [9.0611591970510705 .. 23.000000000000000]
# b = 0.?e1
# t = [9.0622133790638539 .. 23.000000000000000]
# b = 0.?e1
# t = [9.0622817495872229 .. 23.000000000000000]
# b = 0.?e1
# found lower bound!
# t = [9.0622861919944437 .. 9.1530090539143867]
# b = -2.4?
# t = [9.0622861919944437 .. 9.0644940875564615]
# b = -2.43?
# t = [9.0622861919944437 .. 9.0622877673732383]
# b = -2.43105?
# found upper bound!
# t = [9.0632865007403520 .. 23.000000000000000]
# b = 0.?e1
# t = [9.0642214102966907 .. 23.000000000000000]
# b = 0.?e1
# t = [9.0660301816694381 .. 23.000000000000000]
# b = 0.?e1
# t = [9.0695290771746144 .. 23.000000000000000]
# b = 0.?e1
# t = [9.0762953075981940 .. 23.000000000000000]
# b = 0.?e1
# t = [9.0893720540707043 .. 23.000000000000000]
# b = 0.?e1
# t = [9.1146133902474062 .. 23.000000000000000]
# b = 0.?e1
# t = [9.1632050863081406 .. 23.000000000000000]
# b = 0.?e1
# t = [9.2561718516397490 .. 23.000000000000000]
# b = 0.?e1
# t = [9.4312864384980148 .. 23.000000000000000]
# b = 0.?e1
# t = [9.7472873575900820 .. 23.000000000000000]
# b = 0.?e1
# t = [10.251382805031258 .. 23.000000000000000]
# b = 0.?e1
# t = [10.829909761918468 .. 23.000000000000000]
# b = 0.?e1
# t = [11.190383871394214 .. 23.000000000000000]
# b = 0.?e1
# t = [11.342420194541672 .. 23.000000000000000]
# b = 0.?e1
# t = [11.410379070605394 .. 23.000000000000000]
# b = 0.?e1
# t = [11.443417101850402 .. 23.000000000000000]
# b = 0.?e1
# t = [11.460232548435378 .. 23.000000000000000]
# b = 0.?e1
# t = [11.468997529365308 .. 23.000000000000000]
# b = 0.?e1
# t = [11.473623567162354 .. 23.000000000000000]
# b = 0.?e1
# t = [11.476081260405798 .. 23.000000000000000]
# b = 0.?e1
# t = [11.477391545524900 .. 23.000000000000000]
# b = 0.?e1
# t = [11.478091410159231 .. 23.000000000000000]
# b = 0.?e1
# t = [11.478465602558012 .. 23.000000000000000]
# b = 0.?e1
# t = [11.478665776341912 .. 23.000000000000000]
# b = 0.?e1
# t = [11.478772889587800 .. 23.000000000000000]
# b = 0.?e1
# t = [11.478830214761041 .. 23.000000000000000]
# b = 0.?e1
# t = [11.478860896714600 .. 23.000000000000000]
# b = 0.?e1
# t = [11.478877319227327 .. 23.000000000000000]
# b = 0.?e1
# found lower bound!
# t = [11.478886109581180 .. 11.593774970676992]
# b = 1.?
# t = [11.478886109581180 .. 11.494956911520357]
# b = 1.2?
# t = [11.478886109581180 .. 11.479229633433900]
# b = 1.208?
# t = [11.478896086692774 .. 11.478896385561598]
# b = 1.208280?
# found upper bound!
# t = [11.479896234270471 .. 23.000000000000000]
# b = 0.?e1
# t = [11.480360691654009 .. 23.000000000000000]
# b = 0.?e1
# t = [11.481040688764105 .. 23.000000000000000]
# b = 0.?e1
# t = [11.482036043383272 .. 23.000000000000000]
# b = 0.?e1
# t = [11.483492561988205 .. 23.000000000000000]
# b = 0.?e1
# t = [11.485622955375113 .. 23.000000000000000]
# b = 0.?e1
# t = [11.488736952758133 .. 23.000000000000000]
# b = 0.?e1
# t = [11.493284294539698 .. 23.000000000000000]
# b = 0.?e1
# t = [11.499915319617725 .. 23.000000000000000]
# b = 0.?e1
# t = [11.509564622480906 .. 23.000000000000000]
# b = 0.?e1
# t = [11.523562779624361 .. 23.000000000000000]
# b = 0.?e1
# t = [11.543777174465562 .. 23.000000000000000]
# b = 0.?e1
# t = [11.572770596516029 .. 23.000000000000000]
# b = 0.?e1
# t = [11.613935944974004 .. 23.000000000000000]
# b = 0.?e1
# t = [11.671501038514387 .. 23.000000000000000]
# b = 0.?e1
# t = [11.750182645249211 .. 23.000000000000000]
# b = 0.?e1
# t = [11.854123766208701 .. 23.000000000000000]
# b = 0.?e1
# t = [11.984747743211116 .. 23.000000000000000]
# b = 0.?e1
# t = [12.137800549922539 .. 23.000000000000000]
# b = 0.?e1
# t = [12.301581651344790 .. 23.000000000000000]
# b = 0.?e1
# t = [12.459647822717332 .. 23.000000000000000]
# b = 0.?e1
# t = [12.597960704282884 .. 23.000000000000000]
# b = 0.?e1
# t = [12.710328903358526 .. 23.000000000000000]
# b = 0.?e1
# t = [12.797709456569078 .. 23.000000000000000]
# b = 0.?e1
# t = [12.864373787427128 .. 23.000000000000000]
# b = 0.?e1
# t = [12.915020831217733 .. 23.000000000000000]
# b = 0.?e1
# t = [12.953618124982126 .. 23.000000000000000]
# b = 0.?e1
# t = [12.983207138448047 .. 23.000000000000000]
# b = 0.?e1
# t = [13.006038955122503 .. 23.000000000000000]
# b = 0.?e1
# t = [13.023765555543384 .. 23.000000000000000]
# b = 0.?e1
# t = [13.037603274507013 .. 23.000000000000000]
# b = 0.?e1
# t = [13.048455074862822 .. 23.000000000000000]
# b = 0.?e1
# t = [13.056997884243029 .. 23.000000000000000]
# b = 0.?e1
# t = [13.063744162002885 .. 23.000000000000000]
# b = 0.?e1
# t = [13.069085370330149 .. 23.000000000000000]
# b = 0.?e1
# t = [13.073322931255486 .. 23.000000000000000]
# b = 0.?e1
# t = [13.076690529079176 .. 23.000000000000000]
# b = 0.?e1
# t = [13.079370381619394 .. 23.000000000000000]
# b = 0.?e1
# t = [13.081505260448961 .. 23.000000000000000]
# b = 0.?e1
# t = [13.083207475572429 .. 23.000000000000000]
# b = 0.?e1
# t = [13.084565663086985 .. 23.000000000000000]
# b = 0.?e1
# t = [13.085649961679308 .. 23.000000000000000]
# b = 0.?e1
# t = [13.086515992882278 .. 23.000000000000000]
# b = 0.?e1
# t = [13.087207943058494 .. 23.000000000000000]
# b = 0.?e1
# t = [13.087760964005568 .. 23.000000000000000]
# b = 0.?e1
# t = [13.088203052104322 .. 23.000000000000000]
# b = 0.?e1
# t = [13.088556525330474 .. 23.000000000000000]
# b = 0.?e1
# t = [13.088839188117930 .. 23.000000000000000]
# b = 0.?e1
# t = [13.089065252589568 .. 23.000000000000000]
# b = 0.?e1
# t = [13.089246068758113 .. 23.000000000000000]
# b = 0.?e1
# t = [13.089390704372183 .. 23.000000000000000]
# b = 0.?e1
# t = [13.089506406051420 .. 23.000000000000000]
# b = 0.?e1
# t = [13.089598966454593 .. 23.000000000000000]
# b = 0.?e1
# t = [13.089673016911810 .. 23.000000000000000]
# b = 0.?e1
# t = [13.089732260833621 .. 23.000000000000000]
# b = 0.?e1
# t = [13.089779659999376 .. 23.000000000000000]
# b = 0.?e1
# t = [13.089817583312489 .. 23.000000000000000]
# b = 0.?e1
# t = [13.089847925632756 .. 23.000000000000000]
# b = 0.?e1
# t = [13.089872202735682 .. 23.000000000000000]
# b = 0.?e1
# t = [13.089891627214555 .. 23.000000000000000]
# b = 0.?e1
# t = [13.089907169162492 .. 23.000000000000000]
# b = 0.?e1
# t = [13.089919604694493 .. 23.000000000000000]
# b = 0.?e1
# found lower bound!
# t = [13.089929554751442 .. 13.220928850298956]
# b = -1.?
# t = [13.089929554751442 .. 13.118978469875236]
# b = -0.5?
# t = [13.089929554751442 .. 13.091413218890671]
# b = -0.52?
# t = [13.089965743210855 .. 13.089973101784747]
# b = -0.5197?
# found upper bound!
# t = [13.090969390014416 .. 23.000000000000000]
# b = 0.?e1
# t = [13.091169091870209 .. 23.000000000000000]
# b = 0.?e1
# t = [13.091408638526994 .. 23.000000000000000]
# b = 0.?e1
# t = [13.091695964027827 .. 23.000000000000000]
# b = 0.?e1
# t = [13.092040575294067 .. 23.000000000000000]
# b = 0.?e1
# t = [13.092453860862057 .. 23.000000000000000]
# b = 0.?e1
# t = [13.092949458858242 .. 23.000000000000000]
# b = 0.?e1
# t = [13.093543694969881 .. 23.000000000000000]
# b = 0.?e1
# t = [13.094256102843749 .. 23.000000000000000]
# b = 0.?e1
# t = [13.095110041147350 .. 23.000000000000000]
# b = 0.?e1
# t = [13.096133423390869 .. 23.000000000000000]
# b = 0.?e1
# t = [13.097359578415723 .. 23.000000000000000]
# b = 0.?e1
# t = [13.098828261009833 .. 23.000000000000000]
# b = 0.?e1
# t = [13.100586833094572 .. 23.000000000000000]
# b = 0.?e1
# t = [13.102691635851860 .. 23.000000000000000]
# b = 0.?e1
# t = [13.105209571274139 .. 23.000000000000000]
# b = 0.?e1
# t = [13.108219906808180 .. 23.000000000000000]
# b = 0.?e1
# t = [13.111816307385495 .. 23.000000000000000]
# b = 0.?e1
# t = [13.116109082817262 .. 23.000000000000000]
# b = 0.?e1
# t = [13.121227611915905 .. 23.000000000000000]
# b = 0.?e1
# t = [13.127322863117159 .. 23.000000000000000]
# b = 0.?e1
# t = [13.134569868514073 .. 23.000000000000000]
# b = 0.?e1
# t = [13.143169915928343 .. 23.000000000000000]
# b = 0.?e1
# t = [13.153352092075603 .. 23.000000000000000]
# b = 0.?e1
# t = [13.165373628476229 .. 23.000000000000000]
# b = 0.?e1
# t = [13.179518262122099 .. 23.000000000000000]
# b = 0.?e1
# t = [13.196091525099827 .. 23.000000000000000]
# b = 0.?e1
# t = [13.215411542135141 .. 23.000000000000000]
# b = 0.?e1
# t = [13.237793604762996 .. 23.000000000000000]
# b = 0.?e1
# t = [13.263526640883396 .. 23.000000000000000]
# b = 0.?e1
# t = [13.292839953880372 .. 23.000000000000000]
# b = 0.?e1
# t = [13.325859641996848 .. 23.000000000000000]
# b = 0.?e1
# t = [13.362556385705994 .. 23.000000000000000]
# b = 0.?e1
# t = [13.402690147075920 .. 23.000000000000000]
# b = 0.?e1
# t = [13.445762528146996 .. 23.000000000000000]
# b = 0.?e1
# t = [13.490992638577779 .. 23.000000000000000]
# b = 0.?e1
# t = [13.537334267758669 .. 23.000000000000000]
# b = 0.?e1
# t = [13.583547037156099 .. 23.000000000000000]
# b = 0.?e1
# t = [13.628319956798465 .. 23.000000000000000]
# b = 0.?e1
# t = [13.670425805041801 .. 23.000000000000000]
# b = 0.?e1
# t = [13.708868692749488 .. 23.000000000000000]
# b = 0.?e1
# t = [13.742985788876948 .. 23.000000000000000]
# b = 0.?e1
# t = [13.772480340508369 .. 23.000000000000000]
# b = 0.?e1
# t = [13.797388098324587 .. 23.000000000000000]
# b = 0.?e1
# t = [13.817999267358251 .. 23.000000000000000]
# b = 0.?e1
# t = [13.834764758508702 .. 23.000000000000000]
# b = 0.?e1
# t = [13.848210059495338 .. 23.000000000000000]
# b = 0.?e1
# t = [13.858869304028415 .. 23.000000000000000]
# b = 0.?e1
# t = [13.867242370867733 .. 23.000000000000000]
# b = 0.?e1
# t = [13.873771897084887 .. 23.000000000000000]
# b = 0.?e1
# t = [13.878834824293271 .. 23.000000000000000]
# b = 0.?e1
# t = [13.882743179251106 .. 23.000000000000000]
# b = 0.?e1
# t = [13.885749907588667 .. 23.000000000000000]
# b = 0.?e1
# t = [13.888056889329348 .. 23.000000000000000]
# b = 0.?e1
# t = [13.889823375534742 .. 23.000000000000000]
# b = 0.?e1
# t = [13.891173888568813 .. 23.000000000000000]
# b = 0.?e1
# t = [13.892205150189285 .. 23.000000000000000]
# b = 0.?e1
# t = [13.892991911108529 .. 23.000000000000000]
# b = 0.?e1
# t = [13.893591721971363 .. 23.000000000000000]
# b = 0.?e1
# t = [13.894048763079053 .. 23.000000000000000]
# b = 0.?e1
# t = [13.894396876230938 .. 23.000000000000000]
# b = 0.?e1
# t = [13.894661940808230 .. 23.000000000000000]
# b = 0.?e1
# t = [13.894863722137406 .. 23.000000000000000]
# b = 0.?e1
# t = [13.895017301416254 .. 23.000000000000000]
# b = 0.?e1
# t = [13.895134177370850 .. 23.000000000000000]
# b = 0.?e1
# t = [13.895223112377163 .. 23.000000000000000]
# b = 0.?e1
# t = [13.895290780804350 .. 23.000000000000000]
# b = 0.?e1
# t = [13.895342264934654 .. 23.000000000000000]
# b = 0.?e1
# t = [13.895381433788545 .. 23.000000000000000]
# b = 0.?e1
# t = [13.895411232210893 .. 23.000000000000000]
# b = 0.?e1
# t = [13.895433901307294 .. 23.000000000000000]
# b = 0.?e1
# t = [13.895451146435281 .. 23.000000000000000]
# b = 0.?e1
# t = [13.895464265171408 .. 23.000000000000000]
# b = 0.?e1
# found lower bound!
# t = [13.895474244757334 .. 14.034528987204907]
# b = 1.?
# t = [13.895474244757334 .. 13.929339901629947]
# b = 1.?
# t = [13.895474244757334 .. 13.898293450314585]
# b = 0.62?
# t = [13.895483936781191 .. 13.895527437782662]
# b = 0.6222?
# t = [13.895505964630720 .. 13.895505969819219]
# b = 0.6222208?
# found upper bound!
# t = [13.896505967801010 .. 23.000000000000000]
# b = 0.?e1
# t = [13.896745574669580 .. 23.000000000000000]
# b = 0.?e1
# t = [13.897042679453768 .. 23.000000000000000]
# b = 0.?e1
# t = [13.897411126198282 .. 23.000000000000000]
# b = 0.?e1
# t = [13.897868117151400 .. 23.000000000000000]
# b = 0.?e1
# t = [13.898435040742915 .. 23.000000000000000]
# b = 0.?e1
# t = [13.899138510858191 .. 23.000000000000000]
# b = 0.?e1
# t = [13.900011675131407 .. 23.000000000000000]
# b = 0.?e1
# t = [13.901095867730740 .. 23.000000000000000]
# b = 0.?e1
# t = [13.902442706306736 .. 23.000000000000000]
# b = 0.?e1
# t = [13.904116766229076 .. 23.000000000000000]
# b = 0.?e1
# t = [13.906199012179923 .. 23.000000000000000]
# b = 0.?e1
# t = [13.908791234082533 .. 23.000000000000000]
# b = 0.?e1
# t = [13.912021831283547 .. 23.000000000000000]
# b = 0.?e1
# t = [13.916053431744400 .. 23.000000000000000]
# b = 0.?e1
# t = [13.921093047156102 .. 23.000000000000000]
# b = 0.?e1
# t = [13.927405791793480 .. 23.000000000000000]
# b = 0.?e1
# t = [13.935333701237256 .. 23.000000000000000]
# b = 0.?e1
# t = [13.945321992732656 .. 23.000000000000000]
# b = 0.?e1
# t = [13.957956411243308 .. 23.000000000000000]
# b = 0.?e1
# t = [13.974017453164032 .. 23.000000000000000]
# b = 0.?e1
# t = [13.994560874014926 .. 23.000000000000000]
# b = 0.?e1
# t = [14.021040084034140 .. 23.000000000000000]
# b = 0.?e1
# t = [14.055496824342975 .. 23.000000000000000]
# b = 0.?e1
# t = [14.100865407553021 .. 23.000000000000000]
# b = 0.?e1
# t = [14.161468336273387 .. 23.000000000000000]
# b = 0.?e1
# t = [14.243832896240705 .. 23.000000000000000]
# b = 0.?e1
# t = [14.358018064506932 .. 23.000000000000000]
# b = 0.?e1
# t = [14.519589257798251 .. 23.000000000000000]
# b = 0.?e1
# t = [14.751570355247730 .. 23.000000000000000]
# b = 0.?e1
# t = [15.081444988696102 .. 23.000000000000000]
# b = 0.?e1
# t = [15.513977465435893 .. 23.000000000000000]
# b = 0.?e1
# t = [15.954358183804563 .. 23.000000000000000]
# b = 0.?e1
# t = [16.215659156199713 .. 23.000000000000000]
# b = 0.?e1
# t = [16.293219139328115 .. 23.000000000000000]
# b = 0.?e1
# t = [16.308708044089382 .. 23.000000000000000]
# b = 0.?e1
# t = [16.311510501456826 .. 23.000000000000000]
# b = 0.?e1
# t = [16.312008508710842 .. 23.000000000000000]
# b = 0.?e1
# t = [16.312096724549785 .. 23.000000000000000]
# b = 0.?e1
# t = [16.312112342073685 .. 23.000000000000000]
# b = 0.?e1
# found lower bound!
# t = [16.312115106686839 .. 16.475336257753707]
# b = -3.?
# t = [16.312115106686839 .. 16.321702530726953]
# b = -2.2?
# t = [16.312115106686839 .. 16.312158450615471]
# b = -2.1398?
# t = [16.312115700450743 .. 16.312115702201905]
# b = -2.13975805?
# found upper bound!
# t = [16.313115701331621 .. 23.000000000000000]
# b = 0.?e1
# t = [16.313938855348048 .. 23.000000000000000]
# b = 0.?e1
# t = [16.315439846514397 .. 23.000000000000000]
# b = 0.?e1
# t = [16.318177437611186 .. 23.000000000000000]
# b = 0.?e1
# t = [16.323172350821334 .. 23.000000000000000]
# b = 0.?e1
# t = [16.332292264515857 .. 23.000000000000000]
# b = 0.?e1
# t = [16.348964410686296 .. 23.000000000000000]
# b = 0.?e1
# t = [16.379508161720860 .. 23.000000000000000]
# b = 0.?e1
# t = [16.435661783547448 .. 23.000000000000000]
# b = 0.?e1
# t = [16.539421574163256 .. 23.000000000000000]
# b = 0.?e1
# t = [16.732022495473056 .. 23.000000000000000]
# b = 0.?e1
# t = [17.086588724416163 .. 23.000000000000000]
# b = 0.?e1
# t = [17.692270644746834 .. 23.000000000000000]
# b = 0.?e1
# t = [18.428871133239567 .. 23.000000000000000]
# b = 0.?e1
# t = [18.721049687298499 .. 23.000000000000000]
# b = 0.?e1
# t = [18.728671453833335 .. 23.000000000000000]
# b = 0.?e1
# t = [18.728725041385068 .. 23.000000000000000]
# b = 0.?e1
# found lower bound!
# t = [18.728725431993339 .. 18.916112686313273]
# b = 2.5?
# t = [18.728725431993339 .. 18.732650445310267]
# b = 2.58?
# t = [18.728725431993339 .. 18.728726723386853]
# b = 2.581043?
# found upper bound!
# t = [18.729725434862370 .. 23.000000000000000]
# b = 0.?e1
# t = [18.730718107251330 .. 23.000000000000000]
# b = 0.?e1
# t = [18.732696104663400 .. 23.000000000000000]
# b = 0.?e1
# t = [18.736637233390514 .. 23.000000000000000]
# b = 0.?e1
# t = [18.744488921885938 .. 23.000000000000000]
# b = 0.?e1
# t = [18.760127220247088 .. 23.000000000000000]
# b = 0.?e1
# t = [18.791254364153314 .. 23.000000000000000]
# b = 0.?e1
# t = [18.853106920185766 .. 23.000000000000000]
# b = 0.?e1
# t = [18.975401723849408 .. 23.000000000000000]
# b = 0.?e1
# t = [19.213284317619994 .. 23.000000000000000]
# b = 0.?e1
# t = [19.650466347918250 .. 23.000000000000000]
# b = 0.?e1
# t = [20.311113310496175 .. 23.000000000000000]
# b = 0.?e1
# t = [20.874086807321067 .. 23.000000000000000]
# b = 0.?e1
# t = [21.076234090002284 .. 23.000000000000000]
# b = 0.?e1
# t = [21.131906506823948 .. 23.000000000000000]
# b = 0.?e1
# t = [21.143052795936498 .. 23.000000000000000]
# b = 0.?e1
# t = [21.144959539147528 .. 23.000000000000000]
# b = 0.?e1
# t = [21.145273700692925 .. 23.000000000000000]
# b = 0.?e1
# t = [21.145325119405331 .. 23.000000000000000]
# b = 0.?e1
# found lower bound!
# t = [21.145333525799305 .. 21.356886861057298]
# b = -2.?
# t = [21.145333525799305 .. 21.178130141643156]
# b = -1.7?
# t = [21.145333525799305 .. 21.146159326749360]
# b = -1.73?
# t = [21.145334642169874 .. 21.145335694678011]
# b = -1.72412?
# found upper bound!
# t = [21.146335168393363 .. 23.000000000000000]
# b = 0.?e1
# t = [21.147950224465887 .. 23.000000000000000]
# b = 0.?e1
# t = [21.152171367981839 .. 23.000000000000000]
# b = 0.?e1
# t = [21.163190221430028 .. 23.000000000000000]
# b = 0.?e1
# t = [21.191859508979050 .. 23.000000000000000]
# b = 0.?e1
# t = [21.265787843217040 .. 23.000000000000000]
# b = 0.?e1
# t = [21.451567247322728 .. 23.000000000000000]
# b = 0.?e1
# t = [21.881429492549589 .. 23.000000000000000]
# b = 0.?e1
# t = [22.621464190491142 .. 23.000000000000000]
# b = 1.?
# stopping since presumed converged
# t = [22.621464190491142 .. 23.000000000000000], fprime(t) = [0.44459769674724147 .. 1.0636805748532885]
# [1.8124573002?,
#  2.6179938780?,
#  4.229067034?,
#  6.6456767672092?,
#  9.062286500740?,
#  11.4788962342704?,
#  13.0899693900?,
#  13.89550596780101?,
#  16.31211570133162?,
#  18.728725434863?,
#  21.145335168393?]

# %%
p =  plot(g, (0,23))
for z in zs:
    print 'z =', z.str(style='brackets')
    p += point((z.lower(), 0), marker='X', size=100, color='red')
    p += point((z.upper(), 0), marker='X', size=100, color='green')
p
# Out:
# z = [1.8124573001245383 .. 1.8124573001843374]
# z = [2.6179938779747695 .. 2.6179938780021237]
# z = [4.2290670335651698 .. 4.2290670337510435]
# z = [6.6456767672091432 .. 6.6456767672092019]
# z = [9.0622865007393134 .. 9.0622865007403509]
# z = [11.478896234270349 .. 11.478896234270471]
# z = [13.089969389920847 .. 13.089969390014416]
# z = [13.895505967801007 .. 13.895505967801010]
# z = [16.312115701331617 .. 16.312115701331621]
# z = [18.728725434862088 .. 18.728725434862370]
# z = [21.145335168392502 .. 21.145335168393363]
# Graphics object consisting of 23 graphics primitives

# %%
plot([(lambda x: RIF(h(x)).lower()), h, (lambda x: RIF(h(x)).upper())], 
         xmin=5, xmax=10,
         color=['blue', 'blue', 'blue'],
         linestyle=['--', '-', '--'])
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
RIF(h(6.4456766511496752)).str(style='brackets')
# Out:
# '[-0.46895127350575977 .. -2.8214554792516111e-7]'

# %%
RIF(h(6.4456766511496753)).str(style='brackets')
# Out:
# '[-0.46895127350575889 .. -2.8214554709249384e-7]'

# %%
zs = list(isolate_roots(h, h.derivative(), RIF(5,10), 0.001))
zs
# Out:
# t = [5.0000000000000000 .. 10.000000000000000]
# b = 0.?e1
# t = [5.3957518036649094 .. 10.000000000000000]
# b = 0.?e1
# t = [5.9100907541399170 .. 10.000000000000000]
# b = 0.?e1
# t = [6.3374501725412635 .. 10.000000000000000]
# b = 0.?e1
# t = [6.4370717951898406 .. 10.000000000000000]
# b = 0.?e1
# t = [6.4451462110556692 .. 10.000000000000000]
# b = 0.?e1
# t = [6.4456447691632448 .. 10.000000000000000]
# b = 0.?e1
# t = [6.4456748400390857 .. 10.000000000000000]
# b = 0.?e1
# found lower bound!
# t = [6.4456766511496752 .. 6.7078030104497213]
# b = 3.?
# t = [6.4456766511496752 .. 6.6490795269096826]
# b = 3.?
# t = [6.4456766511496752 .. 6.6458791055151121]
# b = 3.?
# t = [6.4456766511496752 .. 6.6456888435329633]
# b = 3.?
# t = [6.4456766511496752 .. 6.6456774881255090]
# b = 3.?
# found upper bound!
# t = [6.6466768102460358 .. 10.000000000000000]
# b = 0.?e1
# t = [6.6476119728139950 .. 10.000000000000000]
# b = 0.?e1
# t = [6.6494218176741570 .. 10.000000000000000]
# b = 0.?e1
# t = [6.6529249766819154 .. 10.000000000000000]
# b = 0.?e1
# t = [6.6597076427873336 .. 10.000000000000000]
# b = 0.?e1
# t = [6.6728468373038296 .. 10.000000000000000]
# b = 0.?e1
# t = [6.6983236833478780 .. 10.000000000000000]
# b = 0.?e1
# t = [6.7477994638531129 .. 10.000000000000000]
# b = 0.?e1
# t = [6.8440669489130590 .. 10.000000000000000]
# b = 0.?e1
# t = [7.0313288918374405 .. 10.000000000000000]
# b = 0.?e1
# t = [7.3898254608035767 .. 10.000000000000000]
# b = 0.?e1
# t = [8.0170865479457074 .. 10.000000000000000]
# b = 0.?e1
# t = [8.6981366938984923 .. 10.000000000000000]
# b = 0.?e1
# t = [8.8531161674792748 .. 10.000000000000000]
# b = 0.?e1
# t = [8.8617013325852482 .. 10.000000000000000]
# b = 0.?e1
# t = [8.8622488015273042 .. 10.000000000000000]
# b = 0.?e1
# t = [8.8622840705895526 .. 10.000000000000000]
# b = 0.?e1
# found lower bound!
# t = [8.8622863440827313 .. 9.1311254925947801]
# b = -2.?
# t = [8.8622863440827313 .. 9.0672197079843180]
# b = -3.?
# t = [8.8622863440827313 .. 9.0625850503964625]
# b = -3.?
# t = [8.8622863440827313 .. 9.0623043381865252]
# b = -3.?
# t = [8.8622863440827313 .. 9.0622875656432580]
# b = -3.?
# found upper bound!
# t = [9.0632865643120368 .. 10.000000000000000]
# b = 0.?e1
# t = [9.0751452034618971 .. 10.000000000000000]
# b = 0.?e1
# t = [9.2274083018831714 .. 10.000000000000000]
# b = 0.?e1
# stopping since presumed converged
# t = [9.2274083018831714 .. 10.000000000000000], fprime(t) = [-2.2959604685799353 .. 0.20499142657861492]
# [7.?, 9.?]

# %%
p = plot([(lambda x: RIF(h(x)).lower()), h, (lambda x: RIF(h(x)).upper())], 
         xmin=5, xmax=10,
         color=['blue', 'blue', 'blue'],
         linestyle=['--', '-', '--'])
for z in zs:
    print 'z =', z.str(style='brackets')
    p += point((z.lower(), 0), marker='X', size=100, color='red')
    p += point((z.upper(), 0), marker='X', size=100, color='green')
p
# Out:
# z = [6.4456766511496752 .. 6.6456768102460356]
# z = [8.8622863440827313 .. 9.0622865643120357]
# Graphics object consisting of 7 graphics primitives

# %%
search_zero(seq2, seq2.map(lambda x: x.derivative()), RIF(0.5,1.5)).str(style='brackets')
# Out:
# t = [0.50000000000000000 .. 1.5000000000000000]
# b = 1.?e1
# t = [0.60243165119724373 .. 1.4411034891747381]
# b = 1.?e1
# t = [0.67021730006802027 .. 1.3319546525971516]
# b = 1.?e1
# t = [0.71728066920076805 .. 1.2688908573310201]
# b = 1.?
# t = [0.74823450000825941 .. 1.2298664986376800]
# b = 1.?
# t = [0.76803648895159715 .. 1.2064507456479848]
# b = 1.?
# t = [0.78048603830030671 .. 1.1924392961609128]
# b = 1.?
# t = [0.78823508068342706 .. 1.1840246582523526]
# b = 1.?
# t = [0.79303091856883956 .. 1.1789426139218473]
# b = 1.?
# t = [0.79598934067094118 .. 1.1758575624638308]
# b = 1.?
# t = [0.79781083931913832 .. 1.1739775274735412]
# b = 1.?
# t = [0.79893107364064763 .. 1.1728287614101594]
# b = 1.?
# t = [0.79961956181355187 .. 1.1721255869976921]
# b = 1.?
# t = [0.80004252985159296 .. 1.1716946784624430]
# b = 1.?
# t = [0.80030231324085254 .. 1.1714304277394541]
# b = 1.?
# t = [0.80046184597425107 .. 1.1712683064625789]
# b = 1.?
# t = [0.80055980585525177 .. 1.1711688155709659]
# b = 1.?
# t = [0.80061995399576479 .. 1.1711077494385960]
# b = 1.?
# t = [0.80065688415269864 .. 1.1710702639677595]
# b = 1.?
# t = [0.80067955829640691 .. 1.1710472520136277]
# b = 1.?
# t = [0.80069347944239899 .. 1.1710331246466295]
# b = 1.?
# found lower bound!
# t = [0.80070202647999721 .. 1.0936308855197430]
# b = 1.?
# t = [0.80070202647999721 .. 1.0893751993275481]
# b = 1.?
# t = [0.80070202647999721 .. 1.0886271818280154]
# b = 1.?
# t = [0.80070202647999721 .. 1.0884985213291532]
# b = 1.?
# t = [0.80070202647999721 .. 1.0884764765461557]
# b = 1.?
# found upper bound!
# '[0.80070202647999721 .. 1.0884727018838710]'

# %%
sigg = to_signal(g, g.derivative(), RIF(0,23))
# Out:
# t = [0.00000000000000000 .. 23.000000000000000]
# b = 0.?e1
# t = [0.38461538461538463 .. 23.000000000000000]
# b = 0.?e1
# t = [0.84298235669719434 .. 23.000000000000000]
# b = 0.?e1
# t = [1.2148421071808785 .. 23.000000000000000]
# b = 0.?e1
# t = [1.4352071807962092 .. 23.000000000000000]
# b = 0.?e1
# t = [1.5610863921072322 .. 23.000000000000000]
# b = 0.?e1
# t = [1.6380728918527696 .. 23.000000000000000]
# b = 0.?e1
# t = [1.6881708565255457 .. 23.000000000000000]
# b = 0.?e1
# t = [1.7222436090318271 .. 23.000000000000000]
# b = 0.?e1
# t = [1.7461407002099318 .. 23.000000000000000]
# b = 0.?e1
# t = [1.7632678705983457 .. 23.000000000000000]
# b = 0.?e1
# t = [1.7757346511305671 .. 23.000000000000000]
# b = 0.?e1
# t = [1.7849117381787857 .. 23.000000000000000]
# b = 0.?e1
# t = [1.7917231520698615 .. 23.000000000000000]
# b = 0.?e1
# t = [1.7968096695042874 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8006254079860171 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8034976116494791 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8056651316725198 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8073040172016612 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8085450031676559 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8094857308071434 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8101994439300830 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8107412683222143 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8111527989814417 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8114654820531683 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8117031261185707 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8118837774190788 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8120211261882455 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8121255648585095 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8122049863619658 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8122653875457144 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8123113259651189 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8123462660801934 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8123728418628672 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8123930561311982 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8124084319329332 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8124201275578775 .. 23.000000000000000]
# b = 0.?e1
# found lower bound!
# t = [1.8124290239434561 .. 1.8306533141828907]
# b = -0.6?
# t = [1.8124290239434561 .. 1.8133542337892970]
# b = -0.62?
# t = [1.8124550174126168 .. 1.8124596325768081]
# b = -0.62222?
# found upper bound!
#   I  = [0.00000000000000000 .. 1.8124573001245384]
# f(I) = [-0.97094181741708486 .. 2.0000000000000000]
# t = [1.8134573001843374 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8136963244966748 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8139923951117313 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8143590806882718 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8148131525232706 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8153753272500334 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8160711746716691 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8169322236029865 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8179973029960623 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8193141593102228 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8209413930128508 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8229507555711239 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8254298406650069 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8284851855896211 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8322457649858723 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8368668007021076 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8425337172658138 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8494659274644627 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8579199199606859 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8681908247342275 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8806112451364820 .. 23.000000000000000]
# b = 0.?e1
# t = [1.8955456839832418 .. 23.000000000000000]
# b = 0.?e1
# t = [1.9133784219151328 .. 23.000000000000000]
# b = 0.?e1
# t = [1.9344923843023260 .. 23.000000000000000]
# b = 0.?e1
# t = [1.9592366460014407 .. 23.000000000000000]
# b = 0.?e1
# t = [1.9878812142469639 .. 23.000000000000000]
# b = 0.?e1
# t = [2.0205601356111602 .. 23.000000000000000]
# b = 0.?e1
# t = [2.0572081787647515 .. 23.000000000000000]
# b = 0.?e1
# t = [2.0975020739315755 .. 23.000000000000000]
# b = 0.?e1
# t = [2.1408229266937883 .. 23.000000000000000]
# b = 0.?e1
# t = [2.1862586956786982 .. 23.000000000000000]
# b = 0.?e1
# t = [2.2326605933441370 .. 23.000000000000000]
# b = 0.?e1
# t = [2.2787532000799761 .. 23.000000000000000]
# b = 0.?e1
# t = [2.3232787790036275 .. 23.000000000000000]
# b = 0.?e1
# t = [2.3651412040573536 .. 23.000000000000000]
# b = 0.?e1
# t = [2.4035135564432157 .. 23.000000000000000]
# b = 0.?e1
# t = [2.4378875055130340 .. 23.000000000000000]
# b = 0.?e1
# t = [2.4680639021458934 .. 23.000000000000000]
# b = 0.?e1
# t = [2.4941010321158980 .. 23.000000000000000]
# b = 0.?e1
# t = [2.5162432406971539 .. 23.000000000000000]
# b = 0.?e1
# t = [2.5348493257955202 .. 23.000000000000000]
# b = 0.?e1
# t = [2.5503324205840693 .. 23.000000000000000]
# b = 0.?e1
# t = [2.5631157187947382 .. 23.000000000000000]
# b = 0.?e1
# t = [2.5736034985931199 .. 23.000000000000000]
# b = 0.?e1
# t = [2.5821645728793498 .. 23.000000000000000]
# b = 0.?e1
# t = [2.5891247403935131 .. 23.000000000000000]
# b = 0.?e1
# t = [2.5947651778062081 .. 23.000000000000000]
# b = 0.?e1
# t = [2.5993244034508831 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6030021402383116 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6059639795806424 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6083461729821189 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6102601705962467 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6117967167371789 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6130294303478165 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6140178673560039 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6148100990071010 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6154448576470259 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6159533070319214 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6163604932034383 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6166865275061095 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6169475473778596 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6171564942426717 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6173237417906252 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6174576024474416 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6175647350309674 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6176504724787572 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6177190850668097 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6177739916566222 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6178179291296665 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6178530882198245 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6178812223658174 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6179037349158122 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6179217489722468 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6179361633217204 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6179476972151616 .. 23.000000000000000]
# b = 0.?e1
# found lower bound!
# t = [2.6179569262165074 .. 2.6442364954786722]
# b = 0.6?
# t = [2.6179569262165074 .. 2.6190613322995904]
# b = 0.520?
# t = [2.6179918289202475 .. 2.6179958592402728]
# b = 0.51962?
# found upper bound!
#   I  = [1.8124573001843373 .. 2.6179938779747696]
# f(I) = [-0.49999999998551592 .. 0.47094181739417230]
# t = [2.6189938780021240 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6191938798485923 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6194339183428252 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6197220238545200 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6200678443754052 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6204829744052959 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6209813520301659 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6215797389042654 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6222983012653524 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6231613144218819 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6241980186241296 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6254436612329610 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6269407691264650 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6287407070143635 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6309055926951985 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6335106605778588 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6366471917751019 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6404261652202256 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6449828329447928 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6504824885094704 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6571277868114258 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6651680941798758 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6749115097033784 .. 23.000000000000000]
# b = 0.?e1
# t = [2.6867404126775547 .. 23.000000000000000]
# b = 0.?e1
# t = [2.7011316642637215 .. 23.000000000000000]
# b = 0.?e1
# t = [2.7186829173340729 .. 23.000000000000000]
# b = 0.?e1
# t = [2.7401468199584657 .. 23.000000000000000]
# b = 0.?e1
# t = [2.7664750845290759 .. 23.000000000000000]
# b = 0.?e1
# t = [2.7988740383446417 .. 23.000000000000000]
# b = 0.?e1
# t = [2.8388714100169472 .. 23.000000000000000]
# b = 0.?e1
# t = [2.8883885443736287 .. 23.000000000000000]
# b = 0.?e1
# t = [2.9497982689020574 .. 23.000000000000000]
# b = 0.?e1
# t = [3.0259170645495445 .. 23.000000000000000]
# b = 0.?e1
# t = [3.1198162863098679 .. 23.000000000000000]
# b = 0.?e1
# t = [3.2342293263931733 .. 23.000000000000000]
# b = 0.?e1
# t = [3.3702190861201759 .. 23.000000000000000]
# b = 0.?e1
# t = [3.5248818627488733 .. 23.000000000000000]
# b = 0.?e1
# t = [3.6887676447183435 .. 23.000000000000000]
# b = 0.?e1
# t = [3.8456745962099319 .. 23.000000000000000]
# b = 0.?e1
# t = [3.9780645191153287 .. 23.000000000000000]
# b = 0.?e1
# t = [4.0759027331310342 .. 23.000000000000000]
# b = 0.?e1
# t = [4.1403493208635699 .. 23.000000000000000]
# b = 0.?e1
# t = [4.1793866813656510 .. 23.000000000000000]
# b = 0.?e1
# t = [4.2018005346880036 .. 23.000000000000000]
# b = 0.?e1
# t = [4.2142713841156105 .. 23.000000000000000]
# b = 0.?e1
# t = [4.2210886265157974 .. 23.000000000000000]
# b = 0.?e1
# t = [4.2247793913154749 .. 23.000000000000000]
# b = 0.?e1
# t = [4.2267670627011302 .. 23.000000000000000]
# b = 0.?e1
# t = [4.2278345054813328 .. 23.000000000000000]
# b = 0.?e1
# t = [4.2284068860750068 .. 23.000000000000000]
# b = 0.?e1
# t = [4.2287135561565367 .. 23.000000000000000]
# b = 0.?e1
# t = [4.2288777921547655 .. 23.000000000000000]
# b = 0.?e1
# t = [4.2289657275618806 .. 23.000000000000000]
# b = 0.?e1
# t = [4.2290128041354044 .. 23.000000000000000]
# b = 0.?e1
# t = [4.2290380050795004 .. 23.000000000000000]
# b = 0.?e1
# t = [4.2290514951182931 .. 23.000000000000000]
# b = 0.?e1
# found lower bound!
# t = [4.2290587161831743 .. 4.2714493033450057]
# b = -2.?
# t = [4.2290587161831743 .. 4.2312063092187833]
# b = -1.21?
# t = [4.2290610223923081 .. 4.2290729879833995]
# b = -1.2083?
# found upper bound!
#   I  = [2.6179938780021236 .. 4.2290670335651699]
# f(I) = [-1.3854560255857836 .. 1.4999999999907950]
# t = [4.2300670337510437 .. 23.000000000000000]
# b = 0.?e1
# t = [4.2305320224417259 .. 23.000000000000000]
# b = 0.?e1
# t = [4.2312134062966864 .. 23.000000000000000]
# b = 0.?e1
# t = [4.2322120976516819 .. 23.000000000000000]
# b = 0.?e1
# t = [4.2336763045543692 .. 23.000000000000000]
# b = 0.?e1
# t = [4.2358239681893792 .. 23.000000000000000]
# b = 0.?e1
# t = [4.2389761531895588 .. 23.000000000000000]
# b = 0.?e1
# t = [4.2436070852252738 .. 23.000000000000000]
# b = 0.?e1
# t = [4.2504198730352475 .. 23.000000000000000]
# b = 0.?e1
# t = [4.2604626534378029 .. 23.000000000000000]
# b = 0.?e1
# t = [4.2753099856771923 .. 23.000000000000000]
# b = 0.?e1
# t = [4.2973528290057920 .. 23.000000000000000]
# b = 0.?e1
# t = [4.3302754460227657 .. 23.000000000000000]
# b = 0.?e1
# t = [4.3798648375228035 .. 23.000000000000000]
# b = 0.?e1
# t = [4.4554247393416002 .. 23.000000000000000]
# b = 0.?e1
# t = [4.5722726089777578 .. 23.000000000000000]
# b = 0.?e1
# t = [4.7559201381159104 .. 23.000000000000000]
# b = 0.?e1
# t = [5.0470633342372011 .. 23.000000000000000]
# b = 0.?e1
# t = [5.4947689678103746 .. 23.000000000000000]
# b = 0.?e1
# t = [6.0776177521744312 .. 23.000000000000000]
# b = 0.?e1
# t = [6.5236305780327299 .. 23.000000000000000]
# b = 0.?e1
# t = [6.6356138295825211 .. 23.000000000000000]
# b = 0.?e1
# t = [6.6450117563217112 .. 23.000000000000000]
# b = 0.?e1
# t = [6.6456335051671491 .. 23.000000000000000]
# b = 0.?e1
# t = [6.6456739556800084 .. 23.000000000000000]
# b = 0.?e1
# found lower bound!
# t = [6.6456765845046072 .. 6.7122333503496528]
# b = 2.5?
# t = [6.6456765845046072 .. 6.6466675780850118]
# b = 2.431?
# t = [6.6456765845046072 .. 6.6456770215836621]
# b = 2.431042?
# found upper bound!
#   I  = [4.2290670337510434 .. 6.6456767672091433]
# f(I) = [-2.0000000000000000 .. 1.2400609126418234]
# t = [6.6466767672092021 .. 23.000000000000000]
# b = 0.?e1
# t = [6.6476118895279059 .. 23.000000000000000]
# b = 0.?e1
# t = [6.6494216564802171 .. 23.000000000000000]
# b = 0.?e1
# t = [6.6529246646426596 .. 23.000000000000000]
# b = 0.?e1
# t = [6.6597070385201408 .. 23.000000000000000]
# b = 0.?e1
# t = [6.6728456663423543 .. 23.000000000000000]
# b = 0.?e1
# t = [6.6983214115443763 .. 23.000000000000000]
# b = 0.?e1
# t = [6.7477950482382000 .. 23.000000000000000]
# b = 0.?e1
# t = [6.8440583513917108 .. 23.000000000000000]
# b = 0.?e1
# t = [7.0313122087980008 .. 23.000000000000000]
# b = 0.?e1
# t = [7.3897941390000880 .. 23.000000000000000]
# b = 0.?e1
# t = [8.0170367980822785 .. 23.000000000000000]
# b = 0.?e1
# t = [8.7681510962948845 .. 23.000000000000000]
# b = 0.?e1
# t = [9.0444446522178267 .. 23.000000000000000]
# b = 0.?e1
# t = [9.0611591970510705 .. 23.000000000000000]
# b = 0.?e1
# t = [9.0622133790638539 .. 23.000000000000000]
# b = 0.?e1
# t = [9.0622817495872229 .. 23.000000000000000]
# b = 0.?e1
# found lower bound!
# t = [9.0622861919944437 .. 9.1530090539143867]
# b = -2.4?
# t = [9.0622861919944437 .. 9.0644940875564615]
# b = -2.43?
# t = [9.0622861919944437 .. 9.0622877673732383]
# b = -2.43105?
# found upper bound!
#   I  = [6.6456767672092018 .. 9.0622865007393135]
# f(I) = [5.8231197641589460e-14 .. 2.0000000000000000]
# t = [9.0632865007403520 .. 23.000000000000000]
# b = 0.?e1
# t = [9.0642214102966907 .. 23.000000000000000]
# b = 0.?e1
# t = [9.0660301816694381 .. 23.000000000000000]
# b = 0.?e1
# t = [9.0695290771746144 .. 23.000000000000000]
# b = 0.?e1
# t = [9.0762953075981940 .. 23.000000000000000]
# b = 0.?e1
# t = [9.0893720540707043 .. 23.000000000000000]
# b = 0.?e1
# t = [9.1146133902474062 .. 23.000000000000000]
# b = 0.?e1
# t = [9.1632050863081406 .. 23.000000000000000]
# b = 0.?e1
# t = [9.2561718516397490 .. 23.000000000000000]
# b = 0.?e1
# t = [9.4312864384980148 .. 23.000000000000000]
# b = 0.?e1
# t = [9.7472873575900820 .. 23.000000000000000]
# b = 0.?e1
# t = [10.251382805031258 .. 23.000000000000000]
# b = 0.?e1
# t = [10.829909761918468 .. 23.000000000000000]
# b = 0.?e1
# t = [11.190383871394214 .. 23.000000000000000]
# b = 0.?e1
# t = [11.342420194541672 .. 23.000000000000000]
# b = 0.?e1
# t = [11.410379070605394 .. 23.000000000000000]
# b = 0.?e1
# t = [11.443417101850402 .. 23.000000000000000]
# b = 0.?e1
# t = [11.460232548435378 .. 23.000000000000000]
# b = 0.?e1
# t = [11.468997529365308 .. 23.000000000000000]
# b = 0.?e1
# t = [11.473623567162354 .. 23.000000000000000]
# b = 0.?e1
# t = [11.476081260405798 .. 23.000000000000000]
# b = 0.?e1
# t = [11.477391545524900 .. 23.000000000000000]
# b = 0.?e1
# t = [11.478091410159231 .. 23.000000000000000]
# b = 0.?e1
# t = [11.478465602558012 .. 23.000000000000000]
# b = 0.?e1
# t = [11.478665776341912 .. 23.000000000000000]
# b = 0.?e1
# t = [11.478772889587800 .. 23.000000000000000]
# b = 0.?e1
# t = [11.478830214761041 .. 23.000000000000000]
# b = 0.?e1
# t = [11.478860896714600 .. 23.000000000000000]
# b = 0.?e1
# t = [11.478877319227327 .. 23.000000000000000]
# b = 0.?e1
# found lower bound!
# t = [11.478886109581180 .. 11.593774970676992]
# b = 1.?
# t = [11.478886109581180 .. 11.494956911520357]
# b = 1.2?
# t = [11.478886109581180 .. 11.479229633433900]
# b = 1.208?
# t = [11.478896086692774 .. 11.478896385561598]
# b = 1.208280?
# found upper bound!
#   I  = [9.0622865007403508 .. 11.478896234270350]
# f(I) = [-2.0000000000000000 .. 1.2400609126951841]
# t = [11.479896234270471 .. 23.000000000000000]
# b = 0.?e1
# t = [11.480360691654009 .. 23.000000000000000]
# b = 0.?e1
# t = [11.481040688764105 .. 23.000000000000000]
# b = 0.?e1
# t = [11.482036043383272 .. 23.000000000000000]
# b = 0.?e1
# t = [11.483492561988205 .. 23.000000000000000]
# b = 0.?e1
# t = [11.485622955375113 .. 23.000000000000000]
# b = 0.?e1
# t = [11.488736952758133 .. 23.000000000000000]
# b = 0.?e1
# t = [11.493284294539698 .. 23.000000000000000]
# b = 0.?e1
# t = [11.499915319617725 .. 23.000000000000000]
# b = 0.?e1
# t = [11.509564622480906 .. 23.000000000000000]
# b = 0.?e1
# t = [11.523562779624361 .. 23.000000000000000]
# b = 0.?e1
# t = [11.543777174465562 .. 23.000000000000000]
# b = 0.?e1
# t = [11.572770596516029 .. 23.000000000000000]
# b = 0.?e1
# t = [11.613935944974004 .. 23.000000000000000]
# b = 0.?e1
# t = [11.671501038514387 .. 23.000000000000000]
# b = 0.?e1
# t = [11.750182645249211 .. 23.000000000000000]
# b = 0.?e1
# t = [11.854123766208701 .. 23.000000000000000]
# b = 0.?e1
# t = [11.984747743211116 .. 23.000000000000000]
# b = 0.?e1
# t = [12.137800549922539 .. 23.000000000000000]
# b = 0.?e1
# t = [12.301581651344790 .. 23.000000000000000]
# b = 0.?e1
# t = [12.459647822717332 .. 23.000000000000000]
# b = 0.?e1
# t = [12.597960704282884 .. 23.000000000000000]
# b = 0.?e1
# t = [12.710328903358526 .. 23.000000000000000]
# b = 0.?e1
# t = [12.797709456569078 .. 23.000000000000000]
# b = 0.?e1
# t = [12.864373787427128 .. 23.000000000000000]
# b = 0.?e1
# t = [12.915020831217733 .. 23.000000000000000]
# b = 0.?e1
# t = [12.953618124982126 .. 23.000000000000000]
# b = 0.?e1
# t = [12.983207138448047 .. 23.000000000000000]
# b = 0.?e1
# t = [13.006038955122503 .. 23.000000000000000]
# b = 0.?e1
# t = [13.023765555543384 .. 23.000000000000000]
# b = 0.?e1
# t = [13.037603274507013 .. 23.000000000000000]
# b = 0.?e1
# t = [13.048455074862822 .. 23.000000000000000]
# b = 0.?e1
# t = [13.056997884243029 .. 23.000000000000000]
# b = 0.?e1
# t = [13.063744162002885 .. 23.000000000000000]
# b = 0.?e1
# t = [13.069085370330149 .. 23.000000000000000]
# b = 0.?e1
# t = [13.073322931255486 .. 23.000000000000000]
# b = 0.?e1
# t = [13.076690529079176 .. 23.000000000000000]
# b = 0.?e1
# t = [13.079370381619394 .. 23.000000000000000]
# b = 0.?e1
# t = [13.081505260448961 .. 23.000000000000000]
# b = 0.?e1
# t = [13.083207475572429 .. 23.000000000000000]
# b = 0.?e1
# t = [13.084565663086985 .. 23.000000000000000]
# b = 0.?e1
# t = [13.085649961679308 .. 23.000000000000000]
# b = 0.?e1
# t = [13.086515992882278 .. 23.000000000000000]
# b = 0.?e1
# t = [13.087207943058494 .. 23.000000000000000]
# b = 0.?e1
# t = [13.087760964005568 .. 23.000000000000000]
# b = 0.?e1
# t = [13.088203052104322 .. 23.000000000000000]
# b = 0.?e1
# t = [13.088556525330474 .. 23.000000000000000]
# b = 0.?e1
# t = [13.088839188117930 .. 23.000000000000000]
# b = 0.?e1
# t = [13.089065252589568 .. 23.000000000000000]
# b = 0.?e1
# t = [13.089246068758113 .. 23.000000000000000]
# b = 0.?e1
# t = [13.089390704372183 .. 23.000000000000000]
# b = 0.?e1
# t = [13.089506406051420 .. 23.000000000000000]
# b = 0.?e1
# t = [13.089598966454593 .. 23.000000000000000]
# b = 0.?e1
# t = [13.089673016911810 .. 23.000000000000000]
# b = 0.?e1
# t = [13.089732260833621 .. 23.000000000000000]
# b = 0.?e1
# t = [13.089779659999376 .. 23.000000000000000]
# b = 0.?e1
# t = [13.089817583312489 .. 23.000000000000000]
# b = 0.?e1
# t = [13.089847925632756 .. 23.000000000000000]
# b = 0.?e1
# t = [13.089872202735682 .. 23.000000000000000]
# b = 0.?e1
# t = [13.089891627214555 .. 23.000000000000000]
# b = 0.?e1
# t = [13.089907169162492 .. 23.000000000000000]
# b = 0.?e1
# t = [13.089919604694493 .. 23.000000000000000]
# b = 0.?e1
# found lower bound!
# t = [13.089929554751442 .. 13.220928850298956]
# b = -1.?
# t = [13.089929554751442 .. 13.118978469875236]
# b = -0.5?
# t = [13.089929554751442 .. 13.091413218890671]
# b = -0.52?
# t = [13.089965743210855 .. 13.089973101784747]
# b = -0.5197?
# found upper bound!
#   I  = [11.478896234270470 .. 13.089969389920848]
# f(I) = [-1.3854560256024322 .. 1.4999999999682825]
# t = [13.090969390014416 .. 23.000000000000000]
# b = 0.?e1
# t = [13.091169091870209 .. 23.000000000000000]
# b = 0.?e1
# t = [13.091408638526994 .. 23.000000000000000]
# b = 0.?e1
# t = [13.091695964027827 .. 23.000000000000000]
# b = 0.?e1
# t = [13.092040575294067 .. 23.000000000000000]
# b = 0.?e1
# t = [13.092453860862057 .. 23.000000000000000]
# b = 0.?e1
# t = [13.092949458858242 .. 23.000000000000000]
# b = 0.?e1
# t = [13.093543694969881 .. 23.000000000000000]
# b = 0.?e1
# t = [13.094256102843749 .. 23.000000000000000]
# b = 0.?e1
# t = [13.095110041147350 .. 23.000000000000000]
# b = 0.?e1
# t = [13.096133423390869 .. 23.000000000000000]
# b = 0.?e1
# t = [13.097359578415723 .. 23.000000000000000]
# b = 0.?e1
# t = [13.098828261009833 .. 23.000000000000000]
# b = 0.?e1
# t = [13.100586833094572 .. 23.000000000000000]
# b = 0.?e1
# t = [13.102691635851860 .. 23.000000000000000]
# b = 0.?e1
# t = [13.105209571274139 .. 23.000000000000000]
# b = 0.?e1
# t = [13.108219906808180 .. 23.000000000000000]
# b = 0.?e1
# t = [13.111816307385495 .. 23.000000000000000]
# b = 0.?e1
# t = [13.116109082817262 .. 23.000000000000000]
# b = 0.?e1
# t = [13.121227611915905 .. 23.000000000000000]
# b = 0.?e1
# t = [13.127322863117159 .. 23.000000000000000]
# b = 0.?e1
# t = [13.134569868514073 .. 23.000000000000000]
# b = 0.?e1
# t = [13.143169915928343 .. 23.000000000000000]
# b = 0.?e1
# t = [13.153352092075603 .. 23.000000000000000]
# b = 0.?e1
# t = [13.165373628476229 .. 23.000000000000000]
# b = 0.?e1
# t = [13.179518262122099 .. 23.000000000000000]
# b = 0.?e1
# t = [13.196091525099827 .. 23.000000000000000]
# b = 0.?e1
# t = [13.215411542135141 .. 23.000000000000000]
# b = 0.?e1
# t = [13.237793604762996 .. 23.000000000000000]
# b = 0.?e1
# t = [13.263526640883396 .. 23.000000000000000]
# b = 0.?e1
# t = [13.292839953880372 .. 23.000000000000000]
# b = 0.?e1
# t = [13.325859641996848 .. 23.000000000000000]
# b = 0.?e1
# t = [13.362556385705994 .. 23.000000000000000]
# b = 0.?e1
# t = [13.402690147075920 .. 23.000000000000000]
# b = 0.?e1
# t = [13.445762528146996 .. 23.000000000000000]
# b = 0.?e1
# t = [13.490992638577779 .. 23.000000000000000]
# b = 0.?e1
# t = [13.537334267758669 .. 23.000000000000000]
# b = 0.?e1
# t = [13.583547037156099 .. 23.000000000000000]
# b = 0.?e1
# t = [13.628319956798465 .. 23.000000000000000]
# b = 0.?e1
# t = [13.670425805041801 .. 23.000000000000000]
# b = 0.?e1
# t = [13.708868692749488 .. 23.000000000000000]
# b = 0.?e1
# t = [13.742985788876948 .. 23.000000000000000]
# b = 0.?e1
# t = [13.772480340508369 .. 23.000000000000000]
# b = 0.?e1
# t = [13.797388098324587 .. 23.000000000000000]
# b = 0.?e1
# t = [13.817999267358251 .. 23.000000000000000]
# b = 0.?e1
# t = [13.834764758508702 .. 23.000000000000000]
# b = 0.?e1
# t = [13.848210059495338 .. 23.000000000000000]
# b = 0.?e1
# t = [13.858869304028415 .. 23.000000000000000]
# b = 0.?e1
# t = [13.867242370867733 .. 23.000000000000000]
# b = 0.?e1
# t = [13.873771897084887 .. 23.000000000000000]
# b = 0.?e1
# t = [13.878834824293271 .. 23.000000000000000]
# b = 0.?e1
# t = [13.882743179251106 .. 23.000000000000000]
# b = 0.?e1
# t = [13.885749907588667 .. 23.000000000000000]
# b = 0.?e1
# t = [13.888056889329348 .. 23.000000000000000]
# b = 0.?e1
# t = [13.889823375534742 .. 23.000000000000000]
# b = 0.?e1
# t = [13.891173888568813 .. 23.000000000000000]
# b = 0.?e1
# t = [13.892205150189285 .. 23.000000000000000]
# b = 0.?e1
# t = [13.892991911108529 .. 23.000000000000000]
# b = 0.?e1
# t = [13.893591721971363 .. 23.000000000000000]
# b = 0.?e1
# t = [13.894048763079053 .. 23.000000000000000]
# b = 0.?e1
# t = [13.894396876230938 .. 23.000000000000000]
# b = 0.?e1
# t = [13.894661940808230 .. 23.000000000000000]
# b = 0.?e1
# t = [13.894863722137406 .. 23.000000000000000]
# b = 0.?e1
# t = [13.895017301416254 .. 23.000000000000000]
# b = 0.?e1
# t = [13.895134177370850 .. 23.000000000000000]
# b = 0.?e1
# t = [13.895223112377163 .. 23.000000000000000]
# b = 0.?e1
# t = [13.895290780804350 .. 23.000000000000000]
# b = 0.?e1
# t = [13.895342264934654 .. 23.000000000000000]
# b = 0.?e1
# t = [13.895381433788545 .. 23.000000000000000]
# b = 0.?e1
# t = [13.895411232210893 .. 23.000000000000000]
# b = 0.?e1
# t = [13.895433901307294 .. 23.000000000000000]
# b = 0.?e1
# t = [13.895451146435281 .. 23.000000000000000]
# b = 0.?e1
# t = [13.895464265171408 .. 23.000000000000000]
# b = 0.?e1
# found lower bound!
# t = [13.895474244757334 .. 14.034528987204907]
# b = 1.?
# t = [13.895474244757334 .. 13.929339901629947]
# b = 1.?
# t = [13.895474244757334 .. 13.898293450314585]
# b = 0.62?
# t = [13.895483936781191 .. 13.895527437782662]
# b = 0.6222?
# t = [13.895505964630720 .. 13.895505969819219]
# b = 0.6222208?
# found upper bound!
#   I  = [13.089969390014415 .. 13.895505967801008]
# f(I) = [-0.49999999995068545 .. 0.47094181734714858]
# t = [13.896505967801010 .. 23.000000000000000]
# b = 0.?e1
# t = [13.896745574669580 .. 23.000000000000000]
# b = 0.?e1
# t = [13.897042679453768 .. 23.000000000000000]
# b = 0.?e1
# t = [13.897411126198282 .. 23.000000000000000]
# b = 0.?e1
# t = [13.897868117151400 .. 23.000000000000000]
# b = 0.?e1
# t = [13.898435040742915 .. 23.000000000000000]
# b = 0.?e1
# t = [13.899138510858191 .. 23.000000000000000]
# b = 0.?e1
# t = [13.900011675131407 .. 23.000000000000000]
# b = 0.?e1
# t = [13.901095867730740 .. 23.000000000000000]
# b = 0.?e1
# t = [13.902442706306736 .. 23.000000000000000]
# b = 0.?e1
# t = [13.904116766229076 .. 23.000000000000000]
# b = 0.?e1
# t = [13.906199012179923 .. 23.000000000000000]
# b = 0.?e1
# t = [13.908791234082533 .. 23.000000000000000]
# b = 0.?e1
# t = [13.912021831283547 .. 23.000000000000000]
# b = 0.?e1
# t = [13.916053431744400 .. 23.000000000000000]
# b = 0.?e1
# t = [13.921093047156102 .. 23.000000000000000]
# b = 0.?e1
# t = [13.927405791793480 .. 23.000000000000000]
# b = 0.?e1
# t = [13.935333701237256 .. 23.000000000000000]
# b = 0.?e1
# t = [13.945321992732656 .. 23.000000000000000]
# b = 0.?e1
# t = [13.957956411243308 .. 23.000000000000000]
# b = 0.?e1
# t = [13.974017453164032 .. 23.000000000000000]
# b = 0.?e1
# t = [13.994560874014926 .. 23.000000000000000]
# b = 0.?e1
# t = [14.021040084034140 .. 23.000000000000000]
# b = 0.?e1
# t = [14.055496824342975 .. 23.000000000000000]
# b = 0.?e1
# t = [14.100865407553021 .. 23.000000000000000]
# b = 0.?e1
# t = [14.161468336273387 .. 23.000000000000000]
# b = 0.?e1
# t = [14.243832896240705 .. 23.000000000000000]
# b = 0.?e1
# t = [14.358018064506932 .. 23.000000000000000]
# b = 0.?e1
# t = [14.519589257798251 .. 23.000000000000000]
# b = 0.?e1
# t = [14.751570355247730 .. 23.000000000000000]
# b = 0.?e1
# t = [15.081444988696102 .. 23.000000000000000]
# b = 0.?e1
# t = [15.513977465435893 .. 23.000000000000000]
# b = 0.?e1
# t = [15.954358183804563 .. 23.000000000000000]
# b = 0.?e1
# t = [16.215659156199713 .. 23.000000000000000]
# b = 0.?e1
# t = [16.293219139328115 .. 23.000000000000000]
# b = 0.?e1
# t = [16.308708044089382 .. 23.000000000000000]
# b = 0.?e1
# t = [16.311510501456826 .. 23.000000000000000]
# b = 0.?e1
# t = [16.312008508710842 .. 23.000000000000000]
# b = 0.?e1
# t = [16.312096724549785 .. 23.000000000000000]
# b = 0.?e1
# t = [16.312112342073685 .. 23.000000000000000]
# b = 0.?e1
# found lower bound!
# t = [16.312115106686839 .. 16.475336257753707]
# b = -3.?
# t = [16.312115106686839 .. 16.321702530726953]
# b = -2.2?
# t = [16.312115106686839 .. 16.312158450615471]
# b = -2.1398?
# t = [16.312115700450743 .. 16.312115702201905]
# b = -2.13975805?
# found upper bound!
#   I  = [13.895505967801009 .. 16.312115701331618]
# f(I) = [-1.5390065641572064 .. 2.0000000000000000]
# t = [16.313115701331621 .. 23.000000000000000]
# b = 0.?e1
# t = [16.313938855348048 .. 23.000000000000000]
# b = 0.?e1
# t = [16.315439846514397 .. 23.000000000000000]
# b = 0.?e1
# t = [16.318177437611186 .. 23.000000000000000]
# b = 0.?e1
# t = [16.323172350821334 .. 23.000000000000000]
# b = 0.?e1
# t = [16.332292264515857 .. 23.000000000000000]
# b = 0.?e1
# t = [16.348964410686296 .. 23.000000000000000]
# b = 0.?e1
# t = [16.379508161720860 .. 23.000000000000000]
# b = 0.?e1
# t = [16.435661783547448 .. 23.000000000000000]
# b = 0.?e1
# t = [16.539421574163256 .. 23.000000000000000]
# b = 0.?e1
# t = [16.732022495473056 .. 23.000000000000000]
# b = 0.?e1
# t = [17.086588724416163 .. 23.000000000000000]
# b = 0.?e1
# t = [17.692270644746834 .. 23.000000000000000]
# b = 0.?e1
# t = [18.428871133239567 .. 23.000000000000000]
# b = 0.?e1
# t = [18.721049687298499 .. 23.000000000000000]
# b = 0.?e1
# t = [18.728671453833335 .. 23.000000000000000]
# b = 0.?e1
# t = [18.728725041385068 .. 23.000000000000000]
# b = 0.?e1
# found lower bound!
# t = [18.728725431993339 .. 18.916112686313273]
# b = 2.5?
# t = [18.728725431993339 .. 18.732650445310267]
# b = 2.58?
# t = [18.728725431993339 .. 18.728726723386853]
# b = 2.581043?
# found upper bound!
#   I  = [16.312115701331620 .. 18.728725434862089]
# f(I) = [-2.0000000000000000 .. 0.44752806647569199]
# t = [18.729725434862370 .. 23.000000000000000]
# b = 0.?e1
# t = [18.730718107251330 .. 23.000000000000000]
# b = 0.?e1
# t = [18.732696104663400 .. 23.000000000000000]
# b = 0.?e1
# t = [18.736637233390514 .. 23.000000000000000]
# b = 0.?e1
# t = [18.744488921885938 .. 23.000000000000000]
# b = 0.?e1
# t = [18.760127220247088 .. 23.000000000000000]
# b = 0.?e1
# t = [18.791254364153314 .. 23.000000000000000]
# b = 0.?e1
# t = [18.853106920185766 .. 23.000000000000000]
# b = 0.?e1
# t = [18.975401723849408 .. 23.000000000000000]
# b = 0.?e1
# t = [19.213284317619994 .. 23.000000000000000]
# b = 0.?e1
# t = [19.650466347918250 .. 23.000000000000000]
# b = 0.?e1
# t = [20.311113310496175 .. 23.000000000000000]
# b = 0.?e1
# t = [20.874086807321067 .. 23.000000000000000]
# b = 0.?e1
# t = [21.076234090002284 .. 23.000000000000000]
# b = 0.?e1
# t = [21.131906506823948 .. 23.000000000000000]
# b = 0.?e1
# t = [21.143052795936498 .. 23.000000000000000]
# b = 0.?e1
# t = [21.144959539147528 .. 23.000000000000000]
# b = 0.?e1
# t = [21.145273700692925 .. 23.000000000000000]
# b = 0.?e1
# t = [21.145325119405331 .. 23.000000000000000]
# b = 0.?e1
# found lower bound!
# t = [21.145333525799305 .. 21.356886861057298]
# b = -2.?
# t = [21.145333525799305 .. 21.178130141643156]
# b = -1.7?
# t = [21.145333525799305 .. 21.146159326749360]
# b = -1.73?
# t = [21.145334642169874 .. 21.145335694678011]
# b = -1.72412?
# found upper bound!
#   I  = [18.728725434862369 .. 21.145335168392503]
# f(I) = [-0.86904742842593297 .. 2.0000000000000000]
# t = [21.146335168393363 .. 23.000000000000000]
# b = 0.?e1
# t = [21.147950224465887 .. 23.000000000000000]
# b = 0.?e1
# t = [21.152171367981839 .. 23.000000000000000]
# b = 0.?e1
# t = [21.163190221430028 .. 23.000000000000000]
# b = 0.?e1
# t = [21.191859508979050 .. 23.000000000000000]
# b = 0.?e1
# t = [21.265787843217040 .. 23.000000000000000]
# b = 0.?e1
# t = [21.451567247322728 .. 23.000000000000000]
# b = 0.?e1
# t = [21.881429492549589 .. 23.000000000000000]
# b = 0.?e1
# t = [22.621464190491142 .. 23.000000000000000]
# b = 1.?
# stopping since presumed converged
# t = [22.621464190491142 .. 23.000000000000000], fprime(t) = [0.44459769674724147 .. 1.0636805748532885]

# %%
sigh = to_signal(h, h.derivative(), RIF(5,10))
# Out:
# t = [5.0000000000000000 .. 10.000000000000000]
# b = 0.?e1
# t = [5.3957518036649094 .. 10.000000000000000]
# b = 0.?e1
# t = [5.9100907541399170 .. 10.000000000000000]
# b = 0.?e1
# t = [6.3374501725412635 .. 10.000000000000000]
# b = 0.?e1
# t = [6.4370717951898406 .. 10.000000000000000]
# b = 0.?e1
# t = [6.4451462110556692 .. 10.000000000000000]
# b = 0.?e1
# t = [6.4456447691632448 .. 10.000000000000000]
# b = 0.?e1
# t = [6.4456748400390857 .. 10.000000000000000]
# b = 0.?e1
# found lower bound!
# t = [6.4456766511496752 .. 6.7078030104497213]
# b = 3.?
# t = [6.4456766511496752 .. 6.6490795269096826]
# b = 3.?
# t = [6.4456766511496752 .. 6.6458791055151121]
# b = 3.?
# t = [6.4456766511496752 .. 6.6456888435329633]
# b = 3.?
# t = [6.4456766511496752 .. 6.6456774881255090]
# b = 3.?
# found upper bound!
#   I  = [5.0000000000000000 .. 6.4456766511496753]
# f(I) = [-1.9589242746631386 .. 0.20910474471639976]
# t = [6.6466768102460358 .. 10.000000000000000]
# b = 0.?e1
# t = [6.6476119728139950 .. 10.000000000000000]
# b = 0.?e1
# t = [6.6494218176741570 .. 10.000000000000000]
# b = 0.?e1
# t = [6.6529249766819154 .. 10.000000000000000]
# b = 0.?e1
# t = [6.6597076427873336 .. 10.000000000000000]
# b = 0.?e1
# t = [6.6728468373038296 .. 10.000000000000000]
# b = 0.?e1
# t = [6.6983236833478780 .. 10.000000000000000]
# b = 0.?e1
# t = [6.7477994638531129 .. 10.000000000000000]
# b = 0.?e1
# t = [6.8440669489130590 .. 10.000000000000000]
# b = 0.?e1
# t = [7.0313288918374405 .. 10.000000000000000]
# b = 0.?e1
# t = [7.3898254608035767 .. 10.000000000000000]
# b = 0.?e1
# t = [8.0170865479457074 .. 10.000000000000000]
# b = 0.?e1
# t = [8.6981366938984923 .. 10.000000000000000]
# b = 0.?e1
# t = [8.8531161674792748 .. 10.000000000000000]
# b = 0.?e1
# t = [8.8617013325852482 .. 10.000000000000000]
# b = 0.?e1
# t = [8.8622488015273042 .. 10.000000000000000]
# b = 0.?e1
# t = [8.8622840705895526 .. 10.000000000000000]
# b = 0.?e1
# found lower bound!
# t = [8.8622863440827313 .. 9.1311254925947801]
# b = -2.?
# t = [8.8622863440827313 .. 9.0672197079843180]
# b = -3.?
# t = [8.8622863440827313 .. 9.0625850503964625]
# b = -3.?
# t = [8.8622863440827313 .. 9.0623043381865252]
# b = -3.?
# t = [8.8622863440827313 .. 9.0622875656432580]
# b = -3.?
# found upper bound!
#   I  = [6.6456768102460355 .. 8.8622863440827314]
# f(I) = [1.0462441790703991e-7 .. 2.0000000000000000]
# t = [9.0632865643120368 .. 10.000000000000000]
# b = 0.?e1
# t = [9.0751452034618971 .. 10.000000000000000]
# b = 0.?e1
# t = [9.2274083018831714 .. 10.000000000000000]
# b = 0.?e1
# stopping since presumed converged
# t = [9.2274083018831714 .. 10.000000000000000], fprime(t) = [-2.2959604685799353 .. 0.20499142657861492]

# %%
g(x)
# Out:
# cos(1.60000000000000*x) + sin(x)

# %%
plot(g, (0,23)) + sigg.plot()
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
#plot(g, (8,10)) + to_signal(g, g.derivative(), RIF(8,10)).plot()

# %%
(plot([(lambda x: RIF(h(x)).lower()), h, (lambda x: RIF(h(x)).upper())], 
         xmin=5, xmax=10,
         color=['blue', 'blue', 'blue'],
         linestyle=['--', '-', '--'])
 + sigh.plot())
# Out:
# Graphics object consisting of 5 graphics primitives

# %% [markdown]
# ### Checking some properties

# %%
sigg.G(RIF(0,1))(0)
# Out:
# True

# %%
sigg.G(RIF(0,2))(0)
# Out:
# False

# %%
sigg.F(RIF(0,2))(0)
# Out:
# True

# %%
sigh.G(RIF(7,8))(0)
# Out:
# True

# %%
sigh.G(RIF(6.5,8))(0) is None
# Out:
# True

# %%
sigh.G(RIF(6,8))(0)
# Out:
# False

# %%
sigh.F(RIF(6,8))(0)
# Out:
# True

# %%
sigh.G(RIF(6.5,8)).plot()
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# ### Lower boundary case

# %%
sigh2 = to_signal(h, h.derivative(), RIF(2.25,5))
# Out:
# 0 on lower boundary!
# t = [2.2500000000000000 .. 2.9761175851900324]
# b = 0.?
# t = [2.2500000000000000 .. 2.9608257653471815]
# b = 0.?
# t = [2.2500000000000000 .. 2.9549628506163491]
# b = 0.?
# t = [2.2500000000000000 .. 2.9527184630231478]
# b = 0.?
# t = [2.2500000000000000 .. 2.9518595694989101]
# b = 0.?
# t = [2.2500000000000000 .. 2.9515309124998770]
# b = 0.?
# t = [2.2500000000000000 .. 2.9514051548567446]
# b = 0.?
# t = [2.2500000000000000 .. 2.9513570352974568]
# b = 0.?
# t = [2.2500000000000000 .. 2.9513386230281614]
# b = 0.?
# found upper bound!
# t = [2.9523315778431817 .. 5.0000000000000000]
# b = 0.?e1
# t = [2.9525633406034006 .. 5.0000000000000000]
# b = 0.?e1
# t = [2.9528485828532411 .. 5.0000000000000000]
# b = 0.?e1
# t = [2.9531996444978716 .. 5.0000000000000000]
# b = 0.?e1
# t = [2.9536317124463544 .. 5.0000000000000000]
# b = 0.?e1
# t = [2.9541634772624161 .. 5.0000000000000000]
# b = 0.?e1
# t = [2.9548179411394297 .. 5.0000000000000000]
# b = 0.?e1
# t = [2.9556234119803730 .. 5.0000000000000000]
# b = 0.?e1
# t = [2.9566147262888877 .. 5.0000000000000000]
# b = 0.?e1
# t = [2.9578347532547692 .. 5.0000000000000000]
# b = 0.?e1
# t = [2.9593362441890298 .. 5.0000000000000000]
# b = 0.?e1
# t = [2.9611841057016232 .. 5.0000000000000000]
# b = 0.?e1
# t = [2.9634581920837534 .. 5.0000000000000000]
# b = 0.?e1
# t = [2.9662567325352746 .. 5.0000000000000000]
# b = 0.?e1
# t = [2.9697005321963696 .. 5.0000000000000000]
# b = 0.?e1
# t = [2.9739381118625614 .. 5.0000000000000000]
# b = 0.?e1
# t = [2.9791519780597304 .. 5.0000000000000000]
# b = 0.?e1
# t = [2.9855662387627721 .. 5.0000000000000000]
# b = 0.?e1
# t = [2.9934557918872517 .. 5.0000000000000000]
# b = 0.?e1
# t = [3.0031572967392952 .. 5.0000000000000000]
# b = 0.?e1
# t = [3.0150820602512582 .. 5.0000000000000000]
# b = 0.?e1
# t = [3.0297307692500856 .. 5.0000000000000000]
# b = 0.?e1
# t = [3.0477095667542748 .. 5.0000000000000000]
# b = 0.?e1
# t = [3.0697461098259126 .. 5.0000000000000000]
# b = 0.?e1
# t = [3.0967026307217935 .. 5.0000000000000000]
# b = 0.?e1
# t = [3.1295801367169175 .. 5.0000000000000000]
# b = 0.?e1
# t = [3.1695030209338637 .. 5.0000000000000000]
# b = 0.?e1
# t = [3.2176730539315854 .. 5.0000000000000000]
# b = 0.?e1
# t = [3.2752867184356722 .. 5.0000000000000000]
# b = 0.?e1
# t = [3.3433400735670866 .. 5.0000000000000000]
# b = 0.?e1
# t = [3.4223111797495788 .. 5.0000000000000000]
# b = 0.?e1
# t = [3.5116952152046119 .. 5.0000000000000000]
# b = 0.?e1
# t = [3.6094421050059355 .. 5.0000000000000000]
# b = 0.?e1
# t = [3.7114995553245422 .. 5.0000000000000000]
# b = 0.?e1
# t = [3.8118616749403932 .. 5.0000000000000000]
# b = 0.?e1
# t = [3.9035609923988494 .. 5.0000000000000000]
# b = 0.?e1
# t = [3.9638323727005291 .. 5.0000000000000000]
# b = 0.?e1
# t = [3.9970593360584776 .. 5.0000000000000000]
# b = 0.?e1
# t = [4.0138839017182865 .. 5.0000000000000000]
# b = 0.?e1
# t = [4.0219910332929327 .. 5.0000000000000000]
# b = 0.?e1
# t = [4.0257977676965541 .. 5.0000000000000000]
# b = 0.?e1
# t = [4.0275627464532171 .. 5.0000000000000000]
# b = 0.?e1
# t = [4.0283761865711129 .. 5.0000000000000000]
# b = 0.?e1
# t = [4.0287500402796405 .. 5.0000000000000000]
# b = 0.?e1
# t = [4.0289216410561472 .. 5.0000000000000000]
# b = 0.?e1
# t = [4.0290003601178678 .. 5.0000000000000000]
# b = 0.?e1
# t = [4.0290364613989231 .. 5.0000000000000000]
# b = 0.?e1
# t = [4.0290530157133019 .. 5.0000000000000000]
# b = 0.?e1
# found lower bound!
# t = [4.0290606062933189 .. 4.2350932901772751]
# b = -1.?
# t = [4.0290606062933189 .. 4.2310194711706873]
# b = -1.?
# t = [4.0290606062933189 .. 4.2296973473188384]
# b = -1.?
# t = [4.0290606062933189 .. 4.2292702815909867]
# b = -1.?
# t = [4.0290606062933189 .. 4.2291325470470041]
# b = -1.?
# t = [4.0290606062933189 .. 4.2290881481538874]
# b = -1.?
# t = [4.0290606062933189 .. 4.2290738384479818]
# b = -1.?
# found upper bound!
#   I  = [2.9513315778431814 .. 4.0290606062933190]
# f(I) = [-0.87571164858992268 .. 1.1891152660260849]
# t = [4.2300692266903947 .. 5.0000000000000000]
# b = -1.?e1
# stopping since presumed converged
# t = [4.2300692266903947 .. 5.0000000000000000], fprime(t) = [-2.0638355409693010 .. -0.27731118553772754]

# %%
plot([(lambda x: RIF(h(x)).lower()), h(x), (lambda x: RIF(h(x)).upper())], 
         xmin=2.25, xmax=5,
         color=['blue', 'blue', 'blue'],
         linestyle=['--', '-', '--']) \
    + sigh2.plot()
# Out:
# Graphics object consisting of 5 graphics primitives

# %% [markdown]
# ### Upper boundary case

# %%
sigh3 = to_signal(h, h.derivative(), RIF(0,2.25))
# Out:
# t = [0.00000000000000000 .. 2.2500000000000000]
# b = 0.?e1
# t = [0.40048219618299535 .. 2.2500000000000000]
# b = 0.?e1
# t = [0.80666628697194775 .. 2.2500000000000000]
# b = 0.?e1
# t = [1.0944548276113668 .. 2.2500000000000000]
# b = 0.?e1
# t = [1.2689054005244879 .. 2.2500000000000000]
# b = 0.?e1
# t = [1.3831754879076989 .. 2.2500000000000000]
# b = 0.?e1
# t = [1.4621222102520912 .. 2.2500000000000000]
# b = 0.?e1
# t = [1.5184229329652099 .. 2.2500000000000000]
# b = 0.?e1
# t = [1.5542324571522301 .. 2.2500000000000000]
# b = 0.?e1
# t = [1.5764451024474224 .. 2.2500000000000000]
# b = 0.?e1
# t = [1.5902064450405628 .. 2.2500000000000000]
# b = 0.?e1
# t = [1.5987197742783028 .. 2.2500000000000000]
# b = 0.?e1
# t = [1.6039803648134571 .. 2.2500000000000000]
# b = 0.?e1
# t = [1.6072283233044664 .. 2.2500000000000000]
# b = 0.?e1
# t = [1.6092325450813200 .. 2.2500000000000000]
# b = 0.?e1
# t = [1.6104688488371174 .. 2.2500000000000000]
# b = 0.?e1
# t = [1.6112312886823909 .. 2.2500000000000000]
# b = 0.?e1
# t = [1.6117014250217360 .. 2.2500000000000000]
# b = 0.?e1
# t = [1.6119912950487389 .. 2.2500000000000000]
# b = 0.?e1
# t = [1.6121700091208057 .. 2.2500000000000000]
# b = 0.?e1
# t = [1.6122801882413646 .. 2.2500000000000000]
# b = 0.?e1
# t = [1.6123481133983077 .. 2.2500000000000000]
# b = 0.?e1
# t = [1.6123899885427106 .. 2.2500000000000000]
# b = 0.?e1
# t = [1.6124158039201219 .. 2.2500000000000000]
# b = 0.?e1
# t = [1.6124317186208732 .. 2.2500000000000000]
# b = 0.?e1
# found lower bound!
# t = [1.6124415297081997 .. 1.8182077256008001]
# b = 0.?e1
# t = [1.6124415297081997 .. 1.8154423855154119]
# b = 0.?e1
# t = [1.6124415297081997 .. 1.8139991990583762]
# b = 0.?e1
# t = [1.6124415297081997 .. 1.8132516682090974]
# b = 0.?e1
# t = [1.6124415297081997 .. 1.8128659945361319]
# b = 0.?e1
# t = [1.6124415297081997 .. 1.8126674219797104]
# b = 0.?e1
# t = [1.6124415297081997 .. 1.8125652909623560]
# b = 0.?e1
# t = [1.6124415297081997 .. 1.8125127910439625]
# b = 0.?e1
# t = [1.6124415297081997 .. 1.8124858113256166]
# b = 0.?e1
# t = [1.6124415297081997 .. 1.8124719484485934]
# b = 0.?e1
# found upper bound!
#   I  = [0.00000000000000000 .. 1.6124415297081998]
# f(I) = [-0.97093577853573199 .. 2.0000000000000000]
# t = [1.8134648258734360 .. 2.2500000000000000]
# b = 0.?e1
# t = [1.8141738122330535 .. 2.2500000000000000]
# b = 0.?e1
# t = [1.8153816023547009 .. 2.2500000000000000]
# b = 0.?e1
# t = [1.8174389278337070 .. 2.2500000000000000]
# b = 0.?e1
# t = [1.8209427453944631 .. 2.2500000000000000]
# b = 0.?e1
# t = [1.8269083086505806 .. 2.2500000000000000]
# b = 0.?e1
# t = [1.8370598179067390 .. 2.2500000000000000]
# b = 0.?e1
# t = [1.8543174638406649 .. 2.2500000000000000]
# b = 0.?e1
# t = [1.8835993190882689 .. 2.2500000000000000]
# b = 0.?
# t = [1.9205219549902299 .. 2.2500000000000000]
# b = 0.?
# t = [1.9578397643892053 .. 2.2500000000000000]
# b = 0.?
# t = [1.9927118877604184 .. 2.2500000000000000]
# b = 0.?
# t = [2.0223967828849294 .. 2.2500000000000000]
# b = 0.?
# t = [2.0452077748244028 .. 2.2500000000000000]
# b = 0.?
# t = [2.0610539149349880 .. 2.2500000000000000]
# b = 0.?
# t = [2.0711376273016370 .. 2.2500000000000000]
# b = 0.?
# t = [2.0771394773387976 .. 2.2500000000000000]
# b = 0.?
# t = [2.0805534243393850 .. 2.2500000000000000]
# b = 0.?
# t = [2.0824415227427293 .. 2.2500000000000000]
# b = 0.?
# t = [2.0834687887026270 .. 2.2500000000000000]
# b = 0.?
# t = [2.0840225919824764 .. 2.2500000000000000]
# b = 0.?
# t = [2.0843196514295674 .. 2.2500000000000000]
# b = 0.?
# t = [2.0844785604629714 .. 2.2500000000000000]
# b = 0.?
# t = [2.0845634429412687 .. 2.2500000000000000]
# b = 0.?
# t = [2.0846087480342947 .. 2.2500000000000000]
# b = 0.?
# t = [2.0846329190005614 .. 2.2500000000000000]
# b = 0.?
# t = [2.0846458116991737 .. 2.2500000000000000]
# b = 0.?
# found lower bound!
# 0 on upper boundary!
#   I  = [1.8124648258734359 .. 2.0846526877930756]
# f(I) = [-0.24415746310089182 .. 0.10008226410370503]

# %%
plot([(lambda x: RIF(h(x)).lower()), h(x), (lambda x: RIF(h(x)).upper())], 
         xmin=0, xmax=2.25,
         color=['blue', 'blue', 'blue'],
         linestyle=['--', '-', '--']) \
    + sigh3.plot()
# Out:
# Graphics object consisting of 5 graphics primitives

# %% [markdown]
# ### Dealing with unknown region

# %%
plot([(lambda x: RIF(h(x)).lower()), h, (lambda x: RIF(h(x)).upper())], 
         xmin=1, xmax=3,
         color=['blue', 'blue', 'blue'],
         linestyle=['--', '-', '--'])
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
sigh = to_signal(h, h.derivative(), RIF(1,3.2))
sigh
# Out:
# t = [1.0000000000000000 .. 3.2000000000000002]
# b = 0.?e1
# t = [1.1920970727034831 .. 3.2000000000000002]
# b = 0.?e1
# t = [1.3190778215379983 .. 3.2000000000000002]
# b = 0.?e1
# t = [1.4079357891233952 .. 3.2000000000000002]
# b = 0.?e1
# t = [1.4722792287834118 .. 3.2000000000000002]
# b = 0.?e1
# t = [1.5198676334090330 .. 3.2000000000000002]
# b = 0.?e1
# t = [1.5511625589676349 .. 3.2000000000000002]
# b = 0.?e1
# t = [1.5718296448155086 .. 3.2000000000000002]
# b = 0.?e1
# t = [1.5855091499925435 .. 3.2000000000000002]
# b = 0.?e1
# t = [1.5945751467119761 .. 3.2000000000000002]
# b = 0.?e1
# t = [1.6005880512551775 .. 3.2000000000000002]
# b = 0.?e1
# t = [1.6045778256770379 .. 3.2000000000000002]
# b = 0.?e1
# t = [1.6072259195825011 .. 3.2000000000000002]
# b = 0.?e1
# t = [1.6089838227291088 .. 3.2000000000000002]
# b = 0.?e1
# t = [1.6101509161623586 .. 3.2000000000000002]
# b = 0.?e1
# t = [1.6109258206528156 .. 3.2000000000000002]
# b = 0.?e1
# t = [1.6114403516730770 .. 3.2000000000000002]
# b = 0.?e1
# t = [1.6117820073462891 .. 3.2000000000000002]
# b = 0.?e1
# t = [1.6120088761264970 .. 3.2000000000000002]
# b = 0.?e1
# t = [1.6121595253163600 .. 3.2000000000000002]
# b = 0.?e1
# t = [1.6122595628126323 .. 3.2000000000000002]
# b = 0.?e1
# t = [1.6123259923829764 .. 3.2000000000000002]
# b = 0.?e1
# t = [1.6123701048968970 .. 3.2000000000000002]
# b = 0.?e1
# t = [1.6123993978613435 .. 3.2000000000000002]
# b = 0.?e1
# t = [1.6124188499215235 .. 3.2000000000000002]
# b = 0.?e1
# t = [1.6124317671217525 .. 3.2000000000000002]
# b = 0.?e1
# found lower bound!
# t = [1.6124403448348354 .. 1.8182063904558355]
# b = 0.?e1
# t = [1.6124403448348354 .. 1.8154416908281488]
# b = 0.?e1
# t = [1.6124403448348354 .. 1.8139988411851771]
# b = 0.?e1
# t = [1.6124403448348354 .. 1.8132514848197772]
# b = 0.?e1
# t = [1.6124403448348354 .. 1.8128659008212121]
# b = 0.?e1
# t = [1.6124403448348354 .. 1.8126673741604864]
# b = 0.?e1
# t = [1.6124403448348354 .. 1.8125652665813903]
# b = 0.?e1
# t = [1.6124403448348354 .. 1.8125127786186786]
# b = 0.?e1
# t = [1.6124403448348354 .. 1.8124858049949844]
# b = 0.?e1
# t = [1.6124403448348354 .. 1.8124719452237160]
# b = 0.?e1
# found upper bound!
#   I  = [1.0000000000000000 .. 1.6124403448348355]
# f(I) = [-0.12946433998563467 .. 0.97080047769871126]
# t = [1.8134648242308619 .. 3.2000000000000002]
# b = 0.?e1
# t = [1.8139253159026682 .. 3.2000000000000002]
# b = 0.?e1
# t = [1.8145961203046248 .. 3.2000000000000002]
# b = 0.?e1
# t = [1.8155731140901532 .. 3.2000000000000002]
# b = 0.?e1
# t = [1.8169956831691733 .. 3.2000000000000002]
# b = 0.?e1
# t = [1.8190662421076677 .. 3.2000000000000002]
# b = 0.?e1
# t = [1.8220782525003553 .. 3.2000000000000002]
# b = 0.?e1
# t = [1.8264561395549201 .. 3.2000000000000002]
# b = 0.?e1
# t = [1.8328114979784992 .. 3.2000000000000002]
# b = 0.?e1
# t = [1.8420207617226365 .. 3.2000000000000002]
# b = 0.?e1
# t = [1.8553291921683048 .. 3.2000000000000002]
# b = 0.?e1
# t = [1.8744823188476060 .. 3.2000000000000002]
# b = 0.?e1
# t = [1.8975679654393433 .. 3.2000000000000002]
# b = 0.?e1
# t = [1.9210204127472316 .. 3.2000000000000002]
# b = 0.?e1
# t = [1.9441806018642913 .. 3.2000000000000002]
# b = 0.?e1
# t = [1.9663656709659049 .. 3.2000000000000002]
# b = 0.?e1
# t = [1.9869503069676255 .. 3.2000000000000002]
# b = 0.?e1
# t = [2.0054444103897486 .. 3.2000000000000002]
# b = 0.?e1
# t = [2.0215461489161361 .. 3.2000000000000002]
# b = 0.?e1
# t = [2.0351569361493409 .. 3.2000000000000002]
# b = 0.?e1
# t = [2.0463584618693135 .. 3.2000000000000002]
# b = 0.?e1
# t = [2.0553642034623189 .. 3.2000000000000002]
# b = 0.?e1
# t = [2.0624628292439250 .. 3.2000000000000002]
# b = 0.?e1
# t = [2.0679679902587402 .. 3.2000000000000002]
# b = 0.?e1
# t = [2.0721820722962940 .. 3.2000000000000002]
# b = 0.?e1
# t = [2.0753749615273147 .. 3.2000000000000002]
# b = 0.?e1
# t = [2.0777750141136461 .. 3.2000000000000002]
# b = 0.?e1
# t = [2.0795682084952771 .. 3.2000000000000002]
# b = 0.?e1
# t = [2.0809018678175932 .. 3.2000000000000002]
# b = 0.?e1
# t = [2.0818903517299807 .. 3.2000000000000002]
# b = 0.?e1
# t = [2.0826211210536844 .. 3.2000000000000002]
# b = 0.?e1
# t = [2.0831603376878042 .. 3.2000000000000002]
# b = 0.?e1
# t = [2.0835576510774300 .. 3.2000000000000002]
# b = 0.?e1
# t = [2.0838501000837750 .. 3.2000000000000002]
# b = 0.?e1
# t = [2.0840651964135510 .. 3.2000000000000002]
# b = 0.?e1
# t = [2.0842233102038281 .. 3.2000000000000002]
# b = 0.?e1
# t = [2.0843394886046673 .. 3.2000000000000002]
# b = 0.?e1
# t = [2.0844248276653800 .. 3.2000000000000002]
# b = 0.?e1
# t = [2.0844874995040321 .. 3.2000000000000002]
# b = 0.?e1
# t = [2.0845335172238490 .. 3.2000000000000002]
# b = 0.?e1
# t = [2.0845673023022293 .. 3.2000000000000002]
# b = 0.?e1
# t = [2.0845921042606283 .. 3.2000000000000002]
# b = 0.?e1
# t = [2.0846103104282329 .. 3.2000000000000002]
# b = 0.?e1
# t = [2.0846236742350190 .. 3.2000000000000002]
# b = 0.?e1
# found lower bound!
# t = [2.0846334832746520 .. 2.9572635652822284]
# b = 0.?e1
# t = [2.0846334832746520 .. 2.9540508089486331]
# b = 0.?e1
# t = [2.0846334832746520 .. 2.9525767019846736]
# b = 0.?e1
# t = [2.0846334832746520 .. 2.9519004176074502]
# b = 0.?e1
# t = [2.0846334832746520 .. 2.9515901678432291]
# b = 0.?e1
# t = [2.0846334832746520 .. 2.9514478411820804]
# b = 0.?e1
# t = [2.0846334832746520 .. 2.9513825494880286]
# b = 0.?e1
# t = [2.0846334832746520 .. 2.9513525973225816]
# b = 0.?e1
# t = [2.0846334832746520 .. 2.9513388569696213]
# b = 0.?e1
# found upper bound!
#   I  = [1.8124648242308618 .. 2.0846334832746521]
# f(I) = [-0.24414488901588783 .. 0.10006716139546546]
# t = [2.9523325536799349 .. 3.2000000000000002]
# b = 1.?
# stopping since presumed converged
# t = [2.9523325536799349 .. 3.2000000000000002], fprime(t) = [0.19482466058849867 .. 0.63309887569023249]
# Signal([1.0000000000000000 .. 3.2000000000000002], [([1.0000000000000000 .. 1.6124403448348355], True), ([1.8124648242308618 .. 2.0846334832746521], False), ([2.9513325536799346 .. 3.2000000000000002], True)])

# %%
plot([(lambda x: RIF(h(x)).lower()), h, (lambda x: RIF(h(x)).upper())], 
         xmin=1, xmax=3,
         color=['blue', 'blue', 'blue'],
         linestyle=['--', '-', '--']) + sigh.plot()
# Out:
# Graphics object consisting of 5 graphics primitives

# %%
sigh = to_signal(h, h.derivative(), RIF(0,40))
# Out:
# t = [0.00000000000000000 .. 40.000000000000000]
# b = 0.?e1
# t = [0.36509054541632340 .. 40.000000000000000]
# b = 0.?e1
# t = [0.74024120745358656 .. 40.000000000000000]
# b = 0.?e1
# t = [1.0251749022054170 .. 40.000000000000000]
# b = 0.?e1
# t = [1.2079034804965527 .. 40.000000000000000]
# b = 0.?e1
# t = [1.3250742365150449 .. 40.000000000000000]
# b = 0.?e1
# t = [1.4043319534612694 .. 40.000000000000000]
# b = 0.?e1
# t = [1.4607936626530344 .. 40.000000000000000]
# b = 0.?e1
# t = [1.5027034087530406 .. 40.000000000000000]
# b = 0.?e1
# t = [1.5323622589438592 .. 40.000000000000000]
# b = 0.?e1
# t = [1.5533552029330246 .. 40.000000000000000]
# b = 0.?e1
# t = [1.5684995404121846 .. 40.000000000000000]
# b = 0.?e1
# t = [1.5795752003097356 .. 40.000000000000000]
# b = 0.?e1
# t = [1.5877564659304628 .. 40.000000000000000]
# b = 0.?e1
# t = [1.5938442727884707 .. 40.000000000000000]
# b = 0.?e1
# t = [1.5983990606512259 .. 40.000000000000000]
# b = 0.?e1
# t = [1.6018207643632873 .. 40.000000000000000]
# b = 0.?e1
# t = [1.6043991133209603 .. 40.000000000000000]
# b = 0.?e1
# t = [1.6063464366342736 .. 40.000000000000000]
# b = 0.?e1
# t = [1.6078197212984304 .. 40.000000000000000]
# b = 0.?e1
# t = [1.6089358233779140 .. 40.000000000000000]
# b = 0.?e1
# t = [1.6097821766394202 .. 40.000000000000000]
# b = 0.?e1
# t = [1.6104244585990248 .. 40.000000000000000]
# b = 0.?e1
# t = [1.6109121524755225 .. 40.000000000000000]
# b = 0.?e1
# t = [1.6112826256599257 .. 40.000000000000000]
# b = 0.?e1
# t = [1.6115641454676483 .. 40.000000000000000]
# b = 0.?e1
# t = [1.6117781236809736 .. 40.000000000000000]
# b = 0.?e1
# t = [1.6119407955868363 .. 40.000000000000000]
# b = 0.?e1
# t = [1.6120644809156825 .. 40.000000000000000]
# b = 0.?e1
# t = [1.6121585336533794 .. 40.000000000000000]
# b = 0.?e1
# t = [1.6122300591537037 .. 40.000000000000000]
# b = 0.?e1
# t = [1.6122844565236640 .. 40.000000000000000]
# b = 0.?e1
# t = [1.6123258294120681 .. 40.000000000000000]
# b = 0.?e1
# t = [1.6123572974530731 .. 40.000000000000000]
# b = 0.?e1
# t = [1.6123812325773341 .. 40.000000000000000]
# b = 0.?e1
# t = [1.6123994384239350 .. 40.000000000000000]
# b = 0.?e1
# t = [1.6124132866160489 .. 40.000000000000000]
# b = 0.?e1
# t = [1.6124238203079384 .. 40.000000000000000]
# b = 0.?e1
# found lower bound!
# t = [1.6124318328845883 .. 1.8181967989772417]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8154367003222416]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8139962702765609]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8132501673642024]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8128652275712199]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8126670306211453]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8125650914227518]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8125126893510700]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8124857595127580]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8124719220543053]
# b = 0.?e1
# found upper bound!
#   I  = [0.00000000000000000 .. 1.6124318328845884]
# f(I) = [-0.97093206507591290 .. 2.0000000000000000]
# t = [1.8134648124294490 .. 40.000000000000000]
# b = 0.?e1
# t = [1.8137056301451326 .. 40.000000000000000]
# b = 0.?e1
# t = [1.8140039210021066 .. 40.000000000000000]
# b = 0.?e1
# t = [1.8143733545521394 .. 40.000000000000000]
# b = 0.?e1
# t = [1.8148308264606702 .. 40.000000000000000]
# b = 0.?e1
# t = [1.8153972064670456 .. 40.000000000000000]
# b = 0.?e1
# t = [1.8160982525513946 .. 40.000000000000000]
# b = 0.?e1
# t = [1.8169657243392751 .. 40.000000000000000]
# b = 0.?e1
# t = [1.8180387331647240 .. 40.000000000000000]
# b = 0.?e1
# t = [1.8193653698570209 .. 40.000000000000000]
# b = 0.?e1
# t = [1.8210046531546928 .. 40.000000000000000]
# b = 0.?e1
# t = [1.8230288399622334 .. 40.000000000000000]
# b = 0.?e1
# t = [1.8255261307587633 .. 40.000000000000000]
# b = 0.?e1
# t = [1.8286037852574730 .. 40.000000000000000]
# b = 0.?e1
# t = [1.8323916288883004 .. 40.000000000000000]
# b = 0.?e1
# t = [1.8370458712959294 .. 40.000000000000000]
# b = 0.?e1
# t = [1.8427530622174672 .. 40.000000000000000]
# b = 0.?e1
# t = [1.8497338630568249 .. 40.000000000000000]
# b = 0.?e1
# t = [1.8582460972287144 .. 40.000000000000000]
# b = 0.?e1
# t = [1.8685862430783848 .. 40.000000000000000]
# b = 0.?e1
# t = [1.8800899232020951 .. 40.000000000000000]
# b = 0.?e1
# t = [1.8916671921104244 .. 40.000000000000000]
# b = 0.?e1
# t = [1.9032382040130833 .. 40.000000000000000]
# b = 0.?e1
# t = [1.9147227448009103 .. 40.000000000000000]
# b = 0.?e1
# t = [1.9260424849981561 .. 40.000000000000000]
# b = 0.?e1
# t = [1.9371231439498821 .. 40.000000000000000]
# b = 0.?e1
# t = [1.9478964368680382 .. 40.000000000000000]
# b = 0.?e1
# t = [1.9583016967326443 .. 40.000000000000000]
# b = 0.?e1
# t = [1.9682870936195020 .. 40.000000000000000]
# b = 0.?e1
# t = [1.9778104103938365 .. 40.000000000000000]
# b = 0.?e1
# t = [1.9868393709061944 .. 40.000000000000000]
# b = 0.?e1
# t = [1.9953515502773411 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0033339231280060 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0107821228115199 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0176994925371078 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0240960087266017 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0299871498761921 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0353927728084162 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0403360446553451 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0448424650313072 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0489389999718503 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0526533381716207 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0560132712405470 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0590461931654449 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0617787097317576 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0642363460151673 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0664433388309677 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0684225008694152 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0701951438239980 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0717810488664869 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0731984741256885 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0744641902286842 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0755935363542370 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0766004905568049 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0774977493047539 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0782968122182827 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0790080688867105 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0796408853965333 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0802036888222743 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0807040484359764 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0811487527936458 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0815438821731890 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0818948760826572 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0822065957426429 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0824833815837142 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0827291058983599 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0829472208551775 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0831408021276294 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0833125884161227 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0834650171548609 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0836002566974247 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0837202352701700 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0838266669724903 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0839210750894756 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0840048129668158 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0840790826809367 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0841449517200296 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0842033678744003 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0842551725177762 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0843011124451269 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0843418504173594 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0843779745490231 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0844100066619439 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0844384097155326 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0844635944133420 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0844859250752443 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0845057248553282 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0845232803772186 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0845388458509090 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0845526467283663 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0845648829489951 .. 40.000000000000000]
# b = 0.?e1
# t = [2.0845757318205166 .. 40.000000000000000]
# b = 0.?e1
# found lower bound!
# t = [2.0845853505758618 .. 2.9571953803684670]
# b = 0.?e1
# t = [2.0845853505758618 .. 2.9540196408812643]
# b = 0.?e1
# t = [2.0845853505758618 .. 2.9525624574909211]
# b = 0.?e1
# t = [2.0845853505758618 .. 2.9518939080587612]
# b = 0.?e1
# t = [2.0845853505758618 .. 2.9515871931802882]
# b = 0.?e1
# t = [2.0845853505758618 .. 2.9514464818873934]
# b = 0.?e1
# t = [2.0845853505758618 .. 2.9513819283604202]
# b = 0.?e1
# t = [2.0845853505758618 .. 2.9513523135042750]
# b = 0.?e1
# t = [2.0845853505758618 .. 2.9513387272837255]
# b = 0.?e1
# found upper bound!
#   I  = [1.8124648124294489 .. 2.0845853505758619]
# f(I) = [-0.24411337554032309 .. 0.10002931460408604]
# t = [2.9523324944231594 .. 40.000000000000000]
# b = 0.?e1
# t = [2.9525644686858822 .. 40.000000000000000]
# b = 0.?e1
# t = [2.9528499712409392 .. 40.000000000000000]
# b = 0.?e1
# t = [2.9532013532532928 .. 40.000000000000000]
# b = 0.?e1
# t = [2.9536338154890007 .. 40.000000000000000]
# b = 0.?e1
# t = [2.9541660655646264 .. 40.000000000000000]
# b = 0.?e1
# t = [2.9548211266585462 .. 40.000000000000000]
# b = 0.?e1
# t = [2.9556273324963489 .. 40.000000000000000]
# b = 0.?e1
# t = [2.9566195513549127 .. 40.000000000000000]
# b = 0.?e1
# t = [2.9578406915153512 .. 40.000000000000000]
# b = 0.?e1
# t = [2.9593435523768576 .. 40.000000000000000]
# b = 0.?e1
# t = [2.9611930996930806 .. 40.000000000000000]
# b = 0.?e1
# t = [2.9634692604746564 .. 40.000000000000000]
# b = 0.?e1
# t = [2.9662703532941123 .. 40.000000000000000]
# b = 0.?e1
# t = [2.9697172930612185 .. 40.000000000000000]
# b = 0.?e1
# t = [2.9739587352655565 .. 40.000000000000000]
# b = 0.?e1
# t = [2.9791773514778796 .. 40.000000000000000]
# b = 0.?e1
# t = [2.9855974514802858 .. 40.000000000000000]
# b = 0.?e1
# t = [2.9934941791599185 .. 40.000000000000000]
# b = 0.?e1
# t = [3.0032044921733547 .. 40.000000000000000]
# b = 0.?e1
# t = [3.0151400566540815 .. 40.000000000000000]
# b = 0.?e1
# t = [3.0298019869209733 .. 40.000000000000000]
# b = 0.?e1
# t = [3.0477969255208909 .. 40.000000000000000]
# b = 0.?e1
# t = [3.0698530959869883 .. 40.000000000000000]
# b = 0.?e1
# t = [3.0968333406095718 .. 40.000000000000000]
# b = 0.?e1
# t = [3.1297392621184392 .. 40.000000000000000]
# b = 0.?e1
# t = [3.1696957147576370 .. 40.000000000000000]
# b = 0.?e1
# t = [3.2178973595804167 .. 40.000000000000000]
# b = 0.?e1
# t = [3.2754890392409019 .. 40.000000000000000]
# b = 0.?e1
# t = [3.3433428352372693 .. 40.000000000000000]
# b = 0.?e1
# t = [3.4216982923308929 .. 40.000000000000000]
# b = 0.?e1
# t = [3.5096730341813078 .. 40.000000000000000]
# b = 0.?e1
# t = [3.6047606109164425 .. 40.000000000000000]
# b = 0.?e1
# t = [3.7026053134973579 .. 40.000000000000000]
# b = 0.?e1
# t = [3.7974467062719181 .. 40.000000000000000]
# b = 0.?e1
# t = [3.8833948447880985 .. 40.000000000000000]
# b = 0.?e1
# t = [3.9450224300807770 .. 40.000000000000000]
# b = 0.?e1
# t = [3.9821174598652824 .. 40.000000000000000]
# b = 0.?e1
# t = [4.0033351575572497 .. 40.000000000000000]
# b = 0.?e1
# t = [4.0151149189322685 .. 40.000000000000000]
# b = 0.?e1
# t = [4.0215466713824259 .. 40.000000000000000]
# b = 0.?e1
# t = [4.0250264703731613 .. 40.000000000000000]
# b = 0.?e1
# t = [4.0268998669490647 .. 40.000000000000000]
# b = 0.?e1
# t = [4.0279057504095954 .. 40.000000000000000]
# b = 0.?e1
# t = [4.0284450671842151 .. 40.000000000000000]
# b = 0.?e1
# t = [4.0287340066303025 .. 40.000000000000000]
# b = 0.?e1
# t = [4.0288887425499568 .. 40.000000000000000]
# b = 0.?e1
# t = [4.0289715901239411 .. 40.000000000000000]
# b = 0.?e1
# t = [4.0290159425354552 .. 40.000000000000000]
# b = 0.?e1
# t = [4.0290396850801322 .. 40.000000000000000]
# b = 0.?e1
# t = [4.0290523944088629 .. 40.000000000000000]
# b = 0.?e1
# found lower bound!
# t = [4.0290591975597873 .. 4.2350918095841737]
# b = -1.?
# t = [4.0290591975597873 .. 4.2310189914514736]
# b = -1.?
# t = [4.0290591975597873 .. 4.2296971929897512]
# b = -1.?
# t = [4.0290591975597873 .. 4.2292702320602658]
# b = -1.?
# t = [4.0290591975597873 .. 4.2291325311631125]
# b = -1.?
# t = [4.0290591975597873 .. 4.2290881430615235]
# b = -1.?
# t = [4.0290591975597873 .. 4.2290738368155508]
# b = -1.?
# found upper bound!
#   I  = [2.9513324944231591 .. 4.0290591975597874]
# f(I) = [-0.87570952745154241 .. 1.1891143659858095]
# t = [4.2300692261671244 .. 40.000000000000000]
# b = 0.?e1
# t = [4.2305352348894107 .. 40.000000000000000]
# b = 0.?e1
# t = [4.2312181141431199 .. 40.000000000000000]
# b = 0.?e1
# t = [4.2322189987078262 .. 40.000000000000000]
# b = 0.?e1
# t = [4.2336864242035439 .. 40.000000000000000]
# b = 0.?e1
# t = [4.2358388153836123 .. 40.000000000000000]
# b = 0.?e1
# t = [4.2389979532648807 .. 40.000000000000000]
# b = 0.?e1
# t = [4.2436391302087699 .. 40.000000000000000]
# b = 0.?e1
# t = [4.2504670547540079 .. 40.000000000000000]
# b = 0.?e1
# t = [4.2605322874614000 .. 40.000000000000000]
# b = 0.?e1
# t = [4.2754131110009403 .. 40.000000000000000]
# b = 0.?e1
# t = [4.2975063115889868 .. 40.000000000000000]
# b = 0.?e1
# t = [4.3305054880499449 .. 40.000000000000000]
# b = 0.?e1
# t = [4.3802130198386945 .. 40.000000000000000]
# b = 0.?e1
# t = [4.4559586815745539 .. 40.000000000000000]
# b = 0.?e1
# t = [4.5731046592080932 .. 40.000000000000000]
# b = 0.?e1
# t = [4.7572365328168499 .. 40.000000000000000]
# b = 0.?e1
# t = [5.0380588603631730 .. 40.000000000000000]
# b = 0.?e1
# t = [5.4497616593030393 .. 40.000000000000000]
# b = 0.?e1
# t = [5.9703062777299180 .. 40.000000000000000]
# b = 0.?e1
# t = [6.3603368086293015 .. 40.000000000000000]
# b = 0.?e1
# t = [6.4391682809356316 .. 40.000000000000000]
# b = 0.?e1
# t = [6.4452492308028954 .. 40.000000000000000]
# b = 0.?e1
# t = [6.4456489648180514 .. 40.000000000000000]
# b = 0.?e1
# t = [6.4456749604231040 .. 40.000000000000000]
# b = 0.?e1
# found lower bound!
# t = [6.4456766497970825 .. 6.7078030090422081]
# b = 3.?
# t = [6.4456766497970825 .. 6.6490795268435426]
# b = 3.?
# t = [6.4456766497970825 .. 6.6458791055114670]
# b = 3.?
# t = [6.4456766497970825 .. 6.6456888435327617]
# b = 3.?
# t = [6.4456766497970825 .. 6.6456774881254984]
# b = 3.?
# found upper bound!
#   I  = [4.2290692261671241 .. 6.4456766497970826]
# f(I) = [-2.0000000000000000 .. 1.2400591726677004]
# t = [6.6466768102460349 .. 40.000000000000000]
# b = 0.?e1
# t = [6.6476119728139932 .. 40.000000000000000]
# b = 0.?e1
# t = [6.6494218176741535 .. 40.000000000000000]
# b = 0.?e1
# t = [6.6529249766819091 .. 40.000000000000000]
# b = 0.?e1
# t = [6.6597076427873220 .. 40.000000000000000]
# b = 0.?e1
# t = [6.6728468373038074 .. 40.000000000000000]
# b = 0.?e1
# t = [6.6983236833478354 .. 40.000000000000000]
# b = 0.?e1
# t = [6.7477994638530303 .. 40.000000000000000]
# b = 0.?e1
# t = [6.8440669489128991 .. 40.000000000000000]
# b = 0.?e1
# t = [7.0313288918371306 .. 40.000000000000000]
# b = 0.?e1
# t = [7.3898254608029949 .. 40.000000000000000]
# b = 0.?e1
# t = [8.0170865479447837 .. 40.000000000000000]
# b = 0.?e1
# t = [8.6981366938980055 .. 40.000000000000000]
# b = 0.?e1
# t = [8.8531161674792482 .. 40.000000000000000]
# b = 0.?e1
# t = [8.8616992884104632 .. 40.000000000000000]
# b = 0.?e1
# t = [8.8622483780967158 .. 40.000000000000000]
# b = 0.?e1
# t = [8.8622840235417932 .. 40.000000000000000]
# b = 0.?e1
# found lower bound!
# t = [8.8622863397628073 .. 9.1311254881439581]
# b = -2.?
# t = [8.8622863397628073 .. 9.0672197076212485]
# b = -3.?
# t = [8.8622863397628073 .. 9.0625850503750325]
# b = -3.?
# t = [8.8622863397628073 .. 9.0623043381852942]
# b = -3.?
# t = [8.8622863397628073 .. 9.0622875656431888]
# b = -3.?
# found upper bound!
#   I  = [6.6456768102460346 .. 8.8622863397628074]
# f(I) = [1.0462441540903810e-7 .. 2.0000000000000000]
# t = [9.0632865643120332 .. 40.000000000000000]
# b = 0.?e1
# t = [9.0642215332953419 .. 40.000000000000000]
# b = 0.?e1
# t = [9.0660304196227663 .. 40.000000000000000]
# b = 0.?e1
# t = [9.0695295374255735 .. 40.000000000000000]
# b = 0.?e1
# t = [9.0762961974599267 .. 40.000000000000000]
# b = 0.?e1
# t = [9.0893737731555290 .. 40.000000000000000]
# b = 0.?e1
# t = [9.1146167056461759 .. 40.000000000000000]
# b = 0.?e1
# t = [9.1632114564918385 .. 40.000000000000000]
# b = 0.?e1
# t = [9.2561839827524590 .. 40.000000000000000]
# b = 0.?e1
# t = [9.4313090081085366 .. 40.000000000000000]
# b = 0.?e1
# t = [9.7473266537234497 .. 40.000000000000000]
# b = 0.?e1
# t = [10.245588340283594 .. 40.000000000000000]
# b = 0.?e1
# t = [10.733205713068871 .. 40.000000000000000]
# b = 0.?e1
# t = [11.022839138470409 .. 40.000000000000000]
# b = 0.?e1
# t = [11.156384785554303 .. 40.000000000000000]
# b = 0.?e1
# t = [11.217009251810736 .. 40.000000000000000]
# b = 0.?e1
# t = [11.246749832189516 .. 40.000000000000000]
# b = 0.?e1
# t = [11.261958390219456 .. 40.000000000000000]
# b = 0.?e1
# t = [11.269905263375644 .. 40.000000000000000]
# b = 0.?e1
# t = [11.274104938469966 .. 40.000000000000000]
# b = 0.?e1
# t = [11.276337646008778 .. 40.000000000000000]
# b = 0.?e1
# t = [11.277528417673428 .. 40.000000000000000]
# b = 0.?e1
# t = [11.278164570338189 .. 40.000000000000000]
# b = 0.?e1
# t = [11.278504733666064 .. 40.000000000000000]
# b = 0.?e1
# t = [11.278686713774533 .. 40.000000000000000]
# b = 0.?e1
# t = [11.278784094463730 .. 40.000000000000000]
# b = 0.?e1
# t = [11.278836211770654 .. 40.000000000000000]
# b = 0.?e1
# t = [11.278864106574106 .. 40.000000000000000]
# b = 0.?e1
# t = [11.278879037333219 .. 40.000000000000000]
# b = 0.?e1
# found lower bound!
# t = [11.278887029226972 .. 11.505793658514432]
# b = 1.?
# t = [11.278887029226972 .. 11.488054436943373]
# b = 1.?
# t = [11.278887029226972 .. 11.481904787988150]
# b = 1.?
# t = [11.278887029226972 .. 11.479871994434291]
# b = 1.?
# t = [11.278887029226972 .. 11.479211349686720]
# b = 1.?
# t = [11.278887029226972 .. 11.478997856788541]
# b = 1.?
# t = [11.278887029226972 .. 11.478928992023409]
# b = 1.?
# t = [11.278887029226972 .. 11.478906792107607]
# b = 1.?
# found upper bound!
#   I  = [9.0622865643120320 .. 11.278887029226973]
# f(I) = [-2.0000000000000000 .. 1.2400540086834635]
# t = [11.479899636905766 .. 40.000000000000000]
# b = 0.?e1
# t = [11.480365673760411 .. 40.000000000000000]
# b = 0.?e1
# t = [11.481047982283110 .. 40.000000000000000]
# b = 0.?e1
# t = [11.482046718030678 .. 40.000000000000000]
# b = 0.?e1
# t = [11.483508179507003 .. 40.000000000000000]
# b = 0.?e1
# t = [11.485645792365163 .. 40.000000000000000]
# b = 0.?e1
# t = [11.488770320404869 .. 40.000000000000000]
# b = 0.?e1
# t = [11.493332992692916 .. 40.000000000000000]
# b = 0.?e1
# t = [11.499986271491950 .. 40.000000000000000]
# b = 0.?e1
# t = [11.509667739571975 .. 40.000000000000000]
# b = 0.?e1
# t = [11.523712091305091 .. 40.000000000000000]
# b = 0.?e1
# t = [11.543992193775300 .. 40.000000000000000]
# b = 0.?e1
# t = [11.573077721715435 .. 40.000000000000000]
# b = 0.?e1
# t = [11.614369301842609 .. 40.000000000000000]
# b = 0.?e1
# t = [11.672101385042958 .. 40.000000000000000]
# b = 0.?e1
# t = [11.750991707799116 .. 40.000000000000000]
# b = 0.?e1
# t = [11.841469323892789 .. 40.000000000000000]
# b = 0.?e1
# t = [11.938134541827770 .. 40.000000000000000]
# b = 0.?e1
# t = [12.035593783823172 .. 40.000000000000000]
# b = 0.?e1
# t = [12.128173091779050 .. 40.000000000000000]
# b = 0.?e1
# t = [12.211361123319079 .. 40.000000000000000]
# b = 0.?e1
# t = [12.282679581382472 .. 40.000000000000000]
# b = 0.?e1
# t = [12.341649287776746 .. 40.000000000000000]
# b = 0.?e1
# t = [12.389168128653546 .. 40.000000000000000]
# b = 0.?e1
# t = [12.426803442817915 .. 40.000000000000000]
# b = 0.?e1
# t = [12.456281217981324 .. 40.000000000000000]
# b = 0.?e1
# t = [12.479209343636579 .. 40.000000000000000]
# b = 0.?e1
# t = [12.496966694162507 .. 40.000000000000000]
# b = 0.?e1
# t = [12.510683370069605 .. 40.000000000000000]
# b = 0.?e1
# t = [12.521261920155813 .. 40.000000000000000]
# b = 0.?e1
# t = [12.529412359970345 .. 40.000000000000000]
# b = 0.?e1
# t = [12.535688286409527 .. 40.000000000000000]
# b = 0.?e1
# t = [12.540519052826223 .. 40.000000000000000]
# b = 0.?e1
# t = [12.544236595864433 .. 40.000000000000000]
# b = 0.?e1
# t = [12.547097047026481 .. 40.000000000000000]
# b = 0.?e1
# t = [12.549297814663729 .. 40.000000000000000]
# b = 0.?e1
# t = [12.550990939203744 .. 40.000000000000000]
# b = 0.?e1
# t = [12.552293468122661 .. 40.000000000000000]
# b = 0.?e1
# t = [12.553295485125971 .. 40.000000000000000]
# b = 0.?e1
# t = [12.554066309728275 .. 40.000000000000000]
# b = 0.?e1
# t = [12.554659277492993 .. 40.000000000000000]
# b = 0.?e1
# t = [12.555115422733939 .. 40.000000000000000]
# b = 0.?e1
# t = [12.555466314170001 .. 40.000000000000000]
# b = 0.?e1
# t = [12.555736237632940 .. 40.000000000000000]
# b = 0.?e1
# t = [12.555943875821707 .. 40.000000000000000]
# b = 0.?e1
# t = [12.556103600819790 .. 40.000000000000000]
# b = 0.?e1
# t = [12.556226468556440 .. 40.000000000000000]
# b = 0.?e1
# t = [12.556320983897785 .. 40.000000000000000]
# b = 0.?e1
# t = [12.556393689247384 .. 40.000000000000000]
# b = 0.?e1
# t = [12.556449617356079 .. 40.000000000000000]
# b = 0.?e1
# t = [12.556492639661243 .. 40.000000000000000]
# b = 0.?e1
# t = [12.556525734254686 .. 40.000000000000000]
# b = 0.?e1
# t = [12.556551192020952 .. 40.000000000000000]
# b = 0.?e1
# t = [12.556570775211090 .. 40.000000000000000]
# b = 0.?e1
# t = [12.556585839426279 .. 40.000000000000000]
# b = 0.?e1
# t = [12.556597427453938 .. 40.000000000000000]
# b = 0.?e1
# found lower bound!
# t = [12.556606341451093 .. 13.463102914681845]
# b = 0.?e1
# t = [12.556606341451093 .. 13.453792238638883]
# b = 0.?e1
# t = [12.556606341451093 .. 13.446433610867788]
# b = 0.?e1
# t = [12.556606341451093 .. 13.440714403492537]
# b = 0.?e1
# t = [12.556606341451093 .. 13.436328912517132]
# b = 0.?e1
# t = [12.556606341451093 .. 13.433001676027641]
# b = 0.?e1
# t = [12.556606341451093 .. 13.430498047051883]
# b = 0.?e1
# t = [12.556606341451093 .. 13.428625994082222]
# b = 0.?e1
# t = [12.556606341451093 .. 13.427232859765165]
# b = 0.?e1
# t = [12.556606341451093 .. 13.426199836110986]
# b = 0.?e1
# t = [12.556606341451093 .. 13.425435887111773]
# b = 0.?e1
# t = [12.556606341451093 .. 13.424872049923709]
# b = 0.?e1
# t = [12.556606341451093 .. 13.424456519975209]
# b = 0.?e1
# t = [12.556606341451093 .. 13.424150621457527]
# b = 0.?e1
# t = [12.556606341451093 .. 13.423925610823999]
# b = 0.?e1
# t = [12.556606341451093 .. 13.423760197184068]
# b = 0.?e1
# t = [12.556606341451093 .. 13.423638648529778]
# b = 0.?e1
# t = [12.556606341451093 .. 13.423549361234054]
# b = 0.?e1
# t = [12.556606341451093 .. 13.423483787973856]
# b = 0.?e1
# t = [12.556606341451093 .. 13.423435638822137]
# b = 0.?e1
# t = [12.556606341451093 .. 13.423400288348635]
# b = 0.?e1
# t = [12.556606341451093 .. 13.423374336921672]
# b = 0.?e1
# t = [12.556606341451093 .. 13.423355286813371]
# b = 0.?e1
# t = [12.556606341451093 .. 13.423341303445734]
# b = 0.?e1
# t = [12.556606341451093 .. 13.423331039601769]
# b = 0.?e1
# found upper bound!
#   I  = [11.478899636905765 .. 12.556606341451094]
# f(I) = [-0.87567249835937389 .. 1.1890903747297701]
# t = [13.424323506106563 .. 40.000000000000000]
# b = 0.?e1
# t = [13.424439024955324 .. 40.000000000000000]
# b = 0.?e1
# t = [13.424567582395479 .. 40.000000000000000]
# b = 0.?e1
# t = [13.424710641882379 .. 40.000000000000000]
# b = 0.?e1
# t = [13.424869829167361 .. 40.000000000000000]
# b = 0.?e1
# t = [13.425046949826398 .. 40.000000000000000]
# b = 0.?e1
# t = [13.425244008568860 .. 40.000000000000000]
# b = 0.?e1
# t = [13.425463230479556 .. 40.000000000000000]
# b = 0.?e1
# t = [13.425707084353316 .. 40.000000000000000]
# b = 0.?e1
# t = [13.425978308285637 .. 40.000000000000000]
# b = 0.?e1
# t = [13.426279937684586 .. 40.000000000000000]
# b = 0.?e1
# t = [13.426615335867241 .. 40.000000000000000]
# b = 0.?e1
# t = [13.426988227397325 .. 40.000000000000000]
# b = 0.?e1
# t = [13.427402734307788 .. 40.000000000000000]
# b = 0.?e1
# t = [13.427863415331216 .. 40.000000000000000]
# b = 0.?e1
# t = [13.428375308229767 .. 40.000000000000000]
# b = 0.?e1
# t = [13.428943975272344 .. 40.000000000000000]
# b = 0.?e1
# t = [13.429575551846504 .. 40.000000000000000]
# b = 0.?e1
# t = [13.430276798112624 .. 40.000000000000000]
# b = 0.?e1
# t = [13.431055153503480 .. 40.000000000000000]
# b = 0.?e1
# t = [13.431918793738523 .. 40.000000000000000]
# b = 0.?e1
# t = [13.432876689853001 .. 40.000000000000000]
# b = 0.?e1
# t = [13.433938668530917 .. 40.000000000000000]
# b = 0.?e1
# t = [13.435115472770560 .. 40.000000000000000]
# b = 0.?e1
# t = [13.436418821594315 .. 40.000000000000000]
# b = 0.?e1
# t = [13.437861467132933 .. 40.000000000000000]
# b = 0.?e1
# t = [13.439457246960989 .. 40.000000000000000]
# b = 0.?e1
# t = [13.441221129028923 .. 40.000000000000000]
# b = 0.?e1
# t = [13.443169245923654 .. 40.000000000000000]
# b = 0.?e1
# t = [13.445318914494572 .. 40.000000000000000]
# b = 0.?e1
# t = [13.447688636110207 .. 40.000000000000000]
# b = 0.?e1
# t = [13.450298071977501 .. 40.000000000000000]
# b = 0.?e1
# t = [13.453167987086304 .. 40.000000000000000]
# b = 0.?e1
# t = [13.456320155478124 .. 40.000000000000000]
# b = 0.?e1
# t = [13.459777218742031 .. 40.000000000000000]
# b = 0.?e1
# t = [13.463562488998562 .. 40.000000000000000]
# b = 0.?e1
# t = [13.467699687260022 .. 40.000000000000000]
# b = 0.?e1
# t = [13.472212608100843 .. 40.000000000000000]
# b = 0.?e1
# t = [13.477124702215595 .. 40.000000000000000]
# b = 0.?e1
# t = [13.482458569895197 .. 40.000000000000000]
# b = 0.?e1
# t = [13.488235360943123 .. 40.000000000000000]
# b = 0.?e1
# t = [13.494474080311636 .. 40.000000000000000]
# b = 0.?e1
# t = [13.501190803959248 .. 40.000000000000000]
# b = 0.?e1
# t = [13.508397816233191 .. 40.000000000000000]
# b = 0.?e1
# t = [13.516102688445425 .. 40.000000000000000]
# b = 0.?e1
# t = [13.524307328011884 .. 40.000000000000000]
# b = 0.?e1
# t = [13.533007038058340 .. 40.000000000000000]
# b = 0.?e1
# t = [13.542189637922399 .. 40.000000000000000]
# b = 0.?e1
# t = [13.551834704301143 .. 40.000000000000000]
# b = 0.?e1
# t = [13.561912999388804 .. 40.000000000000000]
# b = 0.?e1
# t = [13.572386154506029 .. 40.000000000000000]
# b = 0.?e1
# t = [13.583206673763754 .. 40.000000000000000]
# b = 0.?e1
# t = [13.594318310913891 .. 40.000000000000000]
# b = 0.?e1
# t = [13.605656853144283 .. 40.000000000000000]
# b = 0.?e1
# t = [13.617151318715752 .. 40.000000000000000]
# b = 0.?e1
# t = [13.628725542903017 .. 40.000000000000000]
# b = 0.?e1
# t = [13.640300091927079 .. 40.000000000000000]
# b = 0.?e1
# t = [13.651794411723702 .. 40.000000000000000]
# b = 0.?e1
# t = [13.661692505759273 .. 40.000000000000000]
# b = 0.?e1
# t = [13.669448649919731 .. 40.000000000000000]
# b = 0.?e1
# t = [13.675485454929253 .. 40.000000000000000]
# b = 0.?e1
# t = [13.680159311697124 .. 40.000000000000000]
# b = 0.?e1
# t = [13.683763126311289 .. 40.000000000000000]
# b = 0.?e1
# t = [13.686533081068915 .. 40.000000000000000]
# b = 0.?e1
# t = [13.688656925558232 .. 40.000000000000000]
# b = 0.?e1
# t = [13.690282319842214 .. 40.000000000000000]
# b = 0.?e1
# t = [13.691524461464378 .. 40.000000000000000]
# b = 0.?e1
# t = [13.692472675860406 .. 40.000000000000000]
# b = 0.?e1
# t = [13.693195907911730 .. 40.000000000000000]
# b = 0.?e1
# t = [13.693747186074045 .. 40.000000000000000]
# b = 0.?e1
# t = [13.694167188638749 .. 40.000000000000000]
# b = 0.?e1
# t = [13.694487057201648 .. 40.000000000000000]
# b = 0.?e1
# t = [13.694730595982614 .. 40.000000000000000]
# b = 0.?e1
# t = [13.694915979448500 .. 40.000000000000000]
# b = 0.?e1
# t = [13.695057071495506 .. 40.000000000000000]
# b = 0.?e1
# t = [13.695164440710254 .. 40.000000000000000]
# b = 0.?e1
# t = [13.695246139514321 .. 40.000000000000000]
# b = 0.?e1
# t = [13.695308300827278 .. 40.000000000000000]
# b = 0.?e1
# t = [13.695355594248740 .. 40.000000000000000]
# b = 0.?e1
# t = [13.695391574408485 .. 40.000000000000000]
# b = 0.?e1
# t = [13.695418946727411 .. 40.000000000000000]
# b = 0.?e1
# t = [13.695439770027608 .. 40.000000000000000]
# b = 0.?e1
# t = [13.695455610915258 .. 40.000000000000000]
# b = 0.?e1
# t = [13.695467661368173 .. 40.000000000000000]
# b = 0.?e1
# found lower bound!
# t = [13.695476828270166 .. 13.970956912518395]
# b = 0.?e1
# t = [13.695476828270166 .. 13.935339737313556]
# b = 0.?e1
# t = [13.695476828270166 .. 13.916299355718661]
# b = 0.?e1
# t = [13.695476828270166 .. 13.906282926793639]
# b = 0.?e1
# t = [13.695476828270166 .. 13.901068661348238]
# b = 0.?e1
# t = [13.695476828270166 .. 13.898370823254636]
# b = 0.?e1
# t = [13.695476828270166 .. 13.896979655933097]
# b = 0.?e1
# t = [13.695476828270166 .. 13.896263567415329]
# b = 0.?e1
# t = [13.695476828270166 .. 13.895895312891927]
# b = 0.?e1
# t = [13.695476828270166 .. 13.895706026684895]
# b = 0.?e1
# t = [13.695476828270166 .. 13.895608756176305]
# b = 0.?e1
# t = [13.695476828270166 .. 13.895558777189980]
# b = 0.?e1
# t = [13.695476828270166 .. 13.895533098970033]
# b = 0.?e1
# t = [13.695476828270166 .. 13.895519906455317]
# b = 0.?e1
# found upper bound!
#   I  = [13.423323506106562 .. 13.695476828270167]
# f(I) = [-0.24414899985344396 .. 0.10006692568907228]
# t = [13.896513128750427 .. 40.000000000000000]
# b = 0.?e1
# t = [13.896754453531325 .. 40.000000000000000]
# b = 0.?e1
# t = [13.897053689597829 .. 40.000000000000000]
# b = 0.?e1
# t = [13.897424781128096 .. 40.000000000000000]
# b = 0.?e1
# t = [13.897885055117702 .. 40.000000000000000]
# b = 0.?e1
# t = [13.898456055599472 .. 40.000000000000000]
# b = 0.?e1
# t = [13.899164590844209 .. 40.000000000000000]
# b = 0.?e1
# t = [13.900044051773274 .. 40.000000000000000]
# b = 0.?e1
# t = [13.901136077743604 .. 40.000000000000000]
# b = 0.?e1
# t = [13.902492670320375 .. 40.000000000000000]
# b = 0.?e1
# t = [13.904178889476902 .. 40.000000000000000]
# b = 0.?e1
# t = [13.906276314148266 .. 40.000000000000000]
# b = 0.?e1
# t = [13.908887516786853 .. 40.000000000000000]
# b = 0.?e1
# t = [13.912141899737372 .. 40.000000000000000]
# b = 0.?e1
# t = [13.916203385979976 .. 40.000000000000000]
# b = 0.?e1
# t = [13.921280673916351 .. 40.000000000000000]
# b = 0.?e1
# t = [13.927641097505500 .. 40.000000000000000]
# b = 0.?e1
# t = [13.935629649045530 .. 40.000000000000000]
# b = 0.?e1
# t = [13.945695540233950 .. 40.000000000000000]
# b = 0.?e1
# t = [13.958430000829389 .. 40.000000000000000]
# b = 0.?e1
# t = [13.974621198905330 .. 40.000000000000000]
# b = 0.?e1
# t = [13.995335845313316 .. 40.000000000000000]
# b = 0.?e1
# t = [14.022043356435370 .. 40.000000000000000]
# b = 0.?e1
# t = [14.056809440533337 .. 40.000000000000000]
# b = 0.?e1
# t = [14.101096869678102 .. 40.000000000000000]
# b = 0.?e1
# t = [14.156873782607183 .. 40.000000000000000]
# b = 0.?e1
# t = [14.228364887439687 .. 40.000000000000000]
# b = 0.?e1
# t = [14.321805155131620 .. 40.000000000000000]
# b = 0.?e1
# t = [14.446456542318545 .. 40.000000000000000]
# b = 0.?e1
# t = [14.615793028960929 .. 40.000000000000000]
# b = 0.?e1
# t = [14.847592083694465 .. 40.000000000000000]
# b = 0.?e1
# t = [15.157743646611388 .. 40.000000000000000]
# b = 0.?e1
# t = [15.534660714771925 .. 40.000000000000000]
# b = 0.?e1
# t = [15.894317705490170 .. 40.000000000000000]
# b = 0.?e1
# t = [16.062828469251869 .. 40.000000000000000]
# b = 0.?e1
# t = [16.102945196546979 .. 40.000000000000000]
# b = 0.?e1
# t = [16.110477835090172 .. 40.000000000000000]
# b = 0.?e1
# t = [16.111825314232376 .. 40.000000000000000]
# b = 0.?e1
# t = [16.112064283752772 .. 40.000000000000000]
# b = 0.?e1
# t = [16.112106599139998 .. 40.000000000000000]
# b = 0.?e1
# found lower bound!
# t = [16.112114090082723 .. 16.436168583293381]
# b = -2.?
# t = [16.112114090082723 .. 16.328394047565653]
# b = -2.?
# t = [16.112114090082723 .. 16.314225383251035]
# b = -2.?
# t = [16.112114090082723 .. 16.312387134850955]
# b = -2.?
# t = [16.112114090082723 .. 16.312150587661634]
# b = -2.?
# t = [16.112114090082723 .. 16.312120184528660]
# b = -2.?
# found upper bound!
#   I  = [13.895513128750426 .. 16.112114090082724]
# f(I) = [-1.5390024960971119 .. 2.0000000000000000]
# t = [16.313116277451339 .. 40.000000000000000]
# b = 0.?e1
# t = [16.313939905800950 .. 40.000000000000000]
# b = 0.?e1
# t = [16.315441762123207 .. 40.000000000000000]
# b = 0.?e1
# t = [16.318180931889049 .. 40.000000000000000]
# b = 0.?e1
# t = [16.323178727951251 .. 40.000000000000000]
# b = 0.?e1
# t = [16.332303913329319 .. 40.000000000000000]
# b = 0.?e1
# t = [16.348985722570855 .. 40.000000000000000]
# b = 0.?e1
# t = [16.379547257123558 .. 40.000000000000000]
# b = 0.?e1
# t = [16.435733806527629 .. 40.000000000000000]
# b = 0.?e1
# t = [16.539554992571112 .. 40.000000000000000]
# b = 0.?e1
# t = [16.732270230609380 .. 40.000000000000000]
# b = 0.?e1
# t = [17.087038088357392 .. 40.000000000000000]
# b = 0.?e1
# t = [17.692975547950684 .. 40.000000000000000]
# b = 0.?e1
# t = [18.368002880406390 .. 40.000000000000000]
# b = 0.?e1
# t = [18.527138113074865 .. 40.000000000000000]
# b = 0.?e1
# t = [18.528713951313136 .. 40.000000000000000]
# b = 0.?e1
# t = [18.528725351138994 .. 40.000000000000000]
# b = 0.?e1
# found lower bound!
# t = [18.528725434251789 .. 18.901353815480246]
# b = 3.?
# t = [18.528725434251789 .. 18.732714873444330]
# b = 3.?
# t = [18.528725434251789 .. 18.728755118473533]
# b = 3.?
# t = [18.528725434251789 .. 18.728725651321046]
# b = 3.?
# found upper bound!
#   I  = [16.312116277451337 .. 18.528725434251790]
# f(I) = [-2.0000000000000000 .. 0.44752730725003137]
# t = [18.729725436440460 .. 40.000000000000000]
# b = 0.?e1
# t = [18.730718110395887 .. 40.000000000000000]
# b = 0.?e1
# t = [18.732696110929119 .. 40.000000000000000]
# b = 0.?e1
# t = [18.736637245874366 .. 40.000000000000000]
# b = 0.?e1
# t = [18.744488946754717 .. 40.000000000000000]
# b = 0.?e1
# t = [18.760127269768965 .. 40.000000000000000]
# b = 0.?e1
# t = [18.791254462676096 .. 40.000000000000000]
# b = 0.?e1
# t = [18.853107115693997 .. 40.000000000000000]
# b = 0.?e1
# t = [18.975402108763784 .. 40.000000000000000]
# b = 0.?e1
# t = [19.213285055494313 .. 40.000000000000000]
# b = 0.?e1
# t = [19.650467634657971 .. 40.000000000000000]
# b = 0.?e1
# t = [20.288593301713369 .. 40.000000000000000]
# b = 0.?e1
# t = [20.748160083789290 .. 40.000000000000000]
# b = 0.?e1
# t = [20.885887909454211 .. 40.000000000000000]
# b = 0.?e1
# t = [20.926055977405312 .. 40.000000000000000]
# b = 0.?e1
# t = [20.938922347941858 .. 40.000000000000000]
# b = 0.?e1
# t = [20.943184011832705 .. 40.000000000000000]
# b = 0.?e1
# t = [20.944611529445730 .. 40.000000000000000]
# b = 0.?e1
# t = [20.945091508333881 .. 40.000000000000000]
# b = 0.?e1
# t = [20.945253098168524 .. 40.000000000000000]
# b = 0.?e1
# t = [20.945307522306197 .. 40.000000000000000]
# b = 0.?e1
# t = [20.945325855224282 .. 40.000000000000000]
# b = 0.?e1
# found lower bound!
# t = [20.945332031016846 .. 21.154885351327014]
# b = -2.?
# t = [20.945332031016846 .. 21.147385133130034]
# b = -2.?
# t = [20.945332031016846 .. 21.145767738351804]
# b = -2.?
# t = [20.945332031016846 .. 21.145426106896043]
# b = -2.?
# t = [20.945332031016846 .. 21.145354271173013]
# b = -2.?
# t = [20.945332031016846 .. 21.145339180506842]
# b = -2.?
# found upper bound!
#   I  = [18.728725436440459 .. 20.945332031016847]
# f(I) = [-0.86904409810610095 .. 2.0000000000000000]
# t = [21.146336011018743 .. 40.000000000000000]
# b = 0.?e1
# t = [21.146999467292395 .. 40.000000000000000]
# b = 0.?e1
# t = [21.148102478616767 .. 40.000000000000000]
# b = 0.?e1
# t = [21.149935820512002 .. 40.000000000000000]
# b = 0.?e1
# t = [21.152981843217364 .. 40.000000000000000]
# b = 0.?e1
# t = [21.158039299933953 .. 40.000000000000000]
# b = 0.?e1
# t = [21.166427013243126 .. 40.000000000000000]
# b = 0.?e1
# t = [21.180311578120754 .. 40.000000000000000]
# b = 0.?e1
# t = [21.203221353045748 .. 40.000000000000000]
# b = 0.?e1
# t = [21.240813305168668 .. 40.000000000000000]
# b = 0.?e1
# t = [21.301897158964191 .. 40.000000000000000]
# b = 0.?e1
# t = [21.399423716365472 .. 40.000000000000000]
# b = 0.?e1
# t = [21.550166465418904 .. 40.000000000000000]
# b = 0.?e1
# t = [21.759340880610537 .. 40.000000000000000]
# b = 0.?e1
# t = [21.993238238181664 .. 40.000000000000000]
# b = 0.?e1
# t = [22.217245952994311 .. 40.000000000000000]
# b = 0.?e1
# t = [22.402612935773642 .. 40.000000000000000]
# b = 0.?e1
# t = [22.542649244727176 .. 40.000000000000000]
# b = 0.?e1
# t = [22.645326011034402 .. 40.000000000000000]
# b = 0.?e1
# t = [22.721060366837619 .. 40.000000000000000]
# b = 0.?e1
# t = [22.778006514943125 .. 40.000000000000000]
# b = 0.?e1
# t = [22.821759548133471 .. 40.000000000000000]
# b = 0.?e1
# t = [22.856055020758596 .. 40.000000000000000]
# b = 0.?e1
# t = [22.883408455983250 .. 40.000000000000000]
# b = 0.?e1
# t = [22.905549172726683 .. 40.000000000000000]
# b = 0.?e1
# t = [22.923694574379005 .. 40.000000000000000]
# b = 0.?e1
# t = [22.938721954592125 .. 40.000000000000000]
# b = 0.?e1
# t = [22.951277407109671 .. 40.000000000000000]
# b = 0.?e1
# t = [22.961846234897759 .. 40.000000000000000]
# b = 0.?e1
# t = [22.970799476823117 .. 40.000000000000000]
# b = 0.?e1
# t = [22.978425332490559 .. 40.000000000000000]
# b = 0.?e1
# t = [22.984950834979521 .. 40.000000000000000]
# b = 0.?e1
# t = [22.990557092771854 .. 40.000000000000000]
# b = 0.?e1
# t = [22.995390204918550 .. 40.000000000000000]
# b = 0.?e1
# t = [22.999569209472365 .. 40.000000000000000]
# b = 0.?e1
# t = [23.003191961492955 .. 40.000000000000000]
# b = 0.?e1
# t = [23.006339542252284 .. 40.000000000000000]
# b = 0.?e1
# t = [23.009079610470639 .. 40.000000000000000]
# b = 0.?e1
# t = [23.011468980659511 .. 40.000000000000000]
# b = 0.?e1
# t = [23.013555629362954 .. 40.000000000000000]
# b = 0.?e1
# t = [23.015380272704554 .. 40.000000000000000]
# b = 0.?e1
# t = [23.016977618999202 .. 40.000000000000000]
# b = 0.?e1
# t = [23.018377372417326 .. 40.000000000000000]
# b = 0.?e1
# t = [23.019605043985475 .. 40.000000000000000]
# b = 0.?e1
# t = [23.020682612059012 .. 40.000000000000000]
# b = 0.?e1
# t = [23.021629064129086 .. 40.000000000000000]
# b = 0.?e1
# t = [23.022460844286911 .. 40.000000000000000]
# b = 0.?e1
# t = [23.023192225080880 .. 40.000000000000000]
# b = 0.?e1
# t = [23.023835618322056 .. 40.000000000000000]
# b = 0.?e1
# t = [23.024401836238745 .. 40.000000000000000]
# b = 0.?e1
# t = [23.024900311979632 .. 40.000000000000000]
# b = 0.?e1
# t = [23.025339286622756 .. 40.000000000000000]
# b = 0.?e1
# t = [23.025725968423110 .. 40.000000000000000]
# b = 0.?e1
# t = [23.026066668922407 .. 40.000000000000000]
# b = 0.?e1
# t = [23.026366919674206 .. 40.000000000000000]
# b = 0.?e1
# t = [23.026631572650337 .. 40.000000000000000]
# b = 0.?e1
# t = [23.026864886848134 .. 40.000000000000000]
# b = 0.?e1
# t = [23.027070603180625 .. 40.000000000000000]
# b = 0.?e1
# t = [23.027252009379857 .. 40.000000000000000]
# b = 0.?e1
# t = [23.027411996358171 .. 40.000000000000000]
# b = 0.?e1
# t = [23.027553107239992 .. 40.000000000000000]
# b = 0.?e1
# t = [23.027677580086091 .. 40.000000000000000]
# b = 0.?e1
# t = [23.027787385175560 .. 40.000000000000000]
# b = 0.?e1
# t = [23.027884257580605 .. 40.000000000000000]
# b = 0.?e1
# t = [23.027969725661261 .. 40.000000000000000]
# b = 0.?e1
# t = [23.028045136016544 .. 40.000000000000000]
# b = 0.?e1
# t = [23.028111675352668 .. 40.000000000000000]
# b = 0.?e1
# t = [23.028170389664737 .. 40.000000000000000]
# b = 0.?e1
# t = [23.028222201074076 .. 40.000000000000000]
# b = 0.?e1
# t = [23.028267922617214 .. 40.000000000000000]
# b = 0.?e1
# t = [23.028308271242995 .. 40.000000000000000]
# b = 0.?e1
# t = [23.028343879240740 .. 40.000000000000000]
# b = 0.?e1
# t = [23.028375304293287 .. 40.000000000000000]
# b = 0.?e1
# t = [23.028403038323880 .. 40.000000000000000]
# b = 0.?e1
# t = [23.028427515284349 .. 40.000000000000000]
# b = 0.?e1
# t = [23.028449118013377 .. 40.000000000000000]
# b = 0.?e1
# t = [23.028468184277553 .. 40.000000000000000]
# b = 0.?e1
# t = [23.028485012093877 .. 40.000000000000000]
# b = 0.?e1
# t = [23.028499864420176 .. 40.000000000000000]
# b = 0.?e1
# t = [23.028512973289288 .. 40.000000000000000]
# b = 0.?e1
# t = [23.028524543453588 .. 40.000000000000000]
# b = 0.?e1
# t = [23.028534755598339 .. 40.000000000000000]
# b = 0.?e1
# found lower bound!
# t = [23.028543769175197 .. 23.964001030764220]
# b = 0.?e1
# t = [23.028543769175197 .. 23.950804701202597]
# b = 0.?e1
# t = [23.028543769175197 .. 23.940285432866319]
# b = 0.?e1
# t = [23.028543769175197 .. 23.931853160277268]
# b = 0.?e1
# t = [23.028543769175197 .. 23.925062994662707]
# b = 0.?e1
# t = [23.028543769175197 .. 23.919574798069992]
# b = 0.?e1
# t = [23.028543769175197 .. 23.915125431028667]
# b = 0.?e1
# t = [23.028543769175197 .. 23.911509278488275]
# b = 0.?e1
# t = [23.028543769175197 .. 23.908564314126132]
# b = 0.?e1
# t = [23.028543769175197 .. 23.906161950471784]
# b = 0.?e1
# t = [23.028543769175197 .. 23.904199528066372]
# b = 0.?e1
# t = [23.028543769175197 .. 23.902594677705814]
# b = 0.?e1
# t = [23.028543769175197 .. 23.901281034444527]
# b = 0.?e1
# t = [23.028543769175197 .. 23.900204942252217]
# b = 0.?e1
# t = [23.028543769175197 .. 23.899322895033660]
# b = 0.?e1
# t = [23.028543769175197 .. 23.898599532130622]
# b = 0.?e1
# t = [23.028543769175197 .. 23.898006056287298]
# b = 0.?e1
# t = [23.028543769175197 .. 23.897518976915830]
# b = 0.?e1
# t = [23.028543769175197 .. 23.897119106217382]
# b = 0.?e1
# t = [23.028543769175197 .. 23.896790753489992]
# b = 0.?e1
# t = [23.028543769175197 .. 23.896521075909157]
# b = 0.?e1
# t = [23.028543769175197 .. 23.896299553629806]
# b = 0.?e1
# t = [23.028543769175197 .. 23.896117564203280]
# b = 0.?e1
# t = [23.028543769175197 .. 23.895968036702666]
# b = 0.?e1
# t = [23.028543769175197 .. 23.895845170073916]
# b = 0.?e1
# t = [23.028543769175197 .. 23.895744203410736]
# b = 0.?e1
# t = [23.028543769175197 .. 23.895661228325946]
# b = 0.?e1
# t = [23.028543769175197 .. 23.895593035532479]
# b = 0.?e1
# t = [23.028543769175197 .. 23.895536989279677]
# b = 0.?e1
# t = [23.028543769175197 .. 23.895490924508178]
# b = 0.?e1
# t = [23.028543769175197 .. 23.895453062559174]
# b = 0.?e1
# t = [23.028543769175197 .. 23.895421942054388]
# b = 0.?e1
# t = [23.028543769175197 .. 23.895396362191719]
# b = 0.?e1
# t = [23.028543769175197 .. 23.895375336209842]
# b = 0.?e1
# t = [23.028543769175197 .. 23.895358053186872]
# b = 0.?e1
# t = [23.028543769175197 .. 23.895343846672937]
# b = 0.?e1
# t = [23.028543769175197 .. 23.895332168929020]
# b = 0.?e1
# found upper bound!
#   I  = [21.145336011018741 .. 23.028543769175198]
# f(I) = [-1.9449347605338781 .. 1.6095722020030324]
# t = [23.896322569766567 .. 40.000000000000000]
# b = 0.?e1
# t = [23.896445377517597 .. 40.000000000000000]
# b = 0.?e1
# t = [23.896582663752290 .. 40.000000000000000]
# b = 0.?e1
# t = [23.896736144630775 .. 40.000000000000000]
# b = 0.?e1
# t = [23.896907742026687 .. 40.000000000000000]
# b = 0.?e1
# t = [23.897099608756438 .. 40.000000000000000]
# b = 0.?e1
# t = [23.897314157044007 .. 40.000000000000000]
# b = 0.?e1
# t = [23.897554090670872 .. 40.000000000000000]
# b = 0.?e1
# t = [23.897822441331307 .. 40.000000000000000]
# b = 0.?e1
# t = [23.898122609797066 .. 40.000000000000000]
# b = 0.?e1
# t = [23.898458412594997 .. 40.000000000000000]
# b = 0.?e1
# t = [23.898834135019839 .. 40.000000000000000]
# b = 0.?e1
# t = [23.899254591446961 .. 40.000000000000000]
# b = 0.?e1
# t = [23.899725194081160 .. 40.000000000000000]
# b = 0.?e1
# t = [23.900252031485006 .. 40.000000000000000]
# b = 0.?e1
# t = [23.900841958482246 .. 40.000000000000000]
# b = 0.?e1
# t = [23.901502699339214 .. 40.000000000000000]
# b = 0.?e1
# t = [23.902242966504612 .. 40.000000000000000]
# b = 0.?e1
# t = [23.903072597653007 .. 40.000000000000000]
# b = 0.?e1
# t = [23.904002714353655 .. 40.000000000000000]
# b = 0.?e1
# t = [23.905045906403724 .. 40.000000000000000]
# b = 0.?e1
# t = [23.906216446763362 .. 40.000000000000000]
# b = 0.?e1
# t = [23.907530543160657 .. 40.000000000000000]
# b = 0.?e1
# t = [23.909006633865839 .. 40.000000000000000]
# b = 0.?e1
# t = [23.910665736956076 .. 40.000000000000000]
# b = 0.?e1
# t = [23.912531864725902 .. 40.000000000000000]
# b = 0.?e1
# t = [23.914632517905729 .. 40.000000000000000]
# b = 0.?e1
# t = [23.916999278251626 .. 40.000000000000000]
# b = 0.?e1
# t = [23.919668523163121 .. 40.000000000000000]
# b = 0.?e1
# t = [23.922682292683656 .. 40.000000000000000]
# b = 0.?e1
# t = [23.926089348109883 .. 40.000000000000000]
# b = 0.?e1
# t = [23.929946473276945 .. 40.000000000000000]
# b = 0.?e1
# t = [23.934320085515725 .. 40.000000000000000]
# b = 0.?e1
# t = [23.939288244883396 .. 40.000000000000000]
# b = 0.?e1
# t = [23.944943179822928 .. 40.000000000000000]
# b = 0.?e1
# t = [23.951394488189922 .. 40.000000000000000]
# b = 0.?e1
# t = [23.958773229366048 .. 40.000000000000000]
# b = 0.?e1
# t = [23.967237202945433 .. 40.000000000000000]
# b = 0.?e1
# t = [23.976977822535260 .. 40.000000000000000]
# b = 0.?e1
# t = [23.988229154804635 .. 40.000000000000000]
# b = 0.?e1
# t = [24.001279926641700 .. 40.000000000000000]
# b = 0.?e1
# t = [24.016489640457361 .. 40.000000000000000]
# b = 0.?e1
# t = [24.034310427703719 .. 40.000000000000000]
# b = 0.?e1
# t = [24.055316981451884 .. 40.000000000000000]
# b = 0.?e1
# t = [24.080247928358254 .. 40.000000000000000]
# b = 0.?e1
# t = [24.110063420557558 .. 40.000000000000000]
# b = 0.?e1
# t = [24.146025574658359 .. 40.000000000000000]
# b = 0.?e1
# t = [24.189810385650140 .. 40.000000000000000]
# b = 0.?e1
# t = [24.243660640058262 .. 40.000000000000000]
# b = 0.?e1
# t = [24.310584978507478 .. 40.000000000000000]
# b = 0.?e1
# t = [24.394586453928635 .. 40.000000000000000]
# b = 0.?e1
# t = [24.500832312780872 .. 40.000000000000000]
# b = 0.?e1
# t = [24.635479408339641 .. 40.000000000000000]
# b = 0.?e1
# t = [24.804415860014934 .. 40.000000000000000]
# b = 0.?e1
# t = [25.009468377832110 .. 40.000000000000000]
# b = 0.?e1
# t = [25.240813466665102 .. 40.000000000000000]
# b = 0.?e1
# t = [25.469606418855413 .. 40.000000000000000]
# b = 0.?e1
# t = [25.647325527171631 .. 40.000000000000000]
# b = 0.?e1
# t = [25.730010605702215 .. 40.000000000000000]
# b = 0.?e1
# t = [25.761647683114194 .. 40.000000000000000]
# b = 0.?e1
# t = [25.772793837469794 .. 40.000000000000000]
# b = 0.?e1
# t = [25.776606459600813 .. 40.000000000000000]
# b = 0.?e1
# t = [25.777897485283716 .. 40.000000000000000]
# b = 0.?e1
# t = [25.778333159417584 .. 40.000000000000000]
# b = 0.?e1
# t = [25.778480014178573 .. 40.000000000000000]
# b = 0.?e1
# t = [25.778529495986656 .. 40.000000000000000]
# b = 0.?e1
# t = [25.778546166395187 .. 40.000000000000000]
# b = 0.?e1
# found lower bound!
# t = [25.778551782403912 .. 26.036437300227949]
# b = 2.?
# t = [25.778551782403912 .. 25.991279624896170]
# b = 2.?
# t = [25.778551782403912 .. 25.981258080636995]
# b = 2.?
# t = [25.778551782403912 .. 25.979123840832547]
# b = 2.?
# t = [25.778551782403912 .. 25.978674242549581]
# b = 2.?
# t = [25.778551782403912 .. 25.978579757880166]
# b = 2.?
# t = [25.778551782403912 .. 25.978559911731495]
# b = 2.?
# found upper bound!
#   I  = [23.895322569766566 .. 25.778551782403913]
# f(I) = [-1.9449424393695767 .. 1.6095899592808849]
# t = [25.979555743570916 .. 40.000000000000000]
# b = 0.?e1
# t = [25.980219825880304 .. 40.000000000000000]
# b = 0.?e1
# t = [25.981324673035974 .. 40.000000000000000]
# b = 0.?e1
# t = [25.983163266133772 .. 40.000000000000000]
# b = 0.?e1
# t = [25.986224101720100 .. 40.000000000000000]
# b = 0.?e1
# t = [25.991323009006208 .. 40.000000000000000]
# b = 0.?e1
# t = [25.999826163347318 .. 40.000000000000000]
# b = 0.?e1
# t = [26.014031302362134 .. 40.000000000000000]
# b = 0.?e1
# t = [26.037829528962269 .. 40.000000000000000]
# b = 0.?e1
# t = [26.077879106372339 .. 40.000000000000000]
# b = 0.?e1
# t = [26.145740208513057 .. 40.000000000000000]
# b = 0.?e1
# t = [26.261820249341038 .. 40.000000000000000]
# b = 0.?e1
# t = [26.462373197368350 .. 40.000000000000000]
# b = 0.?e1
# t = [26.808303299364393 .. 40.000000000000000]
# b = 0.?e1
# t = [27.353410420283356 .. 40.000000000000000]
# b = 0.?e1
# t = [27.982895317704905 .. 40.000000000000000]
# b = 0.?e1
# t = [28.188923129247740 .. 40.000000000000000]
# b = 0.?e1
# t = [28.195117375915664 .. 40.000000000000000]
# b = 0.?e1
# t = [28.195164026272397 .. 40.000000000000000]
# b = 0.?e1
# found lower bound!
# t = [28.195164366485908 .. 28.477216010150766]
# b = -3.?
# t = [28.195164366485908 .. 28.395698653306017]
# b = -3.?
# t = [28.195164366485908 .. 28.395168254245875]
# b = -3.?
# found upper bound!
#   I  = [25.978555743570915 .. 28.195164366485909]
# f(I) = [-0.86904625023687910 .. 2.0000000000000000]
# t = [28.396164397312052 .. 40.000000000000000]
# b = 0.?e1
# t = [28.397157170145717 .. 40.000000000000000]
# b = 0.?e1
# t = [28.399135582580687 .. 40.000000000000000]
# b = 0.?e1
# t = [28.403078391524854 .. 40.000000000000000]
# b = 0.?e1
# t = [28.410936815978416 .. 40.000000000000000]
# b = 0.?e1
# t = [28.426601986822294 .. 40.000000000000000]
# b = 0.?e1
# t = [28.457836042747139 .. 40.000000000000000]
# b = 0.?e1
# t = [28.520112845000227 .. 40.000000000000000]
# b = 0.?e1
# t = [28.644080770942391 .. 40.000000000000000]
# b = 0.?e1
# t = [28.888415309492909 .. 40.000000000000000]
# b = 0.?e1
# t = [29.348383134685040 .. 40.000000000000000]
# b = 0.?e1
# t = [30.065810890656717 .. 40.000000000000000]
# b = 0.?e1
# t = [30.519254511008380 .. 40.000000000000000]
# b = 0.?e1
# t = [30.596639004286029 .. 40.000000000000000]
# b = 0.?e1
# t = [30.609133049413102 .. 40.000000000000000]
# b = 0.?e1
# t = [30.611307777253173 .. 40.000000000000000]
# b = 0.?e1
# t = [30.611691592452160 .. 40.000000000000000]
# b = 0.?e1
# t = [30.611759498062930 .. 40.000000000000000]
# b = 0.?e1
# t = [30.611771517327930 .. 40.000000000000000]
# b = 0.?e1
# found lower bound!
# t = [30.611773644896548 .. 30.917991381345513]
# b = 2.?
# t = [30.611773644896548 .. 30.829115141345849]
# b = 2.?
# t = [30.611773644896548 .. 30.814099134923908]
# b = 2.?
# t = [30.611773644896548 .. 30.812074614109222]
# b = 2.?
# ...
# b = 0.?e1
# t = [30.822812584315322 .. 40.000000000000000]
# b = 0.?e1
# t = [30.831875950620144 .. 40.000000000000000]
# b = 0.?e1
# t = [30.848348408070343 .. 40.000000000000000]
# b = 0.?e1
# t = [30.878207444273868 .. 40.000000000000000]
# b = 0.?e1
# t = [30.932051085782664 .. 40.000000000000000]
# b = 0.?e1
# t = [31.028115266924526 .. 40.000000000000000]
# b = 0.?e1
# t = [31.195586749102126 .. 40.000000000000000]
# b = 0.?e1
# t = [31.472485307652185 .. 40.000000000000000]
# b = 0.?e1
# t = [31.846890079321148 .. 40.000000000000000]
# b = 0.?e1
# t = [32.212272860524493 .. 40.000000000000000]
# b = 0.?e1
# t = [32.478215206520332 .. 40.000000000000000]
# b = 0.?e1
# t = [32.647264562304634 .. 40.000000000000000]
# b = 0.?e1
# t = [32.756512040655458 .. 40.000000000000000]
# b = 0.?e1
# t = [32.831107103373199 .. 40.000000000000000]
# b = 0.?e1
# t = [32.884657887905113 .. 40.000000000000000]
# b = 0.?e1
# t = [32.924643879892059 .. 40.000000000000000]
# b = 0.?e1
# t = [32.952508080543040 .. 40.000000000000000]
# b = 0.?e1
# t = [32.972306298942527 .. 40.000000000000000]
# b = 0.?e1
# t = [32.986627889786504 .. 40.000000000000000]
# b = 0.?e1
# t = [32.997122657029507 .. 40.000000000000000]
# b = 0.?e1
# t = [33.004886135439789 .. 40.000000000000000]
# b = 0.?e1
# t = [33.010669292031252 .. 40.000000000000000]
# b = 0.?e1
# t = [33.014999622769053 .. 40.000000000000000]
# b = 0.?e1
# t = [33.018254663983903 .. 40.000000000000000]
# b = 0.?e1
# t = [33.020708536996707 .. 40.000000000000000]
# b = 0.?e1
# t = [33.022562480157361 .. 40.000000000000000]
# b = 0.?e1
# t = [33.023965477324026 .. 40.000000000000000]
# b = 0.?e1
# t = [33.025028539387513 .. 40.000000000000000]
# b = 0.?e1
# t = [33.025834790735665 .. 40.000000000000000]
# b = 0.?e1
# t = [33.026446708555695 .. 40.000000000000000]
# b = 0.?e1
# t = [33.026911385965284 .. 40.000000000000000]
# b = 0.?e1
# t = [33.027264397616853 .. 40.000000000000000]
# b = 0.?e1
# t = [33.027532661676829 .. 40.000000000000000]
# b = 0.?e1
# t = [33.027736572021694 .. 40.000000000000000]
# b = 0.?e1
# t = [33.027891594453429 .. 40.000000000000000]
# b = 0.?e1
# t = [33.028009466146066 .. 40.000000000000000]
# b = 0.?e1
# t = [33.028099099547297 .. 40.000000000000000]
# b = 0.?e1
# t = [33.028167265065491 .. 40.000000000000000]
# b = 0.?e1
# t = [33.028219107554754 .. 40.000000000000000]
# b = 0.?e1
# t = [33.028258537566777 .. 40.000000000000000]
# b = 0.?e1
# t = [33.028288528028433 .. 40.000000000000000]
# b = 0.?e1
# t = [33.028311339375768 .. 40.000000000000000]
# b = 0.?e1
# t = [33.028328690495420 .. 40.000000000000000]
# b = 0.?e1
# t = [33.028341888575248 .. 40.000000000000000]
# b = 0.?e1
# t = [33.028351927774579 .. 40.000000000000000]
# b = 0.?e1
# found lower bound!
# t = [33.028359564220281 .. 33.358743159862478]
# b = 0.?e1
# t = [33.028359564220281 .. 33.338989837437219]
# b = 0.?e1
# t = [33.028359564220281 .. 33.317932291116776]
# b = 0.?e1
# t = [33.028359564220281 .. 33.295931889477572]
# b = 0.?e1
# t = [33.028359564220281 .. 33.273463781975757]
# b = 0.?e1
# t = [33.028359564220281 .. 33.253392600384374]
# b = 0.?e1
# t = [33.028359564220281 .. 33.241808210732935]
# b = 0.?e1
# t = [33.028359564220281 .. 33.235447830189124]
# b = 0.?e1
# t = [33.028359564220281 .. 33.232059462895073]
# b = 0.?e1
# t = [33.028359564220281 .. 33.230284813091217]
# b = 0.?e1
# t = [33.028359564220281 .. 33.229363847266960]
# b = 0.?e1
# t = [33.028359564220281 .. 33.228888218803647]
# b = 0.?e1
# t = [33.028359564220281 .. 33.228643202733459]
# b = 0.?e1
# t = [33.028359564220281 .. 33.228517149706726]
# b = 0.?e1
# t = [33.028359564220281 .. 33.228452343133413]
# b = 0.?e1
# t = [33.028359564220281 .. 33.228419036245690]
# b = 0.?e1
# t = [33.028359564220281 .. 33.228401921458506]
# b = 0.?e1
# found upper bound!
#   I  = [30.811774740784059 .. 33.028359564220282]
# f(I) = [-1.5389967443351150 .. 2.0000000000000000]
# t = [33.229393127810162 .. 40.000000000000000]
# b = 0.?e1
# t = [33.229634370338146 .. 40.000000000000000]
# b = 0.?e1
# t = [33.229933187112202 .. 40.000000000000000]
# b = 0.?e1
# t = [33.230303271581121 .. 40.000000000000000]
# b = 0.?e1
# t = [33.230761548866922 .. 40.000000000000000]
# b = 0.?e1
# t = [33.231328924970860 .. 40.000000000000000]
# b = 0.?e1
# t = [33.232031202439493 .. 40.000000000000000]
# b = 0.?e1
# t = [33.232900195559174 .. 40.000000000000000]
# b = 0.?e1
# t = [33.233975082533753 .. 40.000000000000000]
# b = 0.?e1
# t = [33.235304035735140 .. 40.000000000000000]
# b = 0.?e1
# t = [33.236946172933713 .. 40.000000000000000]
# b = 0.?e1
# t = [33.238973870688788 .. 40.000000000000000]
# b = 0.?e1
# t = [33.241475473107414 .. 40.000000000000000]
# b = 0.?e1
# t = [33.244558410862403 .. 40.000000000000000]
# b = 0.?e1
# t = [33.248352710668427 .. 40.000000000000000]
# b = 0.?e1
# t = [33.253014815786251 .. 40.000000000000000]
# b = 0.?e1
# t = [33.258731541940314 .. 40.000000000000000]
# b = 0.?e1
# t = [33.265723845496836 .. 40.000000000000000]
# b = 0.?e1
# t = [33.274249864873226 .. 40.000000000000000]
# b = 0.?e1
# t = [33.284606396142109 .. 40.000000000000000]
# b = 0.?e1
# t = [33.296110996886731 .. 40.000000000000000]
# b = 0.?e1
# t = [33.307688540617917 .. 40.000000000000000]
# b = 0.?e1
# t = [33.319259169424924 .. 40.000000000000000]
# b = 0.?e1
# t = [33.330742675506492 .. 40.000000000000000]
# b = 0.?e1
# t = [33.342060753946775 .. 40.000000000000000]
# b = 0.?e1
# t = [33.353139165627545 .. 40.000000000000000]
# b = 0.?e1
# t = [33.363909682016263 .. 40.000000000000000]
# b = 0.?e1
# t = [33.374311704040458 .. 40.000000000000000]
# b = 0.?e1
# t = [33.384293477900605 .. 40.000000000000000]
# b = 0.?e1
# t = [33.393812867068582 .. 40.000000000000000]
# b = 0.?e1
# t = [33.402837676902628 .. 40.000000000000000]
# b = 0.?e1
# t = [33.411345561713233 .. 40.000000000000000]
# b = 0.?e1
# t = [33.419323570314865 .. 40.000000000000000]
# b = 0.?e1
# t = [33.426767403223038 .. 40.000000000000000]
# b = 0.?e1
# t = [33.433680462411992 .. 40.000000000000000]
# b = 0.?e1
# t = [33.440072773941381 .. 40.000000000000000]
# b = 0.?e1
# t = [33.445959856644968 .. 40.000000000000000]
# b = 0.?e1
# t = [33.451361598661598 .. 40.000000000000000]
# b = 0.?e1
# t = [33.456301190035063 .. 40.000000000000000]
# b = 0.?e1
# t = [33.460804145730243 .. 40.000000000000000]
# b = 0.?e1
# t = [33.464897440543602 .. 40.000000000000000]
# b = 0.?e1
# t = [33.468608766359295 .. 40.000000000000000]
# b = 0.?e1
# t = [33.471965913407636 .. 40.000000000000000]
# b = 0.?e1
# t = [33.474996270668675 .. 40.000000000000000]
# b = 0.?e1
# t = [33.477726436147143 .. 40.000000000000000]
# b = 0.?e1
# t = [33.480181925113278 .. 40.000000000000000]
# b = 0.?e1
# t = [33.482386963192219 .. 40.000000000000000]
# b = 0.?e1
# t = [33.484364351032404 .. 40.000000000000000]
# b = 0.?e1
# t = [33.486135387866831 .. 40.000000000000000]
# b = 0.?e1
# t = [33.487719842330982 .. 40.000000000000000]
# b = 0.?e1
# t = [33.489135960205537 .. 40.000000000000000]
# b = 0.?e1
# t = [33.490400500154237 .. 40.000000000000000]
# b = 0.?e1
# t = [33.491528789917673 .. 40.000000000000000]
# b = 0.?e1
# t = [33.492534796731696 .. 40.000000000000000]
# b = 0.?e1
# t = [33.493431206923126 .. 40.000000000000000]
# b = 0.?e1
# t = [33.494229510676262 .. 40.000000000000000]
# b = 0.?e1
# t = [33.494940088856452 .. 40.000000000000000]
# b = 0.?e1
# t = [33.495572299527836 .. 40.000000000000000]
# b = 0.?e1
# t = [33.496134562421765 .. 40.000000000000000]
# b = 0.?e1
# t = [33.496634440115499 .. 40.000000000000000]
# b = 0.?e1
# t = [33.497078715082359 .. 40.000000000000000]
# b = 0.?e1
# t = [33.497473462090184 .. 40.000000000000000]
# b = 0.?e1
# t = [33.497824115668635 .. 40.000000000000000]
# b = 0.?e1
# t = [33.498135532550456 .. 40.000000000000000]
# b = 0.?e1
# t = [33.498412049128610 .. 40.000000000000000]
# b = 0.?e1
# t = [33.498657534069337 .. 40.000000000000000]
# b = 0.?e1
# t = [33.498875436289409 .. 40.000000000000000]
# b = 0.?e1
# t = [33.499068828550100 .. 40.000000000000000]
# b = 0.?e1
# t = [33.499240446946892 .. 40.000000000000000]
# b = 0.?e1
# t = [33.499392726586286 .. 40.000000000000000]
# b = 0.?e1
# t = [33.499527833743798 .. 40.000000000000000]
# b = 0.?e1
# t = [33.499647694792081 .. 40.000000000000000]
# b = 0.?e1
# t = [33.499754022178116 .. 40.000000000000000]
# b = 0.?e1
# t = [33.499848337714958 .. 40.000000000000000]
# b = 0.?e1
# t = [33.499931993437670 .. 40.000000000000000]
# b = 0.?e1
# t = [33.500006190256314 .. 40.000000000000000]
# b = 0.?e1
# t = [33.500071994621571 .. 40.000000000000000]
# b = 0.?e1
# t = [33.500130353401203 .. 40.000000000000000]
# b = 0.?e1
# t = [33.500182107148887 .. 40.000000000000000]
# b = 0.?e1
# t = [33.500228001930885 .. 40.000000000000000]
# b = 0.?e1
# t = [33.500268699860725 .. 40.000000000000000]
# b = 0.?e1
# t = [33.500304788477961 .. 40.000000000000000]
# b = 0.?e1
# t = [33.500336789093829 .. 40.000000000000000]
# b = 0.?e1
# t = [33.500365164214414 .. 40.000000000000000]
# b = 0.?e1
# t = [33.500390324140866 .. 40.000000000000000]
# b = 0.?e1
# t = [33.500412632835896 .. 40.000000000000000]
# b = 0.?e1
# t = [33.500432413136628 .. 40.000000000000000]
# b = 0.?e1
# t = [33.500449951385427 .. 40.000000000000000]
# b = 0.?e1
# t = [33.500465501542741 .. 40.000000000000000]
# b = 0.?e1
# t = [33.500479288839144 .. 40.000000000000000]
# b = 0.?e1
# t = [33.500491513017642 .. 40.000000000000000]
# b = 0.?e1
# t = [33.500502351211736 .. 40.000000000000000]
# b = 0.?e1
# found lower bound!
# t = [33.500511960499821 .. 34.515913983414898]
# b = 0.?e1
# t = [33.500511960499821 .. 34.437128013358326]
# b = 0.?e1
# t = [33.500511960499821 .. 34.399501552880601]
# b = 0.?e1
# t = [33.500511960499821 .. 34.382070578363561]
# b = 0.?e1
# t = [33.500511960499821 .. 34.374054180359118]
# b = 0.?e1
# t = [33.500511960499821 .. 34.370373998185173]
# b = 0.?e1
# t = [33.500511960499821 .. 34.368685284069202]
# b = 0.?e1
# t = [33.500511960499821 .. 34.367910498913496]
# b = 0.?e1
# t = [33.500511960499821 .. 34.367555043753790]
# b = 0.?e1
# t = [33.500511960499821 .. 34.367391971589371]
# b = 0.?e1
# t = [33.500511960499821 .. 34.367317159594464]
# b = 0.?e1
# t = [33.500511960499821 .. 34.367282838506960]
# b = 0.?e1
# t = [33.500511960499821 .. 34.367267093236436]
# b = 0.?e1
# found upper bound!
#   I  = [33.228393127810157 .. 33.500511960499822]
# f(I) = [-0.24411342400535463 .. 0.10002894693859022]
# t = [34.368259869882656 .. 40.000000000000000]
# b = 0.?e1
# t = [34.368492037875732 .. 40.000000000000000]
# b = 0.?e1
# t = [34.368777778863055 .. 40.000000000000000]
# b = 0.?e1
# t = [34.369129454323235 .. 40.000000000000000]
# b = 0.?e1
# t = [34.369562277714948 .. 40.000000000000000]
# b = 0.?e1
# t = [34.370094972274671 .. 40.000000000000000]
# b = 0.?e1
# t = [34.370750580402436 .. 40.000000000000000]
# b = 0.?e1
# t = [34.371557459476605 .. 40.000000000000000]
# b = 0.?e1
# t = [34.372550506877409 .. 40.000000000000000]
# b = 0.?e1
# t = [34.373772666692453 .. 40.000000000000000]
# b = 0.?e1
# t = [34.375276782368239 .. 40.000000000000000]
# b = 0.?e1
# t = [34.377127873832201 .. 40.000000000000000]
# b = 0.?e1
# t = [34.379405934703598 .. 40.000000000000000]
# b = 0.?e1
# t = [34.382209365417239 .. 40.000000000000000]
# b = 0.?e1
# t = [34.385659181427712 .. 40.000000000000000]
# b = 0.?e1
# t = [34.389904161598693 .. 40.000000000000000]
# b = 0.?e1
# t = [34.395127128674019 .. 40.000000000000000]
# b = 0.?e1
# t = [34.401552577279367 .. 40.000000000000000]
# b = 0.?e1
# t = [34.409455876593739 .. 40.000000000000000]
# b = 0.?e1
# t = [34.419174257533917 .. 40.000000000000000]
# b = 0.?e1
# t = [34.431119715214236 .. 40.000000000000000]
# b = 0.?e1
# t = [34.445793755456087 .. 40.000000000000000]
# b = 0.?e1
# t = [34.463803478236307 .. 40.000000000000000]
# b = 0.?e1
# t = [34.485877625735092 .. 40.000000000000000]
# b = 0.?e1
# t = [34.512879598613189 .. 40.000000000000000]
# b = 0.?e1
# t = [34.545811544307035 .. 40.000000000000000]
# b = 0.?e1
# t = [34.585798738202107 .. 40.000000000000000]
# b = 0.?e1
# t = [34.634043355815038 .. 40.000000000000000]
# b = 0.?e1
# t = [34.691741170104315 .. 40.000000000000000]
# b = 0.?e1
# t = [34.759885406837803 .. 40.000000000000000]
# b = 0.?e1
# t = [34.838947998054017 .. 40.000000000000000]
# b = 0.?e1
# t = [34.928413514809847 .. 40.000000000000000]
# b = 0.?e1
# t = [35.026216563822131 .. 40.000000000000000]
# b = 0.?e1
# t = [35.128287154179325 .. 40.000000000000000]
# b = 0.?e1
# t = [35.228605635459466 .. 40.000000000000000]
# b = 0.?e1
# t = [35.319497016797932 .. 40.000000000000000]
# b = 0.?e1
# t = [35.377801996309216 .. 40.000000000000000]
# b = 0.?e1
# t = [35.410259614070710 .. 40.000000000000000]
# b = 0.?e1
# t = [35.427380529948464 .. 40.000000000000000]
# b = 0.?e1
# t = [35.436151532619426 .. 40.000000000000000]
# b = 0.?e1
# t = [35.440577356740348 .. 40.000000000000000]
# b = 0.?e1
# t = [35.442793526442095 .. 40.000000000000000]
# b = 0.?e1
# t = [35.443898972324717 .. 40.000000000000000]
# b = 0.?e1
# t = [35.444449318356646 .. 40.000000000000000]
# b = 0.?e1
# t = [35.444723045401694 .. 40.000000000000000]
# b = 0.?e1
# t = [35.444859124799101 .. 40.000000000000000]
# b = 0.?e1
# t = [35.444926758635936 .. 40.000000000000000]
# b = 0.?e1
# t = [35.444960369870706 .. 40.000000000000000]
# b = 0.?e1
# t = [35.444977072293049 .. 40.000000000000000]
# b = 0.?e1
# found lower bound!
# t = [35.444985371981850 .. 35.799535225701661]
# b = -1.?e1
# t = [35.444985371981850 .. 35.699692338872396]
# b = -1.?
# t = [35.444985371981850 .. 35.663387342022951]
# b = -1.?
# t = [35.444985371981850 .. 35.651015125176578]
# b = -1.?
# t = [35.444985371981850 .. 35.646944479198439]
# b = -1.?
# t = [35.444985371981850 .. 35.645623390131178]
# b = -1.?
# t = [35.444985371981850 .. 35.645196658729987]
# b = -1.?
# t = [35.444985371981850 .. 35.645059031868464]
# b = -1.?
# t = [35.444985371981850 .. 35.645014667623443]
# b = -1.?
# t = [35.444985371981850 .. 35.645000369062288]
# b = -1.?
# found upper bound!
#   I  = [34.367259869882651 .. 35.444985371981851]
# f(I) = [-0.87570801622803085 .. 1.1891135415740133]
# t = [35.645995760889086 .. 40.000000000000000]
# b = 0.?e1
# t = [35.646461769064238 .. 40.000000000000000]
# b = 0.?e1
# t = [35.647144647515837 .. 40.000000000000000]
# b = 0.?e1
# t = [35.648145530904130 .. 40.000000000000000]
# b = 0.?e1
# t = [35.649612954673429 .. 40.000000000000000]
# b = 0.?e1
# t = [35.651765343317684 .. 40.000000000000000]
# b = 0.?e1
# t = [35.654924477469471 .. 40.000000000000000]
# b = 0.?e1
# t = [35.659565648918025 .. 40.000000000000000]
# b = 0.?e1
# t = [35.666393565343888 .. 40.000000000000000]
# b = 0.?e1
# t = [35.676458786007657 .. 40.000000000000000]
# b = 0.?e1
# t = [35.691339591581815 .. 40.000000000000000]
# b = 0.?e1
# t = [35.713432765156525 .. 40.000000000000000]
# b = 0.?e1
# t = [35.746431900546895 .. 40.000000000000000]
# b = 0.?e1
# t = [35.796139368955785 .. 40.000000000000000]
# b = 0.?e1
# t = [35.871884931029427 .. 40.000000000000000]
# b = 0.?e1
# t = [35.989030748716025 .. 40.000000000000000]
# b = 0.?e1
# t = [36.173162362453979 .. 40.000000000000000]
# b = 0.?e1
# t = [36.453984333932396 .. 40.000000000000000]
# b = 0.?e1
# t = [36.865686698101988 .. 40.000000000000000]
# b = 0.?e1
# t = [37.386231183491815 .. 40.000000000000000]
# b = 0.?e1
# t = [37.776262771647743 .. 40.000000000000000]
# b = 0.?e1
# t = [37.855185060328849 .. 40.000000000000000]
# b = 0.?e1
# t = [37.861209924206704 .. 40.000000000000000]
# b = 0.?e1
# t = [37.861579587221370 .. 40.000000000000000]
# b = 0.?e1
# t = [37.861601874785378 .. 40.000000000000000]
# b = 0.?e1
# found lower bound!
# t = [37.861603217089751 .. 38.240319249260644]
# b = 2.?
# t = [37.861603217089751 .. 38.070729264550203]
# b = 3.?
# t = [37.861603217089751 .. 38.062142153920491]
# b = 3.?
# t = [37.861603217089751 .. 38.061635451497275]
# b = 3.?
# t = [37.861603217089751 .. 38.061605222215406]
# b = 3.?
# found upper bound!
#   I  = [35.644995760889081 .. 37.861603217089752]
# f(I) = [-2.0000000000000000 .. 1.2400592028967022]
# t = [38.062603417672804 .. 40.000000000000000]
# b = 0.?e1
# t = [38.063618184053908 .. 40.000000000000000]
# b = 0.?e1
# t = [38.065662817248529 .. 40.000000000000000]
# b = 0.?e1
# t = [38.069783216580667 .. 40.000000000000000]
# b = 0.?e1
# t = [38.078089567219208 .. 40.000000000000000]
# b = 0.?e1
# t = [38.094845345260353 .. 40.000000000000000]
# b = 0.?e1
# t = [38.128685899620947 .. 40.000000000000000]
# b = 0.?e1
# t = [38.197162292465975 .. 40.000000000000000]
# b = 0.?e1
# t = [38.335977369789233 .. 40.000000000000000]
# b = 0.?e1
# t = [38.616048773048987 .. 40.000000000000000]
# b = 0.?e1
# t = [39.156329362489259 .. 40.000000000000000]
# b = 0.?e1
# t = [39.981418739843597 .. 40.000000000000000]
# b = -3.?
# stopping since presumed converged
# t = [39.981418739843597 .. 40.000000000000000], fprime(t) = [-2.3962132082638231 .. -2.1057326158684661]

# %%
plot([(lambda x: RIF(h(x)).lower()), h, (lambda x: RIF(h(x)).upper())], 
         xmin=0, xmax=40,
         color=['blue', 'blue', 'blue'],
         linestyle=['--', '-', '--']) + sigh.plot()
# Out:
# Graphics object consisting of 5 graphics primitives

# %%
plot([(lambda x: RIF(h(x)).lower()), h, (lambda x: RIF(h(x)).upper())], 
         xmin=0, xmax=10,
         color=['blue', 'blue', 'blue'],
         linestyle=['--', '-', '--']) + to_signal(h, h.derivative(), RIF(0,10)).plot()
# Out:
# t = [0.00000000000000000 .. 10.000000000000000]
# b = 0.?e1
# t = [0.36509054541632340 .. 10.000000000000000]
# b = 0.?e1
# t = [0.74024120745358656 .. 10.000000000000000]
# b = 0.?e1
# t = [1.0251749022054170 .. 10.000000000000000]
# b = 0.?e1
# t = [1.2079034804965527 .. 10.000000000000000]
# b = 0.?e1
# t = [1.3250742365150449 .. 10.000000000000000]
# b = 0.?e1
# t = [1.4043319534612694 .. 10.000000000000000]
# b = 0.?e1
# t = [1.4607936626530344 .. 10.000000000000000]
# b = 0.?e1
# t = [1.5027034087530406 .. 10.000000000000000]
# b = 0.?e1
# t = [1.5323622589438592 .. 10.000000000000000]
# b = 0.?e1
# t = [1.5533552029330246 .. 10.000000000000000]
# b = 0.?e1
# t = [1.5684995404121846 .. 10.000000000000000]
# b = 0.?e1
# t = [1.5795752003097356 .. 10.000000000000000]
# b = 0.?e1
# t = [1.5877564659304628 .. 10.000000000000000]
# b = 0.?e1
# t = [1.5938442727884707 .. 10.000000000000000]
# b = 0.?e1
# t = [1.5983990606512259 .. 10.000000000000000]
# b = 0.?e1
# t = [1.6018207643632873 .. 10.000000000000000]
# b = 0.?e1
# t = [1.6043991133209603 .. 10.000000000000000]
# b = 0.?e1
# t = [1.6063464366342736 .. 10.000000000000000]
# b = 0.?e1
# t = [1.6078197212984304 .. 10.000000000000000]
# b = 0.?e1
# t = [1.6089358233779140 .. 10.000000000000000]
# b = 0.?e1
# t = [1.6097821766394202 .. 10.000000000000000]
# b = 0.?e1
# t = [1.6104244585990248 .. 10.000000000000000]
# b = 0.?e1
# t = [1.6109121524755225 .. 10.000000000000000]
# b = 0.?e1
# t = [1.6112826256599257 .. 10.000000000000000]
# b = 0.?e1
# t = [1.6115641454676483 .. 10.000000000000000]
# b = 0.?e1
# t = [1.6117781236809736 .. 10.000000000000000]
# b = 0.?e1
# t = [1.6119407955868363 .. 10.000000000000000]
# b = 0.?e1
# t = [1.6120644809156825 .. 10.000000000000000]
# b = 0.?e1
# t = [1.6121585336533794 .. 10.000000000000000]
# b = 0.?e1
# t = [1.6122300591537037 .. 10.000000000000000]
# b = 0.?e1
# t = [1.6122844565236640 .. 10.000000000000000]
# b = 0.?e1
# t = [1.6123258294120681 .. 10.000000000000000]
# b = 0.?e1
# t = [1.6123572974530731 .. 10.000000000000000]
# b = 0.?e1
# t = [1.6123812325773341 .. 10.000000000000000]
# b = 0.?e1
# t = [1.6123994384239350 .. 10.000000000000000]
# b = 0.?e1
# t = [1.6124132866160489 .. 10.000000000000000]
# b = 0.?e1
# t = [1.6124238203079384 .. 10.000000000000000]
# b = 0.?e1
# found lower bound!
# t = [1.6124318328845883 .. 1.8181967989772417]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8154367003222416]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8139962702765609]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8132501673642024]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8128652275712199]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8126670306211453]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8125650914227518]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8125126893510700]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8124857595127580]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8124719220543053]
# b = 0.?e1
# found upper bound!
#   I  = [0.00000000000000000 .. 1.6124318328845884]
# f(I) = [-0.97093206507591290 .. 2.0000000000000000]
# t = [1.8134648124294490 .. 10.000000000000000]
# b = 0.?e1
# t = [1.8137056301451326 .. 10.000000000000000]
# b = 0.?e1
# t = [1.8140039210021066 .. 10.000000000000000]
# b = 0.?e1
# t = [1.8143733545521394 .. 10.000000000000000]
# b = 0.?e1
# t = [1.8148308264606702 .. 10.000000000000000]
# b = 0.?e1
# t = [1.8153972064670456 .. 10.000000000000000]
# b = 0.?e1
# t = [1.8160982525513946 .. 10.000000000000000]
# b = 0.?e1
# t = [1.8169657243392751 .. 10.000000000000000]
# b = 0.?e1
# t = [1.8180387331647240 .. 10.000000000000000]
# b = 0.?e1
# t = [1.8193653698570209 .. 10.000000000000000]
# b = 0.?e1
# t = [1.8210046531546928 .. 10.000000000000000]
# b = 0.?e1
# t = [1.8230288399622334 .. 10.000000000000000]
# b = 0.?e1
# t = [1.8255261307587633 .. 10.000000000000000]
# b = 0.?e1
# t = [1.8286037852574730 .. 10.000000000000000]
# b = 0.?e1
# t = [1.8323916288883004 .. 10.000000000000000]
# b = 0.?e1
# t = [1.8370458712959294 .. 10.000000000000000]
# b = 0.?e1
# t = [1.8427530622174672 .. 10.000000000000000]
# b = 0.?e1
# t = [1.8497338630568249 .. 10.000000000000000]
# b = 0.?e1
# t = [1.8582460972287144 .. 10.000000000000000]
# b = 0.?e1
# t = [1.8685862430783848 .. 10.000000000000000]
# b = 0.?e1
# t = [1.8800899232020951 .. 10.000000000000000]
# b = 0.?e1
# t = [1.8916671921104244 .. 10.000000000000000]
# b = 0.?e1
# t = [1.9032382040130833 .. 10.000000000000000]
# b = 0.?e1
# t = [1.9147227448009103 .. 10.000000000000000]
# b = 0.?e1
# t = [1.9260424849981561 .. 10.000000000000000]
# b = 0.?e1
# t = [1.9371231439498821 .. 10.000000000000000]
# b = 0.?e1
# t = [1.9478964368680382 .. 10.000000000000000]
# b = 0.?e1
# t = [1.9583016967326443 .. 10.000000000000000]
# b = 0.?e1
# t = [1.9682870936195020 .. 10.000000000000000]
# b = 0.?e1
# t = [1.9778104103938365 .. 10.000000000000000]
# b = 0.?e1
# t = [1.9868393709061944 .. 10.000000000000000]
# b = 0.?e1
# t = [1.9953515502773411 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0033339231280060 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0107821228115199 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0176994925371078 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0240960087266017 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0299871498761921 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0353927728084162 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0403360446553451 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0448424650313072 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0489389999718503 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0526533381716207 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0560132712405470 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0590461931654449 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0617787097317576 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0642363460151673 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0664433388309677 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0684225008694152 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0701951438239980 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0717810488664869 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0731984741256885 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0744641902286842 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0755935363542370 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0766004905568049 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0774977493047539 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0782968122182827 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0790080688867105 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0796408853965333 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0802036888222743 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0807040484359764 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0811487527936458 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0815438821731890 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0818948760826572 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0822065957426429 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0824833815837142 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0827291058983599 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0829472208551775 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0831408021276294 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0833125884161227 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0834650171548609 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0836002566974247 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0837202352701700 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0838266669724903 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0839210750894756 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0840048129668158 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0840790826809367 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0841449517200296 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0842033678744003 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0842551725177762 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0843011124451269 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0843418504173594 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0843779745490231 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0844100066619439 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0844384097155326 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0844635944133420 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0844859250752443 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0845057248553282 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0845232803772186 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0845388458509090 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0845526467283663 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0845648829489951 .. 10.000000000000000]
# b = 0.?e1
# t = [2.0845757318205166 .. 10.000000000000000]
# b = 0.?e1
# found lower bound!
# t = [2.0845853505758618 .. 2.9571953803684670]
# b = 0.?e1
# t = [2.0845853505758618 .. 2.9540196408812643]
# b = 0.?e1
# t = [2.0845853505758618 .. 2.9525624574909211]
# b = 0.?e1
# t = [2.0845853505758618 .. 2.9518939080587612]
# b = 0.?e1
# t = [2.0845853505758618 .. 2.9515871931802882]
# b = 0.?e1
# t = [2.0845853505758618 .. 2.9514464818873934]
# b = 0.?e1
# t = [2.0845853505758618 .. 2.9513819283604202]
# b = 0.?e1
# t = [2.0845853505758618 .. 2.9513523135042750]
# b = 0.?e1
# t = [2.0845853505758618 .. 2.9513387272837255]
# b = 0.?e1
# found upper bound!
#   I  = [1.8124648124294489 .. 2.0845853505758619]
# f(I) = [-0.24411337554032309 .. 0.10002931460408604]
# t = [2.9523324944231594 .. 10.000000000000000]
# b = 0.?e1
# t = [2.9525644686858822 .. 10.000000000000000]
# b = 0.?e1
# t = [2.9528499712409392 .. 10.000000000000000]
# b = 0.?e1
# t = [2.9532013532532928 .. 10.000000000000000]
# b = 0.?e1
# t = [2.9536338154890007 .. 10.000000000000000]
# b = 0.?e1
# t = [2.9541660655646264 .. 10.000000000000000]
# b = 0.?e1
# t = [2.9548211266585462 .. 10.000000000000000]
# b = 0.?e1
# t = [2.9556273324963489 .. 10.000000000000000]
# b = 0.?e1
# t = [2.9566195513549127 .. 10.000000000000000]
# b = 0.?e1
# t = [2.9578406915153512 .. 10.000000000000000]
# b = 0.?e1
# t = [2.9593435523768576 .. 10.000000000000000]
# b = 0.?e1
# t = [2.9611930996930806 .. 10.000000000000000]
# b = 0.?e1
# t = [2.9634692604746564 .. 10.000000000000000]
# b = 0.?e1
# t = [2.9662703532941123 .. 10.000000000000000]
# b = 0.?e1
# t = [2.9697172930612185 .. 10.000000000000000]
# b = 0.?e1
# t = [2.9739587352655565 .. 10.000000000000000]
# b = 0.?e1
# t = [2.9791773514778796 .. 10.000000000000000]
# b = 0.?e1
# t = [2.9855974514802858 .. 10.000000000000000]
# b = 0.?e1
# t = [2.9934941791599185 .. 10.000000000000000]
# b = 0.?e1
# t = [3.0032044921733547 .. 10.000000000000000]
# b = 0.?e1
# t = [3.0151400566540815 .. 10.000000000000000]
# b = 0.?e1
# t = [3.0298019869209733 .. 10.000000000000000]
# b = 0.?e1
# t = [3.0477969255208909 .. 10.000000000000000]
# b = 0.?e1
# t = [3.0698530959869883 .. 10.000000000000000]
# b = 0.?e1
# t = [3.0968333406095718 .. 10.000000000000000]
# b = 0.?e1
# t = [3.1297392621184392 .. 10.000000000000000]
# b = 0.?e1
# t = [3.1696957147576370 .. 10.000000000000000]
# b = 0.?e1
# t = [3.2178973595804167 .. 10.000000000000000]
# b = 0.?e1
# t = [3.2754890392409019 .. 10.000000000000000]
# b = 0.?e1
# t = [3.3433428352372693 .. 10.000000000000000]
# b = 0.?e1
# t = [3.4216982923308929 .. 10.000000000000000]
# b = 0.?e1
# t = [3.5096730341813078 .. 10.000000000000000]
# b = 0.?e1
# t = [3.6047606109164425 .. 10.000000000000000]
# b = 0.?e1
# t = [3.7026053134973579 .. 10.000000000000000]
# b = 0.?e1
# t = [3.7974467062719181 .. 10.000000000000000]
# b = 0.?e1
# t = [3.8833948447880985 .. 10.000000000000000]
# b = 0.?e1
# t = [3.9450224300807770 .. 10.000000000000000]
# b = 0.?e1
# t = [3.9821174598652824 .. 10.000000000000000]
# b = 0.?e1
# t = [4.0033351575572497 .. 10.000000000000000]
# b = 0.?e1
# t = [4.0151149189322685 .. 10.000000000000000]
# b = 0.?e1
# t = [4.0215466713824259 .. 10.000000000000000]
# b = 0.?e1
# t = [4.0250264703731613 .. 10.000000000000000]
# b = 0.?e1
# t = [4.0268998669490647 .. 10.000000000000000]
# b = 0.?e1
# t = [4.0279057504095954 .. 10.000000000000000]
# b = 0.?e1
# t = [4.0284450671842151 .. 10.000000000000000]
# b = 0.?e1
# t = [4.0287340066303025 .. 10.000000000000000]
# b = 0.?e1
# t = [4.0288887425499568 .. 10.000000000000000]
# b = 0.?e1
# t = [4.0289715901239411 .. 10.000000000000000]
# b = 0.?e1
# t = [4.0290159425354552 .. 10.000000000000000]
# b = 0.?e1
# t = [4.0290396850801322 .. 10.000000000000000]
# b = 0.?e1
# t = [4.0290523944088629 .. 10.000000000000000]
# b = 0.?e1
# found lower bound!
# t = [4.0290591975597873 .. 4.2350918095841737]
# b = -1.?
# t = [4.0290591975597873 .. 4.2310189914514736]
# b = -1.?
# t = [4.0290591975597873 .. 4.2296971929897512]
# b = -1.?
# t = [4.0290591975597873 .. 4.2292702320602658]
# b = -1.?
# t = [4.0290591975597873 .. 4.2291325311631125]
# b = -1.?
# t = [4.0290591975597873 .. 4.2290881430615235]
# b = -1.?
# t = [4.0290591975597873 .. 4.2290738368155508]
# b = -1.?
# found upper bound!
#   I  = [2.9513324944231591 .. 4.0290591975597874]
# f(I) = [-0.87570952745154241 .. 1.1891143659858095]
# t = [4.2300692261671244 .. 10.000000000000000]
# b = 0.?e1
# t = [4.2305352348894107 .. 10.000000000000000]
# b = 0.?e1
# t = [4.2312181141431199 .. 10.000000000000000]
# b = 0.?e1
# t = [4.2322189987078262 .. 10.000000000000000]
# b = 0.?e1
# t = [4.2336864242035439 .. 10.000000000000000]
# b = 0.?e1
# t = [4.2358388153836123 .. 10.000000000000000]
# b = 0.?e1
# t = [4.2389979532648807 .. 10.000000000000000]
# b = 0.?e1
# t = [4.2436391302087699 .. 10.000000000000000]
# b = 0.?e1
# t = [4.2504670547540079 .. 10.000000000000000]
# b = 0.?e1
# t = [4.2605322874614000 .. 10.000000000000000]
# b = 0.?e1
# t = [4.2754131110009403 .. 10.000000000000000]
# b = 0.?e1
# t = [4.2975063115889868 .. 10.000000000000000]
# b = 0.?e1
# t = [4.3305054880499449 .. 10.000000000000000]
# b = 0.?e1
# t = [4.3802130198386945 .. 10.000000000000000]
# b = 0.?e1
# t = [4.4559586815745539 .. 10.000000000000000]
# b = 0.?e1
# t = [4.5731046592080932 .. 10.000000000000000]
# b = 0.?e1
# t = [4.7572365328168499 .. 10.000000000000000]
# b = 0.?e1
# t = [5.0380588603631730 .. 10.000000000000000]
# b = 0.?e1
# t = [5.4497616593030393 .. 10.000000000000000]
# b = 0.?e1
# t = [5.9703062777299180 .. 10.000000000000000]
# b = 0.?e1
# t = [6.3603368086293015 .. 10.000000000000000]
# b = 0.?e1
# t = [6.4392585765781920 .. 10.000000000000000]
# b = 0.?e1
# t = [6.4452833915608822 .. 10.000000000000000]
# b = 0.?e1
# t = [6.4456530515197156 .. 10.000000000000000]
# b = 0.?e1
# t = [6.4456753388992718 .. 10.000000000000000]
# b = 0.?e1
# found lower bound!
# t = [6.4456766811925305 .. 6.7078030417124364]
# b = 3.?
# t = [6.4456766811925305 .. 6.6490795283787270]
# b = 3.?
# t = [6.4456766811925305 .. 6.6458791055960989]
# b = 3.?
# t = [6.4456766811925305 .. 6.6456888435374380]
# b = 3.?
# t = [6.4456766811925305 .. 6.6456774881257550]
# b = 3.?
# found upper bound!
#   I  = [4.2290692261671241 .. 6.4456766811925306]
# f(I) = [-2.0000000000000000 .. 1.2400592020229553]
# t = [6.6466768102460482 .. 10.000000000000000]
# b = 0.?e1
# t = [6.6476119728140190 .. 10.000000000000000]
# b = 0.?e1
# t = [6.6494218176742032 .. 10.000000000000000]
# b = 0.?e1
# t = [6.6529249766820051 .. 10.000000000000000]
# b = 0.?e1
# t = [6.6597076427875077 .. 10.000000000000000]
# b = 0.?e1
# t = [6.6728468373041671 .. 10.000000000000000]
# b = 0.?e1
# t = [6.6983236833485326 .. 10.000000000000000]
# b = 0.?e1
# t = [6.7477994638543856 .. 10.000000000000000]
# b = 0.?e1
# t = [6.8440669489155379 .. 10.000000000000000]
# b = 0.?e1
# t = [7.0313288918422509 .. 10.000000000000000]
# b = 0.?e1
# t = [7.3898254608126086 .. 10.000000000000000]
# b = 0.?e1
# t = [8.0170865479600532 .. 10.000000000000000]
# b = 0.?e1
# t = [8.6981366939060329 .. 10.000000000000000]
# b = 0.?e1
# t = [8.8531161674796905 .. 10.000000000000000]
# b = 0.?e1
# t = [8.8617013325852731 .. 10.000000000000000]
# b = 0.?e1
# t = [8.8622488015273059 .. 10.000000000000000]
# b = 0.?e1
# t = [8.8622840705895526 .. 10.000000000000000]
# b = 0.?e1
# found lower bound!
# t = [8.8622863440827313 .. 9.1311254925947801]
# b = -2.?
# t = [8.8622863440827313 .. 9.0672197079843180]
# b = -3.?
# t = [8.8622863440827313 .. 9.0625850503964625]
# b = -3.?
# t = [8.8622863440827313 .. 9.0623043381865252]
# b = -3.?
# t = [8.8622863440827313 .. 9.0622875656432580]
# b = -3.?
# found upper bound!
#   I  = [6.6456768102460479 .. 8.8622863440827314]
# f(I) = [1.0462444777203927e-7 .. 2.0000000000000000]
# t = [9.0632865643120368 .. 10.000000000000000]
# b = 0.?e1
# t = [9.0751452034618971 .. 10.000000000000000]
# b = 0.?e1
# t = [9.2274083018831714 .. 10.000000000000000]
# b = 0.?e1
# stopping since presumed converged
# t = [9.2274083018831714 .. 10.000000000000000], fprime(t) = [-2.2959604685799353 .. 0.20499142657861492]
# Graphics object consisting of 5 graphics primitives

# %% [markdown]
# #### Properties of uncertain trace

# %% [markdown]
# $\mathrel{\mathbf F_{[2,6]}} (x > 0)$

# %%
sigh.F(RIF(2,6)).plot()
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# $\mathrel{\mathbf G_{[2,3]}} (x > 0)$

# %%
sigh.G(RIF(2,3)).to_domain(RIF(0,40)).plot()
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# $\mathrel{\mathbf F_{[0.5,1.5]}} (x > 0)$

# %%
sigh.F(RIF(0.5,1.5)).to_domain(RIF(0,40)).plot()
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# ${\mathrel{\mathbf G_{[2,3]}} (x > 0)} \wedge {\mathrel{\mathbf F_{[0.5,1.5]}} (x > 0)}$

# %%
(sigh.G(RIF(2,3)) & sigh.F(RIF(0.5,1.5))).to_domain(RIF(0,40)).plot()
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# ${\mathrel{\mathbf G_{[2,3]}} (x > 0)} \vee {\mathrel{\mathbf F_{[0.5,1.5]}} (x > 0)}$

# %%
(sigh.G(RIF(2,3)) | sigh.F(RIF(0.5,1.5))).to_domain(RIF(0,40)).plot()
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# $\left(
#     \mathrel{\mathbf F_{[0.5,1.5]}} (x > 0)
#  \right)
#  \mathrel{\mathbf U_{[0.5,2]}}
#  \left(
#      \mathrel{\mathbf G_{[2,3]}} (x > 0)
#  \right)$

# %%
sigh.F(RIF(0.5,1.5)).U(RIF(0.5,2), sigh.G(RIF(2,3))).to_domain(RIF(0,40)).plot()
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# ### Discontinuities

# %%
R.<x> = QQ[]

# %%
seq = TMSeq([(RIF(0,1), sinTM), (RIF(1,2), sinTM.mul(TM(x, RIF(0)), RIF(1,2)))])

# %%
seq2.plot() + to_signal(seq2, seq2.map(lambda x: x.derivative()), RIF(0,2)).plot()
# Out:
# t = [0.00000000000000000 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.22305659186139367 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.37737681148048890 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.48593577726979125 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.56387171206445707 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.62085641541039093 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.66315324178627454 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.69492486506506190 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.71901443097139117 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.73741283829725245 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.75154444054863056 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.76244670643666678 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.77088651852205702 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.77743756493495586 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.78253316164517650 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.78650313146697969 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.78960006866564802 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.79201836750541787 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.79390821056442884 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.79538597822256729 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.79654207376182395 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.79744685477911181 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.79815515967443839 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.79870978089450350 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.79914414171146241 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.79948436641438092 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.79975088584086095 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.79995968529886030 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.80012327622967471 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.80025145381481743 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.80035188832681292 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.80043058710466608 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.80049225570220150 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.80054058036474295 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.80057844906380970 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.80060812451074048 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.80063137961685837 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.80064960357269265 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.80066388493202311 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.80067507669355353 .. 2.0000000000000000]
# b = 0.?e1
# found lower bound!
# t = [0.80068384728585806 .. 1.0936061376845697]
# b = 1.?
# t = [0.80068384728585806 .. 1.0893707707467136]
# b = 1.?
# t = [0.80068384728585806 .. 1.0886264176202126]
# b = 1.?
# t = [0.80068384728585806 .. 1.0884983903154908]
# b = 1.?
# t = [0.80068384728585806 .. 1.0884764541109116]
# b = 1.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.80068384728585807]
# f(I) = [-0.88214588661112848 .. 0.082829733896986377]
# t = [1.0894726980427247 .. 2.0000000000000000]
# b = 0.?e1
# t = [1.0907576699610184 .. 2.0000000000000000]
# b = 0.?e1
# t = [1.0936951127309499 .. 2.0000000000000000]
# b = 0.?e1
# t = [1.1004211073990199 .. 2.0000000000000000]
# b = 0.?e1
# t = [1.1158799996883312 .. 2.0000000000000000]
# b = 0.?e1
# t = [1.1517218369275605 .. 2.0000000000000000]
# b = 0.?e1
# t = [1.2365578536575796 .. 2.0000000000000000]
# b = 0.?e1
# t = [1.4480559582475893 .. 2.0000000000000000]
# b = 0.?e1
# stopping since presumed converged
# t = [1.4480559582475893 .. 2.0000000000000000], fprime(t) = [-0.76538616559115303 .. 2.1513838043968474]
# Graphics object consisting of 8 graphics primitives

# %%
(seq).plot() + to_signal(seq, seq.map(lambda x: x.derivative()), RIF(0,2)).plot()
# Out:
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.082894013557463093]
# b = 1.0?
# t = [0.00000000000000000 .. 0.082290373755875571]
# b = 1.0?
# t = [0.00000000000000000 .. 0.082242649856629935]
# b = 1.0?
# found upper bound!
# t = [0.083238877977612868 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.084106942554354316 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.085728240730594595 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.088756217361355138 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.094410813845127061 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.10496857952431262 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.12467396537926404 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.16142480133802580 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.22984824014533056 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.35670429321091823 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.58923445315639944 .. 2.0000000000000000]
# b = 0.?e1
# t = [1.0016091403223750 .. 2.0000000000000000]
# b = 0.?e1
# t = [1.5937853442959788 .. 2.0000000000000000]
# b = 0.?e1
# stopping since presumed converged
# t = [1.5937853442959788 .. 2.0000000000000000], fprime(t) = [-0.61058799669466557 .. 1.7115486307360528]
# Graphics object consisting of 8 graphics primitives

# %%
seq3 = seq.map(lambda x: x - 0.72)

# %% [markdown]
# Method can be fooled by discontinuities!

# %%
(seq3).plot() + to_signal(seq3, seq3.map(lambda x: x.derivative()), RIF(0,2)).plot()
# Out:
# t = [0.00000000000000000 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.19819843890790508 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.33521370496208224 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.43119200484833575 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.49952088920076526 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.54887957776491635 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.58496193630980031 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.61158703400989944 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.63137617420562242 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.64616614469796784 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.65726663736262869 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.66562486415731392 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.67193369417463344 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.67670449994970560 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.68031734405611521 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.68305623045711882 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.68513427170887319 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.68671189944633015 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.68791018522508851 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.68882066974965061 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.68951266577780623 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.69003871338133671 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.69043867218389565 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.69074280114600339 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.69097408221584633 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.69114997687787038 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.69128375597275948 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.69138550759882322 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.69146290168627400 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.69152177037228301 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.69156654877606804 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.69160060988141236 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.69162651904104499 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.69164622743835557 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.69166121917248557 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.69167262309867283 .. 2.0000000000000000]
# b = 0.?e1
# found lower bound!
# t = [0.69168129787762411 .. 0.93576037625373943]
# b = 1.?
# t = [0.69168129787762411 .. 0.93238525513673221]
# b = 1.?
# t = [0.69168129787762411 .. 0.93134302738029984]
# b = 1.?
# t = [0.69168129787762411 .. 0.93102347724569746]
# b = 1.?
# t = [0.69168129787762411 .. 0.93092571814392633]
# b = 1.?
# t = [0.69168129787762411 .. 0.93089583120433506]
# b = 1.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.69168129787762412]
# f(I) = [-0.80214588661112841 .. 0.053827184488752497]
# t = [0.93188669605305463 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.93240837757183825 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.93320084257661106 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.93440427947681903 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.93623097754992168 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.93900178564061620 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.94320018898451463 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.94955143804849484 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.95913583402293722 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.97354510939731253 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.99508476222768016 .. 2.0000000000000000]
# b = 0.?e1
# t = [1.0270039702458759 .. 2.0000000000000000]
# b = 0.?e1
# found lower bound!
# t = [1.0270039702458759 .. 1.0373740099483347]
# b = 2.?
# t = [1.0270039702458759 .. 1.0316555923073667]
# b = 2.?
# t = [1.0270039702458759 .. 1.0310010384896840]
# b = 2.?
# t = [1.0270039702458759 .. 1.0309293980899932]
# b = 2.?
# found upper bound!
#   I  = [0.93088669605305462 .. 1.0270039702458760]
# f(I) = [-0.051512551015264724 .. 0.33228926125526970]
# t = [1.0319215981490352 .. 2.0000000000000000]
# b = 0.?e1
# t = [1.0331554692121944 .. 2.0000000000000000]
# b = 0.?e1
# t = [1.0359126803851381 .. 2.0000000000000000]
# b = 0.?e1
# t = [1.0420833582747832 .. 2.0000000000000000]
# b = 0.?e1
# t = [1.0559407864382042 .. 2.0000000000000000]
# b = 0.?e1
# t = [1.0873019723962542 .. 2.0000000000000000]
# b = 0.?e1
# t = [1.1595493984411571 .. 2.0000000000000000]
# b = 0.?e1
# t = [1.3332351668160926 .. 2.0000000000000000]
# b = 0.?e1
# t = [1.8024433441231513 .. 2.0000000000000000]
# b = 0.?
# stopping since presumed converged
# t = [1.8024433441231513 .. 2.0000000000000000], fprime(t) = [-0.36312281777742095 .. 0.99804844449729380]
# Graphics object consisting of 8 graphics primitives

# %%
(seq3).plot() + to_signal(seq3, seq3.map(lambda x: x.derivative()), RIF(0,1)).plot() \
              + to_signal(seq3, seq3.map(lambda x: x.derivative()), RIF(1,2)).plot()
# Out:
# t = [0.00000000000000000 .. 1.0000000000000000]
# b = 1.?
# t = [0.41257342565562599 .. 1.0000000000000000]
# b = 1.?
# t = [0.56579475429632908 .. 1.0000000000000000]
# b = 1.?
# t = [0.63161930407313571 .. 1.0000000000000000]
# b = 1.?
# t = [0.66227944056672138 .. 1.0000000000000000]
# b = 1.?
# t = [0.67711619466854677 .. 1.0000000000000000]
# b = 1.?
# t = [0.68442917971489913 .. 1.0000000000000000]
# b = 1.?
# t = [0.68806644488547286 .. 1.0000000000000000]
# b = 1.?
# t = [0.68988364602154761 .. 1.0000000000000000]
# b = 1.?
# t = [0.69079356565009131 .. 1.0000000000000000]
# b = 1.?
# t = [0.69124969653999634 .. 1.0000000000000000]
# b = 1.?
# t = [0.69147847740414603 .. 1.0000000000000000]
# b = 1.?
# t = [0.69159325897182899 .. 1.0000000000000000]
# b = 1.?
# t = [0.69165085412457605 .. 1.0000000000000000]
# b = 1.?
# t = [0.69167975629702460 .. 1.0000000000000000]
# b = 1.?
# t = [0.69169426038691739 .. 1.0000000000000000]
# b = 1.?
# found lower bound!
# t = [0.69170153916077081 .. 0.93578765844527335]
# b = 1.?
# t = [0.69170153916077081 .. 0.93239367460899392]
# b = 1.?
# t = [0.69170153916077081 .. 0.93134559734005651]
# b = 1.?
# t = [0.69170153916077081 .. 0.93102425901159025]
# b = 1.?
# t = [0.69170153916077081 .. 0.93092595569525772]
# b = 1.?
# t = [0.69170153916077081 .. 0.93089590336202533]
# b = 1.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.69170153916077082]
# f(I) = [-0.80214588661112841 .. 0.053847425771899202]
# t = [0.93188671796839428 .. 1.0000000000000000]
# b = 1.?
# stopping since presumed converged
# t = [0.93188671796839428 .. 1.0000000000000000], fprime(t) = [0.45283185338699832 .. 1.5460378049682888]
# 0 on lower boundary!
# t = [1.0000000000000000 .. 1.0410100500999997]
# b = 1.?
# t = [1.0000000000000000 .. 1.0322931135510288]
# b = 1.?
# t = [1.0000000000000000 .. 1.0310981787199352]
# b = 1.?
# t = [1.0000000000000000 .. 1.0309434470604613]
# b = 1.?
# t = [1.0000000000000000 .. 1.0309235715311181]
# b = 1.?
# found upper bound!
# t = [1.0319210211581133 .. 2.0000000000000000]
# b = 0.?e1
# t = [1.0331541804744892 .. 2.0000000000000000]
# b = 0.?e1
# t = [1.0359097992129473 .. 2.0000000000000000]
# b = 0.?e1
# t = [1.0420769033713119 .. 2.0000000000000000]
# b = 0.?e1
# t = [1.0559262563485611 .. 2.0000000000000000]
# b = 0.?e1
# t = [1.0872689117005767 .. 2.0000000000000000]
# b = 0.?e1
# t = [1.1594722803099795 .. 2.0000000000000000]
# b = 0.?e1
# t = [1.3330439859001754 .. 2.0000000000000000]
# b = 0.?e1
# t = [1.8018767562608446 .. 2.0000000000000000]
# b = 0.?e1
# stopping since presumed converged
# t = [1.8018767562608446 .. 2.0000000000000000], fprime(t) = [-0.36383595441958628 .. 1.0001229087288702]
# Graphics object consisting of 10 graphics primitives

# %%
(seq3).plot() + seq3.to_signal().plot()
# Out:
# t = [0.00000000000000000 .. 1.0000000000000000]
# b = 1.?
# t = [0.58943449425880023 .. 1.0000000000000000]
# b = 1.?
# t = [0.67826046215408553 .. 1.0000000000000000]
# b = 1.?
# t = [0.69021766324743538 .. 1.0000000000000000]
# b = 1.?
# t = [0.69154852355063811 .. 1.0000000000000000]
# b = 1.?
# t = [0.69169169121608453 .. 1.0000000000000000]
# b = 1.?
# t = [0.69170703181905968 .. 1.0000000000000000]
# b = 1.?
# found lower bound!
# t = [0.69170867488342058 .. 0.93579727632130694]
# b = 1.?
# t = [0.69170867488342058 .. 0.93239664279210699]
# b = 1.?
# t = [0.69170867488342058 .. 0.93134650332281977]
# b = 1.?
# t = [0.69170867488342058 .. 0.93102453459454793]
# b = 1.?
# t = [0.69170867488342058 .. 0.93092603943146213]
# b = 1.?
# t = [0.69170867488342058 .. 0.93089592879621653]
# b = 1.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.69170867488342059]
# f(I) = [-0.80214588661112841 .. 0.053854561494548967]
# t = [0.93188672569275821 .. 1.0000000000000000]
# b = 1.?
# stopping since presumed converged
# t = [0.93188672569275821 .. 1.0000000000000000], fprime(t) = [0.45283185396685593 .. 0.68307590348010883]
# 0 on lower boundary!
# t = [1.0000000000000000 .. 1.0410100500999997]
# b = 2.?
# t = [1.0000000000000000 .. 1.0322931135510285]
# b = 2.?
# t = [1.0000000000000000 .. 1.0310981787199347]
# b = 2.?
# t = [1.0000000000000000 .. 1.0309434470604611]
# b = 2.?
# t = [1.0000000000000000 .. 1.0309235715311178]
# b = 2.?
# found upper bound!
# t = [1.0319210211581131 .. 2.0000000000000000]
# b = 0.?e1
# t = [1.0331541804744890 .. 2.0000000000000000]
# b = 0.?e1
# t = [1.0359097992129471 .. 2.0000000000000000]
# b = 0.?e1
# t = [1.0420769033713117 .. 2.0000000000000000]
# b = 0.?e1
# t = [1.0559262563485607 .. 2.0000000000000000]
# b = 0.?e1
# t = [1.0872689117005760 .. 2.0000000000000000]
# b = 0.?e1
# t = [1.1594722803099781 .. 2.0000000000000000]
# b = 0.?e1
# t = [1.3330439859001725 .. 2.0000000000000000]
# b = 0.?e1
# t = [1.8018767562608364 .. 2.0000000000000000]
# b = 0.?e1
# stopping since presumed converged
# t = [1.8018767562608364 .. 2.0000000000000000], fprime(t) = [-0.36383595441959605 .. 1.0001229087288999]
# Graphics object consisting of 8 graphics primitives

# %% [markdown]
# ### Example: topologist's Sine curve

# %%
w(x) = sin(1/x) #if x > 0 else 0)

# %%
w(0.5)
# Out:
# 0.909297426825682

# %%
p = plot(w(x), (x,0,1))
p
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
tsc = to_signal(w, w.derivative(), RIF(0.00000001,1))
tsc
# Out:
# t = [1.0000000000000000e-8 .. 1.0000000000000000]
# b = 0.?e16
# found lower bound!
# t = [1.0000000093163903e-8 .. 0.00010001010000009409]
# b = 0.?e16
# found upper bound!
#   I  = [1.0000000000000000e-8 .. 1.0000000093163904e-8]
# f(I) = [0.84739307245149408 .. 1.0000000000000000]
# t = [0.0011000101000000297 .. 1.0000000000000000]
# b = 0.?e6
# found lower bound!
# t = [0.0011011205534532096 .. 0.0012121317589877414]
# b = 0.?e6
# found upper bound!
#   I  = [0.00010001010000002972 .. 0.0011011205534532097]
# f(I) = [-1.0000000000000000 .. 1.0000000000000000]
# t = [0.0022109826675149276 .. 1.0000000000000000]
# b = 0.?e6
# found lower bound!
# t = [0.0022114792680782992 .. 0.0023335940607590819]
# b = 0.?e6
# found upper bound!
#   I  = [0.0012109826675149276 .. 0.0022114792680782993]
# f(I) = [-1.0000000000000000 .. 1.0000000000000000]
# t = [0.0033289274552688167 .. 1.0000000000000000]
# b = 0.?e5
# t = [0.0033392392964949049 .. 1.0000000000000000]
# b = 0.?e5
# found lower bound!
# t = [0.0033487296458671227 .. 0.0034822169423257936]
# b = 0.?e5
# t = [0.0033487296458671227 .. 0.0034714469899484492]
# b = 0.?e5
# found upper bound!
#   I  = [0.0023289274552688167 .. 0.0033487296458671228]
# f(I) = [-1.0000000000000000 .. 1.0000000000000000]
# t = [0.0044622463996617641 .. 1.0000000000000000]
# b = 0.?e5
# t = [0.0044795112124073471 .. 1.0000000000000000]
# b = 0.?e5
# found lower bound!
# t = [0.0044832134034273026 .. 0.0046280455374615743]
# b = 0.?e5
# t = [0.0044832134034273026 .. 0.0046151594809279362]
# b = 0.?e5
# found upper bound!
#   I  = [0.0034622463996617637 .. 0.0044832134034273027]
# f(I) = [-1.0000000000000000 .. 1.0000000000000000]
# t = [0.0056132998107004178 .. 1.0000000000000000]
# b = 0.?e5
# t = [0.0056384152018383228 .. 1.0000000000000000]
# b = 0.?e5
# t = [0.0056698724520694004 .. 1.0000000000000000]
# b = 0.?e5
# t = [0.0056836124779284912 .. 1.0000000000000000]
# b = 0.?e5
# found lower bound!
# t = [0.0056841050486393122 .. 0.0058409460991257047]
# b = 0.?e5
# t = [0.0056841050486393122 .. 0.0058086392447059960]
# b = 0.?e5
# t = [0.0056841050486393122 .. 0.0057895983888485810]
# b = 0.?e5
# found upper bound!
#   I  = [0.0046132998107004177 .. 0.0056841050486393123]
# f(I) = [-1.0000000000000000 .. 1.0000000000000000]
# t = [0.0067875306130068865 .. 1.0000000000000000]
# b = 0.?e5
# t = [0.0068022792901233884 .. 1.0000000000000000]
# b = 0.?e5
# t = [0.0068301087055716329 .. 1.0000000000000000]
# b = 0.?e5
# t = [0.0068742946477313325 .. 1.0000000000000000]
# b = 0.?e5
# t = [0.0069129032569875030 .. 1.0000000000000000]
# b = 0.?e5
# found lower bound!
# t = [0.0069197496607895309 .. 0.0070889471573974250]
# b = 0.?e5
# t = [0.0069197496607895309 .. 0.0070744770037286728]
# b = 0.?e5
# found upper bound!
#   I  = [0.0057875306130068865 .. 0.0069197496607895310]
# f(I) = [-1.0000000000000000 .. 1.0000000000000000]
# t = [0.0080735929360863413 .. 1.0000000000000000]
# b = 0.?e5
# t = [0.0081370247232393829 .. 1.0000000000000000]
# b = 0.?e5
# t = [0.0081611484169811735 .. 1.0000000000000000]
# b = 0.?e5
# found lower bound!
# t = [0.0081617918926787640 .. 0.0083434098116055497]
# b = 0.?e5
# t = [0.0081617918926787640 .. 0.0083129707573542256]
# b = 0.?e5
# t = [0.0081617918926787640 .. 0.0082602386302027976]
# b = 1.?e4
# t = [0.0081617918926787640 .. 0.0081940305074920030]
# b = 2.?e4
# t = [0.0081617918926787640 .. 0.0081631480704215023]
# b = 1.501?e4
# found upper bound!
#   I  = [0.0070735929360863404 .. 0.0081617918926787641]
# f(I) = [-1.0000000000000000 .. 1.0000000000000000]
# t = [0.0091617922723588526 .. 1.0000000000000000]
# b = 0.?e5
# t = [0.0092224019222890002 .. 1.0000000000000000]
# b = 0.?e5
# t = [0.0093073619881599550 .. 1.0000000000000000]
# b = 0.?e5
# t = [0.0093582352440160238 .. 1.0000000000000000]
# b = 0.?e5
# found lower bound!
# t = [0.0093620527071751058 .. 0.0095556732342468552]
# b = 0.?e5
# t = [0.0093620527071751058 .. 0.0094830130537391384]
# b = -1.?e4
# t = [0.0093620527071751058 .. 0.0093972607599716318]
# b = -1.1?e4
# t = [0.0093620527071751058 .. 0.0093631159672061347]
# b = -1.141?e4
# found upper bound!
#   I  = [0.0081617922723588517 .. 0.0093620553041184676]
# f(I) = [-1.0000000000000000 .. 1.0000000000000000]
# t = [0.010362055622601373 .. 1.0000000000000000]
# b = 0.?e4
# t = [0.010445045332297875 .. 1.0000000000000000]
# b = 0.?e4
# t = [0.010553800558226595 .. 1.0000000000000000]
# b = 0.?e4
# t = [0.010607670436206200 .. 1.0000000000000000]
# b = 0.?e4
# found lower bound!
# t = [0.010610328625743112 .. 0.010816431912000543]
# b = 0.?e4
# t = [0.010610328625743112 .. 0.010706691846831207]
# b = -1.?e4
# t = [0.010610328625743112 .. 0.010622243673929617]
# b = -8.9?e3
# t = [0.010610328625743112 .. 0.010610365056804690]
# b = -8882.6?
# found upper bound!
#   I  = [0.0093620556226013725 .. 0.010610329539339620]
# f(I) = [-1.0000000000000000 .. 1.0000000000000000]
# t = [0.011610329539585290 .. 1.0000000000000000]
# b = 0.?e4
# t = [0.011740473124400369 .. 1.0000000000000000]
# b = 0.?e4
# t = [0.011788053692090932 .. 1.0000000000000000]
# b = 0.?e4
# found lower bound!
# t = [0.011789254906462778 .. 0.012007147455527405]
# b = 1.?e4
# t = [0.011789254906462778 .. 0.011868229971582304]
# b = 1.?e4
# t = [0.011789254906462778 .. 0.011793880264200181]
# b = 7.19?e3
# found upper bound!
#   I  = [0.010610329539585289 .. 0.011789254906462779]
# f(I) = [-1.0000000000000000 .. 1.0000000000000000]
# t = [0.012789257710469724 .. 1.0000000000000000]
# b = 0.?e4
# t = [0.012845220206122925 .. 1.0000000000000000]
# b = 0.?e4
# t = [0.012950229159727004 .. 1.0000000000000000]
# b = 0.?e4
# t = [0.013112736768808438 .. 1.0000000000000000]
# b = 0.?e4
# t = [0.013243435770704614 .. 1.0000000000000000]
# b = 0.?e4
# t = [0.013262843497556697 .. 1.0000000000000000]
# b = 0.?e4
# found lower bound!
# t = [0.013262911923969852 .. 0.013495541043209551]
# b = -1.?e4
# t = [0.013262911923969852 .. 0.013326061785834457]
# b = -6.?e3
# t = [0.013262911923969852 .. 0.013264539948000108]
# b = -5684.?
# found upper bound!
#   I  = [0.011789257710469723 .. 0.013262911923969853]
# f(I) = [-1.0000000000000000 .. 1.0000000000000000]
# t = [0.014262912147373676 .. 1.0000000000000000]
# b = 0.?e4
# t = [0.014433748358496338 .. 1.0000000000000000]
# b = 0.?e4
# t = [0.014468385499376451 .. 1.0000000000000000]
# b = 0.?e4
# found lower bound!
# t = [0.014468631185943837 .. 0.014713317497803275]
# b = -1.?e4
# t = [0.014468631185943837 .. 0.014522289565405798]
# b = -5.?e3
# t = [0.014468631185943837 .. 0.014469408630788614]
# b = -4777.?
# found upper bound!
#   I  = [0.013262912147373675 .. 0.014468631185943838]
# f(I) = [-1.0000000000000000 .. 1.0000000000000000]
# t = [0.015468631233731384 .. 1.0000000000000000]
# b = 0.?e4
# t = [0.015700804187301586 .. 1.0000000000000000]
# b = 0.?e4
# t = [0.015887487490839853 .. 1.0000000000000000]
# b = 0.?e4
# t = [0.015915387895834399 .. 1.0000000000000000]
# b = 0.?e4
# found lower bound!
# t = [0.015915494308474904 .. 0.016174649251559651]
# b = -3.?e3
# t = [0.015915494308474904 .. 0.015960588600172476]
# b = -3.9?e3
# t = [0.015915494308474904 .. 0.015915857526484796]
# b = -3948.?
# found upper bound!
#   I  = [0.014468631233731384 .. 0.015915494308474905]
# f(I) = [-1.0000000000000000 .. 1.0000000000000000]
# t = [0.016915494317603047 .. 1.0000000000000000]
# b = 0.?e4
# t = [0.017070590420363480 .. 1.0000000000000000]
# b = 0.?e4
# t = [0.017331598756182814 .. 1.0000000000000000]
# b = 0.?e4
# t = [0.017605706761170708 .. 1.0000000000000000]
# b = 0.?e4
# t = [0.017682721684473632 .. 1.0000000000000000]
# b = 0.?e4
# found lower bound!
# t = [0.017683882486892166 .. 0.017960721311761089]
# b = -1.?e4
# t = [0.017683882486892166 .. 0.017721374927561641]
# b = -3.2?e3
# t = [0.017683882486892166 .. 0.017684051073055738]
# b = -3197.7?
# found upper bound!
#   I  = [0.015915494317603046 .. 0.017683882564144157]
# f(I) = [-1.0000000000000000 .. 1.0000000000000000]
# t = [0.018683882567381477 .. 1.0000000000000000]
# b = 0.?e4
# t = [0.018723936114687856 .. 1.0000000000000000]
# b = 0.?e4
# found lower bound!
# t = [0.018724110950347885 .. 0.019011352059851363]
# b = 2.?e3
# t = [0.018724110950347885 .. 0.018758167414183951]
# b = 2.9?e3
# t = [0.018724110950347885 .. 0.018724226027342656]
# b = 2852.3?
# found upper bound!
#   I  = [0.017683882567381476 .. 0.018724110951276321]
# f(I) = [-1.0000000000000000 .. -2.0290344124780196e-9]
# t = [0.019724110952697007 .. 1.0000000000000000]
# b = 0.?e4
# t = [0.019887664117517640 .. 1.0000000000000000]
# b = 0.?e4
# found lower bound!
# t = [0.019894365306884372 .. 0.020193308959953215]
# b = -2.?e3
# t = [0.019894365306884372 .. 0.019925231009683489]
# b = -2.52?e3
# t = [0.019894365306884372 .. 0.019894446823884468]
# b = -2526.6?
# found upper bound!
#   I  = [0.018724110952697006 .. 0.019894367886172660]
# f(I) = [7.9400823149496042e-10 .. 1.0000000000000000]
# t = [0.020894367886821123 .. 1.0000000000000000]
# b = 0.?e4
# t = [0.021187419717675865 .. 1.0000000000000000]
# b = 0.?e4
# t = [0.021220576791137969 .. 1.0000000000000000]
# b = 0.?e4
# found lower bound!
# t = [0.021220659078599827 .. 0.021532865669385823]
# b = 2.?e3
# t = [0.021220659078599827 .. 0.021248572425323590]
# b = 2.22?e3
# t = [0.021220659078599827 .. 0.021220713548853878]
# b = 2220.7?
# found upper bound!
#   I  = [0.019894367886821123 .. 0.021220659078779295]
# f(I) = [-1.0000000000000000 .. -3.1107022003189431e-10]
# t = [0.022220659079059332 .. 1.0000000000000000]
# b = 0.?e4
# t = [0.022641618226911453 .. 1.0000000000000000]
# b = 0.?e4
# t = [0.022735492438700106 .. 1.0000000000000000]
# b = 0.?e4
# found lower bound!
# t = [0.022736420403323777 .. 0.023063784607357013]
# b = -2.?e3
# t = [0.022736420403323777 .. 0.022761624098064475]
# b = -1.93?e3
# t = [0.022736420403323777 .. 0.022736458300227563]
# b = -1934.44?
# found upper bound!
#   I  = [0.021220659079059331 .. 0.022736420441636228]
# f(I) = [1.2206952749806640e-10 .. 1.0000000000000000]
# t = [0.023736420441762540 .. 1.0000000000000000]
# b = 0.?e4
# t = [0.024277560134618555 .. 1.0000000000000000]
# b = 0.?e4
# t = [0.024479440441603474 .. 1.0000000000000000]
# b = 0.?e4
# found lower bound!
# t = [0.024485374324527180 .. 0.024830228067772451]
# b = 2.?e3
# t = [0.024485374324527180 .. 0.024508108962490287]
# b = 1.67?e3
# t = [0.024485374324527180 .. 0.024485402381762722]
# b = 1667.96?
# found upper bound!
#   I  = [0.022736420441762539 .. 0.024485375860262848]
# f(I) = [-1.0000000000000000 .. -4.7935173627216262e-11]
# t = [0.025485375860323657 .. 1.0000000000000000]
# b = 0.?e4
# t = [0.026134553539664463 .. 1.0000000000000000]
# b = 0.?e4
# t = [0.026499908768917994 .. 1.0000000000000000]
# b = 0.?e4
# t = [0.026525792665820793 .. 1.0000000000000000]
# b = 0.?e4
# found lower bound!
# t = [0.026525823848612548 .. 0.026891082087098673]
# b = -2.?e3
# t = [0.026525823848612548 .. 0.026546325411698543]
# b = -1.42?e3
# t = [0.026525823848612548 .. 0.026525842575950438]
# b = -1421.23?
# found upper bound!
#   I  = [0.024485375860323656 .. 0.026525823848635999]
# f(I) = [1.8792385784695670e-11 .. 1.0000000000000000]
# t = [0.027525823848662454 .. 1.0000000000000000]
# b = 0.?e4
# t = [0.028268209831142036 .. 1.0000000000000000]
# b = 0.?e4
# t = [0.028851320664918227 .. 1.0000000000000000]
# b = 0.?e4
# t = [0.028936855890195029 .. 1.0000000000000000]
# b = 0.?e4
# found lower bound!
# t = [0.028937262374618549 .. 0.029326634998364732]
# b = 1.1?e3
# t = [0.028937262374618549 .. 0.028955771274177107]
# b = 1.20?e3
# t = [0.028937262374618549 .. 0.028937275715708547]
# b = 1194.222?
# found upper bound!
#   I  = [0.026525823848662453 .. 0.028937262380338461]
# f(I) = [-1.0000000000000000 .. -7.3350066352439722e-12]
# t = [0.029937262380350763 .. 1.0000000000000000]
# b = 0.?e4
# t = [0.030756895665341683 .. 1.0000000000000000]
# b = 0.?e4
# t = [0.031598721290174353 .. 1.0000000000000000]
# b = 0.?e4
# t = [0.031827250003476324 .. 1.0000000000000000]
# b = 0.?e3
# found lower bound!
# t = [0.031830988170786479 .. 0.032249298052494338]
# b = -9.?e2
# t = [0.031830988170786479 .. 0.031847747031458138]
# b = -986.?
# t = [0.031830988170786479 .. 0.031830998200072951]
# b = -986.960?
# found upper bound!
#   I  = [0.028937262380350763 .. 0.031830988618376182]
# f(I) = [2.8480517235988541e-12 .. 1.0000000000000000]
# t = [0.032830988618382225 .. 1.0000000000000000]
# b = 0.?e3
# t = [0.033712052274892378 .. 1.0000000000000000]
# b = 0.?e3
# t = [0.034829753391078827 .. 1.0000000000000000]
# b = 0.?e3
# t = [0.035342896648927389 .. 1.0000000000000000]
# b = 0.?e3
# t = [0.035367746006195598 .. 1.0000000000000000]
# b = 0.?e3
# found lower bound!
# t = [0.035367765131521948 .. 0.035821442782837159]
# b = 8.?e2
# t = [0.035367765131521948 .. 0.035383022888159068]
# b = 799.?
# t = [0.035367765131521948 .. 0.035367772088789461]
# b = 799.438?
# found upper bound!
#   I  = [0.031830988618382224 .. 0.035367765131530928]
# f(I) = [-1.0000000000000000 .. -1.0931336309513216e-12]
# t = [0.036367765131533676 .. 1.0000000000000000]
# b = 0.?e3
# t = [0.037295537450513033 .. 1.0000000000000000]
# b = 0.?e3
# t = [0.038678190997786382 .. 1.0000000000000000]
# b = 0.?e3
# t = [0.039666455085132279 .. 1.0000000000000000]
# b = 0.?e3
# t = [0.039788238050265122 .. 1.0000000000000000]
# b = 0.?e3
# found lower bound!
# t = [0.039788735766739545 .. 0.040286623124406937]
# b = -6.?e2
# t = [0.039788735766739545 .. 0.039802757697342984]
# b = -632.?
# t = [0.039788735766739545 .. 0.039788740895829886]
# b = -631.6546?
# found upper bound!
#   I  = [0.035367765131533675 .. 0.039788735772973178]
# f(I) = [4.1468778298034067e-13 .. 1.0000000000000000]
# t = [0.040788735772974503 .. 1.0000000000000000]
# b = 0.?e3
# t = [0.041750221198249899 .. 1.0000000000000000]
# b = 0.?e3
# t = [0.043362396670967078 .. 1.0000000000000000]
# b = 0.?e3
# t = [0.045012071935942900 .. 1.0000000000000000]
# b = 0.?e3
# t = [0.045464329497359283 .. 1.0000000000000000]
# b = 0.?e3
# found lower bound!
# t = [0.045472839266239337 .. 0.046027567658901724]
# b = 5.?e2
# t = [0.045472839266239337 .. 0.045485920252368563]
# b = 484.?
# t = [0.045472839266239337 .. 0.045472844732411887]
# b = 483.6106?
# found upper bound!
#   I  = [0.039788735772974502 .. 0.045472840883398342]
# f(I) = [-1.0000000000000000 .. -1.5546214910781886e-13]
# t = [0.046472840883399278 .. 1.0000000000000000]
# b = 0.?e3
# t = [0.047457115689989101 .. 1.0000000000000000]
# b = 0.?e3
# t = [0.049248259927981458 .. 1.0000000000000000]
# b = 0.?e3
# t = [0.051657612343910884 .. 1.0000000000000000]
# b = 0.?e3
# t = [0.052957231222082359 .. 1.0000000000000000]
# b = 0.?e3
# t = [0.053051461923807156 .. 1.0000000000000000]
# b = 0.?e3
# found lower bound!
# t = [0.053051647696647774 .. 0.053682164173614246]
# b = -4.?e2
# t = [0.053051647696647774 .. 0.053064131248607878]
# b = -356.?
# t = [0.053051647696647774 .. 0.053051650675008181]
# b = -355.3058?
# found upper bound!
#   I  = [0.045472840883399277 .. 0.053051647697298276]
# f(I) = [5.9661344460120092e-14 .. 1.0000000000000000]
# t = [0.054051647697298615 .. 1.0000000000000000]
# b = 0.?e3
# t = [0.055049971363992186 .. 1.0000000000000000]
# b = 0.?e3
# t = [0.056965507507118061 .. 1.0000000000000000]
# b = 0.?e3
# t = [0.060088005964661357 .. 1.0000000000000000]
# b = 0.?e3
# t = [0.062991549688238612 .. 1.0000000000000000]
# b = 0.?e3
# t = [0.063651831080640763 .. 1.0000000000000000]
# b = 0.?e3
# t = [0.063661975609110049 .. 1.0000000000000000]
# b = 0.?e3
# found lower bound!
# t = [0.063661977236758079 .. 0.064398597009125647]
# b = 2.4?e2
# t = [0.063661977236758079 .. 0.063674314747578162]
# b = 246.7?
# t = [0.063661977236758079 .. 0.063661979646313525]
# b = 246.7401?
# found upper bound!
#   I  = [0.053051647697298615 .. 0.063661977236758080]
# f(I) = [-1.0000000000000000 .. -1.1822174476228075e-14]
# t = [0.064661977236758233 .. 1.0000000000000000]
# b = 0.?e3
# t = [0.065667724774861796 .. 1.0000000000000000]
# b = 0.?e3
# t = [0.067658199126121823 .. 1.0000000000000000]
# b = 0.?e3
# t = [0.071321659352815175 .. 1.0000000000000000]
# b = 0.?e3
# t = [0.076374146449476307 .. 1.0000000000000000]
# b = 0.?e3
# t = [0.079308145808143701 .. 1.0000000000000000]
# b = 0.?e3
# t = [0.079576478565344901 .. 1.0000000000000000]
# b = 0.?e3
# found lower bound!
# t = [0.079577471533553018 .. 0.080473246248888534]
# b = -1.6?e2
# t = [0.079577471533553018 .. 0.079590328576843187]
# b = -157.9?
# t = [0.079577471533553018 .. 0.079577473631706697]
# b = -157.91367?
# found upper bound!
#   I  = [0.063661977236758232 .. 0.079577471545947618]
# f(I) = [6.6155686379420604e-15 .. 1.0000000000000000]
# t = [0.080577471545947729 .. 1.0000000000000000]
# b = 0.?e3
# t = [0.081585938363106527 .. 1.0000000000000000]
# b = 0.?e3
# t = [0.083612409882608873 .. 1.0000000000000000]
# b = 0.?e3
# t = [0.087596826828511081 .. 1.0000000000000000]
# b = 0.?e3
# t = [0.094602004145171836 .. 1.0000000000000000]
# b = 0.?e3
# t = [0.10275547801062885 .. 1.0000000000000000]
# b = 0.?e2
# t = [0.10594695346783729 .. 1.0000000000000000]
# b = 0.?e2
# t = [0.10610305999401269 .. 1.0000000000000000]
# b = 0.?e2
# found lower bound!
# t = [0.10610329539407460 .. 0.10726432834801534]
# b = 9.?e1
# t = [0.10610329539407460 .. 0.10611785341272612]
# b = 88.9?
# t = [0.10610329539407460 .. 0.10610329739582740]
# b = 88.82644?
# found upper bound!
#   I  = [0.079577471545947728 .. 0.10610329539459686]
# f(I) = [-1.0000000000000000 .. -1.4089627996560444e-15]
# t = [0.10710329539459693 .. 1.0000000000000000]
# b = 0.?e2
# t = [0.10811141793220420 .. 1.0000000000000000]
# b = 0.?e2
# t = [0.11014711133797673 .. 1.0000000000000000]
# b = 0.?e2
# t = [0.11426178036250138 .. 1.0000000000000000]
# b = 0.?e2
# t = [0.12239932442699236 .. 1.0000000000000000]
# b = 0.?e2
# t = [0.13663913052275092 .. 1.0000000000000000]
# b = 0.?e2
# t = [0.15269643093052318 .. 1.0000000000000000]
# b = 0.?e2
# t = [0.15882017510492640 .. 1.0000000000000000]
# b = 0.?e2
# t = [0.15915422917193594 .. 1.0000000000000000]
# b = 0.?e2
# found lower bound!
# t = [0.15915494308869279 .. 0.16084649251957970]
# b = -39.?
# t = [0.15915494308869279 .. 0.15917395008404515]
# b = -39.47?
# t = [0.15915494308869279 .. 0.15915494536330774]
# b = -39.478417?
# found upper bound!
#   I  = [0.10610329539459693 .. 0.15915494309189532]
# f(I) = [6.4324905987065454e-16 .. 1.0000000000000000]
# t = [0.16015494309189540 .. 1.0000000000000000]
# b = 0.?e2
# t = [0.16116096816140540 .. 1.0000000000000000]
# b = 0.?e2
# t = [0.16319020746283460 .. 1.0000000000000000]
# b = 0.?e2
# t = [0.16731115725876011 .. 1.0000000000000000]
# b = 0.?e2
# t = [0.17575191118645003 .. 1.0000000000000000]
# b = 0.?e2
# t = [0.19302300274541303 .. 1.0000000000000000]
# b = 0.?e2
# t = [0.22626889920682405 .. 1.0000000000000000]
# b = 0.?e2
# t = [0.27528650092386769 .. 1.0000000000000000]
# b = 0.?e2
# t = [0.31101772584223857 .. 1.0000000000000000]
# b = 0.?e2
# t = [0.31813638894249463 .. 1.0000000000000000]
# b = 0.?e1
# t = [0.31830979153295790 .. 1.0000000000000000]
# b = 0.?e1
# found lower bound!
# t = [0.31830988618376249 .. 0.32159298504560008]
# b = 10.?
# t = [0.31830988618376249 .. 0.31834395996000021]
# b = 9.87?
# t = [0.31830988618376249 .. 0.31830988983150127]
# b = 9.869605?
# found upper bound!
#   I  = [0.15915494309189540 .. 0.31830988618379064]
# f(I) = [-1.0000000000000000 .. -3.2162452993532727e-16]
# t = [0.31930988618379080 .. 1.0000000000000000]
# b = 0.?e1
# t = [0.32116648645706807 .. 1.0000000000000000]
# b = 0.?e1
# t = [0.32650028033089906 .. 1.0000000000000000]
# b = 0.?e1
# t = [0.34203315262877825 .. 1.0000000000000000]
# b = 0.?e1
# t = [0.38884044897405944 .. 1.0000000000000000]
# b = 0.?e1
# t = [0.53981296592778038 .. 1.0000000000000000]
# b = 0.?e1
# stopping since presumed converged
# t = [0.53981296592778038 .. 1.0000000000000000], fprime(t) = [-1.8541727639478525 .. 0.95397453664541366]
# Signal([1.0000000000000000e-8 .. 1.0000000000000000], [([1.0000000000000000e-8 .. 1.0000000093163904e-8], True), ([0.00010001010000002972 .. 0.0011011205534532097], True), ([0.0012109826675149276 .. 0.0022114792680782993], True), ([0.0023289274552688167 .. 0.0033487296458671228], True), ([0.0034622463996617637 .. 0.0044832134034273027], True), ([0.0046132998107004177 .. 0.0056841050486393123], False), ([0.0057875306130068865 .. 0.0069197496607895310], True), ([0.0070735929360863404 .. 0.0081617918926787641], False), ([0.0081617922723588517 .. 0.0093620553041184676], True), ([0.0093620556226013725 .. 0.010610329539339620], False), ([0.010610329539585289 .. 0.011789254906462779], True), ([0.011789257710469723 .. 0.013262911923969853], False), ([0.013262912147373675 .. 0.014468631185943838], True), ([0.014468631233731384 .. 0.015915494308474905], True), ([0.015915494317603046 .. 0.017683882564144157], True), ([0.017683882567381476 .. 0.018724110951276321], False), ([0.018724110952697006 .. 0.019894367886172660], True), ([0.019894367886821123 .. 0.021220659078779295], False), ([0.021220659079059331 .. 0.022736420441636228], True), ([0.022736420441762539 .. 0.024485375860262848], False), ([0.024485375860323656 .. 0.026525823848635999], True), ([0.026525823848662453 .. 0.028937262380338461], False), ([0.028937262380350763 .. 0.031830988618376182], True), ([0.031830988618382224 .. 0.035367765131530928], False), ([0.035367765131533675 .. 0.039788735772973178], True), ([0.039788735772974502 .. 0.045472840883398342], False), ([0.045472840883399277 .. 0.053051647697298276], True), ([0.053051647697298615 .. 0.063661977236758080], False), ([0.063661977236758232 .. 0.079577471545947618], True), ([0.079577471545947728 .. 0.10610329539459686], False), ([0.10610329539459693 .. 0.15915494309189532], True), ([0.15915494309189540 .. 0.31830988618379064], False), ([0.31830988618379080 .. 1.0000000000000000], True)])

# %%
p + tsc.plot()
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
I = RIF(-0.005,0.005)

# %%
tscI = to_signal(w(x+I), w(x+I).derivative(), RIF(0.0000001,2))
tscI
# Out:
# 0 on lower boundary!
# t = [9.9999999999999995e-8 .. 0.058238501767807844]
# b = [-infinity .. +infinity]
# found upper bound!
# 0 on lower boundary!
# t = [0.059238501767807844 .. 0.068799873609210333]
# b = 0.?e3
# t = [0.059238501767807844 .. 0.068700015156400827]
# b = 0.?e3
# t = [0.059238501767807844 .. 0.068672421700363265]
# b = 0.?e3
# found upper bound!
#   I  = [0.058238501767807843 .. 0.059238501767807845]
# f(I) = [-1.0000000000000000 .. 0.14050856070259977]
# t = [0.069664841694556584 .. 2.0000000000000000]
# b = 0.?e3
# t = [0.070673458582329873 .. 2.0000000000000000]
# b = 0.?e3
# t = [0.072669365664730908 .. 2.0000000000000000]
# b = 0.?e3
# t = [0.074060682950427184 .. 2.0000000000000000]
# b = 0.?e3
# t = [0.074452006038195753 .. 2.0000000000000000]
# b = 0.?e3
# t = [0.074547718928436312 .. 2.0000000000000000]
# b = 0.?e3
# t = [0.074570452700129269 .. 2.0000000000000000]
# b = 0.?e3
# found lower bound!
# t = [0.074575817744367431 .. 0.085302148378232579]
# b = 0.?e3
# t = [0.074575817744367431 .. 0.084754360458944425]
# b = 0.?e3
# t = [0.074575817744367431 .. 0.084619459060831432]
# b = 0.?e3
# t = [0.074575817744367431 .. 0.084587379805942512]
# b = 0.?e3
# found upper bound!
#   I  = [0.068664841694556583 .. 0.074575817744367432]
# f(I) = [0.00026116330227740635 .. 1.0000000000000000]
# t = [0.085579806604433511 .. 2.0000000000000000]
# b = 0.?e3
# t = [0.086590638592628332 .. 2.0000000000000000]
# b = 0.?e3
# t = [0.088621820472541579 .. 2.0000000000000000]
# b = 0.?e3
# t = [0.092614864223558954 .. 2.0000000000000000]
# b = 0.?e3
# t = [0.098225119549965683 .. 2.0000000000000000]
# b = 0.?e3
# t = [0.10048278145088600 .. 2.0000000000000000]
# b = 0.?e3
# t = [0.10098798769261048 .. 2.0000000000000000]
# b = 0.?e3
# t = [0.10108245879042240 .. 2.0000000000000000]
# b = 0.?e3
# t = [0.10109954880606998 .. 2.0000000000000000]
# b = 0.?e3
# found lower bound!
# t = [0.10110262232773283 .. 0.11151130179645389]
# b = 1.?e2
# t = [0.10110262232773283 .. 0.11117793791821661]
# b = 1.?e2
# t = [0.10110262232773283 .. 0.11111674650911374]
# b = 1.?e2
# t = [0.10110262232773283 .. 0.11110571294445025]
# b = 1.?e2
# found upper bound!
#   I  = [0.084579806604433510 .. 0.10110262232773284]
# f(I) = [-1.0000000000000000 .. -0.000059786512373247785]
# t = [0.11210372969075793 .. 2.0000000000000000]
# b = 0.?e2
# t = [0.11311229302090454 .. 2.0000000000000000]
# b = 0.?e2
# t = [0.11514888109694641 .. 2.0000000000000000]
# b = 0.?e2
# t = [0.11926534719917365 .. 2.0000000000000000]
# b = 0.?e2
# t = [0.12740618833232586 .. 2.0000000000000000]
# b = 0.?e2
# t = [0.14164972324030264 .. 2.0000000000000000]
# b = 0.?e2
# t = [0.15118265522907853 .. 2.0000000000000000]
# b = 0.?e2
# t = [0.15373179828134314 .. 2.0000000000000000]
# b = 0.?e2
# t = [0.15410230177011172 .. 2.0000000000000000]
# b = 0.?e2
# t = [0.15414851843199289 .. 2.0000000000000000]
# b = 0.?e2
# found lower bound!
# t = [0.15415416085047894 .. 0.16425294954778108]
# b = -4.?e1
# t = [0.15415416085047894 .. 0.16416692612235101]
# b = -4.?e1
# t = [0.15415416085047894 .. 0.16415640251992759]
# b = -4.?e1
# found upper bound!
#   I  = [0.11110372969075793 .. 0.15415416085047895]
# f(I) = [0.000030881805081326560 .. 1.0000000000000000]
# t = [0.16515512075263880 .. 2.0000000000000000]
# b = 0.?e2
# t = [0.16616132557833918 .. 2.0000000000000000]
# b = 0.?e2
# t = [0.16819093020551867 .. 2.0000000000000000]
# b = 0.?e2
# t = [0.17231263054234147 .. 2.0000000000000000]
# b = 0.?e2
# t = [0.18075493783581653 .. 2.0000000000000000]
# b = 0.?e2
# t = [0.19802913353256035 .. 2.0000000000000000]
# b = 0.?e2
# t = [0.23127990905022882 .. 2.0000000000000000]
# b = 0.?e2
# t = [0.27669350220476512 .. 2.0000000000000000]
# b = 0.?e2
# t = [0.30600706127551152 .. 2.0000000000000000]
# b = 0.?e2
# t = [0.31268480761730671 .. 2.0000000000000000]
# b = 0.?e2
# t = [0.31326999826095403 .. 2.0000000000000000]
# b = 0.?e2
# t = [0.31330741432503295 .. 2.0000000000000000]
# b = 0.?e2
# found lower bound!
# t = [0.31330973329277450 .. 0.32643740493649154]
# b = 10.?
# t = [0.31330973329277450 .. 0.32353231072630673]
# b = 10.?
# t = [0.31330973329277450 .. 0.32332378808886592]
# b = 10.?
# t = [0.31330973329277450 .. 0.32331074652817233]
# b = 10.?
# found upper bound!
#   I  = [0.16415512075263880 .. 0.31330973329277451]
# f(I) = [-1.0000000000000000 .. -1.5089745705067799e-6]
# t = [0.32430993939467872 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.32545227847297991 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.32790810069500914 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.33321804287189804 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.34483441720258639 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.37082989667538368 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.43130835232577169 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.57916846401950838 .. 2.0000000000000000]
# b = 0.?e1
# t = [0.94910356232058368 .. 2.0000000000000000]
# b = -1.?
# t = [1.8285585880374146 .. 2.0000000000000000]
# b = -0.3?
# stopping since presumed converged
# t = [1.8285585880374146 .. 2.0000000000000000], fprime(t) = [-0.26408512237846799 .. -0.21228003076100859]
# /usr/lib64/python2.7/site-packages/sage/repl/ipython_kernel/__main__.py:13: DeprecationWarning: Substitution using function-call syntax and unnamed arguments is deprecated and will be removed from a future release of Sage; you can use named arguments instead, like EXPR(x=..., y=...)
# See http://trac.sagemath.org/5930 for details.
# /usr/lib64/python2.7/site-packages/sage/repl/ipython_kernel/__main__.py:1: DeprecationWarning: Substitution using function-call syntax and unnamed arguments is deprecated and will be removed from a future release of Sage; you can use named arguments instead, like EXPR(x=..., y=...)
# See http://trac.sagemath.org/5930 for details.
#   from ipykernel.kernelapp import IPKernelApp
# Signal([9.9999999999999995e-8 .. 2.0000000000000000], [([0.058238501767807843 .. 0.059238501767807845], False), ([0.068664841694556583 .. 0.074575817744367432], True), ([0.084579806604433510 .. 0.10110262232773284], False), ([0.11110372969075793 .. 0.15415416085047895], True), ([0.16415512075263880 .. 0.31330973329277451], False), ([0.32330993939467872 .. 2.0000000000000000], True)])

# %%
ar = 0.13
plot([(lambda x: RIF(w(x+I)).lower()), w(x), (lambda x: RIF(w(x+I)).upper())], 
         xmin=0, xmax=1,
         color=['blue', 'blue', 'blue'],
         linestyle=['--', '-', '--'], aspect_ratio=ar) + tscI.to_domain(RIF(0,1)).plot(aspect_ratio=ar)
# Out:
# Graphics object consisting of 5 graphics primitives

# %% [markdown]
# #### Checking some properties

# %% [markdown]
# $$\mathrel {\mathbf G_{[0.13,0.14]}} \varphi$$

# %%
res = tscI.G(RIF(0.13,0.14))
print res
print res(0)
res.to_domain(RIF(0,1)).plot(aspect_ratio=ar)
# Out:
# Signal([-0.13999990000000004 .. 1.8700000000000002], [([-0.081761498232192171 .. -0.070761498232192160], False), ([-0.055420193395566503 .. -0.028897377672267174], False), ([-0.018896270309242070 .. 0.014154160850478937], True), ([0.024155120752638786 .. 0.18330973329277451], False), ([0.19330993939467872 .. 1.8600000000000001], True)])
# True
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# $$\mathrel {\mathbf F_{[0,0.4]}} \varphi$$

# %%
tscI.F(RIF(0,0.4))
# Out:
# Signal([-0.39999990000000008 .. 2.0000000000000000], [([-0.33133515830544347 .. 0.15415416085047895], True)])

# %% [markdown]
# $$\mathrel {\mathbf G_{[0,0.4]}} \varphi$$

# %%
tscI.G(RIF(0,0.4))(0)
# Out:
# False

# %% [markdown]
# $$\mathrel {\mathbf G_{[0.2,0.3]}} \neg \varphi$$

# %%
(~tscI).G(RIF(0.2,0.3))(0)
# Out:
# True

# %% [markdown]
# Suppose we want to check the property
# $$\mathrel {\mathbf X_{0.2}} (\neg \varphi \mathrel{\mathbf U_{[0,0.2]}} \varphi)$$
# In practice, this cannot be satisfied by an uncertain trace since there will be a gap in between the $\texttt{True}$ and $\texttt{False}$ intervals. We can however loosen this to the property
# $$\mathrel {\mathbf X_{0.2}} (\neg \varphi \mathrel{\mathbf U_{[0,0.2]}} {\mathrel{\mathbf F_{[0,0.1]}} \varphi})$$
# which allows a delay before the signal changes truth value.

# %%
res = ((~tscI).U(RIF(0,0.2),tscI)).F(RIF(0.2))
print res
print res(0)
res.plot(aspect_ratio=ar)
# Out:
# Signal([-0.19999990000000004 .. 1.8000000000000001], [])
# None
# Graphics object consisting of 2 graphics primitives

# %%
res = ((~tscI).U(RIF(0,0.2),tscI.F(RIF(0,0.1)))).F(RIF(0.2))
print res
print res(0)
res.plot(aspect_ratio=ar)
# Out:
# Signal([-0.19999990000000004 .. 1.8000000000000001], [([-0.14176149823219217 .. -0.14076149823219216], True), ([-0.11542019339556651 .. -0.098897377672267181], True), ([-0.035844879247361212 .. 0.11330973329277450], True)])
# True
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# ## Context and given

# %%
to_signal(h, h.derivative(), RIF(0,3*pi)).plot()
# Out:
# t = [0.00000000000000000 .. 9.4247779607693812]
# b = 0.?e1
# t = [0.36509054541632340 .. 9.4247779607693812]
# b = 0.?e1
# t = [0.74024120745358656 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.0251749022054170 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.2079034804965527 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.3250742365150449 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.4043319534612694 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.4607936626530344 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.5027034087530406 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.5323622589438592 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.5533552029330246 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.5684995404121846 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.5795752003097356 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.5877564659304628 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.5938442727884707 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.5983990606512259 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6018207643632873 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6043991133209603 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6063464366342736 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6078197212984304 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6089358233779140 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6097821766394202 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6104244585990248 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6109121524755225 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6112826256599257 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6115641454676483 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6117781236809736 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6119407955868363 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6120644809156825 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6121585336533794 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6122300591537037 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6122844565236640 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6123258294120681 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6123572974530731 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6123812325773341 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6123994384239350 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6124132866160489 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6124238203079384 .. 9.4247779607693812]
# b = 0.?e1
# found lower bound!
# t = [1.6124318328845883 .. 1.8181967989772417]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8154367003222416]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8139962702765609]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8132501673642024]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8128652275712199]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8126670306211453]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8125650914227518]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8125126893510700]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8124857595127580]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8124719220543053]
# b = 0.?e1
# found upper bound!
#   I  = [0.00000000000000000 .. 1.6124318328845884]
# f(I) = [-0.97093206507591290 .. 2.0000000000000000]
# t = [1.8134648124294490 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8137056301451326 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8140039210021066 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8143733545521394 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8148308264606702 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8153972064670456 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8160982525513946 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8169657243392751 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8180387331647240 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8193653698570209 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8210046531546928 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8230288399622334 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8255261307587633 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8286037852574730 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8323916288883004 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8370458712959294 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8427530622174672 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8497338630568249 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8582460972287144 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8685862430783848 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8800899232020951 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8916671921104244 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.9032382040130833 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.9147227448009103 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.9260424849981561 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.9371231439498821 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.9478964368680382 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.9583016967326443 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.9682870936195020 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.9778104103938365 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.9868393709061944 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.9953515502773411 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0033339231280060 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0107821228115199 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0176994925371078 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0240960087266017 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0299871498761921 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0353927728084162 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0403360446553451 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0448424650313072 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0489389999718503 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0526533381716207 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0560132712405470 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0590461931654449 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0617787097317576 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0642363460151673 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0664433388309677 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0684225008694152 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0701951438239980 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0717810488664869 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0731984741256885 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0744641902286842 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0755935363542370 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0766004905568049 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0774977493047539 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0782968122182827 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0790080688867105 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0796408853965333 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0802036888222743 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0807040484359764 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0811487527936458 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0815438821731890 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0818948760826572 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0822065957426429 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0824833815837142 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0827291058983599 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0829472208551775 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0831408021276294 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0833125884161227 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0834650171548609 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0836002566974247 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0837202352701700 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0838266669724903 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0839210750894756 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0840048129668158 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0840790826809367 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0841449517200296 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0842033678744003 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0842551725177762 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0843011124451269 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0843418504173594 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0843779745490231 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0844100066619439 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0844384097155326 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0844635944133420 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0844859250752443 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0845057248553282 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0845232803772186 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0845388458509090 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0845526467283663 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0845648829489951 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0845757318205166 .. 9.4247779607693812]
# b = 0.?e1
# found lower bound!
# t = [2.0845853505758618 .. 2.9571953803684670]
# b = 0.?e1
# t = [2.0845853505758618 .. 2.9540196408812643]
# b = 0.?e1
# t = [2.0845853505758618 .. 2.9525624574909211]
# b = 0.?e1
# t = [2.0845853505758618 .. 2.9518939080587612]
# b = 0.?e1
# t = [2.0845853505758618 .. 2.9515871931802882]
# b = 0.?e1
# t = [2.0845853505758618 .. 2.9514464818873934]
# b = 0.?e1
# t = [2.0845853505758618 .. 2.9513819283604202]
# b = 0.?e1
# t = [2.0845853505758618 .. 2.9513523135042750]
# b = 0.?e1
# t = [2.0845853505758618 .. 2.9513387272837255]
# b = 0.?e1
# found upper bound!
#   I  = [1.8124648124294489 .. 2.0845853505758619]
# f(I) = [-0.24411337554032309 .. 0.10002931460408604]
# t = [2.9523324944231594 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9525644686858822 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9528499712409392 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9532013532532928 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9536338154890007 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9541660655646264 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9548211266585462 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9556273324963489 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9566195513549127 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9578406915153512 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9593435523768576 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9611930996930806 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9634692604746564 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9662703532941123 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9697172930612185 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9739587352655565 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9791773514778796 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9855974514802858 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9934941791599185 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.0032044921733547 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.0151400566540815 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.0298019869209733 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.0477969255208909 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.0698530959869883 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.0968333406095718 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.1297392621184392 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.1696957147576370 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.2178973595804167 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.2754890392409019 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.3433428352372693 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.4216982923308929 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.5096730341813078 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.6047606109164425 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.7026053134973579 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.7974467062719181 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.8833948447880985 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.9450224300807770 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.9821174598652824 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0033351575572497 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0151149189322685 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0215466713824259 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0250264703731613 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0268998669490647 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0279057504095954 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0284450671842151 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0287340066303025 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0288887425499568 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0289715901239411 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0290159425354552 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0290396850801322 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0290523944088629 .. 9.4247779607693812]
# b = 0.?e1
# found lower bound!
# t = [4.0290591975597873 .. 4.2350918095841737]
# b = -1.?
# t = [4.0290591975597873 .. 4.2310189914514736]
# b = -1.?
# t = [4.0290591975597873 .. 4.2296971929897512]
# b = -1.?
# t = [4.0290591975597873 .. 4.2292702320602658]
# b = -1.?
# t = [4.0290591975597873 .. 4.2291325311631125]
# b = -1.?
# t = [4.0290591975597873 .. 4.2290881430615235]
# b = -1.?
# t = [4.0290591975597873 .. 4.2290738368155508]
# b = -1.?
# found upper bound!
#   I  = [2.9513324944231591 .. 4.0290591975597874]
# f(I) = [-0.87570952745154241 .. 1.1891143659858095]
# t = [4.2300692261671244 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.2305352348894107 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.2312181141431199 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.2322189987078262 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.2336864242035439 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.2358388153836123 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.2389979532648807 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.2436391302087699 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.2504670547540079 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.2605322874614000 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.2754131110009403 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.2975063115889868 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.3305054880499449 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.3802130198386945 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.4559586815745539 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.5731046592080932 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.7572365328168499 .. 9.4247779607693812]
# b = 0.?e1
# t = [5.0380588603631730 .. 9.4247779607693812]
# b = 0.?e1
# t = [5.4497616593030393 .. 9.4247779607693812]
# b = 0.?e1
# t = [5.9703062777299180 .. 9.4247779607693812]
# b = 0.?e1
# t = [6.3603368086293015 .. 9.4247779607693812]
# b = 0.?e1
# t = [6.4392585765781920 .. 9.4247779607693812]
# b = 0.?e1
# t = [6.4452833915608822 .. 9.4247779607693812]
# b = 0.?e1
# t = [6.4456530515197156 .. 9.4247779607693812]
# b = 0.?e1
# t = [6.4456753388992718 .. 9.4247779607693812]
# b = 0.?e1
# found lower bound!
# t = [6.4456766811925305 .. 6.7078030417124364]
# b = 3.?
# t = [6.4456766811925305 .. 6.6490795283787270]
# b = 3.?
# t = [6.4456766811925305 .. 6.6458791055960989]
# b = 3.?
# t = [6.4456766811925305 .. 6.6456888435374380]
# b = 3.?
# t = [6.4456766811925305 .. 6.6456774881257550]
# b = 3.?
# found upper bound!
#   I  = [4.2290692261671241 .. 6.4456766811925306]
# f(I) = [-2.0000000000000000 .. 1.2400592020229553]
# t = [6.6466768102460482 .. 9.4247779607693812]
# b = 0.?e1
# t = [6.6476119728140190 .. 9.4247779607693812]
# b = 0.?e1
# t = [6.6494218176742032 .. 9.4247779607693812]
# b = 0.?e1
# t = [6.6529249766820051 .. 9.4247779607693812]
# b = 0.?e1
# t = [6.6597076427875077 .. 9.4247779607693812]
# b = 0.?e1
# t = [6.6728468373041671 .. 9.4247779607693812]
# b = 0.?e1
# t = [6.6983236833485326 .. 9.4247779607693812]
# b = 0.?e1
# t = [6.7477994638543856 .. 9.4247779607693812]
# b = 0.?e1
# t = [6.8440669489155379 .. 9.4247779607693812]
# b = 0.?e1
# t = [7.0313288918422509 .. 9.4247779607693812]
# b = 0.?e1
# t = [7.3898254608126086 .. 9.4247779607693812]
# b = 0.?e1
# t = [8.0170865479600532 .. 9.4247779607693812]
# b = -1.?e1
# t = [8.6981366939060329 .. 9.4247779607693812]
# b = -2.?
# t = [8.8531161674796905 .. 9.4140973758611768]
# b = -2.?
# t = [8.8617013325852731 .. 9.2325685741372397]
# b = -2.?
# t = [8.8622488015273059 .. 9.1398281796857255]
# b = -2.?
# t = [8.8622841196010089 .. 9.1135988676978102]
# b = -3.?
# t = [8.8622863525475583 .. 9.1076227502522702]
# b = -3.?
# t = [8.8622864915533980 .. 9.1063366417984817]
# b = -3.?
# t = [8.8622865001708284 .. 9.1060634023674414]
# b = -3.?
# t = [8.8622865007045561 .. 9.1060055130936526]
# b = -3.?
# t = [8.8622865007376052 .. 9.1059932558660038]
# b = -3.?
# found lower bound!
# 0 on upper boundary!
#   I  = [6.6456768102460479 .. 8.8622865007396517]
# f(I) = [3.2968072716244023e-13 .. 2.0000000000000000]
# t = [9.1069906609089237 .. 9.4247779607693812]
# b = -2.?
# stopping since presumed converged
# t = [9.1069906609089237 .. 9.4247779607693812], fprime(t) = [-2.4516534097315224 .. -1.4354601533230200]
# Graphics object consisting of 2 graphics primitives

# %%
(to_signal(h, h.derivative(), RIF(0,3*pi))
    | ~to_signal(h, h.derivative(), RIF(0,3*pi))).plot()
# Out:
# t = [0.00000000000000000 .. 9.4247779607693812]
# b = 0.?e1
# t = [0.36509054541632340 .. 9.4247779607693812]
# b = 0.?e1
# t = [0.74024120745358656 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.0251749022054170 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.2079034804965527 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.3250742365150449 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.4043319534612694 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.4607936626530344 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.5027034087530406 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.5323622589438592 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.5533552029330246 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.5684995404121846 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.5795752003097356 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.5877564659304628 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.5938442727884707 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.5983990606512259 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6018207643632873 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6043991133209603 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6063464366342736 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6078197212984304 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6089358233779140 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6097821766394202 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6104244585990248 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6109121524755225 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6112826256599257 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6115641454676483 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6117781236809736 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6119407955868363 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6120644809156825 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6121585336533794 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6122300591537037 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6122844565236640 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6123258294120681 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6123572974530731 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6123812325773341 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6123994384239350 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6124132866160489 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6124238203079384 .. 9.4247779607693812]
# b = 0.?e1
# found lower bound!
# t = [1.6124318328845883 .. 1.8181967989772417]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8154367003222416]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8139962702765609]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8132501673642024]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8128652275712199]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8126670306211453]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8125650914227518]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8125126893510700]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8124857595127580]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8124719220543053]
# b = 0.?e1
# found upper bound!
#   I  = [0.00000000000000000 .. 1.6124318328845884]
# f(I) = [-0.97093206507591290 .. 2.0000000000000000]
# t = [1.8134648124294490 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8137056301451326 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8140039210021066 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8143733545521394 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8148308264606702 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8153972064670456 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8160982525513946 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8169657243392751 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8180387331647240 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8193653698570209 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8210046531546928 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8230288399622334 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8255261307587633 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8286037852574730 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8323916288883004 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8370458712959294 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8427530622174672 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8497338630568249 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8582460972287144 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8685862430783848 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8800899232020951 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8916671921104244 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.9032382040130833 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.9147227448009103 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.9260424849981561 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.9371231439498821 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.9478964368680382 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.9583016967326443 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.9682870936195020 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.9778104103938365 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.9868393709061944 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.9953515502773411 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0033339231280060 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0107821228115199 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0176994925371078 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0240960087266017 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0299871498761921 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0353927728084162 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0403360446553451 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0448424650313072 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0489389999718503 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0526533381716207 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0560132712405470 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0590461931654449 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0617787097317576 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0642363460151673 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0664433388309677 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0684225008694152 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0701951438239980 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0717810488664869 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0731984741256885 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0744641902286842 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0755935363542370 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0766004905568049 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0774977493047539 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0782968122182827 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0790080688867105 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0796408853965333 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0802036888222743 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0807040484359764 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0811487527936458 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0815438821731890 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0818948760826572 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0822065957426429 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0824833815837142 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0827291058983599 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0829472208551775 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0831408021276294 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0833125884161227 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0834650171548609 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0836002566974247 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0837202352701700 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0838266669724903 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0839210750894756 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0840048129668158 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0840790826809367 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0841449517200296 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0842033678744003 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0842551725177762 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0843011124451269 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0843418504173594 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0843779745490231 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0844100066619439 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0844384097155326 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0844635944133420 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0844859250752443 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0845057248553282 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0845232803772186 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0845388458509090 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0845526467283663 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0845648829489951 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0845757318205166 .. 9.4247779607693812]
# b = 0.?e1
# found lower bound!
# t = [2.0845853505758618 .. 2.9571953803684670]
# b = 0.?e1
# t = [2.0845853505758618 .. 2.9540196408812643]
# b = 0.?e1
# t = [2.0845853505758618 .. 2.9525624574909211]
# b = 0.?e1
# t = [2.0845853505758618 .. 2.9518939080587612]
# b = 0.?e1
# t = [2.0845853505758618 .. 2.9515871931802882]
# b = 0.?e1
# t = [2.0845853505758618 .. 2.9514464818873934]
# b = 0.?e1
# t = [2.0845853505758618 .. 2.9513819283604202]
# b = 0.?e1
# t = [2.0845853505758618 .. 2.9513523135042750]
# b = 0.?e1
# t = [2.0845853505758618 .. 2.9513387272837255]
# b = 0.?e1
# found upper bound!
#   I  = [1.8124648124294489 .. 2.0845853505758619]
# f(I) = [-0.24411337554032309 .. 0.10002931460408604]
# t = [2.9523324944231594 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9525644686858822 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9528499712409392 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9532013532532928 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9536338154890007 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9541660655646264 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9548211266585462 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9556273324963489 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9566195513549127 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9578406915153512 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9593435523768576 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9611930996930806 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9634692604746564 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9662703532941123 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9697172930612185 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9739587352655565 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9791773514778796 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9855974514802858 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9934941791599185 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.0032044921733547 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.0151400566540815 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.0298019869209733 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.0477969255208909 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.0698530959869883 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.0968333406095718 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.1297392621184392 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.1696957147576370 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.2178973595804167 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.2754890392409019 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.3433428352372693 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.4216982923308929 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.5096730341813078 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.6047606109164425 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.7026053134973579 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.7974467062719181 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.8833948447880985 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.9450224300807770 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.9821174598652824 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0033351575572497 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0151149189322685 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0215466713824259 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0250264703731613 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0268998669490647 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0279057504095954 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0284450671842151 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0287340066303025 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0288887425499568 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0289715901239411 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0290159425354552 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0290396850801322 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0290523944088629 .. 9.4247779607693812]
# b = 0.?e1
# found lower bound!
# t = [4.0290591975597873 .. 4.2350918095841737]
# b = -1.?
# t = [4.0290591975597873 .. 4.2310189914514736]
# b = -1.?
# t = [4.0290591975597873 .. 4.2296971929897512]
# b = -1.?
# t = [4.0290591975597873 .. 4.2292702320602658]
# b = -1.?
# t = [4.0290591975597873 .. 4.2291325311631125]
# b = -1.?
# t = [4.0290591975597873 .. 4.2290881430615235]
# b = -1.?
# t = [4.0290591975597873 .. 4.2290738368155508]
# b = -1.?
# found upper bound!
#   I  = [2.9513324944231591 .. 4.0290591975597874]
# f(I) = [-0.87570952745154241 .. 1.1891143659858095]
# t = [4.2300692261671244 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.2305352348894107 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.2312181141431199 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.2322189987078262 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.2336864242035439 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.2358388153836123 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.2389979532648807 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.2436391302087699 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.2504670547540079 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.2605322874614000 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.2754131110009403 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.2975063115889868 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.3305054880499449 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.3802130198386945 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.4559586815745539 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.5731046592080932 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.7572365328168499 .. 9.4247779607693812]
# b = 0.?e1
# t = [5.0380588603631730 .. 9.4247779607693812]
# b = 0.?e1
# t = [5.4497616593030393 .. 9.4247779607693812]
# b = 0.?e1
# t = [5.9703062777299180 .. 9.4247779607693812]
# b = 0.?e1
# t = [6.3603368086293015 .. 9.4247779607693812]
# b = 0.?e1
# t = [6.4392585765781920 .. 9.4247779607693812]
# b = 0.?e1
# t = [6.4452833915608822 .. 9.4247779607693812]
# b = 0.?e1
# t = [6.4456530515197156 .. 9.4247779607693812]
# b = 0.?e1
# t = [6.4456753388992718 .. 9.4247779607693812]
# b = 0.?e1
# found lower bound!
# t = [6.4456766811925305 .. 6.7078030417124364]
# b = 3.?
# t = [6.4456766811925305 .. 6.6490795283787270]
# b = 3.?
# t = [6.4456766811925305 .. 6.6458791055960989]
# b = 3.?
# t = [6.4456766811925305 .. 6.6456888435374380]
# b = 3.?
# t = [6.4456766811925305 .. 6.6456774881257550]
# b = 3.?
# found upper bound!
#   I  = [4.2290692261671241 .. 6.4456766811925306]
# f(I) = [-2.0000000000000000 .. 1.2400592020229553]
# t = [6.6466768102460482 .. 9.4247779607693812]
# b = 0.?e1
# t = [6.6476119728140190 .. 9.4247779607693812]
# b = 0.?e1
# t = [6.6494218176742032 .. 9.4247779607693812]
# b = 0.?e1
# t = [6.6529249766820051 .. 9.4247779607693812]
# b = 0.?e1
# t = [6.6597076427875077 .. 9.4247779607693812]
# b = 0.?e1
# t = [6.6728468373041671 .. 9.4247779607693812]
# b = 0.?e1
# t = [6.6983236833485326 .. 9.4247779607693812]
# b = 0.?e1
# t = [6.7477994638543856 .. 9.4247779607693812]
# b = 0.?e1
# t = [6.8440669489155379 .. 9.4247779607693812]
# b = 0.?e1
# t = [7.0313288918422509 .. 9.4247779607693812]
# b = 0.?e1
# t = [7.3898254608126086 .. 9.4247779607693812]
# b = 0.?e1
# t = [8.0170865479600532 .. 9.4247779607693812]
# b = -1.?e1
# t = [8.6981366939060329 .. 9.4247779607693812]
# b = -2.?
# t = [8.8531161674796905 .. 9.4140973758611768]
# b = -2.?
# t = [8.8617013325852731 .. 9.2325685741372397]
# b = -2.?
# t = [8.8622488015273059 .. 9.1398281796857255]
# b = -2.?
# t = [8.8622841196010089 .. 9.1135988676978102]
# b = -3.?
# t = [8.8622863525475583 .. 9.1076227502522702]
# b = -3.?
# t = [8.8622864915533980 .. 9.1063366417984817]
# b = -3.?
# t = [8.8622865001708284 .. 9.1060634023674414]
# b = -3.?
# t = [8.8622865007045561 .. 9.1060055130936526]
# b = -3.?
# t = [8.8622865007376052 .. 9.1059932558660038]
# b = -3.?
# found lower bound!
# 0 on upper boundary!
#   I  = [6.6456768102460479 .. 8.8622865007396517]
# f(I) = [3.2968072716244023e-13 .. 2.0000000000000000]
# t = [9.1069906609089237 .. 9.4247779607693812]
# b = -2.?
# stopping since presumed converged
# t = [9.1069906609089237 .. 9.4247779607693812], fprime(t) = [-2.4516534097315224 .. -1.4354601533230200]
# t = [0.00000000000000000 .. 9.4247779607693812]
# b = 0.?e1
# t = [0.36509054541632340 .. 9.4247779607693812]
# b = 0.?e1
# t = [0.74024120745358656 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.0251749022054170 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.2079034804965527 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.3250742365150449 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.4043319534612694 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.4607936626530344 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.5027034087530406 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.5323622589438592 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.5533552029330246 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.5684995404121846 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.5795752003097356 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.5877564659304628 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.5938442727884707 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.5983990606512259 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6018207643632873 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6043991133209603 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6063464366342736 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6078197212984304 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6089358233779140 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6097821766394202 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6104244585990248 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6109121524755225 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6112826256599257 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6115641454676483 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6117781236809736 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6119407955868363 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6120644809156825 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6121585336533794 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6122300591537037 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6122844565236640 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6123258294120681 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6123572974530731 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6123812325773341 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6123994384239350 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6124132866160489 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6124238203079384 .. 9.4247779607693812]
# b = 0.?e1
# found lower bound!
# t = [1.6124318328845883 .. 1.8181967989772417]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8154367003222416]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8139962702765609]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8132501673642024]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8128652275712199]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8126670306211453]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8125650914227518]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8125126893510700]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8124857595127580]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8124719220543053]
# b = 0.?e1
# found upper bound!
#   I  = [0.00000000000000000 .. 1.6124318328845884]
# f(I) = [-0.97093206507591290 .. 2.0000000000000000]
# t = [1.8134648124294490 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8137056301451326 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8140039210021066 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8143733545521394 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8148308264606702 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8153972064670456 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8160982525513946 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8169657243392751 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8180387331647240 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8193653698570209 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8210046531546928 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8230288399622334 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8255261307587633 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8286037852574730 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8323916288883004 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8370458712959294 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8427530622174672 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8497338630568249 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8582460972287144 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8685862430783848 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8800899232020951 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8916671921104244 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.9032382040130833 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.9147227448009103 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.9260424849981561 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.9371231439498821 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.9478964368680382 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.9583016967326443 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.9682870936195020 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.9778104103938365 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.9868393709061944 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.9953515502773411 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0033339231280060 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0107821228115199 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0176994925371078 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0240960087266017 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0299871498761921 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0353927728084162 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0403360446553451 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0448424650313072 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0489389999718503 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0526533381716207 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0560132712405470 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0590461931654449 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0617787097317576 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0642363460151673 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0664433388309677 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0684225008694152 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0701951438239980 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0717810488664869 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0731984741256885 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0744641902286842 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0755935363542370 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0766004905568049 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0774977493047539 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0782968122182827 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0790080688867105 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0796408853965333 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0802036888222743 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0807040484359764 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0811487527936458 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0815438821731890 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0818948760826572 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0822065957426429 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0824833815837142 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0827291058983599 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0829472208551775 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0831408021276294 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0833125884161227 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0834650171548609 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0836002566974247 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0837202352701700 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0838266669724903 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0839210750894756 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0840048129668158 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0840790826809367 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0841449517200296 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0842033678744003 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0842551725177762 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0843011124451269 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0843418504173594 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0843779745490231 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0844100066619439 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0844384097155326 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0844635944133420 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0844859250752443 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0845057248553282 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0845232803772186 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0845388458509090 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0845526467283663 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0845648829489951 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0845757318205166 .. 9.4247779607693812]
# b = 0.?e1
# found lower bound!
# t = [2.0845853505758618 .. 2.9571953803684670]
# b = 0.?e1
# t = [2.0845853505758618 .. 2.9540196408812643]
# b = 0.?e1
# t = [2.0845853505758618 .. 2.9525624574909211]
# b = 0.?e1
# t = [2.0845853505758618 .. 2.9518939080587612]
# b = 0.?e1
# t = [2.0845853505758618 .. 2.9515871931802882]
# b = 0.?e1
# t = [2.0845853505758618 .. 2.9514464818873934]
# b = 0.?e1
# t = [2.0845853505758618 .. 2.9513819283604202]
# b = 0.?e1
# t = [2.0845853505758618 .. 2.9513523135042750]
# b = 0.?e1
# t = [2.0845853505758618 .. 2.9513387272837255]
# b = 0.?e1
# found upper bound!
#   I  = [1.8124648124294489 .. 2.0845853505758619]
# f(I) = [-0.24411337554032309 .. 0.10002931460408604]
# t = [2.9523324944231594 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9525644686858822 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9528499712409392 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9532013532532928 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9536338154890007 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9541660655646264 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9548211266585462 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9556273324963489 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9566195513549127 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9578406915153512 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9593435523768576 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9611930996930806 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9634692604746564 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9662703532941123 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9697172930612185 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9739587352655565 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9791773514778796 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9855974514802858 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9934941791599185 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.0032044921733547 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.0151400566540815 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.0298019869209733 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.0477969255208909 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.0698530959869883 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.0968333406095718 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.1297392621184392 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.1696957147576370 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.2178973595804167 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.2754890392409019 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.3433428352372693 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.4216982923308929 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.5096730341813078 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.6047606109164425 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.7026053134973579 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.7974467062719181 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.8833948447880985 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.9450224300807770 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.9821174598652824 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0033351575572497 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0151149189322685 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0215466713824259 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0250264703731613 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0268998669490647 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0279057504095954 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0284450671842151 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0287340066303025 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0288887425499568 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0289715901239411 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0290159425354552 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0290396850801322 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0290523944088629 .. 9.4247779607693812]
# b = 0.?e1
# found lower bound!
# t = [4.0290591975597873 .. 4.2350918095841737]
# b = -1.?
# t = [4.0290591975597873 .. 4.2310189914514736]
# b = -1.?
# t = [4.0290591975597873 .. 4.2296971929897512]
# b = -1.?
# t = [4.0290591975597873 .. 4.2292702320602658]
# b = -1.?
# t = [4.0290591975597873 .. 4.2291325311631125]
# b = -1.?
# t = [4.0290591975597873 .. 4.2290881430615235]
# b = -1.?
# t = [4.0290591975597873 .. 4.2290738368155508]
# b = -1.?
# found upper bound!
#   I  = [2.9513324944231591 .. 4.0290591975597874]
# f(I) = [-0.87570952745154241 .. 1.1891143659858095]
# t = [4.2300692261671244 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.2305352348894107 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.2312181141431199 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.2322189987078262 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.2336864242035439 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.2358388153836123 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.2389979532648807 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.2436391302087699 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.2504670547540079 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.2605322874614000 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.2754131110009403 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.2975063115889868 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.3305054880499449 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.3802130198386945 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.4559586815745539 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.5731046592080932 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.7572365328168499 .. 9.4247779607693812]
# b = 0.?e1
# t = [5.0380588603631730 .. 9.4247779607693812]
# b = 0.?e1
# t = [5.4497616593030393 .. 9.4247779607693812]
# b = 0.?e1
# t = [5.9703062777299180 .. 9.4247779607693812]
# b = 0.?e1
# t = [6.3603368086293015 .. 9.4247779607693812]
# b = 0.?e1
# t = [6.4392585765781920 .. 9.4247779607693812]
# b = 0.?e1
# t = [6.4452833915608822 .. 9.4247779607693812]
# b = 0.?e1
# t = [6.4456530515197156 .. 9.4247779607693812]
# b = 0.?e1
# t = [6.4456753388992718 .. 9.4247779607693812]
# b = 0.?e1
# found lower bound!
# t = [6.4456766811925305 .. 6.7078030417124364]
# b = 3.?
# t = [6.4456766811925305 .. 6.6490795283787270]
# b = 3.?
# t = [6.4456766811925305 .. 6.6458791055960989]
# b = 3.?
# t = [6.4456766811925305 .. 6.6456888435374380]
# b = 3.?
# t = [6.4456766811925305 .. 6.6456774881257550]
# b = 3.?
# found upper bound!
#   I  = [4.2290692261671241 .. 6.4456766811925306]
# f(I) = [-2.0000000000000000 .. 1.2400592020229553]
# t = [6.6466768102460482 .. 9.4247779607693812]
# b = 0.?e1
# t = [6.6476119728140190 .. 9.4247779607693812]
# b = 0.?e1
# t = [6.6494218176742032 .. 9.4247779607693812]
# b = 0.?e1
# t = [6.6529249766820051 .. 9.4247779607693812]
# b = 0.?e1
# t = [6.6597076427875077 .. 9.4247779607693812]
# b = 0.?e1
# t = [6.6728468373041671 .. 9.4247779607693812]
# b = 0.?e1
# t = [6.6983236833485326 .. 9.4247779607693812]
# b = 0.?e1
# t = [6.7477994638543856 .. 9.4247779607693812]
# b = 0.?e1
# t = [6.8440669489155379 .. 9.4247779607693812]
# b = 0.?e1
# t = [7.0313288918422509 .. 9.4247779607693812]
# b = 0.?e1
# t = [7.3898254608126086 .. 9.4247779607693812]
# b = 0.?e1
# t = [8.0170865479600532 .. 9.4247779607693812]
# b = -1.?e1
# t = [8.6981366939060329 .. 9.4247779607693812]
# b = -2.?
# t = [8.8531161674796905 .. 9.4140973758611768]
# b = -2.?
# t = [8.8617013325852731 .. 9.2325685741372397]
# b = -2.?
# t = [8.8622488015273059 .. 9.1398281796857255]
# b = -2.?
# t = [8.8622841196010089 .. 9.1135988676978102]
# b = -3.?
# t = [8.8622863525475583 .. 9.1076227502522702]
# b = -3.?
# t = [8.8622864915533980 .. 9.1063366417984817]
# b = -3.?
# t = [8.8622865001708284 .. 9.1060634023674414]
# b = -3.?
# t = [8.8622865007045561 .. 9.1060055130936526]
# b = -3.?
# t = [8.8622865007376052 .. 9.1059932558660038]
# b = -3.?
# found lower bound!
# 0 on upper boundary!
#   I  = [6.6456768102460479 .. 8.8622865007396517]
# f(I) = [3.2968072716244023e-13 .. 2.0000000000000000]
# t = [9.1069906609089237 .. 9.4247779607693812]
# b = -2.?
# stopping since presumed converged
# t = [9.1069906609089237 .. 9.4247779607693812], fprime(t) = [-2.4516534097315224 .. -1.4354601533230200]
# Graphics object consisting of 2 graphics primitives

# %%
w = lambda x: RIF(h(x)).max(RIF(-h(x)))

# %%
w(3)
# Out:
# 1.?

# %%
w(0)
# Out:
# 1.?

# %%
sigor = to_signal((lambda x: max(RIF(h(x)), -RIF(h(x)))),
                  (lambda x: h.derivative(x)
                             if   RIF(h(x)) > 0
                             else -h.derivative()(x)),
                  RIF(0,3*pi))
sigor
# Out:
# t = [0.00000000000000000 .. 9.4247779607693812]
# b = 0.?e1
# t = [0.36509054541632340 .. 9.4247779607693812]
# b = 0.?e1
# t = [0.74024120745358656 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.0251749022054170 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.2079034804965527 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.3250742365150449 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.4043319534612694 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.4607936626530344 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.5027034087530406 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.5323622589438592 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.5533552029330246 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.5684995404121846 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.5795752003097356 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.5877564659304628 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.5938442727884707 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.5983990606512259 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6018207643632873 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6043991133209603 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6063464366342736 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6078197212984304 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6089358233779140 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6097821766394202 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6104244585990248 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6109121524755225 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6112826256599257 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6115641454676483 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6117781236809736 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6119407955868363 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6120644809156825 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6121585336533794 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6122300591537037 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6122844565236640 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6123258294120681 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6123572974530731 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6123812325773341 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6123994384239350 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6124132866160489 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.6124238203079384 .. 9.4247779607693812]
# b = 0.?e1
# found lower bound!
# t = [1.6124318328845883 .. 1.8181967989772417]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8154367003222416]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8139962702765609]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8132501673642024]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8128652275712199]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8126670306211453]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8125650914227518]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8125126893510700]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8124857595127580]
# b = 0.?e1
# t = [1.6124318328845883 .. 1.8124719220543053]
# b = 0.?e1
# found upper bound!
#   I  = [0.00000000000000000 .. 1.6124318328845884]
# f(I) = [-0.97093206507591290 .. 2.0000000000000000]
# t = [1.8134648124294490 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8137056301451326 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8140039210021066 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8143733545521394 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8148308264606702 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8153972064670456 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8160982525513946 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8169657243392751 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8180387331647240 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8193653698570211 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8210046531546930 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8230288399622336 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8255261307587637 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8286037852574734 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8323916288883010 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8370458712959301 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8427530622174681 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8497338630568260 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8582460972287158 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8685862430783866 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8800899232020968 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.8916671921104262 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.9032382040130852 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.9147227448009125 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.9260424849981581 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.9371231439498841 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.9478964368680400 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.9583016967326460 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.9682870936195036 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.9778104103938380 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.9868393709061957 .. 9.4247779607693812]
# b = 0.?e1
# t = [1.9953515502773422 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0033339231280069 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0107821228115208 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0176994925371087 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0240960087266026 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0299871498761925 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0353927728084166 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0403360446553455 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0448424650313077 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0489389999718503 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0526533381716207 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0560132712405470 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0590461931654449 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0617787097317576 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0642363460151673 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0664433388309677 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0684225008694152 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0701951438239980 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0717810488664869 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0731984741256885 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0744641902286842 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0755935363542370 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0766004905568049 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0774977493047539 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0782968122182827 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0790080688867105 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0796408853965333 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0802036888222743 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0807040484359764 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0811487527936458 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0815438821731890 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0818948760826572 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0822065957426429 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0824833815837142 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0827291058983599 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0829472208551775 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0831408021276294 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0833125884161227 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0834650171548609 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0836002566974247 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0837202352701700 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0838266669724903 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0839210750894756 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0840048129668158 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0840790826809367 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0841449517200296 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0842033678744003 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0842551725177762 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0843011124451269 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0843418504173594 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0843779745490231 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0844100066619439 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0844384097155326 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0844635944133420 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0844859250752443 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0845057248553287 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0845232803772191 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0845388458509095 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0845526467283668 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0845648829489955 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.0845757318205171 .. 9.4247779607693812]
# b = 0.?e1
# found lower bound!
# t = [2.0845853505758622 .. 2.9571953803684675]
# b = 0.?e1
# t = [2.0845853505758622 .. 2.9521077410235211]
# b = 0.?e1
# t = [2.0845853505758622 .. 2.9514309669208068]
# b = 0.?e1
# t = [2.0845853505758622 .. 2.9513410027105441]
# b = 0.?e1
# t = [2.0845853505758622 .. 2.9513290444876002]
# b = 0.?e1
# found upper bound!
#   I  = [1.8124648124294489 .. 2.0845853505758623]
# f(I) = [-0.24411337554032331 .. 0.10002931460408627]
# t = [2.9523274549901485 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9525582663944245 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9528423377696007 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9531919583733157 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9536222527846489 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9541518348621367 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9548036124066876 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9556057771687238 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9565930227327155 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9578080424515822 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9593033713301846 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9611436499425809 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9634084054772751 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9661954651201698 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9696251402440045 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9738453457527982 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9790378457391346 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9854258403457385 .. 9.4247779607693812]
# b = 0.?e1
# t = [2.9932831209299615 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.0029450045053169 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.0148211817626964 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.0294104156768231 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.0473166006019671 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.0692648424069304 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.0961146236947696 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.1288642632980532 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.1686360628219381 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.2166240707091677 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.2739764727348252 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.3415756085974090 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.4196817011510227 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.5074458353090061 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.6024054304774879 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.7002476893306441 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.7952341304425618 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.8814583085819989 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.9438180091886798 .. 9.4247779607693812]
# b = 0.?e1
# t = [3.9814149027323209 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0029407477963792 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0148982487747328 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0214290550353712 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0249630364115329 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0268657745024878 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0278874618775937 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0284352663732914 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0287287572175252 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0288859317245764 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0289700852858620 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0290151369535882 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0290392538487864 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.0290521635744003 .. 9.4247779607693812]
# b = 0.?e1
# found lower bound!
# t = [4.0290590739976392 .. 4.2350916797191154]
# b = 1.?
# t = [4.0290590739976392 .. 4.2310189493745761]
# b = 1.?
# t = [4.0290590739976392 .. 4.2296971794533010]
# b = 1.?
# t = [4.0290590739976392 .. 4.2292702277158414]
# b = 1.?
# t = [4.0290590739976392 .. 4.2291325297699079]
# b = 1.?
# t = [4.0290590739976392 .. 4.2290881426148630]
# b = 1.?
# t = [4.0290590739976392 .. 4.2290738366723675]
# b = 1.?
# found upper bound!
#   I  = [2.9513274549901482 .. 4.0290590739976393]
# f(I) = [-0.87571753273892239 .. 1.1891193144801955]
# t = [4.2300692261212269 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.2305352348221587 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.2312181140445614 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.2322189985633533 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.2336864239916902 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.2358388150727881 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.2389979528084973 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.2436391295379074 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.2504670537662523 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.2605322860035910 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.2754131088419553 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.2975063083756905 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.3305054832336935 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.3802130125487730 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.4559586703948879 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.5731046417858136 .. 9.4247779607693812]
# b = 0.?e1
# t = [4.7572365052520009 .. 9.4247779607693812]
# b = 0.?e1
# t = [5.0380588189012520 .. 9.4247779607693812]
# b = 0.?e1
# t = [5.4497616008723603 .. 9.4247779607693812]
# b = 0.?e1
# t = [5.9703062141069418 .. 9.4247779607693812]
# b = 0.?e1
# t = [6.3603367862702944 .. 9.4247779607693812]
# b = 0.?e1
# t = [6.4392585745429293 .. 9.4247779607693812]
# b = 0.?e1
# t = [6.4452833914339553 .. 9.4247779607693812]
# b = 0.?e1
# t = [6.4456530515120551 .. 9.4247779607693812]
# b = 0.?e1
# t = [6.4456753388988099 .. 9.4247779607693812]
# b = 0.?e1
# found lower bound!
# t = [6.4456766811925030 .. 6.7078030417124089]
# b = -3.?
# stopping since presumed converged
# t = [6.4456766811925030 .. 6.7078030417124089], fprime(t) = [-2.5868272987156154 .. -2.0527924947938651]
# Signal([0.00000000000000000 .. 9.4247779607693812], [([0.00000000000000000 .. 1.6124318328845884], True), ([1.8124648124294489 .. 2.0845853505758623], True), ([2.9513274549901482 .. 4.0290590739976393], True), ([4.2290692261212265 .. 9.4247779607693812], True)])

# %%
plot([(lambda x: RIF(w(x)).lower()),
      (lambda x: RIF(w(x)).center()),
      (lambda x: RIF(w(x)).upper())], 
         xmin=0, xmax=3*pi,
         color=['blue', 'blue', 'blue'],
         linestyle=['--', '-', '--']) + sigor.plot()
# Out:
# Graphics object consisting of 5 graphics primitives

# %% [markdown]
# ### Context

# %%
load('interval_signals.py')

# %%
RIF(0,1).absolute_diameter()
# Out:
# 1.00000000000000

# %%
var('t')
# Out:
# t

# %%
x = function('x')(t)
x
# Out:
# x(t)

# %%
y(t) = desolve(diff(x,t) == -x, x, [0,1])
y
# Out:
# t |--> e^(-t)

# %%
plot(y, (t, 0, 1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
def g(s, fn = None):
    w(t) = y(t - ln(s))
    return w if fn is None else fn(w)

# %%
g(y(0.4))
# Out:
# t |--> e^(-t - 0.400000000000000)

# %%
def w(t):
    if t < 0.4:
        return y(t)
    else:
        return g(1 + y(0.4))(t)

# %%
plot(w, (0, 1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot((lambda t: g(y(t), (lambda s: s - 0.7))(0)), (0,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
load('interval_signals.py')

# %%
sig = to_signal(lambda t: y(t) - 0.8, y.derivative(), RIF(0,1))
sig.plot()
# Out:
# t = [0.00000000000000000 .. 1.0000000000000000]
# b = -1.?
# t = [0.19999999906867738 .. 0.54365637006234447]
# b = -1.?
# t = [0.22287779342436633 .. 0.23225983987596458]
# b = -0.80?
# t = [0.22314351600365589 .. 0.22314602075734070]
# b = -0.80000?
# found lower bound!
# 0 on upper boundary!
#   I  = [0.00000000000000000 .. 0.22314355131420896]
# f(I) = [-3.9115548577939308e-9 .. 0.20000000279396768]
# t = [0.22414355131429752 .. 1.0000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.22414355131429752 .. 1.0000000000000000], fprime(t) = [-0.79920040303841234 .. -0.36787943867966532]
# Graphics object consisting of 2 graphics primitives

# %%
plot((lambda t: g(y(t) + 0.5, (lambda s: s - 1.2))(0)),
     (0,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# ### Simple context

# %%
csig = C(RIF(0,1),
         (lambda x: x + 0.5),
         (lambda f: to_signal((lambda t: f(t) - 1.2),
                              f.derivative(),
                              RIF(0,10))(0)),
         y,
         g,
         0.001)
csig
# Out:
# I  = [0.00000000000000000 .. 1.0000000000000000]
# C || f(I) = [0.86787943821400403 .. 1.5000000046566129]
# h  = t |--> e^(-t + 0.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.22435568284070104]
# b = -1.?
# t = [0.00000000000000000 .. 0.22338656918764283]
# b = -1.?
# t = [0.00000000000000000 .. 0.22319218180236586]
# b = -1.?
# t = [0.00000000000000000 .. 0.22315328244546307]
# b = -1.?
# found upper bound!
# t = [0.22414550105913116 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.22414550105913116 .. 10.000000000000000], fprime(t) = [-1.1987982848659158 .. -0.000039399601519107818]
# bisecting [0.00000000000000000 .. 1.0000000000000000] -> [0.00000000000000000 .. 0.50000000000000000], [0.50000000000000000 .. 1.0000000000000000]
# I  = [0.00000000000000000 .. 0.50000000000000000]
# C || f(I) = [1.1065306561067700 .. 1.5000000027939678]
# h  = t |--> e^(-t + 1.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.22435568284070104]
# b = -1.?
# t = [0.00000000000000000 .. 0.22338656794467602]
# b = -1.?
# t = [0.00000000000000000 .. 0.22319218055915766]
# b = -1.?
# t = [0.00000000000000000 .. 0.22315328120220657]
# b = -1.?
# found upper bound!
# t = [0.22414549981586501 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.22414549981586501 .. 10.000000000000000], fprime(t) = [-1.1987982848659158 .. -0.000050234608352184295]
# bisecting [0.00000000000000000 .. 0.50000000000000000] -> [0.00000000000000000 .. 0.25000000000000000], [0.25000000000000000 .. 0.50000000000000000]
# I  = [0.00000000000000000 .. 0.25000000000000000]
# C || f(I) = [1.2788007790222764 .. 1.5000000027939678]
# h  = t |--> e^(-t + 1.?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.052533849807735968 .. 10.000000000000000]
# b = -1.?
# t = [0.061917110175816199 .. 10.000000000000000]
# b = -1.?
# t = [0.063351634750390822 .. 10.000000000000000]
# b = -1.?
# t = [0.063564360902149313 .. 10.000000000000000]
# b = -1.?
# t = [0.063595755990745558 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.063600387009634440 .. 0.22343149784916067]
# b = -2.?
# t = [0.063600387009634440 .. 0.22318605191354166]
# b = -2.?
# t = [0.063600387009634440 .. 0.22314982192248204]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.063600387009634441]
# f(I) = [9.6037983898789036e-7 .. 0.30000000558793550]
# t = [0.22414447788499650 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.22414447788499650 .. 10.000000000000000], fprime(t) = [-1.1987995086237789 .. -0.000058055855333805084]
# returning res = True
# I  = [0.25000000000000000 .. 0.50000000000000000]
# C || f(I) = [1.1065306579694151 .. 1.2788007836788893]
# h  = t |--> e^(-t + 0.2?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.063891780303481194]
# b = -2.?
# t = [0.00000000000000000 .. 0.063619141540639482]
# b = -2.?
# t = [0.00000000000000000 .. 0.063602301712363072]
# b = -2.?
# found upper bound!
# t = [0.064601264061761615 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.064601264061761615 .. 10.000000000000000], fprime(t) = [-1.1988005368039012 .. -0.000050234608352184295]
# bisecting [0.25000000000000000 .. 0.50000000000000000] -> [0.25000000000000000 .. 0.37500000000000000], [0.37500000000000000 .. 0.50000000000000000]
# I  = [0.25000000000000000 .. 0.37500000000000000]
# C || f(I) = [1.1872892770916223 .. 1.2788007836788893]
# h  = t |--> e^(-t + 0.2?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.063891780303481194]
# b = -1.2?
# t = [0.00000000000000000 .. 0.063619141540639482]
# b = -1.2?
# t = [0.00000000000000000 .. 0.063602301712363072]
# b = -1.2?
# found upper bound!
# t = [0.064601264061761615 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.064601264061761615 .. 10.000000000000000], fprime(t) = [-1.1988005368039012 .. -0.000053900294005870819]
# bisecting [0.25000000000000000 .. 0.37500000000000000] -> [0.25000000000000000 .. 0.31250000000000000], [0.31250000000000000 .. 0.37500000000000000]
# I  = [0.25000000000000000 .. 0.31250000000000000]
# C || f(I) = [1.2316156271845102 .. 1.2788007836788893]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.024722867965949382 .. 10.000000000000000]
# b = -1.?
# t = [0.025957156471508095 .. 10.000000000000000]
# b = -1.?
# t = [0.026003490527981322 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.026005200128111201 .. 0.063706220414283352]
# b = -1.2?
# t = [0.026005200128111201 .. 0.063605075775070880]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.026005200128111202]
# f(I) = [7.9348683401647690e-8 .. 0.078800785541534469]
# t = [0.064601337849611750 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.064601337849611750 .. 10.000000000000000], fprime(t) = [-1.1988004473969341 .. -0.000055913813412189483]
# returning res = True
# I  = [0.31250000000000000 .. 0.37500000000000000]
# C || f(I) = [1.1872892770916223 .. 1.2316156299784780]
# h  = t |--> e^(-t + 0.2?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.026095845407556645]
# b = -1.2?
# t = [0.00000000000000000 .. 0.026007601671850678]
# b = -1.2?
# found upper bound!
# t = [0.027005332528205760 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.027005332528205760 .. 10.000000000000000], fprime(t) = [-1.1988005442544818 .. -0.000053900294005870819]
# bisecting [0.31250000000000000 .. 0.37500000000000000] -> [0.31250000000000000 .. 0.34375000000000000], [0.34375000000000000 .. 0.37500000000000000]
# I  = [0.31250000000000000 .. 0.34375000000000000]
# C || f(I) = [1.2091061808168888 .. 1.2316156299784780]
# h  = t |--> e^(-t + 0.2?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.0073936841096472229 .. 10.000000000000000]
# b = -1.?
# t = [0.0075567830021339172 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.0075597782442727310 .. 0.026306076064126189]
# b = -1.2?
# t = [0.0075597782442727310 .. 0.026010814029112227]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.0075597782442727311]
# f(I) = [6.6310167357030991e-8 .. 0.031615630909800574]
# t = [0.027005373326634312 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.027005373326634312 .. 10.000000000000000], fprime(t) = [-1.1988004995509983 .. -0.000054891221225261688]
# returning res = True
# I  = [0.34375000000000000 .. 0.37500000000000000]
# C || f(I) = [1.1872892770916223 .. 1.2091061836108566]
# h  = t |--> e^(-t + 0.18?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.0076326791739897982]
# b = -1.2?
# t = [0.00000000000000000 .. 0.0075603914732419739]
# b = -1.2?
# found upper bound!
# t = [0.0085598439745239503 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.0085598439745239503 .. 10.000000000000000], fprime(t) = [-1.1988006168976427 .. -0.000053900294005870819]
# bisecting [0.34375000000000000 .. 0.37500000000000000] -> [0.34375000000000000 .. 0.35937500000000000], [0.35937500000000000 .. 0.37500000000000000]
# I  = [0.34375000000000000 .. 0.35937500000000000]
# C || f(I) = [1.1981125082820653 .. 1.2091061836108566]
# h  = t |--> e^(-t + 0.19?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.0076326791739897982]
# b = -1.2?
# t = [0.00000000000000000 .. 0.0075603914732419739]
# b = -1.2?
# found upper bound!
# t = [0.0085598439745239503 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.0085598439745239503 .. 10.000000000000000], fprime(t) = [-1.1988006168976427 .. -0.000054392032325267791]
# bisecting [0.34375000000000000 .. 0.35937500000000000] -> [0.34375000000000000 .. 0.35156250000000000], [0.35156250000000000 .. 0.35937500000000000]
# I  = [0.34375000000000000 .. 0.35156250000000000]
# C || f(I) = [1.2035878719761967 .. 1.2091061836108566]
# h  = t |--> e^(-t + 0.19?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.0029673730554095824 .. 10.000000000000000]
# b = -1.?
# t = [0.0029853464944426246 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.0029854293128711499 .. 0.0076774207826303242]
# b = -1.20?
# t = [0.0029854293128711499 .. 0.0075603834985412122]
# b = -1.20?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.0029854293128711500]
# f(I) = [1.1175871339474952e-9 .. 0.0091061845421791521]
# t = [0.0085598420884630838 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.0085598420884630838 .. 10.000000000000000], fprime(t) = [-1.1988006168976427 .. -0.000054641626775264739]
# returning res = True
# I  = [0.35156250000000000 .. 0.35937500000000000]
# C || f(I) = [1.1981125082820653 .. 1.2035878747701645]
# h  = t |--> e^(-t + 0.19?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.0030820887811707924]
# b = -1.20?
# t = [0.00000000000000000 .. 0.0029857282681359280]
# b = -1.20?
# found upper bound!
# t = [0.0039854367045925563 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.0039854367045925563 .. 10.000000000000000], fprime(t) = [-1.1988006168976427 .. -0.000054392032325267791]
# bisecting [0.35156250000000000 .. 0.35937500000000000] -> [0.35156250000000000 .. 0.35546875000000000], [0.35546875000000000 .. 0.35937500000000000]
# I  = [0.35156250000000000 .. 0.35546875000000000]
# C || f(I) = [1.2008448429405689 .. 1.2035878747701645]
# h  = t |--> e^(-t + 0.19?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.00070193396084738816 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.00070378089735922326 .. 0.0030606468407430288]
# b = -1.20?
# t = [0.00070378089735922326 .. 0.0029856102207372012]
# b = -1.20?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.00070378089735922327]
# f(I) = [4.8428774324094092e-9 .. 0.0035878766328096834]
# t = [0.0039854361505964686 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.0039854361505964686 .. 10.000000000000000], fprime(t) = [-1.1988006168976427 .. -0.000054516829550266265]
# returning res = True
# I  = [0.35546875000000000 .. 0.35937500000000000]
# C || f(I) = [1.1981125082820653 .. 1.2008448457345367]
# h  = t |--> e^(-t + 0.19?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.00072135352107009972]
# b = -1.20?
# t = [0.00000000000000000 .. 0.00070380361665494719]
# b = -1.20?
# found upper bound!
# t = [0.0017037921384243513 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.0017037921384243513 .. 10.000000000000000], fprime(t) = [-1.1988006168976427 .. -0.000054392032325267791]
# bisecting [0.35546875000000000 .. 0.35937500000000000] -> [0.35546875000000000 .. 0.35742187500000000], [0.35742187500000000 .. 0.35937500000000000]
# I  = [0.35546875000000000 .. 0.35742187500000000]
# C || f(I) = [1.1994773410260677 .. 1.2008448457345367]
# h  = t |--> e^(-t + 0.19?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.00072135352107009972]
# b = -1.20?
# t = [0.00000000000000000 .. 0.00070380361665494719]
# b = -1.20?
# found upper bound!
# t = [0.0017037921384243513 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.0017037921384243513 .. 10.000000000000000], fprime(t) = [-1.1988006168976427 .. -0.000054453499615192413]
# bisecting [0.35546875000000000 .. 0.35742187500000000] -> [0.35546875000000000 .. 0.35644531250000000], [0.35644531250000000 .. 0.35742187500000000]
# I  = [0.35546875000000000 .. 0.35644531250000000]
# C || f(I) = [1.2001607585698366 .. 1.2008448457345367]
# h  = t |--> e^(-t + 0.183?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.00013386812032647912 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.00013395437371177822 .. 0.00075739677296618902]
# b = -1.200?
# t = [0.00013395437371177822 .. 0.00070382286621643973]
# b = -1.200?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.00013395437371177823]
# f(I) = [-7.4505801528346183e-10 .. 0.00084484666585926683]
# t = [0.0017037912192876842 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.0017037912192876842 .. 10.000000000000000], fprime(t) = [-1.1988006168976427 .. -0.000054485164582729339]
# returning res = True
# I  = [0.35644531250000000 .. 0.35742187500000000]
# C || f(I) = [1.1994773410260677 .. 1.2001607613638044]
# h  = t |--> e^(-t + 0.182?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.00020100000000000001]
# b = -1.200?
# t = [0.00000000000000000 .. 0.00013397175987559909]
# b = -1.200?
# found upper bound!
# t = [0.0011339602751024814 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.0011339602751024814 .. 10.000000000000000], fprime(t) = [-1.1988006168976427 .. -0.000054453499615192413]
# returning res = None
# I  = [0.35742187500000000 .. 0.35937500000000000]
# C || f(I) = [1.1981125082820653 .. 1.1994773438200355]
# h  = t |--> e^(-t + 0.181?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.00000000000000000 .. 10.000000000000000], fprime(t) = [-1.1994773605838419 .. -0.000054392032325267791]
# returning res = False
# I  = [0.35937500000000000 .. 0.37500000000000000]
# C || f(I) = [1.1872892770916223 .. 1.1981125110760332]
# h  = t |--> e^(-t + 0.18?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.00000000000000000 .. 10.000000000000000], fprime(t) = [-1.1981125315651298 .. -0.000053900294005870819]
# returning res = False
# I  = [0.37500000000000000 .. 0.50000000000000000]
# C || f(I) = [1.1065306579694151 .. 1.1872892798855901]
# h  = t |--> e^(-t + 0.2?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.00000000000000000 .. 10.000000000000000], fprime(t) = [-1.1872892985120416 .. -0.000050234608352184295]
# returning res = False
# I  = [0.50000000000000000 .. 1.0000000000000000]
# C || f(I) = [0.86787943867966532 .. 1.1065306612290442]
# h  = t |--> e^(-t + 0.?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.00000000000000000 .. 10.000000000000000], fprime(t) = [-1.1065306821838022 .. -0.000039399601519107818]
# returning res = False
# Signal([0.00000000000000000 .. 1.0000000000000000], [([0.00000000000000000 .. 0.35644531250000000], True), ([0.35742187500000000 .. 1.0000000000000000], False)])

# %%
csig.plot(aspect_ratio=ar)
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# ### Temporal contexts

# %%
csig = C(RIF(0,1),
         (lambda x: x + 0.5),
         (lambda f: to_signal((lambda t: f(t) - 1.2),
                              f.derivative(),
                              RIF(0,10)).G(RIF(0,0.1))(0)),
         y,
         g,
         0.001)
csig
# Out:
# I  = [0.00000000000000000 .. 1.0000000000000000]
# C || f(I) = [0.86787943821400403 .. 1.5000000046566129]
# h  = t |--> e^(-t + 0.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.22435568284070104]
# b = -1.?
# t = [0.00000000000000000 .. 0.22338656918764283]
# b = -1.?
# t = [0.00000000000000000 .. 0.22319218180236586]
# b = -1.?
# t = [0.00000000000000000 .. 0.22315328244546307]
# b = -1.?
# found upper bound!
# t = [0.22414550105913116 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.22414550105913116 .. 10.000000000000000], fprime(t) = [-1.1987982848659158 .. -0.000039399601519107818]
# bisecting [0.00000000000000000 .. 1.0000000000000000] -> [0.00000000000000000 .. 0.50000000000000000], [0.50000000000000000 .. 1.0000000000000000]
# I  = [0.00000000000000000 .. 0.50000000000000000]
# C || f(I) = [1.1065306561067700 .. 1.5000000027939678]
# h  = t |--> e^(-t + 1.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.22435568284070104]
# b = -1.?
# t = [0.00000000000000000 .. 0.22338656794467602]
# b = -1.?
# t = [0.00000000000000000 .. 0.22319218055915766]
# b = -1.?
# t = [0.00000000000000000 .. 0.22315328120220657]
# b = -1.?
# found upper bound!
# t = [0.22414549981586501 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.22414549981586501 .. 10.000000000000000], fprime(t) = [-1.1987982848659158 .. -0.000050234608352184295]
# bisecting [0.00000000000000000 .. 0.50000000000000000] -> [0.00000000000000000 .. 0.25000000000000000], [0.25000000000000000 .. 0.50000000000000000]
# I  = [0.00000000000000000 .. 0.25000000000000000]
# C || f(I) = [1.2788007790222764 .. 1.5000000027939678]
# h  = t |--> e^(-t + 1.?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.052533849807735968 .. 10.000000000000000]
# b = -1.?
# t = [0.061917110175816199 .. 10.000000000000000]
# b = -1.?
# t = [0.063351634750390822 .. 10.000000000000000]
# b = -1.?
# t = [0.063564360902149313 .. 10.000000000000000]
# b = -1.?
# t = [0.063595755990745558 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.063600387009634440 .. 0.22343149784916067]
# b = -2.?
# t = [0.063600387009634440 .. 0.22318605191354166]
# b = -2.?
# t = [0.063600387009634440 .. 0.22314982192248204]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.063600387009634441]
# f(I) = [9.6037983898789036e-7 .. 0.30000000558793550]
# t = [0.22414447788499650 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.22414447788499650 .. 10.000000000000000], fprime(t) = [-1.1987995086237789 .. -0.000058055855333805084]
# bisecting [0.00000000000000000 .. 0.25000000000000000] -> [0.00000000000000000 .. 0.12500000000000000], [0.12500000000000000 .. 0.25000000000000000]
# I  = [0.00000000000000000 .. 0.12500000000000000]
# C || f(I) = [1.3824969008564949 .. 1.5000000018626452]
# h  = t |--> e^(-t + 0.4?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.12166459574575073 .. 10.000000000000000]
# b = -1.?
# t = [0.13982900117570321 .. 10.000000000000000]
# b = -1.?
# t = [0.14143190377997066 .. 10.000000000000000]
# b = -1.?
# t = [0.14155885393982864 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.14156880745642974 .. 0.22482821668589090]
# b = -2.?
# t = [0.14156880745642974 .. 0.22327683058050918]
# b = -2.?
# t = [0.14156880745642974 .. 0.22315400207991371]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.14156880745642975]
# f(I) = [1.0143965483155881e-6 .. 0.30000000372529035]
# t = [0.22414437206818607 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.22414437206818607 .. 10.000000000000000], fprime(t) = [-1.1987996427342296 .. -0.000062762759625911712]
# returning res = True
# I  = [0.12500000000000000 .. 0.25000000000000000]
# C || f(I) = [1.2788007808849215 .. 1.3824969036504627]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.056998879809454547 .. 10.000000000000000]
# b = -1.?
# t = [0.063085857027253083 .. 10.000000000000000]
# b = -1.?
# t = [0.063562412911940591 .. 10.000000000000000]
# b = -1.?
# t = [0.063598279577868455 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.063600971081354873 .. 0.14217518224324677]
# b = -1.2?
# t = [0.063600971081354873 .. 0.14161524663815156]
# b = -1.2?
# t = [0.063600971081354873 .. 0.14157308011475964]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.063600971081354874]
# f(I) = [2.6188790802628147e-7 .. 0.18249690458178525]
# t = [0.14256991651995568 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.14256991651995568 .. 10.000000000000000], fprime(t) = [-1.1988003132864833 .. -0.000058055855333805084]
# bisecting [0.12500000000000000 .. 0.25000000000000000] -> [0.12500000000000000 .. 0.18750000000000000], [0.18750000000000000 .. 0.25000000000000000]
# I  = [0.12500000000000000 .. 0.18750000000000000]
# C || f(I) = [1.3290291167795658 .. 1.3824969036504627]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.093330488085460114 .. 10.000000000000000]
# b = -1.?
# t = [0.10174983593852612 .. 10.000000000000000]
# b = -1.?
# t = [0.10211246815532962 .. 10.000000000000000]
# b = -1.?
# t = [0.10212656241865537 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.10212710646465010 .. 0.14264170281607314]
# b = -1.2?
# t = [0.10212710646465010 .. 0.14161167156474655]
# b = -1.2?
# t = [0.10212710646465010 .. 0.14157128530381075]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.10212710646465011]
# f(I) = [2.7194619223180893e-8 .. 0.18249690644443040]
# t = [0.14256972240174009 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.14256972240174009 .. 10.000000000000000], fprime(t) = [-1.1988005442544818 .. -0.000060335732996463775]
# returning res = True
# I  = [0.18750000000000000 .. 0.25000000000000000]
# C || f(I) = [1.2788007808849215 .. 1.3290291186422110]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.059291985211216154 .. 10.000000000000000]
# b = -1.?
# t = [0.063429409223147867 .. 10.000000000000000]
# b = -1.?
# t = [0.063594682408268959 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.063600942695701268 .. 0.10290221168173521]
# b = -1.2?
# t = [0.063600942695701268 .. 0.10215671603728931]
# b = -1.2?
# t = [0.063600942695701268 .. 0.10212825302785072]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.063600942695701269]
# f(I) = [2.9541552071243870e-7 .. 0.12902912050485616]
# t = [0.10312717558732849 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10312717558732849 .. 10.000000000000000], fprime(t) = [-1.1988005721941591 .. -0.000058055855333805084]
# bisecting [0.18750000000000000 .. 0.25000000000000000] -> [0.18750000000000000 .. 0.21875000000000000], [0.21875000000000000 .. 0.25000000000000000]
# I  = [0.18750000000000000 .. 0.21875000000000000]
# C || f(I) = [1.3035225719213485 .. 1.3290291186422110]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.077893377150550752 .. 10.000000000000000]
# b = -1.?
# t = [0.082643986487211648 .. 10.000000000000000]
# b = -1.?
# t = [0.082746695477005013 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.082748672480581944 .. 0.10317100637920182]
# b = -1.2?
# t = [0.082748672480581944 .. 0.10214770266272294]
# b = -1.2?
# t = [0.082748672480581944 .. 0.10212752853878353]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.082748672480581945]
# f(I) = [4.5821070715490463e-8 .. 0.12902912050485616]
# t = [0.10312714123652644 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10312714123652644 .. 10.000000000000000], fprime(t) = [-1.1988006075844169 .. -0.000059177167713642120]
# bisecting [0.18750000000000000 .. 0.21875000000000000] -> [0.18750000000000000 .. 0.20312500000000000], [0.20312500000000000 .. 0.21875000000000000]
# I  = [0.18750000000000000 .. 0.20312500000000000]
# C || f(I) = [1.3161762114614248 .. 1.3290291186422110]
# h  = t |--> e^(-t + 0.28?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.087414341846438287 .. 10.000000000000000]
# b = -1.?
# t = [0.092348526766389493 .. 10.000000000000000]
# b = -1.?
# t = [0.092408576031254269 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.092409158012199607 .. 0.10312342178500764]
# b = -1.2?
# t = [0.092409158012199607 .. 0.10213726109113644]
# b = -1.2?
# t = [0.092409158012199607 .. 0.10212723182869888]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.092409158012199608]
# f(I) = [6.7055225816403662e-9 .. 0.12902912050485616]
# t = [0.10312713437065855 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10312713437065855 .. 10.000000000000000], fprime(t) = [-1.1988006168976427 .. -0.000059752725064754486]
# bisecting [0.18750000000000000 .. 0.20312500000000000] -> [0.18750000000000000 .. 0.19531250000000000], [0.19531250000000000 .. 0.20312500000000000]
# I  = [0.18750000000000000 .. 0.19531250000000000]
# C || f(I) = [1.3225775603204965 .. 1.3290291186422110]
# h  = t |--> e^(-t + 0.28?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.092230902038488341 .. 10.000000000000000]
# b = -1.?
# t = [0.097223984085367892 .. 10.000000000000000]
# b = -1.?
# t = [0.097260790031629379 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.097260970140040786 .. 0.10273235760065879]
# b = -1.20?
# t = [0.097260970140040786 .. 0.10213025413511235]
# b = -1.20?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.097260970140040787]
# f(I) = [-7.4505801528346183e-10 .. 0.12902912050485616]
# t = [0.10312714873183534 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10312714873183534 .. 10.000000000000000], fprime(t) = [-1.1988005982711912 .. -0.000060043297708034515]
# bisecting [0.18750000000000000 .. 0.19531250000000000] -> [0.18750000000000000 .. 0.19140625000000000], [0.19140625000000000 .. 0.19531250000000000]
# I  = [0.18750000000000000 .. 0.19140625000000000]
# C || f(I) = [1.3257970381528139 .. 1.3290291186422110]
# h  = t |--> e^(-t + 0.29?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.094653330359099521 .. 10.000000000000000]
# b = -1.?
# t = [0.099667359606792349 .. 10.000000000000000]
# b = -1.?
# t = [0.099692196725497922 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.099692258043299883 .. 0.10301604315426987]
# b = -1.20?
# t = [0.099692258043299883 .. 0.10212968899211273]
# b = -1.20?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.099692258043299884]
# f(I) = [-7.4505801528346183e-10 .. 0.12902912050485616]
# t = [0.10312713965784159 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10312713965784159 .. 10.000000000000000], fprime(t) = [-1.1988006168976427 .. -0.000060188584029674530]
# bisecting [0.18750000000000000 .. 0.19140625000000000] -> [0.18750000000000000 .. 0.18945312500000000], [0.18945312500000000 .. 0.19140625000000000]
# I  = [0.18750000000000000 .. 0.18945312500000000]
# C || f(I) = [1.3274114988744258 .. 1.3290291186422110]
# h  = t |--> e^(-t + 0.284?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.095868098014317712 .. 10.000000000000000]
# b = -1.?
# t = [0.10089044001443285 .. 10.000000000000000]
# b = -1.?
# t = [0.10090922265757615 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.10090924529217479 .. 0.10313852112254747]
# b = -1.20?
# t = [0.10090924529217479 .. 0.10212887473841416]
# b = -1.20?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.10090924529217480]
# f(I) = [-7.4505801528346183e-10 .. 0.12902912050485616]
# t = [0.10312713621513940 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10312713621513940 .. 10.000000000000000], fprime(t) = [-1.1988006168976427 .. -0.000060263089835643768]
# returning res = True
# I  = [0.18945312500000000 .. 0.19140625000000000]
# C || f(I) = [1.3257970381528139 .. 1.3274115016683937]
# h  = t |--> e^(-t + 0.283?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.094768677613692522 .. 10.000000000000000]
# b = -1.?
# t = [0.099674182558580598 .. 10.000000000000000]
# b = -1.?
# t = [0.099692235046562285 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.099692257681181173 .. 0.10189707206057289]
# b = -1.20?
# t = [0.099692257681181173 .. 0.10091093997269022]
# b = -1.20?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.099692257681181174]
# f(I) = [-7.4505801528346183e-10 .. 0.12741150259971624]
# t = [0.10190925260829943 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10190925260829943 .. 10.000000000000000], fprime(t) = [-1.1988006168976427 .. -0.000060188584029674530]
# bisecting [0.18945312500000000 .. 0.19140625000000000] -> [0.18945312500000000 .. 0.19042968750000000], [0.19042968750000000 .. 0.19140625000000000]
# I  = [0.18945312500000000 .. 0.19042968750000000]
# C || f(I) = [1.3266038745641708 .. 1.3274115016683937]
# h  = t |--> e^(-t + 0.283?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.095376504500096007 .. 10.000000000000000]
# b = -1.?
# t = [0.10028554775379178 .. 10.000000000000000]
# b = -1.?
# t = [0.10030062980533878 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.10030064004365379 .. 0.10140364644409033]
# b = -1.20?
# t = [0.10030064004365379 .. 0.10090967348278606]
# b = -1.200?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.10030064004365380]
# f(I) = [-7.4505801528346183e-10 .. 0.12741150259971624]
# t = [0.10190925091959185 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10190925091959185 .. 10.000000000000000], fprime(t) = [-1.1988006168976427 .. -0.000060225836932659149]
# returning res = True
# I  = [0.19042968750000000 .. 0.19140625000000000]
# C || f(I) = [1.3257970381528139 .. 1.3266038773581386]
# h  = t |--> e^(-t + 0.283?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.094826372183547905 .. 10.000000000000000]
# b = -1.?
# t = [0.099677485366655563 .. 10.000000000000000]
# b = -1.?
# t = [0.099692247871531011 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.099692258109848316 .. 0.10078918069094678]
# b = -1.20?
# t = [0.099692258109848316 .. 0.10030106207543369]
# b = -1.200?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.099692258109848317]
# f(I) = [-7.4505801528346183e-10 .. 0.12660387828946119]
# t = [0.10130064571718604 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10130064571718604 .. 10.000000000000000], fprime(t) = [-1.1988006168976427 .. -0.000060188584029674530]
# returning res = None
# I  = [0.19140625000000000 .. 0.19531250000000000]
# C || f(I) = [1.3225775603204965 .. 1.3257970409467817]
# h  = t |--> e^(-t + 0.28?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.092455746047769071 .. 10.000000000000000]
# b = -1.?
# t = [0.097237803914951057 .. 10.000000000000000]
# b = -1.?
# t = [0.097260913152385025 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.097260969825102461 .. 0.10051108447177285]
# b = -1.20?
# t = [0.097260969825102461 .. 0.099694586329056423]
# b = -1.20?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.097260969825102462]
# f(I) = [1.1175871339474952e-9 .. 0.12579704187810426]
# t = [0.10069226925090637 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10069226925090637 .. 10.000000000000000], fprime(t) = [-1.1988006168976427 .. -0.000060043297708034515]
# returning res = False
# I  = [0.19531250000000000 .. 0.20312500000000000]
# C || f(I) = [1.3161762114614248 .. 1.3225775631144643]
# h  = t |--> e^(-t + 0.28?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.087840750649648136 .. 10.000000000000000]
# b = -1.?
# t = [0.092376683079274643 .. 10.000000000000000]
# b = -1.?
# t = [0.092409005625814596 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.092409162566446934 .. 0.097633059079660343]
# b = -1.20?
# t = [0.092409162566446934 .. 0.097262845333573156]
# b = -1.20?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.092409162566446935]
# f(I) = [1.1175871339474952e-9 .. 0.12257756404578691]
# t = [0.098260984907101514 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.098260984907101514 .. 10.000000000000000], fprime(t) = [-1.1988006075844169 .. -0.000059752725064754486]
# returning res = False
# I  = [0.20312500000000000 .. 0.21875000000000000]
# C || f(I) = [1.3035225719213485 .. 1.3161762133240700]
# h  = t |--> e^(-t + 0.27?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.078654032165492007 .. 10.000000000000000]
# b = -1.?
# t = [0.082701053081253805 .. 10.000000000000000]
# b = -1.?
# t = [0.082748252444133307 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.082748706864325005 .. 0.092452273705611280]
# b = -1.2?
# t = [0.082748706864325005 .. 0.092409584321384339]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.082748706864325006]
# f(I) = [4.8428774324094092e-9 .. 0.11617621518671518]
# t = [0.093409173252317623 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.093409173252317623 .. 10.000000000000000], fprime(t) = [-1.1988006168976427 .. -0.000059177167713642120]
# returning res = False
# I  = [0.21875000000000000 .. 0.25000000000000000]
# C || f(I) = [1.2788007808849215 .. 1.3035225747153163]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.060452176399285781 .. 10.000000000000000]
# b = -1.?
# t = [0.063536607829696153 .. 10.000000000000000]
# b = -1.?
# t = [0.063599962381737526 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.063601166279161625 .. 0.083453950997009863]
# b = -1.2?
# t = [0.063601166279161625 .. 0.082762335905936624]
# b = -1.2?
# t = [0.063601166279161625 .. 0.082748976069711864]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.063601166279161626]
# f(I) = [2.7194619223180893e-8 .. 0.10352257564663892]
# t = [0.083748722681430534 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.083748722681430534 .. 10.000000000000000], fprime(t) = [-1.1988006075844169 .. -0.000058055855333805084]
# returning res = False
# I  = [0.25000000000000000 .. 0.50000000000000000]
# C || f(I) = [1.1065306579694151 .. 1.2788007836788893]
# h  = t |--> e^(-t + 0.2?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.063891780303481194]
# b = -2.?
# t = [0.00000000000000000 .. 0.063619141540639482]
# b = -2.?
# t = [0.00000000000000000 .. 0.063602301712363072]
# b = -2.?
# found upper bound!
# t = [0.064601264061761615 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.064601264061761615 .. 10.000000000000000], fprime(t) = [-1.1988005368039012 .. -0.000050234608352184295]
# returning res = False
# I  = [0.50000000000000000 .. 1.0000000000000000]
# C || f(I) = [0.86787943867966532 .. 1.1065306612290442]
# h  = t |--> e^(-t + 0.?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.00000000000000000 .. 10.000000000000000], fprime(t) = [-1.1065306821838022 .. -0.000039399601519107818]
# returning res = False
# Signal([0.00000000000000000 .. 1.0000000000000000], [([0.00000000000000000 .. 0.19042968750000000], True), ([0.19140625000000000 .. 1.0000000000000000], False)])

# %%
csig.plot(aspect_ratio=ar)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
csig = C(RIF(0,1),
         (lambda x: x + 0.5),
         (lambda f: to_signal((lambda t: f(t) - 1.2),
                              f.derivative(),
                              RIF(0,10)).F(RIF(0.1,0.2))(0)),
         y,
         g,
         0.001)
csig
# Out:
# I  = [0.00000000000000000 .. 1.0000000000000000]
# C || f(I) = [0.86787943821400403 .. 1.5000000046566129]
# h  = t |--> e^(-t + 0.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.22435568284070104]
# b = -1.?
# t = [0.00000000000000000 .. 0.22338656918764283]
# b = -1.?
# t = [0.00000000000000000 .. 0.22319218180236586]
# b = -1.?
# t = [0.00000000000000000 .. 0.22315328244546307]
# b = -1.?
# found upper bound!
# t = [0.22414550105913116 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.22414550105913116 .. 10.000000000000000], fprime(t) = [-1.1987982848659158 .. -0.000039399601519107818]
# bisecting [0.00000000000000000 .. 1.0000000000000000] -> [0.00000000000000000 .. 0.50000000000000000], [0.50000000000000000 .. 1.0000000000000000]
# I  = [0.00000000000000000 .. 0.50000000000000000]
# C || f(I) = [1.1065306561067700 .. 1.5000000027939678]
# h  = t |--> e^(-t + 1.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.22435568284070104]
# b = -1.?
# t = [0.00000000000000000 .. 0.22338656794467602]
# b = -1.?
# t = [0.00000000000000000 .. 0.22319218055915766]
# b = -1.?
# t = [0.00000000000000000 .. 0.22315328120220657]
# b = -1.?
# found upper bound!
# t = [0.22414549981586501 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.22414549981586501 .. 10.000000000000000], fprime(t) = [-1.1987982848659158 .. -0.000050234608352184295]
# bisecting [0.00000000000000000 .. 0.50000000000000000] -> [0.00000000000000000 .. 0.25000000000000000], [0.25000000000000000 .. 0.50000000000000000]
# I  = [0.00000000000000000 .. 0.25000000000000000]
# C || f(I) = [1.2788007790222764 .. 1.5000000027939678]
# h  = t |--> e^(-t + 1.?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.052533849807735968 .. 10.000000000000000]
# b = -1.?
# t = [0.061917110175816199 .. 10.000000000000000]
# b = -1.?
# t = [0.063351634750390822 .. 10.000000000000000]
# b = -1.?
# t = [0.063564360902149313 .. 10.000000000000000]
# b = -1.?
# t = [0.063595755990745558 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.063600387009634440 .. 0.22343149784916067]
# b = -2.?
# t = [0.063600387009634440 .. 0.22318605191354166]
# b = -2.?
# t = [0.063600387009634440 .. 0.22314982192248204]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.063600387009634441]
# f(I) = [9.6037983898789036e-7 .. 0.30000000558793550]
# t = [0.22414447788499650 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.22414447788499650 .. 10.000000000000000], fprime(t) = [-1.1987995086237789 .. -0.000058055855333805084]
# bisecting [0.00000000000000000 .. 0.25000000000000000] -> [0.00000000000000000 .. 0.12500000000000000], [0.12500000000000000 .. 0.25000000000000000]
# I  = [0.00000000000000000 .. 0.12500000000000000]
# C || f(I) = [1.3824969008564949 .. 1.5000000018626452]
# h  = t |--> e^(-t + 0.4?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.12166459574575073 .. 10.000000000000000]
# b = -1.?
# t = [0.13982900117570321 .. 10.000000000000000]
# b = -1.?
# t = [0.14143190377997066 .. 10.000000000000000]
# b = -1.?
# t = [0.14155885393982864 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.14156880745642974 .. 0.22482821668589090]
# b = -2.?
# t = [0.14156880745642974 .. 0.22327683058050918]
# b = -2.?
# t = [0.14156880745642974 .. 0.22315400207991371]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.14156880745642975]
# f(I) = [1.0143965483155881e-6 .. 0.30000000372529035]
# t = [0.22414437206818607 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.22414437206818607 .. 10.000000000000000], fprime(t) = [-1.1987996427342296 .. -0.000062762759625911712]
# returning res = True
# I  = [0.12500000000000000 .. 0.25000000000000000]
# C || f(I) = [1.2788007808849215 .. 1.3824969036504627]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.056998879809454547 .. 10.000000000000000]
# b = -1.?
# t = [0.063085857027253083 .. 10.000000000000000]
# b = -1.?
# t = [0.063562412911940591 .. 10.000000000000000]
# b = -1.?
# t = [0.063598279577868455 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.063600971081354873 .. 0.14217518224324677]
# b = -1.2?
# t = [0.063600971081354873 .. 0.14161524663815156]
# b = -1.2?
# t = [0.063600971081354873 .. 0.14157308011475964]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.063600971081354874]
# f(I) = [2.6188790802628147e-7 .. 0.18249690458178525]
# t = [0.14256991651995568 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.14256991651995568 .. 10.000000000000000], fprime(t) = [-1.1988003132864833 .. -0.000058055855333805084]
# bisecting [0.12500000000000000 .. 0.25000000000000000] -> [0.12500000000000000 .. 0.18750000000000000], [0.18750000000000000 .. 0.25000000000000000]
# I  = [0.12500000000000000 .. 0.18750000000000000]
# C || f(I) = [1.3290291167795658 .. 1.3824969036504627]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.093330488085460114 .. 10.000000000000000]
# b = -1.?
# t = [0.10174983593852612 .. 10.000000000000000]
# b = -1.?
# t = [0.10211246815532962 .. 10.000000000000000]
# b = -1.?
# t = [0.10212656241865537 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.10212710646465010 .. 0.14264170281607314]
# b = -1.2?
# t = [0.10212710646465010 .. 0.14161167156474655]
# b = -1.2?
# t = [0.10212710646465010 .. 0.14157128530381075]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.10212710646465011]
# f(I) = [2.7194619223180893e-8 .. 0.18249690644443040]
# t = [0.14256972240174009 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.14256972240174009 .. 10.000000000000000], fprime(t) = [-1.1988005442544818 .. -0.000060335732996463775]
# returning res = True
# I  = [0.18750000000000000 .. 0.25000000000000000]
# C || f(I) = [1.2788007808849215 .. 1.3290291186422110]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.059291985211216154 .. 10.000000000000000]
# b = -1.?
# t = [0.063429409223147867 .. 10.000000000000000]
# b = -1.?
# t = [0.063594682408268959 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.063600942695701268 .. 0.10290221168173521]
# b = -1.2?
# t = [0.063600942695701268 .. 0.10215671603728931]
# b = -1.2?
# t = [0.063600942695701268 .. 0.10212825302785072]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.063600942695701269]
# f(I) = [2.9541552071243870e-7 .. 0.12902912050485616]
# t = [0.10312717558732849 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10312717558732849 .. 10.000000000000000], fprime(t) = [-1.1988005721941591 .. -0.000058055855333805084]
# bisecting [0.18750000000000000 .. 0.25000000000000000] -> [0.18750000000000000 .. 0.21875000000000000], [0.21875000000000000 .. 0.25000000000000000]
# I  = [0.18750000000000000 .. 0.21875000000000000]
# C || f(I) = [1.3035225719213485 .. 1.3290291186422110]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.077893377150550752 .. 10.000000000000000]
# b = -1.?
# t = [0.082643986487211648 .. 10.000000000000000]
# b = -1.?
# t = [0.082746695477005013 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.082748672480581944 .. 0.10317100637920182]
# b = -1.2?
# t = [0.082748672480581944 .. 0.10214770266272294]
# b = -1.2?
# t = [0.082748672480581944 .. 0.10212752853878353]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.082748672480581945]
# f(I) = [4.5821070715490463e-8 .. 0.12902912050485616]
# t = [0.10312714123652644 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10312714123652644 .. 10.000000000000000], fprime(t) = [-1.1988006075844169 .. -0.000059177167713642120]
# bisecting [0.18750000000000000 .. 0.21875000000000000] -> [0.18750000000000000 .. 0.20312500000000000], [0.20312500000000000 .. 0.21875000000000000]
# I  = [0.18750000000000000 .. 0.20312500000000000]
# C || f(I) = [1.3161762114614248 .. 1.3290291186422110]
# h  = t |--> e^(-t + 0.28?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.087414341846438287 .. 10.000000000000000]
# b = -1.?
# t = [0.092348526766389493 .. 10.000000000000000]
# b = -1.?
# t = [0.092408576031254269 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.092409158012199607 .. 0.10312342178500764]
# b = -1.2?
# t = [0.092409158012199607 .. 0.10213726109113644]
# b = -1.2?
# t = [0.092409158012199607 .. 0.10212723182869888]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.092409158012199608]
# f(I) = [6.7055225816403662e-9 .. 0.12902912050485616]
# t = [0.10312713437065855 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10312713437065855 .. 10.000000000000000], fprime(t) = [-1.1988006168976427 .. -0.000059752725064754486]
# bisecting [0.18750000000000000 .. 0.20312500000000000] -> [0.18750000000000000 .. 0.19531250000000000], [0.19531250000000000 .. 0.20312500000000000]
# I  = [0.18750000000000000 .. 0.19531250000000000]
# C || f(I) = [1.3225775603204965 .. 1.3290291186422110]
# h  = t |--> e^(-t + 0.28?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.092230902038488341 .. 10.000000000000000]
# b = -1.?
# t = [0.097223984085367892 .. 10.000000000000000]
# b = -1.?
# t = [0.097260790031629379 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.097260970140040786 .. 0.10273235760065879]
# b = -1.20?
# t = [0.097260970140040786 .. 0.10213025413511235]
# b = -1.20?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.097260970140040787]
# f(I) = [-7.4505801528346183e-10 .. 0.12902912050485616]
# t = [0.10312714873183534 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10312714873183534 .. 10.000000000000000], fprime(t) = [-1.1988005982711912 .. -0.000060043297708034515]
# bisecting [0.18750000000000000 .. 0.19531250000000000] -> [0.18750000000000000 .. 0.19140625000000000], [0.19140625000000000 .. 0.19531250000000000]
# I  = [0.18750000000000000 .. 0.19140625000000000]
# C || f(I) = [1.3257970381528139 .. 1.3290291186422110]
# h  = t |--> e^(-t + 0.29?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.094653330359099521 .. 10.000000000000000]
# b = -1.?
# t = [0.099667359606792349 .. 10.000000000000000]
# b = -1.?
# t = [0.099692196725497922 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.099692258043299883 .. 0.10301604315426987]
# b = -1.20?
# t = [0.099692258043299883 .. 0.10212968899211273]
# b = -1.20?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.099692258043299884]
# f(I) = [-7.4505801528346183e-10 .. 0.12902912050485616]
# t = [0.10312713965784159 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10312713965784159 .. 10.000000000000000], fprime(t) = [-1.1988006168976427 .. -0.000060188584029674530]
# bisecting [0.18750000000000000 .. 0.19140625000000000] -> [0.18750000000000000 .. 0.18945312500000000], [0.18945312500000000 .. 0.19140625000000000]
# I  = [0.18750000000000000 .. 0.18945312500000000]
# C || f(I) = [1.3274114988744258 .. 1.3290291186422110]
# h  = t |--> e^(-t + 0.284?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.095868098014317712 .. 10.000000000000000]
# b = -1.?
# t = [0.10089044001443285 .. 10.000000000000000]
# b = -1.?
# t = [0.10090922265757615 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.10090924529217479 .. 0.10313852112254747]
# b = -1.20?
# t = [0.10090924529217479 .. 0.10212887473841416]
# b = -1.20?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.10090924529217480]
# f(I) = [-7.4505801528346183e-10 .. 0.12902912050485616]
# t = [0.10312713621513940 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10312713621513940 .. 10.000000000000000], fprime(t) = [-1.1988006168976427 .. -0.000060263089835643768]
# returning res = True
# I  = [0.18945312500000000 .. 0.19140625000000000]
# C || f(I) = [1.3257970381528139 .. 1.3274115016683937]
# h  = t |--> e^(-t + 0.283?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.094768677613692522 .. 10.000000000000000]
# b = -1.?
# t = [0.099674182558580598 .. 10.000000000000000]
# b = -1.?
# t = [0.099692235046562285 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.099692257681181173 .. 0.10189707206057289]
# b = -1.20?
# t = [0.099692257681181173 .. 0.10091093997269022]
# b = -1.20?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.099692257681181174]
# f(I) = [-7.4505801528346183e-10 .. 0.12741150259971624]
# t = [0.10190925260829943 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10190925260829943 .. 10.000000000000000], fprime(t) = [-1.1988006168976427 .. -0.000060188584029674530]
# bisecting [0.18945312500000000 .. 0.19140625000000000] -> [0.18945312500000000 .. 0.19042968750000000], [0.19042968750000000 .. 0.19140625000000000]
# I  = [0.18945312500000000 .. 0.19042968750000000]
# C || f(I) = [1.3266038745641708 .. 1.3274115016683937]
# h  = t |--> e^(-t + 0.283?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.095376504500096007 .. 10.000000000000000]
# b = -1.?
# t = [0.10028554775379178 .. 10.000000000000000]
# b = -1.?
# t = [0.10030062980533878 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.10030064004365379 .. 0.10140364644409033]
# b = -1.20?
# t = [0.10030064004365379 .. 0.10090967348278606]
# b = -1.200?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.10030064004365380]
# f(I) = [-7.4505801528346183e-10 .. 0.12741150259971624]
# t = [0.10190925091959185 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10190925091959185 .. 10.000000000000000], fprime(t) = [-1.1988006168976427 .. -0.000060225836932659149]
# returning res = True
# I  = [0.19042968750000000 .. 0.19140625000000000]
# C || f(I) = [1.3257970381528139 .. 1.3266038773581386]
# h  = t |--> e^(-t + 0.283?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.094826372183547905 .. 10.000000000000000]
# b = -1.?
# t = [0.099677485366655563 .. 10.000000000000000]
# b = -1.?
# t = [0.099692247871531011 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.099692258109848316 .. 0.10078918069094678]
# b = -1.20?
# t = [0.099692258109848316 .. 0.10030106207543369]
# b = -1.200?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.099692258109848317]
# f(I) = [-7.4505801528346183e-10 .. 0.12660387828946119]
# t = [0.10130064571718604 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10130064571718604 .. 10.000000000000000], fprime(t) = [-1.1988006168976427 .. -0.000060188584029674530]
# returning res = None
# I  = [0.19140625000000000 .. 0.19531250000000000]
# C || f(I) = [1.3225775603204965 .. 1.3257970409467817]
# h  = t |--> e^(-t + 0.28?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.092455746047769071 .. 10.000000000000000]
# b = -1.?
# t = [0.097237803914951057 .. 10.000000000000000]
# b = -1.?
# t = [0.097260913152385025 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.097260969825102461 .. 0.10051108447177285]
# b = -1.20?
# t = [0.097260969825102461 .. 0.099694586329056423]
# b = -1.20?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.097260969825102462]
# f(I) = [1.1175871339474952e-9 .. 0.12579704187810426]
# t = [0.10069226925090637 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10069226925090637 .. 10.000000000000000], fprime(t) = [-1.1988006168976427 .. -0.000060043297708034515]
# returning res = False
# I  = [0.19531250000000000 .. 0.20312500000000000]
# C || f(I) = [1.3161762114614248 .. 1.3225775631144643]
# h  = t |--> e^(-t + 0.28?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.087840750649648136 .. 10.000000000000000]
# b = -1.?
# t = [0.092376683079274643 .. 10.000000000000000]
# b = -1.?
# t = [0.092409005625814596 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.092409162566446934 .. 0.097633059079660343]
# b = -1.20?
# t = [0.092409162566446934 .. 0.097262845333573156]
# b = -1.20?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.092409162566446935]
# f(I) = [1.1175871339474952e-9 .. 0.12257756404578691]
# t = [0.098260984907101514 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.098260984907101514 .. 10.000000000000000], fprime(t) = [-1.1988006075844169 .. -0.000059752725064754486]
# returning res = False
# I  = [0.20312500000000000 .. 0.21875000000000000]
# C || f(I) = [1.3035225719213485 .. 1.3161762133240700]
# h  = t |--> e^(-t + 0.27?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.078654032165492007 .. 10.000000000000000]
# b = -1.?
# t = [0.082701053081253805 .. 10.000000000000000]
# b = -1.?
# t = [0.082748252444133307 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.082748706864325005 .. 0.092452273705611280]
# b = -1.2?
# t = [0.082748706864325005 .. 0.092409584321384339]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.082748706864325006]
# f(I) = [4.8428774324094092e-9 .. 0.11617621518671518]
# t = [0.093409173252317623 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.093409173252317623 .. 10.000000000000000], fprime(t) = [-1.1988006168976427 .. -0.000059177167713642120]
# returning res = False
# I  = [0.21875000000000000 .. 0.25000000000000000]
# C || f(I) = [1.2788007808849215 .. 1.3035225747153163]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.060452176399285781 .. 10.000000000000000]
# b = -1.?
# t = [0.063536607829696153 .. 10.000000000000000]
# b = -1.?
# t = [0.063599962381737526 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.063601166279161625 .. 0.083453950997009863]
# b = -1.2?
# t = [0.063601166279161625 .. 0.082762335905936624]
# b = -1.2?
# t = [0.063601166279161625 .. 0.082748976069711864]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.063601166279161626]
# f(I) = [2.7194619223180893e-8 .. 0.10352257564663892]
# t = [0.083748722681430534 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.083748722681430534 .. 10.000000000000000], fprime(t) = [-1.1988006075844169 .. -0.000058055855333805084]
# returning res = False
# I  = [0.25000000000000000 .. 0.50000000000000000]
# C || f(I) = [1.1065306579694151 .. 1.2788007836788893]
# h  = t |--> e^(-t + 0.2?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.063891780303481194]
# b = -2.?
# t = [0.00000000000000000 .. 0.063619141540639482]
# b = -2.?
# t = [0.00000000000000000 .. 0.063602301712363072]
# b = -2.?
# found upper bound!
# t = [0.064601264061761615 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.064601264061761615 .. 10.000000000000000], fprime(t) = [-1.1988005368039012 .. -0.000050234608352184295]
# returning res = False
# I  = [0.50000000000000000 .. 1.0000000000000000]
# C || f(I) = [0.86787943867966532 .. 1.1065306612290442]
# h  = t |--> e^(-t + 0.?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.00000000000000000 .. 10.000000000000000], fprime(t) = [-1.1065306821838022 .. -0.000039399601519107818]
# returning res = False
# Signal([0.00000000000000000 .. 1.0000000000000000], [([0.00000000000000000 .. 0.19042968750000000], True), ([0.19140625000000000 .. 1.0000000000000000], False)])

# %%
csig.plot(aspect_ratio=ar)
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# ### Uncertain contexts

# %%
csig = C(RIF(0,1),
         (lambda x: x + RIF(0.4,0.6)),
         (lambda f: to_signal((lambda t: f(t) - 1.2),
                              f.derivative(),
                              RIF(0,10)).F(RIF(0.1,0.2))(0)),
         y,
         g,
         0.01)
csig
# Out:
# I  = [0.00000000000000000 .. 1.0000000000000000]
# C || f(I) = [0.76787943821400406 .. 1.6000000046566130]
# h  = t |--> e^(-t + 0.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.29054522588902532]
# b = -1.?
# t = [0.00000000000000000 .. 0.28840093611843904]
# b = -1.?
# t = [0.00000000000000000 .. 0.28786198568501587]
# b = -1.?
# t = [0.00000000000000000 .. 0.28772706742918558]
# b = -1.?
# t = [0.00000000000000000 .. 0.28769332514687385]
# b = -1.?
# found upper bound!
# t = [0.28868488980911677 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.28868488980911677 .. 10.000000000000000], fprime(t) = [-1.1987972492352129 .. -0.000034860335290431976]
# bisecting [0.00000000000000000 .. 1.0000000000000000] -> [0.00000000000000000 .. 0.50000000000000000], [0.50000000000000000 .. 1.0000000000000000]
# I  = [0.00000000000000000 .. 0.50000000000000000]
# C || f(I) = [1.0065306561067699 .. 1.6000000027939679]
# h  = t |--> e^(-t + 1.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.29054522588902532]
# b = -1.?
# t = [0.00000000000000000 .. 0.28840093494679698]
# b = -1.?
# t = [0.00000000000000000 .. 0.28786198451180523]
# b = -1.?
# t = [0.00000000000000000 .. 0.28772706509150759]
# b = -1.?
# t = [0.00000000000000000 .. 0.28769332455532748]
# b = -1.?
# found upper bound!
# t = [0.28868488805339753 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.28868488805339753 .. 10.000000000000000], fprime(t) = [-1.1987972399219871 .. -0.000045695342123508453]
# bisecting [0.00000000000000000 .. 0.50000000000000000] -> [0.00000000000000000 .. 0.25000000000000000], [0.25000000000000000 .. 0.50000000000000000]
# I  = [0.00000000000000000 .. 0.25000000000000000]
# C || f(I) = [1.1788007790222763 .. 1.6000000027939679]
# h  = t |--> e^(-t + 1.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.29054522588902532]
# b = -1.?
# t = [0.00000000000000000 .. 0.28840093436596854]
# b = -1.?
# t = [0.00000000000000000 .. 0.28786198509513001]
# b = -1.?
# t = [0.00000000000000000 .. 0.28772706567483237]
# b = -1.?
# t = [0.00000000000000000 .. 0.28769332397447939]
# b = -1.?
# found upper bound!
# t = [0.28868488863670266 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.28868488863670266 .. 10.000000000000000], fprime(t) = [-1.1987972492352129 .. -0.000053514726459980010]
# bisecting [0.00000000000000000 .. 0.25000000000000000] -> [0.00000000000000000 .. 0.12500000000000000], [0.12500000000000000 .. 0.25000000000000000]
# I  = [0.00000000000000000 .. 0.12500000000000000]
# C || f(I) = [1.2824969008564948 .. 1.6000000018626453]
# h  = t |--> e^(-t + 1.?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.051560559781362785 .. 10.000000000000000]
# b = -1.?
# t = [0.063436409318265468 .. 10.000000000000000]
# b = -1.?
# t = [0.065878173471638795 .. 10.000000000000000]
# b = -1.?
# t = [0.066366294337815212 .. 10.000000000000000]
# b = -1.?
# t = [0.066463298724999120 .. 10.000000000000000]
# b = -1.?
# t = [0.066482554027200491 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.066486375649838502 .. 0.28895945308239962]
# b = -1.?
# t = [0.066486375649838502 .. 0.28793621218448301]
# b = -1.?
# t = [0.066486375649838502 .. 0.28773253120896692]
# b = -1.?
# t = [0.066486375649838502 .. 0.28769208911423555]
# b = -1.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.066486375649838503]
# f(I) = [1.1354684830156003e-6 .. 0.40000000521540647]
# t = [0.28868406238195487 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.28868406238195487 .. 10.000000000000000], fprime(t) = [-1.1987982308492065 .. -0.000058223493397235870]
# bisecting [0.00000000000000000 .. 0.12500000000000000] -> [0.00000000000000000 .. 0.062500000000000000], [0.062500000000000000 .. 0.12500000000000000]
# I  = [0.00000000000000000 .. 0.062500000000000000]
# C || f(I) = [1.3394130613654851 .. 1.6000000018626453]
# h  = t |--> e^(-t + 1.?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.087133160010285384 .. 10.000000000000000]
# b = -1.?
# t = [0.10598485517647032 .. 10.000000000000000]
# b = -1.?
# t = [0.10926423719098163 .. 10.000000000000000]
# b = -1.?
# t = [0.10980460505248883 .. 10.000000000000000]
# b = -1.?
# t = [0.10989278303548256 .. 10.000000000000000]
# b = -1.?
# t = [0.10990714975330961 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.10990948944939336 .. 0.28951594117290897]
# b = -2.?
# t = [0.10990948944939336 .. 0.28798215879176726]
# b = -2.?
# t = [0.10990948944939336 .. 0.28773098664005121]
# b = -2.?
# t = [0.10990948944939336 .. 0.28769004199193499]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.10990948944939337]
# f(I) = [5.4500997070938694e-7 .. 0.40000000335276132]
# t = [0.28868337294577911 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.28868337294577911 .. 10.000000000000000], fprime(t) = [-1.1987990615889431 .. -0.000060806982219219207]
# returning res = True
# I  = [0.062500000000000000 .. 0.12500000000000000]
# C || f(I) = [1.2824969008564948 .. 1.5394130632281305]
# h  = t |--> e^(-t + 1.?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.053589837676931213 .. 10.000000000000000]
# b = -1.?
# t = [0.064265836369172532 .. 10.000000000000000]
# b = -1.?
# t = [0.066114518379573966 .. 10.000000000000000]
# b = -1.?
# t = [0.066425045959619857 .. 10.000000000000000]
# b = -1.?
# t = [0.066476926110030351 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.066485587043843621 .. 0.25008097201712854]
# b = -1.?
# t = [0.066485587043843621 .. 0.24924719032998139]
# b = -1.?
# t = [0.066485587043843621 .. 0.24910763229708111]
# b = -1.?
# t = [0.066485587043843621 .. 0.24908432984318150]
# b = -1.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.066485587043843622]
# f(I) = [2.0816922188249264e-6 .. 0.33941306471824651]
# t = [0.25008044017391978 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.25008044017391978 .. 10.000000000000000], fprime(t) = [-1.1987996781244875 .. -0.000058223493397235870]
# bisecting [0.062500000000000000 .. 0.12500000000000000] -> [0.062500000000000000 .. 0.093750000000000000], [0.093750000000000000 .. 0.12500000000000000]
# I  = [0.062500000000000000 .. 0.093750000000000000]
# C || f(I) = [1.3105103593319653 .. 1.5394130632281305]
# h  = t |--> e^(-t + 1.?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.071787330405696875 .. 10.000000000000000]
# b = -1.?
# t = [0.085557622570702762 .. 10.000000000000000]
# b = -1.?
# t = [0.087715041894418491 .. 10.000000000000000]
# b = -1.?
# t = [0.088038515949254173 .. 10.000000000000000]
# b = -1.?
# t = [0.088086675067914579 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.088093837786210327 .. 0.25009760712201762]
# b = -2.?
# t = [0.088093837786210327 .. 0.24923146592131074]
# b = -2.?
# t = [0.088093837786210327 .. 0.24910224324536998]
# b = -2.?
# t = [0.088093837786210327 .. 0.24908301901957481]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.088093837786210328]
# f(I) = [1.5024095774140988e-6 .. 0.33941306471824651]
# t = [0.25008016030727076 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.25008016030727076 .. 10.000000000000000], fprime(t) = [-1.1988000171259046 .. -0.000059495680034160614]
# bisecting [0.062500000000000000 .. 0.093750000000000000] -> [0.062500000000000000 .. 0.078125000000000000], [0.078125000000000000 .. 0.093750000000000000]
# I  = [0.062500000000000000 .. 0.078125000000000000]
# C || f(I) = [1.3248488117009400 .. 1.5394130632281305]
# h  = t |--> e^(-t + 1.?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.081101563525275546 .. 10.000000000000000]
# b = -1.?
# t = [0.096348650507982275 .. 10.000000000000000]
# b = -1.?
# t = [0.098607507130609312 .. 10.000000000000000]
# b = -1.?
# t = [0.098925259117626382 .. 10.000000000000000]
# b = -1.?
# t = [0.098969605419951159 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.098975787188134656 .. 0.25158383810842333]
# b = -2.?
# t = [0.098975787188134656 .. 0.24943139174859616]
# b = -2.?
# t = [0.098975787188134656 .. 0.24912873837753358]
# b = -2.?
# t = [0.098975787188134656 .. 0.24908650208885322]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.098975787188134657]
# f(I) = [1.2025237083879147e-6 .. 0.33941306471824651]
# t = [0.25008061443778994 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.25008061443778994 .. 10.000000000000000], fprime(t) = [-1.1987994732335210 .. -0.000060145743191242218]
# bisecting [0.062500000000000000 .. 0.078125000000000000] -> [0.062500000000000000 .. 0.070312500000000000], [0.070312500000000000 .. 0.078125000000000000]
# I  = [0.062500000000000000 .. 0.070312500000000000]
# C || f(I) = [1.3321024911478160 .. 1.5394130632281305]
# h  = t |--> e^(-t + 1.?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.085813540168900970 .. 10.000000000000000]
# b = -1.?
# t = [0.10177983077643901 .. 10.000000000000000]
# b = -1.?
# t = [0.10407607183543465 .. 10.000000000000000]
# b = -1.?
# t = [0.10438829826914894 .. 10.000000000000000]
# b = -1.?
# t = [0.10443040141135906 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.10443607170537996 .. 0.25135870231824876]
# b = -2.?
# t = [0.10443607170537996 .. 0.24938882350613370]
# b = -2.?
# t = [0.10443607170537996 .. 0.24912133604586096]
# b = -2.?
# t = [0.10443607170537996 .. 0.24908527273858630]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.10443607170537997]
# f(I) = [1.0591000318971310e-6 .. 0.33941306471824651]
# t = [0.25008041664194652 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.25008041664194652 .. 10.000000000000000], fprime(t) = [-1.1987997135147453 .. -0.000060475431382656097]
# returning res = True
# I  = [0.070312500000000000 .. 0.078125000000000000]
# C || f(I) = [1.3248488117009400 .. 1.5321024930104615]
# h  = t |--> e^(-t + 1.?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.081488547059572966 .. 10.000000000000000]
# b = -1.?
# t = [0.096479618164086025 .. 10.000000000000000]
# b = -1.?
# t = [0.098636292894597327 .. 10.000000000000000]
# b = -1.?
# t = [0.098930677659537016 .. 10.000000000000000]
# b = -1.?
# t = [0.098970550292408421 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.098975945491786315 .. 0.24642997558878971]
# b = -2.?
# t = [0.098975945491786315 .. 0.24460684521914828]
# b = -2.?
# t = [0.098975945491786315 .. 0.24435833209917072]
# b = -2.?
# t = [0.098975945491786315 .. 0.24432468050842185]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.098975945491786316]
# f(I) = [1.0125339031663571e-6 .. 0.33210249543190007]
# t = [0.24532012712662204 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.24532012712662204 .. 10.000000000000000], fprime(t) = [-1.1987997675314546 .. -0.000060145743191242218]
# returning res = None
# I  = [0.078125000000000000 .. 0.093750000000000000]
# C || f(I) = [1.3105103593319653 .. 1.5248488135635854]
# h  = t |--> e^(-t + 1.?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.072472990896424699 .. 10.000000000000000]
# b = -1.?
# t = [0.085794858899800569 .. 10.000000000000000]
# b = -1.?
# t = [0.087769488047207883 .. 10.000000000000000]
# b = -1.?
# t = [0.088049275260092541 .. 10.000000000000000]
# b = -1.?
# t = [0.088088647875167652 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.088094183491486288 .. 0.23994956896801420]
# b = -2.?
# t = [0.088094183491486288 .. 0.23962660366308234]
# b = -2.?
# t = [0.088094183491486288 .. 0.23958114641720868]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.088094183491486289]
# f(I) = [1.0870397091355954e-6 .. 0.32484881505370145]
# t = [0.24057475593050473 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.24057475593050473 .. 10.000000000000000], fprime(t) = [-1.1987993652001024 .. -0.000059495680034160614]
# bisecting [0.078125000000000000 .. 0.093750000000000000] -> [0.078125000000000000 .. 0.085937500000000000], [0.085937500000000000 .. 0.093750000000000000]
# I  = [0.078125000000000000 .. 0.085937500000000000]
# C || f(I) = [1.3176515806466340 .. 1.5248488135635854]
# h  = t |--> e^(-t + 1.?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.077156223184851380 .. 10.000000000000000]
# b = -1.?
# t = [0.091189480224108582 .. 10.000000000000000]
# b = -1.?
# t = [0.093209161030238546 .. 10.000000000000000]
# b = -1.?
# t = [0.093485916757492876 .. 10.000000000000000]
# b = -1.?
# t = [0.093523565930829458 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.093528682385182040 .. 0.24099377668481018]
# b = -2.?
# t = [0.093528682385182040 .. 0.23976754167166484]
# b = -2.?
# t = [0.093528682385182040 .. 0.23960006512090227]
# b = -2.?
# t = [0.093528682385182040 .. 0.23957729218149488]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.093528682385182041]
# f(I) = [9.6596777443558323e-7 .. 0.32484881505370145]
# t = [0.24057419729149417 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.24057419729149417 .. 10.000000000000000], fprime(t) = [-1.1988000357523561 .. -0.000059819780290126800]
# returning res = None
# I  = [0.085937500000000000 .. 0.093750000000000000]
# C || f(I) = [1.3105103593319653 .. 1.5176515834406020]
# h  = t |--> e^(-t + 1.?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.072816683259724804 .. 10.000000000000000]
# b = -1.?
# t = [0.085909496753994146 .. 10.000000000000000]
# b = -1.?
# t = [0.087794720509425674 .. 10.000000000000000]
# b = -1.?
# t = [0.088054052828289305 .. 10.000000000000000]
# b = -1.?
# t = [0.088089486932254129 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.088094323681372668 .. 0.23502492518364171]
# b = -2.?
# t = [0.088094323681372668 .. 0.23486747688289825]
# b = -2.?
# t = [0.088094323681372668 .. 0.23484597317578943]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.088094323681372669]
# f(I) = [9.1753900055557835e-7 .. 0.31765158586204057]
# t = [0.23584303728189845 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.23584303728189845 .. 10.000000000000000], fprime(t) = [-1.1988000618293882 .. -0.000059495680034160614]
# returning res = None
# I  = [0.093750000000000000 .. 0.12500000000000000]
# C || f(I) = [1.2824969008564948 .. 1.5105103621259333]
# h  = t |--> e^(-t + 1.?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.054615246450115208 .. 10.000000000000000]
# b = -1.?
# t = [0.064635617920294097 .. 10.000000000000000]
# b = -1.?
# t = [0.066206350363530272 .. 10.000000000000000]
# b = -1.?
# t = [0.066444874889659721 .. 10.000000000000000]
# b = -1.?
# t = [0.066480913363226923 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.066486354398139144 .. 0.23018282379441829]
# b = -2.?
# t = [0.066486354398139144 .. 0.23013460146004142]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.066486354398139145]
# f(I) = [1.1615455151048337e-6 .. 0.31051036454737191]
# t = [0.23112732087649956 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.23112732087649956 .. 10.000000000000000], fprime(t) = [-1.1987990709021688 .. -0.000058223493397235870]
# bisecting [0.093750000000000000 .. 0.12500000000000000] -> [0.093750000000000000 .. 0.10937500000000000], [0.10937500000000000 .. 0.12500000000000000]
# I  = [0.093750000000000000 .. 0.10937500000000000]
# C || f(I) = [1.2963942052796482 .. 1.5105103621259333]
# h  = t |--> e^(-t + 1.?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.063815649418084666 .. 10.000000000000000]
# b = -1.?
# t = [0.075281405076748408 .. 10.000000000000000]
# b = -1.?
# t = [0.076982275670165661 .. 10.000000000000000]
# b = -1.?
# t = [0.077225029193403862 .. 10.000000000000000]
# b = -1.?
# t = [0.077259473403671952 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.077264356607389700 .. 0.23077811872243745]
# b = -2.?
# t = [0.077264356607389700 .. 0.23021864385506316]
# b = -2.?
# t = [0.077264356607389700 .. 0.23013915898719673]
# b = -2.?
# t = [0.077264356607389700 .. 0.23012788823771555]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.077264356607389701]
# f(I) = [9.6783041958481419e-7 .. 0.31051036454737191]
# t = [0.23112629042473656 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.23112629042473656 .. 10.000000000000000], fprime(t) = [-1.1988002946600318 .. -0.000058854930102825164]
# bisecting [0.093750000000000000 .. 0.10937500000000000] -> [0.093750000000000000 .. 0.10156250000000000], [0.10156250000000000 .. 0.10937500000000000]
# I  = [0.093750000000000000 .. 0.10156250000000000]
# C || f(I) = [1.3034247118979691 .. 1.5105103621259333]
# h  = t |--> e^(-t + 1.?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.068470040900292364 .. 10.000000000000000]
# b = -1.?
# t = [0.080639739837633256 .. 10.000000000000000]
# b = -1.?
# t = [0.082393010427766436 .. 10.000000000000000]
# b = -1.?
# t = [0.082635127346679729 .. 10.000000000000000]
# b = -1.?
# t = [0.082668354768671389 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.082672910856260370 .. 0.23088218812145245]
# b = -2.?
# t = [0.082672910856260370 .. 0.23022994054044891]
# b = -2.?
# t = [0.082672910856260370 .. 0.23014027778450047]
# b = -2.?
# t = [0.082672910856260370 .. 0.23012798020288608]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.082672910856260371]
# f(I) = [8.6911022667557347e-7 .. 0.31051036454737191]
# t = [0.23112629469994500 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.23112629469994500 .. 10.000000000000000], fprime(t) = [-1.1988003039732576 .. -0.000059173442423343658]
# returning res = None
# I  = [0.10156250000000000 .. 0.10937500000000000]
# C || f(I) = [1.2963942052796482 .. 1.5034247137606145]
# h  = t |--> e^(-t + 1.?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.064116412459258809 .. 10.000000000000000]
# b = -1.?
# t = [0.075380286598249246 .. 10.000000000000000]
# b = -1.?
# t = [0.077004073616634707 .. 10.000000000000000]
# b = -1.?
# t = [0.077229180163362748 .. 10.000000000000000]
# b = -1.?
# t = [0.077260206610666029 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.077264479745776201 .. 0.22603417163364690]
# b = -2.?
# t = [0.077264479745776201 .. 0.22550826511431630]
# b = -2.?
# t = [0.077264479745776201 .. 0.22543568682269974]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.077264479745776202]
# f(I) = [8.1881880764633763e-7 .. 0.30342471525073056]
# t = [0.22642568936224533 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.22642568936224533 .. 10.000000000000000], fprime(t) = [-1.1987987058237196 .. -0.000058854930102825164]
# returning res = None
# I  = [0.10937500000000000 .. 0.12500000000000000]
# C || f(I) = [1.2824969008564948 .. 1.4963942071422936]
# h  = t |--> e^(-t + 1.?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.055130456866413761 .. 10.000000000000000]
# b = -1.?
# t = [0.064808889000860514 .. 10.000000000000000]
# b = -1.?
# t = [0.066246197699288314 .. 10.000000000000000]
# b = -1.?
# t = [0.066452829968070378 .. 10.000000000000000]
# b = -1.?
# t = [0.066482390995532603 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.066486616898948872 .. 0.22081176489099217]
# b = -2.?
# t = [0.066486616898948872 .. 0.22074751481623406]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.066486616898948873]
# f(I) = [8.4675848488480198e-7 .. 0.29639420956373220]
# t = [0.22173832836618326 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.22173832836618326 .. 10.000000000000000], fprime(t) = [-1.1987987859174610 .. -0.000058223493397235870]
# bisecting [0.10937500000000000 .. 0.12500000000000000] -> [0.10937500000000000 .. 0.11718750000000000], [0.11718750000000000 .. 0.12500000000000000]
# I  = [0.10937500000000000 .. 0.11718750000000000]
# C || f(I) = [1.2894184101372956 .. 1.4963942071422936]
# h  = t |--> e^(-t + 1.?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.059755915282451797 .. 10.000000000000000]
# b = -1.?
# t = [0.070131207139481357 .. 10.000000000000000]
# b = -1.?
# t = [0.071627947188280888 .. 10.000000000000000]
# b = -1.?
# t = [0.071836246755307475 .. 10.000000000000000]
# b = -1.?
# t = [0.071865083287352138 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.071869072523292568 .. 0.22273629564079048]
# b = -2.?
# t = [0.071869072523292568 .. 0.22101508257265504]
# b = -2.?
# t = [0.071869072523292568 .. 0.22077532165791420]
# b = -2.?
# t = [0.071869072523292568 .. 0.22074212550726708]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.071869072523292569]
# f(I) = [7.6852738861710179e-7 .. 0.29639420956373220]
# t = [0.22173753330666468 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.22173753330666468 .. 10.000000000000000], fprime(t) = [-1.1987997321411968 .. -0.000058538280427455902]
# returning res = None
# I  = [0.11718750000000000 .. 0.12500000000000000]
# C || f(I) = [1.2824969008564948 .. 1.4894184119999410]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.055388663964793749 .. 10.000000000000000]
# b = -1.?
# t = [0.064892573007544404 .. 10.000000000000000]
# b = -1.?
# t = [0.066264672381059111 .. 10.000000000000000]
# b = -1.?
# t = [0.066456368056275416 .. 10.000000000000000]
# b = -1.?
# t = [0.066483021713750395 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.066486724771103886 .. 0.21626418038831108]
# b = -2.?
# t = [0.066486724771103886 .. 0.21609196686386720]
# b = -2.?
# t = [0.066486724771103886 .. 0.21606802454290112]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.066486724771103887]
# f(I) = [7.1637332443863499e-7 .. 0.28941841349005704]
# t = [0.21706469731223509 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.21706469731223509 .. 10.000000000000000], fprime(t) = [-1.1987999724224210 .. -0.000058223493397235870]
# returning res = None
# I  = [0.12500000000000000 .. 0.25000000000000000]
# C || f(I) = [1.1788007808849214 .. 1.4824969036504628]
# h  = t |--> e^(-t + 1.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.21298139091857685]
# b = -1.?
# t = [0.00000000000000000 .. 0.21170737051304875]
# b = -1.?
# t = [0.00000000000000000 .. 0.21146363248940312]
# b = -1.?
# t = [0.00000000000000000 .. 0.21141715182598559]
# b = -1.?
# found upper bound!
# t = [0.21240829353205051 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.21240829353205051 .. 10.000000000000000], fprime(t) = [-1.1987981246784330 .. -0.000053514726459980010]
# bisecting [0.12500000000000000 .. 0.25000000000000000] -> [0.12500000000000000 .. 0.18750000000000000], [0.18750000000000000 .. 0.25000000000000000]
# I  = [0.12500000000000000 .. 0.18750000000000000]
# C || f(I) = [1.2290291167795657 .. 1.4824969036504628]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.019581230053161154 .. 10.000000000000000]
# b = -1.?
# t = [0.023156329000590506 .. 10.000000000000000]
# b = -1.?
# t = [0.023775075609449639 .. 10.000000000000000]
# b = -1.?
# t = [0.023881090221584487 .. 10.000000000000000]
# b = -1.?
# t = [0.023899221867780776 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.023902322573712112 .. 0.21231516911734491]
# b = -1.?
# t = [0.023902322573712112 .. 0.21156195890002386]
# b = -1.?
# t = [0.023902322573712112 .. 0.21143284683270442]
# b = -1.?
# t = [0.023902322573712112 .. 0.21141076195509354]
# b = -1.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.023902322573712113]
# f(I) = [7.6666474346787083e-7 .. 0.28249690607190137]
# t = [0.21240698656106810 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.21240698656106810 .. 10.000000000000000], fprime(t) = [-1.1987996781244875 .. -0.000055796466767787933]
# bisecting [0.12500000000000000 .. 0.18750000000000000] -> [0.12500000000000000 .. 0.15625000000000000], [0.15625000000000000 .. 0.18750000000000000]
# I  = [0.12500000000000000 .. 0.15625000000000000]
# C || f(I) = [1.2553453255444764 .. 1.4824969036504628]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.037332503761607134 .. 10.000000000000000]
# b = -1.?
# t = [0.043875238643781476 .. 10.000000000000000]
# b = -1.?
# t = [0.044902515328821557 .. 10.000000000000000]
# b = -1.?
# t = [0.045060525397538145 .. 10.000000000000000]
# b = -1.?
# t = [0.045084750682780845 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.045088463241547346 .. 0.21184670717108764]
# b = -2.?
# t = [0.045088463241547346 .. 0.21147378407638784]
# b = -2.?
# t = [0.045088463241547346 .. 0.21141656371919327]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.045088463241547347]
# f(I) = [8.0578029160172093e-7 .. 0.28249690607190137]
# t = [0.21240779502384002 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.21240779502384002 .. 10.000000000000000], fprime(t) = [-1.1987987132743001 .. -0.000056990422308444976]
# bisecting [0.12500000000000000 .. 0.15625000000000000] -> [0.12500000000000000 .. 0.14062500000000000], [0.14062500000000000 .. 0.15625000000000000]
# I  = [0.12500000000000000 .. 0.14062500000000000]
# C || f(I) = [1.2688150541856884 .. 1.4824969036504628]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.046418342633810054 .. 10.000000000000000]
# b = -1.?
# t = [0.054377889621051993 .. 10.000000000000000]
# b = -1.?
# t = [0.055561574962304134 .. 10.000000000000000]
# b = -1.?
# t = [0.055732989096670411 .. 10.000000000000000]
# b = -1.?
# t = [0.055757713428411882 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.055761277180695137 .. 0.21361411543378648]
# b = -2.?
# t = [0.055761277180695137 .. 0.21172653364666705]
# b = -2.?
# t = [0.055761277180695137 .. 0.21145242237814774]
# b = -2.?
# t = [0.055761277180695137 .. 0.21141286918251518]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.055761277180695138]
# f(I) = [7.2009861473709690e-7 .. 0.28249690607190137]
# t = [0.21240716816806146 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.21240716816806146 .. 10.000000000000000], fprime(t) = [-1.1987994732335210 .. -0.000057601369917392730]
# bisecting [0.12500000000000000 .. 0.14062500000000000] -> [0.12500000000000000 .. 0.13281250000000000], [0.13281250000000000 .. 0.14062500000000000]
# I  = [0.12500000000000000 .. 0.13281250000000000]
# C || f(I) = [1.2756292555481194 .. 1.4824969036504628]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.051014778309365266 .. 10.000000000000000]
# b = -1.?
# t = [0.059664453865842369 .. 10.000000000000000]
# b = -1.?
# t = [0.060914289840312975 .. 10.000000000000000]
# b = -1.?
# t = [0.061089583073480377 .. 10.000000000000000]
# b = -1.?
# t = [0.061114060896435042 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.061117476838092127 .. 0.21332344824794864]
# b = -2.?
# t = [0.061117476838092127 .. 0.21167532099070283]
# b = -2.?
# t = [0.061117476838092127 .. 0.21144379131321673]
# b = -2.?
# t = [0.061117476838092127 .. 0.21141145301565656]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.061117476838092128]
# f(I) = [6.6421926026016819e-7 .. 0.28249690607190137]
# t = [0.21240693945885202 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.21240693945885202 .. 10.000000000000000], fprime(t) = [-1.1987997414544225 .. -0.000057912431657314300]
# returning res = None
# I  = [0.13281250000000000 .. 0.14062500000000000]
# C || f(I) = [1.2688150541856884 .. 1.4756292574107648]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.046634375579988257 .. 10.000000000000000]
# b = -1.?
# t = [0.054446919753562396 .. 10.000000000000000]
# b = -1.?
# t = [0.055576837906361198 .. 10.000000000000000]
# b = -1.?
# t = [0.055735928506308561 .. 10.000000000000000]
# b = -1.?
# t = [0.055758240203108530 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.055761366761159496 .. 0.20703795302777884]
# b = -2.?
# t = [0.055761366761159496 .. 0.20680153265858506]
# b = -2.?
# t = [0.055761366761159496 .. 0.20676836589420287]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.055761366761159497]
# f(I) = [6.1206519608170140e-7 .. 0.27562925890088086]
# t = [0.20776371674943866 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.20776371674943866 .. 10.000000000000000], fprime(t) = [-1.1987997060641647 .. -0.000057601369917392730]
# returning res = None
# I  = [0.14062500000000000 .. 0.15625000000000000]
# C || f(I) = [1.2553453255444764 .. 1.4688150569796564]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.037680251795537814 .. 10.000000000000000]
# b = -1.?
# t = [0.043988967445609282 .. 10.000000000000000]
# b = -1.?
# t = [0.044928725497992830 .. 10.000000000000000]
# b = -1.?
# t = [0.045065811308887544 .. 10.000000000000000]
# b = -1.?
# t = [0.045085745359728361 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.045088642146824092 .. 0.20319101743648633]
# b = -2.?
# t = [0.045088642146824092 .. 0.20228847193988867]
# b = -2.?
# t = [0.045088642146824092 .. 0.20215683277364547]
# b = -2.?
# t = [0.045088642146824092 .. 0.20213769184821188]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.045088642146824093]
# f(I) = [5.9157609944016087e-7 .. 0.26881505846977239]
# t = [0.20313490940684597 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.20313490940684597 .. 10.000000000000000], fprime(t) = [-1.1988000543788076 .. -0.000056990422308444976]
# bisecting [0.14062500000000000 .. 0.15625000000000000] -> [0.14062500000000000 .. 0.14843750000000000], [0.14843750000000000 .. 0.15625000000000000]
# I  = [0.14062500000000000 .. 0.14843750000000000]
# C || f(I) = [1.2620538823306559 .. 1.4688150569796564]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.042247577431700572 .. 10.000000000000000]
# b = -1.?
# t = [0.049240035712636444 .. 10.000000000000000]
# b = -1.?
# t = [0.050252356563398062 .. 10.000000000000000]
# b = -1.?
# t = [0.050395444036878851 .. 10.000000000000000]
# b = -1.?
# t = [0.050415597974695372 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.050418434221551178 .. 0.20378830128690473]
# b = -2.?
# t = [0.050418434221551178 .. 0.20236842212560955]
# b = -2.?
# t = [0.050418434221551178 .. 0.20216739772142959]
# b = -2.?
# t = [0.050418434221551178 .. 0.20213907598328341]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.050418434221551179]
# f(I) = [5.5804848675400364e-7 .. 0.26881505846977239]
# t = [0.20313508900851423 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.20313508900851423 .. 10.000000000000000], fprime(t) = [-1.1987998308613897 .. -0.000057295896112918853]
# returning res = None
# I  = [0.14843750000000000 .. 0.15625000000000000]
# C || f(I) = [1.2553453255444764 .. 1.4620538841933013]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.037854501561649045 .. 10.000000000000000]
# b = -1.?
# t = [0.044043869643598639 .. 10.000000000000000]
# b = -1.?
# t = [0.044940884658676495 .. 10.000000000000000]
# b = -1.?
# t = [0.045068165539680314 .. 10.000000000000000]
# b = -1.?
# t = [0.045086170082065023 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.045088716426729076 .. 0.19899059395842040]
# b = -2.?
# t = [0.045088716426729076 .. 0.19772941124389141]
# b = -2.?
# t = [0.045088716426729076 .. 0.19755019322047815]
# b = -2.?
# t = [0.045088716426729076 .. 0.19752483712820463]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.045088716426729077]
# f(I) = [5.0216913227707493e-7 .. 0.26205388568341737]
# t = [0.19852125149895888 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.19852125149895888 .. 10.000000000000000], fprime(t) = [-1.1987999109551311 .. -0.000056990422308444976]
# returning res = None
# I  = [0.15625000000000000 .. 0.18750000000000000]
# C || f(I) = [1.2290291167795657 .. 1.4553453283384444]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.019946546182115287 .. 10.000000000000000]
# b = -1.?
# t = [0.023281111511455739 .. 10.000000000000000]
# b = -1.?
# t = [0.023806096557009638 .. 10.000000000000000]
# b = -1.?
# t = [0.023887895437339538 .. 10.000000000000000]
# b = -1.?
# t = [0.023900618907548319 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.023902597725574192 .. 0.19327326241269788]
# b = -2.?
# t = [0.023902597725574192 .. 0.19297638484982952]
# b = -2.?
# t = [0.023902597725574192 .. 0.19293016724492851]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.023902597725574193]
# f(I) = [4.3697655205399144e-7 .. 0.25534533075988298]
# t = [0.19392297946514516 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.19392297946514516 .. 10.000000000000000], fprime(t) = [-1.1987990355119110 .. -0.000055796466767787933]
# bisecting [0.15625000000000000 .. 0.18750000000000000] -> [0.15625000000000000 .. 0.17187500000000000], [0.17187500000000000 .. 0.18750000000000000]
# I  = [0.15625000000000000 .. 0.17187500000000000]
# C || f(I) = [1.2420844255015253 .. 1.4553453283384444]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.028917137270626683 .. 10.000000000000000]
# b = -1.?
# t = [0.033642658357362423 .. 10.000000000000000]
# b = -1.?
# t = [0.034347958257927288 .. 10.000000000000000]
# b = -1.?
# t = [0.034451594906739289 .. 10.000000000000000]
# b = -1.?
# t = [0.034466787664166949 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.034469014033230098 .. 0.19381103250601373]
# b = -2.?
# t = [0.034469014033230098 .. 0.19305231877956503]
# b = -2.?
# t = [0.034469014033230098 .. 0.19294081010803091]
# b = -2.?
# t = [0.034469014033230098 .. 0.19292446216901222]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.034469014033230099]
# f(I) = [4.5932829384476292e-7 .. 0.25534533075988298]
# t = [0.19392206649197410 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.19392206649197410 .. 10.000000000000000], fprime(t) = [-1.1988001251593233 .. -0.000056388787925243377]
# bisecting [0.15625000000000000 .. 0.17187500000000000] -> [0.15625000000000000 .. 0.16406250000000000], [0.16406250000000000 .. 0.17187500000000000]
# I  = [0.15625000000000000 .. 0.16406250000000000]
# C || f(I) = [1.2486889749765395 .. 1.4553453283384444]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.033455270032962537 .. 10.000000000000000]
# b = -1.?
# t = [0.038858484466169879 .. 10.000000000000000]
# b = -1.?
# t = [0.039642457376564882 .. 10.000000000000000]
# b = -1.?
# t = [0.039754130556888991 .. 10.000000000000000]
# b = -1.?
# t = [0.039769995394164751 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.039772248251177456 .. 0.19446658136452444]
# b = -2.?
# t = [0.039772248251177456 .. 0.19314205612012431]
# b = -2.?
# t = [0.039772248251177456 .. 0.19295297285337871]
# b = -2.?
# t = [0.039772248251177456 .. 0.19292610338394651]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.039772248251177457]
# f(I) = [4.4628977780014622e-7 .. 0.25534533075988298]
# t = [0.19392228726244653 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.19392228726244653 .. 10.000000000000000], fprime(t) = [-1.1987998662516475 .. -0.000056688673794269561]
# returning res = None
# I  = [0.16406250000000000 .. 0.17187500000000000]
# C || f(I) = [1.2420844255015253 .. 1.4486889777705075]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.029050003948813296 .. 10.000000000000000]
# b = -1.?
# t = [0.033683943639897975 .. 10.000000000000000]
# b = -1.?
# t = [0.034357115728323978 .. 10.000000000000000]
# b = -1.?
# t = [0.034453378458556137 .. 10.000000000000000]
# b = -1.?
# t = [0.034467111942944432 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.034469071728867942 .. 0.18979540921233310]
# b = -2.?
# t = [0.034469071728867942 .. 0.18854627757481863]
# b = -2.?
# t = [0.034469071728867942 .. 0.18836724094166141]
# b = -2.?
# t = [0.034469071728867942 .. 0.18834168967974666]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.034469071728867943]
# f(I) = [3.9041042332321751e-7 .. 0.24868898019194608]
# t = [0.18933804531712977 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.18933804531712977 .. 10.000000000000000], fprime(t) = [-1.1987998923286796 .. -0.000056388787925243377]
# returning res = None
# I  = [0.17187500000000000 .. 0.18750000000000000]
# C || f(I) = [1.2290291167795657 .. 1.4420844273641707]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.020129967780328144 .. 10.000000000000000]
# b = -1.?
# t = [0.023339476951363839 .. 10.000000000000000]
# b = -1.?
# t = [0.023819576511793481 .. 10.000000000000000]
# b = -1.?
# t = [0.023890639123523172 .. 10.000000000000000]
# b = -1.?
# t = [0.023901140807004141 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.023902692012925788 .. 0.18534215300687438]
# b = -2.?
# t = [0.023902692012925788 .. 0.18400164837972017]
# b = -2.?
# t = [0.023902692012925788 .. 0.18380256905640566]
# b = -2.?
# t = [0.023902692012925788 .. 0.18377313313829586]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.023902692012925789]
# f(I) = [3.2335519795090306e-7 .. 0.24208442978560929]
# t = [0.18476878430464074 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.18476878430464074 .. 10.000000000000000], fprime(t) = [-1.1987997135147453 .. -0.000055796466767787933]
# bisecting [0.17187500000000000 .. 0.18750000000000000] -> [0.17187500000000000 .. 0.17968750000000000], [0.17968750000000000 .. 0.18750000000000000]
# I  = [0.17187500000000000 .. 0.17968750000000000]
# C || f(I) = [1.2355312719941138 .. 1.4420844273641707]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.024638826629964524 .. 10.000000000000000]
# b = -1.?
# t = [0.028520307729097523 .. 10.000000000000000]
# b = -1.?
# t = [0.029084893837535243 .. 10.000000000000000]
# b = -1.?
# t = [0.029165943054923388 .. 10.000000000000000]
# b = -1.?
# t = [0.029177556193453000 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.029179219336129467 .. 0.18444507931360780]
# b = -2.?
# t = [0.029179219336129467 .. 0.18386520275429641]
# b = -2.?
# t = [0.029179219336129467 .. 0.18378195185755339]
# b = -2.?
# t = [0.029179219336129467 .. 0.18377002364953485]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.029179219336129468]
# f(I) = [3.3453106884628880e-7 .. 0.24208442978560929]
# t = [0.18476831555419082 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.18476831555419082 .. 10.000000000000000], fprime(t) = [-1.1988002760335804 .. -0.000056090764701366424]
# returning res = None
# I  = [0.17968750000000000 .. 0.18750000000000000]
# C || f(I) = [1.2290291167795657 .. 1.4355312747880818]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.020221860229620320 .. 10.000000000000000]
# b = -1.?
# t = [0.023367638820793287 .. 10.000000000000000]
# b = -1.?
# t = [0.023825832653084404 .. 10.000000000000000]
# b = -1.?
# t = [0.023891863652167968 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.023901364783207042 .. 0.17958974679358362]
# b = -2.?
# t = [0.023901364783207042 .. 0.17926764347808580]
# b = -2.?
# t = [0.023901364783207042 .. 0.17922124781328791]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.023901364783207043]
# f(I) = [1.9159168005433713e-6 .. 0.23553127720952039]
# t = [0.18021457346300320 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.18021457346300320 .. 10.000000000000000], fprime(t) = [-1.1987992683425546 .. -0.000055796466767787933]
# returning res = None
# I  = [0.18750000000000000 .. 0.25000000000000000]
# C || f(I) = [1.1788007808849214 .. 1.4290291186422111]
# h  = t |--> e^(-t + 1.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.17641630355033922]
# b = -1.?
# t = [0.00000000000000000 .. 0.17495427629929464]
# b = -1.?
# t = [0.00000000000000000 .. 0.17471871788111421]
# b = -1.?
# t = [0.00000000000000000 .. 0.17468093211137143]
# b = -1.?
# found upper bound!
# t = [0.17567487583561092 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.17567487583561092 .. 10.000000000000000], fprime(t) = [-1.1987992310896516 .. -0.000053514726459980010]
# bisecting [0.18750000000000000 .. 0.25000000000000000] -> [0.18750000000000000 .. 0.21875000000000000], [0.21875000000000000 .. 0.25000000000000000]
# I  = [0.18750000000000000 .. 0.21875000000000000]
# C || f(I) = [1.2035225719213484 .. 1.4290291186422111]
# h  = t |--> e^(-t + 1.?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.0024650082244827824 .. 10.000000000000000]
# b = -1.?
# t = [0.0028575191058486720 .. 10.000000000000000]
# b = -1.?
# t = [0.0029195474310771572 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.0029293381730852241 .. 0.17608204428167515]
# b = -2.?
# t = [0.0029293381730852241 .. 0.17489679624934493]
# b = -2.?
# t = [0.0029293381730852241 .. 0.17470894408757426]
# b = -2.?
# t = [0.0029293381730852241 .. 0.17467927927063168]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.0029293381730852242]
# f(I) = [2.2027641535249387e-6 .. 0.22902912013232713]
# t = [0.17567459745754018 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.17567459745754018 .. 10.000000000000000], fprime(t) = [-1.1987995719537139 .. -0.000054637901484966278]
# bisecting [0.18750000000000000 .. 0.21875000000000000] -> [0.18750000000000000 .. 0.20312500000000000], [0.20312500000000000 .. 0.21875000000000000]
# I  = [0.18750000000000000 .. 0.20312500000000000]
# C || f(I) = [1.2161762114614247 .. 1.4290291186422111]
# h  = t |--> e^(-t + 1.?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.011319718818972236 .. 10.000000000000000]
# b = -1.?
# t = [0.013079915033260001 .. 10.000000000000000]
# b = -1.?
# t = [0.013343877630862279 .. 10.000000000000000]
# b = -1.?
# t = [0.013383234611330454 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.013389097981532730 .. 0.17529308839107361]
# b = -2.?
# t = [0.013389097981532730 .. 0.17476613837894176]
# b = -2.?
# t = [0.013389097981532730 .. 0.17468748928507475]
# b = -2.?
# t = [0.013389097981532730 .. 0.17467577145859534]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.013389097981532731]
# f(I) = [1.2304633856263791e-6 .. 0.22902912013232713]
# t = [0.17567402588501246 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.17567402588501246 .. 10.000000000000000], fprime(t) = [-1.1988002499565483 .. -0.000055211596190929412]
# bisecting [0.18750000000000000 .. 0.20312500000000000] -> [0.18750000000000000 .. 0.19531250000000000], [0.19531250000000000 .. 0.20312500000000000]
# I  = [0.18750000000000000 .. 0.19531250000000000]
# C || f(I) = [1.2225775603204964 .. 1.4290291186422111]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.015799227778060864 .. 10.000000000000000]
# b = -1.?
# t = [0.018225996206158032 .. 10.000000000000000]
# b = -1.?
# t = [0.018579966322845559 .. 10.000000000000000]
# b = -1.?
# t = [0.018631175411616837 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.018638575524198147 .. 0.17593865434589249]
# b = -2.?
# t = [0.018638575524198147 .. 0.17485715053263773]
# b = -2.?
# t = [0.018638575524198147 .. 0.17470023473950011]
# b = -2.?
# t = [0.018638575524198147 .. 0.17467755139229705]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.018638575524198148]
# f(I) = [1.4986842871156369e-6 .. 0.22902912013232713]
# t = [0.17567427346576669 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.17567427346576669 .. 10.000000000000000], fprime(t) = [-1.1987999556586147 .. -0.000055502168834209442]
# returning res = None
# I  = [0.19531250000000000 .. 0.20312500000000000]
# C || f(I) = [1.2161762114614247 .. 1.4225775631144644]
# h  = t |--> e^(-t + 1.?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.011371055073413035 .. 10.000000000000000]
# b = -1.?
# t = [0.013095436828666083 .. 10.000000000000000]
# b = -1.?
# t = [0.013347330618660025 .. 10.000000000000000]
# b = -1.?
# t = [0.013383913785897771 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.013389222530778099 .. 0.17164304979411760]
# b = -2.?
# t = [0.013389222530778099 .. 0.17036660289358028]
# b = -2.?
# t = [0.013389222530778099 .. 0.17018046886254740]
# b = -2.?
# t = [0.013389222530778099 .. 0.17015344276717795]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.013389222530778100]
# f(I) = [1.0814517736879025e-6 .. 0.22257756553590303]
# t = [0.17114952096841851 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.17114952096841851 .. 10.000000000000000], fprime(t) = [-1.1987998215481639 .. -0.000055211596190929412]
# returning res = None
# I  = [0.20312500000000000 .. 0.21875000000000000]
# C || f(I) = [1.2035225719213484 .. 1.4161762133240701]
# h  = t |--> e^(-t + 1.?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.0024873800960342582 .. 10.000000000000000]
# b = -1.?
# t = [0.0028644501635917930 .. 10.000000000000000]
# b = -1.?
# t = [0.0029211523804729272 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.0029296680358341102 .. 0.16705519726041368]
# b = -2.?
# t = [0.0029296680358341102 .. 0.16585240489626899]
# b = -2.?
# t = [0.0029296680358341102 .. 0.16567095905192095]
# b = -2.?
# t = [0.0029296680358341102 .. 0.16564369489791401]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.0029296680358341103]
# f(I) = [1.8060207367387448e-6 .. 0.21617621481418615]
# t = [0.16663959981364534 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.16663959981364534 .. 10.000000000000000], fprime(t) = [-1.1987997507676483 .. -0.000054637901484966278]
# bisecting [0.20312500000000000 .. 0.21875000000000000] -> [0.20312500000000000 .. 0.21093750000000000], [0.21093750000000000 .. 0.21875000000000000]
# I  = [0.20312500000000000 .. 0.21093750000000000]
# C || f(I) = [1.2098246771842240 .. 1.4161762133240701]
# h  = t |--> e^(-t + 1.?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.0069374655631500425 .. 10.000000000000000]
# b = -1.?
# t = [0.0079760169105052708 .. 10.000000000000000]
# b = -1.?
# t = [0.0081279619025166408 .. 10.000000000000000]
# b = -1.?
# t = [0.0081501161407366053 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.0081533444861300544 .. 0.16723571651328229]
# b = -2.?
# t = [0.0081533444861300544 .. 0.16587264197706178]
# b = -2.?
# t = [0.0081533444861300544 .. 0.16567296234622895]
# b = -2.?
# t = [0.0081533444861300544 .. 0.16564384349404171]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.0081533444861300545]
# f(I) = [6.6049396996170628e-7 .. 0.21617621481418615]
# t = [0.16663959966340247 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.16663959966340247 .. 10.000000000000000], fprime(t) = [-1.1987997507676483 .. -0.000054924748837947845]
# returning res = None
# I  = [0.21093750000000000 .. 0.21875000000000000]
# C || f(I) = [1.2035225719213484 .. 1.4098246799781920]
# h  = t |--> e^(-t + 1.?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.0024985862103200804 .. 10.000000000000000]
# b = -1.?
# t = [0.0028677924705357840 .. 10.000000000000000]
# b = -1.?
# t = [0.0029218976422030408 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.0029298156420682333 .. 0.16184999193265740]
# b = -2.?
# t = [0.0029298156420682333 .. 0.16124735283742123]
# b = -2.?
# t = [0.0029298156420682333 .. 0.16115895849815929]
# b = -2.?
# t = [0.0029298156420682333 .. 0.16114601870135964]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.0029298156420682334]
# f(I) = [1.6290694475618039e-6 .. 0.20982468239963060]
# t = [0.16214412465241695 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.16214412465241695 .. 10.000000000000000], fprime(t) = [-1.1988002313300968 .. -0.000054637901484966278]
# returning res = None
# I  = [0.21875000000000000 .. 0.25000000000000000]
# C || f(I) = [1.1788007808849214 .. 1.4035225747153164]
# h  = t |--> e^(-t + 1.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.15708935420416790]
# b = -2.?
# t = [0.00000000000000000 .. 0.15672545427224849]
# b = -2.?
# t = [0.00000000000000000 .. 0.15667261041293460]
# b = -2.?
# found upper bound!
# t = [0.15766494575475947 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.15766494575475947 .. 10.000000000000000], fprime(t) = [-1.1987990541383625 .. -0.000053514726459980010]
# bisecting [0.21875000000000000 .. 0.25000000000000000] -> [0.21875000000000000 .. 0.23437500000000000], [0.23437500000000000 .. 0.25000000000000000]
# I  = [0.21875000000000000 .. 0.23437500000000000]
# ...
# t = [0.00000000000000000 .. 0.13976615111792926]
# b = -1.?
# t = [0.00000000000000000 .. 0.13900618557522385]
# b = -1.?
# t = [0.00000000000000000 .. 0.13890730805679083]
# b = -1.?
# t = [0.00000000000000000 .. 0.13889448123684290]
# b = -1.?
# found upper bound!
# t = [0.13989281636697442 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.13989281636697442 .. 10.000000000000000], fprime(t) = [-1.1988003207370639 .. -0.000049361027777194976]
# bisecting [0.25000000000000000 .. 0.37500000000000000] -> [0.25000000000000000 .. 0.31250000000000000], [0.31250000000000000 .. 0.37500000000000000]
# I  = [0.25000000000000000 .. 0.31250000000000000]
# C || f(I) = [1.1316156271845101 .. 1.3788007836788894]
# h  = t |--> e^(-t + 1.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.13976615111792926]
# b = -1.?
# t = [0.00000000000000000 .. 0.13900618625119557]
# b = -1.?
# t = [0.00000000000000000 .. 0.13890730805723737]
# b = -1.?
# t = [0.00000000000000000 .. 0.13889448123728077]
# b = -1.?
# found upper bound!
# t = [0.13989281704287070 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.13989281704287070 .. 10.000000000000000], fprime(t) = [-1.1988003207370639 .. -0.000051372684538364410]
# bisecting [0.25000000000000000 .. 0.31250000000000000] -> [0.25000000000000000 .. 0.28125000000000000], [0.28125000000000000 .. 0.31250000000000000]
# I  = [0.25000000000000000 .. 0.28125000000000000]
# C || f(I) = [1.1548396000638603 .. 1.3788007836788894]
# h  = t |--> e^(-t + 1.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.13976615111792926]
# b = -2.?
# t = [0.00000000000000000 .. 0.13900618557522385]
# b = -2.?
# t = [0.00000000000000000 .. 0.13890730738126564]
# b = -2.?
# t = [0.00000000000000000 .. 0.13889447988585066]
# b = -2.?
# found upper bound!
# t = [0.13989281636689898 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.13989281636689898 .. 10.000000000000000], fprime(t) = [-1.1988003207370639 .. -0.000052426941692829132]
# bisecting [0.25000000000000000 .. 0.28125000000000000] -> [0.25000000000000000 .. 0.26562500000000000], [0.26562500000000000 .. 0.28125000000000000]
# I  = [0.25000000000000000 .. 0.26562500000000000]
# C || f(I) = [1.1667265944182871 .. 1.3788007836788894]
# h  = t |--> e^(-t + 1.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.13976615111792926]
# b = -2.?
# t = [0.00000000000000000 .. 0.13900618557522385]
# b = -2.?
# t = [0.00000000000000000 .. 0.13890730738126564]
# b = -2.?
# t = [0.00000000000000000 .. 0.13889447988585066]
# b = -2.?
# found upper bound!
# t = [0.13989281636689898 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.13989281636689898 .. 10.000000000000000], fprime(t) = [-1.1988003207370639 .. -0.000052967108786106109]
# bisecting [0.25000000000000000 .. 0.26562500000000000] -> [0.25000000000000000 .. 0.25781250000000000], [0.25781250000000000 .. 0.26562500000000000]
# I  = [0.25000000000000000 .. 0.25781250000000000]
# C || f(I) = [1.1727401051670311 .. 1.3788007836788894]
# h  = t |--> e^(-t + 1.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.13976615111792926]
# b = -2.?
# t = [0.00000000000000000 .. 0.13900618557522385]
# b = -2.?
# t = [0.00000000000000000 .. 0.13890730738126564]
# b = -2.?
# t = [0.00000000000000000 .. 0.13889447988585066]
# b = -2.?
# found upper bound!
# t = [0.13989281636689898 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.13989281636689898 .. 10.000000000000000], fprime(t) = [-1.1988003207370639 .. -0.000053240917623043060]
# returning res = None
# I  = [0.25781250000000000 .. 0.26562500000000000]
# C || f(I) = [1.1667265944182871 .. 1.3727401079609992]
# h  = t |--> e^(-t + 1.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.13536155076810497]
# b = -2.?
# t = [0.00000000000000000 .. 0.13459761665220088]
# b = -2.?
# t = [0.00000000000000000 .. 0.13450115678695022]
# b = -2.?
# t = [0.00000000000000000 .. 0.13448901351498461]
# b = -2.?
# found upper bound!
# t = [0.13548748512408223 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.13548748512408223 .. 10.000000000000000], fprime(t) = [-1.1988003486767412 .. -0.000052967108786106109]
# returning res = None
# I  = [0.26562500000000000 .. 0.28125000000000000]
# C || f(I) = [1.1548396000638603 .. 1.3667265972122551]
# h  = t |--> e^(-t + 1.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.13108648906300686]
# b = -2.?
# t = [0.00000000000000000 .. 0.13021811917999096]
# b = -2.?
# t = [0.00000000000000000 .. 0.13011176444360651]
# b = -2.?
# t = [0.00000000000000000 .. 0.13009878410250242]
# b = -2.?
# found upper bound!
# t = [0.13109719992412907 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.13109719992412907 .. 10.000000000000000], fprime(t) = [-1.1988003486767412 .. -0.000052426941692829132]
# bisecting [0.26562500000000000 .. 0.28125000000000000] -> [0.26562500000000000 .. 0.27343750000000000], [0.27343750000000000 .. 0.28125000000000000]
# I  = [0.26562500000000000 .. 0.27343750000000000]
# C || f(I) = [1.1607598798349498 .. 1.3667265972122551]
# h  = t |--> e^(-t + 1.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.13108648906300686]
# b = -2.?
# t = [0.00000000000000000 .. 0.13021811917999096]
# b = -2.?
# t = [0.00000000000000000 .. 0.13011176444360651]
# b = -2.?
# t = [0.00000000000000000 .. 0.13009878410250242]
# b = -2.?
# found upper bound!
# t = [0.13109719992412907 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.13109719992412907 .. 10.000000000000000], fprime(t) = [-1.1988003579899669 .. -0.000052697025239467620]
# returning res = None
# I  = [0.27343750000000000 .. 0.28125000000000000]
# C || f(I) = [1.1548396000638603 .. 1.3607598835602404]
# h  = t |--> e^(-t + 1.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.12693715629025590]
# b = -2.?
# t = [0.00000000000000000 .. 0.12586596769379114]
# b = -2.?
# t = [0.00000000000000000 .. 0.12573877572234602]
# b = -2.?
# t = [0.00000000000000000 .. 0.12572373997679243]
# b = -2.?
# found upper bound!
# t = [0.12672196406037633 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.12672196406037633 .. 10.000000000000000], fprime(t) = [-1.1988003300502897 .. -0.000052426941692829132]
# returning res = None
# I  = [0.28125000000000000 .. 0.31250000000000000]
# C || f(I) = [1.1316156271845101 .. 1.3548396028578283]
# h  = t |--> e^(-t + 1.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.12159391562430745]
# b = -2.?
# t = [0.00000000000000000 .. 0.12138810072667411]
# b = -2.?
# t = [0.00000000000000000 .. 0.12136455520454636]
# b = -2.?
# found upper bound!
# t = [0.12236186415417894 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.12236186415417894 .. 10.000000000000000], fprime(t) = [-1.1988001959398389 .. -0.000051372684538364410]
# bisecting [0.28125000000000000 .. 0.31250000000000000] -> [0.28125000000000000 .. 0.29687500000000000], [0.29687500000000000 .. 0.31250000000000000]
# I  = [0.28125000000000000 .. 0.29687500000000000]
# C || f(I) = [1.1431368967518209 .. 1.3548396028578283]
# h  = t |--> e^(-t + 1.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.12159391562430745]
# b = -2.?
# t = [0.00000000000000000 .. 0.12138810072667411]
# b = -2.?
# t = [0.00000000000000000 .. 0.12136455520454636]
# b = -2.?
# found upper bound!
# t = [0.12236186415417894 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.12236186415417894 .. 10.000000000000000], fprime(t) = [-1.1988002052530647 .. -0.000051896087825298309]
# bisecting [0.28125000000000000 .. 0.29687500000000000] -> [0.28125000000000000 .. 0.28906250000000000], [0.28906250000000000 .. 0.29687500000000000]
# I  = [0.28125000000000000 .. 0.28906250000000000]
# C || f(I) = [1.1489653918892144 .. 1.3548396028578283]
# h  = t |--> e^(-t + 1.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.12159391562430745]
# b = -2.?
# t = [0.00000000000000000 .. 0.12138810072667411]
# b = -2.?
# t = [0.00000000000000000 .. 0.12136455520454636]
# b = -2.?
# found upper bound!
# t = [0.12236186415417894 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.12236186415417894 .. 10.000000000000000], fprime(t) = [-1.1988002052530647 .. -0.000052160583436489105]
# returning res = None
# I  = [0.28906250000000000 .. 0.29687500000000000]
# C || f(I) = [1.1431368967518209 .. 1.3489653946831824]
# h  = t |--> e^(-t + 0.2?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.11772375803217457]
# b = -2.?
# t = [0.00000000000000000 .. 0.11709470716092195]
# b = -2.?
# t = [0.00000000000000000 .. 0.11702502200961563]
# b = -2.?
# found upper bound!
# t = [0.11801732352321465 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.11801732352321465 .. 10.000000000000000], fprime(t) = [-1.1987994732335210 .. -0.000051896087825298309]
# returning res = None
# I  = [0.29687500000000000 .. 0.31250000000000000]
# C || f(I) = [1.1316156271845101 .. 1.3431368995457889]
# h  = t |--> e^(-t + 0.2?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.11274002099239907]
# b = -2.?
# t = [0.00000000000000000 .. 0.11269201957008790]
# b = -2.?
# found upper bound!
# t = [0.11368690315715321 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.11368690315715321 .. 10.000000000000000], fprime(t) = [-1.1987998923286796 .. -0.000051372684538364410]
# bisecting [0.29687500000000000 .. 0.31250000000000000] -> [0.29687500000000000 .. 0.30468750000000000], [0.30468750000000000 .. 0.31250000000000000]
# I  = [0.29687500000000000 .. 0.30468750000000000]
# C || f(I) = [1.1373537598177789 .. 1.3431368995457889]
# h  = t |--> e^(-t + 0.2?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.11274002099239907]
# b = -2.?
# t = [0.00000000000000000 .. 0.11269201957008790]
# b = -2.?
# found upper bound!
# t = [0.11368690315715321 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.11368690315715321 .. 10.000000000000000], fprime(t) = [-1.1987998923286796 .. -0.000051633454859256744]
# returning res = None
# I  = [0.30468750000000000 .. 0.31250000000000000]
# C || f(I) = [1.1316156271845101 .. 1.3373537626117469]
# h  = t |--> e^(-t + 0.2?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.10913025513165484]
# b = -2.?
# t = [0.00000000000000000 .. 0.10844950902803996]
# b = -2.?
# t = [0.00000000000000000 .. 0.10837933721899018]
# b = -2.?
# found upper bound!
# t = [0.10937212761102463 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10937212761102463 .. 10.000000000000000], fprime(t) = [-1.1987996241077781 .. -0.000051372684538364410]
# returning res = None
# I  = [0.31250000000000000 .. 0.37500000000000000]
# C || f(I) = [1.0872892770916222 .. 1.3316156299784781]
# h  = t |--> e^(-t + 1.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.10448183361474352]
# b = -1.?
# t = [0.00000000000000000 .. 0.10411205001899131]
# b = -1.?
# t = [0.00000000000000000 .. 0.10407542714688624]
# b = -1.?
# found upper bound!
# t = [0.10507180513071880 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10507180513071880 .. 10.000000000000000], fprime(t) = [-1.1988001437857748 .. -0.000049361027777194976]
# bisecting [0.31250000000000000 .. 0.37500000000000000] -> [0.31250000000000000 .. 0.34375000000000000], [0.34375000000000000 .. 0.37500000000000000]
# I  = [0.31250000000000000 .. 0.34375000000000000]
# C || f(I) = [1.1091061808168887 .. 1.3316156299784781]
# h  = t |--> e^(-t + 0.2?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.10448183361474352]
# b = -1.?
# t = [0.00000000000000000 .. 0.10411205001924992]
# b = -1.?
# t = [0.00000000000000000 .. 0.10407542714714485]
# b = -1.?
# found upper bound!
# t = [0.10507180583037288 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10507180583037288 .. 10.000000000000000], fprime(t) = [-1.1988001437857748 .. -0.000050351954996585845]
# bisecting [0.31250000000000000 .. 0.34375000000000000] -> [0.31250000000000000 .. 0.32812500000000000], [0.32812500000000000 .. 0.34375000000000000]
# I  = [0.31250000000000000 .. 0.32812500000000000]
# C || f(I) = [1.1202729778364299 .. 1.3316156299784781]
# h  = t |--> e^(-t + 0.2?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.10448183361474352]
# b = -2.?
# t = [0.00000000000000000 .. 0.10411205001899131]
# b = -2.?
# t = [0.00000000000000000 .. 0.10407542644746769]
# b = -2.?
# found upper bound!
# t = [0.10507180583008612 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10507180583008612 .. 10.000000000000000], fprime(t) = [-1.1988001437857748 .. -0.000050858594477176666]
# bisecting [0.31250000000000000 .. 0.32812500000000000] -> [0.31250000000000000 .. 0.32031250000000000], [0.32031250000000000 .. 0.32812500000000000]
# I  = [0.31250000000000000 .. 0.32031250000000000]
# C || f(I) = [1.1259221486747263 .. 1.3316156299784781]
# h  = t |--> e^(-t + 0.2?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.10448183361474352]
# b = -2.?
# t = [0.00000000000000000 .. 0.10411205001899131]
# b = -2.?
# t = [0.00000000000000000 .. 0.10407542644746769]
# b = -2.?
# found upper bound!
# t = [0.10507180583008612 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10507180583008612 .. 10.000000000000000], fprime(t) = [-1.1988001437857748 .. -0.000051115639507770538]
# returning res = None
# I  = [0.32031250000000000 .. 0.32812500000000000]
# C || f(I) = [1.1202729778364299 .. 1.3259221514686943]
# h  = t |--> e^(-t + 0.2?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.10001479190412076]
# b = -2.?
# t = [0.00000000000000000 .. 0.099808317788439794]
# b = -2.?
# t = [0.00000000000000000 .. 0.099788685255004756]
# b = -2.?
# found upper bound!
# t = [0.10078682053378620 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10078682053378620 .. 10.000000000000000], fprime(t) = [-1.1988003840669990 .. -0.000050858594477176666]
# returning res = False
# I  = [0.32812500000000000 .. 0.34375000000000000]
# C || f(I) = [1.1091061808168887 .. 1.3202729806303979]
# h  = t |--> e^(-t + 0.2?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.095722052622227383]
# b = -2.?
# t = [0.00000000000000000 .. 0.095535665223836275]
# b = -2.?
# t = [0.00000000000000000 .. 0.095518667304375791]
# b = -2.?
# found upper bound!
# t = [0.096517117678306355 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.096517117678306355 .. 10.000000000000000], fprime(t) = [-1.1988004287704826 .. -0.000050351954996585845]
# returning res = False
# I  = [0.34375000000000000 .. 0.37500000000000000]
# C || f(I) = [1.0872892770916222 .. 1.3091061836108567]
# h  = t |--> e^(-t + 1.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.087632541843019274]
# b = -1.?
# t = [0.00000000000000000 .. 0.087074014306352296]
# b = -1.?
# t = [0.00000000000000000 .. 0.087027295584968592]
# b = -1.?
# found upper bound!
# t = [0.088023401421482641 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.088023401421482641 .. 10.000000000000000], fprime(t) = [-1.1988001959398389 .. -0.000049361027777194976]
# returning res = False
# I  = [0.37500000000000000 .. 0.50000000000000000]
# C || f(I) = [1.0065306579694150 .. 1.2872892798855902]
# h  = t |--> e^(-t + 1.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.070814351890345573]
# b = -1.?
# t = [0.00000000000000000 .. 0.070257782866652214]
# b = -1.?
# t = [0.00000000000000000 .. 0.070219876499631393]
# b = -1.?
# found upper bound!
# t = [0.071217304688047392 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.071217304688047392 .. 10.000000000000000], fprime(t) = [-1.1988003933802248 .. -0.000045695342123508453]
# returning res = False
# I  = [0.50000000000000000 .. 1.0000000000000000]
# C || f(I) = [0.76787943867966534 .. 1.2065306612290443]
# h  = t |--> e^(-t + 0.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.0054931757151547214]
# b = -1.?
# t = [0.00000000000000000 .. 0.0054278220749665024]
# b = -1.?
# found upper bound!
# t = [0.0064274663828521082 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.0064274663828521082 .. 10.000000000000000], fprime(t) = [-1.1988006075844169 .. -0.000034860335290431976]
# returning res = False
# Signal([0.00000000000000000 .. 1.0000000000000000], [([0.00000000000000000 .. 0.070312500000000000], True), ([0.32031250000000000 .. 1.0000000000000000], False)])

# %%
csig.plot(aspect_ratio=ar)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
csig = C(RIF(0,1),
         (lambda x: x + RIF(0.5,0.6)),
         (lambda f: to_signal((lambda t: f(t) - 1.2),
                              f.derivative(),
                              RIF(0,10)).F(RIF(0.1,0.2))(0)),
         y,
         g,
         0.01)
csig
# Out:
# I  = [0.00000000000000000 .. 1.0000000000000000]
# C || f(I) = [0.86787943821400403 .. 1.6000000046566130]
# h  = t |--> e^(-t + 0.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.29054522588902532]
# b = -1.?
# t = [0.00000000000000000 .. 0.28840093611344648]
# b = -1.?
# t = [0.00000000000000000 .. 0.28786198567908217]
# b = -1.?
# t = [0.00000000000000000 .. 0.28772706742301630]
# b = -1.?
# t = [0.00000000000000000 .. 0.28769332514064567]
# b = -1.?
# found upper bound!
# t = [0.28868488922080709 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.28868488922080709 .. 10.000000000000000], fprime(t) = [-1.1987972492352129 .. -0.000039399601519107818]
# bisecting [0.00000000000000000 .. 1.0000000000000000] -> [0.00000000000000000 .. 0.50000000000000000], [0.50000000000000000 .. 1.0000000000000000]
# I  = [0.00000000000000000 .. 0.50000000000000000]
# C || f(I) = [1.1065306561067700 .. 1.6000000027939679]
# h  = t |--> e^(-t + 1.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.29054522588902532]
# b = -1.?
# t = [0.00000000000000000 .. 0.28840093436596854]
# b = -1.?
# t = [0.00000000000000000 .. 0.28786198509513001]
# b = -1.?
# t = [0.00000000000000000 .. 0.28772706567475387]
# b = -1.?
# t = [0.00000000000000000 .. 0.28769332397442055]
# b = -1.?
# found upper bound!
# t = [0.28868488805457215 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.28868488805457215 .. 10.000000000000000], fprime(t) = [-1.1987972492352129 .. -0.000050234608352184295]
# bisecting [0.00000000000000000 .. 0.50000000000000000] -> [0.00000000000000000 .. 0.25000000000000000], [0.25000000000000000 .. 0.50000000000000000]
# I  = [0.00000000000000000 .. 0.25000000000000000]
# C || f(I) = [1.2788007790222764 .. 1.6000000027939679]
# h  = t |--> e^(-t + 1.?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.049250483273317893 .. 10.000000000000000]
# b = -1.?
# t = [0.060638382210424272 .. 10.000000000000000]
# b = -1.?
# t = [0.063002901647810818 .. 10.000000000000000]
# b = -1.?
# t = [0.063480938322452148 .. 10.000000000000000]
# b = -1.?
# t = [0.063577041754954488 .. 10.000000000000000]
# b = -1.?
# t = [0.063596339566535528 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.063600214685944511 .. 0.28935932058231656]
# b = -1.?
# t = [0.063600214685944511 .. 0.28801990632814706]
# b = -1.?
# t = [0.063600214685944511 .. 0.28774994098348739]
# b = -1.?
# t = [0.063600214685944511 .. 0.28769570212708357]
# b = -1.?
# t = [0.063600214685944511 .. 0.28768481103409200]
# b = -1.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.063600214685944512]
# f(I) = [1.1671334505525265e-6 .. 0.40000000521540647]
# t = [0.28868262522303028 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.28868262522303028 .. 10.000000000000000], fprime(t) = [-1.1987999556586147 .. -0.000058055855333805084]
# bisecting [0.00000000000000000 .. 0.25000000000000000] -> [0.00000000000000000 .. 0.12500000000000000], [0.12500000000000000 .. 0.25000000000000000]
# I  = [0.00000000000000000 .. 0.12500000000000000]
# C || f(I) = [1.3824969008564949 .. 1.6000000018626453]
# h  = t |--> e^(-t + 0.4?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.11406055814427236 .. 10.000000000000000]
# b = -1.?
# t = [0.13750612026953215 .. 10.000000000000000]
# b = -1.?
# t = [0.14101013492923669 .. 10.000000000000000]
# b = -1.?
# t = [0.14149345714329475 .. 10.000000000000000]
# b = -1.?
# t = [0.14155929236517053 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.14156824423581945 .. 0.28816841519894604]
# b = -2.?
# t = [0.14156824423581945 .. 0.28774829018694826]
# b = -2.?
# t = [0.14156824423581945 .. 0.28769107822637414]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.14156824423581946]
# f(I) = [1.6905367374864255e-6 .. 0.40000000521540647]
# t = [0.28868329874951637 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.28868329874951637 .. 10.000000000000000], fprime(t) = [-1.1987991509959102 .. -0.000062762759625911712]
# returning res = True
# I  = [0.12500000000000000 .. 0.25000000000000000]
# C || f(I) = [1.2788007808849215 .. 1.4824969036504628]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.053154090688467686 .. 10.000000000000000]
# b = -1.?
# t = [0.062118840753825912 .. 10.000000000000000]
# b = -1.?
# t = [0.063396565823619133 .. 10.000000000000000]
# b = -1.?
# t = [0.063573055079692825 .. 10.000000000000000]
# b = -1.?
# t = [0.063597323311893994 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.063600658038791765 .. 0.21210287848808432]
# b = -2.?
# t = [0.063600658038791765 .. 0.21150214040554836]
# b = -2.?
# t = [0.063600658038791765 .. 0.21141939268130797]
# b = -2.?
# t = [0.063600658038791765 .. 0.21140801927765069]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.063600658038791766]
# f(I) = [6.3814222817093479e-7 .. 0.28249690607190137]
# t = [0.21240645621122702 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.21240645621122702 .. 10.000000000000000], fprime(t) = [-1.1988003207370639 .. -0.000058055855333805084]
# bisecting [0.12500000000000000 .. 0.25000000000000000] -> [0.12500000000000000 .. 0.18750000000000000], [0.18750000000000000 .. 0.25000000000000000]
# I  = [0.12500000000000000 .. 0.18750000000000000]
# C || f(I) = [1.3290291167795658 .. 1.4824969036504628]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.087034995148634886 .. 10.000000000000000]
# b = -1.?
# t = [0.10046320931551859 .. 10.000000000000000]
# b = -1.?
# t = [0.10195364025430891 .. 10.000000000000000]
# b = -1.?
# t = [0.10210915547194079 .. 10.000000000000000]
# b = -1.?
# t = [0.10212526843174282 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.10212693630497489 .. 0.21278438454180596]
# b = -2.?
# t = [0.10212693630497489 .. 0.21154972713146820]
# b = -2.?
# t = [0.10212693630497489 .. 0.21142107358072582]
# b = -2.?
# t = [0.10212693630497489 .. 0.21140774643577943]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.10212693630497490]
# f(I) = [2.3022294048935521e-7 .. 0.28249690607190137]
# t = [0.21240636688271705 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.21240636688271705 .. 10.000000000000000], fprime(t) = [-1.1988004287704826 .. -0.000060335732996463775]
# returning res = True
# I  = [0.18750000000000000 .. 0.25000000000000000]
# C || f(I) = [1.2788007808849215 .. 1.4290291186422111]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.055142876792496860 .. 10.000000000000000]
# b = -1.?
# t = [0.062680079059824853 .. 10.000000000000000]
# b = -1.?
# t = [0.063503977634226257 .. 10.000000000000000]
# b = -1.?
# t = [0.063590966160686226 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.063600115032340226 .. 0.17568048203545864]
# b = -2.?
# t = [0.063600115032340226 .. 0.17478001095912047]
# b = -2.?
# t = [0.063600115032340226 .. 0.17468489965889450]
# b = -2.?
# t = [0.063600115032340226 .. 0.17467489534146985]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.063600115032340227]
# f(I) = [1.2882053852525388e-6 .. 0.22902912013232713]
# t = [0.17567384329353899 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.17567384329353899 .. 10.000000000000000], fprime(t) = [-1.1988004734739662 .. -0.000058055855333805084]
# bisecting [0.18750000000000000 .. 0.25000000000000000] -> [0.18750000000000000 .. 0.21875000000000000], [0.21875000000000000 .. 0.25000000000000000]
# I  = [0.18750000000000000 .. 0.21875000000000000]
# C || f(I) = [1.3035225719213485 .. 1.4290291186422111]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.072442587009599879 .. 10.000000000000000]
# b = -1.?
# t = [0.081795283238929678 .. 10.000000000000000]
# b = -1.?
# t = [0.082664561100624298 .. 10.000000000000000]
# b = -1.?
# t = [0.082741317407762318 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.082748062042339601 .. 0.17612341339622756]
# b = -2.?
# t = [0.082748062042339601 .. 0.17480200006506542]
# b = -2.?
# t = [0.082748062042339601 .. 0.17468499410799194]
# b = -2.?
# t = [0.082748062042339601 .. 0.17467471001405250]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.082748062042339602]
# f(I) = [7.7784061436325657e-7 .. 0.22902912013232713]
# t = [0.17567380753291739 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.17567380753291739 .. 10.000000000000000], fprime(t) = [-1.1988005181774498 .. -0.000059177167713642120]
# bisecting [0.18750000000000000 .. 0.21875000000000000] -> [0.18750000000000000 .. 0.20312500000000000], [0.20312500000000000 .. 0.21875000000000000]
# I  = [0.18750000000000000 .. 0.20312500000000000]
# C || f(I) = [1.3161762114614248 .. 1.4290291186422111]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.081297297623367181 .. 10.000000000000000]
# b = -1.?
# t = [0.091474988954630395 .. 10.000000000000000]
# b = -1.?
# t = [0.092334988387728189 .. 10.000000000000000]
# b = -1.?
# t = [0.092403303049926097 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.092408700706679614 .. 0.17604554847806123]
# b = -2.?
# t = [0.092408700706679614 .. 0.17478292313999700]
# b = -2.?
# t = [0.092408700706679614 .. 0.17468234999441365]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.092408700706679615]
# f(I) = [5.5618584160477269e-7 .. 0.22902912013232713]
# t = [0.17567440214630758 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.17567440214630758 .. 10.000000000000000], fprime(t) = [-1.1987998029217124 .. -0.000059752725064754486]
# bisecting [0.18750000000000000 .. 0.20312500000000000] -> [0.18750000000000000 .. 0.19531250000000000], [0.19531250000000000 .. 0.20312500000000000]
# I  = [0.18750000000000000 .. 0.19531250000000000]
# C || f(I) = [1.3225775603204965 .. 1.4290291186422111]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.085776806582455816 .. 10.000000000000000]
# b = -1.?
# t = [0.096344691219227049 .. 10.000000000000000]
# b = -1.?
# t = [0.097192325894963405 .. 10.000000000000000]
# b = -1.?
# t = [0.097255855018916995 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.097260589378230136 .. 0.17540256450537973]
# b = -1.2?
# t = [0.097260589378230136 .. 0.17472825930241398]
# b = -1.2?
# t = [0.097260589378230136 .. 0.17467778460938425]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.097260589378230137]
# f(I) = [4.5746564869553196e-7 .. 0.22902912013232713]
# t = [0.17567402307724777 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.17567402307724777 .. 10.000000000000000], fprime(t) = [-1.1988002592697740 .. -0.000060043297708034515]
# returning res = None
# I  = [0.19531250000000000 .. 0.20312500000000000]
# C || f(I) = [1.3161762114614248 .. 1.4225775631144644]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.081665990417144673 .. 10.000000000000000]
# b = -1.?
# t = [0.091552430032374995 .. 10.000000000000000]
# b = -1.?
# t = [0.092344744515909071 .. 10.000000000000000]
# b = -1.?
# t = [0.092404344308106525 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.092408802825988900 .. 0.17057415648230301]
# b = -1.2?
# t = [0.092408802825988900 .. 0.17018075018843368]
# b = -1.2?
# t = [0.092408802825988900 .. 0.17015124192316539]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.092408802825988901]
# f(I) = [4.3325126175552952e-7 .. 0.22257756553590303]
# t = [0.17114903405224143 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.17114903405224143 .. 10.000000000000000], fprime(t) = [-1.1988004026934505 .. -0.000059752725064754486]
# returning res = None
# I  = [0.20312500000000000 .. 0.21875000000000000]
# C || f(I) = [1.3035225719213485 .. 1.4161762133240701]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.073100059963462221 .. 10.000000000000000]
# b = -1.?
# t = [0.081938474792192003 .. 10.000000000000000]
# b = -1.?
# t = [0.082683956994286017 .. 10.000000000000000]
# b = -1.?
# t = [0.082743557745584436 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.082748301961628634 .. 0.16709049960060716]
# b = -2.?
# t = [0.082748301961628634 .. 0.16575532003846938]
# b = -2.?
# t = [0.082748301961628634 .. 0.16564814476503989]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.082748301961628635]
# f(I) = [4.9099326138168919e-7 .. 0.21617621481418615]
# t = [0.16663961325070839 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.16663961325070839 .. 10.000000000000000], fprime(t) = [-1.1987997321411968 .. -0.000059177167713642120]
# bisecting [0.20312500000000000 .. 0.21875000000000000] -> [0.20312500000000000 .. 0.21093750000000000], [0.21093750000000000 .. 0.21875000000000000]
# I  = [0.20312500000000000 .. 0.21093750000000000]
# C || f(I) = [1.3098246771842241 .. 1.4161762133240701]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.077550146007453121 .. 10.000000000000000]
# b = -1.?
# t = [0.086772846912467241 .. 10.000000000000000]
# b = -1.?
# t = [0.087511444176894728 .. 10.000000000000000]
# b = -1.?
# t = [0.087567204701466769 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.087571394733590407 .. 0.16725763068680575]
# b = -1.2?
# t = [0.087571394733590407 .. 0.16576165199109414]
# b = -1.2?
# t = [0.087571394733590407 .. 0.16564810402565600]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.087571394733590408]
# f(I) = [4.0717422966629612e-7 .. 0.21617621481418615]
# t = [0.16663957002585644 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.16663957002585644 .. 10.000000000000000], fprime(t) = [-1.1987997861579061 .. -0.000059464015066623687]
# returning res = None
# I  = [0.21093750000000000 .. 0.21875000000000000]
# C || f(I) = [1.3035225719213485 .. 1.4098246799781920]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.073429390036067243 .. 10.000000000000000]
# b = -1.?
# t = [0.082005999682814675 .. 10.000000000000000]
# b = -1.?
# t = [0.082692454535539153 .. 10.000000000000000]
# b = -1.?
# t = [0.082744468648739022 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.082748391803514342 .. 0.16188246070002183]
# b = -1.2?
# t = [0.082748391803514342 .. 0.16119974871204779]
# b = -1.2?
# t = [0.082748391803514342 .. 0.16114802044398078]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.082748391803514343]
# f(I) = [3.8295984272629368e-7 .. 0.20982468239963060]
# t = [0.16214411908828424 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.16214411908828424 .. 10.000000000000000], fprime(t) = [-1.1988002313300968 .. -0.000059177167713642120]
# returning res = None
# I  = [0.21875000000000000 .. 0.25000000000000000]
# C || f(I) = [1.2788007808849215 .. 1.4035225747153164]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.056145001129874853 .. 10.000000000000000]
# b = -1.?
# t = [0.062913342586804837 .. 10.000000000000000]
# b = -1.?
# t = [0.063539849796743111 .. 10.000000000000000]
# b = -1.?
# t = [0.063595736343289091 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.063600704081386336 .. 0.15809546344744152]
# b = -2.?
# t = [0.063600704081386336 .. 0.15679181618218180]
# b = -2.?
# t = [0.063600704081386336 .. 0.15667504221727339]
# b = -2.?
# t = [0.063600704081386336 .. 0.15666465808533018]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.063600704081386337]
# f(I) = [5.8226287369400608e-7 .. 0.20352257713675504]
# t = [0.15766373541594694 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.15766373541594694 .. 10.000000000000000], fprime(t) = [-1.1988005088642240 .. -0.000058055855333805084]
# bisecting [0.21875000000000000 .. 0.25000000000000000] -> [0.21875000000000000 .. 0.23437500000000000], [0.23437500000000000 .. 0.25000000000000000]
# I  = [0.21875000000000000 .. 0.23437500000000000]
# C || f(I) = [1.2910651089623570 .. 1.4035225747153164]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.064883248777252072 .. 10.000000000000000]
# b = -1.?
# t = [0.072452616043472001 .. 10.000000000000000]
# b = -1.?
# t = [0.073090206412644423 .. 10.000000000000000]
# b = -1.?
# t = [0.073141513609786462 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.073145626609010125 .. 0.15685359772124014]
# b = -2.?
# t = [0.073145626609010125 .. 0.15667888177290618]
# b = -2.?
# t = [0.073145626609010125 .. 0.15666486701927463]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.073145626609010126]
# f(I) = [4.2766332630783665e-7 .. 0.20352257713675504]
# t = [0.15766374274344185 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.15766374274344185 .. 10.000000000000000], fprime(t) = [-1.1988004995509983 .. -0.000058612786233425140]
# bisecting [0.21875000000000000 .. 0.23437500000000000] -> [0.21875000000000000 .. 0.22656250000000000], [0.22656250000000000 .. 0.23437500000000000]
# I  = [0.21875000000000000 .. 0.22656250000000000]
# C || f(I) = [1.2972695101052522 .. 1.4035225747153164]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.069303840366929922 .. 10.000000000000000]
# b = -1.?
# t = [0.077251943447873588 .. 10.000000000000000]
# b = -1.?
# t = [0.077887802551395407 .. 10.000000000000000]
# b = -1.?
# t = [0.077936157287822355 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.077939819476558036 .. 0.15790934428464013]
# b = -1.2?
# t = [0.077939819476558036 .. 0.15675866818244231]
# b = -1.2?
# t = [0.077939819476558036 .. 0.15667084275994045]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.077939819476558037]
# f(I) = [3.5874545578629124e-7 .. 0.20352257713675504]
# t = [0.15766419094048186 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.15766419094048186 .. 10.000000000000000], fprime(t) = [-1.1987999649718404 .. -0.000058894045650959014]
# returning res = None
# I  = [0.22656250000000000 .. 0.23437500000000000]
# C || f(I) = [1.2910651089623570 .. 1.3972695119678976]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.065173614693966430 .. 10.000000000000000]
# b = -1.?
# t = [0.072510730632164580 .. 10.000000000000000]
# b = -1.?
# t = [0.073097512510531606 .. 10.000000000000000]
# b = -1.?
# t = [0.073142299131462903 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.073145703391803679 .. 0.15356607372427964]
# b = -1.2?
# t = [0.073145703391803679 .. 0.15230324400153109]
# b = -1.2?
# t = [0.073145703391803679 .. 0.15220640038052663]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.073145703391803680]
# f(I) = [3.3639371399551976e-7 .. 0.19726951345801358]
# t = [0.15319903363692480 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.15319903363692480 .. 10.000000000000000], fprime(t) = [-1.1987998923286796 .. -0.000058612786233425140]
# returning res = None
# I  = [0.23437500000000000 .. 0.25000000000000000]
# C || f(I) = [1.2788007808849215 .. 1.3910651117563249]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.056647798961495438 .. 10.000000000000000]
# b = -1.?
# t = [0.063017851756663370 .. 10.000000000000000]
# b = -1.?
# t = [0.063553954767688353 .. 10.000000000000000]
# b = -1.?
# t = [0.063597376643171249 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.063600882039247727 .. 0.14835391328875520]
# b = -2.?
# t = [0.063600882039247727 .. 0.14779721972799373]
# b = -2.?
# t = [0.063600882039247727 .. 0.14775212515859987]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.063600882039247728]
# f(I) = [3.6805868153244603e-7 .. 0.19106511324644094]
# t = [0.14874848447674185 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.14874848447674185 .. 10.000000000000000], fprime(t) = [-1.1988002313300968 .. -0.000058055855333805084]
# bisecting [0.23437500000000000 .. 0.25000000000000000] -> [0.23437500000000000 .. 0.24218750000000000], [0.24218750000000000 .. 0.25000000000000000]
# I  = [0.23437500000000000 .. 0.24218750000000000]
# C || f(I) = [1.2849089913070201 .. 1.3910651117563249]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.061038829502447704 .. 10.000000000000000]
# b = -1.?
# t = [0.067782412751721518 .. 10.000000000000000]
# b = -1.?
# t = [0.068321614929864632 .. 10.000000000000000]
# b = -1.?
# t = [0.068362918880130893 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.068366072548413925 .. 0.14883478535232206]
# b = -1.2?
# t = [0.068366072548413925 .. 0.14783163378740189]
# b = -1.2?
# t = [0.068366072548413925 .. 0.14775453899940927]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.068366072548413926]
# f(I) = [3.1217932705551731e-7 .. 0.19106511324644094]
# t = [0.14874865144510696 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.14874865144510696 .. 10.000000000000000], fprime(t) = [-1.1988000357523561 .. -0.000058333389461040496]
# returning res = None
# I  = [0.24218750000000000 .. 0.25000000000000000]
# C || f(I) = [1.2788007808849215 .. 1.3849089941009881]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.056899605258782647 .. 10.000000000000000]
# b = -1.?
# t = [0.063067041432048859 .. 10.000000000000000]
# b = -1.?
# t = [0.063560133298509541 .. 10.000000000000000]
# b = -1.?
# t = [0.063598042813446609 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.063600948919412411 .. 0.14369688778609136]
# b = -1.2?
# t = [0.063600948919412411 .. 0.14334236446969712]
# b = -1.2?
# t = [0.063600948919412411 .. 0.14331513304793242]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.063600948919412412]
# f(I) = [2.8796494011551487e-7 .. 0.18490899652242665]
# t = [0.14431304705515182 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.14431304705515182 .. 10.000000000000000], fprime(t) = [-1.1988004101440311 .. -0.000058055855333805084]
# returning res = None
# I  = [0.25000000000000000 .. 0.50000000000000000]
# C || f(I) = [1.1065306579694151 .. 1.3788007836788894]
# h  = t |--> e^(-t + 1.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.13976615111792926]
# b = -1.?
# t = [0.00000000000000000 .. 0.13900618625119557]
# b = -1.?
# t = [0.00000000000000000 .. 0.13890730805723737]
# b = -1.?
# t = [0.00000000000000000 .. 0.13889447988636397]
# b = -1.?
# found upper bound!
# t = [0.13989281636741343 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.13989281636741343 .. 10.000000000000000], fprime(t) = [-1.1988003207370639 .. -0.000050234608352184295]
# bisecting [0.25000000000000000 .. 0.50000000000000000] -> [0.25000000000000000 .. 0.37500000000000000], [0.37500000000000000 .. 0.50000000000000000]
# I  = [0.25000000000000000 .. 0.37500000000000000]
# C || f(I) = [1.1872892770916223 .. 1.3788007836788894]
# h  = t |--> e^(-t + 1.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.13976615111792926]
# b = -2.?
# t = [0.00000000000000000 .. 0.13900618557522385]
# b = -2.?
# t = [0.00000000000000000 .. 0.13890730738126564]
# b = -2.?
# t = [0.00000000000000000 .. 0.13889447988585066]
# b = -2.?
# found upper bound!
# t = [0.13989281636689898 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.13989281636689898 .. 10.000000000000000], fprime(t) = [-1.1988003207370639 .. -0.000053900294005870819]
# bisecting [0.25000000000000000 .. 0.37500000000000000] -> [0.25000000000000000 .. 0.31250000000000000], [0.31250000000000000 .. 0.37500000000000000]
# I  = [0.25000000000000000 .. 0.31250000000000000]
# C || f(I) = [1.2316156271845102 .. 1.3788007836788894]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.022929797624229548 .. 10.000000000000000]
# b = -1.?
# t = [0.025672744063338758 .. 10.000000000000000]
# b = -1.?
# t = [0.025969720829104789 .. 10.000000000000000]
# b = -1.?
# t = [0.026001471577343074 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.026004861023181530 .. 0.13938864559323961]
# b = -2.?
# t = [0.026004861023181530 .. 0.13894563355696116]
# b = -2.?
# t = [0.026004861023181530 .. 0.13889823384077441]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.026004861023181531]
# f(I) = [4.8540532593399632e-7 .. 0.17880078516900544]
# t = [0.13989317391857580 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.13989317391857580 .. 10.000000000000000], fprime(t) = [-1.1987998923286796 .. -0.000055913813412189483]
# bisecting [0.25000000000000000 .. 0.31250000000000000] -> [0.25000000000000000 .. 0.28125000000000000], [0.28125000000000000 .. 0.31250000000000000]
# I  = [0.25000000000000000 .. 0.28125000000000000]
# C || f(I) = [1.2548396000638604 .. 1.3788007836788894]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.039773400920429483 .. 10.000000000000000]
# b = -1.?
# t = [0.044233546037033909 .. 10.000000000000000]
# b = -1.?
# t = [0.044645407343482136 .. 10.000000000000000]
# b = -1.?
# t = [0.044682528378607824 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.044685865900887633 .. 0.13939423722623568]
# b = -2.?
# t = [0.044685865900887633 .. 0.13893778594512818]
# b = -2.?
# t = [0.044685865900887633 .. 0.13889663480455112]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.044685865900887634]
# f(I) = [3.9599835877091038e-7 .. 0.17880078516900544]
# t = [0.13989293450185610 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.13989293450185610 .. 10.000000000000000], fprime(t) = [-1.1988001791760326 .. -0.000056968070566654205]
# bisecting [0.25000000000000000 .. 0.28125000000000000] -> [0.25000000000000000 .. 0.26562500000000000], [0.26562500000000000 .. 0.28125000000000000]
# I  = [0.25000000000000000 .. 0.26562500000000000]
# C || f(I) = [1.2667265944182872 .. 1.3788007836788894]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.048394655975035755 .. 10.000000000000000]
# b = -1.?
# t = [0.053634594874616310 .. 10.000000000000000]
# b = -1.?
# t = [0.054075412589927464 .. 10.000000000000000]
# b = -1.?
# t = [0.054111348126250263 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.054114270918642196 .. 0.13937278541505152]
# b = -2.?
# t = [0.054114270918642196 .. 0.13893170799348729]
# b = -2.?
# t = [0.054114270918642196 .. 0.13889574995482460]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.054114270918642197]
# f(I) = [3.0845403675705540e-7 .. 0.17880078516900544]
# t = [0.13989282743904318 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.13989282743904318 .. 10.000000000000000], fprime(t) = [-1.1988003039732576 .. -0.000057508237659931182]
# bisecting [0.25000000000000000 .. 0.26562500000000000] -> [0.25000000000000000 .. 0.25781250000000000], [0.25781250000000000 .. 0.26562500000000000]
# I  = [0.25000000000000000 .. 0.25781250000000000]
# C || f(I) = [1.2727401051670312 .. 1.3788007836788894]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.052756062437814756 .. 10.000000000000000]
# b = -1.?
# t = [0.058364666074879299 .. 10.000000000000000]
# b = -1.?
# t = [0.058813093175082258 .. 10.000000000000000]
# b = -1.?
# t = [0.058847694977670346 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.058850357981301476 .. 0.13961438706638657]
# b = -1.2?
# t = [0.058850357981301476 .. 0.13894833291225589]
# b = -1.2?
# t = [0.058850357981301476 .. 0.13889685883127482]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.058850357981301477]
# f(I) = [2.6561319832474339e-7 .. 0.17880078516900544]
# t = [0.13989289798603821 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.13989289798603821 .. 10.000000000000000], fprime(t) = [-1.1988002238795162 .. -0.000057780183851718902]
# returning res = None
# I  = [0.25781250000000000 .. 0.26562500000000000]
# C || f(I) = [1.2667265944182872 .. 1.3727401079609992]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.048608319402670352 .. 10.000000000000000]
# b = -1.?
# t = [0.053675334233354680 .. 10.000000000000000]
# b = -1.?
# t = [0.054080522567262950 .. 10.000000000000000]
# b = -1.?
# t = [0.054111901870432320 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.054114326227760502 .. 0.13497987896127531]
# b = -2.?
# t = [0.054114326227760502 .. 0.13452542128452375]
# b = -2.?
# t = [0.054114326227760502 .. 0.13449021258618691]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.054114326227760503]
# f(I) = [2.4326145653397190e-7 .. 0.17274011038243776]
# t = [0.13548749344924101 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.13548749344924101 .. 10.000000000000000], fprime(t) = [-1.1988003486767412 .. -0.000057508237659931182]
# returning res = None
# I  = [0.26562500000000000 .. 0.28125000000000000]
# C || f(I) = [1.2548396000638604 .. 1.3667265972122551]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.040124774406117079 .. 10.000000000000000]
# b = -1.?
# t = [0.044303239197021865 .. 10.000000000000000]
# b = -1.?
# t = [0.044654778382061770 .. 10.000000000000000]
# b = -1.?
# t = [0.044683624450875397 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.044685985320364052 .. 0.13073643668391877]
# b = -2.?
# t = [0.044685985320364052 .. 0.13014951652001445]
# b = -2.?
# t = [0.044685985320364052 .. 0.13010128232811305]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.044685985320364053]
# f(I) = [2.5257468228012669e-7 .. 0.16672659963369374]
# t = [0.13109733271488838 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.13109733271488838 .. 10.000000000000000], fprime(t) = [-1.1988001959398389 .. -0.000056968070566654205]
# bisecting [0.26562500000000000 .. 0.28125000000000000] -> [0.26562500000000000 .. 0.27343750000000000], [0.27343750000000000 .. 0.28125000000000000]
# I  = [0.26562500000000000 .. 0.27343750000000000]
# C || f(I) = [1.2607598798349499 .. 1.3667265972122551]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.044456496411057533 .. 10.000000000000000]
# b = -1.?
# t = [0.048999088861608891 .. 10.000000000000000]
# b = -1.?
# t = [0.049362442020011068 .. 10.000000000000000]
# b = -1.?
# t = [0.049390683959216793 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.049392874122267151 .. 0.13115421824987595]
# b = -2.?
# t = [0.049392874122267151 .. 0.13017946696516053]
# b = -2.?
# t = [0.049392874122267151 .. 0.13010337896343019]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.049392874122267152]
# f(I) = [2.2090971474320042e-7 .. 0.16672659963369374]
# t = [0.13109747627770393 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.13109747627770393 .. 10.000000000000000], fprime(t) = [-1.1988000264391304 .. -0.000057236291468143463]
# returning res = None
# I  = [0.27343750000000000 .. 0.28125000000000000]
# C || f(I) = [1.2548396000638604 .. 1.3607598835602404]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.040300714877316040 .. 10.000000000000000]
# b = -1.?
# t = [0.044335980288523153 .. 10.000000000000000]
# b = -1.?
# t = [0.044658879458623915 .. 10.000000000000000]
# b = -1.?
# t = [0.044684069091983247 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.044686030940152665 .. 0.12659751285125221]
# b = -2.?
# t = [0.044686030940152665 .. 0.12579025009730735]
# b = -2.?
# t = [0.044686030940152665 .. 0.12572706260171318]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.044686030940152666]
# f(I) = [1.9855797295242894e-7 .. 0.16075988411903386]
# t = [0.12672214093815339 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.12672214093815339 .. 10.000000000000000], fprime(t) = [-1.1988001251593233 .. -0.000056968070566654205]
# returning res = None
# I  = [0.28125000000000000 .. 0.31250000000000000]
# C || f(I) = [1.2316156271845102 .. 1.3548396028578283]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.023335325378275227 .. 10.000000000000000]
# b = -1.?
# t = [0.025759195209274225 .. 10.000000000000000]
# b = -1.?
# t = [0.025982858371515916 .. 10.000000000000000]
# b = -1.?
# t = [0.026003228387538955 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.026005080501448583 .. 0.12257564594422088]
# b = -2.?
# t = [0.026005080501448583 .. 0.12147261395866190]
# b = -2.?
# t = [0.026005080501448583 .. 0.12137162742127500]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.026005080501448584]
# f(I) = [2.2277235989243138e-7 .. 0.15483960434794431]
# t = [0.12236243682148495 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.12236243682148495 .. 10.000000000000000], fprime(t) = [-1.1987995179370046 .. -0.000055913813412189483]
# bisecting [0.28125000000000000 .. 0.31250000000000000] -> [0.28125000000000000 .. 0.29687500000000000], [0.29687500000000000 .. 0.31250000000000000]
# I  = [0.28125000000000000 .. 0.29687500000000000]
# C || f(I) = [1.2431368967518210 .. 1.3548396028578283]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.031839114269236468 .. 10.000000000000000]
# b = -1.?
# t = [0.035024149469842592 .. 10.000000000000000]
# b = -1.?
# t = [0.035292248662540159 .. 10.000000000000000]
# b = -1.?
# t = [0.035314391477044175 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.035316216765800816 .. 0.12141369912013338]
# b = -2.?
# t = [0.035316216765800816 .. 0.12136582166220244]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.035316216765800817]
# f(I) = [1.9669532780319798e-7 .. 0.15483960434794431]
# t = [0.12236187170498438 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.12236187170498438 .. 10.000000000000000], fprime(t) = [-1.1988001884892583 .. -0.000056437216699123382]
# bisecting [0.28125000000000000 .. 0.29687500000000000] -> [0.28125000000000000 .. 0.28906250000000000], [0.28906250000000000 .. 0.29687500000000000]
# I  = [0.28125000000000000 .. 0.28906250000000000]
# C || f(I) = [1.2489653918892145 .. 1.3548396028578283]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.036141095447716028 .. 10.000000000000000]
# b = -1.?
# t = [0.039686045825606065 .. 10.000000000000000]
# b = -1.?
# t = [0.039969856943389801 .. 10.000000000000000]
# b = -1.?
# t = [0.039992079251130532 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.039993815796534777 .. 0.12255951803942504]
# b = -2.?
# t = [0.039993815796534777 .. 0.12145579755220260]
# b = -2.?
# t = [0.039993815796534777 .. 0.12136888942671645]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.039993815796534778]
# f(I) = [1.7620623116165745e-7 .. 0.15483960434794431]
# t = [0.12236209347814869 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.12236209347814869 .. 10.000000000000000], fprime(t) = [-1.1987999277189374 .. -0.000056701712310314178]
# returning res = None
# I  = [0.28906250000000000 .. 0.29687500000000000]
# C || f(I) = [1.2431368967518210 .. 1.3489653946831824]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.031977760976827994 .. 10.000000000000000]
# b = -1.?
# t = [0.035049331360089322 .. 10.000000000000000]
# b = -1.?
# t = [0.035295397957917397 .. 10.000000000000000]
# b = -1.?
# t = [0.035314734981389157 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.035316252094374674 .. 0.11754894110595055]
# b = -2.?
# t = [0.035316252094374674 .. 0.11705828118075733]
# b = -2.?
# t = [0.035316252094374674 .. 0.11701965753615100]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.035316252094374675]
# f(I) = [1.5571713452011692e-7 .. 0.14896539710462098]
# t = [0.11801662731072813 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.11801662731072813 .. 10.000000000000000], fprime(t) = [-1.1988003132864833 .. -0.000056437216699123382]
# returning res = None
# I  = [0.29687500000000000 .. 0.31250000000000000]
# C || f(I) = [1.2316156271845102 .. 1.3431368995457889]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.023538645222592479 .. 10.000000000000000]
# b = -1.?
# t = [0.025797673764839004 .. 10.000000000000000]
# b = -1.?
# t = [0.025988010384535700 .. 10.000000000000000]
# b = -1.?
# t = [0.026003832635349576 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.026005147215536157 .. 0.11365592770922044]
# b = -2.?
# t = [0.026005147215536157 .. 0.11276723217476907]
# b = -2.?
# t = [0.026005147215536157 .. 0.11269301522828726]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.026005147215536158]
# f(I) = [1.4267861847550022e-7 .. 0.14313690103590493]
# t = [0.11368685024321825 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.11368685024321825 .. 10.000000000000000], fprime(t) = [-1.1987999463453889 .. -0.000055913813412189483]
# bisecting [0.29687500000000000 .. 0.31250000000000000] -> [0.29687500000000000 .. 0.30468750000000000], [0.30468750000000000 .. 0.31250000000000000]
# I  = [0.29687500000000000 .. 0.30468750000000000]
# C || f(I) = [1.2373537598177790 .. 1.3431368995457889]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.027810833319436022 .. 10.000000000000000]
# b = -1.?
# t = [0.030425875159121477 .. 10.000000000000000]
# b = -1.?
# t = [0.030635525526062083 .. 10.000000000000000]
# b = -1.?
# t = [0.030652060660850213 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.030653364206293155 .. 0.11390543434734067]
# b = -2.?
# t = [0.030653364206293155 .. 0.11278299473074534]
# b = -2.?
# t = [0.030653364206293155 .. 0.11269391223964994]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.030653364206293156]
# f(I) = [1.3336539272934544e-7 .. 0.14313690103590493]
# t = [0.11368689201758959 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.11368689201758959 .. 10.000000000000000], fprime(t) = [-1.1987999016419054 .. -0.000056174583733081817]
# returning res = None
# I  = [0.30468750000000000 .. 0.31250000000000000]
# C || f(I) = [1.2316156271845102 .. 1.3373537626117469]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.023640433669444467 .. 10.000000000000000]
# b = -1.?
# t = [0.025815717065608947 .. 10.000000000000000]
# b = -1.?
# t = [0.025990262808407497 .. 10.000000000000000]
# b = -1.?
# t = [0.026004079372634471 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.026005172350929320 .. 0.10883099896387111]
# b = -2.?
# t = [0.026005172350929320 .. 0.10840774543869277]
# b = -2.?
# t = [0.026005172350929320 .. 0.10837418356324050]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.026005172350929321]
# f(I) = [1.1287629608780491e-7 .. 0.13735376410186296]
# t = [0.10937152987876502 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10937152987876502 .. 10.000000000000000], fprime(t) = [-1.1988003393635154 .. -0.000055913813412189483]
# returning res = None
# I  = [0.31250000000000000 .. 0.37500000000000000]
# C || f(I) = [1.1872892770916223 .. 1.3316156299784781]
# h  = t |--> e^(-t + 0.2?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.10448183361474352]
# b = -2.?
# t = [0.00000000000000000 .. 0.10411205001899131]
# b = -2.?
# t = [0.00000000000000000 .. 0.10407542644746769]
# b = -2.?
# found upper bound!
# t = [0.10507180583008612 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10507180583008612 .. 10.000000000000000], fprime(t) = [-1.1988001437857748 .. -0.000053900294005870819]
# bisecting [0.31250000000000000 .. 0.37500000000000000] -> [0.31250000000000000 .. 0.34375000000000000], [0.34375000000000000 .. 0.37500000000000000]
# I  = [0.31250000000000000 .. 0.34375000000000000]
# C || f(I) = [1.2091061808168888 .. 1.3316156299784781]
# h  = t |--> e^(-t + 0.2?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.0068384425177122239 .. 10.000000000000000]
# b = -1.?
# t = [0.0074932293310476100 .. 10.000000000000000]
# b = -1.?
# t = [0.0075537035255197875 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.0075592700597096398 .. 0.10514527019244479]
# b = -2.?
# t = [0.0075592700597096398 .. 0.10417072889611039]
# b = -2.?
# t = [0.0075592700597096398 .. 0.10408055070812416]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.0075592700597096399]
# f(I) = [6.7539513115555394e-7 .. 0.13161563239991670]
# t = [0.10507225018923450 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10507225018923450 .. 10.000000000000000], fprime(t) = [-1.1987996073439718 .. -0.000054891221225261688]
# bisecting [0.31250000000000000 .. 0.34375000000000000] -> [0.31250000000000000 .. 0.32812500000000000], [0.32812500000000000 .. 0.34375000000000000]
# I  = [0.31250000000000000 .. 0.32812500000000000]
# C || f(I) = [1.2202729778364300 .. 1.3316156299784781]
# h  = t |--> e^(-t + 0.2?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.015224344211227792 .. 10.000000000000000]
# b = -1.?
# t = [0.016624136516534160 .. 10.000000000000000]
# b = -1.?
# t = [0.016742241089660311 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.016752124790852685 .. 0.10436123952384154]
# b = -2.?
# t = [0.016752124790852685 .. 0.10409568101967319]
# b = -2.?
# t = [0.016752124790852685 .. 0.10407343813338315]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.016752124790852686]
# f(I) = [1.0814517736879025e-6 .. 0.13161563239991670]
# t = [0.10507157846684427 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10507157846684427 .. 10.000000000000000], fprime(t) = [-1.1988004101440311 .. -0.000055397860705852508]
# bisecting [0.31250000000000000 .. 0.32812500000000000] -> [0.31250000000000000 .. 0.32031250000000000], [0.32031250000000000 .. 0.32812500000000000]
# I  = [0.31250000000000000 .. 0.32031250000000000]
# C || f(I) = [1.2259221486747264 .. 1.3316156299784781]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.019466686886209602 .. 10.000000000000000]
# b = -1.?
# t = [0.021218895587312339 .. 10.000000000000000]
# b = -1.?
# t = [0.021359630209234044 .. 10.000000000000000]
# b = -1.?
# t = [0.021370811443557850 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.021371699710431953 .. 0.10437119031492291]
# b = -2.?
# t = [0.021371699710431953 .. 0.10409524373103111]
# b = -2.?
# t = [0.021371699710431953 .. 0.10407330083291855]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.021371699710431954]
# f(I) = [9.0524554297033432e-8 .. 0.13161563239991670]
# t = [0.10507155830781611 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10507155830781611 .. 10.000000000000000], fprime(t) = [-1.1988004380837083 .. -0.000055654905736446380]
# returning res = None
# I  = [0.32031250000000000 .. 0.32812500000000000]
# C || f(I) = [1.2202729778364300 .. 1.3259221514686943]
# h  = t |--> e^(-t + 0.2?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.015289717185847243 .. 10.000000000000000]
# b = -1.?
# t = [0.016635444992971794 .. 10.000000000000000]
# b = -1.?
# t = [0.016743651035799732 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.016752280102905737 .. 0.099899541381836918]
# b = -2.?
# t = [0.016752280102905737 .. 0.099795628550778962]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.016752280102905738]
# f(I) = [8.9518725876480687e-7 .. 0.12592215202748780]
# t = [0.10078734254053904 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10078734254053904 .. 10.000000000000000], fprime(t) = [-1.1987997582182289 .. -0.000055397860705852508]
# returning res = False
# I  = [0.32812500000000000 .. 0.34375000000000000]
# C || f(I) = [1.2091061808168888 .. 1.3202729806303979]
# h  = t |--> e^(-t + 0.2?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.0068971925643894448 .. 10.000000000000000]
# b = -1.?
# t = [0.0075038381303340140 .. 10.000000000000000]
# b = -1.?
# t = [0.0075551170448132322 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.0075594364213234198 .. 0.096335732616920855]
# b = -2.?
# t = [0.0075594364213234198 .. 0.095586210504213676]
# b = -2.?
# t = [0.0075594364213234198 .. 0.095522796448676742]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.0075594364213234199]
# f(I) = [4.7609210018784153e-7 .. 0.12027298212051397]
# t = [0.096517453851741305 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.096517453851741305 .. 10.000000000000000], fprime(t) = [-1.1988000357523561 .. -0.000054891221225261688]
# returning res = False
# I  = [0.34375000000000000 .. 0.37500000000000000]
# C || f(I) = [1.1872892770916223 .. 1.3091061836108567]
# h  = t |--> e^(-t + 0.2?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.087632541843019274]
# b = -2.?
# t = [0.00000000000000000 .. 0.087074013594536274]
# b = -2.?
# t = [0.00000000000000000 .. 0.087027295584538006]
# b = -2.?
# found upper bound!
# t = [0.088023400709633395 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.088023400709633395 .. 10.000000000000000], fprime(t) = [-1.1988001884892583 .. -0.000053900294005870819]
# returning res = False
# I  = [0.37500000000000000 .. 0.50000000000000000]
# C || f(I) = [1.1065306579694151 .. 1.2872892798855902]
# h  = t |--> e^(-t + 0.2?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.070814351890345573]
# b = -2.?
# t = [0.00000000000000000 .. 0.070257782866652214]
# b = -2.?
# t = [0.00000000000000000 .. 0.070219876499603956]
# b = -2.?
# found upper bound!
# t = [0.071217304688019955 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.071217304688019955 .. 10.000000000000000], fprime(t) = [-1.1988003933802248 .. -0.000050234608352184295]
# returning res = False
# I  = [0.50000000000000000 .. 1.0000000000000000]
# C || f(I) = [0.86787943867966532 .. 1.2065306612290443]
# h  = t |--> e^(-t + 0.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.0054931757151547214]
# b = -1.?
# t = [0.00000000000000000 .. 0.0054278220749665024]
# b = -1.?
# found upper bound!
# t = [0.0064274656109510937 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.0064274656109510937 .. 10.000000000000000], fprime(t) = [-1.1988006168976427 .. -0.000039399601519107818]
# returning res = False
# Signal([0.00000000000000000 .. 1.0000000000000000], [([0.00000000000000000 .. 0.18750000000000000], True), ([0.32031250000000000 .. 1.0000000000000000], False)])

# %%
csig.plot(aspect_ratio=ar)
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# ### Splitting uncertain contexts

# %%
csig1 = C(RIF(0,1),
         (lambda x: x + RIF(0.4,0.5)),
         (lambda f: to_signal((lambda t: f(t) - 1.2),
                              f.derivative(),
                              RIF(0,10)).F(RIF(0.1,0.2))(0)),
         y,
         g,
         0.01)
csig2 = C(RIF(0,1),
         (lambda x: x + RIF(0.5,0.6)),
         (lambda f: to_signal((lambda t: f(t) - 1.2),
                              f.derivative(),
                              RIF(0,10)).F(RIF(0.1,0.2))(0)),
         y,
         g,
         0.01)
csig = csig1 & csig2
# Out:
# I  = [0.00000000000000000 .. 1.0000000000000000]
# C || f(I) = [0.76787943821400406 .. 1.5000000046566129]
# h  = t |--> e^(-t + 0.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.22435568284070104]
# b = -1.?
# t = [0.00000000000000000 .. 0.22338656980912625]
# b = -1.?
# t = [0.00000000000000000 .. 0.22319218242384928]
# b = -1.?
# t = [0.00000000000000000 .. 0.22315328244604063]
# b = -1.?
# found upper bound!
# t = [0.22414550105970390 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.22414550105970390 .. 10.000000000000000], fprime(t) = [-1.1987982848659158 .. -0.000034860335290431976]
# bisecting [0.00000000000000000 .. 1.0000000000000000] -> [0.00000000000000000 .. 0.50000000000000000], [0.50000000000000000 .. 1.0000000000000000]
# I  = [0.00000000000000000 .. 0.50000000000000000]
# C || f(I) = [1.0065306561067699 .. 1.5000000027939678]
# h  = t |--> e^(-t + 1.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.22435568284070104]
# b = -1.?
# t = [0.00000000000000000 .. 0.22338656794467602]
# b = -1.?
# t = [0.00000000000000000 .. 0.22319218118003937]
# b = -1.?
# t = [0.00000000000000000 .. 0.22315328120220657]
# b = -1.?
# found upper bound!
# t = [0.22414549981586501 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.22414549981586501 .. 10.000000000000000], fprime(t) = [-1.1987982941791416 .. -0.000045695342123508453]
# bisecting [0.00000000000000000 .. 0.50000000000000000] -> [0.00000000000000000 .. 0.25000000000000000], [0.25000000000000000 .. 0.50000000000000000]
# I  = [0.00000000000000000 .. 0.25000000000000000]
# C || f(I) = [1.1788007790222763 .. 1.5000000027939678]
# h  = t |--> e^(-t + 1.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.22435568284070104]
# b = -1.?
# t = [0.00000000000000000 .. 0.22338656794467602]
# b = -1.?
# t = [0.00000000000000000 .. 0.22319218118016008]
# b = -1.?
# t = [0.00000000000000000 .. 0.22315328182318484]
# b = -1.?
# found upper bound!
# t = [0.22414550043683845 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.22414550043683845 .. 10.000000000000000], fprime(t) = [-1.1987982848659158 .. -0.000053514726459980010]
# bisecting [0.00000000000000000 .. 0.25000000000000000] -> [0.00000000000000000 .. 0.12500000000000000], [0.12500000000000000 .. 0.25000000000000000]
# I  = [0.00000000000000000 .. 0.12500000000000000]
# C || f(I) = [1.2824969008564948 .. 1.5000000018626452]
# h  = t |--> e^(-t + 1.?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.054997930610592285 .. 10.000000000000000]
# b = -1.?
# t = [0.064765119489226571 .. 10.000000000000000]
# b = -1.?
# t = [0.066236331989890193 .. 10.000000000000000]
# b = -1.?
# t = [0.066450901292591929 .. 10.000000000000000]
# b = -1.?
# t = [0.066482039439786241 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.066486555113331013 .. 0.22545089116875267]
# b = -2.?
# t = [0.066486555113331013 .. 0.22348039788882169]
# b = -2.?
# t = [0.066486555113331013 .. 0.22319244588563001]
# b = -2.?
# t = [0.066486555113331013 .. 0.22315064472739899]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.066486555113331014]
# f(I) = [9.1940164570480931e-7 .. 0.30000000372529035]
# t = [0.22414458186470995 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.22414458186470995 .. 10.000000000000000], fprime(t) = [-1.1987993931397796 .. -0.000058223493397235870]
# bisecting [0.00000000000000000 .. 0.12500000000000000] -> [0.00000000000000000 .. 0.062500000000000000], [0.062500000000000000 .. 0.12500000000000000]
# I  = [0.00000000000000000 .. 0.062500000000000000]
# C || f(I) = [1.3394130613654851 .. 1.5000000018626452]
# h  = t |--> e^(-t + 1.?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.092942036886262957 .. 10.000000000000000]
# b = -1.?
# t = [0.10796557420990716 .. 10.000000000000000]
# b = -1.?
# t = [0.10970009729464276 .. 10.000000000000000]
# b = -1.?
# t = [0.10988745955176093 .. 10.000000000000000]
# b = -1.?
# t = [0.10990753655381919 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.10990968711036468 .. 0.22355346409333760]
# b = -2.?
# t = [0.10990968711036468 .. 0.22318751331074100]
# b = -2.?
# t = [0.10990968711036468 .. 0.22314826044043068]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.10990968711036469]
# f(I) = [3.0845403675705540e-7 .. 0.30000000372529035]
# t = [0.22414405744880883 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.22414405744880883 .. 10.000000000000000], fprime(t) = [-1.1988000171259046 .. -0.000060806982219219207]
# returning res = True
# I  = [0.062500000000000000 .. 0.12500000000000000]
# C || f(I) = [1.2824969008564948 .. 1.4394130632281304]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.057312871889992157 .. 10.000000000000000]
# b = -1.?
# t = [0.065449795167075622 .. 10.000000000000000]
# b = -1.?
# t = [0.066373737863108739 .. 10.000000000000000]
# b = -1.?
# t = [0.066474934573190314 .. 10.000000000000000]
# b = -1.?
# t = [0.066485971544655658 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.066487175576113971 .. 0.18296404121465185]
# b = -2.?
# t = [0.066487175576113971 .. 0.18202885310635925]
# b = -2.?
# t = [0.066487175576113971 .. 0.18192641986037989]
# b = -2.?
# t = [0.066487175576113971 .. 0.18191524749700977]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.066487175576113972]
# f(I) = [1.7620623116165745e-7 .. 0.23941306509077554]
# t = [0.18291402852777402 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.18291402852777402 .. 10.000000000000000], fprime(t) = [-1.1988004473969341 .. -0.000058223493397235870]
# bisecting [0.062500000000000000 .. 0.12500000000000000] -> [0.062500000000000000 .. 0.093750000000000000], [0.093750000000000000 .. 0.12500000000000000]
# I  = [0.062500000000000000 .. 0.093750000000000000]
# C || f(I) = [1.3105103593319653 .. 1.4394130632281304]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.076774594163267165 .. 10.000000000000000]
# b = -1.?
# t = [0.087023193695513464 .. 10.000000000000000]
# b = -1.?
# t = [0.087998575579872603 .. 10.000000000000000]
# b = -1.?
# t = [0.088086442189531474 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.088094314498075351 .. 0.18297331338358192]
# b = -2.?
# t = [0.088094314498075351 .. 0.18200926608750501]
# b = -2.?
# t = [0.088094314498075351 .. 0.18192242580918939]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.088094314498075352]
# f(I) = [9.2871487145096409e-7 .. 0.23941306509077554]
# t = [0.18291464557914260 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.18291464557914260 .. 10.000000000000000], fprime(t) = [-1.1987997060641647 .. -0.000059495680034160614]
# bisecting [0.062500000000000000 .. 0.093750000000000000] -> [0.062500000000000000 .. 0.078125000000000000], [0.078125000000000000 .. 0.093750000000000000]
# I  = [0.062500000000000000 .. 0.078125000000000000]
# C || f(I) = [1.3248488117009400 .. 1.4394130632281304]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.086735913409998449 .. 10.000000000000000]
# b = -1.?
# t = [0.097933850400035535 .. 10.000000000000000]
# b = -1.?
# t = [0.098893280137765507 .. 10.000000000000000]
# b = -1.?
# t = [0.098970139494558850 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.098976259274025341 .. 0.18215434173604084]
# b = -2.?
# t = [0.098976259274025341 .. 0.18193304568880009]
# b = -2.?
# t = [0.098976259274025341 .. 0.18191540542618954]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.098976259274025342]
# f(I) = [6.3627958302170384e-7 .. 0.23941306509077554]
# t = [0.18291400190852685 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.18291400190852685 .. 10.000000000000000], fprime(t) = [-1.1988004734739662 .. -0.000060145743191242218]
# bisecting [0.062500000000000000 .. 0.078125000000000000] -> [0.062500000000000000 .. 0.070312500000000000], [0.070312500000000000 .. 0.078125000000000000]
# I  = [0.062500000000000000 .. 0.070312500000000000]
# C || f(I) = [1.3321024911478160 .. 1.4394130632281304]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.091775244682351292 .. 10.000000000000000]
# b = -1.?
# t = [0.10341913224032879 .. 10.000000000000000]
# b = -1.?
# t = [0.10436059611068795 .. 10.000000000000000]
# b = -1.?
# t = [0.10443125945213353 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.10443653074718896 .. 0.18198889984521114]
# b = -1.2?
# t = [0.10443653074718896 .. 0.18191947541917350]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.10443653074718897]
# f(I) = [5.0775706772476780e-7 .. 0.23941306509077554]
# t = [0.18291429775503514 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.18291429775503514 .. 10.000000000000000], fprime(t) = [-1.1988001158460975 .. -0.000060475431382656097]
# returning res = True
# I  = [0.070312500000000000 .. 0.078125000000000000]
# C || f(I) = [1.3248488117009400 .. 1.4321024930104614]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.087178680434541216 .. 10.000000000000000]
# b = -1.?
# t = [0.098029066801873482 .. 10.000000000000000]
# b = -1.?
# t = [0.098905396139515391 .. 10.000000000000000]
# b = -1.?
# t = [0.098971440511506122 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.098976388214542798 .. 0.17836836495708114]
# b = -1.2?
# t = [0.098976388214542798 .. 0.17693899436399302]
# b = -1.2?
# t = [0.098976388214542798 .. 0.17683084625141194]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.098976388214542799]
# f(I) = [4.7981739048630345e-7 .. 0.23210249394178395]
# t = [0.17782273970930628 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.17782273970930628 .. 10.000000000000000], fprime(t) = [-1.1987998308613897 .. -0.000060145743191242218]
# returning res = None
# I  = [0.078125000000000000 .. 0.093750000000000000]
# C || f(I) = [1.3105103593319653 .. 1.4248488135635853]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.077559354655969775 .. 10.000000000000000]
# b = -1.?
# t = [0.087198770228638963 .. 10.000000000000000]
# b = -1.?
# t = [0.088022793274216387 .. 10.000000000000000]
# b = -1.?
# t = [0.088089284793131286 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.088094623587300913 .. 0.17179016321217564]
# b = -2.?
# t = [0.088094623587300913 .. 0.17174785008685362]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.088094623587300914]
# f(I) = [5.5804848675400364e-7 .. 0.22484881542623048]
# t = [0.17274445314739703 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.17274445314739703 .. 10.000000000000000], fprime(t) = [-1.1988002592697740 .. -0.000059495680034160614]
# bisecting [0.078125000000000000 .. 0.093750000000000000] -> [0.078125000000000000 .. 0.085937500000000000], [0.085937500000000000 .. 0.093750000000000000]
# I  = [0.078125000000000000 .. 0.085937500000000000]
# C || f(I) = [1.3176515806466340 .. 1.4248488135635853]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.082571269169048194 .. 10.000000000000000]
# b = -1.?
# t = [0.092649732475355323 .. 10.000000000000000]
# b = -1.?
# t = [0.093462941206985741 .. 10.000000000000000]
# b = -1.?
# t = [0.093524478972720398 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.093529110493630052 .. 0.17254955905027078]
# b = -1.2?
# t = [0.093529110493630052 .. 0.17180505087915904]
# b = -1.2?
# t = [0.093529110493630052 .. 0.17174874001626736]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.093529110493630053]
# f(I) = [4.5187771324783909e-7 .. 0.22484881542623048]
# t = [0.17274450206739228 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.17274450206739228 .. 10.000000000000000], fprime(t) = [-1.1988002052530647 .. -0.000059819780290126800]
# returning res = None
# I  = [0.085937500000000000 .. 0.093750000000000000]
# C || f(I) = [1.3105103593319653 .. 1.4176515834406019]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.077953113418889358 .. 10.000000000000000]
# b = -1.?
# t = [0.087281210406920550 .. 10.000000000000000]
# b = -1.?
# t = [0.088033272583459082 .. 10.000000000000000]
# b = -1.?
# t = [0.088090416001036925 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.088094735872758594 .. 0.16820838280655537]
# b = -1.2?
# t = [0.088094735872758594 .. 0.16679671245994646]
# b = -1.2?
# t = [0.088094735872758594 .. 0.16668894994741740]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.088094735872758595]
# f(I) = [4.2393803600937474e-7 .. 0.21765158623456960]
# t = [0.16768079917824177 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.16768079917824177 .. 10.000000000000000], fprime(t) = [-1.1987998122349382 .. -0.000059495680034160614]
# returning res = None
# I  = [0.093750000000000000 .. 0.12500000000000000]
# C || f(I) = [1.2824969008564948 .. 1.4105103621259332]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.058487266951488640 .. 10.000000000000000]
# b = -1.?
# t = [0.065732243640118842 .. 10.000000000000000]
# b = -1.?
# t = [0.066418534845603838 .. 10.000000000000000]
# b = -1.?
# t = [0.066481077350958595 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.066486755947344239 .. 0.16295729787432728]
# b = -2.?
# t = [0.066486755947344239 .. 0.16175130142699296]
# b = -2.?
# t = [0.066486755947344239 .. 0.16164105338217278]
# b = -2.?
# t = [0.066486755947344239 .. 0.16163104084025879]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.066486755947344240]
# f(I) = [6.7912042145401585e-7 .. 0.21051036305725579]
# t = [0.16263013279032262 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.16263013279032262 .. 10.000000000000000], fprime(t) = [-1.1988005088642240 .. -0.000058223493397235870]
# bisecting [0.093750000000000000 .. 0.12500000000000000] -> [0.093750000000000000 .. 0.10937500000000000], [0.10937500000000000 .. 0.12500000000000000]
# I  = [0.093750000000000000 .. 0.10937500000000000]
# C || f(I) = [1.2963942052796482 .. 1.4105103621259332]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.068339944128782220 .. 10.000000000000000]
# b = -1.?
# t = [0.076506577476820145 .. 10.000000000000000]
# b = -1.?
# t = [0.077203526144853928 .. 10.000000000000000]
# b = -1.?
# t = [0.077260174766715483 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.077264759344267533 .. 0.16166917204579251]
# b = -2.?
# t = [0.077264759344267533 .. 0.16163320913927002]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.077264759344267534]
# f(I) = [4.8354268078476536e-7 .. 0.21051036491990094]
# t = [0.16263029825581579 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.16263029825581579 .. 10.000000000000000], fprime(t) = [-1.1988003132864833 .. -0.000058854930102825164]
# bisecting [0.093750000000000000 .. 0.10937500000000000] -> [0.093750000000000000 .. 0.10156250000000000], [0.10156250000000000 .. 0.10937500000000000]
# I  = [0.093750000000000000 .. 0.10156250000000000]
# C || f(I) = [1.3034247118979691 .. 1.4105103621259332]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.073324315472466344 .. 10.000000000000000]
# b = -1.?
# t = [0.081923574849786059 .. 10.000000000000000]
# b = -1.?
# t = [0.082616430358088285 .. 10.000000000000000]
# b = -1.?
# t = [0.082669290144103790 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.082673304330021124 .. 0.16174330767040266]
# b = -1.2?
# t = [0.082673304330021124 .. 0.16163864752744606]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.082673304330021125]
# f(I) = [3.9599835877091038e-7 .. 0.21051036305725579]
# t = [0.16263069629185730 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.16263069629185730 .. 10.000000000000000], fprime(t) = [-1.1987998401746154 .. -0.000059173442423343658]
# returning res = None
# I  = [0.10156250000000000 .. 0.10937500000000000]
# C || f(I) = [1.2963942052796482 .. 1.4034247137606144]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.068684980621535579 .. 10.000000000000000]
# b = -1.?
# t = [0.076576899599855613 .. 10.000000000000000]
# b = -1.?
# t = [0.077212454168556460 .. 10.000000000000000]
# b = -1.?
# t = [0.077261142368388380 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.077264856826372046 .. 0.15662059321960567]
# b = -1.2?
# t = [0.077264856826372046 .. 0.15659595233179025]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.077264856826372047]
# f(I) = [3.6805868153244603e-7 .. 0.20342471562325959]
# t = [0.15759407344509615 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.15759407344509615 .. 10.000000000000000], fprime(t) = [-1.1988004380837083 .. -0.000058854930102825164]
# returning res = None
# I  = [0.10937500000000000 .. 0.12500000000000000]
# C || f(I) = [1.2824969008564948 .. 1.3963942071422935]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.059078515208208746 .. 10.000000000000000]
# b = -1.?
# t = [0.065857875845442434 .. 10.000000000000000]
# b = -1.?
# t = [0.066435799621122684 .. 10.000000000000000]
# b = -1.?
# t = [0.066483117921731851 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.066486979280936886 .. 0.15293407411458324]
# b = -2.?
# t = [0.066486979280936886 .. 0.15168375870107126]
# b = -2.?
# t = [0.066486979280936886 .. 0.15158093118751287]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.066486979280936887]
# f(I) = [4.1089951996475804e-7 .. 0.19639420807361608]
# t = [0.15257253812305759 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.15257253812305759 .. 10.000000000000000], fprime(t) = [-1.1987997228279710 .. -0.000058223493397235870]
# bisecting [0.10937500000000000 .. 0.12500000000000000] -> [0.10937500000000000 .. 0.11718750000000000], [0.11718750000000000 .. 0.12500000000000000]
# I  = [0.10937500000000000 .. 0.11718750000000000]
# C || f(I) = [1.2894184101372956 .. 1.3963942071422935]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.064035216656175827 .. 10.000000000000000]
# b = -1.?
# t = [0.071241257451370568 .. 10.000000000000000]
# b = -1.?
# t = [0.071821385506306567 .. 10.000000000000000]
# b = -1.?
# t = [0.071866008324979205 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.071869429007177285 .. 0.15266591200301777]
# b = -1.2?
# t = [0.071869429007177285 .. 0.15165616460045445]
# b = -1.2?
# t = [0.071869429007177285 .. 0.15157825889061183]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.071869429007177286]
# f(I) = [3.4011900429398167e-7 .. 0.19639420807361608]
# t = [0.15257228722411406 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.15257228722411406 .. 10.000000000000000], fprime(t) = [-1.1988000171259046 .. -0.000058538280427455902]
# returning res = None
# I  = [0.11718750000000000 .. 0.12500000000000000]
# C || f(I) = [1.2824969008564948 .. 1.3894184119999409]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.059375128125117325 .. 10.000000000000000]
# b = -1.?
# t = [0.065916718771765872 .. 10.000000000000000]
# b = -1.?
# t = [0.066443261995638755 .. 10.000000000000000]
# b = -1.?
# t = [0.066483929833905552 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.066487061254149423 .. 0.14657661047792798]
# b = -2.?
# t = [0.066487061254149423 .. 0.14656468938029255]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.066487061254149424]
# f(I) = [3.1217932705551731e-7 .. 0.18941841386258607]
# t = [0.14756377184376481 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.14756377184376481 .. 10.000000000000000], fprime(t) = [-1.1988005274906755 .. -0.000058223493397235870]
# returning res = None
# I  = [0.12500000000000000 .. 0.25000000000000000]
# C || f(I) = [1.1788007808849214 .. 1.3824969036504627]
# h  = t |--> e^(-t + 1.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.14277645075539961]
# b = -2.?
# t = [0.00000000000000000 .. 0.14172959414312511]
# b = -2.?
# t = [0.00000000000000000 .. 0.14159078210582974]
# b = -2.?
# t = [0.00000000000000000 .. 0.14157244743892037]
# b = -2.?
# found upper bound!
# t = [0.14257002714001740 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.14257002714001740 .. 10.000000000000000], fprime(t) = [-1.1988001791760326 .. -0.000053514726459980010]
# bisecting [0.12500000000000000 .. 0.25000000000000000] -> [0.12500000000000000 .. 0.18750000000000000], [0.18750000000000000 .. 0.25000000000000000]
# I  = [0.12500000000000000 .. 0.18750000000000000]
# C || f(I) = [1.2290291167795657 .. 1.3824969036504627]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.020997597059139661 .. 10.000000000000000]
# b = -1.?
# t = [0.023576695363643433 .. 10.000000000000000]
# b = -1.?
# t = [0.023866697442629508 .. 10.000000000000000]
# b = -1.?
# t = [0.023898935650315065 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.023902515918349628 .. 0.14232085532464842]
# b = -2.?
# t = [0.023902515918349628 .. 0.14165329921313544]
# b = -2.?
# t = [0.023902515918349628 .. 0.14157894704789623]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.023902515918349629]
# f(I) = [5.3569674496323216e-7 .. 0.18249690644443040]
# t = [0.14257069057183929 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.14257069057183929 .. 10.000000000000000], fprime(t) = [-1.1987993838265539 .. -0.000055796466767787933]
# bisecting [0.12500000000000000 .. 0.18750000000000000] -> [0.12500000000000000 .. 0.15625000000000000], [0.15625000000000000 .. 0.18750000000000000]
# I  = [0.12500000000000000 .. 0.15625000000000000]
# C || f(I) = [1.2553453255444764 .. 1.3824969036504627]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.040032871738233430 .. 10.000000000000000]
# b = -1.?
# t = [0.044612511293196911 .. 10.000000000000000]
# b = -1.?
# t = [0.045045195533464491 .. 10.000000000000000]
# b = -1.?
# t = [0.045085093174956514 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.045088762789276336 .. 0.14199984487166107]
# b = -2.?
# t = [0.045088762789276336 .. 0.14160930857687760]
# b = -2.?
# t = [0.045088762789276336 .. 0.14157330659051468]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.045088762789276337]
# f(I) = [4.4628977780014622e-7 .. 0.18249690644443040]
# t = [0.14256999383384383 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.14256999383384383 .. 10.000000000000000], fprime(t) = [-1.1988002145662904 .. -0.000056990422308444976]
# bisecting [0.12500000000000000 .. 0.15625000000000000] -> [0.12500000000000000 .. 0.14062500000000000], [0.14062500000000000 .. 0.15625000000000000]
# I  = [0.12500000000000000 .. 0.14062500000000000]
# C || f(I) = [1.2688150541856884 .. 1.3824969036504627]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.049775915240465498 .. 10.000000000000000]
# b = -1.?
# t = [0.055253244869065527 .. 10.000000000000000]
# b = -1.?
# t = [0.055719934499710799 .. 10.000000000000000]
# b = -1.?
# t = [0.055758426978124407 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.055761593210901752 .. 0.14169376274391544]
# b = -2.?
# t = [0.055761593210901752 .. 0.14157987088352209]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.055761593210901753]
# f(I) = [3.4011900429398167e-7 .. 0.18249690644443040]
# t = [0.14257049951130690 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.14257049951130690 .. 10.000000000000000], fprime(t) = [-1.1987996166571975 .. -0.000057601369917392730]
# bisecting [0.12500000000000000 .. 0.14062500000000000] -> [0.12500000000000000 .. 0.13281250000000000], [0.13281250000000000 .. 0.14062500000000000]
# I  = [0.12500000000000000 .. 0.13281250000000000]
# C || f(I) = [1.2756292555481194 .. 1.3824969036504627]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.054704824778280952 .. 10.000000000000000]
# b = -1.?
# t = [0.060603352527482896 .. 10.000000000000000]
# b = -1.?
# t = [0.061078124173680053 .. 10.000000000000000]
# b = -1.?
# t = [0.061114945892285929 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.061117792560306263 .. 0.14301149176958325]
# b = -2.?
# t = [0.061117792560306263 .. 0.14168207222737853]
# b = -2.?
# t = [0.061117792560306263 .. 0.14157835473540609]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.061117792560306264]
# f(I) = [2.8610229496628392e-7 .. 0.18249690644443040]
# t = [0.14257033087819742 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.14257033087819742 .. 10.000000000000000], fprime(t) = [-1.1987998122349382 .. -0.000057912431657314300]
# returning res = None
# I  = [0.13281250000000000 .. 0.14062500000000000]
# C || f(I) = [1.2688150541856884 .. 1.3756292574107647]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.050024415250004686 .. 10.000000000000000]
# b = -1.?
# t = [0.055301224855153367 .. 10.000000000000000]
# b = -1.?
# t = [0.055726011149206423 .. 10.000000000000000]
# b = -1.?
# t = [0.055759091207080335 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.055761660491863616 .. 0.13723262225547720]
# b = -2.?
# t = [0.055761660491863616 .. 0.13663982347393700]
# b = -2.?
# t = [0.055761660491863616 .. 0.13659360400300258]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.055761660491863617]
# f(I) = [2.6002526287705052e-7 .. 0.17562925927340989]
# t = [0.13759001421068145 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.13759001421068145 .. 10.000000000000000], fprime(t) = [-1.1988002592697740 .. -0.000057601369917392730]
# returning res = None
# I  = [0.14062500000000000 .. 0.15625000000000000]
# C || f(I) = [1.2553453255444764 .. 1.3688150569796563]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.040433016164904508 .. 10.000000000000000]
# b = -1.?
# t = [0.044693233505126626 .. 10.000000000000000]
# b = -1.?
# t = [0.045056245076033500 .. 10.000000000000000]
# b = -1.?
# t = [0.045086408162515169 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.045088908732426553 .. 0.13177337521465952]
# b = -2.?
# t = [0.045088908732426553 .. 0.13163628994310920]
# b = -2.?
# t = [0.045088908732426553 .. 0.13162491677704045]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.045088908732426554]
# f(I) = [2.7120113377243626e-7 .. 0.16881505884230142]
# t = [0.13262397382948312 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.13262397382948312 .. 10.000000000000000], fprime(t) = [-1.1988005181774498 .. -0.000056990422308444976]
# bisecting [0.14062500000000000 .. 0.15625000000000000] -> [0.14062500000000000 .. 0.14843750000000000], [0.14843750000000000 .. 0.15625000000000000]
# I  = [0.14062500000000000 .. 0.14843750000000000]
# C || f(I) = [1.2620538823306559 .. 1.3688150569796563]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.045334011845066628 .. 10.000000000000000]
# b = -1.?
# t = [0.050010402000093163 .. 10.000000000000000]
# b = -1.?
# t = [0.050386962153733609 .. 10.000000000000000]
# b = -1.?
# t = [0.050416407768881649 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.050418705600864255 .. 0.13217052334272795]
# b = -2.?
# t = [0.050418705600864255 .. 0.13166666011520248]
# b = -2.?
# t = [0.050418705600864255 .. 0.13162722449850728]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.050418705600864256]
# f(I) = [2.3208558563858616e-7 .. 0.16881505884230142]
# t = [0.13262414840763131 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.13262414840763131 .. 10.000000000000000], fprime(t) = [-1.1988003039732576 .. -0.000057295896112918853]
# returning res = None
# I  = [0.14843750000000000 .. 0.15625000000000000]
# C || f(I) = [1.2553453255444764 .. 1.3620538841933013]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.040633723681740126 .. 10.000000000000000]
# b = -1.?
# t = [0.044730946393396128 .. 10.000000000000000]
# b = -1.?
# t = [0.045061014018707080 .. 10.000000000000000]
# b = -1.?
# t = [0.045086932302788984 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.045088963176072888 .. 0.12760397721387027]
# b = -2.?
# t = [0.045088963176072888 .. 0.12674561190102460]
# b = -2.?
# t = [0.045088963176072888 .. 0.12667796691575667]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.045088963176072889]
# f(I) = [2.0600855354935276e-7 .. 0.16205388605594640]
# t = [0.12767266454598155 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.12767266454598155 .. 10.000000000000000], fprime(t) = [-1.1988000804558397 .. -0.000056990422308444976]
# returning res = None
# I  = [0.15625000000000000 .. 0.18750000000000000]
# C || f(I) = [1.2290291167795657 .. 1.3553453283384443]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.021418241138102374 .. 10.000000000000000]
# b = -1.?
# t = [0.023668592672603083 .. 10.000000000000000]
# b = -1.?
# t = [0.023881095078397827 .. 10.000000000000000]
# b = -1.?
# t = [0.023900923520611877 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.023902772462809886 .. 0.12251450637248345]
# b = -2.?
# t = [0.023902772462809886 .. 0.12180767117400840]
# b = -2.?
# t = [0.023902772462809886 .. 0.12174152182176436]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.023902772462809887]
# f(I) = [2.2836029534012425e-7 .. 0.15534532926976686]
# t = [0.12273535482233631 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.12273535482233631 .. 10.000000000000000], fprime(t) = [-1.1987998569384218 .. -0.000055796466767787933]
# bisecting [0.15625000000000000 .. 0.18750000000000000] -> [0.15625000000000000 .. 0.17187500000000000], [0.17187500000000000 .. 0.18750000000000000]
# I  = [0.15625000000000000 .. 0.17187500000000000]
# C || f(I) = [1.2420844255015253 .. 1.3553453283384443]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.031050699425307339 .. 10.000000000000000]
# b = -1.?
# t = [0.034178360971724802 .. 10.000000000000000]
# b = -1.?
# t = [0.034445037130861541 .. 10.000000000000000]
# b = -1.?
# t = [0.034467360617345503 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.034469226354874343 .. 0.12286503003805032]
# b = -2.?
# t = [0.034469226354874343 .. 0.12182976225492156]
# b = -2.?
# t = [0.034469226354874343 .. 0.12174266816579718]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.034469226354874344]
# f(I) = [2.0414590840012181e-7 .. 0.15534532926976686]
# t = [0.12273538585816744 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.12273538585816744 .. 10.000000000000000], fprime(t) = [-1.1987998215481639 .. -0.000056388787925243377]
# bisecting [0.15625000000000000 .. 0.17187500000000000] -> [0.15625000000000000 .. 0.16406250000000000], [0.16406250000000000 .. 0.17187500000000000]
# I  = [0.15625000000000000 .. 0.16406250000000000]
# C || f(I) = [1.2486889749765395 .. 1.3553453283384443]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.035923664374661629 .. 10.000000000000000]
# b = -1.?
# t = [0.039462918897221060 .. 10.000000000000000]
# b = -1.?
# t = [0.039748206305815353 .. 10.000000000000000]
# b = -1.?
# t = [0.039770699972709357 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.039772469807184539 .. 0.12197261509551615]
# b = -2.?
# t = [0.039772469807184539 .. 0.12175346841077788]
# b = -2.?
# t = [0.039772469807184539 .. 0.12173619704920373]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.039772469807184540]
# f(I) = [1.8179416660935032e-7 .. 0.15534532926976686]
# t = [0.12273483792372642 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.12273483792372642 .. 10.000000000000000], fprime(t) = [-1.1988004734739662 .. -0.000056688673794269561]
# returning res = None
# I  = [0.16406250000000000 .. 0.17187500000000000]
# C || f(I) = [1.2420844255015253 .. 1.3486889777705074]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.031203947757698906 .. 10.000000000000000]
# b = -1.?
# t = [0.034206381415608590 .. 10.000000000000000]
# b = -1.?
# t = [0.034448575312108944 .. 10.000000000000000]
# b = -1.?
# t = [0.034467751261019918 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.034469267400261058 .. 0.11768080018579002]
# b = -2.?
# t = [0.034469267400261058 .. 0.11688050244795202]
# b = -2.?
# t = [0.034469267400261058 .. 0.11681689855124754]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.034469267400261059]
# f(I) = [1.5571713452011692e-7 .. 0.14868897870182996]
# t = [0.11781186895247190 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.11781186895247190 .. 10.000000000000000], fprime(t) = [-1.1988000990822912 .. -0.000056388787925243377]
# returning res = None
# I  = [0.17187500000000000 .. 0.18750000000000000]
# C || f(I) = [1.2290291167795657 .. 1.3420844273641706]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.021629870901686245 .. 10.000000000000000]
# b = -1.?
# t = [0.023709116121910050 .. 10.000000000000000]
# b = -1.?
# t = [0.023886615827121447 .. 10.000000000000000]
# b = -1.?
# t = [0.023901585712121694 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.023902845966843073 .. 0.11237518868953592]
# b = -2.?
# t = [0.023902845966843073 .. 0.11194232290552216]
# b = -2.?
# t = [0.023902845966843073 .. 0.11190575699299012]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.023902845966843074]
# f(I) = [1.3895332817703831e-7 .. 0.14208442829549318]
# t = [0.11290267614528051 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.11290267614528051 .. 10.000000000000000], fprime(t) = [-1.1988002760335804 .. -0.000055796466767787933]
# bisecting [0.17187500000000000 .. 0.18750000000000000] -> [0.17187500000000000 .. 0.17968750000000000], [0.17968750000000000 .. 0.18750000000000000]
# I  = [0.17187500000000000 .. 0.17968750000000000]
# C || f(I) = [1.2355312719941138 .. 1.3420844273641706]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.026474689129704822 .. 10.000000000000000]
# b = -1.?
# t = [0.028961388392904744 .. 10.000000000000000]
# b = -1.?
# t = [0.029162159883683962 .. 10.000000000000000]
# b = -1.?
# t = [0.029178120617957079 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.029179388969001348 .. 0.11303130867149242]
# b = -2.?
# t = [0.029179388969001348 .. 0.11199260785331067]
# b = -2.?
# t = [0.029179388969001348 .. 0.11190955847512362]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.029179388969001349]
# f(I) = [1.3150274758011448e-7 .. 0.14208442829549318]
# t = [0.11290296178372363 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.11290296178372363 .. 10.000000000000000], fprime(t) = [-1.1987999370321632 .. -0.000056090764701366424]
# returning res = None
# I  = [0.17968750000000000 .. 0.18750000000000000]
# C || f(I) = [1.2290291167795657 .. 1.3355312747880817]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.021736003857770608 .. 10.000000000000000]
# b = -1.?
# t = [0.023727998125663195 .. 10.000000000000000]
# b = -1.?
# t = [0.023888995561976683 .. 10.000000000000000]
# b = -1.?
# t = [0.023901847765513444 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.023902872801063308 .. 0.10760024406394757]
# b = -2.?
# t = [0.023902872801063308 .. 0.10705503714529444]
# b = -2.?
# t = [0.023902872801063308 .. 0.10701139823983326]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.023902872801063309]
# f(I) = [1.0728836064011204e-7 .. 0.13553127758204942]
# t = [0.10800791660070022 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10800791660070022 .. 10.000000000000000], fprime(t) = [-1.1988002592697740 .. -0.000055796466767787933]
# returning res = None
# I  = [0.18750000000000000 .. 0.25000000000000000]
# C || f(I) = [1.1788007808849214 .. 1.3290291186422110]
# h  = t |--> e^(-t + 0.2?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.10222608922139355]
# b = -2.?
# t = [0.00000000000000000 .. 0.10213674531899202]
# b = -2.?
# found upper bound!
# t = [0.10312806661989951 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10312806661989951 .. 10.000000000000000], fprime(t) = [-1.1987994993105531 .. -0.000053514726459980010]
# bisecting [0.18750000000000000 .. 0.25000000000000000] -> [0.18750000000000000 .. 0.21875000000000000], [0.21875000000000000 .. 0.25000000000000000]
# I  = [0.18750000000000000 .. 0.21875000000000000]
# C || f(I) = [1.2035225719213484 .. 1.3290291186422110]
# h  = t |--> e^(-t + 0.2?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.0026504825832253621 .. 10.000000000000000]
# b = -1.?
# t = [0.0029046315070096469 .. 10.000000000000000]
# b = -1.?
# t = [0.0029286664467977011 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.0029309373643667362 .. 0.10315910208167980]
# b = -2.?
# t = [0.0029309373643667362 .. 0.10222506997583602]
# b = -2.?
# t = [0.0029309373643667362 .. 0.10213638732154331]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.0029309373643667363]
# f(I) = [2.8423964981705296e-7 .. 0.12902912050485616]
# t = [0.10312800784707770 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10312800784707770 .. 10.000000000000000], fprime(t) = [-1.1987995719537139 .. -0.000054637901484966278]
# bisecting [0.18750000000000000 .. 0.21875000000000000] -> [0.18750000000000000 .. 0.20312500000000000], [0.20312500000000000 .. 0.21875000000000000]
# I  = [0.18750000000000000 .. 0.20312500000000000]
# C || f(I) = [1.2161762114614247 .. 1.3290291186422110]
# h  = t |--> e^(-t + 0.2?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.012171447260539536 .. 10.000000000000000]
# b = -1.?
# t = [0.013285962944211035 .. 10.000000000000000]
# b = -1.?
# t = [0.013381274118825642 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.013389372603794597 .. 0.10266671454498311]
# b = -2.?
# t = [0.013389372603794597 .. 0.10217308532437139]
# b = -2.?
# t = [0.013389372603794597 .. 0.10213103666506700]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.013389372603794598]
# f(I) = [9.0263783936173069e-7 .. 0.12902912050485616]
# t = [0.10312746521216112 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10312746521216112 .. 10.000000000000000], fprime(t) = [-1.1988002238795162 .. -0.000055211596190929412]
# bisecting [0.18750000000000000 .. 0.20312500000000000] -> [0.18750000000000000 .. 0.19531250000000000], [0.19531250000000000 .. 0.20312500000000000]
# I  = [0.18750000000000000 .. 0.19531250000000000]
# C || f(I) = [1.2225775603204964 .. 1.3290291186422110]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.016988007452589597 .. 10.000000000000000]
# b = -1.?
# t = [0.018506264454094638 .. 10.000000000000000]
# b = -1.?
# t = [0.018629119144225506 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.018638967963106583 .. 0.10305947010320820]
# b = -2.?
# t = [0.018638967963106583 .. 0.10220221146043350]
# b = -2.?
# t = [0.018638967963106583 .. 0.10213315024882773]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.018638967963106584]
# f(I) = [1.0274350643602048e-6 .. 0.12902912050485616]
# t = [0.10312761523111570 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10312761523111570 .. 10.000000000000000], fprime(t) = [-1.1988000450655818 .. -0.000055502168834209442]
# returning res = None
# I  = [0.19531250000000000 .. 0.20312500000000000]
# C || f(I) = [1.2161762114614247 .. 1.3225775631144643]
# h  = t |--> e^(-t + 0.2?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.012230819809140494 .. 10.000000000000000]
# b = -1.?
# t = [0.013296240943929182 .. 10.000000000000000]
# b = -1.?
# t = [0.013382567144116151 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.013389516187703462 .. 0.098271162811805202]
# b = -2.?
# t = [0.013389516187703462 .. 0.097342714961445823]
# b = -2.?
# t = [0.013389516187703462 .. 0.097267555548502860]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.013389516187703463]
# f(I) = [7.2941184048325169e-7 .. 0.12257756404578691]
# t = [0.098261505958970984 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.098261505958970984 .. 10.000000000000000], fprime(t) = [-1.1987999817356468 .. -0.000055211596190929412]
# returning res = False
# I  = [0.20312500000000000 .. 0.21875000000000000]
# C || f(I) = [1.2035225719213484 .. 1.3161762133240700]
# h  = t |--> e^(-t + 0.2?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.0026763654179646767 .. 10.000000000000000]
# b = -1.?
# t = [0.0029093341332983042 .. 10.000000000000000]
# b = -1.?
# t = [0.0029293047834426997 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.0029310145275578177 .. 0.092442070221470899]
# b = -2.?
# t = [0.0029310145275578177 .. 0.092411985145146203]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.0029310145275578178]
# f(I) = [1.9110739235550511e-7 .. 0.11617621518671518]
# t = [0.093409409879417926 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.093409409879417926 .. 10.000000000000000], fprime(t) = [-1.1988003207370639 .. -0.000054637901484966278]
# returning res = False
# I  = [0.21875000000000000 .. 0.25000000000000000]
# C || f(I) = [1.1788007808849214 .. 1.3035225747153163]
# h  = t |--> e^(-t + 0.2?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.082894013557463093]
# b = -2.?
# t = [0.00000000000000000 .. 0.082760266377790909]
# b = -2.?
# t = [0.00000000000000000 .. 0.082749634551992566]
# b = -2.?
# found upper bound!
# t = [0.083748789481596239 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.083748789481596239 .. 10.000000000000000], fprime(t) = [-1.1988005368039012 .. -0.000053514726459980010]
# returning res = False
# I  = [0.25000000000000000 .. 0.50000000000000000]
# C || f(I) = [1.0065306579694150 .. 1.2788007836788893]
# h  = t |--> e^(-t + 1.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.063891780303481194]
# b = -1.?
# t = [0.00000000000000000 .. 0.063619141540639482]
# b = -1.?
# t = [0.00000000000000000 .. 0.063602301712363072]
# b = -1.?
# found upper bound!
# t = [0.064601264061761615 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.064601264061761615 .. 10.000000000000000], fprime(t) = [-1.1988005368039012 .. -0.000045695342123508453]
# returning res = False
# I  = [0.50000000000000000 .. 1.0000000000000000]
# C || f(I) = [0.76787943867966534 .. 1.1065306612290442]
# h  = t |--> e^(-t + 0.?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.00000000000000000 .. 10.000000000000000], fprime(t) = [-1.1065306821838022 .. -0.000034860335290431976]
# returning res = False
# I  = [0.00000000000000000 .. 1.0000000000000000]
# C || f(I) = [0.86787943821400403 .. 1.6000000046566130]
# h  = t |--> e^(-t + 0.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.29054522588902532]
# b = -1.?
# t = [0.00000000000000000 .. 0.28840093611344648]
# b = -1.?
# t = [0.00000000000000000 .. 0.28786198567908217]
# b = -1.?
# t = [0.00000000000000000 .. 0.28772706742301630]
# b = -1.?
# t = [0.00000000000000000 .. 0.28769332514064567]
# b = -1.?
# found upper bound!
# t = [0.28868488922080709 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.28868488922080709 .. 10.000000000000000], fprime(t) = [-1.1987972492352129 .. -0.000039399601519107818]
# bisecting [0.00000000000000000 .. 1.0000000000000000] -> [0.00000000000000000 .. 0.50000000000000000], [0.50000000000000000 .. 1.0000000000000000]
# I  = [0.00000000000000000 .. 0.50000000000000000]
# C || f(I) = [1.1065306561067700 .. 1.6000000027939679]
# h  = t |--> e^(-t + 1.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.29054522588902532]
# b = -1.?
# t = [0.00000000000000000 .. 0.28840093436596854]
# b = -1.?
# t = [0.00000000000000000 .. 0.28786198509513001]
# b = -1.?
# t = [0.00000000000000000 .. 0.28772706567475387]
# b = -1.?
# t = [0.00000000000000000 .. 0.28769332397442055]
# b = -1.?
# found upper bound!
# t = [0.28868488805457215 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.28868488805457215 .. 10.000000000000000], fprime(t) = [-1.1987972492352129 .. -0.000050234608352184295]
# bisecting [0.00000000000000000 .. 0.50000000000000000] -> [0.00000000000000000 .. 0.25000000000000000], [0.25000000000000000 .. 0.50000000000000000]
# I  = [0.00000000000000000 .. 0.25000000000000000]
# C || f(I) = [1.2788007790222764 .. 1.6000000027939679]
# h  = t |--> e^(-t + 1.?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.049250483273317893 .. 10.000000000000000]
# b = -1.?
# t = [0.060638382210424272 .. 10.000000000000000]
# b = -1.?
# t = [0.063002901647810818 .. 10.000000000000000]
# b = -1.?
# t = [0.063480938322452148 .. 10.000000000000000]
# b = -1.?
# t = [0.063577041754954488 .. 10.000000000000000]
# b = -1.?
# t = [0.063596339566535528 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.063600214685944511 .. 0.28935932058231656]
# b = -1.?
# t = [0.063600214685944511 .. 0.28801990632814706]
# b = -1.?
# t = [0.063600214685944511 .. 0.28774994098348739]
# b = -1.?
# t = [0.063600214685944511 .. 0.28769570212708357]
# b = -1.?
# t = [0.063600214685944511 .. 0.28768481103409200]
# b = -1.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.063600214685944512]
# f(I) = [1.1671334505525265e-6 .. 0.40000000521540647]
# t = [0.28868262522303028 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.28868262522303028 .. 10.000000000000000], fprime(t) = [-1.1987999556586147 .. -0.000058055855333805084]
# bisecting [0.00000000000000000 .. 0.25000000000000000] -> [0.00000000000000000 .. 0.12500000000000000], [0.12500000000000000 .. 0.25000000000000000]
# I  = [0.00000000000000000 .. 0.12500000000000000]
# C || f(I) = [1.3824969008564949 .. 1.6000000018626453]
# h  = t |--> e^(-t + 0.4?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.11406055814427236 .. 10.000000000000000]
# b = -1.?
# t = [0.13750612026953215 .. 10.000000000000000]
# b = -1.?
# t = [0.14101013492923669 .. 10.000000000000000]
# b = -1.?
# t = [0.14149345714329475 .. 10.000000000000000]
# b = -1.?
# t = [0.14155929236517053 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.14156824423581945 .. 0.28816841519894604]
# b = -2.?
# t = [0.14156824423581945 .. 0.28774829018694826]
# b = -2.?
# t = [0.14156824423581945 .. 0.28769107822637414]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.14156824423581946]
# f(I) = [1.6905367374864255e-6 .. 0.40000000521540647]
# t = [0.28868329874951637 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.28868329874951637 .. 10.000000000000000], fprime(t) = [-1.1987991509959102 .. -0.000062762759625911712]
# returning res = True
# I  = [0.12500000000000000 .. 0.25000000000000000]
# C || f(I) = [1.2788007808849215 .. 1.4824969036504628]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.053154090688467686 .. 10.000000000000000]
# b = -1.?
# t = [0.062118840753825912 .. 10.000000000000000]
# b = -1.?
# t = [0.063396565823619133 .. 10.000000000000000]
# b = -1.?
# t = [0.063573055079692825 .. 10.000000000000000]
# b = -1.?
# t = [0.063597323311893994 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.063600658038791765 .. 0.21210287848808432]
# b = -2.?
# t = [0.063600658038791765 .. 0.21150214040554836]
# b = -2.?
# t = [0.063600658038791765 .. 0.21141939268130797]
# b = -2.?
# t = [0.063600658038791765 .. 0.21140801927765069]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.063600658038791766]
# f(I) = [6.3814222817093479e-7 .. 0.28249690607190137]
# t = [0.21240645621122702 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.21240645621122702 .. 10.000000000000000], fprime(t) = [-1.1988003207370639 .. -0.000058055855333805084]
# bisecting [0.12500000000000000 .. 0.25000000000000000] -> [0.12500000000000000 .. 0.18750000000000000], [0.18750000000000000 .. 0.25000000000000000]
# I  = [0.12500000000000000 .. 0.18750000000000000]
# C || f(I) = [1.3290291167795658 .. 1.4824969036504628]
# h  = t |--> e^(-t + 0.3?)
# ...
# t = [0.044456496411057533 .. 10.000000000000000]
# b = -1.?
# t = [0.048999088861608891 .. 10.000000000000000]
# b = -1.?
# t = [0.049362442020011068 .. 10.000000000000000]
# b = -1.?
# t = [0.049390683959216793 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.049392874122267151 .. 0.13115421824987595]
# b = -2.?
# t = [0.049392874122267151 .. 0.13017946696516053]
# b = -2.?
# t = [0.049392874122267151 .. 0.13010337896343019]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.049392874122267152]
# f(I) = [2.2090971474320042e-7 .. 0.16672659963369374]
# t = [0.13109747627770393 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.13109747627770393 .. 10.000000000000000], fprime(t) = [-1.1988000264391304 .. -0.000057236291468143463]
# returning res = None
# I  = [0.27343750000000000 .. 0.28125000000000000]
# C || f(I) = [1.2548396000638604 .. 1.3607598835602404]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.040300714877316040 .. 10.000000000000000]
# b = -1.?
# t = [0.044335980288523153 .. 10.000000000000000]
# b = -1.?
# t = [0.044658879458623915 .. 10.000000000000000]
# b = -1.?
# t = [0.044684069091983247 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.044686030940152665 .. 0.12659751285125221]
# b = -2.?
# t = [0.044686030940152665 .. 0.12579025009730735]
# b = -2.?
# t = [0.044686030940152665 .. 0.12572706260171318]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.044686030940152666]
# f(I) = [1.9855797295242894e-7 .. 0.16075988411903386]
# t = [0.12672214093815339 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.12672214093815339 .. 10.000000000000000], fprime(t) = [-1.1988001251593233 .. -0.000056968070566654205]
# returning res = None
# I  = [0.28125000000000000 .. 0.31250000000000000]
# C || f(I) = [1.2316156271845102 .. 1.3548396028578283]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.023335325378275227 .. 10.000000000000000]
# b = -1.?
# t = [0.025759195209274225 .. 10.000000000000000]
# b = -1.?
# t = [0.025982858371515916 .. 10.000000000000000]
# b = -1.?
# t = [0.026003228387538955 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.026005080501448583 .. 0.12257564594422088]
# b = -2.?
# t = [0.026005080501448583 .. 0.12147261395866190]
# b = -2.?
# t = [0.026005080501448583 .. 0.12137162742127500]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.026005080501448584]
# f(I) = [2.2277235989243138e-7 .. 0.15483960434794431]
# t = [0.12236243682148495 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.12236243682148495 .. 10.000000000000000], fprime(t) = [-1.1987995179370046 .. -0.000055913813412189483]
# bisecting [0.28125000000000000 .. 0.31250000000000000] -> [0.28125000000000000 .. 0.29687500000000000], [0.29687500000000000 .. 0.31250000000000000]
# I  = [0.28125000000000000 .. 0.29687500000000000]
# C || f(I) = [1.2431368967518210 .. 1.3548396028578283]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.031839114269236468 .. 10.000000000000000]
# b = -1.?
# t = [0.035024149469842592 .. 10.000000000000000]
# b = -1.?
# t = [0.035292248662540159 .. 10.000000000000000]
# b = -1.?
# t = [0.035314391477044175 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.035316216765800816 .. 0.12141369912013338]
# b = -2.?
# t = [0.035316216765800816 .. 0.12136582166220244]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.035316216765800817]
# f(I) = [1.9669532780319798e-7 .. 0.15483960434794431]
# t = [0.12236187170498438 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.12236187170498438 .. 10.000000000000000], fprime(t) = [-1.1988001884892583 .. -0.000056437216699123382]
# bisecting [0.28125000000000000 .. 0.29687500000000000] -> [0.28125000000000000 .. 0.28906250000000000], [0.28906250000000000 .. 0.29687500000000000]
# I  = [0.28125000000000000 .. 0.28906250000000000]
# C || f(I) = [1.2489653918892145 .. 1.3548396028578283]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.036141095447716028 .. 10.000000000000000]
# b = -1.?
# t = [0.039686045825606065 .. 10.000000000000000]
# b = -1.?
# t = [0.039969856943389801 .. 10.000000000000000]
# b = -1.?
# t = [0.039992079251130532 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.039993815796534777 .. 0.12255951803942504]
# b = -2.?
# t = [0.039993815796534777 .. 0.12145579755220260]
# b = -2.?
# t = [0.039993815796534777 .. 0.12136888942671645]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.039993815796534778]
# f(I) = [1.7620623116165745e-7 .. 0.15483960434794431]
# t = [0.12236209347814869 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.12236209347814869 .. 10.000000000000000], fprime(t) = [-1.1987999277189374 .. -0.000056701712310314178]
# returning res = None
# I  = [0.28906250000000000 .. 0.29687500000000000]
# C || f(I) = [1.2431368967518210 .. 1.3489653946831824]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.031977760976827994 .. 10.000000000000000]
# b = -1.?
# t = [0.035049331360089322 .. 10.000000000000000]
# b = -1.?
# t = [0.035295397957917397 .. 10.000000000000000]
# b = -1.?
# t = [0.035314734981389157 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.035316252094374674 .. 0.11754894110595055]
# b = -2.?
# t = [0.035316252094374674 .. 0.11705828118075733]
# b = -2.?
# t = [0.035316252094374674 .. 0.11701965753615100]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.035316252094374675]
# f(I) = [1.5571713452011692e-7 .. 0.14896539710462098]
# t = [0.11801662731072813 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.11801662731072813 .. 10.000000000000000], fprime(t) = [-1.1988003132864833 .. -0.000056437216699123382]
# returning res = None
# I  = [0.29687500000000000 .. 0.31250000000000000]
# C || f(I) = [1.2316156271845102 .. 1.3431368995457889]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.023538645222592479 .. 10.000000000000000]
# b = -1.?
# t = [0.025797673764839004 .. 10.000000000000000]
# b = -1.?
# t = [0.025988010384535700 .. 10.000000000000000]
# b = -1.?
# t = [0.026003832635349576 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.026005147215536157 .. 0.11365592770922044]
# b = -2.?
# t = [0.026005147215536157 .. 0.11276723217476907]
# b = -2.?
# t = [0.026005147215536157 .. 0.11269301522828726]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.026005147215536158]
# f(I) = [1.4267861847550022e-7 .. 0.14313690103590493]
# t = [0.11368685024321825 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.11368685024321825 .. 10.000000000000000], fprime(t) = [-1.1987999463453889 .. -0.000055913813412189483]
# bisecting [0.29687500000000000 .. 0.31250000000000000] -> [0.29687500000000000 .. 0.30468750000000000], [0.30468750000000000 .. 0.31250000000000000]
# I  = [0.29687500000000000 .. 0.30468750000000000]
# C || f(I) = [1.2373537598177790 .. 1.3431368995457889]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.027810833319436022 .. 10.000000000000000]
# b = -1.?
# t = [0.030425875159121477 .. 10.000000000000000]
# b = -1.?
# t = [0.030635525526062083 .. 10.000000000000000]
# b = -1.?
# t = [0.030652060660850213 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.030653364206293155 .. 0.11390543434734067]
# b = -2.?
# t = [0.030653364206293155 .. 0.11278299473074534]
# b = -2.?
# t = [0.030653364206293155 .. 0.11269391223964994]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.030653364206293156]
# f(I) = [1.3336539272934544e-7 .. 0.14313690103590493]
# t = [0.11368689201758959 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.11368689201758959 .. 10.000000000000000], fprime(t) = [-1.1987999016419054 .. -0.000056174583733081817]
# returning res = None
# I  = [0.30468750000000000 .. 0.31250000000000000]
# C || f(I) = [1.2316156271845102 .. 1.3373537626117469]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.023640433669444467 .. 10.000000000000000]
# b = -1.?
# t = [0.025815717065608947 .. 10.000000000000000]
# b = -1.?
# t = [0.025990262808407497 .. 10.000000000000000]
# b = -1.?
# t = [0.026004079372634471 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.026005172350929320 .. 0.10883099896387111]
# b = -2.?
# t = [0.026005172350929320 .. 0.10840774543869277]
# b = -2.?
# t = [0.026005172350929320 .. 0.10837418356324050]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.026005172350929321]
# f(I) = [1.1287629608780491e-7 .. 0.13735376410186296]
# t = [0.10937152987876502 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10937152987876502 .. 10.000000000000000], fprime(t) = [-1.1988003393635154 .. -0.000055913813412189483]
# returning res = None
# I  = [0.31250000000000000 .. 0.37500000000000000]
# C || f(I) = [1.1872892770916223 .. 1.3316156299784781]
# h  = t |--> e^(-t + 0.2?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.10448183361474352]
# b = -2.?
# t = [0.00000000000000000 .. 0.10411205001899131]
# b = -2.?
# t = [0.00000000000000000 .. 0.10407542644746769]
# b = -2.?
# found upper bound!
# t = [0.10507180583008612 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10507180583008612 .. 10.000000000000000], fprime(t) = [-1.1988001437857748 .. -0.000053900294005870819]
# bisecting [0.31250000000000000 .. 0.37500000000000000] -> [0.31250000000000000 .. 0.34375000000000000], [0.34375000000000000 .. 0.37500000000000000]
# I  = [0.31250000000000000 .. 0.34375000000000000]
# C || f(I) = [1.2091061808168888 .. 1.3316156299784781]
# h  = t |--> e^(-t + 0.2?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.0068384425177122239 .. 10.000000000000000]
# b = -1.?
# t = [0.0074932293310476100 .. 10.000000000000000]
# b = -1.?
# t = [0.0075537035255197875 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.0075592700597096398 .. 0.10514527019244479]
# b = -2.?
# t = [0.0075592700597096398 .. 0.10417072889611039]
# b = -2.?
# t = [0.0075592700597096398 .. 0.10408055070812416]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.0075592700597096399]
# f(I) = [6.7539513115555394e-7 .. 0.13161563239991670]
# t = [0.10507225018923450 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10507225018923450 .. 10.000000000000000], fprime(t) = [-1.1987996073439718 .. -0.000054891221225261688]
# bisecting [0.31250000000000000 .. 0.34375000000000000] -> [0.31250000000000000 .. 0.32812500000000000], [0.32812500000000000 .. 0.34375000000000000]
# I  = [0.31250000000000000 .. 0.32812500000000000]
# C || f(I) = [1.2202729778364300 .. 1.3316156299784781]
# h  = t |--> e^(-t + 0.2?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.015224344211227792 .. 10.000000000000000]
# b = -1.?
# t = [0.016624136516534160 .. 10.000000000000000]
# b = -1.?
# t = [0.016742241089660311 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.016752124790852685 .. 0.10436123952384154]
# b = -2.?
# t = [0.016752124790852685 .. 0.10409568101967319]
# b = -2.?
# t = [0.016752124790852685 .. 0.10407343813338315]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.016752124790852686]
# f(I) = [1.0814517736879025e-6 .. 0.13161563239991670]
# t = [0.10507157846684427 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10507157846684427 .. 10.000000000000000], fprime(t) = [-1.1988004101440311 .. -0.000055397860705852508]
# bisecting [0.31250000000000000 .. 0.32812500000000000] -> [0.31250000000000000 .. 0.32031250000000000], [0.32031250000000000 .. 0.32812500000000000]
# I  = [0.31250000000000000 .. 0.32031250000000000]
# C || f(I) = [1.2259221486747264 .. 1.3316156299784781]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.019466686886209602 .. 10.000000000000000]
# b = -1.?
# t = [0.021218895587312339 .. 10.000000000000000]
# b = -1.?
# t = [0.021359630209234044 .. 10.000000000000000]
# b = -1.?
# t = [0.021370811443557850 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.021371699710431953 .. 0.10437119031492291]
# b = -2.?
# t = [0.021371699710431953 .. 0.10409524373103111]
# b = -2.?
# t = [0.021371699710431953 .. 0.10407330083291855]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.021371699710431954]
# f(I) = [9.0524554297033432e-8 .. 0.13161563239991670]
# t = [0.10507155830781611 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10507155830781611 .. 10.000000000000000], fprime(t) = [-1.1988004380837083 .. -0.000055654905736446380]
# returning res = None
# I  = [0.32031250000000000 .. 0.32812500000000000]
# C || f(I) = [1.2202729778364300 .. 1.3259221514686943]
# h  = t |--> e^(-t + 0.2?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.015289717185847243 .. 10.000000000000000]
# b = -1.?
# t = [0.016635444992971794 .. 10.000000000000000]
# b = -1.?
# t = [0.016743651035799732 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.016752280102905737 .. 0.099899541381836918]
# b = -2.?
# t = [0.016752280102905737 .. 0.099795628550778962]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.016752280102905738]
# f(I) = [8.9518725876480687e-7 .. 0.12592215202748780]
# t = [0.10078734254053904 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10078734254053904 .. 10.000000000000000], fprime(t) = [-1.1987997582182289 .. -0.000055397860705852508]
# returning res = False
# I  = [0.32812500000000000 .. 0.34375000000000000]
# C || f(I) = [1.2091061808168888 .. 1.3202729806303979]
# h  = t |--> e^(-t + 0.2?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.0068971925643894448 .. 10.000000000000000]
# b = -1.?
# t = [0.0075038381303340140 .. 10.000000000000000]
# b = -1.?
# t = [0.0075551170448132322 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.0075594364213234198 .. 0.096335732616920855]
# b = -2.?
# t = [0.0075594364213234198 .. 0.095586210504213676]
# b = -2.?
# t = [0.0075594364213234198 .. 0.095522796448676742]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.0075594364213234199]
# f(I) = [4.7609210018784153e-7 .. 0.12027298212051397]
# t = [0.096517453851741305 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.096517453851741305 .. 10.000000000000000], fprime(t) = [-1.1988000357523561 .. -0.000054891221225261688]
# returning res = False
# I  = [0.34375000000000000 .. 0.37500000000000000]
# C || f(I) = [1.1872892770916223 .. 1.3091061836108567]
# h  = t |--> e^(-t + 0.2?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.087632541843019274]
# b = -2.?
# t = [0.00000000000000000 .. 0.087074013594536274]
# b = -2.?
# t = [0.00000000000000000 .. 0.087027295584538006]
# b = -2.?
# found upper bound!
# t = [0.088023400709633395 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.088023400709633395 .. 10.000000000000000], fprime(t) = [-1.1988001884892583 .. -0.000053900294005870819]
# returning res = False
# I  = [0.37500000000000000 .. 0.50000000000000000]
# C || f(I) = [1.1065306579694151 .. 1.2872892798855902]
# h  = t |--> e^(-t + 0.2?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.070814351890345573]
# b = -2.?
# t = [0.00000000000000000 .. 0.070257782866652214]
# b = -2.?
# t = [0.00000000000000000 .. 0.070219876499603956]
# b = -2.?
# found upper bound!
# t = [0.071217304688019955 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.071217304688019955 .. 10.000000000000000], fprime(t) = [-1.1988003933802248 .. -0.000050234608352184295]
# returning res = False
# I  = [0.50000000000000000 .. 1.0000000000000000]
# C || f(I) = [0.86787943867966532 .. 1.2065306612290443]
# h  = t |--> e^(-t + 0.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.0054931757151547214]
# b = -1.?
# t = [0.00000000000000000 .. 0.0054278220749665024]
# b = -1.?
# found upper bound!
# t = [0.0064274656109510937 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.0064274656109510937 .. 10.000000000000000], fprime(t) = [-1.1988006168976427 .. -0.000039399601519107818]
# returning res = False

# %%
csig1.plot(aspect_ratio=ar).show()
csig2.plot(aspect_ratio=ar).show()
csig.plot(aspect_ratio=ar).show()
# Out:
# Graphics object consisting of 2 graphics primitives
# Graphics object consisting of 2 graphics primitives
# Graphics object consisting of 2 graphics primitives

# %%
step = 0.005
csig = reduce(Signal.__and__,
              (C(RIF(0,1),
                 (lambda x: x + RIF(0.4 + step*k, 0.4 + step*(k+1))),
                 (lambda f: to_signal((lambda t: f(t) - 1.2),
                                      f.derivative(),
                                      RIF(0,10)).F(RIF(0.1,0.2))(0)),
                 y, g, 0.01)
               for k in range(round(0.2/step))))
# Out:
# I  = [0.00000000000000000 .. 1.0000000000000000]
# C || f(I) = [0.76787943821400406 .. 1.4050000046566129]
# h  = t |--> e^(-t + 0.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.15876024774620956]
# b = -1.?
# t = [0.00000000000000000 .. 0.15786861754804122]
# b = -1.?
# t = [0.00000000000000000 .. 0.15773806547957062]
# b = -1.?
# t = [0.00000000000000000 .. 0.15771900829977798]
# b = -1.?
# found upper bound!
# t = [0.15871622705904353 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.15871622705904353 .. 10.000000000000000], fprime(t) = [-1.1988000543788076 .. -0.000034860335290431976]
# bisecting [0.00000000000000000 .. 1.0000000000000000] -> [0.00000000000000000 .. 0.50000000000000000], [0.50000000000000000 .. 1.0000000000000000]
# I  = [0.00000000000000000 .. 0.50000000000000000]
# C || f(I) = [1.0065306561067699 .. 1.4050000027939678]
# h  = t |--> e^(-t + 1.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.15876024774620956]
# b = -1.?
# t = [0.00000000000000000 .. 0.15786861622113308]
# b = -1.?
# t = [0.00000000000000000 .. 0.15773806348936676]
# b = -1.?
# t = [0.00000000000000000 .. 0.15771900564667319]
# b = -1.?
# found upper bound!
# t = [0.15871622440593138 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.15871622440593138 .. 10.000000000000000], fprime(t) = [-1.1988000450655818 .. -0.000045695342123508453]
# bisecting [0.00000000000000000 .. 0.50000000000000000] -> [0.00000000000000000 .. 0.25000000000000000], [0.25000000000000000 .. 0.50000000000000000]
# I  = [0.00000000000000000 .. 0.25000000000000000]
# C || f(I) = [1.1788007790222763 .. 1.4050000027939678]
# h  = t |--> e^(-t + 1.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.15876024774620956]
# b = -2.?
# t = [0.00000000000000000 .. 0.15786861555767901]
# b = -2.?
# t = [0.00000000000000000 .. 0.15773806282591269]
# b = -2.?
# t = [0.00000000000000000 .. 0.15771900498321912]
# b = -2.?
# found upper bound!
# t = [0.15871622440533850 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.15871622440533850 .. 10.000000000000000], fprime(t) = [-1.1988000450655818 .. -0.000053514726459980010]
# bisecting [0.00000000000000000 .. 0.25000000000000000] -> [0.00000000000000000 .. 0.12500000000000000], [0.12500000000000000 .. 0.25000000000000000]
# I  = [0.00000000000000000 .. 0.12500000000000000]
# C || f(I) = [1.2824969008564948 .. 1.4050000018626452]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.058716652160406369 .. 10.000000000000000]
# b = -1.?
# t = [0.065782303381953385 .. 10.000000000000000]
# b = -1.?
# t = [0.066425623559626612 .. 10.000000000000000]
# b = -1.?
# t = [0.066481941370360966 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.066486853052618935 .. 0.15787086245251412]
# b = -2.?
# t = [0.066486853052618935 .. 0.15772928441872878]
# b = -2.?
# t = [0.066486853052618935 .. 0.15771692878345398]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.066486853052618936]
# f(I) = [5.6177377705246556e-7 .. 0.20500000305473809]
# t = [0.15871585139880847 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.15871585139880847 .. 10.000000000000000], fprime(t) = [-1.1988004995509983 .. -0.000058223493397235870]
# bisecting [0.00000000000000000 .. 0.12500000000000000] -> [0.00000000000000000 .. 0.062500000000000000], [0.062500000000000000 .. 0.12500000000000000]
# I  = [0.00000000000000000 .. 0.062500000000000000]
# C || f(I) = [1.3394130613654851 .. 1.4050000018626452]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.099226374344334442 .. 10.000000000000000]
# b = -1.?
# t = [0.10935701149354758 .. 10.000000000000000]
# b = -1.?
# t = [0.10988398685246714 .. 10.000000000000000]
# b = -1.?
# t = [0.10990873288474332 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.10990988797280895 .. 0.15818284928483254]
# b = -1.2?
# t = [0.10990988797280895 .. 0.15773765686976055]
# b = -1.2?
# t = [0.10990988797280895 .. 0.15771677114840791]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.10990988797280896]
# f(I) = [6.8172812506261948e-8 .. 0.20500000305473809]
# t = [0.15871579688390230 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.15871579688390230 .. 10.000000000000000], fprime(t) = [-1.1988005628809333 .. -0.000060806982219219207]
# returning res = True
# I  = [0.062500000000000000 .. 0.12500000000000000]
# C || f(I) = [1.2824969008564948 .. 1.3444130632281304]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.061362759897455543 .. 10.000000000000000]
# b = -1.?
# t = [0.066238808431597337 .. 10.000000000000000]
# b = -1.?
# t = [0.066475847475770302 .. 10.000000000000000]
# b = -1.?
# t = [0.066486793709027075 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.066487298041443571 .. 0.11454796467902391]
# b = -1.2?
# t = [0.066487298041443571 .. 0.11367837519845247]
# b = -1.2?
# t = [0.066487298041443571 .. 0.11363793174497457]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.066487298041443572]
# f(I) = [2.9057264372411850e-8 .. 0.14441306442022329]
# t = [0.11463606840896163 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.11463606840896163 .. 10.000000000000000], fprime(t) = [-1.1988005088642240 .. -0.000058223493397235870]
# bisecting [0.062500000000000000 .. 0.12500000000000000] -> [0.062500000000000000 .. 0.093750000000000000], [0.093750000000000000 .. 0.12500000000000000]
# I  = [0.062500000000000000 .. 0.093750000000000000]
# C || f(I) = [1.3105103593319653 .. 1.3444130632281304]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.082199703168270757 .. 10.000000000000000]
# b = -1.?
# t = [0.087929516702665452 .. 10.000000000000000]
# b = -1.?
# t = [0.088090901272523447 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.088094982890370210 .. 0.11455459862304795]
# b = -1.2?
# t = [0.088094982890370210 .. 0.11365955408237720]
# b = -1.2?
# t = [0.088094982890370210 .. 0.11363657309984992]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.088094982890370211]
# f(I) = [1.2777745728165257e-7 .. 0.14441306442022329]
# t = [0.11463599299209002 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.11463599299209002 .. 10.000000000000000], fprime(t) = [-1.1988005982711912 .. -0.000059495680034160614]
# bisecting [0.062500000000000000 .. 0.093750000000000000] -> [0.062500000000000000 .. 0.078125000000000000], [0.078125000000000000 .. 0.093750000000000000]
# I  = [0.062500000000000000 .. 0.078125000000000000]
# C || f(I) = [1.3248488117009400 .. 1.3444130632281304]
# h  = t |--> e^(-t + 0.29?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.092864915917668502 .. 10.000000000000000]
# b = -1.?
# t = [0.098869478901753973 .. 10.000000000000000]
# b = -1.?
# t = [0.098975221545198083 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.098976765843275651 .. 0.11402572492958383]
# b = -1.2?
# t = [0.098976765843275651 .. 0.11364172488660778]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.098976765843275652]
# f(I) = [2.7194619223180893e-8 .. 0.14441306442022329]
# t = [0.11463606163571528 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.11463606163571528 .. 10.000000000000000], fprime(t) = [-1.1988005181774498 .. -0.000060145743191242218]
# bisecting [0.062500000000000000 .. 0.078125000000000000] -> [0.062500000000000000 .. 0.070312500000000000], [0.070312500000000000 .. 0.078125000000000000]
# I  = [0.062500000000000000 .. 0.070312500000000000]
# C || f(I) = [1.3321024911478160 .. 1.3444130632281304]
# h  = t |--> e^(-t + 0.29?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.098260341211088078 .. 10.000000000000000]
# b = -1.?
# t = [0.10436153483632688 .. 10.000000000000000]
# b = -1.?
# t = [0.10443626110501628 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.10443694797131078 .. 0.11391881648234547]
# b = -1.2?
# t = [0.10443694797131078 .. 0.11363860775045303]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.10443694797131079]
# f(I) = [8.5681677308713233e-9 .. 0.14441306442022329]
# t = [0.11463600177851740 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.11463600177851740 .. 10.000000000000000], fprime(t) = [-1.1988005889579654 .. -0.000060475431382656097]
# returning res = True
# I  = [0.070312500000000000 .. 0.078125000000000000]
# C || f(I) = [1.3248488117009400 .. 1.3371024930104614]
# h  = t |--> e^(-t + 0.29?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.093372652285415941 .. 10.000000000000000]
# b = -1.?
# t = [0.098909900944429779 .. 10.000000000000000]
# b = -1.?
# t = [0.098976173577058609 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.098976783539276719 .. 0.10918630322141829]
# b = -1.2?
# t = [0.098976783539276719 .. 0.10819308786034781]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.098976783539276720]
# f(I) = [6.7055225816403662e-9 .. 0.13710249513387685]
# t = [0.10918348717819371 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10918348717819371 .. 10.000000000000000], fprime(t) = [-1.1988005181774498 .. -0.000060145743191242218]
# returning res = None
# I  = [0.078125000000000000 .. 0.093750000000000000]
# C || f(I) = [1.3105103593319653 .. 1.3298488135635854]
# h  = t |--> e^(-t + 0.28?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.083099938573554771 .. 10.000000000000000]
# b = -1.?
# t = [0.088010175678013419 .. 10.000000000000000]
# b = -1.?
# t = [0.088093851087186467 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.088095071120439974 .. 0.10275775469865610]
# b = -1.2?
# t = [0.088095071120439974 .. 0.10274391091407871]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.088095071120439975]
# f(I) = [2.1606683775488022e-8 .. 0.12984881475567823]
# t = [0.10374370839075623 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10374370839075623 .. 10.000000000000000], fprime(t) = [-1.1988006168976427 .. -0.000059495680034160614]
# bisecting [0.078125000000000000 .. 0.093750000000000000] -> [0.078125000000000000 .. 0.085937500000000000], [0.085937500000000000 .. 0.093750000000000000]
# I  = [0.078125000000000000 .. 0.085937500000000000]
# C || f(I) = [1.3176515806466340 .. 1.3298488135635854]
# h  = t |--> e^(-t + 0.28?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.088469887650828873 .. 10.000000000000000]
# b = -1.?
# t = [0.093470420441697357 .. 10.000000000000000]
# b = -1.?
# t = [0.093528943727039820 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.093529482938188107 .. 0.10322867077812301]
# b = -1.2?
# t = [0.093529482938188107 .. 0.10274827059525563]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.093529482938188108]
# f(I) = [4.8428774324094092e-9 .. 0.12984881475567823]
# t = [0.10374374835524796 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10374374835524796 .. 10.000000000000000], fprime(t) = [-1.1988005721941591 .. -0.000059819780290126800]
# returning res = None
# I  = [0.085937500000000000 .. 0.093750000000000000]
# C || f(I) = [1.3105103593319653 .. 1.3226515834406019]
# h  = t |--> e^(-t + 0.28?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.083552128295750371 .. 10.000000000000000]
# b = -1.?
# t = [0.088043178324099538 .. 10.000000000000000]
# b = -1.?
# t = [0.088094611972614922 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.088095085047614055 .. 0.098358001337688101]
# b = -1.2?
# t = [0.088095085047614055 .. 0.097327033533224334]
# b = -1.2?
# t = [0.088095085047614055 .. 0.097317033128880390]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.088095085047614056]
# f(I) = [4.8428774324094092e-9 .. 0.12265158556401735]
# t = [0.098316941774300892 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.098316941774300892 .. 10.000000000000000], fprime(t) = [-1.1988006168976427 .. -0.000059495680034160614]
# returning res = False
# I  = [0.093750000000000000 .. 0.12500000000000000]
# C || f(I) = [1.2824969008564948 .. 1.3155103621259332]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.062710943614892197 .. 10.000000000000000]
# b = -1.?
# t = [0.066385608420654940 .. 10.000000000000000]
# b = -1.?
# t = [0.066484764083440839 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.066487257309139249 .. 0.092072541387041213]
# b = -1.2?
# t = [0.066487257309139249 .. 0.091907407292572352]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.066487257309139250]
# f(I) = [7.7486038252416733e-8 .. 0.11551036424934869]
# t = [0.092903249787434791 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.092903249787434791 .. 10.000000000000000], fprime(t) = [-1.1988004921004177 .. -0.000058223493397235870]
# returning res = False
# I  = [0.12500000000000000 .. 0.25000000000000000]
# C || f(I) = [1.1788007808849214 .. 1.2874969036504627]
# h  = t |--> e^(-t + 0.2?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.070814351890345573]
# b = -2.?
# t = [0.00000000000000000 .. 0.070408108513330917]
# b = -2.?
# t = [0.00000000000000000 .. 0.070380413408985557]
# b = -2.?
# found upper bound!
# t = [0.071378530649977525 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.071378530649977525 .. 10.000000000000000], fprime(t) = [-1.1988004548475147 .. -0.000053514726459980010]
# returning res = False
# I  = [0.25000000000000000 .. 0.50000000000000000]
# C || f(I) = [1.0065306579694150 .. 1.1838007836788894]
# h  = t |--> e^(-t + 0.1?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.00000000000000000 .. 10.000000000000000], fprime(t) = [-1.1838008044287563 .. -0.000045695342123508453]
# returning res = False
# I  = [0.50000000000000000 .. 1.0000000000000000]
# C || f(I) = [0.76787943867966534 .. 1.0115306612290443]
# h  = t |--> e^(-t + 0.?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.00000000000000000 .. 10.000000000000000], fprime(t) = [-1.0115306740626693 .. -0.000034860335290431976]
# returning res = False
# I  = [0.00000000000000000 .. 1.0000000000000000]
# C || f(I) = [0.77287943821400406 .. 1.4100000046566131]
# h  = t |--> e^(-t + 0.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.16215232872590835]
# b = -1.?
# t = [0.00000000000000000 .. 0.16140017161490334]
# b = -1.?
# t = [0.00000000000000000 .. 0.16128782386153942]
# b = -1.?
# t = [0.00000000000000000 .. 0.16127108330532536]
# b = -1.?
# found upper bound!
# t = [0.16226859066340285 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.16226859066340285 .. 10.000000000000000], fprime(t) = [-1.1988000990822912 .. -0.000035087577998638153]
# bisecting [0.00000000000000000 .. 1.0000000000000000] -> [0.00000000000000000 .. 0.50000000000000000], [0.50000000000000000 .. 1.0000000000000000]
# I  = [0.00000000000000000 .. 0.50000000000000000]
# C || f(I) = [1.0115306561067700 .. 1.4100000027939679]
# h  = t |--> e^(-t + 1.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.16215232872590835]
# b = -1.?
# t = [0.00000000000000000 .. 0.16140017029288481]
# b = -1.?
# t = [0.00000000000000000 .. 0.16128782121842178]
# b = -1.?
# t = [0.00000000000000000 .. 0.16127108066216348]
# b = -1.?
# found upper bound!
# t = [0.16226858735972024 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.16226858735972024 .. 10.000000000000000], fprime(t) = [-1.1988000990822912 .. -0.000045920722186565399]
# bisecting [0.00000000000000000 .. 0.50000000000000000] -> [0.00000000000000000 .. 0.25000000000000000], [0.25000000000000000 .. 0.50000000000000000]
# I  = [0.00000000000000000 .. 0.25000000000000000]
# C || f(I) = [1.1838007790222764 .. 1.4100000027939679]
# h  = t |--> e^(-t + 1.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.16215232872590835]
# b = -2.?
# t = [0.00000000000000000 .. 0.16140016963088192]
# b = -2.?
# t = [0.00000000000000000 .. 0.16128781989568378]
# b = -2.?
# t = [0.00000000000000000 .. 0.16127108066045040]
# b = -2.?
# found upper bound!
# t = [0.16226858735800717 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.16226858735800717 .. 10.000000000000000], fprime(t) = [-1.1988000990822912 .. -0.000053741969168186187]
# bisecting [0.00000000000000000 .. 0.25000000000000000] -> [0.00000000000000000 .. 0.12500000000000000], [0.12500000000000000 .. 0.25000000000000000]
# I  = [0.00000000000000000 .. 0.12500000000000000]
# C || f(I) = [1.2874969008564949 .. 1.4100000018626453]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.062054535219736930 .. 10.000000000000000]
# b = -1.?
# t = [0.069623651387151291 .. 10.000000000000000]
# b = -1.?
# t = [0.070312554812973798 .. 10.000000000000000]
# b = -1.?
# t = [0.070372665611497131 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.070377889352857103 .. 0.16293479328315938]
# b = -2.?
# t = [0.070377889352857103 .. 0.16141421906840578]
# b = -2.?
# t = [0.070377889352857103 .. 0.16128085053841424]
# b = -2.?
# t = [0.070377889352857103 .. 0.16126925325028727]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.070377889352857104]
# f(I) = [5.9716403488785374e-7 .. 0.21000000387430196]
# t = [0.16226824636801739 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.16226824636801739 .. 10.000000000000000], fprime(t) = [-1.1988004995509983 .. -0.000058450736105442047]
# bisecting [0.00000000000000000 .. 0.12500000000000000] -> [0.00000000000000000 .. 0.062500000000000000], [0.062500000000000000 .. 0.12500000000000000]
# I  = [0.00000000000000000 .. 0.062500000000000000]
# C || f(I) = [1.3444130613654852 .. 1.4100000018626453]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.10242060699293661 .. 10.000000000000000]
# b = -1.?
# t = [0.11305454076366544 .. 10.000000000000000]
# b = -1.?
# t = [0.11360876593217127 .. 10.000000000000000]
# b = -1.?
# t = [0.11363470760015248 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.11363591468875666 .. 0.16169196891730079]
# b = -1.2?
# t = [0.11363591468875666 .. 0.16128794983008094]
# b = -1.2?
# t = [0.11363591468875666 .. 0.16126907032559390]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.11363591468875667]
# f(I) = [7.0035457655492905e-8 .. 0.21000000387430196]
# t = [0.16226819209208270 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.16226819209208270 .. 10.000000000000000], fprime(t) = [-1.1988005721941591 .. -0.000061034224927425384]
# returning res = True
# I  = [0.062500000000000000 .. 0.12500000000000000]
# C || f(I) = [1.2874969008564949 .. 1.3494130632281305]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.064840705612806387 .. 10.000000000000000]
# b = -1.?
# t = [0.070109694864692109 .. 10.000000000000000]
# b = -1.?
# t = [0.070366023581278136 .. 10.000000000000000]
# b = -1.?
# t = [0.070377818874862871 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.070378360322037258 .. 0.11830503821044059]
# b = -1.2?
# t = [0.070378360322037258 .. 0.11739251497455382]
# b = -1.2?
# t = [0.070378360322037258 .. 0.11735021009543083]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.070378360322037259]
# f(I) = [3.2782554670873764e-8 .. 0.14941306523978715]
# t = [0.11834826793398793 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.11834826793398793 .. 10.000000000000000], fprime(t) = [-1.1988004995509983 .. -0.000058450736105442047]
# bisecting [0.062500000000000000 .. 0.12500000000000000] -> [0.062500000000000000 .. 0.093750000000000000], [0.093750000000000000 .. 0.12500000000000000]
# I  = [0.062500000000000000 .. 0.093750000000000000]
# C || f(I) = [1.3155103593319654 .. 1.3494130632281305]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.085600440959778478 .. 10.000000000000000]
# b = -1.?
# t = [0.091725464903277112 .. 10.000000000000000]
# b = -1.?
# t = [0.091898657851647483 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.091903024341130207 .. 0.11810871365952837]
# b = -1.2?
# t = [0.091903024341130207 .. 0.11736756419387219]
# b = -1.2?
# t = [0.091903024341130207 .. 0.11734866212649505]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.091903024341130208]
# f(I) = [1.3522803787857640e-7 .. 0.14941306523978715]
# t = [0.11834818637437896 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.11834818637437896 .. 10.000000000000000], fprime(t) = [-1.1988005982711912 .. -0.000059722922742366790]
# bisecting [0.062500000000000000 .. 0.093750000000000000] -> [0.062500000000000000 .. 0.078125000000000000], [0.078125000000000000 .. 0.093750000000000000]
# I  = [0.062500000000000000 .. 0.078125000000000000]
# C || f(I) = [1.3298488117009401 .. 1.3494130632281305]
# h  = t |--> e^(-t + 0.29?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.096226137725986121 .. 10.000000000000000]
# b = -1.?
# t = [0.10262832152968445 .. 10.000000000000000]
# b = -1.?
# t = [0.10274202109800702 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.10274367714830294 .. 0.11831282137382357]
# b = -1.2?
# t = [0.10274367714830294 .. 0.11736261862954574]
# b = -1.2?
# t = [0.10274367714830294 .. 0.11734838416046762]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.10274367714830295]
# f(I) = [2.9057264372411850e-8 .. 0.14941306523978715]
# t = [0.11834817703910659 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.11834817703910659 .. 10.000000000000000], fprime(t) = [-1.1988006168976427 .. -0.000060372985899448394]
# returning res = True
# I  = [0.078125000000000000 .. 0.093750000000000000]
# C || f(I) = [1.3155103593319654 .. 1.3348488135635855]
# h  = t |--> e^(-t + 0.28?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.086534408671261012 .. 10.000000000000000]
# b = -1.?
# t = [0.091811181363231353 .. 10.000000000000000]
# b = -1.?
# t = [0.091901800495363492 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.091903116967964590 .. 0.10713500520321228]
# b = -1.2?
# t = [0.091903116967964590 .. 0.10650593299550560]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.091903116967964591]
# f(I) = [2.3469328924718979e-8 .. 0.13484881557524209]
# t = [0.10749661793747156 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10749661793747156 .. 10.000000000000000], fprime(t) = [-1.1988004548475147 .. -0.000059722922742366790]
# bisecting [0.078125000000000000 .. 0.093750000000000000] -> [0.078125000000000000 .. 0.085937500000000000], [0.085937500000000000 .. 0.093750000000000000]
# I  = [0.078125000000000000 .. 0.085937500000000000]
# C || f(I) = [1.3226515806466341 .. 1.3348488135635855]
# h  = t |--> e^(-t + 0.28?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.091884243878651641 .. 10.000000000000000]
# b = -1.?
# t = [0.097252698599635617 .. 10.000000000000000]
# b = -1.?
# t = [0.097316346430376038 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.097316930262777989 .. 0.10737094613809474]
# b = -1.2?
# t = [0.097316930262777989 .. 0.10650485055152619]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.097316930262777990]
# f(I) = [6.7055225816403662e-9 .. 0.13484881557524209]
# t = [0.10749655846537703 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10749655846537703 .. 10.000000000000000], fprime(t) = [-1.1988005274906755 .. -0.000060047022998332977]
# returning res = None
# I  = [0.085937500000000000 .. 0.093750000000000000]
# C || f(I) = [1.3155103593319654 .. 1.3276515834406020]
# h  = t |--> e^(-t + 0.28?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.087003513521946670 .. 10.000000000000000]
# b = -1.?
# t = [0.091846455769609286 .. 10.000000000000000]
# b = -1.?
# t = [0.091902617002860273 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.091903131620580891 .. 0.10144995429384518]
# b = -1.2?
# t = [0.091903131620580891 .. 0.10109345383252850]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.091903131620580892]
# f(I) = [6.7055225816403662e-9 .. 0.12765158452093606]
# t = [0.10209012957870124 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10209012957870124 .. 10.000000000000000], fprime(t) = [-1.1988005815073848 .. -0.000059722922742366790]
# returning res = None
# I  = [0.093750000000000000 .. 0.12500000000000000]
# C || f(I) = [1.2874969008564949 .. 1.3205103621259334]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.066259908176067985 .. 10.000000000000000]
# b = -1.?
# t = [0.070267164470685886 .. 10.000000000000000]
# b = -1.?
# t = [0.070375600414513045 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.070378317864969341 .. 0.096203145329459769]
# b = -1.2?
# t = [0.070378317864969341 .. 0.095709530211381331]
# b = -1.2?
# t = [0.070378317864969341 .. 0.095697063744654393]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.070378317864969342]
# f(I) = [8.3073973700109604e-8 .. 0.12051036320626741]
# t = [0.096696752892654322 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.096696752892654322 .. 10.000000000000000], fprime(t) = [-1.1988006075844169 .. -0.000058450736105442047]
# returning res = False
# I  = [0.12500000000000000 .. 0.25000000000000000]
# C || f(I) = [1.1838007808849215 .. 1.2924969036504628]
# h  = t |--> e^(-t + 0.2?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.074936696029071063]
# b = -2.?
# t = [0.00000000000000000 .. 0.074303421966569389]
# b = -2.?
# t = [0.00000000000000000 .. 0.074257887713467738]
# b = -2.?
# found upper bound!
# t = [0.075254627320061662 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.075254627320061662 .. 10.000000000000000], fprime(t) = [-1.1988003207370639 .. -0.000053741969168186187]
# returning res = False
# I  = [0.25000000000000000 .. 0.50000000000000000]
# C || f(I) = [1.0115306579694152 .. 1.1888007836788895]
# h  = t |--> e^(-t + 0.1?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.00000000000000000 .. 10.000000000000000], fprime(t) = [-1.1888008108362556 .. -0.000045920722186565399]
# returning res = False
# I  = [0.50000000000000000 .. 1.0000000000000000]
# C || f(I) = [0.77287943867966535 .. 1.0165306612290444]
# h  = t |--> e^(-t + 0.?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.00000000000000000 .. 10.000000000000000], fprime(t) = [-1.0165306786075235 .. -0.000035087577998638153]
# returning res = False
# I  = [0.00000000000000000 .. 1.0000000000000000]
# C || f(I) = [0.77787943821400407 .. 1.4150000046566130]
# h  = t |--> e^(-t + 0.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.16561259053329905]
# b = -1.?
# t = [0.00000000000000000 .. 0.16493050910252119]
# b = -1.?
# t = [0.00000000000000000 .. 0.16482660325348048]
# b = -1.?
# t = [0.00000000000000000 .. 0.16481080973398352]
# b = -1.?
# found upper bound!
# t = [0.16580840948864830 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.16580840948864830 .. 10.000000000000000], fprime(t) = [-1.1988000990822912 .. -0.000035312958061695098]
# bisecting [0.00000000000000000 .. 1.0000000000000000] -> [0.00000000000000000 .. 0.50000000000000000], [0.50000000000000000 .. 1.0000000000000000]
# I  = [0.00000000000000000 .. 0.50000000000000000]
# C || f(I) = [1.0165306561067699 .. 1.4150000027939678]
# h  = t |--> e^(-t + 1.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.16561259053329905]
# b = -1.?
# t = [0.00000000000000000 .. 0.16493050844299590]
# b = -1.?
# t = [0.00000000000000000 .. 0.16482660193557153]
# b = -1.?
# t = [0.00000000000000000 .. 0.16481080841603297]
# b = -1.?
# found upper bound!
# t = [0.16580840817069461 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.16580840817069461 .. 10.000000000000000], fprime(t) = [-1.1988000990822912 .. -0.000046147964894771575]
# bisecting [0.00000000000000000 .. 0.50000000000000000] -> [0.00000000000000000 .. 0.25000000000000000], [0.25000000000000000 .. 0.50000000000000000]
# I  = [0.00000000000000000 .. 0.25000000000000000]
# C || f(I) = [1.1888007790222763 .. 1.4150000027939678]
# h  = t |--> e^(-t + 1.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.16561259053329905]
# b = -2.?
# t = [0.00000000000000000 .. 0.16493050778436850]
# b = -2.?
# t = [0.00000000000000000 .. 0.16482660193505425]
# b = -2.?
# t = [0.00000000000000000 .. 0.16481080775732679]
# b = -2.?
# found upper bound!
# t = [0.16580840751198844 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.16580840751198844 .. 10.000000000000000], fprime(t) = [-1.1988000990822912 .. -0.000053969211876392364]
# bisecting [0.00000000000000000 .. 0.25000000000000000] -> [0.00000000000000000 .. 0.12500000000000000], [0.12500000000000000 .. 0.25000000000000000]
# I  = [0.00000000000000000 .. 0.12500000000000000]
# C || f(I) = [1.2924969008564948 .. 1.4150000018626452]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.065368830879798528 .. 10.000000000000000]
# b = -1.?
# t = [0.073449156310651866 .. 10.000000000000000]
# b = -1.?
# t = [0.074184362474769949 .. 10.000000000000000]
# b = -1.?
# t = [0.074248306908129751 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.074253845740910012 .. 0.16594275705013126]
# b = -2.?
# t = [0.074253845740910012 .. 0.16490680780249440]
# b = -2.?
# t = [0.074253845740910012 .. 0.16481653734232263]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.074253845740910013]
# f(I) = [6.2882900242478001e-7 .. 0.21500000283122068]
# t = [0.16580871748669520 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.16580871748669520 .. 10.000000000000000], fprime(t) = [-1.1987997321411968 .. -0.000058677978813648223]
# bisecting [0.00000000000000000 .. 0.12500000000000000] -> [0.00000000000000000 .. 0.062500000000000000], [0.062500000000000000 .. 0.12500000000000000]
# I  = [0.00000000000000000 .. 0.062500000000000000]
# C || f(I) = [1.3494130613654851 .. 1.4150000018626452]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.10559226517909607 .. 10.000000000000000]
# b = -1.?
# t = [0.11673762911592301 .. 10.000000000000000]
# b = -1.?
# t = [0.11731969229559188 .. 10.000000000000000]
# b = -1.?
# t = [0.11734684921879735 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.11734810832437533 .. 0.16509609446916749]
# b = -1.2?
# t = [0.11734810832437533 .. 0.16482137137538234]
# b = -1.2?
# t = [0.11734810832437533 .. 0.16480859763982401]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.11734810832437534]
# f(I) = [7.1898102804723862e-8 .. 0.21500000283122068]
# t = [0.16580800494465200 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.16580800494465200 .. 10.000000000000000], fprime(t) = [-1.1988005815073848 .. -0.000061261467635631561]
# returning res = True
# I  = [0.062500000000000000 .. 0.12500000000000000]
# C || f(I) = [1.2924969008564948 .. 1.3544130632281304]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.068292973827313932 .. 10.000000000000000]
# b = -1.?
# t = [0.073964924982632171 .. 10.000000000000000]
# b = -1.?
# t = [0.074241098338026584 .. 10.000000000000000]
# b = -1.?
# t = [0.074253763713608339 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.074254342288019845 .. 0.12184210031314057]
# b = -1.2?
# t = [0.074254342288019845 .. 0.12108330618569869]
# b = -1.2?
# t = [0.074254342288019845 .. 0.12104831855851842]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.074254342288019846]
# f(I) = [3.2782554670873764e-8 .. 0.15441306419670587]
# t = [0.12204671822014968 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.12204671822014968 .. 10.000000000000000], fprime(t) = [-1.1988005274906755 .. -0.000058677978813648223]
# bisecting [0.062500000000000000 .. 0.12500000000000000] -> [0.062500000000000000 .. 0.093750000000000000], [0.093750000000000000 .. 0.12500000000000000]
# I  = [0.062500000000000000 .. 0.093750000000000000]
# C || f(I) = [1.3205103593319653 .. 1.3544130632281304]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.088976071776882076 .. 10.000000000000000]
# b = -1.?
# t = [0.095506542222686549 .. 10.000000000000000]
# b = -1.?
# t = [0.095691959896272882 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.095696618875119529 .. 0.12156225783590940]
# b = -1.2?
# t = [0.095696618875119529 .. 0.12105967657915344]
# b = -1.2?
# t = [0.095696618875119529 .. 0.12104696685689425]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.095696618875119530]
# f(I) = [1.4267861847550022e-7 .. 0.15441306419670587]
# t = [0.12204664844796361 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.12204664844796361 .. 10.000000000000000], fprime(t) = [-1.1988006075844169 .. -0.000059948302805423736]
# bisecting [0.062500000000000000 .. 0.093750000000000000] -> [0.062500000000000000 .. 0.078125000000000000], [0.078125000000000000 .. 0.093750000000000000]
# I  = [0.062500000000000000 .. 0.078125000000000000]
# C || f(I) = [1.3348488117009400 .. 1.3544130632281304]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.099562540957486858 .. 10.000000000000000]
# b = -1.?
# t = [0.10637267958102225 .. 10.000000000000000]
# b = -1.?
# t = [0.10649468088250604 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.10649645022629011 .. 0.12127111603650666]
# b = -1.2?
# t = [0.10649645022629011 .. 0.12104990881200461]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.10649645022629012]
# f(I) = [3.0919909521642807e-8 .. 0.15441306419670587]
# t = [0.12204668800701055 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.12204668800701055 .. 10.000000000000000], fprime(t) = [-1.1988005628809333 .. -0.000060600228607654571]
# returning res = True
# I  = [0.078125000000000000 .. 0.093750000000000000]
# C || f(I) = [1.3205103593319653 .. 1.3398488135635854]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.089943247467124870 .. 10.000000000000000]
# b = -1.?
# t = [0.095597414722646656 .. 10.000000000000000]
# b = -1.?
# t = [0.095695299401581293 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.095696716912975696 .. 0.11029272328251702]
# b = -1.2?
# t = [0.095696716912975696 .. 0.11023605731892135]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.095696716912975697]
# f(I) = [2.5331974073949936e-8 .. 0.13984881453216081]
# t = [0.11123523826356956 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.11123523826356956 .. 10.000000000000000], fprime(t) = [-1.1988005982711912 .. -0.000059948302805423736]
# bisecting [0.078125000000000000 .. 0.093750000000000000] -> [0.078125000000000000 .. 0.085937500000000000], [0.085937500000000000 .. 0.093750000000000000]
# I  = [0.078125000000000000 .. 0.085937500000000000]
# C || f(I) = [1.3276515806466340 .. 1.3398488135635854]
# h  = t |--> e^(-t + 0.29?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.095273118347473997 .. 10.000000000000000]
# b = -1.?
# t = [0.10102040679448999 .. 10.000000000000000]
# b = -1.?
# t = [0.10108945626959794 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.10109008780232560 .. 0.11029464650556033]
# b = -1.2?
# t = [0.10109008780232560 .. 0.11023576842220616]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.10109008780232561]
# f(I) = [6.7055225816403662e-9 .. 0.13984881453216081]
# t = [0.11123523101919337 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.11123523101919337 .. 10.000000000000000], fprime(t) = [-1.1988006168976427 .. -0.000060274265706539154]
# returning res = True
# I  = [0.085937500000000000 .. 0.093750000000000000]
# C || f(I) = [1.3205103593319653 .. 1.3326515834406019]
# h  = t |--> e^(-t + 0.28?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.090429003086489406 .. 10.000000000000000]
# b = -1.?
# t = [0.095635021674223705 .. 10.000000000000000]
# b = -1.?
# t = [0.095696173737330691 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.095696732976641538 .. 0.10559896022740411]
# b = -1.2?
# t = [0.095696732976641538 .. 0.10485618448146714]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.095696732976641539]
# f(I) = [6.7055225816403662e-9 .. 0.13265158534049993]
# t = [0.10584913800054794 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10584913800054794 .. 10.000000000000000], fprime(t) = [-1.1988005442544818 .. -0.000059948302805423736]
# returning res = None
# I  = [0.093750000000000000 .. 0.12500000000000000]
# C || f(I) = [1.2924969008564948 .. 1.3255103621259333]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.069782099254602186 .. 10.000000000000000]
# b = -1.?
# t = [0.074133245008150744 .. 10.000000000000000]
# b = -1.?
# t = [0.074251345612570740 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.074254294896868841 .. 0.10022221660357786]
# b = -1.2?
# t = [0.074254294896868841 .. 0.099494865482399220]
# b = -1.2?
# t = [0.074254294896868841 .. 0.099476478336947033]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.074254294896868842]
# f(I) = [9.0524554297033432e-8 .. 0.12551036402583127]
# t = [0.10047602064105422 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10047602064105422 .. 10.000000000000000], fprime(t) = [-1.1988005982711912 .. -0.000058677978813648223]
# returning res = False
# I  = [0.12500000000000000 .. 0.25000000000000000]
# C || f(I) = [1.1888007808849214 .. 1.2974969036504627]
# h  = t |--> e^(-t + 0.2?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.078385466484002353]
# b = -2.?
# t = [0.00000000000000000 .. 0.078135721565429986]
# b = -2.?
# t = [0.00000000000000000 .. 0.078116922227117234]
# b = -2.?
# found upper bound!
# t = [0.079115509053893459 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.079115509053893459 .. 10.000000000000000], fprime(t) = [-1.1988004734739662 .. -0.000053969211876392364]
# returning res = False
# I  = [0.25000000000000000 .. 0.50000000000000000]
# C || f(I) = [1.0165306579694151 .. 1.1938007836788894]
# h  = t |--> e^(-t + 0.1?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.00000000000000000 .. 10.000000000000000], fprime(t) = [-1.1938008004799486 .. -0.000046147964894771575]
# returning res = False
# I  = [0.50000000000000000 .. 1.0000000000000000]
# C || f(I) = [0.77787943867966535 .. 1.0215306612290443]
# h  = t |--> e^(-t + 0.?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.00000000000000000 .. 10.000000000000000], fprime(t) = [-1.0215306757017971 .. -0.000035312958061695098]
# returning res = False
# I  = [0.00000000000000000 .. 1.0000000000000000]
# C || f(I) = [0.78287943821400407 .. 1.4200000046566131]
# h  = t |--> e^(-t + 0.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.16914240360301833]
# b = -1.?
# t = [0.00000000000000000 .. 0.16846063691731631]
# b = -1.?
# t = [0.00000000000000000 .. 0.16835474239300000]
# b = -1.?
# t = [0.00000000000000000 .. 0.16833832960353232]
# b = -1.?
# found upper bound!
# t = [0.16933578761760731 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.16933578761760731 .. 10.000000000000000], fprime(t) = [-1.1988000543788076 .. -0.000035540200769901275]
# bisecting [0.00000000000000000 .. 1.0000000000000000] -> [0.00000000000000000 .. 0.50000000000000000], [0.50000000000000000 .. 1.0000000000000000]
# I  = [0.00000000000000000 .. 0.50000000000000000]
# C || f(I) = [1.0215306561067700 .. 1.4200000027939679]
# h  = t |--> e^(-t + 1.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.16914240360301833]
# b = -1.?
# t = [0.00000000000000000 .. 0.16846063429297814]
# b = -1.?
# t = [0.00000000000000000 .. 0.16835473976838400]
# b = -1.?
# t = [0.00000000000000000 .. 0.16833832763476653]
# b = -1.?
# found upper bound!
# t = [0.16933578433711624 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.16933578433711624 .. 10.000000000000000], fprime(t) = [-1.1988000618293882 .. -0.000046375207602977752]
# bisecting [0.00000000000000000 .. 0.50000000000000000] -> [0.00000000000000000 .. 0.25000000000000000], [0.25000000000000000 .. 0.50000000000000000]
# I  = [0.00000000000000000 .. 0.25000000000000000]
# C || f(I) = [1.1938007790222764 .. 1.4200000027939679]
# h  = t |--> e^(-t + 1.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.16914240360301833]
# b = -2.?
# t = [0.00000000000000000 .. 0.16846063429208386]
# b = -2.?
# t = [0.00000000000000000 .. 0.16835473976748972]
# b = -2.?
# t = [0.00000000000000000 .. 0.16833832697797896]
# b = -2.?
# found upper bound!
# t = [0.16933578433618465 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.16933578433618465 .. 10.000000000000000], fprime(t) = [-1.1988000543788076 .. -0.000054196454584598541]
# bisecting [0.00000000000000000 .. 0.25000000000000000] -> [0.00000000000000000 .. 0.12500000000000000], [0.12500000000000000 .. 0.25000000000000000]
# I  = [0.00000000000000000 .. 0.12500000000000000]
# C || f(I) = [1.2974969008564949 .. 1.4200000018626454]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.068659786091906913 .. 10.000000000000000]
# b = -1.?
# t = [0.077258935928894129 .. 10.000000000000000]
# b = -1.?
# t = [0.078041167318337836 .. 10.000000000000000]
# b = -1.?
# t = [0.078108981791988815 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.078114835912741653 .. 0.16859388117107658]
# b = -2.?
# t = [0.078114835912741653 .. 0.16835765361598232]
# b = -2.?
# t = [0.078114835912741653 .. 0.16833724519953692]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.078114835912741654]
# f(I) = [6.6235661511093724e-7 .. 0.22000000365078454]
# t = [0.16933548310962412 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.16933548310962412 .. 10.000000000000000], fprime(t) = [-1.1988004194572568 .. -0.000058905221521854400]
# bisecting [0.00000000000000000 .. 0.12500000000000000] -> [0.00000000000000000 .. 0.062500000000000000], [0.062500000000000000 .. 0.12500000000000000]
# I  = [0.00000000000000000 .. 0.062500000000000000]
# C || f(I) = [1.3544130613654852 .. 1.4200000018626454]
# h  = t |--> e^(-t + 0.4?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.10874158850700063 .. 10.000000000000000]
# b = -1.?
# t = [0.12040637618195060 .. 10.000000000000000]
# b = -1.?
# t = [0.12101686862621841 .. 10.000000000000000]
# b = -1.?
# t = [0.12104526043034093 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.12104657304965227 .. 0.16839729115649807]
# b = -1.2?
# t = [0.12104657304965227 .. 0.16833818116257732]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.12104657304965228]
# f(I) = [7.5623393103185776e-8 .. 0.22000000365078454]
# t = [0.16933544902757605 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.16933544902757605 .. 10.000000000000000], fprime(t) = [-1.1988004548475147 .. -0.000061488710343837738]
# returning res = True
# I  = [0.062500000000000000 .. 0.12500000000000000]
# C || f(I) = [1.2974969008564949 .. 1.3594130632281305]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.071719846556539790 .. 10.000000000000000]
# b = -1.?
# t = [0.077804617274938037 .. 10.000000000000000]
# b = -1.?
# t = [0.078101187426889012 .. 10.000000000000000]
# b = -1.?
# t = [0.078114740951028979 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.078115358146521360 .. 0.12516700267008294]
# b = -1.2?
# t = [0.078115358146521360 .. 0.12475140672506350]
# b = -1.2?
# t = [0.078115358146521360 .. 0.12473238802500753]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.078115358146521361]
# f(I) = [3.6507844969335678e-8 .. 0.15941306501626973]
# t = [0.12573152075071428 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.12573152075071428 .. 10.000000000000000], fprime(t) = [-1.1988005721941591 .. -0.000058905221521854400]
# bisecting [0.062500000000000000 .. 0.12500000000000000] -> [0.062500000000000000 .. 0.093750000000000000], [0.093750000000000000 .. 0.12500000000000000]
# I  = [0.062500000000000000 .. 0.093750000000000000]
# C || f(I) = [1.3255103593319654 .. 1.3594130632281305]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.092326869435708225 .. 10.000000000000000]
# b = -1.?
# t = [0.099272849608943780 .. 10.000000000000000]
# b = -1.?
# t = [0.099470915979749358 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.099475875067326066 .. 0.12491718609545623]
# b = -1.2?
# t = [0.099475875067326066 .. 0.12473612779708429]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.099475875067326067]
# f(I) = [1.5385448937088597e-7 .. 0.15941306501626973]
# t = [0.12573159579267201 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.12573159579267201 .. 10.000000000000000], fprime(t) = [-1.1988004827871919 .. -0.000060175545513629913]
# bisecting [0.062500000000000000 .. 0.093750000000000000] -> [0.062500000000000000 .. 0.078125000000000000], [0.078125000000000000 .. 0.093750000000000000]
# I  = [0.062500000000000000 .. 0.078125000000000000]
# C || f(I) = [1.3398488117009401 .. 1.3594130632281305]
# h  = t |--> e^(-t + 0.30?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.10287440230488022 .. 10.000000000000000]
# b = -1.?
# t = [0.11010265105701458 .. 10.000000000000000]
# b = -1.?
# t = [0.11023330504809120 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.11023519381631960 .. 0.12548402589499733]
# b = -1.2?
# t = [0.11023519381631960 .. 0.12474258978510241]
# b = -1.2?
# t = [0.11023519381631960 .. 0.12473163992647922]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.11023519381631961]
# f(I) = [3.2782554670873764e-8 .. 0.15941306501626973]
# t = [0.12573148173839676 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.12573148173839676 .. 10.000000000000000], fprime(t) = [-1.1988006168976427 .. -0.000060827471315860748]
# returning res = True
# I  = [0.078125000000000000 .. 0.093750000000000000]
# C || f(I) = [1.3255103593319654 .. 1.3448488135635855]
# h  = t |--> e^(-t + 0.29?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.093326739400812624 .. 10.000000000000000]
# b = -1.?
# t = [0.099368982120580165 .. 10.000000000000000]
# b = -1.?
# t = [0.099474458789037364 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.099475980409426886 .. 0.11459387767281496]
# b = -1.2?
# t = [0.099475980409426886 .. 0.11396935695394884]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.099475980409426887]
# f(I) = [2.7194619223180893e-8 .. 0.14484881535172467]
# t = [0.11496017856729527 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.11496017856729527 .. 10.000000000000000], fprime(t) = [-1.1988004548475147 .. -0.000060175545513629913]
# bisecting [0.078125000000000000 .. 0.093750000000000000] -> [0.078125000000000000 .. 0.085937500000000000], [0.085937500000000000 .. 0.093750000000000000]
# I  = [0.078125000000000000 .. 0.085937500000000000]
# C || f(I) = [1.3326515806466341 .. 1.3448488135635855]
# h  = t |--> e^(-t + 0.29?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.098636793614220105 .. 10.000000000000000]
# b = -1.?
# t = [0.10477364351498509 .. 10.000000000000000]
# b = -1.?
# t = [0.10484838097663091 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.10484906175090580 .. 0.11436507665206166]
# b = -1.2?
# t = [0.10484906175090580 .. 0.11396379885108240]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.10484906175090581]
# f(I) = [6.7055225816403662e-9 .. 0.14484881535172467]
# t = [0.11496007904616319 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.11496007904616319 .. 10.000000000000000], fprime(t) = [-1.1988005721941591 .. -0.000060499645769596099]
# returning res = True
# I  = [0.085937500000000000 .. 0.093750000000000000]
# C || f(I) = [1.3255103593319654 .. 1.3376515834406020]
# h  = t |--> e^(-t + 0.29?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.093828882031843849 .. 10.000000000000000]
# b = -1.?
# t = [0.099408975755405179 .. 10.000000000000000]
# b = -1.?
# t = [0.099475392674415075 .. 10.000000000000000]
# ...
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.059266088010470001 .. 10.000000000000000]
# b = -1.?
# t = [0.062348833764094876 .. 10.000000000000000]
# b = -1.?
# t = [0.062417084662436533 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.062418491836767578 .. 0.083800508871988200]
# b = -1.2?
# t = [0.062418491836767578 .. 0.083208936256788519]
# b = -1.2?
# t = [0.062418491836767578 .. 0.083196592449998525]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.062418491836767579]
# f(I) = [3.4645199820104721e-8 .. 0.10410618521273141]
# t = [0.084196339474477382 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.084196339474477382 .. 10.000000000000000], fprime(t) = [-1.1988006075844169 .. -0.000057986937463283538]
# returning res = False
# I  = [0.37500000000000000 .. 0.50000000000000000]
# C || f(I) = [1.1965306579694152 .. 1.2822892798855901]
# h  = t |--> e^(-t + 0.2?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.066892082889841484]
# b = -1.2?
# t = [0.00000000000000000 .. 0.066361939406252346]
# b = -1.2?
# t = [0.00000000000000000 .. 0.066327768014366670]
# b = -1.2?
# found upper bound!
# t = [0.067325575469650913 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.067325575469650913 .. 10.000000000000000], fprime(t) = [-1.1988004380837083 .. -0.000054321251809597015]
# returning res = False
# I  = [0.50000000000000000 .. 1.0000000000000000]
# C || f(I) = [0.95787943867966540 .. 1.2015306612290442]
# h  = t |--> e^(-t + 0.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.0013809328043328925]
# b = -1.?
# t = [0.00000000000000000 .. 0.0012748796121384949]
# b = -1.?
# found upper bound!
# t = [0.0022747394716272377 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.0022747394716272377 .. 10.000000000000000], fprime(t) = [-1.1988006168976427 .. -0.000043486244976520538]
# returning res = False
# I  = [0.00000000000000000 .. 1.0000000000000000]
# C || f(I) = [0.96287943821400401 .. 1.6000000046566130]
# h  = t |--> e^(-t + 0.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.29054522588902532]
# b = -1.?
# t = [0.00000000000000000 .. 0.28840093553136987]
# b = -1.?
# t = [0.00000000000000000 .. 0.28786198626147247]
# b = -1.?
# t = [0.00000000000000000 .. 0.28772706625917677]
# b = -1.?
# t = [0.00000000000000000 .. 0.28769332572303597]
# b = -1.?
# found upper bound!
# t = [0.28868489038527400 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.28868489038527400 .. 10.000000000000000], fprime(t) = [-1.1987972492352129 .. -0.000043713487684726715]
# bisecting [0.00000000000000000 .. 1.0000000000000000] -> [0.00000000000000000 .. 0.50000000000000000], [0.50000000000000000 .. 1.0000000000000000]
# I  = [0.00000000000000000 .. 0.50000000000000000]
# C || f(I) = [1.2015306561067700 .. 1.6000000027939679]
# h  = t |--> e^(-t + 1.?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.00095665755394908253 .. 10.000000000000000]
# b = -1.?
# t = [0.0011954786450257806 .. 10.000000000000000]
# b = -1.?
# t = [0.0012549909443344718 .. 10.000000000000000]
# b = -1.?
# t = [0.0012698147710723266 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.0012735070282422088 .. 0.28770834909724003]
# b = -1.?
# t = [0.0012735070282422088 .. 0.28768861906393712]
# b = -1.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.0012735070282422089]
# f(I) = [1.4688819647279416e-6 .. 0.40000000521540647]
# t = [0.28868370543892335 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.28868370543892335 .. 10.000000000000000], fprime(t) = [-1.1987986611202360 .. -0.000054546631872653961]
# bisecting [0.00000000000000000 .. 0.50000000000000000] -> [0.00000000000000000 .. 0.25000000000000000], [0.25000000000000000 .. 0.50000000000000000]
# I  = [0.00000000000000000 .. 0.25000000000000000]
# C || f(I) = [1.3738007790222763 .. 1.6000000027939679]
# h  = t |--> e^(-t + 0.4?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.10862548284221740 .. 10.000000000000000]
# b = -1.?
# t = [0.13119238098692040 .. 10.000000000000000]
# b = -1.?
# t = [0.13467753285416483 .. 10.000000000000000]
# b = -1.?
# t = [0.13517719111802645 .. 10.000000000000000]
# b = -1.?
# t = [0.13524797174502078 .. 10.000000000000000]
# b = -1.?
# t = [0.13525798147162537 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.13525939632957206 .. 0.29033401440536800]
# b = -2.?
# t = [0.13525939632957206 .. 0.28806000896556733]
# b = -2.?
# t = [0.13525939632957206 .. 0.28773556621995006]
# b = -2.?
# t = [0.13525939632957206 .. 0.28768963871366482]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.13525939632957207]
# f(I) = [2.8051435951859104e-7 .. 0.40000000521540647]
# t = [0.28868314496485103 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.28868314496485103 .. 10.000000000000000], fprime(t) = [-1.1987993298098445 .. -0.000062367878854274749]
# returning res = True
# I  = [0.25000000000000000 .. 0.50000000000000000]
# C || f(I) = [1.2015306579694151 .. 1.3788007836788894]
# h  = t |--> e^(-t + 1.?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.0011101342384189701 .. 10.000000000000000]
# b = -1.?
# t = [0.0012535589062978517 .. 10.000000000000000]
# b = -1.?
# t = [0.0012720093359792437 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.0012743826715479397 .. 0.13984765636157895]
# b = -2.?
# t = [0.0012743826715479397 .. 0.13901575954152501]
# b = -2.?
# t = [0.0012743826715479397 .. 0.13890841353082973]
# b = -2.?
# t = [0.0012743826715479397 .. 0.13889460524589695]
# b = -2.?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.0012743826715479398]
# f(I) = [4.2021274571091282e-7 .. 0.17880078516900544]
# t = [0.13989283004183505 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.13989283004183505 .. 10.000000000000000], fprime(t) = [-1.1988003039732576 .. -0.000054546631872653961]
# bisecting [0.25000000000000000 .. 0.50000000000000000] -> [0.25000000000000000 .. 0.37500000000000000], [0.37500000000000000 .. 0.50000000000000000]
# I  = [0.25000000000000000 .. 0.37500000000000000]
# C || f(I) = [1.2822892770916223 .. 1.3788007836788894]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.059681771031475913 .. 10.000000000000000]
# b = -1.?
# t = [0.065839905964111614 .. 10.000000000000000]
# b = -1.?
# t = [0.066291325469043094 .. 10.000000000000000]
# b = -1.?
# t = [0.066323031498010873 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.066325251103011448 .. 0.14014872855318198]
# b = -1.2?
# t = [0.066325251103011448 .. 0.13898122843904737]
# b = -1.2?
# t = [0.066325251103011448 .. 0.13889877778201182]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.066325251103011449]
# f(I) = [2.0042061810165989e-7 .. 0.17880078516900544]
# t = [0.13989300298513382 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.13989300298513382 .. 10.000000000000000], fprime(t) = [-1.1988000990822912 .. -0.000058214180171489715]
# bisecting [0.25000000000000000 .. 0.37500000000000000] -> [0.25000000000000000 .. 0.31250000000000000], [0.31250000000000000 .. 0.37500000000000000]
# I  = [0.25000000000000000 .. 0.31250000000000000]
# C || f(I) = [1.3266156271845102 .. 1.3788007836788894]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.091830250986700695 .. 10.000000000000000]
# b = -1.?
# t = [0.099954084059033054 .. 10.000000000000000]
# b = -1.?
# t = [0.10029598576965215 .. 10.000000000000000]
# b = -1.?
# t = [0.10030898702527558 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.10030947926815031 .. 0.14016731710233843]
# b = -1.2?
# t = [0.10030947926815031 .. 0.13894159677236421]
# b = -1.2?
# t = [0.10030947926815031 .. 0.13889442536452485]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.10030947926815032]
# f(I) = [2.1606683775488022e-8 .. 0.17880078516900544]
# t = [0.13989263859366432 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.13989263859366432 .. 10.000000000000000], fprime(t) = [-1.1988005368039012 .. -0.000060225836932659149]
# returning res = True
# I  = [0.31250000000000000 .. 0.37500000000000000]
# C || f(I) = [1.2822892770916223 .. 1.3316156299784781]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.061796565635065782 .. 10.000000000000000]
# b = -1.?
# t = [0.066147798684219633 .. 10.000000000000000]
# b = -1.?
# t = [0.066318823441941787 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.066325173811198429 .. 0.10477416107978306]
# b = -1.2?
# t = [0.066325173811198429 .. 0.10409767877973174]
# b = -1.2?
# t = [0.066325173811198429 .. 0.10407238177050659]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.066325173811198430]
# f(I) = [2.9355287556320774e-7 .. 0.13161563239991670]
# t = [0.10507144399170277 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10507144399170277 .. 10.000000000000000], fprime(t) = [-1.1988005815073848 .. -0.000058214180171489715]
# bisecting [0.31250000000000000 .. 0.37500000000000000] -> [0.31250000000000000 .. 0.34375000000000000], [0.34375000000000000 .. 0.37500000000000000]
# I  = [0.31250000000000000 .. 0.34375000000000000]
# C || f(I) = [1.3041061808168887 .. 1.3316156299784781]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.078180350019991018 .. 10.000000000000000]
# b = -1.?
# t = [0.083080405080158681 .. 10.000000000000000]
# b = -1.?
# t = [0.083193925838716722 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.083196278398234055 .. 0.10485434236836005]
# b = -1.2?
# t = [0.083196278398234055 .. 0.10408788377834264]
# b = -1.2?
# t = [0.083196278398234055 .. 0.10407174994902044]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.083196278398234056]
# f(I) = [5.8859586760107163e-8 .. 0.13161563239991670]
# t = [0.10507141643081205 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10507141643081205 .. 10.000000000000000], fprime(t) = [-1.1988006075844169 .. -0.000059205107390880584]
# bisecting [0.31250000000000000 .. 0.34375000000000000] -> [0.31250000000000000 .. 0.32812500000000000], [0.32812500000000000 .. 0.34375000000000000]
# I  = [0.31250000000000000 .. 0.32812500000000000]
# C || f(I) = [1.3152729778364300 .. 1.3316156299784781]
# h  = t |--> e^(-t + 0.28?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.086566250314720719 .. 10.000000000000000]
# b = -1.?
# t = [0.091646280572186156 .. 10.000000000000000]
# b = -1.?
# t = [0.091721731453678206 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.091722661464240823 .. 0.10462364106954713]
# b = -1.2?
# t = [0.091722661464240823 .. 0.10407833730675920]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.091722661464240824]
# f(I) = [1.2293458029333237e-8 .. 0.13161563239991670]
# t = [0.10507149422551743 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10507149422551743 .. 10.000000000000000], fprime(t) = [-1.1988005088642240 .. -0.000059711746871471405]
# bisecting [0.31250000000000000 .. 0.32812500000000000] -> [0.31250000000000000 .. 0.32031250000000000], [0.32031250000000000 .. 0.32812500000000000]
# I  = [0.31250000000000000 .. 0.32031250000000000]
# C || f(I) = [1.3209221486747264 .. 1.3316156299784781]
# h  = t |--> e^(-t + 0.28?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.090808594388488400 .. 10.000000000000000]
# b = -1.?
# t = [0.095953384908529837 .. 10.000000000000000]
# b = -1.?
# t = [0.096008086675274634 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.096008526424637447 .. 0.10479204369267004]
# b = -1.2?
# t = [0.096008526424637447 .. 0.10407745311438825]
# b = -1.20?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.096008526424637448]
# f(I) = [4.8428774324094092e-9 .. 0.13161563239991670]
# t = [0.10507145675338368 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10507145675338368 .. 10.000000000000000], fprime(t) = [-1.1988005628809333 .. -0.000059968791902065277]
# returning res = None
# I  = [0.32031250000000000 .. 0.32812500000000000]
# C || f(I) = [1.3152729778364300 .. 1.3259221514686943]
# h  = t |--> e^(-t + 0.28?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.086937963749874905 .. 10.000000000000000]
# b = -1.?
# t = [0.091672907511388790 .. 10.000000000000000]
# b = -1.?
# t = [0.091722271509151159 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.091722669685158020 .. 0.10015107498296344]
# b = -1.2?
# t = [0.091722669685158020 .. 0.099789617858271327]
# b = -1.20?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.091722669685158021]
# f(I) = [2.9802322831784522e-9 .. 0.12592215202748780]
# t = [0.10078664862805580 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.10078664862805580 .. 10.000000000000000], fprime(t) = [-1.1988005889579654 .. -0.000059711746871471405]
# returning res = False
# I  = [0.32812500000000000 .. 0.34375000000000000]
# C || f(I) = [1.3041061808168887 .. 1.3202729806303979]
# h  = t |--> e^(-t + 0.27?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.078852008134732587 .. 10.000000000000000]
# b = -1.?
# t = [0.083133823363333414 .. 10.000000000000000]
# b = -1.?
# t = [0.083195560752449410 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.083196319071325755 .. 0.096066104496192420]
# b = -1.2?
# t = [0.083196319071325755 .. 0.095523836471406401]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.083196319071325756]
# f(I) = [1.0430812880102280e-8 .. 0.12027298212051397]
# t = [0.096517046859761257 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.096517046859761257 .. 10.000000000000000], fprime(t) = [-1.1988005181774498 .. -0.000059205107390880584]
# returning res = False
# I  = [0.34375000000000000 .. 0.37500000000000000]
# C || f(I) = [1.2822892770916223 .. 1.3091061836108567]
# h  = t |--> e^(-t + 0.3?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.062859127345241141 .. 10.000000000000000]
# b = -1.?
# t = [0.066248533625545544 .. 10.000000000000000]
# b = -1.?
# t = [0.066323840613364923 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.066325386257209489 .. 0.087882117368293586]
# b = -1.2?
# t = [0.066325386257209489 .. 0.087041006050886869]
# b = -1.2?
# t = [0.066325386257209489 .. 0.087023414328063140]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.066325386257209490]
# f(I) = [3.8370490118566635e-8 .. 0.10910618603229528]
# t = [0.088023053383325028 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.088023053383325028 .. 10.000000000000000], fprime(t) = [-1.1988006075844169 .. -0.000058214180171489715]
# returning res = False
# I  = [0.37500000000000000 .. 0.50000000000000000]
# C || f(I) = [1.2015306579694151 .. 1.2872892798855902]
# h  = t |--> e^(-t + 0.2?)
# t = [0.00000000000000000 .. 10.000000000000000]
# b = -1.?
# t = [0.0011890520517431840 .. 10.000000000000000]
# b = -1.?
# t = [0.0012690211190399759 .. 10.000000000000000]
# b = -1.?
# found lower bound!
# t = [0.0012743520824831813 .. 0.070858113031331785]
# b = -1.2?
# t = [0.0012743520824831813 .. 0.070260012997096181]
# b = -1.2?
# t = [0.0012743520824831813 .. 0.070219976372445509]
# b = -1.2?
# found upper bound!
#   I  = [0.00000000000000000 .. 0.0012743520824831814]
# f(I) = [4.5746564869553196e-7 .. 0.087289282307028815]
# t = [0.071217308558393796 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.071217308558393796 .. 10.000000000000000], fprime(t) = [-1.1988003933802248 .. -0.000054546631872653961]
# returning res = False
# I  = [0.50000000000000000 .. 1.0000000000000000]
# C || f(I) = [0.96287943867966530 .. 1.2065306612290443]
# h  = t |--> e^(-t + 0.?)
# 0 on lower boundary!
# t = [0.00000000000000000 .. 0.0054931757151547214]
# b = -1.?
# t = [0.00000000000000000 .. 0.0054278220749665024]
# b = -1.?
# found upper bound!
# t = [0.0064274656109510937 .. 10.000000000000000]
# b = -1.?
# stopping since presumed converged
# t = [0.0064274656109510937 .. 10.000000000000000], fprime(t) = [-1.1988006168976427 .. -0.000043713487684726715]
# returning res = False

# %%
csig.plot(aspect_ratio=ar)
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# ### Nested contexts

# %%
def atom(t):
    b = 0.93
    print '===>', RIF(t).str(style='brackets'), RIF(h(t) - b).str(style='brackets')
    return h(t) - b

# %%
load('interval_signals.py')

# %%
csig = C(RIF(0,5),
         (lambda x: x + 0.5),
         (lambda f: C(RIF(0,10),
                      (lambda x: x + 0.2),
                      (lambda h: to_signal(atom,
                                           h.derivative(),
                                           RIF(0,1)).F(RIF(0.1,0.2))(0)),
                      f,
                      g,
                      0.1).F(RIF(0.1,0.2))(0)),
         y,
         g,
         0.1)
csig
# Out:
# I  = [0.00000000000000000 .. 5.0000000000000000]
# C || f(I) = [0.50673794467002153 .. 1.5000000083819032]
# h  = t |--> e^(-t + 0.?)
# I  = [0.00000000000000000 .. 10.000000000000000]
# C || f(I) = [0.20002300459891558 .. 1.7000000288710000]
# h  = t |--> e^(-t + 0.?e1)
# ===> [0.00000000000000000 .. -0.00000000000000000] [0.019235418082440780 .. 0.26866933079506128]
# t = [0.00000000000000000 .. 1.0000000000000000]
# ===> [0.00000000000000000 .. -0.00000000000000000] [0.019235418082440780 .. 0.26866933079506128]
# b = -1.?
# t = [0.011314951564010831 .. 1.0000000000000000]
# ===> [0.011314951564010831 .. 0.011314951564010832] [0.024699997994693356 .. 0.27958191100356900]
# b = -1.?
# t = [0.026009694994190740 .. 1.0000000000000000]
# ===> [0.026009694994190740 .. 0.026009694994190741] [0.031333261871068773 .. 0.29322469251291151]
# b = -1.?
# t = [0.044926707187921820 .. 1.0000000000000000]
# ===> [0.044926707187921820 .. 0.044926707187921821] [0.039103223624247451 .. 0.30990276877567447]
# b = -1.?
# t = [0.068985567543874026 .. 1.0000000000000000]
# ===> [0.068985567543874026 .. 0.068985567543874027] [0.047739426556886566 .. 0.32966827016550615]
# b = -1.?
# t = [0.099073220981554036 .. 1.0000000000000000]
# ===> [0.099073220981554036 .. 0.099073220981554037] [0.056589919873874183 .. 0.35209713640926077]
# b = -1.?
# t = [0.13582827798369681 .. 1.0000000000000000]
# ===> [0.13582827798369681 .. 0.13582827798369682] [0.064491805999919993 .. 0.37602895979875351]
# b = -1.?
# t = [0.17928381084949290 .. 1.0000000000000000]
# ===> [0.17928381084949290 .. 0.17928381084949291] [0.069771053618053024 .. 0.39939398497102208]
# b = -1.?
# t = [0.22838458268929975 .. 1.0000000000000000]
# ===> [0.22838458268929975 .. 0.22838458268929976] [0.070560559974650494 .. 0.41937732816153417]
# b = -1.?
# t = [0.28053997919405371 .. 1.0000000000000000]
# ===> [0.28053997919405371 .. 0.28053997919405372] [0.065575597178766820 .. 0.43319872352677569]
# b = -1.?
# t = [0.33160579659809702 .. 1.0000000000000000]
# ===> [0.33160579659809702 .. 0.33160579659809703] [0.055117115679868433 .. 0.43943732494343724]
# b = -1.?
# t = [0.37677600755430995 .. 1.0000000000000000]
# ===> [0.37677600755430995 .. 0.37677600755430996] [0.041481461716225687 .. 0.43905213408722477]
# b = -1.?
# t = [0.41234215798167339 .. 1.0000000000000000]
# ===> [0.41234215798167339 .. 0.41234215798167340] [0.027988543360314532 .. 0.43493267946754888]
# b = -1.?
# t = [0.43720835036322880 .. 1.0000000000000000]
# ===> [0.43720835036322880 .. 0.43720835036322881] [0.017175580404365953 .. 0.43009666824492310]
# b = -1.?
# t = [0.45285205708114062 .. 1.0000000000000000]
# ===> [0.45285205708114062 .. 0.45285205708114063] [0.0098114866065553973 .. 0.42624336531130103]
# b = -1.?
# t = [0.46192936428202790 .. 1.0000000000000000]
# ===> [0.46192936428202790 .. 0.46192936428202791] [0.0053444447933258532 .. 0.42372377995213462]
# b = -1.?
# t = [0.46691897929013498 .. 1.0000000000000000]
# ===> [0.46691897929013498 .. 0.46691897929013499] [0.0028292404370811041 .. 0.42225075022700398]
# b = -1.?
# t = [0.46957359256177805 .. 1.0000000000000000]
# ===> [0.46957359256177805 .. 0.46957359256177806] [0.0014739560762261350 .. 0.42144170888275990]
# b = -1.?
# t = [0.47096024886423926 .. 1.0000000000000000]
# ===> [0.47096024886423926 .. 0.47096024886423927] [0.00076130687005337982 .. 0.42101211702586017]
# b = -1.?
# t = [0.47167745873028654 .. 1.0000000000000000]
# ===> [0.47167745873028654 .. 0.47167745873028655] [0.00039144454854656007 .. 0.42078804450302998]
# b = -1.?
# t = [0.47204649430735245 .. 1.0000000000000000]
# ===> [0.47204649430735245 .. 0.47204649430735246] [0.00020079896688252052 .. 0.42067225090695393]
# b = -1.?
# t = [0.47223586803639128 .. 1.0000000000000000]
# ===> [0.47223586803639128 .. 0.47223586803639129] [0.00010287916127416085 .. 0.42061269896656673]
# b = -1.?
# t = [0.47233291186348830 .. 1.0000000000000000]
# ===> [0.47233291186348830 .. 0.47233291186348831] [0.000052677309481663492 .. 0.42058214725603638]
# b = -1.?
# t = [0.47238260612383686 .. 1.0000000000000000]
# ===> [0.47238260612383686 .. 0.47238260612383687] [0.000026963822191139463 .. 0.42056649325428042]
# b = -1.?
# t = [0.47240804428311233 .. 1.0000000000000000]
# ===> [0.47240804428311233 .. 0.47240804428311234] [0.000013799663238001080 .. 0.42055847770006627]
# b = -1.?
# t = [0.47242106346709361 .. 1.0000000000000000]
# ===> [0.47242106346709361 .. 0.47242106346709362] [7.0618624873342028e-6 .. 0.42055437473790714]
# b = -1.?
# found lower bound!
# ===> [0.47242772601256877 .. 0.47242772601256878] [3.6136947444420641e-6 .. 0.42055227489095526]
# ===> [0.47242772601256877 .. 0.47725200327269441] [-0.0068031314272616328 .. 0.42431910073753077]
# ===> [0.47725200327269440 .. 0.47725200327269441] [-0.0025125876774059198 .. 0.41900287071611409]
# ===> [0.47725200327269440 .. 0.47725200327269441] [-0.0025125876774059198 .. 0.41900287071611409]
# ===> [0.47242772601256877 .. 0.48212452330542133] [-0.013706254745561642 .. 0.42810879055456431]
# ===> [0.48212452330542132 .. 0.48212452330542133] [-0.0050931135351656165 .. 0.41737948383803081]
# ===> [0.48212452330542132 .. 0.48212452330542133] [-0.0050931135351656165 .. 0.41737948383803081]
# ===> [0.47242772601256877 .. 0.48704576853847554] [-0.020706863194339121 .. 0.43192118408770098]
# ===> [0.48704576853847553 .. 0.48704576853847554] [-0.0077390725664790994 .. 0.41568044145046124]
# ===> [0.48704576853847553 .. 0.48704576853847554] [-0.0077390725664790994 .. 0.41568044145046124]
# ===> [0.47242772601256877 .. 0.49201622622386027] [-0.027806062958827927 .. 0.43575610926948694]
# ===> [0.49201622622386026 .. 0.49201622622386027] [-0.010451582087682821 .. 0.41390404577557927]
# ===> [0.49201622622386026 .. 0.49201622622386027] [-0.010451582087682821 .. 0.41390404577557927]
# ===> [0.47242772601256877 .. 0.49703638848609883] [-0.035004958740564863 .. 0.43961338184099009]
# ===> [0.49703638848609882 .. 0.49703638848609883] [-0.013231767664144912 .. 0.41204857407527318]
# ===> [0.49703638848609882 .. 0.49703638848609883] [-0.013231767664144912 .. 0.41204857407527318]
# ===> [0.47242772601256877 .. 0.50210675237095970] [-0.042304652985597713 .. 0.44349280496356059]
# ===> [0.50210675237095969 .. 0.50210675237095970] [-0.016080762704204777 .. 0.41011227868391787]
# ===> [0.50210675237095969 .. 0.50210675237095970] [-0.016080762704204777 .. 0.41011227868391787]
# ===> [0.47242772601256877 .. 0.50722781989466926] [-0.049706245074299882 .. 0.44739416882052108]
# ===> [0.50722781989466925 .. 0.50722781989466926] [-0.018999708025321583 .. 0.40809338706380272]
# ===> [0.50722781989466925 .. 0.50722781989466926] [-0.018999708025321583 .. 0.40809338706380272]
# ===> [0.47242772601256877 .. 0.51240009809361587] [-0.057210830471406294 .. 0.45131725020857994]
# ===> [0.51240009809361586 .. 0.51240009809361587] [-0.021989751391297219 .. 0.40599010188445617]
# ===> [0.51240009809361586 .. 0.51240009809361587] [-0.021989751391297219 .. 0.40599010188445617]
# ===> [0.47242772601256877 .. 0.51762409907455198] [-0.064819499834846140 .. 0.45526181211875139]
# ===> [0.51762409907455197 .. 0.51762409907455198] [-0.025052047019415769 .. 0.40380060112714434]
# ===> [0.51762409907455197 .. 0.51762409907455198] [-0.025052047019415769 .. 0.40380060112714434]
# ===> [0.47242772601256877 .. 0.52290034006529740] [-0.072533338081911092 .. 0.45922760330657109]
# ===> [0.52290034006529739 .. 0.52290034006529740] [-0.028187755056299003 .. 0.40152303821587821]
# ===> [0.52290034006529739 .. 0.52290034006529740] [-0.028187755056299003 .. 0.40152303821587821]
# ===> [0.47242772601256877 .. 0.52822934346595030] [-0.080353423411260506 .. 0.46321435785139109]
# ===> [0.52822934346595029 .. 0.52822934346595030] [-0.031398041021248991 .. 0.39915554217630656]
# ===> [0.52822934346595029 .. 0.52822934346595030] [-0.031398041021248991 .. 0.39915554217630656]
# ===> [0.47242772601256877 .. 0.53361163690060976] [-0.088280826279222069 .. 0.46722179470453352]
# ===> [0.53361163690060975 .. 0.53361163690060976] [-0.034684075215813404 .. 0.39669621782392895]
# ===> [0.53361163690060975 .. 0.53361163690060976] [-0.034684075215813404 .. 0.39669621782392895]
# ===> [0.47242772601256877 .. 0.53904775326961574] [-0.096316608328814946 .. 0.47124961722609016]
# ===> [0.53904775326961573 .. 0.53904775326961574] [-0.038047032098269096 .. 0.39414314598311185]
# ===> [0.53904775326961573 .. 0.53904775326961574] [-0.038047032098269096 .. 0.39414314598311185]
# ===> [0.47242772601256877 .. 0.54453823080231179] [-0.10446182126987525 .. 0.47529751271014054]
# ===> [0.54453823080231178 .. 0.54453823080231179] [-0.041488089621695035 .. 0.39149438373844315]
# ===> [0.54453823080231178 .. 0.54453823080231179] [-0.041488089621695035 .. 0.39149438373844315]
# ===> [0.47242772601256877 .. 0.55008361311033483] [-0.11271750570863060 .. 0.47936515189817375]
# ===> [0.55008361311033482 .. 0.55008361311033483] [-0.045008428534257350 .. 0.38874796472002305]
# ===> [0.55008361311033482 .. 0.55008361311033483] [-0.045008428534257350 .. 0.38874796472002305]
# ===> [0.47242772601256877 .. 0.55568444924143812] [-0.12108468992502908 .. 0.48345218848048821]
# ===> [0.55568444924143811 .. 0.55568444924143812] [-0.048609231640302731 .. 0.38590189942433606]
# ===> [0.55568444924143811 .. 0.55568444924143812] [-0.048609231640302731 .. 0.38590189942433606]
# ===> [0.47242772601256877 .. 0.56134129373385245] [-0.12956438859608788 .. 0.48755825858534785]
# ===> [0.56134129373385244 .. 0.56134129373385245] [-0.052291683020820324 .. 0.38295417557241030]
# ===> [0.56134129373385244 .. 0.56134129373385245] [-0.052291683020820324 .. 0.38295417557241030]
# ===> [0.47242772601256877 .. 0.56705470667119096] [-0.13815760146349021 .. 0.49168298025567270]
# ===> [0.56705470667119095 .. 0.56705470667119096] [-0.056056967211788989 .. 0.37990275850703237]
# ===> [0.56705470667119095 .. 0.56705470667119096] [-0.056056967211788989 .. 0.37990275850703237]
# ===> [0.47242772601256877 .. 0.57282525373790283] [-0.14686531194361763 .. 0.49582595291304055]
# ===> [0.57282525373790282 .. 0.57282525373790283] [-0.059906268338902336 .. 0.37674559163084054]
# ===> [0.57282525373790282 .. 0.57282525373790283] [-0.059906268338902336 .. 0.37674559163084054]
# ===> [0.47242772601256877 .. 0.57865350627528179] [-0.15568848567816862 .. 0.49998675680877581]
# ===> [0.57865350627528178 .. 0.57865350627528179] [-0.063840769207117121 .. 0.37348059688718228]
# ===> [0.57865350627528178 .. 0.57865350627528179] [-0.063840769207117121 .. 0.37348059688718228]
# ===> [0.47242772601256877 .. 0.58454004133803450] [-0.16462806902347494 .. 0.50416495246190663]
# ===> [0.58454004133803449 .. 0.58454004133803450] [-0.067861650343444824 .. 0.37010567528568561]
# ===> [0.58454004133803449 .. 0.58454004133803450] [-0.067861650343444824 .. 0.37010567528568561]
# ===> [0.47242772601256877 .. 0.59048544175141482] [-0.17368498747659112 .. 0.50836008008376610]
# ===> [0.59048544175141481 .. 0.59048544175141482] [-0.071970088991365811 .. 0.36661870747455450]
# ===> [0.59048544175141481 .. 0.59048544175141482] [-0.071970088991365811 .. 0.36661870747455450]
# ===> [0.47242772601256877 .. 0.59649029616892891] [-0.18286014403619078 .. 0.51257165898901825]
# ===> [0.59649029616892890 .. 0.59649029616892891] [-0.076167258055208964 .. 0.36301755436166395]
# ===> [0.59649029616892890 .. 0.59649029616892891] [-0.076167258055208964 .. 0.36301755436166395]
# ===> [0.47242772601256877 .. 0.60255519913061817] [-0.19215441749627682 .. 0.51679918699289374]
# ===> [0.60255519913061816 .. 0.60255519913061817] [-0.080454324992815130 .. 0.35930005778659891]
# ===> [0.60255519913061816 .. 0.60255519913061817] [-0.080454324992815130 .. 0.35930005778659891]
# ===> [0.47242772601256877 .. 0.60868075112192433] [-0.20156866067066682 .. 0.52104213979441394]
# ===> [0.60868075112192432 .. 0.60868075112192433] [-0.084832450654756642 .. 0.35546404124584042]
# ===> [0.60868075112192432 .. 0.60868075112192433] [-0.084832450654756642 .. 0.35546404124584042]
# ===> [0.47242772601256877 .. 0.61486755863314347] [-0.21110369854618738 .. 0.52529997034539633]
# ===> [0.61486755863314346 .. 0.61486755863314347] [-0.089302788068362671 .. 0.35150731067337604]
# ===> [0.61486755863314346 .. 0.61486755863314347] [-0.089302788068362671 .. 0.35150731067337604]
# ===> [0.47242772601256877 .. 0.62111623421947482] [-0.22076032636247789 .. 0.52957210820502321]
# ===> [0.62111623421947481 .. 0.62111623421947482] [-0.093866481164764371 .. 0.34742765527907660]
# ===> [0.62111623421947481 .. 0.62111623421947482] [-0.093866481164764371 .. 0.34742765527907660]
# ===> [0.47242772601256877 .. 0.62742739656166946] [-0.23053930761626885 .. 0.53385795887977372]
# ===> [0.62742739656166945 .. 0.62742739656166946] [-0.098524663447139838 .. 0.34322284844724871]
# ===> [0.62742739656166945 .. 0.62742739656166946] [-0.098524663447139838 .. 0.34322284844724871]
# ===> [0.47242772601256877 .. 0.63380167052728609] [-0.24044137198797578 .. 0.53815690314851239]
# ===> [0.63380167052728608 .. 0.63380167052728609] [-0.10327845659832114 .. 0.33889064869784725]
# ===> [0.63380167052728608 .. 0.63380167052728609] [-0.10327845659832114 .. 0.33889064869784725]
# ===> [0.47242772601256877 .. 0.64023968723255887] [-0.25046721318841814 .. 0.54246829637253436]
# ===> [0.64023968723255886 .. 0.64023968723255887] [-0.10812896902587810 .. 0.33442880071289161]
# ===> [0.64023968723255886 .. 0.64023968723255887] [-0.10812896902587810 .. 0.33442880071289161]
# ===> [0.47242772601256877 .. 0.64674208410488443] [-0.26061748672344587 .. 0.54679146779038035]
# ===> [0.64674208410488442 .. 0.64674208410488443] [-0.11307729434279179 .. 0.32983503643071177]
# ===> [0.64674208410488442 .. 0.64674208410488443] [-0.11307729434279179 .. 0.32983503643071177]
# ===> [0.47242772601256877 .. 0.65330950494593321] [-0.27089280757423806 .. 0.55112571979722603]
# ===> [0.65330950494593320 .. 0.65330950494593321] [-0.11812450978178280 .. 0.32510707621070901]
# ===> [0.65330950494593320 .. 0.65330950494593321] [-0.11812450978178280 .. 0.32510707621070901]
# ===> [0.47242772601256877 .. 0.65994259999539251] [-0.28129374779101258 .. 0.55547032720867107]
# ===> [0.65994259999539250 .. 0.65994259999539251] [-0.12327167454135435 .. 0.32024263007139487]
# ===> [0.65994259999539250 .. 0.65994259999539251] [-0.12327167454135435 .. 0.32024263007139487]
# ===> [0.47242772601256877 .. 0.66664202599534639] [-0.29182083399786807 .. 0.55982453650875164]
# ===> [0.66664202599534638 .. 0.66664202599534639] [-0.12851982806157792 .. 0.31523939900453824]
# ===> [0.66664202599534638 .. 0.66664202599534639] [-0.12851982806157792 .. 0.31523939900453824]
# ===> [0.47242772601256877 .. 0.67340844625529984] [-0.30247454480646486 .. 0.56418756508201085]
# ===> [0.67340844625529983 .. 0.67340844625529984] [-0.13386998822764307 .. 0.31009507636832002]
# ===> [0.67340844625529983 .. 0.67340844625529984] [-0.13386998822764307 .. 0.31009507636832002]
# ===> [0.47242772601256877 .. 0.68024253071785279] [-0.31325530813624425 .. 0.56855860042947171]
# ===> [0.68024253071785278 .. 0.68024253071785279] [-0.13932314949916303 .. 0.30480734936246668]
# ===> [0.68024253071785278 .. 0.68024253071785279] [-0.13932314949916303 .. 0.30480734936246668]
# ===> [0.47242772601256877 .. 0.68714495602503123] [-0.32416349843887072 .. 0.57293679936836373]
# ===> [0.68714495602503122 .. 0.68714495602503123] [-0.14488028096323502 .. 0.29937390058840097]
# ===> [0.68714495602503122 .. 0.68714495602503123] [-0.14488028096323502 .. 0.29937390058840097]
# ===> [0.47242772601256877 .. 0.69411640558528143] [-0.33519943382458173 .. 0.57732128721546861]
# ===> [0.69411640558528142 .. 0.69411640558528143] [-0.15054232430922643 .. 0.29379240969751697]
# ===> [0.69411640558528142 .. 0.69411640558528143] [-0.15054232430922643 .. 0.29379240969751697]
# ===> [0.47242772601256877 .. 0.70115756964113419] [-0.34636337308813193 .. 0.58171115695395826]
# ===> [0.70115756964113418 .. 0.70115756964113419] [-0.15631019172326788 .. 0.28806055513075391]
# ===> [0.70115756964113418 .. 0.70115756964113419] [-0.15631019172326788 .. 0.28806055513075391]
# ===> [0.47242772601256877 .. 0.70826914533754549] [-0.35765551263202023 .. 0.58610546838361433]
# ===> [0.70826914533754548 .. 0.70826914533754549] [-0.16218476370042468 .. 0.28217601595270748]
# ===> [0.70826914533754548 .. 0.70826914533754549] [-0.16218476370042468 .. 0.28217601595270748]
# ===> [0.47242772601256877 .. 0.71545183679092084] [-0.36907598328470482 .. 0.59050324725432913]
# ===> [0.71545183679092083 .. 0.71545183679092084] [-0.16816688677252701 .. 0.27613647378358153]
# ===> [0.71545183679092083 .. 0.71545183679092084] [-0.16816688677252701 .. 0.27613647378358153]
# ===> [0.47242772601256877 .. 0.72270635515882998] [-0.38062484701152044 .. 0.59490348438280483]
# ===> [0.72270635515882997 .. 0.72270635515882998] [-0.17425737114964457 .. 0.26993961483234597]
# ===> [0.72270635515882997 .. 0.72270635515882998] [-0.17425737114964457 .. 0.26993961483234597]
# ===> [0.47242772601256877 .. 0.73003341871041816] [-0.39230209351604284 .. 0.59930513475238423]
# ===> [0.73003341871041815 .. 0.73003341871041816] [-0.18045698827320600 .. 0.26358313203452755]
# ===> [0.73003341871041815 .. 0.73003341871041816] [-0.18045698827320600 .. 0.26358313203452755]
# ===> [0.47242772601256877 .. 0.73743375289752234] [-0.40410763672966855 .. 0.60370711659595700]
# ===> [0.73743375289752233 .. 0.73743375289752234] [-0.18676646827878185 .. 0.25706472729810848]
# ===> [0.73743375289752233 .. 0.73743375289752234] [-0.18676646827878185 .. 0.25706472729810848]
# ===> [0.47242772601256877 .. 0.74490809042649753] [-0.41604131118721722 .. 0.60810831046191638]
# ===> [0.74490809042649752 .. 0.74490809042649753] [-0.19318649736657712 .. 0.25038211386108012]
# ===> [0.74490809042649752 .. 0.74490809042649753] [-0.19318649736657712 .. 0.25038211386108012]
# ===> [0.47242772601256877 .. 0.75245717133076240] [-0.42810286828641209 .. 0.61250755826314796]
# ===> [0.75245717133076239 .. 0.75245717133076240] [-0.19971771507770775 .. 0.24353301876422385]
# ===> [0.75245717133076239 .. 0.75245717133076240] [-0.19971771507770775 .. 0.24353301876422385]
# ===> [0.47242772601256877 .. 0.76008174304406995] [-0.44029197242913754 .. 0.61690366230906147]
# ===> [0.76008174304406994 .. 0.76008174304406995] [-0.20636071147437929 .. 0.23651518544276485]
# ===> [0.76008174304406994 .. 0.76008174304406995] [-0.20636071147437929 .. 0.23651518544276485]
# ===> [0.47242772601256877 .. 0.76778256047451055] [-0.45260819704244221 .. 0.62129538432069865]
# ===> [0.76778256047451054 .. 0.76778256047451055] [-0.21311602422212284 .. 0.22932637644056542]
# ===> [0.76778256047451054 .. 0.76778256047451055] [-0.21311602422212284 .. 0.22932637644056542]
# ===> [0.47242772601256877 .. 0.77556038607925560] [-0.46505102047732733 .. 0.62568144442897078]
# ===> [0.77556038607925559 .. 0.77556038607925560] [-0.21998413557231289 .. 0.22196437625057397]
# ===> [0.77556038607925559 .. 0.77556038607925560] [-0.21998413557231289 .. 0.22196437625057397]
# ===> [0.47242772601256877 .. 0.78341598994004813] [-0.47761982178343238 .. 0.63006052015611036]
# ===> [0.78341598994004812 .. 0.78341598994004813] [-0.22696546924323735 .. 0.21442699428527202]
# ===> [0.78341598994004812 .. 0.78341598994004813] [-0.22696546924323735 .. 0.21442699428527202]
# ===> [0.47242772601256877 .. 0.79135014983944852] [-0.49031387635783525 .. 0.63443124538044627]
# ===> [0.79135014983944851 .. 0.79135014983944852] [-0.23406038719807710 .. 0.20671206798089415]
# ===> [0.79135014983944851 .. 0.79135014983944852] [-0.23406038719807710 .. 0.20671206798089415]
# ===> [0.47242772601256877 .. 0.79936365133784293] [-0.50313235146627811 .. 0.63879220928464398]
# ===> [0.79936365133784292 .. 0.79936365133784293] [-0.24126918631822525 .. 0.19881746603920647]
# ===> [0.79936365133784292 .. 0.79936365133784293] [-0.24126918631822525 .. 0.19881746603920647]
# ===> [0.47242772601256877 .. 0.80745728785122129] [-0.51607430163525026 .. 0.64314195528758112]
# ===> [0.80745728785122128 .. 0.80745728785122129] [-0.24859209497047408 .. 0.19074109181065058]
# ===> [0.80745728785122128 .. 0.80745728785122129] [-0.24859209497047408 .. 0.19074109181065058]
# ===> [0.47242772601256877 .. 0.81563186072973349] [-0.52913866391348874 .. 0.64747897996006565]
# ===> [0.81563186072973348 .. 0.81563186072973349] [-0.25602926946670391 .. 0.18248088682265607]
# ===> [0.81563186072973348 .. 0.81563186072973349] [-0.25602926946670391 .. 0.18248088682265607]
# ===> [0.47242772601256877 .. 0.82388817933703074] [-0.54232425300160192 .. 0.65180173192463953]
# ===> [0.82388817933703073 .. 0.82388817933703074] [-0.26358079041481575 .. 0.17403483445693191]
# ===> [0.82388817933703073 .. 0.82388817933703074] [-0.26358079041481575 .. 0.17403483445693191]
# ===> [0.47242772601256877 .. 0.83222706113040102] [-0.55562975624867872 .. 0.65610861073974614]
# ===> [0.83222706113040101 .. 0.83222706113040102] [-0.27124665895979117 .. 0.16540096377951963]
# ===> [0.83222706113040101 .. 0.83222706113040102] [-0.27124665895979117 .. 0.16540096377951963]
# ===> [0.47242772601256877 .. 0.84064933174170498] [-0.56905372851492198 .. 0.66039796576858379]
# ===> [0.84064933174170497 .. 0.84064933174170498] [-0.27902679291389865 .. 0.15657735352737901]
# ===> [0.84064933174170497 .. 0.84064933174170498] [-0.27902679291389865 .. 0.15657735352737901]
# ===> [0.47242772601256877 .. 0.84915582505912202] [-0.58259458689953426 .. 0.66466809503301072]
# ===> [0.84915582505912201 .. 0.84915582505912202] [-0.28692102277522414 .. 0.14756213625523940]
# ===> [0.84915582505912201 .. 0.84915582505912202] [-0.28692102277522414 .. 0.14756213625523940]
# ===> [0.47242772601256877 .. 0.85774738330971323] [-0.59625060533329722 .. 0.66891724405290931]
# ===> [0.85774738330971322 .. 0.85774738330971323] [-0.29492908763388004 .. 0.13835350264639946]
# ===> [0.85774738330971322 .. 0.85774738330971323] [-0.29492908763388004 .. 0.13835350264639946]
# ===> [0.47242772601256877 .. 0.86642485714281026] [-0.61001990903551307 .. 0.67314360467147017]
# ===> [0.86642485714281025 .. 0.86642485714281026] [-0.30305063096543572 .. 0.12894970599110390]
# ===> [0.86642485714281025 .. 0.86642485714281026] [-0.30305063096543572 .. 0.12894970599110390]
# ===> [0.47242772601256877 .. 0.87518910571423825] [-0.62390046883522410 .. 0.67734531386690556]
# ===> [0.87518910571423824 .. 0.87518910571423825] [-0.31128519631131846 .. 0.11934906683604918]
# ===> [0.87518910571423824 .. 0.87518910571423825] [-0.31128519631131846 .. 0.11934906683604918]
# ===> [0.47242772601256877 .. 0.88404099677138060] [-0.63789009535689878 .. 0.68152045255115435]
# ===> [0.88404099677138059 .. 0.88404099677138060] [-0.31963222284616289 .. 0.10954997780848464]
# ===> [0.88404099677138059 .. 0.88404099677138060] [-0.31963222284616289 .. 0.10954997780848464]
# ===> [0.47242772601256877 .. 0.89298140673909432] [-0.65198643307106308 .. 0.68566704435620530]
# ===> [0.89298140673909431 .. 0.89298140673909432] [-0.32809104083232999 .. 0.099550908618267653]
# ===> [0.89298140673909431 .. 0.89298140673909432] [-0.32809104083232999 .. 0.099550908618267653]
# ===> [0.47242772601256877 .. 0.90201122080648522] [-0.66618695421067820 .. 0.68978305440871568]
# ===> [0.90201122080648521 .. 0.90201122080648522] [-0.33666086696208509 .. 0.089350411241113315]
# ===> [0.90201122080648521 .. 0.90201122080648522] [-0.33666086696208509 .. 0.089350411241113315]
# ===> [0.47242772601256877 .. 0.91113133301454997] [-0.68048895255439835 .. 0.69386638809367496]
# ===> [0.91113133301454996 .. 0.91113133301454997] [-0.34534079958821018 .. 0.078947125286135012]
# ===> [0.91113133301454996 .. 0.91113133301454997] [-0.34534079958821018 .. 0.078947125286135012]
# ===> [0.47242772601256877 .. 0.92034264634469543] [-0.69488953707822066 .. 0.69791488980792716]
# ===> [0.92034264634469542 .. 0.92034264634469543] [-0.35412981384414300 .. 0.068339783550617095]
# ===> [0.92034264634469542 .. 0.92034264634469543] [-0.35412981384414300 .. 0.068339783550617095]
# ===> [0.47242772601256877 .. 0.92964607280814238] [-0.70938562547742734 .. 0.70192634170443625]
# ===> [0.92964607280814237 .. 0.92964607280814238] [-0.36302675665505935 .. 0.057527217764772432]
# ===> [0.92964607280814237 .. 0.92964607280814238] [-0.36302675665505935 .. 0.057527217764772432]
# ===> [0.47242772601256877 .. 0.93904253353622369] [-0.72397393756114859 .. 0.70589846242825794]
# ===> [0.93904253353622368 .. 0.93904253353622369] [-0.37203034164169103 .. 0.046508364529043500]
# ===> [0.93904253353622368 .. 0.93904253353622369] [-0.37203034164169103 .. 0.046508364529043500]
# ===> [0.47242772601256877 .. 0.94853295887158585] [-0.73865098852233724 .. 0.70982890584525460]
# ===> [0.94853295887158584 .. 0.94853295887158585] [-0.38113914391904836 .. 0.035282271446264280]
# ===> [0.94853295887158584 .. 0.94853295887158585] [-0.38113914391904836 .. 0.035282271446264280]
# ===> [0.47242772601256877 .. 0.95811828846030168] [-0.75341308208641867 .. 0.71371525976467821]
# ===> [0.95811828846030167 .. 0.95811828846030168] [-0.39035159479263793 .. 0.023848103450758052]
# ===> [0.95811828846030167 .. 0.95811828846030168] [-0.39035159479263793 .. 0.023848103450758052]
# ===> [0.47242772601256877 .. 0.96779947134490463] [-0.76825630354242470 .. 0.71755504465683074]
# ===> [0.96779947134490462 .. 0.96779947134490463] [-0.39966597635521118 .. 0.012205149336158239]
# ===> [0.96779947134490462 .. 0.96779947134490463] [-0.39966597635521118 .. 0.012205149336158239]
# ===> [0.47242772601256877 .. 0.97757746605835361] [-0.78317651266095634 .. 0.72134571236710821]
# ===> [0.97757746605835360 .. 0.97757746605835361] [-0.40908041598755552 .. 0.00035282848343010099]
# ===> [0.97757746605835360 .. 0.97757746605835361] [-0.40908041598755552 .. 0.00035282848343010099]
# ===> [0.47242772601256877 .. 0.98745324071893704] [-0.79816933650393330 .. 0.72508464482782354]
# ===> [0.98745324071893703 .. 0.98745324071893704] [-0.41859288076735391 .. -0.011709302209774175]
# ===> [0.98745324071893703 .. 0.98745324071893704] [-0.41859288076735391 .. -0.011709302209774175]
# t = [0.47242772601256877 .. 0.98745324071893704]
# ===> [0.98745324071893703 .. 0.98745324071893704] [-0.41859288076735413 .. -0.011709302209774397]
# b = -1.?
# t = [0.47242772601256877 .. 0.97640597403447005]
# ===> [0.97640597403447004 .. 0.97640597403447005] [-0.40795221759280565 .. 0.0017776543608468698]
# b = -1.?
# found upper bound!
# ===> [0.00000000000000000 .. 0.47242772601256878] [-0.45504581846129167 .. 0.69288705941544804]
#   I  = [0.00000000000000000 .. 0.47242772601256878]
# f(I) = [-0.45504581846129167 .. 0.69288705941544804]
# ===> [0.23621386300628438 .. 0.23621386300628439] [0.070189563322540338 .. 0.42193686265336983]
# ===> [0.97740597403447004 .. 0.97740597403447005] [-0.40891525805306439 .. 0.00056148627673169305]
# 0 on lower boundary!
# ===> [0.97740597403447004 .. 0.97740597403447005] [-0.40891525805306462 .. 0.00056148627673169305]
# ===> [0.97740597403447004 .. 0.97740597403447005] [-0.40891525805306439 .. 0.00056148627673169305]
# ===> [0.97740597403447004 .. 0.97740597403447005] [-0.40891525805306439 .. 0.00056148627673169305]
# ===> [0.97740597403447004 .. 0.98728003377481466] [-0.42390685338692114 .. 0.0043013445282559238]
# ===> [0.98728003377481465 .. 0.98728003377481466] [-0.41842603035175219 .. -0.011496979591157807]
# ===> [0.98728003377481465 .. 0.98728003377481466] [-0.41842603035175219 .. -0.011496979591157807]
# t = [0.97740597403447004 .. 0.98728003377481466]
# ===> [0.98728003377481465 .. 0.98728003377481466] [-0.41842603035175241 .. -0.011496979591158029]
# b = -1.?
# stopping since presumed converged
# t = [0.97740597403447004 .. 0.98728003377481466], fprime(t) = [-0.63968609552830458 .. -0.074526319280266761]
# ===> [1.0000000000000000 .. 1.0000000000000000] [-0.43067866634300195 .. -0.027160436334062287]
# ===> [0.98820298701723507 .. 0.98820298701723508] [-0.41931511436161729 .. -0.012628677776028163]
# returning res = True
# returning res = True
# Signal([0.00000000000000000 .. 5.0000000000000000], [([0.00000000000000000 .. 5.0000000000000000], True)])

# %% [markdown]
# ## Using flow* output

# %%
from flowstar.reachability import Poly, Reach

varsd = [b't', b'x', b'y']
qt = Poly(1, 't', 0, varsd)
qx = Poly(-1, 'y', 1, varsd)
qy = Poly(1, 'x', 1, varsd)
print "t' = {}\nx' = {}\ny' = {}".format(qt, qx, qy)

D = Reach(
    varsd,
    [qt, qx, qy],
    [(0,0), (4,5), (1,2)],
    10,
    0.1,
    order=5,
)
