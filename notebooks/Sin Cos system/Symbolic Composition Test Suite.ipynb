# %% [markdown]
# # Tests

# %% [markdown]
# ## Example 1: Simple

# %%
import sys

sys.path.insert(0, "/home/twright/Documents/PhD/Notebooks")

from flowstar.reachability import Reach
from flowstar.poly import Poly
from lbuc import *

# %%
kwargs = {
    'symbolic_composition': True,
}

# %%
R.<t,x,y> = RIF[]

# %%
TM_ORDER = 4
UNPRECONDITIONING_ORDER = 1

# %%
odes = [
    R(1),
    -y,
    x,
]
initials = [(0,0), (4,5), (1,2)]
system = System(
    R,
    [t, x, y],
    initials,
    odes,
)
reach = system.reach(2*pi, step=0.1, order=TM_ORDER,
              precompose_taylor_models=False,
              unpreconditioning_order=UNPRECONDITIONING_ORDER,
              symbolic_composition=False)
reach_superfine = system.reach(2*pi, step=0.01, order=TM_ORDER,
              precompose_taylor_models=False,
              symbolic_composition=False)
# Out:
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.0000000000000000 .. 5.0000000000000000]', '[1.0000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.0..5.0]
# C = [1.0..2.0]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.0000000000000000 .. 5.0000000000000000]', '[1.0000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.0..5.0]
# C = [1.0..2.0]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2

# %%
[4 + x for x in srange(0, 1, 0.1, include_endpoint=True)]
# Out:
# [4.00000000000000,
#  4.10000000000000,
#  4.20000000000000,
#  4.30000000000000,
#  4.40000000000000,
#  4.50000000000000,
#  4.60000000000000,
#  4.70000000000000,
#  4.80000000000000,
#  4.90000000000000,
#  5.00000000000000]

# %%
reach_points = [system.with_y0([(0,0), (4 + k), (1 + k)]).reach(2*pi, step=0.01, order=TM_ORDER,
              precompose_taylor_models=False,
              symbolic_composition=False)
    for k in srange(0, 1, 0.1, include_endpoint=True)]
reach_bands = [system.with_y0([(0,0), (4 + k, 4.1 + k), (1 + k, 1.1 + k)]).reach(2*pi, step=0.01, order=TM_ORDER,
               precompose_taylor_models=False,
               symbolic_composition=False)
     for k in srange(0, 1, 0.1, include_endpoint=False)]
# Out:
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.0000000000000000 .. 4.0000000000000000]', '[1.0000000000000000 .. 1.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.0..4.0]
# C = [1.0..1.0]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.0999999999999996 .. 4.0999999999999997]', '[1.1000000000000000 .. 1.1000000000000001]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.1..4.1]
# C = [1.1..1.1]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.2000000000000001 .. 4.2000000000000002]', '[1.1999999999999999 .. 1.2000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.2..4.2]
# C = [1.2..1.2]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.2999999999999998 .. 4.2999999999999999]', '[1.3000000000000000 .. 1.3000000000000001]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.3..4.3]
# C = [1.3..1.3]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.4000000000000003 .. 4.4000000000000004]', '[1.3999999999999999 .. 1.4000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.4..4.4]
# C = [1.4..1.4]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.5000000000000000 .. 4.5000000000000000]', '[1.5000000000000000 .. 1.5000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.5..4.5]
# C = [1.5..1.5]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.5999999999999996 .. 4.5999999999999997]', '[1.6000000000000000 .. 1.6000000000000001]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.6..4.6]
# C = [1.6..1.6]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.7000000000000001 .. 4.7000000000000002]', '[1.6999999999999999 .. 1.7000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.7..4.7]
# C = [1.7..1.7]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.7999999999999998 .. 4.7999999999999999]', '[1.7999999999999998 .. 1.7999999999999999]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.8..4.8]
# C = [1.7999999999999998..1.7999999999999998]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.9000000000000003 .. 4.9000000000000004]', '[1.8999999999999999 .. 1.9000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.9..4.9]
# C = [1.9..1.9]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[5.0000000000000000 .. 5.0000000000000000]', '[2.0000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [5.0..5.0]
# C = [2.0..2.0]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.0000000000000000 .. 4.0999999999999997]', '[1.0000000000000000 .. 1.1000000000000001]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.0..4.1]
# C = [1.0..1.1]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.0999999999999996 .. 4.1999999999999993]', '[1.1000000000000000 .. 1.2000000000000002]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.1..4.199999999999999]
# C = [1.1..1.2000000000000002]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.2000000000000001 .. 4.2999999999999999]', '[1.1999999999999999 .. 1.3000000000000001]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.2..4.3]
# C = [1.2..1.3]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.2999999999999998 .. 4.3999999999999995]', '[1.3000000000000000 .. 1.4000000000000002]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.3..4.3999999999999995]
# C = [1.3..1.4000000000000001]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.4000000000000003 .. 4.5000000000000000]', '[1.3999999999999999 .. 1.5000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.4..4.5]
# C = [1.4..1.5]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.5000000000000000 .. 4.5999999999999997]', '[1.5000000000000000 .. 1.6000000000000001]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.5..4.6]
# C = [1.5..1.6]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.5999999999999996 .. 4.6999999999999993]', '[1.6000000000000000 .. 1.7000000000000002]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.6..4.699999999999999]
# C = [1.6..1.7000000000000002]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.7000000000000001 .. 4.7999999999999999]', '[1.6999999999999999 .. 1.8000000000000001]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.7..4.8]
# C = [1.7..1.8]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.7999999999999998 .. 4.8999999999999995]', '[1.7999999999999998 .. 1.9000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.8..4.8999999999999995]
# C = [1.7999999999999998..1.9]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.9000000000000003 .. 5.0000000000000000]', '[1.8999999999999999 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.9..5.0]
# C = [1.9..2.0]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2

# %%
def plot_signal(sig):
    return sig.to_domain(RIF(0,2*pi)).plot().show(
        ticks=[pi/2, 1], tick_formatter=pi, aspect_ratio=2/3)

# %%
reach.res
# Out:
# 2

# %%
#S = Atomic(x + 1); S

# %%
S = Atomic(7 - (x + 1)**2 + y + x); S
# Out:
# Atomic(-x^2 - x + y + 6)

# %%
#S = Atomic(3 - y**2 + y); S

# %%
# Very Weird S
#S = Atomic(3 - y**2 + y + x**5 + x**3*y**6); S

# %%
p_points = sum([
    S.sage_plot(r, symbolic_composition=False,
                color=('black', 'black'),
                fillcolor=('black',))
    for r in reach_points
], Graphics())
# p_points += sum([
#     S.sage_plot(r, symbolic_composition=False,
#                 color=('grey', 'grey'),
#                 fillcolor=('grey',))
#     for r in reach_bands
# ], Graphics())
p_points
# Out:
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7fb57256b480>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=4, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7fb57256b590>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=4, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7fb57256b6a0>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=4, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7fb57256b7b0>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=4, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7fb57256b8c0>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=4, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7fb57256b9d0>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=4, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7fb57256bae0>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=4, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7fb57256bbf0>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=4, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7fb57256bd00>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=4, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7fb57256be10>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=4, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7fb5724d6040>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=4, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# /usr/lib64/python3.8/site-packages/numpy/core/getlimits.py:400: UserWarning: Signature b'\x99\x99\x99\x99\x99\x99\xb9\xbf' for <class 'numpy.float64'> does not match any known type: falling back to type probe function
#   machar = _get_machar(dtype)
# Graphics object consisting of 33 graphics primitives

# %%
p1 = S.sage_plot(reach); p1 + p_points
# Out:
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7fb57256b150>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=1, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# Graphics object consisting of 36 graphics primitives

# %%
SYMBOLIC_COMPOSITION_ORDER = None

# %%
p2 = S.sage_plot(
    reach, symbolic_composition=True,
    symbolic_composition_order=SYMBOLIC_COMPOSITION_ORDER,
    color=('orange', 'orange'),
    fillcolor=('orange',),
)
p2 + p_points
# Out:
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7fb57256b150>, 2*x*y + x + y, symbolic_composition=True, symbolic_composition_order=1, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# Graphics object consisting of 36 graphics primitives

# %%
p1+p2+p_points
# Out:
# Graphics object consisting of 39 graphics primitives

# %%
from functools import reduce

# %%
combined_signal = reduce(
    lambda a, b: a & b,
    (S.signal(r, symbolic_composition=False)
     for r in reach_bands),
)
combined_signal.plot()
# Out:
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7f
]
# signal given bool roots: 1 items in 0.00 seconds
# Monitoring atomic -x^2 - x + y + 6 > 0: 1 items in 0.04 seconds
# Graphics object consisting of 2 graphics primitives

# %%
INCLUDE_DERIVS = None

# %%
sig1 = S.signal_for_system(system, 2*pi, symbolic_composition=False,
    selective_unpreconditioning=False,
    unpreconditioning_order=UNPRECONDITIONING_ORDER,
    unpreconditioning_include_derivs=INCLUDE_DERIVS)
sig2 = S.signal_for_system(
    system, 2*pi, symbolic_composition=True,
    symbolic_composition_order=SYMBOLIC_COMPOSITION_ORDER,
    unpreconditioning_order=UNPRECONDITIONING_ORDER,
    selective_unpreconditioning=False,
    unpreconditioning_include_derivs=INCLUDE_DERIVS,
)
sig3 = S.signal_for_system(system, 2*pi, symbolic_composition=False,
    selective_unpreconditioning=True,
    unpreconditioning_order=UNPRECONDITIONING_ORDER,
    selective_unpreconditioning_include_derivs=INCLUDE_DERIVS)
sig4 = S.signal_for_system(
    system, 2*pi, symbolic_composition=True,
    symbolic_composition_order=SYMBOLIC_COMPOSITION_ORDER,
    selective_unpreconditioning=True,
    unpreconditioning_order=UNPRECONDITIONING_ORDER,
    unpreconditioning_include_derivs=INCLUDE_DERIVS
)

g = graphics_array([
    sig1.plot(),
    sig2.plot(),
    sig3.plot(),
    sig4.plot(),
    combined_signal.plot(),
], ncols=1)
g.show(aspect_ratio=1/6)
# Out:
# Precomposing Contexts: 1 items in 0.00 seconds
# include_derivs = True
# phi variables sfs = {x, y}
# system sfs = System(R, (t, x, y), [0, [4 .. 5], [1 .. 2]], (1, -y, x), varmap=bidict({'t': t, 'x': x, 'y': y}))
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.0000000000000000 .. 5.0000000000000000]', '[1.0000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.0..5.0]
# C = [1.0..2.0]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# Running Flow*: 1 items in 0.02 seconds
# Computed 63 flowpipes in 0.024697749060578644 sec
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7fb566a45150>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=1, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# symbolic_composition=False,symbolic_composition_order=1, tentative_unpreconditioning=True,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.02 seconds
# roots = [[0.43295214282981459 .. 0.84891712902838279], [1.8999999999999959 .. 2.4000000000000022], [3.6804281140221810 .. 4.7390675084272056]]
# domain = [0.0000000000000000 .. 6.2851853071795869]
# roots = [[0.43295214282981459 .. 0.84891712902838279],
#  [1.8999999999999959 .. 2.4000000000000022],
#  [3.6804281140221810 .. 4.7390675084272056]]
# seg_domain = [0.0000000000000000 .. 6.2851853071795869]
# roots = [[0.43295214282981459 .. 0.84891712902838279],
#  [1.8999999999999959 .. 2.4000000000000022],
#  [3.6804281140221810 .. 4.7390675084272056]]
# signal given bool roots: 1 items in 0.00 seconds
# Monitoring atomic -x^2 - x + y + 6 > 0: 1 items in 0.02 seconds
# Monitoring Signal for -x^2 - x + y + 6 > 0: 1 items in 0.03 seconds
# ran "restoring globals" 9 times in 0.00010275840759277344
# ran "capturing globals [on exit]" 9 times in 6.604194641113281e-05
# ran "mask intersect check" 63 times in 0.00012063980102539062
# ran "tentative eval" 63 times in 0.011592626571655273
# ran "composing flowpipe" 22 times in 0.007358551025390625
# ran "whole domain eval" 22 times in 0.0002548694610595703
# ran "post retrieve" 22 times in 9.894371032714844e-05
# ran "root detection" 22 times in 0.0005664825439453125
# ran "root amalgamation" 22 times in 3.62396240234375e-05
# ran "prepare in check" 4 times in 2.1696090698242188e-05
# ran "check boolean [unguarded]" 4 times in 4.00543212890625e-05
# ran "observer.check" 4 times in 0.00016927719116210938
# Precomposing Contexts: 1 items in 0.00 seconds
# include_derivs = False
# phi variables sfs = {x, y}
# system sfs = System(R, (t, x, y), [0, [4 .. 5], [1 .. 2]], (1, -y, x), varmap=bidict({'t': t, 'x': x, 'y': y}))
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.0000000000000000 .. 5.0000000000000000]', '[1.0000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.0..5.0]
# C = [1.0..2.0]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# Running Flow*: 1 items in 0.03 seconds
# Computed 63 flowpipes in 0.027420308091677725 sec
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7fb566a45260>, 2*x*y + x + y, symbolic_composition=True, symbolic_composition_order=1, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# symbolic_composition=True,symbolic_composition_order=1, tentative_unpreconditioning=True,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.02 seconds
# roots = [[0.45231058046112943 .. 0.80000000000000038], [1.9809680674111789 .. 2.3279833542353213], [3.7291690899309148 .. 4.1545163355205253], [4.4449611598260192 .. 4.6988229544116261], [4.6999999999999708 .. 4.7234529496071485]]
# domain = [0.0000000000000000 .. 6.2851853071795869]
# roots = [[0.45231058046112943 .. 0.80000000000000038],
#  [1.9809680674111789 .. 2.3279833542353213],
#  [3.7291690899309148 .. 4.1545163355205253],
#  [4.4449611598260192 .. 4.6988229544116261],
#  [4.6999999999999708 .. 4.7234529496071485]]
# seg_domain = [0.0000000000000000 .. 6.2851853071795869]
# roots = [[0.45231058046112943 .. 0.80000000000000038],
#  [1.9809680674111789 .. 2.3279833542353213],
#  [3.7291690899309148 .. 4.1545163355205253],
#  [4.4449611598260192 .. 4.6988229544116261],
#  [4.6999999999999708 .. 4.7234529496071485]]
# signal given bool roots: 1 items in 0.00 seconds
# Monitoring atomic -x^2 - x + y + 6 > 0: 1 items in 0.02 seconds
# Monitoring Signal for -x^2 - x + y + 6 > 0: 1 items in 0.03 seconds
# ran "restoring globals" 9 times in 8.320808410644531e-05
# ran "capturing globals [on exit]" 9 times in 6.127357482910156e-05
# ran "mask intersect check" 63 times in 0.00011348724365234375
# ran "tentative eval" 63 times in 0.008520364761352539
# ran "composing flowpipe" 24 times in 0.006884098052978516
# ran "whole domain eval" 22 times in 0.00022745132446289062
# ran "post retrieve" 22 times in 0.0011615753173828125
# ran "root detection" 22 times in 0.00010633468627929688
# ran "root amalgamation" 22 times in 3.0517578125e-05
# ran "prepare in check" 6 times in 3.0994415283203125e-05
# ran "check boolean [unguarded]" 6 times in 6.794929504394531e-05
# ran "observer.check" 6 times in 0.0002262592315673828
# Precomposing Contexts: 1 items in 0.00 seconds
# include_derivs = True
# phi variables sfs = {x, y}
# system sfs = System(R, (t, x, y), [0, [4 .. 5], [1 .. 2]], (1, -y, x), varmap=bidict({'t': t, 'x': x, 'y': y}))
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.0000000000000000 .. 5.0000000000000000]', '[1.0000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.0..5.0]
# C = [1.0..2.0]
# assigning system with dimension 3
# resulting system has dimension 3
# unpreconditioning_orders = [-1, 1, 1]
# run within tmv args
# integrationScheme = 2
# Running Flow*: 1 items in 0.02 seconds
# Computed 63 flowpipes in 0.025214645080268383 sec
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7fb566a45590>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=1, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# symbolic_composition=False,symbolic_composition_order=1, tentative_unpreconditioning=True,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.02 seconds
# roots = [[0.43295214282981459 .. 0.84891712902838279], [1.8999999999999959 .. 2.4000000000000022], [3.6804281140221810 .. 4.7390675084272056]]
# domain = [0.0000000000000000 .. 6.2851853071795869]
# roots = [[0.43295214282981459 .. 0.84891712902838279],
#  [1.8999999999999959 .. 2.4000000000000022],
#  [3.6804281140221810 .. 4.7390675084272056]]
# seg_domain = [0.0000000000000000 .. 6.2851853071795869]
# roots = [[0.43295214282981459 .. 0.84891712902838279],
#  [1.8999999999999959 .. 2.4000000000000022],
#  [3.6804281140221810 .. 4.7390675084272056]]
# signal given bool roots: 1 items in 0.00 seconds
# Monitoring atomic -x^2 - x + y + 6 > 0: 1 items in 0.02 seconds
# Monitoring Signal for -x^2 - x + y + 6 > 0: 1 items in 0.03 seconds
# ran "restoring globals" 9 times in 8.559226989746094e-05
# ran "capturing globals [on exit]" 9 times in 6.079673767089844e-05
# ran "mask intersect check" 63 times in 0.00010418891906738281
# ran "tentative eval" 63 times in 0.009041786193847656
# ran "composing flowpipe" 22 times in 0.0062906742095947266
# ran "whole domain eval" 22 times in 0.0002040863037109375
# ran "post retrieve" 22 times in 0.00010371208190917969
# ran "root detection" 22 times in 0.00044083595275878906
# ran "root amalgamation" 22 times in 2.9325485229492188e-05
# ran "prepare in check" 4 times in 2.09808349609375e-05
# ran "check boolean [unguarded]" 4 times in 3.2901763916015625e-05
# ran "observer.check" 4 times in 0.0001494884490966797
# Precomposing Contexts: 1 items in 0.00 seconds
# include_derivs = False
# phi variables sfs = {x, y}
# system sfs = System(R, (t, x, y), [0, [4 .. 5], [1 .. 2]], (1, -y, x), varmap=bidict({'t': t, 'x': x, 'y': y}))
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.0000000000000000 .. 5.0000000000000000]', '[1.0000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.0..5.0]
# C = [1.0..2.0]
# assigning system with dimension 3
# resulting system has dimension 3
# unpreconditioning_orders = [-1, 1, 1]
# run within tmv args
# integrationScheme = 2
# Running Flow*: 1 items in 0.02 seconds
# Computed 63 flowpipes in 0.025764716032426804 sec
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7fb566a457b0>, 2*x*y + x + y, symbolic_composition=True, symbolic_composition_order=1, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# symbolic_composition=True,symbolic_composition_order=1, tentative_unpreconditioning=True,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.02 seconds
# roots = [[0.45231058046112943 .. 0.80000000000000038], [1.9809680674111789 .. 2.3279833542353213], [3.7291690899309148 .. 4.1545163355205253], [4.4449611598260192 .. 4.6988229544116261], [4.6999999999999708 .. 4.7234529496071485]]
# domain = [0.0000000000000000 .. 6.2851853071795869]
# roots = [[0.45231058046112943 .. 0.80000000000000038],
#  [1.9809680674111789 .. 2.3279833542353213],
#  [3.7291690899309148 .. 4.1545163355205253],
#  [4.4449611598260192 .. 4.6988229544116261],
#  [4.6999999999999708 .. 4.7234529496071485]]
# seg_domain = [0.0000000000000000 .. 6.2851853071795869]
# roots = [[0.45231058046112943 .. 0.80000000000000038],
#  [1.9809680674111789 .. 2.3279833542353213],
#  [3.7291690899309148 .. 4.1545163355205253],
#  [4.4449611598260192 .. 4.6988229544116261],
#  [4.6999999999999708 .. 4.7234529496071485]]
# signal given bool roots: 1 items in 0.00 seconds
# Monitoring atomic -x^2 - x + y + 6 > 0: 1 items in 0.02 seconds
# Monitoring Signal for -x^2 - x + y + 6 > 0: 1 items in 0.03 seconds
# ran "restoring globals" 9 times in 0.00011491775512695312
# ran "capturing globals [on exit]" 9 times in 8.344650268554688e-05
# ran "mask intersect check" 63 times in 0.00011658668518066406
# ran "tentative eval" 63 times in 0.00854039192199707
# ran "composing flowpipe" 24 times in 0.006763458251953125
# ran "whole domain eval" 22 times in 0.0001990795135498047
# ran "post retrieve" 22 times in 0.0011115074157714844
# ran "root detection" 22 times in 0.00011563301086425781
# ran "root amalgamation" 22 times in 3.170967102050781e-05
# ran "prepare in check" 6 times in 3.075599670410156e-05
# ran "check boolean [unguarded]" 6 times in 8.106231689453125e-05
# ran "observer.check" 6 times in 0.00024056434631347656
# Graphics Array of size 5 x 1

# %%
sig1
# Out:
# Signal([0.0000000000000000 .. 6.2831853071795872], [([0.0000000000000000 .. 0.43295214282981460], False), ([0.84891712902838278 .. 1.8999999999999960], True), ([2.4000000000000021 .. 3.6804281140221811], False), ([4.7390675084272055 .. 6.2831853071795872], False)], mask=None)

# %%
sig2
# Out:
# Signal([0.0000000000000000 .. 6.2831853071795872], [([0.0000000000000000 .. 0.45231058046112944], False), ([0.80000000000000037 .. 1.9809680674111790], True), ([2.3279833542353212 .. 3.7291690899309149], False), ([4.1545163355205252 .. 4.4449611598260193], True), ([4.6988229544116260 .. 4.6999999999999709], False), ([4.7234529496071484 .. 6.2831853071795872], False)], mask=None)
