# %%
import sys

sys.path.insert(0, "/home/twright/Documents/PhD/Notebooks")

# %%
# %display latex
from ulbc import *
from flowstar import *
from ulbc.bondcalculus import *

# %%
R.<x1,x2,x3,x4,x5,x6,x7,x8,x9> = RIF[]

# %%
y = vector([
    10*x3 - RIF('0.1')*x1*x6,
    100*x4 - x1*x2,
    RIF('0.1')*x1*x6 - 50*x3,
    x2*x6 - 100*x4,
    5*x3 + RIF('0.5')*x1 - 10*x5,
    50*x5 + 50*x3 + 100*x4 - x6*(RIF('0.1')*x1 + x2 + 2*x8 + 1),
    50*x4 + RIF('0.01')*x2 - RIF('0.5')*x7,
    RIF('0.5')*x7 - 2*x6*x8 + x9 - RIF('0.2')*x8,
    2*x6*x8 - x9,
])

# %%
table([[yi] for yi in y])
# Out:
#   -0.10000000000000000?*x1*x6 + 10*x3
#   -x1*x2 + 100*x4
#   0.10000000000000000?*x1*x6 - 50*x3
#   x2*x6 - 100*x4
#   0.50000000000000000?*x1 + 5*x3 - 10*x5
#   -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6
#   0.01000000000000000?*x2 + 50*x4 - 0.50000000000000000?*x7
#   -2*x6*x8 + 0.50000000000000000?*x7 - 0.2000000000000000?*x8 + x9
#   2*x6*x8 - x9

# %%
y0 = [
    RIF('[0.98, 1.02]'),
    RIF('[1.28, 1.32]'),
    RIF('[0.08, 0.12]'),
    RIF('[0.08, 0.12]'), # x4
    RIF('[0.08, 0.12]'),
    RIF('[1.28, 1.32]'), # x6
    RIF('[2.48, 2.52]'),
    RIF('[0.58, 0.62]'),
    RIF('[1.28, 1.32]'),
]

# %%
table([y0i.endpoints() for y0i in y0])
# Out:
#   0.979999999999999    1.02000000000001
#   1.27999999999999     1.32000000000001
#   0.0799999999999999   0.120000000000001
#   0.0799999999999999   0.120000000000001
#   0.0799999999999999   0.120000000000001
#   1.27999999999999     1.32000000000001
#   2.47999999999999     2.52000000000001
#   0.579999999999999    0.620000000000001
#   1.27999999999999     1.32000000000001

# %%
sys = System(R, R.gens(), y0, y); sys
# Out:
# System(R, (x1, x2, x3, x4, x5, x6, x7, x8, x9), [[0.97999999999999998 .. 1.0200000000000001], [1.2799999999999998 .. 1.3200000000000001], [0.079999999999999987 .. 0.12000000000000001], [0.079999999999999987 .. 0.12000000000000001], [0.079999999999999987 .. 0.12000000000000001], [1.2799999999999998 .. 1.3200000000000001], [2.4799999999999999 .. 2.5200000000000001], [0.57999999999999996 .. 0.62000000000000011], [1.2799999999999998 .. 1.3200000000000001]], (-0.10000000000000000?*x1*x6 + 10*x3, -x1*x2 + 100*x4, 0.10000000000000000?*x1*x6 - 50*x3, x2*x6 - 100*x4, 0.50000000000000000?*x1 + 5*x3 - 10*x5, -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6, 0.01000000000000000?*x2 + 50*x4 - 0.50000000000000000?*x7, -2*x6*x8 + 0.50000000000000000?*x7 - 0.2000000000000000?*x8 + x9, 2*x6*x8 - x9), varmap=bidict({'x1': x1, 'x2': x2, 'x3': x3, 'x4': x4, 'x5': x5, 'x6': x6, 'x7': x7, 'x8': x8, 'x9': x9}))

# %%
def test_monitoring(prop, duration, **kwargs):
    t0 = time.time()
    sig = prop.signal_for_system(sys,
    duration, order=4, step=0.003,
    precondition=1,
    estimation=1e-1,
    max_remainder_queue=100,
    integration_method=IntegrationMethod.ONLY_PICARD_SYMB,
    cutoff_threshold=1e-6,
    **kwargs)
    t1 = time.time()
    print(f"Run done in {t1 - t0} sec\noptions: {repr(kwargs)}")
    return t1 - t0, sig

# %%
prop = Atomic(var("x6") > 1.4)
prop
# Out:
# Atomic(x6 > 1.40000000000000)

# %%
test_monitoring(prop, 4, use_masks=False)[1].plot()
# Out:
# Precomposing Contexts: 1 items in 0.00 seconds
# calling reach with y0 = ['[0.97999999999999998 .. 1.0200000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[2.4799999999999999 .. 2.5200000000000001]', '[0.57999999999999996 .. 0.62000000000000011]', '[1.2799999999999998 .. 1.3200000000000001]']
# ode in polynomial ring
# entering managed function _init_args
# crude_roots = False
# _handle_initials called!
# vars = [x1, x2, x3, x4, x5, x6, x7, x8, x9]
# C = [0.98..1.02]
# C = [1.2799999999999998..1.32]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [1.2799999999999998..1.32]
# C = [2.48..2.52]
# C = [0.58..0.6200000000000001]
# C = [1.2799999999999998..1.32]
# assigning system with dimension 9
# resulting system has dimension 9
# run within tmv args
# entering managed function run
# integrationScheme = 7
# Running Flow*: 1 items in 44.53 seconds
# Computed 1334 flowpipes in 44.53030311700002 sec
# entering managed function prepare
# PolyObserver(x6 - 1.4000000000000000?, <flowstar.reachability.Reach object at 0x7f174cfdcb90>, -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6 symbolic_composition=False, tentative_unpreconditioning=True, mask=None)
# entering managed function prepare
# symbolic_composition=False, tentative_unpreconditioning=True
# entering managed function roots
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 5.78 seconds
# roots = [[0.0048028783727901138 .. 0.020435765977123051], [0.20345478283219919 .. 0.48300000000000043]]
# domain = [0.0000000000000000 .. 4.0000000000000009]
# roots = [[0.0048028783727901138 .. 0.020435765977123051],
#  [0.20345478283219919 .. 0.48300000000000043]]
# seg_domain = [0.0000000000000000 .. 4.0000000000000009]
# roots = [[0.0048028783727901138 .. 0.020435765977123051],
#  [0.20345478283219919 .. 0.48300000000000043]]
# entering managed function check
# entering managed function prepare
# running f_bool: 1 items in 0.00 seconds
# entering managed function check
# entering managed function prepare
# running f_bool: 1 items in 0.00 seconds
# entering managed function check
# entering managed function prepare
# running f_bool: 1 items in 0.00 seconds
# signal given bool roots: 1 items in 0.00 seconds
# Monitoring Signal for x6 > 1.40000000000000: 1 items in 7.43 seconds
# Monitored signal in 7.426805136999917 sec
# ran "check boolean [unguarded]" 3 times in 0.0002951622009277344
# ran "restoring globals" 9 times in 0.0037500858306884766
# ran "whole domain eval" 102 times in 0.18879199028015137
# ran "root amalgamation" 100 times in 8.96453857421875e-05
# ran "root detection" 100 times in 0.38504457473754883
# ran "post retrieve" 100 times in 0.0007650852203369141
# ran "observer.check" 3 times in 0.0010063648223876953
# ran "prepare in check" 3 times in 0.0005645751953125
# ran "composing flowpipe" 102 times in 4.1461310386657715
# ran "capturing globals [on exit]" 9 times in 0.00029778480529785156
# ran "mask intersect check" 1334 times in 0.0007724761962890625
# ran "tentative eval" 1334 times in 1.0339109897613525
# Run done in 52.02371668815613 sec
# options: {'use_masks': False}
# /usr/lib64/python3.7/site-packages/numpy/core/getlimits.py:400: UserWarning: Signature b'\x99\x99\x99\x99\x99\x99\xb9\xbf' for <class 'numpy.float64'> does not match any known type: falling back to type probe function
#   machar = _get_machar(dtype)
# Graphics object consisting of 2 graphics primitives

# %%
test_monitoring(prop, 4, use_masks=False, tentative_unpreconditioning=False)[1].plot()
# Out:
# Precomposing Contexts: 1 items in 0.00 seconds
# calling reach with y0 = ['[0.97999999999999998 .. 1.0200000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[2.4799999999999999 .. 2.5200000000000001]', '[0.57999999999999996 .. 0.62000000000000011]', '[1.2799999999999998 .. 1.3200000000000001]']
# ode in polynomial ring
# entering managed function _init_args
# crude_roots = False
# _handle_initials called!
# vars = [x1, x2, x3, x4, x5, x6, x7, x8, x9]
# C = [0.98..1.02]
# C = [1.2799999999999998..1.32]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [1.2799999999999998..1.32]
# C = [2.48..2.52]
# C = [0.58..0.6200000000000001]
# C = [1.2799999999999998..1.32]
# assigning system with dimension 9
# resulting system has dimension 9
# run within tmv args
# entering managed function run
# integrationScheme = 7
# Running Flow*: 1 items in 42.02 seconds
# Computed 1334 flowpipes in 42.019696948000046 sec
# entering managed function prepare
# PolyObserver(x6 - 1.4000000000000000?, <flowstar.reachability.Reach object at 0x7f1745476b90>, -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6 symbolic_composition=False, tentative_unpreconditioning=False, mask=None)
# entering managed function prepare
# symbolic_composition=False, tentative_unpreconditioning=False
# entering managed function roots
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 69.24 seconds
# roots = [[0.0048028783727901138 .. 0.020435765977123051], [0.20345478283219919 .. 0.48300000000000043]]
# domain = [0.0000000000000000 .. 3.9999999999999996]
# roots = [[0.0048028783727901138 .. 0.020435765977123051],
#  [0.20345478283219919 .. 0.48300000000000043]]
# seg_domain = [0.0000000000000000 .. 3.9999999999999996]
# roots = [[0.0048028783727901138 .. 0.020435765977123051],
#  [0.20345478283219919 .. 0.48300000000000043]]
# entering managed function check
# entering managed function prepare
# running f_bool: 1 items in 0.00 seconds
# entering managed function check
# entering managed function prepare
# running f_bool: 1 items in 0.00 seconds
# entering managed function check
# entering managed function prepare
# running f_bool: 1 items in 0.00 seconds
# signal given bool roots: 1 items in 0.00 seconds
# Monitoring Signal for x6 > 1.40000000000000: 1 items in 69.29 seconds
# Monitored signal in 69.29371510699991 sec
# ran "check boolean [unguarded]" 3 times in 0.0003421306610107422
# ran "restoring globals" 9 times in 0.0003960132598876953
# ran "whole domain eval" 1334 times in 2.3501012325286865
# ran "root amalgamation" 100 times in 0.00011801719665527344
# ran "root detection" 100 times in 0.3858509063720703
# ran "post retrieve" 100 times in 0.0009677410125732422
# ran "observer.check" 3 times in 0.0005729198455810547
# ran "prepare in check" 3 times in 6.437301635742188e-05
# ran "composing flowpipe" 1334 times in 66.43117308616638
# ran "capturing globals [on exit]" 9 times in 0.00035309791564941406
# ran "mask intersect check" 1334 times in 0.0012989044189453125
# Run done in 111.42941188812256 sec
# options: {'use_masks': False, 'tentative_unpreconditioning': False}
# Graphics object consisting of 2 graphics primitives

# %%
test_monitoring(prop, 4, use_masks=False, tentative_unpreconditioning=False, precompose_taylor_models=True)[1].plot()
# Out:
# Precomposing Contexts: 1 items in 0.00 seconds
# calling reach with y0 = ['[0.97999999999999998 .. 1.0200000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[2.4799999999999999 .. 2.5200000000000001]', '[0.57999999999999996 .. 0.62000000000000011]', '[1.2799999999999998 .. 1.3200000000000001]']
# ode in polynomial ring
# entering managed function _init_args
# crude_roots = False
# _handle_initials called!
# vars = [x1, x2, x3, x4, x5, x6, x7, x8, x9]
# C = [0.98..1.02]
# C = [1.2799999999999998..1.32]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [1.2799999999999998..1.32]
# C = [2.48..2.52]
# C = [0.58..0.6200000000000001]
# C = [1.2799999999999998..1.32]
# assigning system with dimension 9
# resulting system has dimension 9
# run within tmv args
# entering managed function run
# integrationScheme = 7
# entering managed function precompose_taylor_models
# entering managed function prepare
# Running Flow*: 1 items in 54.22 seconds
# Computed 1334 flowpipes in 54.22418720300004 sec
# entering managed function prepare
# PolyObserver(x6 - 1.4000000000000000?, <flowstar.reachability.Reach object at 0x7f1745476e60>, -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6 symbolic_composition=False, tentative_unpreconditioning=False, mask=None)
# entering managed function prepare
# symbolic_composition=False, tentative_unpreconditioning=False
# entering managed function roots
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 75.41 seconds
# roots = [[0.0048028783727901138 .. 0.020435765977123051], [0.20345478283219919 .. 0.48300000000000043]]
# domain = [0.0000000000000000 .. 3.9999999999999996]
# roots = [[0.0048028783727901138 .. 0.020435765977123051],
#  [0.20345478283219919 .. 0.48300000000000043]]
# seg_domain = [0.0000000000000000 .. 3.9999999999999996]
# roots = [[0.0048028783727901138 .. 0.020435765977123051],
#  [0.20345478283219919 .. 0.48300000000000043]]
# entering managed function check
# entering managed function prepare
# running f_bool: 1 items in 0.00 seconds
# entering managed function check
# entering managed function prepare
# running f_bool: 1 items in 0.00 seconds
# entering managed function check
# entering managed function prepare
# running f_bool: 1 items in 0.00 seconds
# signal given bool roots: 1 items in 0.00 seconds
# Monitoring Signal for x6 > 1.40000000000000: 1 items in 75.46 seconds
# Monitored signal in 75.45934033399999 sec
# ran "check boolean [unguarded]" 3 times in 0.0003197193145751953
# ran "restoring globals" 9 times in 0.00043892860412597656
# ran "whole domain eval" 1334 times in 2.6491801738739014
# ran "precomposing taylor models" 1 times in 0.14381957054138184
# ran "root amalgamation" 100 times in 0.00010466575622558594
# ran "root detection" 100 times in 0.3820979595184326
# ran "post retrieve" 100 times in 0.00096893310546875
# ran "observer.check" 3 times in 0.0005030632019042969
# ran "prepare in check" 3 times in 4.9114227294921875e-05
# ran "composing flowpipe" 1334 times in 72.31056070327759
# ran "capturing globals [on exit]" 9 times in 0.00024318695068359375
# ran "mask intersect check" 1334 times in 0.0013644695281982422
# Run done in 129.6853768825531 sec
# options: {'use_masks': False, 'tentative_unpreconditioning': False, 'precompose_taylor_models': True}
# Graphics object consisting of 2 graphics primitives

# %%
maskA = Mask(RIF(0, 4), [RIF(1, 1.5)])
maskA.plot()
# Out:
# /usr/lib64/python3.7/site-packages/sage/plot/contour_plot.py:205: UserWarning: No contour levels were found within the data range.
#   linewidths=linewidths, linestyles=linestyles)
# Graphics object consisting of 2 graphics primitives

# %%
test_monitoring(prop, 4, mask=maskA)[1].plot()
# Out:
# Precomposing Contexts: 1 items in 0.00 seconds
# calling reach with y0 = ['[0.97999999999999998 .. 1.0200000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[2.4799999999999999 .. 2.5200000000000001]', '[0.57999999999999996 .. 0.62000000000000011]', '[1.2799999999999998 .. 1.3200000000000001]']
# ode in polynomial ring
# entering managed function _init_args
# crude_roots = False
# _handle_initials called!
# vars = [x1, x2, x3, x4, x5, x6, x7, x8, x9]
# C = [0.98..1.02]
# C = [1.2799999999999998..1.32]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [1.2799999999999998..1.32]
# C = [2.48..2.52]
# C = [0.58..0.6200000000000001]
# C = [1.2799999999999998..1.32]
# assigning system with dimension 9
# resulting system has dimension 9
# run within tmv args
# entering managed function run
# integrationScheme = 7
# Running Flow*: 1 items in 49.44 seconds
# Computed 1334 flowpipes in 49.44141848200013 sec
# entering managed function prepare
# PolyObserver(x6 - 1.4000000000000000?, <flowstar.reachability.Reach object at 0x7f1745476d70>, -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6 symbolic_composition=False, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 4.0000000000000000], [[1.0000000000000000 .. 1.5000000000000000]]))
# entering managed function prepare
# symbolic_composition=False, tentative_unpreconditioning=True
# entering managed function roots
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.15 seconds
# roots = []
# domain = [0.0000000000000000 .. 3.9999999999999996]
# roots = []
# seg_domain = [1.0000000000000000 .. 1.5000000000000000]
# roots = []
# entering managed function check
# entering managed function prepare
# running f_bool: 1 items in 0.00 seconds
# signal given bool roots: 1 items in 0.00 seconds
# Monitoring Signal for x6 > 1.40000000000000: 1 items in 0.20 seconds
# Monitored signal in 0.19961909099981767 sec
# ran "check boolean [unguarded]" 1 times in 0.00015425682067871094
# ran "restoring globals" 9 times in 0.0004482269287109375
# ran "observer.check" 1 times in 0.0002493858337402344
# ran "prepare in check" 1 times in 2.6464462280273438e-05
# ran "capturing globals [on exit]" 9 times in 0.0002682209014892578
# ran "mask intersect check" 1334 times in 0.001455068588256836
# ran "tentative eval" 168 times in 0.1474313735961914
# Run done in 49.78690195083618 sec
# options: {'mask': Mask([0.0000000000000000 .. 4.0000000000000000], [[1.0000000000000000 .. 1.5000000000000000]])}
# /usr/lib64/python3.7/site-packages/sage/plot/contour_plot.py:205: UserWarning: No contour levels were found within the data range.
#   linewidths=linewidths, linestyles=linestyles)
# Graphics object consisting of 2 graphics primitives

# %%
zebra_mask = Mask(RIF(0, 4), [RIF(2*k/10, (2*k + 1)/10) for k in range(21)])
zebra_mask.plot()
# Out:
# /usr/lib64/python3.7/site-packages/sage/plot/contour_plot.py:205: UserWarning: No contour levels were found within the data range.
#   linewidths=linewidths, linestyles=linestyles)
# Graphics object consisting of 2 graphics primitives

# %%
test_monitoring(prop, 4, mask=zebra_mask)[1].plot()
# Out:
# Precomposing Contexts: 1 items in 0.00 seconds
# calling reach with y0 = ['[0.97999999999999998 .. 1.0200000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[2.4799999999999999 .. 2.5200000000000001]', '[0.57999999999999996 .. 0.62000000000000011]', '[1.2799999999999998 .. 1.3200000000000001]']
# ode in polynomial ring
# entering managed function _init_args
# crude_roots = False
# _handle_initials called!
# vars = [x1, x2, x3, x4, x5, x6, x7, x8, x9]
# C = [0.98..1.02]
# C = [1.2799999999999998..1.32]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [1.2799999999999998..1.32]
# C = [2.48..2.52]
# C = [0.58..0.6200000000000001]
# C = [1.2799999999999998..1.32]
# assigning system with dimension 9
# resulting system has dimension 9
# run within tmv args
# entering managed function run
# integrationScheme = 7
# Running Flow*: 1 items in 40.78 seconds
# Computed 1334 flowpipes in 40.7837808590001 sec
# entering managed function prepare
# PolyObserver(x6 - 1.4000000000000000?, <flowstar.reachability.Reach object at 0x7f1745476410>, -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6 symbolic_composition=False, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 4.0000000000000000], [[0.0000000000000000 .. 0.10000000000000001], [0.19999999999999998 .. 0.30000000000000005], [0.39999999999999996 .. 0.50000000000000000], [0.59999999999999997 .. 0.70000000000000007], [0.79999999999999993 .. 0.90000000000000003], [1.0000000000000000 .. 1.1000000000000001], [1.1999999999999999 .. 1.3000000000000001], [1.3999999999999999 .. 1.5000000000000000], [1.5999999999999998 .. 1.7000000000000002], [1.7999999999999998 .. 1.9000000000000002], [2.0000000000000000 .. 2.1000000000000001], [2.1999999999999997 .. 2.3000000000000003], [2.3999999999999999 .. 2.5000000000000000], [2.5999999999999996 .. 2.7000000000000002], [2.7999999999999998 .. 2.9000000000000004], [3.0000000000000000 .. 3.1000000000000001], [3.1999999999999997 .. 3.3000000000000003], [3.3999999999999999 .. 3.5000000000000000], [3.5999999999999996 .. 3.7000000000000002], [3.7999999999999998 .. 3.9000000000000004], [4.0000000000000000 .. 4.1000000000000006]]))
# entering managed function prepare
# symbolic_composition=False, tentative_unpreconditioning=True
# entering managed function roots
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 2.92 seconds
# roots = [[0.0048028783727901138 .. 0.020435765977123051], [0.20345478283219919 .. 0.30000000000000505], [0.39999999999999130 .. 0.48300000000000043]]
# domain = [0.0000000000000000 .. 3.9999999999999996]
# roots = [[0.0048028783727901138 .. 0.020435765977123051],
#  [0.20345478283219919 .. 0.30000000000000505],
#  [0.39999999999999130 .. 0.48300000000000043]]
# seg_domain = [0.0000000000000000 .. 0.10000000000000001]
# roots = [[0.0048028783727901138 .. 0.020435765977123051],
#  [0.20345478283219919 .. 0.30000000000000505],
#  [0.39999999999999130 .. 0.48300000000000043]]
# entering managed function check
# entering managed function prepare
# running f_bool: 1 items in 0.00 seconds
# entering managed function check
# entering managed function prepare
# running f_bool: 1 items in 0.00 seconds
# seg_domain = [0
], [1.7999999999999998 .. 1.9000000000000002], [2.0000000000000000 .. 2.1000000000000001], [2.1999999999999997 .. 2.3000000000000003], [2.3999999999999999 .. 2.5000000000000000], [2.5999999999999996 .. 2.7000000000000002], [2.7999999999999998 .. 2.9000000000000004], [3.0000000000000000 .. 3.1000000000000001], [3.1999999999999997 .. 3.3000000000000003], [3.3999999999999999 .. 3.5000000000000000], [3.5999999999999996 .. 3.7000000000000002], [3.7999999999999998 .. 3.9000000000000004], [4.0000000000000000 .. 4.1000000000000006]]), 'crude_roots': True}
# Graphics object consisting of 2 graphics primitives

# %%
test_monitoring(prop, 4, mask=zebra_mask, crude_roots=True, skip_unpreconditioning=True)[1].plot()
# Out:
# Precomposing Contexts: 1 items in 0.00 seconds
# calling reach with y0 = ['[0.97999999999999998 .. 1.0200000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[0.079999999999999987 .. 0.12000000000000001]', '[1.2799999999999998 .. 1.3200000000000001]', '[2.4799999999999999 .. 2.5200000000000001]', '[0.57999999999999996 .. 0.62000000000000011]', '[1.2799999999999998 .. 1.3200000000000001]']
# ode in polynomial ring
# entering managed function _init_args
# crude_roots = True
# _handle_initials called!
# vars = [x1, x2, x3, x4, x5, x6, x7, x8, x9]
# C = [0.98..1.02]
# C = [1.2799999999999998..1.32]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [0.07999999999999999..0.12000000000000001]
# C = [1.2799999999999998..1.32]
# C = [2.48..2.52]
# C = [0.58..0.6200000000000001]
# C = [1.2799999999999998..1.32]
# assigning system with dimension 9
# resulting system has dimension 9
# run within tmv args
# entering managed function run
# integrationScheme = 7
# Running Flow*: 1 items in 41.94 seconds
# Computed 1334 flowpipes in 41.93643955200014 sec
# entering managed function prepare
# PolyObserver(x6 - 1.4000000000000000?, <flowstar.reachability.Reach object at 0x7f17452767d0>, -0.10000000000000000?*x1*x6 - x2*x6 - 2*x6*x8 + 50*x3 + 100*x4 + 50*x5 - x6 symbolic_composition=False, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 4.0000000000000000], [[0.0000000000000000 .. 0.10000000000000001], [0.19999999999999998 .. 0.30000000000000005], [0.39999999999999996 .. 0.50000000000000000], [0.59999999999999997 .. 0.70000000000000007], [0.79999999999999993 .. 0.90000000000000003], [1.0000000000000000 .. 1.1000000000000001], [1.1999999999999999 .. 1.3000000000000001], [1.3999999999999999 .. 1.5000000000000000], [1.5999999999999998 .. 1.7000000000000002], [1.7999999999999998 .. 1.9000000000000002], [2.0000000000000000 .. 2.1000000000000001], [2.1999999999999997 .. 2.3000000000000003], [2.3999999999999999 .. 2.5000000000000000], [2.5999999999999996 .. 2.7000000000000002], [2.7999999999999998 .. 2.9000000000000004], [3.0000000000000000 .. 3.1000000000000001], [3.1999999999999997 .. 3.3000000000000003], [3.3999999999999999 .. 3.5000000000000000], [3.5999999999999996 .. 3.7000000000000002], [3.7999999999999998 .. 3.9000000000000004], [4.0000000000000000 .. 4.1000000000000006]]))
# entering managed function prepare
# symbolic_composition=False, tentative_unpreconditioning=True
# entering managed function roots
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.55 seconds
# roots = [[0.0029999999999999996 .. 0.021000000000000009], [0.19999999999999781 .. 0.30000000000000505], [0.39999999999999130 .. 0.48600000000000044]]
# domain = [0.0000000000000000 .. 3.9999999999999996]
# roots = [[0.0029999999999999996 .. 0.021000000000000009],
#  [0.19999999999999781 .. 0.30000000000000505],
#  [0.39999999999999130 .. 0.48600000000000044]]
# seg_domain = [0.0000000000000000 .. 0.10000000000000001]
# roots = [[0.0029999999999999996 .. 0.021000000000000009],
#  [0.19999999999999781 .. 0.30000000000000505],
#  [0.39999999999999130 .. 0.48600000000000044]]
# entering managed function check
# entering managed function prepare
# running f_bool: 1 items in 0.00 seconds
# entering managed function check
# entering managed function prepare
# running f_bool: 1 items in 0.00 seconds
# seg_domain = [0.19999999999999998 .. 0.30000000000000005]
# roots = [[0.0029999999999999996 .. 0.021000000000000009],
#  [0.19999999999999781 .. 0.30000000000000505],
#  [0.39999999999999130 .. 0.48600000000000044]]
# entering managed function check
# entering managed function prepare
# running f_bool: 1 items in 0.03 seconds
# 0 at 0.300000000000001
# seg_domain = [0.39999999999999996 .. 0.50000000000000000]
# roots = [[0.0029999999999999996 .. 0.021000000000000009],
#  [0.19999999999999781 .. 0.30000000000000505],
#  [0.39999999999999130 .. 0.48600000000000044]]
# entering managed function check
# entering managed function prepare
# running f_bool: 1 items in 0.00 seconds
# seg_domain = [0.59999999999999997 .. 0.70000000000000007]
# roots = [[0.0029999999999999996 .. 0.021000000000000009],
#  [0.19999999999999781 .. 0.30000000000000505],
#  [0.39999999999999130 .. 0.48600000000000044]]
# entering managed function check
# entering managed function prepare
# running f_bool: 1 items in 0.00 seconds
# seg_domain = [0.79999999999999993 .. 0.90000000000000003]
# roots = [[0.0029999999999999996 .. 0.021000000000000009],
#  [0.19999999999999781 .. 0.30000000000000505],
#  [0.39999999999999130 .. 0.48600000000000044]]
# entering managed function check
# entering managed function prepare
# running f_bool: 1 items in 0.00 seconds
# seg_domain = [1.0000000000000000 .. 1.1000000000000001]
# roots = [[0.0029999999999999996 .. 0.021000000000000009],
#  [0.19999999999999781 .. 0.30000000000000505],
#  [0.39999999999999130 .. 0.48600000000000044]]
# entering managed function check
# entering managed function prepare
# running f_bool: 1 items in 0.00 seconds
# seg_domain = [1.1999999999999999 .. 1.3000000000000001]
# roots = [[0.0029999999999999996 .. 0.021000000000000009],
#  [0.19999999999999781 .. 0.30000000000000505],
#  [0.39999999999999130 .. 0.48600000000000044]]
# entering managed function check
# entering managed function prepare
# running f_bool: 1 items in 0.00 seconds
# seg_domain = [1.3999999999999999 .. 1.5000000000000000]
# roots = [[0.0029999999999999996 .. 0.021000000000000009],
#  [0.19999999999999781 .. 0.30000000000000505],
#  [0.39999999999999130 .. 0.48600000000000044]]
# entering managed function check
# entering managed function prepare
# running f_bool: 1 items in 0.00 seconds
# seg_domain = [1.5999999999999998 .. 1.7000000000000002]
# roots = [[0.0029999999999999996 .. 0.021000000000000009],
#  [0.19999999999999781 .. 0.30000000000000505],
#  [0.39999999999999130 .. 0.48600000000000044]]
# entering managed function check
# entering managed function prepare
# running f_bool: 1 items in 0.00 seconds
# seg_domain = [1.7999999999999998 .. 1.9000000000000002]
# roots = [[0.0029999999999999996 .. 0.021000000000000009],
#  [0.19999999999999781 .. 0.30000000000000505],
#  [0.39999999999999130 .. 0.48600000000000044]]
# entering managed function check
# entering managed function prepare
# running f_bool: 1 items in 0.00 seconds
# seg_domain = [2.0000000000000000 .. 2.1000000000000001]
# roots = [[0.0029999999999999996 .. 0.021000000000000009],
#  [0.19999999999999781 .. 0.30000000000000505],
#  [0.39999999999999130 .. 0.48600000000000044]]
# entering managed function check
# entering managed function prepare
# running f_bool: 1 items in 0.00 seconds
# seg_domain = [2.1999999999999997 .. 2.3000000000000003]
# roots = [[0.0029999999999999996 .. 0.021000000000000009],
#  [0.19999999999999781 .. 0.30000000000000505],
#  [0.39999999999999130 .. 0.48600000000000044]]
# entering managed function check
# entering managed function prepare
# running f_bool: 1 items in 0.00 seconds
# seg_domain = [2.3999999999999999 .. 2.5000000000000000]
# roots = [[0.0029999999999999996 .. 0.021000000000000009],
#  [0.19999999999999781 .. 0.30000000000000505],
#  [0.39999999999999130 .. 0.48600000000000044]]
# entering managed function check
# entering managed function prepare
# running f_bool: 1 items in 0.00 seconds
# seg_domain = [2.5999999999999996 .. 2.7000000000000002]
# roots = [[0.0029999999999999996 .. 0.021000000000000009],
#  [0.19999999999999781 .. 0.30000000000000505],
#  [0.39999999999999130 .. 0.48600000000000044]]
# entering managed function check
# entering managed function prepare
# running f_bool: 1 items in 0.00 seconds
# seg_domain = [2.7999999999999998 .. 2.9000000000000004]
# roots = [[0.0029999999999999996 .. 0.021000000000000009],
#  [0.19999999999999781 .. 0.30000000000000505],
#  [0.39999999999999130 .. 0.48600000000000044]]
# entering managed function check
# entering managed function prepare
# running f_bool: 1 items in 0.00 seconds
# seg_domain = [3.0000000000000000 .. 3.1000000000000001]
# roots = [[0.0029999999999999996 .. 0.021000000000000009],
#  [0.19999999999999781 .. 0.30000000000000505],
#  [0.39999999999999130 .. 0.48600000000000044]]
# entering managed function check
# entering managed function prepare
# running f_bool: 1 items in 0.00 seconds
# seg_domain = [3.1999999999999997 .. 3.3000000000000003]
# roots = [[0.0029999999999999996 .. 0.021000000000000009],
#  [0.19999999999999781 .. 0.30000000000000505],
#  [0.39999999999999130 .. 0.48600000000000044]]
# entering managed function check
# entering managed function prepare
# running f_bool: 1 items in 0.00 seconds
# seg_domain = [3.3999999999999999 .. 3.5000000000000000]
# roots = [[0.0029999999999999996 .. 0.021000000000000009],
#  [0.19999999999999781 .. 0.30000000000000505],
#  [0.39999999999999130 .. 0.48600000000000044]]
# entering managed function check
# entering managed function prepare
# running f_bool: 1 items in 0.00 seconds
# seg_domain = [3.5999999999999996 .. 3.7000000000000002]
# roots = [[0.0029999999999999996 .. 0.021000000000000009],
#  [0.19999999999999781 .. 0.30000000000000505],
#  [0.39999999999999130 .. 0.48600000000000044]]
# entering managed function check
# entering managed function prepare
# running f_bool: 1 items in 0.00 seconds
# seg_domain = [3.7999999999999998 .. 3.9000000000000004]
# roots = [[0.0029999999999999996 .. 0.021000000000000009],
#  [0.19999999999999781 .. 0.30000000000000505],
#  [0.39999999999999130 .. 0.48600000000000044]]
# entering managed function check
# entering managed function prepare
# running f_bool: 1 items in 0.00 seconds
# seg_domain = [4.0000000000000000 .. 4.1000000000000006]
# roots = [[0.0029999999999999996 .. 0.021000000000000009],
#  [0.19999999999999781 .. 0.30000000000000505],
#  [0.39999999999999130 .. 0.48600000000000044]]
# entering managed function check
# entering managed function prepare
# running f_bool: 1 items in 0.00 seconds
# signal given bool roots: 1 items in 0.04 seconds
# Monitoring Signal for x6 > 1.40000000000000: 1 items in 0.63 seconds
# Monitored signal in 0.6319359579998718 sec
# ran "check boolean [unguarded]" 22 times in 0.027874231338500977
# ran "restoring globals" 9 times in 0.00040841102600097656
# ran "root amalgamation" 70 times in 1.2159347534179688e-05
# ran "observer.check" 22 times in 0.029084205627441406
# ran "prepare in check" 22 times in 0.00035762786865234375
# ran "capturing globals [on exit]" 9 times in 0.00027108192443847656
# ran "composing flowpipe" 1 times in 0.022363901138305664
# ran "mask intersect check" 1334 times in 0.0018858909606933594
# ran "tentative eval" 694 times in 0.5381472110748291
# Run done in 42.69750380516052 sec
# options: {'mask': Mask([0.0000000000000000 .. 4.0000000000000000], [[0.0000000000000000 .. 0.10000000000000001], [0.19999999999999998 .. 0.30000000000000005], [0.39999999999999996 .. 0.50000000000000000], [0.59999999999999997 .. 0.70000000000000007], [0.79999999999999993 .. 0.90000000000000003], [1.0000000000000000 .. 1.1000000000000001], [1.1999999999999999 .. 1.3000000000000001], [1.3999999999999999 .. 1.5000000000000000], [1.5999999999999998 .. 1.7000000000000002], [1.7999999999999998 .. 1.9000000000000002], [2.0000000000000000 .. 2.1000000000000001], [2.1999999999999997 .. 2.3000000000000003], [2.3999999999999999 .. 2.5000000000000000], [2.5999999999999996 .. 2.7000000000000002], [2.7999999999999998 .. 2.9000000000000004], [3.0000000000000000 .. 3.1000000000000001], [3.1999999999999997 .. 3.3000000000000003], [3.3999999999999999 .. 3.5000000000000000], [3.5999999999999996 .. 3.7000000000000002], [3.7999999999999998 .. 3.9000000000000004], [4.0000000000000000 .. 4.1000000000000006]]), 'crude_roots': True, 'skip_unpreconditioning': True}
# Graphics object consisting of 2 graphics primitives
