# %% [markdown]
# # Tests

# %% [markdown]
# ## Example 1: Simple

# %%
import sys

sys.path.insert(0, "/home/twright/Documents/PhD/Notebooks")

from flowstar.reachability import Reach
from flowstar.poly import Poly
from ulbc import *

# %%
kwargs = {
    'symbolic_composition': True,
}

# %%
R.<t,x,y> = RIF[]

# %%
odes = [
    R(1),
    -y,
    x,
]
initials = [(0,0), (4,5), (1,2)]
system = System(
    R,
    [t, x, y],
    initials,
    odes,
)
reach = system.reach(2*pi, step=0.1, order=10,
              precompose_taylor_models=False,
              symbolic_composition=False)
reach_sc = system.reach(2*pi, step=0.1, order=10,
              precompose_taylor_models=False,
              symbolic_composition=True)
# Out:
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.0000000000000000 .. 5.0000000000000000]', '[1.0000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.0..5.0]
# C = [1.0..2.0]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.0000000000000000 .. 5.0000000000000000]', '[1.0000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.0..5.0]
# C = [1.0..2.0]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2

# %%
def plot_signal(sig):
    return sig.to_domain(RIF(0,2*pi)).plot().show(
        ticks=[pi/2, 1], tick_formatter=pi, aspect_ratio=2/3)

# %%
reach.res
# Out:
# 2

# %%
S = Atomic(3 - y**2 + y); S
# Out:
# Atomic(-y^2 + y + 3)

# %%
p1 = S.sage_plot(reach); p1
# Out:
# PolyObserver(-y^2 + y + 3, <flowstar.reachability.Reach object at 0x7f2dba600ba0>, -2*x*y + x, symbolic_composition=False, tentative_unpreconditioning=True, mask=None)
# fprime = -2*x*y + x
# /usr/lib64/python3.8/site-packages/numpy/core/getlimits.py:400: UserWarning: Signature b'\x99\x99\x99\x99\x99\x99\xb9\xbf' for <class 'numpy.float64'> does not match any known type: falling back to type probe function
#   machar = _get_machar(dtype)
# Graphics object consisting of 3 graphics primitives

# %%
p2 = S.sage_plot(reach, symbolic_composition=True,
                color=('orange', 'orange'),
                fillcolor=('orange',)); p2
# Out:
# PolyObserver(-y^2 + y + 3, <flowstar.reachability.Reach object at 0x7f2dba600ba0>, -2*x*y + x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -2*x*y + x
# Graphics object consisting of 3 graphics primitives

# %%
p1+p2
# Out:
# Graphics object consisting of 6 graphics primitives

# %%
sig1 = S.signal_for_system(system, 2*pi, symbolic_composition=False)
sig2 = S.signal_for_system(system, 2*pi, symbolic_composition=True)

graphics_array([
    sig1.plot(),
    sig2.plot(),
], ncols=1)
# Out:
# Precomposing Contexts: 1 items in 0.00 seconds
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.0000000000000000 .. 5.0000000000000000]', '[1.0000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.0..5.0]
# C = [1.0..2.0]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# Running Flow*: 1 items in 0.04 seconds
# Computed 63 flowpipes in 0.041888463019859046 sec
# PolyObserver(-y^2 + y + 3, <flowstar.reachability.Reach object at 0x7f2db2af19e0>, -2*x*y + x, symbolic_composition=False, tentative_unpreconditioning=True, mask=None)
# fprime = -2*x*y + x
# symbolic_composition=False, tentative_unpreconditioning=True,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.04 seconds
# roots = [[0.059608151095034402 .. 0.35312852931153011], [2.1186147208572507 .. 2.5000000000000023], [2.9583801173991473 .. 3.2184294365198052], [5.4999999999999609 .. 5.8391025229313307]]
# domain = [0.0000000000000000 .. 6.2851853071795869]
# roots = [[0.059608151095034402 .. 0.35312852931153011],
#  [2.1186147208572507 .. 2.5000000000000023],
#  [2.9583801173991473 .. 3.2184294365198052],
#  [5.4999999999999609 .. 5.8391025229313307]]
# seg_domain = [0.0000000000000000 .. 6.2851853071795869]
# roots = [[0.059608151095034402 .. 0.35312852931153011],
#  [2.1186147208572507 .. 2.5000000000000023],
#  [2.9583801173991473 .. 3.2184294365198052],
#  [5.4999999999999609 .. 5.8391025229313307]]
# signal given bool roots: 1 items in 0.00 seconds
# Monitoring atomic -y^2 + y + 3 > 0: 1 items in 0.04 seconds
# Monitoring Signal for -y^2 + y + 3 > 0: 1 items in 0.05 seconds
# ran "restoring globals" 9 times in 0.00013780593872070312
# ran "capturing globals [on exit]" 9 times in 9.799003601074219e-05
# ran "mask intersect check" 63 times in 0.00014257431030273438
# ran "tentative eval" 63 times in 0.010854244232177734
# ran "composing flowpipe" 17 times in 0.012073278427124023
# ran "whole domain eval" 16 times in 0.0038497447967529297
# ran "post retrieve" 16 times in 8.702278137207031e-05
# ran "root detection" 16 times in 0.01098775863647461
# ran "root amalgamation" 16 times in 4.696846008300781e-05
# ran "prepare in check" 5 times in 3.457069396972656e-05
# ran "check boolean [unguarded]" 5 times in 0.0006248950958251953
# ran "observer.check" 5 times in 0.0009002685546875
# Precomposing Contexts: 1 items in 0.00 seconds
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.0000000000000000 .. 5.0000000000000000]', '[1.0000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.0..5.0]
# C = [1.0..2.0]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# Running Flow*: 1 items in 0.03 seconds
# Computed 63 flowpipes in 0.030603969062212855 sec
# PolyObserver(-y^2 + y + 3, <flowstar.reachability.Reach object at 0x7f2db2af1ac0>, -2*x*y + x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -2*x*y + x
# symbolic_composition=True, tentative_unpreconditioning=True,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.04 seconds
# roots = [[0.059456098390765724 .. 0.40000000000000008], [2.0999999999999947 .. 2.5000000000000023], [2.9642242313394668 .. 3.2439956708126867], [5.4999999999999609 .. 5.9000000000000137]]
# domain = [0.0000000000000000 .. 6.2851853071795869]
# roots = [[0.059456098390765724 .. 0.40000000000000008],
#  [2.0999999999999947 .. 2.5000000000000023],
#  [2.9642242313394668 .. 3.2439956708126867],
#  [5.4999999999999609 .. 5.9000000000000137]]
# seg_domain = [0.0000000000000000 .. 6.2851853071795869]
# roots = [[0.059456098390765724 .. 0.40000000000000008],
#  [2.0999999999999947 .. 2.5000000000000023],
#  [2.9642242313394668 .. 3.2439956708126867],
#  [5.4999999999999609 .. 5.9000000000000137]]
# signal given bool roots: 1 items in 0.00 seconds
# Monitoring atomic -y^2 + y + 3 > 0: 1 items in 0.04 seconds
# Monitoring Signal for -y^2 + y + 3 > 0: 1 items in 0.05 seconds
# ran "restoring globals" 9 times in 0.000110626220703125
# ran "capturing globals [on exit]" 9 times in 8.58306884765625e-05
# ran "mask intersect check" 63 times in 0.000125885009765625
# ran "tentative eval" 63 times in 0.008870840072631836
# ran "composing flowpipe" 17 times in 0.005295276641845703
# ran "whole domain eval" 16 times in 0.0025098323822021484
# ran "post retrieve" 16 times in 0.01731085777282715
# ran "root detection" 16 times in 0.0002880096435546875
# ran "root amalgamation" 16 times in 3.600120544433594e-05
# ran "prepare in check" 5 times in 2.765655517578125e-05
# ran "check boolean [unguarded]" 5 times in 0.00010824203491210938
# ran "observer.check" 5 times in 0.0002791881561279297
# Deallocing CReach
# Deallocing CReach
# Graphics Array of size 2 x 1

# %%
sig1
# Out:
# Signal([0.0000000000000000 .. 6.2831853071795872], [([0.0000000000000000 .. 0.059608151095034403], True), ([0.35312852931153010 .. 2.1186147208572508], False), ([2.5000000000000022 .. 2.9583801173991474], True), ([3.2184294365198051 .. 5.4999999999999610], False), ([5.8391025229313306 .. 6.2831853071795872], True)], mask=None)

# %%
sig2
# Out:
# Signal([0.0000000000000000 .. 6.2831853071795872], [([0.0000000000000000 .. 0.059456098390765725], True), ([0.40000000000000007 .. 2.0999999999999948], False), ([2.5000000000000022 .. 2.9642242313394669], True), ([3.2439956708126866 .. 5.4999999999999610], False), ([5.9000000000000136 .. 6.2831853071795872], True)], mask=None)
