# %%
import sympy as sym

# %%
sym.var("a0 a1 a2 x0 x1 x2")
# Out:
# (a0, a1, a2, x0, x1, x2)

# %%
a0 * x0
# Out:
# a0*x0

# %%
from sage.all import *
import sympy as sym

R, x = PolynomialRing(RIF, 3, 'x').objgens()
xsym = sym.var(','.join(map('x{}'.format, range(0,3))))
asym = []
y0 = [RIF(100.00000000000000000000, 100.00000000000000000000), RIF(0.00000000000000000000, 0.00000000000000000000), RIF(10.00000000000000000000, 10.00000000000000000000)]
ysymraw = [(((0) * (((-1) * ((1) * ((x0) * (1)))) * ((1) * ((x2) * (1)))) + ((1.1) * ((0) * (abs((x2) * (1))))) * (((-1) * ((1) * ((x0) * (1)))) * ((1) * ((x2) * (1)))) + ((1.1) * ((0) * (abs((x0) * (1))))) * (((-1) * ((1) * ((x0) * (1)))) * ((1) * ((x2) * (1)))) + ((1.1) * ((abs((x2) * (1))) * (abs((x0) * (1))))) * (((-1) * ((1) * ((x0) * (1)))) * ((1) * ((x2) * (1))))) / (0 + (0) * (abs((1) * ((x0) * (1)))) + (0) * (abs((0) * ((x2) * (1)))) + (0) * (abs((0) * ((x0) * (1)))) + (abs((0) * ((x0) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((0) * ((x0) * (1)))) + (0) * (abs((1) * ((x2) * (1)))) + (abs((1) * ((x2) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((1) * ((x2) * (1))))) + (((0) * (((-2.0) * ((1) * ((x0) * (1)))) * ((0) * ((x0) * (1)))) + ((1.1) * ((0) * (abs((x2) * (1))))) * (((-2.0) * ((1) * ((x0) * (1)))) * ((0) * ((x0) * (1)))) + ((1.1) * ((0) * (abs((x0) * (1))))) * (((-2.0) * ((1) * ((x0) * (1)))) * ((0) * ((x0) * (1)))) + ((1.1) * ((abs((x2) * (1))) * (abs((x0) * (1))))) * (((-2.0) * ((1) * ((x0) * (1)))) * ((0) * ((x0) * (1))))) / (0 + abs((1) * ((x0) * (1))) + abs((0) * ((x2) * (1)))) + ((0) * (((-1) * ((0) * ((x2) * (1)))) * ((0) * ((x0) * (1)))) + ((1.1) * ((0) * (abs((x2) * (1))))) * (((-1) * ((0) * ((x2) * (1)))) * ((0) * ((x0) * (1)))) + ((1.1) * ((0) * (abs((x0) * (1))))) * (((-1) * ((0) * ((x2) * (1)))) * ((0) * ((x0) * (1)))) + ((1.1) * ((abs((x2) * (1))) * (abs((x0) * (1))))) * (((-1) * ((0) * ((x2) * (1)))) * ((0) * ((x0) * (1))))) / (0 + abs((1) * ((x0) * (1))) + abs((0) * ((x2) * (1))))) / (0 + abs((0) * ((x0) * (1))) + abs((1) * ((x2) * (1))))) / (2.0 + 0 + abs((x0) * (1))), (((0) * (((1) * ((x2) * (1))) * ((1) * ((1) * ((x0) * (1))))) + ((1.1) * ((0) * (abs((x2) * (1))))) * (((1) * ((x2) * (1))) * ((1) * ((1) * ((x0) * (1))))) + ((1.1) * ((0) * (abs((x0) * (1))))) * (((1) * ((x2) * (1))) * ((1) * ((1) * ((x0) * (1))))) + ((1.1) * ((abs((x2) * (1))) * (abs((x0) * (1))))) * (((1) * ((x2) * (1))) * ((1) * ((1) * ((x0) * (1)))))) / (0 + (0) * (abs((1) * ((x0) * (1)))) + (0) * (abs((0) * ((x2) * (1)))) + (0) * (abs((0) * ((x0) * (1)))) + (abs((0) * ((x0) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((0) * ((x0) * (1)))) + (0) * (abs((1) * ((x2) * (1)))) + (abs((1) * ((x2) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((1) * ((x2) * (1))))) + (((0) * (((0) * ((x0) * (1))) * ((1) * ((0) * ((x2) * (1))))) + ((1.1) * ((0) * (abs((x2) * (1))))) * (((0) * ((x0) * (1))) * ((1) * ((0) * ((x2) * (1))))) + ((1.1) * ((0) * (abs((x0) * (1))))) * (((0) * ((x0) * (1))) * ((1) * ((0) * ((x2) * (1))))) + ((1.1) * ((abs((x2) * (1))) * (abs((x0) * (1))))) * (((0) * ((x0) * (1))) * ((1) * ((0) * ((x2) * (1)))))) / (0 + abs((1) * ((x0) * (1))) + abs((0) * ((x2) * (1)))) + ((0) * (((0) * ((x0) * (1))) * ((2.0) * ((1) * ((x0) * (1))))) + ((1.1) * ((0) * (abs((x2) * (1))))) * (((0) * ((x0) * (1))) * ((2.0) * ((1) * ((x0) * (1))))) + ((1.1) * ((0) * (abs((x0) * (1))))) * (((0) * ((x0) * (1))) * ((2.0) * ((1) * ((x0) * (1))))) + ((1.1) * ((abs((x2) * (1))) * (abs((x0) * (1))))) * (((0) * ((x0) * (1))) * ((2.0) * ((1) * ((x0) * (1)))))) / (0 + abs((1) * ((x0) * (1))) + abs((0) * ((x2) * (1))))) / (0 + abs((0) * ((x0) * (1))) + abs((1) * ((x2) * (1))))) / (2.0 + 0 + abs((x0) * (1))), (((0) * (((0) * ((x0) * (1))) * ((0) * ((0) * ((x2) * (1))))) + ((1.1) * ((0) * (abs((x2) * (1))))) * (((0) * ((x0) * (1))) * ((0) * ((0) * ((x2) * (1))))) + ((1.1) * ((0) * (abs((x0) * (1))))) * (((0) * ((x0) * (1))) * ((0) * ((0) * ((x2) * (1))))) + ((1.1) * ((abs((x2) * (1))) * (abs((x0) * (1))))) * (((0) * ((x0) * (1))) * ((0) * ((0) * ((x2) * (1)))))) / (0 + (0) * (abs((1) * ((x0) * (1)))) + (0) * (abs((0) * ((x2) * (1)))) + (0) * (abs((0) * ((x0) * (1)))) + (abs((0) * ((x0) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((0) * ((x0) * (1)))) + (0) * (abs((1) * ((x2) * (1)))) + (abs((1) * ((x2) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((1) * ((x2) * (1))))) + (((0) * (((0) * ((0) * ((x2) * (1)))) * ((1) * ((x2) * (1)))) + ((1.1) * ((0) * (abs((x2) * (1))))) * (((0) * ((0) * ((x2) * (1)))) * ((1) * ((x2) * (1)))) + ((1.1) * ((0) * (abs((x0) * (1))))) * (((0) * ((0) * ((x2) * (1)))) * ((1) * ((x2) * (1)))) + ((1.1) * ((abs((x2) * (1))) * (abs((x0) * (1))))) * (((0) * ((0) * ((x2) * (1)))) * ((1) * ((x2) * (1))))) / (0 + abs((1) * ((x0) * (1))) + abs((0) * ((x2) * (1)))) + ((0) * (((0) * ((1) * ((x0) * (1)))) * ((1) * ((x2) * (1)))) + ((1.1) * ((0) * (abs((x2) * (1))))) * (((0) * ((1) * ((x0) * (1)))) * ((1) * ((x2) * (1)))) + ((1.1) * ((0) * (abs((x0) * (1))))) * (((0) * ((1) * ((x0) * (1)))) * ((1) * ((x2) * (1)))) + ((1.1) * ((abs((x2) * (1))) * (abs((x0) * (1))))) * (((0) * ((1) * ((x0) * (1)))) * ((1) * ((x2) * (1))))) / (0 + abs((1) * ((x0) * (1))) + abs((0) * ((x2) * (1))))) / (0 + abs((0) * ((x0) * (1))) + abs((1) * ((x2) * (1))))) / (2.0 + 0 + abs((x0) * (1)))]
ysym = [sym.simplify(y1) for y1 in ysymraw]
ysage = [y1._sage_().substitute() for y1 in ysym]
try:
    y = vector([R(y1) for y1 in ysage])
except TypeError:
    y = None

# %%
ysage
# Out:
# [-1.10000000000000*x0*x2/(abs(x0) + 2.00000000000000),
#  1.10000000000000*x0*x2/(abs(x0) + 2.00000000000000),
#  0]

# %%
from sage.all import *
import sympy as sym

R, x = PolynomialRing(RIF, 3, 'x').objgens()
xsym = sym.var(','.join(map('x{}'.format, range(0,3))))
asym = []
y0 = [RIF(100.00000000000000000000, 100.00000000000000000000), RIF(0.00000000000000000000, 0.00000000000000000000), RIF(10.00000000000000000000, 10.00000000000000000000)]
ysymraw = [(((0) * (((-1) * ((1) * ((x0) * (1)))) * ((1) * ((x2) * (1)))) + ((1.1) * ((0) * (abs((x2) * (1))))) * (((-1) * ((1) * ((x0) * (1)))) * ((1) * ((x2) * (1)))) + ((1.1) * ((0) * (abs((x0) * (1))))) * (((-1) * ((1) * ((x0) * (1)))) * ((1) * ((x2) * (1)))) + ((1.1) * ((abs((x2) * (1))) * (abs((x0) * (1))))) * (((-1) * ((1) * ((x0) * (1)))) * ((1) * ((x2) * (1))))) / (0 + (0) * (abs((1) * ((x0) * (1)))) + (0) * (abs((0) * ((x2) * (1)))) + (0) * (abs((0) * ((x0) * (1)))) + (abs((0) * ((x0) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((0) * ((x0) * (1)))) + (0) * (abs((1) * ((x2) * (1)))) + (abs((1) * ((x2) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((1) * ((x2) * (1))))) + (((0) * (((-2.0) * ((1) * ((x0) * (1)))) * ((0) * ((x0) * (1)))) + ((1.1) * ((0) * (abs((x2) * (1))))) * (((-2.0) * ((1) * ((x0) * (1)))) * ((0) * ((x0) * (1)))) + ((1.1) * ((0) * (abs((x0) * (1))))) * (((-2.0) * ((1) * ((x0) * (1)))) * ((0) * ((x0) * (1)))) + ((1.1) * ((abs((x2) * (1))) * (abs((x0) * (1))))) * (((-2.0) * ((1) * ((x0) * (1)))) * ((0) * ((x0) * (1))))) / (0 + abs((1) * ((x0) * (1))) + abs((0) * ((x2) * (1)))) + ((0) * (((-1) * ((0) * ((x2) * (1)))) * ((0) * ((x0) * (1)))) + ((1.1) * ((0) * (abs((x2) * (1))))) * (((-1) * ((0) * ((x2) * (1)))) * ((0) * ((x0) * (1)))) + ((1.1) * ((0) * (abs((x0) * (1))))) * (((-1) * ((0) * ((x2) * (1)))) * ((0) * ((x0) * (1)))) + ((1.1) * ((abs((x2) * (1))) * (abs((x0) * (1))))) * (((-1) * ((0) * ((x2) * (1)))) * ((0) * ((x0) * (1))))) / (0 + abs((1) * ((x0) * (1))) + abs((0) * ((x2) * (1))))) / (0 + abs((0) * ((x0) * (1))) + abs((1) * ((x2) * (1))))) / (2.0 + 0 + abs((x0) * (1))), (((0) * (((1) * ((x2) * (1))) * ((1) * ((1) * ((x0) * (1))))) + ((1.1) * ((0) * (abs((x2) * (1))))) * (((1) * ((x2) * (1))) * ((1) * ((1) * ((x0) * (1))))) + ((1.1) * ((0) * (abs((x0) * (1))))) * (((1) * ((x2) * (1))) * ((1) * ((1) * ((x0) * (1))))) + ((1.1) * ((abs((x2) * (1))) * (abs((x0) * (1))))) * (((1) * ((x2) * (1))) * ((1) * ((1) * ((x0) * (1)))))) / (0 + (0) * (abs((1) * ((x0) * (1)))) + (0) * (abs((0) * ((x2) * (1)))) + (0) * (abs((0) * ((x0) * (1)))) + (abs((0) * ((x0) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((0) * ((x0) * (1)))) + (0) * (abs((1) * ((x2) * (1)))) + (abs((1) * ((x2) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((1) * ((x2) * (1))))) + (((0) * (((0) * ((x0) * (1))) * ((1) * ((0) * ((x2) * (1))))) + ((1.1) * ((0) * (abs((x2) * (1))))) * (((0) * ((x0) * (1))) * ((1) * ((0) * ((x2) * (1))))) + ((1.1) * ((0) * (abs((x0) * (1))))) * (((0) * ((x0) * (1))) * ((1) * ((0) * ((x2) * (1))))) + ((1.1) * ((abs((x2) * (1))) * (abs((x0) * (1))))) * (((0) * ((x0) * (1))) * ((1) * ((0) * ((x2) * (1)))))) / (0 + abs((1) * ((x0) * (1))) + abs((0) * ((x2) * (1)))) + ((0) * (((0) * ((x0) * (1))) * ((2.0) * ((1) * ((x0) * (1))))) + ((1.1) * ((0) * (abs((x2) * (1))))) * (((0) * ((x0) * (1))) * ((2.0) * ((1) * ((x0) * (1))))) + ((1.1) * ((0) * (abs((x0) * (1))))) * (((0) * ((x0) * (1))) * ((2.0) * ((1) * ((x0) * (1))))) + ((1.1) * ((abs((x2) * (1))) * (abs((x0) * (1))))) * (((0) * ((x0) * (1))) * ((2.0) * ((1) * ((x0) * (1)))))) / (0 + abs((1) * ((x0) * (1))) + abs((0) * ((x2) * (1))))) / (0 + abs((0) * ((x0) * (1))) + abs((1) * ((x2) * (1))))) / (2.0 + 0 + abs((x0) * (1))), (((0) * (((0) * ((x0) * (1))) * ((0) * ((0) * ((x2) * (1))))) + ((1.1) * ((0) * (abs((x2) * (1))))) * (((0) * ((x0) * (1))) * ((0) * ((0) * ((x2) * (1))))) + ((1.1) * ((0) * (abs((x0) * (1))))) * (((0) * ((x0) * (1))) * ((0) * ((0) * ((x2) * (1))))) + ((1.1) * ((abs((x2) * (1))) * (abs((x0) * (1))))) * (((0) * ((x0) * (1))) * ((0) * ((0) * ((x2) * (1)))))) / (0 + (0) * (abs((1) * ((x0) * (1)))) + (0) * (abs((0) * ((x2) * (1)))) + (0) * (abs((0) * ((x0) * (1)))) + (abs((0) * ((x0) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((0) * ((x0) * (1)))) + (0) * (abs((1) * ((x2) * (1)))) + (abs((1) * ((x2) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((1) * ((x2) * (1))))) + (((0) * (((0) * ((0) * ((x2) * (1)))) * ((1) * ((x2) * (1)))) + ((1.1) * ((0) * (abs((x2) * (1))))) * (((0) * ((0) * ((x2) * (1)))) * ((1) * ((x2) * (1)))) + ((1.1) * ((0) * (abs((x0) * (1))))) * (((0) * ((0) * ((x2) * (1)))) * ((1) * ((x2) * (1)))) + ((1.1) * ((abs((x2) * (1))) * (abs((x0) * (1))))) * (((0) * ((0) * ((x2) * (1)))) * ((1) * ((x2) * (1))))) / (0 + abs((1) * ((x0) * (1))) + abs((0) * ((x2) * (1)))) + ((0) * (((0) * ((1) * ((x0) * (1)))) * ((1) * ((x2) * (1)))) + ((1.1) * ((0) * (abs((x2) * (1))))) * (((0) * ((1) * ((x0) * (1)))) * ((1) * ((x2) * (1)))) + ((1.1) * ((0) * (abs((x0) * (1))))) * (((0) * ((1) * ((x0) * (1)))) * ((1) * ((x2) * (1)))) + ((1.1) * ((abs((x2) * (1))) * (abs((x0) * (1))))) * (((0) * ((1) * ((x0) * (1)))) * ((1) * ((x2) * (1))))) / (0 + abs((1) * ((x0) * (1))) + abs((0) * ((x2) * (1))))) / (0 + abs((0) * ((x0) * (1))) + abs((1) * ((x2) * (1))))) / (2.0 + 0 + abs((x0) * (1)))]
ysym = [sym.simplify(y1) for y1 in ysymraw]
ysage = [y1._sage_().substitute() for y1 in ysym]
try:
    y = vector([R(y1) for y1 in ysage])
except TypeError:
    y = None

# %%
ysage
# Out:
# [-1.10000000000000*x0*x2/(abs(x0) + 2.00000000000000),
#  1.10000000000000*x0*x2/(abs(x0) + 2.00000000000000),
#  0]

# %%
from sage.all import *
import sympy as sym

R, x = PolynomialRing(RIF, 3, 'x').objgens()
xsym = sym.var(','.join(map('x{}'.format, range(0,3))))
asym = []
y0 = [RIF(100.00000000000000000000, 100.00000000000000000000), RIF(0.00000000000000000000, 0.00000000000000000000), RIF(10.00000000000000000000, 10.00000000000000000000)]
ysymraw = [(((0) * (((-1) * ((1) * ((x0) * (1)))) * ((1) * ((x2) * (1)))) + ((1.1) * ((0) * (abs((x2) * (1))))) * (((-1) * ((1) * ((x0) * (1)))) * ((1) * ((x2) * (1)))) + ((1.1) * ((0) * (abs((x0) * (1))))) * (((-1) * ((1) * ((x0) * (1)))) * ((1) * ((x2) * (1)))) + ((1.1) * ((abs((x2) * (1))) * (abs((x0) * (1))))) * (((-1) * ((1) * ((x0) * (1)))) * ((1) * ((x2) * (1))))) / (0 + (0) * (abs((1) * ((x0) * (1)))) + (0) * (abs((0) * ((x2) * (1)))) + (0) * (abs((0) * ((x0) * (1)))) + (abs((0) * ((x0) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((0) * ((x0) * (1)))) + (0) * (abs((1) * ((x2) * (1)))) + (abs((1) * ((x2) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((1) * ((x2) * (1))))) + (((0) * (((-2.0) * ((1) * ((x0) * (1)))) * ((0) * ((x0) * (1)))) + ((1.1) * ((0) * (abs((x2) * (1))))) * (((-2.0) * ((1) * ((x0) * (1)))) * ((0) * ((x0) * (1)))) + ((1.1) * ((0) * (abs((x0) * (1))))) * (((-2.0) * ((1) * ((x0) * (1)))) * ((0) * ((x0) * (1)))) + ((1.1) * ((abs((x2) * (1))) * (abs((x0) * (1))))) * (((-2.0) * ((1) * ((x0) * (1)))) * ((0) * ((x0) * (1))))) / (0 + abs((1) * ((x0) * (1))) + abs((0) * ((x2) * (1)))) + ((0) * (((-1) * ((0) * ((x2) * (1)))) * ((0) * ((x0) * (1)))) + ((1.1) * ((0) * (abs((x2) * (1))))) * (((-1) * ((0) * ((x2) * (1)))) * ((0) * ((x0) * (1)))) + ((1.1) * ((0) * (abs((x0) * (1))))) * (((-1) * ((0) * ((x2) * (1)))) * ((0) * ((x0) * (1)))) + ((1.1) * ((abs((x2) * (1))) * (abs((x0) * (1))))) * (((-1) * ((0) * ((x2) * (1)))) * ((0) * ((x0) * (1))))) / (0 + abs((1) * ((x0) * (1))) + abs((0) * ((x2) * (1))))) / (0 + abs((0) * ((x0) * (1))) + abs((1) * ((x2) * (1))))) / (2.0 + 0 + abs((x0) * (1))), (((0) * (((1) * ((x2) * (1))) * ((1) * ((1) * ((x0) * (1))))) + ((1.1) * ((0) * (abs((x2) * (1))))) * (((1) * ((x2) * (1))) * ((1) * ((1) * ((x0) * (1))))) + ((1.1) * ((0) * (abs((x0) * (1))))) * (((1) * ((x2) * (1))) * ((1) * ((1) * ((x0) * (1))))) + ((1.1) * ((abs((x2) * (1))) * (abs((x0) * (1))))) * (((1) * ((x2) * (1))) * ((1) * ((1) * ((x0) * (1)))))) / (0 + (0) * (abs((1) * ((x0) * (1)))) + (0) * (abs((0) * ((x2) * (1)))) + (0) * (abs((0) * ((x0) * (1)))) + (abs((0) * ((x0) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((0) * ((x0) * (1)))) + (0) * (abs((1) * ((x2) * (1)))) + (abs((1) * ((x2) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((1) * ((x2) * (1))))) + (((0) * (((0) * ((x0) * (1))) * ((1) * ((0) * ((x2) * (1))))) + ((1.1) * ((0) * (abs((x2) * (1))))) * (((0) * ((x0) * (1))) * ((1) * ((0) * ((x2) * (1))))) + ((1.1) * ((0) * (abs((x0) * (1))))) * (((0) * ((x0) * (1))) * ((1) * ((0) * ((x2) * (1))))) + ((1.1) * ((abs((x2) * (1))) * (abs((x0) * (1))))) * (((0) * ((x0) * (1))) * ((1) * ((0) * ((x2) * (1)))))) / (0 + abs((1) * ((x0) * (1))) + abs((0) * ((x2) * (1)))) + ((0) * (((0) * ((x0) * (1))) * ((2.0) * ((1) * ((x0) * (1))))) + ((1.1) * ((0) * (abs((x2) * (1))))) * (((0) * ((x0) * (1))) * ((2.0) * ((1) * ((x0) * (1))))) + ((1.1) * ((0) * (abs((x0) * (1))))) * (((0) * ((x0) * (1))) * ((2.0) * ((1) * ((x0) * (1))))) + ((1.1) * ((abs((x2) * (1))) * (abs((x0) * (1))))) * (((0) * ((x0) * (1))) * ((2.0) * ((1) * ((x0) * (1)))))) / (0 + abs((1) * ((x0) * (1))) + abs((0) * ((x2) * (1))))) / (0 + abs((0) * ((x0) * (1))) + abs((1) * ((x2) * (1))))) / (2.0 + 0 + abs((x0) * (1))), (((0) * (((0) * ((x0) * (1))) * ((0) * ((0) * ((x2) * (1))))) + ((1.1) * ((0) * (abs((x2) * (1))))) * (((0) * ((x0) * (1))) * ((0) * ((0) * ((x2) * (1))))) + ((1.1) * ((0) * (abs((x0) * (1))))) * (((0) * ((x0) * (1))) * ((0) * ((0) * ((x2) * (1))))) + ((1.1) * ((abs((x2) * (1))) * (abs((x0) * (1))))) * (((0) * ((x0) * (1))) * ((0) * ((0) * ((x2) * (1)))))) / (0 + (0) * (abs((1) * ((x0) * (1)))) + (0) * (abs((0) * ((x2) * (1)))) + (0) * (abs((0) * ((x0) * (1)))) + (abs((0) * ((x0) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((0) * ((x0) * (1)))) + (0) * (abs((1) * ((x2) * (1)))) + (abs((1) * ((x2) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((1) * ((x2) * (1))))) + (((0) * (((0) * ((0) * ((x2) * (1)))) * ((1) * ((x2) * (1)))) + ((1.1) * ((0) * (abs((x2) * (1))))) * (((0) * ((0) * ((x2) * (1)))) * ((1) * ((x2) * (1)))) + ((1.1) * ((0) * (abs((x0) * (1))))) * (((0) * ((0) * ((x2) * (1)))) * ((1) * ((x2) * (1)))) + ((1.1) * ((abs((x2) * (1))) * (abs((x0) * (1))))) * (((0) * ((0) * ((x2) * (1)))) * ((1) * ((x2) * (1))))) / (0 + abs((1) * ((x0) * (1))) + abs((0) * ((x2) * (1)))) + ((0) * (((0) * ((1) * ((x0) * (1)))) * ((1) * ((x2) * (1)))) + ((1.1) * ((0) * (abs((x2) * (1))))) * (((0) * ((1) * ((x0) * (1)))) * ((1) * ((x2) * (1)))) + ((1.1) * ((0) * (abs((x0) * (1))))) * (((0) * ((1) * ((x0) * (1)))) * ((1) * ((x2) * (1)))) + ((1.1) * ((abs((x2) * (1))) * (abs((x0) * (1))))) * (((0) * ((1) * ((x0) * (1)))) * ((1) * ((x2) * (1))))) / (0 + abs((1) * ((x0) * (1))) + abs((0) * ((x2) * (1))))) / (0 + abs((0) * ((x0) * (1))) + abs((1) * ((x2) * (1))))) / (2.0 + 0 + abs((x0) * (1)))]
ysym = [sym.simplify(y1) for y1 in ysymraw]
ysage = [y1._sage_().substitute() for y1 in ysym]
try:
    y = vector([R(y1) for y1 in ysage])
except TypeError:
    y = None

# %%
ysage
# Out:
# [-1.10000000000000*x0*x2/(abs(x0) + 2.00000000000000),
#  1.10000000000000*x0*x2/(abs(x0) + 2.00000000000000),
#  0]

# %%
from sage.all import *
import sympy as sym

R, x = PolynomialRing(RIF, 4, 'x').objgens()
xsym = sym.var(','.join(map('x{}'.format, range(0,4))))
asym = []
y0 = [RIF(1.00000000000000000000, 1.00000000000000000000), RIF(0.00000000000000000000, 0.00000000000000000000), RIF(0.10000000000000000000, 0.10000000000000000000), RIF(0.00000000000000000000, 0.00000000000000000000)]
ysymraw = [((0) * (((-1) * ((1) * ((x0) * (1)))) * ((0) * ((x3) * (1)))) + ((0) * ((1) * (abs((x2) * (1))))) * (((-1) * ((1) * ((x0) * (1)))) * ((0) * ((x3) * (1)))) + ((0) * (abs((x0) * (1)))) * (((-1) * ((1) * ((x0) * (1)))) * ((0) * ((x3) * (1)))) + (((-1) * ((1) * ((x0) * (1)))) * ((0) * ((x3) * (1)))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + (0) * (abs((0) * ((x2) * (1)))) + (0) * (abs((0) * ((x3) * (1)))) + (0) * (abs((1) * ((x0) * (1)))) + (0) * (abs((0) * ((x3) * (1)))) + (0) * (abs((0) * ((x3) * (1)))) + (0) * (abs((1) * ((x2) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((1) * ((x2) * (1)))) + (abs((0) * ((x3) * (1)))) * (abs((1) * ((x2) * (1)))) + (abs((1) * ((x2) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x3) * (1)))) * (abs((1) * ((x2) * (1)))) + (abs((0) * ((x3) * (1)))) * (abs((1) * ((x2) * (1)))) + (0) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x3) * (1)))) ** (2.0) + (abs((0) * ((x3) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x3) * (1)))) ** (2.0) + (abs((0) * ((x3) * (1)))) ** (2.0) + (0) * (abs((0) * ((x0) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((0) * ((x0) * (1)))) + (abs((0) * ((x0) * (1)))) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x0) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x0) * (1)))) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x0) * (1)))) * (abs((0) * ((x3) * (1)))) + (0) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x3) * (1)))) ** (2.0) + (abs((0) * ((x3) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x3) * (1)))) ** (2.0) + (abs((0) * ((x3) * (1)))) ** (2.0) + (0) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x3) * (1)))) ** (2.0) + (abs((0) * ((x3) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x3) * (1)))) ** (2.0) + (abs((0) * ((x3) * (1)))) ** (2.0)) + ((0) * (((-1) * ((1) * ((x0) * (1)))) * ((1) * ((x2) * (1)))) + ((0) * ((1) * (abs((x2) * (1))))) * (((-1) * ((1) * ((x0) * (1)))) * ((1) * ((x2) * (1)))) + ((0) * (abs((x0) * (1)))) * (((-1) * ((1) * ((x0) * (1)))) * ((1) * ((x2) * (1)))) + (((-1) * ((1) * ((x0) * (1)))) * ((1) * ((x2) * (1)))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + (0) * (abs((0) * ((x2) * (1)))) + (0) * (abs((0) * ((x3) * (1)))) + (0) * (abs((1) * ((x0) * (1)))) + (0) * (abs((0) * ((x3) * (1)))) + (0) * (abs((0) * ((x3) * (1)))) + (0) * (abs((1) * ((x2) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((1) * ((x2) * (1)))) + (abs((0) * ((x3) * (1)))) * (abs((1) * ((x2) * (1)))) + (abs((1) * ((x2) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x3) * (1)))) * (abs((1) * ((x2) * (1)))) + (abs((0) * ((x3) * (1)))) * (abs((1) * ((x2) * (1)))) + (0) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x3) * (1)))) ** (2.0) + (abs((0) * ((x3) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x3) * (1)))) ** (2.0) + (abs((0) * ((x3) * (1)))) ** (2.0) + (0) * (abs((0) * ((x0) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((0) * ((x0) * (1)))) + (abs((0) * ((x0) * (1)))) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x0) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x0) * (1)))) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x0) * (1)))) * (abs((0) * ((x3) * (1)))) + (0) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x3) * (1)))) ** (2.0) + (abs((0) * ((x3) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x3) * (1)))) ** (2.0) + (abs((0) * ((x3) * (1)))) ** (2.0) + (0) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x3) * (1)))) ** (2.0) + (abs((0) * ((x3) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x3) * (1)))) ** (2.0) + (abs((0) * ((x3) * (1)))) ** (2.0)) + (((0) * (((-1) * ((0) * ((x2) * (1)))) * ((0) * ((x0) * (1)))) + ((0) * ((1) * (abs((x2) * (1))))) * (((-1) * ((0) * ((x2) * (1)))) * ((0) * ((x0) * (1)))) + ((0) * (abs((x0) * (1)))) * (((-1) * ((0) * ((x2) * (1)))) * ((0) * ((x0) * (1)))) + (((-1) * ((0) * ((x2) * (1)))) * ((0) * ((x0) * (1)))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + ((0) * (((-1) * ((0) * ((x3) * (1)))) * ((0) * ((x0) * (1)))) + ((0) * ((1) * (abs((x2) * (1))))) * (((-1) * ((0) * ((x3) * (1)))) * ((0) * ((x0) * (1)))) + ((0) * (abs((x0) * (1)))) * (((-1) * ((0) * ((x3) * (1)))) * ((0) * ((x0) * (1)))) + (((-1) * ((0) * ((x3) * (1)))) * ((0) * ((x0) * (1)))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + ((0) * (((-2.0) * ((1) * ((x0) * (1)))) * ((0) * ((x0) * (1)))) + ((0) * ((1) * (abs((x2) * (1))))) * (((-2.0) * ((1) * ((x0) * (1)))) * ((0) * ((x0) * (1)))) + ((0) * (abs((x0) * (1)))) * (((-2.0) * ((1) * ((x0) * (1)))) * ((0) * ((x0) * (1)))) + (((-2.0) * ((1) * ((x0) * (1)))) * ((0) * ((x0) * (1)))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + ((0) * (((-1) * ((0) * ((x3) * (1)))) * ((0) * ((x0) * (1)))) + ((0) * ((1) * (abs((x2) * (1))))) * (((-1) * ((0) * ((x3) * (1)))) * ((0) * ((x0) * (1)))) + ((0) * (abs((x0) * (1)))) * (((-1) * ((0) * ((x3) * (1)))) * ((0) * ((x0) * (1)))) + (((-1) * ((0) * ((x3) * (1)))) * ((0) * ((x0) * (1)))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + ((0) * (((-1) * ((0) * ((x3) * (1)))) * ((0) * ((x0) * (1)))) + ((0) * ((1) * (abs((x2) * (1))))) * (((-1) * ((0) * ((x3) * (1)))) * ((0) * ((x0) * (1)))) + ((0) * (abs((x0) * (1)))) * (((-1) * ((0) * ((x3) * (1)))) * ((0) * ((x0) * (1)))) + (((-1) * ((0) * ((x3) * (1)))) * ((0) * ((x0) * (1)))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1))))) / (0 + abs((1) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + ((0) * (((-1) * ((1) * ((x0) * (1)))) * ((0) * ((x3) * (1)))) + ((0) * ((1) * (abs((x2) * (1))))) * (((-1) * ((1) * ((x0) * (1)))) * ((0) * ((x3) * (1)))) + ((0) * (abs((x0) * (1)))) * (((-1) * ((1) * ((x0) * (1)))) * ((0) * ((x3) * (1)))) + (((-1) * ((1) * ((x0) * (1)))) * ((0) * ((x3) * (1)))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + (0) * (abs((0) * ((x2) * (1)))) + (0) * (abs((0) * ((x3) * (1)))) + (0) * (abs((1) * ((x0) * (1)))) + (0) * (abs((0) * ((x3) * (1)))) + (0) * (abs((0) * ((x3) * (1)))) + (0) * (abs((1) * ((x2) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((1) * ((x2) * (1)))) + (abs((0) * ((x3) * (1)))) * (abs((1) * ((x2) * (1)))) + (abs((1) * ((x2) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x3) * (1)))) * (abs((1) * ((x2) * (1)))) + (abs((0) * ((x3) * (1)))) * (abs((1) * ((x2) * (1)))) + (0) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x3) * (1)))) ** (2.0) + (abs((0) * ((x3) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x3) * (1)))) ** (2.0) + (abs((0) * ((x3) * (1)))) ** (2.0) + (0) * (abs((0) * ((x0) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((0) * ((x0) * (1)))) + (abs((0) * ((x0) * (1)))) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x0) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x0) * (1)))) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x0) * (1)))) * (abs((0) * ((x3) * (1)))) + (0) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x3) * (1)))) ** (2.0) + (abs((0) * ((x3) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x3) * (1)))) ** (2.0) + (abs((0) * ((x3) * (1)))) ** (2.0) + (0) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x3) * (1)))) ** (2.0) + (abs((0) * ((x3) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x3) * (1)))) ** (2.0) + (abs((0) * ((x3) * (1)))) ** (2.0)) + ((0) * (((-1) * ((1) * ((x0) * (1)))) * ((0) * ((x3) * (1)))) + ((0) * ((1) * (abs((x2) * (1))))) * (((-1) * ((1) * ((x0) * (1)))) * ((0) * ((x3) * (1)))) + ((0) * (abs((x0) * (1)))) * (((-1) * ((1) * ((x0) * (1)))) * ((0) * ((x3) * (1)))) + (((-1) * ((1) * ((x0) * (1)))) * ((0) * ((x3) * (1)))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + (0) * (abs((0) * ((x2) * (1)))) + (0) * (abs((0) * ((x3) * (1)))) + (0) * (abs((1) * ((x0) * (1)))) + (0) * (abs((0) * ((x3) * (1)))) + (0) * (abs((0) * ((x3) * (1)))) + (0) * (abs((1) * ((x2) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((1) * ((x2) * (1)))) + (abs((0) * ((x3) * (1)))) * (abs((1) * ((x2) * (1)))) + (abs((1) * ((x2) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x3) * (1)))) * (abs((1) * ((x2) * (1)))) + (abs((0) * ((x3) * (1)))) * (abs((1) * ((x2) * (1)))) + (0) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x3) * (1)))) ** (2.0) + (abs((0) * ((x3) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x3) * (1)))) ** (2.0) + (abs((0) * ((x3) * (1)))) ** (2.0) + (0) * (abs((0) * ((x0) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((0) * ((x0) * (1)))) + (abs((0) * ((x0) * (1)))) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x0) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x0) * (1)))) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x0) * (1)))) * (abs((0) * ((x3) * (1)))) + (0) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x3) * (1)))) ** (2.0) + (abs((0) * ((x3) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x3) * (1)))) ** (2.0) + (abs((0) * ((x3) * (1)))) ** (2.0) + (0) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x3) * (1)))) ** (2.0) + (abs((0) * ((x3) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x3) * (1)))) ** (2.0) + (abs((0) * ((x3) * (1)))) ** (2.0)) + ((0) * ((-1) * ((0) * ((x0) * (1)))) + ((-1) * ((0) * ((x0) * (1)))) * ((0.5) * (abs((x3) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x3) * (1)))), ((0) * ((2.0) * (((0) * ((x3) * (1))) * ((1) * ((0) * ((x3) * (1)))))) + ((0) * ((1) * (abs((x2) * (1))))) * ((2.0) * (((0) * ((x3) * (1))) * ((1) * ((0) * ((x3) * (1)))))) + ((0) * (abs((x0) * (1)))) * ((2.0) * (((0) * ((x3) * (1))) * ((1) * ((0) * ((x3) * (1)))))) + ((2.0) * (((0) * ((x3) * (1))) * ((1) * ((0) * ((x3) * (1)))))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + (0) * (abs((0) * ((x2) * (1)))) + (0) * (abs((0) * ((x3) * (1)))) + (0) * (abs((1) * ((x0) * (1)))) + (0) * (abs((0) * ((x3) * (1)))) + (0) * (abs((0) * ((x3) * (1)))) + (0) * (abs((1) * ((x2) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((1) * ((x2) * (1)))) + (abs((0) * ((x3) * (1)))) * (abs((1) * ((x2) * (1)))) + (abs((1) * ((x2) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x3) * (1)))) * (abs((1) * ((x2) * (1)))) + (abs((0) * ((x3) * (1)))) * (abs((1) * ((x2) * (1)))) + (0) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x3) * (1)))) ** (2.0) + (abs((0) * ((x3) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x3) * (1)))) ** (2.0) + (abs((0) * ((x3) * (1)))) ** (2.0) + (0) * (abs((0) * ((x0) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((0) * ((x0) * (1)))) + (abs((0) * ((x0) * (1)))) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x0) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x0) * (1)))) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x0) * (1)))) * (abs((0) * ((x3) * (1)))) + (0) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x3) * (1)))) ** (2.0) + (abs((0) * ((x3) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x3) * (1)))) ** (2.0) + (abs((0) * ((x3) * (1)))) ** (2.0) + (0) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x3) * (1)))) ** (2.0) + (abs((0) * ((x3) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x3) * (1)))) ** (2.0) + (abs((0) * ((x3) * (1)))) ** (2.0)) + ((0) * ((2.0) * (((1) * ((x2) * (1))) * ((1) * ((0) * ((x3) * (1)))))) + ((0) * ((1) * (abs((x2) * (1))))) * ((2.0) * (((1) * ((x2) * (1))) * ((1) * ((0) * ((x3) * (1)))))) + ((0) * (abs((x0) * (1)))) * ((2.0) * (((1) * ((x2) * (1))) * ((1) * ((0) * ((x3) * (1)))))) + ((2.0) * (((1) * ((x2) * (1))) * ((1) * ((0) * ((x3) * (1)))))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + (0) * (abs((0) * ((x2) * (1)))) + (0) * (abs((0) * ((x3) * (1)))) + (0) * (abs((1) * ((x0) * (1)))) + (0) * (abs((0) * ((x3) * (1)))) + (0) * (abs((0) * ((x3) * (1)))) + (0) * (abs((1) * ((x2) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((1) * ((x2) * (1)))) + (abs((0) * ((x3) * (1)))) * (abs((1) * ((x2) * (1)))) + (abs((1) * ((x2) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x3) * (1)))) * (abs((1) * ((x2) * (1)))) + (abs((0) * ((x3) * (1)))) * (abs((1) * ((x2) * (1)))) + (0) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x3) * (1)))) ** (2.0) + (abs((0) * ((x3) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x3) * (1)))) ** (2.0) + (abs((0) * ((x3) * (1)))) ** (2.0) + (0) * (abs((0) * ((x0) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((0) * ((x0) * (1)))) + (abs((0) * ((x0) * (1)))) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x0) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x0) * (1)))) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x0) * (1)))) * (abs((0) * ((x3) * (1)))) + (0) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x3) * (1)))) ** (2.0) + (abs((0) * ((x3) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x3) * (1)))) ** (2.0) + (abs((0) * ((x3) * (1)))) ** (2.0) + (0) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x3) * (1)))) ** (2.0) + (abs((0) * ((x3) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x3) * (1)))) ** (2.0) + (abs((0) * ((x3) * (1)))) ** (2.0)) + ((0) * ((2.0) * (((0) * ((x0) * (1))) * ((1) * ((0) * ((x3) * (1)))))) + ((0) * ((1) * (abs((x2) * (1))))) * ((2.0) * (((0) * ((x0) * (1))) * ((1) * ((0) * ((x3) * (1)))))) + ((0) * (abs((x0) * (1)))) * ((2.0) * (((0) * ((x0) * (1))) * ((1) * ((0) * ((x3) * (1)))))) + ((2.0) * (((0) * ((x0) * (1))) * ((1) * ((0) * ((x3) * (1)))))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + (0) * (abs((0) * ((x2) * (1)))) + (0) * (abs((0) * ((x3) * (1)))) + (0) * (abs((1) * ((x0) * (1)))) + (0) * (abs((0) * ((x3) * (1)))) + (0) * (abs((0) * ((x3) * (1)))) + (0) * (abs((1) * ((x2) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((1) * ((x2) * (1)))) + (abs((0) * ((x3) * (1)))) * (abs((1) * ((x2) * (1)))) + (abs((1) * ((x2) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x3) * (1)))) * (abs((1) * ((x2) * (1)))) + (abs((0) * ((x3) * (1)))) * (abs((1) * ((x2) * (1)))) + (0) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x3) * (1)))) ** (2.0) + (abs((0) * ((x3) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x3) * (1)))) ** (2.0) + (abs((0) * ((x3) * (1)))) ** (2.0) + (0) * (abs((0) * ((x0) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((0) * ((x0) * (1)))) + (abs((0) * ((x0) * (1)))) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x0) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x0) * (1)))) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x0) * (1)))) * (abs((0) * ((x3) * (1)))) + (0) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x3) * (1)))) ** (2.0) + (abs((0) * ((x3) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x3) * (1)))) ** (2.0) + (abs((0) * ((x3) * (1)))) ** (2.0) + (0) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x2) * (1)))) * (abs((0) * ((x3) * (1)))) + (abs((0) * ((x3) * (1)))) ** (2.0) + (abs((0) * ((x3) * (1)))) * (abs((1) * ((x0) * (1)))) + (abs((0) * ((x3) * (1)))) ** (2.0) + (abs((0) * ((x3) * (1)))) ** (2.0)) + (((0) * (((0) * ((x3) * (1))) * ((1) * ((0) * ((x2) * (1))))) + ((0) * ((1) * (abs((x2) * (1))))) * (((0) * ((x3) * (1))) * ((1) * ((0) * ((x2) * (1))))) + ((0) * (abs((x0) * (1)))) * (((0) * ((x3) * (1))) * ((1) * ((0) * ((x2) * (1))))) + (((0) * ((x3) * (1))) * ((1) * ((0) * ((x2) * (1))))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + ((0) * (((0) * ((x3) * (1))) * ((1) * ((0) * ((x3) * (1))))) + ((0) * ((1) * (abs((x2) * (1))))) * (((0) * ((x3) * (1))) * ((1) * ((0) * ((x3) * (1))))) + ((0) * (abs((x0) * (1)))) * (((0) * ((x3) * (1))) * ((1) * ((0) * ((x3) * (1))))) + (((0) * ((x3) * (1))) * ((1) * ((0) * ((x3) * (1))))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + ((0) * (((0) * ((x3) * (1))) * ((1) * ((1) * ((x0) * (1))))) + ((0) * ((1) * (abs((x2) * (1))))) * (((0) * ((x3) * (1))) * ((1) * ((1) * ((x0) * (1))))) + ((0) * (abs((x0) * (1)))) * (((0) * ((x3) * (1))) * ((1) * ((1) * ((x0) * (1))))) + (((0) * ((x3) * (1))) * ((1) * ((1) * ((x0) * (1))))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + ((0) * (((0) * ((x3) * (1))) * ((2.0) * ((0) * ((x3) * (1))))) + ((0) * ((1) * (abs((x2) * (1))))) * (((0) * ((x3) * (1))) * ((2.0) * ((0) * ((x3) * (1))))) + ((0) * (abs((x0) * (1)))) * (((0) * ((x3) * (1))) * ((2.0) * ((0) * ((x3) * (1))))) + (((0) * ((x3) * (1))) * ((2.0) * ((0) * ((x3) * (1))))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + ((0) * (((0) * ((x3) * (1))) * ((2.0) * ((0) * ((x3) * (1))))) + ((0) * ((1) * (abs((x2) * (1))))) * (((0) * ((x3) * (1))) * ((2.0) * ((0) * ((x3) * (1))))) + ((0) * (abs((x0) * (1)))) * (((0) * ((x3) * (1))) * ((2.0) * ((0) * ((x3) * (1))))) + (((0) * ((x3) * (1))) * ((2.0) * ((0) * ((x3) * (1))))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1))))) / (0 + abs((1) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + (((0) * (((0) * ((x3) * (1))) * ((1) * ((0) * ((x2) * (1))))) + ((0) * ((1) * (abs((x2) * (1))))) * (((0) * ((x3) * (1))) * ((1) * ((0) * ((x2) * (1))))) + ((0) * (abs((x0) * (1)))) * (((0) * ((x3) * (1))) * ((1) * ((0) * ((x2) * (1))))) + (((0) * ((x3) * (1))) * ((1) * ((0) * ((x2) * (1))))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + ((0) * (((0) * ((x3) * (1))) * ((1) * ((0) * ((x3) * (1))))) + ((0) * ((1) * (abs((x2) * (1))))) * (((0) * ((x3) * (1))) * ((1) * ((0) * ((x3) * (1))))) + ((0) * (abs((x0) * (1)))) * (((0) * ((x3) * (1))) * ((1) * ((0) * ((x3) * (1))))) + (((0) * ((x3) * (1))) * ((1) * ((0) * ((x3) * (1))))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + ((0) * (((0) * ((x3) * (1))) * ((1) * ((1) * ((x0) * (1))))) + ((0) * ((1) * (abs((x2) * (1))))) * (((0) * ((x3) * (1))) * ((1) * ((1) * ((x0) * (1))))) + ((0) * (abs((x0) * (1)))) * (((0) * ((x3) * (1))) * ((1) * ((1) * ((x0) * (1))))) + (((0) * ((x3) * (1))) * ((1) * ((1) * ((x0) * (1))))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + ((0) * (((0) * ((x3) * (1))) * ((2.0) * ((0) * ((x3) * (1))))) + ((0) * ((1) * (abs((x2) * (1))))) * (((0) * ((x3) * (1))) * ((2.0) * ((0) * ((x3) * (1))))) + ((0) * (abs((x0) * (1)))) * (((0) * ((x3) * (1))) * ((2.0) * ((0) * ((x3) * (1))))) + (((0) * ((x3) * (1))) * ((2.0) * ((0) * ((x3) * (1))))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + ((0) * (((0) * ((x3) * (1))) * ((2.0) * ((0) * ((x3) * (1))))) + ((0) * ((1) * (abs((x2) * (1))))) * (((0) * ((x3) * (1))) * ((2.0) * ((0) * ((x3) * (1))))) + ((0) * (abs((x0) * (1)))) * (((0) * ((x3) * (1))) * ((2.0) * ((0) * ((x3) * (1))))) + (((0) * ((x3) * (1))) * ((2.0) * ((0) * ((x3) * (1))))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1))))) / (0 + abs((1) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + ((0) * ((1) * ((0) * ((x3) * (1)))) + ((0.5) * (abs((x3) * (1)))) * ((1) * ((0) * ((x3) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x3) * (1)))) + ((0) * ((1) * ((1) * ((x3) * (1)))) + ((0.5) * (abs((x3) * (1)))) * ((1) * ((1) * ((x3) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x3) * (1)))), (((0) * (((-2.0) * ((0) * ((x2) * (1)))) * ((1) * ((x2) * (1)))) + ((0) * ((1) * (abs((x2) * (1))))) * (((-2.0) * ((0) * ((x2) * (1)))) * ((1) * ((x2) * (1)))) + ((0) * (abs((x0) * (1)))) * (((-2.0) * ((0) * ((x2) * (1)))) * ((1) * ((x2) * (1)))) + (((-2.0) * ((0) * ((x2) * (1)))) * ((1) * ((x2) * (1)))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + ((0) * (((0) * ((0) * ((x3) * (1)))) * ((1) * ((x2) * (1)))) + ((0) * ((1) * (abs((x2) * (1))))) * (((0) * ((0) * ((x3) * (1)))) * ((1) * ((x2) * (1)))) + ((0) * (abs((x0) * (1)))) * (((0) * ((0) * ((x3) * (1)))) * ((1) * ((x2) * (1)))) + (((0) * ((0) * ((x3) * (1)))) * ((1) * ((x2) * (1)))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + ((0) * (((-1) * ((1) * ((x0) * (1)))) * ((1) * ((x2) * (1)))) + ((0) * ((1) * (abs((x2) * (1))))) * (((-1) * ((1) * ((x0) * (1)))) * ((1) * ((x2) * (1)))) + ((0) * (abs((x0) * (1)))) * (((-1) * ((1) * ((x0) * (1)))) * ((1) * ((x2) * (1)))) + (((-1) * ((1) * ((x0) * (1)))) * ((1) * ((x2) * (1)))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + ((0) * (((-1) * ((0) * ((x3) * (1)))) * ((1) * ((x2) * (1)))) + ((0) * ((1) * (abs((x2) * (1))))) * (((-1) * ((0) * ((x3) * (1)))) * ((1) * ((x2) * (1)))) + ((0) * (abs((x0) * (1)))) * (((-1) * ((0) * ((x3) * (1)))) * ((1) * ((x2) * (1)))) + (((-1) * ((0) * ((x3) * (1)))) * ((1) * ((x2) * (1)))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + ((0) * (((0) * ((0) * ((x3) * (1)))) * ((1) * ((x2) * (1)))) + ((0) * ((1) * (abs((x2) * (1))))) * (((0) * ((0) * ((x3) * (1)))) * ((1) * ((x2) * (1)))) + ((0) * (abs((x0) * (1)))) * (((0) * ((0) * ((x3) * (1)))) * ((1) * ((x2) * (1)))) + (((0) * ((0) * ((x3) * (1)))) * ((1) * ((x2) * (1)))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1))))) / (0 + abs((1) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + (((0) * (((0) * ((x3) * (1))) * ((0) * ((0) * ((x2) * (1))))) + ((0) * ((1) * (abs((x2) * (1))))) * (((0) * ((x3) * (1))) * ((0) * ((0) * ((x2) * (1))))) + ((0) * (abs((x0) * (1)))) * (((0) * ((x3) * (1))) * ((0) * ((0) * ((x2) * (1))))) + (((0) * ((x3) * (1))) * ((0) * ((0) * ((x2) * (1))))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + ((0) * (((0) * ((x3) * (1))) * ((2.0) * ((0) * ((x3) * (1))))) + ((0) * ((1) * (abs((x2) * (1))))) * (((0) * ((x3) * (1))) * ((2.0) * ((0) * ((x3) * (1))))) + ((0) * (abs((x0) * (1)))) * (((0) * ((x3) * (1))) * ((2.0) * ((0) * ((x3) * (1))))) + (((0) * ((x3) * (1))) * ((2.0) * ((0) * ((x3) * (1))))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + ((0) * (((0) * ((x3) * (1))) * ((1) * ((1) * ((x0) * (1))))) + ((0) * ((1) * (abs((x2) * (1))))) * (((0) * ((x3) * (1))) * ((1) * ((1) * ((x0) * (1))))) + ((0) * (abs((x0) * (1)))) * (((0) * ((x3) * (1))) * ((1) * ((1) * ((x0) * (1))))) + (((0) * ((x3) * (1))) * ((1) * ((1) * ((x0) * (1))))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + ((0) * (((0) * ((x3) * (1))) * ((1) * ((0) * ((x3) * (1))))) + ((0) * ((1) * (abs((x2) * (1))))) * (((0) * ((x3) * (1))) * ((1) * ((0) * ((x3) * (1))))) + ((0) * (abs((x0) * (1)))) * (((0) * ((x3) * (1))) * ((1) * ((0) * ((x3) * (1))))) + (((0) * ((x3) * (1))) * ((1) * ((0) * ((x3) * (1))))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + ((0) * (((0) * ((x3) * (1))) * ((2.0) * ((0) * ((x3) * (1))))) + ((0) * ((1) * (abs((x2) * (1))))) * (((0) * ((x3) * (1))) * ((2.0) * ((0) * ((x3) * (1))))) + ((0) * (abs((x0) * (1)))) * (((0) * ((x3) * (1))) * ((2.0) * ((0) * ((x3) * (1))))) + (((0) * ((x3) * (1))) * ((2.0) * ((0) * ((x3) * (1))))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1))))) / (0 + abs((1) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + (((0) * (((-1) * ((0) * ((x2) * (1)))) * ((0) * ((x0) * (1)))) + ((0) * ((1) * (abs((x2) * (1))))) * (((-1) * ((0) * ((x2) * (1)))) * ((0) * ((x0) * (1)))) + ((0) * (abs((x0) * (1)))) * (((-1) * ((0) * ((x2) * (1)))) * ((0) * ((x0) * (1)))) + (((-1) * ((0) * ((x2) * (1)))) * ((0) * ((x0) * (1)))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + ((0) * (((0) * ((x0) * (1))) * ((1) * ((0) * ((x3) * (1))))) + ((0) * ((1) * (abs((x2) * (1))))) * (((0) * ((x0) * (1))) * ((1) * ((0) * ((x3) * (1))))) + ((0) * (abs((x0) * (1)))) * (((0) * ((x0) * (1))) * ((1) * ((0) * ((x3) * (1))))) + (((0) * ((x0) * (1))) * ((1) * ((0) * ((x3) * (1))))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + ((0) * (((0) * ((x0) * (1))) * ((1) * ((0) * ((x3) * (1))))) + ((0) * ((1) * (abs((x2) * (1))))) * (((0) * ((x0) * (1))) * ((1) * ((0) * ((x3) * (1))))) + ((0) * (abs((x0) * (1)))) * (((0) * ((x0) * (1))) * ((1) * ((0) * ((x3) * (1))))) + (((0) * ((x0) * (1))) * ((1) * ((0) * ((x3) * (1))))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1))))) / (0 + abs((1) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + (((0) * (((-1) * ((0) * ((x2) * (1)))) * ((0) * ((x3) * (1)))) + ((0) * ((1) * (abs((x2) * (1))))) * (((-1) * ((0) * ((x2) * (1)))) * ((0) * ((x3) * (1)))) + ((0) * (abs((x0) * (1)))) * (((-1) * ((0) * ((x2) * (1)))) * ((0) * ((x3) * (1)))) + (((-1) * ((0) * ((x2) * (1)))) * ((0) * ((x3) * (1)))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + ((0) * (((0) * ((x3) * (1))) * ((1) * ((0) * ((x3) * (1))))) + ((0) * ((1) * (abs((x2) * (1))))) * (((0) * ((x3) * (1))) * ((1) * ((0) * ((x3) * (1))))) + ((0) * (abs((x0) * (1)))) * (((0) * ((x3) * (1))) * ((1) * ((0) * ((x3) * (1))))) + (((0) * ((x3) * (1))) * ((1) * ((0) * ((x3) * (1))))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + ((0) * (((0) * ((x3) * (1))) * ((1) * ((0) * ((x3) * (1))))) + ((0) * ((1) * (abs((x2) * (1))))) * (((0) * ((x3) * (1))) * ((1) * ((0) * ((x3) * (1))))) + ((0) * (abs((x0) * (1)))) * (((0) * ((x3) * (1))) * ((1) * ((0) * ((x3) * (1))))) + (((0) * ((x3) * (1))) * ((1) * ((0) * ((x3) * (1))))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1))))) / (0 + abs((1) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + (((0) * (((0) * ((x3) * (1))) * ((0) * ((0) * ((x2) * (1))))) + ((0) * ((1) * (abs((x2) * (1))))) * (((0) * ((x3) * (1))) * ((0) * ((0) * ((x2) * (1))))) + ((0) * (abs((x0) * (1)))) * (((0) * ((x3) * (1))) * ((0) * ((0) * ((x2) * (1))))) + (((0) * ((x3) * (1))) * ((0) * ((0) * ((x2) * (1))))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + ((0) * (((0) * ((x3) * (1))) * ((2.0) * ((0) * ((x3) * (1))))) + ((0) * ((1) * (abs((x2) * (1))))) * (((0) * ((x3) * (1))) * ((2.0) * ((0) * ((x3) * (1))))) + ((0) * (abs((x0) * (1)))) * (((0) * ((x3) * (1))) * ((2.0) * ((0) * ((x3) * (1))))) + (((0) * ((x3) * (1))) * ((2.0) * ((0) * ((x3) * (1))))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + ((0) * (((0) * ((x3) * (1))) * ((1) * ((1) * ((x0) * (1))))) + ((0) * ((1) * (abs((x2) * (1))))) * (((0) * ((x3) * (1))) * ((1) * ((1) * ((x0) * (1))))) + ((0) * (abs((x0) * (1)))) * (((0) * ((x3) * (1))) * ((1) * ((1) * ((x0) * (1))))) + (((0) * ((x3) * (1))) * ((1) * ((1) * ((x0) * (1))))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + ((0) * (((0) * ((x3) * (1))) * ((1) * ((0) * ((x3) * (1))))) + ((0) * ((1) * (abs((x2) * (1))))) * (((0) * ((x3) * (1))) * ((1) * ((0) * ((x3) * (1))))) + ((0) * (abs((x0) * (1)))) * (((0) * ((x3) * (1))) * ((1) * ((0) * ((x3) * (1))))) + (((0) * ((x3) * (1))) * ((1) * ((0) * ((x3) * (1))))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + ((0) * (((0) * ((x3) * (1))) * ((2.0) * ((0) * ((x3) * (1))))) + ((0) * ((1) * (abs((x2) * (1))))) * (((0) * ((x3) * (1))) * ((2.0) * ((0) * ((x3) * (1))))) + ((0) * (abs((x0) * (1)))) * (((0) * ((x3) * (1))) * ((2.0) * ((0) * ((x3) * (1))))) + (((0) * ((x3) * (1))) * ((2.0) * ((0) * ((x3) * (1))))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1))))) / (0 + abs((1) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + ((0) * ((-1) * ((0) * ((x2) * (1)))) + ((-1) * ((0) * ((x2) * (1)))) * ((0.5) * (abs((x3) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x3) * (1)))) + ((0) * ((1) * ((0) * ((x3) * (1)))) + ((0.5) * (abs((x3) * (1)))) * ((1) * ((0) * ((x3) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x3) * (1)))) + ((0) * ((1) * ((1) * ((x3) * (1)))) + ((0.5) * (abs((x3) * (1)))) * ((1) * ((1) * ((x3) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x3) * (1)))), (((0) * (((-2.0) * ((0) * ((x3) * (1)))) * ((0) * ((x3) * (1)))) + ((0) * ((1) * (abs((x2) * (1))))) * (((-2.0) * ((0) * ((x3) * (1)))) * ((0) * ((x3) * (1)))) + ((0) * (abs((x0) * (1)))) * (((-2.0) * ((0) * ((x3) * (1)))) * ((0) * ((x3) * (1)))) + (((-2.0) * ((0) * ((x3) * (1)))) * ((0) * ((x3) * (1)))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + ((0) * (((-1) * ((0) * ((x2) * (1)))) * ((0) * ((x3) * (1)))) + ((0) * ((1) * (abs((x2) * (1))))) * (((-1) * ((0) * ((x2) * (1)))) * ((0) * ((x3) * (1)))) + ((0) * (abs((x0) * (1)))) * (((-1) * ((0) * ((x2) * (1)))) * ((0) * ((x3) * (1)))) + (((-1) * ((0) * ((x2) * (1)))) * ((0) * ((x3) * (1)))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + ((0) * (((-1) * ((1) * ((x0) * (1)))) * ((0) * ((x3) * (1)))) + ((0) * ((1) * (abs((x2) * (1))))) * (((-1) * ((1) * ((x0) * (1)))) * ((0) * ((x3) * (1)))) + ((0) * (abs((x0) * (1)))) * (((-1) * ((1) * ((x0) * (1)))) * ((0) * ((x3) * (1)))) + (((-1) * ((1) * ((x0) * (1)))) * ((0) * ((x3) * (1)))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + ((0) * (((-2.0) * ((0) * ((x3) * (1)))) * ((0) * ((x3) * (1)))) + ((0) * ((1) * (abs((x2) * (1))))) * (((-2.0) * ((0) * ((x3) * (1)))) * ((0) * ((x3) * (1)))) + ((0) * (abs((x0) * (1)))) * (((-2.0) * ((0) * ((x3) * (1)))) * ((0) * ((x3) * (1)))) + (((-2.0) * ((0) * ((x3) * (1)))) * ((0) * ((x3) * (1)))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + ((0) * (((-2.0) * ((0) * ((x3) * (1)))) * ((0) * ((x3) * (1)))) + ((0) * ((1) * (abs((x2) * (1))))) * (((-2.0) * ((0) * ((x3) * (1)))) * ((0) * ((x3) * (1)))) + ((0) * (abs((x0) * (1)))) * (((-2.0) * ((0) * ((x3) * (1)))) * ((0) * ((x3) * (1)))) + (((-2.0) * ((0) * ((x3) * (1)))) * ((0) * ((x3) * (1)))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1))))) / (0 + abs((1) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + (((0) * (((-1) * ((0) * ((x3) * (1)))) * ((1) * ((x2) * (1)))) + ((0) * ((1) * (abs((x2) * (1))))) * (((-1) * ((0) * ((x3) * (1)))) * ((1) * ((x2) * (1)))) + ((0) * (abs((x0) * (1)))) * (((-1) * ((0) * ((x3) * (1)))) * ((1) * ((x2) * (1)))) + (((-1) * ((0) * ((x3) * (1)))) * ((1) * ((x2) * (1)))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + ((0) * (((1) * ((x2) * (1))) * ((1) * ((1) * ((x0) * (1))))) + ((0) * ((1) * (abs((x2) * (1))))) * (((1) * ((x2) * (1))) * ((1) * ((1) * ((x0) * (1))))) + ((0) * (abs((x0) * (1)))) * (((1) * ((x2) * (1))) * ((1) * ((1) * ((x0) * (1))))) + (((1) * ((x2) * (1))) * ((1) * ((1) * ((x0) * (1))))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + ((0) * (((-1) * ((0) * ((x3) * (1)))) * ((1) * ((x2) * (1)))) + ((0) * ((1) * (abs((x2) * (1))))) * (((-1) * ((0) * ((x3) * (1)))) * ((1) * ((x2) * (1)))) + ((0) * (abs((x0) * (1)))) * (((-1) * ((0) * ((x3) * (1)))) * ((1) * ((x2) * (1)))) + (((-1) * ((0) * ((x3) * (1)))) * ((1) * ((x2) * (1)))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + ((0) * (((-1) * ((0) * ((x3) * (1)))) * ((1) * ((x2) * (1)))) + ((0) * ((1) * (abs((x2) * (1))))) * (((-1) * ((0) * ((x3) * (1)))) * ((1) * ((x2) * (1)))) + ((0) * (abs((x0) * (1)))) * (((-1) * ((0) * ((x3) * (1)))) * ((1) * ((x2) * (1)))) + (((-1) * ((0) * ((x3) * (1)))) * ((1) * ((x2) * (1)))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1))))) / (0 + abs((1) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + (((0) * (((-1) * ((0) * ((x3) * (1)))) * ((0) * ((x0) * (1)))) + ((0) * ((1) * (abs((x2) * (1))))) * (((-1) * ((0) * ((x3) * (1)))) * ((0) * ((x0) * (1)))) + ((0) * (abs((x0) * (1)))) * (((-1) * ((0) * ((x3) * (1)))) * ((0) * ((x0) * (1)))) + (((-1) * ((0) * ((x3) * (1)))) * ((0) * ((x0) * (1)))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + ((0) * (((0) * ((x0) * (1))) * ((1) * ((0) * ((x2) * (1))))) + ((0) * ((1) * (abs((x2) * (1))))) * (((0) * ((x0) * (1))) * ((1) * ((0) * ((x2) * (1))))) + ((0) * (abs((x0) * (1)))) * (((0) * ((x0) * (1))) * ((1) * ((0) * ((x2) * (1))))) + (((0) * ((x0) * (1))) * ((1) * ((0) * ((x2) * (1))))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + ((0) * (((-1) * ((0) * ((x3) * (1)))) * ((0) * ((x0) * (1)))) + ((0) * ((1) * (abs((x2) * (1))))) * (((-1) * ((0) * ((x3) * (1)))) * ((0) * ((x0) * (1)))) + ((0) * (abs((x0) * (1)))) * (((-1) * ((0) * ((x3) * (1)))) * ((0) * ((x0) * (1)))) + (((-1) * ((0) * ((x3) * (1)))) * ((0) * ((x0) * (1)))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + ((0) * (((-1) * ((0) * ((x3) * (1)))) * ((0) * ((x0) * (1)))) + ((0) * ((1) * (abs((x2) * (1))))) * (((-1) * ((0) * ((x3) * (1)))) * ((0) * ((x0) * (1)))) + ((0) * (abs((x0) * (1)))) * (((-1) * ((0) * ((x3) * (1)))) * ((0) * ((x0) * (1)))) + (((-1) * ((0) * ((x3) * (1)))) * ((0) * ((x0) * (1)))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1))))) / (0 + abs((1) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + (((0) * (((-2.0) * ((0) * ((x3) * (1)))) * ((0) * ((x3) * (1)))) + ((0) * ((1) * (abs((x2) * (1))))) * (((-2.0) * ((0) * ((x3) * (1)))) * ((0) * ((x3) * (1)))) + ((0) * (abs((x0) * (1)))) * (((-2.0) * ((0) * ((x3) * (1)))) * ((0) * ((x3) * (1)))) + (((-2.0) * ((0) * ((x3) * (1)))) * ((0) * ((x3) * (1)))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + ((0) * (((-1) * ((0) * ((x2) * (1)))) * ((0) * ((x3) * (1)))) + ((0) * ((1) * (abs((x2) * (1))))) * (((-1) * ((0) * ((x2) * (1)))) * ((0) * ((x3) * (1)))) + ((0) * (abs((x0) * (1)))) * (((-1) * ((0) * ((x2) * (1)))) * ((0) * ((x3) * (1)))) + (((-1) * ((0) * ((x2) * (1)))) * ((0) * ((x3) * (1)))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + ((0) * (((-1) * ((1) * ((x0) * (1)))) * ((0) * ((x3) * (1)))) + ((0) * ((1) * (abs((x2) * (1))))) * (((-1) * ((1) * ((x0) * (1)))) * ((0) * ((x3) * (1)))) + ((0) * (abs((x0) * (1)))) * (((-1) * ((1) * ((x0) * (1)))) * ((0) * ((x3) * (1)))) + (((-1) * ((1) * ((x0) * (1)))) * ((0) * ((x3) * (1)))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + ((0) * (((-2.0) * ((0) * ((x3) * (1)))) * ((0) * ((x3) * (1)))) + ((0) * ((1) * (abs((x2) * (1))))) * (((-2.0) * ((0) * ((x3) * (1)))) * ((0) * ((x3) * (1)))) + ((0) * (abs((x0) * (1)))) * (((-2.0) * ((0) * ((x3) * (1)))) * ((0) * ((x3) * (1)))) + (((-2.0) * ((0) * ((x3) * (1)))) * ((0) * ((x3) * (1)))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + ((0) * (((-2.0) * ((0) * ((x3) * (1)))) * ((0) * ((x3) * (1)))) + ((0) * ((1) * (abs((x2) * (1))))) * (((-2.0) * ((0) * ((x3) * (1)))) * ((0) * ((x3) * (1)))) + ((0) * (abs((x0) * (1)))) * (((-2.0) * ((0) * ((x3) * (1)))) * ((0) * ((x3) * (1)))) + (((-2.0) * ((0) * ((x3) * (1)))) * ((0) * ((x3) * (1)))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1))))) / (0 + abs((1) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + (((0) * (((-2.0) * ((0) * ((x3) * (1)))) * ((0) * ((x3) * (1)))) + ((0) * ((1) * (abs((x2) * (1))))) * (((-2.0) * ((0) * ((x3) * (1)))) * ((0) * ((x3) * (1)))) + ((0) * (abs((x0) * (1)))) * (((-2.0) * ((0) * ((x3) * (1)))) * ((0) * ((x3) * (1)))) + (((-2.0) * ((0) * ((x3) * (1)))) * ((0) * ((x3) * (1)))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + ((0) * (((-1) * ((0) * ((x2) * (1)))) * ((0) * ((x3) * (1)))) + ((0) * ((1) * (abs((x2) * (1))))) * (((-1) * ((0) * ((x2) * (1)))) * ((0) * ((x3) * (1)))) + ((0) * (abs((x0) * (1)))) * (((-1) * ((0) * ((x2) * (1)))) * ((0) * ((x3) * (1)))) + (((-1) * ((0) * ((x2) * (1)))) * ((0) * ((x3) * (1)))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + ((0) * (((-1) * ((1) * ((x0) * (1)))) * ((0) * ((x3) * (1)))) + ((0) * ((1) * (abs((x2) * (1))))) * (((-1) * ((1) * ((x0) * (1)))) * ((0) * ((x3) * (1)))) + ((0) * (abs((x0) * (1)))) * (((-1) * ((1) * ((x0) * (1)))) * ((0) * ((x3) * (1)))) + (((-1) * ((1) * ((x0) * (1)))) * ((0) * ((x3) * (1)))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + ((0) * (((-2.0) * ((0) * ((x3) * (1)))) * ((0) * ((x3) * (1)))) + ((0) * ((1) * (abs((x2) * (1))))) * (((-2.0) * ((0) * ((x3) * (1)))) * ((0) * ((x3) * (1)))) + ((0) * (abs((x0) * (1)))) * (((-2.0) * ((0) * ((x3) * (1)))) * ((0) * ((x3) * (1)))) + (((-2.0) * ((0) * ((x3) * (1)))) * ((0) * ((x3) * (1)))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + ((0) * (((-2.0) * ((0) * ((x3) * (1)))) * ((0) * ((x3) * (1)))) + ((0) * ((1) * (abs((x2) * (1))))) * (((-2.0) * ((0) * ((x3) * (1)))) * ((0) * ((x3) * (1)))) + ((0) * (abs((x0) * (1)))) * (((-2.0) * ((0) * ((x3) * (1)))) * ((0) * ((x3) * (1)))) + (((-2.0) * ((0) * ((x3) * (1)))) * ((0) * ((x3) * (1)))) * (((1) * (abs((x2) * (1)))) * (abs((x0) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1))))) / (0 + abs((1) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x3) * (1)))) + ((0) * ((-1) * ((1) * ((x3) * (1)))) + ((-1) * ((1) * ((x3) * (1)))) * ((0.5) * (abs((x3) * (1))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x3) * (1)))) + ((2.0) * ((0) * ((-1) * ((0) * ((x3) * (1))))) + (2.0) * (((-1) * ((0) * ((x3) * (1)))) * ((0.5) * (abs((x3) * (1)))))) / (0 + abs((0) * ((x2) * (1))) + abs((0) * ((x3) * (1))) + abs((0) * ((x0) * (1))) + abs((0) * ((x3) * (1))) + abs((1) * ((x3) * (1))))]
ysym = [sym.simplify(y1) for y1 in ysymraw]
ysage = [y1._sage_().substitute() for y1 in ysym]
try:
    y = vector([R(y1) for y1 in ysage])
except TypeError:
    y = None

# %%
ysage
# Out:
# [-x0*x2,
#  0.500000000000000*x3,
#  -x0*x2 + 0.500000000000000*x3,
#  x0*x2 - 0.500000000000000*x3]

# %%
y
# Out:
# (-x0*x2, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3)

# %%
y0
# Out:
# [1, 0, 0.10000000000000001?, 0]
