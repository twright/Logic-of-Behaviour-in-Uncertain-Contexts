# %%
# %display latex

# %%
import sys, os, warnings
from contextlib import contextmanager

@contextmanager
def suppress_stdout():
    with open(os.devnull, "w") as devnull:
        old_stdout = sys.stdout
        sys.stdout = devnull
        try:  
            yield
        finally:
            sys.stdout = old_stdout

import matplotlib
import matplotlib.pyplot as plt
            
@contextmanager
def suppress_warnings():
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        yield
        
matplotlib.use("pgf")
matplotlib.rcParams.update({
    "pgf.texsystem": "pdflatex",
    'font.family': 'sans',
    'text.usetex': True,
    'pgf.rcfonts': False,
    "axes.labelsize": 8,
    "font.size": 8,
})
textwidth = 6.26894

# %%
from lbuc import *
from lbuc.bondcalculus import *

# %% [markdown]
# ## Model

# %%
m = BondModel("WhelksAndLobsters.bond")
# Out:
# Running cmd: 'load "WhelksAndLobsters.bond"' ...

# %%
k = 0.8; b = 0.6; c = 0.3; e = 0.05; f = 2

# %%
P = Atomic((var("Whelk") - 1)^2 + var("Lobster")^2 < 0.2)

# %%
Qbox = [RIF(0, 0.31), RIF(1.5, 4)]

# %%
Q = (  Atomic(var("Whelk") < Qbox[0].upper())
     & Atomic(var("Whelk") > Qbox[0].lower())
     & Atomic(var("Lobster") < Qbox[1].upper())
     & Atomic(var("Lobster") > Qbox[1].lower()) )

# %%
s3 = m.process("[0, 1.4] Whelk || [0, 8] Lobster with network N(0.8, 0.6, 0.3, 0.05, 2)").as_system
# Out:
# Running cmd: 'savesage "[0, 1.4] Whelk || [0, 8] Lobster with network N(0.8, 0.6, 0.3, 0.05, 2)" "/tmp/bond-sage-script-t2fchy2k.py"' ...

# %% [markdown]
# ## Parameter set 1

# %% [markdown]
# ### Prop 1

# %%
kwargs = dict(step=0.05, order=6, estimation=1e-4, cutoff_threshold=1e-15, integration_method=2)

# %%
csign1 = F(RIF(0, 10), Q).context_signal_for_system(s3, 0, use_masks=True, **kwargs)
# Out:
# phi variables sfs = {x1, x0}
# system sfs = System(R, (x0, x1), [[0 .. 8], [-6.6610000000000012e-17 .. 1.4000000000000002]], (-2*x0*x1^2 - 0.05000000000000000?*x0^2 + 1.600000000000000?*x0*x1 - 0.05000000000000000?*x0, 0.3000000000000000?*x0*x1^2 - 0.2400000000000000?*x0*x1 - 0.600000000000000?*x1^2 + 0.600000000000000?*x1), varmap=bidict({'Lobster': x0, 'Whelk': x1})))
# Generating Reach Tree: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(), signal = <function base_context_signal.<locals>.<lambda> at 0x7fe7858c75e0>, reach_tree = None, ctx_mask=<lbuc.context_masks.ContextMask object at 0x7fe7858699a0>
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(Whelk < 0.310000000000000)>, precompose_systems=False, step=0.0500000000000000, order=6, estimation=0.000100000000000000, cutoff_threshold=1.00000000000000e-15, integration_method=2, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7fe785864180>, print_timings=False, unpreconditioning_order=6, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7fe785869760>, ctx_mask=<lbuc.context_masks.ContextMask object at 0x7fe78915af10>
# setting reach level to 0
# ====> reach_tree coordinate ()
# ==> reach_tree call at [[0 .. 8], [-6.6610000000000012e-17 .. 1.4000000000000002]]
# initials = (1.?e1, 0.?e1)
# context loop 0, 0
# ctx
# zero width static set [0.0..0.0]
# poly 1,0 = b'(([1.0000000000 , 1.0000000000] * c0))'
# context loop 1, 0
# ctx
# zero width static set [0.0..0.0]
# poly 2,0 = b'(([1.0000000000 , 1.0000000000] * c1))'
# contexts = ['[0.0..8.0]', '[-6.661000000000001e-17..1.4000000000000001]']
# statics  = []
# recomputing reachset
# PolyObserver(-x1 + 0.31000000000000000?, <flowstar.reachability.Reach object at 0x7fe7858e6940>, 0, symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# var_names = [b'local_t', b'x0', b'x1']
# res = b'(([0.3099999999 , 0.3100000000]) + ([-1.0000000000 , -1.0000000000] * x1))'
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# PolyObserver((([0.3099999999 , 0.3100000000]) + ([-1.0000000000 , -1.0000000000] * x1)), <flowstar.reachability.Reach object at 0x7fe7858e6940>, , symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 10.002000000000001], [[0.0000000000000000 .. 10.002000000000001]]))
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# fprime =
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7fe785b1f6d0>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=None), reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(Whelk > 0.000000000000000)>, precompose_systems=False, step=0.0500000000000000, order=6, estimation=0.000100000000000000, cutoff_threshold=1.00000000000000e-15, integration_method=2, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7fe785864180>, print_timings=False, unpreconditioning_order=6, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7fe785869760>, ctx_mask=<lbuc.context_masks.ContextMask object at 0x7fe7858fd640>
# setting reach level to 0
# ====> reach_tree coordinate ()
# recomputing reachset
# PolyObserver(x1, <flowstar.reachability.Reach object at 0x7fe7858e6940>, 0, symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# var_names = [b'local_t', b'x0', b'x1']
# res = b'(([1.0000000000 , 1.0000000000] * x1))'
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# PolyObserver((([1.0000000000 , 1.0000000000] * x1)), <flowstar.reachability.Reach object at 0x7fe7858e6940>, , symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 10.002000000000001], [[0.0000000000000000 .. 10.002000000000001]]))
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# fprime =
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7fe785b1f820>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=None), reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(Lobster < 4.00000000000000)>, precompose_systems=False, step=0.0500000000000000, order=6, estimation=0.000100000000000000, cutoff_threshold=1.00000000000000e-15, integration_method=2, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7fe785864180>, print_timings=False, unpreconditioning_order=6, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7fe785869760>, ctx_mask=<lbuc.context_masks.ContextMask object at 0x7fe78ca776d0>
# setting reach level to 0
# ====> reach_tree coordinate ()
# recomputing reachset
# PolyObserver(-x0 + 4, <flowstar.reachability.Reach object at 0x7fe7858e6940>, 0, symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# var_names = [b'local_t', b'x0', b'x1']
# res = b'(([4.0000000000 , 4.0000000000]) + ([-1.0000000000 , -1.0000000000] * x0))'
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# PolyObserver((([4.0000000000 , 4.0000000000]) + ([-1.0000000000 , -1.0000000000] * x0)), <flowstar.reachability.Reach object at 0x7fe7858e6940>, , symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 10.002000000000001], [[0.0000000000000000 .. 10.002000000000001]]))
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# fprime =
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7fe785b1f970>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=None), reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(Lobster > 1.50000000000000)>, precompose_systems=False, step=0.0500000000000000, order=6, estimation=0.000100000000000000, cutoff_threshold=1.00000000000000e-15, integration_method=2, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7fe785864180>, print_timings=False, unpreconditioning_order=6, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7fe785869760>, ctx_mask=<lbuc.context_masks.ContextMask object at 0x7fe7858fdeb0>
# setting reach level to 0
# ====> reach_tree coordinate ()
# recomputing reachset
# PolyObserver(x0 - 1.5000000000000000?, <flowstar.reachability.Reach object at 0x7fe7858e6940>, 0, symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# var_names = [b'local_t', b'x0', b'x1']
# res = b'(([-1.5000000000 , -1.5000000000]) + ([1.0000000000 , 1.0000000000] * x0))'
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# PolyObserver((([-1.5000000000 , -1.5000000000]) + ([1.0000000000 , 1.0000000000] * x0)), <flowstar.reachability.Reach object at 0x7fe7858e6940>, , symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 10.002000000000001], [[0.0000000000000000 .. 10.002000000000001]]))
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# fprime =
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7fe785b1fac0>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=None), reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=None), reach_tree = None, ctx_mask=None
# Monitoring initial signal: 1 items in 0.11 seconds
# (ContextSignal([0.0000000000000000 .. 10.002000000000001], [[0 .. 8], [-6.6610000000000012e-17 .. 1.4000000000000002]], [[-1 .. 1], [-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7fe78587f7c0>)).to_domain(0)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None, ctx_mask=None

# %%
with suppress_stdout():
    plo2b = csign1.plot_histogram2d(4, flip=True)

plo2b
# Out:
# Graphics object consisting of 199 graphics primitives

# %%
with suppress_stdout():
    plo2b = csign1.plot_histogram2d(5, flip=True)
    
plo2b
# Out:
# Graphics object consisting of 501 graphics primitives

# %%
with suppress_stdout():
    plo2b1 = csign1.plot_histogram2d(6, flip=True)
    
plo2b1
# Out:
# Graphics object consisting of 1056 graphics primitives

# %% [markdown]
# ### Prop 2

# %%
csign2 = F(RIF(0, 5), G(RIF(0, 5), P)).context_signal_for_system(s3, 0, use_masks=True, **kwargs)
# Out:
# phi variables sfs = {x1, x0}
# system sfs = System(R, (x0, x1), [[0 .. 8], [-6.6610000000000012e-17 .. 1.4000000000000002]], (-2*x0*x1^2 - 0.05000000000000000?*x0^2 + 1.600000000000000?*x0*x1 - 0.05000000000000000?*x0, 0.3000000000000000?*x0*x1^2 - 0.2400000000000000?*x0*x1 - 0.600000000000000?*x1^2 + 0.600000000000000?*x1), varmap=bidict({'Lobster': x0, 'Whelk': x1})))
# Generating Reach Tree: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(Lobster^2 + (Whelk - 1)^2 < 0.200000000000000)>, precompose_systems=False, step=0.0500000000000000, order=6, estimation=0.000100000000000000, cutoff_threshold=1.00000000000000e-15, integration_method=2, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7fe767e830c0>, print_timings=False, unpreconditioning_order=6, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7fe7681b7eb0>, ctx_mask=<lbuc.context_masks.ContextMask object at 0x7fe7678b7700>
# setting reach level to 0
# ====> reach_tree coordinate ()
# ==> reach_tree call at [[0 .. 8], [-6.6610000000000012e-17 .. 1.4000000000000002]]
# initials = (1.?e1, 0.?e1)
# context loop 0, 0
# ctx
# zero width static set [0.0..0.0]
# poly 1,0 = b'(([1.0000000000 , 1.0000000000] * c0))'
# context loop 1, 0
# ctx
# zero width static set [0.0..0.0]
# poly 2,0 = b'(([1.0000000000 , 1.0000000000] * c1))'
# contexts = ['[0.0..8.0]', '[-6.661000000000001e-17..1.4000000000000001]']
# statics  = []
# recomputing reachset
# PolyObserver(-x0^2 - x1^2 + 2*x1 - 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7fe7681c7700>, 0, symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# var_names = [b'local_t', b'x0', b'x1']
# res = b'(([-0.8000000001 , -0.7999999999]) + ([2.0000000000 , 2.0000000000] * x1) + ([-1.0000000000 , -1.0000000000] * x1^2) + ([-1.0000000000 , -1.0000000000] * x0^2))'
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# PolyObserver((([-0.8000000001 , -0.7999999999]) + ([2.0000000000 , 2.0000000000] * x1) + ([-1.0000000000 , -1.0000000000] * x1^2) + ([-1.0000000000 , -1.0000000000] * x0^2)), <flowstar.reachability.Reach object at 0x7fe7681c7700>, , symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 10.002000000000001], [[0.0000000000000000 .. 10.002000000000001]]))
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# fprime =
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7fe768141190>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=Mask([0.0000000000000000 .. 10.002000000000001], [[0.0000000000000000 .. 5.0020000000000007]])), reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=Mask([0.0000000000000000 .. 10.002000000000001], [[0.0000000000000000 .. 0.0020000000000006680]])), reach_tree = None, ctx_mask=None
# Monitoring initial signal: 1 items in 0.04 seconds
# (ContextSignal([0.0000000000000000 .. 10.002000000000001], [[0 .. 8], [-6.6610000000000012e-17 .. 1.4000000000000002]], [[-1 .. 1], [-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7fe768144400>)).to_domain(0)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=Mask([0.0000000000000000 .. -0.0000000000000000], [[0.0000000000000000 .. -0.0000000000000000]])), reach_tree = None, ctx_mask=None

# %%
with suppress_stdout():
    plo3 = csign2.plot_histogram2d(4, flip=True)

plo3
# Out:
# Graphics object consisting of 190 graphics primitives

# %%
with suppress_stdout():
    plo31 = csign2.plot_histogram2d(6, flip=True)

plo31
# Out:
# Graphics object consisting of 1111 graphics primitives

# %% [markdown]
# ## Parameter set 2

# %% [markdown]
# ### Prop 1

# %%
kwargs = dict(step=(0.02,0.1), order=6, estimation=1e-4, cutoff_threshold=1e-5, integration_method=2)

# %%
csign1 = F(RIF(0, 10), Q).context_signal_for_system(s3, 0, use_masks=False, **kwargs)
# Out:
# phi variables sfs = {x1, x0}
# system sfs = System(R, (x0, x1), [[0 .. 8], [-6.6610000000000012e-17 .. 1.4000000000000002]], (-2*x0*x1^2 - 0.05000000000000000?*x0^2 + 1.600000000000000?*x0*x1 - 0.05000000000000000?*x0, 0.3000000000000000?*x0*x1^2 - 0.2400000000000000?*x0*x1 - 0.600000000000000?*x1^2 + 0.600000000000000?*x1), varmap=bidict({'Lobster': x0, 'Whelk': x1})))
# Generating Reach Tree: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(), signal = <function base_context_signal.<locals>.<lambda> at 0x7fe7625e09d0>, reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(Whelk < 0.310000000000000)>, precompose_systems=False, step=(0.0200000000000000, 0.100000000000000), order=6, estimation=0.000100000000000000, cutoff_threshold=0.0000100000000000000, integration_method=2, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7fe7623bf300>, print_timings=False, unpreconditioning_order=6, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7fe761c00760>, ctx_mask=None
# setting reach level to 0
# ====> reach_tree coordinate ()
# ==> reach_tree call at [[0 .. 8], [-6.6610000000000012e-17 .. 1.4000000000000002]]
# initials = (1.?e1, 0.?e1)
# context loop 0, 0
# ctx
# zero width static set [0.0..0.0]
# poly 1,0 = b'(([1.0000000000 , 1.0000000000] * c0))'
# context loop 1, 0
# ctx
# zero width static set [0.0..0.0]
# poly 2,0 = b'(([1.0000000000 , 1.0000000000] * c1))'
# contexts = ['[0.0..8.0]', '[-6.661000000000001e-17..1.4000000000000001]']
# statics  = []
# recomputing reachset
# PolyObserver(-x1 + 0.31000000000000000?, <flowstar.reachability.Reach object at 0x7fe7858e65e0>, 0, symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# var_names = [b'local_t', b'x0', b'x1']
# res = b'(([0.3099999999 , 0.3100000000]) + ([-1.0000000000 , -1.0000000000] * x1))'
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# PolyObserver((([0.3099999999 , 0.3100000000]) + ([-1.0000000000 , -1.0000000000] * x1)), <flowstar.reachability.Reach object at 0x7fe7858e65e0>, , symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=None)
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# fprime =
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7fe761c7e190>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=None), reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(Whelk > 0.000000000000000)>, precompose_systems=False, step=(0.0200000000000000, 0.100000000000000), order=6, estimation=0.000100000000000000, cutoff_threshold=0.0000100000000000000, integration_method=2, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7fe7623bf300>, print_timings=False, unpreconditioning_order=6, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7fe761c00760>, ctx_mask=None
# setting reach level to 0
# ====> reach_tree coordinate ()
# recomputing reachset
# PolyObserver(x1, <flowstar.reachability.Reach object at 0x7fe7858e65e0>, 0, symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# var_names = [b'local_t', b'x0', b'x1']
# res = b'(([1.0000000000 , 1.0000000000] * x1))'
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# PolyObserver((([1.0000000000 , 1.0000000000] * x1)), <flowstar.reachability.Reach object at 0x7fe7858e65e0>, , symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=None)
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# fprime =
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7fe761c7e2e0>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=None), reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(Lobster < 4.00000000000000)>, precompose_systems=False, step=(0.0200000000000000, 0.100000000000000), order=6, estimation=0.000100000000000000, cutoff_threshold=0.0000100000000000000, integration_method=2, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7fe7623bf300>, print_timings=False, unpreconditioning_order=6, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7fe761c00760>, ctx_mask=None
# setting reach level to 0
# ====> reach_tree coordinate ()
# recomputing reachset
# PolyObserver(-x0 + 4, <flowstar.reachability.Reach object at 0x7fe7858e65e0>, 0, symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# var_names = [b'local_t', b'x0', b'x1']
# res = b'(([4.0000000000 , 4.0000000000]) + ([-1.0000000000 , -1.0000000000] * x0))'
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# PolyObserver((([4.0000000000 , 4.0000000000]) + ([-1.0000000000 , -1.0000000000] * x0)), <flowstar.reachability.Reach object at 0x7fe7858e65e0>, , symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=None)
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# fprime =
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7fe761c7e430>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=None), reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(Lobster > 1.50000000000000)>, precompose_systems=False, step=(0.0200000000000000, 0.100000000000000), order=6, estimation=0.000100000000000000, cutoff_threshold=0.0000100000000000000, integration_method=2, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7fe7623bf300>, print_timings=False, unpreconditioning_order=6, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7fe761c00760>, ctx_mask=None
# setting reach level to 0
# ====> reach_tree coordinate ()
# recomputing reachset
# PolyObserver(x0 - 1.5000000000000000?, <flowstar.reachability.Reach object at 0x7fe7858e65e0>, 0, symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# var_names = [b'local_t', b'x0', b'x1']
# res = b'(([-1.5000000000 , -1.5000000000]) + ([1.0000000000 , 1.0000000000] * x0))'
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# PolyObserver((([-1.5000000000 , -1.5000000000]) + ([1.0000000000 , 1.0000000000] * x0)), <flowstar.reachability.Reach object at 0x7fe7858e65e0>, , symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=None)
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# fprime =
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7fe761c7e580>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=None), reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=None), reach_tree = None, ctx_mask=None
# Monitoring initial signal: 1 items in 0.07 seconds
# (ContextSignal([0.0000000000000000 .. 10.002000000000001], [[0 .. 8], [-6.6610000000000012e-17 .. 1.4000000000000002]], [[-1 .. 1], [-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7fe7626120d0>)).to_domain(0)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None, ctx_mask=None

# %%
with suppress_stdout():
    plo2b = csign1.plot_histogram2d(4, flip=True)

plo2b
# Out:
# Graphics object consisting of 216 graphics primitives

# %%
with suppress_stdout():
    plo2b = csign1.plot_histogram2d(5, flip=True)
    
plo2b
# Out:
# Graphics object consisting of 556 graphics primitives

# %%
with suppress_stdout():
    plo2b2 = csign1.plot_histogram2d(6, flip=True)
    
plo2b2
# Out:
# /usr/lib/python3.8/site-packages/lbuc/interval_signals.py:261: UserWarning: Inconsistent intervals [0.0000000000000000 .. 0.050000000000000003] (False) and [0.050000000000000002 .. 0.10500000000000001] (True) in signal!
#   warnings.warn('Inconsistent intervals {} ({}) '
# /usr/lib/python3.8/site-packages/lbuc/interval_signals.py:261: UserWarning: Inconsistent intervals [0.0000000000000000 .. 0.025000000000000002] (False) and [0.025000000000000001 .. 0.052500000000000005] (True) in signal!
#   warnings.warn('Inconsistent intervals {} ({}) '
# Graphics object consisting of 1038 graphics primitives

# %% [markdown]
# ### Prop 2

# %%
csign2 = F(RIF(0, 5), G(RIF(0, 5), P)).context_signal_for_system(s3, 0, use_masks=True, **kwargs)
# Out:
# phi variables sfs = {x1, x0}
# system sfs = System(R, (x0, x1), [[0 .. 8], [-6.6610000000000012e-17 .. 1.4000000000000002]], (-2*x0*x1^2 - 0.05000000000000000?*x0^2 + 1.600000000000000?*x0*x1 - 0.05000000000000000?*x0, 0.3000000000000000?*x0*x1^2 - 0.2400000000000000?*x0*x1 - 0.600000000000000?*x1^2 + 0.600000000000000?*x1), varmap=bidict({'Lobster': x0, 'Whelk': x1})))
# Generating Reach Tree: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(Lobster^2 + (Whelk - 1)^2 < 0.200000000000000)>, precompose_systems=False, step=(0.0200000000000000, 0.100000000000000), order=6, estimation=0.000100000000000000, cutoff_threshold=0.0000100000000000000, integration_method=2, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7fe75fb08200>, print_timings=False, unpreconditioning_order=6, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7fe75fc6f730>, ctx_mask=<lbuc.context_masks.ContextMask object at 0x7fe75fc51a30>
# setting reach level to 0
# ====> reach_tree coordinate ()
# ==> reach_tree call at [[0 .. 8], [-6.6610000000000012e-17 .. 1.4000000000000002]]
# initials = (1.?e1, 0.?e1)
# context loop 0, 0
# ctx
# zero width static set [0.0..0.0]
# poly 1,0 = b'(([1.0000000000 , 1.0000000000] * c0))'
# context loop 1, 0
# ctx
# zero width static set [0.0..0.0]
# poly 2,0 = b'(([1.0000000000 , 1.0000000000] * c1))'
# contexts = ['[0.0..8.0]', '[-6.661000000000001e-17..1.4000000000000001]']
# statics  = []
# recomputing reachset
# PolyObserver(-x0^2 - x1^2 + 2*x1 - 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7fe758e15ee0>, 0, symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# var_names = [b'local_t', b'x0', b'x1']
# res = b'(([-0.8000000001 , -0.7999999999]) + ([2.0000000000 , 2.0000000000] * x1) + ([-1.0000000000 , -1.0000000000] * x1^2) + ([-1.0000000000 , -1.0000000000] * x0^2))'
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# PolyObserver((([-0.8000000001 , -0.7999999999]) + ([2.0000000000 , 2.0000000000] * x1) + ([-1.0000000000 , -1.0000000000] * x1^2) + ([-1.0000000000 , -1.0000000000] * x0^2)), <flowstar.reachability.Reach object at 0x7fe758e15ee0>, , symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 10.002000000000001], [[0.0000000000000000 .. 10.002000000000001]]))
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# fprime =
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7fe75f718430>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=Mask([0.0000000000000000 .. 10.002000000000001], [[0.0000000000000000 .. 5.0020000000000007]])), reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=Mask([0.0000000000000000 .. 10.002000000000001], [[0.0000000000000000 .. 0.0020000000000006680]])), reach_tree = None, ctx_mask=None
# Monitoring initial signal: 1 items in 0.04 seconds
# (ContextSignal([0.0000000000000000 .. 10.002000000000001], [[0 .. 8], [-6.6610000000000012e-17 .. 1.4000000000000002]], [[-1 .. 1], [-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7fe75fc51c70>)).to_domain(0)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=Mask([0.0000000000000000 .. -0.0000000000000000], [[0.0000000000000000 .. -0.0000000000000000]])), reach_tree = None, ctx_mask=None

# %%
with suppress_stdout():
    plo3 = csign2.plot_histogram2d(4, flip=True)

plo3
# Out:
# Graphics object consisting of 205 graphics primitives

# %%
with suppress_stdout():
    plo3 = csign2.plot_histogram2d(5, flip=True)

plo3
# Out:
# Graphics object consisting of 544 graphics primitives

# %% [markdown]
# ## Parameter set 3

# %% [markdown]
# ### Prop 1

# %%
kwargs = dict(step=(0.005,0.1), order=8, estimation=1e-6, cutoff_threshold=1e-7, integration_method=2)

# %%
csign1 = F(RIF(0, 10), Q).context_signal_for_system(s3, 0, use_masks=False, **kwargs)
# Out:
# phi variables sfs = {x1, x0}
# system sfs = System(R, (x0, x1), [[0 .. 8], [-6.6610000000000012e-17 .. 1.4000000000000002]], (-2*x0*x1^2 - 0.05000000000000000?*x0^2 + 1.600000000000000?*x0*x1 - 0.05000000000000000?*x0, 0.3000000000000000?*x0*x1^2 - 0.2400000000000000?*x0*x1 - 0.600000000000000?*x1^2 + 0.600000000000000?*x1), varmap=bidict({'Lobster': x0, 'Whelk': x1})))
# Generating Reach Tree: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(), signal = <function base_context_signal.<locals>.<lambda> at 0x7fe7571c8a60>, reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(Whelk < 0.310000000000000)>, precompose_systems=False, step=(0.00500000000000000, 0.100000000000000), order=8, estimation=1.00000000000000e-6, cutoff_threshold=1.00000000000000e-7, integration_method=2, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7fe757191100>, print_timings=False, unpreconditioning_order=8, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7fe7571dd8b0>, ctx_mask=None
# setting reach level to 0
# ====> reach_tree coordinate ()
# ==> reach_tree call at [[0 .. 8], [-6.6610000000000012e-17 .. 1.4000000000000002]]
# initials = (1.?e1, 0.?e1)
# context loop 0, 0
# ctx
# zero width static set [0.0..0.0]
# poly 1,0 = b'(([1.0000000000 , 1.0000000000] * c0))'
# context loop 1, 0
# ctx
# zero width static set [0.0..0.0]
# poly 2,0 = b'(([1.0000000000 , 1.0000000000] * c1))'
# contexts = ['[0.0..8.0]', '[-6.661000000000001e-17..1.4000000000000001]']
# statics  = []
# recomputing reachset
# PolyObserver(-x1 + 0.31000000000000000?, <flowstar.reachability.Reach object at 0x7fe7571e0040>, 0, symbolic_composition=False, symbolic_composition_order=8, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# var_names = [b'local_t', b'x0', b'x1']
# res = b'(([0.3099999999 , 0.3100000000]) + ([-1.0000000000 , -1.0000000000] * x1))'
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# PolyObserver((([0.3099999999 , 0.3100000000]) + ([-1.0000000000 , -1.0000000000] * x1)), <flowstar.reachability.Reach object at 0x7fe7571e0040>, , symbolic_composition=False, symbolic_composition_order=8, tentative_unpreconditioning=True, mask=None)
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# fprime =
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7fe7576f9970>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=None), reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(Whelk > 0.000000000000000)>, precompose_systems=False, step=(0.00500000000000000, 0.100000000000000), order=8, estimation=1.00000000000000e-6, cutoff_threshold=1.00000000000000e-7, integration_method=2, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7fe757191100>, print_timings=False, unpreconditioning_order=8, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7fe7571dd8b0>, ctx_mask=None
# setting reach level to 0
# ====> reach_tree coordinate ()
# recomputing reachset
# PolyObserver(x1, <flowstar.reachability.Reach object at 0x7fe7571e0040>, 0, symbolic_composition=False, symbolic_composition_order=8, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# var_names = [b'local_t', b'x0', b'x1']
# res = b'(([1.0000000000 , 1.0000000000] * x1))'
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# PolyObserver((([1.0000000000 , 1.0000000000] * x1)), <flowstar.reachability.Reach object at 0x7fe7571e0040>, , symbolic_composition=False, symbolic_composition_order=8, tentative_unpreconditioning=True, mask=None)
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# fprime =
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7fe7576f9ac0>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=None), reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(Lobster < 4.00000000000000)>, precompose_systems=False, step=(0.00500000000000000, 0.100000000000000), order=8, estimation=1.00000000000000e-6, cutoff_threshold=1.00000000000000e-7, integration_method=2, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7fe757191100>, print_timings=False, unpreconditioning_order=8, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7fe7571dd8b0>, ctx_mask=None
# setting reach level to 0
# ====> reach_tree coordinate ()
# recomputing reachset
# PolyObserver(-x0 + 4, <flowstar.reachability.Reach object at 0x7fe7571e0040>, 0, symbolic_composition=False, symbolic_composition_order=8, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# var_names = [b'local_t', b'x0', b'x1']
# res = b'(([4.0000000000 , 4.0000000000]) + ([-1.0000000000 , -1.0000000000] * x0))'
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# PolyObserver((([4.0000000000 , 4.0000000000]) + ([-1.0000000000 , -1.0000000000] * x0)), <flowstar.reachability.Reach object at 0x7fe7571e0040>, , symbolic_composition=False, symbolic_composition_order=8, tentative_unpreconditioning=True, mask=None)
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# fprime =
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7fe7576f9c10>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=None), reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(Lobster > 1.50000000000000)>, precompose_systems=False, step=(0.00500000000000000, 0.100000000000000), order=8, estimation=1.00000000000000e-6, cutoff_threshold=1.00000000000000e-7, integration_method=2, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7fe757191100>, print_timings=False, unpreconditioning_order=8, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7fe7571dd8b0>, ctx_mask=None
# setting reach level to 0
# ====> reach_tree coordinate ()
# recomputing reachset
# PolyObserver(x0 - 1.5000000000000000?, <flowstar.reachability.Reach object at 0x7fe7571e0040>, 0, symbolic_composition=False, symbolic_composition_order=8, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# var_names = [b'local_t', b'x0', b'x1']
# res = b'(([-1.5000000000 , -1.5000000000]) + ([1.0000000000 , 1.0000000000] * x0))'
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# PolyObserver((([-1.5000000000 , -1.5000000000]) + ([1.0000000000 , 1.0000000000] * x0)), <flowstar.reachability.Reach object at 0x7fe7571e0040>, , symbolic_composition=False, symbolic_composition_order=8, tentative_unpreconditioning=True, mask=None)
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# fprime =
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7fe7576f9d60>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=None), reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=None), reach_tree = None, ctx_mask=None
# Monitoring initial signal: 1 items in 0.13 seconds
# (ContextSignal([0.0000000000000000 .. 10.002000000000001], [[0 .. 8], [-6.6610000000000012e-17 .. 1.4000000000000002]], [[-1 .. 1], [-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7fe7571e7df0>)).to_domain(0)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None, ctx_mask=None

# %%
with suppress_stdout():
    plo2b = csign1.plot_histogram2d(4, flip=True)

plo2b
# Out:
# Graphics object consisting of 148 graphics primitives

# %%
with suppress_stdout():
    plo2b = csign1.plot_histogram2d(5, flip=True)
    
plo2b
# Out:
# Graphics object consisting of 334 graphics primitives

# %%
with suppress_stdout():
    plo2b3 = csign1.plot_histogram2d(6,flip=True)
    
plo2b3
# Out:
# /usr/lib/python3.8/site-packages/lbuc/interval_signals.py:261: UserWarning: Inconsistent intervals [0.0000000000000000 .. 0.025000000000000002] (False) and [0.025000000000000001 .. 0.052500000000000005] (True) in signal!
#   warnings.warn('Inconsistent intervals {} ({}) '
# Graphics object consisting of 661 graphics primitives

# %% [markdown]
# ### Prop 2

# %%
csign2 = F(RIF(0, 5), G(RIF(0, 5), P)).context_signal_for_system(s3, 0, use_masks=True, **kwargs)
# Out:
# phi variables sfs = {x1, x0}
# system sfs = System(R, (x0, x1), [[0 .. 8], [-6.6610000000000012e-17 .. 1.4000000000000002]], (-2*x0*x1^2 - 0.05000000000000000?*x0^2 + 1.600000000000000?*x0*x1 - 0.05000000000000000?*x0, 0.3000000000000000?*x0*x1^2 - 0.2400000000000000?*x0*x1 - 0.600000000000000?*x1^2 + 0.600000000000000?*x1), varmap=bidict({'Lobster': x0, 'Whelk': x1})))
# Generating Reach Tree: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(Lobster^2 + (Whelk - 1)^2 < 0.200000000000000)>, precompose_systems=False, step=(0.00500000000000000, 0.100000000000000), order=8, estimation=1.00000000000000e-6, cutoff_threshold=1.00000000000000e-7, integration_method=2, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7fe74dfc45c0>, print_timings=False, unpreconditioning_order=8, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7fe74dfc8eb0>, ctx_mask=<lbuc.context_masks.ContextMask object at 0x7fe7549a5400>
# setting reach level to 0
# ====> reach_tree coordinate ()
# ==> reach_tree call at [[0 .. 8], [-6.6610000000000012e-17 .. 1.4000000000000002]]
# initials = (1.?e1, 0.?e1)
# context loop 0, 0
# ctx
# zero width static set [0.0..0.0]
# poly 1,0 = b'(([1.0000000000 , 1.0000000000] * c0))'
# context loop 1, 0
# ctx
# zero width static set [0.0..0.0]
# poly 2,0 = b'(([1.0000000000 , 1.0000000000] * c1))'
# contexts = ['[0.0..8.0]', '[-6.661000000000001e-17..1.4000000000000001]']
# statics  = []
# recomputing reachset
# PolyObserver(-x0^2 - x1^2 + 2*x1 - 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7fe74efaeee0>, 0, symbolic_composition=False, symbolic_composition_order=8, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# var_names = [b'local_t', b'x0', b'x1']
# res = b'(([-0.8000000001 , -0.7999999999]) + ([2.0000000000 , 2.0000000000] * x1) + ([-1.0000000000 , -1.0000000000] * x1^2) + ([-1.0000000000 , -1.0000000000] * x0^2))'
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# PolyObserver((([-0.8000000001 , -0.7999999999]) + ([2.0000000000 , 2.0000000000] * x1) + ([-1.0000000000 , -1.0000000000] * x1^2) + ([-1.0000000000 , -1.0000000000] * x0^2)), <flowstar.reachability.Reach object at 0x7fe74efaeee0>, , symbolic_composition=False, symbolic_composition_order=8, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 10.002000000000001], [[0.0000000000000000 .. 10.002000000000001]]))
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# fprime =
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7fe74e597eb0>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=Mask([0.0000000000000000 .. 10.002000000000001], [[0.0000000000000000 .. 5.0020000000000007]])), reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=Mask([0.0000000000000000 .. 10.002000000000001], [[0.0000000000000000 .. 0.0020000000000006680]])), reach_tree = None, ctx_mask=None
# Monitoring initial signal: 1 items in 0.12 seconds
# (ContextSignal([0.0000000000000000 .. 10.002000000000001], [[0 .. 8], [-6.6610000000000012e-17 .. 1.4000000000000002]], [[-1 .. 1], [-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7fe74dfd1190>)).to_domain(0)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=Mask([0.0000000000000000 .. -0.0000000000000000], [[0.0000000000000000 .. -0.0000000000000000]])), reach_tree = None, ctx_mask=None

# %%
with suppress_stdout():
    plo3 = csign2.plot_histogram2d(4, flip=True)

plo3
# Out:
# Graphics object consisting of 138 graphics primitives

# %%
with suppress_stdout():
    plo3 = csign2.plot_histogram2d(5, flip=True)

plo3
# Out:
# Graphics object consisting of 336 graphics primitives

# %% [markdown]
# ## Parameter set 4

# %% [markdown]
# ### Prop 1

# %%
kwargs = dict(step=(0.005,0.1), order=8, estimation=1e-6, cutoff_threshold=1e-7, integration_method=2)

# %%
csign1 = F(RIF(0, 10), Q).context_signal_for_system(s3, 0, use_masks=False, **kwargs)
# Out:
# phi variables sfs = {x1, x0}
# system sfs = System(R, (x0, x1), [[0 .. 8], [-6.6610000000000012e-17 .. 1.4000000000000002]], (-2*x0*x1^2 - 0.05000000000000000?*x0^2 + 1.600000000000000?*x0*x1 - 0.05000000000000000?*x0, 0.3000000000000000?*x0*x1^2 - 0.2400000000000000?*x0*x1 - 0.600000000000000?*x1^2 + 0.600000000000000?*x1), varmap=bidict({'Lobster': x0, 'Whelk': x1})))
# Generating Reach Tree: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(), signal = <function base_context_signal.<locals>.<lambda> at 0x7fe75f6813a0>, reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(Whelk < 0.310000000000000)>, precompose_systems=False, step=(0.00500000000000000, 0.100000000000000), order=8, estimation=1.00000000000000e-6, cutoff_threshold=1.00000000000000e-7, integration_method=2, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7fe757191bc0>, print_timings=False, unpreconditioning_order=8, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7fe7671d53d0>, ctx_mask=None
# setting reach level to 0
# ====> reach_tree coordinate ()
# ==> reach_tree call at [[0 .. 8], [-6.6610000000000012e-17 .. 1.4000000000000002]]
# initials = (1.?e1, 0.?e1)
# context loop 0, 0
# ctx
# zero width static set [0.0..0.0]
# poly 1,0 = b'(([1.0000000000 , 1.0000000000] * c0))'
# context loop 1, 0
# ctx
# zero width static set [0.0..0.0]
# poly 2,0 = b'(([1.0000000000 , 1.0000000000] * c1))'
# contexts = ['[0.0..8.0]', '[-6.661000000000001e-17..1.4000000000000001]']
# statics  = []
# recomputing reachset
# PolyObserver(-x1 + 0.31000000000000000?, <flowstar.reachability.Reach object at 0x7fe74cad03a0>, 0, symbolic_composition=False, symbolic_composition_order=8, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# var_names = [b'local_t', b'x0', b'x1']
# res = b'(([0.3099999999 , 0.3100000000]) + ([-1.0000000000 , -1.0000000000] * x1))'
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# PolyObserver((([0.3099999999 , 0.3100000000]) + ([-1.0000000000 , -1.0000000000] * x1)), <flowstar.reachability.Reach object at 0x7fe74cad03a0>, , symbolic_composition=False, symbolic_composition_order=8, tentative_unpreconditioning=True, mask=None)
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# fprime =
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7fe74c982d60>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=None), reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(Whelk > 0.000000000000000)>, precompose_systems=False, step=(0.00500000000000000, 0.100000000000000), order=8, estimation=1.00000000000000e-6, cutoff_threshold=1.00000000000000e-7, integration_method=2, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7fe757191bc0>, print_timings=False, unpreconditioning_order=8, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7fe7671d53d0>, ctx_mask=None
# setting reach level to 0
# ====> reach_tree coordinate ()
# recomputing reachset
# PolyObserver(x1, <flowstar.reachability.Reach object at 0x7fe74cad03a0>, 0, symbolic_composition=False, symbolic_composition_order=8, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# var_names = [b'local_t', b'x0', b'x1']
# res = b'(([1.0000000000 , 1.0000000000] * x1))'
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# PolyObserver((([1.0000000000 , 1.0000000000] * x1)), <flowstar.reachability.Reach object at 0x7fe74cad03a0>, , symbolic_composition=False, symbolic_composition_order=8, tentative_unpreconditioning=True, mask=None)
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# fprime =
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7fe74c982eb0>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=None), reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(Lobster < 4.00000000000000)>, precompose_systems=False, step=(0.00500000000000000, 0.100000000000000), order=8, estimation=1.00000000000000e-6, cutoff_threshold=1.00000000000000e-7, integration_method=2, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7fe757191bc0>, print_timings=False, unpreconditioning_order=8, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7fe7671d53d0>, ctx_mask=None
# setting reach level to 0
# ====> reach_tree coordinate ()
# recomputing reachset
# PolyObserver(-x0 + 4, <flowstar.reachability.Reach object at 0x7fe74cad03a0>, 0, symbolic_composition=False, symbolic_composition_order=8, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# var_names = [b'local_t', b'x0', b'x1']
# res = b'(([4.0000000000 , 4.0000000000]) + ([-1.0000000000 , -1.0000000000] * x0))'
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# PolyObserver((([4.0000000000 , 4.0000000000]) + ([-1.0000000000 , -1.0000000000] * x0)), <flowstar.reachability.Reach object at 0x7fe74cad03a0>, , symbolic_composition=False, symbolic_composition_order=8, tentative_unpreconditioning=True, mask=None)
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# fprime =
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7fe74c640040>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=None), reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(Lobster > 1.50000000000000)>, precompose_systems=False, step=(0.00500000000000000, 0.100000000000000), order=8, estimation=1.00000000000000e-6, cutoff_threshold=1.00000000000000e-7, integration_method=2, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7fe757191bc0>, print_timings=False, unpreconditioning_order=8, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7fe7671d53d0>, ctx_mask=None
# setting reach level to 0
# ====> reach_tree coordinate ()
# recomputing reachset
# PolyObserver(x0 - 1.5000000000000000?, <flowstar.reachability.Reach object at 0x7fe74cad03a0>, 0, symbolic_composition=False, symbolic_composition_order=8, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# var_names = [b'local_t', b'x0', b'x1']
# res = b'(([-1.5000000000 , -1.5000000000]) + ([1.0000000000 , 1.0000000000] * x0))'
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# PolyObserver((([-1.5000000000 , -1.5000000000]) + ([1.0000000000 , 1.0000000000] * x0)), <flowstar.reachability.Reach object at 0x7fe74cad03a0>, , symbolic_composition=False, symbolic_composition_order=8, tentative_unpreconditioning=True, mask=None)
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# fprime =
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7fe74c640190>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=None), reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=None), reach_tree = None, ctx_mask=None
# Monitoring initial signal: 1 items in 0.19 seconds
# (ContextSignal([0.0000000000000000 .. 10.002000000000001], [[0 .. 8], [-6.6610000000000012e-17 .. 1.4000000000000002]], [[-1 .. 1], [-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7fe74c65cd90>)).to_domain(0)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None, ctx_mask=None

# %%
with suppress_stdout():
    plo2b = csign1.plot_histogram2d(4, flip=True)

plo2b
# Out:
# Graphics object consisting of 148 graphics primitives

# %%
with suppress_stdout():
    plo2b = csign1.plot_histogram2d(5, flip=True)
    
plo2b
# Out:
# Graphics object consisting of 334 graphics primitives

# %%
with suppress_stdout():
    plo2b4 = csign1.plot_histogram2d(6,flip=True)
    
plo2b4
# Out:
# /usr/lib/python3.8/site-packages/lbuc/interval_signals.py:261: UserWarning: Inconsistent intervals [0.0000000000000000 .. 0.025000000000000002] (False) and [0.025000000000000001 .. 0.052500000000000005] (True) in signal!
#   warnings.warn('Inconsistent intervals {} ({}) '
# Graphics object consisting of 661 graphics primitives

# %% [markdown]
# ### Prop 2

# %%
csign2 = F(RIF(0, 5), G(RIF(0, 5), P)).context_signal_for_system(s3, 0, use_masks=True, **kwargs)
# Out:
# phi variables sfs = {x1, x0}
# system sfs = System(R, (x0, x1), [[0 .. 8], [-6.6610000000000012e-17 .. 1.4000000000000002]], (-2*x0*x1^2 - 0.05000000000000000?*x0^2 + 1.600000000000000?*x0*x1 - 0.05000000000000000?*x0, 0.3000000000000000?*x0*x1^2 - 0.2400000000000000?*x0*x1 - 0.600000000000000?*x1^2 + 0.600000000000000?*x1), varmap=bidict({'Lobster': x0, 'Whelk': x1})))
# Generating Reach Tree: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(Lobster^2 + (Whelk - 1)^2 < 0.200000000000000)>, precompose_systems=False, step=(0.00500000000000000, 0.100000000000000), order=8, estimation=1.00000000000000e-6, cutoff_threshold=1.00000000000000e-7, integration_method=2, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7fe74465ce40>, print_timings=False, unpreconditioning_order=8, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7fe756b4e8e0>, ctx_mask=<lbuc.context_masks.ContextMask object at 0x7fe75548a4f0>
# setting reach level to 0
# ====> reach_tree coordinate ()
# ==> reach_tree call at [[0 .. 8], [-6.6610000000000012e-17 .. 1.4000000000000002]]
# initials = (1.?e1, 0.?e1)
# context loop 0, 0
# ctx
# zero width static set [0.0..0.0]
# poly 1,0 = b'(([1.0000000000 , 1.0000000000] * c0))'
# context loop 1, 0
# ctx
# zero width static set [0.0..0.0]
# poly 2,0 = b'(([1.0000000000 , 1.0000000000] * c1))'
# contexts = ['[0.0..8.0]', '[-6.661000000000001e-17..1.4000000000000001]']
# statics  = []
# recomputing reachset
# PolyObserver(-x0^2 - x1^2 + 2*x1 - 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7fe744657040>, 0, symbolic_composition=False, symbolic_composition_order=8, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# var_names = [b'local_t', b'x0', b'x1']
# res = b'(([-0.8000000001 , -0.7999999999]) + ([2.0000000000 , 2.0000000000] * x1) + ([-1.0000000000 , -1.0000000000] * x1^2) + ([-1.0000000000 , -1.0000000000] * x0^2))'
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# PolyObserver((([-0.8000000001 , -0.7999999999]) + ([2.0000000000 , 2.0000000000] * x1) + ([-1.0000000000 , -1.0000000000] * x1^2) + ([-1.0000000000 , -1.0000000000] * x0^2)), <flowstar.reachability.Reach object at 0x7fe744657040>, , symbolic_composition=False, symbolic_composition_order=8, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 10.002000000000001], [[0.0000000000000000 .. 10.002000000000001]]))
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# fprime =
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7fe7446a7eb0>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=Mask([0.0000000000000000 .. 10.002000000000001], [[0.0000000000000000 .. 5.0020000000000007]])), reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=Mask([0.0000000000000000 .. 10.002000000000001], [[0.0000000000000000 .. 0.0020000000000006680]])), reach_tree = None, ctx_mask=None
# Monitoring initial signal: 1 items in 0.13 seconds
# (ContextSignal([0.0000000000000000 .. 10.002000000000001], [[0 .. 8], [-6.6610000000000012e-17 .. 1.4000000000000002]], [[-1 .. 1], [-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7fe755536ac0>)).to_domain(0)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=Mask([0.0000000000000000 .. -0.0000000000000000], [[0.0000000000000000 .. -0.0000000000000000]])), reach_tree = None, ctx_mask=None

# %%
with suppress_stdout():
    plo3 = csign2.plot_histogram2d(4, flip=True)

plo3
# Out:
# Graphics object consisting of 138 graphics primitives

# %%
with suppress_stdout():
    plo3 = csign2.plot_histogram2d(5, flip=True)

plo3
# Out:
# Graphics object consisting of 336 graphics primitives

# %%
with suppress_stdout():
    plo2 = csign2.plot_histogram2d(6, flip=True)

plo2

# %% [markdown]
# ## Physical Tree

# %%
kwargs = dict(step=0.05, order=6, estimation=1e-4, cutoff_threshold=1e-15, integration_method=2)

# %%
from lbuc import RestrictionMethod

# %%
csignp = F(RIF(0, 10), Q).context_signal_for_system(s3, 0, use_masks=True, restriction_method=RestrictionMethod.RECOMPUTE_FLOWPIPE, **kwargs)
# Out:
# phi variables sfs = {x1, x0}
# system sfs = System(R, (x0, x1), [[0 .. 8], [-6.6610000000000012e-17 .. 1.4000000000000002]], (-2*x0*x1^2 - 0.05000000000000000?*x0^2 + 1.600000000000000?*x0*x1 - 0.05000000000000000?*x0, 0.3000000000000000?*x0*x1^2 - 0.2400000000000000?*x0*x1 - 0.600000000000000?*x1^2 + 0.600000000000000?*x1), varmap=bidict({'Lobster': x0, 'Whelk': x1})))
# Generating Reach Tree: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(), signal = <function base_context_signal.<locals>.<lambda> at 0x7fe742c62f70>, reach_tree = None, ctx_mask=<lbuc.context_masks.ContextMask object at 0x7fe742c6a970>
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(Whelk < 0.310000000000000)>, precompose_systems=False, step=0.0500000000000000, order=6, estimation=0.000100000000000000, cutoff_threshold=1.00000000000000e-15, integration_method=2, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7fe742f1b840>, print_timings=False, unpreconditioning_order=6, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7fe742c6fe80>, ctx_mask=<lbuc.context_masks.ContextMask object at 0x7fe74d927ee0>
# setting reach level to 0
# ====> reach_tree coordinate ()
# ==> reach_tree call at [[0 .. 8], [-6.6610000000000012e-17 .. 1.4000000000000002]]
# initials = (1.?e1, 0.?e1)
# context loop 0, 0
# ctx
# zero width static set [0.0..0.0]
# poly 1,0 = b'(([1.0000000000 , 1.0000000000] * c0))'
# context loop 1, 0
# ctx
# zero width static set [0.0..0.0]
# poly 2,0 = b'(([1.0000000000 , 1.0000000000] * c1))'
# contexts = ['[0.0..8.0]', '[-6.661000000000001e-17..1.4000000000000001]']
# statics  = []
# recomputing reachset
# PolyObserver(-x1 + 0.31000000000000000?, <flowstar.reachability.Reach object at 0x7fe7430834c0>, 0, symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# var_names = [b'local_t', b'x0', b'x1']
# res = b'(([0.3099999999 , 0.3100000000]) + ([-1.0000000000 , -1.0000000000] * x1))'
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# PolyObserver((([0.3099999999 , 0.3100000000]) + ([-1.0000000000 , -1.0000000000] * x1)), <flowstar.reachability.Reach object at 0x7fe7430834c0>, , symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 10.002000000000001], [[0.0000000000000000 .. 10.002000000000001]]))
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# fprime =
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7fe742fafd60>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=None), reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(Whelk > 0.000000000000000)>, precompose_systems=False, step=0.0500000000000000, order=6, estimation=0.000100000000000000, cutoff_threshold=1.00000000000000e-15, integration_method=2, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7fe742f1b840>, print_timings=False, unpreconditioning_order=6, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7fe742c6fe80>, ctx_mask=<lbuc.context_masks.ContextMask object at 0x7fe742c78910>
# setting reach level to 0
# ====> reach_tree coordinate ()
# recomputing reachset
# PolyObserver(x1, <flowstar.reachability.Reach object at 0x7fe7430834c0>, 0, symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# var_names = [b'local_t', b'x0', b'x1']
# res = b'(([1.0000000000 , 1.0000000000] * x1))'
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# PolyObserver((([1.0000000000 , 1.0000000000] * x1)), <flowstar.reachability.Reach object at 0x7fe7430834c0>, , symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 10.002000000000001], [[0.0000000000000000 .. 10.002000000000001]]))
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# fprime =
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7fe742fafeb0>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=None), reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(Lobster < 4.00000000000000)>, precompose_systems=False, step=0.0500000000000000, order=6, estimation=0.000100000000000000, cutoff_threshold=1.00000000000000e-15, integration_method=2, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7fe742f1b840>, print_timings=False, unpreconditioning_order=6, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7fe742c6fe80>, ctx_mask=<lbuc.context_masks.ContextMask object at 0x7fe742c78a90>
# setting reach level to 0
# ====> reach_tree coordinate ()
# recomputing reachset
# PolyObserver(-x0 + 4, <flowstar.reachability.Reach object at 0x7fe7430834c0>, 0, symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# var_names = [b'local_t', b'x0', b'x1']
# res = b'(([4.0000000000 , 4.0000000000]) + ([-1.0000000000 , -1.0000000000] * x0))'
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# PolyObserver((([4.0000000000 , 4.0000000000]) + ([-1.0000000000 , -1.0000000000] * x0)), <flowstar.reachability.Reach object at 0x7fe7430834c0>, , symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 10.002000000000001], [[0.0000000000000000 .. 10.002000000000001]]))
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# fprime =
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7fe742c7a040>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=None), reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(Lobster > 1.50000000000000)>, precompose_systems=False, step=0.0500000000000000, order=6, estimation=0.000100000000000000, cutoff_threshold=1.00000000000000e-15, integration_method=2, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7fe742f1b840>, print_timings=False, unpreconditioning_order=6, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7fe742c6fe80>, ctx_mask=<lbuc.context_masks.ContextMask object at 0x7fe742c75a60>
# setting reach level to 0
# ====> reach_tree coordinate ()
# recomputing reachset
# PolyObserver(x0 - 1.5000000000000000?, <flowstar.reachability.Reach object at 0x7fe7430834c0>, 0, symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# var_names = [b'local_t', b'x0', b'x1']
# res = b'(([-1.5000000000 , -1.5000000000]) + ([1.0000000000 , 1.0000000000] * x0))'
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# PolyObserver((([-1.5000000000 , -1.5000000000]) + ([1.0000000000 , 1.0000000000] * x0)), <flowstar.reachability.Reach object at 0x7fe7430834c0>, , symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 10.002000000000001], [[0.0000000000000000 .. 10.002000000000001]]))
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# fprime =
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7fe742c7a190>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=None), reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=None), reach_tree = None, ctx_mask=None
# Monitoring initial signal: 1 items in 0.11 seconds
# (ContextSignal([0.0000000000000000 .. 10.002000000000001], [[0 .. 8], [-6.6610000000000012e-17 .. 1.4000000000000002]], [[-1 .. 1], [-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7fe742c7b700>)).to_domain(0)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None, ctx_mask=None

# %%
with suppress_stdout():
    plo2 = csignp.plot_histogram2d(4, flip=True)

plo2
# Out:
# Graphics object consisting of 291 graphics primitives

# %%
with suppress_stdout():
    plo2 = csignp.plot_histogram2d(5, flip=True)

plo2
# Out:
# Graphics object consisting of 1270 graphics primitives

# %%
csignp1 = F(RIF(0, 5), G(RIF(0, 5), P)).context_signal_for_system(s3, 0, use_masks=True, restriction_method=RestrictionMethod.RECOMPUTE_FLOWPIPE, **kwargs)
# Out:
# phi variables sfs = {x1, x0}
# system sfs = System(R, (x0, x1), [[0 .. 8], [-6.6610000000000012e-17 .. 1.4000000000000002]], (-2*x0*x1^2 - 0.05000000000000000?*x0^2 + 1.600000000000000?*x0*x1 - 0.05000000000000000?*x0, 0.3000000000000000?*x0*x1^2 - 0.2400000000000000?*x0*x1 - 0.600000000000000?*x1^2 + 0.600000000000000?*x1), varmap=bidict({'Lobster': x0, 'Whelk': x1})))
# Generating Reach Tree: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(Lobster^2 + (Whelk - 1)^2 < 0.200000000000000)>, precompose_systems=False, step=0.0500000000000000, order=6, estimation=0.000100000000000000, cutoff_threshold=1.00000000000000e-15, integration_method=2, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7fe73df0a580>, print_timings=False, unpreconditioning_order=6, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7fe755698a90>, ctx_mask=<lbuc.context_masks.ContextMask object at 0x7fe742c6f250>
# setting reach level to 0
# ====> reach_tree coordinate ()
# ==> reach_tree call at [[0 .. 8], [-6.6610000000000012e-17 .. 1.4000000000000002]]
# initials = (1.?e1, 0.?e1)
# context loop 0, 0
# ctx
# zero width static set [0.0..0.0]
# poly 1,0 = b'(([1.0000000000 , 1.0000000000] * c0))'
# context loop 1, 0
# ctx
# zero width static set [0.0..0.0]
# poly 2,0 = b'(([1.0000000000 , 1.0000000000] * c1))'
# contexts = ['[0.0..8.0]', '[-6.661000000000001e-17..1.4000000000000001]']
# statics  = []
# recomputing reachset
# PolyObserver(-x0^2 - x1^2 + 2*x1 - 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7fe73e359b80>, 0, symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# var_names = [b'local_t', b'x0', b'x1']
# res = b'(([-0.8000000001 , -0.7999999999]) + ([2.0000000000 , 2.0000000000] * x1) + ([-1.0000000000 , -1.0000000000] * x1^2) + ([-1.0000000000 , -1.0000000000] * x0^2))'
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# PolyObserver((([-0.8000000001 , -0.7999999999]) + ([2.0000000000 , 2.0000000000] * x1) + ([-1.0000000000 , -1.0000000000] * x1^2) + ([-1.0000000000 , -1.0000000000] * x0^2)), <flowstar.reachability.Reach object at 0x7fe73e359b80>, , symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 10.002000000000001], [[0.0000000000000000 .. 10.002000000000001]]))
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# fprime =
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7fe73e2c3eb0>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=Mask([0.0000000000000000 .. 10.002000000000001], [[0.0000000000000000 .. 5.0020000000000007]])), reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=Mask([0.0000000000000000 .. 10.002000000000001], [[0.0000000000000000 .. 0.0020000000000006680]])), reach_tree = None, ctx_mask=None
# Monitoring initial signal: 1 items in 0.11 seconds
# (ContextSignal([0.0000000000000000 .. 10.002000000000001], [[0 .. 8], [-6.6610000000000012e-17 .. 1.4000000000000002]], [[-1 .. 1], [-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7fe74180feb0>)).to_domain(0)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=Mask([0.0000000000000000 .. -0.0000000000000000], [[0.0000000000000000 .. -0.0000000000000000]])), reach_tree = None, ctx_mask=None

# %%
with suppress_stdout():
    plo22 = csignp1.plot_histogram2d(5, flip=True)

plo22
# Out:
# Graphics object consisting of 1262 graphics primitives
