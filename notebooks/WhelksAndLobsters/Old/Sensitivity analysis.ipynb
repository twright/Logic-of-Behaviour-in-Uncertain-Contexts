# %% [markdown]
# # Sensitivity Analysis

# %%
import numpy as np

# %%
from lbuc import vec_to_numpy, mat_to_numpy

# %%
y0 = np.array([4.5, 1.5])

# %%
R.<x,y> = QQ[]
odes = vector([-y, x])

# %%
import sympy
t_ = sympy.var('_')

# %%
list(odes)
# Out:
# [-y, x]

# %%
f = vec_to_numpy(R, odes)
f(0, np.array([1, 2]))
# Out:
# [-2, 1]

# %%
jac = mat_to_numpy(R, jacobian(odes, R.gens()))
jac(0, np.array([1, 2]))
# Out:
# array([[ 0, -1],
#        [ 1,  0]])

# %%
from scipy.integrate import solve_ivp

# %%
sln = solve_ivp(f, (0, 10), y0, method='LSODA', jac=jac, vectorized=True,
                events=[(lambda t, x: x[0])],
                dense_output=True)
sln
# Out:
#   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 128
#      njev: 0
#       nlu: 0
#       sol: <scipy.integrate._ivp.common.OdeSolution object at 0x7fde1ab3d050>
#    status: 0
#   success: True
#         t: array([ 0.        ,  0.01054209,  0.02108418,  0.13608572,  0.25108726,
#         0.3660888 ,  0.64557237,  0.92505595,  1.20453953,  1.37031421,
#         1.5360889 ,  1.70186358,  1.86763826,  1.93769171,  2.00774515,
#         2.0777986 ,  2.3625439 ,  2.64728921,  2.93203452,  3.21677982,
#         3.50152513,  3.78627044,  4.07101575,  4.3014447 ,  4.53187366,
#         4.76230262,  4.99273158,  5.07426596,  5.15580034,  5.23733472,
#         5.52313162,  5.80892851,  6.0947254 ,  6.3805223 ,  6.4573511 ,
#         6.5341799 ,  6.6110087 ,  6.89046806,  7.16992742,  7.44938678,
#         7.72884614,  7.92116269,  8.11347923,  8.30579578,  8.49811233,
#         8.61228097,  8.7264496 ,  8.84061824,  9.11839163,  9.14472335,
#         9.17105508,  9.1973868 ,  9.22371853,  9.27638198,  9.32904543,
#         9.38170888,  9.66259628,  9.94348368, 10.        ])
#  t_events: [array([1.24925727, 4.39117688, 7.53296662])]
#         y: array([[ 4.5       ,  4.48368851,  4.46688059,  4.25469257,  3.98642635,
#          3.66561797,  2.69294984,  1.5115818 ,  0.21220726, -0.57332244,
#         -1.34323225, -2.07636092, -2.75260872, -3.01656989, -3.26574374,
#         -3.49891032, -4.26138979, -4.6804646 , -4.72319278, -4.38532174,
#         -3.69402768, -2.70510555, -1.49764056, -0.42652206,  0.66752389,
#          1.72659331,  2.69468649,  3.00533534,  3.29603415,  3.56485709,
#          4.31216846,  4.70927687,  4.72495161,  4.35703856,  4.19557794,
#          4.00938834,  3.79956762,  2.85754954,  1.6940027 ,  0.39838369,
#         -0.9289955 , -1.80703757, -2.61850392, -3.33353916, -3.92575064,
#         -4.20964324, -4.43883241, -4.61035133, -4.77640313, -4.77291855,
#         -4.76613364, -4.75604421, -4.74265734, -4.70604043, -4.65638069,
#         -4.59381577, -4.05139524, -3.19154038, -2.98550043],
#        [ 1.5       ,  1.54726743,  1.59435767,  2.09584911,  2.56970325,
#          3.00968045,  3.9062381 ,  4.49875089,  4.74286956,  4.71304945,
#          4.55398829,  4.27005227,  3.86902259,  3.66695099,  3.44690315,
#          3.20996076,  2.09766306,  0.81664105, -0.53095253, -1.836701  ,
#         -2.99543606, -3.9136653 , -4.5174401 , -4.74080112, -4.71359065,
#         -4.43719782, -3.92617733, -3.69382579, -3.43693898, -3.15724245,
#         -2.02388979, -0.72661485,  0.63045947,  1.93731235,  2.26586254,
#          2.58104929,  2.88102287,  3.81897032,  4.46021769,  4.75607153,
#          4.68283803,  4.41914575,  3.9925845 ,  3.41873371,  2.71876195,
#          2.25437432,  1.76069749,  1.24415129, -0.06914969, -0.19486013,
#         -0.32045963, -0.44583456, -0.5709004 , -0.81970079, -1.06622913,
#         -1.30980229, -2.53310015, -3.557787  , -3.73240621]])

# %%
from itertools import cycle

# %%
zip(sln.t_events[0], cycle([0]))
# Out:
# [(1.249257269985202, 0), (4.391176875509009, 0), (7.532966619222182, 0)]

# %%
points(zip(sln.t, sln.y[0, :]))\
+ points(zip(sln.t_events[0], cycle([0])),
         color='red', marker='X', size=100)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
plot((lambda t: sln.sol(t)[0]), (0, 10))\
+ points(zip(sln.t_events[0], cycle([0])),
         color='red', marker='X', size=100)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
parametric_plot(((lambda t: sln.sol(t)[0]),
                 (lambda t: sln.sol(t)[1])),
                (0, 10))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
load('lbuc.py')

# %%
Atomic(x - 3).numerical_signal_for_system(odes, y0, 10)
# Out:
# Signal([0.00000000000000000 .. 10.000000000000000], [([0.00000000000000000 .. 0.56458902188736560], True), ([0.56458902188736559 .. 5.0728223633526906], False), ([5.0728223633526905 .. 6.8526089639259010], True), ([6.8526089639259009 .. 10.000000000000000], False)])

# %%
Atomic(x - 3).numerical_signal_for_system(odes, y0, 10).plot()
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
odes
# Out:
# (-y, x)

# %%
list(map(RIF, list(y0)))
# Out:
# [4.5000000000000000?, 1.5000000000000000?]

# %%
inter = RIF(-1e-3,1e-3)
#y01 = [RIF(4.5) + inter, RIF(1.5) + inter]
y01 = [RIF(4.5) + inter, RIF(1.5) + inter]

# %%
P = Atomic(x - 3.0)
reach = Reach(odes, y01, 10, order=10, step=0.1)
print(reach.res)
rs = reach.roots(x - 3.0, -y)
rs
# Out:
# 2
# verified contractive!
# verified contractive!
# verified contractive!
# [0.564?, 5.075?, 6.848?]

# %%
P.dpdt(odes)
# Out:
# -y

# %%
Atomic(x - 3.0).signal_for_system(odes, y01, 10).plot()
# Out:
# Computed 100 flowpipes in 0.223366975784 sec
# Prepared for plotting in 0.176862001419 sec
# verified contractive!
# verified contractive!
# verified contractive!
# roots = [0.564?, 5.075?, 6.848?]
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177e9a40>
#   I  = [0.00000000000000000 .. 0.56393240821000846]
# f(I) = [-0.00015203955216813725 .. 1.5010000000000022]
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177e9a40>
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177e9a40>
#   I  = [0.56472073079642937 .. 5.0749927785478324]
# f(I) = [-7.7675691814720374 .. 0.0078988760109286460]
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177e9a40>
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177e9a40>
#   I  = [5.0757225303095294 .. 6.8471224360005439]
# f(I) = [-0.0027030419825471164 .. 1.7650221611385027]
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177e9a40>
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177e9a40>
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177e9a40>
# Monitored signal 0.273425102234 sec
# Graphics object consisting of 2 graphics primitives

# %%
plot((lambda t: sln.sol(t)[0] - 3), (0, 10))\
 + points([(r.lower(), 0) for r in rs],
          color='red', marker='X', size=100)\
 + points([(r.upper(), 0) for r in rs],
          color='green', marker='X', size=100)#\
# + reach.sage_plot('x')
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
G(RIF(1,1.2), Atomic(x - 3)).signal_for_system(odes, y01, 2*pi).plot()
# Out:
# Computed 75 flowpipes in 0.163213968277 sec
# Prepared for plotting in 0.123379945755 sec
# verified contractive!
# verified contractive!
# verified contractive!
# roots = [0.564?, 5.075?, 6.848?]
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177717a0>
#   I  = [0.00000000000000000 .. 0.56393240821000846]
# f(I) = [-0.00015203955216813725 .. 1.5010000000000022]
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177717a0>
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177717a0>
#   I  = [0.56472073079642937 .. 5.0749927785478324]
# f(I) = [-7.7675691814720374 .. 0.0078988760109286460]
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177717a0>
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177717a0>
#   I  = [5.0757225303095294 .. 6.8471224360005439]
# f(I) = [-0.0027030419825471164 .. 1.7650221611385027]
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177717a0>
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177717a0>
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177717a0>
# Monitored signal 0.225457191467 sec
# Graphics object consisting of 2 graphics primitives

# %%
G(RIF(1,1.2), Atomic(x - 3)).numerical_signal_for_system(odes, y0, 2*pi).plot()
# Out:
# interval_signals.py:123: UserWarning: Inconsitient intervals [4.0728222341462183 .. 5.6526092220169764] (True) and [5.6526092220169754 .. 6.4831853071795873] (False) in signal!
#   u.str(style='brackets'), bu))
# interval_signals.py:123: UserWarning: Inconsitient intervals [4.0728222341462183 .. 5.6526092220169764] (True) and [5.6526092220169754 .. 6.2831853071795872] (False) in signal!
#   u.str(style='brackets'), bu))
# Graphics object consisting of 2 graphics primitives

# %%
Atomic(3 - y).numerical_signal_for_system(odes, y0, 2*pi).plot()
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
Atomic(3 - y).signal_for_system(odes, y01, 2*pi).plot()
# Out:
# Computed 63 flowpipes in 0.140866994858 sec
# Prepared for plotting in 0.103219985962 sec
# verified contractive!
# verified contractive!
# roots = [0.363?, 2.135?]
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177e9b20>
#   I  = [0.00000000000000000 .. 0.36260584287121867]
# f(I) = [-0.0055663014357953955 .. 1.5010000000000008]
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177e9b20>
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177e9b20>
#   I  = [0.36333145431905650 .. 2.1347369731621360]
# f(I) = [-1.7627437368777823 .. 0.0034503077647216607]
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177e9b20>
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177e9b20>
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177e9b20>
# Monitored signal 0.14528298378 sec
# Graphics object consisting of 2 graphics primitives

# %%
F(RIF(3.5,4), Atomic(3 - y)).signal_for_system(odes, y01, 2*pi).plot()
# Out:
# Computed 103 flowpipes in 0.211855888367 sec
# Prepared for plotting in 0.167587041855 sec
# verified contractive!
# verified contractive!
# verified contractive!
# verified contractive!
# roots = [0.363?, 2.135?, 6.646?, 8.418?]
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177e9810>
#   I  = [0.00000000000000000 .. 0.36260584287121867]
# f(I) = [-0.0055663014357953955 .. 1.5010000000000008]
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177e9810>
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177e9810>
#   I  = [0.36333145431905650 .. 2.1347369731621360]
# f(I) = [-1.7627437368777823 .. 0.0034503077647216607]
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177e9810>
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177e9810>
#   I  = [2.1355088193305729 .. 6.6457940876200974]
# f(I) = [-0.0030221070467963962 .. 7.7683288721205699]
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177e9810>
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177e9810>
#   I  = [6.6465138239168446 .. 8.4179271026242191]
# f(I) = [-1.7660184879904320 .. 0.0037477392343006067]
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177e9810>
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177e9810>
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177e9810>
# Monitored signal 0.27574300766 sec
# Graphics object consisting of 2 graphics primitives

# %%
F(RIF(3.5,4), Atomic(3 - y)).numerical_signal_for_system(odes, y0, 2*pi).plot()
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
(G(RIF(1,1.2), Atomic(x - 3)) & F(RIF(3.5,4), Atomic(3 - y))).signal_for_system(odes, y01, 2*pi).plot()
# Out:
# Computed 103 flowpipes in 0.215734004974 sec
# Prepared for plotting in 0.177868843079 sec
# verified contractive!
# verified contractive!
# verified contractive!
# roots = [0.564?, 5.075?, 6.848?]
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177e9810>
#   I  = [0.00000000000000000 .. 0.56393240821000846]
# f(I) = [-0.00015203955216813725 .. 1.5010000000000022]
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177e9810>
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177e9810>
#   I  = [0.56472073079642937 .. 5.0749927785478324]
# f(I) = [-7.7675691814720374 .. 0.0078988760109286460]
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177e9810>
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177e9810>
#   I  = [5.0757225303095294 .. 6.8471224360005439]
# f(I) = [-0.0027030419825471164 .. 1.7650221611385027]
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177e9810>
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177e9810>
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177e9810>
# verified contractive!
# verified contractive!
# verified contractive!
# verified contractive!
# roots = [0.363?, 2.135?, 6.646?, 8.418?]
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177e9810>
#   I  = [0.00000000000000000 .. 0.36260584287121867]
# f(I) = [-0.0055663014357953955 .. 1.5010000000000008]
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177e9810>
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177e9810>
#   I  = [0.36333145431905650 .. 2.1347369731621360]
# f(I) = [-1.7627437368777823 .. 0.0034503077647216607]
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177e9810>
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177e9810>
#   I  = [2.1355088193305729 .. 6.6457940876200974]
# f(I) = [-0.0030221070467963962 .. 7.7683288721205699]
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177e9810>
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177e9810>
#   I  = [6.6465138239168446 .. 8.4179271026242191]
# f(I) = [-1.7660184879904320 .. 0.0037477392343006067]
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177e9810>
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177e9810>
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177e9810>
# Monitored signal 0.5365691185 sec
# Graphics object consisting of 2 graphics primitives

# %%
(G(RIF(1,1.2), Atomic(x - 3)) & F(RIF(3.5,4), Atomic(3 - y))).numerical_signal_for_system(odes, y0, 2*pi).plot()
# Out:
# interval_signals.py:123: UserWarning: Inconsitient intervals [4.0728223722879777 .. 5.6526089460790150] (True) and [5.6526089460790140 .. 9.2831853071795881] (False) in signal!
#   u.str(style='brackets'), bu))
# interval_signals.py:123: UserWarning: Inconsitient intervals [4.4245682451676380 .. 5.6526089460790150] (True) and [5.6526089460790140 .. 9.2831853071795881] (False) in signal!
#   u.str(style='brackets'), bu))
# interval_signals.py:123: UserWarning: Inconsitient intervals [4.4245682451676380 .. 5.6526089460790150] (True) and [5.6526089460790140 .. 6.2831853071795872] (False) in signal!
#   u.str(style='brackets'), bu))
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# ## Real example: Welks and lobsters

# %%
us = [x,y]
k=RIF(0.8); b=RIF(0.6); c=RIF(0.3); e=RIF(0.05); f=RIF(2)
vf = vector([b*x*(RIF(1)-x) - c*x*(k-x)*y,
            -e*y*(RIF(1)+y)+f*x*(k-x)*y])
v0 = [RIF(0.5), RIF(2.0)]
v1 = [RIF(0.4), RIF(2.5)]
v2 = [RIF(1,1.2), RIF(4,6)]

# %%
plot_vector_field((SR^2)(vf)/(SR^2)(vf).norm(),(x,0,1.5),(y,0,8))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
p = streamline_plot(tuple(vf),(x,0,1.5),(y,0,8))\
    + point(v0, size=100, marker='X', color='red')\
    + point(v1, size=100, marker='X', color='green')\
    + polygon([(v2[0].lower(), v2[1].lower()),
               (v2[0].lower(), v2[1].upper()),
               (v2[0].upper(), v2[1].upper()),
               (v2[0].upper(), v2[1].lower())],
              color='orange')
p.set_aspect_ratio(1/6)
p.show()
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
P = Atomic((x - 1)^2 + y^2 - 0.1)

# %%
sln = solve_ivp(vec_to_numpy(R, vf),
                (0, 20), v0,
                method='LSODA', vectorized=True,
                dense_output=True,
                events=(lambda _, (x, y): (x - 1)^2 + y - 0.1))
sln
# Out:
#   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 76
#      njev: 0
#       nlu: 0
#       sol: <scipy.integrate._ivp.common.OdeSolution object at 0x7fde170d7cd0>
#    status: 0
#   success: True
#         t: array([ 0.        ,  0.20008999,  0.40017999,  0.9710477 ,  1.54191541,
#         2.11278312,  3.20489744,  4.29701176,  4.97165901,  5.64630626,
#         6.32095351,  6.99560076,  7.25083687,  7.50607298,  7.76130909,
#         8.05625241,  8.35119574,  8.64613906,  9.19397061,  9.74180216,
#        10.28963371, 10.83746525, 11.3852968 , 11.93312835, 12.4809599 ,
#        13.02879145, 13.57662299, 14.12445454, 14.74703921, 15.36962389,
#        15.99220856, 16.61479323, 17.23737791, 18.02353807, 18.80969823,
#        19.59585839, 20.        ])
#  t_events: [array([10.92388566])]
#         y: array([[0.50000000000000000?, 0.511769892309286, 0.5233346774410491,
#         0.5557746858867384, 0.5876674327854491, 0.6202755023375599,
#         0.6897011122413346, 0.777654502299361, 0.8431459878553224,
#         0.9120795274507394, 0.974530380627377, 1.019812839939381,
#         1.0311589589194503, 1.0395551555173628, 1.0453067982969364,
#         1.0491642968376147, 1.050611222626316, 1.0502444129606012,
#         1.0463074920392417, 1.0405599050045427, 1.0343843437145999,
#         1.0284797559779686, 1.0232309609647594, 1.0187493953839484,
#         1.015015618545246, 1.0119578072389523, 1.00948316815441,
#         1.0074971474362164, 1.005723070209363, 1.004357873297046,
#         1.0033119274571847, 1.0025147259184404, 1.0019076593678913,
#         1.0013439177089074, 1.0009461533050321, 1.0006658534587565,
#         1.0005557301953718],
#        [2, 2.05852610526245, 2.1151634989718806, 2.2659390322126804,
#         2.3905637797598054, 2.479905375393113, 2.5206505268097494,
#         2.32672661981975, 2.066047448387885, 1.7100810033429519,
#         1.3078181524383707, 0.9300308033137159, 0.8068437170482333,
#         0.6966215685986861, 0.5994420937228114, 0.5026962776053951,
#         0.42123145585224336, 0.35319861871517094, 0.25649195390696333,
#         0.18788428330890067, 0.13901062214510823, 0.1038363627437671,
#         0.07821657478211862, 0.059345017672053524, 0.045296170589373054,
#         0.03474177782336322, 0.026751639460665135, 0.02066400631791782,
#         0.01544318473249686, 0.011574310534449066, 0.008696269773099223,
#         0.006541109050405765, 0.004925470060114251, 0.003446402774703173,
#         0.002414170324414286, 0.001692297693057762,
#         0.0014102097515622035]], dtype=object)

# %%
plot(((lambda t: sln.sol(t)[0]),
      (lambda t: sln.sol(t)[1]),
      (lambda t: (sln.sol(t)[0] - 1)^2 + sln.sol(t)[1]^2)),
     (0, 20))
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
W = QQ['x, y']

# %%
nvf = [sum(c.center()*W.gens()[0]^ex*W.gens()[1]^ey
     for c, (ex, ey) in zip(p.coefficients(), p.exponents())) for p in vf]
nvf
# Out:
# [0.300000000000000*x^2*y - 0.600000000000000*x^2 - 0.240000000000000*x*y + 0.600000000000000*x,
#  -2.00000000000000*x^2*y + 1.60000000000000*x*y - 0.0500000000000000*y^2 - 0.0500000000000000*y]

# %%
nv0 = [v.center() for v in v0]
nv0
# Out:
# [0.500000000000000, 2.00000000000000]

# %%
#P.numerical_signal_for_system(nvf, v0, 20).plot()

# %%
P.signal_for_system(vf, v0, 20, order=3, step=0.1).plot()
# Out:
# Computed 200 flowpipes in 0.819276094437 sec
# Prepared for plotting in 0.0542099475861 sec
# verified contractive!
# roots = [8.86?]
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde16ba27a0>
#   I  = [0.00000000000000000 .. 8.8500769978751422]
# f(I) = [-0.85344479842623700 .. 7.4241497834511004]
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde16ba27a0>
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde16ba27a0>
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde16ba27a0>
# Monitored signal 0.0901799201965 sec
# Graphics object consisting of 2 graphics primitives

# %%
G(RIF(0, 5), P).signal_for_system(vf, v0, 20, order=3, step=0.1).plot()
# Out:
# Computed 250 flowpipes in 1.23355484009 sec
# Prepared for plotting in 0.0726959705353 sec
# verified contractive!
# roots = [8.86?]
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde16ba2ea0>
#   I  = [0.00000000000000000 .. 8.8500769978751422]
# f(I) = [-0.85344479842623700 .. 7.4241497834511004]
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde16ba2ea0>
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde16ba2ea0>
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde16ba2ea0>
# Monitored signal 0.107809066772 sec
# Graphics object consisting of 2 graphics primitives

# %%
G(RIF(0, 20), P).signal_for_system(vf, v1, 20, order=10, step=0.1).plot()
# Out:
# Computed 400 flowpipes in 15.3086071014 sec
# Prepared for plotting in 0.467555046082 sec
# roots = []
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde16ba2f10>
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde16ba2f10>
# Monitored signal 0.535532951355 sec
# /usr/lib64/python2.7/site-packages/matplotlib/contour.py:1230: UserWarning: No contour levels were found within the data range.
#   warnings.warn("No contour levels were found"
# Graphics object consisting of 2 graphics primitives

# %%
reach = Reach(vf, v2, 20, order=5, step=0.01)

# %%
reach.prepare()

# %%
index_fn(P.p)(reach(RIF(3,4))).str(style='brackets')
# Out:
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde1768b0a0>
# '[-0.31874472771564611 .. 0.21103535262425855]'

# %%
P.signal_for_system(vf, v2, 20, order=5, step=0.01).plot()
# Out:
# Computed 2000 flowpipes in 48.0965528488 sec
# Prepared for plotting in 80.8671250343 sec
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# roots = [0.84?, 1.?e1, 3.360?]
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde16ba2960>
#   I  = [0.00000000000000000 .. 0.83771736685254350]
# f(I) = [-0.79847490602347282 .. 37.403502507625632]
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde16ba2960>
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde16ba2960>
#   I  = [0.84000000000000052 .. 0.84500855966144484]
# f(I) = [-0.51337593628196788 .. 7.3531054956731872]
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde16ba2960>
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde16ba2960>
#   I  = [3.3399999999999732 .. 3.3599999999999724]
# f(I) = [-0.19991802241966683 .. 0.062389000021475294]
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde16ba2960>
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde16ba2960>
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde16ba2960>
# Monitored signal 10.0214731693 sec
# Graphics object consisting of 2 graphics primitives

# %%
P.signal_for_system(vf, v2, 5, order=(3,20), step=0.01).plot()
# Out:
# Computed 500 flowpipes in 5.47883605957 sec
# Prepared for plotting in 3.06810903549 sec
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# roots = [1.?e1]
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177711f0>
#   I  = [0.00000000000000000 .. 0.78511575105147569]
# f(I) = [-0.76839436035376974 .. 37.452520432148440]
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177711f0>
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde177711f0>
# Monitored signal 3.47738194466 sec
# Graphics object consisting of 2 graphics primitives

# %%
P.signal_for_system(vf, v2, 5, order=5, step=(0.001, 0.05),
                    precondition=1,
                    estimation=1e-3,
                    integrationScheme=2,
                    cutoff_threshold=1e-5).plot()
# Out:
# Computed 147 flowpipes in 4.63982892036 sec
# Prepared for plotting in 7.46357798576 sec
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# roots = [1.?e1]
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde1768b2d0>
#   I  = [0.00000000000000000 .. 0.79104062258369235]
# f(I) = [-0.76352403276807702 .. 37.442306860062651]
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde1768b2d0>
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde1768b2d0>
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde1768b2d0>
# Monitored signal 0.847561120987 sec
# Graphics object consisting of 2 graphics primitives

# %%
reach = Reach(
    vf,
    v2,
    5,
    step=(0.001, 0.05),
    order=5,
    precondition=1,
    estimation=1e-3,
    integrationScheme=2,
    cutoff_threshold=1e-5
)

# %%
reach.num_flowpipes
# Out:
# 147

# %%
rs = reach.roots(P.p, P.dpdt(odes))
rs
# Out:
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# [0.79?, 1.?e1]

# %%
rs[0].str(style='brackets')
# Out:
# '[0.78008130421818255 .. 0.78681602996822231]'

# %%
sig = P.signal_for_system(
    vf,
    v2,
    5,
    step=(0.001, 0.01),
    order=4,
    precondition=1,
    estimation=1e-4,
    integrationScheme=1,
    cutoff_threshold=1e-6
)
# Out:
# Computed 670 flowpipes in 10.4408609867 sec
# Prepared for plotting in 14.9567968845 sec
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# roots = [1.?e1, 3.999?]
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde1768b810>
#   I  = [0.00000000000000000 .. 0.82388926351551762]
# f(I) = [-0.79269539662873534 .. 37.414952107048635]
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde1768b810>
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde1768b810>
#   I  = [3.9705961451099933 .. 3.9983633546183067]
# f(I) = [-0.23865286304908851 .. 0.079103766977033363]
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde1768b810>
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde1768b810>
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde1768b810>
# Monitored signal 1.85409998894 sec

# %%
sig
# Out:
# Signal([0.00000000000000000 .. 5.0000000000000000], [([0.00000000000000000 .. 0.82388926351551762], True), ([3.9705961451099933 .. 3.9983633546183067], False), ([3.9985237845469603 .. 5.0000000000000000], False)])

# %%
sig.plot()
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
K1 = RIF(0.83088524483822367, 0.83403490192890706)
reach(K1)
# Out:
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde1768b2d0>
# [2.?, 1.?e1]

# %%
index_fn(P.p)(reach(K1.center())).str(style='brackets')
# Out:
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde1768b2d0>
# '[-0.59192727705960691 .. 7.7299788185848648]'

# %%
K2 = RIF(0.82384410824369480,0.82707023662316004)
reach(K2)
# Out:
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde1768b2d0>
# [2.?, 1.?e1]

# %%
load('interval_signals.py')

# %%
index_fn(P.p)(reach(K2.center())).str(style='brackets')
# Out:
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde1768b2d0>
# '[-0.54681263853267970 .. 7.7638501845120214]'

# %%
signal_given_roots(lambda t: index_fn(P.p)(reach(t)), rs, RIF(0, 5))
# Out:
# roots = [0.79?, 1.?e1]
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde1768b2d0>
#   I  = [0.00000000000000000 .. 0.78008130421818256]
# f(I) = [-0.75664916624353574 .. 37.442306860062651]
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde1768b2d0>
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde1768b2d0>
#   I  = [0.78681602996822230 .. 0.80147337423282828]
# f(I) = [-0.58494254380095479 .. 8.5908320324052383]
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde1768b2d0>
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde1768b2d0>
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde1768b2d0>
# Signal([0.00000000000000000 .. 5.0000000000000000], [([0.00000000000000000 .. 0.78008130421818256], True), ([0.78681602996822230 .. 0.80147337423282828], False), ([4.3404416667981298 .. 5.0000000000000000], False)])

# %%
P.signal_for_system(vf, v2, 5, order=(3,20), step=0.01,
                    precondition=1,
                    estimation=1e-4,
                    integrationScheme=2,
                    cutoff_threshold=1e-5).plot()
# Out:
# Computed 500 flowpipes in 9.34537386894 sec
# Prepared for plotting in 6.99460697174 sec
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# roots = [0.80?, 1.?e1]
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde1768b180>
#   I  = [0.00000000000000000 .. 0.79889366820677821]
# f(I) = [-0.78023221348840100 .. 37.437303361582501]
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde1768b180>
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde1768b180>
#   I  = [0.80000000000000048 .. 0.80500408368534815]
# f(I) = [-0.53797930784850756 .. 8.3818412402870060]
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde1768b180>
# <flowstar.reachability.FlowstarGlobalManager object at 0x7fde1768b180>
# Monitored signal 4.88450813293 sec
# Graphics object consisting of 2 graphics primitives
