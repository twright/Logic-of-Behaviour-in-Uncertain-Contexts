# %%
# %display latex

# %%
import sys, os, warnings
from contextlib import contextmanager

@contextmanager
def suppress_stdout():
    with open(os.devnull, "w") as devnull:
        old_stdout = sys.stdout
        sys.stdout = devnull
        try:  
            yield
        finally:
            sys.stdout = old_stdout

import matplotlib
import matplotlib.pyplot as plt
            
@contextmanager
def suppress_warnings():
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        yield
        
matplotlib.use("pgf")
matplotlib.rcParams.update({
    "pgf.texsystem": "pdflatex",
    'font.family': 'sans',
    'text.usetex': True,
    'pgf.rcfonts': False,
    "axes.labelsize": 8,
    "font.size": 8,
})
textwidth = 6.26894

# %%
from lbuc import *
from lbuc.bondcalculus import *

# %% [markdown]
# ## Model

# %%
m = BondModel("WhelksAndLobsters.bond")
# Out:
# Running cmd: 'load "WhelksAndLobsters.bond"' ...

# %%
k = 0.8; b = 0.6; c = 0.3; e = 0.05; f = 2

# %%
P = Atomic((var("Whelk") - 1)^2 + var("Lobster")^2 < 0.2)

# %%
Qbox = [RIF(0, 0.31), RIF(1.5, 4)]

# %%
Q = (  Atomic(var("Whelk") < Qbox[0].upper())
     & Atomic(var("Whelk") > Qbox[0].lower())
     & Atomic(var("Lobster") < Qbox[1].upper())
     & Atomic(var("Lobster") > Qbox[1].lower()) )

# %%
s3 = m.process("[0, 1.4] Whelk || [0, 8] Lobster with network N(0.8, 0.6, 0.3, 0.05, 2)").as_system
# Out:
# Running cmd: 'savesage "[0, 1.4] Whelk || [0, 8] Lobster with network N(0.8, 0.6, 0.3, 0.05, 2)" "/tmp/bond-sage-script-kbne_ytw.py"' ...

# %% [markdown]
# ## Parameter set 1

# %% [markdown]
# ### Prop 1

# %%
kwargs = dict(step=0.05, order=6, estimation=1e-4, cutoff_threshold=1e-15, integration_method=2)

# %%
csign1 = F(RIF(0, 10), Q).context_signal_for_system(s3, 0, use_masks=True, **kwargs)
# Out:
# phi variables sfs = {x0, x1}
# system sfs = System(R, (x0, x1), [[0 .. 8], [-6.6610000000000012e-17 .. 1.4000000000000002]], (-2*x0*x1^2 - 0.05000000000000000?*x0^2 + 1.600000000000000?*x0*x1 - 0.05000000000000000?*x0, 0.3000000000000000?*x0*x1^2 - 0.2400000000000000?*x0*x1 - 0.600000000000000?*x1^2 + 0.600000000000000?*x1), varmap=bidict({'Lobster': x0, 'Whelk': x1})))
# Generating Reach Tree: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(), signal = <function base_context_signal.<locals>.<lambda> at 0x7f8e4e738550>, reach_tree = None, ctx_mask=<lbuc.context_masks.ContextMask object at 0x7f8e4e6b9bb0>
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(Whelk < 0.310000000000000)>, precompose_systems=False, step=0.0500000000000000, order=6, estimation=0.000100000000000000, cutoff_threshold=1.00000000000000e-15, integration_method=2, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7f8e4e749200>, print_timings=False, unpreconditioning_order=6, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f8e4e6b97c0>, ctx_mask=<lbuc.context_masks.ContextMask object at 0x7f8e4e6ac220>
# setting reach level to 0
# ====> reach_tree coordinate ()
# ==> reach_tree call at [[0 .. 8], [-6.6610000000000012e-17 .. 1.4000000000000002]]
# initials = (1.?e1, 0.?e1)
# context loop 0, 0
# ctx
# zero width static set [0.0..0.0]
# poly 1,0 = b'(([1.0000000000 , 1.0000000000] * c0))'
# context loop 1, 0
# ctx
# zero width static set [0.0..0.0]
# poly 2,0 = b'(([1.0000000000 , 1.0000000000] * c1))'
# contexts = ['[0.0..8.0]', '[-6.661000000000001e-17..1.4000000000000001]']
# statics  = []
# recomputing reachset
# PolyObserver(-x1 + 0.31000000000000000?, <flowstar.reachability.Reach object at 0x7f8e4e72f3a0>, 0, symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# var_names = [b'local_t', b'x0', b'x1']
# res = b'(([0.3099999999 , 0.3100000000]) + ([-1.0000000000 , -1.0000000000] * x1))'
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# PolyObserver((([0.3099999999 , 0.3100000000]) + ([-1.0000000000 , -1.0000000000] * x1)), <flowstar.reachability.Reach object at 0x7f8e4e72f3a0>, , symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 10.002000000000001], [[0.0000000000000000 .. 10.002000000000001]]))
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# fprime =
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f8e4e9656d0>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=None), reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(Whelk > 0.000000000000000)>, precompose_systems=False, step=0.0500000000000000, order=6, estimation=0.000100000000000000, cutoff_threshold=1.00000000000000e-15, integration_method=2, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7f8e4e749200>, print_timings=False, unpreconditioning_order=6, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f8e4e6b97c0>, ctx_mask=<lbuc.context_masks.ContextMask object at 0x7f8e4e6ac5b0>
# setting reach level to 0
# ====> reach_tree coordinate ()
# recomputing reachset
# PolyObserver(x1, <flowstar.reachability.Reach object at 0x7f8e4e72f3a0>, 0, symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# var_names = [b'local_t', b'x0', b'x1']
# res = b'(([1.0000000000 , 1.0000000000] * x1))'
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# PolyObserver((([1.0000000000 , 1.0000000000] * x1)), <flowstar.reachability.Reach object at 0x7f8e4e72f3a0>, , symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 10.002000000000001], [[0.0000000000000000 .. 10.002000000000001]]))
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# fprime =
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f8e4e965820>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=None), reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(Lobster < 4.00000000000000)>, precompose_systems=False, step=0.0500000000000000, order=6, estimation=0.000100000000000000, cutoff_threshold=1.00000000000000e-15, integration_method=2, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7f8e4e749200>, print_timings=False, unpreconditioning_order=6, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f8e4e6b97c0>, ctx_mask=<lbuc.context_masks.ContextMask object at 0x7f8e4e6bd5e0>
# setting reach level to 0
# ====> reach_tree coordinate ()
# recomputing reachset
# PolyObserver(-x0 + 4, <flowstar.reachability.Reach object at 0x7f8e4e72f3a0>, 0, symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# var_names = [b'local_t', b'x0', b'x1']
# res = b'(([4.0000000000 , 4.0000000000]) + ([-1.0000000000 , -1.0000000000] * x0))'
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# PolyObserver((([4.0000000000 , 4.0000000000]) + ([-1.0000000000 , -1.0000000000] * x0)), <flowstar.reachability.Reach object at 0x7f8e4e72f3a0>, , symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 10.002000000000001], [[0.0000000000000000 .. 10.002000000000001]]))
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# fprime =
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f8e4e965970>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=None), reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(Lobster > 1.50000000000000)>, precompose_systems=False, step=0.0500000000000000, order=6, estimation=0.000100000000000000, cutoff_threshold=1.00000000000000e-15, integration_method=2, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7f8e4e749200>, print_timings=False, unpreconditioning_order=6, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f8e4e6b97c0>, ctx_mask=<lbuc.context_masks.ContextMask object at 0x7f8e4e6bddf0>
# setting reach level to 0
# ====> reach_tree coordinate ()
# recomputing reachset
# PolyObserver(x0 - 1.5000000000000000?, <flowstar.reachability.Reach object at 0x7f8e4e72f3a0>, 0, symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# var_names = [b'local_t', b'x0', b'x1']
# res = b'(([-1.5000000000 , -1.5000000000]) + ([1.0000000000 , 1.0000000000] * x0))'
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# PolyObserver((([-1.5000000000 , -1.5000000000]) + ([1.0000000000 , 1.0000000000] * x0)), <flowstar.reachability.Reach object at 0x7f8e4e72f3a0>, , symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 10.002000000000001], [[0.0000000000000000 .. 10.002000000000001]]))
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# fprime =
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f8e4e965ac0>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=None), reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=None), reach_tree = None, ctx_mask=None
# Monitoring initial signal: 1 items in 0.09 seconds
# (ContextSignal([0.0000000000000000 .. 10.002000000000001], [[0 .. 8], [-6.6610000000000012e-17 .. 1.4000000000000002]], [[-1 .. 1], [-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7f8e4e6b93a0>)).to_domain(0)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None, ctx_mask=None

# %%
with suppress_stdout():
    plo2b = csign1.plot_histogram2d(4, flip=True)

plo2b
# Out:
# Graphics object consisting of 199 graphics primitives

# %%
with suppress_stdout():
    plo2b = csign1.plot_histogram2d(5, flip=True)
    
plo2b
# Out:
# Graphics object consisting of 805 graphics primitives

# %%
with suppress_stdout():
    plo2b1 = csign1.plot_histogram2d(6, flip=True)
    
plo2b1
# Out:
# Graphics object consisting of 2008 graphics primitives

# %% [markdown]
# ### Prop 2

# %%
csign2 = F(RIF(0, 5), G(RIF(0, 5), P)).context_signal_for_system(s3, 0, use_masks=True, **kwargs)
# Out:
# phi variables sfs = {x1, x0}
# system sfs = System(R, (x0, x1), [[0 .. 8], [-6.6610000000000012e-17 .. 1.4000000000000002]], (-2*x0*x1^2 - 0.05000000000000000?*x0^2 + 1.600000000000000?*x0*x1 - 0.05000000000000000?*x0, 0.3000000000000000?*x0*x1^2 - 0.2400000000000000?*x0*x1 - 0.600000000000000?*x1^2 + 0.600000000000000?*x1), varmap=bidict({'Lobster': x0, 'Whelk': x1})))
# Generating Reach Tree: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(Lobster^2 + (Whelk - 1)^2 < 0.200000000000000)>, precompose_systems=False, step=(0.00500000000000000, 0.100000000000000), order=8, estimation=1.00000000000000e-6, cutoff_threshold=1.00000000000000e-7, integration_method=2, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7f5af2017640>, print_timings=False, unpreconditioning_order=8, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f5af22a5040>, ctx_mask=<lbuc.context_masks.ContextMask object at 0x7f5af237e6a0>
# initials = (1.?e1, 0.?e1)
# context loop 0, 0
# ctx
# zero width static set [0.0..0.0]
# poly 1,0 = b'(([1.0000000000 , 1.0000000000] * c0))'
# context loop 1, 0
# ctx
# zero width static set [0.0..0.0]
# poly 2,0 = b'(([1.0000000000 , 1.0000000000] * c1))'
# contexts = ['[0.0..8.0]', '[-6.661000000000001e-17..1.4000000000000001]']
# statics  = []
# recomputing reachset
# PolyObserver(-x0^2 - x1^2 + 2*x1 - 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7f5af2696160>, 0, symbolic_composition=False, symbolic_composition_order=8, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# setting reach level to 0
# var_names = [b'local_t', b'x0', b'x1']
# res = b'(([-0.8000000001 , -0.7999999999]) + ([2.0000000000 , 2.0000000000] * x1) + ([-1.0000000000 , -1.0000000000] * x1^2) + ([-1.0000000000 , -1.0000000000] * x0^2))'
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# PolyObserver((([-0.8000000001 , -0.7999999999]) + ([2.0000000000 , 2.0000000000] * x1) + ([-1.0000000000 , -1.0000000000] * x1^2) + ([-1.0000000000 , -1.0000000000] * x0^2)), <flowstar.reachability.Reach object at 0x7f5af2696160>, , symbolic_composition=False, symbolic_composition_order=8, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 10.002000000000001], [[0.0000000000000000 .. 10.002000000000001]]))
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# fprime =
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f5af2408580>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=Mask([0.0000000000000000 .. 10.002000000000001], [[0.0000000000000000 .. 5.0020000000000007]])), reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=Mask([0.0000000000000000 .. 10.002000000000001], [[0.0000000000000000 .. 0.0020000000000006680]])), reach_tree = None, ctx_mask=None
# Monitoring initial signal: 1 items in 0.17 seconds
# (ContextSignal([0.0000000000000000 .. 10.002000000000001], [[0 .. 8], [-6.6610000000000012e-17 .. 1.4000000000000002]], [[-1 .. 1], [-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7f5af2371f70>)).to_domain(0)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=Mask([0.0000000000000000 .. -0.0000000000000000], [[0.0000000000000000 .. -0.0000000000000000]])), reach_tree = None, ctx_mask=None

# %%
with suppress_stdout():
    plo3 = csign2.plot_histogram2d(4, flip=True)

plo3
# Out:
# Graphics object consisting of 173 graphics primitives

# %%
with suppress_stdout():
    plo31 = csign2.plot_histogram2d(6, flip=True)

plo31

# %% [markdown]
# ## Parameter set 2

# %% [markdown]
# ### Prop 1

# %%
kwargs = dict(step=(0.02,0.1), order=6, estimation=1e-4, cutoff_threshold=1e-5, integration_method=2)

# %%
csign1 = F(RIF(0, 10), Q).context_signal_for_system(s3, 0, use_masks=False, **kwargs)
# Out:
# phi variables sfs = {x1, x0}
# system sfs = System(R, (x0, x1), [[0 .. 8], [-6.6610000000000012e-17 .. 1.4000000000000002]], (-2*x0*x1^2 - 0.05000000000000000?*x0^2 + 1.600000000000000?*x0*x1 - 0.05000000000000000?*x0, 0.3000000000000000?*x0*x1^2 - 0.2400000000000000?*x0*x1 - 0.600000000000000?*x1^2 + 0.600000000000000?*x1), varmap=bidict({'Lobster': x0, 'Whelk': x1})))
# Generating Reach Tree: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(), signal = <function base_context_signal.<locals>.<lambda> at 0x7f5b11d04550>, reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(Whelk < 0.310000000000000)>, precompose_systems=False, step=(0.0200000000000000, 0.100000000000000), order=6, estimation=0.000100000000000000, cutoff_threshold=0.0000100000000000000, integration_method=2, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7f5b11580d80>, print_timings=False, unpreconditioning_order=6, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f5b10e381f0>, ctx_mask=None
# initials = (1.?e1, 0.?e1)
# context loop 0, 0
# ctx
# zero width static set [0.0..0.0]
# poly 1,0 = b'(([1.0000000000 , 1.0000000000] * c0))'
# context loop 1, 0
# ctx
# zero width static set [0.0..0.0]
# poly 2,0 = b'(([1.0000000000 , 1.0000000000] * c1))'
# contexts = ['[0.0..8.0]', '[-6.661000000000001e-17..1.4000000000000001]']
# statics  = []
# recomputing reachset
# PolyObserver(-x1 + 0.31000000000000000?, <flowstar.reachability.Reach object at 0x7f5b11fcea60>, 0, symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# setting reach level to 0
# var_names = [b'local_t', b'x0', b'x1']
# res = b'(([0.3099999999 , 0.3100000000]) + ([-1.0000000000 , -1.0000000000] * x1))'
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# PolyObserver((([0.3099999999 , 0.3100000000]) + ([-1.0000000000 , -1.0000000000] * x1)), <flowstar.reachability.Reach object at 0x7f5b11fcea60>, , symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=None)
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# fprime =
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f5b11e53970>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=None), reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(Whelk > 0.000000000000000)>, precompose_systems=False, step=(0.0200000000000000, 0.100000000000000), order=6, estimation=0.000100000000000000, cutoff_threshold=0.0000100000000000000, integration_method=2, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7f5b11580d80>, print_timings=False, unpreconditioning_order=6, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f5b10e381f0>, ctx_mask=None
# recomputing reachset
# PolyObserver(x1, <flowstar.reachability.Reach object at 0x7f5b11fcea60>, 0, symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# setting reach level to 0
# var_names = [b'local_t', b'x0', b'x1']
# res = b'(([1.0000000000 , 1.0000000000] * x1))'
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# PolyObserver((([1.0000000000 , 1.0000000000] * x1)), <flowstar.reachability.Reach object at 0x7f5b11fcea60>, , symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=None)
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# fprime =
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f5b11e53ac0>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=None), reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(Lobster < 4.00000000000000)>, precompose_systems=False, step=(0.0200000000000000, 0.100000000000000), order=6, estimation=0.000100000000000000, cutoff_threshold=0.0000100000000000000, integration_method=2, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7f5b11580d80>, print_timings=False, unpreconditioning_order=6, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f5b10e381f0>, ctx_mask=None
# recomputing reachset
# PolyObserver(-x0 + 4, <flowstar.reachability.Reach object at 0x7f5b11fcea60>, 0, symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# setting reach level to 0
# var_names = [b'local_t', b'x0', b'x1']
# res = b'(([4.0000000000 , 4.0000000000]) + ([-1.0000000000 , -1.0000000000] * x0))'
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# PolyObserver((([4.0000000000 , 4.0000000000]) + ([-1.0000000000 , -1.0000000000] * x0)), <flowstar.reachability.Reach object at 0x7f5b11fcea60>, , symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=None)
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# fprime =
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f5b11e53c10>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=None), reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(Lobster > 1.50000000000000)>, precompose_systems=False, step=(0.0200000000000000, 0.100000000000000), order=6, estimation=0.000100000000000000, cutoff_threshold=0.0000100000000000000, integration_method=2, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7f5b11580d80>, print_timings=False, unpreconditioning_order=6, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f5b10e381f0>, ctx_mask=None
# recomputing reachset
# PolyObserver(x0 - 1.5000000000000000?, <flowstar.reachability.Reach object at 0x7f5b11fcea60>, 0, symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# setting reach level to 0
# var_names = [b'local_t', b'x0', b'x1']
# res = b'(([-1.5000000000 , -1.5000000000]) + ([1.0000000000 , 1.0000000000] * x0))'
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# PolyObserver((([-1.5000000000 , -1.5000000000]) + ([1.0000000000 , 1.0000000000] * x0)), <flowstar.reachability.Reach object at 0x7f5b11fcea60>, , symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=None)
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# fprime =
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f5b11e53d60>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=None), reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=None), reach_tree = None, ctx_mask=None
# Monitoring initial signal: 1 items in 0.08 seconds
# (ContextSignal([0.0000000000000000 .. 10.002000000000001], [[0 .. 8], [-6.6610000000000012e-17 .. 1.4000000000000002]], [[-1 .. 1], [-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7f5b11cfa310>)).to_domain(0)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None, ctx_mask=None

# %%
with suppress_stdout():
    plo2b = csign1.plot_histogram2d(4, flip=True)

plo2b
# Out:
# Graphics object consisting of 189 graphics primitives

# %%
with suppress_stdout():
    plo2b = csign1.plot_histogram2d(5, flip=True)
    
plo2b
# Out:
# Graphics object consisting of 873 graphics primitives

# %%
with suppress_stdout():
    plo2b2 = csign1.plot_histogram2d(6, flip=True)
    
plo2b2
# Out:
# Graphics object consisting of 2225 graphics primitives

# %% [markdown]
# ### Prop 2

# %%
csign2 = F(RIF(0, 5), G(RIF(0, 5), P)).context_signal_for_system(s3, 0, use_masks=True, **kwargs)

# %%
with suppress_stdout():
    plo3 = csign2.plot_histogram2d(4, flip=True)

plo3
# Out:
# Graphics object consisting of 173 graphics primitives

# %%
with suppress_stdout():
    plo3 = csign2.plot_histogram2d(5, flip=True)

plo3
# Out:
# Graphics object consisting of 766 graphics primitives

# %% [markdown]
# ## Parameter set 3

# %% [markdown]
# ### Prop 1

# %%
kwargs = dict(step=(0.005,0.1), order=8, estimation=1e-6, cutoff_threshold=1e-7, integration_method=2)

# %%
csign1 = F(RIF(0, 10), Q).context_signal_for_system(s3, 0, use_masks=False, **kwargs)
# Out:
# phi variables sfs = {x1, x0}
# system sfs = System(R, (x0, x1), [[0 .. 8], [-6.6610000000000012e-17 .. 1.4000000000000002]], (-2*x0*x1^2 - 0.05000000000000000?*x0^2 + 1.600000000000000?*x0*x1 - 0.05000000000000000?*x0, 0.3000000000000000?*x0*x1^2 - 0.2400000000000000?*x0*x1 - 0.600000000000000?*x1^2 + 0.600000000000000?*x1), varmap=bidict({'Lobster': x0, 'Whelk': x1})))
# Generating Reach Tree: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(), signal = <function base_context_signal.<locals>.<lambda> at 0x7f5b0641bdc0>, reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(Whelk < 0.310000000000000)>, precompose_systems=False, step=(0.00500000000000000, 0.100000000000000), order=8, estimation=1.00000000000000e-6, cutoff_threshold=1.00000000000000e-7, integration_method=2, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7f5b05aef4c0>, print_timings=False, unpreconditioning_order=8, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f5b11e14a00>, ctx_mask=None
# initials = (1.?e1, 0.?e1)
# context loop 0, 0
# ctx
# zero width static set [0.0..0.0]
# poly 1,0 = b'(([1.0000000000 , 1.0000000000] * c0))'
# context loop 1, 0
# ctx
# zero width static set [0.0..0.0]
# poly 2,0 = b'(([1.0000000000 , 1.0000000000] * c1))'
# contexts = ['[0.0..8.0]', '[-6.661000000000001e-17..1.4000000000000001]']
# statics  = []
# recomputing reachset
# PolyObserver(-x1 + 0.31000000000000000?, <flowstar.reachability.Reach object at 0x7f5b06670a60>, 0, symbolic_composition=False, symbolic_composition_order=8, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# setting reach level to 0
# var_names = [b'local_t', b'x0', b'x1']
# res = b'(([0.3099999999 , 0.3100000000]) + ([-1.0000000000 , -1.0000000000] * x1))'
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# PolyObserver((([0.3099999999 , 0.3100000000]) + ([-1.0000000000 , -1.0000000000] * x1)), <flowstar.reachability.Reach object at 0x7f5b06670a60>, , symbolic_composition=False, symbolic_composition_order=8, tentative_unpreconditioning=True, mask=None)
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# fprime =
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f5b06564ac0>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=None), reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(Whelk > 0.000000000000000)>, precompose_systems=False, step=(0.00500000000000000, 0.100000000000000), order=8, estimation=1.00000000000000e-6, cutoff_threshold=1.00000000000000e-7, integration_method=2, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7f5b05aef4c0>, print_timings=False, unpreconditioning_order=8, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f5b11e14a00>, ctx_mask=None
# recomputing reachset
# PolyObserver(x1, <flowstar.reachability.Reach object at 0x7f5b06670a60>, 0, symbolic_composition=False, symbolic_composition_order=8, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# setting reach level to 0
# var_names = [b'local_t', b'x0', b'x1']
# res = b'(([1.0000000000 , 1.0000000000] * x1))'
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# PolyObserver((([1.0000000000 , 1.0000000000] * x1)), <flowstar.reachability.Reach object at 0x7f5b06670a60>, , symbolic_composition=False, symbolic_composition_order=8, tentative_unpreconditioning=True, mask=None)
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# fprime =
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f5b06564c10>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=None), reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(Lobster < 4.00000000000000)>, precompose_systems=False, step=(0.00500000000000000, 0.100000000000000), order=8, estimation=1.00000000000000e-6, cutoff_threshold=1.00000000000000e-7, integration_method=2, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7f5b05aef4c0>, print_timings=False, unpreconditioning_order=8, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f5b11e14a00>, ctx_mask=None
# recomputing reachset
# PolyObserver(-x0 + 4, <flowstar.reachability.Reach object at 0x7f5b06670a60>, 0, symbolic_composition=False, symbolic_composition_order=8, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# setting reach level to 0
# var_names = [b'local_t', b'x0', b'x1']
# res = b'(([4.0000000000 , 4.0000000000]) + ([-1.0000000000 , -1.0000000000] * x0))'
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# PolyObserver((([4.0000000000 , 4.0000000000]) + ([-1.0000000000 , -1.0000000000] * x0)), <flowstar.reachability.Reach object at 0x7f5b06670a60>, , symbolic_composition=False, symbolic_composition_order=8, tentative_unpreconditioning=True, mask=None)
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# fprime =
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f5b06564d60>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=None), reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(Lobster > 1.50000000000000)>, precompose_systems=False, step=(0.00500000000000000, 0.100000000000000), order=8, estimation=1.00000000000000e-6, cutoff_threshold=1.00000000000000e-7, integration_method=2, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7f5b05aef4c0>, print_timings=False, unpreconditioning_order=8, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f5b11e14a00>, ctx_mask=None
# recomputing reachset
# PolyObserver(x0 - 1.5000000000000000?, <flowstar.reachability.Reach object at 0x7f5b06670a60>, 0, symbolic_composition=False, symbolic_composition_order=8, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# setting reach level to 0
# var_names = [b'local_t', b'x0', b'x1']
# res = b'(([-1.5000000000 , -1.5000000000]) + ([1.0000000000 , 1.0000000000] * x0))'
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# PolyObserver((([-1.5000000000 , -1.5000000000]) + ([1.0000000000 , 1.0000000000] * x0)), <flowstar.reachability.Reach object at 0x7f5b06670a60>, , symbolic_composition=False, symbolic_composition_order=8, tentative_unpreconditioning=True, mask=None)
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# fprime =
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f5b06564eb0>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=None), reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=None), reach_tree = None, ctx_mask=None
# Monitoring initial signal: 1 items in 0.16 seconds
# (ContextSignal([0.0000000000000000 .. 10.002000000000001], [[0 .. 8], [-6.6610000000000012e-17 .. 1.4000000000000002]], [[-1 .. 1], [-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7f5b064ff520>)).to_domain(0)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None, ctx_mask=None

# %%
with suppress_stdout():
    plo2b = csign1.plot_histogram2d(4, flip=True)

plo2b
# Out:
# Graphics object consisting of 261 graphics primitives

# %%
with suppress_stdout():
    plo2b = csign1.plot_histogram2d(5, flip=True)
    
plo2b
# Out:
# Graphics object consisting of 596 graphics primitives

# %%
with suppress_stdout():
    plo2b3 = csign1.plot_histogram2d(6,flip=True)
    
plo2b3
# Out:
# Graphics object consisting of 1309 graphics primitives

# %% [markdown]
# ### Prop 2

# %%
csign2 = F(RIF(0, 5), G(RIF(0, 5), P)).context_signal_for_system(s3, 0, use_masks=True, **kwargs)
# Out:
# phi variables sfs = {x0, x1}
# system sfs = System(R, (x0, x1), [[0 .. 8], [-6.6610000000000012e-17 .. 1.4000000000000002]], (-2*x0*x1^2 - 0.05000000000000000?*x0^2 + 1.600000000000000?*x0*x1 - 0.05000000000000000?*x0, 0.3000000000000000?*x0*x1^2 - 0.2400000000000000?*x0*x1 - 0.600000000000000?*x1^2 + 0.600000000000000?*x1), varmap=bidict({'Lobster': x0, 'Whelk': x1})))
# Generating Reach Tree: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(Lobster^2 + (Whelk - 1)^2 < 0.200000000000000)>, precompose_systems=False, step=0.0500000000000000, order=6, estimation=0.000100000000000000, cutoff_threshold=1.00000000000000e-15, integration_method=2, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7f927b1e5200>, print_timings=False, unpreconditioning_order=6, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f928c018f10>, ctx_mask=<lbuc.context_masks.ContextMask object at 0x7f927b6cc100>
# initials = (1.?e1, 0.?e1)
# context loop 0, 0
# ctx
# zero width static set [0.0..0.0]
# poly 1,0 = b'(([1.0000000000 , 1.0000000000] * c0))'
# context loop 1, 0
# ctx
# zero width static set [0.0..0.0]
# poly 2,0 = b'(([1.0000000000 , 1.0000000000] * c1))'
# contexts = ['[0.0..8.0]', '[-6.661000000000001e-17..1.4000000000000001]']
# statics  = []
# recomputing reachset
# PolyObserver(-x0^2 - x1^2 + 2*x1 - 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7f927b8faee0>, 0, symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# setting reach level to 0
# var_names = [b'local_t', b'x0', b'x1']
# res = b'(([-0.8000000001 , -0.7999999999]) + ([2.0000000000 , 2.0000000000] * x1) + ([-1.0000000000 , -1.0000000000] * x1^2) + ([-1.0000000000 , -1.0000000000] * x0^2))'
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# PolyObserver((([-0.8000000001 , -0.7999999999]) + ([2.0000000000 , 2.0000000000] * x1) + ([-1.0000000000 , -1.0000000000] * x1^2) + ([-1.0000000000 , -1.0000000000] * x0^2)), <flowstar.reachability.Reach object at 0x7f927b8faee0>, , symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 10.002000000000001], [[0.0000000000000000 .. 10.002000000000001]]))
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# fprime =
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f9284fba2e0>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=Mask([0.0000000000000000 .. 10.002000000000001], [[0.0000000000000000 .. 5.0020000000000007]])), reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=Mask([0.0000000000000000 .. 10.002000000000001], [[0.0000000000000000 .. 0.0020000000000006680]])), reach_tree = None, ctx_mask=None
# Monitoring initial signal: 1 items in 0.05 seconds
# (ContextSignal([0.0000000000000000 .. 10.002000000000001], [[0 .. 8], [-6.6610000000000012e-17 .. 1.4000000000000002]], [[-1 .. 1], [-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7f928da0cfa0>)).to_domain(0)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=Mask([0.0000000000000000 .. -0.0000000000000000], [[0.0000000000000000 .. -0.0000000000000000]])), reach_tree = None, ctx_mask=None

# %%
with suppress_stdout():
    plo3 = csign2.plot_histogram2d(4, flip=True)

plo3
# Out:
# Graphics object consisting of 173 graphics primitives

# %%
with suppress_stdout():
    plo3 = csign2.plot_histogram2d(5, flip=True)

plo3
# Out:
# Graphics object consisting of 766 graphics primitives

# %% [markdown]
# ## Parameter set 4

# %% [markdown]
# ### Prop 1

# %%
kwargs = dict(step=(0.005,0.1), order=8, estimation=1e-6, cutoff_threshold=1e-7, integration_method=2)

# %%
csign1 = F(RIF(0, 10), Q).context_signal_for_system(s3, 0, use_masks=False, **kwargs)
# Out:
# phi variables sfs = {x1, x0}
# system sfs = System(R, (x0, x1), [[0 .. 8], [-6.6610000000000012e-17 .. 1.4000000000000002]], (-2*x0*x1^2 - 0.05000000000000000?*x0^2 + 1.600000000000000?*x0*x1 - 0.05000000000000000?*x0, 0.3000000000000000?*x0*x1^2 - 0.2400000000000000?*x0*x1 - 0.600000000000000?*x1^2 + 0.600000000000000?*x1), varmap=bidict({'Lobster': x0, 'Whelk': x1})))
# Generating Reach Tree: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(), signal = <function base_context_signal.<locals>.<lambda> at 0x7f5b0635f700>, reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(Whelk < 0.310000000000000)>, precompose_systems=False, step=(0.00500000000000000, 0.100000000000000), order=8, estimation=1.00000000000000e-6, cutoff_threshold=1.00000000000000e-7, integration_method=2, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7f5afb0e7d00>, print_timings=False, unpreconditioning_order=8, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f5afc4f3430>, ctx_mask=None
# initials = (1.?e1, 0.?e1)
# context loop 0, 0
# ctx
# zero width static set [0.0..0.0]
# poly 1,0 = b'(([1.0000000000 , 1.0000000000] * c0))'
# context loop 1, 0
# ctx
# zero width static set [0.0..0.0]
# poly 2,0 = b'(([1.0000000000 , 1.0000000000] * c1))'
# contexts = ['[0.0..8.0]', '[-6.661000000000001e-17..1.4000000000000001]']
# statics  = []
# recomputing reachset
# PolyObserver(-x1 + 0.31000000000000000?, <flowstar.reachability.Reach object at 0x7f5afc2d4dc0>, 0, symbolic_composition=False, symbolic_composition_order=8, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# setting reach level to 0
# var_names = [b'local_t', b'x0', b'x1']
# res = b'(([0.3099999999 , 0.3100000000]) + ([-1.0000000000 , -1.0000000000] * x1))'
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# PolyObserver((([0.3099999999 , 0.3100000000]) + ([-1.0000000000 , -1.0000000000] * x1)), <flowstar.reachability.Reach object at 0x7f5afc2d4dc0>, , symbolic_composition=False, symbolic_composition_order=8, tentative_unpreconditioning=True, mask=None)
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# fprime =
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f5afb5e5430>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=None), reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(Whelk > 0.000000000000000)>, precompose_systems=False, step=(0.00500000000000000, 0.100000000000000), order=8, estimation=1.00000000000000e-6, cutoff_threshold=1.00000000000000e-7, integration_method=2, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7f5afb0e7d00>, print_timings=False, unpreconditioning_order=8, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f5afc4f3430>, ctx_mask=None
# recomputing reachset
# PolyObserver(x1, <flowstar.reachability.Reach object at 0x7f5afc2d4dc0>, 0, symbolic_composition=False, symbolic_composition_order=8, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# setting reach level to 0
# var_names = [b'local_t', b'x0', b'x1']
# res = b'(([1.0000000000 , 1.0000000000] * x1))'
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# PolyObserver((([1.0000000000 , 1.0000000000] * x1)), <flowstar.reachability.Reach object at 0x7f5afc2d4dc0>, , symbolic_composition=False, symbolic_composition_order=8, tentative_unpreconditioning=True, mask=None)
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# fprime =
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f5afb5e52e0>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=None), reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(Lobster < 4.00000000000000)>, precompose_systems=False, step=(0.00500000000000000, 0.100000000000000), order=8, estimation=1.00000000000000e-6, cutoff_threshold=1.00000000000000e-7, integration_method=2, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7f5afb0e7d00>, print_timings=False, unpreconditioning_order=8, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f5afc4f3430>, ctx_mask=None
# recomputing reachset
# PolyObserver(-x0 + 4, <flowstar.reachability.Reach object at 0x7f5afc2d4dc0>, 0, symbolic_composition=False, symbolic_composition_order=8, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# setting reach level to 0
# var_names = [b'local_t', b'x0', b'x1']
# res = b'(([4.0000000000 , 4.0000000000]) + ([-1.0000000000 , -1.0000000000] * x0))'
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# PolyObserver((([4.0000000000 , 4.0000000000]) + ([-1.0000000000 , -1.0000000000] * x0)), <flowstar.reachability.Reach object at 0x7f5afc2d4dc0>, , symbolic_composition=False, symbolic_composition_order=8, tentative_unpreconditioning=True, mask=None)
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# fprime =
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f5afb5e5190>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=None), reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(Lobster > 1.50000000000000)>, precompose_systems=False, step=(0.00500000000000000, 0.100000000000000), order=8, estimation=1.00000000000000e-6, cutoff_threshold=1.00000000000000e-7, integration_method=2, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7f5afb0e7d00>, print_timings=False, unpreconditioning_order=8, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f5afc4f3430>, ctx_mask=None
# recomputing reachset
# PolyObserver(x0 - 1.5000000000000000?, <flowstar.reachability.Reach object at 0x7f5afc2d4dc0>, 0, symbolic_composition=False, symbolic_composition_order=8, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# setting reach level to 0
# var_names = [b'local_t', b'x0', b'x1']
# res = b'(([-1.5000000000 , -1.5000000000]) + ([1.0000000000 , 1.0000000000] * x0))'
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# PolyObserver((([-1.5000000000 , -1.5000000000]) + ([1.0000000000 , 1.0000000000] * x0)), <flowstar.reachability.Reach object at 0x7f5afc2d4dc0>, , symbolic_composition=False, symbolic_composition_order=8, tentative_unpreconditioning=True, mask=None)
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# fprime =
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f5afb5e5040>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=None), reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=None), reach_tree = None, ctx_mask=None
# Monitoring initial signal: 1 items in 0.19 seconds
# (ContextSignal([0.0000000000000000 .. 10.002000000000001], [[0 .. 8], [-6.6610000000000012e-17 .. 1.4000000000000002]], [[-1 .. 1], [-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7f5afc54f040>)).to_domain(0)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None, ctx_mask=None

# %%
with suppress_stdout():
    plo2b = csign1.plot_histogram2d(4, flip=True)

plo2b
# Out:
# Graphics object consisting of 261 graphics primitives

# %%
with suppress_stdout():
    plo2b = csign1.plot_histogram2d(5, flip=True)
    
plo2b
# Out:
# Graphics object consisting of 596 graphics primitives

# %%
with suppress_stdout():
    plo2b4 = csign1.plot_histogram2d(6,flip=True)
    
plo2b4
# Out:
# Graphics object consisting of 1309 graphics primitives

# %% [markdown]
# ### Prop 2

# %%
csign2 = F(RIF(0, 5), G(RIF(0, 5), P)).context_signal_for_system(s3, 0, use_masks=True, **kwargs)
# Out:
# phi variables sfs = {x0, x1}
# system sfs = System(R, (x0, x1), [[0 .. 8], [-6.6610000000000012e-17 .. 1.4000000000000002]], (-2*x0*x1^2 - 0.05000000000000000?*x0^2 + 1.600000000000000?*x0*x1 - 0.05000000000000000?*x0, 0.3000000000000000?*x0*x1^2 - 0.2400000000000000?*x0*x1 - 0.600000000000000?*x1^2 + 0.600000000000000?*x1), varmap=bidict({'Lobster': x0, 'Whelk': x1})))
# Generating Reach Tree: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(Lobster^2 + (Whelk - 1)^2 < 0.200000000000000)>, precompose_systems=False, step=0.0500000000000000, order=6, estimation=0.000100000000000000, cutoff_threshold=1.00000000000000e-15, integration_method=2, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7f927b1e5200>, print_timings=False, unpreconditioning_order=6, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f928c018f10>, ctx_mask=<lbuc.context_masks.ContextMask object at 0x7f927b6cc100>
# initials = (1.?e1, 0.?e1)
# context loop 0, 0
# ctx
# zero width static set [0.0..0.0]
# poly 1,0 = b'(([1.0000000000 , 1.0000000000] * c0))'
# context loop 1, 0
# ctx
# zero width static set [0.0..0.0]
# poly 2,0 = b'(([1.0000000000 , 1.0000000000] * c1))'
# contexts = ['[0.0..8.0]', '[-6.661000000000001e-17..1.4000000000000001]']
# statics  = []
# recomputing reachset
# PolyObserver(-x0^2 - x1^2 + 2*x1 - 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7f927b8faee0>, 0, symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# setting reach level to 0
# var_names = [b'local_t', b'x0', b'x1']
# res = b'(([-0.8000000001 , -0.7999999999]) + ([2.0000000000 , 2.0000000000] * x1) + ([-1.0000000000 , -1.0000000000] * x1^2) + ([-1.0000000000 , -1.0000000000] * x0^2))'
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# PolyObserver((([-0.8000000001 , -0.7999999999]) + ([2.0000000000 , 2.0000000000] * x1) + ([-1.0000000000 , -1.0000000000] * x1^2) + ([-1.0000000000 , -1.0000000000] * x0^2)), <flowstar.reachability.Reach object at 0x7f927b8faee0>, , symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 10.002000000000001], [[0.0000000000000000 .. 10.002000000000001]]))
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# fprime =
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f9284fba2e0>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=Mask([0.0000000000000000 .. 10.002000000000001], [[0.0000000000000000 .. 5.0020000000000007]])), reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=Mask([0.0000000000000000 .. 10.002000000000001], [[0.0000000000000000 .. 0.0020000000000006680]])), reach_tree = None, ctx_mask=None
# Monitoring initial signal: 1 items in 0.05 seconds
# (ContextSignal([0.0000000000000000 .. 10.002000000000001], [[0 .. 8], [-6.6610000000000012e-17 .. 1.4000000000000002]], [[-1 .. 1], [-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7f928da0cfa0>)).to_domain(0)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=Mask([0.0000000000000000 .. -0.0000000000000000], [[0.0000000000000000 .. -0.0000000000000000]])), reach_tree = None, ctx_mask=None

# %%
with suppress_stdout():
    plo3 = csign2.plot_histogram2d(4, flip=True)

plo3
# Out:
# Graphics object consisting of 173 graphics primitives

# %%
with suppress_stdout():
    plo3 = csign2.plot_histogram2d(5, flip=True)

plo3
# Out:
# Graphics object consisting of 766 graphics primitives

# %% [markdown]
# ## Physical Tree

# %%
kwargs = dict(step=0.05, order=6, estimation=1e-4, cutoff_threshold=1e-15, integration_method=2)

# %%
from lbuc import RestrictionMethod

# %%
csignp = F(RIF(0, 10), Q).context_signal_for_system(s3, 0, use_masks=True, restriction_method=RestrictionMethod.RECOMPUTE_FLOWPIPE, **kwargs)
# Out:
# phi variables sfs = {x1, x0}
# system sfs = System(R, (x0, x1), [[0 .. 8], [-6.6610000000000012e-17 .. 1.4000000000000002]], (-2*x0*x1^2 - 0.05000000000000000?*x0^2 + 1.600000000000000?*x0*x1 - 0.05000000000000000?*x0, 0.3000000000000000?*x0*x1^2 - 0.2400000000000000?*x0*x1 - 0.600000000000000?*x1^2 + 0.600000000000000?*x1), varmap=bidict({'Lobster': x0, 'Whelk': x1})))
# Generating Reach Tree: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(), signal = <function base_context_signal.<locals>.<lambda> at 0x7f1015dc28b0>, reach_tree = None, ctx_mask=<lbuc.context_masks.ContextMask object at 0x7f10226c2850>
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(Whelk < 0.310000000000000)>, precompose_systems=False, step=0.0500000000000000, order=6, estimation=0.000100000000000000, cutoff_threshold=1.00000000000000e-15, integration_method=2, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7f10226d1400>, print_timings=False, unpreconditioning_order=6, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f1015dc8490>, ctx_mask=<lbuc.context_masks.ContextMask object at 0x7f1015dd0400>
# initials = (1.?e1, 0.?e1)
# context loop 0, 0
# ctx
# zero width static set [0.0..0.0]
# poly 1,0 = b'(([1.0000000000 , 1.0000000000] * c0))'
# context loop 1, 0
# ctx
# zero width static set [0.0..0.0]
# poly 2,0 = b'(([1.0000000000 , 1.0000000000] * c1))'
# contexts = ['[0.0..8.0]', '[-6.661000000000001e-17..1.4000000000000001]']
# statics  = []
# recomputing reachset
# PolyObserver(-x1 + 0.31000000000000000?, <flowstar.reachability.Reach object at 0x7f10164fd4c0>, 0, symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# setting reach level to 0
# var_names = [b'local_t', b'x0', b'x1']
# res = b'(([0.3099999999 , 0.3100000000]) + ([-1.0000000000 , -1.0000000000] * x1))'
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# PolyObserver((([0.3099999999 , 0.3100000000]) + ([-1.0000000000 , -1.0000000000] * x1)), <flowstar.reachability.Reach object at 0x7f10164fd4c0>, , symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 10.002000000000001], [[0.0000000000000000 .. 10.002000000000001]]))
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# fprime =
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f1015dd5190>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=None), reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(Whelk > 0.000000000000000)>, precompose_systems=False, step=0.0500000000000000, order=6, estimation=0.000100000000000000, cutoff_threshold=1.00000000000000e-15, integration_method=2, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7f10226d1400>, print_timings=False, unpreconditioning_order=6, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f1015dc8490>, ctx_mask=<lbuc.context_masks.ContextMask object at 0x7f1015dd0a30>
# recomputing reachset
# PolyObserver(x1, <flowstar.reachability.Reach object at 0x7f10164fd4c0>, 0, symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# setting reach level to 0
# var_names = [b'local_t', b'x0', b'x1']
# res = b'(([1.0000000000 , 1.0000000000] * x1))'
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# PolyObserver((([1.0000000000 , 1.0000000000] * x1)), <flowstar.reachability.Reach object at 0x7f10164fd4c0>, , symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 10.002000000000001], [[0.0000000000000000 .. 10.002000000000001]]))
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# fprime =
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f1015dd52e0>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=None), reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(Lobster < 4.00000000000000)>, precompose_systems=False, step=0.0500000000000000, order=6, estimation=0.000100000000000000, cutoff_threshold=1.00000000000000e-15, integration_method=2, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7f10226d1400>, print_timings=False, unpreconditioning_order=6, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f1015dc8490>, ctx_mask=<lbuc.context_masks.ContextMask object at 0x7f1015dd37f0>
# recomputing reachset
# PolyObserver(-x0 + 4, <flowstar.reachability.Reach object at 0x7f10164fd4c0>, 0, symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# setting reach level to 0
# var_names = [b'local_t', b'x0', b'x1']
# res = b'(([4.0000000000 , 4.0000000000]) + ([-1.0000000000 , -1.0000000000] * x0))'
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# PolyObserver((([4.0000000000 , 4.0000000000]) + ([-1.0000000000 , -1.0000000000] * x0)), <flowstar.reachability.Reach object at 0x7f10164fd4c0>, , symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 10.002000000000001], [[0.0000000000000000 .. 10.002000000000001]]))
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# fprime =
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f1015dd5430>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=None), reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(Lobster > 1.50000000000000)>, precompose_systems=False, step=0.0500000000000000, order=6, estimation=0.000100000000000000, cutoff_threshold=1.00000000000000e-15, integration_method=2, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7f10226d1400>, print_timings=False, unpreconditioning_order=6, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f1015dc8490>, ctx_mask=<lbuc.context_masks.ContextMask object at 0x7f1015dd3f40>
# recomputing reachset
# PolyObserver(x0 - 1.5000000000000000?, <flowstar.reachability.Reach object at 0x7f10164fd4c0>, 0, symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# setting reach level to 0
# var_names = [b'local_t', b'x0', b'x1']
# res = b'(([-1.5000000000 , -1.5000000000]) + ([1.0000000000 , 1.0000000000] * x0))'
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# PolyObserver((([-1.5000000000 , -1.5000000000]) + ([1.0000000000 , 1.0000000000] * x0)), <flowstar.reachability.Reach object at 0x7f10164fd4c0>, , symbolic_composition=False, symbolic_composition_order=6, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 10.002000000000001], [[0.0000000000000000 .. 10.002000000000001]]))
# var_names = [b'local_t', b'x0', b'x1']
# res = b''
# fprime =
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f1015dd5580>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=None), reach_tree = None, ctx_mask=None
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.002000000000001], [], mask=None), reach_tree = None, ctx_mask=None
# Monitoring initial signal: 1 items in 0.08 seconds
# (ContextSignal([0.0000000000000000 .. 10.002000000000001], [[0 .. 8], [-6.6610000000000012e-17 .. 1.4000000000000002]], [[-1 .. 1], [-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7f102271eca0>)).to_domain(0)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None, ctx_mask=None

# %%
with suppress_stdout():
    plo2 = csignp.plot_histogram2d(4, flip=True)

plo2
# Out:
# Graphics object consisting of 173 graphics primitives

# %%
with suppress_stdout():
    plo2 = csignp.plot_histogram2d(5, flip=True)

plo2
# Out:
# Graphics object consisting of 1 graphics primitive
