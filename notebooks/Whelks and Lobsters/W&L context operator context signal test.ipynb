# %%
# %matplotlib inline

# %%
import sys

sys.path.insert(0, "/home/twright/Documents/PhD/Notebooks")

from contextlib import contextmanager
import sys, os

@contextmanager
def suppress_stdout():
    with open(os.devnull, "w") as devnull:
        old_stdout = sys.stdout
        sys.stdout = devnull
        try:  
            yield
        finally:
            sys.stdout = old_stdout
            
            
import warnings
            
@contextmanager
def suppress_warnings():
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        yield

# %%
from sage.all import *

# %%
from flowstar.reachability import Reach
from flowstar.poly import Poly
from lbuc import *

# %%
R, (x,y) = PolynomialRing(RIF, "x, y").objgens()

# %%
us = [x,y]
k=RIF(0.8); b=RIF(0.6); c=RIF(0.3); e=RIF(0.05); f=RIF(2)
vf = vector([b*x*(RIF(1)-x) - c*x*(k-x)*y,
            -e*y*(RIF(1)+y)+f*x*(k-x)*y])

# %%
odes_whelks = list(vf)

# %%
v2 = initials = [RIF(1, 1.2), RIF(4, 6)]

# %%
p = streamline_plot(tuple(vf),(x,0,1.5),(y,0,8), color='grey')\
    + polygon([(v2[0].lower(), v2[1].lower()),
               (v2[0].lower(), v2[1].upper()),
               (v2[0].upper(), v2[1].upper()),
               (v2[0].upper(), v2[1].lower())],
              color='orange')\
    + region_plot((lambda x, y: (x - 1)**2 + y**2 - 0.2 < 0),
                  (x, 0, 1.5),
                  (y, 0, 8),
                  incol='pink', plot_points=500, bordercol='red')
p.set_aspect_ratio(1/6)
p.show()
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
P = Atomic((x - 1)**2 + y**2 - 0.2)

# %%
kwargs = dict(
    order=5, step=(0.01, 0.5),
    precondition=1,
    estimation=1e-3,
    integration_method=IntegrationMethod.LOW_DEGREE,
    cutoff_threshold=1e-5,
    verbosity=0,
    epsilon_ctx=0.1,
    symbolic_composition=True,
)

# %%
from lbuc import InitialForm

# %%
sig = ({x: RIF(0.05, 0.1)} >> G(RIF(0, 0.2), P)
       ).signal_for_system(odes_whelks, initials, 10, **kwargs)
# Out:
# phi variables sfs = {y, x}
# system sfs = System(R, (x, y), [[1.0000000000000000 .. 1.2000000000000000], [4 .. 6]], (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y), varmap=bidict({'x': x, 'y': y}))
# Computed 143 flowpipes in 0.7341463250340894 sec
# mask = None
# phi variables sfs = {y, x}
# system sfs = System(R, (x, y), [[0.99863734049121122 .. 1.5959882046269048], [-0.18566626515230495 .. 6.0001133420806650]], (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y), varmap=bidict({'x': x, 'y': y}))
# Flowstar failed!
# I  = [0.0000000000000000 .. 10.002000000000001]
# fI = ['[0.99863734049121122 .. 1.5959882046269048]', '[-0.18566626515230495 .. 6.0001133420806650]']
# C || f(I) = ['[0.99863734049121122 .. 1.5959882046269048]', '[-0.18566626515230495 .. 6.0001133420806650]']
#      odes = (1.1?, 5.?)
# D || odes = (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y)
# phi(D || odes, C || f(I)) = None
# bisecting [0.0000000000000000 .. 10.002000000000001] -> [0.0000000000000000 .. 5.0010000000000004], [5.0010000000000003 .. 10.002000000000001]
# phi variables sfs = {y, x}
# system sfs = System(R, (x, y), [[0.99998486618648119 .. 1.5959882046269048], [-0.18566626515230495 .. 6.0001133420806650]], (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y), varmap=bidict({'x': x, 'y': y}))
# Flowstar failed!
# I  = [0.0000000000000000 .. 5.0010000000000004]
# fI = ['[0.99998486618648119 .. 1.5959882046269048]', '[-0.18566626515230495 .. 6.0001133420806650]']
# C || f(I) = ['[0.99998486618648119 .. 1.5959882046269048]', '[-0.18566626515230495 .. 6.0001133420806650]']
#      odes = (1.1?, 5.?)
# D || odes = (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y)
# phi(D || odes, C || f(I)) = None
# bisecting [0.0000000000000000 .. 5.0010000000000004] -> [0.0000000000000000 .. 2.5005000000000002], [2.5005000000000001 .. 5.0010000000000004]
# phi variables sfs = {y, x}
# system sfs = System(R, (x, y), [[0.99998486618648119 .. 1.5959882046269048], [-0.18566626515230495 .. 6.0001133420806650]], (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y), varmap=bidict({'x': x, 'y': y}))
# Flowstar failed!
# I  = [0.0000000000000000 .. 2.5005000000000002]
# fI = ['[0.99998486618648119 .. 1.5959882046269048]', '[-0.18566626515230495 .. 6.0001133420806650]']
# C || f(I) = ['[0.99998486618648119 .. 1.5959882046269048]', '[-0.18566626515230495 .. 6.0001133420806650]']
#      odes = (1.1?, 5.?)
# D || odes = (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y)
# phi(D || odes, C || f(I)) = None
# bisecting [0.0000000000000000 .. 2.5005000000000002] -> [0.0000000000000000 .. 1.2502500000000001], [1.2502500000000000 .. 2.5005000000000002]
# phi variables sfs = {y, x}
# system sfs = System(R, (x, y), [[0.99998486618648119 .. 1.5959882046269048], [0.061157558039720075 .. 6.0001133420806650]], (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y), varmap=bidict({'x': x, 'y': y}))
# Flowstar failed!
# I  = [0.0000000000000000 .. 1.2502500000000001]
# fI = ['[0.99998486618648119 .. 1.5959882046269048]', '[0.061157558039720075 .. 6.0001133420806650]']
# C || f(I) = ['[0.99998486618648119 .. 1.5959882046269048]', '[0.061157558039720075 .. 6.0001133420806650]']
#      odes = (1.1?, 5.?)
# D || odes = (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y)
# phi(D || odes, C || f(I)) = None
# bisecting [0.0000000000000000 .. 1.2502500000000001] -> [0.0000000000000000 .. 0.62512500000000005], [0.62512500000000004 .. 1.2502500000000001]
# phi variables sfs = {y, x}
# system sfs = System(R, (x, y), [[0.99998486618648119 .. 1.5719639955222958], [1.1328194291313433 .. 6.0001133420806650]], (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y), varmap=bidict({'x': x, 'y': y}))
# Flowstar failed!
# I  = [0.0000000000000000 .. 0.62512500000000005]
# fI = ['[0.99998486618648119 .. 1.5719639955222958]', '[1.1328194291313433 .. 6.0001133420806650]']
# C || f(I) = ['[0.99998486618648119 .. 1.5719639955222958]', '[1.1328194291313433 .. 6.0001133420806650]']
#      odes = (1.1?, 5.?)
# D || odes = (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y)
# phi(D || odes, C || f(I)) = None
# bisecting [0.0000000000000000 .. 0.62512500000000005] -> [0.0000000000000000 .. 0.31256250000000003], [0.31256250000000002 .. 0.62512500000000005]
# phi variables sfs = {y, x}
# system sfs = System(R, (x, y), [[0.99998486618648119 .. 1.4231287678389127], [2.3542991988952897 .. 6.0001133420806650]], (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y), varmap=bidict({'x': x, 'y': y}))
# Flowstar failed!
# I  = [0.0000000000000000 .. 0.31256250000000003]
# fI = ['[0.99998486618648119 .. 1.4231287678389127]', '[2.3542991988952897 .. 6.0001133420806650]']
# C || f(I) = ['[0.99998486618648119 .. 1.4231287678389127]', '[2.3542991988952897 .. 6.0001133420806650]']
#      odes = (1.1?, 5.?)
# D || odes = (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y)
# phi(D || odes, C || f(I)) = None
# bisecting [0.0000000000000000 .. 0.31256250000000003] -> [0.0000000000000000 .. 0.15628125000000002], [0.15628125000000001 .. 0.31256250000000003]
# phi variables sfs = {y, x}
# system sfs = System(R, (x, y), [[0.99998486618648119 .. 1.3147891504460838], [3.1054426286052523 .. 6.0001133420806650]], (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y), varmap=bidict({'x': x, 'y': y}))
# Flowstar failed!
# I  = [0.0000000000000000 .. 0.15628125000000002]
# fI = ['[0.99998486618648119 .. 1.3147891504460838]', '[3.1054426286052523 .. 6.0001133420806650]']
# C || f(I) = ['[0.99998486618648119 .. 1.3147891504460838]', '[3.1054426286052523 .. 6.0001133420806650]']
#      odes = (1.1?, 5.?)
# D || odes = (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y)
# phi(D || odes, C || f(I)) = None
# bisecting [0.0000000000000000 .. 0.15628125000000002] -> [0.0000000000000000 .. 0.078140625000000006], [0.078140625000000005 .. 0.15628125000000002]
# phi variables sfs = {y, x}
# system sfs = System(R, (x, y), [[0.99998486618648119 .. 1.2571717200961304], [3.5484300813614431 .. 6.0001133420806650]], (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y), varmap=bidict({'x': x, 'y': y}))
# Computed 14 flowpipes in 0.08646789297927171 sec
# In G.signal
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7f5dae89b280>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = []
# domain = [0.0000000000000000 .. 0.20600000000000002]
# roots = []
# seg_domain = [0.0000000000000000 .. 0.20600000000000002]
# roots = []
# signal given bool roots: 1 items in 0.00 seconds
# I  = [0.0000000000000000 .. 0.078140625000000006]
# fI = ['[0.99998486618648119 .. 1.2571717200961304]', '[3.5484300813614431 .. 6.0001133420806650]']
# C || f(I) = ['[0.99998486618648119 .. 1.2571717200961304]', '[3.5484300813614431 .. 6.0001133420806650]']
#      odes = (1.1?, 5.?)
# D || odes = (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y)
# phi(D || odes, C || f(I)) = True
# phi variables sfs = {y, x}
# system sfs = System(R, (x, y), [[1.0103347280509704 .. 1.3147891504460838], [3.1054426286052523 .. 5.7010432514185139]], (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y), varmap=bidict({'x': x, 'y': y}))
# Flowstar failed!
# I  = [0.078140625000000005 .. 0.15628125000000002]
# fI = ['[1.0103347280509704 .. 1.3147891504460838]', '[3.1054426286052523 .. 5.7010432514185139]']
# C || f(I) = ['[1.0103347280509704 .. 1.3147891504460838]', '[3.1054426286052523 .. 5.7010432514185139]']
#      odes = (1.1?, 5.?)
# D || odes = (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y)
# phi(D || odes, C || f(I)) = None
# phi variables sfs = {y, x}
# system sfs = System(R, (x, y), [[1.0203307199787692 .. 1.4231287678389127], [2.3542991988952897 .. 5.3961085286365301]], (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y), varmap=bidict({'x': x, 'y': y}))
# Flowstar failed!
# I  = [0.15628125000000001 .. 0.31256250000000003]
# fI = ['[1.0203307199787692 .. 1.4231287678389127]', '[2.3542991988952897 .. 5.3961085286365301]']
# C || f(I) = ['[1.0203307199787692 .. 1.4231287678389127]', '[2.3542991988952897 .. 5.3961085286365301]']
#      odes = (1.1?, 5.?)
# D || odes = (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y)
# phi(D || odes, C || f(I)) = None
# bisecting [0.15628125000000001 .. 0.31256250000000003] -> [0.15628125000000001 .. 0.23442187500000001], [0.23442187500000000 .. 0.31256250000000003]
# phi variables sfs = {y, x}
# system sfs = System(R, (x, y), [[1.0203307199787692 .. 1.3705708503372114], [2.7031335755309608 .. 5.3961085286365301]], (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y), varmap=bidict({'x': x, 'y': y}))
# Flowstar failed!
# I  = [0.15628125000000001 .. 0.23442187500000001]
# fI = ['[1.0203307199787692 .. 1.3705708503372114]', '[2.7031335755309608 .. 5.3961085286365301]']
# C || f(I) = ['[1.0203307199787692 .. 1.3705708503372114]', '[2.7031335755309608 .. 5.3961085286365301]']
#      odes = (1.1?, 5.?)
# D || odes = (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y)
# phi(D || odes, C || f(I)) = None
# phi variables sfs = {y, x}
# system sfs = System(R, (x, y), [[1.0308361916637505 .. 1.4231287678389127], [2.3542991988952897 .. 5.0592364092274301]], (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y), varmap=bidict({'x': x, 'y': y}))
# Flowstar failed!
# I  = [0.23442187500000000 .. 0.31256250000000003]
# fI = ['[1.0308361916637505 .. 1.4231287678389127]', '[2.3542991988952897 .. 5.0592364092274301]']
# C || f(I) = ['[1.0308361916637505 .. 1.4231287678389127]', '[2.3542991988952897 .. 5.0592364092274301]']
#      odes = (1.1?, 5.?)
# D || odes = (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y)
# phi(D || odes, C || f(I)) = None
# phi variables sfs = {y, x}
# system sfs = System(R, (x, y), [[1.0414094763215728 .. 1.5719639955222958], [1.1328194291313433 .. 4.6659584623313056]], (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y), varmap=bidict({'x': x, 'y': y}))
# Flowstar failed!
# I  = [0.31256250000000002 .. 0.62512500000000005]
# fI = ['[1.0414094763215728 .. 1.5719639955222958]', '[1.1328194291313433 .. 4.6659584623313056]']
# C || f(I) = ['[1.0414094763215728 .. 1.5719639955222958]', '[1.1328194291313433 .. 4.6659584623313056]']
#      odes = (1.1?, 5.?)
# D || odes = (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y)
# phi(D || odes, C || f(I)) = None
# bisecting [0.31256250000000002 .. 0.62512500000000005] -> [0.31256250000000002 .. 0.46884375000000001], [0.46884375000000000 .. 0.62512500000000005]
# phi variables sfs = {y, x}
# system sfs = System(R, (x, y), [[1.0414094763215728 .. 1.5136230924869741], [1.6761763005998993 .. 4.6659584623313056]], (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y), varmap=bidict({'x': x, 'y': y}))
# Flowstar failed!
# I  = [0.31256250000000002 .. 0.46884375000000001]
# fI = ['[1.0414094763215728 .. 1.5136230924869741]', '[1.6761763005998993 .. 4.6659584623313056]']
# C || f(I) = ['[1.0414094763215728 .. 1.5136230924869741]', '[1.6761763005998993 .. 4.6659584623313056]']
#      odes = (1.1?, 5.?)
# D || odes = (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y)
# phi(D || odes, C || f(I)) = None
# bisecting [0.31256250000000002 .. 0.46884375000000001] -> [0.31256250000000002 .. 0.39070312500000004], [0.39070312500000003 .. 0.46884375000000001]
# phi variables sfs = {y, x}
# system sfs = System(R, (x, y), [[1.0414094763215728 .. 1.4716588479728663], [2.0006930158043645 .. 4.6659584623313056]], (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y), varmap=bidict({'x': x, 'y': y}))
# Flowstar failed!
# I  = [0.31256250000000002 .. 0.39070312500000004]
# fI = ['[1.0414094763215728 .. 1.4716588479728663]', '[2.0006930158043645 .. 4.6659584623313056]']
# C || f(I) = ['[1.0414094763215728 .. 1.4716588479728663]', '[2.0006930158043645 .. 4.6659584623313056]']
#      odes = (1.1?, 5.?)
# D || odes = (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y)
# phi(D || odes, C || f(I)) = None
# phi variables sfs = {y, x}
# system sfs = System(R, (x, y), [[1.
>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.02 seconds
# roots = [[0.0000000000000000 .. 0.20599999999900002]]
# domain = [0.0000000000000000 .. 0.20600000000000002]
# roots = [[0.0000000000000000 .. 0.20599999999900002]]
# seg_domain = [0.0000000000000000 .. 0.20600000000000002]
# roots = [[0.0000000000000000 .. 0.20599999999900002]]
# signal given bool roots: 1 items in 0.00 seconds
# I  = [2.8130625000000000 .. 2.9693437500000002]
# fI = ['[1.0715086027688491 .. 1.2252468345347248]', '[-0.13637097608058663 .. 0.38670415592968472]']
# C || f(I) = ['[1.0715086027688491 .. 1.2252468345347248]', '[-0.13637097608058663 .. 0.38670415592968472]']
#      odes = (1.1?, 5.?)
# D || odes = (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y)
# phi(D || odes, C || f(I)) = None
# bisecting [2.8130625000000000 .. 2.9693437500000002] -> [2.8130625000000000 .. 2.8912031250000001], [2.8912031250000000 .. 2.9693437500000002]
# phi variables sfs = {y, x}
# system sfs = System(R, (x, y), [[1.0766325189740959 .. 1.2252468345347248], [-0.13637097608058663 .. 0.38670415592968472]], (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y), varmap=bidict({'x': x, 'y': y}))
# Computed 3 flowpipes in 0.026033787988126278 sec
# In G.signal
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7f5d99346b80>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.02 seconds
# roots = [[0.0000000000000000 .. 0.20599999999900002]]
# domain = [0.0000000000000000 .. 0.20600000000000002]
# roots = [[0.0000000000000000 .. 0.20599999999900002]]
# seg_domain = [0.0000000000000000 .. 0.20600000000000002]
# roots = [[0.0000000000000000 .. 0.20599999999900002]]
# signal given bool roots: 1 items in 0.00 seconds
# I  = [2.8130625000000000 .. 2.8912031250000001]
# fI = ['[1.0766325189740959 .. 1.2252468345347248]', '[-0.13637097608058663 .. 0.38670415592968472]']
# C || f(I) = ['[1.0766325189740959 .. 1.2252468345347248]', '[-0.13637097608058663 .. 0.38670415592968472]']
#      odes = (1.1?, 5.?)
# D || odes = (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y)
# phi(D || odes, C || f(I)) = None
# phi variables sfs = {y, x}
# system sfs = System(R, (x, y), [[1.0715086027688491 .. 1.2171953496778470], [-0.13473782679571276 .. 0.37013417041604902]], (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y), varmap=bidict({'x': x, 'y': y}))
# Computed 3 flowpipes in 0.027428035042248666 sec
# In G.signal
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7f5d99346700>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.02 seconds
# roots = [[0.0000000000000000 .. 0.13125000000000001], [0.17269267743378624 .. 0.20599999999900002]]
# domain = [0.0000000000000000 .. 0.20600000000000002]
# roots = [[0.0000000000000000 .. 0.13125000000000001],
#  [0.17269267743378624 .. 0.20599999999900002]]
# seg_domain = [0.0000000000000000 .. 0.20600000000000002]
# roots = [[0.0000000000000000 .. 0.13125000000000001],
#  [0.17269267743378624 .. 0.20599999999900002]]
# signal given bool roots: 1 items in 0.00 seconds
# I  = [2.8912031250000000 .. 2.9693437500000002]
# fI = ['[1.0715086027688491 .. 1.2171953496778470]', '[-0.13473782679571276 .. 0.37013417041604902]']
# C || f(I) = ['[1.0715086027688491 .. 1.2171953496778470]', '[-0.13473782679571276 .. 0.37013417041604902]']
#      odes = (1.1?, 5.?)
# D || odes = (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y)
# phi(D || odes, C || f(I)) = False
# phi variables sfs = {y, x}
# system sfs = System(R, (x, y), [[1.0631308717990188 .. 1.2090464685128777], [-0.13270031949485029 .. 0.35303472693459609]], (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y), varmap=bidict({'x': x, 'y': y}))
# Computed 3 flowpipes in 0.02684178506024182 sec
# In G.signal
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7f5d993465e0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.02 seconds
# roots = [[0.0000000000000000 .. 0.13125000000000001]]
# domain = [0.0000000000000000 .. 0.20600000000000002]
# roots = [[0.0000000000000000 .. 0.13125000000000001]]
# seg_domain = [0.0000000000000000 .. 0.20600000000000002]
# roots = [[0.0000000000000000 .. 0.13125000000000001]]
# signal given bool roots: 1 items in 0.00 seconds
# I  = [2.9693437500000001 .. 3.1256250000000004]
# fI = ['[1.0631308717990188 .. 1.2090464685128777]', '[-0.13270031949485029 .. 0.35303472693459609]']
# C || f(I) = ['[1.0631308717990188 .. 1.2090464685128777]', '[-0.13270031949485029 .. 0.35303472693459609]']
#      odes = (1.1?, 5.?)
# D || odes = (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y)
# phi(D || odes, C || f(I)) = False
# phi variables sfs = {y, x}
# system sfs = System(R, (x, y), [[1.0353138912913404 .. 1.1926895011892529], [-0.12755722284379559 .. 0.31777092840130189]], (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y), varmap=bidict({'x': x, 'y': y}))
# Computed 3 flowpipes in 0.025623608962632716 sec
# In G.signal
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7f5dae89bee0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.01 seconds
# roots = []
# domain = [0.0000000000000000 .. 0.20600000000000002]
# roots = []
# seg_domain = [0.0000000000000000 .. 0.20600000000000002]
# roots = []
# signal given bool roots: 1 items in 0.00 seconds
# I  = [3.1256250000000003 .. 3.7507500000000001]
# fI = ['[1.0353138912913404 .. 1.1926895011892529]', '[-0.12755722284379559 .. 0.31777092840130189]']
# C || f(I) = ['[1.0353138912913404 .. 1.1926895011892529]', '[-0.12755722284379559 .. 0.31777092840130189]']
#      odes = (1.1?, 5.?)
# D || odes = (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y)
# phi(D || odes, C || f(I)) = False
# phi variables sfs = {y, x}
# system sfs = System(R, (x, y), [[1.0107493386729400 .. 1.1416913735520867], [-0.10742451333011963 .. 0.22692493651710613]], (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y), varmap=bidict({'x': x, 'y': y}))
# Computed 3 flowpipes in 0.023122373037040234 sec
# In G.signal
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7f5dae89bca0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.01 seconds
# roots = []
# domain = [0.0000000000000000 .. 0.20600000000000002]
# roots = []
# seg_domain = [0.0000000000000000 .. 0.20600000000000002]
# roots = []
# signal given bool roots: 1 items in 0.00 seconds
# I  = [3.7507500000000000 .. 5.0010000000000004]
# fI = ['[1.0107493386729400 .. 1.1416913735520867]', '[-0.10742451333011963 .. 0.22692493651710613]']
# C || f(I) = ['[1.0107493386729400 .. 1.1416913735520867]', '[-0.10742451333011963 .. 0.22692493651710613]']
#      odes = (1.1?, 5.?)
# D || odes = (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y)
# phi(D || odes, C || f(I)) = False
# phi variables sfs = {y, x}
# system sfs = System(R, (x, y), [[0.99863734049121122 .. 1.0726859832830782], [-0.060068629854421553 .. 0.11313085016410141]], (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y), varmap=bidict({'x': x, 'y': y}))
# Computed 2 flowpipes in 0.016612582025118172 sec
# In G.signal
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7f5dae89ba60>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = []
# domain = [0.0000000000000000 .. 0.20600000000000002]
# roots = []
# seg_domain = [0.0000000000000000 .. 0.20600000000000002]
# roots = []
# signal given bool roots: 1 items in 0.00 seconds
# I  = [5.0010000000000003 .. 10.002000000000001]
# fI = ['[0.99863734049121122 .. 1.0726859832830782]', '[-0.060068629854421553 .. 0.11313085016410141]']
# C || f(I) = ['[0.99863734049121122 .. 1.0726859832830782]', '[-0.060068629854421553 .. 0.11313085016410141]']
#      odes = (1.1?, 5.?)
# D || odes = (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y)
# phi(D || odes, C || f(I)) = False

# %%
ctx_sig = ({x: RIF(0.05, 0.1)} >> G(RIF(0, 0.2), P)
           ).context_signal_for_system(odes_whelks, initials, 10,
                                       initial_form=InitialForm.COMBINED,
                                       **kwargs)
# Out:
# phi variables sfs = {x, y}
# system sfs = System(R, (x, y), [[1.0000000000000000 .. 1.2000000000000000], [4 .. 6]], (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y), varmap=bidict({'x': x, 'y': y}))
# Generating Reach Tree: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(), signal = <function C.context_signal.<locals>.signal_fn at 0x7fe62eca2430>, reach_tree = <lbuc.reach_trees.ReachTree object at 0x7fe62ec980a0>
# recomputing reachset
# setting reach level to 0
# mask = None
# phi variables sfs = {x, y}
# system sfs = System(R, (x, y), [[0.99863734049121122 .. 1.5959882046269048], [-0.18566626515230495 .. 6.0001133420806650]], (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y), varmap=bidict({'x': x, 'y': y}))
# Generating Reach Tree: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2*x + 0.8000000000000000?)>, precompose_systems=False, initial_form=<InitialForm.COMBINED: 1>, order=5, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.00100000000000000, integration_method=<IntegrationMethod.LOW_DEGREE: 2>, cutoff_threshold=0.0000100000000000000, verbosity=0, epsilon_ctx=0.100000000000000, symbolic_composition=True, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7fe63eee7040>, print_timings=False, unpreconditioning_order=5), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7fe62ec98040>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7fe6245ab3a0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7fe637f24820>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.20600000000000002], [], mask=None), reach_tree = None
# Monitoring initial signal: 1 items in 0.03 seconds
# (ContextSignal([0.0000000000000000 .. 0.20600000000000002], [[0.050000000000000002 .. 0.10000000000000001], None], [[-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7fe635b48340>)).to_domain(0.01?)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.0040000000000000001], [], mask=None), reach_tree = None
# (ContextSignal([0.0000000000000000 .. 0.0040000000000000001], [[0.050000000000000002 .. 0.10000000000000001], None], [[-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7fe62ec98160>)).to_domain(0.01?)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.0020000000000000001], [], mask=None), reach_tree = None
# I  = [0.0000000000000000 .. 10.001999999999999]
# fI = ['[0.99863734049121122 .. 1.5959882046269048]', '[-0.18566626515230495 .. 6.0001133420806650]']
# C || f(I) = ['[0.99863734049121122 .. 1.5959882046269048]', '[-0.18566626515230495 .. 6.0001133420806650]']
#      odes = (1.1?, 5.?)
# D || odes = (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y)
# phi(D || odes, C || f(I)) = None
# bisecting [0.0000000000000000 .. 10.001999999999999] -> [0.0000000000000000 .. 5.0009999999999995], [5.0009999999999994 .. 10.001999999999999]
# phi variables sfs = {x, y}
# system sfs = System(R, (x, y), [[0.99998486618648119 .. 1.5959882046269048], [-0.18566626515230495 .. 6.0001133420806650]], (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y), varmap=bidict({'x': x, 'y': y}))
# Generating Reach Tree: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2*x + 0.8000000000000000?)>, precompose_systems=False, initial_form=<InitialForm.COMBINED: 1>, order=5, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.00100000000000000, integration_method=<IntegrationMethod.LOW_DEGREE: 2>, cutoff_threshold=0.0000100000000000000, verbosity=0, epsilon_ctx=0.100000000000000, symbolic_composition=True, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7fe63eee7040>, print_timings=False, unpreconditioning_order=5), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7fe62ec826d0>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7fe635b31ca0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7fe637f24d60>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.20600000000000002], [], mask=None), reach_tree = None
# Monitoring initial signal: 1 items in 0.03 seconds
# (ContextSignal([0.0000000000000000 .. 0.20600000000000002], [[0.050000000000000002 .. 0.10000000000000001], None], [[-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7fe62ecb6f40>)).to_domain(0.01?)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.0040000000000000001], [], mask=None), reach_tree = None
# (ContextSignal([0.0000000000000000 .. 0.0040000000000000001], [[0.050000000000000002 .. 0.10000000000000001], None], [[-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7fe635bc3700>)).to_domain(0.01?)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.0020000000000000001], [], mask=None), reach_tree = None
# I  = [0.0000000000000000 .. 5.0009999999999995]
# fI = ['[0.99998486618648119 .. 1.5959882046269048]', '[-0.18566626515230495 .. 6.0001133420806650]']
# C || f(I) = ['[0.99998486618648119 .. 1.5959882046269048]', '[-0.18566626515230495 .. 6.0001133420806650]']
#      odes = (1.1?, 5.?)
# D || odes = (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y)
# phi(D || odes, C || f(I)) = None
# bisecting [0.0000000000000000 .. 5.0009999999999995] -> [0.0000000000000000 .. 2.5004999999999998], [2.5004999999999997 .. 5.0009999999999995]
# phi variables sfs = {x, y}
# system sfs = System(R, (x, y), [[0.99998486618648119 .. 1.5959882046269048], [-0.18566626515230495 .. 6.0001133420806650]], (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y), varmap=bidict({'x': x, 'y': y}))
# Generating Reach Tree: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2*x + 0.8000000000000000?)>, precompose_systems=False, initial_form=<InitialForm.COMBINED: 1>, order=5, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.00100000000000000, integration_method=<IntegrationMethod.LOW_DEGREE: 2>, cutoff_threshold=0.0000100000000000000, verbosity=0, epsilon_ctx=0.100000000000000, symbolic_composition=True, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7fe63eee7040>, print_timings=False, unpreconditioning_order=5), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7fe635bc7b80>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7fe635b31b80>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7fe637f24eb0>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.20600000000000002], [], mask=None), reach_tree = None
# Monitoring initial signal: 1 items in 0.03 seconds
# (ContextSignal([0.0000000000000000 .. 0.20600000000000002], [[0.050000000000000002 .. 0.10000000000000001], None], [[-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7fe62eca1f10>)).to_domain(0.01?)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.0040000000000000001], [], mask=None), reach_tree = None
# (ContextSignal([0.0000000000000000 .. 0.0040000000000000001], [[0.050000000000000002 .. 0.10000000000000001], None], [[-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7fe62eca1ca0>)).to_domain(0.01?)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.0020000000000000001], [], mask=None), reach_tree = None
# I  = [0.0000000000000000 .. 2.5004999999999998]
# fI = ['[0.99998486618648119 .. 1.5959882046269048]', '[-0.18566626515230495 .. 6.0001133420806650]']
# C || f(I) = ['[0.99998486618648119 .. 1.5959882046269048]', '[-0.18566626515230495 .. 6.0001133420806650]']
#      odes = (1.1?, 5.?)
# D || odes = (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y)
# phi(D || odes, C || f(I)) = None
# bisecting [0.0000000000000000 .. 2.5004999999999998] -> [0.0000000000000000 .. 1.2502499999999999], [1.2502499999999998 .. 2.5004999999999998]
# phi variables sfs = {x, y}
# system sfs = System(R, (x, y), [[0.99998486618648119 .. 1.5959882046269048], [0.061157558039720075 .. 6.0001133420806650]], (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y), varmap=bidict({'x': x, 'y': y}))
# Generating Reach Tree: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2*x + 0.8000000000000000?)>, precompose_systems=False, initial_form=<InitialForm.COMBINED: 1>, order=5, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.00100000000000000, integration_method=<IntegrationMethod.LOW_DEGREE: 2>, cutoff_threshold=0.0000100000000000000, verbosity=0, epsilon_ctx=0.100000000000000, symbolic_composition=True, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7fe63eee7040>, print_timings=False, unpreconditioning_order=5), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7fe635b48f40>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7fe635b31a60>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7fe6245b4040>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.20600000000000002], [], mask=None), reach_tree = None
# Monitoring initial signal: 1 items in 0.03 seconds
# (ContextSignal([0.0000000000000000 .. 0.20600000000000002], [[0.050000000000000002 .. 0.10000000000000001], None], [[-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7fe62eca1b20>)).to_domain(0.01?)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.0040000000000000001], [], mask=None), reach_tree = None
# (ContextSignal([0.0000000000000000 .. 0.0040000000000000001], [[0.050000000000000002 .. 0.10000000000000001], None], [[-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7fe6245b5070>)).to_domain(0.01?)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.0020000000000000001], [], mask=None), reach_tree = None
# I  = [0.0000000000000000 .. 1.2502499999999999]
# fI = ['[0.99998486618648119 .. 1.5959882046269048]', '[0.061157558039720075 .. 6.0001133420806650]']
# C || f(I) = ['[0.99998486618648119 .. 1.5959882046269048]', '[0.061157558039720075 .. 6.0001133420806650]']
#      odes = (1.1?, 5.?)
# D || odes = (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y)
# phi(D || odes, C || f(I)) = None
# bisecting [0.0000000000000000 .. 1.2502499999999999] -> [0.0000000000000000 .. 0.62512499999999994], [0.62512499999999993 .. 1.2502499999999999]
# phi variables sfs = {x, y}
# system sfs = System(R, (x, y), [[0.99998486618648119 .. 1.5719639955222958], [1.1328194291313433 .. 6.0001133420806650]], (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y), varmap=bidict({'x': x, 'y': y}))
# Generating Reach Tree: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2*x + 0.8000000000000000?)>, precompose_systems=False, initial_form=<InitialForm.COMBINED: 1>, order=5, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.00100000000000000, integration_method=<IntegrationMethod.LOW_DEGREE: 2>, cutoff_threshold=0.0000100000000000000, verbosity=0, epsilon_ctx=0.100000000000000, symbolic_composition=True, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7fe63eee7040>, print_timings=False, unpreconditioning_order=5), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7fe62eca16a0>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7fe635b31a60>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7fe637f24eb0>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.20600000000000002], [], mask=None), reach_tree = None
# Monitoring initial signal: 1 items in 0.04 seconds
# (ContextSignal([0.0000000000000000 .. 0.20600000000000002], [[0.050000000000000002 .. 0.10000000000000001], None], [[-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7fe635bc7400>)).to_domain(0.01?)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.0040000000000000001], [], mask=None), reach_tree = None
# (ContextSignal([0.0000000000000000 .. 0.0040000000000000001], [[0.050000000000000002 .. 0.10000000000000001], None], [[-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7fe635bc74c0>)).to_domain(0.01?)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.0020000000000000001], [], mask=None), reach_tree = None
# I  = [0.0000000000000000 .. 0.62512499999999994]
# fI = ['[0.99998486618648119 .. 1.5719639955222958]', '[1.1328194291313433 .. 6.0001133420806650]']
# C || f(I) = ['[0.99998486618648119 .. 1.5719639955222958]', '[1.1328194291313433 .. 6.0001133420806650]']
#      odes = (1.1?, 5.?)
# D || odes = (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y)
# phi(D || odes, C || f(I)) = None
# bisecting [0.0000000000000000 .. 0.62512499999999994] -> [0.0000000000000000 .. 0.31256249999999997], [0.31256249999999996 .. 0.62512499999999994]
# phi variables sfs = {x, y}
# system sfs = System(R, (x, y), [[0.99998486618648119 .. 1.4231287678389127], [2.3542991988952897 .. 6.0001133420806650]], (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y), varmap=bidict({'x': x, 'y': y}))
# Generating Reach Tree: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2*x + 0.8000000000000000?)>, precompose_systems=False, initial_form=<InitialForm.COMBINED: 1>, order=5, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.00100000000000000, integration_method=<IntegrationMethod.LOW_DEGREE: 2>, cutoff_threshold=0.0000100000000000000, verbosity=0, epsilon_ctx=0.100000000000000, symbolic_composition=True, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7fe63eee7040>, print_timings=False, unpreconditioning_order=5), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7fe62eca1e20>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7fe635b31b80>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7fe637f24d60>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.20600000000000002], [], mask=None), reach_tree = None
# Monitoring initial signal: 1 items in 0.05 seconds
# (ContextSignal([0.0000000000000000 .. 0.20600000000000002], [[0.050000000000000002 .. 0.10000000000000001], None], [[-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7fe62ecb6730>)).to_domain(0.01?)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.0040000000000000001], [], mask=None), reach_tree = None
# (ContextSignal([0.0000000000000000 .. 0.0040000000000000001], [[0.050000000000000002 .. 0.10000000000000001], None], [[-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7fe62ecb6f70>)).to_domain(0.01?)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.0020000000000000001], [], mask=None), reach_tree = None
# I  = [0.0000000000000000 .. 0.31256249999999997]
# fI = ['[0.99998486618648119 .. 1.4231287678389127]', '[2.3542991988952897 .. 6.0001133420806650]']
# C || f(I) = ['[0.99998486618648119 .. 1.4231287678389127]', '[2.3542991988952897 .. 6.0001133420806650]']
#      odes = (1.1?, 5.?)
# D || odes = (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y)
# phi(D || odes, C || f(I)) = None
# bisecting [0.0000000000000000 .. 0.31256249999999997] -> [0.0000000000000000 .. 0.15628124999999999], [0.15628124999999998 .. 0.31256249999999997]
# phi variables sfs = {x, y}
# system sfs = System(R, (x, y), [[0.99998486618648119 .. 1.3147891504460838], [3.1054426286052523 .. 6.0001133420806650]], (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y), varmap=bidict({'x': x, 'y': y}))
# Generating Reach Tree: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2*x + 0.8000000000000000?)>, precompose_systems=False, initial_form=<InitialForm.COMBINED: 1>, order=5, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.00100000000000000, integration_method=<IntegrationMethod.LOW_DEGREE: 2>, cutoff_threshold=0.0000100000000000000, verbosity=0, epsilon_ctx=0.100000000000000, symbolic_composition=True, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7fe63eee7040>, print_timings=False, unpreconditioning_order=5), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7fe635bc7370>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7fe635b31ca0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7fe6245ba040>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.20600000000000002], [], mask=None), reach_tree = None
# Monitoring initial signal: 1 items in 0.07 seconds
# (ContextSignal([0.0000000000000000 .. 0.20600000000000002], [[0.050000000000000002 .. 0.10000000000000001], None], [[-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7fe62ecb6e80>)).to_domain(0.01?)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.0040000000000000001], [], mask=None), reach_tree = None
# (ContextSignal([0.0000000000000000 .. 0.0040000000000000001], [[0.050000000000000002 .. 0.10000000000000001], None], [[-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7fe62ec986d0>)).to_domain(0.01?)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.0020000000000000001], [], mask=None), reach_tree = None
# I  = [0.0000000000000000 .. 0.15628124999999999]
# fI = ['[0.99998486618648119 .. 1.3147891504460838]', '[3.1054426286052523 .. 6.0001133420806650]']
# C || f(I) = ['[0.99998486618648119 .. 1.3147891504460838]', '[3.1054426286052523 .. 6.0001133420806650]']
#      odes = (1.1?, 5.?)
# D || odes = (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y)
# phi(D || odes, C || f(I)) = None
# bisecting [0.0000000000000000 .. 0.15628124999999999] -> [0.0000000000000000 .. 0.078140624999999992], [0.078140624999999991 .. 0.15628124999999999]
# phi variables sfs = {x, y}
# system sfs = System(R, (x, y), [[0.99998486618648119 .. 1.2571717200961304], [3.5484300813614431 .. 6.0001133420806650]], (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y), varmap=bidict({'x': x, 'y': y}))
# Generating Reach Tree: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2*x + 0.8000000000000000?)>, precompose_systems=False, initial_form=<InitialForm.COMBINED: 1>, order=5, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.00100000000000000, integration_method=<IntegrationMethod.LOW_DEGREE: 2>, cutoff_threshold=0.0000100000000000000, verbosity=0, epsilon_ctx=0.100000000000000, symbolic_composition=True, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7fe63eee7040>, print_timings=False, unpreconditioning_order=5), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7fe62ecb66a0>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7fe635b31940>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7fe6245ba190>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = []
# domain = [0.0000000000000000 .. 0.20600000000000002]
# roots = []
# seg_domain = [0.0000000000000000 .. 0.20600000000000002]
# roots = []
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.20600000000000002], [([0.0000000000000000 .. 0.0060000000000000054], True)], mask=None), reach_tree = None
# Monitoring initial signal: 1 items in 0.10 seconds
# (ContextSignal([0.0000000000000000 .. 0.20600000000000002], [[0.050000000000000002 .. 0.10000000000000001], None], [[-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7fe62ec98a00>)).to_domain(0.01?)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.0040000000000000001], [([0.0000000000000000 .. 0.0040000000000000001], True)], mask=None), reach_tree = None
# (ContextSignal([0.0000000000000000 .. 0.0040000000000000001], [[0.050000000000000002 .. 0.10000000000000001], None], [[-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7fe6245b5640>)).to_domain(0.01?)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.0020000000000000001], [([0.0000000000000000 .. 0.0020000000000000001], True)], mask=None), reach_tree = None
# I  = [0.0000000000000000 .. 0.078140624999999992]
# fI = ['[0.99998486618648119 .. 1.2571717200961304]', '[3.5484300813614431 .. 6.0001133420806650]']
# C || f(I) = ['[0.99998486618648119 .. 1.2571717200961304]', '[3.5484300813614431 .. 6.0001133420806650]']
#      odes = (1.1?, 5.?)
# D || odes = (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y)
# phi(D || odes, C || f(I)) = True
# phi variables sfs = {x, y}
# system sfs = System(R, (x, y), [[1.0103347280509704 .. 1.3147891504460838], [3.1054426286052523 .. 5.7010432514185139]], (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y), varmap=bidict({'x': x, 'y': y}))
# Generating Reach Tree: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2*x + 0.8000000000000000?)>, precompose_systems=False, initial_form=<InitialForm.COMBINED: 1>, order=5, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.00100000000000000, integration_method=<IntegrationMethod.LOW_DEGREE: 2>, cutoff_threshold=0.0000100000000000000, verbosity=0, epsilon_ctx=0.100000000000000, symbolic_composition=True, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7fe63eee7040>, print_timings=False, unpreconditioning_order=5), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7fe62ec82370>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7fe635b31820>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7fe637f24d60>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.20600000000000002], [], mask=None), reach_tree = None
# Monitoring initial signal: 1 items in 0.07 seconds
# (ContextSignal([0.0000000000000000 .. 0.20600000000000002], [[0.050000000000000002 .. 0.10000000000000001], None], [[-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7fe62ecb6be0>)).to_domain(0.01?)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.0040000000000000001], [], mask=None), reach_tree = None
# (ContextSignal([0.0000000000000000 .. 0.0040000000000000001], [[0.050000000000000002 .. 0.10000000000000001], None], [[-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7fe635bc74c0>)).to_domain(0.01?)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.0020000000000000001], [], mask=None), reach_tree = None
# I  = [0.078140624999999991 .. 0.15628124999999999]
# fI = ['[1.0103347280509704 .. 1.3147891504460838]', '[3.1054426286052523 .. 5.7010432514185139]']
# C || f(I) = ['[1.0103347280509704 .. 1.3147891504460838]', '[3.1054426286052523 .. 5.7010432514185139]']
#      odes = (1.1?, 5.?)
# D || odes = (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y)
# phi(D || odes, C || f(I)) = None
# phi variables sfs = {x, y}
# system sfs = System(R, (x, y), [[1.0203307199787692 .. 1.4231287678389127], [2.3542991988952897 .. 5.3961085286365301]], (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y), varmap=bidict({'x': x, 'y': y}))
# Generating Reach Tree: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2*x + 0.8000000000000000?)>, precompose_systems=False, initial_form=<InitialForm.COMBINED: 1>, order=5, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.00100000000000000, integration_method=<IntegrationMethod.LOW_DEGREE: 2>, cutoff_threshold=0.0000100000000000000, verbosity=0, epsilon_ctx=0.100000000000000, symbolic_composition=True, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7fe63eee7040>, print_timings=False, unpreconditioning_order=5), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7fe62ecb67c0>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7fe635b31940>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7fe6245bf040>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.20600000000000002], [], mask=None), reach_tree = None
# Monitoring initial signal: 1 items in 0.05 seconds
# (ContextSignal([0.0000000000000000 .. 0.20600000000000002], [[0.050000000000000002 .. 0.10000000000000001], None], [[-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7fe62eca1910>)).to_domain(0.01?)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.0040000000000000001], [], mask=None), reach_tree = None
# (ContextSignal([0.0000000000000000 .. 0.0040000000000000001], [[0.050000000000000002 .. 0.10000000000000001], None], [[-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7fe62eca1fd0>)).to_domain(0.01?)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.0020000000000000001], [], mask=None), reach_tree = None
# I  = [0.15628124999999998 .. 0.31256249999999997]
# fI = ['[1.0203307199787692 .. 1.4231287678389127]', '[2.3542991988952897 .. 5.3961085286365301]']
# C || f(I) = ['[1.0203307199787692 .. 1.4231287678389127]', '[2.3542991988952897 .. 5.3961085286365301]']
#      odes = (1.1?, 5.?)
# D || odes = (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y)
# phi(D || odes, C || f(I)) = None
# bisecting [0.15628124999999998 .. 0.31256249999999997] -> [0.15628124999999998 .. 0.23442187499999998], [0.23442187499999997 .. 0.31256249999999997]
# phi variables sfs = {x, y}
# system sfs = System(R, (x, y), [[1.0203307199787692 .. 1.3705708503372114], [2.7031335755309608 .. 5.3961085286365301]], (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y), varmap=bidict({'x': x, 'y': y}))
# Generating Reach Tree: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2*x + 0.8000000000000000?)>, precompose_systems=False, initial_form=<InitialForm.COMBINED: 1>, order=5, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.00100000000000000, integration_method=<IntegrationMethod.LOW_DEGREE: 2>, cutoff_threshold=0.0000100000000000000, verbosity=0, epsilon_ctx=0.100000000000000, symbolic_composition=True, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7fe63eee7040>, print_timings=False, unpreconditioning_order=5), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7fe62ec824f0>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7fe635b31ca0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7fe6245bf190>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.20600000000000002], [], mask=None), reach_tree = None
# Monitoring initial signal: 1 items in 0.07 seconds
# (ContextSignal([0.0000000000000000 .. 0.20600000000000002], [[0.050000000000000002 .. 0.10000000000000001], None], [[-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7fe62ec82a00>)).to_domain(0.01?)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.0040000000000000001], [], mask=None), reach_tree = None
# (ContextSignal([0.0000000000000000 .. 0.0040000000000000001], [[0.050000000000000002 .. 0.10000000000000001], None], [[-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7fe6245b5490>)).to_domain(0.01?)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.0020000000000000001], [], mask=None), reach_tree = None
# I  = [0.15628124999999998 .. 0.23442187499999998]
# fI = ['[1.0203307199787692 .. 1.3705708503372114]', '[2.7031335755309608 .. 5.3961085286365301]']
# C || f(I) = ['[1.0203307199787692 .. 1.3705708503372114]', '[2.7031335755309608 .. 5.3961085286365301]']
#      odes = (1.1?, 5.?)
# D || odes = (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y)
# phi(D || odes, C || f(I)) = None
# phi variables sfs = {x, y}
# system sfs = System(R, (x, y), [[1.0308361916637505 .. 1.4231287678389127], [2.3542991988952897 .. 5.0592364092274301]], (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y), varmap=bidict({'x': x, 'y': y}))
# Generating Reach Tree: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2*x + 0.8000000000000000?)>, precompose_systems=False, initial_form=<InitialForm.COMBINED: 1>, order=5, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.00100000000000000, integration_method=<IntegrationMethod.LOW_DEGREE: 2>, cutoff_threshold=0.0000100000000000000, verbosity=0, epsilon_ctx=0.100000000000000, symbolic_composition=True, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7fe63eee7040>, print_timings=False, unpreconditioning_order=5), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7fe635bc71f0>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7fe635b31b80>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7fe6245bf2e0>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.20600000000000002], [], mask=None), reach_tree = None
# Monitoring initial signal: 1 items in 0.05 seconds
# (ContextSignal([0.0000000000000000 .. 0.20600000000000002], [[0.050000000000000002 .. 0.10000000000000001], None], [[-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7fe6245b5d30>)).to_domain(0.01?)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.0040000000000000001], [], mask=None), reach_tree = None
# (ContextSignal([0.0000000000000000 .. 0.0040000000000000001], [[0.050000000000000002 .. 0.10000000000000001], None], [[-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7fe6245b57f0>)).to_domain(0.01?)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.0020000000000000001], [], mask=None), reach_tree = None
# I  = [0.23442187499999997 .. 0.31256249999999997]
# fI = ['[1.0308361916637505 .. 1.4231287678389127]', '[2.3542991988952897 .. 5.0592364092274301]']
# C || f(I) = ['[1.0308361916637505 .. 1.4231287678389127]', '[2.3542991988952897 .. 5.0592364092274301]']
#      odes = (1.1?, 5.?)
# D || odes = (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y)
# phi(D || odes, C || f(I)) = None
# phi variables sfs = {x, y}
# system sfs = System(R, (x, y), [[1.0414094763215728 .. 1.5719639955222958], [1.1328194291313433 .. 4.6659584623313056]], (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y), varmap=bidict({'x': x, 'y': y}))
# Generating Reach Tree: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2*x + 0.8000000000000000?)>, precompose_systems=False, initial_form=<InitialForm.COMBINED: 1>, order=5, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.00100000000000000, integration_method=<IntegrationMethod.LOW_DEGREE: 2>, cutoff_threshold=0.0000100000000000000, verbosity=0, epsilon_ctx=0.100000000000000, symbolic_composition=True, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7fe63eee7040>, print_timings=False, unpreconditioning_order=5), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7fe62eca12e0>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7fe635b31280>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7fe6245bf430>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.20600000000000002], [], mask=None), reach_tree = None
# Monitoring initial signal: 1 items in 0.04 seconds
# (ContextSignal([0.0000000000000000 .. 0.20600000000000002], [[0.050000000000000002 .. 0.10000000000000001], None], [[-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7fe6245b5e80>)).to_domain(0.01?)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.0040000000000000001], [], mask=None), reach_tree = None
# (ContextSignal([0.0000000000000000 .. 0.0040000000000000001], [[0.050000000000000002 .. 0.10000000000000001], None], [[-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7fe6245c02b0>)).to_domain(0.01?)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.0020000000000000001], [], mask=None), reach_tree = None
# I  = [0.31256249999999996 .. 0.62512499999999994]
# fI = ['[1.0414094763215728 .. 1.5719639955222958]', '[1.1328194291313433 .. 4.6659584623313056]']
# C || f(I) = ['[1.0414094763215728 .. 1.5719639955222958]', '[1.1328194291313433 .. 4.6659584623313056]']
#      odes = (1.1?, 5.?)
# D || odes = (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y)
# phi(D || odes, C || f(I)) = None
# bisecting [0.31256249999999996 .. 0.62512499999999994] -> [0.31256249999999996 .. 0.46884374999999995], [0.46884374999999994 .. 0.62512499999999994]
# phi variables sfs = {x, y}
# system sfs = System(R, (x, y), [[1.0414094763215728 .. 1.5136230924869741], [1.6761763005998997 .. 4.6659584623313056]], (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y), varmap=bidict({'x': x, 'y': y}))
# Generating Reach Tree: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2*x + 0.8000000000000000?)>, precompose_systems=False, initial_form=<InitialForm.COMBINED: 1>, order=5, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.00100000000000000, integration_method=<IntegrationMethod.LOW_DEGREE: 2>, cutoff_threshold=0.0000100000000000000, verbosity=0, epsilon_ctx=0.100000000000000, symbolic_composition=True, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7fe63eee7040>, print_timings=False, unpreconditioning_order=5), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7fe6245b5fd0>
# recomputing reachset
# ...
# Generating Reach Tree: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2*x + 0.8000000000000000?)>, precompose_systems=False, initial_form=<InitialForm.COMBINED: 1>, order=5, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.00100000000000000, integration_method=<IntegrationMethod.LOW_DEGREE: 2>, cutoff_threshold=0.0000100000000000000, verbosity=0, epsilon_ctx=0.100000000000000, symbolic_composition=True, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7fe63eee7040>, print_timings=False, unpreconditioning_order=5), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7fe6245cb250>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7fe635b31a60>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7fe6245c1ac0>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.02 seconds
# roots = [[0.0000000000000000 .. 0.13125000000000001]]
# domain = [0.0000000000000000 .. 0.20600000000000002]
# roots = [[0.0000000000000000 .. 0.13125000000000001]]
# seg_domain = [0.0000000000000000 .. 0.20600000000000002]
# roots = [[0.0000000000000000 .. 0.13125000000000001]]
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.20600000000000002], [([0.0000000000000000 .. 0.20600000000000002], False)], mask=None), reach_tree = None
# Monitoring initial signal: 1 items in 0.05 seconds
# (ContextSignal([0.0000000000000000 .. 0.20600000000000002], [[0.050000000000000002 .. 0.10000000000000001], None], [[-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7fe6399e66d0>)).to_domain(0.01?)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.0040000000000000001], [([0.0000000000000000 .. 0.0040000000000000001], False)], mask=None), reach_tree = None
# (ContextSignal([0.0000000000000000 .. 0.0040000000000000001], [[0.050000000000000002 .. 0.10000000000000001], None], [[-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7fe6399e6cd0>)).to_domain(0.01?)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.0020000000000000001], [([0.0000000000000000 .. 0.0020000000000000001], False)], mask=None), reach_tree = None
# I  = [2.9693437499999992 .. 3.1256249999999995]
# fI = ['[1.0631308717990188 .. 1.2090464685128777]', '[-0.13270031949485029 .. 0.35303472693459609]']
# C || f(I) = ['[1.0631308717990188 .. 1.2090464685128777]', '[-0.13270031949485029 .. 0.35303472693459609]']
#      odes = (1.1?, 5.?)
# D || odes = (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y)
# phi(D || odes, C || f(I)) = False
# phi variables sfs = {x, y}
# system sfs = System(R, (x, y), [[1.0353138912913404 .. 1.1926895011892529], [-0.12755722284379559 .. 0.31777092840130189]], (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y), varmap=bidict({'x': x, 'y': y}))
# Generating Reach Tree: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2*x + 0.8000000000000000?)>, precompose_systems=False, initial_form=<InitialForm.COMBINED: 1>, order=5, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.00100000000000000, integration_method=<IntegrationMethod.LOW_DEGREE: 2>, cutoff_threshold=0.0000100000000000000, verbosity=0, epsilon_ctx=0.100000000000000, symbolic_composition=True, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7fe63eee7040>, print_timings=False, unpreconditioning_order=5), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7fe6245b5100>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7fe635b31b80>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7fe6245c1580>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.02 seconds
# roots = []
# domain = [0.0000000000000000 .. 0.20600000000000002]
# roots = []
# seg_domain = [0.0000000000000000 .. 0.20600000000000002]
# roots = []
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.20600000000000002], [([0.0000000000000000 .. 0.20600000000000002], False)], mask=None), reach_tree = None
# Monitoring initial signal: 1 items in 0.06 seconds
# (ContextSignal([0.0000000000000000 .. 0.20600000000000002], [[0.050000000000000002 .. 0.10000000000000001], None], [[-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7fe62ec82a30>)).to_domain(0.01?)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.0040000000000000001], [([0.0000000000000000 .. 0.0040000000000000001], False)], mask=None), reach_tree = None
# (ContextSignal([0.0000000000000000 .. 0.0040000000000000001], [[0.050000000000000002 .. 0.10000000000000001], None], [[-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7fe6245c3fd0>)).to_domain(0.01?)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.0020000000000000001], [([0.0000000000000000 .. 0.0020000000000000001], False)], mask=None), reach_tree = None
# I  = [3.1256249999999994 .. 3.7507499999999996]
# fI = ['[1.0353138912913404 .. 1.1926895011892529]', '[-0.12755722284379559 .. 0.31777092840130189]']
# C || f(I) = ['[1.0353138912913404 .. 1.1926895011892529]', '[-0.12755722284379559 .. 0.31777092840130189]']
#      odes = (1.1?, 5.?)
# D || odes = (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y)
# phi(D || odes, C || f(I)) = False
# phi variables sfs = {x, y}
# system sfs = System(R, (x, y), [[1.0107493386729400 .. 1.1416913735520867], [-0.10742451333011963 .. 0.22692493651710613]], (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y), varmap=bidict({'x': x, 'y': y}))
# Generating Reach Tree: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2*x + 0.8000000000000000?)>, precompose_systems=False, initial_form=<InitialForm.COMBINED: 1>, order=5, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.00100000000000000, integration_method=<IntegrationMethod.LOW_DEGREE: 2>, cutoff_threshold=0.0000100000000000000, verbosity=0, epsilon_ctx=0.100000000000000, symbolic_composition=True, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7fe63eee7040>, print_timings=False, unpreconditioning_order=5), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7fe6245c3670>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7fe635b31940>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7fe6245c1820>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.02 seconds
# roots = []
# domain = [0.0000000000000000 .. 0.20600000000000002]
# roots = []
# seg_domain = [0.0000000000000000 .. 0.20600000000000002]
# roots = []
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.20600000000000002], [([0.0000000000000000 .. 0.20600000000000002], False)], mask=None), reach_tree = None
# Monitoring initial signal: 1 items in 0.06 seconds
# (ContextSignal([0.0000000000000000 .. 0.20600000000000002], [[0.050000000000000002 .. 0.10000000000000001], None], [[-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7fe62ecb6dc0>)).to_domain(0.01?)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.0040000000000000001], [([0.0000000000000000 .. 0.0040000000000000001], False)], mask=None), reach_tree = None
# (ContextSignal([0.0000000000000000 .. 0.0040000000000000001], [[0.050000000000000002 .. 0.10000000000000001], None], [[-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7fe62eca13a0>)).to_domain(0.01?)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.0020000000000000001], [([0.0000000000000000 .. 0.0020000000000000001], False)], mask=None), reach_tree = None
# I  = [3.7507499999999995 .. 5.0009999999999995]
# fI = ['[1.0107493386729400 .. 1.1416913735520867]', '[-0.10742451333011963 .. 0.22692493651710613]']
# C || f(I) = ['[1.0107493386729400 .. 1.1416913735520867]', '[-0.10742451333011963 .. 0.22692493651710613]']
#      odes = (1.1?, 5.?)
# D || odes = (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y)
# phi(D || odes, C || f(I)) = False
# phi variables sfs = {x, y}
# system sfs = System(R, (x, y), [[0.99863734049121122 .. 1.0726859832830782], [-0.060068629854421553 .. 0.11313085016410141]], (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y), varmap=bidict({'x': x, 'y': y}))
# Generating Reach Tree: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2*x + 0.8000000000000000?)>, precompose_systems=False, initial_form=<InitialForm.COMBINED: 1>, order=5, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.00100000000000000, integration_method=<IntegrationMethod.LOW_DEGREE: 2>, cutoff_threshold=0.0000100000000000000, verbosity=0, epsilon_ctx=0.100000000000000, symbolic_composition=True, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7fe63eee7040>, print_timings=False, unpreconditioning_order=5), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7fe62ecb6b20>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7fe6245abb80>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7fe6245c1d60>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = []
# domain = [0.0000000000000000 .. 0.20600000000000002]
# roots = []
# seg_domain = [0.0000000000000000 .. 0.20600000000000002]
# roots = []
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.20600000000000002], [([0.0000000000000000 .. 0.20600000000000002], False)], mask=None), reach_tree = None
# Monitoring initial signal: 1 items in 0.03 seconds
# (ContextSignal([0.0000000000000000 .. 0.20600000000000002], [[0.050000000000000002 .. 0.10000000000000001], None], [[-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7fe6245d7430>)).to_domain(0.01?)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.0040000000000000001], [([0.0000000000000000 .. 0.0040000000000000001], False)], mask=None), reach_tree = None
# (ContextSignal([0.0000000000000000 .. 0.0040000000000000001], [[0.050000000000000002 .. 0.10000000000000001], None], [[-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7fe6245d7700>)).to_domain(0.01?)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.0020000000000000001], [([0.0000000000000000 .. 0.0020000000000000001], False)], mask=None), reach_tree = None
# I  = [5.0009999999999994 .. 10.001999999999999]
# fI = ['[0.99863734049121122 .. 1.0726859832830782]', '[-0.060068629854421553 .. 0.11313085016410141]']
# C || f(I) = ['[0.99863734049121122 .. 1.0726859832830782]', '[-0.060068629854421553 .. 0.11313085016410141]']
#      odes = (1.1?, 5.?)
# D || odes = (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y)
# phi(D || odes, C || f(I)) = False
# Monitoring initial signal: 1 items in 11.41 seconds
# (ContextSignal([0.0000000000000000 .. 10.001999999999999], [[1.0000000000000000 .. 1.2000000000000000], [4 .. 6]], [[-1 .. 1], [-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7fe637df3c10>)).to_domain(1.?e1)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 10.000000000000000], [([0.0000000000000000 .. 0.078140624999999992], True), ([2.8912031249999996 .. 10.000000000000000], False)], mask=None), reach_tree = None

# %%
refined_csig =({x: RIF(0.05, 0.1)} >> G(RIF(0, 0.2), P)
           ).context_signal_for_system(odes_whelks, initials, 10,
                                       refine=1,
                                       initial_form=InitialForm.SPLIT_VARS,
                                       **kwargs)
# Out:
# phi variables sfs = {y, x}
# system sfs = System(R, (x, y), [[1.0000000000000000 .. 1.2000000000000000], [4 .. 6]], (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y), varmap=bidict({'x': x, 'y': y}))
# Generating Reach Tree: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(), signal = <function C.context_signal.<locals>.signal_fn at 0x7f5d9934dca0>, reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f5dac06eb50>
# contexts = ['[1.0..1.2]', '[4.0..6.0]']
# statics  = []
# recomputing reachset
# setting reach level to 0
# mask = None
# phi variables sfs = {y, x}
# system sfs = System(R, (x, y), [[0.99863734049219643 .. 1.5959882046270193], [-0.18566626515688304 .. 6.0001133420806659]], (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y), varmap=bidict({'x': x, 'y': y}))
# Generating Reach Tree: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2*x + 0.8000000000000000?)>, precompose_systems=False, initial_form=<InitialForm.SPLIT_VARS: 3>, order=5, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.00100000000000000, integration_method=<IntegrationMethod.LOW_DEGREE: 2>, cutoff_threshold=0.0000100000000000000, verbosity=0, epsilon_ctx=0.100000000000000, symbolic_composition=True, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7f5dae87dd00>, print_timings=False, unpreconditioning_order=5), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f5dac06e0a0>
# contexts = ['[0.05..0.1]']
# statics  = ['[0.9986373404921964..1.5959882046270193]', '[-0.18566626515688303..6.000113342080666]']
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7f5dae89b280>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f5db0c8d820>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.20600000000000002], [], mask=None), reach_tree = None
# Monitoring initial signal: 1 items in 0.03 seconds
# (ContextSignal([0.0000000000000000 .. 0.20600000000000002], [[0.050000000000000002 .. 0.10000000000000001], None], [[-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7f5daea9c760>)).to_domain(0.01?)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.0040000000000000001], [], mask=None), reach_tree = None
# (ContextSignal([0.0000000000000000 .. 0.0040000000000000001], [[0.050000000000000002 .. 0.10000000000000001], None], [[-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7f5dac053100>)).to_domain(0.01?)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.0020000000000000001], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0,), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2*x + 0.8000000000000000?)>, precompose_systems=False, initial_form=<InitialForm.SPLIT_VARS: 3>, order=5, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.00100000000000000, integration_method=<IntegrationMethod.LOW_DEGREE: 2>, cutoff_threshold=0.0000100000000000000, verbosity=0, epsilon_ctx=0.100000000000000, symbolic_composition=True, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7f5dae87dd00>, print_timings=False, unpreconditioning_order=5), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f5dac06e0a0>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7f5dae89b280>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f5db0c8dd60>
#  ==> creating ContextSignal with coord=(0,), signal = Signal([0.0000000000000000 .. 0.20600000000000002], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0,), signal = Signal([0.0000000000000000 .. 0.0040000000000000001], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0,), signal = Signal([0.0000000000000000 .. 0.0020000000000000001], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2*x + 0.8000000000000000?)>, precompose_systems=False, initial_form=<InitialForm.SPLIT_VARS: 3>, order=5, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.00100000000000000, integration_method=<IntegrationMethod.LOW_DEGREE: 2>, cutoff_threshold=0.0000100000000000000, verbosity=0, epsilon_ctx=0.100000000000000, symbolic_composition=True, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7f5dae87dd00>, print_timings=False, unpreconditioning_order=5), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f5dac06e0a0>
# contexts = ['[0.05..0.07500000000000001]']
# statics  = ['[0.9986373404921964..1.5959882046270193]', '[-0.18566626515688303..6.000113342080666]']
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7f5dae89b820>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f5db0c8deb0>
#  ==> creating ContextSignal with coord=(0, 0), signal = Signal([0.0000000000000000 .. 0.20600000000000002], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0), signal = Signal([0.0000000000000000 .. 0.0040000000000000001], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0), signal = Signal([0.0000000000000000 .. 0.0020000000000000001], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2*x + 0.8000000000000000?)>, precompose_systems=False, initial_form=<InitialForm.SPLIT_VARS: 3>, order=5, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.00100000000000000, integration_method=<IntegrationMethod.LOW_DEGREE: 2>, cutoff_threshold=0.0000100000000000000, verbosity=0, epsilon_ctx=0.100000000000000, symbolic_composition=True, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7f5dae87dd00>, print_timings=False, unpreconditioning_order=5), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f5dac06e0a0>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7f5dae89b820>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f5d99355040>
#  ==> creating ContextSignal with coord=(0, 1), signal = Signal([0.0000000000000000 .. 0.20600000000000002], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 1), signal = Signal([0.0000000000000000 .. 0.0040000000000000001], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 1), signal = Signal([0.0000000000000000 .. 0.0020000000000000001], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1,), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2*x + 0.8000000000000000?)>, precompose_systems=False, initial_form=<InitialForm.SPLIT_VARS: 3>, order=5, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.00100000000000000, integration_method=<IntegrationMethod.LOW_DEGREE: 2>, cutoff_threshold=0.0000100000000000000, verbosity=0, epsilon_ctx=0.100000000000000, symbolic_composition=True, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7f5dae87dd00>, print_timings=False, unpreconditioning_order=5), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f5dac06e0a0>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7f5dae89b280>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f5db0c8dd60>
#  ==> creating ContextSignal with coord=(1,), signal = Signal([0.0000000000000000 .. 0.20600000000000002], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1,), signal = Signal([0.0000000000000000 .. 0.0040000000000000001], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1,), signal = Signal([0.0000000000000000 .. 0.0020000000000000001], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2*x + 0.8000000000000000?)>, precompose_systems=False, initial_form=<InitialForm.SPLIT_VARS: 3>, order=5, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.00100000000000000, integration_method=<IntegrationMethod.LOW_DEGREE: 2>, cutoff_threshold=0.0000100000000000000, verbosity=0, epsilon_ctx=0.100000000000000, symbolic_composition=True, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7f5dae87dd00>, print_timings=False, unpreconditioning_order=5), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f5dac06e0a0>
# contexts = ['[0.07500000000000001..0.1]']
# statics  = ['[0.9986373404921964..1.5959882046270193]', '[-0.18566626515688303..6.000113342080666]']
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7f5dae89ba60>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f5d99355190>
#  ==> creating ContextSignal with coord=(1, 0), signal = Signal([0.0000000000000000 .. 0.20600000000000002], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 0), signal = Signal([0.0000000000000000 .. 0.0040000000000000001], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 0), signal = Signal([0.0000000000000000 .. 0.0020000000000000001], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2*x + 0.8000000000000000?)>, precompose_systems=False, initial_form=<InitialForm.SPLIT_VARS: 3>, order=5, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.00100000000000000, integration_method=<IntegrationMethod.LOW_DEGREE: 2>, cutoff_threshold=0.0000100000000000000, verbosity=0, epsilon_ctx=0.100000000000000, symbolic_composition=True, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7f5dae87dd00>, print_timings=False, unpreconditioning_order=5), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f5dac06e0a0>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7f5dae89ba60>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f5d993552e0>
#  ==> creating ContextSignal with coord=(1, 1), signal = Signal([0.0000000000000000 .. 0.20600000000000002], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 1), signal = Signal([0.0000000000000000 .. 0.0040000000000000001], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 1), signal = Signal([0.0000000000000000 .. 0.0020000000000000001], [], mask=None), reach_tree = None
# I  = [0.0000000000000000 .. 10.001999999999999]
# fI = ['[0.99863734049219643 .. 1.5959882046270193]', '[-0.18566626515688304 .. 6.0001133420806659]']
# C || f(I) = ['[0.99863734049219643 .. 1.5959882046270193]', '[-0.18566626515688304 .. 6.0001133420806659]']
#      odes = (1.1?, 5.?)
# D || odes = (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y)
# phi(D || odes, C || f(I)) = None
# bisecting [0.0000000000000000 .. 10.001999999999999] -> [0.0000000000000000 .. 5.0009999999999995], [5.0009999999999994 .. 10.001999999999999]
# phi variables sfs = {y, x}
# system sfs = System(R, (x, y), [[0.99998486618648063 .. 1.5959882046270193], [-0.18566626515688304 .. 6.0001133420806659]], (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y), varmap=bidict({'x': x, 'y': y}))
# Generating Reach Tree: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2*x + 0.8000000000000000?)>, precompose_systems=False, initial_form=<InitialForm.SPLIT_VARS: 3>, order=5, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.00100000000000000, integration_method=<IntegrationMethod.LOW_DEGREE: 2>, cutoff_threshold=0.0000100000000000000, verbosity=0, epsilon_ctx=0.100000000000000, symbolic_composition=True, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7f5dae87dd00>, print_timings=False, unpreconditioning_order=5), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f5dae886b80>
# contexts = ['[0.05..0.1]']
# statics  = ['[0.9999848661864806..1.5959882046270193]', '[-0.18566626515688303..6.000113342080666]']
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7f5dae89bb80>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f5db0c8d820>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.20600000000000002], [], mask=None), reach_tree = None
# Monitoring initial signal: 1 items in 0.04 seconds
# (ContextSignal([0.0000000000000000 .. 0.20600000000000002], [[0.050000000000000002 .. 0.10000000000000001], None], [[-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7f5d993576a0>)).to_domain(0.01?)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.0040000000000000001], [], mask=None), reach_tree = None
# (ContextSignal([0.0000000000000000 .. 0.0040000000000000001], [[0.050000000000000002 .. 0.10000000000000001], None], [[-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7f5dac068640>)).to_domain(0.01?)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.0020000000000000001], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0,), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2*x + 0.8000000000000000?)>, precompose_systems=False, initial_form=<InitialForm.SPLIT_VARS: 3>, order=5, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.00100000000000000, integration_method=<IntegrationMethod.LOW_DEGREE: 2>, cutoff_threshold=0.0000100000000000000, verbosity=0, epsilon_ctx=0.100000000000000, symbolic_composition=True, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7f5dae87dd00>, print_timings=False, unpreconditioning_order=5), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f5dae886b80>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7f5dae89bb80>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f5d99355430>
#  ==> creating ContextSignal with coord=(0,), signal = Signal([0.0000000000000000 .. 0.20600000000000002], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0,), signal = Signal([0.0000000000000000 .. 0.0040000000000000001], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0,), signal = Signal([0.0000000000000000 .. 0.0020000000000000001], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2*x + 0.8000000000000000?)>, precompose_systems=False, initial_form=<InitialForm.SPLIT_VARS: 3>, order=5, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.00100000000000000, integration_method=<IntegrationMethod.LOW_DEGREE: 2>, cutoff_threshold=0.0000100000000000000, verbosity=0, epsilon_ctx=0.100000000000000, symbolic_composition=True, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7f5dae87dd00>, print_timings=False, unpreconditioning_order=5), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f5dae886b80>
# contexts = ['[0.05..0.07500000000000001]']
# statics  = ['[0.9999848661864806..1.5959882046270193]', '[-0.18566626515688303..6.000113342080666]']
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7f5dae89bdc0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f5d99355580>
#  ==> creating ContextSignal with coord=(0, 0), signal = Signal([0.0000000000000000 .. 0.20600000000000002], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0), signal = Signal([0.0000000000000000 .. 0.0040000000000000001], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0), signal = Signal([0.0000000000000000 .. 0.0020000000000000001], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2*x + 0.8000000000000000?)>, precompose_systems=False, initial_form=<InitialForm.SPLIT_VARS: 3>, order=5, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.00100000000000000, integration_method=<IntegrationMethod.LOW_DEGREE: 2>, cutoff_threshold=0.0000100000000000000, verbosity=0, epsilon_ctx=0.100000000000000, symbolic_composition=True, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7f5dae87dd00>, print_timings=False, unpreconditioning_order=5), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f5dae886b80>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7f5dae89bdc0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f5db0c8dd60>
#  ==> creating ContextSignal with coord=(0, 1), signal = Signal([0.0000000000000000 .. 0.20600000000000002], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 1), signal = Signal([0.0000000000000000 .. 0.0040000000000000001], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 1), signal = Signal([0.0000000000000000 .. 0.0020000000000000001], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1,), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2*x + 0.8000000000000000?)>, precompose_systems=False, initial_form=<InitialForm.SPLIT_VARS: 3>, order=5, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.00100000000000000, integration_method=<IntegrationMethod.LOW_DEGREE: 2>, cutoff_threshold=0.0000100000000000000, verbosity=0, epsilon_ctx=0.100000000000000, symbolic_composition=True, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7f5dae87dd00>, print_timings=False, unpreconditioning_order=5), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f5dae886b80>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7f5dae89bb80>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f5d99355430>
#  ==> creating ContextSignal with coord=(1,), signal = Signal([0.0000000000000000 .. 0.20600000000000002], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1,), signal = Signal([0.0000000000000000 .. 0.0040000000000000001], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1,), signal = Signal([0.0000000000000000 .. 0.0020000000000000001], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2*x + 0.8000000000000000?)>, precompose_systems=False, initial_form=<InitialForm.SPLIT_VARS: 3>, order=5, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.00100000000000000, integration_method=<IntegrationMethod.LOW_DEGREE: 2>, cutoff_threshold=0.0000100000000000000, verbosity=0, epsilon_ctx=0.100000000000000, symbolic_composition=True, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7f5dae87dd00>, print_timings=False, unpreconditioning_order=5), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f5dae886b80>
# contexts = ['[0.07500000000000001..0.1]']
# statics  = ['[0.9999848661864806..1.5959882046270193]', '[-0.18566626515688303..6.000113342080666]']
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7f5dae89bca0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f5d993552e0>
#  ==> creating ContextSignal with coord=(1, 0), signal = Signal([0.0000000000000000 .. 0.20600000000000002], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 0), signal = Signal([0.0000000000000000 .. 0.0040000000000000001], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 0), signal = Signal([0.0000000000000000 .. 0.0020000000000000001], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2*x + 0.8000000000000000?)>, precompose_systems=False, initial_form=<InitialForm.SPLIT_VARS: 3>, order=5, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.00100000000000000, integration_method=<IntegrationMethod.LOW_DEGREE: 2>, cutoff_threshold=0.0000100000000000000, verbosity=0, epsilon_ctx=0.100000000000000, symbolic_composition=True, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7f5dae87dd00>, print_timings=False, unpreconditioning_order=5), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f5dae886b80>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7f5dae89bca0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f5d99355190>
#  ==> creating ContextSignal with coord=(1, 1), signal = Signal([0.0000000000000000 .. 0.20600000000000002], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 1), signal = Signal([0.0000000000000000 .. 0.0040000000000000001], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 1), signal = Signal([0.0000000000000000 .. 0.0020000000000000001], [], mask=None), reach_tree = None
# I  = [0.0000000000000000 .. 5.0009999999999995]
# fI = ['[0.99998486618648063 .. 1.5959882046270193]', '[-0.18566626515688304 .. 6.0001133420806659]']
# C || f(I) = ['[0.99998486618648063 .. 1.5959882046270193]', '[-0.18566626515688304 .. 6.0001133420806659]']
#      odes = (1.1?, 5.?)
# D || odes = (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y)
# phi(D || odes, C || f(I)) = None
# bisecting [0.0000000000000000 .. 5.0009999999999995] -> [0.0000000000000000 .. 2.5004999999999998], [2.5004999999999997 .. 5.0009999999999995]
# phi variables sfs = {y, x}
# system sfs = System(R, (x, y), [[0.99998486618648063 .. 1.5959882046270193], [-0.18566626515688304 .. 6.0001133420806659]], (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y), varmap=bidict({'x': x, 'y': y}))
# Generating Reach Tree: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2*x + 0.8000000000000000?)>, precompose_systems=False, initial_form=<InitialForm.SPLIT_VARS: 3>, order=5, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.00100000000000000, integration_method=<IntegrationMethod.LOW_DEGREE: 2>, cutoff_threshold=0.0000100000000000000, verbosity=0, epsilon_ctx=0.100000000000000, symbolic_composition=True, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7f5dae87dd00>, print_timings=False, unpreconditioning_order=5), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f5dac06e280>
# contexts = ['[0.05..0.1]']
# statics  = ['[0.9999848661864806..1.5959882046270193]', '[-0.18566626515688303..6.000113342080666]']
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7f5dae89bee0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f5db0c8d820>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.20600000000000002], [], mask=None), reach_tree = None
# Monitoring initial signal: 1 items in 0.04 seconds
# (ContextSignal([0.0000000000000000 .. 0.20600000000000002], [[0.050000000000000002 .. 0.10000000000000001], None], [[-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7f5dac0685e0>)).to_domain(0.01?)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.0040000000000000001], [], mask=None), reach_tree = None
# (ContextSignal([0.0000000000000000 .. 0.0040000000000000001], [[0.050000000000000002 .. 0.10000000000000001], None], [[-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7f5dac0680d0>)).to_domain(0.01?)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.0020000000000000001], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0,), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2*x + 0.8000000000000000?)>, precompose_systems=False, initial_form=<InitialForm.SPLIT_VARS: 3>, order=5, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.00100000000000000, integration_method=<IntegrationMethod.LOW_DEGREE: 2>, cutoff_threshold=0.0000100000000000000, verbosity=0, epsilon_ctx=0.100000000000000, symbolic_composition=True, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7f5dae87dd00>, print_timings=False, unpreconditioning_order=5), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f5dac06e280>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7f5dae89bee0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f5d99355040>
#  ==> creating ContextSignal with coord=(0,), signal = Signal([0.0000000000000000 .. 0.20600000000000002], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0,), signal = Signal([0.0000000000000000 .. 0.0040000000000000001], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0,), signal = Signal([0.0000000000000000 .. 0.0020000000000000001], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2*x + 0.8000000000000000?)>, precompose_systems=False, initial_form=<InitialForm.SPLIT_VARS: 3>, order=5, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.00100000000000000, integration_method=<IntegrationMethod.LOW_DEGREE: 2>, cutoff_threshold=0.0000100000000000000, verbosity=0, epsilon_ctx=0.100000000000000, symbolic_composition=True, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7f5dae87dd00>, print_timings=False, unpreconditioning_order=5), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f5dac06e280>
# contexts = ['[0.05..0.07500000000000001]']
# statics  = ['[0.9999848661864806..1.5959882046270193]', '[-0.18566626515688303..6.000113342080666]']
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7f5d99346040>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f5d993556d0>
#  ==> creating ContextSignal with coord=(0, 0), signal = Signal([0.0000000000000000 .. 0.20600000000000002], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0), signal = Signal([0.0000000000000000 .. 0.0040000000000000001], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0), signal = Signal([0.0000000000000000 .. 0.0020000000000000001], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2*x + 0.8000000000000000?)>, precompose_systems=False, initial_form=<InitialForm.SPLIT_VARS: 3>, order=5, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.00100000000000000, integration_method=<IntegrationMethod.LOW_DEGREE: 2>, cutoff_threshold=0.0000100000000000000, verbosity=0, epsilon_ctx=0.100000000000000, symbolic_composition=True, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7f5dae87dd00>, print_timings=False, unpreconditioning_order=5), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f5dac06e280>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7f5d99346040>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f5d99355820>
#  ==> creating ContextSignal with coord=(0, 1), signal = Signal([0.0000000000000000 .. 0.20600000000000002], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 1), signal = Signal([0.0000000000000000 .. 0.0040000000000000001], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 1), signal = Signal([0.0000000000000000 .. 0.0020000000000000001], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1,), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2*x + 0.8000000000000000?)>, precompose_systems=False, initial_form=<InitialForm.SPLIT_VARS: 3>, order=5, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.00100000000000000, integration_method=<IntegrationMethod.LOW_DEGREE: 2>, cutoff_threshold=0.0000100000000000000, verbosity=0, epsilon_ctx=0.100000000000000, symbolic_composition=True, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7f5dae87dd00>, print_timings=False, unpreconditioning_order=5), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f5dac06e280>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7f5dae89bee0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f5d99355970>
#  ==> creating ContextSignal with coord=(1,), signal = Signal([0.0000000000000000 .. 0.20600000000000002], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1,), signal = Signal([0.0000000000000000 .. 0.0040000000000000001], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1,), signal = Signal([0.0000000000000000 .. 0.0020000000000000001], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2*x + 0.8000000000000000?)>, precompose_systems=False, initial_form=<InitialForm.SPLIT_VARS: 3>, order=5, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.00100000000000000, integration_method=<IntegrationMethod.LOW_DEGREE: 2>, cutoff_threshold=0.0000100000000000000, verbosity=0, epsilon_ctx=0.100000000000000, symbolic_composition=True, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7f5dae87dd00>, print_timings=False, unpreconditioning_order=5), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f5dac06e280>
# contexts = ['[0.07500000000000001..0.1]']
# statics  = ['[0.9999848661864806..1.5959882046270193]', '[-0.18566626515688303..6.000113342080666]']
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7f5dae89b3a0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f5d99355040>
#  ==> creating ContextSignal with coord=(1, 0), signal = Signal([0.0000000000000000 .. 0.20600000000000002], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 0), signal = Signal([0.0000000000000000 .. 0.0040000000000000001], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 0), signal = Signal([0.0000000000000000 .. 0.0020000000000000001], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2*x + 0.8000000000000000?)>, precompose_systems=False, initial_form=<InitialForm.SPLIT_VARS: 3>, order=5, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.00100000000000000, integration_method=<IntegrationMethod.LOW_DEGREE: 2>, cutoff_threshold=0.0000100000000000000, verbosity=0, epsilon_ctx=0.100000000000000, symbolic_composition=True, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7f5dae87dd00>, print_timings=False, unpreconditioning_order=5), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f5dac06e280>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7f5dae89b3a0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f5d99355190>
#  ==> creating ContextSignal with coord=(1, 1), signal = Signal([0.0000000000000000 .. 0.20600000000000002], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 1), signal = Signal([0.0000000000000000 .. 0.0040000000000000001], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 1), signal = Signal([0.0000000000000000 .. 0.0020000000000000001], [], mask=None), reach_tree = None
# I  = [0.0000000000000000 .. 2.5004999999999998]
# fI = ['[0.99998486618648063 .. 1.5959882046270193]', '[-0.18566626515688304 .. 6.0001133420806659]']
# C || f(I) = ['[0.99998486618648063 .. 1.5959882046270193]', '[-0.18566626515688304 .. 6.0001133420806659]']
#      odes = (1.1?, 5.?)
# ...
# contexts = ['[0.07500000000000001..0.1]']
# statics  = ['[1.111982497622794..1.5959882036662845]', '[0.4389751681489013..2.76416992912444]']
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7f5dae89bdc0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f5d9937b040>
#  ==> creating ContextSignal with coord=(1, 0), signal = Signal([0.0000000000000000 .. 0.20600000000000002], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 0), signal = Signal([0.0000000000000000 .. 0.0040000000000000001], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 0), signal = Signal([0.0000000000000000 .. 0.0020000000000000001], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2*x + 0.8000000000000000?)>, precompose_systems=False, initial_form=<InitialForm.SPLIT_VARS: 3>, order=5, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.00100000000000000, integration_method=<IntegrationMethod.LOW_DEGREE: 2>, cutoff_threshold=0.0000100000000000000, verbosity=0, epsilon_ctx=0.100000000000000, symbolic_composition=True, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7f5dae87dd00>, print_timings=False, unpreconditioning_order=5), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f5dae886790>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7f5dae89bdc0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f5d9930dac0>
#  ==> creating ContextSignal with coord=(1, 1), signal = Signal([0.0000000000000000 .. 0.20600000000000002], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 1), signal = Signal([0.0000000000000000 .. 0.0040000000000000001], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 1), signal = Signal([0.0000000000000000 .. 0.0020000000000000001], [], mask=None), reach_tree = None
# I  = [0.78140624999999985 .. 0.93768749999999990]
# fI = ['[1.1119824976227941 .. 1.5959882036662845]', '[0.43897516814890130 .. 2.7641699291244400]']
# C || f(I) = ['[1.1119824976227941 .. 1.5959882036662845]', '[0.43897516814890130 .. 2.7641699291244400]']
#      odes = (1.1?, 5.?)
# D || odes = (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y)
# phi(D || odes, C || f(I)) = None
# bisecting [0.78140624999999985 .. 0.93768749999999990] -> [0.78140624999999985 .. 0.85954687499999994], [0.85954687499999993 .. 0.93768749999999990]
# phi variables sfs = {y, x}
# system sfs = System(R, (x, y), [[1.1119824976227941 .. 1.5959882036662845], [0.59392837371012685 .. 2.7641699291244400]], (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y), varmap=bidict({'x': x, 'y': y}))
# Generating Reach Tree: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2*x + 0.8000000000000000?)>, precompose_systems=False, initial_form=<InitialForm.SPLIT_VARS: 3>, order=5, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.00100000000000000, integration_method=<IntegrationMethod.LOW_DEGREE: 2>, cutoff_threshold=0.0000100000000000000, verbosity=0, epsilon_ctx=0.100000000000000, symbolic_composition=True, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7f5dae87dd00>, print_timings=False, unpreconditioning_order=5), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f5dae886a60>
# contexts = ['[0.05..0.1]']
# statics  = ['[1.111982497622794..1.5959882036662845]', '[0.5939283737101269..2.76416992912444]']
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7f5dae89bca0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f5db0c8d820>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.20600000000000002], [], mask=None), reach_tree = None
# Monitoring initial signal: 1 items in 0.10 seconds
# (ContextSignal([0.0000000000000000 .. 0.20600000000000002], [[0.050000000000000002 .. 0.10000000000000001], None], [[-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7f5d99367d30>)).to_domain(0.01?)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.0040000000000000001], [], mask=None), reach_tree = None
# (ContextSignal([0.0000000000000000 .. 0.0040000000000000001], [[0.050000000000000002 .. 0.10000000000000001], None], [[-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7f5d99361910>)).to_domain(0.01?)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 0.0020000000000000001], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0,), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2*x + 0.8000000000000000?)>, precompose_systems=False, initial_form=<InitialForm.SPLIT_VARS: 3>, order=5, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.00100000000000000, integration_method=<IntegrationMethod.LOW_DEGREE: 2>, cutoff_threshold=0.0000100000000000000, verbosity=0, epsilon_ctx=0.100000000000000, symbolic_composition=True, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7f5dae87dd00>, print_timings=False, unpreconditioning_order=5), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f5dae886a60>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7f5dae89bca0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f5d9930deb0>
#  ==> creating ContextSignal with coord=(0,), signal = Signal([0.0000000000000000 .. 0.20600000000000002], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0,), signal = Signal([0.0000000000000000 .. 0.0040000000000000001], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0,), signal = Signal([0.0000000000000000 .. 0.0020000000000000001], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2*x + 0.8000000000000000?)>, precompose_systems=False, initial_form=<InitialForm.SPLIT_VARS: 3>, order=5, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.00100000000000000, integration_method=<IntegrationMethod.LOW_DEGREE: 2>, cutoff_threshold=0.0000100000000000000, verbosity=0, epsilon_ctx=0.100000000000000, symbolic_composition=True, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7f5dae87dd00>, print_timings=False, unpreconditioning_order=5), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f5dae886a60>
# contexts = ['[0.05..0.07500000000000001]']
# statics  = ['[1.111982497622794..1.5959882036662845]', '[0.5939283737101269..2.76416992912444]']
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7f5dae89b3a0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f5d9930d430>
#  ==> creating ContextSignal with coord=(0, 0), signal = Signal([0.0000000000000000 .. 0.20600000000000002], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0), signal = Signal([0.0000000000000000 .. 0.0040000000000000001], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0), signal = Signal([0.0000000000000000 .. 0.0020000000000000001], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2*x + 0.8000000000000000?)>, precompose_systems=False, initial_form=<InitialForm.SPLIT_VARS: 3>, order=5, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.00100000000000000, integration_method=<IntegrationMethod.LOW_DEGREE: 2>, cutoff_threshold=0.0000100000000000000, verbosity=0, epsilon_ctx=0.100000000000000, symbolic_composition=True, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7f5dae87dd00>, print_timings=False, unpreconditioning_order=5), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f5dae886a60>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7f5dae89b3a0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f5d9937b190>
#  ==> creating ContextSignal with coord=(0, 1), signal = Signal([0.0000000000000000 .. 0.20600000000000002], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 1), signal = Signal([0.0000000000000000 .. 0.0040000000000000001], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 1), signal = Signal([0.0000000000000000 .. 0.0020000000000000001], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1,), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2*x + 0.8000000000000000?)>, precompose_systems=False, initial_form=<InitialForm.SPLIT_VARS: 3>, order=5, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.00100000000000000, integration_method=<IntegrationMethod.LOW_DEGREE: 2>, cutoff_threshold=0.0000100000000000000, verbosity=0, epsilon_ctx=0.100000000000000, symbolic_composition=True, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7f5dae87dd00>, print_timings=False, unpreconditioning_order=5), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f5dae886a60>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.8000000000000000?, <flowstar.reachability.Reach object at 0x7f5dae89bca0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, symbolic_composition_order=5, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f5d9937b2e0>
#  ==> creating ContextSignal with coord=(1,), signal = Signal([0.0000000000000000 .. 0.20600000000000002], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1,), signal = Signal([0.0000000000000000 .. 0.0040000000000000001], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1,), signal = Signal([0.0000000000000000 .. 0.0020000000000000001], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2*x + 0.8000000000000000?)>, precompose_systems=False, initial_form=<InitialForm.SPLIT_VARS: 3>, order=5, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.00100000000000000, integration_method=<IntegrationMethod.LOW_DEGREE: 2>, cutoff_threshold=0.0000100000000000000, verbosity=0, epsilon_ctx=0.100000000000000, symbolic_composition=True, instrumentor=<flowstar.instrumentation.AggregateMetric object at 0x7f5dae87dd00>, print_timings=False, unpreconditioning_order=5), reach_tree = <lbuc.reach_trees.ReachTree object at 0x7f5dae886a60>
# contexts = ['[0.07500000000000001..0.1]']
# statics  = ['[1.111982497622794..1.5959882036662845]', '[0.5939283737101269..2.76416992912444]']

# %%
graphics_array(
    [
        sig.plot(),
        ctx_sig.signal.plot(),
        ctx_sig.refined_signal(1).plot(),
        ctx_sig.refined_signal(2).plot(),
        refined_csig.refined_signal(2).plot(),
    ],
    ncols=1
)
