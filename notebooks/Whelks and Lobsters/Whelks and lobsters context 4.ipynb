# %% [markdown]
# # Whelks and lobsters -- context operator

# %%
# %display latex
import sys

sys.path.insert(0, "/home/twright/Documents/PhD/Notebooks")

# %% [markdown]
# ## The system

# %%
R.<x,y> = QQ[]

# %%
from lbuc import *

# %%
us = [x,y]
k=RIF(0.8); b=RIF(0.6); c=RIF(0.3); e=RIF(0.05); f=RIF(2)
vf = vector([b*x*(RIF(1)-x) - c*x*(k-x)*y,
            -e*y*(RIF(1)+y)+f*x*(k-x)*y])
v0 = [RIF(0.5), RIF(2.0)]
v1 = [RIF(0.4), RIF(2.5)]
v2 = [RIF(1,1.2), RIF(4,6)]

# %%
v3 = [RIF(1,1.1), RIF(4,5)]

# %%
p = streamline_plot(tuple(vf),(x,0,1.5),(y,0,8), color='grey')\
    + point(v0, size=100, marker='X', color='red')\
    + point(v1, size=100, marker='X', color='green')\
    + polygon([(v2[0].lower(), v2[1].lower()),
               (v2[0].lower(), v2[1].upper()),
               (v2[0].upper(), v2[1].upper()),
               (v2[0].upper(), v2[1].lower())],
              color='orange')\
    + region_plot((lambda x, y: (x - 1)^2 + y^2 - 0.2 < 0),
                  (x, 0, 1.5),
                  (y, 0, 8),
                  incol='pink', plot_points=500, bordercol='red')
p.set_aspect_ratio(1/6)
p.show()
# Out:
# Graphics object consisting of 6 graphics primitives

# %%
P = Atomic((x - 1)^2 + y^2 - 0.2)

# %% [markdown]
# ## Simple signal

# %%
sig = P.signal_for_system(vf, v2, 5, order=5, step=0.01,
                    precondition=1,
                    estimation=1e-3,
                    integrationScheme=2,
                    cutoff_threshold=1e-5)
sig.plot()
# Out:
# Precomposing Contexts: 1 items in 0.00 seconds
# calling reach with y0 = ['[1.0000000000000000 .. 1.2000000000000000]', '[4.0000000000000000 .. 6.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [1.0..1.2]
# C = [4.0..6.0]
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# Running Flow*: 1 items in 5.26 seconds
# Computed 501 flowpipes in 5.264381844000127 sec
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f72669b07d0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=False, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# symbolic_composition=False, tentative_unpreconditioning=True,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 3.56 seconds
# roots = [[0.76763771907959865 .. 3.5700000000000381]]
# domain = [0.0000000000000000 .. 5.0019999999999998]
# roots = [[0.76763771907959865 .. 3.5700000000000381]]
# seg_domain = [0.0000000000000000 .. 5.0019999999999998]
# roots = [[0.76763771907959865 .. 3.5700000000000381]]
# signal given bool roots: 1 items in 0.00 seconds
# Monitoring Signal for x^2 + y^2 - 2.00000000000000*x + 0.800000000000000 > 0: 1 items in 6.38 seconds
# ran "observer.check" 2 times in 0.0004487037658691406
# ran "mask intersect check" 501 times in 0.0005970001220703125
# ran "root amalgamation" 281 times in 0.0004982948303222656
# ran "capturing globals [on exit]" 9 times in 0.0001308917999267578
# ran "check boolean [unguarded]" 2 times in 0.0002899169921875
# ran "tentative eval" 501 times in 0.1308298110961914
# ran "whole domain eval" 282 times in 0.10143542289733887
# ran "prepare in check" 2 times in 1.9073486328125e-05
# ran "root detection" 281 times in 0.22960615158081055
# ran "restoring globals" 9 times in 0.00016641616821289062
# ran "composing flowpipe" 282 times in 3.0623133182525635
# ran "post retrieve" 281 times in 0.003622770309448242
# Graphics object consisting of 2 graphics primitives

# %%
sig = P.signal_for_system(vf, v3, 5, order=5, step=0.01,
                    precondition=1,
                    estimation=1e-3,
                    integrationScheme=2,
                    cutoff_threshold=1e-5,
                    symbolic_composition=True)
sig.plot()
# Out:
# Precomposing Contexts: 1 items in 0.00 seconds
# calling reach with y0 = ['[1.0000000000000000 .. 1.1000000000000001]', '[4.0000000000000000 .. 5.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [1.0..1.1]
# C = [4.0..5.0]
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# Running Flow*: 1 items in 2.99 seconds
# Computed 501 flowpipes in 2.9859455100004197 sec
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f72669b05f0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# symbolic_composition=True, tentative_unpreconditioning=True,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 1.64 seconds
# roots = [[1.6679767143790411 .. 1.6700000000000015], [1.6741848470338664 .. 2.3200000000000092]]
# domain = [0.0000000000000000 .. 5.0019999999999998]
# roots = [[1.6679767143790411 .. 1.6700000000000015],
#  [1.6741848470338664 .. 2.3200000000000092]]
# seg_domain = [0.0000000000000000 .. 5.0019999999999998]
# roots = [[1.6679767143790411 .. 1.6700000000000015],
#  [1.6741848470338664 .. 2.3200000000000092]]
# signal given bool roots: 1 items in 0.00 seconds
# Monitoring Signal for x^2 + y^2 - 2.00000000000000*x + 0.800000000000000 > 0: 1 items in 1.67 seconds
# ran "observer.check" 3 times in 0.0005037784576416016
# ran "mask intersect check" 501 times in 0.0006530284881591797
# ran "root amalgamation" 121 times in 0.00019407272338867188
# ran "capturing globals [on exit]" 9 times in 0.00021767616271972656
# ran "check boolean [unguarded]" 3 times in 0.0002930164337158203
# ran "tentative eval" 501 times in 0.1287555694580078
# ran "whole domain eval" 121 times in 0.03319072723388672
# ran "prepare in check" 3 times in 2.7179718017578125e-05
# ran "root detection" 121 times in 0.005828380584716797
# ran "restoring globals" 9 times in 0.00030422210693359375
# ran "composing flowpipe" 122 times in 0.47449493408203125
# ran "post retrieve" 121 times in 0.9690399169921875
# Graphics object consisting of 2 graphics primitives

# %%
csig = P.context_signal_for_system(vf, v3, 5, order=5, step=0.01,
                    precondition=1,
                    estimation=1e-3,
                    integrationScheme=2,
                    cutoff_threshold=1e-5,
                    symbolic_composition=True)
# Out:
# ==> calling context signal
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integrationScheme=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7266953fd0>
# calling reach with y0 = ['[1.0000000000000000 .. 1.1000000000000001]', '[4.0000000000000000 .. 5.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [1.0..1.1]
# C = [4.0..5.0]
# contexts = ['[1.0..1.1]', '[4.0..5.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725c418aa0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f72668ab2b0>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 1.55 seconds
# roots = [[1.4699999999999657 .. 1.4800000000000014], [1.6679767143790409 .. 1.6700000000000015], [1.6741848470338660 .. 2.3200000000000092]]
# domain = [0.0000000000000000 .. 5.0019999999999998]
# roots = [[1.4699999999999657 .. 1.4800000000000014],
#  [1.6679767143790409 .. 1.6700000000000015],
#  [1.6741848470338660 .. 2.3200000000000092]]
# seg_domain = [0.0000000000000000 .. 5.0019999999999998]
# roots = [[1.4699999999999657 .. 1.4800000000000014],
#  [1.6679767143790409 .. 1.6700000000000015],
#  [1.6741848470338660 .. 2.3200000000000092]]
# signal given bool roots: 1 items in 0.00 seconds
# Monitoring initial signal: 1 items in 4.44 seconds
# ==> calling to_domain
# (ContextSignal([0 .. 5], [[1.0000000000000000 .. 1.1000000000000001], [4 .. 5]], [[-1 .. 1], [-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7f72667d30d0>)).to_domain(1.?e1)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [([0.0000000000000000 .. 1.4699999999999658], True), ([1.4800000000000013 .. 1.6679767143790410], True), ([1.6700000000000014 .. 1.6741848470338661], True), ([2.3200000000000091 .. 5.0000000000000000], False)], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7266953fd0>
# recomputing reachset
# setting reach level to 0

# %%
csig.refined_signal(0).plot()
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
csig.refined_signal(1).plot()
# Out:
#  ==> creating ContextSignal with coord=(0,), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integrationScheme=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = None
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7266949e90>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.74 seconds
# roots = [[2.0296093990124828 .. 2.0300000000000025], [2.0329094479094740 .. 2.3137968369855391]]
# domain = [0.0000000000000000 .. 5.0019999999999998]
# roots = [[2.0296093990124828 .. 2.0300000000000025],
#  [2.0329094479094740 .. 2.3137968369855391]]
# seg_domain = [0.0000000000000000 .. 5.0019999999999998]
# roots = [[2.0296093990124828 .. 2.0300000000000025],
#  [2.0329094479094740 .. 2.3137968369855391]]
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(0,), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [([0.0000000000000000 .. 2.0296093990124829], True), ([2.0300000000000024 .. 2.0329094479094741], True), ([2.3137968369855390 .. 5.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1,), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integrationScheme=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = None
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7269bfe050>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.75 seconds
# roots = [[1.9695039445505302 .. 1.9700000000000018], [1.9728211041216112 .. 2.2699967755237332]]
# domain = [0.0000000000000000 .. 5.0019999999999998]
# roots = [[1.9695039445505302 .. 1.9700000000000018],
#  [1.9728211041216112 .. 2.2699967755237332]]
# seg_domain = [0.0000000000000000 .. 5.0019999999999998]
# roots = [[1.9695039445505302 .. 1.9700000000000018],
#  [1.9728211041216112 .. 2.2699967755237332]]
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(1,), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [([0.0000000000000000 .. 1.9695039445505303], True), ([1.9700000000000017 .. 1.9728211041216113], True), ([2.2699967755237331 .. 5.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(2,), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integrationScheme=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = None
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7269bfe180>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.64 seconds
# roots = [[1.7358878560574648 .. 2.1459548275888541]]
# domain = [0.0000000000000000 .. 5.0019999999999998]
# roots = [[1.7358878560574648 .. 2.1459548275888541]]
# seg_domain = [0.0000000000000000 .. 5.0019999999999998]
# roots = [[1.7358878560574648 .. 2.1459548275888541]]
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(2,), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [([0.0000000000000000 .. 1.7358878560574649], True), ([2.1459548275888540 .. 5.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3,), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integrationScheme=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = None
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7266961c30>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.64 seconds
# roots = [[1.7059822298286706 .. 2.1285870732462820]]
# domain = [0.0000000000000000 .. 5.0019999999999998]
# roots = [[1.7059822298286706 .. 2.1285870732462820]]
# seg_domain = [0.0000000000000000 .. 5.0019999999999998]
# roots = [[1.7059822298286706 .. 2.1285870732462820]]
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(3,), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [([0.0000000000000000 .. 1.
>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.17 seconds
# roots = [[1.8180950675480889 .. 1.8934216071692889]]
# domain = [0.0000000000000000 .. 5.0019999999999998]
# roots = [[1.8180950675480889 .. 1.8934216071692889]]
# seg_domain = [0.0000000000000000 .. 5.0019999999999998]
# roots = [[1.8180950675480889 .. 1.8934216071692889]]
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(3, 3, 2, 2), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [([0.0000000000000000 .. 1.8180950675480890], True), ([1.8934216071692888 .. 5.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 2, 3), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integrationScheme=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = None
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725bfd7180>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.17 seconds
# roots = [[1.8137624534080578 .. 1.8900000000000017]]
# domain = [0.0000000000000000 .. 5.0019999999999998]
# roots = [[1.8137624534080578 .. 1.8900000000000017]]
# seg_domain = [0.0000000000000000 .. 5.0019999999999998]
# roots = [[1.8137624534080578 .. 1.8900000000000017]]
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(3, 3, 2, 3), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [([0.0000000000000000 .. 1.8137624534080579], True), ([1.8900000000000016 .. 5.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 3, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integrationScheme=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = None
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725c1a92b0>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.17 seconds
# roots = [[1.8329664742108551 .. 1.9031243530499003]]
# domain = [0.0000000000000000 .. 5.0019999999999998]
# roots = [[1.8329664742108551 .. 1.9031243530499003]]
# seg_domain = [0.0000000000000000 .. 5.0019999999999998]
# roots = [[1.8329664742108551 .. 1.9031243530499003]]
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(3, 3, 3, 0), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [([0.0000000000000000 .. 1.8329664742108552], True), ([1.9031243530499002 .. 5.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 3, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integrationScheme=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = None
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725bfd73e0>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.17 seconds
# roots = [[1.8273930707539292 .. 1.9000000000000017]]
# domain = [0.0000000000000000 .. 5.0019999999999998]
# roots = [[1.8273930707539292 .. 1.9000000000000017]]
# seg_domain = [0.0000000000000000 .. 5.0019999999999998]
# roots = [[1.8273930707539292 .. 1.9000000000000017]]
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(3, 3, 3, 1), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [([0.0000000000000000 .. 1.8273930707539293], True), ([1.9000000000000016 .. 5.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 3, 2), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integrationScheme=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = None
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725bfd79d0>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.17 seconds
# roots = [[1.8081851020427606 .. 1.8873268143589792]]
# domain = [0.0000000000000000 .. 5.0019999999999998]
# roots = [[1.8081851020427606 .. 1.8873268143589792]]
# seg_domain = [0.0000000000000000 .. 5.0019999999999998]
# roots = [[1.8081851020427606 .. 1.8873268143589792]]
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(3, 3, 3, 2), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [([0.0000000000000000 .. 1.8081851020427607], True), ([1.8873268143589791 .. 5.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 3, 3), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integrationScheme=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = None
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725bfd72b0>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.17 seconds
# roots = [[1.8036554705584364 .. 1.8833881632124126]]
# domain = [0.0000000000000000 .. 5.0019999999999998]
# roots = [[1.8036554705584364 .. 1.8833881632124126]]
# seg_domain = [0.0000000000000000 .. 5.0019999999999998]
# roots = [[1.8036554705584364 .. 1.8833881632124126]]
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(3, 3, 3, 3), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [([0.0000000000000000 .. 1.8036554705584365], True), ([1.8833881632124125 .. 5.0000000000000000], False)], mask=None), reach_tree = None
# Graphics object consisting of 2 graphics primitives

# %%
dir(csig)
# Out:
# ['F',
#  'G',
#  'U',
#  '__and__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_children',
#  '_context_embedding',
#  '_coordinate',
#  '_dimension',
#  '_domain',
#  '_reach_level',
#  '_reach_tree',
#  '_restriction_method',
#  '_signal',
#  '_top_level_domain',
#  'physical_coordinate',
#  'physical_space_domain',
#  'children',
#  'coordinate',
#  'dimension',
#  'domain',
#  'histogram2d',
#  'plot_histogram2d',
#  'reach_level',
#  'refined_signal',
#  'restriction_method',
#  'signal',
#  'signal_map',
#  'signal_zip_with',
#  'symbolic_coordinate',
#  'symbolic_space_domain',
#  'to_domain',
#  'to_mask_and',
#  'to_mask_or',
#  'top_level_domain']

# %%
help(csig.plot_histogram2d)
# Out:
# Help on method plot_histogram2d in module lbuc.context_signals:
#
# plot_histogram2d(n: int) method of lbuc.context_signals.ContextSignal instance

# %%
csig.plot_histogram2d(2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
csig.G(2).plot_histogram2d(4)
# Out:
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.32000000000000916 .. 3.0000000000000000], False)], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7266953fd0>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0,), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.029609399012482829], True), ([0.030000000000002469 .. 0.032909447909474033], True), ([0.31379683698553906 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1,), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.26999677552373313 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(2,), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.14595482758885403 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3,), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.12858707324628193 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.16458674241775607], True), ([0.31239943983805273 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 1), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.14638442242253991], True), ([0.29000000000000847 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 2), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.039999999999940084], True), ([0.050000000000002930 .. 0.057591355179436033], True), ([0.19459408060578331 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 3), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.042839382635678103], True), ([0.17271674604749209 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 0), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.23515159778713102], True), ([0.31095738682535323 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 1), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.22558348682106733], True), ([0.30000000000000870 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 2), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.17754288771981131], True), ([0.25074847980081127 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 3), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.16838949745316079], True), ([0.24001099929224523 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 0, 0), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.27154681485240540], True), ([0.31000000000000893 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 0, 1), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.26659008099519488], True), ([0.30497071594305991 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 0, 2), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.24195796047331797], True), ([0.28000000000000824 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 0, 3), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.23701942047765102], True), ([0.27472840395638442 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 1, 0), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.26162065807447821], True), ([0.29989989846994857 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 1, 1), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.25635945477047440], True), ([0.29390955828667841 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 1, 2), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.23221205927796263], True), ([0.26976124394534473 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 1, 3), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.22699748097703588], True), ([0.26388612099196206 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 2, 0), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.21288801553039428], True), ([0.25000000000000754 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 2, 1), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.20798799897927945], True), ([0.24505273734809485 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 2, 2), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.18438422613254036], True), ([0.22058446163702738 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 2, 3), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.
 3, 3), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.023237559924711882], True), ([0.056468177225156512 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 3, 0), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.057424948553375544], True), ([0.13000000000000477 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 3, 1), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.044057360217683695], True), ([0.12000000000000454 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 3, 2), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.0083757084699529472], True), ([0.078777328806443946 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 3, 3), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.069167256847709523 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 3, 0, 0), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.092338307300419143], True), ([0.12905289899343186 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 3, 0, 1), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.085911375864348827], True), ([0.12307004677935973 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 3, 0, 2), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.066633237198575391], True), ([0.10210086582075827 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 3, 0, 3), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.060467241202769806], True), ([0.097033787268571369 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 3, 1, 0), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.079150305811653610], True), ([0.11780672175499429 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 3, 1, 1), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.072884752846088308], True), ([0.11169409223979220 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 3, 1, 2), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.054208857599937322], True), ([0.091152291489935866 .. 0.16999999999993154], False), ([0.18000000000000593 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 3, 1, 3), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.047557128222817103], True), ([0.085980497498147290 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 3, 2, 0), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.041759307841318539], True), ([0.076601801230579358 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 3, 2, 1), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.035691945880469867], True), ([0.070959489314319057 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 3, 2, 2), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.017283436498702898], True), ([0.051072705408067520 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 3, 2, 3), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.011528159042211162], True), ([0.046319880011836733 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 3, 3, 0), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.029245329814660437], True), ([0.065991318192600179 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 3, 3, 1), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.023308785968773727], True), ([0.060224873674098233 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 3, 3, 2), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.0055465060573474113], True), ([0.040789720192051515 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 3, 3, 3), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.035942300859737041 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(2, 0), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.10000000000000408 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(2, 1), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.080000000000003623 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(2, 2), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.043092111250855325 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(2, 3), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.025638786987441264 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(2, 0, 0), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.014102075199348363], True), ([0.088312115612869668 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(2, 0, 1), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.0067468692034990952], True), ([0.079433557526837006 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(2, 0, 2), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.046793712705130996 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(2, 0, 3), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.038540773425804975 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(2, 0, 0, 0), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.048451605080053195], True), ([0.083748381073574407 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(2, 0, 0, 1), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.045006244163884102], True), ([0.079928577512242249 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(2, 0, 0, 2), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.020967096774262118], True), ([0.060000000000003161 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(2, 0, 0, 3), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.017266778737981881], True), ([0.056258805656945298 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(2, 0, 1, 0), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.041038039907180135], True), ([0.075231645644524558 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(2, 0, 1, 1), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.036882466275550919], True), ([0.070444880877553739 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(2, 0, 1, 2), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.013755704671536418], True), ([0.051704058029266697 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(2, 0, 1, 3), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.0095372905995581015], True), ([0.047817509265420277 .. 3.0000000000000000], False)], mask=None), reach_tree = None
# ...
#  ==> creating ContextSignal with coord=(3, 0, 1), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.042124303665334927 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 0, 2), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.011420494337397890 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 0, 3), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0042455172962023723 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 0, 0, 0), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.014589905421515060], True), ([0.047264025369772699 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 0, 0, 1), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.0089977929458675555], True), ([0.042290808495132115 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 0, 0, 2), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.024748426659704225 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 0, 0, 3), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.020000000000002238 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 0, 1, 0), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.0038805444634659736], True), ([0.037947601832415855 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 0, 1, 1), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.032803592575461060 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 0, 1, 2), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.015857196147893937 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 0, 1, 3), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.010898950977363153 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 0, 2, 0), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0030213240815295527 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 0, 2, 1), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 0, 2, 2), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 0, 2, 3), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 0, 3, 0), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 0, 3, 1), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 0, 3, 2), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 0.039999999999940084], False), ([0.050000000000002930 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 0, 3, 3), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 1, 0), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.033577304023263199 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 1, 1), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.024908836123546773 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 1, 2), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 1, 3), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 1, 0, 0), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.028335460715563254 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 1, 0, 1), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.023046181520624209 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 1, 0, 2), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0066864574519502895 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 1, 0, 3), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0015858307276053196 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 1, 1, 0), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.018479570551316548 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 1, 1, 1), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.013071256959975574 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 1, 1, 2), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 1, 1, 3), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 1, 2, 0), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 1, 2, 1), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 1, 2, 2), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 1, 2, 3), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 1, 3, 0), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 1, 3, 1), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 1, 3, 2), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 1, 3, 3), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 2, 0), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 2, 1), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 2, 2), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 2, 3), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 2, 0, 0), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 2, 0, 1), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 2, 0, 2), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 2, 0, 3), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 2, 1, 0), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 2, 1, 1), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 2, 1, 2), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 2, 1, 3), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 2, 2, 0), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 2, 2, 1), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 2, 2, 2), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 2, 2, 3), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 2, 3, 0), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 2, 3, 1), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 2, 3, 2), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 2, 3, 3), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 0), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 1), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 2), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 3), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 0, 0), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 0, 1), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 0, 2), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 0, 3), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 1, 0), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 1, 1), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 1, 2), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 1, 3), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 2, 0), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 2, 1), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 2, 2), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 2, 3), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 3, 0), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 3, 1), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 3, 2), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 3, 3), signal = Signal([0.0000000000000000 .. 3.0000000000000000], [([0.0000000000000000 .. 3.0000000000000000], False)], mask=None), reach_tree = None
# Graphics object consisting of 1 graphics primitive

# %%
csig.refined_signal(4)(2)
# Out:
# False

# %% [markdown]
# # Around the attractor

# %%
B = [RIF(0, 1.5), RIF(0, 8)]

# %%
P
# Out:
# Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)

# %%
prop = F(RIF(0, 10), P)

# %%
csig = prop.context_signal_for_system(vf,
    B, 5, order=5, step=0.01,
    precondition=1,
    estimation=1e-3,
    integration_method=2,
    cutoff_threshold=1e-5,
    symbolic_composition=True)
# Out:
# ==> calling context signal
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[0.0000000000000000 .. 1.5000000000000000]', '[0.0000000000000000 .. 8.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.0..1.5]
# C = [0.0..8.0]
# contexts = ['[0.0..1.5]', '[0.0..8.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b773e60>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b4a38a0>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 15.002000000000001], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
# Monitoring initial signal: 1 items in 0.02 seconds
# ==> calling to_domain
# (ContextSignal([0 .. 5], [[0.0000000000000000 .. 1.5000000000000000], [0 .. 8]], [[-1 .. 1], [-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7f725b38d290>)).to_domain(1.?e1)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0

# %%
csig.signal.plot()
# Out:
# /usr/lib64/python3.7/site-packages/sage/plot/contour_plot.py:205: UserWarning: No contour levels were found within the data range.
#   linewidths=linewidths, linestyles=linestyles)
# Graphics object consisting of 2 graphics primitives

# %%
csig.refined_signal(3).plot()
# Out:
#  ==> creating ContextSignal with coord=(0,), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b773e60>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b2913e0>
#  ==> creating ContextSignal with coord=(0,), signal = Signal([0.0000000000000000 .. 15.002000000000001], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[0.0000000000000000 .. 0.75000000000000000]', '[0.0000000000000000 .. 4.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.0..0.75]
# C = [0.0..4.0]
# contexts = ['[0.0..0.75]', '[0.0..4.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0,), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b3875f0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b5a3770>
#  ==> creating ContextSignal with coord=(0, 0), signal = Signal([0.0000000000000000 .. 15.002000000000001], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[0.0000000000000000 .. 0.37500000000000000]', '[0.0000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.0..0.375]
# C = [0.0..2.0]
# contexts = ['[0.0..0.375]', '[0.0..2.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 0), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 0, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b3879b0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b2918a0>
#  ==> creating ContextSignal with coord=(0, 0, 0), signal = Signal([0.0000000000000000 .. 15.002000000000001], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[0.0000000000000000 .. 0.18750000000000000]', '[0.0000000000000000 .. 1.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.0..0.1875]
# C = [0.0..1.0]
# contexts = ['[0.0..0.1875]', '[0.0..1.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 0, 0), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 0, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b3879b0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b291510>
#  ==> creating ContextSignal with coord=(0, 0, 1), signal = Signal([0.0000000000000000 .. 15.002000000000001], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[0.0000000000000000 .. 0.18750000000000000]', '[1.0000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.0..0.1875]
# C = [1.0..2.0]
# contexts = ['[0.0..0.1875]', '[1.0..2.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 0, 1), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 0, 2), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b3879b0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b291050>
#  ==> creating ContextSignal with coord=(0, 0, 2), signal = Signal([0.0000000000000000 .. 15.002000000000001], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[0.18750000000000000 .. 0.37500000000000000]', '[0.0000000000000000 .. 1.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.1875..0.375]
# C = [0.0..1.0]
# contexts = ['[0.1875..0.375]', '[0.0..1.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 0, 2), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 0, 3), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b3879b0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b291c30>
#  ==> creating ContextSignal with coord=(0, 0, 3), signal = Signal([0.0000000000000000 .. 15.002000000000001], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[0.18750000000000000 .. 0.37500000000000000]', '[1.0000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.1875..0.375]
# C = [1.0..2.0]
# contexts = ['[0.1875..0.375]', '[1.0..2.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 0, 3), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b3875f0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b5a38a0>
#  ==> creating ContextSignal with coord=(0, 1), signal = Signal([0.0000000000000000 .. 15.002000000000001], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[0.0000000000000000 .. 0.37500000000000000]', '[2.0000000000000000 .. 4.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.0..0.375]
# C = [2.0..4.0]
# contexts = ['[0.0..0.375]', '[2.0..4.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 1), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 1, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b387c80>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b2912b0>
#  ==> creating ContextSignal with coord=(0, 1, 0), signal = Signal([0.0000000000000000 .. 15.002000000000001], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[0.0000000000000000 .. 0.18750000000000000]', '[2.0000000000000000 .. 3.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.0..0.1875]
# C = [2.0..3.0]
# contexts = ['[0.0..0.1875]', '[2.0..3.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 1, 0), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 1, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b387c80>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b291e90>
#  ==> creating ContextSignal with coord=(0, 1, 1), signal = Signal([0.0000000000000000 .. 15.002000000000001], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[0.0000000000000000 .. 0.18750000000000000]', '[3.0000000000000000 .. 4.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.0..0.1875]
# C = [3.0..4.0]
# contexts = ['[0.0..0.1875]', '[3.0..4.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 1, 1), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 1, 2), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b387c80>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b291d60>
#  ==> creating ContextSignal with coord=(0, 1, 2), signal = Signal([0.0000000000000000 .. 15.002000000000001], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[0.18750000000000000 .. 0.37500000000000000]', '[2.0000000000000000 .. 3.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.1875..0.375]
# C = [2.0..3.0]
# contexts = ['[0.1875..0.375]', '[2.0..3.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 1, 2), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 1, 3), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b387c80>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725c0aac30>
#  ==> creating ContextSignal with coord=(0, 1, 3), signal = Signal([0.0000000000000000 .. 15.002000000000001], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[0.18750000000000000 .. 0.37500000000000000]', '[3.0000000000000000 .. 4.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.1875..0.375]
# C = [3.0..4.0]
# contexts = ['[0.1875..0.375]', '[3.0..4.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 1, 3), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 2), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b3875f0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b5a3770>
#  ==> creating ContextSignal with coord=(0, 2), signal = Signal([0.0000000000000000 .. 15.002000000000001], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[0.37500000000000000 .. 0.75000000000000000]', '[0.0000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.375..0.75]
# C = [0.0..2.0]
# contexts = ['[0.375..0.75]', '[0.0..2.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 2), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 2, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b299b90>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b2919d0>
#  ==> creating ContextSignal with coord=(0, 2, 0), signal = Signal([0.0000000000000000 .. 15.002000000000001], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[0.37500000000000000 .. 0.56250000000000000]', '[0.0000000000000000 .. 1.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.375..0.5625]
# C = [0.0..1.0]
# contexts = ['[0.375..0.5625]', '[0.0..1.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 2, 0), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 2, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b299b90>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b291180>
#  ==> creating ContextSignal with coord=(0, 2, 1), signal = Signal([0.0000000000000000 .. 15.002000000000001], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[0.37500000000000000 .. 0.56250000000000000]', '[1.0000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.375..0.5625]
# C = [1.0..2.0]
# contexts = ['[0.375..0.5625]', '[1.0..2.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 2, 1), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 2, 2), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b299b90>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b291b00>
#  ==> creating ContextSignal with coord=(0, 2, 2), signal = Signal([0.0000000000000000 .. 15.002000000000001], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[0.56250000000000000 .. 0.75000000000000000]', '[0.0000000000000000 .. 1.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.5625..0.75]
# C = [0.0..1.0]
# contexts = ['[0.5625..0.75]', '[0.0..1.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 2, 2), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 2, 3), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b299b90>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b291640>
#  ==> creating ContextSignal with coord=(0, 2, 3), signal = Signal([0.0000000000000000 .. 15.002000000000001], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[0.56250000000000000 .. 0.75000000000000000]', '[1.0000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.5625..0.75]
# C = [1.0..2.0]
# contexts = ['[0.5625..0.75]', '[1.0..2.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 2, 3), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 3), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b3875f0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b5a38a0>
#  ==> creating ContextSignal with coord=(0, 3), signal = Signal([0.0000000000000000 .. 15.002000000000001], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[0.37500000000000000 .. 0.75000000000000000]', '[2.0000000000000000 .. 4.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.375..0.75]
# C = [2.0..4.0]
# contexts = ['[0.375..0.75]', '[2.0..4.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 3), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 3, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b2bf8c0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b2a4050>
#  ==> creating ContextSignal with coord=(0, 3, 0), signal = Signal([0.0000000000000000 .. 15.002000000000001], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[0.37500000000000000 .. 0.56250000000000000]', '[2.0000000000000000 .. 3.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.375..0.5625]
# C = [2.0..3.0]
# contexts = ['[0.375..0.5625]', '[2.0..3.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 3, 0), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 3, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b2bf8c0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b2a43e0>
#  ==> creating ContextSignal with coord=(0, 3, 1), signal = Signal([0.0000000000000000 .. 15.002000000000001], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[0.37500000000000000 .. 0.56250000000000000]', '[3.0000000000000000 .. 4.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.375..0.5625]
# C = [3.0..4.0]
# contexts = ['[0.375..0.5625]', '[3.0..4.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 3, 1), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 3, 2), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b2bf8c0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b2a4d60>
#  ==> creating ContextSignal with coord=(0, 3, 2), signal = Signal([0.0000000000000000 .. 15.002000000000001], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[0.56250000000000000 .. 0.75000000000000000]', '[2.0000000000000000 .. 3.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.5625..0.75]
# C = [2.0..3.0]
# contexts = ['[0.5625..0.75]', '[2.0..3.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 3, 2), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 3, 3), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b2bf8c0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b2a4b00>
#  ==> creating ContextSignal with coord=(0, 3, 3), signal = Signal([0.0000000000000000 .. 15.002000000000001], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[0.56250000000000000 .. 0.75000000000000000]', '[3.0000000000000000 .. 4.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.5625..0.75]
# C = [3.0..4.0]
# contexts = ['[0.5625..0.75]', '[3.0..4.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 3, 3), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(1,), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b773e60>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b5a38a0>
#  ==> creating ContextSignal with coord=(1,), signal = Signal([0.0000000000000000 .. 15.002000000000001], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[0.0000000000000000 .. 0.75000000000000000]', '[4.0000000000000000 .. 8.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.0..0.75]
# C = [4.0..8.0]
# contexts = ['[0.0..0.75]', '[4.0..8.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(1,), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
# ...
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b1c5c30>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 2.21 seconds
# roots = [[0.35999999999999815 .. 1.8500000000000017]]
# domain = [0.0000000000000000 .. 15.002000000000001]
# roots = [[0.35999999999999815 .. 1.8500000000000017]]
# seg_domain = [0.0000000000000000 .. 15.002000000000001]
# roots = [[0.35999999999999815 .. 1.8500000000000017]]
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(3, 2, 2), signal = Signal([0.0000000000000000 .. 15.002000000000001], [([0.0000000000000000 .. 0.35999999999999816], True), ([1.8500000000000016 .. 5.0020000000000007], False)], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[1.3125000000000000 .. 1.5000000000000000]', '[4.0000000000000000 .. 5.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [1.3125..1.5]
# C = [4.0..5.0]
# contexts = ['[1.3125..1.5]', '[4.0..5.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(3, 2, 2), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [([0.0000000000000000 .. 0.35999999999999816], True), ([1.8500000000000016 .. 5.0000000000000000], False)], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(3, 2, 3), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b1c8d70>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b1c5d60>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 2.23 seconds
# roots = [[0.35999999999999815 .. 1.8500000000000017]]
# domain = [0.0000000000000000 .. 15.002000000000001]
# roots = [[0.35999999999999815 .. 1.8500000000000017]]
# seg_domain = [0.0000000000000000 .. 15.002000000000001]
# roots = [[0.35999999999999815 .. 1.8500000000000017]]
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(3, 2, 3), signal = Signal([0.0000000000000000 .. 15.002000000000001], [([0.0000000000000000 .. 0.35999999999999816], True), ([1.8500000000000016 .. 5.0020000000000007], False)], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[1.3125000000000000 .. 1.5000000000000000]', '[5.0000000000000000 .. 6.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [1.3125..1.5]
# C = [5.0..6.0]
# contexts = ['[1.3125..1.5]', '[5.0..6.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(3, 2, 3), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [([0.0000000000000000 .. 0.35999999999999816], True), ([1.8500000000000016 .. 5.0000000000000000], False)], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(3, 3), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b231230>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b1c5050>
#  ==> creating ContextSignal with coord=(3, 3), signal = Signal([0.0000000000000000 .. 15.002000000000001], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[1.1250000000000000 .. 1.5000000000000000]', '[6.0000000000000000 .. 8.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [1.125..1.5]
# C = [6.0..8.0]
# contexts = ['[1.125..1.5]', '[6.0..8.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(3, 3), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(3, 3, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b1d76e0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b1c5e90>
#  ==> creating ContextSignal with coord=(3, 3, 0), signal = Signal([0.0000000000000000 .. 15.002000000000001], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[1.1250000000000000 .. 1.3125000000000000]', '[6.0000000000000000 .. 7.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [1.125..1.3125]
# C = [6.0..7.0]
# contexts = ['[1.125..1.3125]', '[6.0..7.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(3, 3, 0), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(3, 3, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b1d76e0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b1c5180>
#  ==> creating ContextSignal with coord=(3, 3, 1), signal = Signal([0.0000000000000000 .. 15.002000000000001], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[1.1250000000000000 .. 1.3125000000000000]', '[7.0000000000000000 .. 8.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [1.125..1.3125]
# C = [7.0..8.0]
# contexts = ['[1.125..1.3125]', '[7.0..8.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(3, 3, 1), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(3, 3, 2), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b1d76e0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b1d6510>
#  ==> creating ContextSignal with coord=(3, 3, 2), signal = Signal([0.0000000000000000 .. 15.002000000000001], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[1.3125000000000000 .. 1.5000000000000000]', '[6.0000000000000000 .. 7.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [1.3125..1.5]
# C = [6.0..7.0]
# contexts = ['[1.3125..1.5]', '[6.0..7.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(3, 3, 2), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(3, 3, 3), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b1d76e0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b1c5b00>
#  ==> creating ContextSignal with coord=(3, 3, 3), signal = Signal([0.0000000000000000 .. 15.002000000000001], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[1.3125000000000000 .. 1.5000000000000000]', '[7.0000000000000000 .. 8.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [1.3125..1.5]
# C = [7.0..8.0]
# contexts = ['[1.3125..1.5]', '[7.0..8.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(3, 3, 3), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
# /usr/lib64/python3.7/site-packages/sage/plot/contour_plot.py:205: UserWarning: No contour levels were found within the data range.
#   linewidths=linewidths, linestyles=linestyles)
# Graphics object consisting of 2 graphics primitives

# %%
csig.plot_histogram2d(3)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
csig.plot_histogram2d(4)
# Out:
#  ==> creating ContextSignal with coord=(0, 0, 0, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b3878c0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b05b510>
#  ==> creating ContextSignal with coord=(0, 0, 0, 0), signal = Signal([0.0000000000000000 .. 15.002000000000001], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[0.0000000000000000 .. 0.093750000000000000]', '[0.0000000000000000 .. 0.50000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.0..0.09375]
# C = [0.0..0.5]
# contexts = ['[0.0..0.09375]', '[0.0..0.5]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 0, 0, 0), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 0, 0, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b3878c0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b05b8a0>
#  ==> creating ContextSignal with coord=(0, 0, 0, 1), signal = Signal([0.0000000000000000 .. 15.002000000000001], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[0.0000000000000000 .. 0.093750000000000000]', '[0.50000000000000000 .. 1.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.0..0.09375]
# C = [0.5..1.0]
# contexts = ['[0.0..0.09375]', '[0.5..1.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 0, 0, 1), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 0, 0, 2), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b3878c0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b05b9d0>
#  ==> creating ContextSignal with coord=(0, 0, 0, 2), signal = Signal([0.0000000000000000 .. 15.002000000000001], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[0.093750000000000000 .. 0.18750000000000000]', '[0.0000000000000000 .. 0.50000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.09375..0.1875]
# C = [0.0..0.5]
# contexts = ['[0.09375..0.1875]', '[0.0..0.5]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 0, 0, 2), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 0, 0, 3), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b3878c0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b05bb00>
#  ==> creating ContextSignal with coord=(0, 0, 0, 3), signal = Signal([0.0000000000000000 .. 15.002000000000001], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[0.093750000000000000 .. 0.18750000000000000]', '[0.50000000000000000 .. 1.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.09375..0.1875]
# C = [0.5..1.0]
# contexts = ['[0.09375..0.1875]', '[0.5..1.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 0, 0, 3), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 0, 1, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b387d70>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b05be90>
#  ==> creating ContextSignal with coord=(0, 0, 1, 0), signal = Signal([0.0000000000000000 .. 15.002000000000001], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[0.0000000000000000 .. 0.093750000000000000]', '[1.0000000000000000 .. 1.5000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.0..0.09375]
# C = [1.0..1.5]
# contexts = ['[0.0..0.09375]', '[1.0..1.5]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 0, 1, 0), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 0, 1, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b387d70>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b05b3e0>
#  ==> creating ContextSignal with coord=(0, 0, 1, 1), signal = Signal([0.0000000000000000 .. 15.002000000000001], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[0.0000000000000000 .. 0.093750000000000000]', '[1.5000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.0..0.09375]
# C = [1.5..2.0]
# contexts = ['[0.0..0.09375]', '[1.5..2.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 0, 1, 1), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 0, 1, 2), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b387d70>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b136d60>
#  ==> creating ContextSignal with coord=(0, 0, 1, 2), signal = Signal([0.0000000000000000 .. 15.002000000000001], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[0.093750000000000000 .. 0.18750000000000000]', '[1.0000000000000000 .. 1.5000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.09375..0.1875]
# C = [1.0..1.5]
# contexts = ['[0.09375..0.1875]', '[1.0..1.5]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 0, 1, 2), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 0, 1, 3), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b387d70>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b5a38a0>
#  ==> creating ContextSignal with coord=(0, 0, 1, 3), signal = Signal([0.0000000000000000 .. 15.002000000000001], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[0.093750000000000000 .. 0.18750000000000000]', '[1.5000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.09375..0.1875]
# C = [1.5..2.0]
# contexts = ['[0.09375..0.1875]', '[1.5..2.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 0, 1, 3), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 0, 2, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b387050>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b05b050>
#  ==> creating ContextSignal with coord=(0, 0, 2, 0), signal = Signal([0.0000000000000000 .. 15.002000000000001], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[0.18750000000000000 .. 0.28125000000000000]', '[0.0000000000000000 .. 0.50000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.1875..0.28125]
# C = [0.0..0.5]
# contexts = ['[0.1875..0.28125]', '[0.0..0.5]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 0, 2, 0), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 0, 2, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b387050>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b05bc30>
#  ==> creating ContextSignal with coord=(0, 0, 2, 1), signal = Signal([0.0000000000000000 .. 15.002000000000001], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[0.18750000000000000 .. 0.28125000000000000]', '[0.50000000000000000 .. 1.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.1875..0.28125]
# C = [0.5..1.0]
# contexts = ['[0.1875..0.28125]', '[0.5..1.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 0, 2, 1), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 0, 2, 2), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b387050>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b05bd60>
#  ==> creating ContextSignal with coord=(0, 0, 2, 2), signal = Signal([0.0000000000000000 .. 15.002000000000001], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[0.28125000000000000 .. 0.37500000000000000]', '[0.0000000000000000 .. 0.50000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.28125..0.375]
# C = [0.0..0.5]
# contexts = ['[0.28125..0.375]', '[0.0..0.5]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 0, 2, 2), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 0, 2, 3), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b387050>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b4a38a0>
#  ==> creating ContextSignal with coord=(0, 0, 2, 3), signal = Signal([0.0000000000000000 .. 15.002000000000001], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[0.28125000000000000 .. 0.37500000000000000]', '[0.50000000000000000 .. 1.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.28125..0.375]
# C = [0.5..1.0]
# contexts = ['[0.28125..0.375]', '[0.5..1.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 0, 2, 3), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 0, 3, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b387aa0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b2918a0>
#  ==> creating ContextSignal with coord=(0, 0, 3, 0), signal = Signal([0.0000000000000000 .. 15.002000000000001], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[0.18750000000000000 .. 0.28125000000000000]', '[1.0000000000000000 .. 1.5000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.1875..0.28125]
# C = [1.0..1.5]
# contexts = ['[0.1875..0.28125]', '[1.0..1.5]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 0, 3, 0), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 0, 3, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b387aa0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b291050>
#  ==> creating ContextSignal with coord=(0, 0, 3, 1), signal = Signal([0.0000000000000000 .. 15.002000000000001], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[0.18750000000000000 .. 0.28125000000000000]', '[1.5000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.1875..0.28125]
# C = [1.5..2.0]
# contexts = ['[0.1875..0.28125]', '[1.5..2.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 0, 3, 1), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 0, 3, 2), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b387aa0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b006640>
#  ==> creating ContextSignal with coord=(0, 0, 3, 2), signal = Signal([0.0000000000000000 .. 15.002000000000001], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[0.28125000000000000 .. 0.37500000000000000]', '[1.0000000000000000 .. 1.5000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.28125..0.375]
# C = [1.0..1.5]
# contexts = ['[0.28125..0.375]', '[1.0..1.5]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 0, 3, 2), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 0, 3, 3), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b387aa0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b006050>
#  ==> creating ContextSignal with coord=(0, 0, 3, 3), signal = Signal([0.0000000000000000 .. 15.002000000000001], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[0.28125000000000000 .. 0.37500000000000000]', '[1.5000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.28125..0.375]
# C = [1.5..2.0]
# contexts = ['[0.28125..0.375]', '[1.5..2.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 0, 3, 3), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 1, 0, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b2997d0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b05b770>
#  ==> creating ContextSignal with coord=(0, 1, 0, 0), signal = Signal([0.0000000000000000 .. 15.002000000000001], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[0.0000000000000000 .. 0.093750000000000000]', '[2.0000000000000000 .. 2.5000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.0..0.09375]
# C = [2.0..2.5]
# contexts = ['[0.0..0.09375]', '[2.0..2.5]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 1, 0, 0), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 1, 0, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b2997d0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b291510>
#  ==> creating ContextSignal with coord=(0, 1, 0, 1), signal = Signal([0.0000000000000000 .. 15.002000000000001], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[0.0000000000000000 .. 0.093750000000000000]', '[2.5000000000000000 .. 3.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.0..0.09375]
# C = [2.5..3.0]
# contexts = ['[0.0..0.09375]', '[2.5..3.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 1, 0, 1), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 1, 0, 2), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b2997d0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b0062b0>
#  ==> creating ContextSignal with coord=(0, 1, 0, 2), signal = Signal([0.0000000000000000 .. 15.002000000000001], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[0.093750000000000000 .. 0.18750000000000000]', '[2.0000000000000000 .. 2.5000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.09375..0.1875]
# C = [2.0..2.5]
# contexts = ['[0.09375..0.1875]', '[2.0..2.5]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 1, 0, 2), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 1, 0, 3), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b2997d0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b0069d0>
#  ==> creating ContextSignal with coord=(0, 1, 0, 3), signal = Signal([0.0000000000000000 .. 15.002000000000001], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[0.093750000000000000 .. 0.18750000000000000]', '[2.5000000000000000 .. 3.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.09375..0.1875]
# C = [2.5..3.0]
# contexts = ['[0.09375..0.1875]', '[2.5..3.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 1, 0, 3), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 1, 1, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b2995f0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b291c30>
#  ==> creating ContextSignal with coord=(0, 1, 1, 0), signal = Signal([0.0000000000000000 .. 15.002000000000001], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[0.0000000000000000 .. 0.093750000000000000]', '[3.0000000000000000 .. 3.5000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.0..0.09375]
# C = [3.0..3.5]
# contexts = ['[0.0..0.09375]', '[3.0..3.5]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 1, 1, 0), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 1, 1, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b2995f0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b006e90>
#  ==> creating ContextSignal with coord=(0, 1, 1, 1), signal = Signal([0.0000000000000000 .. 15.002000000000001], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[0.0000000000000000 .. 0.093750000000000000]', '[3.5000000000000000 .. 4.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.0..0.09375]
# C = [3.5..4.0]
# contexts = ['[0.0..0.09375]', '[3.5..4.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
# ...
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b142770>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.32 seconds
# roots = [[1.3135875416926114 .. 1.4645472258812631]]
# domain = [0.0000000000000000 .. 15.002000000000001]
# roots = [[1.3135875416926114 .. 1.4645472258812631]]
# seg_domain = [0.0000000000000000 .. 15.002000000000001]
# roots = [[1.3135875416926114 .. 1.4645472258812631]]
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(3, 3, 2, 2), signal = Signal([0.0000000000000000 .. 15.002000000000001], [([0.0000000000000000 .. 1.3135875416926115], True), ([1.4645472258812630 .. 5.0020000000000007], False)], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[1.4062500000000000 .. 1.5000000000000000]', '[6.0000000000000000 .. 6.5000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [1.40625..1.5]
# C = [6.0..6.5]
# contexts = ['[1.40625..1.5]', '[6.0..6.5]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(3, 3, 2, 2), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [([0.0000000000000000 .. 1.3135875416926115], True), ([1.4645472258812630 .. 5.0000000000000000], False)], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(3, 3, 2, 3), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b1d7d70>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b1423e0>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.33 seconds
# roots = [[1.3135875416926114 .. 1.4645472258812631]]
# domain = [0.0000000000000000 .. 15.002000000000001]
# roots = [[1.3135875416926114 .. 1.4645472258812631]]
# seg_domain = [0.0000000000000000 .. 15.002000000000001]
# roots = [[1.3135875416926114 .. 1.4645472258812631]]
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(3, 3, 2, 3), signal = Signal([0.0000000000000000 .. 15.002000000000001], [([0.0000000000000000 .. 1.3135875416926115], True), ([1.4645472258812630 .. 5.0020000000000007], False)], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[1.4062500000000000 .. 1.5000000000000000]', '[6.5000000000000000 .. 7.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [1.40625..1.5]
# C = [6.5..7.0]
# contexts = ['[1.40625..1.5]', '[6.5..7.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(3, 3, 2, 3), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [([0.0000000000000000 .. 1.3135875416926115], True), ([1.4645472258812630 .. 5.0000000000000000], False)], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(3, 3, 3, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b1d7e60>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b1c5180>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.34 seconds
# roots = [[1.3769644306491293 .. 1.4876505452186662]]
# domain = [0.0000000000000000 .. 15.002000000000001]
# roots = [[1.3769644306491293 .. 1.4876505452186662]]
# seg_domain = [0.0000000000000000 .. 15.002000000000001]
# roots = [[1.3769644306491293 .. 1.4876505452186662]]
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(3, 3, 3, 0), signal = Signal([0.0000000000000000 .. 15.002000000000001], [([0.0000000000000000 .. 1.3769644306491294], True), ([1.4876505452186661 .. 5.0020000000000007], False)], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[1.3125000000000000 .. 1.4062500000000000]', '[7.0000000000000000 .. 7.5000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [1.3125..1.40625]
# C = [7.0..7.5]
# contexts = ['[1.3125..1.40625]', '[7.0..7.5]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(3, 3, 3, 0), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [([0.0000000000000000 .. 1.3769644306491294], True), ([1.4876505452186661 .. 5.0000000000000000], False)], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(3, 3, 3, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b1d7e60>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b142b00>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.25 seconds
# roots = [[1.3769644306491293 .. 1.4876505452186662]]
# domain = [0.0000000000000000 .. 15.002000000000001]
# roots = [[1.3769644306491293 .. 1.4876505452186662]]
# seg_domain = [0.0000000000000000 .. 15.002000000000001]
# roots = [[1.3769644306491293 .. 1.4876505452186662]]
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(3, 3, 3, 1), signal = Signal([0.0000000000000000 .. 15.002000000000001], [([0.0000000000000000 .. 1.3769644306491294], True), ([1.4876505452186661 .. 5.0020000000000007], False)], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[1.3125000000000000 .. 1.4062500000000000]', '[7.5000000000000000 .. 8.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [1.3125..1.40625]
# C = [7.5..8.0]
# contexts = ['[1.3125..1.40625]', '[7.5..8.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(3, 3, 3, 1), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [([0.0000000000000000 .. 1.3769644306491294], True), ([1.4876505452186661 .. 5.0000000000000000], False)], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(3, 3, 3, 2), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b1d7e60>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b1422b0>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.25 seconds
# roots = [[1.3769644306491293 .. 1.4876505452186662]]
# domain = [0.0000000000000000 .. 15.002000000000001]
# roots = [[1.3769644306491293 .. 1.4876505452186662]]
# seg_domain = [0.0000000000000000 .. 15.002000000000001]
# roots = [[1.3769644306491293 .. 1.4876505452186662]]
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(3, 3, 3, 2), signal = Signal([0.0000000000000000 .. 15.002000000000001], [([0.0000000000000000 .. 1.3769644306491294], True), ([1.4876505452186661 .. 5.0020000000000007], False)], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[1.4062500000000000 .. 1.5000000000000000]', '[7.0000000000000000 .. 7.5000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [1.40625..1.5]
# C = [7.0..7.5]
# contexts = ['[1.40625..1.5]', '[7.0..7.5]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(3, 3, 3, 2), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [([0.0000000000000000 .. 1.3769644306491294], True), ([1.4876505452186661 .. 5.0000000000000000], False)], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(3, 3, 3, 3), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725b1d7e60>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b142e90>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.25 seconds
# roots = [[1.3769644306491293 .. 1.4876505452186662]]
# domain = [0.0000000000000000 .. 15.002000000000001]
# roots = [[1.3769644306491293 .. 1.4876505452186662]]
# seg_domain = [0.0000000000000000 .. 15.002000000000001]
# roots = [[1.3769644306491293 .. 1.4876505452186662]]
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(3, 3, 3, 3), signal = Signal([0.0000000000000000 .. 15.002000000000001], [([0.0000000000000000 .. 1.3769644306491294], True), ([1.4876505452186661 .. 5.0020000000000007], False)], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# calling reach with y0 = ['[1.4062500000000000 .. 1.5000000000000000]', '[7.5000000000000000 .. 8.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [1.40625..1.5]
# C = [7.5..8.0]
# contexts = ['[1.40625..1.5]', '[7.5..8.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(3, 3, 3, 3), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [([0.0000000000000000 .. 1.3769644306491294], True), ([1.4876505452186661 .. 5.0000000000000000], False)], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725b388690>
# recomputing reachset
# setting reach level to 0
# Graphics object consisting of 1 graphics primitive

# %%
prop = F(RIF(0, 5), P)

# %%
csig = prop.context_signal_for_system(vf,
    B, 0, order=5, step=0.01,
    precondition=1,
    estimation=1e-3,
    integration_method=2,
    cutoff_threshold=1e-5,
    symbolic_composition=True)
# Out:
# ==> calling context signal
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# calling reach with y0 = ['[0.0000000000000000 .. 1.5000000000000000]', '[0.0000000000000000 .. 8.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.0..1.5]
# C = [0.0..8.0]
# contexts = ['[0.0..1.5]', '[0.0..8.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725af6e5f0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b1c5b00>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 5.0020000000000007], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# setting reach level to 0
# Monitoring initial signal: 1 items in 0.03 seconds
# ==> calling to_domain
# (ContextSignal(0, [[0.0000000000000000 .. 1.5000000000000000], [0 .. 8]], [[-1 .. 1], [-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7f725af16a90>)).to_domain(0)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# setting reach level to 0

# %%
csig.plot_histogram2d(3)
# Out:
#  ==> creating ContextSignal with coord=(0,), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725af6e5f0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b13a3e0>
#  ==> creating ContextSignal with coord=(0,), signal = Signal([0.0000000000000000 .. 5.0020000000000007], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# calling reach with y0 = ['[0.0000000000000000 .. 0.75000000000000000]', '[0.0000000000000000 .. 4.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.0..0.75]
# C = [0.0..4.0]
# contexts = ['[0.0..0.75]', '[0.0..4.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(1,), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725af6e5f0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b05b180>
#  ==> creating ContextSignal with coord=(1,), signal = Signal([0.0000000000000000 .. 5.0020000000000007], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# calling reach with y0 = ['[0.0000000000000000 .. 0.75000000000000000]', '[4.0000000000000000 .. 8.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.0..0.75]
# C = [4.0..8.0]
# contexts = ['[0.0..0.75]', '[4.0..8.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(1,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(2,), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725af6e5f0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b13a050>
#  ==> creating ContextSignal with coord=(2,), signal = Signal([0.0000000000000000 .. 5.0020000000000007], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# calling reach with y0 = ['[0.75000000000000000 .. 1.5000000000000000]', '[0.0000000000000000 .. 4.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.75..1.5]
# C = [0.0..4.0]
# contexts = ['[0.75..1.5]', '[0.0..4.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(2,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(3,), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725af6e5f0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725af07b00>
#  ==> creating ContextSignal with coord=(3,), signal = Signal([0.0000000000000000 .. 5.0020000000000007], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# calling reach with y0 = ['[0.75000000000000000 .. 1.5000000000000000]', '[4.0000000000000000 .. 8.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.75..1.5]
# C = [4.0..8.0]
# contexts = ['[0.75..1.5]', '[4.0..8.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(3,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725af1c140>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725af07510>
#  ==> creating ContextSignal with coord=(0, 0), signal = Signal([0.0000000000000000 .. 5.0020000000000007], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# calling reach with y0 = ['[0.0000000000000000 .. 0.37500000000000000]', '[0.0000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.0..0.375]
# C = [0.0..2.0]
# contexts = ['[0.0..0.375]', '[0.0..2.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 0), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725af1c140>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b1d6510>
#  ==> creating ContextSignal with coord=(0, 1), signal = Signal([0.0000000000000000 .. 5.0020000000000007], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# calling reach with y0 = ['[0.0000000000000000 .. 0.37500000000000000]', '[2.0000000000000000 .. 4.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.0..0.375]
# C = [2.0..4.0]
# contexts = ['[0.0..0.375]', '[2.0..4.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 2), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725af1c140>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725af15770>
#  ==> creating ContextSignal with coord=(0, 2), signal = Signal([0.0000000000000000 .. 5.0020000000000007], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# calling reach with y0 = ['[0.37500000000000000 .. 0.75000000000000000]', '[0.0000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.375..0.75]
# C = [0.0..2.0]
# contexts = ['[0.375..0.75]', '[0.0..2.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 2), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 3), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725af1c140>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725af158a0>
#  ==> creating ContextSignal with coord=(0, 3), signal = Signal([0.0000000000000000 .. 5.0020000000000007], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# calling reach with y0 = ['[0.37500000000000000 .. 0.75000000000000000]', '[2.0000000000000000 .. 4.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.375..0.75]
# C = [2.0..4.0]
# contexts = ['[0.375..0.75]', '[2.0..4.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 3), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 0, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725af1ce60>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725af15510>
#  ==> creating ContextSignal with coord=(0, 0, 0), signal = Signal([0.0000000000000000 .. 5.0020000000000007], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# calling reach with y0 = ['[0.0000000000000000 .. 0.18750000000000000]', '[0.0000000000000000 .. 1.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.0..0.1875]
# C = [0.0..1.0]
# contexts = ['[0.0..0.1875]', '[0.0..1.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 0, 0), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 0, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725af1ce60>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725af153e0>
#  ==> creating ContextSignal with coord=(0, 0, 1), signal = Signal([0.0000000000000000 .. 5.0020000000000007], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# calling reach with y0 = ['[0.0000000000000000 .. 0.18750000000000000]', '[1.0000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.0..0.1875]
# C = [1.0..2.0]
# contexts = ['[0.0..0.1875]', '[1.0..2.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 0, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 0, 2), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725af1ce60>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725af15c30>
#  ==> creating ContextSignal with coord=(0, 0, 2), signal = Signal([0.0000000000000000 .. 5.0020000000000007], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# calling reach with y0 = ['[0.18750000000000000 .. 0.37500000000000000]', '[0.0000000000000000 .. 1.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.1875..0.375]
# C = [0.0..1.0]
# contexts = ['[0.1875..0.375]', '[0.0..1.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 0, 2), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 0, 3), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725af1ce60>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725af07770>
#  ==> creating ContextSignal with coord=(0, 0, 3), signal = Signal([0.0000000000000000 .. 5.0020000000000007], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# calling reach with y0 = ['[0.18750000000000000 .. 0.37500000000000000]', '[1.0000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.1875..0.375]
# C = [1.0..2.0]
# contexts = ['[0.1875..0.375]', '[1.0..2.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 0, 3), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 1, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725af1c500>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725af07180>
#  ==> creating ContextSignal with coord=(0, 1, 0), signal = Signal([0.0000000000000000 .. 5.0020000000000007], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# calling reach with y0 = ['[0.0000000000000000 .. 0.18750000000000000]', '[2.0000000000000000 .. 3.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.0..0.1875]
# C = [2.0..3.0]
# contexts = ['[0.0..0.1875]', '[2.0..3.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 1, 0), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 1, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725af1c500>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725af152b0>
#  ==> creating ContextSignal with coord=(0, 1, 1), signal = Signal([0.0000000000000000 .. 5.0020000000000007], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# calling reach with y0 = ['[0.0000000000000000 .. 0.18750000000000000]', '[3.0000000000000000 .. 4.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.0..0.1875]
# C = [3.0..4.0]
# contexts = ['[0.0..0.1875]', '[3.0..4.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 1, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 1, 2), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725af1c500>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725af159d0>
#  ==> creating ContextSignal with coord=(0, 1, 2), signal = Signal([0.0000000000000000 .. 5.0020000000000007], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# calling reach with y0 = ['[0.18750000000000000 .. 0.37500000000000000]', '[2.0000000000000000 .. 3.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.1875..0.375]
# C = [2.0..3.0]
# contexts = ['[0.1875..0.375]', '[2.0..3.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 1, 2), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 1, 3), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725af1c500>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725af15640>
#  ==> creating ContextSignal with coord=(0, 1, 3), signal = Signal([0.0000000000000000 .. 5.0020000000000007], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# calling reach with y0 = ['[0.18750000000000000 .. 0.37500000000000000]', '[3.0000000000000000 .. 4.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.1875..0.375]
# C = [3.0..4.0]
# contexts = ['[0.1875..0.375]', '[3.0..4.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 1, 3), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 2, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725af6eb90>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b13a3e0>
#  ==> creating ContextSignal with coord=(0, 2, 0), signal = Signal([0.0000000000000000 .. 5.0020000000000007], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# calling reach with y0 = ['[0.37500000000000000 .. 0.56250000000000000]', '[0.0000000000000000 .. 1.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.375..0.5625]
# C = [0.0..1.0]
# contexts = ['[0.375..0.5625]', '[0.0..1.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 2, 0), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 2, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725af6eb90>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725af15d60>
#  ==> creating ContextSignal with coord=(0, 2, 1), signal = Signal([0.0000000000000000 .. 5.0020000000000007], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# calling reach with y0 = ['[0.37500000000000000 .. 0.56250000000000000]', '[1.0000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.375..0.5625]
# C = [1.0..2.0]
# contexts = ['[0.375..0.5625]', '[1.0..2.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 2, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 2, 2), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725af6eb90>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725b1c5b00>
#  ==> creating ContextSignal with coord=(0, 2, 2), signal = Signal([0.0000000000000000 .. 5.0020000000000007], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# calling reach with y0 = ['[0.56250000000000000 .. 0.75000000000000000]', '[0.0000000000000000 .. 1.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.5625..0.75]
# C = [0.0..1.0]
# contexts = ['[0.5625..0.75]', '[0.0..1.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 2, 2), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 2, 3), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725af6eb90>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725af15050>
#  ==> creating ContextSignal with coord=(0, 2, 3), signal = Signal([0.0000000000000000 .. 5.0020000000000007], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# calling reach with y0 = ['[0.56250000000000000 .. 0.75000000000000000]', '[1.0000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.5625..0.75]
# C = [1.0..2.0]
# contexts = ['[0.5625..0.75]', '[1.0..2.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 2, 3), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 3, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725af1c6e0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725af15b00>
#  ==> creating ContextSignal with coord=(0, 3, 0), signal = Signal([0.0000000000000000 .. 5.0020000000000007], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# calling reach with y0 = ['[0.37500000000000000 .. 0.56250000000000000]', '[2.0000000000000000 .. 3.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.375..0.5625]
# C = [2.0..3.0]
# contexts = ['[0.375..0.5625]', '[2.0..3.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 3, 0), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 3, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725af1c6e0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725af40180>
#  ==> creating ContextSignal with coord=(0, 3, 1), signal = Signal([0.0000000000000000 .. 5.0020000000000007], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# calling reach with y0 = ['[0.37500000000000000 .. 0.56250000000000000]', '[3.0000000000000000 .. 4.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.375..0.5625]
# C = [3.0..4.0]
# contexts = ['[0.375..0.5625]', '[3.0..4.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(0, 3, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# setting reach level to 0
# ...
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725aebad60>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 2.15 seconds
# roots = [[0.35999999999999815 .. 1.8500000000000017]]
# domain = [0.0000000000000000 .. 5.0020000000000007]
# roots = [[0.35999999999999815 .. 1.8500000000000017]]
# seg_domain = [0.0000000000000000 .. 5.0020000000000007]
# roots = [[0.35999999999999815 .. 1.8500000000000017]]
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(3, 2, 1), signal = Signal([0.0000000000000000 .. 5.0020000000000007], [([0.0000000000000000 .. 0.35999999999999816], True)], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# calling reach with y0 = ['[1.1250000000000000 .. 1.3125000000000000]', '[5.0000000000000000 .. 6.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [1.125..1.3125]
# C = [5.0..6.0]
# contexts = ['[1.125..1.3125]', '[5.0..6.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(3, 2, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [([0.0000000000000000 .. -0.0000000000000000], True)], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(3, 2, 2), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725aeae8c0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725aeba3e0>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 2.16 seconds
# roots = [[0.35999999999999815 .. 1.8500000000000017]]
# domain = [0.0000000000000000 .. 5.0020000000000007]
# roots = [[0.35999999999999815 .. 1.8500000000000017]]
# seg_domain = [0.0000000000000000 .. 5.0020000000000007]
# roots = [[0.35999999999999815 .. 1.8500000000000017]]
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(3, 2, 2), signal = Signal([0.0000000000000000 .. 5.0020000000000007], [([0.0000000000000000 .. 0.35999999999999816], True)], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# calling reach with y0 = ['[1.3125000000000000 .. 1.5000000000000000]', '[4.0000000000000000 .. 5.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [1.3125..1.5]
# C = [4.0..5.0]
# contexts = ['[1.3125..1.5]', '[4.0..5.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(3, 2, 2), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [([0.0000000000000000 .. -0.0000000000000000], True)], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(3, 2, 3), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725aeae8c0>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725aebae90>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 2.11 seconds
# roots = [[0.35999999999999815 .. 1.8500000000000017]]
# domain = [0.0000000000000000 .. 5.0020000000000007]
# roots = [[0.35999999999999815 .. 1.8500000000000017]]
# seg_domain = [0.0000000000000000 .. 5.0020000000000007]
# roots = [[0.35999999999999815 .. 1.8500000000000017]]
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(3, 2, 3), signal = Signal([0.0000000000000000 .. 5.0020000000000007], [([0.0000000000000000 .. 0.35999999999999816], True)], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# calling reach with y0 = ['[1.3125000000000000 .. 1.5000000000000000]', '[5.0000000000000000 .. 6.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [1.3125..1.5]
# C = [5.0..6.0]
# contexts = ['[1.3125..1.5]', '[5.0..6.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(3, 2, 3), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [([0.0000000000000000 .. -0.0000000000000000], True)], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(3, 3, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725aeaeb90>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725aefc050>
#  ==> creating ContextSignal with coord=(3, 3, 0), signal = Signal([0.0000000000000000 .. 5.0020000000000007], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# calling reach with y0 = ['[1.1250000000000000 .. 1.3125000000000000]', '[6.0000000000000000 .. 7.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [1.125..1.3125]
# C = [6.0..7.0]
# contexts = ['[1.125..1.3125]', '[6.0..7.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(3, 3, 0), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(3, 3, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725aeaeb90>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725aeba8a0>
#  ==> creating ContextSignal with coord=(3, 3, 1), signal = Signal([0.0000000000000000 .. 5.0020000000000007], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# calling reach with y0 = ['[1.1250000000000000 .. 1.3125000000000000]', '[7.0000000000000000 .. 8.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [1.125..1.3125]
# C = [7.0..8.0]
# contexts = ['[1.125..1.3125]', '[7.0..8.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(3, 3, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(3, 3, 2), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725aeaeb90>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725aebac30>
#  ==> creating ContextSignal with coord=(3, 3, 2), signal = Signal([0.0000000000000000 .. 5.0020000000000007], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# calling reach with y0 = ['[1.3125000000000000 .. 1.5000000000000000]', '[6.0000000000000000 .. 7.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [1.3125..1.5]
# C = [6.0..7.0]
# contexts = ['[1.3125..1.5]', '[6.0..7.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(3, 3, 2), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(3, 3, 3), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integration_method=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f725aeaeb90>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725aeba2b0>
#  ==> creating ContextSignal with coord=(3, 3, 3), signal = Signal([0.0000000000000000 .. 5.0020000000000007], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# calling reach with y0 = ['[1.3125000000000000 .. 1.5000000000000000]', '[7.0000000000000000 .. 8.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [1.3125..1.5]
# C = [7.0..8.0]
# contexts = ['[1.3125..1.5]', '[7.0..8.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# setting reach level to 0
#  ==> creating ContextSignal with coord=(3, 3, 3), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725af17690>
# recomputing reachset
# setting reach level to 0
# Graphics object consisting of 1 graphics primitive

# %%
#csig.plot_histogram2d(5)

# %% [markdown]
# # Multiple sets

# %%
def plot_box(B, **kwargs):
    if 'color' not in kwargs:
        kwargs['color'] = 'orange'
    return polygon(
        [(B[0].lower(), B[1].lower()),
         (B[0].lower(), B[1].upper()),
         (B[0].upper(), B[1].upper()),
         (B[0].upper(), B[1].lower())],
        **kwargs,
    )

# %%
v4 = [RIF(0.2, 0.4), RIF(7, 8)]
v5 = [RIF(0.4, 1.0), RIF(6, 7)]
v6 = [RIF(0.2, 0.6), RIF(2, 3)]

# %%
p = streamline_plot(tuple(vf),(x,0,1.5),(y,0,8), color='grey')\
    + plot_box(v2)\
    + plot_box(v4, color='cyan')\
    + plot_box(v5, color='yellow')\
    + plot_box(v6, color='magenta')\
    + region_plot((lambda x, y: (x - 1)^2 + y^2 - 0.2 < 0),
                  (x, 0, 1.5),
                  (y, 0, 8),
                  incol='pink', plot_points=500, bordercol='red')
p.set_aspect_ratio(1/6)
p.show()
# Out:
# Graphics object consisting of 7 graphics primitives

# %%
def plot_reach(B, duration=10, poly=None, **kwargs):
    global p
    kwargs_ = dict(
        order=5, step=(0.01, 0.5),
        precondition=1,
        estimation=1e-3,
        integrationScheme=2,
        cutoff_threshold=1e-7,
        symbolic_composition=True,
    )
    kwargs_.update(kwargs)
    reach = Reach(vf, B, duration, **kwargs_)
    return p + reach.sage_interval_plot(
        'x', 'y',
        poly=poly,
        aspect_ratio='automatic')

# %%
plot_reach(v2, poly=(x - 1)^2 + y^2 - 0.2)
# Out:
# ode in polynomial ring
# crude_roots = False
# vars = None
# _handle_initials called!
# vars = [x, y]
# C = [1.0..1.2]
# C = [4.0..6.0]
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# var_id_x = 0
# var_id_y = 1
# PolyObserver(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000, <flowstar.reachability.Reach object at 0x7f725a40e6e0>, None, symbolic_composition=True, tentative_unpreconditioning=False, mask=None)
# Graphics object consisting of 107 graphics primitives

# %%
Qbox = [RIF(0, 0.3), RIF(1.75, 3.5)]

# %%
Qplt = plot_reach(v4, duration=25, step=(0.01, 0.5), order=6, estimation=1e-5, cutoff_threshold=1e-10) + plot_box(Qbox)
Qplt.show(aspect_ratio=1/8)
# Out:
# ode in polynomial ring
# crude_roots = False
# vars = None
# _handle_initials called!
# vars = [x, y]
# C = [0.2..0.4]
# C = [7.0..8.0]
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# var_id_x = 0
# var_id_y = 1
# Graphics object consisting of 258 graphics primitives

# %%
plot_reach(v4, duration=40, step=(0.01, 0.5), order=8, estimation=1e-5, cutoff_threshold=1e-10)
# Out:
# ode in polynomial ring
# crude_roots = False
# vars = None
# _handle_initials called!
# vars = [x, y]
# C = [0.2..0.4]
# C = [7.0..8.0]
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# var_id_x = 0
# var_id_y = 1
# Graphics object consisting of 407 graphics primitives

# %%
plot_reach(v5)
# Out:
# ode in polynomial ring
# crude_roots = False
# vars = None
# _handle_initials called!
# vars = [x, y]
# C = [0.4..1.0]
# C = [6.0..7.0]
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# var_id_x = 0
# var_id_y = 1
# warning: eval failed for t in [0.2, 0.3]
# warning: eval failed for t in [0.30000000000000004, 0.4000000000000001]
# warning: eval failed for t in [0.4, 0.5000000000000001]
# warning: eval failed for t in [0.5000000000000001, 0.6000000000000002]
# warning: eval failed for t in [0.6000000000000001, 0.7000000000000002]
# warning: eval failed for t in [0.7000000000000001, 0.8000000000000002]
# warning: eval failed for t in [0.8, 0.9000000000000001]
# warning: eval failed for t in [0.9000000000000001, 1.0000000000000002]
# warning: eval failed for t in [1.0000000000000002, 1.1000000000000003]
# warning: eval failed for t in [1.1, 1.2000000000000002]
# warning: eval failed for t in [1.2000000000000002, 1.3000000000000003]
# warning: eval failed for t in [1.3000000000000003, 1.4000000000000004]
# warning: eval failed for t in [1.4000000000000001, 1.5000000000000002]
# warning: eval failed for t in [1.5000000000000002, 1.6000000000000003]
# warning: eval failed for t in [1.6, 1.7000000000000002]
# warning: eval failed for t in [1.7000000000000002, 1.8000000000000003]
# warning: eval failed for t in [1.8000000000000003, 1.9000000000000004]
# warning: eval failed for t in [1.9000000000000001, 2.0000000000000004]
# warning: eval failed for t in [2.0000000000000004, 2.1000000000000005]
# warning: eval failed for t in [2.1000000000000005, 2.2000000000000006]
# warning: eval failed for t in [2.2, 2.3000000000000003]
# warning: eval failed for t in [2.3000000000000003, 2.4000000000000004]
# warning: eval failed for t in [2.4000000000000004, 2.5000000000000004]
# warning: eval failed for t in [2.5000000000000004, 2.6000000000000005]
# warning: eval failed for t in [2.6000000000000005, 2.7000000000000006]
# warning: eval failed for t in [2.7, 2.8000000000000003]
# warning: eval failed for t in [2.8000000000000003, 2.9000000000000004]
# warning: eval failed for t in [2.9000000000000004, 3.0000000000000004]
# warning: eval failed for t in [3.0000000000000004, 3.1000000000000005]
# warning: eval failed for t in [3.1000000000000005, 3.2000000000000006]
# warning: eval failed for t in [3.2, 3.3000000000000003]
# warning: eval failed for t in [3.3000000000000003, 3.4000000000000004]
# warning: eval failed for t in [3.4000000000000004, 3.5000000000000004]
# warning: eval failed for t in [3.5000000000000004, 3.6000000000000005]
# warning: eval failed for t in [3.6000000000000005, 3.7000000000000006]
# warning: eval failed for t in [3.7000000000000006, 3.8000000000000007]
# warning: eval failed for t in [3.8000000000000003, 3.9000000000000004]
# warning: eval failed for t in [3.9000000000000004, 4.000000000000001]
# warning: eval failed for t in [4.000000000000001, 4.100000000000001]
# warning: eval failed for t in [4.1000000000000005, 4.200000000000001]
# warning: eval failed for t in [4.200000000000001, 4.300000000000002]
# warning: eval failed for t in [4.300000000000001, 4.400000000000001]
# warning: eval failed for t in [4.4, 4.500000000000001]
# warning: eval failed for t in [4.500000000000001, 4.600000000000001]
# warning: eval failed for t in [4.6000000000000005, 4.700000000000001]
# warning: eval failed for t in [4.700000000000001, 4.800000000000002]
# warning: eval failed for t in [4.800000000000001, 4.900000000000001]
# warning: eval failed for t in [4.9, 5.000000000000001]
# warning: eval failed for t in [5.000000000000001, 5.100000000000001]
# warning: eval failed for t in [5.1000000000000005, 5.200000000000001]
# warning: eval failed for t in [5.200000000000001, 5.300000000000002]
# warning: eval failed for t in [5.300000000000001, 5.400000000000001]
# warning: eval failed for t in [5.4, 5.500000000000001]
# warning: eval failed for t in [5.500000000000001, 5.600000000000001]
# warning: eval failed for t in [5.6000000000000005, 5.700000000000001]
# warning: eval failed for t in [5.700000000000001, 5.800000000000002]
# warning: eval failed for t in [5.800000000000001, 5.900000000000001]
# warning: eval failed for t in [5.9, 6.000000000000001]
# warning: eval failed for t in [6.000000000000001, 6.100000000000001]
# warning: eval failed for t in [6.1000000000000005, 6.200000000000001]
# warning: eval failed for t in [6.200000000000001, 6.300000000000002]
# warning: eval failed for t in [6.300000000000001, 6.400000000000001]
# warning: eval failed for t in [6.4, 6.500000000000001]
# warning: eval failed for t in [6.500000000000001, 6.600000000000001]
# warning: eval failed for t in [6.6000000000000005, 6.700000000000001]
# warning: eval failed for t in [6.700000000000001, 6.800000000000002]
# warning: eval failed for t in [6.800000000000001, 6.900000000000001]
# warning: eval failed for t in [6.900000000000001, 7.000000000000002]
# warning: eval failed for t in [7.000000000000001, 7.100000000000001]
# warning: eval failed for t in [7.1000000000000005, 7.200000000000001]
# warning: eval failed for t in [7.200000000000001, 7.300000000000002]
# warning: eval failed for t in [7.300000000000001, 7.400000000000001]
# warning: eval failed for t in [7.400000000000001, 7.500000000000002]
# warning: eval failed for t in [7.500000000000001, 7.600000000000001]
# warning: eval failed for t in [7.6000000000000005, 7.700000000000001]
# warning: eval failed for t in [7.700000000000001, 7.800000000000002]
# warning: eval failed for t in [7.800000000000001, 7.900000000000001]
# warning: eval failed for t in [7.900000000000001, 8.000000000000002]
# warning: eval failed for t in [8.000000000000002, 8.100000000000003]
# warning: eval failed for t in [8.100000000000001, 8.200000000000003]
# warning: eval failed for t in [8.200000000000001, 8.300000000000002]
# warning: eval failed for t in [8.3, 8.400000000000002]
# warning: eval failed for t in [8.400000000000002, 8.500000000000004]
# warning: eval failed for t in [8.500000000000002, 8.600000000000003]
# warning: eval failed for t in [8.600000000000001, 8.700000000000003]
# warning: eval failed for t in [8.700000000000001, 8.800000000000002]
# warning: eval failed for t in [8.8, 8.900000000000002]
# warning: eval failed for t in [8.900000000000002, 9.000000000000004]
# warning: eval failed for t in [9.000000000000002, 9.100000000000003]
# warning: eval failed for t in [9.100000000000001, 9.200000000000003]
# warning: eval failed for t in [9.200000000000001, 9.300000000000002]
# warning: eval failed for t in [9.3, 9.400000000000002]
# warning: eval failed for t in [9.400000000000002, 9.500000000000004]
# warning: eval failed for t in [9.500000000000002, 9.600000000000003]
# warning: eval failed for t in [9.600000000000001, 9.700000000000003]
# warning: eval failed for t in [9.700000000000001, 9.800000000000002]
# warning: eval failed for t in [9.8, 9.900000000000002]
# warning: eval failed for t in [9.900000000000002, 10.000000000000004]
# Graphics object consisting of 107 graphics primitives

# %%
plot_reach(v6)
# Out:
# ode in polynomial ring
# crude_roots = False
# vars = None
# _handle_initials called!
# vars = [x, y]
# C = [0.2..0.6]
# C = [2.0..3.0]
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# var_id_x = 0
# var_id_y = 1
# warning: eval failed for t in [1.9, 1.9999999999999998]
# warning: eval failed for t in [2.0000000000000004, 2.1000000000000005]
# warning: eval failed for t in [2.1000000000000005, 2.2000000000000006]
# warning: eval failed for t in [2.2, 2.3000000000000003]
# warning: eval failed for t in [2.3000000000000003, 2.4000000000000004]
# warning: eval failed for t in [2.4000000000000004, 2.5000000000000004]
# warning: eval failed for t in [2.5000000000000004, 2.6000000000000005]
# warning: eval failed for t in [2.6000000000000005, 2.7000000000000006]
# warning: eval failed for t in [2.7, 2.8000000000000003]
# warning: eval failed for t in [2.8000000000000003, 2.9000000000000004]
# warning: eval failed for t in [2.9000000000000004, 3.0000000000000004]
# warning: eval failed for t in [3.0000000000000004, 3.1000000000000005]
# warning: eval failed for t in [3.1000000000000005, 3.2000000000000006]
# warning: eval failed for t in [3.2, 3.3000000000000003]
# warning: eval failed for t in [3.3000000000000003, 3.4000000000000004]
# warning: eval failed for t in [3.4000000000000004, 3.5000000000000004]
# warning: eval failed for t in [3.5000000000000004, 3.6000000000000005]
# warning: eval failed for t in [3.6000000000000005, 3.7000000000000006]
# warning: eval failed for t in [3.7000000000000006, 3.8000000000000007]
# warning: eval failed for t in [3.8000000000000003, 3.9000000000000004]
# warning: eval failed for t in [3.9000000000000004, 4.000000000000001]
# warning: eval failed for t in [4.000000000000001, 4.100000000000001]
# warning: eval failed for t in [4.1000000000000005, 4.200000000000001]
# warning: eval failed for t in [4.200000000000001, 4.300000000000002]
# warning: eval failed for t in [4.300000000000001, 4.400000000000001]
# warning: eval failed for t in [4.4, 4.500000000000001]
# warning: eval failed for t in [4.500000000000001, 4.600000000000001]
# warning: eval failed for t in [4.6000000000000005, 4.700000000000001]
# warning: eval failed for t in [4.700000000000001, 4.800000000000002]
# warning: eval failed for t in [4.800000000000001, 4.900000000000001]
# warning: eval failed for t in [4.9, 5.000000000000001]
# warning: eval failed for t in [5.000000000000001, 5.100000000000001]
# warning: eval failed for t in [5.1000000000000005, 5.200000000000001]
# warning: eval failed for t in [5.200000000000001, 5.300000000000002]
# warning: eval failed for t in [5.300000000000001, 5.400000000000001]
# warning: eval failed for t in [5.4, 5.500000000000001]
# warning: eval failed for t in [5.500000000000001, 5.600000000000001]
# warning: eval failed for t in [5.6000000000000005, 5.700000000000001]
# warning: eval failed for t in [5.700000000000001, 5.800000000000002]
# warning: eval failed for t in [5.800000000000001, 5.900000000000001]
# warning: eval failed for t in [5.9, 6.000000000000001]
# warning: eval failed for t in [6.000000000000001, 6.100000000000001]
# warning: eval failed for t in [6.1000000000000005, 6.200000000000001]
# warning: eval failed for t in [6.200000000000001, 6.300000000000002]
# warning: eval failed for t in [6.300000000000001, 6.400000000000001]
# warning: eval failed for t in [6.4, 6.500000000000001]
# warning: eval failed for t in [6.500000000000001, 6.600000000000001]
# warning: eval failed for t in [6.6000000000000005, 6.700000000000001]
# warning: eval failed for t in [6.700000000000001, 6.800000000000002]
# warning: eval failed for t in [6.800000000000001, 6.900000000000001]
# warning: eval failed for t in [6.900000000000001, 7.000000000000002]
# warning: eval failed for t in [7.000000000000001, 7.100000000000001]
# warning: eval failed for t in [7.1000000000000005, 7.200000000000001]
# warning: eval failed for t in [7.200000000000001, 7.300000000000002]
# warning: eval failed for t in [7.300000000000001, 7.400000000000001]
# warning: eval failed for t in [7.400000000000001, 7.500000000000002]
# warning: eval failed for t in [7.500000000000001, 7.600000000000001]
# warning: eval failed for t in [7.6000000000000005, 7.700000000000001]
# warning: eval failed for t in [7.700000000000001, 7.800000000000002]
# warning: eval failed for t in [7.800000000000001, 7.900000000000001]
# warning: eval failed for t in [7.900000000000001, 8.000000000000002]
# warning: eval failed for t in [8.000000000000002, 8.100000000000003]
# warning: eval failed for t in [8.100000000000001, 8.200000000000003]
# warning: eval failed for t in [8.200000000000001, 8.300000000000002]
# warning: eval failed for t in [8.3, 8.400000000000002]
# warning: eval failed for t in [8.400000000000002, 8.500000000000004]
# warning: eval failed for t in [8.500000000000002, 8.600000000000003]
# warning: eval failed for t in [8.600000000000001, 8.700000000000003]
# warning: eval failed for t in [8.700000000000001, 8.800000000000002]
# warning: eval failed for t in [8.8, 8.900000000000002]
# warning: eval failed for t in [8.900000000000002, 9.000000000000004]
# warning: eval failed for t in [9.000000000000002, 9.100000000000003]
# warning: eval failed for t in [9.100000000000001, 9.200000000000003]
# warning: eval failed for t in [9.200000000000001, 9.300000000000002]
# warning: eval failed for t in [9.3, 9.400000000000002]
# warning: eval failed for t in [9.400000000000002, 9.500000000000004]
# warning: eval failed for t in [9.500000000000002, 9.600000000000003]
# warning: eval failed for t in [9.600000000000001, 9.700000000000003]
# warning: eval failed for t in [9.700000000000001, 9.800000000000002]
# warning: eval failed for t in [9.8, 9.900000000000002]
# warning: eval failed for t in [9.900000000000002, 10.000000000000004]
# Graphics object consisting of 107 graphics primitives

# %%
propP = F(RIF(0, 10), P)

# %%
Q = (  Atomic(var("x") < Qbox[0].upper())
     & Atomic(var("x") > Qbox[0].lower())
     & Atomic(var("y") < Qbox[1].upper())
     & Atomic(var("y") > Qbox[1].lower()) )

# %%
propQ = F(RIF(0, 20), Q)

# %%
csig = propP.context_signal_for_system(vf,
    v4, 5, order=5, step=0.01,
    precondition=1,
    estimation=1e-3,
    integrationScheme=2,
    cutoff_threshold=1e-5,
    symbolic_composition=True)
# Out:
# ==> calling context signal
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)>, order=5, step=0.0100000000000000, precondition=1, estimation=0.00100000000000000, integrationScheme=2, cutoff_threshold=0.0000100000000000000, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7259708f50>
# calling reach with y0 = ['[0.20000000000000001 .. 0.40000000000000003]', '[7.0000000000000000 .. 8.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.2..0.4]
# C = [7.0..8.0]
# contexts = ['[0.2..0.4]', '[7.0..8.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# PolyObserver(x^2 + y^2 - 2*x + 0.80000000000000005?, <flowstar.reachability.Reach object at 0x7f7259edee60>, 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.59999999999999998?*x^3*y - 4*x^2*y^2 - 1.2000000000000000?*x^3 - 1.080000000000000?*x^2*y + 3.2000000000000002?*x*y^2 - 0.10000000000000001?*y^3 + 2.4000000000000000?*x^2 + 0.4800000000000000?*x*y - 0.10000000000000001?*y^2 - 1.2000000000000000?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f72593f8b00>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 15.002000000000001], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7259708f50>
# recomputing reachset
# setting reach level to 0
# Monitoring initial signal: 1 items in 4.32 seconds
# ==> calling to_domain
# (ContextSignal([0 .. 5], [[0.20000000000000001 .. 0.40000000000000003], [7 .. 8]], [[-1 .. 1], [-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7f725938af90>)).to_domain(1.?e1)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. 5.0000000000000000], [], mask=None), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7259708f50>
# recomputing reachset
# setting reach level to 0

# %%
csig.signal(0)

# %%
sig = propQ.signal_for_system(vf,
    v4, 0, order=6, step=(0.01, 0.5),
    precondition=1,
    estimation=1e-5,
    integrationScheme=2,
    cutoff_threshold=1e-10,
    symbolic_composition=True)
sig(0)
# Out:
# Precomposing Contexts: 1 items in 0.00 seconds
# calling reach with y0 = ['[0.20000000000000001 .. 0.40000000000000003]', '[7.0000000000000000 .. 8.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.2..0.4]
# C = [7.0..8.0]
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# Running Flow*: 1 items in 3.10 seconds
# Computed 204 flowpipes in 3.103966267000942 sec
# PolyObserver(-x + 0.29999999999999999?, <flowstar.reachability.Reach object at 0x7f72593847d0>, -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x
# symbolic_composition=True, tentative_unpreconditioning=True,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.50 seconds
# roots = [[0.0000000000000000 .. 0.54138396861958916]]
# domain = [0.0000000000000000 .. 20.002000000000003]
# roots = [[0.0000000000000000 .. 0.54138396861958916]]
# seg_domain = [0.0000000000000000 .. 20.002000000000003]
# roots = [[0.0000000000000000 .. 0.54138396861958916]]
# signal given bool roots: 1 items in 0.00 seconds
# PolyObserver(x, <flowstar.reachability.Reach object at 0x7f72593847d0>, 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x
# symbolic_composition=True, tentative_unpreconditioning=True,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.06 seconds
# roots = []
# domain = [0.0000000000000000 .. 20.002000000000003]
# roots = []
# seg_domain = [0.0000000000000000 .. 20.002000000000003]
# roots = []
# signal given bool roots: 1 items in 0.00 seconds
# PolyObserver(-y + 3.5000000000000000?, <flowstar.reachability.Reach object at 0x7f72593847d0>, 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y
# symbolic_composition=True, tentative_unpreconditioning=True,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.44 seconds
# roots = [[3.4796032126058853 .. 3.4876638413994879], [3.4907362133454875 .. 4.6465226461964822]]
# domain = [0.0000000000000000 .. 20.002000000000003]
# roots = [[3.4796032126058853 .. 3.4876638413994879],
#  [3.4907362133454875 .. 4.6465226461964822]]
# seg_domain = [0.0000000000000000 .. 20.002000000000003]
# roots = [[3.4796032126058853 .. 3.4876638413994879],
#  [3.4907362133454875 .. 4.6465226461964822]]
# signal given bool roots: 1 items in 0.00 seconds
# PolyObserver(y - 1.7500000000000000?, <flowstar.reachability.Reach object at 0x7f72593847d0>, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y
# symbolic_composition=True, tentative_unpreconditioning=True,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 1.44 seconds
# roots = [[8.3691220774290453 .. 10.735538725811079], [16.429416171323492 .. 18.211988719300323]]
# domain = [0.0000000000000000 .. 20.002000000000003]
# roots = [[8.3691220774290453 .. 10.735538725811079],
#  [16.429416171323492 .. 18.211988719300323]]
# seg_domain = [0.0000000000000000 .. 20.002000000000003]
# roots = [[8.3691220774290453 .. 10.735538725811079],
#  [16.429416171323492 .. 18.211988719300323]]
# signal given bool roots: 1 items in 0.00 seconds
# Monitoring Signal for F([0 .. 20], x < 0.300000000000000 & x > 0.000000000000000 & y < 3.50000000000000 & y > 1.75000000000000): 1 items in 2.47 seconds
# ran "observer.check" 8 times in 0.0009245872497558594
# ran "mask intersect check" 816 times in 0.0005605220794677734
# ran "root amalgamation" 66 times in 6.389617919921875e-05
# ran "capturing globals [on exit]" 28 times in 0.0002486705780029297
# ran "check boolean [unguarded]" 8 times in 0.0004761219024658203
# ran "tentative eval" 729 times in 0.2551448345184326
# ran "whole domain eval" 153 times in 0.07672595977783203
# ran "prepare in check" 8 times in 5.14984130859375e-05
# ran "root detection" 66 times in 0.0030548572540283203
# ran "restoring globals" 28 times in 0.000377655029296875
# ran "composing flowpipe" 154 times in 2.04852557182312
# ran "post retrieve" 66 times in 0.04075193405151367
# True

# %%
csig = F(RIF(0, 20), G(RIF(0, 5), Q)).context_signal_for_system(vf,
    v4, 0, order=6, step=(0.01, 0.5),
    precondition=1,
    estimation=1e-5,
    integrationScheme=2,
    cutoff_threshold=1e-10,
    symbolic_composition=True)
csig.signal(0)
# Out:
# ==> calling context signal
#  ==> creating ContextSignal with coord=(), signal = <function base_context_signal.<locals>.<lambda> at 0x7f72593f5710>, reach_tree = None
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x < 0.300000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f72593866d0>
# calling reach with y0 = ['[0.20000000000000001 .. 0.40000000000000003]', '[7.0000000000000000 .. 8.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.2..0.4]
# C = [7.0..8.0]
# contexts = ['[0.2..0.4]', '[7.0..8.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# PolyObserver(-x + 0.29999999999999999?, <flowstar.reachability.Reach object at 0x7f72593849b0>, -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725c1eb510>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 1.84 seconds
# roots = [[0.0000000000000000 .. 0.54138396861958916], [20.807811853959606 .. 22.556000145236368]]
# domain = [0.0000000000000000 .. 25.002000000000003]
# roots = [[0.0000000000000000 .. 0.54138396861958916],
#  [20.807811853959606 .. 22.556000145236368]]
# seg_domain = [0.0000000000000000 .. 25.002000000000003]
# roots = [[0.0000000000000000 .. 0.54138396861958916],
#  [20.807811853959606 .. 22.556000145236368]]
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x > 0.000000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f72593866d0>
# recomputing reachset
# PolyObserver(x, <flowstar.reachability.Reach object at 0x7f72593849b0>, 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725c1eb8a0>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.07 seconds
# roots = []
# domain = [0.0000000000000000 .. 25.002000000000003]
# roots = []
# seg_domain = [0.0000000000000000 .. 25.002000000000003]
# roots = []
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y < 3.50000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f72593866d0>
# recomputing reachset
# PolyObserver(-y + 3.5000000000000000?, <flowstar.reachability.Reach object at 0x7f72593849b0>, 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725c1ebd60>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 1.30 seconds
# roots = [[3.4796032126058853 .. 3.4876638413994879], [3.4907362133454871 .. 4.6465226461964822], [24.106734421507891 .. 25.001999999999001]]
# domain = [0.0000000000000000 .. 25.002000000000003]
# roots = [[3.4796032126058853 .. 3.4876638413994879],
#  [3.4907362133454871 .. 4.6465226461964822],
#  [24.106734421507891 .. 25.001999999999001]]
# seg_domain = [0.0000000000000000 .. 25.002000000000003]
# roots = [[3.4796032126058853 .. 3.4876638413994879],
#  [3.4907362133454871 .. 4.6465226461964822],
#  [24.106734421507891 .. 25.001999999999001]]
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [([0.0000000000000000 .. -0.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y > 1.75000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f72593866d0>
# recomputing reachset
# PolyObserver(y - 1.7500000000000000?, <flowstar.reachability.Reach object at 0x7f72593849b0>, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f72596d9510>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.96 seconds
# roots = [[8.3691220774290435 .. 10.735538725811079], [16.429416171323488 .. 18.211988719300309]]
# domain = [0.0000000000000000 .. 25.002000000000003]
# roots = [[8.3691220774290435 .. 10.735538725811079],
#  [16.429416171323488 .. 18.211988719300309]]
# seg_domain = [0.0000000000000000 .. 25.002000000000003]
# roots = [[8.3691220774290435 .. 10.735538725811079],
#  [16.429416171323488 .. 18.211988719300309]]
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [([0.0000000000000000 .. -0.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [([0.0000000000000000 .. -0.0000000000000000], False)], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
# Monitoring initial signal: 1 items in 8.19 seconds
# ==> calling to_domain
# (ContextSignal(0, [[0.20000000000000001 .. 0.40000000000000003], [7 .. 8]], [[-1 .. 1], [-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7f7259395c10>)).to_domain(0)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None

# %%
#csig.plot_histogram2d(5)

# %%
csigv6 = propQ.context_signal_for_system(vf,
    v6, 0, order=6, step=(0.01, 0.5),
    precondition=1,
    estimation=1e-5,
    integrationScheme=2,
    cutoff_threshold=1e-10,
    symbolic_composition=True)
csigv6.signal(0)
# Out:
# ==> calling context signal
#  ==> creating ContextSignal with coord=(), signal = <function base_context_signal.<locals>.<lambda> at 0x7f7258044b90>, reach_tree = None
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x < 0.300000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# calling reach with y0 = ['[0.20000000000000001 .. 0.59999999999999998]', '[2.0000000000000000 .. 3.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.2..0.6]
# C = [2.0..3.0]
# contexts = ['[0.2..0.6]', '[2.0..3.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# PolyObserver(-x + 0.29999999999999999?, <flowstar.reachability.Reach object at 0x7f7259ede500>, -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f72599623e0>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x > 0.000000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(x, <flowstar.reachability.Reach object at 0x7f7259ede500>, 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f72640b8050>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y < 3.50000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(-y + 3.5000000000000000?, <flowstar.reachability.Reach object at 0x7f7259ede500>, 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f72640b83e0>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y > 1.75000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(y - 1.7500000000000000?, <flowstar.reachability.Reach object at 0x7f7259ede500>, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f72593f8770>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
# Monitoring initial signal: 1 items in 0.50 seconds
# ==> calling to_domain
# (ContextSignal(0, [[0.20000000000000001 .. 0.59999999999999998], [2 .. 3]], [[-1 .. 1], [-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7f7257fb6b90>)).to_domain(0)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None

# %%
csigv6.plot_histogram2d(2)
# Out:
#  ==> creating ContextSignal with coord=(0,), signal = <function base_context_signal.<locals>.<lambda> at 0x7f7258044b90>, reach_tree = None
#  ==> creating ContextSignal with coord=(0,), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x < 0.300000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(-x + 0.29999999999999999?, <flowstar.reachability.Reach object at 0x7f7259ede500>, -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7259962640>
#  ==> creating ContextSignal with coord=(0,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0,), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x > 0.000000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(x, <flowstar.reachability.Reach object at 0x7f7259ede500>, 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f72599628a0>
#  ==> creating ContextSignal with coord=(0,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0,), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y < 3.50000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(-y + 3.5000000000000000?, <flowstar.reachability.Reach object at 0x7f7259ede500>, 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f72593f8640>
#  ==> creating ContextSignal with coord=(0,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0,), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y > 1.75000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(y - 1.7500000000000000?, <flowstar.reachability.Reach object at 0x7f7259ede500>, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f72640b8180>
#  ==> creating ContextSignal with coord=(0,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1,), signal = <function base_context_signal.<locals>.<lambda> at 0x7f7258044b90>, reach_tree = None
#  ==> creating ContextSignal with coord=(1,), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x < 0.300000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(-x + 0.29999999999999999?, <flowstar.reachability.Reach object at 0x7f7259ede500>, -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f72640b8640>
#  ==> creating ContextSignal with coord=(1,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1,), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x > 0.000000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(x, <flowstar.reachability.Reach object at 0x7f7259ede500>, 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f72640b82b0>
#  ==> creating ContextSignal with coord=(1,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1,), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y < 3.50000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(-y + 3.5000000000000000?, <flowstar.reachability.Reach object at 0x7f7259ede500>, 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7259962050>
#  ==> creating ContextSignal with coord=(1,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1,), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y > 1.75000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(y - 1.7500000000000000?, <flowstar.reachability.Reach object at 0x7f7259ede500>, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7259962180>
#  ==> creating ContextSignal with coord=(1,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(2,), signal = <function base_context_signal.<locals>.<lambda> at 0x7f7258044b90>, reach_tree = None
#  ==> creating ContextSignal with coord=(2,), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x < 0.300000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(-x + 0.29999999999999999?, <flowstar.reachability.Reach object at 0x7f7259ede500>, -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f72593f8d60>
#  ==> creating ContextSignal with coord=(2,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(2,), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x > 0.000000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(x, <flowstar.reachability.Reach object at 0x7f7259ede500>, 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f72640b8c30>
#  ==> creating ContextSignal with coord=(2,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(2,), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y < 3.50000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(-y + 3.5000000000000000?, <flowstar.reachability.Reach object at 0x7f7259ede500>, 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f72640b8510>
#  ==> creating ContextSignal with coord=(2,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(2,), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y > 1.75000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(y - 1.7500000000000000?, <flowstar.reachability.Reach object at 0x7f7259ede500>, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f72640b8d60>
#  ==> creating ContextSignal with coord=(2,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(2,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(2,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3,), signal = <function base_context_signal.<locals>.<lambda> at 0x7f7258044b90>, reach_tree = None
#  ==> creating ContextSignal with coord=(3,), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x < 0.300000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(-x + 0.29999999999999999?, <flowstar.reachability.Reach object at 0x7f7259ede500>, -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257f52180>
#  ==> creating ContextSignal with coord=(3,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3,), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x > 0.000000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(x, <flowstar.reachability.Reach object at 0x7f7259ede500>, 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f72640b8b00>
#  ==> creating ContextSignal with coord=(3,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3,), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y < 3.50000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(-y + 3.5000000000000000?, <flowstar.reachability.Reach object at 0x7f7259ede500>, 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f72599622b0>
#  ==> creating ContextSignal with coord=(3,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3,), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y > 1.75000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(y - 1.7500000000000000?, <flowstar.reachability.Reach object at 0x7f7259ede500>, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257f52b00>
#  ==> creating ContextSignal with coord=(3,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0), signal = <function base_context_signal.<locals>.<lambda> at 0x7f7258044b90>, reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x < 0.300000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# calling reach with y0 = ['[0.20000000000000001 .. 0.40000000000000003]', '[2.0000000000000000 .. 2.5000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.2..0.4]
# C = [2.0..2.5]
# contexts = ['[0.2..0.4]', '[2.0..2.5]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# PolyObserver(-x + 0.29999999999999999?, <flowstar.reachability.Reach object at 0x7f725a40e6e0>, -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7259962770>
#  ==> creating ContextSignal with coord=(0, 0), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x > 0.000000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(x, <flowstar.reachability.Reach object at 0x7f725a40e6e0>, 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f72640b8e90>
#  ==> creating ContextSignal with coord=(0, 0), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y < 3.50000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(-y + 3.5000000000000000?, <flowstar.reachability.Reach object at 0x7f725a40e6e0>, 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f72640b8770>
#  ==> creating ContextSignal with coord=(0, 0), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y > 1.75000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(y - 1.7500000000000000?, <flowstar.reachability.Reach object at 0x7f725a40e6e0>, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257f528a0>
#  ==> creating ContextSignal with coord=(0, 0), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 1), signal = <function base_context_signal.<locals>.<lambda> at 0x7f7258044b90>, reach_tree = None
#  ==> creating ContextSignal with coord=(0, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x < 0.300000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(-x + 0.29999999999999999?, <flowstar.reachability.Reach object at 0x7f725a40e6e0>, -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257f52050>
#  ==> creating ContextSignal with coord=(0, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x > 0.000000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(x, <flowstar.reachability.Reach object at 0x7f725a40e6e0>, 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257f52e90>
#  ==> creating ContextSignal with coord=(0, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y < 3.50000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(-y + 3.5000000000000000?, <flowstar.reachability.Reach object at 0x7f725a40e6e0>, 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257f529d0>
#  ==> creating ContextSignal with coord=(0, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y > 1.75000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(y - 1.7500000000000000?, <flowstar.reachability.Reach object at 0x7f725a40e6e0>, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257f52640>
#  ==> creating ContextSignal with coord=(0, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 2), signal = <function base_context_signal.<locals>.<lambda> at 0x7f7258044b90>, reach_tree = None
#  ==> creating ContextSignal with coord=(0, 2), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x < 0.300000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(-x + 0.29999999999999999?, <flowstar.reachability.Reach object at 0x7f725a40e6e0>, -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257f52770>
#  ==> creating ContextSignal with coord=(0, 2), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 2), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x > 0.000000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(x, <flowstar.reachability.Reach object at 0x7f725a40e6e0>, 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f72640b89d0>
#  ==> creating ContextSignal with coord=(0, 2), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 2), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y < 3.50000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(-y + 3.5000000000000000?, <flowstar.reachability.Reach object at 0x7f725a40e6e0>, 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257f78180>
#  ==> creating ContextSignal with coord=(0, 2), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 2), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y > 1.75000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(y - 1.7500000000000000?, <flowstar.reachability.Reach object at 0x7f725a40e6e0>, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257f783e0>
#  ==> creating ContextSignal with coord=(0, 2), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 2), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 2), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 3), signal = <function base_context_signal.<locals>.<lambda> at 0x7f7258044b90>, reach_tree = None
#  ==> creating ContextSignal with coord=(0, 3), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x < 0.300000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(-x + 0.29999999999999999?, <flowstar.reachability.Reach object at 0x7f725a40e6e0>, -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257f78640>
#  ==> creating ContextSignal with coord=(0, 3), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 3), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x > 0.000000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(x, <flowstar.reachability.Reach object at 0x7f725a40e6e0>, 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257f789d0>
#  ==> creating ContextSignal with coord=(0, 3), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 3), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y < 3.50000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(-y + 3.5000000000000000?, <flowstar.reachability.Reach object at 0x7f725a40e6e0>, 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257f523e0>
#  ==> creating ContextSignal with coord=(0, 3), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 3), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y > 1.75000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(y - 1.7500000000000000?, <flowstar.reachability.Reach object at 0x7f725a40e6e0>, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257f78d60>
#  ==> creating ContextSignal with coord=(0, 3), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 3), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 3), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 0), signal = <function base_context_signal.<locals>.<lambda> at 0x7f7258044b90>, reach_tree = None
#  ==> creating ContextSignal with coord=(1, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x < 0.300000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# calling reach with y0 = ['[0.20000000000000001 .. 0.40000000000000003]', '[2.5000000000000000 .. 3.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.2..0.4]
# C = [2.5..3.0]
# contexts = ['[0.2..0.4]', '[2.5..3.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# PolyObserver(-x + 0.29999999999999999?, <flowstar.reachability.Reach object at 0x7f7259edee60>, -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f72640b88a0>
#  ==> creating ContextSignal with coord=(1, 0), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x > 0.000000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(x, <flowstar.reachability.Reach object at 0x7f7259edee60>, 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257f522b0>
#  ==> creating ContextSignal with coord=(1, 0), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y < 3.50000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(-y + 3.5000000000000000?, <flowstar.reachability.Reach object at 0x7f7259edee60>, 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257f78b00>
#  ==> creating ContextSignal with coord=(1, 0), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y > 1.75000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(y - 1.7500000000000000?, <flowstar.reachability.Reach object at 0x7f7259edee60>, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257f788a0>
#  ==> creating ContextSignal with coord=(1, 0), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 0), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 0), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 1), signal = <function base_context_signal.<locals>.<lambda> at 0x7f7258044b90>, reach_tree = None
#  ==> creating ContextSignal with coord=(1, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x < 0.300000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(-x + 0.29999999999999999?, <flowstar.reachability.Reach object at 0x7f7259edee60>, -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257f78050>
#  ==> creating ContextSignal with coord=(1, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x > 0.000000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(x, <flowstar.reachability.Reach object at 0x7f7259edee60>, 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257f51050>
#  ==> creating ContextSignal with coord=(1, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y < 3.50000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(-y + 3.5000000000000000?, <flowstar.reachability.Reach object at 0x7f7259edee60>, 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257f512b0>
# ...
# recomputing reachset
# PolyObserver(y - 1.7500000000000000?, <flowstar.reachability.Reach object at 0x7f7259384140>, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257f31050>
#  ==> creating ContextSignal with coord=(3, 0), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 0), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 0), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 1), signal = <function base_context_signal.<locals>.<lambda> at 0x7f7258044b90>, reach_tree = None
#  ==> creating ContextSignal with coord=(3, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x < 0.300000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(-x + 0.29999999999999999?, <flowstar.reachability.Reach object at 0x7f7259384140>, -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257f313e0>
#  ==> creating ContextSignal with coord=(3, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x > 0.000000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(x, <flowstar.reachability.Reach object at 0x7f7259384140>, 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257f31c30>
#  ==> creating ContextSignal with coord=(3, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y < 3.50000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(-y + 3.5000000000000000?, <flowstar.reachability.Reach object at 0x7f7259384140>, 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257f31b00>
#  ==> creating ContextSignal with coord=(3, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y > 1.75000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(y - 1.7500000000000000?, <flowstar.reachability.Reach object at 0x7f7259384140>, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257f318a0>
#  ==> creating ContextSignal with coord=(3, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 2), signal = <function base_context_signal.<locals>.<lambda> at 0x7f7258044b90>, reach_tree = None
#  ==> creating ContextSignal with coord=(3, 2), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x < 0.300000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(-x + 0.29999999999999999?, <flowstar.reachability.Reach object at 0x7f7259384140>, -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257f31770>
#  ==> creating ContextSignal with coord=(3, 2), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 2), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x > 0.000000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(x, <flowstar.reachability.Reach object at 0x7f7259384140>, 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257f31640>
#  ==> creating ContextSignal with coord=(3, 2), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 2), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y < 3.50000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(-y + 3.5000000000000000?, <flowstar.reachability.Reach object at 0x7f7259384140>, 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257f312b0>
#  ==> creating ContextSignal with coord=(3, 2), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 2), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y > 1.75000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(y - 1.7500000000000000?, <flowstar.reachability.Reach object at 0x7f7259384140>, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257f17c30>
#  ==> creating ContextSignal with coord=(3, 2), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 2), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 2), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3), signal = <function base_context_signal.<locals>.<lambda> at 0x7f7258044b90>, reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x < 0.300000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(-x + 0.29999999999999999?, <flowstar.reachability.Reach object at 0x7f7259384140>, -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257f17b00>
#  ==> creating ContextSignal with coord=(3, 3), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x > 0.000000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(x, <flowstar.reachability.Reach object at 0x7f7259384140>, 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257f3a2b0>
#  ==> creating ContextSignal with coord=(3, 3), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y < 3.50000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(-y + 3.5000000000000000?, <flowstar.reachability.Reach object at 0x7f7259384140>, 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257f3ad60>
#  ==> creating ContextSignal with coord=(3, 3), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y > 1.75000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(y - 1.7500000000000000?, <flowstar.reachability.Reach object at 0x7f7259384140>, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257f3a9d0>
#  ==> creating ContextSignal with coord=(3, 3), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
# Graphics object consisting of 1 graphics primitive

# %%
csigv6.plot_histogram2d(3)
# Out:
#  ==> creating ContextSignal with coord=(0, 0, 0), signal = <function base_context_signal.<locals>.<lambda> at 0x7f7258044b90>, reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x < 0.300000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# calling reach with y0 = ['[0.20000000000000001 .. 0.30000000000000005]', '[2.0000000000000000 .. 2.2500000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.2..0.30000000000000004]
# C = [2.0..2.25]
# contexts = ['[0.2..0.30000000000000004]', '[2.0..2.25]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# PolyObserver(-x + 0.29999999999999999?, <flowstar.reachability.Reach object at 0x7f7259384d70>, -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257f3a180>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 1.92 seconds
# roots = [[0.0000000000000000 .. 5.1790470540394403]]
# domain = [0.0000000000000000 .. 20.002000000000003]
# roots = [[0.0000000000000000 .. 5.1790470540394403]]
# seg_domain = [0.0000000000000000 .. 20.002000000000003]
# roots = [[0.0000000000000000 .. 5.1790470540394403]]
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(0, 0, 0), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x > 0.000000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(x, <flowstar.reachability.Reach object at 0x7f7259384d70>, 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257e9a2b0>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.06 seconds
# roots = []
# domain = [0.0000000000000000 .. 20.002000000000003]
# roots = []
# seg_domain = [0.0000000000000000 .. 20.002000000000003]
# roots = []
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(0, 0, 0), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y < 3.50000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(-y + 3.5000000000000000?, <flowstar.reachability.Reach object at 0x7f7259384d70>, 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257e9a640>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 1.94 seconds
# roots = [[3.7856484422681337 .. 9.9951610954932644]]
# domain = [0.0000000000000000 .. 20.002000000000003]
# roots = [[3.7856484422681337 .. 9.9951610954932644]]
# seg_domain = [0.0000000000000000 .. 20.002000000000003]
# roots = [[3.7856484422681337 .. 9.9951610954932644]]
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(0, 0, 0), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y > 1.75000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(y - 1.7500000000000000?, <flowstar.reachability.Reach object at 0x7f7259384d70>, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257e9a3e0>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.07 seconds
# roots = []
# domain = [0.0000000000000000 .. 20.002000000000003]
# roots = []
# seg_domain = [0.0000000000000000 .. 20.002000000000003]
# roots = []
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(0, 0, 0), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 0), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 0), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 1), signal = <function base_context_signal.<locals>.<lambda> at 0x7f7258044b90>, reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x < 0.300000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(-x + 0.29999999999999999?, <flowstar.reachability.Reach object at 0x7f7259384d70>, -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257e9a9d0>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.10 seconds
# roots = [[0.0000000000000000 .. 5.1790470540394403]]
# domain = [0.0000000000000000 .. 20.002000000000003]
# roots = [[0.0000000000000000 .. 5.1790470540394403]]
# seg_domain = [0.0000000000000000 .. 20.002000000000003]
# roots = [[0.0000000000000000 .. 5.1790470540394403]]
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(0, 0, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x > 0.000000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(x, <flowstar.reachability.Reach object at 0x7f7259384d70>, 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257e9ae90>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.07 seconds
# roots = []
# domain = [0.0000000000000000 .. 20.002000000000003]
# roots = []
# seg_domain = [0.0000000000000000 .. 20.002000000000003]
# roots = []
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(0, 0, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y < 3.50000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(-y + 3.5000000000000000?, <flowstar.reachability.Reach object at 0x7f7259384d70>, 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257e98c30>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.14 seconds
# roots = [[3.7856484422681337 .. 9.9951610954932644]]
# domain = [0.0000000000000000 .. 20.002000000000003]
# roots = [[3.7856484422681337 .. 9.9951610954932644]]
# seg_domain = [0.0000000000000000 .. 20.002000000000003]
# roots = [[3.7856484422681337 .. 9.9951610954932644]]
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(0, 0, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y > 1.75000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(y - 1.7500000000000000?, <flowstar.reachability.Reach object at 0x7f7259384d70>, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257e9ad60>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.07 seconds
# roots = []
# domain = [0.0000000000000000 .. 20.002000000000003]
# roots = []
# seg_domain = [0.0000000000000000 .. 20.002000000000003]
# roots = []
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(0, 0, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 2), signal = <function base_context_signal.<locals>.<lambda> at 0x7f7258044b90>, reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 2), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x < 0.300000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(-x + 0.29999999999999999?, <flowstar.reachability.Reach object at 0x7f7259384d70>, -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257e9ac30>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.12 seconds
# roots = [[0.0000000000000000 .. 5.1790470540394403]]
# domain = [0.0000000000000000 .. 20.002000000000003]
# roots = [[0.0000000000000000 .. 5.1790470540394403]]
# seg_domain = [0.0000000000000000 .. 20.002000000000003]
# roots = [[0.0000000000000000 .. 5.1790470540394403]]
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(0, 0, 2), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 2), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x > 0.000000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(x, <flowstar.reachability.Reach object at 0x7f7259384d70>, 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257e9ab00>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.07 seconds
# roots = []
# domain = [0.0000000000000000 .. 20.002000000000003]
# roots = []
# seg_domain = [0.0000000000000000 .. 20.002000000000003]
# roots = []
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(0, 0, 2), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 2), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y < 3.50000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(-y + 3.5000000000000000?, <flowstar.reachability.Reach object at 0x7f7259384d70>, 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7259962510>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.11 seconds
# roots = [[3.7856484422681337 .. 9.9951610954932644]]
# domain = [0.0000000000000000 .. 20.002000000000003]
# roots = [[3.7856484422681337 .. 9.9951610954932644]]
# seg_domain = [0.0000000000000000 .. 20.002000000000003]
# roots = [[3.7856484422681337 .. 9.9951610954932644]]
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(0, 0, 2), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 2), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y > 1.75000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(y - 1.7500000000000000?, <flowstar.reachability.Reach object at 0x7f7259384d70>, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7259962e90>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.08 seconds
# roots = []
# domain = [0.0000000000000000 .. 20.002000000000003]
# roots = []
# seg_domain = [0.0000000000000000 .. 20.002000000000003]
# roots = []
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(0, 0, 2), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 2), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 2), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 3), signal = <function base_context_signal.<locals>.<lambda> at 0x7f7258044b90>, reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 3), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x < 0.300000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(-x + 0.29999999999999999?, <flowstar.reachability.Reach object at 0x7f7259384d70>, -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257e9a8a0>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.10 seconds
# roots = [[0.0000000000000000 .. 5.1790470540394403]]
# domain = [0.0000000000000000 .. 20.002000000000003]
# roots = [[0.0000000000000000 .. 5.1790470540394403]]
# seg_domain = [0.0000000000000000 .. 20.002000000000003]
# roots = [[0.0000000000000000 .. 5.1790470540394403]]
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(0, 0, 3), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 3), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x > 0.000000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(x, <flowstar.reachability.Reach object at 0x7f7259384d70>, 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257e9a770>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.07 seconds
# roots = []
# domain = [0.0000000000000000 .. 20.002000000000003]
# roots = []
# seg_domain = [0.0000000000000000 .. 20.002000000000003]
# roots = []
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(0, 0, 3), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 3), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y < 3.50000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(-y + 3.5000000000000000?, <flowstar.reachability.Reach object at 0x7f7259384d70>, 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257eaf050>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.11 seconds
# roots = [[3.7856484422681337 .. 9.9951610954932644]]
# domain = [0.0000000000000000 .. 20.002000000000003]
# roots = [[3.7856484422681337 .. 9.9951610954932644]]
# seg_domain = [0.0000000000000000 .. 20.002000000000003]
# roots = [[3.7856484422681337 .. 9.9951610954932644]]
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(0, 0, 3), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 3), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y > 1.75000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(y - 1.7500000000000000?, <flowstar.reachability.Reach object at 0x7f7259384d70>, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257e9a180>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.07 seconds
# roots = []
# domain = [0.0000000000000000 .. 20.002000000000003]
# roots = []
# seg_domain = [0.0000000000000000 .. 20.002000000000003]
# roots = []
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(0, 0, 3), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 3), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 3), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 1, 0), signal = <function base_context_signal.<locals>.<lambda> at 0x7f7258044b90>, reach_tree = None
#  ==> creating ContextSignal with coord=(0, 1, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x < 0.300000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# calling reach with y0 = ['[0.20000000000000001 .. 0.30000000000000005]', '[2.2500000000000000 .. 2.5000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.2..0.30000000000000004]
# C = [2.25..2.5]
# contexts = ['[0.2..0.30000000000000004]', '[2.25..2.5]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# PolyObserver(-x + 0.29999999999999999?, <flowstar.reachability.Reach object at 0x7f7259384e60>, -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257eaf2b0>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.97 seconds
# roots = [[0.0000000000000000 .. 3.5985312742197527]]
# domain = [0.0000000000000000 .. 20.002000000000003]
# roots = [[0.0000000000000000 .. 3.5985312742197527]]
# seg_domain = [0.0000000000000000 .. 20.002000000000003]
# roots = [[0.0000000000000000 .. 3.5985312742197527]]
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(0, 1, 0), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 1, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x > 0.000000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(x, <flowstar.reachability.Reach object at 0x7f7259384e60>, 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257eaf640>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.06 seconds
# roots = []
# domain = [0.0000000000000000 .. 20.002000000000003]
# roots = []
# seg_domain = [0.0000000000000000 .. 20.002000000000003]
# roots = []
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(0, 1, 0), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 1, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y < 3.50000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(-y + 3.5000000000000000?, <flowstar.reachability.Reach object at 0x7f7259384e60>, 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257eaf8a0>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 1.57 seconds
# roots = [[3.2925135440526007 .. 8.6860024093307562]]
# domain = [0.0000000000000000 .. 20.002000000000003]
# roots = [[3.2925135440526007 .. 8.6860024093307562]]
# seg_domain = [0.0000000000000000 .. 20.002000000000003]
# roots = [[3.2925135440526007 .. 8.6860024093307562]]
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(0, 1, 0), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 1, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y > 1.75000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(y - 1.7500000000000000?, <flowstar.reachability.Reach object at 0x7f7259384e60>, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257eafc30>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.06 seconds
# roots = []
# domain = [0.0000000000000000 .. 20.002000000000003]
# roots = []
# seg_domain = [0.0000000000000000 .. 20.002000000000003]
# roots = []
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(0, 1, 0), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 1, 0), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 1, 0), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 1, 1), signal = <function base_context_signal.<locals>.<lambda> at 0x7f7258044b90>, reach_tree = None
#  ==> creating ContextSignal with coord=(0, 1, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x < 0.300000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(-x + 0.29999999999999999?, <flowstar.reachability.Reach object at 0x7f7259384e60>, -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257eafe90>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.08 seconds
# roots = [[0.0000000000000000 .. 3.5985312742197527]]
# domain = [0.0000000000000000 .. 20.002000000000003]
# roots = [[0.0000000000000000 .. 3.5985312742197527]]
# seg_domain = [0.0000000000000000 .. 20.002000000000003]
# roots = [[0.0000000000000000 .. 3.5985312742197527]]
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(0, 1, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 1, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x > 0.000000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(x, <flowstar.reachability.Reach object at 0x7f7259384e60>, 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257eafd60>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.06 seconds
# roots = []
# domain = [0.0000000000000000 .. 20.002000000000003]
# roots = []
# seg_domain = [0.0000000000000000 .. 20.002000000000003]
# roots = []
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(0, 1, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 1, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y < 3.50000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(-y + 3.5000000000000000?, <flowstar.reachability.Reach object at 0x7f7259384e60>, 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257eafb00>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.10 seconds
# roots = [[3.2925135440526007 .. 8.6860024093307562]]
# domain = [0.0000000000000000 .. 20.002000000000003]
# roots = [[3.2925135440526007 .. 8.6860024093307562]]
# seg_domain = [0.0000000000000000 .. 20.002000000000003]
# roots = [[3.2925135440526007 .. 8.6860024093307562]]
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(0, 1, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 1, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y > 1.75000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(y - 1.7500000000000000?, <flowstar.reachability.Reach object at 0x7f7259384e60>, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257eaf9d0>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.06 seconds
# roots = []
# domain = [0.0000000000000000 .. 20.002000000000003]
# roots = []
# seg_domain = [0.0000000000000000 .. 20.002000000000003]
# roots = []
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(0, 1, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 1, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 1, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 1, 2), signal = <function base_context_signal.<locals>.<lambda> at 0x7f7258044b90>, reach_tree = None
#  ==> creating ContextSignal with coord=(0, 1, 2), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x < 0.300000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(-x + 0.29999999999999999?, <flowstar.reachability.Reach object at 0x7f7259384e60>, -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257eaf3e0>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.08 seconds
# roots = [[0.0000000000000000 .. 3.5985312742197527]]
# domain = [0.0000000000000000 .. 20.002000000000003]
# roots = [[0.0000000000000000 .. 3.5985312742197527]]
# seg_domain = [0.0000000000000000 .. 20.002000000000003]
# roots = [[0.0000000000000000 .. 3.5985312742197527]]
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(0, 1, 2), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 1, 2), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x > 0.000000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(x, <flowstar.reachability.Reach object at 0x7f7259384e60>, 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257eaf770>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.07 seconds
# roots = []
# domain = [0.0000000000000000 .. 20.002000000000003]
# roots = []
# seg_domain = [0.0000000000000000 .. 20.002000000000003]
# roots = []
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(0, 1, 2), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 1, 2), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y < 3.50000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(-y + 3.5000000000000000?, <flowstar.reachability.Reach object at 0x7f7259384e60>, 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257eaf510>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.10 seconds
# roots = [[3.2925135440526007 .. 8.6860024093307562]]
# domain = [0.0000000000000000 .. 20.002000000000003]
# roots = [[3.2925135440526007 .. 8.6860024093307562]]
# seg_domain = [0.0000000000000000 .. 20.002000000000003]
# roots = [[3.2925135440526007 .. 8.6860024093307562]]
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(0, 1, 2), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 1, 2), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y > 1.75000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(y - 1.7500000000000000?, <flowstar.reachability.Reach object at 0x7f7259384e60>, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257eb8770>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.07 seconds
# roots = []
# domain = [0.0000000000000000 .. 20.002000000000003]
# roots = []
# seg_domain = [0.0000000000000000 .. 20.002000000000003]
# roots = []
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(0, 1, 2), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 1, 2), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 1, 2), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 1, 3), signal = <function base_context_signal.<locals>.<lambda> at 0x7f7258044b90>, reach_tree = None
#  ==> creating ContextSignal with coord=(0, 1, 3), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x < 0.300000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(-x + 0.29999999999999999?, <flowstar.reachability.Reach object at 0x7f7259384e60>, -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257fec3e0>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.09 seconds
# roots = [[0.0000000000000000 .. 3.5985312742197527]]
# domain = [0.0000000000000000 .. 20.002000000000003]
# roots = [[0.0000000000000000 .. 3.5985312742197527]]
# seg_domain = [0.0000000000000000 .. 20.002000000000003]
# roots = [[0.0000000000000000 .. 3.5985312742197527]]
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(0, 1, 3), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 1, 3), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x > 0.000000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(x, <flowstar.reachability.Reach object at 0x7f7259384e60>, 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257eb83e0>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.06 seconds
# roots = []
# domain = [0.0000000000000000 .. 20.002000000000003]
# roots = []
# ...
# recomputing reachset
# PolyObserver(y - 1.7500000000000000?, <flowstar.reachability.Reach object at 0x7f725886c500>, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f72599628a0>
#  ==> creating ContextSignal with coord=(3, 3, 0), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 0), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 0), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 1), signal = <function base_context_signal.<locals>.<lambda> at 0x7f7258044b90>, reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x < 0.300000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(-x + 0.29999999999999999?, <flowstar.reachability.Reach object at 0x7f725886c500>, -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7258099c30>
#  ==> creating ContextSignal with coord=(3, 3, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x > 0.000000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(x, <flowstar.reachability.Reach object at 0x7f725886c500>, 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f72580d42b0>
#  ==> creating ContextSignal with coord=(3, 3, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y < 3.50000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(-y + 3.5000000000000000?, <flowstar.reachability.Reach object at 0x7f725886c500>, 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f72580d4d60>
#  ==> creating ContextSignal with coord=(3, 3, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y > 1.75000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(y - 1.7500000000000000?, <flowstar.reachability.Reach object at 0x7f725886c500>, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f72580d4180>
#  ==> creating ContextSignal with coord=(3, 3, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 2), signal = <function base_context_signal.<locals>.<lambda> at 0x7f7258044b90>, reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 2), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x < 0.300000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(-x + 0.29999999999999999?, <flowstar.reachability.Reach object at 0x7f725886c500>, -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f72580d4510>
#  ==> creating ContextSignal with coord=(3, 3, 2), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 2), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x > 0.000000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(x, <flowstar.reachability.Reach object at 0x7f725886c500>, 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725815cc30>
#  ==> creating ContextSignal with coord=(3, 3, 2), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 2), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y < 3.50000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(-y + 3.5000000000000000?, <flowstar.reachability.Reach object at 0x7f725886c500>, 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725815c8a0>
#  ==> creating ContextSignal with coord=(3, 3, 2), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 2), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y > 1.75000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(y - 1.7500000000000000?, <flowstar.reachability.Reach object at 0x7f725886c500>, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725815c9d0>
#  ==> creating ContextSignal with coord=(3, 3, 2), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 2), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 2), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 3), signal = <function base_context_signal.<locals>.<lambda> at 0x7f7258044b90>, reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 3), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x < 0.300000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(-x + 0.29999999999999999?, <flowstar.reachability.Reach object at 0x7f725886c500>, -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725815c3e0>
#  ==> creating ContextSignal with coord=(3, 3, 3), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 3), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x > 0.000000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(x, <flowstar.reachability.Reach object at 0x7f725886c500>, 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725815c770>
#  ==> creating ContextSignal with coord=(3, 3, 3), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 3), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y < 3.50000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(-y + 3.5000000000000000?, <flowstar.reachability.Reach object at 0x7f725886c500>, 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257f52640>
#  ==> creating ContextSignal with coord=(3, 3, 3), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 3), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y > 1.75000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f7257f4bdd0>
# recomputing reachset
# PolyObserver(y - 1.7500000000000000?, <flowstar.reachability.Reach object at 0x7f725886c500>, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f72593f8d60>
#  ==> creating ContextSignal with coord=(3, 3, 3), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 3), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 3), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
# Graphics object consisting of 1 graphics primitive

# %%
csigv6.plot_histogram2d(4)

# %%
csigv6.plot_histogram2d(5)

# %%
csigv6 = F(RIF(0, 5), Q).context_signal_for_system(vf,
    v6, 0, order=6, step=(0.01, 0.5),
    precondition=1,
    estimation=1e-5,
    integrationScheme=2,
    cutoff_threshold=1e-10,
    symbolic_composition=True)
csigv6.signal(0)
# Out:
# ==> calling context signal
#  ==> creating ContextSignal with coord=(), signal = <function base_context_signal.<locals>.<lambda> at 0x7f7257d523b0>, reach_tree = None
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x < 0.300000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# calling reach with y0 = ['[0.20000000000000001 .. 0.59999999999999998]', '[2.0000000000000000 .. 3.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.2..0.6]
# C = [2.0..3.0]
# contexts = ['[0.2..0.6]', '[2.0..3.0]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# PolyObserver(-x + 0.29999999999999999?, <flowstar.reachability.Reach object at 0x7f725886cc80>, -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257fecd60>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x > 0.000000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# recomputing reachset
# PolyObserver(x, <flowstar.reachability.Reach object at 0x7f725886cc80>, 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f72587e0050>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y < 3.50000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# recomputing reachset
# PolyObserver(-y + 3.5000000000000000?, <flowstar.reachability.Reach object at 0x7f725886cc80>, 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f72587f3640>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y > 1.75000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# recomputing reachset
# PolyObserver(y - 1.7500000000000000?, <flowstar.reachability.Reach object at 0x7f725886cc80>, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f72587f39d0>
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
# Monitoring initial signal: 1 items in 0.73 seconds
# ==> calling to_domain
# (ContextSignal(0, [[0.20000000000000001 .. 0.59999999999999998], [2 .. 3]], [[-1 .. 1], [-1 .. 1]], children=<lbuc.context_signals.ChildIterator object at 0x7f72585fe950>)).to_domain(0)
#  ==> creating ContextSignal with coord=(), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None

# %%
csigv6.plot_histogram2d(3)
# Out:
#  ==> creating ContextSignal with coord=(0,), signal = <function base_context_signal.<locals>.<lambda> at 0x7f7257d523b0>, reach_tree = None
#  ==> creating ContextSignal with coord=(0,), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x < 0.300000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# recomputing reachset
# PolyObserver(-x + 0.29999999999999999?, <flowstar.reachability.Reach object at 0x7f725886cc80>, -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725870b770>
#  ==> creating ContextSignal with coord=(0,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0,), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x > 0.000000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# recomputing reachset
# PolyObserver(x, <flowstar.reachability.Reach object at 0x7f725886cc80>, 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725870b8a0>
#  ==> creating ContextSignal with coord=(0,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0,), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y < 3.50000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# recomputing reachset
# PolyObserver(-y + 3.5000000000000000?, <flowstar.reachability.Reach object at 0x7f725886cc80>, 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f72587f3510>
#  ==> creating ContextSignal with coord=(0,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0,), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y > 1.75000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# recomputing reachset
# PolyObserver(y - 1.7500000000000000?, <flowstar.reachability.Reach object at 0x7f725886cc80>, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f72587f3e90>
#  ==> creating ContextSignal with coord=(0,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1,), signal = <function base_context_signal.<locals>.<lambda> at 0x7f7257d523b0>, reach_tree = None
#  ==> creating ContextSignal with coord=(1,), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x < 0.300000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# recomputing reachset
# PolyObserver(-x + 0.29999999999999999?, <flowstar.reachability.Reach object at 0x7f725886cc80>, -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f72587f32b0>
#  ==> creating ContextSignal with coord=(1,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1,), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x > 0.000000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# recomputing reachset
# PolyObserver(x, <flowstar.reachability.Reach object at 0x7f725886cc80>, 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725815c180>
#  ==> creating ContextSignal with coord=(1,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1,), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y < 3.50000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# recomputing reachset
# PolyObserver(-y + 3.5000000000000000?, <flowstar.reachability.Reach object at 0x7f725886cc80>, 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257d969d0>
#  ==> creating ContextSignal with coord=(1,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1,), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y > 1.75000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# recomputing reachset
# PolyObserver(y - 1.7500000000000000?, <flowstar.reachability.Reach object at 0x7f725886cc80>, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7258739e90>
#  ==> creating ContextSignal with coord=(1,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(1,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(2,), signal = <function base_context_signal.<locals>.<lambda> at 0x7f7257d523b0>, reach_tree = None
#  ==> creating ContextSignal with coord=(2,), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x < 0.300000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# recomputing reachset
# PolyObserver(-x + 0.29999999999999999?, <flowstar.reachability.Reach object at 0x7f725886cc80>, -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f72587f3c30>
#  ==> creating ContextSignal with coord=(2,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(2,), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x > 0.000000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# recomputing reachset
# PolyObserver(x, <flowstar.reachability.Reach object at 0x7f725886cc80>, 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f72587f3d60>
#  ==> creating ContextSignal with coord=(2,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(2,), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y < 3.50000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# recomputing reachset
# PolyObserver(-y + 3.5000000000000000?, <flowstar.reachability.Reach object at 0x7f725886cc80>, 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f72587f33e0>
#  ==> creating ContextSignal with coord=(2,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(2,), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y > 1.75000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# recomputing reachset
# PolyObserver(y - 1.7500000000000000?, <flowstar.reachability.Reach object at 0x7f725886cc80>, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7258804050>
#  ==> creating ContextSignal with coord=(2,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(2,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(2,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3,), signal = <function base_context_signal.<locals>.<lambda> at 0x7f7257d523b0>, reach_tree = None
#  ==> creating ContextSignal with coord=(3,), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x < 0.300000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# recomputing reachset
# PolyObserver(-x + 0.29999999999999999?, <flowstar.reachability.Reach object at 0x7f725886cc80>, -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7258804510>
#  ==> creating ContextSignal with coord=(3,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3,), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x > 0.000000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# recomputing reachset
# PolyObserver(x, <flowstar.reachability.Reach object at 0x7f725886cc80>, 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f72587f3770>
#  ==> creating ContextSignal with coord=(3,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3,), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y < 3.50000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# recomputing reachset
# PolyObserver(-y + 3.5000000000000000?, <flowstar.reachability.Reach object at 0x7f725886cc80>, 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725888cd60>
#  ==> creating ContextSignal with coord=(3,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3,), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y > 1.75000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# recomputing reachset
# PolyObserver(y - 1.7500000000000000?, <flowstar.reachability.Reach object at 0x7f725886cc80>, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725870b050>
#  ==> creating ContextSignal with coord=(3,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3,), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0), signal = <function base_context_signal.<locals>.<lambda> at 0x7f7257d523b0>, reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x < 0.300000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# calling reach with y0 = ['[0.20000000000000001 .. 0.40000000000000003]', '[2.0000000000000000 .. 2.5000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.2..0.4]
# C = [2.0..2.5]
# contexts = ['[0.2..0.4]', '[2.0..2.5]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# PolyObserver(-x + 0.29999999999999999?, <flowstar.reachability.Reach object at 0x7f725886c9b0>, -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7258917b00>
#  ==> creating ContextSignal with coord=(0, 0), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x > 0.000000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# recomputing reachset
# PolyObserver(x, <flowstar.reachability.Reach object at 0x7f725886c9b0>, 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f72587f38a0>
#  ==> creating ContextSignal with coord=(0, 0), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y < 3.50000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# recomputing reachset
# PolyObserver(-y + 3.5000000000000000?, <flowstar.reachability.Reach object at 0x7f725886c9b0>, 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f72587f3180>
#  ==> creating ContextSignal with coord=(0, 0), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y > 1.75000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# recomputing reachset
# PolyObserver(y - 1.7500000000000000?, <flowstar.reachability.Reach object at 0x7f725886c9b0>, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725888c8a0>
#  ==> creating ContextSignal with coord=(0, 0), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 1), signal = <function base_context_signal.<locals>.<lambda> at 0x7f7257d523b0>, reach_tree = None
#  ==> creating ContextSignal with coord=(0, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x < 0.300000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# recomputing reachset
# PolyObserver(-x + 0.29999999999999999?, <flowstar.reachability.Reach object at 0x7f725886c9b0>, -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7258917510>
#  ==> creating ContextSignal with coord=(0, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x > 0.000000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# recomputing reachset
# PolyObserver(x, <flowstar.reachability.Reach object at 0x7f725886c9b0>, 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f72589be2b0>
#  ==> creating ContextSignal with coord=(0, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y < 3.50000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# recomputing reachset
# PolyObserver(-y + 3.5000000000000000?, <flowstar.reachability.Reach object at 0x7f725886c9b0>, 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f72589bed60>
#  ==> creating ContextSignal with coord=(0, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y > 1.75000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# recomputing reachset
# PolyObserver(y - 1.7500000000000000?, <flowstar.reachability.Reach object at 0x7f725886c9b0>, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f72589be8a0>
#  ==> creating ContextSignal with coord=(0, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 2), signal = <function base_context_signal.<locals>.<lambda> at 0x7f7257d523b0>, reach_tree = None
#  ==> creating ContextSignal with coord=(0, 2), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x < 0.300000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# recomputing reachset
# PolyObserver(-x + 0.29999999999999999?, <flowstar.reachability.Reach object at 0x7f725886c9b0>, -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f72589be3e0>
#  ==> creating ContextSignal with coord=(0, 2), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 2), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x > 0.000000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# recomputing reachset
# PolyObserver(x, <flowstar.reachability.Reach object at 0x7f725886c9b0>, 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f72589be050>
#  ==> creating ContextSignal with coord=(0, 2), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 2), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y < 3.50000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# recomputing reachset
# PolyObserver(-y + 3.5000000000000000?, <flowstar.reachability.Reach object at 0x7f725886c9b0>, 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f72589beb00>
#  ==> creating ContextSignal with coord=(0, 2), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 2), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y > 1.75000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# recomputing reachset
# PolyObserver(y - 1.7500000000000000?, <flowstar.reachability.Reach object at 0x7f725886c9b0>, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f72589be770>
#  ==> creating ContextSignal with coord=(0, 2), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 2), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 2), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 3), signal = <function base_context_signal.<locals>.<lambda> at 0x7f7257d523b0>, reach_tree = None
#  ==> creating ContextSignal with coord=(0, 3), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x < 0.300000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# recomputing reachset
# PolyObserver(-x + 0.29999999999999999?, <flowstar.reachability.Reach object at 0x7f725886c9b0>, -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725898de90>
#  ==> creating ContextSignal with coord=(0, 3), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 3), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x > 0.000000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# recomputing reachset
# PolyObserver(x, <flowstar.reachability.Reach object at 0x7f725886c9b0>, 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725898dd60>
#  ==> creating ContextSignal with coord=(0, 3), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 3), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y < 3.50000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# recomputing reachset
# PolyObserver(-y + 3.5000000000000000?, <flowstar.reachability.Reach object at 0x7f725886c9b0>, 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725898db00>
#  ==> creating ContextSignal with coord=(0, 3), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 3), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y > 1.75000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# recomputing reachset
# PolyObserver(y - 1.7500000000000000?, <flowstar.reachability.Reach object at 0x7f725886c9b0>, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725898d510>
#  ==> creating ContextSignal with coord=(0, 3), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 3), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 3), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 0), signal = <function base_context_signal.<locals>.<lambda> at 0x7f7257d523b0>, reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x < 0.300000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# calling reach with y0 = ['[0.20000000000000001 .. 0.30000000000000005]', '[2.0000000000000000 .. 2.2500000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [x, y]
# C = [0.2..0.30000000000000004]
# C = [2.0..2.25]
# contexts = ['[0.2..0.30000000000000004]', '[2.0..2.25]']
# statics  = []
# assigning system with dimension 2
# resulting system has dimension 2
# run within tmv args
# integrationScheme = 2
# recomputing reachset
# PolyObserver(-x + 0.29999999999999999?, <flowstar.reachability.Reach object at 0x7f725886c8c0>, -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f72589352b0>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 2.09 seconds
# roots = [[0.0000000000000000 .. 5.0019999999990006]]
# domain = [0.0000000000000000 .. 5.0020000000000007]
# roots = [[0.0000000000000000 .. 5.0019999999990006]]
# seg_domain = [0.0000000000000000 .. 5.0020000000000007]
# roots = [[0.0000000000000000 .. 5.0019999999990006]]
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(0, 0, 0), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x > 0.000000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# recomputing reachset
# PolyObserver(x, <flowstar.reachability.Reach object at 0x7f725886c8c0>, 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f725a02b510>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.04 seconds
# roots = []
# domain = [0.0000000000000000 .. 5.0020000000000007]
# roots = []
# seg_domain = [0.0000000000000000 .. 5.0020000000000007]
# roots = []
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(0, 0, 0), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y < 3.50000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# recomputing reachset
# PolyObserver(-y + 3.5000000000000000?, <flowstar.reachability.Reach object at 0x7f725886c8c0>, 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f72589bec30>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.06 seconds
# roots = [[3.7856484422681337 .. 5.0019999999990006]]
# domain = [0.0000000000000000 .. 5.0020000000000007]
# roots = [[3.7856484422681337 .. 5.0019999999990006]]
# seg_domain = [0.0000000000000000 .. 5.0020000000000007]
# roots = [[3.7856484422681337 .. 5.0019999999990006]]
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(0, 0, 0), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 0), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y > 1.75000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# recomputing reachset
# PolyObserver(y - 1.7500000000000000?, <flowstar.reachability.Reach object at 0x7f725886c8c0>, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f72589be510>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.04 seconds
# roots = []
# domain = [0.0000000000000000 .. 5.0020000000000007]
# roots = []
# seg_domain = [0.0000000000000000 .. 5.0020000000000007]
# roots = []
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(0, 0, 0), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 0), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 0), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 1), signal = <function base_context_signal.<locals>.<lambda> at 0x7f7257d523b0>, reach_tree = None
#  ==> creating ContextSignal with coord=(0, 0, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x < 0.300000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# recomputing reachset
# PolyObserver(-x + 0.29999999999999999?, <flowstar.reachability.Reach object at 0x7f725886c8c0>, -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257fecd60>
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.09 seconds
# roots = [[0.0000000000000000 .. 5.0019999999990006]]
# domain = [0.0000000000000000 .. 5.0020000000000007]
# roots = [[0.0000000000000000 .. 5.0019999999990006]]
# seg_domain = [0.0000000000000000 .. 5.0020000000000007]
# roots = [[0.0000000000000000 .. 5.0019999999990006]]
# signal given bool roots: 1 items in 0.00 seconds
#  ==> creating ContextSignal with coord=(0, 0, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
# ...
# recomputing reachset
# PolyObserver(y - 1.7500000000000000?, <flowstar.reachability.Reach object at 0x7f7257c759b0>, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257bf93e0>
#  ==> creating ContextSignal with coord=(3, 3, 0), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 0), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 0), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 1), signal = <function base_context_signal.<locals>.<lambda> at 0x7f7257d523b0>, reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x < 0.300000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# recomputing reachset
# PolyObserver(-x + 0.29999999999999999?, <flowstar.reachability.Reach object at 0x7f7257c759b0>, -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257bf98a0>
#  ==> creating ContextSignal with coord=(3, 3, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x > 0.000000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# recomputing reachset
# PolyObserver(x, <flowstar.reachability.Reach object at 0x7f7257c759b0>, 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257bf9c30>
#  ==> creating ContextSignal with coord=(3, 3, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y < 3.50000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# recomputing reachset
# PolyObserver(-y + 3.5000000000000000?, <flowstar.reachability.Reach object at 0x7f7257c759b0>, 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257bf9e90>
#  ==> creating ContextSignal with coord=(3, 3, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 1), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y > 1.75000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# recomputing reachset
# PolyObserver(y - 1.7500000000000000?, <flowstar.reachability.Reach object at 0x7f7257c759b0>, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257bf9b00>
#  ==> creating ContextSignal with coord=(3, 3, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 1), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 2), signal = <function base_context_signal.<locals>.<lambda> at 0x7f7257d523b0>, reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 2), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x < 0.300000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# recomputing reachset
# PolyObserver(-x + 0.29999999999999999?, <flowstar.reachability.Reach object at 0x7f7257c759b0>, -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257bf9640>
#  ==> creating ContextSignal with coord=(3, 3, 2), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 2), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x > 0.000000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# recomputing reachset
# PolyObserver(x, <flowstar.reachability.Reach object at 0x7f7257c759b0>, 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257bf9510>
#  ==> creating ContextSignal with coord=(3, 3, 2), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 2), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y < 3.50000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# recomputing reachset
# PolyObserver(-y + 3.5000000000000000?, <flowstar.reachability.Reach object at 0x7f7257c759b0>, 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257bf92b0>
#  ==> creating ContextSignal with coord=(3, 3, 2), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 2), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y > 1.75000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# recomputing reachset
# PolyObserver(y - 1.7500000000000000?, <flowstar.reachability.Reach object at 0x7f7257c759b0>, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257b91050>
#  ==> creating ContextSignal with coord=(3, 3, 2), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 2), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 2), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 3), signal = <function base_context_signal.<locals>.<lambda> at 0x7f7257d523b0>, reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 3), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x < 0.300000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# recomputing reachset
# PolyObserver(-x + 0.29999999999999999?, <flowstar.reachability.Reach object at 0x7f7257c759b0>, -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -0.29999999999999999?*x^2*y + 0.59999999999999998?*x^2 + 0.2400000000000000?*x*y - 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257b912b0>
#  ==> creating ContextSignal with coord=(3, 3, 3), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 3), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(x > 0.000000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# recomputing reachset
# PolyObserver(x, <flowstar.reachability.Reach object at 0x7f7257c759b0>, 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257b91c30>
#  ==> creating ContextSignal with coord=(3, 3, 3), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 3), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y < 3.50000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# recomputing reachset
# PolyObserver(-y + 3.5000000000000000?, <flowstar.reachability.Reach object at 0x7f7257c759b0>, 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x^2*y - 1.6000000000000001?*x*y + 0.050000000000000003?*y^2 + 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257b919d0>
#  ==> creating ContextSignal with coord=(3, 3, 3), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 3), signal = functools.partial(<bound method Atomic.signal_fn of Atomic(y > 1.75000000000000)>, ctx_mask=None, order=6, step=(0.0100000000000000, 0.500000000000000), precondition=1, estimation=0.0000100000000000000, integrationScheme=2, cutoff_threshold=1.00000000000000e-10, symbolic_composition=True, initial_form=<InitialForm.SPLIT_VARS: 3>), reach_tree = <lbuc.context_signals.ReachTree object at 0x7f725852b750>
# recomputing reachset
# PolyObserver(y - 1.7500000000000000?, <flowstar.reachability.Reach object at 0x7f7257c759b0>, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y, symbolic_composition=True, tentative_unpreconditioning=True, mask=None)
# fprime = -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y
# setting reach level to 0
# === in signal_fn ===
# observer = <flowstar.observers.RestrictedObserver object at 0x7f7257b91770>
#  ==> creating ContextSignal with coord=(3, 3, 3), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 3), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
#  ==> creating ContextSignal with coord=(3, 3, 3), signal = Signal([0.0000000000000000 .. -0.0000000000000000], [], mask=None), reach_tree = None
# Graphics object consisting of 1 graphics primitive
