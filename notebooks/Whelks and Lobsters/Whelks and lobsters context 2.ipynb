# %% [markdown]
# # Whelks and lobsters -- context operator

# %% [markdown]
# ## The system

# %%
R.<x,y> = QQ[]

# %%
from ulbc import *

# %%
us = [x,y]
k=RIF(0.8); b=RIF(0.6); c=RIF(0.3); e=RIF(0.05); f=RIF(2)
vf = vector([b*x*(RIF(1)-x) - c*x*(k-x)*y,
            -e*y*(RIF(1)+y)+f*x*(k-x)*y])
v0 = [RIF(0.5), RIF(2.0)]
v1 = [RIF(0.4), RIF(2.5)]
v2 = [RIF(1,1.2), RIF(4,6)]

# %%
v3 = [RIF(1,1.1), RIF(4,5)]

# %%
p = streamline_plot(tuple(vf),(x,0,1.5),(y,0,8), color='grey')\
    + point(v0, size=100, marker='X', color='red')\
    + point(v1, size=100, marker='X', color='green')\
    + polygon([(v3[0].lower(), v3[1].lower()),
               (v3[0].lower(), v3[1].upper()),
               (v3[0].upper(), v3[1].upper()),
               (v3[0].upper(), v3[1].lower())],
              color='orange')\
    + region_plot((lambda x, y: (x - 1)^2 + y^2 - 0.2 < 0),
                  (x, 0, 1.5),
                  (y, 0, 8),
                  incol='pink', plot_points=500, bordercol='red')
p.set_aspect_ratio(1/6)
p.show()
# Out:
# Graphics object consisting of 6 graphics primitives

# %% [markdown]
# ## Simple signal

# %%
P = Atomic((x - 1)^2 + y^2 - 0.2)

# %%
sig = P.signal_for_system(vf, v3, 5, order=5, step=0.01,
                    precondition=1,
                    estimation=1e-3,
                    integrationScheme=2,
                    cutoff_threshold=1e-5)
sig.plot()
# Out:
# Computed 501 flowpipes in 2.43694710732 sec
# Prepared for plotting in 1.26907372475 sec
# domain = [0.00000000000000000 .. 5.0000000000000009]
# roots = [[1.4278780504788519 .. 2.6200000000000161]]
#   J  = [0.00000000000000000 .. 1.4278780504788520]
# f(J) = [0.00063228197608383718 .. 24.904302744153416]
#   J  = [2.6200000000000160 .. 5.0000000000000009]
# f(J) = [-0.22912887659251774 .. 0.0014731635816359890]
# Monitored signal 0.246024370193 sec
# Graphics object consisting of 2 graphics primitives

# %%
sig = P.signal_for_system(vf, v3, 5, order=5, step=0.01,
                    precondition=1,
                    estimation=1e-3,
                    integrationScheme=2,
                    cutoff_threshold=1e-5,
                    symbolic_composition=True)
sig.plot()
# Out:
# Computed 501 flowpipes in 2.45989608765 sec
# Prepared for plotting in 1.17993187904 sec
# domain = [0.00000000000000000 .. 5.0000000000000009]
# roots = [[1.6679767143790413 .. 1.6700000000000015],
#  [1.6741848470338667 .. 2.3200000000000092]]
#   J  = [0.00000000000000000 .. 1.6679767143790414]
# f(J) = [-0.000013361748243909469 .. 24.810000000000010]
#   J  = [1.6700000000000014 .. 1.6741848470338668]
# f(J) = [-0.0030347699162351187 .. 0.50079420254075380]
#   J  = [2.3200000000000091 .. 5.0000000000000009]
# f(J) = [-0.19790309605503754 .. 0.00074757056277772333]
# Monitored signal 3.315980196 sec
# Graphics object consisting of 2 graphics primitives

# %%
sig = P.signal_for_system(vf, v3, 5, order=5, step=(0.01, 0.5),
                    precondition=1,
                    estimation=1e-3,
                    integrationScheme=2,
                    cutoff_threshold=1e-5,
                    symbolic_composition=True,
                    verbosity=3)
sig.plot()
# Out:
# Computed 66 flowpipes in 0.354666948318 sec
# Prepared for plotting in 0.278243780136 sec
# domain = [0.00000000000000000 .. 5.0000000000000000]
# roots = [[1.5148129129113059 .. 1.5184870921717871],
#  [1.5670945148659607 .. 2.3236493583492095]]
#   J  = [0.00000000000000000 .. 1.5148129129113060]
# f(J) = [-0.00096747812515832199 .. 24.810000000000010]
#   J  = [1.5184870921717870 .. 1.5670945148659608]
# f(J) = [-0.0072411469951589591 .. 0.86605476363196832]
#   J  = [2.3236493583492094 .. 5.0000000000000000]
# f(J) = [-0.19915451945373667 .. 0.023968375926044960]
# Monitored signal 0.670851230621 sec
# Graphics object consisting of 2 graphics primitives

# %%
sig2 = Atomic(x - 1.15).signal_for_system(vf, v3, 5, order=5, step=(0.01, 0.5),
                                   precondition=1,
                                   estimation=1e-3,
                                   integrationScheme=2,
                                   cutoff_threshold=1e-5)
sig2.plot()
# Out:
# Computed 66 flowpipes in 0.407451152802 sec
# Prepared for plotting in 0.23334980011 sec
# domain = [0.00000000000000000 .. 5.0000000000000009]
# roots = [[0.10343749999999997 .. 0.76510436099420421],
#  [2.4878883481318871 .. 3.0546524239379834]]
#   J  = [0.00000000000000000 .. 0.10343749999999998]
# f(J) = [-0.15000118745448177 .. -0.0050948730237294626]
#   J  = [0.76510436099420420 .. 2.4878883481318872]
# f(J) = [0.00081812236518552516 .. 0.23331653224762694]
#   J  = [3.0546524239379833 .. 5.0000000000000009]
# f(J) = [-0.11440814829967195 .. 0.0013367637732706328]
# Monitored signal 0.0426061153412 sec
# Graphics object consisting of 2 graphics primitives

# %%
sig2 = Atomic(x - 1.15).signal_for_system(vf, v3, 5, order=5, step=(0.01, 0.5),
                                   precondition=1,
                                   estimation=1e-3,
                                   integrationScheme=2,
                                   cutoff_threshold=1e-5,
                                   symbolic_composition=True)
sig2.plot()
# Out:
# Computed 66 flowpipes in 0.400904893875 sec
# Prepared for plotting in 0.240082740784 sec
# domain = [0.00000000000000000 .. 5.0000000000000000]
# roots = [[0.10633378976545114 .. 0.73619713464944559],
#  [2.5906952982047100 .. 2.9719646571903078]]
#   J  = [0.00000000000000000 .. 0.10633378976545115]
# f(J) = [-0.14999999999999994 .. -0.0039992475348420309]
#   J  = [0.73619713464944558 .. 2.5906952982047101]
# f(J) = [-0.00066566433754494410 .. 0.22592704294990227]
#   J  = [2.9719646571903077 .. 5.0000000000000000]
# f(J) = [-0.11119669081481020 .. 0.00012671753804259501]
# Monitored signal 0.0367453098297 sec
# Graphics object consisting of 2 graphics primitives

# %%
reach = Reach(vf, v3, 10,
              order=5, step=(0.01, 0.5),
              precondition=1,
              estimation=1e-3,
              integrationScheme=2,
              cutoff_threshold=1e-7)

# %%
reach.wplot('x', 'y')
# Out:
# <wand.image.Image: 87b4e3f 'PS' (720x504)>

# %% [markdown]
# ### Polynomial plot

# %%
reach.symbolic_composition = True

# %%
p + reach.sage_interval_plot('x', 'y',
                             poly=(x - 1)^2 + y^2 - 0.2,
                             aspect_ratio='automatic')
# Out:
# Graphics object consisting of 106 graphics primitives

# %%
p1 = reach.sage_plot((x - 1)^2 + y^2 - 0.2, (1, 3))
p1
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
roots = reach.roots(P.p, P.dpdt(vf), verbosity=10)
# Out:
# reached detect roots t=[0.0..0.0] + [0.0..0.03125]
# reached detect roots t=[0.03125..0.03125] + [0.0..0.034375]
# reached detect roots t=[0.065625..0.065625] + [0.0..0.0378125]
# reached detect roots t=[0.1034375..0.1034375] + [0.0..0.04159375]
# reached detect roots t=[0.14503125..0.14503125] + [0.0..0.045753125]
# reached detect roots t=[0.190784375..0.190784375] + [0.0..0.02516421875]
# reached detect roots t=[0.21594859375..0.21594859375] + [0.0..0.027680640625]
# reached detect roots t=[0.243629234375..0.243629234375] + [0.0..0.0304487046875]
# reached detect roots t=[0.274077939062..0.274077939063] + [0.0..0.0334935751563]
# reached detect roots t=[0.307571514219..0.307571514219] + [0.0..0.0368429326719]
# reached detect roots t=[0.344414446891..0.344414446891] + [0.0..0.0405272259391]
# reached detect roots t=[0.38494167283..0.38494167283] + [0.0..0.044579948533]
# reached detect roots t=[0.429521621363..0.429521621363] + [0.0..0.0245189716931]
# reached detect roots t=[0.454040593056..0.454040593056] + [0.0..0.0269708688624]
# reached detect roots t=[0.481011461918..0.481011461918] + [0.0..0.0296679557487]
# reached detect roots t=[0.510679417667..0.510679417667] + [0.0..0.0326347513236]
# reached detect roots t=[0.54331416899..0.54331416899] + [0.0..0.0358982264559]
# reached detect roots t=[0.579212395446..0.579212395446] + [0.0..0.0394880491015]
# reached detect roots t=[0.618700444548..0.618700444548] + [0.0..0.0434368540117]
# reached detect roots t=[0.66213729856..0.66213729856] + [0.0..0.0477805394128]
# reached detect roots t=[0.709917837972..0.709917837972] + [0.0..0.0262792966771]
# reached detect roots t=[0.736197134649..0.736197134649] + [0.0..0.0289072263448]
# reached detect roots t=[0.765104360994..0.765104360994] + [0.0..0.0317979489792]
# reached detect roots t=[0.796902309973..0.796902309973] + [0.0..0.0349777438772]
# reached detect roots t=[0.831880053851..0.831880053851] + [0.0..0.0384755182649]
# reached detect roots t=[0.870355572115..0.870355572115] + [0.0..0.0423230700914]
# reached detect roots t=[0.912678642207..0.912678642207] + [0.0..0.0465553771005]
# reached detect roots t=[0.959234019307..0.959234019307] + [0.0..0.0512109148105]
# reached detect roots t=[1.01044493412..1.01044493412] + [0.0..0.0563320062916]
# reached detect roots t=[1.06677694041..1.06677694041] + [0.0..0.0619652069208]
# reached detect roots t=[1.12874214733..1.12874214733] + [0.0..0.0340808638064]
# reached detect roots t=[1.16282301114..1.16282301114] + [0.0..0.0374889501871]
# reached detect roots t=[1.20031196132..1.20031196132] + [0.0..0.0412378452058]
# reached detect roots t=[1.24154980653..1.24154980653] + [0.0..0.0453616297263]
# reached detect roots t=[1.28691143626..1.28691143626] + [0.0..0.049897792699]
# reached detect roots t=[1.33680922895..1.33680922895] + [0.0..0.0548875719689]
# reached detect roots t=[1.39169680092..1.39169680092] + [0.0..0.0603763291658]
# detect_roots(T0=[0.0..0.0603763291658], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0603763291658]
# M = [0.0301881645829..0.0301881645829]
# fI = [0.133490487768..1.04190534375]
# failed! on:
# M=[0.0301881645829..0.0301881645829]
# extdiv(T=[-0.0301881645829..0.0301881645829], Tu=[-0.0301881645829..0.0301881645829], split=False, T=[-0.0301881645829..0.0301881645829], fI=[0.133490487768..1.04190534375], fP=[-3.09326502824..-0.428457197657])
# reached detect roots t=[1.45207313009..1.45207313009] + [0.0..0.0664139620823]
# detect_roots(T0=[0.0..0.0664139620823], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0664139620823]
# M = [0.0332069810412..0.0332069810412]
# fI = [0.0777913196421..0.880745764759]
# T = [0.062773403496..0.0664139620823]
# M = [0.0645936827891..0.0645936827891]
# fI = [-0.00253023000158..0.866427671087]
# Tfinal = [0.062773403496..0.0664139620823]
# root on boundary!
# reached detect roots t=[1.51848709217..1.51848709217] + [0.0..0.0730553582906]
# detect_roots(T0=[0.0..0.0730553582906], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0730553582906]
# M = [0.0365276791453..0.0365276791453]
# fI = [0.0264360170245..0.731919505927]
# T = [0.0485331655081..0.0730553582906]
# M = [0.0607942618993..0.0607942618993]
# fI = [-0.0255829149044..0.722405974069]
# Tfinal = [0.0485331655081..0.0730553582906]
# root on boundary!
# reached detect roots t=[1.59154245046..1.59154245046] + [0.0..0.0803608941196]
# detect_roots(T0=[0.0..0.0803608941196], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0803608941196]
# M = [0.0401804470598..0.0401804470598]
# fI = [-0.019978878987..0.596309572939]
# Tfinal = [-0.0..0.0803608941196]
# root on boundary!
# merging intervals:
# [1.59154245046..1.67190334458]
# [1.56702025768..1.59154245046]
# reached detect roots t=[1.67190334458..1.67190334458] + [0.0..0.0883969835316]
# detect_roots(T0=[0.0..0.0883969835316], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0883969835316]
# M = [0.0441984917658..0.0441984917658]
# fI = [-0.0583494235644..0.47170463458]
# Tfinal = [-0.0..0.0883969835316]
# root on boundary!
# merging intervals:
# [1.67190334458..1.76030032811]
# [1.56702025768..1.67190334458]
# reached detect roots t=[1.76030032811..1.76030032811] + [0.0..0.0972366818848]
# detect_roots(T0=[0.0..0.0972366818848], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0972366818848]
# M = [0.0486183409424..0.0486183409424]
# fI = [-0.0892476583544..0.358948590564]
# Tfinal = [-0.0..0.0972366818848]
# root on boundary!
# merging intervals:
# [1.76030032811..1.85753701]
# [1.56702025768..1.76030032811]
# reached detect roots t=[1.85753701..1.85753701] + [0.0..0.106960350073]
# detect_roots(T0=[0.0..0.106960350073], epsilon=1e-05, verbosity=10)
# T = [0.0..0.106960350073]
# M = [0.0534801750366..0.0534801750366]
# fI = [-0.114391644667..0.259427949765]
# Tfinal = [-0.0..0.106960350073]
# root on boundary!
# merging intervals:
# [1.85753701..1.96449736007]
# [1.56702025768..1.85753701]
# reached detect roots t=[1.96449736007..1.96449736007] + [0.0..0.117656385081]
# detect_roots(T0=[0.0..0.117656385081], epsilon=1e-05, verbosity=10)
# T = [0.0..0.117656385081]
# M = [0.0588281925403..0.0588281925403]
# fI = [-0.134362509108..0.172854869235]
# Tfinal = [-0.0..0.117656385081]
# root on boundary!
# merging intervals:
# [1.96449736007..2.08215374515]
# [1.56702025768..1.96449736007]
# reached detect roots t=[2.08215374515..2.08215374515] + [0.0..0.0647110117943]
# detect_roots(T0=[0.0..0.0647110117943], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0647110117943]
# M = [0.0323555058972..0.0323555058972]
# fI = [-0.131299043967..0.101248184737]
# Tfinal = [-0.0..0.0647110117943]
# root on boundary!
# merging intervals:
# [2.08215374515..2.14686475695]
# [1.56702025768..2.08215374515]
# reached detect roots t=[2.14686475695..2.14686475695] + [0.0..0.0711821129737]
# detect_roots(T0=[0.0..0.0711821129737], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0711821129737]
# M = [0.0355910564869..0.0355910564869]
# fI = [-0.139948931867..0.0670758985246]
# Tfinal = [-0.0..0.0711821129737]
# root on boundary!
# merging intervals:
# [2.14686475695..2.21804686992]
# [1.56702025768..2.14686475695]
# reached detect roots t=[2.21804686992..2.21804686992] + [0.0..0.0783003242711]
# detect_roots(T0=[0.0..0.0783003242711], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0783003242711]
# M = [0.0391501621356..0.0391501621356]
# fI = [-0.147862426772..0.0345595056907]
# Tfinal = [-0.0..0.0783003242711]
# root on boundary!
# merging intervals:
# [2.21804686992..2.29634719419]
# [1.56702025768..2.21804686992]
# reached detect roots t=[2.29634719419..2.29634719419] + [0.0..0.0861303566982]
# detect_roots(T0=[0.0..0.0861303566982], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0861303566982]
# M = [0.0430651783491..0.0430651783491]
# fI = [-0.155026410734..0.0039605919409]
# Tfinal = [-0.0..0.0861303566982]
# root on boundary!
# merging intervals:
# [2.29634719419..2.38247755089]
# [1.56702025768..2.29634719419]
# reached detect roots t=[2.38247755089..2.38247755089] + [0.0..0.094743392368]
# detect_roots(T0=[0.0..0.094743392368], epsilon=1e-05, verbosity=10)
# T = [0.0..0.094743392368]
# M = [0.047371696184..0.047371696184]
# fI = [-0.161447527014..-0.0245022805573]
# failed! on:
# M=[0.047371696184..0.047371696184]
# extdiv(T=[-0.047371696184..0.047371696184], Tu=[-0.047371696184..0.047371696184], split=False, T=[-0.047371696184..0.047371696184], fI=[-0.161447527014..-0.0245022805573], fP=[-0.306140836237..-0.022251442022])
# reached detect roots t=[2.47722094326..2.47722094326] + [0.0..0.104217731605]
# detect_roots(T0=[0.0..0.104217731605], epsilon=1e-05, verbosity=10)
# T = [0.0..0.104217731605]
# M = [0.0521088658024..0.0521088658024]
# fI = [-0.167180601391..-0.0506309841461]
# failed! on:
# M=[0.0521088658024..0.0521088658024]
# extdiv(T=[-0.0521088658024..0.0521088658024], Tu=[-0.0521088658024..0.0521088658024], split=False, T=[-0.0521088658024..0.0521088658024], fI=[-0.167180601391..-0.0506309841461], fP=[-0.253798542808..-0.0156435309111])
# reached detect roots t=[2.58143867486..2.58143867486] + [0.0..0.114639504765]
# reached detect roots t=[2.69607817963..2.69607817963] + [0.0..0.126103455242]
# reached detect roots t=[2.82218163487..2.82218163487] + [0.0..0.138713800766]
# reached detect roots t=[2.96089543564..2.96089543564] + [0.0..0.152585180843]
# reached detect roots t=[3.11348061648..3.11348061648] + [0.0..0.167843698927]
# reached detect roots t=[3.28132431541..3.28132431541] + [0.0..0.18462806882]
# reached detect roots t=[3.46595238422..3.46595238422] + [0.0..0.101545437851]
# reached detect roots t=[3.56749782208..3.56749782208] + [0.0..0.111699981636]
# reached detect roots t=[3.67919780371..3.67919780371] + [0.0..0.122869979799]
# reached detect roots t=[3.80206778351..3.80206778351] + [0.0..0.135156977779]
# reached detect roots t=[3.93722476129..3.93722476129] + [0.0..0.148672675557]
# reached detect roots t=[4.08589743685..4.08589743685] + [0.0..0.163539943113]
# reached detect roots t=[4.24943737996..4.24943737996] + [0.0..0.179893937424]
# reached detect roots t=[4.42933131739..4.42933131739] + [0.0..0.197883331167]
# reached detect roots t=[4.62721464855..4.62721464855] + [0.0..0.217671664283]
# reached detect roots t=[4.84488631284..4.84488631284] + [0.0..0.119719415356]
# reached detect roots t=[4.96460572819..4.96460572819] + [0.0..0.131691356892]
# reached detect roots t=[5.09629708508..5
# <b>limit_output extension: Maximum message size of 10000 exceeded with 11970 characters</b>

# %%
[root.str(style='brackets') for root in roots]
# Out:
# ['[1.5148465335853924 .. 1.5184870921717871]',
#  '[1.5670202576799034 .. 2.3824775508894854]']

# %%
J = RIF(1.5184870921717871, 1.5184870921717871)

# %%
J.center()
# Out:
# 1.51848709217179

# %%
reach.eval_poly(Poly(P.p), J.center())
# Out:
# 0.?

# %%
reach.symbolic_composition = False

# %%
p + reach.sage_interval_plot('x', 'y',
                             poly=(x - 1)^2 + y^2 - 0.2,
                             aspect_ratio='automatic')
# Out:
# Graphics object consisting of 106 graphics primitives

# %%
p2 = reach.sage_plot((x - 1)^2 + y^2 - 0.2, (1, 3),
                     color=['orange', 'magenta'])
p2
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
roots = reach.roots(P.p, P.dpdt(vf))

# %%
[root.str(style='brackets') for root in roots]
# Out:
# ['[1.4390681573910084 .. 2.4772209432575254]']

# %%
p1 + p2 + sig.to_domain(RIF(1, 3)).plot(aspect_ratio='automatic')
# Out:
# Graphics object consisting of 6 graphics primitives

# %% [markdown]
# ### $x \ge 1.15$

# %%
q = streamline_plot(tuple(vf),(x,0,1.5),(y,0,8), color='grey')\
    + polygon([(v3[0].lower(), v3[1].lower()),
               (v3[0].lower(), v3[1].upper()),
               (v3[0].upper(), v3[1].upper()),
               (v3[0].upper(), v3[1].lower())],
              color='orange')\
    + region_plot((lambda x, y: x - 1.15 < 0),
                  (x, 0, 1.5),
                  (y, 0, 8),
                  incol='pink', plot_points=500, bordercol='red')
q.set_aspect_ratio(1/6)

# %%
q + reach.sage_interval_plot('x', 'y',
                             poly=x - 1.15,
                             aspect_ratio='automatic')
# Out:
# Graphics object consisting of 103 graphics primitives

# %%
reach.symbolic_composition = True

# %%
q1 = reach.sage_plot(x - 1.15, (0, 3.5))
q1
# Out:
# Graphics object consisting of 6 graphics primitives

# %%
roots = reach.roots(P.p, P.dpdt(vf))

# %%
[root.str(style='brackets') for root in roots]
# Out:
# ['[1.5148465335853924 .. 1.5184870921717871]',
#  '[1.5670202576799034 .. 2.3824775508894854]']

# %%
reach.symbolic_composition = False

# %%
q2 = reach.sage_plot(x - 1.15, (0, 3.5),
                     color=['orange', 'magenta'])
q2
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
roots = reach.roots(P.p, P.dpdt(vf))

# %%
[root.str(style='brackets') for root in roots]
# Out:
# ['[1.4390681573910084 .. 2.4772209432575254]']

# %%
q1 + q2 + sig2.to_domain(RIF(0, 3.5)).plot(aspect_ratio='automatic')
# Out:
# Graphics object consisting of 10 graphics primitives

# %% [markdown]
# ## Context

# %%
kwargs = dict(
    order=5, step=(0.01, 0.5),
    precondition=1,
    estimation=1e-3,
    integrationScheme=2,
    cutoff_threshold=1e-5,
    verbosity=0,
    epsilon_ctx=0.1,
#    symbolic_composition=True,
)
args = (vf, v3, 7)

# %%
{x: RIF(0.05,0.1)} >> G(RIF(0,0.2), P)
# Out:
# C({x: [0.050000000000000002 .. 0.10000000000000001]}, G([0.00000000000000000 .. 0.20000000000000002], Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)))

# %%
sig = ({x: RIF(0.05,0.1)} >> G(RIF(0,0.2), P)
       ).signal_for_system(vf, v3, 10, **kwargs)
# Out:
# Computed 95 flowpipes in 0.421810150146 sec
# Prepared for plotting in 0.230690956116 sec
# Computed 11 flowpipes in 0.0755889415741 sec
# Prepared for plotting in 0.0389437675476 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = []
#   J  = [0.00000000000000000 .. 0.20100000000000002]
# f(J) = [2.4500681154031562 .. 25.113294284375244]
# Monitored signal 0.00837326049805 sec
# Computed 11 flowpipes in 0.0841228961945 sec
# Prepared for plotting in 0.0429327487946 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = []
#   J  = [0.00000000000000000 .. 0.20100000000000002]
# f(J) = [0.36766214382017847 .. 15.584001914492188]
# Monitored signal 0.00744938850403 sec
# Computed 11 flowpipes in 0.0825779438019 sec
# Prepared for plotting in 0.0448627471924 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = [[0.0081983870893337675 .. 0.20199999999900001]]
#   J  = [0.00000000000000000 .. 0.0081983870893337676]
# f(J) = [0.027748803006220290 .. 8.5064646332237626]
# 0 at 0.201000000000001
# Monitored signal 0.0147821903229 sec
# Computed 10 flowpipes in 0.0806329250336 sec
# Prepared for plotting in 0.0371427536011 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = [[0.13369994292098977 .. 0.20199999999900001]]
#   J  = [0.00000000000000000 .. 0.13369994292098978]
# f(J) = [0.0057033131434636175 .. 8.5186480314454159]
# 0 at 0.201000000000001
# Monitored signal 0.0197823047638 sec
# Computed 8 flowpipes in 0.0743768215179 sec
# Prepared for plotting in 0.0314779281616 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = []
#   J  = [0.00000000000000000 .. 0.20100000000000002]
# f(J) = [0.19175325799869569 .. 8.4580835553224994]
# Monitored signal 0.00824618339539 sec
# Computed 8 flowpipes in 0.0763268470764 sec
# Prepared for plotting in 0.0329608917236 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = [[0.18637911108411137 .. 0.19995579687500012]]
#   J  = [0.00000000000000000 .. 0.18637911108411138]
# f(J) = [0.0090096015581624389 .. 6.0101611869484684]
#   J  = [0.19995579687500011 .. 0.20100000000000002]
# f(J) = [-0.064309561601343102 .. 4.1462673256363676]
# Monitored signal 0.014172077179 sec
# Computed 8 flowpipes in 0.0716760158539 sec
# Prepared for plotting in 0.03169465065 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = []
#   J  = [0.00000000000000000 .. 0.20100000000000002]
# f(J) = [0.10408054115152198 .. 6.0027258949145886]
# Monitored signal 0.00701832771301 sec
# Computed 8 flowpipes in 0.0759871006012 sec
# Prepared for plotting in 0.0221257209778 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = []
#   J  = [0.00000000000000000 .. 0.20100000000000002]
# f(J) = [0.00059200274345200254 .. 5.0488942901025747]
# Monitored signal 0.00645017623901 sec
# Computed 8 flowpipes in 0.0580110549927 sec
# Prepared for plotting in 0.0244576931 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = [[0.024801789871789894 .. 0.20199999999900001]]
#   J  = [0.00000000000000000 .. 0.024801789871789895]
# f(J) = [0.014901520528696365 .. 4.2014513090855755]
# 0 at 0.201000000000001
# Monitored signal 0.00985431671143 sec
# Computed 7 flowpipes in 0.0545680522919 sec
# Prepared for plotting in 0.01886677742 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = [[0.10021842919164469 .. 0.20199999999900001]]
#   J  = [0.00000000000000000 .. 0.10021842919164470]
# f(J) = [0.0080675308377050058 .. 4.1963866290293384]
# 0 at 0.201000000000001
# Monitored signal 0.0119152069092 sec
# Computed 7 flowpipes in 0.05326795578 sec
# Prepared for plotting in 0.0187368392944 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = [[0.14340664843806252 .. 0.14503125000000006],
#  [0.16325453146751192 .. 0.20199999999900001]]
#   J  = [0.00000000000000000 .. 0.14340664843806253]
# f(J) = [0.0014744809221008958 .. 4.1954884189755771]
#   J  = [0.14503125000000005 .. 0.16325453146751193]
# f(J) = [-0.0065673095412630001 .. 3.3098665561766532]
# 0 at 0.201000000000001
# Monitored signal 0.0176992416382 sec
# Computed 6 flowpipes in 0.0455119609833 sec
# Prepared for plotting in 0.0148987770081 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = [[0.12556297267864111 .. 0.20199999999900001]]
#   J  = [0.00000000000000000 .. 0.12556297267864112]
# f(J) = [0.027038677516147191 .. 3.4163940032925560]
# 0 at 0.201000000000001
# Monitored signal 0.00916624069214 sec
# Computed 6 flowpipes in 0.0533571243286 sec
# Prepared for plotting in 0.01651263237 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = [[0.049491343813571342 .. 0.20199999999900001]]
#   J  = [0.00000000000000000 .. 0.049491343813571343]
# f(J) = [0.020949115363104675 .. 2.8873615544512959]
# 0 at 0.201000000000001
# Monitored signal 0.00914025306702 sec
# Computed 6 flowpipes in 0.0448710918427 sec
# Prepared for plotting in 0.0133516788483 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = [[0.095348519249748964 .. 0.20199999999900001]]
#   J  = [0.00000000000000000 .. 0.095348519249748965]
# f(J) = [0.0042322020399497284 .. 2.8865510786798066]
# 0 at 0.201000000000001
# Monitored signal 0.00930428504944 sec
# Computed 6 flowpipes in 0.0651822090149 sec
# Prepared for plotting in 0.0196907520294 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = [[0.064370819024527750 .. 0.20199999999900001]]
#   J  = [0.00000000000000000 .. 0.064370819024527751]
# f(J) = [0.00019204498422431548 .. 2.3240998678461798]
# 0 at 0.201000000000001
# Monitored signal 0.0200791358948 sec
# Computed 6 flowpipes in 0.0617408752441 sec
# Prepared for plotting in 0.0166659355164 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.00697207450867 sec
# Computed 6 flowpipes in 0.0454580783844 sec
# Prepared for plotting in 0.014910697937 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.00582218170166 sec
# Computed 6 flowpipes in 0.0513908863068 sec
# Prepared for plotting in 0.0132048130035 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.00536417961121 sec
# Computed 6 flowpipes in 0.0402739048004 sec
# Prepared for plotting in 0.0123426914215 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.00565934181213 sec
# Computed 6 flowpipes in 0.0430481433868 sec
# Prepared for plotting in 0.0126876831055 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = [[0.017328191748287112 .. 0.20199999999900001]]
#   J  = [0.00000000000000000 .. 0.017328191748287113]
# f(J) = [0.022192812930788174 .. 1.9308853413485192]
# 0 at 0.201000000000001
# Monitored signal 0.00740623474121 sec
# Computed 6 flowpipes in 0.0440151691437 sec
# Prepared for plotting in 0.0122697353363 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.006019115448 sec
# Computed 6 flowpipes in 0.0450809001923 sec
# Prepared for plotting in 0.0112867355347 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.00670337677002 sec
# Computed 6 flowpipes in 0.0462229251862 sec
# Prepared for plotting in 0.011237859726 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.00654315948486 sec
# Computed 5 flowpipes in 0.0404739379883 sec
# Prepared for plotting in 0.00988268852234 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.00552034378052 sec
# Computed 5 flowpipes in 0.0421290397644 sec
# Prepared for plotting in 0.0104167461395 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0061821937561 sec
# Computed 5 flowpipes in 0.0399050712585 sec
# Prepared for plotting in 0.0096287727356 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0049352645874 sec
# Computed 3 flowpipes in 0.0268189907074 sec
# Prepared for plotting in 0.00514364242554 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.00453019142151 sec
# Computed 3 flowpipes in 0.027195930481 sec
# Prepared for plotting in 0.00778961181641 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.00615429878235 sec
# Computed 3 flowpipes in 0.0404539108276 sec
# Prepared for plotting in 0.00790190696716 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0059061050415 sec
# Computed 3 flowpipes in 0.0397329330444 sec
# Prepared for plotting in 0.00791478157043 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.00620126724243 sec
# Computed 3 flowpipes in 0.0338468551636 sec
# Prepared for plotting in 0.00514078140259 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.00412321090698 sec
# Computed 3 flowpipes in 0.0263938903809 sec
# Prepared for plotting in 0.00404286384583 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.00462532043457 sec
# Computed 3 flowpipes in 0.0228071212769 sec
# Prepared for
# <b>limit_output extension: Maximum message size of 10000 exceeded with 11761 characters</b>

# %%
sig.plot()
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# ## Differential Context

# %%
{x: RIF(6,7)} % G(RIF(0,0.2), P)
# Out:
# D({x: [6 .. 7]}, G([0.00000000000000000 .. 0.20000000000000002], Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)))

# %%
# Use symbolic remainders for context jump 
kwargs['integrationScheme'] = 7

# %%
kwargs['verbosity'] = 10

# %%
kwargs['symbolic_composition'] = True

# %%
sig = ({x: RIF(6)} % G(RIF(0,0.2), P)
       ).signal_for_system(vf, v3, 2*pi, **kwargs)
# Out:
# Computed 72 flowpipes in 0.395979881287 sec
# Prepared for plotting in 0.0917439460754 sec
# Flowstar failed!
# I  = [0.00000000000000000 .. 6.2841853071795866]
# fI = ['[0.99999881254552125 .. 1.3743176832705973]', '[0.011496194198696817 .. 5.0000087847057957]']
# C || f(I) = ['[0.99999881254552125 .. 1.3743176832705973]', '[0.011496194198696817 .. 5.0000087847057957]']
#      odes = (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y)
# D || odes = [0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x + 6, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y]
# phi(D || odes, C || f(I)) = None
# bisecting [0.00000000000000000 .. 6.2841853071795866] -> [0.00000000000000000 .. 3.1420926535897933], [3.1420926535897932 .. 6.2841853071795866]
# Computed 14 flowpipes in 0.108999967575 sec
# Prepared for plotting in 0.0351068973541 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = []
#   J  = [0.00000000000000000 .. 0.20100000000000002]
# f(J) = [3.4497292701850641 .. 24.820307312326218]
# Monitored signal 0.0991032123566 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [([0.00000000000000000 .. 0.0010000000000000001], True)])
# sig(0) = True
# Computed 14 flowpipes in 0.152598142624 sec
# Prepared for plotting in 0.0495436191559 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = []
#   J  = [0.00000000000000000 .. 0.20100000000000002]
# f(J) = [2.4514957891820268 .. 18.448960604637585]
# Monitored signal 0.119432210922 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [([0.00000000000000000 .. 0.0010000000000000001], True)])
# sig(0) = True
# Computed 14 flowpipes in 0.108196020126 sec
# Prepared for plotting in 0.0410759449005 sec
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = []
#   J  = [0.00000000000000000 .. 0.20100000000000004]
# f(J) = [1.9662978532526009 .. 15.689966019227516]
# Monitored signal 0.096755027771 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [([0.00000000000000000 .. 0.0010000000000000001], True)])
# sig(0) = True
# Computed 13 flowpipes in 0.0958888530731 sec
# Prepared for plotting in 0.0313558578491 sec
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = []
#   J  = [0.00000000000000000 .. 0.20100000000000004]
# f(J) = [1.7090533378755290 .. 12.954446889565546]
# Monitored signal 0.0838062763214 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [([0.00000000000000000 .. 0.0010000000000000001], True)])
# sig(0) = True
# Computed 13 flowpipes in 0.0928950309753 sec
# Prepared for plotting in 0.0372936725616 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = []
#   J  = [0.00000000000000000 .. 0.20100000000000002]
# f(J) = [1.5660568562085539 .. 10.627348277638675]
# Monitored signal 0.0904252529144 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [([0.00000000000000000 .. 0.0010000000000000001], True)])
# sig(0) = True
# Computed 13 flowpipes in 0.10964679718 sec
# Prepared for plotting in 0.0316197872162 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = []
#   J  = [0.00000000000000000 .. 0.20100000000000002]
# f(J) = [0.57639198903940536 .. 8.6603211658004291]
# Monitored signal 0.0959162712097 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [([0.00000000000000000 .. 0.0010000000000000001], True)])
# sig(0) = True
# Computed 12 flowpipes in 0.106174945831 sec
# Prepared for plotting in 0.0402595996857 sec
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.095392187500000045]]
#   J  = [0.095392187500000044 .. 0.20100000000000004]
# f(J) = [-0.80459290243914683 .. 4.7631880621035761]
# Monitored signal 0.0944314002991 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 11 flowpipes in 0.104027986526 sec
# Prepared for plotting in 0.0340147018433 sec
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.031250000000000000]]
#   J  = [0.031250000000000000 .. 0.20100000000000004]
# f(J) = [-0.52802820562000186 .. 5.6386635255381253]
# Monitored signal 0.0837132930756 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 11 flowpipes in 0.0862190723419 sec
# Prepared for plotting in 0.0275297164917 sec
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = []
#   J  = [0.00000000000000000 .. 0.20100000000000004]
# f(J) = [0.28076774010078631 .. 5.5564988447602462]
# Monitored signal 0.0856652259827 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [([0.00000000000000000 .. 0.0010000000000000001], True)])
# sig(0) = True
# Computed 11 flowpipes in 0.0933899879456 sec
# Prepared for plotting in 0.0211007595062 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = []
#   J  = [0.00000000000000000 .. 0.20100000000000002]
# f(J) = [0.075585577637697104 .. 3.4069033728650072]
# Monitored signal 0.0676121711731 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [([0.00000000000000000 .. 0.0010000000000000001], True)])
# sig(0) = True
# Computed 9 flowpipes in 0.070170879364 sec
# Prepared for plotting in 0.016548871994 sec
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.065625000000000003]]
#   J  = [0.065625000000000002 .. 0.20100000000000004]
# f(J) = [-0.18644319952693031 .. 2.3754430083002998]
# Monitored signal 0.0636992454529 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 9 flowpipes in 0.0690231323242 sec
# Prepared for plotting in 0.0145127773285 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = [[0.023431624785104777 .. 0.031250000000000000]]
#   J  = [0.00000000000000000 .. 0.023431624785104778]
# f(J) = [0.00099150235109744799 .. 2.0864185439691503]
#   J  = [0.031250000000000000 .. 0.20100000000000002]
# f(J) = [-0.024969643325082225 .. 2.3426788374822035]
# Monitored signal 0.0688891410828 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 9 flowpipes in 0.0692131519318 sec
# Prepared for plotting in 0.0173296928406 sec
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = []
#   J  = [0.00000000000000000 .. 0.20100000000000004]
# f(J) = [0.18036779467791885 .. 2.3295894826110435]
# Monitored signal 0.0705552101135 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [([0.00000000000000000 .. 0.0010000000000000001], True)])
# sig(0) = True
# Computed 8 flowpipes in 0.0723819732666 sec
# Prepared for plotting in 0.013439655304 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = []
#   J  = [0.00000000000000000 .. 0.20100000000000002]
# f(J) = [0.10348437670938015 .. 2.2358084281461364]
# Monitored signal 0.0586183071136 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [([0.00000000000000000 .. 0.0010000000000000001], True)])
# sig(0) = True
# Computed 8 flowpipes in 0.0664088726044 sec
# Prepared for plotting in 0.0147979259491 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = [[0.00000000000000000 .. 0.031250000000000000]]
#   J  = [0.031250000000000000 .. 0.20100000000000002]
# f(J) = [-0.057938565528493636 .. 2.1268553349422535]
# Monitored signal 0.063490152359 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 8 flowpipes in 0.0658178329468 sec
# Prepared for plotting in 0.0124688148499 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = []
#   J  = [0.00000000000000000 .. 0.20100000000000002]
# f(J) = [0.028576798544665688 .. 2.1176488412128478]
# Monitored signal 0.0582273006439 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [([0.00000000000000000 .. 0.0010000000000000001], True)])
# sig(0) = True
# Computed 8 flowpipes in 0.0613760948181 sec
# Prepared for plotting in 0.0107426643372 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = [[0.00000000000000000 .. 0.031250000000000000]]
#   J  = [0.031250000000000000 .. 0.20100000000000002]
# f(J) = [-0.0058331256943273090 .. 2.0339886016386220]
# Monitored signal 0.0563282966614 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 8 flowpipes in 0.0622820854187 sec
# Prepared for plotting in 0.0178925991058 sec
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.084531250000000017]]
#   J  = [0.084531250000000016 .. 0.20100000000000004]
# f(J) = [-0.052431881994898920 .. 1.9431509804241709]
# Monitored signal 0.0580132007599 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 8 flowpipes in 0.0614371299744 sec
# Prepared for plotting in 0.0123777389526 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = [[0.00000000000000000 .. 0.066424754892794688]]
#   J  = [0.066424754892794687 .. 0.20100000000000002]
# f(J) = [7.3895158709596717e-6 .. 1.9449948128869508]
# Monitored signal 0.0573651790619 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 8 flowpipes in 0.0665760040283 sec
# Prepared for plotting in 0.0110757350922 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = [[0.00000000000000000 .. 0.065625000000000003]]
#   J  = [0.065625000000000002 .. 0.20100000000000002]
# f(J) = [-0.017822274241702088 .. 1.9336868719641387]
# Monitored signal 0.0563902854919 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 8 flowpipes in 0.0615200996399 sec
# Prepared for plotting in 0.0105776786804 sec
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.041299670595727707]]
#   J  = [0.041299670595727706 .. 0.20100000000000004]
# f(J) = [0.00073839497761146385 .. 1.9261409455359411]
# Monitored signal 0.0521562099457 sec
# sig    = Signal([0.00000000000000000 .. 0.00100
# <b>limit_output extension: Maximum message size of 10000 exceeded with 10454 characters</b>

# %%
sig.plot()
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
sig = ({x: RIF(6, 6.1)} % G(RIF(0,0.2), P)
       ).signal_for_system(vf, v3, 2*pi, **kwargs)
# Out:
# Computed 72 flowpipes in 0.413310050964 sec
# Prepared for plotting in 0.102604627609 sec
# Flowstar failed!
# I  = [0.00000000000000000 .. 6.2841853071795866]
# fI = ['[0.99999881254552125 .. 1.3743176832705973]', '[0.011496194198696817 .. 5.0000087847057957]']
# C || f(I) = ['[0.99999881254552125 .. 1.3743176832705973]', '[0.011496194198696817 .. 5.0000087847057957]']
#      odes = (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y)
# D || odes = [0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x + 6.1?, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y]
# phi(D || odes, C || f(I)) = None
# bisecting [0.00000000000000000 .. 6.2841853071795866] -> [0.00000000000000000 .. 3.1420926535897933], [3.1420926535897932 .. 6.2841853071795866]
# Computed 15 flowpipes in 0.0949521064758 sec
# Prepared for plotting in 0.021196603775 sec
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = []
#   J  = [0.00000000000000000 .. 0.20100000000000004]
# f(J) = [0.34741206353026066 .. 2.5416699961920042]
# Monitored signal 0.0800273418427 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [([0.00000000000000000 .. 0.0010000000000000001], True)])
# sig(0) = True
# Computed 15 flowpipes in 0.111356019974 sec
# Prepared for plotting in 0.0302717685699 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = []
#   J  = [0.00000000000000000 .. 0.20100000000000002]
# f(J) = [0.026656375468014581 .. 2.3586252742561933]
# Monitored signal 0.115350246429 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [([0.00000000000000000 .. 0.0010000000000000001], True)])
# sig(0) = True
# Computed 15 flowpipes in 0.131666898727 sec
# Prepared for plotting in 0.0277688503265 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = [[0.00000000000000000 .. 0.032812500000000002]]
#   J  = [0.032812500000000001 .. 0.20100000000000002]
# f(J) = [-0.0047406344046465807 .. 2.0741259318648085]
# Monitored signal 0.110829353333 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 15 flowpipes in 0.109007120132 sec
# Prepared for plotting in 0.0194268226624 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = []
#   J  = [0.00000000000000000 .. 0.20100000000000002]
# f(J) = [0.038964418502526410 .. 2.0716888619606447]
# Monitored signal 0.0872581005096 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [([0.00000000000000000 .. 0.0010000000000000001], True)])
# sig(0) = True
# Computed 15 flowpipes in 0.106158018112 sec
# Prepared for plotting in 0.0207767486572 sec
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.015625000000000000]]
#   J  = [0.015625000000000000 .. 0.20100000000000004]
# f(J) = [-0.014779922211352524 .. 2.0007476586217337]
# Monitored signal 0.0940203666687 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 15 flowpipes in 0.10212802887 sec
# Prepared for plotting in 0.0195198059082 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = [[0.00000000000000000 .. 0.068252850610850971]]
#   J  = [0.068252850610850970 .. 0.20100000000000002]
# f(J) = [0.000081651638319642227 .. 1.9110496424687467]
# Monitored signal 0.0804622173309 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 15 flowpipes in 0.102468013763 sec
# Prepared for plotting in 0.0209758281708 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = [[0.00000000000000000 .. 0.051718750000000008]]
#   J  = [0.051718750000000007 .. 0.20100000000000002]
# f(J) = [-0.045576064067264007 .. 1.9065003647346477]
# Monitored signal 0.106741189957 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 15 flowpipes in 0.130503177643 sec
# Prepared for plotting in 0.0265867710114 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = [[0.00000000000000000 .. 0.037685984146345726]]
#   J  = [0.037685984146345725 .. 0.20100000000000002]
# f(J) = [0.00013769058322056319 .. 1.9041231835438677]
# Monitored signal 0.087865114212 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 15 flowpipes in 0.111932992935 sec
# Prepared for plotting in 0.0214467048645 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = [[0.00000000000000000 .. 0.029953774664727908]]
#   J  = [0.029953774664727907 .. 0.20100000000000002]
# f(J) = [0.0025262035841711223 .. 1.9027708509829416]
# Monitored signal 0.0909261703491 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 15 flowpipes in 0.0999479293823 sec
# Prepared for plotting in 0.0174477100372 sec
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.032812500000000002]]
#   J  = [0.032812500000000001 .. 0.20100000000000004]
# f(J) = [-0.022854241747074671 .. 1.8383005657195264]
# Monitored signal 0.0793092250824 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 15 flowpipes in 0.105234146118 sec
# Prepared for plotting in 0.0178866386414 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = [[0.00000000000000000 .. 0.048283244335924070]]
#   J  = [0.048283244335924069 .. 0.20100000000000002]
# f(J) = [0.0033407392530775195 .. 1.7768572198006701]
# Monitored signal 0.103816270828 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 15 flowpipes in 0.157144069672 sec
# Prepared for plotting in 0.0275237560272 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = [[0.00000000000000000 .. 0.037869859702116690]]
#   J  = [0.037869859702116689 .. 0.20100000000000002]
# f(J) = [0.00026690070425625274 .. 1.7761618758047711]
# Monitored signal 0.0891671180725 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 15 flowpipes in 0.10348200798 sec
# Prepared for plotting in 0.0154867172241 sec
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.042014300183407114]]
#   J  = [0.042014300183407113 .. 0.20100000000000004]
# f(J) = [0.00070477798988790446 .. 1.7163428743835781]
# Monitored signal 0.0742163658142 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 15 flowpipes in 0.102015972137 sec
# Prepared for plotting in 0.0179557800293 sec
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.053206696226776401]]
#   J  = [0.053206696226776400 .. 0.20100000000000004]
# f(J) = [5.1644540731768384e-7 .. 1.6604888058144039]
# Monitored signal 0.0781803131104 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 15 flowpipes in 0.107090950012 sec
# Prepared for plotting in 0.0181858539581 sec
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.051647249313133644]]
#   J  = [0.051647249313133643 .. 0.20100000000000004]
# f(J) = [0.0066327127888940601 .. 1.6596846611542766]
# Monitored signal 0.0962240695953 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 15 flowpipes in 0.107893943787 sec
# Prepared for plotting in 0.014949798584 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = [[0.00000000000000000 .. 0.044053769813692114]]
#   J  = [0.044053769813692113 .. 0.20100000000000002]
# f(J) = [0.00089902046721979100 .. 1.6592163133857352]
# Monitored signal 0.0806732177734 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 15 flowpipes in 0.108463048935 sec
# Prepared for plotting in 0.0177457332611 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = [[0.00000000000000000 .. 0.047116298017362085]]
#   J  = [0.047116298017362084 .. 0.20100000000000002]
# f(J) = [0.0029883209264414678 .. 1.6051236282783293]
# Monitored signal 0.0827901363373 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 15 flowpipes in 0.104140996933 sec
# Prepared for plotting in 0.0139138698578 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = [[0.00000000000000000 .. 0.051718750000000008]]
#   J  = [0.051718750000000007 .. 0.20100000000000002]
# f(J) = [-0.00045206328451405376 .. 1.5540769608008947]
# Monitored signal 0.0766351222992 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 15 flowpipes in 0.0982520580292 sec
# Prepared for plotting in 0.0117406845093 sec
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.050529067330523009]]
#   J  = [0.050529067330523008 .. 0.20100000000000004]
# f(J) = [0.0060535333382600864 .. 1.5539185590216167]
# Monitored signal 0.0760772228241 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 15 flowpipes in 0.100208997726 sec
# Prepared for plotting in 0.0109207630157 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = [[0.00000000000000000 .. 0.050930860567069241]]
#   J  = [0.050930860567069240 .. 0.20100000000000002]
# f(J) = [0.0066360286676143548 .. 1.5056301408697109]
# Monitored signal 0.0712502002716 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 15 flowpipes in 0.109208106995 sec
# Prepared for plotting in 0.0175657272339 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = [[0.00000000000000000 .. 0.062117187500000018]]
#   J  = [0.062117187500000017 .. 0.20100000000000002]
# f(J) = [-0.0040234508375528375 .. 1.4879512223635352]
# Monitored signal 0.0801711082458 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 15 flowpipes in 0.128468990326 sec
# Prepared for plotting in 0.0140097141266 sec
# domain = [0.00000
# <b>limit_output extension: Maximum message size of 10000 exceeded with 12177 characters</b>

# %%
sig.plot()
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
sig = ({x: RIF(10, 10.05)} % G(RIF(0,0.2), P)
       ).signal_for_system(vf, v3, 2*pi, **kwargs)
# Out:
# Computed 72 flowpipes in 0.561532974243 sec
# Prepared for plotting in 0.10325884819 sec
# Flowstar failed!
# I  = [0.00000000000000000 .. 6.2841853071795866]
# fI = ['[0.99999881254552125 .. 1.3743176832705973]', '[0.011496194198696817 .. 5.0000087847057957]']
# C || f(I) = ['[0.99999881254552125 .. 1.3743176832705973]', '[0.011496194198696817 .. 5.0000087847057957]']
#      odes = (0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y)
# D || odes = [0.29999999999999999?*x^2*y - 0.59999999999999998?*x^2 - 0.2400000000000000?*x*y + 0.59999999999999998?*x + 10.1?, -2*x^2*y + 1.6000000000000001?*x*y - 0.050000000000000003?*y^2 - 0.050000000000000003?*y]
# phi(D || odes, C || f(I)) = None
# bisecting [0.00000000000000000 .. 6.2841853071795866] -> [0.00000000000000000 .. 3.1420926535897933], [3.1420926535897932 .. 6.2841853071795866]
# Computed 14 flowpipes in 0.0834968090057 sec
# Prepared for plotting in 0.0220017433167 sec
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = []
#   J  = [0.00000000000000000 .. 0.20100000000000004]
# f(J) = [1.1056262394131199 .. 5.4796682350839685]
# Monitored signal 0.0736353397369 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [([0.00000000000000000 .. 0.0010000000000000001], True)])
# sig(0) = True
# Computed 13 flowpipes in 0.0861821174622 sec
# Prepared for plotting in 0.0196328163147 sec
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = []
#   J  = [0.00000000000000000 .. 0.20100000000000004]
# f(J) = [0.81889457008966326 .. 4.9148456916490267]
# Monitored signal 0.0721781253815 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [([0.00000000000000000 .. 0.0010000000000000001], True)])
# sig(0) = True
# Computed 12 flowpipes in 0.0790009498596 sec
# Prepared for plotting in 0.0183038711548 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = []
#   J  = [0.00000000000000000 .. 0.20100000000000002]
# f(J) = [0.23083956768692157 .. 4.7841886030518462]
# Monitored signal 0.0628042221069 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [([0.00000000000000000 .. 0.0010000000000000001], True)])
# sig(0) = True
# Computed 11 flowpipes in 0.0731019973755 sec
# Prepared for plotting in 0.020391702652 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = [[0.00000000000000000 .. 0.031250000000000000]]
#   J  = [0.031250000000000000 .. 0.20100000000000002]
# f(J) = [-0.21129635912846706 .. 4.5572196584740024]
# Monitored signal 0.0704102516174 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 11 flowpipes in 0.0778028964996 sec
# Prepared for plotting in 0.0186338424683 sec
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = []
#   J  = [0.00000000000000000 .. 0.20100000000000004]
# f(J) = [0.028149644255182092 .. 4.5534643701531313]
# Monitored signal 0.0774502754211 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [([0.00000000000000000 .. 0.0010000000000000001], True)])
# sig(0) = True
# Computed 11 flowpipes in 0.0846409797668 sec
# Prepared for plotting in 0.0184626579285 sec
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.031250000000000000]]
#   J  = [0.031250000000000000 .. 0.20100000000000004]
# f(J) = [0.035807295380854795 .. 4.2930707152136991]
# Monitored signal 0.0648283958435 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 11 flowpipes in 0.0833070278168 sec
# Prepared for plotting in 0.0171127319336 sec
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = []
#   J  = [0.00000000000000000 .. 0.20100000000000004]
# f(J) = [0.048699564464089600 .. 4.2913809170378921]
# Monitored signal 0.0729992389679 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [([0.00000000000000000 .. 0.0010000000000000001], True)])
# sig(0) = True
# Computed 11 flowpipes in 0.0906989574432 sec
# Prepared for plotting in 0.017552614212 sec
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.0092192905864578751]]
#   J  = [0.0092192905864578750 .. 0.20100000000000004]
# f(J) = [0.0021633618468602823 .. 4.2163133614749003]
# Monitored signal 0.0661172866821 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 11 flowpipes in 0.111820936203 sec
# Prepared for plotting in 0.0222027301788 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = [[0.00000000000000000 .. 0.049295070814844293]]
#   J  = [0.049295070814844292 .. 0.20100000000000002]
# f(J) = [0.000029840377318057602 .. 4.1121626538270615]
# Monitored signal 0.0828151702881 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 11 flowpipes in 0.102084159851 sec
# Prepared for plotting in 0.0165796279907 sec
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.045365070547788288]]
#   J  = [0.045365070547788287 .. 0.20100000000000004]
# f(J) = [0.0077361012472240558 .. 4.1075918840867534]
# Monitored signal 0.0708792209625 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 11 flowpipes in 0.0843040943146 sec
# Prepared for plotting in 0.0157556533813 sec
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.031250000000000000]]
#   J  = [0.031250000000000000 .. 0.20100000000000004]
# f(J) = [-0.076021912890665636 .. 4.1059792847830039]
# Monitored signal 0.068359375 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 10 flowpipes in 0.0829570293427 sec
# Prepared for plotting in 0.0138757228851 sec
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.031250000000000000]]
#   J  = [0.031250000000000000 .. 0.20100000000000004]
# f(J) = [0.0091335457842031814 .. 4.1064816377566809]
# Monitored signal 0.0686101913452 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 10 flowpipes in 0.0824749469757 sec
# Prepared for plotting in 0.016019821167 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = [[0.00000000000000000 .. 0.020653349023650493]]
#   J  = [0.020653349023650492 .. 0.20100000000000002]
# f(J) = [0.012096406144285518 .. 4.1063096544380829]
# Monitored signal 0.0647592544556 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 10 flowpipes in 0.0756261348724 sec
# Prepared for plotting in 0.0114586353302 sec
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.031250000000000000]]
#   J  = [0.031250000000000000 .. 0.20100000000000004]
# f(J) = [0.047654133316502145 .. 4.0359728964983237]
# Monitored signal 0.0618412494659 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 10 flowpipes in 0.0763101577759 sec
# Prepared for plotting in 0.014940738678 sec
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.031250000000000000]]
#   J  = [0.031250000000000000 .. 0.20100000000000004]
# f(J) = [0.00016170527593253880 .. 3.9662787043961108]
# Monitored signal 0.0658431053162 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 9 flowpipes in 0.0724709033966 sec
# Prepared for plotting in 0.0129718780518 sec
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.031250000000000000]]
#   J  = [0.031250000000000000 .. 0.20100000000000004]
# f(J) = [0.033702031919565916 .. 3.9660004648572822]
# Monitored signal 0.0620572566986 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 9 flowpipes in 0.0784919261932 sec
# Prepared for plotting in 0.0128128528595 sec
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.031250000000000000]]
#   J  = [0.031250000000000000 .. 0.20100000000000004]
# f(J) = [0.027533964064397953 .. 3.8964832464780131]
# Monitored signal 0.0583400726318 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 9 flowpipes in 0.070741891861 sec
# Prepared for plotting in 0.0143487453461 sec
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.031754824427134815]]
#   J  = [0.031754824427134814 .. 0.20100000000000004]
# f(J) = [0.000011256069648031552 .. 3.8286659479708956]
# Monitored signal 0.0598483085632 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 9 flowpipes in 0.0714139938354 sec
# Prepared for plotting in 0.0104196071625 sec
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.031250000000000000]]
#   J  = [0.031250000000000000 .. 0.20100000000000004]
# f(J) = [-0.0017395291810442526 .. 3.8283275879920864]
# Monitored signal 0.0607953071594 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 9 flowpipes in 0.0742411613464 sec
# Prepared for plotting in 0.0113816261292 sec
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.031250000000000000]]
#   J  = [0.031250000000000000 .. 0.20100000000000004]
# f(J) = [0.025229169562644176 .. 3.8281326546146000]
# Monitored signal 0.0578582286835 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 8 flowpipes in 0.0605590343475 sec
# Prepared for plotting in 0.00800561904907 sec
# domain = [0.00000000000000000 .. 0.20100000000000002]
# roots = [[0.00000000000000000 .. 0.031250000000000000]]
#   J  = [0.031250000000000000 .. 0.20100000000000002]
# f(J) = [0.018056284760070318 .. 3.7660468088433237]
# Monitored signal 0.0525891780853 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 8 flowpipes in 0.0599248409271 sec
# Prepared for plotting in 0.010155916214 sec
# domain
# <b>limit_output extension: Maximum message size of 10000 exceeded with 10672 characters</b>

# %%
sig.plot()
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
{x: 1, y: 2}
# Out:
# {y: 2, x: 1}

# %%
kxs = [[('x', RIF(1,2)), ('y', RIF(5,6))], [('x', RIF(2,3)), ('y', RIF(6,7))], [('x', RIF(1,2)), ('y', RIF(5,6))], [('x', RIF(2,3)), ('y', RIF(6,7))]]

# %%
sorted(kxs)
# Out:
# [[('x', 2.?), ('y', 6.?)],
#  [('x', 3.?), ('y', 7.?)],
#  [('x', 2.?), ('y', 6.?)],
#  [('x', 3.?), ('y', 7.?)]]

# %%
sorted(kxs,
       key=lambda xs: [(k, x.endpoints()) for k, x in xs])
# Out:
# [[('x', 2.?), ('y', 6.?)],
#  [('x', 2.?), ('y', 6.?)],
#  [('x', 3.?), ('y', 7.?)],
#  [('x', 3.?), ('y', 7.?)]]
