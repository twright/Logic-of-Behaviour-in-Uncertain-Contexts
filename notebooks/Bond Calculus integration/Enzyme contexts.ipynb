# %% [markdown]
# # Bond-Calculus Enzyme Contexts

# %%
import sys

sys.path.insert(0, "/home/twright/Documents/PhD/Notebooks")

# %%
from lbuc.bondcalculus import *
from lbuc.logic import *

# %% [markdown]
# ## Load Enzyme Model

# %%
model = BondModel("../../../bondwb/models/enzyme-context.biocpi"); model
# Out:
# Running cmd: 'load "../../../bondwb/models/enzyme-context.biocpi"' ...

# %%
pi1 = model.process("[1.0] S with network M4(1.0, 0.1, 0.5, 0.1)"); pi1
# Out:
# BondProcess('[1.0] S with network M4(1.0, 0.1, 0.5, 0.1)', <lbuc.bondcalculus.BondModel object at 0x7f2936e70520>)

# %%
sys1 = pi1.as_system; sys1
# Out:
# Running cmd: 'savesage "[1.0] S with network M4(1.0, 0.1, 0.5, 0.1)" "/tmp/bond-sage-script-_g0hbsc3.py"' ...
# System(R, (x0), [1], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))

# %% [markdown]
# ## Basic Property

# %%
r = sys1.reach(10)

# %%
r.sage_plot(var("S"), color=["blue", "blue"], fillcolor="blue", fill={0: [1]})
# Out:
# var_names = [b'local_t', b'x0']
# res = b'(([1.0000000000 , 1.0000000000] * x0))'
# PolyObserver((([1.0000000000 , 1.0000000000] * x0)), <flowstar.reachability.Reach object at 0x7f29305d6ee0>, None, symbolic_composition=False, symbolic_composition_order=-1, tentative_unpreconditioning=False, mask=None)
# plot_points = 1000
# /usr/lib64/python3.8/site-packages/numpy/core/getlimits.py:400: UserWarning: Signature b'\x99\x99\x99\x99\x99\x99\xb9\xbf' for <class 'numpy.float64'> does not match any known type: falling back to type probe function
#   machar = _get_machar(dtype)
# Graphics object consisting of 3 graphics primitives

# %%
prop1 = G(RIF(0, 2), Atomic(var("S") > 0.6)); prop1
# Out:
# G([0 .. 2], Atomic(S > 0.600000000000000))

# %%
sig1 = prop1.signal_for_system(sys1, 10); sig1.plot()
# Out:
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [1], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 121 flowpipes in 0.01949066100496566 sec
# In G.signal
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7f292e806ee0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = [[5.1999999999999655 .. 5.2000000000000100]]
# domain = [0.0000000000000000 .. 12.002000000000001]
# roots = [[5.1999999999999655 .. 5.2000000000000100]]
# seg_domain = [0.0000000000000000 .. 12.002000000000001]
# roots = [[5.1999999999999655 .. 5.2000000000000100]]
# signal given bool roots: 1 items in 0.00 seconds
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# ## Simple Context

# %%
prop2 = G(RIF(0, 2), "[0.1 .. 0.3] S" >> Atomic(var("S") > 0.6)); prop2
# Out:
# G([0 .. 2], C([0.1 .. 0.3] S, Atomic(S > 0.600000000000000)))

# %%
sig2 = prop2.signal_for_system(sys1, 20); sig2.plot()
# Out:
# Running cmd: 'savesage "([1] S || { e || s at rate MA(1.0); r|x at rate MA([9.999999999999999e-2 .. 0.1]); p|x at rate MA(0.5); d at rate MA([9.999999999999999e-2 .. 0.1]); }) || ([0.1 .. 0.3] S)" "/tmp/bond-sage-script-le95vd2p.py"' ...
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [1], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 221 flowpipes in 0.014391200034879148 sec
# In G.signal
# mask = None
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.0016831110115163028 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92c282040>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.002159430005121976 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92c282280>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.002781578979920596 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92c4b44c0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = []
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = []
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = []
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.0021340090315788984 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92c282160>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.003000113007146865 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92c282ee0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.0018918679561465979 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92c4b4700>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.0018647689721547067 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92c4b4ee0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = []
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = []
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = []
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.0017584000015631318 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92c4b4820>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.0024564669583924115 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92c4b45e0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = []
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = []
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = []
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.002373495022766292 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92e233040>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.0036672399728558958 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92e233160>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.0022093680454418063 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92c4b4dc0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.0037899509770795703 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92c4b4a60>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.0030554280383512378 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92c4b4b80>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.0031249200110323727 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92c4b44c0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.0036816270439885557 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92c282040>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.0037905100034549832 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92c282280>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.0038438690244220197 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92e226040>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.0048935170052573085 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92e226280>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.003137911029625684 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92e2264c0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.0025919589679688215 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92c282160>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.002494670043233782 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92c282ee0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.0032750089885666966 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92c4b4700>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.0025397869758307934 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92c4b4ee0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.002282281988300383 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92c4b4820>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.001881600997876376 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92c4b45e0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.002140154014341533 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92e2265e0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.0032641140278428793 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92e2263a0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.0038019639905542135 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92e226160>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.006717430020216852 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92e226700>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.003458343038801104 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92c4b4dc0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.003257129981648177 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92c4b4820>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.003217530029360205 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92c4b4ee0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.0033169849775731564 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92c4b4700>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.00413978798314929 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92c282ee0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.004235400992911309 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92c282160>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.003166615031659603 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92e2263a0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.003327669983264059 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92e2265e0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.0031396569684147835 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92e226940>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.0021139640011824667 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92c282160>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.0028803349705412984 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92c282ee0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.10000000000000001]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.0028570779832080007 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92c4b4700>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = [[0.10000000000000000 .. 0.10000000000000001]]
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.10000000000000000 .. 0.10000000000000001]]
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.10000000000000000 .. 0.10000000000000001]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.0017667110078036785 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92c4b4ee0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = []
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = []
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = []
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.002893115975894034 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92c4b4820>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = []
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = []
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = []
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.002878170053008944 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92c4b4dc0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = []
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = []
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = []
# signal given bool roots: 1 items in 0.00 seconds
# Graphics object consisting of 2 graphics primitives

# %%
sig2 = prop2.signal_for_system(sys1, 20, use_masks=True); sig2.plot()
# Out:
# Running cmd: 'savesage "([1] S || { e || s at rate MA(1.0); r|x at rate MA([9.999999999999999e-2 .. 0.1]); p|x at rate MA(0.5); d at rate MA([9.999999999999999e-2 .. 0.1]); }) || ([0.1 .. 0.3] S)" "/tmp/bond-sage-script-d1riwnc3.py"' ...
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [1], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 221 flowpipes in 0.012451700051315129 sec
# In G.signal
# mask = Mask([0.0000000000000000 .. 22.002000000000003], [[0.0000000000000000 .. 22.002000000000003]])
# mask = Mask([0.0000000000000000 .. 22.002000000000003], [[0.0000000000000000 .. 22.002000000000003]])
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.002120598976034671 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92c4b4a60>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 0.0060000000000000002], [[0.0000000000000000 .. 0.0060000000000000002]]))
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = [[0.0000000000000000 .. 0.0060000000000000002]]
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.0060000000000000002]]
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.0060000000000000002]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.0028606400010176003 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92c4b4820>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 0.0060000000000000002], [[0.0000000000000000 .. 0.0060000000000000002]]))
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = [[0.0000000000000000 .. 0.0060000000000000002]]
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.0060000000000000002]]
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.0060000000000000002]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.0020579510019160807 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92c4b44c0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 0.0060000000000000002], [[0.0000000000000000 .. 0.0060000000000000002]]))
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = []
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = []
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = []
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.0037923959898762405 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92c282ca0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 0.0060000000000000002], [[0.0000000000000000 .. 0.0060000000000000002]]))
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = [[0.0000000000000000 .. 0.0060000000000000002]]
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.0060000000000000002]]
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.0060000000000000002]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.001553764974232763 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92c282ee0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 0.0060000000000000002], [[0.0000000000000000 .. 0.0060000000000000002]]))
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = [[0.0000000000000000 .. 0.0060000000000000002]]
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.0060000000000000002]]
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.0060000000000000002]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.0036157669965177774 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92c282160>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 0.0060000000000000002], [[0.0000000000000000 .. 0.0060000000000000002]]))
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = []
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = []
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = []
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.0024005940067581832 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92e1d8040>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 0.0060000000000000002], [[0.0000000000000000 .. 0.0060000000000000002]]))
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = [[0.0000000000000000 .. 0.0060000000000000002]]
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.0060000000000000002]]
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.0060000000000000002]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.0027707539848051965 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92c282160>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 0.0060000000000000002], [[0.0000000000000000 .. 0.0060000000000000002]]))
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = [[0.0000000000000000 .. 0.0060000000000000002]]
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.0060000000000000002]]
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.0060000000000000002]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.003046627971343696 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92c282ee0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 0.0060000000000000002], [[0.0000000000000000 .. 0.0060000000000000002]]))
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = [[0.0000000000000000 .. 0.0060000000000000002]]
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.0060000000000000002]]
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.0060000000000000002]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.0020117160165682435 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92c282ca0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 0.0060000000000000002], [[0.0000000000000000 .. 0.0060000000000000002]]))
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = [[0.0000000000000000 .. 0.0060000000000000002]]
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.0060000000000000002]]
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.0060000000000000002]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.0028406649944372475 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92c4b4ee0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 0.0060000000000000002], [[0.0000000000000000 .. 0.0060000000000000002]]))
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = [[0.0000000000000000 .. 0.0060000000000000002]]
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.0060000000000000002]]
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = [[0.0000000000000000 .. 0.0060000000000000002]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.099999999999999866 .. 0.30000000000000005]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [[0.12243193671563602 .. 0.14956861941836159]], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 1 flowpipes in 0.002049500006251037 sec
# PolyObserver(x0 - 0.59999999999999998?, <flowstar.reachability.Reach object at 0x7ff92cfd3a60>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 0.0060000000000000002], [[0.0000000000000000 .. 0.0060000000000000002]]))
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.00 seconds
# roots = []
# domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = []
# seg_domain = [0.0000000000000000 .. 0.0060000000000000002]
# roots = []
# signal given bool roots: 1 items in 0.00 seconds
# /usr/lib64/python3.8/site-packages/sage/plot/contour_plot.py:203: UserWarning: No contour levels were found within the data range.
#   CS = subplot.contour(self.xy_data_array, contours, cmap=cmap,
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# ## Introducing Enzyme

# %%
pi2 = model.process("[1.0] S || [0.125 .. 0.175] E with network M4(1.0, 0.1, 0.5, 0.1)"); pi2
# Out:
# BondProcess('[1.0] S || [0.125 .. 0.175] E with network M4(1.0, 0.1, 0.5, 0.1)', <lbuc.bondcalculus.BondModel object at 0x7ff92c20b5e0>)

# %%
sys2 = pi2.as_system; sys2
# Out:
# Running cmd: 'savesage "[1.0] S || [0.125 .. 0.175] E with network M4(1.0, 0.1, 0.5, 0.1)" "/tmp/bond-sage-script-2snfyyqs.py"' ...
# System(R, (x0, x1, x2, x3), [1, 0, [0.12499999999999998 .. 0.17500000000000005], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))

# %%
r = sys2.reach(20)

# %%
  r.sage_plot(var("S"), color=["blue", "blue"], fillcolor="blue", fill={0: [1]})\
+ r.sage_plot(var("P"), color=["orange", "orange"], fillcolor="orange", fill={0: [1]})
# Out:
# var_names = [b'local_t', b'x0', b'x1', b'x2', b'x3']
# res = b'(([1.0000000000 , 1.0000000000] * x0))'
# PolyObserver((([1.0000000000 , 1.0000000000] * x0)), <flowstar.reachability.Reach object at 0x7ff92ed2aee0>, None, symbolic_composition=False, symbolic_composition_order=-1, tentative_unpreconditioning=False, mask=None)
# plot_points = 2000
# var_names = [b'local_t', b'x0', b'x1', b'x2', b'x3']
# res = b'(([1.0000000000 , 1.0000000000] * x1))'
# PolyObserver((([1.0000000000 , 1.0000000000] * x1)), <flowstar.reachability.Reach object at 0x7ff92ed2aee0>, None, symbolic_composition=False, symbolic_composition_order=-1, tentative_unpreconditioning=False, mask=None)
# plot_points = 2000
# Graphics object consisting of 6 graphics primitives

# %%
r.sage_plot(var("P"), color=["orange", "orange"], fillcolor="orange", fill={0: [1]})
# Out:
# var_names = [b'local_t', b'x0', b'x1', b'x2', b'x3']
# res = b'(([1.0000000000 , 1.0000000000] * x1))'
# PolyObserver((([1.0000000000 , 1.0000000000] * x1)), <flowstar.reachability.Reach object at 0x7ff92ed2aee0>, None, symbolic_composition=False, symbolic_composition_order=-1, tentative_unpreconditioning=False, mask=None)
# plot_points = 2000
# Graphics object consisting of 3 graphics primitives

# %% [markdown]
# ## Delayed Enzyme Introduction via Context

# %%
r1 = sys1.reach(5)

# %%
sys3 = to_context_body("[0.125 .. 0.175] E").apply_jump(sys1.with_y0(r1(RIF(5, 5))))
sys3
# Out:
# Running cmd: 'savesage "([0.60653050398995167 .. 0.60653076496687731] S || { e || s at rate MA(1.0); r|x at rate MA([9.999999999999999e-2 .. 0.1]); p|x at rate MA(0.5); d at rate MA([9.999999999999999e-2 .. 0.1]); }) || ([0.125 .. 0.175] E)" "/tmp/bond-sage-script-qmvki5cs.py"' ...
# System(R, (x0, x1, x2, x3), [[0.60653050398995156 .. 0.60653076496687742], 0, [0.12499999999999998 .. 0.17500000000000005], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))

# %%
r2 = sys3.reach(10)

# %%
r2.successful
# Out:
# True

# %%
graphics_array([
  r1.sage_plot(var("S"), color=["blue", "blue"], fillcolor="blue", fill={0: [1]}, ymax=1),
#+ r1.sage_plot(var("P"), color=["orange", "orange"], fillcolor="orange", fill={0: [1]}),
  r2.sage_plot(var("S"), color=["blue", "blue"], fillcolor="blue", fill={0: [1]}, ymax=1)\
+ r2.sage_plot(var("P"), color=["orange", "orange"], fillcolor="orange", fill={0: [1]})
], 1, 2)
# Out:
# var_names = [b'local_t', b'x0']
# res = b'(([1.0000000000 , 1.0000000000] * x0))'
# PolyObserver((([1.0000000000 , 1.0000000000] * x0)), <flowstar.reachability.Reach object at 0x7ff92c282940>, None, symbolic_composition=False, symbolic_composition_order=-1, tentative_unpreconditioning=False, mask=None)
# plot_points = 500
# var_names = [b'local_t', b'x0', b'x1', b'x2', b'x3']
# res = b'(([1.0000000000 , 1.0000000000] * x0))'
# PolyObserver((([1.0000000000 , 1.0000000000] * x0)), <flowstar.reachability.Reach object at 0x7ff92c282700>, None, symbolic_composition=False, symbolic_composition_order=-1, tentative_unpreconditioning=False, mask=None)
# plot_points = 1000
# var_names = [b'local_t', b'x0', b'x1', b'x2', b'x3']
# res = b'(([1.0000000000 , 1.0000000000] * x1))'
# PolyObserver((([1.0000000000 , 1.0000000000] * x1)), <flowstar.reachability.Reach object at 0x7ff92c282700>, None, symbolic_composition=False, symbolic_composition_order=-1, tentative_unpreconditioning=False, mask=None)
# plot_points = 1000
# Graphics Array of size 1 x 2

# %%
prop4 = "[0.125 .. 0.175] E" >> F(RIF(0, 5), Atomic(var("P") > 0.125)); prop4
# Out:
# C([0.125 .. 0.175] E, F([0 .. 5], Atomic(P > 0.125000000000000)))

# %%
sig4 = prop4.signal_for_system(sys1, 10)
# Out:
# Running cmd: 'savesage "([1] S || { e || s at rate MA(1.0); r|x at rate MA([9.999999999999999e-2 .. 0.1]); p|x at rate MA(0.5); d at rate MA([9.999999999999999e-2 .. 0.1]); }) || ([0.125 .. 0.175] E)" "/tmp/bond-sage-script-9byl1sa3.py"' ...
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [1], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 101 flowpipes in 0.0070125110214576125 sec
# mask = None
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, [0.12499999999999998 .. 0.17500000000000005], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 3.8404354649828747 sec
# PolyObserver(x1 - 0.12500000000000000?, <flowstar.reachability.Reach object at 0x7ff92c282820>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 2.13 seconds
# roots = [[2.8999999999999883 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[2.8999999999999883 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[2.8999999999999883 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, [0.12499999999999998 .. 0.17500000000000005], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 3.511764229973778 sec
# PolyObserver(x1 - 0.12500000000000000?, <flowstar.reachability.Reach object at 0x7ff92c282040>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 1.29 seconds
# roots = [[2.9999999999999875 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[2.9999999999999875 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[2.9999999999999875 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, [0.12499999999999998 .. 0.17500000000000005], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 3.239771573978942 sec
# PolyObserver(x1 - 0.12500000000000000?, <flowstar.reachability.Reach object at 0x7ff93cb6d3a0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.81 seconds
# roots = [[2.9999999999999875 .. 4.8000000000000079], [4.8999999999999692 .. 4.9000000000000084]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[2.9999999999999875 .. 4.8000000000000079],
#  [4.8999999999999692 .. 4.9000000000000084]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[2.9999999999999875 .. 4.8000000000000079],
#  [4.8999999999999692 .. 4.9000000000000084]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, [0.12499999999999998 .. 0.17500000000000005], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 2.863106067001354 sec
# PolyObserver(x1 - 0.12500000000000000?, <flowstar.reachability.Reach object at 0x7ff92c4b44c0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.61 seconds
# roots = [[3.4999999999999835 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.4999999999999835 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.4999999999999835 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, [0.12499999999999998 .. 0.17500000000000005], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 2.746045003004838 sec
# PolyObserver(x1 - 0.12500000000000000?, <flowstar.reachability.Reach object at 0x7ff93cb6d3a0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.46 seconds
# roots = [[3.4999999999999835 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.4999999999999835 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.4999999999999835 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, [0.12499999999999998 .. 0.17500000000000005], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 2.239729006018024 sec
# PolyObserver(x1 - 0.12500000000000000?, <flowstar.reachability.Reach object at 0x7ff92c282040>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.31 seconds
# roots = [[3.4999999999999835 .. 4.9000000000000084]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.4999999999999835 .. 4.9000000000000084]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.4999999999999835 .. 4.9000000000000084]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, [0.12499999999999998 .. 0.17500000000000005], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 2.1620729609858245 sec
# PolyObserver(x1 - 0.12500000000000000?, <flowstar.reachability.Reach object at 0x7ff92c282820>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.33 seconds
# roots = [[3.5999999999999827 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.5999999999999827 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.5999999999999827 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, [0.12499999999999998 .. 0.17500000000000005], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.8592761310283095 sec
# PolyObserver(x1 - 0.12500000000000000?, <flowstar.reachability.Reach object at 0x7ff92c4b44c0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.30 seconds
# roots = [[3.5999999999999827 .. 5.0000000000000089]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.5999999999999827 .. 5.0000000000000089]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.5999999999999827 .. 5.0000000000000089]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, [0.12499999999999998 .. 0.17500000000000005], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.9582474660128355 sec
# PolyObserver(x1 - 0.12500000000000000?, <flowstar.reachability.Reach object at 0x7ff92c4b4040>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.28 seconds
# roots = [[3.6999999999999819 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.6999999999999819 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.6999999999999819 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, [0.12499999999999998 .. 0.17500000000000005], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 2.362963852006942 sec
# PolyObserver(x1 - 0.12500000000000000?, <flowstar.reachability.Reach object at 0x7ff92c4b45e0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.38 seconds
# roots = [[3.7999999999999811 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.7999999999999811 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.7999999999999811 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, [0.12499999999999998 .. 0.17500000000000005], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 2.3094891849905252 sec
# PolyObserver(x1 - 0.12500000000000000?, <flowstar.reachability.Reach object at 0x7ff92c4b4820>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.35 seconds
# roots = [[3.7999999999999811 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.7999999999999811 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.7999999999999811 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, [0.12499999999999998 .. 0.17500000000000005], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 2.0424026169930585 sec
# PolyObserver(x1 - 0.12500000000000000?, <flowstar.reachability.Reach object at 0x7ff92c4b4b80>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.23 seconds
# roots = [[3.7999999999999811 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.7999999999999811 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.7999999999999811 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.02 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, [0.12499999999999998 .. 0.17500000000000005], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.842894167988561 sec
# PolyObserver(x1 - 0.12500000000000000?, <flowstar.reachability.Reach object at 0x7ff92c4b4dc0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.24 seconds
# roots = [[3.7999999999999811 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.7999999999999811 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.7999999999999811 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, [0.12499999999999998 .. 0.17500000000000005], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 2.1153040589997545 sec
# PolyObserver(x1 - 0.12500000000000000?, <flowstar.reachability.Reach object at 0x7ff92c4b43a0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.25 seconds
# roots = [[3.8999999999999803 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.8999999999999803 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.8999999999999803 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, [0.12499999999999998 .. 0.17500000000000005], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.870725326007232 sec
# PolyObserver(x1 - 0.12500000000000000?, <flowstar.reachability.Reach object at 0x7ff92c4b4a60>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.20 seconds
# roots = [[3.8999999999999803 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.8999999999999803 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.8999999999999803 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, [0.12499999999999998 .. 0.17500000000000005], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.8699894750025123 sec
# PolyObserver(x1 - 0.12500000000000000?, <flowstar.reachability.Reach object at 0x7ff92c4b4ee0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.21 seconds
# roots = [[3.9999999999999795 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.9999999999999795 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.9999999999999795 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, [0.12499999999999998 .. 0.17500000000000005], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 3.266228528053034 sec
# PolyObserver(x1 - 0.12500000000000000?, <flowstar.reachability.Reach object at 0x7ff92c4b4700>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.48 seconds
# roots = [[3.9999999999999795 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.9999999999999795 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.9999999999999795 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, [0.12499999999999998 .. 0.17500000000000005], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 2.611519642989151 sec
# PolyObserver(x1 - 0.12500000000000000?, <flowstar.reachability.Reach object at 0x7ff92c282ca0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.36 seconds
# roots = [[4.0999999999999783 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.0999999999999783 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.0999999999999783 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, [0.12499999999999998 .. 0.17500000000000005], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 2.233417076000478 sec
# PolyObserver(x1 - 0.12500000000000000?, <flowstar.reachability.Reach object at 0x7ff92c282dc0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.26 seconds
# roots = [[4.0999999999999783 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.0999999999999783 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.0999999999999783 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, [0.12499999999999998 .. 0.17500000000000005], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.974473474023398 sec
# PolyObserver(x1 - 0.12500000000000000?, <flowstar.reachability.Reach object at 0x7ff92eb28160>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.26 seconds
# roots = [[4.0999999999999783 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.0999999999999783 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.0999999999999783 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, [0.12499999999999998 .. 0.17500000000000005], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.8375984329613857 sec
# PolyObserver(x1 - 0.12500000000000000?, <flowstar.reachability.Reach object at 0x7ff92eb283a0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.21 seconds
# roots = [[4.0999999999999783 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.0999999999999783 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.0999999999999783 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, [0.12499999999999998 .. 0.17500000000000005], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.8255156369996257 sec
# PolyObserver(x1 - 0.12500000000000000?, <flowstar.reachability.Reach object at 0x7ff92eb285e0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.17 seconds
# roots = [[4.1999999999999770 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.1999999999999770 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.1999999999999770 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, [0.12499999999999998 .. 0.17500000000000005], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.9242664119810797 sec
# PolyObserver(x1 - 0.12500000000000000?, <flowstar.reachability.Reach object at 0x7ff92c282dc0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.20 seconds
# roots = [[4.2999999999999758 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.2999999999999758 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.2999999999999758 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, [0.12499999999999998 .. 0.17500000000000005], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.743550089013297 sec
# PolyObserver(x1 - 0.12500000000000000?, <flowstar.reachability.Reach object at 0x7ff92c282ca0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.16 seconds
# roots = [[4.2999999999999758 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.2999999999999758 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.2999999999999758 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, [0.12499999999999998 .. 0.17500000000000005], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.6101499460055493 sec
# PolyObserver(x1 - 0.12500000000000000?, <flowstar.reachability.Reach object at 0x7ff92c4b4700>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.16 seconds
# roots = [[4.2999999999999758 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.2999999999999758 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.2999999999999758 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, [0.12499999999999998 .. 0.17500000000000005], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 2.161110822984483 sec
# PolyObserver(x1 - 0.12500000000000000?, <flowstar.reachability.Reach object at 0x7ff92c4b4ee0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.19 seconds
# roots = [[4.3999999999999745 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.3999999999999745 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.3999999999999745 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, [0.12499999999999998 .. 0.17500000000000005], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.7346999080036767 sec
# PolyObserver(x1 - 0.12500000000000000?, <flowstar.reachability.Reach object at 0x7ff92c4b4a60>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.16 seconds
# roots = [[4.3999999999999745 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.3999999999999745 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.3999999999999745 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, [0.12499999999999998 .. 0.17500000000000005], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.70046204602113 sec
# PolyObserver(x1 - 0.12500000000000000?, <flowstar.reachability.Reach object at 0x7ff92c4b43a0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.15 seconds
# roots = [[4.3999999999999745 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.3999999999999745 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.3999999999999745 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, [0.12499999999999998 .. 0.17500000000000005], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.9025074189994484 sec
# PolyObserver(x1 - 0.12500000000000000?, <flowstar.reachability.Reach object at 0x7ff92c4b4dc0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.13 seconds
# roots = [[4.4999999999999733 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.4999999999999733 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.4999999999999733 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, [0.12499999999999998 .. 0.17500000000000005], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 2.0269557620049454 sec
# PolyObserver(x1 - 0.12500000000000000?, <flowstar.reachability.Reach object at 0x7ff92eb283a0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.13 seconds
# roots = [[4.5999999999999721 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.5999999999999721 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.5999999999999721 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, [0.12499999999999998 .. 0.17500000000000005], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.5736098270281218 sec
# PolyObserver(x1 - 0.12500000000000000?, <flowstar.reachability.Reach object at 0x7ff92eb28160>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.10 seconds
# roots = [[4.5999999999999721 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.5999999999999721 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.5999999999999721 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, [0.12499999999999998 .. 0.17500000000000005], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.5216539329849184 sec
# PolyObserver(x1 - 0.12500000000000000?, <flowstar.reachability.Reach object at 0x7ff92c4b4820>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.10 seconds
# roots = [[4.7999999999999696 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.7999999999999696 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.7999999999999696 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, [0.12499999999999998 .. 0.17500000000000005], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 2.322123520076275 sec
# PolyObserver(x1 - 0.12500000000000000?, <flowstar.reachability.Reach object at 0x7ff92c4b45e0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.16 seconds
# roots = [[4.7999999999999696 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.7999999999999696 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.7999999999999696 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, [0.12499999999999998 .. 0.17500000000000005], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.943230906035751 sec
# PolyObserver(x1 - 0.12500000000000000?, <flowstar.reachability.Reach object at 0x7ff92c4b4040>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.11 seconds
# roots = [[4.8999999999999683 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.8999999999999683 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.8999999999999683 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, [0.12499999999999998 .. 0.17500000000000005], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.5923427260131575 sec
# PolyObserver(x1 - 0.12500000000000000?, <flowstar.reachability.Reach object at 0x7ff92c4b44c0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.10 seconds
# roots = [[4.8999999999999683 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.8999999999999683 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.8999999999999683 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, [0.12499999999999998 .. 0.17500000000000005], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.467760008003097 sec
# PolyObserver(x1 - 0.12500000000000000?, <flowstar.reachability.Reach object at 0x7ff92c282ca0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.09 seconds
# roots = [[4.8999999999999683 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.8999999999999683 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.8999999999999683 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, [0.12499999999999998 .. 0.17500000000000005], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.4231880420120433 sec
# PolyObserver(x1 - 0.12500000000000000?, <flowstar.reachability.Reach object at 0x7ff92c282040>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.08 seconds
# roots = [[4.9999999999999671 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.9999999999999671 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.9999999999999671 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, [0.12499999999999998 .. 0.17500000000000005], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.7197109350236133 sec
# PolyObserver(x1 - 0.12500000000000000?, <flowstar.reachability.Reach object at 0x7ff93cb6d3a0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.07 seconds
# roots = []
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = []
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = []
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, [0.12499999999999998 .. 0.17500000000000005], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.6715583330369554 sec
# PolyObserver(x1 - 0.12500000000000000?, <flowstar.reachability.Reach object at 0x7ff92eb283a0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.07 seconds
# roots = []
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = []
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = []
# signal given bool roots: 1 items in 0.00 seconds

# %%
sig4.plot()
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# ## Differential Context For Enzyme Introduction

# %% [markdown]
# Not implemented yet!

# %%
prop6 = D("[0.2] E", F(RIF(0, 5), Atomic(var("P") > 0.125))); prop6
# Out:
# D([0.2] E, F([0 .. 5], Atomic(P > 0.125000000000000)))

# %%
sig6 = prop6.signal_for_system(sys1, 10)
# Out:
# Running cmd: 'savesage "([1] S || { e || s at rate MA(1.0); r|x at rate MA([9.999999999999999e-2 .. 0.1]); p|x at rate MA(0.5); d at rate MA([9.999999999999999e-2 .. 0.1]); }) || ([0.2] E)" "/tmp/bond-sage-script-2zhgqz5n.py"' ...
# phi variables sfs = {x0}
# system sfs = System(R, (x0), [1], (-0.1000000000000000?*x0), varmap=bidict({'S': x0}))
# Computed 101 flowpipes in 0.006453987094573677 sec
# mask = None
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, [0.19999999999999998 .. 0.20000000000000002], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 3.398237148998305 sec
# PolyObserver(x1 - 0.12500000000000000?, <flowstar.reachability.Reach object at 0x7ff92c4b4b80>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.68 seconds
# roots = [[2.5999999999999907 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[2.5999999999999907 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[2.5999999999999907 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, [0.19999999999999998 .. 0.20000000000000002], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 2.8935318370349705 sec
# PolyObserver(x1 - 0.12500000000000000?, <flowstar.reachability.Reach object at 0x7ff92c4b44c0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.27 seconds
# roots = [[2.6999999999999899 .. 3.7000000000000033]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[2.6999999999999899 .. 3.7000000000000033]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[2.6999999999999899 .. 3.7000000000000033]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, [0.19999999999999998 .. 0.20000000000000002], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 2.293526132008992 sec
# PolyObserver(x1 - 0.12500000000000000?, <flowstar.reachability.Reach object at 0x7ff92c4b4040>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.24 seconds
# roots = [[3.5999999999999827 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.5999999999999827 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.5999999999999827 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, [0.19999999999999998 .. 0.20000000000000002], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.5981469069956802 sec
# PolyObserver(x1 - 0.12500000000000000?, <flowstar.reachability.Reach object at 0x7ff92c4b45e0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.12 seconds
# roots = [[3.6999999999999819 .. 4.4000000000000057]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.6999999999999819 .. 4.4000000000000057]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.6999999999999819 .. 4.4000000000000057]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, [0.19999999999999998 .. 0.20000000000000002], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.3489088350906968 sec
# PolyObserver(x1 - 0.12500000000000000?, <flowstar.reachability.Reach object at 0x7ff92c4b4040>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.09 seconds
# roots = [[4.3999999999999745 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.3999999999999745 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.3999999999999745 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, [0.19999999999999998 .. 0.20000000000000002], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 0.9143634059582837 sec
# PolyObserver(x1 - 0.12500000000000000?, <flowstar.reachability.Reach object at 0x7ff92c4b44c0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.05 seconds
# roots = [[4.3999999999999745 .. 4.8000000000000079], [4.8999999999999692 .. 4.9000000000000084]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.3999999999999745 .. 4.8000000000000079],
#  [4.8999999999999692 .. 4.9000000000000084]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.3999999999999745 .. 4.8000000000000079],
#  [4.8999999999999692 .. 4.9000000000000084]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, [0.19999999999999998 .. 0.20000000000000002], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 0.85601484606741 sec
# PolyObserver(x1 - 0.12500000000000000?, <flowstar.reachability.Reach object at 0x7ff92c4b4b80>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.04 seconds
# roots = [[4.7999999999999696 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.7999999999999696 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.7999999999999696 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, [0.19999999999999998 .. 0.20000000000000002], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 0.6822477559908293 sec
# PolyObserver(x1 - 0.12500000000000000?, <flowstar.reachability.Reach object at 0x7ff92c4b4820>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.03 seconds
# roots = [[4.7999999999999696 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.7999999999999696 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.7999999999999696 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, [0.19999999999999998 .. 0.20000000000000002], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 0.6014176920289174 sec
# PolyObserver(x1 - 0.12500000000000000?, <flowstar.reachability.Reach object at 0x7ff92c282dc0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.02 seconds
# roots = [[4.7999999999999696 .. 5.0000000000000089]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.7999999999999696 .. 5.0000000000000089]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.7999999999999696 .. 5.0000000000000089]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, [0.19999999999999998 .. 0.20000000000000002], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 0.6040079060476273 sec
# PolyObserver(x1 - 0.12500000000000000?, <flowstar.reachability.Reach object at 0x7ff92c282820>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.03 seconds
# roots = [[4.9999999999999671 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.9999999999999671 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.9999999999999671 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, [0.19999999999999998 .. 0.20000000000000002], 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 0.6736652780673467 sec
# PolyObserver(x1 - 0.12500000000000000?, <flowstar.reachability.Reach object at 0x7ff92c282280>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.02 seconds
# roots = []
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = []
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = []
# signal given bool roots: 1 items in 0.02 seconds

# %%
sig6.plot()
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# ## Introducing Enzyme Affinity Rule

# %%
pi3 = model.process("[1.0] S || [0.1 .. 0.15] E with network M4(0.0, 0.1, 0.5, 0.1)"); pi3
# Out:
# BondProcess('[1.0] S || [0.1 .. 0.15] E with network M4(0.0, 0.1, 0.5, 0.1)', <lbuc.bondcalculus.BondModel object at 0x7ff92c20b5e0>)

# %%
sys4 = pi3.as_system; sys4
# Out:
# Running cmd: 'savesage "[1.0] S || [0.1 .. 0.15] E with network M4(0.0, 0.1, 0.5, 0.1)" "/tmp/bond-sage-script-cu50orns.py"' ...
# System(R, (x0, x1), [1, [0.099999999999999977 .. 0.15000000000000003]], (-0.1000000000000000?*x0, 0), varmap=bidict({'S': x0, 'E': x1}))

# %%
r = sys4.reach(20)

# %%
r.sage_plot(var("S"), color=["blue", "blue"], fillcolor="blue", fill={0: [1]})
# Out:
# var_names = [b'local_t', b'x0', b'x1']
# res = b'(([1.0000000000 , 1.0000000000] * x0))'
# PolyObserver((([1.0000000000 , 1.0000000000] * x0)), <flowstar.reachability.Reach object at 0x7ff93cb6d3a0>, None, symbolic_composition=False, symbolic_composition_order=-1, tentative_unpreconditioning=False, mask=None)
# plot_points = 2000
# Graphics object consisting of 3 graphics primitives

# %%
r1 = sys4.reach(5)

# %%
sys5 = to_context_body("{ e || s at rate MA([1.0 .. 1.1]); }").apply_jump(sys4.with_y0(r1(RIF(5, 5))))
sys5
# Out:
# Running cmd: 'savesage "([0.60653050398995167 .. 0.60653076496687731] S || [0.099999999999996508 .. 0.15000000000000350] E || { e || s at rate MA(0.0); r|x at rate MA([9.999999999999999e-2 .. 0.1]); p|x at rate MA(0.5); d at rate MA([9.999999999999999e-2 .. 0.1]); }) || ({ e || s at rate MA([1.0 .. 1.1]); })" "/tmp/bond-sage-script-o20j8219.py"' ...
# System(R, (x0, x1, x2, x3), [[0.60653050398995156 .. 0.60653076496687742], 0, [0.099999999999996494 .. 0.15000000000000355], 0], (-1.?*x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -1.?*x0*x2 + 0.50000000000000000?*x3, 1.?*x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))

# %%
r2 = sys5.reach(10)

# %%
r2.successful
# Out:
# True

# %%
graphics_array([
  r1.sage_plot(var("S"), color=["blue", "blue"], fillcolor="blue", fill={0: [1]}, ymax=1)\
+ r1.sage_plot(var("E"), color=["green", "green"], fillcolor="green", fill={0: [1]}),
  r2.sage_plot(var("S"), color=["blue", "blue"], fillcolor="blue", fill={0: [1]}, ymax=1)\
+ r2.sage_plot(var("P"), color=["orange", "orange"], fillcolor="orange", fill={0: [1]})\
+ r2.sage_plot(var("E"), color=["green", "green"], fillcolor="green", fill={0: [1]}),
], 1, 2)
# Out:
# var_names = [b'local_t', b'x0', b'x1']
# res = b'(([1.0000000000 , 1.0000000000] * x0))'
# PolyObserver((([1.0000000000 , 1.0000000000] * x0)), <flowstar.reachability.Reach object at 0x7ff92ed2aee0>, None, symbolic_composition=False, symbolic_composition_order=-1, tentative_unpreconditioning=False, mask=None)
# plot_points = 500
# var_names = [b'local_t', b'x0', b'x1']
# res = b'(([1.0000000000 , 1.0000000000] * x1))'
# PolyObserver((([1.0000000000 , 1.0000000000] * x1)), <flowstar.reachability.Reach object at 0x7ff92ed2aee0>, None, symbolic_composition=False, symbolic_composition_order=-1, tentative_unpreconditioning=False, mask=None)
# plot_points = 500
# var_names = [b'local_t', b'x0', b'x1', b'x2', b'x3']
# res = b'(([1.0000000000 , 1.0000000000] * x0))'
# PolyObserver((([1.0000000000 , 1.0000000000] * x0)), <flowstar.reachability.Reach object at 0x7ff92c282940>, None, symbolic_composition=False, symbolic_composition_order=-1, tentative_unpreconditioning=False, mask=None)
# plot_points = 1000
# var_names = [b'local_t', b'x0', b'x1', b'x2', b'x3']
# res = b'(([1.0000000000 , 1.0000000000] * x1))'
# PolyObserver((([1.0000000000 , 1.0000000000] * x1)), <flowstar.reachability.Reach object at 0x7ff92c282940>, None, symbolic_composition=False, symbolic_composition_order=-1, tentative_unpreconditioning=False, mask=None)
# plot_points = 1000
# var_names = [b'local_t', b'x0', b'x1', b'x2', b'x3']
# res = b'(([1.0000000000 , 1.0000000000] * x2))'
# PolyObserver((([1.0000000000 , 1.0000000000] * x2)), <flowstar.reachability.Reach object at 0x7ff92c282940>, None, symbolic_composition=False, symbolic_composition_order=-1, tentative_unpreconditioning=False, mask=None)
# plot_points = 1000
# Graphics Array of size 1 x 2

# %%
prop5 = "{ e || s at rate MA(1.0); }" >> F(RIF(0, 5), Atomic(var("P") > 0.1)); prop5
# Out:
# C({ e || s at rate MA(1.0); }, F([0 .. 5], Atomic(P > 0.100000000000000)))

# %%
sig5 = prop5.signal_for_system(sys4, 10)
# Out:
# Running cmd: 'savesage "([1] S || [1] E || { e || s at rate MA(0.0); r|x at rate MA([9.999999999999999e-2 .. 0.1]); p|x at rate MA(0.5); d at rate MA([9.999999999999999e-2 .. 0.1]); }) || ({ e || s at rate MA(1.0); })" "/tmp/bond-sage-script-o4axjoks.py"' ...
# phi variables sfs = {x0, x1}
# system sfs = System(R, (x0, x1), [1, [0.099999999999999977 .. 0.15000000000000003]], (-0.1000000000000000?*x0, 0), varmap=bidict({'S': x0, 'E': x1}))
# Computed 101 flowpipes in 0.008357448037713766 sec
# mask = None
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, 0, 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 3.7210407870588824 sec
# PolyObserver(x1 - 0.10000000000000001?, <flowstar.reachability.Reach object at 0x7ff92c2825e0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 2.17 seconds
# roots = [[2.6999999999999899 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[2.6999999999999899 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[2.6999999999999899 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, 0, 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 3.4436729850131087 sec
# PolyObserver(x1 - 0.10000000000000001?, <flowstar.reachability.Reach object at 0x7ff92c2823a0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 1.23 seconds
# roots = [[2.7999999999999891 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[2.7999999999999891 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[2.7999999999999891 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, 0, 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 3.0049348269822076 sec
# PolyObserver(x1 - 0.10000000000000001?, <flowstar.reachability.Reach object at 0x7ff92c282040>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.76 seconds
# roots = [[2.8999999999999883 .. 4.8000000000000079]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[2.8999999999999883 .. 4.8000000000000079]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[2.8999999999999883 .. 4.8000000000000079]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, 0, 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 2.779361794993747 sec
# PolyObserver(x1 - 0.10000000000000001?, <flowstar.reachability.Reach object at 0x7ff92c4b4820>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.66 seconds
# roots = [[3.1999999999999859 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.1999999999999859 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.1999999999999859 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, 0, 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 2.444044367992319 sec
# PolyObserver(x1 - 0.10000000000000001?, <flowstar.reachability.Reach object at 0x7ff92c4b4b80>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.49 seconds
# roots = [[3.2999999999999851 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.2999999999999851 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.2999999999999851 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, 0, 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 2.1434208680293523 sec
# PolyObserver(x1 - 0.10000000000000001?, <flowstar.reachability.Reach object at 0x7ff92c4b44c0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.37 seconds
# roots = [[3.2999999999999851 .. 4.8000000000000079], [4.8999999999999692 .. 4.9000000000000084]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.2999999999999851 .. 4.8000000000000079],
#  [4.8999999999999692 .. 4.9000000000000084]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.2999999999999851 .. 4.8000000000000079],
#  [4.8999999999999692 .. 4.9000000000000084]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, 0, 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 2.0596305700019 sec
# PolyObserver(x1 - 0.10000000000000001?, <flowstar.reachability.Reach object at 0x7ff92c4b4040>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.42 seconds
# roots = [[3.3999999999999843 .. 5.0000000000000089]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.3999999999999843 .. 5.0000000000000089]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.3999999999999843 .. 5.0000000000000089]]
# signal given bool roots: 1 items in 0.04 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, 0, 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.9063627420109697 sec
# PolyObserver(x1 - 0.10000000000000001?, <flowstar.reachability.Reach object at 0x7ff92c282040>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.25 seconds
# roots = [[3.3999999999999843 .. 4.9000000000000084]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.3999999999999843 .. 4.9000000000000084]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.3999999999999843 .. 4.9000000000000084]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, 0, 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.8302731729927473 sec
# PolyObserver(x1 - 0.10000000000000001?, <flowstar.reachability.Reach object at 0x7ff92c2823a0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.25 seconds
# roots = [[3.3999999999999843 .. 5.0000000000000089]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.3999999999999843 .. 5.0000000000000089]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.3999999999999843 .. 5.0000000000000089]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, 0, 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 2.361233389005065 sec
# PolyObserver(x1 - 0.10000000000000001?, <flowstar.reachability.Reach object at 0x7ff92c2825e0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.47 seconds
# roots = [[3.4999999999999835 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.4999999999999835 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.4999999999999835 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, 0, 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 2.1091982320067473 sec
# PolyObserver(x1 - 0.10000000000000001?, <flowstar.reachability.Reach object at 0x7ff92c4b44c0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.33 seconds
# roots = [[3.4999999999999835 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.4999999999999835 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.4999999999999835 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, 0, 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.8773331039701588 sec
# PolyObserver(x1 - 0.10000000000000001?, <flowstar.reachability.Reach object at 0x7ff92c4b4b80>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.28 seconds
# roots = [[3.4999999999999835 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.4999999999999835 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.4999999999999835 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, 0, 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.7743546100100502 sec
# PolyObserver(x1 - 0.10000000000000001?, <flowstar.reachability.Reach object at 0x7ff92c4b4820>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.38 seconds
# roots = [[3.5999999999999827 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.5999999999999827 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.5999999999999827 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, 0, 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.9850117239984684 sec
# PolyObserver(x1 - 0.10000000000000001?, <flowstar.reachability.Reach object at 0x7ff92c4b45e0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.35 seconds
# roots = [[3.5999999999999827 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.5999999999999827 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.5999999999999827 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, 0, 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.75892270100303 sec
# PolyObserver(x1 - 0.10000000000000001?, <flowstar.reachability.Reach object at 0x7ff92ded6160>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.25 seconds
# roots = [[3.5999999999999827 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.5999999999999827 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.5999999999999827 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.04 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, 0, 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.6504312650067732 sec
# PolyObserver(x1 - 0.10000000000000001?, <flowstar.reachability.Reach object at 0x7ff92c2825e0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.22 seconds
# roots = [[3.6999999999999819 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.6999999999999819 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.6999999999999819 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, 0, 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 3.1328390010166913 sec
# PolyObserver(x1 - 0.10000000000000001?, <flowstar.reachability.Reach object at 0x7ff92c2823a0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.62 seconds
# roots = [[3.6999999999999819 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.6999999999999819 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.6999999999999819 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, 0, 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 2.6217076369794086 sec
# PolyObserver(x1 - 0.10000000000000001?, <flowstar.reachability.Reach object at 0x7ff92c282040>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.45 seconds
# roots = [[3.7999999999999811 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.7999999999999811 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.7999999999999811 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, 0, 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 2.256012630998157 sec
# PolyObserver(x1 - 0.10000000000000001?, <flowstar.reachability.Reach object at 0x7ff92c4b4dc0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.34 seconds
# roots = [[3.7999999999999811 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.7999999999999811 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.7999999999999811 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, 0, 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.9373449399718083 sec
# PolyObserver(x1 - 0.10000000000000001?, <flowstar.reachability.Reach object at 0x7ff92c4b43a0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.30 seconds
# roots = [[3.7999999999999811 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.7999999999999811 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.7999999999999811 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, 0, 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.8685693870065734 sec
# PolyObserver(x1 - 0.10000000000000001?, <flowstar.reachability.Reach object at 0x7ff92c4b4700>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.24 seconds
# roots = [[3.7999999999999811 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.7999999999999811 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.7999999999999811 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, 0, 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.785611669998616 sec
# PolyObserver(x1 - 0.10000000000000001?, <flowstar.reachability.Reach object at 0x7ff92c4b4ee0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.21 seconds
# roots = [[3.8999999999999803 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.8999999999999803 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.8999999999999803 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, 0, 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.800170000991784 sec
# PolyObserver(x1 - 0.10000000000000001?, <flowstar.reachability.Reach object at 0x7ff92c4b4040>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.23 seconds
# roots = [[3.8999999999999803 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.8999999999999803 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.8999999999999803 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, 0, 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.651308614993468 sec
# PolyObserver(x1 - 0.10000000000000001?, <flowstar.reachability.Reach object at 0x7ff92ded63a0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.20 seconds
# roots = [[3.8999999999999803 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.8999999999999803 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.8999999999999803 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.04 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, 0, 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.6505159140215255 sec
# PolyObserver(x1 - 0.10000000000000001?, <flowstar.reachability.Reach object at 0x7ff92c4b4040>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.18 seconds
# roots = [[3.9999999999999795 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.9999999999999795 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.9999999999999795 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, 0, 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 2.125016364036128 sec
# PolyObserver(x1 - 0.10000000000000001?, <flowstar.reachability.Reach object at 0x7ff92c4b4ee0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.24 seconds
# roots = [[4.0999999999999783 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.0999999999999783 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.0999999999999783 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, 0, 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.7896633180207573 sec
# PolyObserver(x1 - 0.10000000000000001?, <flowstar.reachability.Reach object at 0x7ff92c4b4700>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.22 seconds
# roots = [[4.0999999999999783 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.0999999999999783 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.0999999999999783 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, 0, 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.569359411019832 sec
# PolyObserver(x1 - 0.10000000000000001?, <flowstar.reachability.Reach object at 0x7ff92c4b43a0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.18 seconds
# roots = [[4.0999999999999783 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.0999999999999783 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.0999999999999783 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, 0, 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.5104102130280808 sec
# PolyObserver(x1 - 0.10000000000000001?, <flowstar.reachability.Reach object at 0x7ff92c4b4dc0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.17 seconds
# roots = [[4.1999999999999770 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.1999999999999770 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.1999999999999770 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, 0, 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.6311070179799572 sec
# PolyObserver(x1 - 0.10000000000000001?, <flowstar.reachability.Reach object at 0x7ff92c282040>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.18 seconds
# roots = [[4.2999999999999758 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.2999999999999758 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.2999999999999758 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, 0, 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.5958299150224775 sec
# PolyObserver(x1 - 0.10000000000000001?, <flowstar.reachability.Reach object at 0x7ff92c2823a0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.16 seconds
# roots = [[4.2999999999999758 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.2999999999999758 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.2999999999999758 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, 0, 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.5040283019770868 sec
# PolyObserver(x1 - 0.10000000000000001?, <flowstar.reachability.Reach object at 0x7ff92c2825e0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.14 seconds
# roots = [[4.3999999999999745 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.3999999999999745 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.3999999999999745 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, 0, 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 2.2832594250212424 sec
# PolyObserver(x1 - 0.10000000000000001?, <flowstar.reachability.Reach object at 0x7ff92ded65e0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.23 seconds
# roots = [[4.3999999999999745 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.3999999999999745 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.3999999999999745 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, 0, 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.99205887602875 sec
# PolyObserver(x1 - 0.10000000000000001?, <flowstar.reachability.Reach object at 0x7ff92ded6820>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.17 seconds
# roots = [[4.3999999999999745 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.3999999999999745 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.3999999999999745 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, 0, 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.6610105140134692 sec
# PolyObserver(x1 - 0.10000000000000001?, <flowstar.reachability.Reach object at 0x7ff92c282ca0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.16 seconds
# roots = [[4.4999999999999733 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.4999999999999733 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.4999999999999733 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, 0, 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.484516181051731 sec
# PolyObserver(x1 - 0.10000000000000001?, <flowstar.reachability.Reach object at 0x7ff92c2824c0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.18 seconds
# roots = [[4.4999999999999733 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.4999999999999733 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.4999999999999733 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, 0, 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.4666174000012688 sec
# PolyObserver(x1 - 0.10000000000000001?, <flowstar.reachability.Reach object at 0x7ff92c4b45e0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.14 seconds
# roots = [[4.5999999999999721 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.5999999999999721 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.5999999999999721 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, 0, 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.58671314798994 sec
# PolyObserver(x1 - 0.10000000000000001?, <flowstar.reachability.Reach object at 0x7ff92c4b4820>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.12 seconds
# roots = [[4.6999999999999708 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.6999999999999708 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.6999999999999708 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, 0, 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.4023059089668095 sec
# PolyObserver(x1 - 0.10000000000000001?, <flowstar.reachability.Reach object at 0x7ff92c4b4b80>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.12 seconds
# roots = [[4.6999999999999708 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.6999999999999708 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.6999999999999708 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, 0, 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.3879388749483041 sec
# PolyObserver(x1 - 0.10000000000000001?, <flowstar.reachability.Reach object at 0x7ff92c4b44c0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.10 seconds
# roots = [[4.7999999999999696 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.7999999999999696 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.7999999999999696 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, 0, 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.726387436967343 sec
# PolyObserver(x1 - 0.10000000000000001?, <flowstar.reachability.Reach object at 0x7ff92c4b4a60>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.11 seconds
# roots = [[4.8999999999999683 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.8999999999999683 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.8999999999999683 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, 0, 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.5494057509931736 sec
# PolyObserver(x1 - 0.10000000000000001?, <flowstar.reachability.Reach object at 0x7ff92c4b4040>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.13 seconds
# roots = [[4.8999999999999683 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.8999999999999683 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.8999999999999683 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, 0, 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.4257602359866723 sec
# PolyObserver(x1 - 0.10000000000000001?, <flowstar.reachability.Reach object at 0x7ff92c4b4ee0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.08 seconds
# roots = [[4.8999999999999683 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.8999999999999683 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.8999999999999683 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, 0, 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.4066517989849672 sec
# PolyObserver(x1 - 0.10000000000000001?, <flowstar.reachability.Reach object at 0x7ff92c4b4700>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.08 seconds
# roots = [[4.9999999999999671 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.9999999999999671 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[4.9999999999999671 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, 0, 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 1.4448715359903872 sec
# PolyObserver(x1 - 0.10000000000000001?, <flowstar.reachability.Reach object at 0x7ff92c4b43a0>, 0, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.06 seconds
# roots = []
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = []
# seg_domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = []
# signal given bool roots: 1 items in 0.00 seconds

# %%
sig5.plot()
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
sig7 = prop5.signal_for_system(sys4, 10, use_masks=True, symbolic_composition=True)
# Out:
# Running cmd: 'savesage "([1] S || [1] E || { e || s at rate MA(0.0); r|x at rate MA([9.999999999999999e-2 .. 0.1]); p|x at rate MA(0.5); d at rate MA([9.999999999999999e-2 .. 0.1]); }) || ({ e || s at rate MA(1.0); })" "/tmp/bond-sage-script-j7_ipi2u.py"' ...
# phi variables sfs = {x0, x1}
# system sfs = System(R, (x0, x1), [1, [0.099999999999999977 .. 0.15000000000000003]], (-0.1000000000000000?*x0, 0), varmap=bidict({'S': x0, 'E': x1}))
# Computed 101 flowpipes in 0.010120739054400474 sec
# mask = Mask([0.0000000000000000 .. 10.002000000000001], [[0.0000000000000000 .. 10.002000000000001]])
# mask = Mask([0.0000000000000000 .. 10.002000000000001], [[0.0000000000000000 .. 10.002000000000001]])
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, 0, 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 3.8062202330329455 sec
# PolyObserver(x1 - 0.10000000000000001?, <flowstar.reachability.Reach object at 0x7ff92c4b4820>, 0, symbolic_composition=True, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 5.0060000000000003], [[0.0000000000000000 .. 5.0060000000000003]]))
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 2.13 seconds
# roots = [[2.7725019234275123 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[2.7725019234275123 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000003]
# roots = [[2.7725019234275123 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, 0, 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 3.3246970750042237 sec
# PolyObserver(x1 - 0.10000000000000001?, <flowstar.reachability.Reach object at 0x7ff92c4b4700>, 0, symbolic_composition=True, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 5.0060000000000003], [[0.0000000000000000 .. 5.0060000000000003]]))
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 1.21 seconds
# roots = [[2.8236352991594011 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[2.8236352991594011 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000003]
# roots = [[2.8236352991594011 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, 0, 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 2.9913648950168863 sec
# PolyObserver(x1 - 0.10000000000000001?, <flowstar.reachability.Reach object at 0x7ff92c4b4ee0>, 0, symbolic_composition=True, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 5.0060000000000003], [[0.0000000000000000 .. 5.0060000000000003]]))
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.72 seconds
# roots = [[2.8626991606654934 .. 4.7784439036015583]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[2.8626991606654934 .. 4.7784439036015583]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000003]
# roots = [[2.8626991606654934 .. 4.7784439036015583]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, 0, 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 2.7813783999881707 sec
# PolyObserver(x1 - 0.10000000000000001?, <flowstar.reachability.Reach object at 0x7ff92c4b4040>, 0, symbolic_composition=True, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 5.0060000000000003], [[0.0000000000000000 .. 5.0060000000000003]]))
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.64 seconds
# roots = [[3.2623063320420007 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.2623063320420007 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000003]
# roots = [[3.2623063320420007 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, 0, 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 2.399578490993008 sec
# PolyObserver(x1 - 0.10000000000000001?, <flowstar.reachability.Reach object at 0x7ff92c4b45e0>, 0, symbolic_composition=True, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 5.0060000000000003], [[0.0000000000000000 .. 5.0060000000000003]]))
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.45 seconds
# roots = [[3.2701222995734777 .. 5.0059999999990011]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.2701222995734777 .. 5.0059999999990011]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000003]
# roots = [[3.2701222995734777 .. 5.0059999999990011]]
# signal given bool roots: 1 items in 0.00 seconds
# phi variables sfs = {x1}
# system sfs = System(R, (x0, x1, x2, x3), [0, 0, 0, 0], (-x0*x2 - 0.1000000000000000?*x0, 0.50000000000000000?*x3, -x0*x2 + 0.50000000000000000?*x3, x0*x2 - 0.50000000000000000?*x3), varmap=bidict({'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3}))
# Computed 51 flowpipes in 2.130770260002464 sec
# PolyObserver(x1 - 0.10000000000000001?, <flowstar.reachability.Reach object at 0x7ff92c282040>, 0, symbolic_composition=True, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=Mask([0.0000000000000000 .. 5.0060000000000003], [[0.0000000000000000 .. 5.0060000000000003]]))
# fprime = 0
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.34 seconds
# roots = [[3.2722420232951816 .. 4.8036222124488584]]
# domain = [0.0000000000000000 .. 5.0060000000000012]
# roots = [[3.2722420232951816 .. 4.8036222124488584]]
# seg_domain = [0.0000000000000000 .. 5.0060000000000003]
# roots = [[3