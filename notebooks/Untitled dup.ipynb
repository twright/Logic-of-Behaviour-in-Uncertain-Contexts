# %%
from sage.plot.plot2d.shapes import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-aaee24a81ab1> in <module>()
# ----> 1 from sage.plot.plot2d.shapes import *
#
# ModuleNotFoundError: No module named 'sage.plot.plot2d'

# %%
var("x, y")
# Out:
# (x, y)

# %%
implicit_plot([2*x + y == 3, x + 4*y == 2], (0, 10), (0,10))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/lib64/python3.7/site-packages/sage/ext/fast_callable.pyx in sage.ext.fast_callable.ExpressionTreeBuilder.var (build/cythonized/sage/ext/fast_callable.c:6766)()
#     726         try:
# --> 727             ind = self._vars.index(var_name)
#     728         except ValueError:
#
# ValueError: 'x' is not in list
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-aea5c24cbebe> in <module>()
# ----> 1 implicit_plot([Integer(2)*x + y == Integer(3), x + Integer(4)*y == Integer(2)], (Integer(0), Integer(10)), (Integer(0),Integer(10)))
#
# /usr/lib64/python3.7/site-packages/sage/misc/decorators.py in wrapper(*args, **kwds)
#     491                 options['__original_opts'] = kwds
# ...

# %%
Polyhedron?

# %%
zon = Polyhedron(ieqs=[[-3, 2, 1], [-2, 1, 4], [2, 1, 4], [3, 2, 1]]); zon
# Out:
# A 2-dimensional polyhedron in QQ^2 defined as the convex hull of 1 vertex and 2 rays

# %%
f = lambda v: (3*v[0] + 2*v[1] + 7, v[0] + 4*v[1] + 6)

# %%
zon = Polyhedron(vertices=[f((a, b)) for a in {-1, 1} for b in {-1, 1}])
zon
# Out:
# A 2-dimensional polyhedron in ZZ^2 defined as the convex hull of 4 vertices

# %%
zon.plot().save('zon.pdf')

# %%
zon.projection().plot()
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
from polytopes import parallelotope
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-31-87dadc673cdc> in <module>()
# ----> 1 from polytopes import parallelotope
#
# ModuleNotFoundError: No module named 'polytopes'

# %%
zon = polytopes.parallelotope([(3, 1), (2, 4)])
zon
# Out:
# A 2-dimensional polyhedron in ZZ^2 defined as the convex hull of 4 vertices

# %%
vs = [vector(v) + vector((4,3)) for v in zon.Vrepresentation()]

# %%
zon1 = Polyhedron(vertices=vs); zon1
# Out:
# A 2-dimensional polyhedron in ZZ^2 defined as the convex hull of 4 vertices

# %%
vs = [f((x, y)) for x in srange(-1, 1, 0.1) for y in srange(-1, 1, 0.1)]
vs
# Out:
# [(2.00000000000000, 1.00000000000000),
#  (2.20000000000000, 1.40000000000000),
#  (2.40000000000000, 1.80000000000000),
#  (2.60000000000000, 2.20000000000000),
#  (2.80000000000000, 2.60000000000000),
#  (3.00000000000000, 3.00000000000000),
#  (3.20000000000000, 3.40000000000000),
#  (3.40000000000000, 3.80000000000000),
#  (3.60000000000000, 4.20000000000000),
#  (3.80000000000000, 4.60000000000000),
#  (4.00000000000000, 5.00000000000000),
#  (4.20000000000000, 5.40000000000000),
#  (4.40000000000000, 5.80000000000000),
#  (4.60000000000000, 6.20000000000000),
#  (4.80000000000000, 6.60000000000000),
#  (5.00000000000000, 7.00000000000000),
#  (5.20000000000000, 7.40000000000000),
#  (5.40000000000000, 7.80000000000000),
#  (5.60000000000000, 8.20000000000000),
#  (5.80000000000000, 8.60000000000000),
#  (2.30000000000000, 1.10000000000000),
#  (2.50000000000000, 1.50000000000000),
#  (2.70000000000000, 1.90000000000000),
#  (2.90000000000000, 2.30000000000000),
# ...

# %%
zon = Polyhedron(vertices=vs)
zon
# Out:
# A 2-dimensional polyhedron in RDF^2 defined as the convex hull of 4 vertices
