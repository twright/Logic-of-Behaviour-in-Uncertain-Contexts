# %% [markdown]
# # Tests

# %% [markdown]
# ## Example 1: Simple

# %%
import sys

sys.path.insert(0, "/home/twright/Documents/PhD/Notebooks")

from flowstar.reachability import Reach
from flowstar.poly import Poly
from ulbc import *

# %%
R.<t,x,y> = RIF[]

# %%
TM_ORDER = 10
UNPRECONDITIONING_ORDER = None

# %%
odes = [
    R(1),
    -y,
    x,
]
initials = [(0,0), (4,5), (1,2)]
system = System(
    R,
    [t, x, y],
    initials,
    odes,
)
reach = system.reach(2*pi, step=0.01,
    order=TM_ORDER,
    precompose_taylor_models=False,
    unpreconditioning_order=UNPRECONDITIONING_ORDER,
    symbolic_composition=False)
# Out:
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.0000000000000000 .. 5.0000000000000000]', '[1.0000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.0..5.0]
# C = [1.0..2.0]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2

# %%
reach_points = [system.with_y0([(0,0), (4 + k), (1 + k)]).reach(2*pi, step=0.01, order=TM_ORDER,
              precompose_taylor_models=False,
              symbolic_composition=False)
    for k in srange(0, 1, 0.1, include_endpoint=True)]
reach_bands = [system.with_y0([(0,0), (4 + k, 4.1 + k), (1 + k, 1.1 + k)]).reach(2*pi, step=0.01, order=TM_ORDER,
               precompose_taylor_models=False,
               symbolic_composition=False)
     for k in srange(0, 1, 0.1, include_endpoint=False)]
# Out:
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.0000000000000000 .. 4.0000000000000000]', '[1.0000000000000000 .. 1.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.0..4.0]
# C = [1.0..1.0]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.0999999999999996 .. 4.0999999999999997]', '[1.1000000000000000 .. 1.1000000000000001]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.1..4.1]
# C = [1.1..1.1]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.2000000000000001 .. 4.2000000000000002]', '[1.1999999999999999 .. 1.2000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.2..4.2]
# C = [1.2..1.2]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.2999999999999998 .. 4.2999999999999999]', '[1.3000000000000000 .. 1.3000000000000001]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.3..4.3]
# C = [1.3..1.3]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.4000000000000003 .. 4.4000000000000004]', '[1.3999999999999999 .. 1.4000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.4..4.4]
# C = [1.4..1.4]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.5000000000000000 .. 4.5000000000000000]', '[1.5000000000000000 .. 1.5000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.5..4.5]
# C = [1.5..1.5]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.5999999999999996 .. 4.5999999999999997]', '[1.6000000000000000 .. 1.6000000000000001]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.6..4.6]
# C = [1.6..1.6]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.7000000000000001 .. 4.7000000000000002]', '[1.6999999999999999 .. 1.7000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.7..4.7]
# C = [1.7..1.7]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.7999999999999998 .. 4.7999999999999999]', '[1.7999999999999998 .. 1.7999999999999999]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.8..4.8]
# C = [1.7999999999999998..1.7999999999999998]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.9000000000000003 .. 4.9000000000000004]', '[1.8999999999999999 .. 1.9000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.9..4.9]
# C = [1.9..1.9]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[5.0000000000000000 .. 5.0000000000000000]', '[2.0000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [5.0..5.0]
# C = [2.0..2.0]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.0000000000000000 .. 4.0999999999999997]', '[1.0000000000000000 .. 1.1000000000000001]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.0..4.1]
# C = [1.0..1.1]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.0999999999999996 .. 4.1999999999999993]', '[1.1000000000000000 .. 1.2000000000000002]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.1..4.199999999999999]
# C = [1.1..1.2000000000000002]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.2000000000000001 .. 4.2999999999999999]', '[1.1999999999999999 .. 1.3000000000000001]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.2..4.3]
# C = [1.2..1.3]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.2999999999999998 .. 4.3999999999999995]', '[1.3000000000000000 .. 1.4000000000000002]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.3..4.3999999999999995]
# C = [1.3..1.4000000000000001]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.4000000000000003 .. 4.5000000000000000]', '[1.3999999999999999 .. 1.5000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.4..4.5]
# C = [1.4..1.5]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.5000000000000000 .. 4.5999999999999997]', '[1.5000000000000000 .. 1.6000000000000001]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.5..4.6]
# C = [1.5..1.6]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.5999999999999996 .. 4.6999999999999993]', '[1.6000000000000000 .. 1.7000000000000002]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.6..4.699999999999999]
# C = [1.6..1.7000000000000002]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.7000000000000001 .. 4.7999999999999999]', '[1.6999999999999999 .. 1.8000000000000001]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.7..4.8]
# C = [1.7..1.8]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.7999999999999998 .. 4.8999999999999995]', '[1.7999999999999998 .. 1.9000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.8..4.8999999999999995]
# C = [1.7999999999999998..1.9]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.9000000000000003 .. 5.0000000000000000]', '[1.8999999999999999 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.9..5.0]
# C = [1.9..2.0]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2

# %%
def plot_signal(sig):
    return sig.to_domain(RIF(0,2*pi)).plot().show(
        ticks=[pi/2, 1], tick_formatter=pi, aspect_ratio=2/3)

# %%
reach.res
# Out:
# 2

# %%
#S = Atomic(x + 1); S

# %%
S = Atomic(7 - (x + 1)**2 + y + x); S
# Out:
# Atomic(-x^2 - x + y + 6)

# %%
#S = Atomic(3 - y**2 + y); S

# %%
# Very Weird S
#S = Atomic(1e4 - y**2 + y + x**5 + x**3*y**6); S

# %%
p_points = sum([
    S.sage_plot(r, symbolic_composition=False,
                color=('black', 'black'),
                fillcolor=('black',))
    for r in reach_points
], Graphics())
# p_points += sum([
#     S.sage_plot(r, symbolic_composition=False,
#                 color=('grey', 'grey'),
#                 fillcolor=('grey',))
#     for r in reach_bands
# ], Graphics())
p_points
# Out:
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7f96535b7260>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7f96535b7370>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7f96535b7480>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7f96535b7590>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7f96535b76a0>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7f96535b77b0>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7f96535b78c0>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7f96535b79d0>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7f96535b7ae0>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7f96535b7bf0>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7f96535b7d00>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# /usr/lib64/python3.8/site-packages/numpy/core/getlimits.py:400: UserWarning: Signature b'\x99\x99\x99\x99\x99\x99\xb9\xbf' for <class 'numpy.float64'> does not match any known type: falling back to type probe function
#   machar = _get_machar(dtype)
# Graphics object consisting of 33 graphics primitives

# %%
p1 = S.sage_plot(reach); p1 + p_points
# Out:
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7f96535b7150>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# Graphics object consisting of 36 graphics primitives

# %%
SYMBOLIC_COMPOSITION_ORDER = -1

# %%
p2 = S.sage_plot(
    reach, symbolic_composition=True,
    symbolic_composition_order=SYMBOLIC_COMPOSITION_ORDER,
    color=('orange', 'orange'),
    fillcolor=('orange',),
)
p2 + p_points
# Out:
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7f96535b7150>, 2*x*y + x + y, symbolic_composition=True, symbolic_composition_order=-1, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# Graphics object consisting of 36 graphics primitives

# %%
p1+p2+p_points
# Out:
# Graphics object consisting of 39 graphics primitives

# %%
from functools import reduce

# %%
combined_signal = reduce(
    lambda a, b: a & b,
    (S.signal(r, symbolic_composition=False)
     for r in reach_bands),
)
combined_signal.plot()
# Out:
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7f96535b7e10>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# symbolic_composition=False,symbolic_composition_order=10, tentative_unpreconditioning=True,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0
]
# seg_domain = [0.0000000000000000 .. 6.2831853071795863]
# roots = [[0.62842505146896010 .. 0.66114434420739799],
#  [1.9415029379521331 .. 1.9760074426461345],
#  [4.0111975978527363 .. 4.0599420282428805],
#  [4.4075312300305951 .. 4.4450639412730757]]
# signal given bool roots: 1 items in 0.00 seconds
# Monitoring atomic -x^2 - x + y + 6 > 0: 1 items in 0.09 seconds
# Graphics object consisting of 2 graphics primitives

# %%
INCLUDE_DERIVS = None

# %%
sig1 = S.signal_for_system(system, 2*pi, symbolic_composition=False,
    selective_unpreconditioning=False,
    unpreconditioning_order=UNPRECONDITIONING_ORDER,
    unpreconditioning_include_derivs=INCLUDE_DERIVS)
sig2 = S.signal_for_system(
    system, 2*pi, symbolic_composition=True,
    symbolic_composition_order=SYMBOLIC_COMPOSITION_ORDER,
    unpreconditioning_order=UNPRECONDITIONING_ORDER,
    selective_unpreconditioning=False,
    unpreconditioning_include_derivs=INCLUDE_DERIVS,
)
sig3 = S.signal_for_system(system, 2*pi, symbolic_composition=False,
    selective_unpreconditioning=True,
    unpreconditioning_order=UNPRECONDITIONING_ORDER,
    selective_unpreconditioning_include_derivs=INCLUDE_DERIVS)
sig4 = S.signal_for_system(
    system, 2*pi, symbolic_composition=True,
    symbolic_composition_order=SYMBOLIC_COMPOSITION_ORDER,
    selective_unpreconditioning=True,
    unpreconditioning_order=UNPRECONDITIONING_ORDER,
    unpreconditioning_include_derivs=INCLUDE_DERIVS
)

g = graphics_array([
    sig1.plot(),
    sig2.plot(),
    sig3.plot(),
    sig4.plot(),
    combined_signal.plot(),
], ncols=1)
g.show(aspect_ratio=1/6)
# Out:
# Precomposing Contexts: 1 items in 0.00 seconds
# include_derivs = True
# phi variables sfs = {y, x}
# system sfs = System(R, (t, x, y), [0, [4 .. 5], [1 .. 2]], (1, -y, x), varmap=bidict({'t': t, 'x': x, 'y': y}))
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.0000000000000000 .. 5.0000000000000000]', '[1.0000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.0..5.0]
# C = [1.0..2.0]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# Running Flow*: 1 items in 0.03 seconds
# Computed 63 flowpipes in 0.03511893004179001 sec
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7f964b969e10>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# symbolic_composition=False,symbolic_composition_order=10, tentative_unpreconditioning=True,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.04 seconds
# roots = [[0.45140973772012277 .. 0.84050550362655119], [1.8999999999999959 .. 2.3763279338798871], [3.6862142030886904 .. 4.2447619084053479], [4.2999999999999758 .. 4.7168594972678176]]
# domain = [0.0000000000000000 .. 6.2851853071795869]
# roots = [[0.45140973772012277 .. 0.84050550362655119],
#  [1.8999999999999959 .. 2.3763279338798871],
#  [3.6862142030886904 .. 4.2447619084053479],
#  [4.2999999999999758 .. 4.7168594972678176]]
# seg_domain = [0.0000000000000000 .. 6.2851853071795869]
# roots = [[0.45140973772012277 .. 0.84050550362655119],
#  [1.8999999999999959 .. 2.3763279338798871],
#  [3.6862142030886904 .. 4.2447619084053479],
#  [4.2999999999999758 .. 4.7168594972678176]]
# signal given bool roots: 1 items in 0.00 seconds
# Monitoring atomic -x^2 - x + y + 6 > 0: 1 items in 0.04 seconds
# Monitoring Signal for -x^2 - x + y + 6 > 0: 1 items in 0.05 seconds
# ran "restoring globals" 9 times in 0.00011396408081054688
# ran "capturing globals [on exit]" 9 times in 8.082389831542969e-05
# ran "mask intersect check" 63 times in 0.00012159347534179688
# ran "tentative eval" 63 times in 0.009184122085571289
# ran "composing flowpipe" 23 times in 0.009277105331420898
# ran "whole domain eval" 22 times in 0.004163980484008789
# ran "post retrieve" 22 times in 0.00010371208190917969
# ran "root detection" 22 times in 0.01133275032043457
# ran "root amalgamation" 22 times in 3.838539123535156e-05
# ran "prepare in check" 5 times in 2.8371810913085938e-05
# ran "check boolean [unguarded]" 5 times in 0.00044226646423339844
# ran "observer.check" 5 times in 0.0005998611450195312
# Precomposing Contexts: 1 items in 0.00 seconds
# include_derivs = False
# phi variables sfs = {y, x}
# system sfs = System(R, (t, x, y), [0, [4 .. 5], [1 .. 2]], (1, -y, x), varmap=bidict({'t': t, 'x': x, 'y': y}))
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.0000000000000000 .. 5.0000000000000000]', '[1.0000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.0..5.0]
# C = [1.0..2.0]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# Running Flow*: 1 items in 0.03 seconds
# Computed 63 flowpipes in 0.03321295604109764 sec
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7f964836c260>, 2*x*y + x + y, symbolic_composition=True, symbolic_composition_order=-1, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# symbolic_composition=True,symbolic_composition_order=-1, tentative_unpreconditioning=True,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.06 seconds
# roots = [[0.42336374259952935 .. 0.80807924481532246], [1.9369353037238430 .. 2.3562092333469305], [3.6689217311387931 .. 4.7392255427521671]]
# domain = [0.0000000000000000 .. 6.2851853071795869]
# roots = [[0.42336374259952935 .. 0.80807924481532246],
#  [1.9369353037238430 .. 2.3562092333469305],
#  [3.6689217311387931 .. 4.7392255427521671]]
# seg_domain = [0.0000000000000000 .. 6.2851853071795869]
# roots = [[0.42336374259952935 .. 0.80807924481532246],
#  [1.9369353037238430 .. 2.3562092333469305],
#  [3.6689217311387931 .. 4.7392255427521671]]
# signal given bool roots: 1 items in 0.00 seconds
# Monitoring atomic -x^2 - x + y + 6 > 0: 1 items in 0.06 seconds
# Monitoring Signal for -x^2 - x + y + 6 > 0: 1 items in 0.07 seconds
# ran "restoring globals" 9 times in 9.584426879882812e-05
# ran "capturing globals [on exit]" 9 times in 6.937980651855469e-05
# ran "mask intersect check" 63 times in 0.00012373924255371094
# ran "tentative eval" 63 times in 0.009122848510742188
# ran "composing flowpipe" 22 times in 0.008521556854248047
# ran "whole domain eval" 22 times in 0.003875732421875
# ran "post retrieve" 22 times in 0.03576517105102539
# ran "root detection" 22 times in 0.00030612945556640625
# ran "root amalgamation" 22 times in 3.838539123535156e-05
# ran "prepare in check" 4 times in 2.2411346435546875e-05
# ran "check boolean [unguarded]" 4 times in 4.1484832763671875e-05
# ran "observer.check" 4 times in 0.00017571449279785156
# Precomposing Contexts: 1 items in 0.00 seconds
# include_derivs = True
# phi variables sfs = {y, x}
# system sfs = System(R, (t, x, y), [0, [4 .. 5], [1 .. 2]], (1, -y, x), varmap=bidict({'t': t, 'x': x, 'y': y}))
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.0000000000000000 .. 5.0000000000000000]', '[1.0000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.0..5.0]
# C = [1.0..2.0]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# Running Flow*: 1 items in 0.03 seconds
# Computed 63 flowpipes in 0.03256978705758229 sec
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7f964836c480>, 2*x*y + x + y, symbolic_composition=False, symbolic_composition_order=10, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# symbolic_composition=False,symbolic_composition_order=10, tentative_unpreconditioning=True,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.04 seconds
# roots = [[0.45140973772012277 .. 0.84050550362655119], [1.8999999999999959 .. 2.3763279338798871], [3.6862142030886904 .. 4.2447619084053479], [4.2999999999999758 .. 4.7168594972678176]]
# domain = [0.0000000000000000 .. 6.2851853071795869]
# roots = [[0.45140973772012277 .. 0.84050550362655119],
#  [1.8999999999999959 .. 2.3763279338798871],
#  [3.6862142030886904 .. 4.2447619084053479],
#  [4.2999999999999758 .. 4.7168594972678176]]
# seg_domain = [0.0000000000000000 .. 6.2851853071795869]
# roots = [[0.45140973772012277 .. 0.84050550362655119],
#  [1.8999999999999959 .. 2.3763279338798871],
#  [3.6862142030886904 .. 4.2447619084053479],
#  [4.2999999999999758 .. 4.7168594972678176]]
# signal given bool roots: 1 items in 0.00 seconds
# Monitoring atomic -x^2 - x + y + 6 > 0: 1 items in 0.04 seconds
# Monitoring Signal for -x^2 - x + y + 6 > 0: 1 items in 0.05 seconds
# ran "restoring globals" 9 times in 9.870529174804688e-05
# ran "capturing globals [on exit]" 9 times in 7.128715515136719e-05
# ran "mask intersect check" 63 times in 0.0001347064971923828
# ran "tentative eval" 63 times in 0.010441780090332031
# ran "composing flowpipe" 23 times in 0.008924007415771484
# ran "whole domain eval" 22 times in 0.004275321960449219
# ran "post retrieve" 22 times in 0.00010752677917480469
# ran "root detection" 22 times in 0.013295888900756836
# ran "root amalgamation" 22 times in 4.982948303222656e-05
# ran "prepare in check" 5 times in 2.765655517578125e-05
# ran "check boolean [unguarded]" 5 times in 0.0004832744598388672
# ran "observer.check" 5 times in 0.0006420612335205078
# Precomposing Contexts: 1 items in 0.00 seconds
# include_derivs = False
# phi variables sfs = {y, x}
# system sfs = System(R, (t, x, y), [0, [4 .. 5], [1 .. 2]], (1, -y, x), varmap=bidict({'t': t, 'x': x, 'y': y}))
# calling reach with y0 = ['[0.0000000000000000 .. 0.0000000000000000]', '[4.0000000000000000 .. 5.0000000000000000]', '[1.0000000000000000 .. 2.0000000000000000]']
# ode in polynomial ring
# crude_roots = False
# _handle_initials called!
# vars = [t, x, y]
# C = [0.0..0.0]
# C = [4.0..5.0]
# C = [1.0..2.0]
# assigning system with dimension 3
# resulting system has dimension 3
# run within tmv args
# integrationScheme = 2
# Running Flow*: 1 items in 0.03 seconds
# Computed 63 flowpipes in 0.031384857080411166 sec
# PolyObserver(-x^2 - x + y + 6, <flowstar.reachability.Reach object at 0x7f964836c370>, 2*x*y + x + y, symbolic_composition=True, symbolic_composition_order=-1, tentative_unpreconditioning=True, mask=None)
# fprime = 2*x*y + x + y
# symbolic_composition=True,symbolic_composition_order=-1, tentative_unpreconditioning=True,two_pass_masks=False
# roots(space_domain=None, epsilon=1e-05, verbosity=0)
# top-level root detection: 1 items in 0.06 seconds
# roots = [[0.42336374259952935 .. 0.80807924481532246], [1.9369353037238430 .. 2.3562092333469305], [3.6689217311387931 .. 4.7392255427521671]]
# domain = [0.0000000000000000 .. 6.2851853071795869]
# roots = [[0.42336374259952935 .. 0.80807924481532246],
#  [1.9369353037238430 .. 2.3562092333469305],
#  [3.6689217311387931 .. 4.7392255427521671]]
# seg_domain = [0.0000000000000000 .. 6.2851853071795869]
# roots = [[0.42336374259952935 .. 0.80807924481532246],
#  [1.9369353037238430 .. 2.3562092333469305],
#  [3.6689217311387931 .. 4.7392255427521671]]
# signal given bool roots: 1 items in 0.00 seconds
# Monitoring atomic -x^2 - x + y + 6 > 0: 1 items in 0.06 seconds
# Monitoring Signal for -x^2 - x + y + 6 > 0: 1 items in 0.07 seconds
# ran "restoring globals" 9 times in 0.00010752677917480469
# ran "capturing globals [on exit]" 9 times in 7.343292236328125e-05
# ran "mask intersect check" 63 times in 0.00011420249938964844
# ran "tentative eval" 63 times in 0.00901174545288086
# ran "composing flowpipe" 22 times in 0.008470535278320312
# ran "whole domain eval" 22 times in 0.003828763961791992
# ran "post retrieve" 22 times in 0.03597402572631836
# ran "root detection" 22 times in 0.00030231475830078125
# ran "root amalgamation" 22 times in 3.457069396972656e-05
# ran "prepare in check" 4 times in 2.2649765014648438e-05
# ran "check boolean [unguarded]" 4 times in 3.910064697265625e-05
# ran "observer.check" 4 times in 0.0001881122589111328
# Graphics Array of size 5 x 1

# %%
sig1
# Out:
# Signal([0.0000000000000000 .. 6.2831853071795872], [([0.0000000000000000 .. 0.45140973772012278], False), ([0.84050550362655118 .. 1.8999999999999960], True), ([2.3763279338798870 .. 3.6862142030886905], False), ([4.2447619084053478 .. 4.2999999999999759], True), ([4.7168594972678175 .. 6.2831853071795872], False)], mask=None)

# %%
sig2
# Out:
# Signal([0.0000000000000000 .. 6.2831853071795872], [([0.0000000000000000 .. 0.42336374259952936], False), ([0.80807924481532245 .. 1.9369353037238431], True), ([2.3562092333469304 .. 3.6689217311387932], False), ([4.7392255427521670 .. 6.2831853071795872], False)], mask=None)
