# %% [markdown]
# # Whelks and lobsters -- context operator

# %% [markdown]
# ## The system

# %%
R.<x,y> = QQ[]

# %%
from ulbc import *

# %%
us = [x,y]
k=RIF(0.8); b=RIF(0.6); c=RIF(0.3); e=RIF(0.05); f=RIF(2)
vf = vector([b*x*(RIF(1)-x) - c*x*(k-x)*y,
            -e*y*(RIF(1)+y)+f*x*(k-x)*y])
v0 = [RIF(0.5), RIF(2.0)]
v1 = [RIF(0.4), RIF(2.5)]
v2 = [RIF(1,1.2), RIF(4,6)]

# %%
v3 = v2 # [RIF(1,1.1), RIF(4,5)]

# %%
p = streamline_plot(tuple(vf),(x,0,1.5),(y,0,8), color='grey')\
    + point(v0, size=100, marker='X', color='red')\
    + point(v1, size=100, marker='X', color='green')\
    + polygon([(v3[0].lower(), v3[1].lower()),
               (v3[0].lower(), v3[1].upper()),
               (v3[0].upper(), v3[1].upper()),
               (v3[0].upper(), v3[1].lower())],
              color='orange')\
    + region_plot((lambda x, y: (x - 1)^2 + y^2 - 0.2 < 0),
                  (x, 0, 1.5),
                  (y, 0, 8),
                  incol='pink', plot_points=500, bordercol='red')
p.set_aspect_ratio(1/6)
p.show()
# Out:
# Graphics object consisting of 6 graphics primitives

# %% [markdown]
# ## Simple signal

# %%
P = Atomic((x - 1)^2 + y^2 - 0.2)

# %%
sig = F(RIF(4, 4.5), P).signal_for_system(vf, v3, 5, order=5, step=0.01,
                    precondition=1,
                    estimation=1e-3,
                    integrationScheme=2,
                    cutoff_threshold=1e-5,
                    precompose_taylor_models=True)
sig.plot()
# Out:
# In prepare! flowpipes_compo.size() = 951
# Pre-composing Taylor models: 8.26911568642 sec
# Computed 951 flowpipes in 16.6929018497 sec
# Prepared for plotting in 4.10079956055e-05 sec
# domain = [0.00000000000000000 .. 9.5000000000000018]
# roots = [[0.76763936727370341 .. 3.5700000000000381]]
# seg_domain = [0.00000000000000000 .. 9.5000000000000018]
# roots = [[0.76763936727370341 .. 3.5700000000000381]]
# Monitored signal 1.57165193558 sec
# /usr/lib64/python2.7/site-packages/matplotlib/contour.py:1230: UserWarning: No contour levels were found within the data range.
#   warnings.warn("No contour levels were found"
# Graphics object consisting of 2 graphics primitives

# %%
sig = F(RIF(4, 4.5), P).signal_for_system(vf, v3, 5, order=5, step=0.01,
                    precondition=1,
                    estimation=1e-3,
                    integrationScheme=2,
                    cutoff_threshold=1e-5,
                    use_masks=True,
                    precompose_taylor_models=True)
sig.plot()
# Out:
# In prepare! flowpipes_compo.size() = 951
# Pre-composing Taylor models: 9.91613674164 sec
# Computed 951 flowpipes in 17.9976549149 sec
# Prepared for plotting in 3.00407409668e-05 sec
# domain = [0.00000000000000000 .. 9.5000000000000018]
# roots = []
# seg_domain = [4.0000000000000000 .. 9.5000000000000000]
# roots = []
# Monitored signal 0.19082903862 sec
# Graphics object consisting of 2 graphics primitives

# %%
sig = F(RIF(4, 4.5), P).signal_for_system(vf, v3, 5, order=5, step=0.01,
                    precondition=1,
                    estimation=1e-3,
                    integrationScheme=2,
                    cutoff_threshold=1e-5,
                    tentative_unpreconditioning=False)
sig.plot()
# Out:
# Computed 951 flowpipes in 9.02815318108 sec
# In prepare! flowpipes_compo.size() = 951
# Prepared for plotting in 0.000509977340698 sec
# domain = [0.00000000000000000 .. 9.5000000000000018]
# roots = [[0.76763936727370341 .. 3.5700000000000381]]
# seg_domain = [0.00000000000000000 .. 9.5000000000000018]
# roots = [[0.76763936727370341 .. 3.5700000000000381]]
# Monitored signal 10.419277668 sec
# Graphics object consisting of 2 graphics primitives

# %%
sig = F(RIF(4, 4.5), P).signal_for_system(vf, v3, 5, order=5, step=0.01,
                    precondition=1,
                    estimation=1e-3,
                    integrationScheme=2,
                    cutoff_threshold=1e-5)
sig.plot()
# Out:
# Computed 951 flowpipes in 9.18362903595 sec
# In prepare! flowpipes_compo.size() = 951
# Prepared for plotting in 0.000625133514404 sec
# domain = [0.00000000000000000 .. 9.5000000000000018]
# roots = [[0.76763936727370341 .. 3.5700000000000381]]
# seg_domain = [0.00000000000000000 .. 9.5000000000000018]
# roots = [[0.76763936727370341 .. 3.5700000000000381]]
# Monitored signal 8.09141683578 sec
# Graphics object consisting of 2 graphics primitives

# %%
sig = F(RIF(4, 4.5), P).signal_for_system(vf, v3, 5, order=5, step=0.01,
                    precondition=1,
                    estimation=1e-3,
                    integrationScheme=2,
                    cutoff_threshold=1e-5,
                    use_masks=True)
sig.plot()
# Out:
# Computed 951 flowpipes in 8.23444914818 sec
# In prepare! flowpipes_compo.size() = 951
# Prepared for plotting in 0.000845193862915 sec
# domain = [0.00000000000000000 .. 9.5000000000000018]
# roots = []
# seg_domain = [4.0000000000000000 .. 9.5000000000000000]
# roots = []
# Monitored signal 1.17379260063 sec
# Graphics object consisting of 2 graphics primitives

# %%
sig = F(RIF(4, 4.5), P).signal_for_system(vf, v3, 5, order=5, step=0.01,
                    precondition=1,
                    estimation=1e-3,
                    symbolic_composition=True,
                    tentative_unpreconditioning=False,
                    integrationScheme=2,
                    cutoff_threshold=1e-5)
sig.plot()
# Out:
# Computed 951 flowpipes in 8.35416531563 sec
# In prepare! flowpipes_compo.size() = 951
# Prepared for plotting in 0.000303983688354 sec
# domain = [0.00000000000000000 .. 9.5000000000000018]
# roots = [[0.75999999999999123 .. 2.3400000000000097]]
# seg_domain = [0.00000000000000000 .. 9.5000000000000018]
# roots = [[0.75999999999999123 .. 2.3400000000000097]]
# Monitored signal 26.6030676365 sec
# Graphics object consisting of 2 graphics primitives

# %%
sig = F(RIF(4, 4.5), P).signal_for_system(vf, v3, 5, order=5, step=0.01,
                    precondition=1,
                    estimation=1e-3,
                    symbolic_composition=True,
                    integrationScheme=2,
                    cutoff_threshold=1e-5)
sig.plot()
# Out:
# Computed 951 flowpipes in 8.40780329704 sec
# In prepare! flowpipes_compo.size() = 951
# Prepared for plotting in 0.00102090835571 sec
# domain = [0.00000000000000000 .. 9.5000000000000018]
# roots = [[0.75999999999999123 .. 2.3400000000000097]]
# seg_domain = [0.00000000000000000 .. 9.5000000000000018]
# roots = [[0.75999999999999123 .. 2.3400000000000097]]
# Monitored signal 24.8469438553 sec
# Graphics object consisting of 2 graphics primitives

# %%
sig = F(RIF(4, 4.5), P).signal_for_system(vf, v3, 5, order=5, step=0.01,
                    precondition=1,
                    estimation=1e-3,
                    integrationScheme=2,
                    cutoff_threshold=1e-5,
                    tentative_unpreconditioning=False,
                    symbolic_composition=True,
                    use_masks=True)
sig.plot()
# Out:
# Computed 951 flowpipes in 9.32181811333 sec
# In prepare! flowpipes_compo.size() = 951
# Prepared for plotting in 0.000530004501343 sec
# domain = [0.00000000000000000 .. 9.5000000000000018]
# roots = []
# seg_domain = [4.0000000000000000 .. 9.5000000000000000]
# roots = []
# Monitored signal 3.99916267395 sec
# Graphics object consisting of 2 graphics primitives

# %%
sig = F(RIF(4, 4.5), P).signal_for_system(vf, v3, 5, order=5, step=0.01,
                    precondition=1,
                    estimation=1e-3,
                    integrationScheme=2,
                    cutoff_threshold=1e-5,
                    symbolic_composition=True,
                    use_masks=True)
sig.plot()
# Out:
# Computed 951 flowpipes in 8.17429924011 sec
# In prepare! flowpipes_compo.size() = 951
# Prepared for plotting in 0.000316143035889 sec
# domain = [0.00000000000000000 .. 9.5000000000000018]
# roots = []
# seg_domain = [4.0000000000000000 .. 9.5000000000000000]
# roots = []
# Monitored signal 1.15910768509 sec
# Graphics object consisting of 2 graphics primitives

# %%
sig = P.signal_for_system(vf, v3, 5, order=5, step=(0.01, 0.5),
                    precondition=1,
                    estimation=1e-3,
                    integrationScheme=2,
                    cutoff_threshold=1e-5,
                    symbolic_composition=True,
                    verbosity=3,
                    use_masks=True)
sig.plot()
# Out:
# Computed 115 flowpipes in 1.40578126907 sec
# In prepare! flowpipes_compo.size() = 115
# Prepared for plotting in 0.00086498260498 sec
# ===
# reached detect roots t=[0.0..0.0] + [0.0..0.03125]
# mask_overlap = [0.0..0.03125]
# mask_overlap = [-0.0..0.03125]
# t0 = [-0.0..0.03125]
# skipping given consistent value over domain
# ===
# reached detect roots t=[0.03125..0.03125] + [0.0..0.0171875]
# mask_overlap = [0.03125..0.0484375]
# mask_overlap = [-3.46944695195e-18..0.0171875]
# t0 = [0.0..0.0171875]
# skipping given consistent value over domain
# ===
# reached detect roots t=[0.0484375..0.0484375] + [0.0..0.01890625]
# mask_overlap = [0.0484375..0.06734375]
# mask_overlap = [-1.38777878078e-17..0.01890625]
# t0 = [0.0..0.01890625]
# skipping given consistent value over domain
# ===
# reached detect roots t=[0.06734375..0.06734375] + [0.0..0.020796875]
# mask_overlap = [0.06734375..0.088140625]
# mask_overlap = [-2.77555756156e-17..0.020796875]
# t0 = [0.0..0.020796875]
# skipping given consistent value over domain
# ===
# reached detect roots t=[0.088140625..0.088140625] + [0.0..0.0228765625]
# mask_overlap = [0.088140625..0.1110171875]
# mask_overlap = [-5.55111512313e-17..0.0228765625]
# t0 = [0.0..0.0228765625]
# skipping given consistent value over domain
# ===
# reached detect roots t=[0.1110171875..0.1110171875] + [0.0..0.02516421875]
# mask_overlap = [0.1110171875..0.13618140625]
# mask_overlap = [-8.32667268469e-17..0.02516421875]
# t0 = [0.0..0.02516421875]
# skipping given consistent value over domain
# ===
# reached detect roots t=[0.13618140625..0.13618140625] + [0.0..0.027680640625]
# mask_overlap = [0.13618140625..0.163862046875]
# mask_overlap = [-1.38777878078e-16..0.027680640625]
# t0 = [0.0..0.027680640625]
# skipping given consistent value over domain
# ===
# reached detect roots t=[0.163862046875..0.163862046875] + [0.0..0.0152243523438]
# mask_overlap = [0.163862046875..0.179086399219]
# mask_overlap = [-1.94289029309e-16..0.0152243523438]
# t0 = [0.0..0.0152243523438]
# skipping given consistent value over domain
# ===
# reached detect roots t=[0.179086399219..0.179086399219] + [0.0..0.0167467875781]
# mask_overlap = [0.179086399219..0.195833186797]
# mask_overlap = [-2.49800180541e-16..0.0167467875781]
# t0 = [0.0..0.0167467875781]
# skipping given consistent value over domain
# ===
# reached detect roots t=[0.195833186797..0.195833186797] + [0.0..0.0184214663359]
# mask_overlap = [0.195833186797..0.214254653133]
# mask_overlap = [-3.05311331772e-16..0.0184214663359]
# t0 = [0.0..0.0184214663359]
# skipping given consistent value over domain
# ===
# reached detect roots t=[0.214254653133..0.214254653133] + [0.0..0.0202636129695]
# mask_overlap = [0.214254653133..0.234518266102]
# mask_overlap = [-3.33066907388e-16..0.0202636129695]
# t0 = [0.0..0.0202636129695]
# skipping given consistent value over domain
# ===
# reached detect roots t=[0.234518266102..0.234518266102] + [0.0..0.0222899742665]
# mask_overlap = [0.234518266102..0.256808240369]
# mask_overlap = [-3.88578058619e-16..0.0222899742665]
# t0 = [0.0..0.0222899742665]
# skipping given consistent value over domain
# ===
# reached detect roots t=[0.256808240369..0.256808240369] + [0.0..0.0245189716931]
# mask_overlap = [0.256808240369..0.281327212062]
# mask_overlap = [-4.99600361081e-16..0.0245189716931]
# t0 = [0.0..0.0245189716931]
# skipping given consistent value over domain
# ===
# reached detect roots t=[0.281327212062..0.281327212062] + [0.0..0.0134854344312]
# mask_overlap = [0.281327212062..0.294812646493]
# mask_overlap = [-6.10622663544e-16..0.0134854344312]
# t0 = [0.0..0.0134854344312]
# skipping given consistent value over domain
# ===
# reached detect roots t=[0.294812646493..0.294812646493] + [0.0..0.0148339778743]
# mask_overlap = [0.294812646493..0.309646624368]
# mask_overlap = [-6.66133814775e-16..0.0148339778743]
# t0 = [0.0..0.0148339778743]
# skipping given consistent value over domain
# ===
# reached detect roots t=[0.309646624368..0.309646624368] + [0.0..0.0163173756618]
# mask_overlap = [0.309646624368..0.325964000029]
# mask_overlap = [-7.77156117238e-16..0.0163173756618]
# t0 = [0.0..0.0163173756618]
# skipping given consistent value over domain
# ===
# reached detect roots t=[0.325964000029..0.325964000029] + [0.0..0.017949113228]
# mask_overlap = [0.325964000029..0.343913113257]
# mask_overlap = [-8.881784197e-16..0.017949113228]
# t0 = [0.0..0.017949113228]
# skipping given consistent value over domain
# ===
# reached detect roots t=[0.343913113257..0.343913113257] + [0.0..0.0197440245508]
# mask_overlap = [0.343913113257..0.363657137808]
# mask_overlap = [-9.99200722163e-16..0.0197440245508]
# t0 = [0.0..0.0197440245508]
# skipping given consistent value over domain
# ===
# reached detect roots t=[0.363657137808..0.363657137808] + [0.0..0.0217184270058]
# mask_overlap = [0.363657137808..0.385375564814]
# mask_overlap = [-1.11022302463e-15..0.0217184270058]
# t0 = [0.0..0.0217184270058]
# skipping given consistent value over domain
# ===
# reached detect roots t=[0.385375564814..0.385375564814] + [0.0..0.0238902697064]
# mask_overlap = [0.385375564814..0.40926583452]
# mask_overlap = [-1.22124532709e-15..0.0238902697064]
# t0 = [0.0..0.0238902697064]
# skipping given consistent value over domain
# ===
# reached detect roots t=[0.40926583452..0.40926583452] + [0.0..0.0131396483385]
# mask_overlap = [0.40926583452..0.422405482859]
# mask_overlap = [-1.33226762955e-15..0.0131396483385]
# t0 = [0.0..0.0131396483385]
# skipping given consistent value over domain
# ===
# reached detect roots t=[0.422405482859..0.422405482859] + [0.0..0.0144536131724]
# mask_overlap = [0.422405482859..0.436859096031]
# mask_overlap = [-1.44328993201e-15..0.0144536131724]
# t0 = [0.0..0.0144536131724]
# skipping given consistent value over domain
# ===
# reached detect roots t=[0.436859096031..0.436859096031] + [0.0..0.0158989744896]
# mask_overlap = [0.436859096031..0.452758070521]
# mask_overlap = [-1.55431223448e-15..0.0158989744896]
# t0 = [0.0..0.0158989744896]
# skipping given consistent value over domain
# ===
# reached detect roots t=[0.452758070521..0.452758070521] + [0.0..0.0174888719386]
# mask_overlap = [0.452758070521..0.470246942459]
# mask_overlap = [-1.66533453694e-15..0.0174888719386]
# t0 = [0.0..0.0174888719386]
# skipping given consistent value over domain
# ===
# reached detect roots t=[0.470246942459..0.470246942459] + [0.0..0.0192377591324]
# mask_overlap = [0.470246942459..0.489484701592]
# mask_overlap = [-1.7763568394e-15..0.0192377591324]
# t0 = [0.0..0.0192377591324]
# skipping given consistent value over domain
# ===
# reached detect roots t=[0.489484701592..0.489484701592] + [0.0..0.0211615350457]
# mask_overlap = [0.489484701592..0.510646236637]
# mask_overlap = [-1.88737914186e-15..0.0211615350457]
# t0 = [0.0..0.0211615350457]
# skipping given consistent value over domain
# ===
# reached detect roots t=[0.510646236637..0.510646236637] + [0.0..0.0116388442751]
# mask_overlap = [0.510646236637..0.522285080913]
# mask_overlap = [-2.10942374679e-15..0.0116388442751]
# t0 = [0.0..0.0116388442751]
# skipping given consistent value over domain
# ===
# reached detect roots t=[0.522285080913..0.522285080913] + [0.0..0.0128027287026]
# mask_overlap = [0.522285080913..0.535087809615]
# mask_overlap = [-2.33146835171e-15..0.0128027287026]
# t0 = [0.0..0.0128027287026]
# skipping given consistent value over domain
# ===
# reached detect roots t=[0.535087809615..0.535087809615] + [0.0..0.0140830015729]
# mask_overlap = [0.535087809615..0.549170811188]
# mask_overlap = [-2.55351295664e-15..0.0140830015729]
# t0 = [0.0..0.0140830015729]
# skipping given consistent value over domain
# ===
# reached detect roots t=[0.549170811188..0.549170811188] + [0.0..0.0154913017302]
# mask_overlap = [0.549170811188..0.564662112918]
# mask_overlap = [-2.77555756156e-15..0.0154913017302]
# t0 = [0.0..0.0154913017302]
# skipping given consistent value over domain
# ===
# reached detect roots t=[0.564662112918..0.564662112918] + [0.0..0.0170404319032]
# mask_overlap = [0.564662112918..0.581702544822]
# mask_overlap = [-2.88657986403e-15..0.0170404319032]
# t0 = [0.0..0.0170404319032]
# skipping given consistent value over domain
# ===
# reached detect roots t=[0.581702544822..0.581702544822] + [0.0..0.0187444750935]
# mask_overlap = [0.581702544822..0.600447019915]
# mask_overlap = [-3.10862446895e-15..0.0187444750935]
# t0 = [0.0..0.0187444750935]
# skipping given consistent value over domain
# ===
# reached detect roots t=[0.600447019915..0.600447019915] + [0.0..0.0206189226029]
# mask_overlap = [0.600447019915..0.621065942518]
# mask_overlap = [-3.33066907388e-15..0.0206189226029]
# t0 = [0.0..0.0206189226029]
# skipping given consistent value over domain
# ===
# reached detect roots t=[0.621065942518..0.621065942518] + [0.0..0.0226808148632]
# mask_overlap = [0.621065942518..0.643746757381]
# mask_overlap = [-3.5527136788e-15..0.0226808148632]
# t0 = [0.0..0.0226808148632]
# skipping given consistent value over domain
# ===
# reached detect roots t=[0.643746757381..0.643746757381] + [0.0..0.0124744481747]
# mask_overlap = [0.643746757381..0.656221205556]
# mask_overlap = [-3.77475828373e-15..0.0124744481747]
# t0 = [0.0..0.0124744481747]
# skipping given consistent value over domain
# ===
# reached detect roots t=[0.656221205556..0.656221205556] + [0.0..0.0137218929922]
# mask_overlap = [0.656221205556..0.669943098548]
# mask_overlap = [-3.99680288865e-15..0.0137218929922]
# t0 = [0.0..0.0137218929922]
# skipping given consistent value over domain
# ===
# reached detect roots t=[0.669943098548..0.669943098548] + [0.0..0.0150940822914]
# mask_overlap = [0.669943098548..0.68503718084]
# mask_overlap = [-4.21884749358e-15..0.0150940822914]
# t0 = [0.0..0.0150940822914]
# skipping given consistent value over domain
# ===
# reached detect roots t=[0.68503718084..0.68503718084] + [0.0..0.0166034905206]
# mask_overlap = [0.68503718084..0.70164067136]
# mask_overlap = [-4.4408920985e-15..0.0166034905206]
# t0 = [0.0..0.0166034905206]
# skipping given consistent value over domain
# ===
# reached detect roots t=[0.70164067136..0.70164067136] + [0.0..0.0182638395726]
# mask_overlap = [0.70164067136..0.719904510933]
# mask_overlap = [-4.66293670343e-15..0.0182638395726]
# t0 = [0.0..0.0182638395726]
# skipping given consistent value over domain
# ===
# reached detect roots t=[0.719904510933..0.719904510933] + [0.0..0.0200902235299]
# mask_overlap = [0.719904510933..0.739994734463]
# mask_overlap = [-4.88498130835e-15..0.0200902235299]
# t0 = [0.0..0.0200902235299]
# skipping given consistent value over domain
# ===
# reached detect roots t=[0.739994734463..0.739994734463] + [0.0..0.0220992458829]
# mask_overlap = [0.739994734463..0.762093980346]
# mask_overlap = [-5.10702591328e-15..0.0220992458829]
# t0 = [0.0..0.0220992458829]
# detect_roots(T0=[0.0..0.0220992458829], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0220992458829]
# M = [0.0110496229414..0.0110496229414]
# fI = [-0.561955283383..7.55183883739]
# Tfinal = [-0.0..0.0220992458829]
# root on boundary!
# new root:
# [0.739994734463..0.762093980346]
# ===
# reached detect roots t=[0.762093980346..0.762093980346] + [0.0..0.0243091704712]
# mask_overlap = [0.762093980346..0.786403150817]
# mask_overlap = [-5.3290705182e-15..0.0243091704712]
# t0 = [0.0..0.0243091704712]
# detect_roots(T0=[0.0..0.0243091704712], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0243091704712]
# M = [0.0121545852356..0.0121545852356]
# fI = [-0.610802713084..7.1145224074]
# Tfinal = [-0.0..0.0243091704712]
# root on boundary!
# merging intervals:
# [0.739994734463..0.762093980346]
# [0.762093980346..0.786403150817]
# ===
# reached detect roots t=[0.786403150817..0.786403150817] + [0.0..0.0133700437592]
# mask_overlap = [0.786403150817..0.799773194576]
# mask_overlap = [-5.44009282066e-15..0.0133700437592]
# t0 = [0.0..0.0133700437592]
# detect_roots(T0=[0.0..0.0133700437592], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0133700437592]
# M = [0.00668502187958..0.00668502187958]
# fI = [-0.515681122302..6.6483352781]
# Tfinal = [-0.0..0.0133700437592]
# root on boundary!
# merging intervals:
# [0.739994734463..0.786403150817]
# [0.786403150817..0.799773194576]
# ===
# reached detect roots t=[0.799773194576..0.799773194576] + [0.0..0.0147070481351]
# mask_overlap = [0.799773194576..0.814480242711]
# mask_overlap = [-5.66213742559e-15..0.0147070481351]
# t0 = [0.0..0.0147070481351]
# detect_roots(T0=[0.0..0.0147070481351], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0147070481351]
# M = [0.00735352406753..0.00735352406753]
# fI = [-0.535551676322..6.40481321634]
# Tfinal = [-0.0..0.0147070481351]
# root on boundary!
# merging intervals:
# [0.739994734463..0.799773194576]
# [0.799773194576..0.814480242711]
# ===
# reached detect roots t=[0.814480242711..0.814480242711] + [0.0..0.0161777529486]
# mask_overlap = [0.814480242711..0.83065799566]
# mask_overlap = [-5.88418203051e-15..0.0161777529486]
# t0 = [0.0..0.0161777529486]
# detect_roots(T0=[0.0..0.0161777529486], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0161777529486]
# M = [0.00808887647429..0.00808887647429]
# fI = [-0.55345487654..6.14538273737]
# Tfinal = [-0.0..0.0161777529486]
# root on boundary!
# merging intervals:
# [0.739994734463..0.814480242711]
# [0.814480242711..0.83065799566]
# ===
# reached detect roots t=[0.83065799566..0.83065799566] + [0.0..0.0177955282434]
# mask_overlap = [0.83065799566..0.848453523903]
# mask_overlap = [-6.10622663544e-15..0.0177955282434]
# t0 = [0.0..0.0177955282434]
# detect_roots(T0=[0.0..0.0177955282434], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0177955282434]
# M = [0.00889776412172..0.00889776412172]
# fI = [-0.56921202036..5.87046632995]
# Tfinal = [-0.0..0.0177955282434]
# root on boundary!
# merging intervals:
# [0.739994734463..0.83065799566]
# [0.83065799566..0.848453523903]
# ===
# reached detect roots t=[0.848453523903..0.848453523903] + [0.0..0.0195750810678]
# mask_overlap = [0.848453523903..0.868028604971]
# mask_overlap = [-6.32827124036e-15..0.0195750810678]
# t0 = [0.0..0.0195750810678]
# detect_roots(T0=[0.0..0.0195750810678], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0195750810678]
# M = [0.00978754053389..0.00978754053389]
# fI = [-0.581487664407..5.57964576681]
# Tfinal = [-0.0..0.0195750810678]
# root on boundary!
# merging intervals:
# [0.739994734463..0.848453523903]
# [0.848453523903..0.868028604971]
# ===
# reached detect roots t=[0.868028604971..0.868028604971] + [0.0..0.0215325891746]
# mask_overlap = [0.868028604971..0.889561194145]
# mask_overlap = [-6.55031584529e-15..0.0215325891746]
# t0 = [0.0..0.0215325891746]
# detect_roots(T0=[0.0..0.0215325891746], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0215325891746]
# M = [0.0107662945873..0.0107662945873]
# fI = [-0.591287823166..5.27517683194]
# Tfinal = [-0.0..0.0215325891746]
# root on boundary!
# merging intervals:
# [0.739994734463..0.868028604971]
# [0.868028604971..0.889561194145]
# ===
# reached detect roots t=[0.889561194145..0.889561194145] + [0.0..0.023685848092]
# mask_overlap = [0.889561194145..0.913247042237]
# mask_overlap = [-6.77236045021e-15..0.023685848092]
# t0 = [0.0..0.023685848092]
# detect_roots(T0=[0.0..0.023685848092], epsilon=1e-05, verbosity=3)
# T = [0.0..0.023685848092]
# M = [0.011842924046..0.011842924046]
# fI = [-0.596133553334..4.95620452861]
# Tfinal = [-0.0..0.023685848092]
# root on boundary!
# merging intervals:
# [0.739994734463..0.889561194145]
# [0.889561194145..0.913247042237]
# ===
# reached detect roots t=[0.913247042237..0.913247042237] + [0.0..0.0260544329012]
# mask_overlap = [0.913247042237..0.939301475139]
# mask_overlap = [-6.99440505514e-15..0.0260544329012]
# t0 = [0.0..0.0260544329012]
# detect_roots(T0=[0.0..0.0260544329012], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0260544329012]
# M = [0.0130272164506..0.0130272164506]
# fI = [-0.598284755222..4.62701100842]
# Tfinal = [-0.0..0.0260544329012]
# root on boundary!
# merging intervals:
# [0.739994734463..0.913247042237]
# [0.913247042237..0.939301475139]
# ===
# reached detect roots t=[0.939301475139..0.939301475139] + [0.0..0.0286598761913]
# mask_overlap = [0.939301475139..0.96796135133]
# mask_overlap = [-7.21644966006e-15..0.0286598761913]
# t0 = [0.0..0.0286598761913]
# detect_roots(T0=[0.0..0.0286598761913], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0286598761913]
# M = [0.0143299380957..0.0143299380957]
# fI = [-0.593226879773..4.28541928441]
# Tfinal = [-0.0..0.0286598761913]
# root on boundary!
# merging intervals:
# [0.739994734463..0.939301475139]
# [0.939301475139..0.96796135133]
# ===
# reached detect roots t=[0.96796135133..0.96796135133] + [0.0..0.0157629319052]
# mask_overlap = [0.96796135133..0.983724283235]
# mask_overlap = [-7.43849426499e-15..0.0157629319052]
# t0 = [0.0..0.0157629319052]
# detect_roots(T0=[0.0..0.0157629319052], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0157629319052]
# M = [0.00788146595262..0.00788146595262]
# fI = [-0.483238270685..3.92221814322]
# Tfinal = [-0.0..0.0157629319052]
# root on boundary!
# merging intervals:
# [0.739994734463..0.96796135133]
# [0.96796135133..0.983724283235]
# ===
# reached detect roots t=[0.983724283235..0.983724283235] + [0.0..0.0173392250958]
# mask_overlap = [0.983724283235..1.00106350833]
# mask_overlap = [-7.66053886991e-15..0.0173392250958]
# t0 = [0.0..0.0173392250958]
# detect_roots(T0=[0.0..0.0173392250958], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0173392250958]
# M = [0.00866961254788..0.00866961254788]
# fI = [-0.4781803549..3.73947344574]
# Tfinal = [-0.0..0.0173392250958]
# root on boundary!
# merging intervals:
# [0.739994734463..0.983724283235]
# [0.983724283235..1.00106350833]
# ===
# reached detect roots t=[1.00106350833..1.00106350833] + [0.0..0.0190731476053]
# mask_overlap = [1.00106350833..1.02013665594]
# mask_overlap = [-7.9936057773e-15..0.0190731476053]
# t0 = [0.0..0.0190731476053]
# detect_roots(T0=[0.0..0.0190731476053], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0190731476053]
# M = [0.00953657380267..0.00953657380267]
# fI = [-0.470608065966..3.54664634334]
# Tfinal = [-0.0..0.0190731476053]
# root on boundary!
# merging intervals:
# [0.739994734463..1.00106350833]
# [1.00106350833..1.02013665594]
# ===
# reached detect roots t=[1.02013665594..1.02013665594] + [0.0..0.0209804623659]
# mask_overlap = [1.02013665594..1.0411171183]
# mask_overlap = [-8.43769498715e-15..0.0209804623659]
# t0 = [0.0..0.0209804623659]
# detect_roots(T0=[0.0..0.0209804623659], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0209804623659]
# M = [0.0104902311829..0.0104902311829]
# fI = [-0.461003286785..3.34496430863]
# Tfinal = [-0.0..0.0209804623659]
# root on boundary!
# merging intervals:
# [0.739994734463..1.02013665594]
# [1.02013665594..1.0411171183]
# ===
# reached detect roots t=[1.0411171183..1.0411171183] + [0.0..0.0230785086025]
# mask_overlap = [1.0411171183..1.0641956269]
# mask_overlap = [-8.881784197e-15..0.0230785086025]
# t0 = [0.0..0.0230785086025]
# detect_roots(T0=[0.0..0.0230785086025], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0230785086025]
# M = [0.0115392543012..0.0115392543012]
# fI = [-0.448876284419..3.13485798958]
# Tfinal = [-0.0..0.0230785086025]
# root on boundary!
# merging intervals:
# [0.739994734463..1.0411171183]
# [1.0411171183..1.0641956269]
# ===
# reached detect roots t=[1.0641956269..1.0641956269] + [0.0..0.0253863594627]
# mask_overlap = [1.0641956269..1.08958198637]
# mask_overlap = [-9.32587340685e-15..0.0253863594627]
# t0 = [0.0..0.0253863594627]
# detect_roots(T0=[0.0..0.0253863594627], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0253863594627]
# M = [0.0126931797313..0.0126931797313]
# fI = [-0.455687754131..2.9389528362]
# Tfinal = [-0.0..0.0253863594627]
# root on boundary!
# merging intervals:
# [0.739994734463..1.0641956269]
# [1.0641956269..1.08958198637]
# ===
# reached detect roots t=[1.08958198637..1.08958198637] + [0.0..0.027924995409]
# mask_overlap = [1.08958198637..1.11750698178]
# mask_overlap = [-9.7699626167e-15..0.027924995409]
# t0 = [0.0..0.027924995409]
# detect_roots(T0=[0.0..0.027924995409], epsilon=1e-05, verbosity=3)
# T = [0.0..0.027924995409]
# M = [0.0139624977045..0.0139624977045]
# fI = [-0.460609339831..2.73773635554]
# Tfinal = [-0.0..0.027924995409]
# root on boundary!
# merging intervals:
# [0.739994734463..1.08958198637]
# [1.08958198637..1.11750698178]
# ===
# reached detect roots t=[1.11750698178..1.11750698178] + [0.0..0.0307174949499]
# mask_overlap = [1.11750698178..1.14822447673]
# mask_overlap = [-1.02140518266e-14..0.0307174949499]
# t0 = [0.0..0.0307174949499]
# detect_roots(T0=[0.0..0.0307174949499], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0307174949499]
# M = [0.0153587474749..0.0153587474749]
# fI = [-0.46356224242..2.53273847529]
# Tfinal = [-0.0..0.0307174949499]
# root on boundary!
# merging intervals:
# [0.739994734463..1.11750698178]
# [1.11750698178..1.14822447673]
# ===
# reached detect roots t=[1.14822447673..1.14822447673] + [0.0..0.0337892444448]
# mask_overlap = [1.14822447673..1.18201372117]
# mask_overlap = [-1.06581410364e-14..0.0337892444449]
# t0 = [0.0..0.0337892444448]
# detect_roots(T0=[0.0..0.0337892444448], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0337892444448]
# M = [0.0168946222224..0.0168946222224]
# fI = [-0.460624029063..2.32177133409]
# Tfinal = [-0.0..0.0337892444448]
# root on boundary!
# merging intervals:
# [0.739994734463..1.14822447673]
# [1.14822447673..1.18201372117]
# ===
# reached detect roots t=[1.18201372117..1.18201372117] + [0.0..0.0185840844447]
# mask_overlap = [1.18201372117..1.20059780562]
# mask_overlap = [-1.11022302463e-14..0.0185840844447]
# t0 = [0.0..0.0185840844447]
# detect_roots(T0=[0.0..0.0185840844447], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0185840844447]
# M = [0.00929204222233..0.00929204222233]
# fI = [-0.389602641668..2.09628385127]
# Tfinal = [-0.0..0.0185840844447]
# root on boundary!
# merging intervals:
# [0.739994734463..1.18201372117]
# [1.18201372117..1.20059780562]
# ===
# reached detect roots t=[1.20059780562..1.20059780562] + [0.0..0.0204424928891]
# mask_overlap = [1.20059780562..1.2210402985]
# mask_overlap = [-1.15463194561e-14..0.0204424928891]
# t0 = [0.0..0.0204424928891]
# detect_roots(T0=[0.0..0.0204424928891], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0204424928891]
# M = [0.0102212464446..0.0102212464446]
# fI = [-0.394652451035..1.99413926252]
# Tfinal = [-0.0..0.0204424928891]
# root on boundary!
# merging intervals:
# [0.739994734463..1.20059780562]
# [1.20059780562..1.2210402985]
# ===
# reached detect roots t=[1.2210402985..1.2210402985] + [0.0..0.022486742178]
# mask_overlap = [1.2210402985..1.24352704068]
# mask_overlap = [-1.1990408666e-14..0.0224867421781]
# t0 = [0.0..0.022486742178]
# detect_roots(T0=[0.0..0.022486742178], epsilon=1e-05, verbosity=3)
# T = [0.0..0.022486742178]
# M = [0.011243371089..0.011243371089]
# fI = [-0.40291189135..1.89163276504]
# Tfinal = [-0.0..0.022486742178]
# root on boundary!
# merging intervals:
# [0.739994734463..1.2210402985]
# [1.2210402985..1.24352704068]
# ===
# reached detect roots t=[1.24352704068..1.24352704068] + [0.0..0.0247354163959]
# mask_overlap = [1.24352704068..1.26826245708]
# mask_overlap = [-1.24344978758e-14..0.0247354163959]
# t0 = [0.0..0.0247354163959]
# detect_roots(T0=[0.0..0.0247354163959], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0247354163959]
# M = [0.0123677081979..0.0123677081979]
# fI = [-0.408821956728..1.78377431628]
# Tfinal = [-0.0..0.0247354163959]
# root on boundary!
# merging intervals:
# [0.739994734463..1.24352704068]
# [1.24352704068..1.26826245708]
# ===
# reached detect roots t=[1.26826245708..1.26826245708] + [0.0..0.0272089580354]
# mask_overlap = [1.26826245708..1.29547141511]
# mask_overlap = [-1.26565424807e-14..0.0272089580354]
# t0 = [0.0..0.0272089580354]
# detect_roots(T0=[0.0..0.0272089580354], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0272089580354]
# M = [0.0136044790177..0.0136044790177]
# fI = [-0.411847549116..1.6707188523]
# Tfinal = [-0.0..0.0272089580354]
# root on boundary!
# merging intervals:
# [0.739994734463..1.26826245708]
# [1.26826245708..1.29547141511]
# ===
# reached detect roots t=[1.29547141511..1.29547141511] + [0.0..0.029929853839]
# mask_overlap = [1.29547141511..1.32540126895]
# mask_overlap = [-1.31006316906e-14..0.029929853839]
# t0 = [0.0..0.029929853839]
# detect_roots(T0=[0.0..0.029929853839], epsilon=1e-05, verbosity=3)
# T = [0.0..0.029929853839]
# M = [0.0149649269195..0.0149649269195]
# fI = [-0.411574988893..1.55282796183]
# Tfinal = [-0.0..0.029929853839]
# root on boundary!
# merging intervals:
# [0.739994734463..1.29547141511]
# [1.29547141511..1.32540126895]
# ===
# reached detect roots t=[1.32540126895..1.32540126895] + [0.0..0.0329228392229]
# mask_overlap = [1.32540126895..1.35832410818]
# mask_overlap = [-1.35447209004e-14..0.0329228392229]
# t0 = [0.0..0.0329228392229]
# detect_roots(T0=[0.0..0.0329228392229], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0329228392229]
# M = [0.0164614196114..0.0164614196114]
# fI = [-0.408221819764..1.43123647911]
# Tfinal = [-0.0..0.0329228392229]
# root on boundary!
# merging intervals:
# [0.739994734463..1.32540126895]
# [1.32540126895..1.35832410818]
# ===
# reached detect roots t=[1.35832410818..1.35832410818] + [0.0..0.0362151231452]
# mask_overlap = [1.35832410818..1.39453923132]
# mask_overlap = [-1.39888101103e-14..0.0362151231452]
# t0 = [0.0..0.0362151231452]
# detect_roots(T0=[0.0..0.0362151231452], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0362151231452]
# M = [0.0181075615726..0.0181075615726]
# fI = [-0.40257111944..1.30765408371]
# Tfinal = [-0.0..0.0362151231452]
# root on boundary!
# merging intervals:
# [0.739994734463..1.35832410818]
# [1.35832410818..1.39453923132]
# ===
# reached detect roots t=[1.39453923132..1.39453923132] + [0.0..0.0398366354597]
# mask_overlap = [1.39453923132..1.43437586678]
# mask_overlap = [-1.44328993201e-14..0.0398366354597]
# t0 = [0.0..0.0398366354597]
# detect_roots(T0=[0.0..0.0398366354597], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0398366354597]
# M = [0.0199183177298..0.0199183177298]
# fI = [-0.393358695195..1.18185441433]
# Tfinal = [-0.0..0.0398366354597]
# root on boundary!
# merging intervals:
# [0.739994734463..1.39453923132]
# [1.39453923132..1.43437586678]
# ===
# reached detect roots t=[1.43437586678..1.43437586678] + [0.0..0.0438202990057]
# mask_overlap = [1.43437586678..1.47819616579]
# mask_overlap = [-1.487698853e-14..0.0438202990057]
# t0 = [0.0..0.0438202990057]
# detect_roots(T0=[0.0..0.0438202990057], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0438202990057]
# M = [0.0219101495028..0.0219101495028]
# fI = [-0.384658090962..1.05895577757]
# Tfinal = [-0.0..0.0438202990057]
# root on boundary!
# merging intervals:
# [0.739994734463..1.43437586678]
# [1.43437586678..1.47819616579]
# ===
# reached detect roots t=[1.47819616579..1.47819616579] + [0.0..0.0241011644531]
# mask_overlap = [1.47819616579..1.50229733024]
# mask_overlap = [-1.53210777398e-14..0.0241011644531]
# t0 = [0.0..0.0241011644531]
# detect_roots(T0=[0.0..0.0241011644531], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0241011644531]
# M = [0.0120505822266..0.0120505822266]
# fI = [-0.343645963467..0.934757466344]
# Tfinal = [-0.0..0.0241011644531]
# root on boundary!
# merging intervals:
# [0.739994734463..1.47819616579]
# [1.47819616579..1.50229733024]
# ===
# reached detect roots t=[1.50229733024..1.50229733024] + [0.0..0.0265112808984]
# mask_overlap = [1.50229733024..1.52880861114]
# mask_overlap = [-1.57651669497e-14..0.0265112808984]
# t0 = [0.0..0.0265112808984]
# detect_roots(T0=[0.0..0.0265112808984], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0265112808984]
# M = [0.0132556404492..0.0132556404492]
# fI = [-0.340647874634..0.874800287781]
# Tfinal = [-0.0..0.0265112808984]
# root on boundary!
# merging intervals:
# [0.739994734463..1.50229733024]
# [1.50229733024..1.52880861114]
# ===
# reached detect roots t=[1.52880861114..1.52880861114] + [0.0..0.0291624089883]
# mask_overlap = [1.52880861114..1.55797102013]
# mask_overlap = [-1.62092561595e-14..0.0291624089883]
# t0 = [0.0..0.0291624089883]
# detect_roots(T0=[0.0..0.0291624089883], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0291624089883]
# M = [0.0145812044941..0.0145812044941]
# fI = [-0.336951969325..0.812945704776]
# Tfinal = [-0.0..0.0291624089883]
# root on boundary!
# merging intervals:
# [0.739994734463..1.52880861114]
# [1.52880861114..1.55797102013]
# ===
# reached detect roots t=[1.55797102013..1.55797102013] + [0.0..0.0320786498871]
# mask_overlap = [1.55797102013..1.59004967001]
# mask_overlap = [-1.66533453694e-14..0.0320786498871]
# t0 = [0.0..0.0320786498871]
# detect_roots(T0=[0.0..0.0320786498871], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0320786498871]
# M = [0.0160393249435..0.0160393249435]
# fI = [-0.332029826169..0.749038599775]
# Tfinal = [-0.0..0.0320786498871]
# root on boundary!
# merging intervals:
# [0.739994734463..1.55797102013]
# [1.55797102013..1.59004967001]
# ===
# reached detect roots t=[1.59004967001..1.59004967001] + [0.0..0.0352865148758]
# mask_overlap = [1.59004967001..1.62533618489]
# mask_overlap = [-1.70974345792e-14..0.0352865148758]
# t0 = [0.0..0.0352865148758]
# detect_roots(T0=[0.0..0.0352865148758], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0352865148758]
# M = [0.0176432574379..0.0176432574379]
# fI = [-0.325900093563..0.68349445954]
# Tfinal = [-0.0..0.0352865148758]
# root on boundary!
# merging intervals:
# [0.739994734463..1.59004967001]
# [1.59004967001..1.62533618489]
# ===
# reached detect roots t=[1.62533618489..1.62533618489] + [0.0..0.0388151663634]
# mask_overlap = [1.62533618489..1.66415135125]
# mask_overlap = [-1.75415237891e-14..0.0388151663634]
# t0 = [0.0..0.0388151663634]
# detect_roots(T0=[0.0..0.0388151663634], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0388151663634]
# M = [0.0194075831817..0.0194075831817]
# fI = [-0.318547468253..0.616745459762]
# Tfinal = [-0.0..0.0388151663634]
# root on boundary!
# merging intervals:
# [0.739994734463..1.62533618489]
# [1.62533618489..1.66415135125]
# ===
# reached detect roots t=[1.66415135125..1.66415135125] + [0.0..0.0426966829997]
# mask_overlap = [1.66415135125..1.70684803425]
# mask_overlap = [-1.79856129989e-14..0.0426966829997]
# t0 = [0.0..0.0426966829997]
# detect_roots(T0=[0.0..0.0426966829997], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0426966829997]
# M = [0.0213483414999..0.0213483414999]
# fI = [-0.310702005079..0.54999996842]
# Tfinal = [-0.0..0.0426966829997]
# root on boundary!
# merging intervals:
# [0.739994734463..1.66415135125]
# [1.66415135125..1.70684803425]
# ===
# reached detect roots t=[1.70684803425..1.70684803425] + [0.0..0.0469663512997]
# mask_overlap = [1.70684803425..1.75381438555]
# mask_overlap = [-1.84297022088e-14..0.0469663512997]
# t0 = [0.0..0.0469663512997]
# detect_roots(T0=[0.0..0.0469663512997], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0469663512997]
# M = [0.0234831756498..0.0234831756498]
# fI = [-0.3030248933..0.484376532681]
# Tfinal = [-0.0..0.0469663512997]
# root on boundary!
# merging intervals:
# [0.739994734463..1.70684803425]
# [1.70684803425..1.75381438555]
# ===
# reached detect roots t=[1.75381438555..1.75381438555] + [0.0..0.0516629864297]
# mask_overlap = [1.75381438555..1.80547737198]
# mask_overlap = [-1.88737914186e-14..0.0516629864297]
# t0 = [0.0..0.0516629864297]
# detect_roots(T0=[0.0..0.0516629864297], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0516629864297]
# M = [0.0258314932148..0.0258314932148]
# fI = [-0.294349904247..0.419209975654]
# Tfinal = [-0.0..0.0516629864297]
# root on boundary!
# merging intervals:
# [0.739994734463..1.75381438555]
# [1.75381438555..1.80547737198]
# ===
# reached detect roots t=[1.80547737198..1.80547737198] + [0.0..0.0568292850726]
# mask_overlap = [1.80547737198..1.86230665705]
# mask_overlap = [-1.93178806285e-14..0.0568292850726]
# t0 = [0.0..0.0568292850726]
# detect_roots(T0=[0.0..0.0568292850726], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0568292850726]
# M = [0.0284146425363..0.0284146425363]
# fI = [-0.285145334679..0.355442115252]
# Tfinal = [-0.0..0.0568292850726]
# root on boundary!
# merging intervals:
# [0.739994734463..1.80547737198]
# [1.80547737198..1.86230665705]
# ===
# reached detect roots t=[1.86230665705..1.86230665705] + [0.0..0.0625122135799]
# mask_overlap = [1.86230665705..1.92481887063]
# mask_overlap = [-1.97619698383e-14..0.0625122135799]
# t0 = [0.0..0.0625122135799]
# detect_roots(T0=[0.0..0.0625122135799], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0625122135799]
# M = [0.0312561067899..0.0312561067899]
# fI = [-0.275485037491..0.293565067485]
# Tfinal = [-0.0..0.0625122135799]
# root on boundary!
# merging intervals:
# [0.739994734463..1.86230665705]
# [1.86230665705..1.92481887063]
# ===
# reached detect roots t=[1.92481887063..1.92481887063] + [0.0..0.0343817174689]
# mask_overlap = [1.92481887063..1.9592005881]
# mask_overlap = [-2.02060590482e-14..0.034381717469]
# t0 = [0.0..0.0343817174689]
# detect_roots(T0=[0.0..0.0343817174689], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0343817174689]
# M = [0.0171908587345..0.0171908587345]
# fI = [-0.250848471316..0.231709071988]
# Tfinal = [-0.0..0.0343817174689]
# root on boundary!
# merging intervals:
# [0.739994734463..1.92481887063]
# [1.92481887063..1.9592005881]
# ===
# reached detect roots t=[1.9592005881..1.9592005881] + [0.0..0.0378198892158]
# mask_overlap = [1.9592005881..1.99702047732]
# mask_overlap = [-2.0650148258e-14..0.0378198892158]
# t0 = [0.0..0.0378198892158]
# detect_roots(T0=[0.0..0.0378198892158], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0378198892158]
# M = [0.0189099446079..0.0189099446079]
# fI = [-0.247358409579..0.203081012719]
# Tfinal = [-0.0..0.0378198892158]
# root on boundary!
# merging intervals:
# [0.739994734463..1.9592005881]
# [1.9592005881..1.99702047732]
# ===
# reached detect roots t=[1.99702047732..1.99702047732] + [0.0..0.0416018781374]
# mask_overlap = [1.99702047732..2.03862235546]
# mask_overlap = [-2.10942374679e-14..0.0416018781374]
# t0 = [0.0..0.0416018781374]
# detect_roots(T0=[0.0..0.0416018781374], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0416018781374]
# M = [0.0208009390687..0.0208009390687]
# fI = [-0.243665030114..0.174051928866]
# Tfinal = [-0.0..0.0416018781374]
# root on boundary!
# merging intervals:
# [0.739994734463..1.99702047732]
# [1.99702047732..2.03862235546]
# ===
# reached detect roots t=[2.03862235546..2.03862235546] + [0.0..0.0457620659512]
# mask_overlap = [2.03862235546..2.08438442141]
# mask_overlap = [-2.17603712827e-14..0.0457620659512]
# t0 = [0.0..0.0457620659512]
# detect_roots(T0=[0.0..0.0457620659512], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0457620659512]
# M = [0.0228810329756..0.0228810329756]
# fI = [-0.239821471069..0.144836340564]
# Tfinal = [-0.0..0.0457620659512]
# root on boundary!
# merging intervals:
# [0.739994734463..2.03862235546]
# [2.03862235546..2.08438442141]
# ===
# reached detect roots t=[2.08438442141..2.08438442141] + [0.0..0.0503382725463]
# mask_overlap = [2.08438442141..2.13472269395]
# mask_overlap = [-2.26485497024e-14..0.0503382725463]
# t0 = [0.0..0.0503382725463]
# detect_roots(T0=[0.0..0.0503382725463], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0503382725463]
# M = [0.0251691362731..0.0251691362731]
# fI = [-0.236075104948..0.115870552934]
# Tfinal = [-0.0..0.0503382725463]
# root on boundary!
# merging intervals:
# [0.739994734463..2.08438442141]
# [2.08438442141..2.13472269395]
# ===
# reached detect roots t=[2.13472269395..2.13472269395] + [0.0..0.0553720998009]
# mask_overlap = [2.13472269395..2.19009479375]
# mask_overlap = [-2.35367281221e-14..0.0553720998009]
# t0 = [0.0..0.0553720998009]
# detect_roots(T0=[0.0..0.0553720998009], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0553720998009]
# M = [0.0276860499004..0.0276860499004]
# fI = [-0.232689607942..0.0876114212961]
# Tfinal = [-0.0..0.0553720998009]
# root on boundary!
# merging intervals:
# [0.739994734463..2.13472269395]
# [2.13472269395..2.19009479375]
# ===
# reached detect roots t=[2.19009479375..2.19009479375] + [0.0..0.060909309781]
# mask_overlap = [2.19009479375..2.25100410354]
# mask_overlap = [-2.44249065418e-14..0.060909309781]
# t0 = [0.0..0.060909309781]
# detect_roots(T0=[0.0..0.060909309781], epsilon=1e-05, verbosity=3)
# T = [0.0..0.060909309781]
# M = [0.0304546548905..0.0304546548905]
# fI = [-0.229180914451..0.0597699482925]
# Tfinal = [-0.0..0.060909309781]
# root on boundary!
# merging intervals:
# [0.739994734463..2.19009479375]
# [2.19009479375..2.25100410354]
# ===
# reached detect roots t=[2.25100410354..2.25100410354] + [0.0..0.0670002407591]
# mask_overlap = [2.25100410354..2.31800434429]
# mask_overlap = [-2.53130849615e-14..0.0670002407591]
# t0 = [0.0..0.0670002407591]
# detect_roots(T0=[0.0..0.0670002407591], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0670002407591]
# M = [0.0335001203795..0.0335001203795]
# fI = [-0.225630922837..0.03262867532]
# Tfinal = [-0.0..0.0670002407591]
# root on boundary!
# merging intervals:
# [0.739994734463..2.25100410354]
# [2.25100410354..2.31800434429]
# ===
# reached detect roots t=[2.31800434429..2.31800434429] + [0.0..0.073700264835]
# mask_overlap = [2.31800434429..2.39170460913]
# mask_overlap = [-2.62012633812e-14..0.073700264835]
# t0 = [0.0..0.073700264835]
# detect_roots(T0=[0.0..0.073700264835], epsilon=1e-05, verbosity=3)
# T = [0.0..0.073700264835]
# M = [0.0368501324175..0.0368501324175]
# fI = [-0.222138435447..0.00645789434547]
# Tfinal = [-0.0..0.073700264835]
# root on boundary!
# merging intervals:
# [0.739994734463..2.31800434429]
# [2.31800434429..2.39170460913]
# ===
# reached detect roots t=[2.39170460913..2.39170460913] + [0.0..0.0810702913185]
# mask_overlap = [2.39170460913..2.47277490045]
# mask_overlap = [-2.70894418009e-14..0.0810702913185]
# t0 = [0.0..0.0810702913185]
# detect_roots(T0=[0.0..0.0810702913185], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0810702913185]
# M = [0.0405351456592..0.0405351456592]
# fI = [-0.218784917329..-0.0184980346138]
# failed! on:
# M=[0.0405351456592..0.0405351456592]
# extdiv(T=[-0.0405351456592..0.0405351456592], Tu=[0.0..0.0], split=False, T=[-0.0405351456592..0.0405351456592], fI=[-0.218784917329..-0.0184980346138], fP=[-0.324355127523..0.0840775063089])
# ===
# reached detect roots t=[2.47277490045..2.47277490045] + [0.0..0.0891773204503]
# mask_overlap = [2.47277490045..2.5619522209]
# mask_overlap = [-2.79776202206e-14..0.0891773204504]
# t0 = [0.0..0.0891773204503]
# detect_roots(T0=[0.0..0.0891773204503], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0891773204503]
# M = [0.0445886602252..0.0445886602252]
# fI = [-0.21576549601..-0.0418966826669]
# failed! on:
# M=[0.0445886602252..0.0445886602252]
# extdiv(T=[-0.0445886602252..0.0445886602252], Tu=[0.0..0.0], split=False, T=[-0.0445886602252..0.0445886602252], fI=[-0.21576549601..-0.0418966826669], fP=[-0.275639803932..0.0717032773394])
# ===
# reached detect roots t=[2.5619522209..2.5619522209] + [0.0..0.0980950524954]
# mask_overlap = [2.5619522209..2.66004727339]
# mask_overlap = [-2.88657986403e-14..0.0980950524954]
# t0 = [0.0..0.0980950524954]
# detect_roots(T0=[0.0..0.0980950524954], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0980950524954]
# M = [0.0490475262477..0.0490475262477]
# fI = [-0.213008343344..-0.0636850604362]
# failed! on:
# M=[0.0490475262477..0.0490475262477]
# extdiv(T=[-0.0490475262477..0.0490475262477], Tu=[0.0..0.0], split=False, T=[-0.0490475262477..0.0490475262477], fI=[-0.213008343344..-0.0636850604362], fP=[-0.231916818861..0.0606316792386])
# ===
# reached detect roots t=[2.66004727339..2.66004727339] + [0.0..0.0539522788725]
# mask_overlap = [2.66004727339..2.71399955227]
# mask_overlap = [-2.975397706e-14..0.0539522788725]
# t0 = [0.0..0.0539522788725]
# detect_roots(T0=[0.0..0.0539522788725], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0539522788725]
# M = [0.0269761394362..0.0269761394362]
# fI = [-0.205522372493..-0.0844502658144]
# failed! on:
# M=[0.0269761394362..0.0269761394362]
# extdiv(T=[-0.0269761394362..0.0269761394362], Tu=[0.0..0.0], split=False, T=[-0.0269761394362..0.0269761394362], fI=[-0.205522372493..-0.0844502658144], fP=[-0.187088652605..0.0310868640417])
# ===
# reached detect roots t=[2.71399955227..2.71399955227] + [0.0..0.0593475067597]
# mask_overlap = [2.71399955227..2.77334705903]
# mask_overlap = [-3.06421554797e-14..0.0593475067597]
# t0 = [0.0..0.0593475067597]
# detect_roots(T0=[0.0..0.0593475067597], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0593475067597]
# M = [0.0296737533798..0.0296737533798]
# fI = [-0.20486539175..-0.0939289113414]
# failed! on:
# M=[0.0296737533798..0.0296737533798]
# extdiv(T=[-0.0296737533798..0.0296737533798], Tu=[0.0..0.0], split=False, T=[-0.0296737533798..0.0296737533798], fI=[-0.20486539175..-0.0939289113414], fP=[-0.169349610887..0.0283350417641])
# ===
# reached detect roots t=[2.77334705903..2.77334705903] + [0.0..0.0652822574357]
# mask_overlap = [2.77334705903..2.83862931646]
# mask_overlap = [-3.15303338994e-14..0.0652822574357]
# t0 = [0.0..0.0652822574357]
# detect_roots(T0=[0.0..0.0652822574357], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0652822574357]
# M = [0.0326411287178..0.0326411287178]
# fI = [-0.204264651061..-0.103298335132]
# failed! on:
# M=[0.0326411287178..0.0326411287178]
# extdiv(T=[-0.0326411287178..0.0326411287178], Tu=[0.0..0.0], split=False, T=[-0.0326411287178..0.0326411287178], fI=[-0.204264651061..-0.103298335132], fP=[-0.15201833394..0.0255587663159])
# ===
# reached detect roots t=[2.83862931646..2.83862931646] + [0.0..0.0718104831792]
# mask_overlap = [2.83862931646..2.91043979964]
# mask_overlap = [-3.24185123191e-14..0.0718104831793]
# t0 = [0.0..0.0718104831792]
# detect_roots(T0=[0.0..0.0718104831792], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0718104831792]
# M = [0.0359052415896..0.0359052415896]
# fI = [-0.203704842908..-0.11250830847]
# failed! on:
# M=[0.0359052415896..0.0359052415896]
# extdiv(T=[-0.0359052415896..0.0359052415896], Tu=[0.0..0.0], split=False, T=[-0.0359052415896..0.0359052415896], fI=[-0.203704842908..-0.11250830847], fP=[-0.135277936999..0.0228285822642])
# ===
# reached detect roots t=[2.91043979964..2.91043979964] + [0.0..0.0789915314972]
# mask_overlap = [2.91043979964..2.98943133114]
# mask_overlap = [-3.33066907388e-14..0.0789915314972]
# t0 = [0.0..0.0789915314972]
# detect_roots(T0=[0.0..0.0789915314972], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0789915314972]
# M = [0.0394957657486..0.0394957657486]
# fI = [-0.203194894403..-0.121485755043]
# failed! on:
# M=[0.0394957657486..0.0394957657486]
# extdiv(T=[-0.0394957657486..0.0394957657486], Tu=[0.0..0.0], split=False, T=[-0.0394957657486..0.0394957657486], fI=[-0.203194894403..-0.121485755043], fP=[-0.119327774321..0.0202322272363])
# ===
# reached detect roots t=[2.98943133114..2.98943133114] + [0.0..0.0868906846469]
# mask_overlap = [2.98943133114..3.07632201578]
# mask_overlap = [-3.41948691585e-14..0.0868906846469]
# t0 = [0.0..0.0868906846469]
# detect_roots(T0=[0.0..0.0868906846469], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0868906846469]
# M = [0.0434453423234..0.0434453423234]
# fI = [-0.202722022215..-0.130157253156]
# failed! on:
# M=[0.0434453423234..0.0434453423234]
# extdiv(T=[-0.0434453423234..0.0434453423234], Tu=[0.0..0.0], split=False, T=[-0.0434453423234..0.0434453423234], fI=[-0.202722022215..-0.130157253156], fP=[-0.104226013193..0.0177292399867])
# ===
# reached detect roots t=[3.07632201578..3.07632201578] + [0.0..0.0955797531116]
# mask_overlap = [3.07632201578..3.1719017689]
# mask_overlap = [-3.50830475782e-14..0.0955797531116]
# t0 = [0.0..0.0955797531116]
# detect_roots(T0=[0.0..0.0955797531116], epsilon=1e-05, verbosity=3)
# T = [0.0..0.0955797531116]
# M = [0.0477898765558..0.0477898765558]
# fI = [-0.202290863363..-0.138452397039]
# failed! on:
# M=[0.0477898765558..0.0477898765558]
# extdiv(T=[-0.0477898765558..0.0477898765558], Tu=[0.0..0.0], split=False, T=[-0.0477898765558..0.0477898765558], fI=[-0.202290863363..-0.138452397039], fP=[-0.0900968763799..0.0153640341353])
# ===
# reached detect roots t=[3.1719017689..3.1719017689] + [0.0..0.105137728423]
# mask_overlap = [3.1719017689..3.27703949732]
# mask_overlap = [-3.59712259979e-14..0.105137728423]
# t0 = [0.0..0.105137728423]
# detect_roots(T0=[0.0..0.105137728423], epsilon=1e-05, verbosity=3)
# T = [0.0..0.105137728423]
# M = [0.0525688642114..0.0525688642114]
# fI = [-0.201935254468..-0.146295662443]
# failed! on:
# M=[0.0525688642114..0.0525688642114]
# extdiv(T=[-0.0525688642114..0.0525688642114], Tu=[0.0..0.0], split=False, T=[-0.0525688642114..0.0525688642114], fI=[-0.201935254468..-0.146295662443], fP=[-0.0770213164413..0.0131537071282])
# ===
# reached detect roots t=[3.27703949732..3.27703949732] + [0.0..0.115651501265]
# mask_overlap = [3.27703949732..3.39269099858]
# mask_overlap = [-3.68594044176e-14..0.115651501265]
# t0 = [0.0..0.115651501265]
# detect_roots(T0=[0.0..0.115651501265], epsilon=1e-05, verbosity=3)
# T = [0.0..0.115651501265]
# M = [0.0578257506325..0.0578257506325]
# fI = [-0.20163917408..-0.15363229071]
# failed! on:
# M=[0.0578257506325..0.0578257506325]
# extdiv(T=[-0.0578257506325..0.0578257506325], Tu=[0.0..0.0], split=False, T=[-0.0578257506325..0.0578257506325], fI=[-0.20163917408..-0.15363229071], fP=[-0.0650871385013..0.0111400033706])
# ===
# reached detect roots t=[3.39269099858..3.39269099858] + [0.0..0.127216651391]
# mask_overlap = [3.39269099858..3.51990764998]
# mask_overlap = [-3.77475828373e-14..0.127216651392]
# t0 = [0.0..0.127216651391]
# detect_roots(T0=[0.0..0.127216651391], epsilon=1e-05, verbosity=3)
# T = [0.0..0.127216651391]
# M = [0.0636083256957..0.0636083256957]
# fI = [-0.20139598264..-0.160416899505]
# failed! on:
# M=[0.0636083256957..0.0636083256957]
# extdiv(T=[-0.0636083256957..0.0636083256957], Tu=[0.0..0.0], split=False, T=[-0.0636083256957..0.0636083256957], fI=[-0.20139598264..-0.160416899505], fP=[-0.0543756911773..0.00937002704049])
# ===
# reached detect roots t=[3.51990764998..3.51990764998] + [0.0..0.139938316531]
# mask_overlap = [3.51990764998..3.65984596651]
# mask_overlap = [-3.8635761257e-14..0.139938316531]
# t0 = [0.0..0.139938316531]
# skipping given consistent value over domain
# ===
# reached detect roots t=[3.65984596651..3.65984596651] + [0.0..0.153932148184]
# mask_overlap = [3.65984596651..3.81377811469]
# mask_overlap = [-3.95239396767e-14..0.153932148184]
# t0 = [0.0..0.153932148184]
# skipping given consistent value over domain
# ===
# reached detect roots t=[3.81377811469..3.81377811469] + [0.0..0.084662681501]
# mask_overlap = [3.81377811469..3.89844079619]
# mask_overlap = [-4.04121180964e-14..0.0846626815011]
# t0 = [0.0..0.084662681501]
# skipping given consistent value over domain
# ===
# reached detect roots t=[3.89844079619..3.89844079619] + [0.0..0.0931289496511]
# mask_overlap = [3.89844079619..3.99156974584]
# mask_overlap = [-4.13002965161e-14..0.0931289496512]
# t0 = [0.0..0.0931289496511]
# skipping given consistent value over domain
# ===
# reached detect roots t=[3.99156974584..3.99156974584] + [0.0..0.102441844616]
# mask_overlap = [3.99156974584..4.09401159046]
# mask_overlap = [-4.21884749358e-14..0.102441844616]
# t0 = [0.0..0.102441844616]
# skipping given consistent value over domain
# ===
# reached detect roots t=[4.09401159046..4.09401159046] + [0.0..0.112686029078]
# mask_overlap = [4.09401159046..4.20669761954]
# mask_overlap = [-4.35207425653e-14..0.112686029078]
# t0 = [0.0..0.112686029078]
# skipping given consistent value over domain
# ===
# reached detect roots t=[4.20669761954..4.20669761954] + [0.0..0.123954631986]
# mask_overlap = [4.20669761954..4.33065225152]
# mask_overlap = [-4.52970994047e-14..0.123954631986]
# t0 = [0.0..0.123954631986]
# skipping given consistent value over domain
# ===
# reached detect roots t=[4.33065225152..4.33065225152] + [0.0..0.136350095184]
# mask_overlap = [4.33065225152..4.46700234671]
# mask_overlap = [-4.70734562441e-14..0.136350095184]
# t0 = [0.0..0.136350095184]
# skipping given consistent value over domain
# ===
# reached detect roots t=[4.46700234671..4.46700234671] + [0.0..0.149985104703]
# mask_overlap = [4.46700234671..4.61698745141]
# mask_overlap = [-4.88498130835e-14..0.149985104703]
# t0 = [0.0..0.149985104703]
# skipping given consistent value over domain
# ===
# reached detect roots t=[4.61698745141..4.61698745141] + [0.0..0.164983615173]
# mask_overlap = [4.61698745141..4.78197106658]
# mask_overlap = [-5.06261699229e-14..0.164983615173]
# t0 = [0.0..0.164983615173]
# skipping given consistent value over domain
# ===
# reached detect roots t=[4.78197106658..4.78197106658] + [0.0..0.18148197669]
# mask_overlap = [4.78197106658..4.96345304327]
# mask_overlap = [-5.24025267623e-14..0.18148197669]
# t0 = [0.0..0.18148197669]
# skipping given consistent value over domain (unpreconditioned)
# ===
# reached detect roots t=[4.96345304327..4.96345304327] + [0.0..0.0375469567271]
# mask_overlap = [4.96345304327..5.0]
# mask_overlap = [-5.3290705182e-14..0.0365469567282]
# t0 = [0.0..0.0365469567282]
# skipping given consistent value over domain (unpreconditioned)
# domain = [0.00000000000000000 .. 5.0000000000000000]
# roots = [[0.73999473446266517 .. 2.3917046091295045]]
# seg_domain = [0.00000000000000000 .. 5.0000000000000000]
# roots = [[0.73999473446266517 .. 2.3917046091295045]]
# Monitored signal 7.78463363647 sec
# Graphics object consisting of 2 graphics primitives

# %%
sig2 = Atomic(x - 1.15).signal_for_system(vf, v3, 5, order=5, step=(0.01, 0.5),
                                   precondition=1,
                                   estimation=1e-3,
                                   integrationScheme=2,
                                   cutoff_threshold=1e-5)
sig2.plot()
# Out:
# Computed 115 flowpipes in 1.32625818253 sec
# In prepare! flowpipes_compo.size() = 115
# Prepared for plotting in 0.000496864318848 sec
# domain = [0.00000000000000000 .. 5.0000000000000000]
# roots = [[0.00000000000000000 .. 0.96796135132987427],
#  [1.7974045409423886 .. 1.8054773719814759],
#  [1.8368406824341438 .. 1.9248188706339733],
#  [1.9427422934617277 .. 3.6598459665061820]]
# seg_domain = [0.00000000000000000 .. 5.0000000000000000]
# roots = [[0.00000000000000000 .. 0.96796135132987427],
#  [1.7974045409423886 .. 1.8054773719814759],
#  [1.8368406824341438 .. 1.9248188706339733],
#  [1.9427422934617277 .. 3.6598459665061820]]
# Monitored signal 2.11137294769 sec
# Graphics object consisting of 2 graphics primitives

# %%
sig2 = Atomic(x - 1.15).signal_for_system(vf, v3, 5, order=5, step=(0.01, 0.5),
                                   precondition=1,
                                   estimation=1e-3,
                                   integrationScheme=2,
                                   cutoff_threshold=1e-5,
                                   symbolic_composition=True,
                                   tentative_unpreconditioning=False,
                                   use_masks=True,
                                   verbosity=10)
sig2.plot()
# Out:
# Computed 115 flowpipes in 1.42777729034 sec
# In prepare! flowpipes_compo.size() = 115
# Prepared for plotting in 0.00078296661377 sec
# ===
# reached detect roots t=[0.0..0.0] + [0.0..0.03125]
# using mask!
# mask_overlap = [0.0..0.03125]
# mask_overlap = [-0.0..0.03125]
# t0 = [-0.0..0.03125]
# detect_roots(T0=[-0.0..0.03125], epsilon=1e-05, verbosity=10)
# T = [-0.0..0.03125]
# M = [0.015625..0.015625]
# fI = [-0.147743741509..0.0613162002737]
# Tfinal = [-0.0..0.03125]
# root on boundary!
# new root:
# [-0.0..0.03125]
# ===
# reached detect roots t=[0.03125..0.03125] + [0.0..0.0171875]
# using mask!
# mask_overlap = [0.03125..0.0484375]
# mask_overlap = [-3.46944695195e-18..0.0171875]
# t0 = [0.0..0.0171875]
# detect_roots(T0=[0.0..0.0171875], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0171875]
# M = [0.00859375..0.00859375]
# fI = [-0.144239307142..0.0789355872924]
# Tfinal = [-0.0..0.0171875]
# root on boundary!
# merging intervals:
# [-0.0..0.03125]
# [0.03125..0.0484375]
# ===
# reached detect roots t=[0.0484375..0.0484375] + [0.0..0.01890625]
# using mask!
# mask_overlap = [0.0484375..0.06734375]
# mask_overlap = [-1.38777878078e-17..0.01890625]
# t0 = [0.0..0.01890625]
# detect_roots(T0=[0.0..0.01890625], epsilon=1e-05, verbosity=10)
# T = [0.0..0.01890625]
# M = [0.009453125..0.009453125]
# fI = [-0.14167762036..0.0921588309592]
# Tfinal = [-0.0..0.01890625]
# root on boundary!
# merging intervals:
# [-0.0..0.0484375]
# [0.0484375..0.06734375]
# ===
# reached detect roots t=[0.06734375..0.06734375] + [0.0..0.020796875]
# using mask!
# mask_overlap = [0.06734375..0.088140625]
# mask_overlap = [-2.77555756156e-17..0.020796875]
# t0 = [0.0..0.020796875]
# detect_roots(T0=[0.0..0.020796875], epsilon=1e-05, verbosity=10)
# T = [0.0..0.020796875]
# M = [0.0103984375..0.0103984375]
# fI = [-0.13887430496..0.106741264325]
# Tfinal = [-0.0..0.020796875]
# root on boundary!
# merging intervals:
# [-0.0..0.06734375]
# [0.06734375..0.088140625]
# ===
# reached detect roots t=[0.088140625..0.088140625] + [0.0..0.0228765625]
# using mask!
# mask_overlap = [0.088140625..0.1110171875]
# mask_overlap = [-5.55111512313e-17..0.0228765625]
# t0 = [0.0..0.0228765625]
# detect_roots(T0=[0.0..0.0228765625], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0228765625]
# M = [0.01143828125..0.01143828125]
# fI = [-0.135819508858..0.122794224006]
# Tfinal = [-0.0..0.0228765625]
# root on boundary!
# merging intervals:
# [-0.0..0.088140625]
# [0.088140625..0.1110171875]
# ===
# reached detect roots t=[0.1110171875..0.1110171875] + [0.0..0.02516421875]
# using mask!
# mask_overlap = [0.1110171875..0.13618140625]
# mask_overlap = [-8.32667268469e-17..0.02516421875]
# t0 = [0.0..0.02516421875]
# detect_roots(T0=[0.0..0.02516421875], epsilon=1e-05, verbosity=10)
# T = [0.0..0.02516421875]
# M = [0.012582109375..0.012582109375]
# fI = [-0.132482365607..0.140426291054]
# Tfinal = [-0.0..0.02516421875]
# root on boundary!
# merging intervals:
# [-0.0..0.1110171875]
# [0.1110171875..0.13618140625]
# ===
# reached detect roots t=[0.13618140625..0.13618140625] + [0.0..0.027680640625]
# using mask!
# mask_overlap = [0.13618140625..0.163862046875]
# mask_overlap = [-1.38777878078e-16..0.027680640625]
# t0 = [0.0..0.027680640625]
# detect_roots(T0=[0.0..0.027680640625], epsilon=1e-05, verbosity=10)
# T = [0.0..0.027680640625]
# M = [0.0138403203125..0.0138403203125]
# fI = [-0.128824579111..0.159718391739]
# Tfinal = [-0.0..0.027680640625]
# root on boundary!
# merging intervals:
# [-0.0..0.13618140625]
# [0.13618140625..0.163862046875]
# ===
# reached detect roots t=[0.163862046875..0.163862046875] + [0.0..0.0152243523438]
# using mask!
# mask_overlap = [0.163862046875..0.179086399219]
# mask_overlap = [-1.94289029309e-16..0.0152243523438]
# t0 = [0.0..0.0152243523438]
# detect_roots(T0=[0.0..0.0152243523438], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0152243523438]
# M = [0.00761217617188..0.00761217617188]
# fI = [-0.125766234125..0.175148837752]
# Tfinal = [-0.0..0.0152243523438]
# root on boundary!
# merging intervals:
# [-0.0..0.163862046875]
# [0.163862046875..0.179086399219]
# ===
# reached detect roots t=[0.179086399219..0.179086399219] + [0.0..0.0167467875781]
# using mask!
# mask_overlap = [0.179086399219..0.195833186797]
# mask_overlap = [-2.49800180541e-16..0.0167467875781]
# t0 = [0.0..0.0167467875781]
# detect_roots(T0=[0.0..0.0167467875781], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0167467875781]
# M = [0.00837339378906..0.00837339378906]
# fI = [-0.123506445563..0.186556857208]
# Tfinal = [-0.0..0.0167467875781]
# root on boundary!
# merging intervals:
# [-0.0..0.179086399219]
# [0.179086399219..0.195833186797]
# ===
# reached detect roots t=[0.195833186797..0.195833186797] + [0.0..0.0184214663359]
# using mask!
# mask_overlap = [0.195833186797..0.214254653133]
# mask_overlap = [-3.05311331772e-16..0.0184214663359]
# t0 = [0.0..0.0184214663359]
# detect_roots(T0=[0.0..0.0184214663359], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0184214663359]
# M = [0.00921073316797..0.00921073316797]
# fI = [-0.120993324572..0.198954864794]
# Tfinal = [-0.0..0.0184214663359]
# root on boundary!
# merging intervals:
# [-0.0..0.195833186797]
# [0.195833186797..0.214254653133]
# ===
# reached detect roots t=[0.214254653133..0.214254653133] + [0.0..0.0202636129695]
# using mask!
# mask_overlap = [0.214254653133..0.234518266102]
# mask_overlap = [-3.33066907388e-16..0.0202636129695]
# t0 = [0.0..0.0202636129695]
# detect_roots(T0=[0.0..0.0202636129695], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0202636129695]
# M = [0.0101318064848..0.0101318064848]
# fI = [-0.118190494576..0.212381065344]
# Tfinal = [-0.0..0.0202636129695]
# root on boundary!
# merging intervals:
# [-0.0..0.214254653133]
# [0.214254653133..0.234518266102]
# ===
# reached detect roots t=[0.234518266102..0.234518266102] + [0.0..0.0222899742665]
# using mask!
# mask_overlap = [0.234518266102..0.256808240369]
# mask_overlap = [-3.88578058619e-16..0.0222899742665]
# t0 = [0.0..0.0222899742665]
# detect_roots(T0=[0.0..0.0222899742665], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0222899742665]
# M = [0.0111449871332..0.0111449871332]
# fI = [-0.115040462591..0.226842223301]
# Tfinal = [-0.0..0.0222899742665]
# root on boundary!
# merging intervals:
# [-0.0..0.234518266102]
# [0.234518266102..0.256808240369]
# ===
# reached detect roots t=[0.256808240369..0.256808240369] + [0.0..0.0245189716931]
# using mask!
# mask_overlap = [0.256808240369..0.281327212062]
# mask_overlap = [-4.99600361081e-16..0.0245189716931]
# t0 = [0.0..0.0245189716931]
# detect_roots(T0=[0.0..0.0245189716931], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0245189716931]
# M = [0.0122594858466..0.0122594858466]
# fI = [-0.111677382921..0.242525951543]
# Tfinal = [-0.0..0.0245189716931]
# root on boundary!
# merging intervals:
# [-0.0..0.256808240369]
# [0.256808240369..0.281327212062]
# ===
# reached detect roots t=[0.281327212062..0.281327212062] + [0.0..0.0134854344312]
# using mask!
# mask_overlap = [0.281327212062..0.294812646493]
# mask_overlap = [-6.10622663544e-16..0.0134854344312]
# t0 = [0.0..0.0134854344312]
# detect_roots(T0=[0.0..0.0134854344312], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0134854344312]
# M = [0.00674271721561..0.00674271721561]
# fI = [-0.108828471981..0.254858052098]
# Tfinal = [-0.0..0.0134854344312]
# root on boundary!
# merging intervals:
# [-0.0..0.281327212062]
# [0.281327212062..0.294812646493]
# ===
# reached detect roots t=[0.294812646493..0.294812646493] + [0.0..0.0148339778743]
# using mask!
# mask_overlap = [0.294812646493..0.309646624368]
# mask_overlap = [-6.66133814775e-16..0.0148339778743]
# t0 = [0.0..0.0148339778743]
# detect_roots(T0=[0.0..0.0148339778743], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0148339778743]
# M = [0.00741698893717..0.00741698893717]
# fI = [-0.106761746898..0.263913645477]
# Tfinal = [-0.0..0.0148339778743]
# root on boundary!
# merging intervals:
# [-0.0..0.294812646493]
# [0.294812646493..0.309646624368]
# ===
# reached detect roots t=[0.309646624368..0.309646624368] + [0.0..0.0163173756618]
# using mask!
# mask_overlap = [0.309646624368..0.325964000029]
# mask_overlap = [-7.77156117238e-16..0.0163173756618]
# t0 = [0.0..0.0163173756618]
# detect_roots(T0=[0.0..0.0163173756618], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0163173756618]
# M = [0.00815868783089..0.00815868783089]
# fI = [-0.104434260773..0.273626661957]
# Tfinal = [-0.0..0.0163173756618]
# root on boundary!
# merging intervals:
# [-0.0..0.309646624368]
# [0.309646624368..0.325964000029]
# ===
# reached detect roots t=[0.325964000029..0.325964000029] + [0.0..0.017949113228]
# using mask!
# mask_overlap = [0.325964000029..0.343913113257]
# mask_overlap = [-8.881784197e-16..0.017949113228]
# t0 = [0.0..0.017949113228]
# detect_roots(T0=[0.0..0.017949113228], epsilon=1e-05, verbosity=10)
# T = [0.0..0.017949113228]
# M = [0.00897455661398..0.00897455661398]
# fI = [-0.101823273572..0.284000624117]
# Tfinal = [-0.0..0.017949113228]
# root on boundary!
# merging intervals:
# [-0.0..0.325964000029]
# [0.325964000029..0.343913113257]
# ===
# reached detect roots t=[0.343913113257..0.343913113257] + [0.0..0.0197440245508]
# using mask!
# mask_overlap = [0.343913113257..0.363657137808]
# mask_overlap = [-9.99200722163e-16..0.0197440245508]
# t0 = [0.0..0.0197440245508]
# detect_roots(T0=[0.0..0.0197440245508], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0197440245508]
# M = [0.00987201227538..0.00987201227538]
# fI = [-0.098951681713..0.29508897145]
# Tfinal = [-0.0..0.0197440245508]
# root on boundary!
# merging intervals:
# [-0.0..0.343913113257]
# [0.343913113257..0.363657137808]
# ===
# reached detect roots t=[0.363657137808..0.363657137808] + [0.0..0.0217184270058]
# using mask!
# mask_overlap = [0.363657137808..0.385375564814]
# mask_overlap = [-1.11022302463e-15..0.0217184270058]
# t0 = [0.0..0.0217184270058]
# detect_roots(T0=[0.0..0.0217184270058], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0217184270058]
# M = [0.0108592135029..0.0108592135029]
# fI = [-0.0959190293876..0.306989217023]
# Tfinal = [-0.0..0.0217184270058]
# root on boundary!
# merging intervals:
# [-0.0..0.363657137808]
# [0.363657137808..0.385375564814]
# ===
# reached detect roots t=[0.385375564814..0.385375564814] + [0.0..0.0238902697064]
# using mask!
# mask_overlap = [0.385375564814..0.40926583452]
# mask_overlap = [-1.22124532709e-15..0.0238902697064]
# t0 = [0.0..0.0238902697064]
# detect_roots(T0=[0.0..0.0238902697064], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0238902697064]
# M = [0.0119451348532..0.0119451348532]
# fI = [-0.0924856266418..0.31945362119]
# Tfinal = [-0.0..0.0238902697064]
# root on boundary!
# merging intervals:
# [-0.0..0.385375564814]
# [0.385375564814..0.40926583452]
# ===
# reached detect roots t=[0.40926583452..0.40926583452] + [0.0..0.0131396483385]
# using mask!
# mask_overlap = [0.40926583452..0.422405482859]
# mask_overlap = [-1.33226762955e-15..0.0131396483385]
# t0 = [0.0..0.0131396483385]
# detect_roots(T0=[0.0..0.0131396483385], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0131396483385]
# M = [0.00656982416926..0.00656982416926]
# fI = [-0.0895002420264..0.328963948971]
# Tfinal = [-0.0..0.0131396483385]
# root on boundary!
# merging intervals:
# [-0.0..0.40926583452]
# [0.40926583452..0.422405482859]
# ===
# reached detect roots t=[0.422405482859..0.422405482859] + [0.0..0.0144536131724]
# using mask!
# mask_overlap = [0.422405482859..0.436859096031]
# mask_overlap = [-1.44328993201e-15..0.0144536131724]
# t0 = [0.0..0.0144536131724]
# detect_roots(T0=[0.0..0.0144536131724], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0144536131724]
# M = [0.00722680658619..0.00722680658619]
# fI = [-0.0873062928595..0.335808362685]
# Tfinal = [-0.0..0.0144536131724]
# root on boundary!
# merging intervals:
# [-0.0..0.422405482859]
# [0.422405482859..0.436859096031]
# ===
# reached detect roots t=[0.436859096031..0.436859096031] + [0.0..0.0158989744896]
# using mask!
# mask_overlap = [0.436859096031..0.452758070521]
# mask_overlap = [-1.55431223448e-15..0.0158989744896]
# t0 = [0.0..0.0158989744896]
# detect_roots(T0=[0.0..0.0158989744896], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0158989744896]
# M = [0.00794948724481..0.00794948724481]
# fI = [-0.0849163727023..0.343083603552]
# Tfinal = [-0.0..0.0158989744896]
# root on boundary!
# merging intervals:
# [-0.0..0.436859096031]
# [0.436859096031..0.452758070521]
# ===
# reached detect roots t=[0.452758070521..0.452758070521] + [0.0..0.0174888719386]
# using mask!
# mask_overlap = [0.452758070521..0.470246942459]
# mask_overlap = [-1.66533453694e-15..0.0174888719386]
# t0 = [0.0..0.0174888719386]
# detect_roots(T0=[0.0..0.0174888719386], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0174888719386]
# M = [0.00874443596929..0.00874443596929]
# fI = [-0.0822841664517..0.350760200687]
# Tfinal = [-0.0..0.0174888719386]
# root on boundary!
# merging intervals:
# [-0.0..0.452758070521]
# [0.452758070521..0.470246942459]
# ===
# reached detect roots t=[0.470246942459..0.470246942459] + [0.0..0.0192377591324]
# using mask!
# mask_overlap = [0.470246942459..0.489484701592]
# mask_overlap = [-1.7763568394e-15..0.0192377591324]
# t0 = [0.0..0.0192377591324]
# detect_roots(T0=[0.0..0.0192377591324], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0192377591324]
# M = [0.00961887956622..0.00961887956622]
# fI = [-0.0793004513599..0.358714772329]
# Tfinal = [-0.0..0.0192377591324]
# root on boundary!
# merging intervals:
# [-0.0..0.470246942459]
# [0.470246942459..0.489484701592]
# ===
# reached detect roots t=[0.489484701592..0.489484701592] + [0.0..0.0211615350457]
# using mask!
# mask_overlap = [0.489484701592..0.510646236637]
# mask_overlap = [-1.88737914186e-15..0.0211615350457]
# t0 = [0.0..0.0211615350457]
# detect_roots(T0=[0.0..0.0211615350457], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0211615350457]
# M = [0.0105807675228..0.0105807675228]
# fI = [-0.0759783894599..0.366923138227]
# Tfinal = [-0.0..0.0211615350457]
# root on boundary!
# merging intervals:
# [-0.0..0.489484701592]
# [0.489484701592..0.510646236637]
# ===
# reached detect roots t=[0.510646236637..0.510646236637] + [0.0..0.0116388442751]
# using mask!
# mask_overlap = [0.510646236637..0.522285080913]
# mask_overlap = [-2.10942374679e-15..0.0116388442751]
# t0 = [0.0..0.0116388442751]
# detect_roots(T0=[0.0..0.0116388442751], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0116388442751]
# M = [0.00581942213756..0.00581942213756]
# fI = [-0.0726857944278..0.372596406637]
# Tfinal = [-0.0..0.0116388442751]
# root on boundary!
# merging intervals:
# [-0.0..0.510646236637]
# [0.510646236637..0.522285080913]
# ===
# reached detect roots t=[0.522285080913..0.522285080913] + [0.0..0.0128027287026]
# using mask!
# mask_overlap = [0.522285080913..0.535087809615]
# mask_overlap = [-2.33146835171e-15..0.0128027287026]
# t0 = [0.0..0.0128027287026]
# detect_roots(T0=[0.0..0.0128027287026], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0128027287026]
# M = [0.00640136435132..0.00640136435132]
# fI = [-0.0705168113484..0.376874388138]
# Tfinal = [-0.0..0.0128027287026]
# root on boundary!
# merging intervals:
# [-0.0..0.522285080913]
# [0.522285080913..0.535087809615]
# ===
# reached detect roots t=[0.535087809615..0.535087809615] + [0.0..0.0140830015729]
# using mask!
# mask_overlap = [0.535087809615..0.549170811188]
# mask_overlap = [-2.55351295664e-15..0.0140830015729]
# t0 = [0.0..0.0140830015729]
# detect_roots(T0=[0.0..0.0140830015729], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0140830015729]
# M = [0.00704150078645..0.00704150078645]
# fI = [-0.0680931858216..0.381309751385]
# Tfinal = [-0.0..0.0140830015729]
# root on boundary!
# merging intervals:
# [-0.0..0.535087809615]
# [0.535087809615..0.549170811188]
# ===
# reached detect roots t=[0.549170811188..0.549170811188] + [0.0..0.0154913017302]
# using mask!
# mask_overlap = [0.549170811188..0.564662112918]
# mask_overlap = [-2.77555756156e-15..0.0154913017302]
# t0 = [0.0..0.0154913017302]
# detect_roots(T0=[0.0..0.0154913017302], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0154913017302]
# M = [0.0077456508651..0.0077456508651]
# fI = [-0.0653775018706..0.385861703538]
# Tfinal = [-0.0..0.0154913017302]
# root on boundary!
# merging intervals:
# [-0.0..0.549170811188]
# [0.549170811188..0.564662112918]
# ===
# reached detect roots t=[0.564662112918..0.564662112918] + [0.0..0.0170404319032]
# using mask!
# mask_overlap = [0.564662112918..0.581702544822]
# mask_overlap = [-2.88657986403e-15..0.0170404319032]
# t0 = [0.0..0.0170404319032]
# detect_roots(T0=[0.0..0.0170404319032], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0170404319032]
# M = [0.0085202159516..0.0085202159516]
# fI = [-0.062340662022..0.390468388425]
# Tfinal = [-0.0..0.0170404319032]
# root on boundary!
# merging intervals:
# [-0.0..0.564662112918]
# [0.564662112918..0.581702544822]
# ===
# reached detect roots t=[0.581702544822..0.581702544822] + [0.0..0.0187444750935]
# using mask!
# mask_overlap = [0.581702544822..0.600447019915]
# mask_overlap = [-3.10862446895e-15..0.0187444750935]
# t0 = [0.0..0.0187444750935]
# detect_roots(T0=[0.0..0.0187444750935], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0187444750935]
# M = [0.00937223754677..0.00937223754677]
# fI = [-0.0589411252597..0.395050064926]
# Tfinal = [-0.0..0.0187444750935]
# root on boundary!
# merging intervals:
# [-0.0..0.581702544822]
# [0.581702544822..0.600447019915]
# ===
# reached detect roots t=[0.600447019915..0.600447019915] + [0.0..0.0206189226029]
# using mask!
# mask_overlap = [0.600447019915..0.621065942518]
# mask_overlap = [-3.33066907388e-15..0.0206189226029]
# t0 = [0.0..0.0206189226029]
# detect_roots(T0=[0.0..0.0206189226029], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0206189226029]
# M = [0.0103094613014..0.0103094613014]
# fI = [-0.0550905126382..0.399489089606]
# Tfinal = [-0.0..0.0206189226029]
# root on boundary!
# merging intervals:
# [-0.0..0.600447019915]
# [0.600447019915..0.621065942518]
# ===
# reached detect roots t=[0.621065942518..0.621065942518] + [0.0..0.0226808148632]
# using mask!
# mask_overlap = [0.621065942518..0.643746757381]
# mask_overlap = [-3.5527136788e-15..0.0226808148632]
# t0 = [0.0..0.0226808148632]
# detect_roots(T0=[0.0..0.0226808148632], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0226808148632]
# M = [0.0113404074316..0.0113404074316]
# fI = [-0.0507232032999..0.40364311032]
# Tfinal = [-0.0..0.0226808148632]
# root on boundary!
# merging intervals:
# [-0.0..0.621065942518]
# [0.621065942518..0.643746757381]
# ===
# reached detect roots t=[0.643746757381..0.643746757381] + [0.0..0.0124744481747]
# using mask!
# mask_overlap = [0.643746757381..0.656221205556]
# mask_overlap = [-3.77475828373e-15..0.0124744481747]
# t0 = [0.0..0.0124744481747]
# detect_roots(T0=[0.0..0.0124744481747], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0124744481747]
# M = [0.00623722408737..0.00623722408737]
# fI = [-0.0456445806002..0.405018062692]
# Tfinal = [-0.0..0.0124744481747]
# root on boundary!
# merging intervals:
# [-0.0..0.643746757381]
# [0.643746757381..0.656221205556]
# ===
# reached detect roots t=[0.656221205556..0.656221205556] + [0.0..0.0137218929922]
# using mask!
# mask_overlap = [0.656221205556..0.669943098548]
# mask_overlap = [-3.99680288865e-15..0.0137218929922]
# t0 = [0.0..0.0137218929922]
# detect_roots(T0=[0.0..0.0137218929922], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0137218929922]
# M = [0.00686094649611..0.00686094649611]
# fI = [-0.0430523435824..0.406946699732]
# Tfinal = [-0.0..0.0137218929922]
# root on boundary!
# merging intervals:
# [-0.0..0.656221205556]
# [0.656221205556..0.669943098548]
# ===
# reached detect roots t=[0.669943098548..0.669943098548] + [0.0..0.0150940822914]
# using mask!
# mask_overlap = [0.669943098548..0.68503718084]
# mask_overlap = [-4.21884749358e-15..0.0150940822914]
# t0 = [0.0..0.0150940822914]
# detect_roots(T0=[0.0..0.0150940822914], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0150940822914]
# M = [0.00754704114572..0.00754704114572]
# fI = [-0.0401729185262..0.408778263912]
# Tfinal = [-0.0..0.0150940822914]
# root on boundary!
# merging intervals:
# [-0.0..0.669943098548]
# [0.669943098548..0.68503718084]
# ===
# reached detect roots t=[0.68503718084..0.68503718084] + [0.0..0.0166034905206]
# using mask!
# mask_overlap = [0.68503718084..0.70164067136]
# mask_overlap = [-4.4408920985e-15..0.0166034905206]
# t0 = [0.0..0.0166034905206]
# detect_roots(T0=[0.0..0.0166034905206], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0166034905206]
# M = [0.00830174526029..0.00830174526029]
# fI = [-0.036984878372..0.410457946531]
# Tfinal = [-0.0..0.0166034905206]
# root on boundary!
# merging intervals:
# [-0.0..0.68503718084]
# [0.68503718084..0.70164067136]
# ===
# reached detect roots t=[0.70164067136..0.70164067136] + [0.0..0.0182638395726]
# using mask!
# mask_overlap = [0.70164067136..0.719904510933]
# mask_overlap = [-4.66293670343e-15..0.0182638395726]
# t0 = [0.0..0.0182638395726]
# detect_roots(T0=[0.0..0.0182638395726], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0182638395726]
# M = [0.00913191978632..0.00913191978632]
# fI = [-0.0335861980084..0.412024274159]
# Tfinal = [-0.0..0.0182638395726]
# root on boundary!
# merging intervals:
# [-0.0..0.70164067136]
# [0.70164067136..0.719904510933]
# ===
# reached detect roots t=[0.719904510933..0.719904510933] + [0.0..0.0200902235299]
# using mask!
# mask_overlap = [0.719904510933..0.739994734463]
# mask_overlap = [-4.88498130835e-15..0.0200902235299]
# t0 = [0.0..0.0200902235299]
# detect_roots(T0=[0.0..0.0200902235299], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0200902235299]
# M = [0.010045111765..0.010045111765]
# fI = [-0.0300259807467..0.413474609568]
# Tfinal = [-0.0..0.0200902235299]
# root on boundary!
# merging intervals:
# [-0.0..0.719904510933]
# [0.719904510933..0.739994734463]
# ===
# reached detect roots t=[0.739994734463..0.739994734463] + [0.0..0.0220992458829]
# using mask!
# mask_overlap = [0.739994734463..0.762093980346]
# mask_overlap = [-5.10702591328e-15..0.0220992458829]
# t0 = [0.0..0.0220992458829]
# detect_roots(T0=[0.0..0.0220992458829], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0220992458829]
# M = [0.0110496229414..0.0110496229414]
# fI = [-0.0260935079332..0.414511085592]
# Tfinal = [-0.0..0.0220992458829]
# root on boundary!
# merging intervals:
# [-0.0..0.739994734463]
# [0.739994734463..0.762093980346]
# ===
# reached detect roots t=[0.762093980346..0.762093980346] + [0.0..0.0243091704712]
# using mask!
# mask_overlap = [0.762093980346..0.786403150817]
# mask_overlap = [-5.3290705182e-15..0.0243091704712]
# t0 = [0.0..0.0243091704712]
# detect_roots(T0=[0.0..0.0243091704712], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0243091704712]
# M = [0.0121545852356..0.0121545852356]
# fI = [-0.0217362738611..0.414976680161]
# Tfinal = [-0.0..0.0243091704712]
# root on boundary!
# merging intervals:
# [-0.0..0.762093980346]
# [0.762093980346..0.786403150817]
# ===
# reached detect roots t=[0.786403150817..0.786403150817] + [0.0..0.0133700437592]
# using mask!
# mask_overlap = [0.786403150817..0.799773194576]
# mask_overlap = [-5.44009282066e-15..0.0133700437592]
# t0 = [0.0..0.0133700437592]
# detect_roots(T0=[0.0..0.0133700437592], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0133700437592]
# M = [0.00668502187958..0.00668502187958]
# fI = [-0.0158787269876..0.412560165407]
# Tfinal = [-0.0..0.0133700437592]
# root on boundary!
# merging intervals:
# [-0.0..0.786403150817]
# [0.786403150817..0.799773194576]
# ===
# reached detect roots t=[0.799773194576..0.799773194576] + [0.0..0.0147070481351]
# using mask!
# mask_overlap = [0.799773194576..0.814480242711]
# mask_overlap = [-5.66213742559e-15..0.0147070481351]
# t0 = [0.0..0.0147070481351]
# detect_roots(T0=[0.0..0.0147070481351], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0147070481351]
# M = [0.00735352406753..0.00735352406753]
# fI = [-0.0131861127808..0.412153241567]
# Tfinal = [-0.0..0.0147070481351]
# root on boundary!
# merging intervals:
# [-0.0..0.799773194576]
# [0.799773194576..0.814480242711]
# ===
# reached detect roots t=[0.814480242711..0.814480242711] + [0.0..0.0161777529486]
# using mask!
# mask_overlap = [0.814480242711..0.83065799566]
# mask_overlap = [-5.88418203051e-15..0.0161777529486]
# t0 = [0.0..0.0161777529486]
# detect_roots(T0=[0.0..0.0161777529486], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0161777529486]
# M = [0.00808887647429..0.00808887647429]
# fI = [-0.0102298576815..0.411443063066]
# Tfinal = [-0.0..0.0161777529486]
# root on boundary!
# merging intervals:
# [-0.0..0.814480242711]
# [0.814480242711..0.83065799566]
# ===
# reached detect roots t=[0.83065799566..0.83065799566] + [0.0..0.0177955282434]
# using mask!
# mask_overlap = [0.83065799566..0.848453523903]
# mask_overlap = [-6.10622663544e-15..0.0177955282434]
# t0 = [0.0..0.0177955282434]
# detect_roots(T0=[0.0..0.0177955282434], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0177955282434]
# M = [0.00889776412172..0.00889776412172]
# fI = [-0.00698726010394..0.410355511432]
# Tfinal = [-0.0..0.0177955282434]
# root on boundary!
# merging intervals:
# [-0.0..0.83065799566]
# [0.83065799566..0.848453523903]
# ===
# reached detect roots t=[0.848453523903..0.848453523903] + [0.0..0.0195750810678]
# using mask!
# mask_overlap = [0.848453523903..0.868028604971]
# mask_overlap = [-6.32827124036e-15..0.0195750810678]
# t0 = [0.0..0.0195750810678]
# detect_roots(T0=[0.0..0.0195750810678], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0195750810678]
# M = [0.00978754053389..0.00978754053389]
# fI = [-0.00345740565564..0.408823654884]
# Tfinal = [-0.0..0.0195750810678]
# root on boundary!
# merging intervals:
# [-0.0..0.848453523903]
# [0.848453523903..0.868028604971]
# ===
# reached detect roots t=[0.868028604971..0.868028604971] + [0.0..0.0215325891746]
# using mask!
# mask_overlap = [0.868028604971..0.889561194145]
# mask_overlap = [-6.55031584529e-15..0.0215325891746]
# t0 = [0.0..0.0215325891746]
# detect_roots(T0=[0.0..0.0215325891746], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0215325891746]
# M = [0.0107662945873..0.0107662945873]
# fI = [0.000370418810894..0.406761806117]
# Tfinal = [-0.0..0.00934642987349]
# splitting! [0.0..0.0215325891746] -> [-0.0..0.00934642987349] + [0.0126426268082..0.0215325891746]
# detect_roots(T0=[-0.0..0.00934642987349], epsilon=1e-05, verbosity=10)
# T = [-0.0..0.00934642987349]
# M = [0.00467321493674..0.00467321493674]
# fI = [0.0014860889086..0.405174253963]
# failed! on:
# M=[0.00467321493674..0.00467321493674]
# extdiv(T=[-0.00467321493674..0.00467321493674], Tu=[0.0..0.0], split=False, T=[-0.00467321493674..0.00467321493674], fI=[0.0014860889086..0.405174253963], fP=[-0.184773551922..0.260883172387])
# detect_roots(T0=[0.0126426268082..0.0215325891746], epsilon=1e-05, verbosity=10)
# T = [0.0126426268082..0.0215325891746]
# M = [0.0170876079914..0.0170876079914]
# fI = [-0.000827487692274..0.408408010169]
# Tfinal = [0.0126426268082..0.0215325891746]
# root on boundary!
# new root:
# [0.880671231779..0.889561194145]
# ===
# reached detect roots t=[0.889561194145..0.889561194145] + [0.0..0.023685848092]
# using mask!
# mask_overlap = [0.889561194145..0.913247042237]
# mask_overlap = [-6.77236045021e-15..0.023685848092]
# t0 = [0.0..0.023685848092]
# detect_roots(T0=[0.0..0.023685848092], epsilon=1e-05, verbosity=10)
# T = [0.0..0.023685848092]
# M = [0.011842924046..0.011842924046]
# fI = [0.0044781131636..0.404084949648]
# failed! on:
# M=[0.011842924046..0.011842924046]
# extdiv(T=[-0.011842924046..0.011842924046], Tu=[0.0..0.0], split=False, T=[-0.011842924046..0.011842924046], fI=[0.0044781131636..0.404084949648], fP=[-0.214718807327..0.254413780625])
# ===
# reached detect roots t=[0.913247042237..0.913247042237] + [0.0..0.0260544329012]
# using mask!
# mask_overlap = [0.913247042237..0.939301475139]
# mask_overlap = [-6.99440505514e-15..0.0260544329012]
# t0 = [0.0..0.0260544329012]
# detect_roots(T0=[0.0..0.0260544329012], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0260544329012]
# M = [0.0130272164506..0.0130272164506]
# fI = [0.0089421546311..0.400594265379]
# failed! on:
# M=[0.0130272164506..0.0130272164506]
# extdiv(T=[-0.0130272164506..0.0130272164506], Tu=[0.0..0.0], split=False, T=[-0.0130272164506..0.0130272164506], fI=[0.0089421546311..0.400594265379], fP=[-0.231524259101..0.246314616169])
# ===
# reached detect roots t=[0.939301475139..0.939301475139] + [0.0..0.0286598761913]
# using mask!
# mask_overlap = [0.939301475139..0.96796135133]
# mask_overlap = [-7.21644966006e-15..0.0286598761913]
# t0 = [0.0..0.0286598761913]
# detect_roots(T0=[0.0..0.0286598761913], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0286598761913]
# M = [0.0143299380957..0.0143299380957]
# fI = [0.0137543910796..0.396162774862]
# failed! on:
# M=[0.0143299380957..0.0143299380957]
# extdiv(T=[-0.0143299380957..0.0143299380957], Tu=[0.0..0.0], split=False, T=[-0.0143299380957..0.0143299380957], fI=[0.0137543910796..0.396162774862], fP=[-0.247982170555..0.236335139049])
# ===
# reached detect roots t=[0.96796135133..0.96796135133] + [0.0..0.0157629319052]
# using mask!
# mask_overlap = [0.96796135133..0.983724283235]
# mask_overlap = [-7.43849426499e-15..0.0157629319052]
# t0 = [0.0..0.0157629319052]
# skipping given consistent value over domain
# ===
# reached detect roots t=[0.983724283235..0.983724283235] + [0.0..0.0173392250958]
# using mask!
# mask_overlap = [0.983724283235..1.00106350833]
# mask_overlap = [-7.66053886991e-15..0.0173392250958]
# t0 = [0.0..0.0173392250958]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.00106350833..1.00106350833] + [0.0..0.0190731476053]
# using mask!
# mask_overlap = [1.00106350833..1.02013665594]
# mask_overlap = [-7.9936057773e-15..0.0190731476053]
# t0 = [0.0..0.0190731476053]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.02013665594..1.02013665594] + [0.0..0.0209804623659]
# using mask!
# mask_overlap = [1.02013665594..1.0411171183]
# mask_overlap = [-8.43769498715e-15..0.0209804623659]
# t0 = [0.0..0.0209804623659]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.0411171183..1.0411171183] + [0.0..0.0230785086025]
# using mask!
# mask_overlap = [1.0411171183..1.0641956269]
# mask_overlap = [-8.881784197e-15..0.0230785086025]
# t0 = [0.0..0.0230785086025]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.0641956269..1.0641956269] + [0.0..0.0253863594627]
# using mask!
# mask_overlap = [1.0641956269..1.08958198637]
# mask_overlap = [-9.32587340685e-15..0.0253863594627]
# t0 = [0.0..0.0253863594627]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.08958198637..1.08958198637] + [0.0..0.027924995409]
# using mask!
# mask_overlap = [1.08958198637..1.11750698178]
# mask_overlap = [-9.7699626167e-15..0.027924995409]
# t0 = [0.0..0.027924995409]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.11750698178..1.11750698178] + [0.0..0.0307174949499]
# using mask!
# mask_overlap = [1.11750698178..1.14822447673]
# mask_overlap = [-1.02140518266e-14..0.0307174949499]
# t0 = [0.0..0.0307174949499]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.14822447673..1.14822447673] + [0.0..0.0337892444448]
# using mask!
# mask_overlap = [1.14822447673..1.18201372117]
# mask_overlap = [-1.06581410364e-14..0.0337892444449]
# t0 = [0.0..0.0337892444448]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.18201372117..1.18201372117] + [0.0..0.0185840844447]
# using mask!
# mask_overlap = [1.18201372117..1.20059780562]
# mask_overlap = [-1.11022302463e-14..0.0185840844447]
# t0 = [0.0..0.0185840844447]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.20059780562..1.20059780562] + [0.0..0.0204424928891]
# using mask!
# mask_overlap = [1.20059780562..1.2210402985]
# mask_overlap = [-1.15463194561e-14..0.0204424928891]
# t0 = [0.0..0.0204424928891]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.2210402985..1.2210402985] + [0.0..0.022486742178]
# using mask!
# mask_overlap = [1.2210402985..1.24352704068]
# mask_overlap = [-1.1990408666e-14..0.0224867421781]
# t0 = [0.0..0.022486742178]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.24352704068..1.24352704068] + [0.0..0.0247354163959]
# using mask!
# mask_overlap = [1.24352704068..1.26826245708]
# mask_overlap = [-1.24344978758e-14..0.0247354163959]
# t0 = [0.0..0.0247354163959]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.26826245708..1.26826245708] + [0.0..0.0272089580354]
# using mask!
# mask_overlap = [1.26826245708..1.29547141511]
# mask_overlap = [-1.26565424807e-14..0.0272089580354]
# t0 = [0.0..0.0272089580354]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.29547141511..1.29547141511] + [0.0..0.029929853839]
# using mask!
# mask_overlap = [1.29547141511..1.32540126895]
# mask_overlap = [-1.31006316906e-14..0.029929853839]
# t0 = [0.0..0.029929853839]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.32540126895..1.32540126895] + [0.0..0.0329228392229]
# using mask!
# mask_overlap = [1.32540126895..1.35832410818]
# mask_overlap = [-1.35447209004e-14..0.0329228392229]
# t0 = [0.0..0.0329228392229]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.35832410818..1.35832410818] + [0.0..0.0362151231452]
# using mask!
# mask_overlap = [1.35832410818..1.39453923132]
# mask_overlap = [-1.39888101103e-14..0.0362151231452]
# t0 = [0.0..0.0362151231452]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.39453923132..1.39453923132] + [0.0..0.0398366354597]
# using mask!
# mask_overlap = [1.39453923132..1.43437586678]
# mask_overlap = [-1.44328993201e-14..0.0398366354597]
# t0 = [0.0..0.0398366354597]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.43437586678..1.43437586678] + [0.0..0.0438202990057]
# using mask!
# mask_overlap = [1.43437586678..1.47819616579]
# mask_overlap = [-1.487698853e-14..0.0438202990057]
# t0 = [0.0..0.0438202990057]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.47819616579..1.47819616579] + [0.0..0.0241011644531]
# using mask!
# mask_overlap = [1.47819616579..1.50229733024]
# mask_overlap = [-1.53210777398e-14..0.0241011644531]
# t0 = [0.0..0.0241011644531]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.50229733024..1.50229733024] + [0.0..0.0265112808984]
# using mask!
# mask_overlap = [1.50229733024..1.52880861114]
# mask_overlap = [-1.57651669497e-14..0.0265112808984]
# t0 = [0.0..0.0265112808984]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.52880861114..1.52880861114] + [0.0..0.0291624089883]
# using mask!
# mask_overlap = [1.52880861114..1.55797102013]
# mask_overlap = [-1.62092561595e-14..0.0291624089883]
# t0 = [0.0..0.0291624089883]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.55797102013..1.55797102013] + [0.0..0.0320786498871]
# using mask!
# mask_overlap = [1.55797102013..1.59004967001]
# mask_overlap = [-1.66533453694e-14..0.0320786498871]
# t0 = [0.0..0.0320786498871]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.59004967001..1.59004967001] + [0.0..0.0352865148758]
# using mask!
# mask_overlap = [1.59004967001..1.62533618489]
# mask_overlap = [-1.70974345792e-14..0.0352865148758]
# t0 = [0.0..0.0352865148758]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.62533618489..1.62533618489] + [0.0..0.0388151663634]
# using mask!
# mask_overlap = [1.62533618489..1.66415135125]
# mask_overlap = [-1.75415237891e-14..0.0388151663634]
# t0 = [0.0..0.0388151663634]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.66415135125..1.66415135125] + [0.0..0.0426966829997]
# using mask!
# mask_overlap = [1.66415135125..1.70684803425]
# mask_overlap = [-1.79856129989e-14..0.0426966829997]
# t0 = [0.0..0.0426966829997]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.70684803425..1.70684803425] + [0.0..0.0469663512997]
# using mask!
# mask_overlap = [1.70684803425..1.75381438555]
# mask_overlap = [-1.84297022088e-14..0.0469663512997]
# t0 = [0.0..0.0469663512997]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.75381438555..1.75381438555] + [0.0..0.0516629864297]
# using mask!
# mask_overlap = [1.75381438555..1.80547737198]
# mask_overlap = [-1.88737914186e-14..0.0516629864297]
# t0 = [0.0..0.0516629864297]
# detect_roots(T0=[0.0..0.0516629864297], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0516629864297]
# M = [0.0258314932148..0.0258314932148]
# fI = [0.0470561097116..0.197384439239]
# failed! on:
# M=[0.0258314932148..0.0258314932148]
# extdiv(T=[-0.0258314932148..0.0258314932148], Tu=[-0.0258314932148..0.0258314932148], split=False, T=[-0.0258314932148..0.0258314932148], fI=[0.0470561097116..0.197384439239], fP=[-0.255894824826..-0.0161943243669])
# ===
# reached detect roots t=[1.80547737198..1.80547737198] + [0.0..0.0568292850726]
# using mask!
# mask_overlap = [1.80547737198..1.86230665705]
# mask_overlap = [-1.93178806285e-14..0.0568292850726]
# t0 = [0.0..0.0568292850726]
# detect_roots(T0=[0.0..0.0568292850726], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0568292850726]
# M = [0.0284146425363..0.0284146425363]
# fI = [0.0448080195102..0.1848753656]
# failed! on:
# M=[0.0284146425363..0.0284146425363]
# extdiv(T=[-0.0284146425363..0.0284146425363], Tu=[-0.0284146425363..0.0284146425363], split=False, T=[-0.0284146425363..0.0284146425363], fI=[0.0448080195102..0.1848753656], fP=[-0.247461332162..-0.0224264709715])
# ===
# reached detect roots t=[1.86230665705..1.86230665705] + [0.0..0.0625122135799]
# using mask!
# mask_overlap = [1.86230665705..1.92481887063]
# mask_overlap = [-1.97619698383e-14..0.0625122135799]
# t0 = [0.0..0.0625122135799]
# detect_roots(T0=[0.0..0.0625122135799], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0625122135799]
# M = [0.0312561067899..0.0312561067899]
# fI = [0.0418442936539..0.171746363415]
# failed! on:
# M=[0.0312561067899..0.0312561067899]
# extdiv(T=[-0.0312561067899..0.0312561067899], Tu=[-0.0312561067899..0.0312561067899], split=False, T=[-0.0312561067899..0.0312561067899], fI=[0.0418442936539..0.171746363415], fP=[-0.237908963416..-0.0285083064117])
# ===
# reached detect roots t=[1.92481887063..1.92481887063] + [0.0..0.0343817174689]
# using mask!
# mask_overlap = [1.92481887063..1.9592005881]
# mask_overlap = [-2.02060590482e-14..0.034381717469]
# t0 = [0.0..0.0343817174689]
# detect_roots(T0=[0.0..0.0343817174689], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0343817174689]
# M = [0.0171908587345..0.0171908587345]
# fI = [0.0421841492155..0.158486466869]
# failed! on:
# M=[0.0171908587345..0.0171908587345]
# extdiv(T=[-0.0171908587345..0.0171908587345], Tu=[-0.0171908587345..0.0171908587345], split=False, T=[-0.0171908587345..0.0171908587345], fI=[0.0421841492155..0.158486466869], fP=[-0.223864234186..-0.0402151419481])
# ===
# reached detect roots t=[1.9592005881..1.9592005881] + [0.0..0.0378198892158]
# using mask!
# mask_overlap = [1.9592005881..1.99702047732]
# mask_overlap = [-2.0650148258e-14..0.0378198892158]
# t0 = [0.0..0.0378198892158]
# detect_roots(T0=[0.0..0.0378198892158], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0378198892158]
# M = [0.0189099446079..0.0189099446079]
# fI = [0.0400958734684..0.151047452686]
# failed! on:
# M=[0.0189099446079..0.0189099446079]
# extdiv(T=[-0.0189099446079..0.0189099446079], Tu=[-0.0189099446079..0.0189099446079], split=False, T=[-0.0189099446079..0.0189099446079], fI=[0.0400958734684..0.151047452686], fP=[-0.218508220947..-0.0427702758346])
# ===
# reached detect roots t=[1.99702047732..1.99702047732] + [0.0..0.0416018781374]
# using mask!
# mask_overlap = [1.99702047732..2.03862235546]
# mask_overlap = [-2.10942374679e-14..0.0416018781374]
# t0 = [0.0..0.0416018781374]
# detect_roots(T0=[0.0..0.0416018781374], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0416018781374]
# M = [0.0208009390687..0.0208009390687]
# fI = [0.0377343701391..0.143040379571]
# failed! on:
# M=[0.0208009390687..0.0208009390687]
# extdiv(T=[-0.0208009390687..0.0208009390687], Tu=[-0.0208009390687..0.0208009390687], split=False, T=[-0.0208009390687..0.0208009390687], fI=[0.0377343701391..0.143040379571], fP=[-0.212636574668..-0.045271021846])
# ===
# reached detect roots t=[2.03862235546..2.03862235546] + [0.0..0.0457620659512]
# using mask!
# mask_overlap = [2.03862235546..2.08438442141]
# mask_overlap = [-2.17603712827e-14..0.0457620659512]
# t0 = [0.0..0.0457620659512]
# detect_roots(T0=[0.0..0.0457620659512], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0457620659512]
# M = [0.0228810329756..0.0228810329756]
# fI = [0.0350340408197..0.134483439458]
# failed! on:
# M=[0.0228810329756..0.0228810329756]
# extdiv(T=[-0.0228810329756..0.0228810329756], Tu=[-0.0228810329756..0.0228810329756], split=False, T=[-0.0228810329756..0.0228810329756], fI=[0.0350340408197..0.134483439458], fP=[-0.206559677557..-0.0473488882379])
# ===
# reached detect roots t=[2.08438442141..2.08438442141] + [0.0..0.0503382725463]
# using mask!
# mask_overlap = [2.08438442141..2.13472269395]
# mask_overlap = [-2.26485497024e-14..0.0503382725463]
# t0 = [0.0..0.0503382725463]
# detect_roots(T0=[0.0..0.0503382725463], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0503382725463]
# M = [0.0251691362731..0.0251691362731]
# fI = [0.0319957134054..0.125331736988]
# failed! on:
# M=[0.0251691362731..0.0251691362731]
# extdiv(T=[-0.0251691362731..0.0251691362731], Tu=[-0.0251691362731..0.0251691362731], split=False, T=[-0.0251691362731..0.0251691362731], fI=[0.0319957134054..0.125331736988], fP=[-0.199952421031..-0.049274775665])
# ===
# reached detect roots t=[2.13472269395..2.13472269395] + [0.0..0.0553720998009]
# using mask!
# mask_overlap = [2.13472269395..2.19009479375]
# mask_overlap = [-2.35367281221e-14..0.0553720998009]
# t0 = [0.0..0.0553720998009]
# detect_roots(T0=[0.0..0.0553720998009], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0553720998009]
# M = [0.0276860499004..0.0276860499004]
# fI = [0.0285947836788..0.115572470613]
# failed! on:
# M=[0.0276860499004..0.0276860499004]
# extdiv(T=[-0.0276860499004..0.0276860499004], Tu=[-0.0276860499004..0.0276860499004], split=False, T=[-0.0276860499004..0.0276860499004], fI=[0.0285947836788..0.115572470613], fP=[-0.192735724712..-0.0510622995653])
# ===
# reached detect roots t=[2.19009479375..2.19009479375] + [0.0..0.060909309781]
# using mask!
# mask_overlap = [2.19009479375..2.25100410354]
# mask_overlap = [-2.44249065418e-14..0.060909309781]
# t0 = [0.0..0.060909309781]
# detect_roots(T0=[0.0..0.060909309781], epsilon=1e-05, verbosity=10)
# T = [0.0..0.060909309781]
# M = [0.0304546548905..0.0304546548905]
# fI = [0.0236396417539..0.106367972853]
# failed! on:
# M=[0.0304546548905..0.0304546548905]
# extdiv(T=[-0.0304546548905..0.0304546548905], Tu=[-0.0304546548905..0.0304546548905], split=False, T=[-0.0304546548905..0.0304546548905], fI=[0.0236396417539..0.106367972853], fP=[-0.184894162012..-0.0526818230246])
# ===
# reached detect roots t=[2.25100410354..2.25100410354] + [0.0..0.0670002407591]
# using mask!
# mask_overlap = [2.25100410354..2.31800434429]
# mask_overlap = [-2.53130849615e-14..0.0670002407591]
# t0 = [0.0..0.0670002407591]
# detect_roots(T0=[0.0..0.0670002407591], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0670002407591]
# M = [0.0335001203795..0.0335001203795]
# fI = [0.017422433272..0.0974166228351]
# failed! on:
# M=[0.0335001203795..0.0335001203795]
# extdiv(T=[-0.0335001203795..0.0335001203795], Tu=[-0.0335001203795..0.0335001203795], split=False, T=[-0.0335001203795..0.0335001203795], fI=[0.017422433272..0.0974166228351], fP=[-0.176438224264..-0.0540907838419])
# ===
# reached detect roots t=[2.31800434429..2.31800434429] + [0.0..0.073700264835]
# using mask!
# mask_overlap = [2.31800434429..2.39170460913]
# mask_overlap = [-2.62012633812e-14..0.073700264835]
# t0 = [0.0..0.073700264835]
# detect_roots(T0=[0.0..0.073700264835], epsilon=1e-05, verbosity=10)
# T = [0.0..0.073700264835]
# M = [0.0368501324175..0.0368501324175]
# fI = [0.0108546039895..0.0877914226596]
# failed! on:
# M=[0.0368501324175..0.0368501324175]
# extdiv(T=[-0.0368501324175..0.0368501324175], Tu=[-0.0368501324175..0.0368501324175], split=False, T=[-0.0368501324175..0.0368501324175], fI=[0.0108546039895..0.0877914226596], fP=[-0.167424246466..-0.05521358718])
# ===
# reached detect roots t=[2.39170460913..2.39170460913] + [0.0..0.0810702913185]
# using mask!
# mask_overlap = [2.39170460913..2.47277490045]
# mask_overlap = [-2.70894418009e-14..0.0810702913185]
# t0 = [0.0..0.0810702913185]
# detect_roots(T0=[0.0..0.0810702913185], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0810702913185]
# M = [0.0405351456592..0.0405351456592]
# fI = [0.00394211822313..0.0775005780416]
# T = [0.0655047300898..0.0810702913185]
# M = [0.0732875107042..0.0732875107042]
# fI = [-0.00121399296942..0.0755666380757]
# Tfinal = [0.0655047300898..0.0810702913185]
# root on boundary!
# new root:
# [2.45720933922..2.47277490045]
# ===
# reached detect roots t=[2.47277490045..2.47277490045] + [0.0..0.0891773204503]
# using mask!
# mask_overlap = [2.47277490045..2.5619522209]
# mask_overlap = [-2.79776202206e-14..0.0891773204504]
# t0 = [0.0..0.0891773204503]
# detect_roots(T0=[0.0..0.0891773204503], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0891773204503]
# M = [0.0445886602252..0.0445886602252]
# fI = [-0.00331815610588..0.0665785798239]
# Tfinal = [-0.0..0.0891773204503]
# root on boundary!
# merging intervals:
# [2.45720933922..2.47277490045]
# [2.47277490045..2.5619522209]
# ===
# reached detect roots t=[2.5619522209..2.5619522209] + [0.0..0.0980950524954]
# using mask!
# mask_overlap = [2.5619522209..2.66004727339]
# mask_overlap = [-2.88657986403e-14..0.0980950524954]
# t0 = [0.0..0.0980950524954]
# detect_roots(T0=[0.0..0.0980950524954], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0980950524954]
# M = [0.0490475262477..0.0490475262477]
# fI = [-0.0111790627388..0.0553366569645]
# Tfinal = [-0.0..0.0980950524954]
# root on boundary!
# merging intervals:
# [2.45720933922..2.5619522209]
# [2.5619522209..2.66004727339]
# ===
# reached detect roots t=[2.66004727339..2.66004727339] + [0.0..0.0539522788725]
# using mask!
# mask_overlap = [2.66004727339..2.71399955227]
# mask_overlap = [-2.975397706e-14..0.0539522788725]
# t0 = [0.0..0.0539522788725]
# detect_roots(T0=[0.0..0.0539522788725], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0539522788725]
# M = [0.0269761394362..0.0269761394362]
# fI = [-0.0158908437412..0.0452285759532]
# Tfinal = [-0.0..0.0539522788725]
# root on boundary!
# merging intervals:
# [2.45720933922..2.66004727339]
# [2.66004727339..2.71399955227]
# ===
# reached detect roots t=[2.71399955227..2.71399955227] + [0.0..0.0593475067597]
# using mask!
# mask_overlap = [2.71399955227..2.77334705903]
# mask_overlap = [-3.06421554797e-14..0.0593475067597]
# t0 = [0.0..0.0593475067597]
# detect_roots(T0=[0.0..0.0593475067597], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0593475067597]
# M = [0.0296737533798..0.0296737533798]
# fI = [-0.0202979485449..0.0389699565682]
# Tfinal = [-0.0..0.0593475067597]
# root on boundary!
# merging intervals:
# [2.45720933922..2.71399955227]
# [2.71399955227..2.77334705903]
# ===
# reached detect roots t=[2.77334705903..2.77334705903] + [0.0..0.0652822574357]
# using mask!
# mask_overlap = [2.77334705903..2.83862931646]
# mask_overlap = [-3.15303338994e-14..0.0652822574357]
# t0 = [0.0..0.0652822574357]
# detect_roots(T0=[0.0..0.0652822574357], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0652822574357]
# M = [0.0326411287178..0.0326411287178]
# fI = [-0.0249591416817..0.0322871253051]
# Tfinal = [-0.0..0.0652822574357]
# root on boundary!
# merging intervals:
# [2.45720933922..2.77334705903]
# [2.77334705903..2.83862931646]
# ===
# reached detect roots t=[2.83862931646..2.83862931646] + [0.0..0.0718104831792]
# using mask!
# mask_overlap = [2.83862931646..2.91043979964]
# mask_overlap = [-3.24185123191e-14..0.0718104831793]
# t0 = [0.0..0.0718104831792]
# detect_roots(T0=[0.0..0.0718104831792], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0718104831792]
# M = [0.0359052415896..0.0359052415896]
# fI = [-0.0298829496617..0.0251793247621]
# Tfinal = [-0.0..0.0718104831792]
# root on boundary!
# merging intervals:
# [2.45720933922..2.83862931646]
# [2.83862931646..2.91043979964]
# ===
# reached detect roots t=[2.91043979964..2.91043979964] + [0.0..0.0789915314972]
# using mask!
# mask_overlap = [2.91043979964..2.98943133114]
# mask_overlap = [-3.33066907388e-14..0.0789915314972]
# t0 = [0.0..0.0789915314972]
# detect_roots(T0=[0.0..0.0789915314972], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0789915314972]
# M = [0.0394957657486..0.0394957657486]
# fI = [-0.0350538243794..0.0176522808156]
# Tfinal = [-0.0..0.0789915314972]
# root on boundary!
# merging intervals:
# [2.45720933922..2.91043979964]
# [2.91043979964..2.98943133114]
# ===
# reached detect roots t=[2.98943133114..2.98943133114] + [0.0..0.0868906846469]
# using mask!
# mask_overlap = [2.98943133114..3.07632201578]
# mask_overlap = [-3.41948691585e-14..0.0868906846469]
# t0 = [0.0..0.0868906846469]
# detect_roots(T0=[0.0..0.0868906846469], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0868906846469]
# M = [0.0434453423234..0.0434453423234]
# fI = [-0.0404770525871..0.00972482943239]
# Tfinal = [-0.0..0.0868906846469]
# root on boundary!
# merging intervals:
# [2.45720933922..2.98943133114]
# [2.98943133114..3.07632201578]
# ===
# reached detect roots t=[3.07632201578..3.07632201578] + [0.0..0.0955797531116]
# using mask!
# mask_overlap = [3.07632201578..3.1719017689]
# mask_overlap = [-3.50830475782e-14..0.0955797531116]
# t0 = [0.0..0.0955797531116]
# detect_roots(T0=[0.0..0.0955797531116], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0955797531116]
# M = [0.0477898765558..0.0477898765558]
# fI = [-0.0462114041467..0.00149229286856]
# T = [-0.0..0.0760979286401]
# M = [0.03804896432..0.03804896432]
# fI = [-0.045304049664..0.00204159916599]
# T = [-0.0..0.0758000673842]
# M = [0.0379000336921..0.0379000336921]
# fI = [-0.0452901639218..0.00205004873573]
# Tfinal = [-0.0..0.0757927918473]
# root on boundary!
# merging intervals:
# [2.45720933922..3.07632201578]
# [3.07632201578..3.15211480763]
# ===
# reached detect roots t=[3.1719017689..3.1719017689] + [0.0..0.105137728423]
# using mask!
# mask_overlap = [3.1719017689..3.27703949732]
# mask_overlap = [-3.59712259979e-14..0.105137728423]
# t0 = [0.0..0.105137728423]
# detect_roots(T0=[0.0..0.105137728423], epsilon=1e-05, verbosity=10)
# T = [0.0..0.105137728423]
# M = [0.0525688642114..0.0525688642114]
# fI = [-0.0521582139947..-0.00709246212011]
# failed! on:
# M=[0.0525688642114..0.0525688642114]
# extdiv(T=[-0.0525688642114..0.0525688642114], Tu=[-0.0525688642114..0.0525688642114], split=False, T=[-0.0525688642114..0.0525688642114], fI=[-0.0521582139947..-0.00709246212011], fP=[-0.0876113065523..-0.050666078554])
# ===
# reached detect roots t=[3.27703949732..3.27703949732] + [0.0..0.115651501265]
# using mask!
# mask_overlap = [3.27703949732..3.39269099858]
# mask_overlap = [-3.68594044176e-14..0.115651501265]
# t0 = [0.0..0.115651501265]
# detect_roots(T0=[0.0..0.115651501265], epsilon=1e-05, verbosity=10)
# T = [0.0..0.115651501265]
# M = [0.0578257506325..0.0578257506325]
# fI = [-0.0583247503975..-0.0159638205368]
# failed! on:
# M=[0.0578257506325..0.0578257506325]
# extdiv(T=[-0.0578257506325..0.0578257506325], Tu=[-0.0578257506325..0.0578257506325], split=False, T=[-0.0578257506325..0.0578257506325], fI=[-0.0583247503975..-0.0159638205368], fP=[-0.0816867839907..-0.0478693702666])
# ===
# reached detect roots t=[3.39269099858..3.39269099858] + [0.0..0.127216651391]
# using mask!
# mask_overlap = [3.39269099858..3.51990764998]
# mask_overlap = [-3.77475828373e-14..0.127216651392]
# t0 = [0.0..0.127216651391]
# detect_roots(T0=[0.0..0.127216651391], epsilon=1e-05, verbosity=10)
# T = [0.0..0.127216651391]
# M = [0.0636083256957..0.0636083256957]
# fI = [nan..nan]
# Tfinal = [-0.0..0.127216651391]
# root on boundary!
# new root:
# [3.39269099858..3.51990764998]
# ===
# reached detect roots t=[3.51990764998..3.51990764998] + [0.0..0.139938316531]
# using mask!
# mask_overlap = [3.51990764998..3.65984596651]
# mask_overlap = [-3.8635761257e-14..0.139938316531]
# t0 = [0.0..0.139938316531]
# detect_roots(T0=[0.0..0.139938316531], epsilon=1e-05, verbosity=10)
# T = [0.0..0.139938316531]
# M = [0.0699691582653..0.0699691582653]
# fI = [-0.0711127131838..-0.034383552209]
# failed! on:
# M=[0.0699691582653..0.0699691582653]
# extdiv(T=[-0.0699691582653..0.0699691582653], Tu=[-0.0699691582653..0.0699691582653], split=False, T=[-0.0699691582653..0.0699691582653], fI=[-0.0711127131838..-0.034383552209], fP=[-0.0703640162717..-0.0409960915261])
# ===
# reached detect roots t=[3.65984596651..3.65984596651] + [0.0..0.153932148184]
# using mask!
# mask_overlap = [3.65984596651..3.81377811469]
# mask_overlap = [-3.95239396767e-14..0.153932148184]
# t0 = [0.0..0.153932148184]
# skipping given consistent value over domain
# ===
# reached detect roots t=[3.81377811469..3.81377811469] + [0.0..0.084662681501]
# using mask!
# mask_overlap = [3.81377811469..3.89844079619]
# mask_overlap = [-4.04121180964e-14..0.0846626815011]
# t0 = [0.0..0.084662681501]
# skipping given consistent value over domain
# ===
# reached detect roots t=[3.89844079619..3.89844079619] + [0.0..0.0931289496511]
# using mask!
# mask_overlap = [3.89844079619..3.99156974584]
# mask_overlap = [-4.13002965161e-14..0.0931289496512]
# t0 = [0.0..0.0931289496511]
# skipping given consistent value over domain
# ===
# reached detect roots t=[3.99156974584..3.99156974584] + [0.0..0.102441844616]
# using mask!
# mask_overlap = [3.99156974584..4.09401159046]
# mask_overlap = [-4.21884749358e-14..0.102441844616]
# t0 = [0.0..0.102441844616]
# skipping given consistent value over domain
# ===
# reached detect roots t=[4.09401159046..4.09401159046] + [0.0..0.112686029078]
# using mask!
# mask_overlap = [4.09401159046..4.20669761954]
# mask_overlap = [-4.35207425653e-14..0.112686029078]
# t0 = [0.0..0.112686029078]
# skipping given consistent value over domain
# ===
# reached detect roots t=[4.20669761954..4.20669761954] + [0.0..0.123954631986]
# using mask!
# mask_overlap = [4.20669761954..4.33065225152]
# mask_overlap = [-4.52970994047e-14..0.123954631986]
# t0 = [0.0..0.123954631986]
# skipping given consistent value over domain
# ===
# reached detect roots t=[4.33065225152..4.33065225152] + [0.0..0.136350095184]
# using mask!
# mask_overlap = [4.33065225152..4.46700234671]
# mask_overlap = [-4.70734562441e-14..0.136350095184]
# t0 = [0.0..0.136350095184]
# skipping given consistent value over domain
# ===
# reached detect roots t=[4.46700234671..4.46700234671] + [0.0..0.149985104703]
# using mask!
# mask_overlap = [4.46700234671..4.61698745141]
# mask_overlap = [-4.88498130835e-14..0.149985104703]
# t0 = [0.0..0.149985104703]
# skipping given consistent value over domain
# ===
# reached detect roots t=[4.61698745141..4.61698745141] + [0.0..0.164983615173]
# using mask!
# mask_overlap = [4.61698745141..4.78197106658]
# mask_overlap = [-5.06261699229e-14..0.164983615173]
# t0 = [0.0..0.164983615173]
# skipping given consistent value over domain
# ===
# reached detect roots t=[4.78197106658..4.78197106658] + [0.0..0.18148197669]
# using mask!
# mask_overlap = [4.78197106658..4.96345304327]
# mask_overlap = [-5.24025267623e-14..0.18148197669]
# t0 = [0.0..0.18148197669]
# skipping given consistent value over domain
# ===
# reached detect roots t=[4.96345304327..4.96345304327] + [0.0..0.0375469567271]
# using mask!
# mask_overlap = [4.96345304327..5.0]
# mask_overlap = [-5.3290705182e-14..0.0365469567282]
# t0 = [0.0..0.0365469567282]
# skipping given consistent value over domain
# domain = [0.00000000000000000 .. 5.0000000000000000]
# roots = [[0.00000000000000000 .. 0.86802860497076651],
#  [0.88067123177899719 .. 0.88956119414532109],
#  [2.4572093392192906 .. 3.1521148076320591],
#  [3.3926909985840172 .. 3.5199076499755440]]
# seg_domain = [0.00000000000000000 .. 5.0000000000000000]
# roots = [[0.00000000000000000 .. 0.86802860497076651],
#  [0.88067123177899719 .. 0.88956119414532109],
#  [2.4572093392192906 .. 3.1521148076320591],
#  [3.3926909985840172 .. 3.5199076499755440]]
# Monitored signal 2.42356061935 sec
# Graphics object consisting of 2 graphics primitives

# %%
sig2.plot()
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
sig2 = Atomic(x - 1.15).signal_for_system(vf, v3, 5, order=5, step=(0.01, 0.5),
                                   precondition=1,
                                   estimation=1e-3,
                                   integrationScheme=2,
                                   cutoff_threshold=1e-5,
                                   symbolic_composition=True,
                                   use_masks=True,
                                   verbosity=10)
sig2.plot()
# Out:
# Computed 115 flowpipes in 1.39678621292 sec
# In prepare! flowpipes_compo.size() = 115
# Prepared for plotting in 0.000761985778809 sec
# ===
# reached detect roots t=[0.0..0.0] + [0.0..0.03125]
# using mask!
# mask_overlap = [0.0..0.03125]
# mask_overlap = [-0.0..0.03125]
# t0 = [-0.0..0.03125]
# f_domain = [-1.60240505978..1.50240828693]
# detect_roots(T0=[-0.0..0.03125], epsilon=1e-05, verbosity=10)
# T = [-0.0..0.03125]
# M = [0.015625..0.015625]
# fI = [-0.147743741509..0.0613162002737]
# Tfinal = [-0.0..0.03125]
# root on boundary!
# new root:
# [-0.0..0.03125]
# ===
# reached detect roots t=[0.03125..0.03125] + [0.0..0.0171875]
# using mask!
# mask_overlap = [0.03125..0.0484375]
# mask_overlap = [-3.46944695195e-18..0.0171875]
# t0 = [0.0..0.0171875]
# f_domain = [-1.67261465507..1.59953266879]
# detect_roots(T0=[0.0..0.0171875], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0171875]
# M = [0.00859375..0.00859375]
# fI = [-0.144239307142..0.0789355872924]
# Tfinal = [-0.0..0.0171875]
# root on boundary!
# merging intervals:
# [-0.0..0.03125]
# [0.03125..0.0484375]
# ===
# reached detect roots t=[0.0484375..0.0484375] + [0.0..0.01890625]
# using mask!
# mask_overlap = [0.0484375..0.06734375]
# mask_overlap = [-1.38777878078e-17..0.01890625]
# t0 = [0.0..0.01890625]
# f_domain = [-1.70731666121..1.64900974626]
# detect_roots(T0=[0.0..0.01890625], epsilon=1e-05, verbosity=10)
# T = [0.0..0.01890625]
# M = [0.009453125..0.009453125]
# fI = [-0.14167762036..0.0921588309592]
# Tfinal = [-0.0..0.01890625]
# root on boundary!
# merging intervals:
# [-0.0..0.0484375]
# [0.0484375..0.06734375]
# ===
# reached detect roots t=[0.06734375..0.06734375] + [0.0..0.020796875]
# using mask!
# mask_overlap = [0.06734375..0.088140625]
# mask_overlap = [-2.77555756156e-17..0.020796875]
# t0 = [0.0..0.020796875]
# f_domain = [-1.74112706575..1.6990480621]
# detect_roots(T0=[0.0..0.020796875], epsilon=1e-05, verbosity=10)
# T = [0.0..0.020796875]
# M = [0.0103984375..0.0103984375]
# fI = [-0.13887430496..0.106741264325]
# Tfinal = [-0.0..0.020796875]
# root on boundary!
# merging intervals:
# [-0.0..0.06734375]
# [0.06734375..0.088140625]
# ===
# reached detect roots t=[0.088140625..0.088140625] + [0.0..0.0228765625]
# using mask!
# mask_overlap = [0.088140625..0.1110171875]
# mask_overlap = [-5.55111512313e-17..0.0228765625]
# t0 = [0.0..0.0228765625]
# f_domain = [-1.77840406729..1.7543098166]
# detect_roots(T0=[0.0..0.0228765625], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0228765625]
# M = [0.01143828125..0.01143828125]
# fI = [-0.135819508858..0.122794224006]
# Tfinal = [-0.0..0.0228765625]
# root on boundary!
# merging intervals:
# [-0.0..0.088140625]
# [0.088140625..0.1110171875]
# ===
# reached detect roots t=[0.1110171875..0.1110171875] + [0.0..0.02516421875]
# using mask!
# mask_overlap = [0.1110171875..0.13618140625]
# mask_overlap = [-8.32667268469e-17..0.02516421875]
# t0 = [0.0..0.02516421875]
# f_domain = [-1.83866410322..1.83442935492]
# detect_roots(T0=[0.0..0.02516421875], epsilon=1e-05, verbosity=10)
# T = [0.0..0.02516421875]
# M = [0.012582109375..0.012582109375]
# fI = [-0.132482365607..0.140426291054]
# Tfinal = [-0.0..0.02516421875]
# root on boundary!
# merging intervals:
# [-0.0..0.1110171875]
# [0.1110171875..0.13618140625]
# ===
# reached detect roots t=[0.13618140625..0.13618140625] + [0.0..0.027680640625]
# using mask!
# mask_overlap = [0.13618140625..0.163862046875]
# mask_overlap = [-1.38777878078e-16..0.027680640625]
# t0 = [0.0..0.027680640625]
# f_domain = [-1.89403412273..1.91154554154]
# detect_roots(T0=[0.0..0.027680640625], epsilon=1e-05, verbosity=10)
# T = [0.0..0.027680640625]
# M = [0.0138403203125..0.0138403203125]
# fI = [-0.128824579111..0.159718391739]
# Tfinal = [-0.0..0.027680640625]
# root on boundary!
# merging intervals:
# [-0.0..0.13618140625]
# [0.13618140625..0.163862046875]
# ===
# reached detect roots t=[0.163862046875..0.163862046875] + [0.0..0.0152243523438]
# using mask!
# mask_overlap = [0.163862046875..0.179086399219]
# mask_overlap = [-1.94289029309e-16..0.0152243523438]
# t0 = [0.0..0.0152243523438]
# f_domain = [-1.99013701307..2.03154328946]
# detect_roots(T0=[0.0..0.0152243523438], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0152243523438]
# M = [0.00761217617188..0.00761217617188]
# fI = [-0.125766234125..0.175148837752]
# Tfinal = [-0.0..0.0152243523438]
# root on boundary!
# merging intervals:
# [-0.0..0.163862046875]
# [0.163862046875..0.179086399219]
# ===
# reached detect roots t=[0.179086399219..0.179086399219] + [0.0..0.0167467875781]
# using mask!
# mask_overlap = [0.179086399219..0.195833186797]
# mask_overlap = [-2.49800180541e-16..0.0167467875781]
# t0 = [0.0..0.0167467875781]
# f_domain = [-2.05031198886..2.10478300026]
# detect_roots(T0=[0.0..0.0167467875781], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0167467875781]
# M = [0.00837339378906..0.00837339378906]
# fI = [-0.123506445563..0.186556857208]
# Tfinal = [-0.0..0.0167467875781]
# root on boundary!
# merging intervals:
# [-0.0..0.179086399219]
# [0.179086399219..0.195833186797]
# ===
# reached detect roots t=[0.195833186797..0.195833186797] + [0.0..0.0184214663359]
# using mask!
# mask_overlap = [0.195833186797..0.214254653133]
# mask_overlap = [-3.05311331772e-16..0.0184214663359]
# t0 = [0.0..0.0184214663359]
# f_domain = [-2.1128348808..2.18159121746]
# detect_roots(T0=[0.0..0.0184214663359], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0184214663359]
# M = [0.00921073316797..0.00921073316797]
# fI = [-0.120993324572..0.198954864794]
# Tfinal = [-0.0..0.0184214663359]
# root on boundary!
# merging intervals:
# [-0.0..0.195833186797]
# [0.195833186797..0.214254653133]
# ===
# reached detect roots t=[0.214254653133..0.214254653133] + [0.0..0.0202636129695]
# using mask!
# mask_overlap = [0.214254653133..0.234518266102]
# mask_overlap = [-3.33066907388e-16..0.0202636129695]
# t0 = [0.0..0.0202636129695]
# f_domain = [-2.17628060803..2.26062534507]
# detect_roots(T0=[0.0..0.0202636129695], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0202636129695]
# M = [0.0101318064848..0.0101318064848]
# fI = [-0.118190494576..0.212381065344]
# Tfinal = [-0.0..0.0202636129695]
# root on boundary!
# merging intervals:
# [-0.0..0.214254653133]
# [0.214254653133..0.234518266102]
# ===
# reached detect roots t=[0.234518266102..0.234518266102] + [0.0..0.0222899742665]
# using mask!
# mask_overlap = [0.234518266102..0.256808240369]
# mask_overlap = [-3.88578058619e-16..0.0222899742665]
# t0 = [0.0..0.0222899742665]
# f_domain = [-2.25558673328..2.35687381015]
# detect_roots(T0=[0.0..0.0222899742665], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0222899742665]
# M = [0.0111449871332..0.0111449871332]
# fI = [-0.115040462591..0.226842223301]
# Tfinal = [-0.0..0.0222899742665]
# root on boundary!
# merging intervals:
# [-0.0..0.234518266102]
# [0.234518266102..0.256808240369]
# ===
# reached detect roots t=[0.256808240369..0.256808240369] + [0.0..0.0245189716931]
# using mask!
# mask_overlap = [0.256808240369..0.281327212062]
# mask_overlap = [-4.99600361081e-16..0.0245189716931]
# t0 = [0.0..0.0245189716931]
# f_domain = [-2.36777221088..2.48742500994]
# detect_roots(T0=[0.0..0.0245189716931], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0245189716931]
# M = [0.0122594858466..0.0122594858466]
# fI = [-0.111677382921..0.242525951543]
# Tfinal = [-0.0..0.0245189716931]
# root on boundary!
# merging intervals:
# [-0.0..0.256808240369]
# [0.256808240369..0.281327212062]
# ===
# reached detect roots t=[0.281327212062..0.281327212062] + [0.0..0.0134854344312]
# using mask!
# mask_overlap = [0.281327212062..0.294812646493]
# mask_overlap = [-6.10622663544e-16..0.0134854344312]
# t0 = [0.0..0.0134854344312]
# f_domain = [-2.48364596703..2.6231179424]
# detect_roots(T0=[0.0..0.0134854344312], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0134854344312]
# M = [0.00674271721561..0.00674271721561]
# fI = [-0.108828471981..0.254858052098]
# Tfinal = [-0.0..0.0134854344312]
# root on boundary!
# merging intervals:
# [-0.0..0.281327212062]
# [0.281327212062..0.294812646493]
# ===
# reached detect roots t=[0.294812646493..0.294812646493] + [0.0..0.0148339778743]
# using mask!
# mask_overlap = [0.294812646493..0.309646624368]
# mask_overlap = [-6.66133814775e-16..0.0148339778743]
# t0 = [0.0..0.0148339778743]
# f_domain = [-2.54178280331..2.69196724745]
# detect_roots(T0=[0.0..0.0148339778743], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0148339778743]
# M = [0.00741698893717..0.00741698893717]
# fI = [-0.106761746898..0.263913645477]
# Tfinal = [-0.0..0.0148339778743]
# root on boundary!
# merging intervals:
# [-0.0..0.294812646493]
# [0.294812646493..0.309646624368]
# ===
# reached detect roots t=[0.309646624368..0.309646624368] + [0.0..0.0163173756618]
# using mask!
# mask_overlap = [0.309646624368..0.325964000029]
# mask_overlap = [-7.77156117238e-16..0.0163173756618]
# t0 = [0.0..0.0163173756618]
# f_domain = [-2.60008628508..2.76188982667]
# detect_roots(T0=[0.0..0.0163173756618], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0163173756618]
# M = [0.00815868783089..0.00815868783089]
# fI = [-0.104434260773..0.273626661957]
# Tfinal = [-0.0..0.0163173756618]
# root on boundary!
# merging intervals:
# [-0.0..0.309646624368]
# [0.309646624368..0.325964000029]
# ===
# reached detect roots t=[0.325964000029..0.325964000029] + [0.0..0.017949113228]
# using mask!
# mask_overlap = [0.325964000029..0.343913113257]
# mask_overlap = [-8.881784197e-16..0.017949113228]
# t0 = [0.0..0.017949113228]
# f_domain = [-2.65694202098..2.83144403924]
# detect_roots(T0=[0.0..0.017949113228], epsilon=1e-05, verbosity=10)
# T = [0.0..0.017949113228]
# M = [0.00897455661398..0.00897455661398]
# fI = [-0.101823273572..0.284000624117]
# Tfinal = [-0.0..0.017949113228]
# root on boundary!
# merging intervals:
# [-0.0..0.325964000029]
# [0.325964000029..0.343913113257]
# ===
# reached detect roots t=[0.343913113257..0.343913113257] + [0.0..0.0197440245508]
# using mask!
# mask_overlap = [0.343913113257..0.363657137808]
# mask_overlap = [-9.99200722163e-16..0.0197440245508]
# t0 = [0.0..0.0197440245508]
# f_domain = [-2.71044817315..2.89868260718]
# detect_roots(T0=[0.0..0.0197440245508], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0197440245508]
# M = [0.00987201227538..0.00987201227538]
# fI = [-0.098951681713..0.29508897145]
# Tfinal = [-0.0..0.0197440245508]
# root on boundary!
# merging intervals:
# [-0.0..0.343913113257]
# [0.343913113257..0.363657137808]
# ===
# reached detect roots t=[0.363657137808..0.363657137808] + [0.0..0.0217184270058]
# using mask!
# mask_overlap = [0.363657137808..0.385375564814]
# mask_overlap = [-1.11022302463e-15..0.0217184270058]
# t0 = [0.0..0.0217184270058]
# f_domain = [-2.75306751724..2.95610025085]
# detect_roots(T0=[0.0..0.0217184270058], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0217184270058]
# M = [0.0108592135029..0.0108592135029]
# fI = [-0.0959190293876..0.306989217023]
# Tfinal = [-0.0..0.0217184270058]
# root on boundary!
# merging intervals:
# [-0.0..0.363657137808]
# [0.363657137808..0.385375564814]
# ===
# reached detect roots t=[0.385375564814..0.385375564814] + [0.0..0.0238902697064]
# using mask!
# mask_overlap = [0.385375564814..0.40926583452]
# mask_overlap = [-1.22124532709e-15..0.0238902697064]
# t0 = [0.0..0.0238902697064]
# f_domain = [-2.77913452849..2.99804378604]
# detect_roots(T0=[0.0..0.0238902697064], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0238902697064]
# M = [0.0119451348532..0.0119451348532]
# fI = [-0.0924856266418..0.31945362119]
# Tfinal = [-0.0..0.0238902697064]
# root on boundary!
# merging intervals:
# [-0.0..0.385375564814]
# [0.385375564814..0.40926583452]
# ===
# reached detect roots t=[0.40926583452..0.40926583452] + [0.0..0.0131396483385]
# using mask!
# mask_overlap = [0.40926583452..0.422405482859]
# mask_overlap = [-1.33226762955e-15..0.0131396483385]
# t0 = [0.0..0.0131396483385]
# f_domain = [-2.78557248013..3.02128078719]
# detect_roots(T0=[0.0..0.0131396483385], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0131396483385]
# M = [0.00656982416926..0.00656982416926]
# fI = [-0.0895002420264..0.328963948971]
# Tfinal = [-0.0..0.0131396483385]
# root on boundary!
# merging intervals:
# [-0.0..0.40926583452]
# [0.40926583452..0.422405482859]
# ===
# reached detect roots t=[0.422405482859..0.422405482859] + [0.0..0.0144536131724]
# using mask!
# mask_overlap = [0.422405482859..0.436859096031]
# mask_overlap = [-1.44328993201e-15..0.0144536131724]
# t0 = [0.0..0.0144536131724]
# f_domain = [-2.78145111101..3.0262154172]
# detect_roots(T0=[0.0..0.0144536131724], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0144536131724]
# M = [0.00722680658619..0.00722680658619]
# fI = [-0.0873062928595..0.335808362685]
# Tfinal = [-0.0..0.0144536131724]
# root on boundary!
# merging intervals:
# [-0.0..0.422405482859]
# [0.422405482859..0.436859096031]
# ===
# reached detect roots t=[0.436859096031..0.436859096031] + [0.0..0.0158989744896]
# using mask!
# mask_overlap = [0.436859096031..0.452758070521]
# mask_overlap = [-1.55431223448e-15..0.0158989744896]
# t0 = [0.0..0.0158989744896]
# f_domain = [-2.76860950634..3.02317182969]
# detect_roots(T0=[0.0..0.0158989744896], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0158989744896]
# M = [0.00794948724481..0.00794948724481]
# fI = [-0.0849163727023..0.343083603552]
# Tfinal = [-0.0..0.0158989744896]
# root on boundary!
# merging intervals:
# [-0.0..0.436859096031]
# [0.436859096031..0.452758070521]
# ===
# reached detect roots t=[0.452758070521..0.452758070521] + [0.0..0.0174888719386]
# using mask!
# mask_overlap = [0.452758070521..0.470246942459]
# mask_overlap = [-1.66533453694e-15..0.0174888719386]
# t0 = [0.0..0.0174888719386]
# f_domain = [-2.74421266686..3.0092050142]
# detect_roots(T0=[0.0..0.0174888719386], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0174888719386]
# M = [0.00874443596929..0.00874443596929]
# fI = [-0.0822841664517..0.350760200687]
# Tfinal = [-0.0..0.0174888719386]
# root on boundary!
# merging intervals:
# [-0.0..0.452758070521]
# [0.452758070521..0.470246942459]
# ===
# reached detect roots t=[0.470246942459..0.470246942459] + [0.0..0.0192377591324]
# using mask!
# mask_overlap = [0.470246942459..0.489484701592]
# mask_overlap = [-1.7763568394e-15..0.0192377591324]
# t0 = [0.0..0.0192377591324]
# f_domain = [-2.70483447726..2.98098586277]
# detect_roots(T0=[0.0..0.0192377591324], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0192377591324]
# M = [0.00961887956622..0.00961887956622]
# fI = [-0.0793004513599..0.358714772329]
# Tfinal = [-0.0..0.0192377591324]
# root on boundary!
# merging intervals:
# [-0.0..0.470246942459]
# [0.470246942459..0.489484701592]
# ===
# reached detect roots t=[0.489484701592..0.489484701592] + [0.0..0.0211615350457]
# using mask!
# mask_overlap = [0.489484701592..0.510646236637]
# mask_overlap = [-1.88737914186e-15..0.0211615350457]
# t0 = [0.0..0.0211615350457]
# f_domain = [-2.67446909103..2.96247267456]
# detect_roots(T0=[0.0..0.0211615350457], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0211615350457]
# M = [0.0105807675228..0.0105807675228]
# fI = [-0.0759783894599..0.366923138227]
# Tfinal = [-0.0..0.0211615350457]
# root on boundary!
# merging intervals:
# [-0.0..0.489484701592]
# [0.489484701592..0.510646236637]
# ===
# reached detect roots t=[0.510646236637..0.510646236637] + [0.0..0.0116388442751]
# using mask!
# mask_overlap = [0.510646236637..0.522285080913]
# mask_overlap = [-2.10942374679e-15..0.0116388442751]
# t0 = [0.0..0.0116388442751]
# f_domain = [-2.63532588018..2.93583737957]
# detect_roots(T0=[0.0..0.0116388442751], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0116388442751]
# M = [0.00581942213756..0.00581942213756]
# fI = [-0.0726857944278..0.372596406637]
# Tfinal = [-0.0..0.0116388442751]
# root on boundary!
# merging intervals:
# [-0.0..0.510646236637]
# [0.510646236637..0.522285080913]
# ===
# reached detect roots t=[0.522285080913..0.522285080913] + [0.0..0.0128027287026]
# using mask!
# mask_overlap = [0.522285080913..0.535087809615]
# mask_overlap = [-2.33146835171e-15..0.0128027287026]
# t0 = [0.0..0.0128027287026]
# f_domain = [-2.60683249132..2.91398140478]
# detect_roots(T0=[0.0..0.0128027287026], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0128027287026]
# M = [0.00640136435132..0.00640136435132]
# fI = [-0.0705168113484..0.376874388138]
# Tfinal = [-0.0..0.0128027287026]
# root on boundary!
# merging intervals:
# [-0.0..0.522285080913]
# [0.522285080913..0.535087809615]
# ===
# reached detect roots t=[0.535087809615..0.535087809615] + [0.0..0.0140830015729]
# using mask!
# mask_overlap = [0.535087809615..0.549170811188]
# mask_overlap = [-2.55351295664e-15..0.0140830015729]
# t0 = [0.0..0.0140830015729]
# f_domain = [-2.57005991338..2.88430790911]
# detect_roots(T0=[0.0..0.0140830015729], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0140830015729]
# M = [0.00704150078645..0.00704150078645]
# fI = [-0.0680931858216..0.381309751385]
# Tfinal = [-0.0..0.0140830015729]
# root on boundary!
# merging intervals:
# [-0.0..0.535087809615]
# [0.535087809615..0.549170811188]
# ===
# reached detect roots t=[0.549170811188..0.549170811188] + [0.0..0.0154913017302]
# using mask!
# mask_overlap = [0.549170811188..0.564662112918]
# mask_overlap = [-2.77555756156e-15..0.0154913017302]
# t0 = [0.0..0.0154913017302]
# f_domain = [-2.52333104143..2.84513961372]
# detect_roots(T0=[0.0..0.0154913017302], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0154913017302]
# M = [0.0077456508651..0.0077456508651]
# fI = [-0.0653775018706..0.385861703538]
# Tfinal = [-0.0..0.0154913017302]
# root on boundary!
# merging intervals:
# [-0.0..0.549170811188]
# [0.549170811188..0.564662112918]
# ===
# reached detect roots t=[0.564662112918..0.564662112918] + [0.0..0.0170404319032]
# using mask!
# mask_overlap = [0.564662112918..0.581702544822]
# mask_overlap = [-2.88657986403e-15..0.0170404319032]
# t0 = [0.0..0.0170404319032]
# f_domain = [-2.47989068263..2.80971288366]
# detect_roots(T0=[0.0..0.0170404319032], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0170404319032]
# M = [0.0085202159516..0.0085202159516]
# fI = [-0.062340662022..0.390468388425]
# Tfinal = [-0.0..0.0170404319032]
# root on boundary!
# merging intervals:
# [-0.0..0.564662112918]
# [0.564662112918..0.581702544822]
# ===
# reached detect roots t=[0.581702544822..0.581702544822] + [0.0..0.0187444750935]
# using mask!
# mask_overlap = [0.581702544822..0.600447019915]
# mask_overlap = [-3.10862446895e-15..0.0187444750935]
# t0 = [0.0..0.0187444750935]
# f_domain = [-2.50206510408..2.84034575198]
# detect_roots(T0=[0.0..0.0187444750935], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0187444750935]
# M = [0.00937223754677..0.00937223754677]
# fI = [-0.0589411252597..0.395050064926]
# Tfinal = [-0.0..0.0187444750935]
# root on boundary!
# merging intervals:
# [-0.0..0.581702544822]
# [0.581702544822..0.600447019915]
# ===
# reached detect roots t=[0.600447019915..0.600447019915] + [0.0..0.0206189226029]
# using mask!
# mask_overlap = [0.600447019915..0.621065942518]
# mask_overlap = [-3.33066907388e-15..0.0206189226029]
# t0 = [0.0..0.0206189226029]
# f_domain = [-2.51396920021..2.86097481561]
# detect_roots(T0=[0.0..0.0206189226029], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0206189226029]
# M = [0.0103094613014..0.0103094613014]
# fI = [-0.0550905126382..0.399489089606]
# Tfinal = [-0.0..0.0206189226029]
# root on boundary!
# merging intervals:
# [-0.0..0.600447019915]
# [0.600447019915..0.621065942518]
# ===
# reached detect roots t=[0.621065942518..0.621065942518] + [0.0..0.0226808148632]
# using mask!
# mask_overlap = [0.621065942518..0.643746757381]
# mask_overlap = [-3.5527136788e-15..0.0226808148632]
# t0 = [0.0..0.0226808148632]
# f_domain = [-2.51207807997..2.86811699297]
# detect_roots(T0=[0.0..0.0226808148632], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0226808148632]
# M = [0.0113404074316..0.0113404074316]
# fI = [-0.0507232032999..0.40364311032]
# Tfinal = [-0.0..0.0226808148632]
# root on boundary!
# merging intervals:
# [-0.0..0.621065942518]
# [0.621065942518..0.643746757381]
# ===
# reached detect roots t=[0.643746757381..0.643746757381] + [0.0..0.0124744481747]
# using mask!
# mask_overlap = [0.643746757381..0.656221205556]
# mask_overlap = [-3.77475828373e-15..0.0124744481747]
# t0 = [0.0..0.0124744481747]
# f_domain = [-2.49427537089..2.85962705311]
# detect_roots(T0=[0.0..0.0124744481747], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0124744481747]
# M = [0.00623722408737..0.00623722408737]
# fI = [-0.0456445806002..0.405018062692]
# Tfinal = [-0.0..0.0124744481747]
# root on boundary!
# merging intervals:
# [-0.0..0.643746757381]
# [0.643746757381..0.656221205556]
# ===
# reached detect roots t=[0.656221205556..0.656221205556] + [0.0..0.0137218929922]
# using mask!
# mask_overlap = [0.656221205556..0.669943098548]
# mask_overlap = [-3.99680288865e-15..0.0137218929922]
# t0 = [0.0..0.0137218929922]
# f_domain = [-2.49130519468..2.86142041802]
# detect_roots(T0=[0.0..0.0137218929922], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0137218929922]
# M = [0.00686094649611..0.00686094649611]
# fI = [-0.0430523435824..0.406946699732]
# Tfinal = [-0.0..0.0137218929922]
# root on boundary!
# merging intervals:
# [-0.0..0.656221205556]
# [0.656221205556..0.669943098548]
# ===
# reached detect roots t=[0.669943098548..0.669943098548] + [0.0..0.0150940822914]
# using mask!
# mask_overlap = [0.669943098548..0.68503718084]
# mask_overlap = [-4.21884749358e-15..0.0150940822914]
# t0 = [0.0..0.0150940822914]
# f_domain = [-2.48672388751..2.8618304433]
# detect_roots(T0=[0.0..0.0150940822914], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0150940822914]
# M = [0.00754704114572..0.00754704114572]
# fI = [-0.0401729185262..0.408778263912]
# Tfinal = [-0.0..0.0150940822914]
# root on boundary!
# merging intervals:
# [-0.0..0.669943098548]
# [0.669943098548..0.68503718084]
# ===
# reached detect roots t=[0.68503718084..0.68503718084] + [0.0..0.0166034905206]
# using mask!
# mask_overlap = [0.68503718084..0.70164067136]
# mask_overlap = [-4.4408920985e-15..0.0166034905206]
# t0 = [0.0..0.0166034905206]
# f_domain = [-2.47380415214..2.85409700895]
# detect_roots(T0=[0.0..0.0166034905206], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0166034905206]
# M = [0.00830174526029..0.00830174526029]
# fI = [-0.036984878372..0.410457946531]
# Tfinal = [-0.0..0.0166034905206]
# root on boundary!
# merging intervals:
# [-0.0..0.68503718084]
# [0.68503718084..0.70164067136]
# ===
# reached detect roots t=[0.70164067136..0.70164067136] + [0.0..0.0182638395726]
# using mask!
# mask_overlap = [0.70164067136..0.719904510933]
# mask_overlap = [-4.66293670343e-15..0.0182638395726]
# t0 = [0.0..0.0182638395726]
# f_domain = [-2.45149701606..2.83713092151]
# detect_roots(T0=[0.0..0.0182638395726], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0182638395726]
# M = [0.00913191978632..0.00913191978632]
# fI = [-0.0335861980084..0.412024274159]
# Tfinal = [-0.0..0.0182638395726]
# root on boundary!
# merging intervals:
# [-0.0..0.70164067136]
# [0.70164067136..0.719904510933]
# ===
# reached detect roots t=[0.719904510933..0.719904510933] + [0.0..0.0200902235299]
# using mask!
# mask_overlap = [0.719904510933..0.739994734463]
# mask_overlap = [-4.88498130835e-15..0.0200902235299]
# t0 = [0.0..0.0200902235299]
# f_domain = [-2.41943283504..2.81059764482]
# detect_roots(T0=[0.0..0.0200902235299], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0200902235299]
# M = [0.010045111765..0.010045111765]
# fI = [-0.0300259807467..0.413474609568]
# Tfinal = [-0.0..0.0200902235299]
# root on boundary!
# merging intervals:
# [-0.0..0.719904510933]
# [0.719904510933..0.739994734463]
# ===
# reached detect roots t=[0.739994734463..0.739994734463] + [0.0..0.0220992458829]
# using mask!
# mask_overlap = [0.739994734463..0.762093980346]
# mask_overlap = [-5.10702591328e-15..0.0220992458829]
# t0 = [0.0..0.0220992458829]
# f_domain = [-2.37186213609..2.76858848924]
# detect_roots(T0=[0.0..0.0220992458829], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0220992458829]
# M = [0.0110496229414..0.0110496229414]
# fI = [-0.0260935079332..0.414511085592]
# Tfinal = [-0.0..0.0220992458829]
# root on boundary!
# merging intervals:
# [-0.0..0.739994734463]
# [0.739994734463..0.762093980346]
# ===
# reached detect roots t=[0.762093980346..0.762093980346] + [0.0..0.0243091704712]
# using mask!
# mask_overlap = [0.762093980346..0.786403150817]
# mask_overlap = [-5.3290705182e-15..0.0243091704712]
# t0 = [0.0..0.0243091704712]
# f_domain = [-2.30596531522..2.70818542145]
# detect_roots(T0=[0.0..0.0243091704712], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0243091704712]
# M = [0.0121545852356..0.0121545852356]
# fI = [-0.0217362738611..0.414976680161]
# Tfinal = [-0.0..0.0243091704712]
# root on boundary!
# merging intervals:
# [-0.0..0.762093980346]
# [0.762093980346..0.786403150817]
# ===
# reached detect roots t=[0.786403150817..0.786403150817] + [0.0..0.0133700437592]
# using mask!
# mask_overlap = [0.786403150817..0.799773194576]
# mask_overlap = [-5.44009282066e-15..0.0133700437592]
# t0 = [0.0..0.0133700437592]
# f_domain = [-2.23575588049..2.64326459718]
# detect_roots(T0=[0.0..0.0133700437592], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0133700437592]
# M = [0.00668502187958..0.00668502187958]
# fI = [-0.0158787269876..0.412560165407]
# Tfinal = [-0.0..0.0133700437592]
# root on boundary!
# merging intervals:
# [-0.0..0.786403150817]
# [0.786403150817..0.799773194576]
# ===
# reached detect roots t=[0.799773194576..0.799773194576] + [0.0..0.0147070481351]
# using mask!
# mask_overlap = [0.799773194576..0.814480242711]
# mask_overlap = [-5.66213742559e-15..0.0147070481351]
# t0 = [0.0..0.0147070481351]
# f_domain = [-2.19307145276..2.60304062469]
# detect_roots(T0=[0.0..0.0147070481351], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0147070481351]
# M = [0.00735352406753..0.00735352406753]
# fI = [-0.0131861127808..0.412153241567]
# Tfinal = [-0.0..0.0147070481351]
# root on boundary!
# merging intervals:
# [-0.0..0.799773194576]
# [0.799773194576..0.814480242711]
# ===
# reached detect roots t=[0.814480242711..0.814480242711] + [0.0..0.0161777529486]
# using mask!
# mask_overlap = [0.814480242711..0.83065799566]
# mask_overlap = [-5.88418203051e-15..0.0161777529486]
# t0 = [0.0..0.0161777529486]
# f_domain = [-2.14157500797..2.55401867486]
# detect_roots(T0=[0.0..0.0161777529486], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0161777529486]
# M = [0.00808887647429..0.00808887647429]
# fI = [-0.0102298576815..0.411443063066]
# Tfinal = [-0.0..0.0161777529486]
# root on boundary!
# merging intervals:
# [-0.0..0.814480242711]
# [0.814480242711..0.83065799566]
# ===
# reached detect roots t=[0.83065799566..0.83065799566] + [0.0..0.0177955282434]
# using mask!
# mask_overlap = [0.83065799566..0.848453523903]
# mask_overlap = [-6.10622663544e-15..0.0177955282434]
# t0 = [0.0..0.0177955282434]
# f_domain = [-2.08015551061..2.49502775824]
# detect_roots(T0=[0.0..0.0177955282434], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0177955282434]
# M = [0.00889776412172..0.00889776412172]
# fI = [-0.00698726010394..0.410355511432]
# Tfinal = [-0.0..0.0177955282434]
# root on boundary!
# merging intervals:
# [-0.0..0.83065799566]
# [0.83065799566..0.848453523903]
# ===
# reached detect roots t=[0.848453523903..0.848453523903] + [0.0..0.0195750810678]
# using mask!
# mask_overlap = [0.848453523903..0.868028604971]
# mask_overlap = [-6.32827124036e-15..0.0195750810678]
# t0 = [0.0..0.0195750810678]
# f_domain = [-2.00764676..2.42484460696]
# detect_roots(T0=[0.0..0.0195750810678], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0195750810678]
# M = [0.00978754053389..0.00978754053389]
# fI = [-0.00345740565564..0.408823654884]
# Tfinal = [-0.0..0.0195750810678]
# root on boundary!
# merging intervals:
# [-0.0..0.848453523903]
# [0.848453523903..0.868028604971]
# ===
# reached detect roots t=[0.868028604971..0.868028604971] + [0.0..0.0215325891746]
# using mask!
# mask_overlap = [0.868028604971..0.889561194145]
# mask_overlap = [-6.55031584529e-15..0.0215325891746]
# t0 = [0.0..0.0215325891746]
# f_domain = [-1.92302395233..2.34237039883]
# detect_roots(T0=[0.0..0.0215325891746], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0215325891746]
# M = [0.0107662945873..0.0107662945873]
# fI = [0.000370418810894..0.406761806117]
# Tfinal = [-0.0..0.00934642987349]
# splitting! [0.0..0.0215325891746] -> [-0.0..0.00934642987349] + [0.0126426268082..0.0215325891746]
# detect_roots(T0=[-0.0..0.00934642987349], epsilon=1e-05, verbosity=10)
# T = [-0.0..0.00934642987349]
# M = [0.00467321493674..0.00467321493674]
# fI = [0.0014860889086..0.405174253963]
# failed! on:
# M=[0.00467321493674..0.00467321493674]
# extdiv(T=[-0.00467321493674..0.00467321493674], Tu=[0.0..0.0], split=False, T=[-0.00467321493674..0.00467321493674], fI=[0.0014860889086..0.405174253963], fP=[-0.184773551922..0.260883172387])
# detect_roots(T0=[0.0126426268082..0.0215325891746], epsilon=1e-05, verbosity=10)
# T = [0.0126426268082..0.0215325891746]
# M = [0.0170876079914..0.0170876079914]
# fI = [-0.000827487692274..0.408408010169]
# Tfinal = [0.0126426268082..0.0215325891746]
# root on boundary!
# new root:
# [0.880671231779..0.889561194145]
# ===
# reached detect roots t=[0.889561194145..0.889561194145] + [0.0..0.023685848092]
# using mask!
# mask_overlap = [0.889561194145..0.913247042237]
# mask_overlap = [-6.77236045021e-15..0.023685848092]
# t0 = [0.0..0.023685848092]
# f_domain = [-1.82530575674..2.24653848948]
# detect_roots(T0=[0.0..0.023685848092], epsilon=1e-05, verbosity=10)
# T = [0.0..0.023685848092]
# M = [0.011842924046..0.011842924046]
# fI = [0.0044781131636..0.404084949648]
# failed! on:
# M=[0.011842924046..0.011842924046]
# extdiv(T=[-0.011842924046..0.011842924046], Tu=[0.0..0.0], split=False, T=[-0.011842924046..0.011842924046], fI=[0.0044781131636..0.404084949648], fP=[-0.214718807327..0.254413780625])
# ===
# reached detect roots t=[0.913247042237..0.913247042237] + [0.0..0.0260544329012]
# using mask!
# mask_overlap = [0.913247042237..0.939301475139]
# mask_overlap = [-6.99440505514e-15..0.0260544329012]
# t0 = [0.0..0.0260544329012]
# f_domain = [-1.71369264965..2.13643575194]
# detect_roots(T0=[0.0..0.0260544329012], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0260544329012]
# M = [0.0130272164506..0.0130272164506]
# fI = [0.0089421546311..0.400594265379]
# failed! on:
# M=[0.0130272164506..0.0130272164506]
# extdiv(T=[-0.0130272164506..0.0130272164506], Tu=[0.0..0.0], split=False, T=[-0.0130272164506..0.0130272164506], fI=[0.0089421546311..0.400594265379], fP=[-0.231524259101..0.246314616169])
# ===
# reached detect roots t=[0.939301475139..0.939301475139] + [0.0..0.0286598761913]
# using mask!
# mask_overlap = [0.939301475139..0.96796135133]
# mask_overlap = [-7.21644966006e-15..0.0286598761913]
# t0 = [0.0..0.0286598761913]
# f_domain = [-1.58865231752..2.01242302266]
# detect_roots(T0=[0.0..0.0286598761913], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0286598761913]
# M = [0.0143299380957..0.0143299380957]
# fI = [0.0137543910796..0.396162774862]
# failed! on:
# M=[0.0143299380957..0.0143299380957]
# extdiv(T=[-0.0143299380957..0.0143299380957], Tu=[0.0..0.0], split=False, T=[-0.0143299380957..0.0143299380957], fI=[0.0137543910796..0.396162774862], fP=[-0.247982170555..0.236335139049])
# ===
# reached detect roots t=[0.96796135133..0.96796135133] + [0.0..0.0157629319052]
# using mask!
# mask_overlap = [0.96796135133..0.983724283235]
# mask_overlap = [-7.43849426499e-15..0.0157629319052]
# t0 = [0.0..0.0157629319052]
# f_domain = [-1.48365377725..1.91065787979]
# skipping given consistent value over domain
# ===
# reached detect roots t=[0.983724283235..0.983724283235] + [0.0..0.0173392250958]
# using mask!
# mask_overlap = [0.983724283235..1.00106350833]
# mask_overlap = [-7.66053886991e-15..0.0173392250958]
# t0 = [0.0..0.0173392250958]
# f_domain = [-1.45524432899..1.88209832672]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.00106350833..1.00106350833] + [0.0..0.0190731476053]
# using mask!
# mask_overlap = [1.00106350833..1.02013665594]
# mask_overlap = [-7.9936057773e-15..0.0190731476053]
# t0 = [0.0..0.0190731476053]
# f_domain = [-1.42688919858..1.85323787845]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.02013665594..1.02013665594] + [0.0..0.0209804623659]
# using mask!
# mask_overlap = [1.02013665594..1.0411171183]
# mask_overlap = [-8.43769498715e-15..0.0209804623659]
# t0 = [0.0..0.0209804623659]
# f_domain = [-1.40273567574..1.82829451707]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.0411171183..1.0411171183] + [0.0..0.0230785086025]
# using mask!
# mask_overlap = [1.0411171183..1.0641956269]
# mask_overlap = [-8.881784197e-15..0.0230785086025]
# t0 = [0.0..0.0230785086025]
# f_domain = [-1.37968936198..1.80401459332]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.0641956269..1.0641956269] + [0.0..0.0253863594627]
# using mask!
# mask_overlap = [1.0641956269..1.08958198637]
# mask_overlap = [-9.32587340685e-15..0.0253863594627]
# t0 = [0.0..0.0253863594627]
# f_domain = [-1.34876823055..1.7713186804]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.08958198637..1.08958198637] + [0.0..0.027924995409]
# using mask!
# mask_overlap = [1.08958198637..1.11750698178]
# mask_overlap = [-9.7699626167e-15..0.027924995409]
# t0 = [0.0..0.027924995409]
# f_domain = [-1.30983742012..1.72992745394]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.11750698178..1.11750698178] + [0.0..0.0307174949499]
# using mask!
# mask_overlap = [1.11750698178..1.14822447673]
# mask_overlap = [-1.02140518266e-14..0.0307174949499]
# t0 = [0.0..0.0307174949499]
# f_domain = [-1.26532912231..1.68216058693]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.14822447673..1.14822447673] + [0.0..0.0337892444448]
# using mask!
# mask_overlap = [1.14822447673..1.18201372117]
# mask_overlap = [-1.06581410364e-14..0.0337892444449]
# t0 = [0.0..0.0337892444448]
# f_domain = [-1.21556712882..1.62813190988]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.18201372117..1.18201372117] + [0.0..0.0185840844447]
# using mask!
# mask_overlap = [1.18201372117..1.20059780562]
# mask_overlap = [-1.11022302463e-14..0.0185840844447]
# t0 = [0.0..0.0185840844447]
# f_domain = [-1.15577088627..1.56291055842]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.20059780562..1.20059780562] + [0.0..0.0204424928891]
# using mask!
# mask_overlap = [1.20059780562..1.2210402985]
# mask_overlap = [-1.15463194561e-14..0.0204424928891]
# t0 = [0.0..0.0204424928891]
# f_domain = [-1.12163576293..1.52558075016]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.2210402985..1.2210402985] + [0.0..0.022486742178]
# using mask!
# mask_overlap = [1.2210402985..1.24352704068]
# mask_overlap = [-1.1990408666e-14..0.0224867421781]
# t0 = [0.0..0.022486742178]
# f_domain = [-1.08347783487..1.48370625531]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.24352704068..1.24352704068] + [0.0..0.0247354163959]
# using mask!
# mask_overlap = [1.24352704068..1.26826245708]
# mask_overlap = [-1.24344978758e-14..0.0247354163959]
# t0 = [0.0..0.0247354163959]
# f_domain = [-1.0409647509..1.43677346317]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.26826245708..1.26826245708] + [0.0..0.0272089580354]
# using mask!
# mask_overlap = [1.26826245708..1.29547141511]
# mask_overlap = [-1.26565424807e-14..0.0272089580354]
# t0 = [0.0..0.0272089580354]
# f_domain = [-0.993951498752..1.38461340687]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.29547141511..1.29547141511] + [0.0..0.029929853839]
# using mask!
# mask_overlap = [1.29547141511..1.32540126895]
# mask_overlap = [-1.31006316906e-14..0.029929853839]
# t0 = [0.0..0.029929853839]
# f_domain = [-0.942371357266..1.32708011759]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.32540126895..1.32540126895] + [0.0..0.0329228392229]
# using mask!
# mask_overlap = [1.32540126895..1.35832410818]
# mask_overlap = [-1.35447209004e-14..0.0329228392229]
# t0 = [0.0..0.0329228392229]
# f_domain = [-0.890501515919..1.26840978633]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.35832410818..1.35832410818] + [0.0..0.0362151231452]
# using mask!
# mask_overlap = [1.35832410818..1.39453923132]
# mask_overlap = [-1.39888101103e-14..0.0362151231452]
# t0 = [0.0..0.0362151231452]
# f_domain = [-0.838968774208..1.20900701091]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.39453923132..1.39453923132] + [0.0..0.0398366354597]
# using mask!
# mask_overlap = [1.39453923132..1.43437586678]
# mask_overlap = [-1.44328993201e-14..0.0398366354597]
# t0 = [0.0..0.0398366354597]
# f_domain = [-0.782941620074..1.14400033487]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.43437586678..1.43437586678] + [0.0..0.0438202990057]
# using mask!
# mask_overlap = [1.43437586678..1.47819616579]
# mask_overlap = [-1.487698853e-14..0.0438202990057]
# t0 = [0.0..0.0438202990057]
# f_domain = [-0.723653903771..1.07445662499]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.47819616579..1.47819616579] + [0.0..0.0241011644531]
# using mask!
# mask_overlap = [1.47819616579..1.50229733024]
# mask_overlap = [-1.53210777398e-14..0.0241011644531]
# t0 = [0.0..0.0241011644531]
# f_domain = [-0.663179231272..1.00232329022]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.50229733024..1.50229733024] + [0.0..0.0265112808984]
# using mask!
# mask_overlap = [1.50229733024..1.52880861114]
# mask_overlap = [-1.57651669497e-14..0.0265112808984]
# t0 = [0.0..0.0265112808984]
# f_domain = [-0.6314785997..0.964096408902]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.52880861114..1.52880861114] + [0.0..0.0291624089883]
# using mask!
# mask_overlap = [1.52880861114..1.55797102013]
# mask_overlap = [-1.62092561595e-14..0.0291624089883]
# t0 = [0.0..0.0291624089883]
# f_domain = [-0.597940607955..0.923286948024]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.55797102013..1.55797102013] + [0.0..0.0320786498871]
# using mask!
# mask_overlap = [1.55797102013..1.59004967001]
# mask_overlap = [-1.66533453694e-14..0.0320786498871]
# t0 = [0.0..0.0320786498871]
# f_domain = [-0.562833629426..0.880051651005]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.59004967001..1.59004967001] + [0.0..0.0352865148758]
# using mask!
# mask_overlap = [1.59004967001..1.62533618489]
# mask_overlap = [-1.70974345792e-14..0.0352865148758]
# t0 = [0.0..0.0352865148758]
# f_domain = [-0.526278978964..0.834468166796]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.62533618489..1.62533618489] + [0.0..0.0388151663634]
# using mask!
# mask_overlap = [1.62533618489..1.66415135125]
# mask_overlap = [-1.75415237891e-14..0.0388151663634]
# t0 = [0.0..0.0388151663634]
# f_domain = [-0.488701097088..0.786879373201]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.66415135125..1.66415135125] + [0.0..0.0426966829997]
# using mask!
# mask_overlap = [1.66415135125..1.70684803425]
# mask_overlap = [-1.79856129989e-14..0.0426966829997]
# t0 = [0.0..0.0426966829997]
# f_domain = [-0.45256912698..0.739674001469]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.70684803425..1.70684803425] + [0.0..0.0469663512997]
# using mask!
# mask_overlap = [1.70684803425..1.75381438555]
# mask_overlap = [-1.84297022088e-14..0.0469663512997]
# t0 = [0.0..0.0469663512997]
# f_domain = [-0.42173482864..0.69662662446]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.75381438555..1.75381438555] + [0.0..0.0516629864297]
# using mask!
# mask_overlap = [1.75381438555..1.80547737198]
# mask_overlap = [-1.88737914186e-14..0.0516629864297]
# t0 = [0.0..0.0516629864297]
# f_domain = [-0.400042675049..0.661506540726]
# detect_roots(T0=[0.0..0.0516629864297], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0516629864297]
# M = [0.0258314932148..0.0258314932148]
# fI = [0.0470561097116..0.197384439239]
# failed! on:
# M=[0.0258314932148..0.0258314932148]
# extdiv(T=[-0.0258314932148..0.0258314932148], Tu=[-0.0258314932148..0.0258314932148], split=False, T=[-0.0258314932148..0.0258314932148], fI=[0.0470561097116..0.197384439239], fP=[-0.255894824826..-0.0161943243669])
# ===
# reached detect roots t=[1.80547737198..1.80547737198] + [0.0..0.0568292850726]
# using mask!
# mask_overlap = [1.80547737198..1.86230665705]
# mask_overlap = [-1.93178806285e-14..0.0568292850726]
# t0 = [0.0..0.0568292850726]
# f_domain = [-0.381095079713..0.627814449602]
# detect_roots(T0=[0.0..0.0568292850726], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0568292850726]
# M = [0.0284146425363..0.0284146425363]
# fI = [0.0448080195102..0.1848753656]
# failed! on:
# M=[0.0284146425363..0.0284146425363]
# extdiv(T=[-0.0284146425363..0.0284146425363], Tu=[-0.0284146425363..0.0284146425363], split=False, T=[-0.0284146425363..0.0284146425363], fI=[0.0448080195102..0.1848753656], fP=[-0.247461332162..-0.0224264709715])
# ===
# reached detect roots t=[1.86230665705..1.86230665705] + [0.0..0.0625122135799]
# using mask!
# mask_overlap = [1.86230665705..1.92481887063]
# mask_overlap = [-1.97619698383e-14..0.0625122135799]
# t0 = [0.0..0.0625122135799]
# f_domain = [-0.362358932189..0.592990512991]
# detect_roots(T0=[0.0..0.0625122135799], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0625122135799]
# M = [0.0312561067899..0.0312561067899]
# fI = [0.0418442936539..0.171746363415]
# failed! on:
# M=[0.0312561067899..0.0312561067899]
# extdiv(T=[-0.0312561067899..0.0312561067899], Tu=[-0.0312561067899..0.0312561067899], split=False, T=[-0.0312561067899..0.0312561067899], fI=[0.0418442936539..0.171746363415], fP=[-0.237908963416..-0.0285083064117])
# ===
# reached detect roots t=[1.92481887063..1.92481887063] + [0.0..0.0343817174689]
# using mask!
# mask_overlap = [1.92481887063..1.9592005881]
# mask_overlap = [-2.02060590482e-14..0.034381717469]
# t0 = [0.0..0.0343817174689]
# f_domain = [-0.34342924996..0.556582752274]
# detect_roots(T0=[0.0..0.0343817174689], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0343817174689]
# M = [0.0171908587345..0.0171908587345]
# fI = [0.0421841492155..0.158486466869]
# failed! on:
# M=[0.0171908587345..0.0171908587345]
# extdiv(T=[-0.0171908587345..0.0171908587345], Tu=[-0.0171908587345..0.0171908587345], split=False, T=[-0.0171908587345..0.0171908587345], fI=[0.0421841492155..0.158486466869], fP=[-0.223864234186..-0.0402151419481])
# ===
# reached detect roots t=[1.9592005881..1.9592005881] + [0.0..0.0378198892158]
# using mask!
# mask_overlap = [1.9592005881..1.99702047732]
# mask_overlap = [-2.0650148258e-14..0.0378198892158]
# t0 = [0.0..0.0378198892158]
# f_domain = [-0.333899995515..0.537576711198]
# detect_roots(T0=[0.0..0.0378198892158], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0378198892158]
# M = [0.0189099446079..0.0189099446079]
# fI = [0.0400958734684..0.151047452686]
# failed! on:
# M=[0.0189099446079..0.0189099446079]
# extdiv(T=[-0.0189099446079..0.0189099446079], Tu=[-0.0189099446079..0.0189099446079], split=False, T=[-0.0189099446079..0.0189099446079], fI=[0.0400958734684..0.151047452686], fP=[-0.218508220947..-0.0427702758346])
# ===
# reached detect roots t=[1.99702047732..1.99702047732] + [0.0..0.0416018781374]
# using mask!
# mask_overlap = [1.99702047732..2.03862235546]
# mask_overlap = [-2.10942374679e-14..0.0416018781374]
# t0 = [0.0..0.0416018781374]
# f_domain = [-0.324018746332..0.517382827135]
# detect_roots(T0=[0.0..0.0416018781374], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0416018781374]
# M = [0.0208009390687..0.0208009390687]
# fI = [0.0377343701391..0.143040379571]
# failed! on:
# M=[0.0208009390687..0.0208009390687]
# extdiv(T=[-0.0208009390687..0.0208009390687], Tu=[-0.0208009390687..0.0208009390687], split=False, T=[-0.0208009390687..0.0208009390687], fI=[0.0377343701391..0.143040379571], fP=[-0.212636574668..-0.045271021846])
# ===
# reached detect roots t=[2.03862235546..2.03862235546] + [0.0..0.0457620659512]
# using mask!
# mask_overlap = [2.03862235546..2.08438442141]
# mask_overlap = [-2.17603712827e-14..0.0457620659512]
# t0 = [0.0..0.0457620659512]
# f_domain = [-0.313910964463..0.496076327595]
# detect_roots(T0=[0.0..0.0457620659512], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0457620659512]
# M = [0.0228810329756..0.0228810329756]
# fI = [0.0350340408197..0.134483439458]
# failed! on:
# M=[0.0228810329756..0.0228810329756]
# extdiv(T=[-0.0228810329756..0.0228810329756], Tu=[-0.0228810329756..0.0228810329756], split=False, T=[-0.0228810329756..0.0228810329756], fI=[0.0350340408197..0.134483439458], fP=[-0.206559677557..-0.0473488882379])
# ===
# reached detect roots t=[2.08438442141..2.08438442141] + [0.0..0.0503382725463]
# using mask!
# mask_overlap = [2.08438442141..2.13472269395]
# mask_overlap = [-2.26485497024e-14..0.0503382725463]
# t0 = [0.0..0.0503382725463]
# f_domain = [-0.303605450434..0.473642473019]
# detect_roots(T0=[0.0..0.0503382725463], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0503382725463]
# M = [0.0251691362731..0.0251691362731]
# fI = [0.0319957134054..0.125331736988]
# failed! on:
# M=[0.0251691362731..0.0251691362731]
# extdiv(T=[-0.0251691362731..0.0251691362731], Tu=[-0.0251691362731..0.0251691362731], split=False, T=[-0.0251691362731..0.0251691362731], fI=[0.0319957134054..0.125331736988], fP=[-0.199952421031..-0.049274775665])
# ===
# reached detect roots t=[2.13472269395..2.13472269395] + [0.0..0.0553720998009]
# using mask!
# mask_overlap = [2.13472269395..2.19009479375]
# mask_overlap = [-2.35367281221e-14..0.0553720998009]
# t0 = [0.0..0.0553720998009]
# f_domain = [-0.293199902453..0.45013918412]
# detect_roots(T0=[0.0..0.0553720998009], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0553720998009]
# M = [0.0276860499004..0.0276860499004]
# fI = [0.0285947836788..0.115572470613]
# failed! on:
# M=[0.0276860499004..0.0276860499004]
# extdiv(T=[-0.0276860499004..0.0276860499004], Tu=[-0.0276860499004..0.0276860499004], split=False, T=[-0.0276860499004..0.0276860499004], fI=[0.0285947836788..0.115572470613], fP=[-0.192735724712..-0.0510622995653])
# ===
# reached detect roots t=[2.19009479375..2.19009479375] + [0.0..0.060909309781]
# using mask!
# mask_overlap = [2.19009479375..2.25100410354]
# mask_overlap = [-2.44249065418e-14..0.060909309781]
# t0 = [0.0..0.060909309781]
# f_domain = [-0.28547133467..0.428310459649]
# detect_roots(T0=[0.0..0.060909309781], epsilon=1e-05, verbosity=10)
# T = [0.0..0.060909309781]
# M = [0.0304546548905..0.0304546548905]
# fI = [0.0236396417539..0.106367972853]
# failed! on:
# M=[0.0304546548905..0.0304546548905]
# extdiv(T=[-0.0304546548905..0.0304546548905], Tu=[-0.0304546548905..0.0304546548905], split=False, T=[-0.0304546548905..0.0304546548905], fI=[0.0236396417539..0.106367972853], fP=[-0.184894162012..-0.0526818230246])
# ===
# reached detect roots t=[2.25100410354..2.25100410354] + [0.0..0.0670002407591]
# using mask!
# mask_overlap = [2.25100410354..2.31800434429]
# mask_overlap = [-2.53130849615e-14..0.0670002407591]
# t0 = [0.0..0.0670002407591]
# f_domain = [-0.279638333545..0.407378013232]
# detect_roots(T0=[0.0..0.0670002407591], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0670002407591]
# M = [0.0335001203795..0.0335001203795]
# fI = [0.017422433272..0.0974166228351]
# failed! on:
# M=[0.0335001203795..0.0335001203795]
# extdiv(T=[-0.0335001203795..0.0335001203795], Tu=[-0.0335001203795..0.0335001203795], split=False, T=[-0.0335001203795..0.0335001203795], fI=[0.017422433272..0.0974166228351], fP=[-0.176438224264..-0.0540907838419])
# ===
# reached detect roots t=[2.31800434429..2.31800434429] + [0.0..0.073700264835]
# using mask!
# mask_overlap = [2.31800434429..2.39170460913]
# mask_overlap = [-2.62012633812e-14..0.073700264835]
# t0 = [0.0..0.073700264835]
# f_domain = [-0.273625948522..0.385223159283]
# detect_roots(T0=[0.0..0.073700264835], epsilon=1e-05, verbosity=10)
# T = [0.0..0.073700264835]
# M = [0.0368501324175..0.0368501324175]
# fI = [0.0108546039895..0.0877914226596]
# failed! on:
# M=[0.0368501324175..0.0368501324175]
# extdiv(T=[-0.0368501324175..0.0368501324175], Tu=[-0.0368501324175..0.0368501324175], split=False, T=[-0.0368501324175..0.0368501324175], fI=[0.0108546039895..0.0877914226596], fP=[-0.167424246466..-0.05521358718])
# ===
# reached detect roots t=[2.39170460913..2.39170460913] + [0.0..0.0810702913185]
# using mask!
# mask_overlap = [2.39170460913..2.47277490045]
# mask_overlap = [-2.70894418009e-14..0.0810702913185]
# t0 = [0.0..0.0810702913185]
# f_domain = [-0.267992446161..0.362415634139]
# detect_roots(T0=[0.0..0.0810702913185], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0810702913185]
# M = [0.0405351456592..0.0405351456592]
# fI = [0.00394211822313..0.0775005780416]
# T = [0.0655047300898..0.0810702913185]
# M = [0.0732875107042..0.0732875107042]
# fI = [-0.00121399296942..0.0755666380757]
# Tfinal = [0.0655047300898..0.0810702913185]
# root on boundary!
# new root:
# [2.45720933922..2.47277490045]
# ===
# reached detect roots t=[2.47277490045..2.47277490045] + [0.0..0.0891773204503]
# using mask!
# mask_overlap = [2.47277490045..2.5619522209]
# mask_overlap = [-2.79776202206e-14..0.0891773204504]
# t0 = [0.0..0.0891773204503]
# f_domain = [-0.26610752324..0.342355121069]
# detect_roots(T0=[0.0..0.0891773204503], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0891773204503]
# M = [0.0445886602252..0.0445886602252]
# fI = [-0.00331815610588..0.0665785798239]
# Tfinal = [-0.0..0.0891773204503]
# root on boundary!
# merging intervals:
# [2.45720933922..2.47277490045]
# [2.47277490045..2.5619522209]
# ===
# reached detect roots t=[2.5619522209..2.5619522209] + [0.0..0.0980950524954]
# using mask!
# mask_overlap = [2.5619522209..2.66004727339]
# mask_overlap = [-2.88657986403e-14..0.0980950524954]
# t0 = [0.0..0.0980950524954]
# f_domain = [-0.265909776139..0.323031091447]
# detect_roots(T0=[0.0..0.0980950524954], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0980950524954]
# M = [0.0490475262477..0.0490475262477]
# fI = [-0.0111790627388..0.0553366569645]
# Tfinal = [-0.0..0.0980950524954]
# root on boundary!
# merging intervals:
# [2.45720933922..2.5619522209]
# [2.5619522209..2.66004727339]
# ===
# reached detect roots t=[2.66004727339..2.66004727339] + [0.0..0.0539522788725]
# using mask!
# mask_overlap = [2.66004727339..2.71399955227]
# mask_overlap = [-2.975397706e-14..0.0539522788725]
# t0 = [0.0..0.0539522788725]
# f_domain = [-0.264722971603..0.301849986189]
# detect_roots(T0=[0.0..0.0539522788725], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0539522788725]
# M = [0.0269761394362..0.0269761394362]
# fI = [-0.0158908437412..0.0452285759532]
# Tfinal = [-0.0..0.0539522788725]
# root on boundary!
# merging intervals:
# [2.45720933922..2.66004727339]
# [2.66004727339..2.71399955227]
# ===
# reached detect roots t=[2.71399955227..2.71399955227] + [0.0..0.0593475067597]
# using mask!
# mask_overlap = [2.71399955227..2.77334705903]
# mask_overlap = [-3.06421554797e-14..0.0593475067597]
# t0 = [0.0..0.0593475067597]
# f_domain = [-0.263697066547..0.290250536874]
# detect_roots(T0=[0.0..0.0593475067597], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0593475067597]
# M = [0.0296737533798..0.0296737533798]
# fI = [-0.0202979485449..0.0389699565682]
# Tfinal = [-0.0..0.0593475067597]
# root on boundary!
# merging intervals:
# [2.45720933922..2.71399955227]
# [2.71399955227..2.77334705903]
# ===
# reached detect roots t=[2.77334705903..2.77334705903] + [0.0..0.0652822574357]
# using mask!
# mask_overlap = [2.77334705903..2.83862931646]
# mask_overlap = [-3.15303338994e-14..0.0652822574357]
# t0 = [0.0..0.0652822574357]
# f_domain = [-0.262215846917..0.277534139041]
# detect_roots(T0=[0.0..0.0652822574357], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0652822574357]
# M = [0.0326411287178..0.0326411287178]
# fI = [-0.0249591416817..0.0322871253051]
# Tfinal = [-0.0..0.0652822574357]
# root on boundary!
# merging intervals:
# [2.45720933922..2.77334705903]
# [2.77334705903..2.83862931646]
# ===
# reached detect roots t=[2.83862931646..2.83862931646] + [0.0..0.0718104831792]
# using mask!
# mask_overlap = [2.83862931646..2.91043979964]
# mask_overlap = [-3.24185123191e-14..0.0718104831793]
# t0 = [0.0..0.0718104831792]
# f_domain = [-0.260300286365..0.263688460795]
# detect_roots(T0=[0.0..0.0718104831792], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0718104831792]
# M = [0.0359052415896..0.0359052415896]
# fI = [-0.0298829496617..0.0251793247621]
# Tfinal = [-0.0..0.0718104831792]
# root on boundary!
# merging intervals:
# [2.45720933922..2.83862931646]
# [2.83862931646..2.91043979964]
# ===
# reached detect roots t=[2.91043979964..2.91043979964] + [0.0..0.0789915314972]
# using mask!
# mask_overlap = [2.91043979964..2.98943133114]
# mask_overlap = [-3.33066907388e-14..0.0789915314972]
# t0 = [0.0..0.0789915314972]
# f_domain = [-0.257879622544..0.24868194988]
# detect_roots(T0=[0.0..0.0789915314972], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0789915314972]
# M = [0.0394957657486..0.0394957657486]
# fI = [-0.0350538243794..0.0176522808156]
# Tfinal = [-0.0..0.0789915314972]
# root on boundary!
# merging intervals:
# [2.45720933922..2.91043979964]
# [2.91043979964..2.98943133114]
# ===
# reached detect roots t=[2.98943133114..2.98943133114] + [0.0..0.0868906846469]
# using mask!
# mask_overlap = [2.98943133114..3.07632201578]
# mask_overlap = [-3.41948691585e-14..0.0868906846469]
# t0 = [0.0..0.0868906846469]
# f_domain = [-0.25498679977..0.232537333221]
# detect_roots(T0=[0.0..0.0868906846469], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0868906846469]
# M = [0.0434453423234..0.0434453423234]
# fI = [-0.0404770525871..0.00972482943239]
# Tfinal = [-0.0..0.0868906846469]
# root on boundary!
# merging intervals:
# [2.45720933922..2.98943133114]
# [2.98943133114..3.07632201578]
# ===
# reached detect roots t=[3.07632201578..3.07632201578] + [0.0..0.0955797531116]
# using mask!
# mask_overlap = [3.07632201578..3.1719017689]
# mask_overlap = [-3.50830475782e-14..0.0955797531116]
# t0 = [0.0..0.0955797531116]
# f_domain = [-0.251858886098..0.215524128658]
# detect_roots(T0=[0.0..0.0955797531116], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0955797531116]
# M = [0.0477898765558..0.0477898765558]
# fI = [-0.0462114041467..0.00149229286856]
# T = [-0.0..0.0760979286401]
# M = [0.03804896432..0.03804896432]
# fI = [-0.045304049664..0.00204159916599]
# T = [-0.0..0.0758000673842]
# M = [0.0379000336921..0.0379000336921]
# fI = [-0.0452901639218..0.00205004873573]
# Tfinal = [-0.0..0.0757927918473]
# root on boundary!
# merging intervals:
# [2.45720933922..3.07632201578]
# [3.07632201578..3.15211480763]
# ===
# reached detect roots t=[3.1719017689..3.1719017689] + [0.0..0.105137728423]
# using mask!
# mask_overlap = [3.1719017689..3.27703949732]
# mask_overlap = [-3.59712259979e-14..0.105137728423]
# t0 = [0.0..0.105137728423]
# f_domain = [-0.248813696207..0.198009908629]
# detect_roots(T0=[0.0..0.105137728423], epsilon=1e-05, verbosity=10)
# T = [0.0..0.105137728423]
# M = [0.0525688642114..0.0525688642114]
# fI = [-0.0521582139947..-0.00709246212011]
# failed! on:
# M=[0.0525688642114..0.0525688642114]
# extdiv(T=[-0.0525688642114..0.0525688642114], Tu=[-0.0525688642114..0.0525688642114], split=False, T=[-0.0525688642114..0.0525688642114], fI=[-0.0521582139947..-0.00709246212011], fP=[-0.0876113065523..-0.050666078554])
# ===
# reached detect roots t=[3.27703949732..3.27703949732] + [0.0..0.115651501265]
# using mask!
# mask_overlap = [3.27703949732..3.39269099858]
# mask_overlap = [-3.68594044176e-14..0.115651501265]
# t0 = [0.0..0.115651501265]
# f_domain = [-0.245202191902..0.179375624543]
# detect_roots(T0=[0.0..0.115651501265], epsilon=1e-05, verbosity=10)
# T = [0.0..0.115651501265]
# M = [0.0578257506325..0.0578257506325]
# fI = [-0.0583247503975..-0.0159638205368]
# failed! on:
# M=[0.0578257506325..0.0578257506325]
# extdiv(T=[-0.0578257506325..0.0578257506325], Tu=[-0.0578257506325..0.0578257506325], split=False, T=[-0.0578257506325..0.0578257506325], fI=[-0.0583247503975..-0.0159638205368], fP=[-0.0816867839907..-0.0478693702666])
# ===
# reached detect roots t=[3.39269099858..3.39269099858] + [0.0..0.127216651391]
# using mask!
# mask_overlap = [3.39269099858..3.51990764998]
# mask_overlap = [-3.77475828373e-14..0.127216651392]
# t0 = [0.0..0.127216651391]
# f_domain = [-0.24100068644..0.159707996541]
# detect_roots(T0=[0.0..0.127216651391], epsilon=1e-05, verbosity=10)
# T = [0.0..0.127216651391]
# M = [0.0636083256957..0.0636083256957]
# fI = [-0.0646596487263..-0.0250786762334]
# failed! on:
# M=[0.0636083256957..0.0636083256957]
# extdiv(T=[-0.0636083256957..0.0636083256957], Tu=[-0.0636083256957..0.0636083256957], split=False, T=[-0.0636083256957..0.0636083256957], fI=[-0.0646596487263..-0.0250786762334], fP=[-0.0761028266689..-0.0444706934198])
# ===
# reached detect roots t=[3.51990764998..3.51990764998] + [0.0..0.139938316531]
# using mask!
# mask_overlap = [3.51990764998..3.65984596651]
# mask_overlap = [-3.8635761257e-14..0.139938316531]
# t0 = [0.0..0.139938316531]
# f_domain = [-0.236274824363..0.139167975027]
# detect_roots(T0=[0.0..0.139938316531], epsilon=1e-05, verbosity=10)
# T = [0.0..0.139938316531]
# M = [0.0699691582653..0.0699691582653]
# fI = [-0.0711127131838..-0.034383552209]
# failed! on:
# M=[0.0699691582653..0.0699691582653]
# extdiv(T=[-0.0699691582653..0.0699691582653], Tu=[-0.0699691582653..0.0699691582653], split=False, T=[-0.0699691582653..0.0699691582653], fI=[-0.0711127131838..-0.034383552209], fP=[-0.0703640162717..-0.0409960915261])
# ===
# reached detect roots t=[3.65984596651..3.65984596651] + [0.0..0.153932148184]
# using mask!
# mask_overlap = [3.65984596651..3.81377811469]
# mask_overlap = [-3.95239396767e-14..0.153932148184]
# t0 = [0.0..0.153932148184]
# f_domain = [-0.231108940712..0.11795130964]
# skipping given consistent value over domain
# ===
# reached detect roots t=[3.81377811469..3.81377811469] + [0.0..0.084662681501]
# using mask!
# mask_overlap = [3.81377811469..3.89844079619]
# mask_overlap = [-4.04121180964e-14..0.0846626815011]
# t0 = [0.0..0.084662681501]
# f_domain = [-0.225280633161..0.0959626504618]
# skipping given consistent value over domain
# ===
# reached detect roots t=[3.89844079619..3.89844079619] + [0.0..0.0931289496511]
# using mask!
# mask_overlap = [3.89844079619..3.99156974584]
# mask_overlap = [-4.13002965161e-14..0.0931289496512]
# t0 = [0.0..0.0931289496511]
# f_domain = [-0.222258807745..0.0846470080435]
# skipping given consistent value over domain
# ===
# reached detect roots t=[3.99156974584..3.99156974584] + [0.0..0.102441844616]
# using mask!
# mask_overlap = [3.99156974584..4.09401159046]
# mask_overlap = [-4.21884749358e-14..0.102441844616]
# t0 = [0.0..0.102441844616]
# f_domain = [-0.219024498494..0.0727682446119]
# skipping given consistent value over domain
# ===
# reached detect roots t=[4.09401159046..4.09401159046] + [0.0..0.112686029078]
# using mask!
# mask_overlap = [4.09401159046..4.20669761954]
# mask_overlap = [-4.35207425653e-14..0.112686029078]
# t0 = [0.0..0.112686029078]
# f_domain = [-0.215600648024..0.0603805979662]
# skipping given consistent value over domain
# ===
# reached detect roots t=[4.20669761954..4.20669761954] + [0.0..0.123954631986]
# using mask!
# mask_overlap = [4.20669761954..4.33065225152]
# mask_overlap = [-4.52970994047e-14..0.123954631986]
# t0 = [0.0..0.123954631986]
# f_domain = [-0.211956642268..0.0475226714016]
# skipping given consistent value over domain
# ===
# reached detect roots t=[4.33065225152..4.33065225152] + [0.0..0.136350095184]
# using mask!
# mask_overlap = [4.33065225152..4.46700234671]
# mask_overlap = [-4.70734562441e-14..0.136350095184]
# t0 = [0.0..0.136350095184]
# f_domain = [-0.208178946068..0.0343047271815]
# skipping given consistent value over domain
# ===
# reached detect roots t=[4.46700234671..4.46700234671] + [0.0..0.149985104703]
# using mask!
# mask_overlap = [4.46700234671..4.61698745141]
# mask_overlap = [-4.88498130835e-14..0.149985104703]
# t0 = [0.0..0.149985104703]
# f_domain = [-0.204267325038..0.0207877810372]
# skipping given consistent value over domain
# ===
# reached detect roots t=[4.61698745141..4.61698745141] + [0.0..0.164983615173]
# using mask!
# mask_overlap = [4.61698745141..4.78197106658]
# mask_overlap = [-5.06261699229e-14..0.164983615173]
# t0 = [0.0..0.164983615173]
# f_domain = [-0.200253007771..0.00709726509599]
# skipping given consistent value over domain
# ===
# reached detect roots t=[4.78197106658..4.78197106658] + [0.0..0.18148197669]
# using mask!
# mask_overlap = [4.78197106658..4.96345304327]
# mask_overlap = [-5.24025267623e-14..0.18148197669]
# t0 = [0.0..0.18148197669]
# f_domain = [-0.196223961478..-0.00664977321004]
# skipping given consistent value over domain (unpreconditioned)
# ===
# reached detect roots t=[4.96345304327..4.96345304327] + [0.0..0.0375469567271]
# using mask!
# mask_overlap = [4.96345304327..5.0]
# mask_overlap = [-5.3290705182e-14..0.0365469567282]
# t0 = [0.0..0.0365469567282]
# f_domain = [-0.192157287152..-0.0203641608928]
# skipping given consistent value over domain (unpreconditioned)
# domain = [0.00000000000000000 .. 5.0000000000000000]
# roots = [[0.00000000000000000 .. 0.86802860497076651],
#  [0.88067123177899719 .. 0.88956119414532109],
#  [2.4572093392192906 .. 3.1521148076320591]]
# seg_domain = [0.00000000000000000 .. 5.0000000000000000]
# roots = [[0.00000000000000000 .. 0.86802860497076651],
#  [0.88067123177899719 .. 0.88956119414532109],
#  [2.4572093392192906 .. 3.1521148076320591]]
# Monitored signal 2.42904686928 sec
# Graphics object consisting of 2 graphics primitives

# %%
reach = Reach(vf, v3, 5, order=5, step=(0.01, 0.5),
              precondition=1,
              estimation=1e-3,
              integrationScheme=2,
              cutoff_threshold=1e-5,
              symbolic_composition=True,
              use_masks=True,
              verbosity=10)

# %%
observer = PolyObserver(x - 1.15, reach, reach.symbolic_composition,
                        tentative_unpreconditioning=True,
                        mask=None)
# Out:
# In prepare! flowpipes_compo.size() = 115

# %%
# %%time
observer.roots(verbosity=10)
# Out:
# ===
# reached detect roots t=[0.0..0.0] + [0.0..0.03125]
# not using mask!
# f_domain = [-1.60240505978..1.50240828693]
# detect_roots(T0=[0.0..0.03125], epsilon=1e-05, verbosity=10)
# T = [0.0..0.03125]
# M = [0.015625..0.015625]
# fI = [-0.147743741509..0.0613162002737]
# Tfinal = [-0.0..0.03125]
# root on boundary!
# new root:
# [-0.0..0.03125]
# ===
# reached detect roots t=[0.03125..0.03125] + [0.0..0.0171875]
# not using mask!
# f_domain = [-1.67261465507..1.59953266879]
# detect_roots(T0=[0.0..0.0171875], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0171875]
# M = [0.00859375..0.00859375]
# fI = [-0.144239307142..0.0789355872924]
# Tfinal = [-0.0..0.0171875]
# root on boundary!
# merging intervals:
# [-0.0..0.03125]
# [0.03125..0.0484375]
# ===
# reached detect roots t=[0.0484375..0.0484375] + [0.0..0.01890625]
# not using mask!
# f_domain = [-1.70731666121..1.64900974626]
# detect_roots(T0=[0.0..0.01890625], epsilon=1e-05, verbosity=10)
# T = [0.0..0.01890625]
# M = [0.009453125..0.009453125]
# fI = [-0.14167762036..0.0921588309592]
# Tfinal = [-0.0..0.01890625]
# root on boundary!
# merging intervals:
# [-0.0..0.0484375]
# [0.0484375..0.06734375]
# ===
# reached detect roots t=[0.06734375..0.06734375] + [0.0..0.020796875]
# not using mask!
# f_domain = [-1.74112706575..1.6990480621]
# detect_roots(T0=[0.0..0.020796875], epsilon=1e-05, verbosity=10)
# T = [0.0..0.020796875]
# M = [0.0103984375..0.0103984375]
# fI = [-0.13887430496..0.106741264325]
# Tfinal = [-0.0..0.020796875]
# root on boundary!
# merging intervals:
# [-0.0..0.06734375]
# [0.06734375..0.088140625]
# ===
# reached detect roots t=[0.088140625..0.088140625] + [0.0..0.0228765625]
# not using mask!
# f_domain = [-1.77840406729..1.7543098166]
# detect_roots(T0=[0.0..0.0228765625], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0228765625]
# M = [0.01143828125..0.01143828125]
# fI = [-0.135819508858..0.122794224006]
# Tfinal = [-0.0..0.0228765625]
# root on boundary!
# merging intervals:
# [-0.0..0.088140625]
# [0.088140625..0.1110171875]
# ===
# reached detect roots t=[0.1110171875..0.1110171875] + [0.0..0.02516421875]
# not using mask!
# f_domain = [-1.83866410322..1.83442935492]
# detect_roots(T0=[0.0..0.02516421875], epsilon=1e-05, verbosity=10)
# T = [0.0..0.02516421875]
# M = [0.012582109375..0.012582109375]
# fI = [-0.132482365607..0.140426291054]
# Tfinal = [-0.0..0.02516421875]
# root on boundary!
# merging intervals:
# [-0.0..0.1110171875]
# [0.1110171875..0.13618140625]
# ===
# reached detect roots t=[0.13618140625..0.13618140625] + [0.0..0.027680640625]
# not using mask!
# f_domain = [-1.89403412273..1.91154554154]
# detect_roots(T0=[0.0..0.027680640625], epsilon=1e-05, verbosity=10)
# T = [0.0..0.027680640625]
# M = [0.0138403203125..0.0138403203125]
# fI = [-0.128824579111..0.159718391739]
# Tfinal = [-0.0..0.027680640625]
# root on boundary!
# merging intervals:
# [-0.0..0.13618140625]
# [0.13618140625..0.163862046875]
# ===
# reached detect roots t=[0.163862046875..0.163862046875] + [0.0..0.0152243523438]
# not using mask!
# f_domain = [-1.99013701307..2.03154328946]
# detect_roots(T0=[0.0..0.0152243523438], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0152243523438]
# M = [0.00761217617188..0.00761217617188]
# fI = [-0.125766234125..0.175148837752]
# Tfinal = [-0.0..0.0152243523438]
# root on boundary!
# merging intervals:
# [-0.0..0.163862046875]
# [0.163862046875..0.179086399219]
# ===
# reached detect roots t=[0.179086399219..0.179086399219] + [0.0..0.0167467875781]
# not using mask!
# f_domain = [-2.05031198886..2.10478300026]
# detect_roots(T0=[0.0..0.0167467875781], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0167467875781]
# M = [0.00837339378906..0.00837339378906]
# fI = [-0.123506445563..0.186556857208]
# Tfinal = [-0.0..0.0167467875781]
# root on boundary!
# merging intervals:
# [-0.0..0.179086399219]
# [0.179086399219..0.195833186797]
# ===
# reached detect roots t=[0.195833186797..0.195833186797] + [0.0..0.0184214663359]
# not using mask!
# f_domain = [-2.1128348808..2.18159121746]
# detect_roots(T0=[0.0..0.0184214663359], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0184214663359]
# M = [0.00921073316797..0.00921073316797]
# fI = [-0.120993324572..0.198954864794]
# Tfinal = [-0.0..0.0184214663359]
# root on boundary!
# merging intervals:
# [-0.0..0.195833186797]
# [0.195833186797..0.214254653133]
# ===
# reached detect roots t=[0.214254653133..0.214254653133] + [0.0..0.0202636129695]
# not using mask!
# f_domain = [-2.17628060803..2.26062534507]
# detect_roots(T0=[0.0..0.0202636129695], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0202636129695]
# M = [0.0101318064848..0.0101318064848]
# fI = [-0.118190494576..0.212381065344]
# Tfinal = [-0.0..0.0202636129695]
# root on boundary!
# merging intervals:
# [-0.0..0.214254653133]
# [0.214254653133..0.234518266102]
# ===
# reached detect roots t=[0.234518266102..0.234518266102] + [0.0..0.0222899742665]
# not using mask!
# f_domain = [-2.25558673328..2.35687381015]
# detect_roots(T0=[0.0..0.0222899742665], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0222899742665]
# M = [0.0111449871332..0.0111449871332]
# fI = [-0.115040462591..0.226842223301]
# Tfinal = [-0.0..0.0222899742665]
# root on boundary!
# merging intervals:
# [-0.0..0.234518266102]
# [0.234518266102..0.256808240369]
# ===
# reached detect roots t=[0.256808240369..0.256808240369] + [0.0..0.0245189716931]
# not using mask!
# f_domain = [-2.36777221088..2.48742500994]
# detect_roots(T0=[0.0..0.0245189716931], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0245189716931]
# M = [0.0122594858466..0.0122594858466]
# fI = [-0.111677382921..0.242525951543]
# Tfinal = [-0.0..0.0245189716931]
# root on boundary!
# merging intervals:
# [-0.0..0.256808240369]
# [0.256808240369..0.281327212062]
# ===
# reached detect roots t=[0.281327212062..0.281327212062] + [0.0..0.0134854344312]
# not using mask!
# f_domain = [-2.48364596703..2.6231179424]
# detect_roots(T0=[0.0..0.0134854344312], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0134854344312]
# M = [0.00674271721561..0.00674271721561]
# fI = [-0.108828471981..0.254858052098]
# Tfinal = [-0.0..0.0134854344312]
# root on boundary!
# merging intervals:
# [-0.0..0.281327212062]
# [0.281327212062..0.294812646493]
# ===
# reached detect roots t=[0.294812646493..0.294812646493] + [0.0..0.0148339778743]
# not using mask!
# f_domain = [-2.54178280331..2.69196724745]
# detect_roots(T0=[0.0..0.0148339778743], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0148339778743]
# M = [0.00741698893717..0.00741698893717]
# fI = [-0.106761746898..0.263913645477]
# Tfinal = [-0.0..0.0148339778743]
# root on boundary!
# merging intervals:
# [-0.0..0.294812646493]
# [0.294812646493..0.309646624368]
# ===
# reached detect roots t=[0.309646624368..0.309646624368] + [0.0..0.0163173756618]
# not using mask!
# f_domain = [-2.60008628508..2.76188982667]
# detect_roots(T0=[0.0..0.0163173756618], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0163173756618]
# M = [0.00815868783089..0.00815868783089]
# fI = [-0.104434260773..0.273626661957]
# Tfinal = [-0.0..0.0163173756618]
# root on boundary!
# merging intervals:
# [-0.0..0.309646624368]
# [0.309646624368..0.325964000029]
# ===
# reached detect roots t=[0.325964000029..0.325964000029] + [0.0..0.017949113228]
# not using mask!
# f_domain = [-2.65694202098..2.83144403924]
# detect_roots(T0=[0.0..0.017949113228], epsilon=1e-05, verbosity=10)
# T = [0.0..0.017949113228]
# M = [0.00897455661398..0.00897455661398]
# fI = [-0.101823273572..0.284000624117]
# Tfinal = [-0.0..0.017949113228]
# root on boundary!
# merging intervals:
# [-0.0..0.325964000029]
# [0.325964000029..0.343913113257]
# ===
# reached detect roots t=[0.343913113257..0.343913113257] + [0.0..0.0197440245508]
# not using mask!
# f_domain = [-2.71044817315..2.89868260718]
# detect_roots(T0=[0.0..0.0197440245508], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0197440245508]
# M = [0.00987201227538..0.00987201227538]
# fI = [-0.098951681713..0.29508897145]
# Tfinal = [-0.0..0.0197440245508]
# root on boundary!
# merging intervals:
# [-0.0..0.343913113257]
# [0.343913113257..0.363657137808]
# ===
# reached detect roots t=[0.363657137808..0.363657137808] + [0.0..0.0217184270058]
# not using mask!
# f_domain = [-2.75306751724..2.95610025085]
# detect_roots(T0=[0.0..0.0217184270058], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0217184270058]
# M = [0.0108592135029..0.0108592135029]
# fI = [-0.0959190293876..0.306989217023]
# Tfinal = [-0.0..0.0217184270058]
# root on boundary!
# merging intervals:
# [-0.0..0.363657137808]
# [0.363657137808..0.385375564814]
# ===
# reached detect roots t=[0.385375564814..0.385375564814] + [0.0..0.0238902697064]
# not using mask!
# f_domain = [-2.77913452849..2.99804378604]
# detect_roots(T0=[0.0..0.0238902697064], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0238902697064]
# M = [0.0119451348532..0.0119451348532]
# fI = [-0.0924856266418..0.31945362119]
# Tfinal = [-0.0..0.0238902697064]
# root on boundary!
# merging intervals:
# [-0.0..0.385375564814]
# [0.385375564814..0.40926583452]
# ===
# reached detect roots t=[0.40926583452..0.40926583452] + [0.0..0.0131396483385]
# not using mask!
# f_domain = [-2.78557248013..3.02128078719]
# detect_roots(T0=[0.0..0.0131396483385], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0131396483385]
# M = [0.00656982416926..0.00656982416926]
# fI = [-0.0895002420264..0.328963948971]
# Tfinal = [-0.0..0.0131396483385]
# root on boundary!
# merging intervals:
# [-0.0..0.40926583452]
# [0.40926583452..0.422405482859]
# ===
# reached detect roots t=[0.422405482859..0.422405482859] + [0.0..0.0144536131724]
# not using mask!
# f_domain = [-2.78145111101..3.0262154172]
# detect_roots(T0=[0.0..0.0144536131724], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0144536131724]
# M = [0.00722680658619..0.00722680658619]
# fI = [-0.0873062928595..0.335808362685]
# Tfinal = [-0.0..0.0144536131724]
# root on boundary!
# merging intervals:
# [-0.0..0.422405482859]
# [0.422405482859..0.436859096031]
# ===
# reached detect roots t=[0.436859096031..0.436859096031] + [0.0..0.0158989744896]
# not using mask!
# f_domain = [-2.76860950634..3.02317182969]
# detect_roots(T0=[0.0..0.0158989744896], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0158989744896]
# M = [0.00794948724481..0.00794948724481]
# fI = [-0.0849163727023..0.343083603552]
# Tfinal = [-0.0..0.0158989744896]
# root on boundary!
# merging intervals:
# [-0.0..0.436859096031]
# [0.436859096031..0.452758070521]
# ===
# reached detect roots t=[0.452758070521..0.452758070521] + [0.0..0.0174888719386]
# not using mask!
# f_domain = [-2.74421266686..3.0092050142]
# detect_roots(T0=[0.0..0.0174888719386], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0174888719386]
# M = [0.00874443596929..0.00874443596929]
# fI = [-0.0822841664517..0.350760200687]
# Tfinal = [-0.0..0.0174888719386]
# root on boundary!
# merging intervals:
# [-0.0..0.452758070521]
# [0.452758070521..0.470246942459]
# ===
# reached detect roots t=[0.470246942459..0.470246942459] + [0.0..0.0192377591324]
# not using mask!
# f_domain = [-2.70483447726..2.98098586277]
# detect_roots(T0=[0.0..0.0192377591324], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0192377591324]
# M = [0.00961887956622..0.00961887956622]
# fI = [-0.0793004513599..0.358714772329]
# Tfinal = [-0.0..0.0192377591324]
# root on boundary!
# merging intervals:
# [-0.0..0.470246942459]
# [0.470246942459..0.489484701592]
# ===
# reached detect roots t=[0.489484701592..0.489484701592] + [0.0..0.0211615350457]
# not using mask!
# f_domain = [-2.67446909103..2.96247267456]
# detect_roots(T0=[0.0..0.0211615350457], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0211615350457]
# M = [0.0105807675228..0.0105807675228]
# fI = [-0.0759783894599..0.366923138227]
# Tfinal = [-0.0..0.0211615350457]
# root on boundary!
# merging intervals:
# [-0.0..0.489484701592]
# [0.489484701592..0.510646236637]
# ===
# reached detect roots t=[0.510646236637..0.510646236637] + [0.0..0.0116388442751]
# not using mask!
# f_domain = [-2.63532588018..2.93583737957]
# detect_roots(T0=[0.0..0.0116388442751], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0116388442751]
# M = [0.00581942213756..0.00581942213756]
# fI = [-0.0726857944278..0.372596406637]
# Tfinal = [-0.0..0.0116388442751]
# root on boundary!
# merging intervals:
# [-0.0..0.510646236637]
# [0.510646236637..0.522285080913]
# ===
# reached detect roots t=[0.522285080913..0.522285080913] + [0.0..0.0128027287026]
# not using mask!
# f_domain = [-2.60683249132..2.91398140478]
# detect_roots(T0=[0.0..0.0128027287026], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0128027287026]
# M = [0.00640136435132..0.00640136435132]
# fI = [-0.0705168113484..0.376874388138]
# Tfinal = [-0.0..0.0128027287026]
# root on boundary!
# merging intervals:
# [-0.0..0.522285080913]
# [0.522285080913..0.535087809615]
# ===
# reached detect roots t=[0.535087809615..0.535087809615] + [0.0..0.0140830015729]
# not using mask!
# f_domain = [-2.57005991338..2.88430790911]
# detect_roots(T0=[0.0..0.0140830015729], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0140830015729]
# M = [0.00704150078645..0.00704150078645]
# fI = [-0.0680931858216..0.381309751385]
# Tfinal = [-0.0..0.0140830015729]
# root on boundary!
# merging intervals:
# [-0.0..0.535087809615]
# [0.535087809615..0.549170811188]
# ===
# reached detect roots t=[0.549170811188..0.549170811188] + [0.0..0.0154913017302]
# not using mask!
# f_domain = [-2.52333104143..2.84513961372]
# detect_roots(T0=[0.0..0.0154913017302], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0154913017302]
# M = [0.0077456508651..0.0077456508651]
# fI = [-0.0653775018706..0.385861703538]
# Tfinal = [-0.0..0.0154913017302]
# root on boundary!
# merging intervals:
# [-0.0..0.549170811188]
# [0.549170811188..0.564662112918]
# ===
# reached detect roots t=[0.564662112918..0.564662112918] + [0.0..0.0170404319032]
# not using mask!
# f_domain = [-2.47989068263..2.80971288366]
# detect_roots(T0=[0.0..0.0170404319032], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0170404319032]
# M = [0.0085202159516..0.0085202159516]
# fI = [-0.062340662022..0.390468388425]
# Tfinal = [-0.0..0.0170404319032]
# root on boundary!
# merging intervals:
# [-0.0..0.564662112918]
# [0.564662112918..0.581702544822]
# ===
# reached detect roots t=[0.581702544822..0.581702544822] + [0.0..0.0187444750935]
# not using mask!
# f_domain = [-2.50206510408..2.84034575198]
# detect_roots(T0=[0.0..0.0187444750935], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0187444750935]
# M = [0.00937223754677..0.00937223754677]
# fI = [-0.0589411252597..0.395050064926]
# Tfinal = [-0.0..0.0187444750935]
# root on boundary!
# merging intervals:
# [-0.0..0.581702544822]
# [0.581702544822..0.600447019915]
# ===
# reached detect roots t=[0.600447019915..0.600447019915] + [0.0..0.0206189226029]
# not using mask!
# f_domain = [-2.51396920021..2.86097481561]
# detect_roots(T0=[0.0..0.0206189226029], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0206189226029]
# M = [0.0103094613014..0.0103094613014]
# fI = [-0.0550905126382..0.399489089606]
# Tfinal = [-0.0..0.0206189226029]
# root on boundary!
# merging intervals:
# [-0.0..0.600447019915]
# [0.600447019915..0.621065942518]
# ===
# reached detect roots t=[0.621065942518..0.621065942518] + [0.0..0.0226808148632]
# not using mask!
# f_domain = [-2.51207807997..2.86811699297]
# detect_roots(T0=[0.0..0.0226808148632], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0226808148632]
# M = [0.0113404074316..0.0113404074316]
# fI = [-0.0507232032999..0.40364311032]
# Tfinal = [-0.0..0.0226808148632]
# root on boundary!
# merging intervals:
# [-0.0..0.621065942518]
# [0.621065942518..0.643746757381]
# ===
# reached detect roots t=[0.643746757381..0.643746757381] + [0.0..0.0124744481747]
# not using mask!
# f_domain = [-2.49427537089..2.85962705311]
# detect_roots(T0=[0.0..0.0124744481747], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0124744481747]
# M = [0.00623722408737..0.00623722408737]
# fI = [-0.0456445806002..0.405018062692]
# Tfinal = [-0.0..0.0124744481747]
# root on boundary!
# merging intervals:
# [-0.0..0.643746757381]
# [0.643746757381..0.656221205556]
# ===
# reached detect roots t=[0.656221205556..0.656221205556] + [0.0..0.0137218929922]
# not using mask!
# f_domain = [-2.49130519468..2.86142041802]
# detect_roots(T0=[0.0..0.0137218929922], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0137218929922]
# M = [0.00686094649611..0.00686094649611]
# fI = [-0.0430523435824..0.406946699732]
# Tfinal = [-0.0..0.0137218929922]
# root on boundary!
# merging intervals:
# [-0.0..0.656221205556]
# [0.656221205556..0.669943098548]
# ===
# reached detect roots t=[0.669943098548..0.669943098548] + [0.0..0.0150940822914]
# not using mask!
# f_domain = [-2.48672388751..2.8618304433]
# detect_roots(T0=[0.0..0.0150940822914], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0150940822914]
# M = [0.00754704114572..0.00754704114572]
# fI = [-0.0401729185262..0.408778263912]
# Tfinal = [-0.0..0.0150940822914]
# root on boundary!
# merging intervals:
# [-0.0..0.669943098548]
# [0.669943098548..0.68503718084]
# ===
# reached detect roots t=[0.68503718084..0.68503718084] + [0.0..0.0166034905206]
# not using mask!
# f_domain = [-2.47380415214..2.85409700895]
# detect_roots(T0=[0.0..0.0166034905206], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0166034905206]
# M = [0.00830174526029..0.00830174526029]
# fI = [-0.036984878372..0.410457946531]
# Tfinal = [-0.0..0.0166034905206]
# root on boundary!
# merging intervals:
# [-0.0..0.68503718084]
# [0.68503718084..0.70164067136]
# ===
# reached detect roots t=[0.70164067136..0.70164067136] + [0.0..0.0182638395726]
# not using mask!
# f_domain = [-2.45149701606..2.83713092151]
# detect_roots(T0=[0.0..0.0182638395726], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0182638395726]
# M = [0.00913191978632..0.00913191978632]
# fI = [-0.0335861980084..0.412024274159]
# Tfinal = [-0.0..0.0182638395726]
# root on boundary!
# merging intervals:
# [-0.0..0.70164067136]
# [0.70164067136..0.719904510933]
# ===
# reached detect roots t=[0.719904510933..0.719904510933] + [0.0..0.0200902235299]
# not using mask!
# f_domain = [-2.41943283504..2.81059764482]
# detect_roots(T0=[0.0..0.0200902235299], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0200902235299]
# M = [0.010045111765..0.010045111765]
# fI = [-0.0300259807467..0.413474609568]
# Tfinal = [-0.0..0.0200902235299]
# root on boundary!
# merging intervals:
# [-0.0..0.719904510933]
# [0.719904510933..0.739994734463]
# ===
# reached detect roots t=[0.739994734463..0.739994734463] + [0.0..0.0220992458829]
# not using mask!
# f_domain = [-2.37186213609..2.76858848924]
# detect_roots(T0=[0.0..0.0220992458829], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0220992458829]
# M = [0.0110496229414..0.0110496229414]
# fI = [-0.0260935079332..0.414511085592]
# Tfinal = [-0.0..0.0220992458829]
# root on boundary!
# merging intervals:
# [-0.0..0.739994734463]
# [0.739994734463..0.762093980346]
# ===
# reached detect roots t=[0.762093980346..0.762093980346] + [0.0..0.0243091704712]
# not using mask!
# f_domain = [-2.30596531522..2.70818542145]
# detect_roots(T0=[0.0..0.0243091704712], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0243091704712]
# M = [0.0121545852356..0.0121545852356]
# fI = [-0.0217362738611..0.414976680161]
# Tfinal = [-0.0..0.0243091704712]
# root on boundary!
# merging intervals:
# [-0.0..0.762093980346]
# [0.762093980346..0.786403150817]
# ===
# reached detect roots t=[0.786403150817..0.786403150817] + [0.0..0.0133700437592]
# not using mask!
# f_domain = [-2.23575588049..2.64326459718]
# detect_roots(T0=[0.0..0.0133700437592], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0133700437592]
# M = [0.00668502187958..0.00668502187958]
# fI = [-0.0158787269876..0.412560165407]
# Tfinal = [-0.0..0.0133700437592]
# root on boundary!
# merging intervals:
# [-0.0..0.786403150817]
# [0.786403150817..0.799773194576]
# ===
# reached detect roots t=[0.799773194576..0.799773194576] + [0.0..0.0147070481351]
# not using mask!
# f_domain = [-2.19307145276..2.60304062469]
# detect_roots(T0=[0.0..0.0147070481351], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0147070481351]
# M = [0.00735352406753..0.00735352406753]
# fI = [-0.0131861127808..0.412153241567]
# Tfinal = [-0.0..0.0147070481351]
# root on boundary!
# merging intervals:
# [-0.0..0.799773194576]
# [0.799773194576..0.814480242711]
# ===
# reached detect roots t=[0.814480242711..0.814480242711] + [0.0..0.0161777529486]
# not using mask!
# f_domain = [-2.14157500797..2.55401867486]
# detect_roots(T0=[0.0..0.0161777529486], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0161777529486]
# M = [0.00808887647429..0.00808887647429]
# fI = [-0.0102298576815..0.411443063066]
# Tfinal = [-0.0..0.0161777529486]
# root on boundary!
# merging intervals:
# [-0.0..0.814480242711]
# [0.814480242711..0.83065799566]
# ===
# reached detect roots t=[0.83065799566..0.83065799566] + [0.0..0.0177955282434]
# not using mask!
# f_domain = [-2.08015551061..2.49502775824]
# detect_roots(T0=[0.0..0.0177955282434], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0177955282434]
# M = [0.00889776412172..0.00889776412172]
# fI = [-0.00698726010394..0.410355511432]
# Tfinal = [-0.0..0.0177955282434]
# root on boundary!
# merging intervals:
# [-0.0..0.83065799566]
# [0.83065799566..0.848453523903]
# ===
# reached detect roots t=[0.848453523903..0.848453523903] + [0.0..0.0195750810678]
# not using mask!
# f_domain = [-2.00764676..2.42484460696]
# detect_roots(T0=[0.0..0.0195750810678], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0195750810678]
# M = [0.00978754053389..0.00978754053389]
# fI = [-0.00345740565564..0.408823654884]
# Tfinal = [-0.0..0.0195750810678]
# root on boundary!
# merging intervals:
# [-0.0..0.848453523903]
# [0.848453523903..0.868028604971]
# ===
# reached detect roots t=[0.868028604971..0.868028604971] + [0.0..0.0215325891746]
# not using mask!
# f_domain = [-1.92302395233..2.34237039883]
# detect_roots(T0=[0.0..0.0215325891746], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0215325891746]
# M = [0.0107662945873..0.0107662945873]
# fI = [0.000370418810894..0.406761806117]
# Tfinal = [-0.0..0.00934642987349]
# splitting! [0.0..0.0215325891746] -> [-0.0..0.00934642987349] + [0.0126426268082..0.0215325891746]
# detect_roots(T0=[-0.0..0.00934642987349], epsilon=1e-05, verbosity=10)
# T = [-0.0..0.00934642987349]
# M = [0.00467321493674..0.00467321493674]
# fI = [0.0014860889086..0.405174253963]
# failed! on:
# M=[0.00467321493674..0.00467321493674]
# extdiv(T=[-0.00467321493674..0.00467321493674], Tu=[0.0..0.0], split=False, T=[-0.00467321493674..0.00467321493674], fI=[0.0014860889086..0.405174253963], fP=[-0.184773551922..0.260883172387])
# detect_roots(T0=[0.0126426268082..0.0215325891746], epsilon=1e-05, verbosity=10)
# T = [0.0126426268082..0.0215325891746]
# M = [0.0170876079914..0.0170876079914]
# fI = [-0.000827487692274..0.408408010169]
# Tfinal = [0.0126426268082..0.0215325891746]
# root on boundary!
# new root:
# [0.880671231779..0.889561194145]
# ===
# reached detect roots t=[0.889561194145..0.889561194145] + [0.0..0.023685848092]
# not using mask!
# f_domain = [-1.82530575674..2.24653848948]
# detect_roots(T0=[0.0..0.023685848092], epsilon=1e-05, verbosity=10)
# T = [0.0..0.023685848092]
# M = [0.011842924046..0.011842924046]
# fI = [0.0044781131636..0.404084949648]
# failed! on:
# M=[0.011842924046..0.011842924046]
# extdiv(T=[-0.011842924046..0.011842924046], Tu=[0.0..0.0], split=False, T=[-0.011842924046..0.011842924046], fI=[0.0044781131636..0.404084949648], fP=[-0.214718807327..0.254413780625])
# ===
# reached detect roots t=[0.913247042237..0.913247042237] + [0.0..0.0260544329012]
# not using mask!
# f_domain = [-1.71369264965..2.13643575194]
# detect_roots(T0=[0.0..0.0260544329012], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0260544329012]
# M = [0.0130272164506..0.0130272164506]
# fI = [0.0089421546311..0.400594265379]
# failed! on:
# M=[0.0130272164506..0.0130272164506]
# extdiv(T=[-0.0130272164506..0.0130272164506], Tu=[0.0..0.0], split=False, T=[-0.0130272164506..0.0130272164506], fI=[0.0089421546311..0.400594265379], fP=[-0.231524259101..0.246314616169])
# ===
# reached detect roots t=[0.939301475139..0.939301475139] + [0.0..0.0286598761913]
# not using mask!
# f_domain = [-1.58865231752..2.01242302266]
# detect_roots(T0=[0.0..0.0286598761913], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0286598761913]
# M = [0.0143299380957..0.0143299380957]
# fI = [0.0137543910796..0.396162774862]
# failed! on:
# M=[0.0143299380957..0.0143299380957]
# extdiv(T=[-0.0143299380957..0.0143299380957], Tu=[0.0..0.0], split=False, T=[-0.0143299380957..0.0143299380957], fI=[0.0137543910796..0.396162774862], fP=[-0.247982170555..0.236335139049])
# ===
# reached detect roots t=[0.96796135133..0.96796135133] + [0.0..0.0157629319052]
# not using mask!
# f_domain = [-1.48365377725..1.91065787979]
# skipping given consistent value over domain
# ===
# reached detect roots t=[0.983724283235..0.983724283235] + [0.0..0.0173392250958]
# not using mask!
# f_domain = [-1.45524432899..1.88209832672]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.00106350833..1.00106350833] + [0.0..0.0190731476053]
# not using mask!
# f_domain = [-1.42688919858..1.85323787845]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.02013665594..1.02013665594] + [0.0..0.0209804623659]
# not using mask!
# f_domain = [-1.40273567574..1.82829451707]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.0411171183..1.0411171183] + [0.0..0.0230785086025]
# not using mask!
# f_domain = [-1.37968936198..1.80401459332]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.0641956269..1.0641956269] + [0.0..0.0253863594627]
# not using mask!
# f_domain = [-1.34876823055..1.7713186804]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.08958198637..1.08958198637] + [0.0..0.027924995409]
# not using mask!
# f_domain = [-1.30983742012..1.72992745394]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.11750698178..1.11750698178] + [0.0..0.0307174949499]
# not using mask!
# f_domain = [-1.26532912231..1.68216058693]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.14822447673..1.14822447673] + [0.0..0.0337892444448]
# not using mask!
# f_domain = [-1.21556712882..1.62813190988]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.18201372117..1.18201372117] + [0.0..0.0185840844447]
# not using mask!
# f_domain = [-1.15577088627..1.56291055842]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.20059780562..1.20059780562] + [0.0..0.0204424928891]
# not using mask!
# f_domain = [-1.12163576293..1.52558075016]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.2210402985..1.2210402985] + [0.0..0.022486742178]
# not using mask!
# f_domain = [-1.08347783487..1.48370625531]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.24352704068..1.24352704068] + [0.0..0.0247354163959]
# not using mask!
# f_domain = [-1.0409647509..1.43677346317]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.26826245708..1.26826245708] + [0.0..0.0272089580354]
# not using mask!
# f_domain = [-0.993951498752..1.38461340687]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.29547141511..1.29547141511] + [0.0..0.029929853839]
# not using mask!
# f_domain = [-0.942371357266..1.32708011759]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.32540126895..1.32540126895] + [0.0..0.0329228392229]
# not using mask!
# f_domain = [-0.890501515919..1.26840978633]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.35832410818..1.35832410818] + [0.0..0.0362151231452]
# not using mask!
# f_domain = [-0.838968774208..1.20900701091]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.39453923132..1.39453923132] + [0.0..0.0398366354597]
# not using mask!
# f_domain = [-0.782941620074..1.14400033487]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.43437586678..1.43437586678] + [0.0..0.0438202990057]
# not using mask!
# f_domain = [-0.723653903771..1.07445662499]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.47819616579..1.47819616579] + [0.0..0.0241011644531]
# not using mask!
# f_domain = [-0.663179231272..1.00232329022]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.50229733024..1.50229733024] + [0.0..0.0265112808984]
# not using mask!
# f_domain = [-0.6314785997..0.964096408902]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.52880861114..1.52880861114] + [0.0..0.0291624089883]
# not using mask!
# f_domain = [-0.597940607955..0.923286948024]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.55797102013..1.55797102013] + [0.0..0.0320786498871]
# not using mask!
# f_domain = [-0.562833629426..0.880051651005]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.59004967001..1.59004967001] + [0.0..0.0352865148758]
# not using mask!
# f_domain = [-0.526278978964..0.834468166796]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.62533618489..1.62533618489] + [0.0..0.0388151663634]
# not using mask!
# f_domain = [-0.488701097088..0.786879373201]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.66415135125..1.66415135125] + [0.0..0.0426966829997]
# not using mask!
# f_domain = [-0.45256912698..0.739674001469]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.70684803425..1.70684803425] + [0.0..0.0469663512997]
# not using mask!
# f_domain = [-0.42173482864..0.69662662446]
# skipping given consistent value over domain
# ===
# reached detect roots t=[1.75381438555..1.75381438555] + [0.0..0.0516629864297]
# not using mask!
# f_domain = [-0.400042675049..0.661506540726]
# detect_roots(T0=[0.0..0.0516629864297], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0516629864297]
# M = [0.0258314932148..0.0258314932148]
# fI = [0.0470561097116..0.197384439239]
# failed! on:
# M=[0.0258314932148..0.0258314932148]
# extdiv(T=[-0.0258314932148..0.0258314932148], Tu=[-0.0258314932148..0.0258314932148], split=False, T=[-0.0258314932148..0.0258314932148], fI=[0.0470561097116..0.197384439239], fP=[-0.255894824826..-0.0161943243669])
# ===
# reached detect roots t=[1.80547737198..1.80547737198] + [0.0..0.0568292850726]
# not using mask!
# f_domain = [-0.381095079713..0.627814449602]
# detect_roots(T0=[0.0..0.0568292850726], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0568292850726]
# M = [0.0284146425363..0.0284146425363]
# fI = [0.0448080195102..0.1848753656]
# failed! on:
# M=[0.0284146425363..0.0284146425363]
# extdiv(T=[-0.0284146425363..0.0284146425363], Tu=[-0.0284146425363..0.0284146425363], split=False, T=[-0.0284146425363..0.0284146425363], fI=[0.0448080195102..0.1848753656], fP=[-0.247461332162..-0.0224264709715])
# ===
# reached detect roots t=[1.86230665705..1.86230665705] + [0.0..0.0625122135799]
# not using mask!
# f_domain = [-0.362358932189..0.592990512991]
# detect_roots(T0=[0.0..0.0625122135799], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0625122135799]
# M = [0.0312561067899..0.0312561067899]
# fI = [0.0418442936539..0.171746363415]
# failed! on:
# M=[0.0312561067899..0.0312561067899]
# extdiv(T=[-0.0312561067899..0.0312561067899], Tu=[-0.0312561067899..0.0312561067899], split=False, T=[-0.0312561067899..0.0312561067899], fI=[0.0418442936539..0.171746363415], fP=[-0.237908963416..-0.0285083064117])
# ===
# reached detect roots t=[1.92481887063..1.92481887063] + [0.0..0.0343817174689]
# not using mask!
# f_domain = [-0.34342924996..0.556582752274]
# detect_roots(T0=[0.0..0.0343817174689], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0343817174689]
# M = [0.0171908587345..0.0171908587345]
# fI = [0.0421841492155..0.158486466869]
# failed! on:
# M=[0.0171908587345..0.0171908587345]
# extdiv(T=[-0.0171908587345..0.0171908587345], Tu=[-0.0171908587345..0.0171908587345], split=False, T=[-0.0171908587345..0.0171908587345], fI=[0.0421841492155..0.158486466869], fP=[-0.223864234186..-0.0402151419481])
# ===
# reached detect roots t=[1.9592005881..1.9592005881] + [0.0..0.0378198892158]
# not using mask!
# f_domain = [-0.333899995515..0.537576711198]
# detect_roots(T0=[0.0..0.0378198892158], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0378198892158]
# M = [0.0189099446079..0.0189099446079]
# fI = [0.0400958734684..0.151047452686]
# failed! on:
# M=[0.0189099446079..0.0189099446079]
# extdiv(T=[-0.0189099446079..0.0189099446079], Tu=[-0.0189099446079..0.0189099446079], split=False, T=[-0.0189099446079..0.0189099446079], fI=[0.0400958734684..0.151047452686], fP=[-0.218508220947..-0.0427702758346])
# ===
# reached detect roots t=[1.99702047732..1.99702047732] + [0.0..0.0416018781374]
# not using mask!
# f_domain = [-0.324018746332..0.517382827135]
# detect_roots(T0=[0.0..0.0416018781374], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0416018781374]
# M = [0.0208009390687..0.0208009390687]
# fI = [0.0377343701391..0.143040379571]
# failed! on:
# M=[0.0208009390687..0.0208009390687]
# extdiv(T=[-0.0208009390687..0.0208009390687], Tu=[-0.0208009390687..0.0208009390687], split=False, T=[-0.0208009390687..0.0208009390687], fI=[0.0377343701391..0.143040379571], fP=[-0.212636574668..-0.045271021846])
# ===
# reached detect roots t=[2.03862235546..2.03862235546] + [0.0..0.0457620659512]
# not using mask!
# f_domain = [-0.313910964463..0.496076327595]
# detect_roots(T0=[0.0..0.0457620659512], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0457620659512]
# M = [0.0228810329756..0.0228810329756]
# fI = [0.0350340408197..0.134483439458]
# Tfinal = [-0.0..0.0457620659512]
# root on boundary!
# new root:
# [2.03862235546..2.08438442141]
# ===
# reached detect roots t=[2.08438442141..2.08438442141] + [0.0..0.0503382725463]
# not using mask!
# f_domain = [-0.303605450434..0.473642473019]
# detect_roots(T0=[0.0..0.0503382725463], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0503382725463]
# M = [0.0251691362731..0.0251691362731]
# fI = [0.0319957134054..0.125331736988]
# failed! on:
# M=[0.0251691362731..0.0251691362731]
# extdiv(T=[-0.0251691362731..0.0251691362731], Tu=[-0.0251691362731..0.0251691362731], split=False, T=[-0.0251691362731..0.0251691362731], fI=[0.0319957134054..0.125331736988], fP=[-0.199952421031..-0.049274775665])
# ===
# reached detect roots t=[2.13472269395..2.13472269395] + [0.0..0.0553720998009]
# not using mask!
# f_domain = [-0.293199902453..0.45013918412]
# detect_roots(T0=[0.0..0.0553720998009], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0553720998009]
# M = [0.0276860499004..0.0276860499004]
# fI = [0.0285947836788..0.115572470613]
# failed! on:
# M=[0.0276860499004..0.0276860499004]
# extdiv(T=[-0.0276860499004..0.0276860499004], Tu=[-0.0276860499004..0.0276860499004], split=False, T=[-0.0276860499004..0.0276860499004], fI=[0.0285947836788..0.115572470613], fP=[-0.192735724712..-0.0510622995653])
# ===
# reached detect roots t=[2.19009479375..2.19009479375] + [0.0..0.060909309781]
# not using mask!
# f_domain = [-0.28547133467..0.428310459649]
# detect_roots(T0=[0.0..0.060909309781], epsilon=1e-05, verbosity=10)
# T = [0.0..0.060909309781]
# M = [0.0304546548905..0.0304546548905]
# fI = [0.0236396417539..0.106367972853]
# failed! on:
# M=[0.0304546548905..0.0304546548905]
# extdiv(T=[-0.0304546548905..0.0304546548905], Tu=[-0.0304546548905..0.0304546548905], split=False, T=[-0.0304546548905..0.0304546548905], fI=[0.0236396417539..0.106367972853], fP=[-0.184894162012..-0.0526818230246])
# ===
# reached detect roots t=[2.25100410354..2.25100410354] + [0.0..0.0670002407591]
# not using mask!
# f_domain = [-0.279638333545..0.407378013232]
# detect_roots(T0=[0.0..0.0670002407591], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0670002407591]
# M = [0.0335001203795..0.0335001203795]
# fI = [0.017422433272..0.0974166228351]
# failed! on:
# M=[0.0335001203795..0.0335001203795]
# extdiv(T=[-0.0335001203795..0.0335001203795], Tu=[-0.0335001203795..0.0335001203795], split=False, T=[-0.0335001203795..0.0335001203795], fI=[0.017422433272..0.0974166228351], fP=[-0.176438224264..-0.0540907838419])
# ===
# reached detect roots t=[2.31800434429..2.31800434429] + [0.0..0.073700264835]
# not using mask!
# f_domain = [-0.273625948522..0.385223159283]
# detect_roots(T0=[0.0..0.073700264835], epsilon=1e-05, verbosity=10)
# T = [0.0..0.073700264835]
# M = [0.0368501324175..0.0368501324175]
# fI = [0.0108546039895..0.0877914226596]
# failed! on:
# M=[0.0368501324175..0.0368501324175]
# extdiv(T=[-0.0368501324175..0.0368501324175], Tu=[-0.0368501324175..0.0368501324175], split=False, T=[-0.0368501324175..0.0368501324175], fI=[0.0108546039895..0.0877914226596], fP=[-0.167424246466..-0.05521358718])
# ===
# reached detect roots t=[2.39170460913..2.39170460913] + [0.0..0.0810702913185]
# not using mask!
# f_domain = [-0.267992446161..0.362415634139]
# detect_roots(T0=[0.0..0.0810702913185], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0810702913185]
# M = [0.0405351456592..0.0405351456592]
# fI = [0.00394211822313..0.0775005780416]
# T = [0.0655047300898..0.0810702913185]
# M = [0.0732875107042..0.0732875107042]
# fI = [-0.00121399296942..0.0755666380757]
# Tfinal = [0.0655047300898..0.0810702913185]
# root on boundary!
# new root:
# [2.45720933922..2.47277490045]
# ===
# reached detect roots t=[2.47277490045..2.47277490045] + [0.0..0.0891773204503]
# not using mask!
# f_domain = [-0.26610752324..0.342355121069]
# detect_roots(T0=[0.0..0.0891773204503], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0891773204503]
# M = [0.0445886602252..0.0445886602252]
# fI = [-0.00331815610588..0.0665785798239]
# Tfinal = [-0.0..0.0891773204503]
# root on boundary!
# merging intervals:
# [2.45720933922..2.47277490045]
# [2.47277490045..2.5619522209]
# ===
# reached detect roots t=[2.5619522209..2.5619522209] + [0.0..0.0980950524954]
# not using mask!
# f_domain = [-0.265909776139..0.323031091447]
# detect_roots(T0=[0.0..0.0980950524954], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0980950524954]
# M = [0.0490475262477..0.0490475262477]
# fI = [-0.0111790627388..0.0553366569645]
# Tfinal = [-0.0..0.0980950524954]
# root on boundary!
# merging intervals:
# [2.45720933922..2.5619522209]
# [2.5619522209..2.66004727339]
# ===
# reached detect roots t=[2.66004727339..2.66004727339] + [0.0..0.0539522788725]
# not using mask!
# f_domain = [-0.264722971603..0.301849986189]
# detect_roots(T0=[0.0..0.0539522788725], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0539522788725]
# M = [0.0269761394362..0.0269761394362]
# fI = [-0.0158908437412..0.0452285759532]
# Tfinal = [-0.0..0.0539522788725]
# root on boundary!
# merging intervals:
# [2.45720933922..2.66004727339]
# [2.66004727339..2.71399955227]
# ===
# reached detect roots t=[2.71399955227..2.71399955227] + [0.0..0.0593475067597]
# not using mask!
# f_domain = [-0.263697066547..0.290250536874]
# detect_roots(T0=[0.0..0.0593475067597], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0593475067597]
# M = [0.0296737533798..0.0296737533798]
# fI = [-0.0202979485449..0.0389699565682]
# Tfinal = [-0.0..0.0593475067597]
# root on boundary!
# merging intervals:
# [2.45720933922..2.71399955227]
# [2.71399955227..2.77334705903]
# ===
# reached detect roots t=[2.77334705903..2.77334705903] + [0.0..0.0652822574357]
# not using mask!
# f_domain = [-0.262215846917..0.277534139041]
# detect_roots(T0=[0.0..0.0652822574357], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0652822574357]
# M = [0.0326411287178..0.0326411287178]
# fI = [-0.0249591416817..0.0322871253051]
# Tfinal = [-0.0..0.0652822574357]
# root on boundary!
# merging intervals:
# [2.45720933922..2.77334705903]
# [2.77334705903..2.83862931646]
# ===
# reached detect roots t=[2.83862931646..2.83862931646] + [0.0..0.0718104831792]
# not using mask!
# f_domain = [-0.260300286365..0.263688460795]
# detect_roots(T0=[0.0..0.0718104831792], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0718104831792]
# M = [0.0359052415896..0.0359052415896]
# fI = [-0.0298829496617..0.0251793247621]
# Tfinal = [-0.0..0.0718104831792]
# root on boundary!
# merging intervals:
# [2.45720933922..2.83862931646]
# [2.83862931646..2.91043979964]
# ===
# reached detect roots t=[2.91043979964..2.91043979964] + [0.0..0.0789915314972]
# not using mask!
# f_domain = [-0.257879622544..0.24868194988]
# detect_roots(T0=[0.0..0.0789915314972], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0789915314972]
# M = [0.0394957657486..0.0394957657486]
# fI = [-0.0350538243794..0.0176522808156]
# Tfinal = [-0.0..0.0789915314972]
# root on boundary!
# merging intervals:
# [2.45720933922..2.91043979964]
# [2.91043979964..2.98943133114]
# ===
# reached detect roots t=[2.98943133114..2.98943133114] + [0.0..0.0868906846469]
# not using mask!
# f_domain = [-0.25498679977..0.232537333221]
# detect_roots(T0=[0.0..0.0868906846469], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0868906846469]
# M = [0.0434453423234..0.0434453423234]
# fI = [-0.0404770525871..0.00972482943239]
# Tfinal = [-0.0..0.0868906846469]
# root on boundary!
# merging intervals:
# [2.45720933922..2.98943133114]
# [2.98943133114..3.07632201578]
# ===
# reached detect roots t=[3.07632201578..3.07632201578] + [0.0..0.0955797531116]
# not using mask!
# f_domain = [-0.251858886098..0.215524128658]
# detect_roots(T0=[0.0..0.0955797531116], epsilon=1e-05, verbosity=10)
# T = [0.0..0.0955797531116]
# M = [0.0477898765558..0.0477898765558]
# fI = [-0.0462114041467..0.00149229286856]
# T = [-0.0..0.0760979286401]
# M = [0.03804896432..0.03804896432]
# fI = [-0.045304049664..0.00204159916599]
# T = [-0.0..0.0758000673842]
# M = [0.0379000336921..0.0379000336921]
# fI = [-0.0452901639218..0.00205004873573]
# Tfinal = [-0.0..0.0757927918473]
# root on boundary!
# merging intervals:
# [2.45720933922..3.07632201578]
# [3.07632201578..3.15211480763]
# ===
# reached detect roots t=[3.1719017689..3.1719017689] + [0.0..0.105137728423]
# not using mask!
# f_domain = [-0.248813696207..0.198009908629]
# detect_roots(T0=[0.0..0.105137728423], epsilon=1e-05, verbosity=10)
# T = [0.0..0.105137728423]
# M = [0.0525688642114..0.0525688642114]
# fI = [-0.0521582139947..-0.00709246212011]
# failed! on:
# M=[0.0525688642114..0.0525688642114]
# extdiv(T=[-0.0525688642114..0.0525688642114], Tu=[-0.0525688642114..0.0525688642114], split=False, T=[-0.0525688642114..0.0525688642114], fI=[-0.0521582139947..-0.00709246212011], fP=[-0.0876113065523..-0.050666078554])
# ===
# reached detect roots t=[3.27703949732..3.27703949732] + [0.0..0.115651501265]
# not using mask!
# f_domain = [-0.245202191902..0.179375624543]
# detect_roots(T0=[0.0..0.115651501265], epsilon=1e-05, verbosity=10)
# T = [0.0..0.115651501265]
# M = [0.0578257506325..0.0578257506325]
# fI = [-0.0583247503975..-0.0159638205368]
# failed! on:
# M=[0.0578257506325..0.0578257506325]
# extdiv(T=[-0.0578257506325..0.0578257506325], Tu=[-0.0578257506325..0.0578257506325], split=False, T=[-0.0578257506325..0.0578257506325], fI=[-0.0583247503975..-0.0159638205368], fP=[-0.0816867839907..-0.0478693702666])
# ===
# reached detect roots t=[3.39269099858..3.39269099858] + [0.0..0.127216651391]
# not using mask!
# f_domain = [-0.24100068644..0.159707996541]
# detect_roots(T0=[0.0..0.127216651391], epsilon=1e-05, verbosity=10)
# T = [0.0..0.127216651391]
# M = [0.0636083256957..0.0636083256957]
# fI = [-0.0646596487263..-0.0250786762334]
# failed! on:
# M=[0.0636083256957..0.0636083256957]
# extdiv(T=[-0.0636083256957..0.0636083256957], Tu=[-0.0636083256957..0.0636083256957], split=False, T=[-0.0636083256957..0.0636083256957], fI=[-0.0646596487263..-0.0250786762334], fP=[-0.0761028266689..-0.0444706934198])
# ===
# reached detect roots t=[3.51990764998..3.51990764998] + [0.0..0.139938316531]
# not using mask!
# f_domain = [-0.236274824363..0.139167975027]
# detect_roots(T0=[0.0..0.139938316531], epsilon=1e-05, verbosity=10)
# T = [0.0..0.139938316531]
# M = [0.0699691582653..0.0699691582653]
# fI = [-0.0711127131838..-0.034383552209]
# failed! on:
# M=[0.0699691582653..0.0699691582653]
# extdiv(T=[-0.0699691582653..0.0699691582653], Tu=[-0.0699691582653..0.0699691582653], split=False, T=[-0.0699691582653..0.0699691582653], fI=[-0.0711127131838..-0.034383552209], fP=[-0.0703640162717..-0.0409960915261])
# ===
# reached detect roots t=[3.65984596651..3.65984596651] + [0.0..0.153932148184]
# not using mask!
# f_domain = [-0.231108940712..0.11795130964]
# skipping given consistent value over domain
# ===
# reached detect roots t=[3.81377811469..3.81377811469] + [0.0..0.084662681501]
# not using mask!
# f_domain = [-0.225280633161..0.0959626504618]
# skipping given consistent value over domain
# ===
# reached detect roots t=[3.89844079619..3.89844079619] + [0.0..0.0931289496511]
# not using mask!
# f_domain = [-0.222258807745..0.0846470080435]
# skipping given consistent value over domain
# ===
# reached detect roots t=[3.99156974584..3.99156974584] + [0.0..0.102441844616]
# not using mask!
# f_domain = [-0.219024498494..0.0727682446119]
# skipping given consistent value over domain
# ===
# reached detect roots t=[4.09401159046..4.09401159046] + [0.0..0.112686029078]
# not using mask!
# f_domain = [-0.215600648024..0.0603805979662]
# skipping given consistent value over domain
# ===
# reached detect roots t=[4.20669761954..4.20669761954] + [0.0..0.123954631986]
# not using mask!
# f_domain = [-0.211956642268..0.0475226714016]
# skipping given consistent value over domain
# ===
# reached detect roots t=[4.33065225152..4.33065225152] + [0.0..0.136350095184]
# not using mask!
# f_domain = [-0.208178946068..0.0343047271815]
# skipping given consistent value over domain
# ===
# reached detect roots t=[4.46700234671..4.46700234671] + [0.0..0.149985104703]
# not using mask!
# f_domain = [-0.204267325038..0.0207877810372]
# skipping given consistent value over domain
# ===
# reached detect roots t=[4.61698745141..4.61698745141] + [0.0..0.164983615173]
# not using mask!
# f_domain = [-0.200253007771..0.00709726509599]
# skipping given consistent value over domain
# ===
# reached detect roots t=[4.78197106658..4.78197106658] + [0.0..0.18148197669]
# not using mask!
# f_domain = [-0.196223961478..-0.00664977321004]
# skipping given consistent value over domain (unpreconditioned)
# ===
# reached detect roots t=[4.96345304327..4.96345304327] + [0.0..0.0365469567271]
# not using mask!
# f_domain = [-0.192157281968..-0.0203641662033]
# skipping given consistent value over domain (unpreconditioned)
# CPU times: user 2.52 s, sys: 47.2 ms, total: 2.56 s
# Wall time: 2.58 s
# [1.?, 0.89?, 2.1?, 3.?]

# %%
help(PolyObserver)
# Out:
# Help on class PolyObserver in module flowstar.observers:
#
# class PolyObserver(__builtin__.object)
#  |  Methods defined here:
#  |
#  |  __call__(...)
#  |      x.__call__(...) <==> x(...)
#  |
#  |  __init__(...)
#  |      x.__init__(...) initializes x; see help(type(x)) for signature
#  |
#  |  __reduce__ = __reduce_cython__(...)
#  |
#  |  __setstate__ = __setstate_cython__(...)
#  |
#  |  check(...)
#  |
#  |  roots(...)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  f
#  |
#  |  flowstar_successful
#  |
#  |  fprime
#  |
#  |  mask
#  |
#  |  reach
#  |
#  |  symbolic_composition
#  |
#  |  tentative_unpreconditioning
#  |
#  |  time
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __new__ = <built-in method __new__ of type object>
#  |      T.__new__(S, ...) -> a new object with type S, a subtype of T
#  |
#  |  __pyx_vtable__ = <capsule object NULL>

# %%
sig2.plot()
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
prop = (P & Atomic(x - 1.15))
prop
# Out:
# And([Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000), Atomic(x - 1.15000000000000)])

# %%
sig3 = prop.signal_for_system(vf, v3, 5, order=5, step=(0.01, 0.5),
                                   precondition=1,
                                   estimation=1e-3,
                                   integrationScheme=2,
                                   cutoff_threshold=1e-5,
                                   symbolic_composition=True,
                             #      precompose_taylor_models=True,
                             )
sig3.plot()
# Out:
# Computed 115 flowpipes in 1.56510829926 sec
# In prepare! flowpipes_compo.size() = 115
# Prepared for plotting in 0.00142693519592 sec
# domain = [0.00000000000000000 .. 5.0000000000000000]
# roots = [[0.73999473446266517 .. 2.3917046091295045]]
# seg_domain = [0.00000000000000000 .. 5.0000000000000000]
# roots = [[0.73999473446266517 .. 2.3917046091295045]]
# domain = [0.00000000000000000 .. 5.0000000000000000]
# roots = [[0.00000000000000000 .. 0.86802860497076651],
#  [0.88067123177899730 .. 0.88956119414532109],
#  [2.4572093392192910 .. 3.1521148076320591]]
# seg_domain = [0.00000000000000000 .. 5.0000000000000000]
# roots = [[0.00000000000000000 .. 0.86802860497076651],
#  [0.88067123177899730 .. 0.88956119414532109],
#  [2.4572093392192910 .. 3.1521148076320591]]
# Monitored signal 7.81478476524 sec
# Graphics object consisting of 2 graphics primitives

# %%
sig3 = prop.signal_for_system(vf, v3, 5, order=5, step=(0.01, 0.5),
                                   precondition=1,
                                   estimation=1e-3,
                                   integrationScheme=2,
                                   cutoff_threshold=1e-5,
                                   symbolic_composition=True,
                              #     precompose_taylor_models=True,
                                   use_masks=True)
sig3.plot()
# Out:
# Computed 115 flowpipes in 1.38462519646 sec
# In prepare! flowpipes_compo.size() = 115
# Prepared for plotting in 0.00251793861389 sec
# domain = [0.00000000000000000 .. 5.0000000000000000]
# roots = [[0.73999473446266517 .. 2.3917046091295045]]
# seg_domain = [0.00000000000000000 .. 5.0000000000000000]
# roots = [[0.73999473446266517 .. 2.3917046091295045]]
# domain = [0.00000000000000000 .. 5.0000000000000000]
# roots = [[0.00000000000000000 .. 0.86802860497076651],
#  [0.88067123177899719 .. 0.88956119414532109]]
# seg_domain = [0.00000000000000000 .. 2.3917046091295045]
# roots = [[0.00000000000000000 .. 0.86802860497076651],
#  [0.88067123177899719 .. 0.88956119414532109]]
# Monitored signal 9.38489985466 sec
# Graphics object consisting of 2 graphics primitives

# %%
Atomic(x - 1.15).signal_for_system(vf, v3, 5, order=5, step=(0.01, 0.5),
                                   precondition=1,
                                   estimation=1e-3,
                                   integrationScheme=2,
                                   cutoff_threshold=1e-5,
                                   symbolic_composition=True,
                                   use_masks=True)
# Out:
# Computed 115 flowpipes in 1.57173323631 sec
# In prepare! flowpipes_compo.size() = 115
# Prepared for plotting in 0.000960826873779 sec
# domain = [0.00000000000000000 .. 5.0000000000000000]
# roots = [[0.00000000000000000 .. 0.86802860497076651],
#  [0.88067123177899719 .. 0.88956119414532109],
#  [2.4572093392192906 .. 3.1521148076320591]]
# seg_domain = [0.00000000000000000 .. 5.0000000000000000]
# roots = [[0.00000000000000000 .. 0.86802860497076651],
#  [0.88067123177899719 .. 0.88956119414532109],
#  [2.4572093392192906 .. 3.1521148076320591]]
# Monitored signal 2.20943784714 sec
# Signal([0.00000000000000000 .. 5.0000000000000000], [([0.86802860497076650 .. 0.88067123177899720], True), ([0.88956119414532108 .. 2.4572093392192907], True), ([3.1521148076320590 .. 5.0000000000000000], False)], mask=Mask([0.00000000000000000 .. 5.0000000000000000], [[0.00000000000000000 .. 5.0000000000000000]]))

# %%
reach = Reach(vf, v3, 10,
              order=5, step=(0.01, 0.5),
              precondition=1,
              estimation=1e-3,
              integrationScheme=2,
              cutoff_threshold=1e-7,
              symbolic_composition=True)

# %%
# %%time
reach.prepare_for_plotting()
# Out:
# CPU times: user 3.01 s, sys: 2.91 ms, total: 3.01 s
# Wall time: 3.04 s

# %%
reach.wplot('x', 'y')
# Out:
# In prepare! flowpipes_compo.size() = 132
# <wand.image.Image: 6eb73fc 'PS' (720x504)>

# %% [markdown]
# ### Polynomial plot

# %%
p + reach.sage_interval_plot('x', 'y',
                             poly=(x - 1)^2 + y^2 - 0.2,
                             aspect_ratio='automatic')
# Out:
# Graphics object consisting of 106 graphics primitives

# %% [markdown]
# ## Context

# %%
kwargs = dict(
    order=5, step=(0.01, 0.5),
    precondition=1,
    estimation=1e-3,
    integrationScheme=2,
    cutoff_threshold=1e-5,
    verbosity=0,
    epsilon_ctx=0.1,
#    symbolic_composition=True,
)
args = (vf, v3, 7)

# %%
{x: RIF(0.05,0.1)} >> G(RIF(0,0.2), P)
# Out:
# C({x: [0.050000000000000002 .. 0.10000000000000001]}, G([0.00000000000000000 .. 0.20000000000000002], Atomic(x^2 + y^2 - 2.00000000000000*x + 0.800000000000000)))

# %%
sig = ({x: RIF(0.05,0.1)} >> G(RIF(0,0.2), P)
       ).signal_for_system(vf, v3, 10, **kwargs)
# Out:
# Computed 143 flowpipes in 1.64693617821 sec
# In prepare! flowpipes_compo.size() = 143
# Prepared for plotting in 0.000645160675049 sec
# In C.signal
# {'precondition': 1, 'verbosity': 0, 'epsilon_ctx': 0.100000000000000, 'step': (0.0100000000000000, 0.500000000000000), 'cutoff_threshold': 0.0000100000000000000, 'integrationScheme': 2, 'estimation': 0.00100000000000000, 'order': 5}
# mask = None
# Computed 14 flowpipes in 0.178845882416 sec
# In prepare! flowpipes_compo.size() = 14
# Prepared for plotting in 0.000925064086914 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = []
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = []
# Monitored signal 0.139825820923 sec
# Computed 15 flowpipes in 0.191457033157 sec
# In prepare! flowpipes_compo.size() = 15
# Prepared for plotting in 0.000195980072021 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.191292762756 sec
# Computed 15 flowpipes in 0.187021017075 sec
# In prepare! flowpipes_compo.size() = 15
# Prepared for plotting in 0.00028395652771 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.187718868256 sec
# Computed 13 flowpipes in 0.174787044525 sec
# In prepare! flowpipes_compo.size() = 13
# Prepared for plotting in 0.000210046768188 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.163563728333 sec
# Computed 12 flowpipes in 0.161823987961 sec
# In prepare! flowpipes_compo.size() = 12
# Prepared for plotting in 0.00071907043457 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.140904664993 sec
# Computed 12 flowpipes in 0.158236980438 sec
# In prepare! flowpipes_compo.size() = 12
# Prepared for plotting in 0.000460863113403 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.138365745544 sec
# Computed 12 flowpipes in 0.152416229248 sec
# In prepare! flowpipes_compo.size() = 12
# Prepared for plotting in 0.000349998474121 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.130799531937 sec
# Computed 11 flowpipes in 0.145544052124 sec
# In prepare! flowpipes_compo.size() = 11
# Prepared for plotting in 0.000690937042236 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.122785806656 sec
# Computed 11 flowpipes in 0.149620056152 sec
# In prepare! flowpipes_compo.size() = 11
# Prepared for plotting in 0.000154972076416 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.115234613419 sec
# Computed 11 flowpipes in 0.148053884506 sec
# In prepare! flowpipes_compo.size() = 11
# Prepared for plotting in 0.000586032867432 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.131967782974 sec
# Computed 11 flowpipes in 0.145478963852 sec
# In prepare! flowpipes_compo.size() = 11
# Prepared for plotting in 0.00059700012207 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.110243797302 sec
# Computed 11 flowpipes in 0.139101028442 sec
# In prepare! flowpipes_compo.size() = 11
# Prepared for plotting in 0.000563859939575 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.104906797409 sec
# Computed 11 flowpipes in 0.141247034073 sec
# In prepare! flowpipes_compo.size() = 11
# Prepared for plotting in 0.000372886657715 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.105248689651 sec
# Computed 11 flowpipes in 0.141122102737 sec
# In prepare! flowpipes_compo.size() = 11
# Prepared for plotting in 0.000728845596313 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.127341747284 sec
# Computed 9 flowpipes in 0.122469902039 sec
# In prepare! flowpipes_compo.size() = 9
# Prepared for plotting in 0.000204086303711 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0886247158051 sec
# Computed 9 flowpipes in 0.123570919037 sec
# In prepare! flowpipes_compo.size() = 9
# Prepared for plotting in 0.000349044799805 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0820076465607 sec
# Computed 9 flowpipes in 0.11994099617 sec
# In prepare! flowpipes_compo.size() = 9
# Prepared for plotting in 0.000488996505737 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0853595733643 sec
# Computed 8 flowpipes in 0.110313892365 sec
# In prepare! flowpipes_compo.size() = 8
# Prepared for plotting in 0.000322103500366 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0627257823944 sec
# Computed 8 flowpipes in 0.105640172958 sec
# In prepare! flowpipes_compo.size() = 8
# Prepared for plotting in 0.000183820724487 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0681667327881 sec
# Computed 8 flowpipes in 0.107429981232 sec
# In prepare! flowpipes_compo.size() = 8
# Prepared for plotting in 0.000349044799805 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0652837753296 sec
# Computed 8 flowpipes in 0.127983093262 sec
# In prepare! flowpipes_compo.size() = 8
# Prepared for plotting in 0.000211954116821 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0808658599854 sec
# Computed 7 flowpipes in 0.0941450595856 sec
# In prepare! flowpipes_compo.size() = 7
# Prepared for plotting in 0.000750064849854 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0582206249237 sec
# Computed 6 flowpipes in 0.0857989788055 sec
# In prepare! flowpipes_compo.size() = 6
# Prepared for plotting in 0.000839948654175 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0
# <b>limit_output extension: Maximum message size of 10000 exceeded with 10327 characters</b>

# %%
sig.plot()
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
sigM = ({x: RIF(0.05,0.1)} >> G(RIF(0,0.2), P)
       ).signal_for_system(vf, v3, 10, use_masks=True, **kwargs)
sigM
# Out:
# Computed 143 flowpipes in 1.79495429993 sec
# In prepare! flowpipes_compo.size() = 143
# Prepared for plotting in 0.000601053237915 sec
# In C.signal
# {'precondition': 1, 'verbosity': 0, 'epsilon_ctx': 0.100000000000000, 'step': (0.0100000000000000, 0.500000000000000), 'cutoff_threshold': 0.0000100000000000000, 'integrationScheme': 2, 'estimation': 0.00100000000000000, 'order': 5}
# mask = Mask([0.00000000000000000 .. 10.000000000000000], [[0.00000000000000000 .. 10.000000000000000]])
# mask = Mask([0.00000000000000000 .. 10.000000000000000], [[0.00000000000000000 .. 10.000000000000000]])
# Computed 14 flowpipes in 0.206800937653 sec
# In prepare! flowpipes_compo.size() = 14
# Prepared for plotting in 0.00109004974365 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = []
# seg_domain = [0.00000000000000000 .. 0.20000000000000002]
# roots = []
# Monitored signal 0.147114753723 sec
# Computed 15 flowpipes in 0.204417943954 sec
# In prepare! flowpipes_compo.size() = 15
# Prepared for plotting in 0.000490188598633 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20000000000000043]]
# seg_domain = [0.00000000000000000 .. 0.20000000000000002]
# roots = [[0.00000000000000000 .. 0.20000000000000043]]
# 0 at 0.200000000000001
# Monitored signal 0.204516649246 sec
# Computed 15 flowpipes in 0.226850986481 sec
# In prepare! flowpipes_compo.size() = 15
# Prepared for plotting in 0.000363111495972 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20000000000000043]]
# seg_domain = [0.00000000000000000 .. 0.20000000000000002]
# roots = [[0.00000000000000000 .. 0.20000000000000043]]
# 0 at 0.200000000000001
# Monitored signal 0.223146677017 sec
# Computed 13 flowpipes in 0.182183980942 sec
# In prepare! flowpipes_compo.size() = 13
# Prepared for plotting in 0.000706911087036 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20000000000000040]]
# seg_domain = [0.00000000000000000 .. 0.20000000000000002]
# roots = [[0.00000000000000000 .. 0.20000000000000040]]
# 0 at 0.200000000000001
# Monitored signal 0.175825834274 sec
# Computed 12 flowpipes in 0.185878992081 sec
# In prepare! flowpipes_compo.size() = 12
# Prepared for plotting in 0.00117206573486 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20000000000000035]]
# seg_domain = [0.00000000000000000 .. 0.20000000000000002]
# roots = [[0.00000000000000000 .. 0.20000000000000035]]
# 0 at 0.200000000000001
# Monitored signal 0.177051782608 sec
# Computed 12 flowpipes in 0.202128887177 sec
# In prepare! flowpipes_compo.size() = 12
# Prepared for plotting in 0.000214099884033 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20000000000000035]]
# seg_domain = [0.00000000000000000 .. 0.20000000000000002]
# roots = [[0.00000000000000000 .. 0.20000000000000035]]
# 0 at 0.200000000000001
# Monitored signal 0.154684782028 sec
# Computed 12 flowpipes in 0.173082113266 sec
# In prepare! flowpipes_compo.size() = 12
# Prepared for plotting in 0.000396013259888 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20000000000000035]]
# seg_domain = [0.00000000000000000 .. 0.20000000000000002]
# roots = [[0.00000000000000000 .. 0.20000000000000035]]
# 0 at 0.200000000000001
# Monitored signal 0.148112773895 sec
# Computed 11 flowpipes in 0.166264057159 sec
# In prepare! flowpipes_compo.size() = 11
# Prepared for plotting in 0.00039005279541 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20000000000000032]]
# seg_domain = [0.00000000000000000 .. 0.20000000000000002]
# roots = [[0.00000000000000000 .. 0.20000000000000032]]
# 0 at 0.200000000000001
# Monitored signal 0.147184848785 sec
# Computed 11 flowpipes in 0.158672809601 sec
# In prepare! flowpipes_compo.size() = 11
# Prepared for plotting in 0.000325202941895 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20000000000000032]]
# seg_domain = [0.00000000000000000 .. 0.20000000000000002]
# roots = [[0.00000000000000000 .. 0.20000000000000032]]
# 0 at 0.200000000000001
# Monitored signal 0.125995635986 sec
# Computed 11 flowpipes in 0.162025928497 sec
# In prepare! flowpipes_compo.size() = 11
# Prepared for plotting in 0.000231981277466 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20000000000000032]]
# seg_domain = [0.00000000000000000 .. 0.20000000000000002]
# roots = [[0.00000000000000000 .. 0.20000000000000032]]
# 0 at 0.200000000000001
# Monitored signal 0.137076854706 sec
# Computed 11 flowpipes in 0.166755914688 sec
# In prepare! flowpipes_compo.size() = 11
# Prepared for plotting in 0.000200033187866 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20000000000000032]]
# seg_domain = [0.00000000000000000 .. 0.20000000000000002]
# roots = [[0.00000000000000000 .. 0.20000000000000032]]
# 0 at 0.200000000000001
# Monitored signal 0.13685464859 sec
# Computed 11 flowpipes in 0.167407989502 sec
# In prepare! flowpipes_compo.size() = 11
# Prepared for plotting in 0.000448942184448 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20000000000000032]]
# seg_domain = [0.00000000000000000 .. 0.20000000000000002]
# roots = [[0.00000000000000000 .. 0.20000000000000032]]
# 0 at 0.200000000000001
# Monitored signal 0.135321855545 sec
# Computed 11 flowpipes in 0.158254861832 sec
# In prepare! flowpipes_compo.size() = 11
# Prepared for plotting in 0.000347137451172 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20000000000000032]]
# seg_domain = [0.00000000000000000 .. 0.20000000000000002]
# roots = [[0.00000000000000000 .. 0.20000000000000032]]
# 0 at 0.200000000000001
# Monitored signal 0.11893081665 sec
# Computed 11 flowpipes in 0.176260948181 sec
# In prepare! flowpipes_compo.size() = 11
# Prepared for plotting in 0.00107908248901 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20000000000000032]]
# seg_domain = [0.00000000000000000 .. 0.20000000000000002]
# roots = [[0.00000000000000000 .. 0.20000000000000032]]
# 0 at 0.200000000000001
# Monitored signal 0.125843763351 sec
# Computed 9 flowpipes in 0.139357089996 sec
# In prepare! flowpipes_compo.size() = 9
# Prepared for plotting in 0.000221014022827 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20000000000000027]]
# seg_domain = [0.00000000000000000 .. 0.20000000000000002]
# roots = [[0.00000000000000000 .. 0.20000000000000027]]
# 0 at 0.200000000000001
# Monitored signal 0.102755784988 sec
# Computed 9 flowpipes in 0.150243997574 sec
# In prepare! flowpipes_compo.size() = 9
# Prepared for plotting in 0.00400495529175 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20000000000000027]]
# seg_domain = [0.00000000000000000 .. 0.20000000000000002]
# roots = [[0.00000000000000000 .. 0.20000000000000027]]
# 0 at 0.200000000000001
# Monitored signal 0.0930647850037 sec
# Computed 9 flowpipes in 0.137080907822 sec
# In prepare! flowpipes_compo.size() = 9
# Prepared for plotting in 0.000383138656616 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20000000000000027]]
# seg_domain = [0.00000000000000000 .. 0.20000000000000002]
# roots = [[0.00000000000000000 .. 0.20000000000000027]]
# 0 at 0.200000000000001
# Monitored signal 0.103606700897 sec
# Computed 8 flowpipes in 0.114489078522 sec
# In prepare! flowpipes_compo.size() = 8
# Prepared for plotting in 0.000333070755005 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20000000000000027]]
# seg_domain = [0.00000000000000000 .. 0.20000000000000002]
# roots = [[0.00000000000000000 .. 0.20000000000000027]]
# 0 at 0.200000000000001
# Monitored signal 0.0659766197205 sec
# Computed 8 flowpipes in 0.106204032898 sec
# In prepare! flowpipes_compo.size() = 8
# Prepared for plotting in 0.000423908233643 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20000000000000027]]
# seg_domain = [0.00000000000000000 .. 0.20000000000000002]
# roots = [[0.00000000000000000 .. 0.20000000000000027]]
# 0 at 0.200000000000001
# Monitored signal 0.0668716430664 sec
# Computed 8 flowpipes in 0.102656841278 sec
# In prepare! flowpipes_compo.size() = 8
# Prepared for plotting in 0.00019907951355 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20000000000000027]]
# seg_domain = [0.00000000000000000 .. 0.20000000000000002]
# roots = [[0.00000000000000000 .. 0.20000000000000027]]
# 0 at 0.200000000000001
# Monitored signal 0.0688927173615 sec
# Computed 8 flowpipes in 0.114481925964 sec
# In prepare! flowpipes_compo.size() = 8
# Prepared for plotting in 0.000699043273926 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20000000000000027]]
# seg_domain = [0.00000000000000000 .. 0.20000000000000002]
# roots = [[0.00000000000000000 .. 0.20000000000000027]]
# 0 at 0.200000000000001
# Monitored signal 0.0654757022858 sec
# Computed 7 flowpipes in 0.0990540981293 sec
# In prepare! flowpipes_compo.size() = 7
# Prepared for plotting in 0.000359058380127 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20000000000000024]]
# seg_domain = [0.00000000000000000 .. 0.20000000000000002]
# roots = [[0.00000000000000000 .. 0.20000000000000024]]
# 0 at 0.200000000000001
# Monitored signal 0.055793762207 sec
# Computed 6 flowpipes in 0.0869841575623 sec
# In prepare! flowpipes_compo.size() = 6
# Prepared for plotting in 0.000534057617188 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000
# <b>limit_output extension: Maximum message size of 10000 exceeded with 11250 characters</b>

# %%
sigM.plot()
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
sigM.mask
# Out:
# Mask([0.00000000000000000 .. 10.000000000000000], [[0.00000000000000000 .. 10.000000000000000]])

# %%
# %%time
sigG = G(RIF(10.2, 10.3), ({x: RIF(0.05,0.1)} >> G(RIF(0,0.2), P)),
         ).signal_for_system(vf, v3, 0, **kwargs)
# Out:
# Computed 145 flowpipes in 1.70415139198 sec
# In prepare! flowpipes_compo.size() = 145
# Prepared for plotting in 0.000690937042236 sec
# In G.signal
# In C.signal
# {'precondition': 1, 'verbosity': 0, 'epsilon_ctx': 0.100000000000000, 'step': (0.0100000000000000, 0.500000000000000), 'cutoff_threshold': 0.0000100000000000000, 'integrationScheme': 2, 'estimation': 0.00100000000000000, 'order': 5}
# mask = None
# Computed 14 flowpipes in 0.191476821899 sec
# In prepare! flowpipes_compo.size() = 14
# Prepared for plotting in 0.000595092773438 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = []
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = []
# Monitored signal 0.135485649109 sec
# Computed 15 flowpipes in 0.188107967377 sec
# In prepare! flowpipes_compo.size() = 15
# Prepared for plotting in 0.000257968902588 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.197209835052 sec
# Computed 13 flowpipes in 0.175936937332 sec
# In prepare! flowpipes_compo.size() = 13
# Prepared for plotting in 0.000407934188843 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.172862768173 sec
# Computed 12 flowpipes in 0.173864841461 sec
# In prepare! flowpipes_compo.size() = 12
# Prepared for plotting in 0.000241994857788 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.177002906799 sec
# Computed 12 flowpipes in 0.18597984314 sec
# In prepare! flowpipes_compo.size() = 12
# Prepared for plotting in 0.000265121459961 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.166619777679 sec
# Computed 12 flowpipes in 0.169732093811 sec
# In prepare! flowpipes_compo.size() = 12
# Prepared for plotting in 0.000407934188843 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.175797700882 sec
# Computed 11 flowpipes in 0.155680894852 sec
# In prepare! flowpipes_compo.size() = 11
# Prepared for plotting in 0.000519990921021 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.131025791168 sec
# Computed 11 flowpipes in 0.158607006073 sec
# In prepare! flowpipes_compo.size() = 11
# Prepared for plotting in 0.000179052352905 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.14004778862 sec
# Computed 11 flowpipes in 0.156141042709 sec
# In prepare! flowpipes_compo.size() = 11
# Prepared for plotting in 0.000484943389893 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.122797727585 sec
# Computed 11 flowpipes in 0.15562915802 sec
# In prepare! flowpipes_compo.size() = 11
# Prepared for plotting in 0.000197887420654 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.132627725601 sec
# Computed 11 flowpipes in 0.161619901657 sec
# In prepare! flowpipes_compo.size() = 11
# Prepared for plotting in 0.000603914260864 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.116028785706 sec
# Computed 11 flowpipes in 0.150166988373 sec
# In prepare! flowpipes_compo.size() = 11
# Prepared for plotting in 0.000216960906982 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.112814903259 sec
# Computed 11 flowpipes in 0.148344039917 sec
# In prepare! flowpipes_compo.size() = 11
# Prepared for plotting in 0.000860929489136 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.114673852921 sec
# Computed 11 flowpipes in 0.152719974518 sec
# In prepare! flowpipes_compo.size() = 11
# Prepared for plotting in 0.00049614906311 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.110952615738 sec
# Computed 9 flowpipes in 0.124587059021 sec
# In prepare! flowpipes_compo.size() = 9
# Prepared for plotting in 0.000261068344116 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.105610609055 sec
# Computed 8 flowpipes in 0.11722612381 sec
# In prepare! flowpipes_compo.size() = 8
# Prepared for plotting in 0.000383853912354 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0701777935028 sec
# Computed 8 flowpipes in 0.117905855179 sec
# In prepare! flowpipes_compo.size() = 8
# Prepared for plotting in 0.00058913230896 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0763087272644 sec
# Computed 8 flowpipes in 0.121513128281 sec
# In prepare! flowpipes_compo.size() = 8
# Prepared for plotting in 0.000289916992188 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0726897716522 sec
# Computed 8 flowpipes in 0.110709905624 sec
# In prepare! flowpipes_compo.size() = 8
# Prepared for plotting in 0.000655174255371 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0745117664337 sec
# Computed 8 flowpipes in 0.111932039261 sec
# In prepare! flowpipes_compo.size() = 8
# Prepared for plotting in 0.000426054000854 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0678126811981 sec
# Computed 8 flowpipes in 0.126637935638 sec
# In prepare! flowpipes_compo.size() = 8
# Prepared for plotting in 0.00036096572876 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0682239532471 sec
# Computed 7 flowpipes in 0.0964660644531 sec
# In prepare! flowpipes_compo.size() = 7
# Prepared for plotting in 0.000591993331909 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0574867725372 sec
# Computed 6 flowpipes in 0.0853509902954 sec
# In prepare! flowpipes_compo.size() = 6
# Prepared for plotting in 0.000135898590088 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0458056926727 sec
# Computed 6 flowpipes in 0.0896210670471 sec
# In prepare! flowpipes_compo.size() = 6
# Prepared for plotting in 0.000571012496948 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.04469871521 sec
# Computed 6 flowpipes in 0.0830380916595 sec
# In prepare! flowpipes_compo.size() = 6
# Prepared for plotting in 0.000694990158081 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0474877357483 sec
# Computed 6 flowpipes in 0.0892560482025 sec
# In prepare! flowpipes_compo.size() = 6
# Prepared for plotting in 0.000176906585693 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0503268241882 sec
# Computed 6 flowpipes in 0.0896649360657 sec
# In prepare! flowpipes_compo.size() = 6
# Prepared for plotting in 0.000514984130859 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0428988933563 sec
# Computed 6 flowpipes in 0.0881850719452 sec
# In prepare! flowpipes_compo.size() = 6
# Prepared for plotting in 0.00106191635132 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.042017698288 sec
# Computed 6 flowpipes in 0.0917608737946 sec
# In prepare! flowpipes_compo.size() = 6
# Prepared for plotting in 0.000606060028076 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0507566928864 sec
# Computed 6 flowpipes in 0.0850131511688 sec
# In prepare! flowpipes_compo.size() = 6
# Prepared for plotting in 0.000504970550537 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0382037162781 sec
# Computed 6 flowpipes in 0.0841269493103 sec
# In prepare! flowpipes_compo.size() = 6
# Prepared for plotting in 0.000287055969238 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0381307601929 sec
# Computed 6 flowpipes in 0.0956928730011 sec
# In prepare! flowpipes_compo.size() = 6
# Prepared for plotting in 0.000363111495972 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0516836643219 sec
# Computed 6 flowpipes in 0.107697963715 sec
# In prepare! flowpipes_compo.size() = 6
# Prepared for plotting in 0.000525951385498 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0429198741913 sec
# Computed 5 flowpipes in 0.0929338932037 sec
# In prepare! flowpipes_compo.size() = 5
# Prepared for plotting in 0.000355958938599 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0410239696503 sec
# Computed 5 flowpipes in 0.0919680595398 sec
# In prepare! flowpipes_compo.size() = 5
# Prepared for plotting in 0.000935077667236 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0356366634369 sec
# Computed 5 flowpipes in 0.0821390151978 sec
# In prepare! flowpipes_compo.size() = 5
# Prepared for plotting in 0.000190019607544 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0334618091583 sec
# Computed 3 flowpipes in 0.054792881012 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000472068786621 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0179808139801 sec
# Computed 3 flowpipes in 0.053631067276 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000453948974609 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.017374753952 sec
# Computed 3 flowpipes in 0.0533339977264 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000439882278442 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0192458629608 sec
# Computed 3 flowpipes in 0.0571429729462 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000267028808594 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.017689704895 sec
# Computed 3 flowpipes in 0.0574948787689 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.00025200843811 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0199408531189 sec
# Computed 3 flowpipes in 0.0527369976044 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000236034393311 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0214247703552 sec
# Computed 3 flowpipes in 0.0586559772491 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000447034835815 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0177667140961 sec
# Computed 3 flowpipes in 0.0494289398193 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000459909439087 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0175199508667 sec
# Computed 3 flowpipes in 0.0507950782776 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000321865081787 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0148859024048 sec
# Computed 3 flowpipes in 0.0525758266449 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000216007232666 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0175919532776 sec
# Computed 3 flowpipes in 0.0535781383514 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000172853469849 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0166437625885 sec
# Computed 3 flowpipes in 0.0487329959869 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000452041625977 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0157907009125 sec
# Computed 3 flowpipes in 0.0505590438843 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000409841537476 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0150539875031 sec
# Computed 3 flowpipes in 0.0515561103821 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000573873519897 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0143587589264 sec
# Computed 3 flowpipes in 0.0517089366913 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000381946563721 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0166218280792 sec
# Computed 3 flowpipes in 0.0501799583435 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000426054000854 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0154795646667 sec
# Computed 3 flowpipes in 0.0497219562531 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000332117080688 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0147137641907 sec
# Computed 3 flowpipes in 0.0516998767853 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000406980514526 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0149466991425 sec
# Computed 3 flowpipes in 0.0499060153961 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000511884689331 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0141837596893 sec
# Computed 3 flowpipes in 0.0571010112762 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.00102114677429 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0242116451263 sec
# Computed 3 flowpipes in 0.0690739154816 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000286102294922 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0182726383209 sec
# Computed 3 flowpipes in 0.0510568618774 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000492095947266 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0146117210388 sec
# Computed 3 flowpipes in 0.0563840866089 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000185012817383 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0178327560425 sec
# Computed 3 flowpipes in 0.0515120029449 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000392913818359 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0138447284698 sec
# Computed 3 flowpipes in 0.0584781169891 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000515937805176 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0189967155457 sec
# Computed 3 flowpipes in 0.057580947876 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000291109085083 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0154156684875 sec
# Computed 3 flowpipes in 0.0555250644684 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000516891479492 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0147838592529 sec
# Computed 3 flowpipes in 0.0552220344543 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000359058380127 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0174908638 sec
# Computed 3 flowpipes in 0.0672528743744 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000417947769165 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0176777839661 sec
# Computed 3 flowpipes in 0.062803030014 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.00106811523438 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0198817253113 sec
# Computed 3 flowpipes in 0.0578851699829 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000568866729736 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0146417617798 sec
# Computed 3 flowpipes in 0.0541870594025 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000458002090454 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0142707824707 sec
# Computed 3 flowpipes in 0.0543100833893 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000422954559326 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0147697925568 sec
# Computed 3 flowpipes in 0.0488519668579 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000459909439087 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0134449005127 sec
# Computed 3 flowpipes in 0.0524251461029 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000324010848999 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0138328075409 sec
# Computed 3 flowpipes in 0.0504779815674 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.00044584274292 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0162909030914 sec
# Computed 3 flowpipes in 0.0725889205933 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000235080718994 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0174276828766 sec
# Computed 3 flowpipes in 0.0626940727234 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000916957855225 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0182638168335 sec
# Computed 3 flowpipes in 0.0591330528259 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000520944595337 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.13125000000000001],
#  [0.16744751804631213 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.13125000000000001],
#  [0.16744751804631213 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0245697498322 sec
# Computed 2 flowpipes in 0.0373499393463 sec
# In prepare! flowpipes_compo.size() = 2
# Prepared for plotting in 0.000643968582153 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.065706854810561488 .. 0.12500000000000000]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.065706854810561488 .. 0.12500000000000000]]
# Monitored signal 0.0113897323608 sec
# Computed 2 flowpipes in 0.0372250080109 sec
# In prepare! flowpipes_compo.size() = 2
# Prepared for plotting in 0.000457048416138 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = []
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = []
# Monitored signal 0.00653386116028 sec
# Computed 2 flowpipes in 0.0394868850708 sec
# In prepare! flowpipes_compo.size() = 2
# Prepared for plotting in 0.00044322013855 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = []
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = []
# Monitored signal 0.00882267951965 sec
# Monitored signal 14.9493536949 sec
# CPU times: user 16.5 s, sys: 135 ms, total: 16.6 s
# Wall time: 16.7 s

# %%
sigG(0)
# Out:
# False

# %%
# %%time
sigG = G(RIF(10.2, 10.3), ({x: RIF(0.05,0.1)} >> G(RIF(0,0.2), P)),
         ).signal_for_system(vf, v3, 0, use_masks=True, **kwargs)
# Out:
# Computed 145 flowpipes in 1.69530534744 sec
# In prepare! flowpipes_compo.size() = 145
# Prepared for plotting in 0.00082802772522 sec
# In G.signal
# In C.signal
# {'precondition': 1, 'verbosity': 0, 'epsilon_ctx': 0.100000000000000, 'step': (0.0100000000000000, 0.500000000000000), 'cutoff_threshold': 0.0000100000000000000, 'integrationScheme': 2, 'estimation': 0.00100000000000000, 'order': 5}
# mask = Mask([10.199999999999999 .. 10.300000000000001], [[10.199999999999999 .. 10.300000000000001]])
# mask = Mask([10.199999999999999 .. 10.300000000000001], [[10.199999999999999 .. 10.300000000000001]])
# Computed 2 flowpipes in 0.0245931148529 sec
# In prepare! flowpipes_compo.size() = 2
# Prepared for plotting in 0.000503063201904 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = []
# seg_domain = [0.00000000000000000 .. 0.20000000000000002]
# roots = []
# Monitored signal 0.00525569915771 sec
# Monitored signal 1.96939873695 sec
# CPU times: user 3.65 s, sys: 8.62 ms, total: 3.66 s
# Wall time: 3.67 s

# %%
# %%time
sigG = F(RIF(5, 5.1),
         {y: RIF(1, 1.5)} >>
         G(RIF(10.2, 10.3),
           {x: RIF(0.05,0.1)} >>
            G(RIF(0,0.2), P)),
         ).signal_for_system(vf, v3, 0, **kwargs)
# Out:
# Computed 115 flowpipes in 1.50969028473 sec
# In prepare! flowpipes_compo.size() = 115
# Prepared for plotting in 0.000319957733154 sec
# In C.signal
# {'precondition': 1, 'verbosity': 0, 'epsilon_ctx': 0.100000000000000, 'step': (0.0100000000000000, 0.500000000000000), 'cutoff_threshold': 0.0000100000000000000, 'integrationScheme': 2, 'estimation': 0.00100000000000000, 'order': 5}
# mask = None
# Computed 143 flowpipes in 1.63874697685 sec
# In prepare! flowpipes_compo.size() = 143
# Prepared for plotting in 0.000261068344116 sec
# In G.signal
# In C.signal
# {'precondition': 1, 'verbosity': 0, 'epsilon_ctx': 0.100000000000000, 'step': (0.0100000000000000, 0.500000000000000), 'cutoff_threshold': 0.0000100000000000000, 'integrationScheme': 2, 'estimation': 0.00100000000000000, 'order': 5}
# mask = None
# Computed 15 flowpipes in 0.209183931351 sec
# In prepare! flowpipes_compo.size() = 15
# Prepared for plotting in 0.000375986099243 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.225732803345 sec
# Computed 15 flowpipes in 0.223998069763 sec
# In prepare! flowpipes_compo.size() = 15
# Prepared for plotting in 0.00059700012207 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.220365762711 sec
# Computed 15 flowpipes in 0.197853088379 sec
# In prepare! flowpipes_compo.size() = 15
# Prepared for plotting in 0.000428915023804 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.216535806656 sec
# Computed 12 flowpipes in 0.155427932739 sec
# In prepare! flowpipes_compo.size() = 12
# Prepared for plotting in 0.000561952590942 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.15235376358 sec
# Computed 12 flowpipes in 0.179363965988 sec
# In prepare! flowpipes_compo.size() = 12
# Prepared for plotting in 0.000200986862183 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.181036710739 sec
# Computed 12 flowpipes in 0.177635908127 sec
# In prepare! flowpipes_compo.size() = 12
# Prepared for plotting in 0.000649213790894 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.181416749954 sec
# Computed 12 flowpipes in 0.197917938232 sec
# In prepare! flowpipes_compo.size() = 12
# Prepared for plotting in 0.000259160995483 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.167303562164 sec
# Computed 11 flowpipes in 0.173522949219 sec
# In prepare! flowpipes_compo.size() = 11
# Prepared for plotting in 0.000268936157227 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.147444725037 sec
# Computed 11 flowpipes in 0.186180114746 sec
# In prepare! flowpipes_compo.size() = 11
# Prepared for plotting in 0.000153064727783 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.145098686218 sec
# Computed 11 flowpipes in 0.179603099823 sec
# In prepare! flowpipes_compo.size() = 11
# Prepared for plotting in 0.000307083129883 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.131749629974 sec
# Computed 11 flowpipes in 0.15546298027 sec
# In prepare! flowpipes_compo.size() = 11
# Prepared for plotting in 0.000376224517822 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.125280618668 sec
# Computed 9 flowpipes in 0.125318050385 sec
# In prepare! flowpipes_compo.size() = 9
# Prepared for plotting in 0.000304937362671 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0879118442535 sec
# Computed 9 flowpipes in 0.122727155685 sec
# In prepare! flowpipes_compo.size() = 9
# Prepared for plotting in 0.000643968582153 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0935666561127 sec
# Computed 9 flowpipes in 0.120975017548 sec
# In prepare! flowpipes_compo.size() = 9
# Prepared for plotting in 0.000181913375854 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0878119468689 sec
# Computed 9 flowpipes in 0.129006147385 sec
# In prepare! flowpipes_compo.size() = 9
# Prepared for plotting in 0.000452995300293 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0945286750793 sec
# Computed 9 flowpipes in 0.133627891541 sec
# In prepare! flowpipes_compo.size() = 9
# Prepared for plotting in 0.000662088394165 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0911948680878 sec
# Computed 8 flowpipes in 0.117420196533 sec
# In prepare! flowpipes_compo.size() = 8
# Prepared for plotting in 0.000838994979858 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0750956535339 sec
# Computed 8 flowpipes in 0.111927032471 sec
# In prepare! flowpipes_compo.size() = 8
# Prepared for plotting in 0.000779867172241 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0751647949219 sec
# Computed 8 flowpipes in 0.116088867188 sec
# In prepare! flowpipes_compo.size() = 8
# Prepared for plotting in 0.000373125076294 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0751097202301 sec
# Computed 8 flowpipes in 0.124844074249 sec
# In prepare! flowpipes_compo.size() = 8
# Prepared for plotting in 0.000516891479492 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.071525812149 sec
# Computed 7 flowpipes in 0.105602025986 sec
# In prepare! flowpipes_compo.size() = 7
# Prepared for plotting in 0.000711917877197 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0675847530365 sec
# Computed 7 flowpipes in 0.10004901886 sec
# In prepare! flowpipes_compo.size() = 7
# Prepared for plotting in 0.000401020050049 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0560367107391 sec
# Computed 6 flowpipes in 0.0853490829468 sec
# In prepare! flowpipes_compo.size() = 6
# Prepared for plotting in 0.000757932662964 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0497817993164 sec
# Computed 6 flowpipes in 0.0897769927979 sec
# In prepare! flowpipes_compo.size() = 6
# Prepared for plotting in 0.000635147094727 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0460736751556 sec
# Computed 6 flowpipes in 0.0851359367371 sec
# In prepare! flowpipes_compo.size() = 6
# Prepared for plotting in 0.000609159469604 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0457875728607 sec
# Computed 6 flowpipes in 0.0910880565643 sec
# In prepare! flowpipes_compo.size() = 6
# Prepared for plotting in 0.000386953353882 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0502316951752 sec
# Computed 6 flowpipes in 0.0899901390076 sec
# In prepare! flowpipes_compo.size() = 6
# Prepared for plotting in 0.000295877456665 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0430767536163 sec
# Computed 6 flowpipes in 0.0810329914093 sec
# In prepare! flowpipes_compo.size() = 6
# Prepared for plotting in 0.000476121902466 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0425508022308 sec
# Computed 6 flowpipes in 0.100118875504 sec
# In prepare! flowpipes_compo.size() = 6
# Prepared for plotting in 0.000832080841064 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0467386245728 sec
# Computed 6 flowpipes in 0.108113050461 sec
# In prepare! flowpipes_compo.size() = 6
# Prepared for plotting in 0.000488996505737 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0620477199554 sec
# Computed 6 flowpipes in 0.120518922806 sec
# In prepare! flowpipes_compo.size() = 6
# Prepared for plotting in 0.000954151153564 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0525107383728 sec
# Computed 6 flowpipes in 0.107208967209 sec
# In prepare! flowpipes_compo.size() = 6
# Prepared for plotting in 0.000362157821655 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0518946647644 sec
# Computed 6 flowpipes in 0.110403776169 sec
# In prepare! flowpipes_compo.size() = 6
# Prepared for plotting in 0.000754117965698 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0678956508636 sec
# Computed 6 flowpipes in 0.110799074173 sec
# In prepare! flowpipes_compo.size() = 6
# Prepared for plotting in 0.000344038009644 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0520987510681 sec
# Computed 6 flowpipes in 0.11624288559 sec
# In prepare! flowpipes_compo.size() = 6
# Prepared for plotting in 0.000478982925415 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0489168167114 sec
# Computed 5 flowpipes in 0.093493938446 sec
# In prepare! flowpipes_compo.size() = 5
# Prepared for plotting in 0.000938177108765 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0439646244049 sec
# Computed 5 flowpipes in 0.0874540805817 sec
# In prepare! flowpipes_compo.size() = 5
# Prepared for plotting in 0.000495910644531 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0349757671356 sec
# Computed 5 flowpipes in 0.0925481319427 sec
# In prepare! flowpipes_compo.size() = 5
# Prepared for plotting in 0.00103378295898 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0459649562836 sec
# Computed 3 flowpipes in 0.0680658817291 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000524044036865 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.020519733429 sec
# Computed 3 flowpipes in 0.0711541175842 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000759840011597 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0255937576294 sec
# Computed 3 flowpipes in 0.066018819809 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.00106501579285 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0234267711639 sec
# Computed 3 flowpipes in 0.066722869873 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.00100111961365 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0238146781921 sec
# Computed 3 flowpipes in 0.066055059433 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000388860702515 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0222508907318 sec
# Computed 3 flowpipes in 0.0616800785065 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.00096607208252 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0175817012787 sec
# Computed 3 flowpipes in 0.0625581741333 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000545978546143 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0198826789856 sec
# Computed 3 flowpipes in 0.0599188804626 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000524997711182 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0183138847351 sec
# Computed 3 flowpipes in 0.0695850849152 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000306129455566 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.01704454422 sec
# Computed 3 flowpipes in 0.0614459514618 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000690937042236 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0196797847748 sec
# Computed 3 flowpipes in 0.062842130661 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000489950180054 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0206928253174 sec
# Computed 3 flowpipes in 0.0505979061127 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.00048303604126 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0170638561249 sec
# Computed 3 flowpipes in 0.0558269023895 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000504016876221 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0157957077026 sec
# Computed 3 flowpipes in 0.0531899929047 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000324964523315 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.018355846405 sec
# Computed 3 flowpipes in 0.0512499809265 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000308990478516 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0147099494934 sec
# Computed 3 flowpipes in 0.0498869419098 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000494956970215 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0146727561951 sec
# Computed 3 flowpipes in 0.0539979934692 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000401020050049 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.014378786087 sec
# Computed 3 flowpipes in 0.0553619861603 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000671863555908 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0166788101196 sec
# Computed 3 flowpipes in 0.0533170700073 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000345945358276 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0153796672821 sec
# Computed 3 flowpipes in 0.0509021282196 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000181913375854 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0150198936462 sec
# Computed 3 flowpipes in 0.0514161586761 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000570058822632 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0161397457123 sec
# Computed 3 flowpipes in 0.0472288131714 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000315189361572 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0134797096252 sec
# Computed 3 flowpipes in 0.0478250980377 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000558853149414 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0140767097473 sec
# Computed 3 flowpipes in 0.047712802887 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000282049179077 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0131797790527 sec
# Computed 3 flowpipes in 0.0580039024353 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000478982925415 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0152707099915 sec
# Computed 3 flowpipes in 0.0523698329926 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.00106716156006 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0126786231995 sec
# Computed 3 flowpipes in 0.0490350723267 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000402927398682 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0133187770844 sec
# Computed 3 flowpipes in 0.0502262115479 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000340938568115 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0138776302338 sec
# Computed 3 flowpipes in 0.0503380298615 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000465154647827 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0164265632629 sec
# Computed 3 flowpipes in 0.0484108924866 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000364065170288 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0135846138 sec
# Computed 3 flowpipes in 0.0484409332275 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.00068211555481 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0127966403961 sec
# Computed 3 flowpipes in 0.0479121208191 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000293016433716 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.012544631958 sec
# Computed 3 flowpipes in 0.0522809028625 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.00037407875061 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0151557922363 sec
# Computed 3 flowpipes in 0.0493619441986 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000334024429321 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0124478340149 sec
# Computed 3 flowpipes in 0.0479531288147 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000537872314453 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0160458087921 sec
# Computed 3 flowpipes in 0.0478920936584 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000262022018433 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0151498317719 sec
# Computed 2 flowpipes in 0.0345749855042 sec
# In prepare! flowpipes_compo.size() = 2
# Prepared for plotting in 0.00068998336792 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.12500000000000000],
#  [0.19929912929777773 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.12500000000000000],
#  [0.19929912929777773 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0240876674652 sec
# Computed 2 flowpipes in 0.0318858623505 sec
# In prepare! flowpipes_compo.size() = 2
# Prepared for plotting in 0.000530958175659 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.12500000000000000]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.12500000000000000]]
# Monitored signal 0.0063169002533 sec
# Computed 2 flowpipes in 0.0343189239502 sec
# In prepare! flowpipes_compo.size() = 2
# Prepared for plotting in 0.000404119491577 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = []
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = []
# Monitored signal 0.00496482849121 sec
# Monitored signal 15.210329771 sec
# Computed 148 flowpipes in 1.66607904434 sec
# In prepare! flowpipes_compo.size() = 148
# Prepared for plotting in 0.000281095504761 sec
# In G.signal
# In C.signal
# {'precondition': 1, 'verbosity': 0, 'epsilon_ctx': 0.100000000000000, 'step': (0.0100000000000000, 0.500000000000000), 'cutoff_threshold': 0.0000100000000000000, 'integrationScheme': 2, 'estimation': 0.00100000000000000, 'order': 5}
# mask = None
# Computed 15 flowpipes in 0.183248996735 sec
# In prepare! flowpipes_compo.size() = 15
# Prepared for plotting in 0.00118088722229 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.194563865662 sec
# Computed 12 flowpipes in 0.163803100586 sec
# In prepare! flowpipes_compo.size() = 12
# Prepared for plotting in 0.00044584274292 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.13688492775 sec
# Computed 12 flowpipes in 0.15424990654 sec
# In prepare! flowpipes_compo.size() = 12
# Prepared for plotting in 0.000728130340576 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.141426563263 sec
# Computed 12 flowpipes in 0.158460140228 sec
# In prepare! flowpipes_compo.size() = 12
# Prepared for plotting in 0.000633955001831 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.144208669662 sec
# Computed 12 flowpipes in 0.155599117279 sec
# In prepare! flowpipes_compo.size() = 12
# Prepared for plotting in 0.000629901885986 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.129201889038 sec
# Computed 12 flowpipes in 0.162524938583 sec
# In prepare! flowpipes_compo.size() = 12
# Prepared for plotting in 0.000971078872681 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.154768705368 sec
# Computed 12 flowpipes in 0.145442962646 sec
# In prepare! flowpipes_compo.size() = 12
# Prepared for plotting in 0.000746011734009 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.138887643814 sec
# Computed 11 flowpipes in 0.145385026932 sec
# In prepare! flowpipes_compo.size() = 11
# Prepared for plotting in 0.00019097328186 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.113067626953 sec
# Computed 11 flowpipes in 0.143063783646 sec
# In prepare! flowpipes_compo.size() = 11
# Prepared for plotting in 0.000268220901489 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.113580703735 sec
# Computed 11 flowpipes in 0.146291017532 sec
# In prepare! flowpipes_compo.size() = 11
# Prepared for plotting in 0.000287055969238 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.117119789124 sec
# Computed 9 flowpipes in 0.112406015396 sec
# In prepare! flowpipes_compo.size() = 9
# Prepared for plotting in 0.000386953353882 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0871179103851 sec
# Computed 9 flowpipes in 0.113533973694 sec
# In prepare! flowpipes_compo.size() = 9
# Prepared for plotting in 0.000510931015015 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0844008922577 sec
# Computed 9 flowpipes in 0.11315202713 sec
# In prepare! flowpipes_compo.size() = 9
# Prepared for plotting in 0.000610113143921 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0918066501617 sec
# Computed 9 flowpipes in 0.128403902054 sec
# In prepare! flowpipes_compo.size() = 9
# Prepared for plotting in 0.000931978225708 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0854768753052 sec
# Computed 9 flowpipes in 0.120491981506 sec
# In prepare! flowpipes_compo.size() = 9
# Prepared for plotting in 0.000231027603149 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0867898464203 sec
# Computed 9 flowpipes in 0.117722988129 sec
# In prepare! flowpipes_compo.size() = 9
# Prepared for plotting in 0.000468969345093 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0916757583618 sec
# Computed 8 flowpipes in 0.105690956116 sec
# In prepare! flowpipes_compo.size() = 8
# Prepared for plotting in 0.000241994857788 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0764057636261 sec
# Computed 8 flowpipes in 0.111377954483 sec
# In prepare! flowpipes_compo.size() = 8
# Prepared for plotting in 0.000464916229248 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0707247257233 sec
# Computed 8 flowpipes in 0.109942913055 sec
# In prepare! flowpipes_compo.size() = 8
# Prepared for plotting in 0.000481128692627 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0694417953491 sec
# Computed 8 flowpipes in 0.110252857208 sec
# In prepare! flowpipes_compo.size() = 8
# Prepared for plotting in 0.000494956970215 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0664489269257 sec
# Computed 8 flowpipes in 0.107075929642 sec
# In prepare! flowpipes_compo.size() = 8
# Prepared for plotting in 0.0024139881134 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0683867931366 sec
# Computed 8 flowpipes in 0.103881835938 sec
# In prepare! flowpipes_compo.size() = 8
# Prepared for plotting in 0.00028920173645 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.070440530777 sec
# Computed 7 flowpipes in 0.0949220657349 sec
# In prepare! flowpipes_compo.size() = 7
# Prepared for plotting in 0.00045108795166 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0599927902222 sec
# Computed 7 flowpipes in 0.0972509384155 sec
# In prepare! flowpipes_compo.size() = 7
# Prepared for plotting in 0.000432014465332 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0661568641663 sec
# Computed 6 flowpipes in 0.0826280117035 sec
# In prepare! flowpipes_compo.size() = 6
# Prepared for plotting in 0.00061297416687 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.045806646347 sec
# Computed 6 flowpipes in 0.0876219272614 sec
# In prepare! flowpipes_compo.size() = 6
# Prepared for plotting in 0.000284910202026 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0465197563171 sec
# Computed 6 flowpipes in 0.085743188858 sec
# In prepare! flowpipes_compo.size() = 6
# Prepared for plotting in 0.000310897827148 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0424506664276 sec
# Computed 6 flowpipes in 0.0840759277344 sec
# In prepare! flowpipes_compo.size() = 6
# Prepared for plotting in 0.000772953033447 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.044784784317 sec
# Computed 6 flowpipes in 0.0818910598755 sec
# In prepare! flowpipes_compo.size() = 6
# Prepared for plotting in 0.000288963317871 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0442917346954 sec
# Computed 6 flowpipes in 0.0839610099792 sec
# In prepare! flowpipes_compo.size() = 6
# Prepared for plotting in 0.000340938568115 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0462808609009 sec
# Computed 6 flowpipes in 0.0916728973389 sec
# In prepare! flowpipes_compo.size() = 6
# Prepared for plotting in 0.000218152999878 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0387907028198 sec
# Computed 6 flowpipes in 0.0865089893341 sec
# In prepare! flowpipes_compo.size() = 6
# Prepared for plotting in 0.000509977340698 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0412948131561 sec
# Computed 6 flowpipes in 0.0844860076904 sec
# In prepare! flowpipes_compo.size() = 6
# Prepared for plotting in 0.000617980957031 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0409736633301 sec
# Computed 6 flowpipes in 0.0840840339661 sec
# In prepare! flowpipes_compo.size() = 6
# Prepared for plotting in 0.000597953796387 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# ...
# Computed 3 flowpipes in 0.0470399856567 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000555992126465 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0139145851135 sec
# Computed 3 flowpipes in 0.047168970108 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000279903411865 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0148057937622 sec
# Computed 3 flowpipes in 0.046110868454 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000159978866577 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0150027275085 sec
# Computed 3 flowpipes in 0.0468819141388 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000483989715576 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0153458118439 sec
# Computed 3 flowpipes in 0.047199010849 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000532865524292 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.013671875 sec
# Computed 3 flowpipes in 0.0477440357208 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000205993652344 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0138998031616 sec
# Computed 3 flowpipes in 0.0477609634399 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000308036804199 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0146386623383 sec
# Computed 3 flowpipes in 0.053906917572 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000386953353882 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0138597488403 sec
# Computed 3 flowpipes in 0.0512669086456 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000178098678589 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0157246589661 sec
# Computed 3 flowpipes in 0.048437833786 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000275135040283 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0152597427368 sec
# Computed 3 flowpipes in 0.0464689731598 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000491142272949 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0129127502441 sec
# Computed 3 flowpipes in 0.0488300323486 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000404119491577 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0157387256622 sec
# Computed 3 flowpipes in 0.047908782959 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000433206558228 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0129437446594 sec
# Computed 3 flowpipes in 0.0508110523224 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.00427103042603 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0141768455505 sec
# Computed 3 flowpipes in 0.0458168983459 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000241041183472 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0123116970062 sec
# Computed 3 flowpipes in 0.0577929019928 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000612020492554 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0220878124237 sec
# Computed 3 flowpipes in 0.0503480434418 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000450849533081 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0124707221985 sec
# Computed 3 flowpipes in 0.0451729297638 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000251054763794 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0144698619843 sec
# Computed 3 flowpipes in 0.0468060970306 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000614881515503 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0120897293091 sec
# Computed 3 flowpipes in 0.0481870174408 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.00092601776123 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0119276046753 sec
# Computed 3 flowpipes in 0.0455369949341 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000725030899048 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0125057697296 sec
# Computed 3 flowpipes in 0.0498521327972 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000397920608521 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.012188911438 sec
# Computed 3 flowpipes in 0.0442600250244 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000381946563721 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.015499830246 sec
# Computed 3 flowpipes in 0.045184135437 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.00072193145752 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0115838050842 sec
# Computed 3 flowpipes in 0.0570039749146 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000457048416138 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0118277072906 sec
# Computed 3 flowpipes in 0.0460121631622 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000468969345093 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0151495933533 sec
# Computed 3 flowpipes in 0.0457558631897 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000360012054443 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0114307403564 sec
# Computed 2 flowpipes in 0.0343899726868 sec
# In prepare! flowpipes_compo.size() = 2
# Prepared for plotting in 0.000499963760376 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.00898671150208 sec
# Computed 2 flowpipes in 0.0346901416779 sec
# In prepare! flowpipes_compo.size() = 2
# Prepared for plotting in 0.000586986541748 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.00776672363281 sec
# Computed 2 flowpipes in 0.0332908630371 sec
# In prepare! flowpipes_compo.size() = 2
# Prepared for plotting in 0.000478029251099 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.00753688812256 sec
# Computed 2 flowpipes in 0.0323638916016 sec
# In prepare! flowpipes_compo.size() = 2
# Prepared for plotting in 0.000393152236938 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.00845074653625 sec
# Computed 2 flowpipes in 0.0313150882721 sec
# In prepare! flowpipes_compo.size() = 2
# Prepared for plotting in 0.000497102737427 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.00695276260376 sec
# Computed 2 flowpipes in 0.0371639728546 sec
# In prepare! flowpipes_compo.size() = 2
# Prepared for plotting in 0.000365018844604 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.00916171073914 sec
# Computed 2 flowpipes in 0.0301451683044 sec
# In prepare! flowpipes_compo.size() = 2
# Prepared for plotting in 0.000237941741943 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.00720262527466 sec
# Computed 2 flowpipes in 0.0306529998779 sec
# In prepare! flowpipes_compo.size() = 2
# Prepared for plotting in 0.000238180160522 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.12500000000000000]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.12500000000000000]]
# Monitored signal 0.00790071487427 sec
# Computed 2 flowpipes in 0.041023015976 sec
# In prepare! flowpipes_compo.size() = 2
# Prepared for plotting in 0.000404119491577 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.067049054485112266 .. 0.12500000000000000]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.067049054485112266 .. 0.12500000000000000]]
# Monitored signal 0.00941562652588 sec
# Computed 2 flowpipes in 0.0298039913177 sec
# In prepare! flowpipes_compo.size() = 2
# Prepared for plotting in 0.000454902648926 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = []
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = []
# Monitored signal 0.00467085838318 sec
# Computed 2 flowpipes in 0.0319399833679 sec
# In prepare! flowpipes_compo.size() = 2
# Prepared for plotting in 0.000351905822754 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = []
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = []
# Monitored signal 0.00466394424438 sec
# Monitored signal 10.421962738 sec
# Monitored signal 49.6592748165 sec
# CPU times: user 50.7 s, sys: 162 ms, total: 50.9 s
# Wall time: 51.2 s

# %%
# %%time
sigG = F(RIF(5, 5.1),
         {y: RIF(1, 1.5)} >>
         G(RIF(10.2, 10.3),
           {x: RIF(0.05,0.1)} >>
            G(RIF(0,0.2), P)),
         ).signal_for_system(vf, v3, 0, use_masks=True, **kwargs)
# Out:
# Computed 115 flowpipes in 1.30789732933 sec
# In prepare! flowpipes_compo.size() = 115
# Prepared for plotting in 0.000737905502319 sec
# In C.signal
# {'precondition': 1, 'verbosity': 0, 'epsilon_ctx': 0.100000000000000, 'step': (0.0100000000000000, 0.500000000000000), 'cutoff_threshold': 0.0000100000000000000, 'integrationScheme': 2, 'estimation': 0.00100000000000000, 'order': 5}
# mask = Mask([5.0000000000000000 .. 5.0999999999999997], [[5.0000000000000000 .. 5.0999999999999997]])
# mask = Mask([5.0000000000000000 .. 5.0999999999999997], [[5.0000000000000000 .. 5.0999999999999997]])
# Computed 70 flowpipes in 0.489590883255 sec
# In prepare! flowpipes_compo.size() = 70
# Prepared for plotting in 0.000457048416138 sec
# In G.signal
# In C.signal
# {'precondition': 1, 'verbosity': 0, 'epsilon_ctx': 0.100000000000000, 'step': (0.0100000000000000, 0.500000000000000), 'cutoff_threshold': 0.0000100000000000000, 'integrationScheme': 2, 'estimation': 0.00100000000000000, 'order': 5}
# mask = Mask([10.199999999999999 .. 10.300000000000001], [[10.199999999999999 .. 10.300000000000001]])
# mask = Mask([10.199999999999999 .. 10.300000000000001], [[10.199999999999999 .. 10.300000000000001]])
# Computed 2 flowpipes in 0.0199282169342 sec
# In prepare! flowpipes_compo.size() = 2
# Prepared for plotting in 0.000253915786743 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = []
# seg_domain = [0.00000000000000000 .. 0.20000000000000002]
# roots = []
# Monitored signal 0.00350069999695 sec
# Monitored signal 0.182002782822 sec
# Monitored signal 2.41023373604 sec
# CPU times: user 3.7 s, sys: 3.62 ms, total: 3.7 s
# Wall time: 3.72 s

# %%
# %%time
sigG = G(RIF(2, 2.5),
         {x: RIF(0.1, 0.2)} >>
         F(RIF(5, 5.1),
           {y: RIF(1, 1.5)} >>
           G(RIF(10.2, 10.3),
             {x: RIF(0.05,0.1)} >>
             G(RIF(0,0.2), P))),
         ).signal_for_system(vf, v3, 0, **kwargs)
# Out:
# Computed 92 flowpipes in 1.09739613533 sec
# In prepare! flowpipes_compo.size() = 92
# Prepared for plotting in 0.000687122344971 sec
# In G.signal
# In C.signal
# {'precondition': 1, 'verbosity': 0, 'epsilon_ctx': 0.100000000000000, 'step': (0.0100000000000000, 0.500000000000000), 'cutoff_threshold': 0.0000100000000000000, 'integrationScheme': 2, 'estimation': 0.00100000000000000, 'order': 5}
# mask = None
# Computed 97 flowpipes in 1.05477285385 sec
# In prepare! flowpipes_compo.size() = 97
# Prepared for plotting in 0.00059700012207 sec
# In C.signal
# {'precondition': 1, 'verbosity': 0, 'epsilon_ctx': 0.100000000000000, 'step': (0.0100000000000000, 0.500000000000000), 'cutoff_threshold': 0.0000100000000000000, 'integrationScheme': 2, 'estimation': 0.00100000000000000, 'order': 5}
# mask = None
# Computed 150 flowpipes in 1.5902121067 sec
# In prepare! flowpipes_compo.size() = 150
# Prepared for plotting in 0.000502824783325 sec
# In G.signal
# In C.signal
# {'precondition': 1, 'verbosity': 0, 'epsilon_ctx': 0.100000000000000, 'step': (0.0100000000000000, 0.500000000000000), 'cutoff_threshold': 0.0000100000000000000, 'integrationScheme': 2, 'estimation': 0.00100000000000000, 'order': 5}
# mask = None
# Computed 15 flowpipes in 0.186330080032 sec
# In prepare! flowpipes_compo.size() = 15
# Prepared for plotting in 0.00052285194397 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.202103853226 sec
# Computed 15 flowpipes in 0.186078071594 sec
# In prepare! flowpipes_compo.size() = 15
# Prepared for plotting in 0.000507831573486 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.195920944214 sec
# Computed 15 flowpipes in 0.191843986511 sec
# In prepare! flowpipes_compo.size() = 15
# Prepared for plotting in 0.00207901000977 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.19465970993 sec
# Computed 15 flowpipes in 0.195527076721 sec
# In prepare! flowpipes_compo.size() = 15
# Prepared for plotting in 0.000234842300415 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.198949813843 sec
# Computed 12 flowpipes in 0.160703897476 sec
# In prepare! flowpipes_compo.size() = 12
# Prepared for plotting in 0.0002760887146 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.146088838577 sec
# Computed 12 flowpipes in 0.155313014984 sec
# In prepare! flowpipes_compo.size() = 12
# Prepared for plotting in 0.000367879867554 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.139550924301 sec
# Computed 12 flowpipes in 0.154687166214 sec
# In prepare! flowpipes_compo.size() = 12
# Prepared for plotting in 0.000543832778931 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.135044813156 sec
# Computed 12 flowpipes in 0.151930093765 sec
# In prepare! flowpipes_compo.size() = 12
# Prepared for plotting in 0.000350952148438 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.136612892151 sec
# Computed 11 flowpipes in 0.153511047363 sec
# In prepare! flowpipes_compo.size() = 11
# Prepared for plotting in 0.000370025634766 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.114759683609 sec
# Computed 11 flowpipes in 0.149229049683 sec
# In prepare! flowpipes_compo.size() = 11
# Prepared for plotting in 0.000387907028198 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.137592792511 sec
# Computed 11 flowpipes in 0.149942159653 sec
# In prepare! flowpipes_compo.size() = 11
# Prepared for plotting in 0.000411987304688 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.119112730026 sec
# Computed 11 flowpipes in 0.211259126663 sec
# In prepare! flowpipes_compo.size() = 11
# Prepared for plotting in 0.000814914703369 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.18435883522 sec
# Computed 9 flowpipes in 0.186099052429 sec
# In prepare! flowpipes_compo.size() = 9
# Prepared for plotting in 0.000578880310059 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.13580083847 sec
# Computed 9 flowpipes in 0.1887550354 sec
# In prepare! flowpipes_compo.size() = 9
# Prepared for plotting in 0.000890970230103 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.141241788864 sec
# Computed 9 flowpipes in 0.190379858017 sec
# In prepare! flowpipes_compo.size() = 9
# Prepared for plotting in 0.0003821849823 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.155353784561 sec
# Computed 9 flowpipes in 0.185246944427 sec
# In prepare! flowpipes_compo.size() = 9
# Prepared for plotting in 0.000715970993042 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.147094726562 sec
# Computed 9 flowpipes in 0.192198991776 sec
# In prepare! flowpipes_compo.size() = 9
# Prepared for plotting in 0.00526309013367 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.136799812317 sec
# Computed 9 flowpipes in 0.190225124359 sec
# In prepare! flowpipes_compo.size() = 9
# Prepared for plotting in 0.000489950180054 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.134306907654 sec
# Computed 9 flowpipes in 0.19427895546 sec
# In prepare! flowpipes_compo.size() = 9
# Prepared for plotting in 0.000663042068481 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.138467788696 sec
# Computed 9 flowpipes in 0.194242954254 sec
# In prepare! flowpipes_compo.size() = 9
# Prepared for plotting in 0.000789880752563 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.139975786209 sec
# Computed 8 flowpipes in 0.175751209259 sec
# In prepare! flowpipes_compo.size() = 8
# Prepared for plotting in 0.000564813613892 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.12694978714 sec
# Computed 8 flowpipes in 0.174242973328 sec
# In prepare! flowpipes_compo.size() = 8
# Prepared for plotting in 0.000227928161621 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.107913732529 sec
# Computed 8 flowpipes in 0.166482925415 sec
# In prepare! flowpipes_compo.size() = 8
# Prepared for plotting in 0.000441074371338 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.111432790756 sec
# Computed 8 flowpipes in 0.164455890656 sec
# In prepare! flowpipes_compo.size() = 8
# Prepared for plotting in 0.000469207763672 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.108862638474 sec
# Computed 7 flowpipes in 0.161370038986 sec
# In prepare! flowpipes_compo.size() = 7
# Prepared for plotting in 0.00119805335999 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0867435932159 sec
# Computed 7 flowpipes in 0.154579877853 sec
# In prepare! flowpipes_compo.size() = 7
# Prepared for plotting in 0.000615119934082 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0924775600433 sec
# Computed 7 flowpipes in 0.173290014267 sec
# In prepare! flowpipes_compo.size() = 7
# Prepared for plotting in 0.000340938568115 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0908906459808 sec
# Computed 6 flowpipes in 0.126533985138 sec
# In prepare! flowpipes_compo.size() = 6
# Prepared for plotting in 0.000629901885986 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0769009590149 sec
# Computed 6 flowpipes in 0.131021022797 sec
# In prepare! flowpipes_compo.size() = 6
# Prepared for plotting in 0.000763893127441 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.067519903183 sec
# Computed 6 flowpipes in 0.124928951263 sec
# In prepare! flowpipes_compo.size() = 6
# Prepared for plotting in 0.00049901008606 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0752327442169 sec
# Computed 6 flowpipes in 0.130211830139 sec
# In prepare! flowpipes_compo.size() = 6
# Prepared for plotting in 0.000396966934204 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0702557563782 sec
# Computed 6 flowpipes in 0.126227855682 sec
# In prepare! flowpipes_compo.size() = 6
# Prepared for plotting in 0.00049901008606 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0649857521057 sec
# Computed 6 flowpipes in 0.130382061005 sec
# In prepare! flowpipes_compo.size() = 6
# Prepared for plotting in 0.00026798248291 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0655376911163 sec
# Computed 6 flowpipes in 0.141570091248 sec
# In prepare! flowpipes_compo.size() = 6
# Prepared for plotting in 0.000464916229248 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0642747879028 sec
# Computed 6 flowpipes in 0.130872011185 sec
# In prepare! flowpipes_compo.size() = 6
# Prepared for plotting in 0.00097393989563 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0702338218689 sec
# Computed 6 flowpipes in 0.129405021667 sec
# In prepare! flowpipes_compo.size() = 6
# Prepared for plotting in 0.000298023223877 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.068018913269 sec
# Computed 6 flowpipes in 0.130383968353 sec
# In prepare! flowpipes_compo.size() = 6
# Prepared for plotting in 0.000614881515503 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0618779659271 sec
# Computed 6 flowpipes in 0.137597084045 sec
# In prepare! flowpipes_compo.size() = 6
# Prepared for plotting in 0.000475883483887 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0618867874146 sec
# Computed 6 flowpipes in 0.128976821899 sec
# In prepare! flowpipes_compo.size() = 6
# Prepared for plotting in 0.000370979309082 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.060683965683 sec
# Computed 5 flowpipes in 0.113667964935 sec
# In prepare! flowpipes_compo.size() = 5
# Prepared for plotting in 0.000257968902588 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0525686740875 sec
# Computed 5 flowpipes in 0.124109983444 sec
# In prepare! flowpipes_compo.size() = 5
# Prepared for plotting in 0.00103902816772 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0503966808319 sec
# Computed 5 flowpipes in 0.114367961884 sec
# In prepare! flowpipes_compo.size() = 5
# Prepared for plotting in 0.000306844711304 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0482089519501 sec
# Computed 5 flowpipes in 0.111045122147 sec
# In prepare! flowpipes_compo.size() = 5
# Prepared for plotting in 0.00154995918274 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0493638515472 sec
# Computed 3 flowpipes in 0.0738918781281 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000231027603149 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0125348567963 sec
# Computed 3 flowpipes in 0.0371279716492 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000228881835938 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0131669044495 sec
# Computed 3 flowpipes in 0.0350680351257 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000216960906982 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0140187740326 sec
# Computed 3 flowpipes in 0.0338900089264 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.0002601146698 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0176236629486 sec
# Computed 3 flowpipes in 0.0369930267334 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000382900238037 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0133438110352 sec
# Computed 3 flowpipes in 0.0363178253174 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000241994857788 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.011843919754 sec
# Computed 3 flowpipes in 0.0416600704193 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000277042388916 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0143156051636 sec
# Computed 3 flowpipes in 0.0374670028687 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000207901000977 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0118808746338 sec
# Computed 3 flowpipes in 0.0376310348511 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000382900238037 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0121917724609 sec
# Computed 3 flowpipes in 0.0458500385284 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000398874282837 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0119287967682 sec
# Computed 3 flowpipes in 0.0359981060028 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000353097915649 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0127365589142 sec
# Computed 3 flowpipes in 0.0356438159943 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000177145004272 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0112707614899 sec
# Computed 3 flowpipes in 0.0390138626099 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000326156616211 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0113096237183 sec
# Computed 3 flowpipes in 0.0370070934296 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000402927398682 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0129587650299 sec
# Computed 3 flowpipes in 0.0394520759583 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000365972518921 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.011846780777 sec
# Computed 3 flowpipes in 0.0389981269836 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000683784484863 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0108997821808 sec
# Computed 3 flowpipes in 0.0367350578308 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000257968902588 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0135338306427 sec
# Computed 3 flowpipes in 0.0407428741455 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000372171401978 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0105185508728 sec
# Computed 3 flowpipes in 0.0347690582275 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000571012496948 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0178437232971 sec
# Computed 3 flowpipes in 0.0357449054718 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000319957733154 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0102078914642 sec
# Computed 3 flowpipes in 0.0360429286957 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000319004058838 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0124068260193 sec
# Computed 3 flowpipes in 0.0447249412537 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000689029693604 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.010333776474 sec
# Computed 3 flowpipes in 0.0367410182953 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000223875045776 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0104827880859 sec
# Computed 3 flowpipes in 0.0347120761871 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000192880630493 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0102229118347 sec
# Computed 3 flowpipes in 0.036288022995 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000371932983398 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0118129253387 sec
# Computed 3 flowpipes in 0.0344049930573 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000365018844604 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.010000705719 sec
# Computed 3 flowpipes in 0.0355498790741 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000220060348511 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0106067657471 sec
# Computed 3 flowpipes in 0.0386710166931 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000266075134277 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0108237266541 sec
# Computed 3 flowpipes in 0.0368058681488 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000200986862183 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.00994277000427 sec
# Computed 3 flowpipes in 0.0356712341309 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000393867492676 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0106778144836 sec
# Computed 3 flowpipes in 0.0384578704834 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000222206115723 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0102846622467 sec
# Computed 3 flowpipes in 0.0389490127563 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000572919845581 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.00982785224915 sec
# Computed 3 flowpipes in 0.0364079475403 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000158071517944 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.00969076156616 sec
# Computed 3 flowpipes in 0.037015914917 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000248908996582 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0106768608093 sec
# Computed 3 flowpipes in 0.0411570072174 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000359058380127 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.00970363616943 sec
# Computed 3 flowpipes in 0.0362260341644 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000494956970215 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0107567310333 sec
# Computed 3 flowpipes in 0.0430178642273 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000290155410767 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.00987362861633 sec
# Computed 3 flowpipes in 0.0357918739319 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000296115875244 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.009685754776 sec
# Computed 3 flowpipes in 0.03653216362 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000498056411743 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0121176242828 sec
# Computed 3 flowpipes in 0.0473489761353 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000571012496948 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0101096630096 sec
# Computed 3 flowpipes in 0.0356149673462 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000409126281738 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0090057849884 sec
# Computed 3 flowpipes in 0.0375211238861 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000431060791016 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.00981473922729 sec
# Computed 3 flowpipes in 0.0365469455719 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.00062894821167 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.00950074195862 sec
# Computed 3 flowpipes in 0.0371630191803 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000375986099243 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.13125000000000001],
#  [0.16670991741643625 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.13125000000000001],
#  [0.16670991741643625 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0214207172394 sec
# Computed 3 flowpipes in 0.0356571674347 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000262022018433 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.00936961174011 sec
# Computed 3 flowpipes in 0.034371137619 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000371932983398 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0119607448578 sec
# Computed 3 flowpipes in 0.0412361621857 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.00036096572876 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0106296539307 sec
# Computed 2 flowpipes in 0.0349628925323 sec
# In prepare! flowpipes_compo.size() = 2
# Prepared for plotting in 0.000247955322266 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.063865761300592932 .. 0.12500000000000000]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.063865761300592932 .. 0.12500000000000000]]
# Monitored signal 0.0110678672791 sec
# Computed 2 flowpipes in 0.0258738994598 sec
# In prepare! flowpipes_compo.size() = 2
# Prepared for plotting in 0.000379085540771 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.097215353392693576 .. 0.12500000000000000]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.097215353392693576 .. 0.12500000000000000]]
# Monitored signal 0.0122618675232 sec
# Computed 2 flowpipes in 0.0240240097046 sec
# In prepare! flowpipes_compo.size() = 2
# Prepared for plotting in 0.00028395652771 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = []
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = []
# Monitored signal 0.00416874885559 sec
# Computed 2 flowpipes in 0.0241918563843 sec
# In prepare! flowpipes_compo.size() = 2
# Prepared for plotting in 0.000235080718994 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = []
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = []
# Monitored signal 0.00438475608826 sec
# Monitored signal 17.7112398148 sec
# Computed 133 flowpipes in 1.11149811745 sec
# In prepare! flowpipes_compo.size() = 133
# Prepared for plotting in 0.000387907028198 sec
# In G.signal
# In C.signal
# {'precondition': 1, 'verbosity': 0, 'epsilon_ctx': 0.100000000000000, 'step': (0.0100000000000000, 0.500000000000000), 'cutoff_threshold': 0.0000100000000000000, 'integrationScheme': 2, 'estimation': 0.00100000000000000, 'order': 5}
# mask = None
# Computed 15 flowpipes in 0.150218009949 sec
# In prepare! flowpipes_compo.size() = 15
# Prepared for plotting in 0.000298023223877 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.151975631714 sec
# Computed 15 flowpipes in 0.154553890228 sec
# In prepare! flowpipes_compo.size() = 15
# Prepared for plotting in 0.000386953353882 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.151874780655 sec
# Computed 15 flowpipes in 0.161090135574 sec
# In prepare! flowpipes_compo.size() = 15
# Prepared for plotting in 0.000257015228271 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.148609638214 sec
# Computed 14 flowpipes in 0.143661975861 sec
# In prepare! flowpipes_compo.size() = 14
# Prepared for plotting in 0.000432968139648 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.131312847137 sec
# Computed 12 flowpipes in 0.123817920685 sec
# In prepare! flowpipes_compo.size() = 12
# Prepared for plotting in 0.000169038772583 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.12583565712 sec
# Computed 12 flowpipes in 0.126788139343 sec
# In prepare! flowpipes_compo.size() = 12
# Prepared for plotting in 0.000271797180176 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.108459949493 sec
# Computed 12 flowpipes in 0.124972105026 sec
# In prepare! flowpipes_compo.size() = 12
# Prepared for plotting in 0.000339984893799 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.117601633072 sec
# Computed 12 flowpipes in 0.124727964401 sec
# In prepare! flowpipes_compo.size() = 12
# Prepared for plotting in 0.000514984130859 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.11835193634 sec
# Computed 12 flowpipes in 0.121870040894 sec
# In prepare! flowpipes_compo.size() = 12
# Prepared for plotting in 0.000241994857788 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.112939834595 sec
# Computed 12 flowpipes in 0.137096166611 sec
# In prepare! flowpipes_compo.size() = 12
# Prepared for plotting in 0.000484943389893 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.112980604172 sec
# Computed 11 flowpipes in 0.11788892746 sec
# In prepare! flowpipes_compo.size() = 11
# Prepared for plotting in 0.000432968139648 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.129685878754 sec
# Computed 11 flowpipes in 0.998641967773 sec
# In prepare! flowpipes_compo.size() = 11
# Prepared for plotting in 0.00318503379822 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.856493711472 sec
# Computed 11 flowpipes in 1.01668000221 sec
# In prepare! flowpipes_compo.size() = 11
# Prepared for plotting in 0.0598261356354 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.828999757767 sec
# Computed 9 flowpipes in 0.841089010239 sec
# In prepare! flowpipes_compo.size() = 9
# Prepared for plotting in 0.000948905944824 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.235062837601 sec
# Computed 9 flowpipes in 0.210070848465 sec
# In prepare! flowpipes_compo.size() = 9
# Prepared for plotting in 0.000470161437988 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.154934644699 sec
# Computed 9 flowpipes in 0.106510877609 sec
# In prepare! flowpipes_compo.size() = 9
# Prepared for plotting in 0.000308990478516 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# ...
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000452995300293 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0218436717987 sec
# Computed 3 flowpipes in 0.0690150260925 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.0012948513031 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0202538967133 sec
# Computed 3 flowpipes in 0.0563571453094 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000531911849976 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0179507732391 sec
# Computed 3 flowpipes in 0.0530860424042 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000386953353882 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0172007083893 sec
# Computed 3 flowpipes in 0.0611190795898 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000295877456665 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0172717571259 sec
# Computed 3 flowpipes in 0.056144952774 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000224113464355 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0166997909546 sec
# Computed 3 flowpipes in 0.064747095108 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000514030456543 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0205898284912 sec
# Computed 3 flowpipes in 0.0653479099274 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000292062759399 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0190198421478 sec
# Computed 3 flowpipes in 0.0488920211792 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000798940658569 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0149428844452 sec
# Computed 3 flowpipes in 0.0506529808044 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000280141830444 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0162456035614 sec
# Computed 3 flowpipes in 0.0537180900574 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.00023889541626 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0158407688141 sec
# Computed 3 flowpipes in 0.0576169490814 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000355958938599 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0187909603119 sec
# Computed 3 flowpipes in 0.059849023819 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000418901443481 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0188689231873 sec
# Computed 3 flowpipes in 0.0537810325623 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000587940216064 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0174398422241 sec
# Computed 3 flowpipes in 0.049290895462 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000674962997437 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0167117118835 sec
# Computed 3 flowpipes in 0.0558798313141 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000241041183472 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0137417316437 sec
# Computed 3 flowpipes in 0.0562989711761 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000334024429321 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0139067173004 sec
# Computed 3 flowpipes in 0.0579569339752 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000238180160522 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0152857303619 sec
# Computed 3 flowpipes in 0.0586810112 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.0135378837585 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0146687030792 sec
# Computed 3 flowpipes in 0.0518951416016 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000664949417114 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0152447223663 sec
# Computed 3 flowpipes in 0.0580310821533 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000665903091431 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0157697200775 sec
# Computed 3 flowpipes in 0.0592861175537 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.00068187713623 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0160148143768 sec
# Computed 3 flowpipes in 0.063225030899 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000399112701416 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0177595615387 sec
# Computed 3 flowpipes in 0.0559110641479 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000468015670776 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0141367912292 sec
# Computed 3 flowpipes in 0.0507497787476 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000490188598633 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0128235816956 sec
# Computed 3 flowpipes in 0.0499439239502 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000595092773438 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0131306648254 sec
# Computed 3 flowpipes in 0.0503129959106 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000492095947266 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0128026008606 sec
# Computed 2 flowpipes in 0.0364730358124 sec
# In prepare! flowpipes_compo.size() = 2
# Prepared for plotting in 0.000379085540771 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.00829458236694 sec
# Computed 3 flowpipes in 0.0536289215088 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000461101531982 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0134546756744 sec
# Computed 3 flowpipes in 0.0599391460419 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000337839126587 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0136368274689 sec
# Computed 3 flowpipes in 0.0539500713348 sec
# In prepare! flowpipes_compo.size() = 3
# Prepared for plotting in 0.000627994537354 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0155217647552 sec
# Computed 2 flowpipes in 0.0359399318695 sec
# In prepare! flowpipes_compo.size() = 2
# Prepared for plotting in 0.000354051589966 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.00977778434753 sec
# Computed 2 flowpipes in 0.034147977829 sec
# In prepare! flowpipes_compo.size() = 2
# Prepared for plotting in 0.000605821609497 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.0079939365387 sec
# Computed 2 flowpipes in 0.0361928939819 sec
# In prepare! flowpipes_compo.size() = 2
# Prepared for plotting in 0.000420093536377 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.20199999999900001]]
# 0 at 0.201000000000001
# Monitored signal 0.00768280029297 sec
# Computed 2 flowpipes in 0.0336029529572 sec
# In prepare! flowpipes_compo.size() = 2
# Prepared for plotting in 0.000830173492432 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.12500000000000000]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.12500000000000000]]
# Monitored signal 0.00692772865295 sec
# Computed 2 flowpipes in 0.0341930389404 sec
# In prepare! flowpipes_compo.size() = 2
# Prepared for plotting in 0.000442981719971 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.12500000000000000]]
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = [[0.00000000000000000 .. 0.12500000000000000]]
# Monitored signal 0.00626397132874 sec
# Computed 2 flowpipes in 0.0361020565033 sec
# In prepare! flowpipes_compo.size() = 2
# Prepared for plotting in 0.000327110290527 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = []
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = []
# Monitored signal 0.00547480583191 sec
# Computed 2 flowpipes in 0.0321769714355 sec
# In prepare! flowpipes_compo.size() = 2
# Prepared for plotting in 0.000223875045776 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = []
# seg_domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = []
# Monitored signal 0.00480890274048 sec
# Monitored signal 9.0706346035 sec
# Monitored signal 75.4742267132 sec
# Monitored signal 262.456883669 sec
# CPU times: user 4min 20s, sys: 931 ms, total: 4min 21s
# Wall time: 4min 23s

# %%
# %%time
sigG = G(RIF(2, 2.5),
         {x: RIF(0.1, 0.2)} >>
         F(RIF(5, 5.1),
           {y: RIF(1, 1.5)} >>
           G(RIF(10.2, 10.3),
             {x: RIF(0.05,0.1)} >>
             G(RIF(0,0.2), P))),
         ).signal_for_system(vf, v3, 0, use_masks=True, **kwargs)
# Out:
# Computed 92 flowpipes in 1.17631220818 sec
# In prepare! flowpipes_compo.size() = 92
# Prepared for plotting in 0.000540018081665 sec
# In G.signal
# In C.signal
# {'precondition': 1, 'verbosity': 0, 'epsilon_ctx': 0.100000000000000, 'step': (0.0100000000000000, 0.500000000000000), 'cutoff_threshold': 0.0000100000000000000, 'integrationScheme': 2, 'estimation': 0.00100000000000000, 'order': 5}
# mask = Mask([2.0000000000000000 .. 2.5000000000000000], [[2.0000000000000000 .. 2.5000000000000000]])
# mask = Mask([2.0000000000000000 .. 2.5000000000000000], [[2.0000000000000000 .. 2.5000000000000000]])
# Computed 56 flowpipes in 0.63732790947 sec
# In prepare! flowpipes_compo.size() = 56
# Prepared for plotting in 0.000967979431152 sec
# In C.signal
# {'precondition': 1, 'verbosity': 0, 'epsilon_ctx': 0.100000000000000, 'step': (0.0100000000000000, 0.500000000000000), 'cutoff_threshold': 0.0000100000000000000, 'integrationScheme': 2, 'estimation': 0.00100000000000000, 'order': 5}
# mask = Mask([5.0000000000000000 .. 5.0999999999999997], [[5.0000000000000000 .. 5.0999999999999997]])
# mask = Mask([5.0000000000000000 .. 5.0999999999999997], [[5.0000000000000000 .. 5.0999999999999997]])
# Computed 68 flowpipes in 0.491760015488 sec
# In prepare! flowpipes_compo.size() = 68
# Prepared for plotting in 0.000826120376587 sec
# In G.signal
# In C.signal
# {'precondition': 1, 'verbosity': 0, 'epsilon_ctx': 0.100000000000000, 'step': (0.0100000000000000, 0.500000000000000), 'cutoff_threshold': 0.0000100000000000000, 'integrationScheme': 2, 'estimation': 0.00100000000000000, 'order': 5}
# mask = Mask([10.199999999999999 .. 10.300000000000001], [[10.199999999999999 .. 10.300000000000001]])
# mask = Mask([10.199999999999999 .. 10.300000000000001], [[10.199999999999999 .. 10.300000000000001]])
# Computed 2 flowpipes in 0.0205731391907 sec
# In prepare! flowpipes_compo.size() = 2
# Prepared for plotting in 0.000488996505737 sec
# In G.signal
# domain = [0.00000000000000000 .. 0.20100000000000004]
# roots = []
# seg_domain = [0.00000000000000000 .. 0.20000000000000002]
# roots = []
# Monitored signal 0.00327754020691 sec
# Monitored signal 0.14560174942 sec
# Monitored signal 1.13768291473 sec
# Monitored signal 3.63690686226 sec
# CPU times: user 4.78 s, sys: 14.7 ms, total: 4.79 s
# Wall time: 4.82 s

# %%
sigG(0)
# Out:
# False

# %%
sigG.plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-1fbebb1a8578> in <module>()
# ----> 1 sigG.plot()
#
# /home/twright/Documents/PhD/Notebooks/ulbc/interval_signals.pyc in plot(self, **kwargs)
#     257
#     258         return (region_plot(trues, self.domain.endpoints(), (-1, 1),
# --> 259                             incol='lightgreen', **kwargs)
#     260                 + region_plot(falses, self.domain.endpoints(), (-1, 1),
#     261                               incol='pink', **kwargs))
#
# /usr/lib64/python2.7/site-packages/sage/misc/decorators.pyc in wrapper(*args, **kwds)
#     565                 options['__original_opts'] = kwds
#     566             options.update(kwds)
# --> 567             return func(*args, **options)
#     568
#     569         #Add the options specified by @options to the signature of the wrapped
#
# /usr/lib64/python2.7/site-packages/sage/plot/contour_plot.pyc in region_plot(f, xrange, yrange, plot_points, incol, outcol, bordercol, borderstyle, borderwidth, alpha, **options)
#    1504     f_all, ranges = setup_for_eval_on_grid(feqs + f,
#    1505                                            [xrange, yrange],
# -> 1506                                            plot_points)
#    1507     xrange, yrange = [r[:2] for r in ranges]
#    1508
#
# /usr/lib64/python2.7/site-packages/sage/plot/misc.pyc in setup_for_eval_on_grid(funcs, ranges, plot_points, return_vars)
#     132     range_steps = [abs(range[1] - range[0])/(p-1) for range, p in zip(ranges, plot_points)]
#     133     if min(range_steps) == float(0):
# --> 134         raise ValueError("plot start point and end point must be different")
#     135
#     136     options={}
#
# ValueError: plot start point and end point must be different

# %% [markdown]
# ## Differential Context

# %%
{x: RIF(6,7)} % G(RIF(0,0.2), P)

# %%
# Use symbolic remainders for context jump 
kwargs['integrationScheme'] = 7

# %%
kwargs['verbosity'] = 10

# %%
kwargs['symbolic_composition'] = True

# %%
sig = ({x: RIF(6)} % G(RIF(0,0.2), P)
       ).signal_for_system(vf, v3, 2*pi, **kwargs)

# %%
sig.plot()

# %%
sig = ({x: RIF(6, 6.1)} % G(RIF(0,0.2), P)
       ).signal_for_system(vf, v3, 2*pi, **kwargs)

# %%
sig.plot()

# %%
sig = ({x: RIF(10, 10.05)} % G(RIF(0,0.2), P)
       ).signal_for_system(vf, v3, 2*pi, **kwargs)

# %%
sig.plot()

# %%
{x: 1, y: 2}

# %%
kxs = [[('x', RIF(1,2)), ('y', RIF(5,6))], [('x', RIF(2,3)), ('y', RIF(6,7))], [('x', RIF(1,2)), ('y', RIF(5,6))], [('x', RIF(2,3)), ('y', RIF(6,7))]]

# %%
sorted(kxs)

# %%
sorted(kxs,
       key=lambda xs: [(k, x.endpoints()) for k, x in xs])
