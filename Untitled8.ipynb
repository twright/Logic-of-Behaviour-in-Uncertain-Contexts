# %%
var('t')
# Out:
# t

# %%
f = lambda t: RIF(t^2 - 2)

# %%
fp = lambda t: RIF(2*t)

# %%
plot(f, (1, 2))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(fp, (1, 2))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
fp(RIF(1,2)).str(style='brackets')
# Out:
# '[2.0000000000000000 .. 4.0000000000000000]'

# %%
( RIF(1.5) - f(RIF(1.5))/fp(RIF(1,2)) ).intersection(RIF(1,2)).str(style='brackets')
# Out:
# '[1.3750000000000000 .. 1.4375000000000000]'

# %%
from flowstar.reachability import py_int_diff2, py_extdiv2, py_detect_roots3

# %%
py_extdiv2(RIF(-10,10), f(RIF(1.5)), fp(RIF(1,2)))
# Out:
# (True, False, (0.0625, 0.125), (0.0625, 0.125))

# %%
( f(RIF(1.5))/fp(RIF(1,2)) ).str(style='brackets')
# Out:
# '[0.062500000000000000 .. 0.12500000000000000]'

# %%
plot(((lambda t: (t + RIF(-1,1)).lower()), (lambda t: (t + RIF(-1,1)).upper())),
     (0, 1))
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
R.<t> = RIF[]

# %%
g=t + RIF(-1,1); gp = R(1)

# %%
from flowstar.reachability import Poly

# %%
Poly(gp)
# Out:
# (([1.0000000000e+00 , 1.0000000000e+00]))

# %%
py_detect_roots3(Poly(g), Poly(gp), RIF(0,1), verbosity=5)
# Out:
# T = [0.0..1.0]
# T = [-0.0..1.0]
# root on boundary!
# [(-0.0, 1.0)]

# %%
g(RIF(0,1)).str(style='brackets')
# Out:
# '[-1.0000000000000000 .. 2.0000000000000000]'

# %%
Poly(g)
# Out:
# (([-1.0000000000e+00 , 1.0000000000e+00]) + ([1.0000000000e+00 , 1.0000000000e+00] * t))

# %%
g
# Out:
# t + 0.?

# %%
Poly(g)
# Out:
# (([-1.0000000000e+00 , 1.0000000000e+00]) + ([1.0000000000e+00 , 1.0000000000e+00] * t))

# %%
g.coefficients()
# Out:
# [1]

# %%
W.<x,y> = RIF[]

# %%
x.coefficients()
# Out:
# [1]

# %%
x.exponents()
# Out:
# [(1, 0)]

# %%
list(g)
# Out:
# [0.?, 1]

# %%
g
# Out:
# t + 0.?

# %%
g.coefficients()
# Out:
# [1]

# %%
g.coefficients(sparse=False)
# Out:
# [0.?, 1]

# %%
g.exponents()
# Out:
# [0, 1]

# %%
list(zip(g.coefficients(), g.exponents()))
# Out:
# [(1, 0)]

# %%
help(g.exponents)
# Out:
# Help on built-in function exponents:
#
# exponents(...)
#     Polynomial.exponents(self)
#     File: sage/rings/polynomial/polynomial_element.pyx (starting at line 5541)
#
#             Return the exponents of the monomials appearing in self.
#
#             EXAMPLES::
#
#                 sage: _.<x> = PolynomialRing(ZZ)
#                 sage: f = x^4+2*x^2+1
#                 sage: f.exponents()
#                 [0, 2, 4]
#
#             TESTS::
#
#                 sage: a = RIF['x'](1/3)
#                 sage: (a - a).exponents()
#                 [0]

# %%
g.exponents()
# Out:
# [0, 1]

# %%
(t**2 - 2).coefficients()
# Out:
# [-2, 1]

# %%
(t**2 - RIF(1,2)).coefficients()
# Out:
# [-2.?, 1]

# %%
t.parent()(0)
# Out:
# 0

# %%
[c for c in (t**2 - 2) if c != t.parent()(0)]
# Out:
# [-2, 1]

# %%
g.list()[0].str(style='brackets')
# Out:
# '[-1.0000000000000000 .. 1.0000000000000000]'

# %%
t[0].issubset(RIF(0))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-3b6b3bb3fe2e> in <module>()
# ----> 1 t[Integer(0)].issubset(RIF(Integer(0)))
#
# /usr/lib64/python2.7/site-packages/sage/structure/element.pyx in sage.structure.element.Element.__getattr__ (build/cythonized/sage/structure/element.c:4531)()
#     491             AttributeError: 'LeftZeroSemigroup_with_category.element_class' object has no attribute 'blah_blah'
#     492         """
# --> 493         return self.getattr_from_category(name)
#     494
#     495     cdef getattr_from_category(self, name):
#
# /usr/lib64/python2.7/site-packages/sage/structure/element.pyx in sage.structure.element.Element.getattr_from_category (build/cythonized/sage/structure/element.c:4640)()
#     504         else:
#     505             cls = P._abstract_element_class
# ...

# %%
not(t[0] == 0 and hasattr(t[0], 'diameter') <= t[0].diameter() == 0)
# Out:
# True

# %%
RIF(0) == 0
# Out:
# True

# %%
not((RIF(0) == 0) and (hasattr(RIF(0), 'diameter') <= (RIF(0).diameter() == 0)))
# Out:
# False

# %%
True <= False
# Out:
# False

# %%
hasattr(RIF(0), 'diameter')
# Out:
# True

# %%
RIF(0).diameter() == 0
# Out:
# True

# %%
[c for c in g if c != 0]
# Out:
# [1]

# %%
(t**2 - 2).coefficients(sparse=False)
# Out:
# [-2, 0, 1]

# %%
W, (x, y) = PolynomialRing(RIF, 'x, y').objgens()

# %%
W.<x,y> = RIF[]

# %%
g = x*y + x + RIF(-1,1)

# %%
g.coefficients()
# Out:
# [1, 1, 0.?]

# %%
g.list() if hasattr(g)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-22d3775e965e> in <module>()
# ----> 1 g.list()
#
# /usr/lib64/python2.7/site-packages/sage/structure/element.pyx in sage.structure.element.Element.__getattr__ (build/cythonized/sage/structure/element.c:4531)()
#     491             AttributeError: 'LeftZeroSemigroup_with_category.element_class' object has no attribute 'blah_blah'
#     492         """
# --> 493         return self.getattr_from_category(name)
#     494
#     495     cdef getattr_from_category(self, name):
#
# /usr/lib64/python2.7/site-packages/sage/structure/element.pyx in sage.structure.element.Element.getattr_from_category (build/cythonized/sage/structure/element.c:4640)()
#     504         else:
#     505             cls = P._abstract_element_class
# --> 506         return getattr_from_other_class(self, cls, name)
#     507
# ...

# %%
Poly(g)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/lib64/python2.7/site-packages/sage/rings/polynomial/multi_polynomial.pyx in sage.rings.polynomial.multi_polynomial.MPolynomial.__float__ (build/cythonized/sage/rings/polynomial/multi_polynomial.c:3933)()
#      86             return float(self.constant_coefficient())
#      87         else:
# ---> 88             raise TypeError
#      89
#      90     def _mpfr_(self, R):
#
# TypeError:
# Exception TypeError: TypeError() in 'reachability._interval' ignored
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/lib64/python2.7/site-packages/sage/rings/polynomial/multi_polynomial.pyx in sage.rings.polynomial.multi_polynomial.MPolynomial.__float__ (build/cythonized/sage/rings/polynomial/multi_polynomial.c:3933)()
# ...
