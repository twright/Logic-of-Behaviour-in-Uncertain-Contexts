# %% [markdown]
# # Tests

# %% [markdown]
# ## Example 1: Simple

# %%
from flowstar.reachability import Reach
from flowstar.poly import Poly
from ulbc import *

# %%
R.<x,y> = RIF[]

# %%
odes = [
    -y,
    x,
]
initials = [(4,5), (1,2)]
reach = Reach(odes, [(4,5), (1,2)], 2*pi, 0.1, order=10)

# %%
def plot_signal(sig):
    return sig.to_domain(RIF(0,2*pi)).plot().show(
        ticks=[pi/2, 1], tick_formatter=pi, aspect_ratio=2/3)

# %%
reach.res
# Out:
# 2

# %%
reach(RIF(1,2))[0].str(style='brackets')
# Out:
# '[-3.9498690968545423 .. 1.9455015887879262]'

# %%
reach.sage_plot(x, (0.9,2.1))
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
reach(RIF(1,2))[1].str(style='brackets')
# Out:
# '[2.7656753616904756 .. 5.5009063678660049]'

# %%
reach.sage_plot(y, (1,2))
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
P = Atomic(x - 3); P
# Out:
# Atomic(x - 3)

# %%
P.signal(reach, odes).plot() + P.sage_plot(reach)
# Out:
# domain = [0.00000000000000000 .. 6.2821853071795868]
# roots = [[0.36442391108285443 .. 0.75322999900880539],
#  [4.9094498886890116 .. 5.3000000000000105]]
#   J  = [0.00000000000000000 .. 0.36442391108285444]
# f(J) = [0.0027202813179409979 .. 2.0000000000000009]
#   J  = [0.75322999900880538 .. 4.9094498886890117]
# f(J) = [-8.4984031964855867 .. -0.00016697542414467747]
#   J  = [5.3000000000000104 .. 6.2821853071795868]
# f(J) = [-0.0039940204023398707 .. 2.5005510818925254]
# Graphics object consisting of 4 graphics primitives

# %%
plot_signal( P.signal_for_system(odes, initials, 2*pi) )
# Out:
# Computed 63 flowpipes in 0.0200500488281 sec
# Prepared for plotting in 0.0184886455536 sec
# domain = [0.00000000000000000 .. 6.2831853071795872]
# roots = [[0.36442391108285443 .. 0.75322999900880539],
#  [4.9094498886890116 .. 5.3000000000000105]]
#   J  = [0.00000000000000000 .. 0.36442391108285444]
# f(J) = [0.0027202813179409979 .. 2.0000000000000009]
#   J  = [0.75322999900880538 .. 4.9094498886890117]
# f(J) = [-8.4984031964855867 .. -0.00016697542414467747]
#   J  = [5.3000000000000104 .. 6.2831853071795872]
# f(J) = [-0.0039940204023398707 .. 2.5005510818925254]
# Monitored signal 0.0226013660431 sec
# Graphics object consisting of 2 graphics primitives

# %%
Q = Atomic(3 - y); Q
# Out:
# Atomic(-y + 3)

# %%
Q.signal(reach, odes).plot() + Q.sage_plot(reach)
# Out:
# domain = [0.00000000000000000 .. 6.2821853071795868]
# roots = [[0.20000000000000001 .. 0.58848494710426814],
#  [1.9311141906428948 .. 2.3182023568246275]]
#   J  = [0.00000000000000000 .. 0.20000000000000002]
# f(J) = [0.023305845235470190 .. 2.0000000000000005]
#   J  = [0.58848494710426813 .. 1.9311141906428949]
# f(J) = [-2.5009063678660049 .. -0.0021143037956745658]
#   J  = [2.3182023568246274 .. 6.2821853071795868]
# f(J) = [0.000081063638504463852 .. 8.4963733382557046]
# Graphics object consisting of 4 graphics primitives

# %%
plot_signal( Q.signal_for_system(odes, initials, 2*pi) )
# Out:
# Computed 63 flowpipes in 0.0283329486847 sec
# Prepared for plotting in 0.0246818065643 sec
# domain = [0.00000000000000000 .. 6.2831853071795872]
# roots = [[0.20000000000000001 .. 0.58848494710426814],
#  [1.9311141906428948 .. 2.3182023568246275]]
#   J  = [0.00000000000000000 .. 0.20000000000000002]
# f(J) = [0.023305845235470190 .. 2.0000000000000005]
#   J  = [0.58848494710426813 .. 1.9311141906428949]
# f(J) = [-2.5009063678660049 .. -0.0021143037956745658]
#   J  = [2.3182023568246274 .. 6.2831853071795872]
# f(J) = [0.000081063638504463852 .. 8.4963733382557046]
# Monitored signal 0.0238304138184 sec
# Graphics object consisting of 2 graphics primitives

# %%
plot_signal( G(RIF(1,1.2), P).signal_for_system(odes, initials, 2*pi) )
# Out:
# Computed 75 flowpipes in 0.0248558521271 sec
# Prepared for plotting in 0.0215857028961 sec
# domain = [0.00000000000000000 .. 7.4831853071795873]
# roots = [[0.36442391108285443 .. 0.75322999900880539],
#  [4.9094498886890116 .. 5.3000000000000105],
#  [6.6497432568189269 .. 7.0331814940841380]]
#   J  = [0.00000000000000000 .. 0.36442391108285444]
# f(J) = [0.0027202813179409979 .. 2.0000000000000009]
#   J  = [0.75322999900880538 .. 4.9094498886890117]
# f(J) = [-8.4984031964855867 .. -0.00016697542414467747]
#   J  = [5.3000000000000104 .. 6.6497432568189270]
# f(J) = [-0.0039940204023398707 .. 2.5005510818925254]
#   J  = [7.0331814940841379 .. 7.4831853071795873]
# f(J) = [-3.4944620224989702 .. -0.00053751205010632574]
# Monitored signal 0.0300762653351 sec
# Graphics object consisting of 2 graphics primitives

# %%
plot_signal( F(RIF(3.5, 4), Q).signal_for_system(odes, initials, 2*pi) )
# Out:
# Computed 103 flowpipes in 0.0355820655823 sec
# Prepared for plotting in 0.0292496681213 sec
# domain = [0.00000000000000000 .. 10.283185307179589]
# roots = [[0.20000000000000001 .. 0.58848494710426814],
#  [1.9311141906428948 .. 2.3182023568246275],
#  [6.4892456363200734 .. 6.8667576512155782],
#  [8.2066212216718827 .. 8.6000000000000334]]
#   J  = [0.00000000000000000 .. 0.20000000000000002]
# f(J) = [0.023305845235470190 .. 2.0000000000000005]
#   J  = [0.58848494710426813 .. 1.9311141906428949]
# f(J) = [-2.5009063678660049 .. -0.0021143037956745658]
#   J  = [2.3182023568246274 .. 6.4892456363200735]
# f(J) = [-0.0019014547054210241 .. 8.4963733382557046]
#   J  = [6.8667576512155781 .. 8.2066212216718828]
# f(J) = [-2.5000379898895063 .. 0.0024387538136543264]
#   J  = [8.6000000000000333 .. 10.283185307179589]
# f(J) = [-0.060602264719935129 .. 8.1667675079350258]
# Monitored signal 0.0373022556305 sec
# Graphics object consisting of 2 graphics primitives

# %%
plot_signal( (G(RIF(1,1.2), P) | F(RIF(3.5,4), Q)).signal_for_system(odes, initials, 2*pi) )
# Out:
# Computed 103 flowpipes in 0.0344998836517 sec
# Prepared for plotting in 0.040730714798 sec
# domain = [0.00000000000000000 .. 10.283185307179589]
# roots = [[0.36442391108285443 .. 0.75322999900880539],
#  [4.9094498886890116 .. 5.3000000000000105],
#  [6.6497432568189269 .. 7.0331814940841380]]
#   J  = [0.00000000000000000 .. 0.36442391108285444]
# f(J) = [0.0027202813179409979 .. 2.0000000000000009]
#   J  = [0.75322999900880538 .. 4.9094498886890117]
# f(J) = [-8.4984031964855867 .. -0.00016697542414467747]
#   J  = [5.3000000000000104 .. 6.6497432568189270]
# f(J) = [-0.0039940204023398707 .. 2.5005510818925254]
#   J  = [7.0331814940841379 .. 10.283185307179589]
# f(J) = [-8.4948345026507575 .. -0.00053751205010632574]
# domain = [0.00000000000000000 .. 10.283185307179589]
# roots = [[0.20000000000000001 .. 0.58848494710426814],
#  [1.9311141906428948 .. 2.3182023568246275],
#  [6.4892456363200734 .. 6.8667576512155782],
#  [8.2066212216718827 .. 8.6000000000000334]]
#   J  = [0.00000000000000000 .. 0.20000000000000002]
# f(J) = [0.023305845235470190 .. 2.0000000000000005]
#   J  = [0.58848494710426813 .. 1.9311141906428949]
# f(J) = [-2.5009063678660049 .. -0.0021143037956745658]
#   J  = [2.3182023568246274 .. 6.4892456363200735]
# f(J) = [-0.0019014547054210241 .. 8.4963733382557046]
#   J  = [6.8667576512155781 .. 8.2066212216718828]
# f(J) = [-2.5000379898895063 .. 0.0024387538136543264]
#   J  = [8.6000000000000333 .. 10.283185307179589]
# f(J) = [-0.060602264719935129 .. 8.1667675079350258]
# Monitored signal 0.0741822719574 sec
# Graphics object consisting of 2 graphics primitives

# %%
(G(RIF(1,1.2), P) & F(RIF(3.5,4), Q)).signal_for_system(odes, initials, 2*pi).plot()
# Out:
# Computed 103 flowpipes in 0.0460441112518 sec
# Prepared for plotting in 0.0310127735138 sec
# domain = [0.00000000000000000 .. 10.283185307179589]
# roots = [[0.36442391108285443 .. 0.75322999900880539],
#  [4.9094498886890116 .. 5.3000000000000105],
#  [6.6497432568189269 .. 7.0331814940841380]]
#   J  = [0.00000000000000000 .. 0.36442391108285444]
# f(J) = [0.0027202813179409979 .. 2.0000000000000009]
#   J  = [0.75322999900880538 .. 4.9094498886890117]
# f(J) = [-8.4984031964855867 .. -0.00016697542414467747]
#   J  = [5.3000000000000104 .. 6.6497432568189270]
# f(J) = [-0.0039940204023398707 .. 2.5005510818925254]
#   J  = [7.0331814940841379 .. 10.283185307179589]
# f(J) = [-8.4948345026507575 .. -0.00053751205010632574]
# domain = [0.00000000000000000 .. 10.283185307179589]
# roots = [[0.20000000000000001 .. 0.58848494710426814],
#  [1.9311141906428948 .. 2.3182023568246275],
#  [6.4892456363200734 .. 6.8667576512155782],
#  [8.2066212216718827 .. 8.6000000000000334]]
#   J  = [0.00000000000000000 .. 0.20000000000000002]
# f(J) = [0.023305845235470190 .. 2.0000000000000005]
#   J  = [0.58848494710426813 .. 1.9311141906428949]
# f(J) = [-2.5009063678660049 .. -0.0021143037956745658]
#   J  = [2.3182023568246274 .. 6.4892456363200735]
# f(J) = [-0.0019014547054210241 .. 8.4963733382557046]
#   J  = [6.8667576512155781 .. 8.2066212216718828]
# f(J) = [-2.5000379898895063 .. 0.0024387538136543264]
#   J  = [8.6000000000000333 .. 10.283185307179589]
# f(J) = [-0.060602264719935129 .. 8.1667675079350258]
# Monitored signal 0.0780072212219 sec
# Graphics object consisting of 2 graphics primitives

# %%
sig = U(G(RIF(1, 1.2), P), RIF(0.4, 0.5), F(RIF(3.5, 4), Q)).signal_for_system(
    odes, [RIF(4, 5), RIF(1, 2)], 2*pi)
plot_signal( sig )
# Out:
# Computed 120 flowpipes in 0.0383131504059 sec
# Prepared for plotting in 0.0351545810699 sec
# domain = [0.00000000000000000 .. 11.983185307179588]
# roots = [[0.36442391108285443 .. 0.75322999900880539],
#  [4.9094498886890116 .. 5.3000000000000105],
#  [6.6497432568189269 .. 7.0331814940841380],
#  [11.200000000000070 .. 11.582737468232921]]
#   J  = [0.00000000000000000 .. 0.36442391108285444]
# f(J) = [0.0027202813179409979 .. 2.0000000000000009]
#   J  = [0.75322999900880538 .. 4.9094498886890117]
# f(J) = [-8.4984031964855867 .. -0.00016697542414467747]
#   J  = [5.3000000000000104 .. 6.6497432568189270]
# f(J) = [-0.0039940204023398707 .. 2.5005510818925254]
#   J  = [7.0331814940841379 .. 11.200000000000071]
# f(J) = [-8.4948345026507575 .. -0.00053751205010632574]
#   J  = [11.582737468232920 .. 11.983185307179588]
# f(J) = [0.00065815528209167695 .. 2.3583359199431007]
# domain = [0.00000000000000000 .. 11.983185307179588]
# roots = [[0.20000000000000001 .. 0.58848494710426814],
#  [1.9311141906428948 .. 2.3182023568246275],
#  [6.4892456363200734 .. 6.8667576512155782],
#  [8.2066212216718827 .. 8.6000000000000334]]
#   J  = [0.00000000000000000 .. 0.20000000000000002]
# f(J) = [0.023305845235470190 .. 2.0000000000000005]
#   J  = [0.58848494710426813 .. 1.9311141906428949]
# f(J) = [-2.5009063678660049 .. -0.0021143037956745658]
#   J  = [2.3182023568246274 .. 6.4892456363200735]
# f(J) = [-0.0019014547054210241 .. 8.4963733382557046]
#   J  = [6.8667576512155781 .. 8.2066212216718828]
# f(J) = [-2.5000379898895063 .. 0.0024387538136543264]
#   J  = [8.6000000000000333 .. 11.983185307179588]
# f(J) = [-0.060602264719935129 .. 8.4993515684232808]
# Monitored signal 0.0808854103088 sec
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# ## Context!

# %%
{y: RIF(9,10)} >> P
# Out:
# C({y: [9 .. 10]}, Atomic(x - 3))

# %%
sig = ({y: RIF(9,10)} >> P).signal_for_system(odes, initials, 4*pi)
# Out:
# Computed 126 flowpipes in 0.0453960895538 sec
# Prepared for plotting in 0.0370516777039 sec
# Computed 1 flowpipes in 0.00103688240051 sec
# Prepared for plotting in 0.000356912612915 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.10000000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00262522697449 sec
# Computed 1 flowpipes in 0.00078296661377 sec
# Prepared for plotting in 0.000239849090576 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.10000000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00147128105164 sec
# Computed 1 flowpipes in 0.00115895271301 sec
# Prepared for plotting in 0.000600814819336 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.10000000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00233912467957 sec
# Computed 1 flowpipes in 0.000702857971191 sec
# Prepared for plotting in 0.000255823135376 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.10000000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00280833244324 sec
# Computed 1 flowpipes in 0.00065803527832 sec
# Prepared for plotting in 0.00024676322937 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.10000000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00171804428101 sec
# Computed 1 flowpipes in 0.00131893157959 sec
# Prepared for plotting in 0.000902891159058 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.10000000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00168228149414 sec
# Computed 1 flowpipes in 0.000724077224731 sec
# Prepared for plotting in 0.00038480758667 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.10000000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00157618522644 sec
# Computed 1 flowpipes in 0.000679969787598 sec
# Prepared for plotting in 0.000360727310181 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = []
#   J  = [0.00000000000000000 .. 0.0010000000000000001]
# f(J) = [-5.0912954091701268 .. -0.11147099143369798]
# Monitored signal 0.0016393661499 sec
# Computed 1 flowpipes in 0.000684976577759 sec
# Prepared for plotting in 0.000699758529663 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = []
#   J  = [0.00000000000000000 .. 0.0010000000000000001]
# f(J) = [-8.5134764279171229 .. -3.9251246305377724]
# Monitored signal 0.00246238708496 sec
# Computed 1 flowpipes in 0.000671148300171 sec
# Prepared for plotting in 0.00057578086853 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.10000000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.0021550655365 sec
# Computed 1 flowpipes in 0.00068211555481 sec
# Prepared for plotting in 0.000403642654419 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = []
#   J  = [0.00000000000000000 .. 0.0010000000000000001]
# f(J) = [-8.0512970239632243 .. -0.94195209315728023]
# Monitored signal 0.0020854473114 sec
# Computed 1 flowpipes in 0.000779867172241 sec
# Prepared for plotting in 0.000598907470703 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.10000000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00174117088318 sec
# Computed 1 flowpipes in 0.000696897506714 sec
# Prepared for plotting in 0.000597715377808 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.10000000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.0019793510437 sec
# Computed 1 flowpipes in 0.000783920288086 sec
# Prepared for plotting in 0.000401973724365 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.10000000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00173616409302 sec
# Computed 1 flowpipes in 0.000713109970093 sec
# Prepared for plotting in 0.000762701034546 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.10000000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00190114974976 sec
# Computed 1 flowpipes in 0.00075888633728 sec
# Prepared for plotting in 0.00040864944458 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.026319357623306765 .. 0.10000000000000001]]
#   J  = [0.00000000000000000 .. 0.026319357623306766]
# f(J) = [0.14662921301689912 .. 2.5005510818925272]
#   J  = [0.0010000000000000000 .. 0.0010000000000000001]
# f(J) = [0.45468347614772763 .. 2.4944451893558153]
# Monitored signal 0.0024893283844 sec
# Computed 1 flowpipes in 0.000760078430176 sec
# Prepared for plotting in 0.000311851501465 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.10000000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00166916847229 sec
# Computed 1 flowpipes in 0.000771999359131 sec
# Prepared for plotting in 0.00107073783875 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.10000000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00168609619141 sec
# Computed 1 flowpipes in 0.000717878341675 sec
# Prepared for plotting in 0.00037693977356 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.10000000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00263810157776 sec
# Computed 1 flowpipes in 0.000775098800659 sec
# Prepared for plotting in 0.000549793243408 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.10000000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00201821327209 sec
# Computed 1 flowpipes in 0.00072979927063 sec
# Prepared for plotting in 0.000264883041382 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.10000000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00186920166016 sec
# Computed 1 flowpipes in 0.000975131988525 sec
# Prepared for plotting in 0.000283718109131 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.10000000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00218510627747 sec
# Computed 1 flowpipes in 0.000756978988647 sec
# Prepared for plotting in 0.000277757644653 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = []
#   J  = [0.00000000000000000 .. 0.0010000000000000001]
# f(J) = [-5.0752945887592658 .. -0.12499641275796369]
# Monitored signal 0.00159120559692 sec
# Computed 1 flowpipes in 0.000799894332886 sec
# Prepared for plotting in 0.000517845153809 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = []
#   J  = [0.00000000000000000 .. 0.0010000000000000001]
# f(J) = [-8.5098893940755503 .. -3.9444942303603691]
# Monitored signal 0.00205612182617 sec
# Computed 1 flowpipes in 0.000745058059692 sec
# Prepared for plotting in 0.000747680664062 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.10000000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00168037414551 sec
# Computed 1 flowpipes in 0.000746011734009 sec
# Prepared for plotting in 0.000324726104736 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = []
#   J  = [0.00000000000000000 .. 0.0010000000000000001]
# f(J) = [-8.0333944235326698 .. -0.89238918546432310]
# Monitored signal 0.00266122817993 sec
# Computed 1 flowpipes in 0.000772953033447 sec
# Prepared for plotting in 0.000421762466431 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.10000000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00172543525696 sec
# Computed 1 flowpipes in 0.000698804855347 sec
# Prepared for plotting in 0.000263929367065 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.10000000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00144529342651 sec
# Computed 1 flowpipes in 0.000845909118652 sec
# Prepared for plotting in 0.000427961349487 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.10000000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00170922279358 sec
# Computed 1 flowpipes in 0.000784158706665 sec
# Prepared for plotting in 0.000280618667603 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.10000000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00160026550293 sec
# Computed 1 flowpipes in 0.000839948654175 sec
# Prepared for plotting in 0.00116467475891 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.028013549409454257 .. 0.10000000000000001]]
#   J  = [0.00000000000000000 .. 0.028013549409454258]
# f(J) = [0.13557902058944559 .. 2.5008287124739593]
#   J  = [0.0010000000000000000 .. 0.0010000000000000001]
# f(J) = [0.46393293167837867 .. 2.4947093671474736]
# Monitored signal 0.00253915786743 sec
# Monitored signal 0.195897340775 sec

# %%
sig.plot()
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
sig = ({y: RIF(9,10)} >> G(RIF(0, 5), P)).signal_for_system(odes, initials, 4*pi)
# Out:
# Computed 126 flowpipes in 0.0417628288269 sec
# Prepared for plotting in 0.0367448329926 sec
# Computed 51 flowpipes in 0.0152430534363 sec
# Prepared for plotting in 0.0135028362274 sec
# domain = [0.00000000000000000 .. 5.0010000000000013]
# roots = [[0.00000000000000000 .. 0.60000000000000020],
#  [2.4822037957995264 .. 4.7000000000000073],
#  [4.7698759272905624 .. 5.0019999999990006]]
#   J  = [0.60000000000000019 .. 2.4822037957995265]
# f(J) = [-20.514225737162644 .. 0.16953181235869197]
#   J  = [4.7000000000000072 .. 4.7698759272905625]
# f(J) = [-0.72676785106918729 .. 13.726834376009397]
# 0 at 5.00100000000001
# Monitored signal 0.0197021961212 sec
# Monitored signal 0.0648522377014 sec

# %%
sig.plot()
# Out:
# /usr/lib64/python2.7/site-packages/matplotlib/contour.py:1230: UserWarning: No contour levels were found within the data range.
#   warnings.warn("No contour levels were found"
# Graphics object consisting of 2 graphics primitives

# %%
sig = ({y: RIF(9,10)} >> G(RIF(0, pi/2), Atomic(y))).signal_for_system(odes, initials, 4*pi)
# Out:
# Computed 126 flowpipes in 0.0431590080261 sec
# Prepared for plotting in 0.0358798503876 sec
# Computed 16 flowpipes in 0.00530505180359 sec
# Prepared for plotting in 0.0039267539978 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = [[0.48976875460053881 .. 1.5727963267938970]]
#   J  = [0.00000000000000000 .. 0.48976875460053882]
# f(J) = [0.020031670474434062 .. 16.856250509811777]
# 0 at 1.57179632679490
# Monitored signal 0.0083372592926 sec
# Computed 16 flowpipes in 0.00487017631531 sec
# Prepared for plotting in 0.00467371940613 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = [[0.48998378304691336 .. 1.5727963267938970]]
#   J  = [0.00000000000000000 .. 0.48998378304691337]
# f(J) = [0.020067908071656651 .. 16.856053928583024]
# 0 at 1.57179632679490
# Monitored signal 0.00690317153931 sec
# Computed 16 flowpipes in 0.00503587722778 sec
# Prepared for plotting in 0.00436496734619 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = [[0.85830949637413489 .. 1.5727963267938965]]
#   J  = [0.00000000000000000 .. 0.85830949637413490]
# f(J) = [0.0054489278887099139 .. 16.558300474072543]
# 0 at 1.57179632679490
# Monitored signal 0.00791215896606 sec
# Computed 16 flowpipes in 0.00518798828125 sec
# Prepared for plotting in 0.00445675849915 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = [[1.3366343237330100 .. 1.5727963267938956]]
#   J  = [0.00000000000000000 .. 1.3366343237330101]
# f(J) = [0.10131233640166592 .. 16.476630869492909]
# 0 at 1.57179632679490
# Monitored signal 0.00590944290161 sec
# Computed 16 flowpipes in 0.00476884841919 sec
# Prepared for plotting in 0.00454092025757 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = []
#   J  = [0.00000000000000000 .. 1.5717963267948972]
# f(J) = [0.97271708457058558 .. 16.011326963574135]
# Monitored signal 0.00611925125122 sec
# Computed 16 flowpipes in 0.005047082901 sec
# Prepared for plotting in 0.00400757789612 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = [[1.3841807072496381 .. 1.5727963267938956]]
#   J  = [0.00000000000000000 .. 1.3841807072496382]
# f(J) = [0.0075605104019722648 .. 15.874732577292049]
# 0 at 1.57179632679490
# Monitored signal 0.00624823570251 sec
# Computed 16 flowpipes in 0.00518083572388 sec
# Prepared for plotting in 0.0042188167572 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = [[1.5303714965960022 .. 1.5727963267938952]]
#   J  = [0.00000000000000000 .. 1.5303714965960023]
# f(J) = [0.020177306343244983 .. 15.847924401319905]
# 0 at 1.57179632679490
# Monitored signal 0.00743126869202 sec
# Computed 16 flowpipes in 0.00482702255249 sec
# Prepared for plotting in 0.00415563583374 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = [[1.3923712010375324 .. 1.5727963267938956]]
#   J  = [0.00000000000000000 .. 1.3923712010375325]
# f(J) = [0.0060541017422362109 .. 15.591524203832837]
# 0 at 1.57179632679490
# Monitored signal 0.00778722763062 sec
# Computed 16 flowpipes in 0.00473380088806 sec
# Prepared for plotting in 0.00478887557983 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = [[0.86006538426177880 .. 1.5206754703498886]]
#   J  = [0.00000000000000000 .. 0.86006538426177881]
# f(J) = [0.0043352245123530076 .. 15.073231431533668]
#   J  = [1.5206754703498885 .. 1.5717963267948972]
# f(J) = [-6.1002773969591369 .. 0.0026087793972518416]
# Monitored signal 0.00905513763428 sec
# Computed 16 flowpipes in 0.00549697875977 sec
# Prepared for plotting in 0.00403189659119 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = [[0.56120942771699966 .. 1.5727963267938970]]
#   J  = [0.00000000000000000 .. 0.56120942771699967]
# f(J) = [0.0067145908142869871 .. 13.649325196960004]
# 0 at 1.57179632679490
# Monitored signal 0.00868320465088 sec
# Computed 16 flowpipes in 0.00550293922424 sec
# Prepared for plotting in 0.00413870811462 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = [[0.57155966864181462 .. 1.5727963267938970]]
#   J  = [0.00000000000000000 .. 0.57155966864181463]
# f(J) = [0.0075538905911483869 .. 9.4046781511413738]
# 0 at 1.57179632679490
# Monitored signal 0.00865936279297 sec
# Computed 16 flowpipes in 0.00509691238403 sec
# Prepared for plotting in 0.00401282310486 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = [[0.65028086630060666 .. 1.4400585080577073]]
#   J  = [0.00000000000000000 .. 0.65028086630060667]
# f(J) = [0.000022107821313528211 .. 9.0439887153214294]
#   J  = [1.4400585080577072 .. 1.5717963267948972]
# f(J) = [-5.4182473937653662 .. 0.0047671654116289526]
# Monitored signal 0.00850534439087 sec
# Computed 16 flowpipes in 0.00484204292297 sec
# Prepared for plotting in 0.00407767295837 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = [[0.85825406577124396 .. 1.5727963267938965]]
#   J  = [0.00000000000000000 .. 0.85825406577124397]
# f(J) = [0.0022479855611655915 .. 6.8997249066261146]
# 0 at 1.57179632679490
# Monitored signal 0.00817131996155 sec
# Computed 16 flowpipes in 0.00493717193604 sec
# Prepared for plotting in 0.00431275367737 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = [[0.85861773535250618 .. 1.5727963267938965]]
#   J  = [0.00000000000000000 .. 0.85861773535250619]
# f(J) = [0.0018275718600956022 .. 6.5218059307944394]
# 0 at 1.57179632679490
# Monitored signal 0.0072500705719 sec
# Computed 16 flowpipes in 0.00501608848572 sec
# Prepared for plotting in 0.00410962104797 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = [[1.2542205278912765 .. 1.5727963267938959]]
#   J  = [0.00000000000000000 .. 1.2542205278912766]
# f(J) = [0.00078120136234648032 .. 6.5217888306821533]
# 0 at 1.57179632679490
# Monitored signal 0.00913524627686 sec
# Computed 16 flowpipes in 0.00553202629089 sec
# Prepared for plotting in 0.00456976890564 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = []
#   J  = [0.00000000000000000 .. 1.5717963267948972]
# f(J) = [0.39016925798180962 .. 13.630466707676826]
# Monitored signal 0.00576519966125 sec
# Computed 16 flowpipes in 0.00475001335144 sec
# Prepared for plotting in 0.00415587425232 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = [[0.48990352449496671 .. 1.5727963267938970]]
#   J  = [0.00000000000000000 .. 0.48990352449496672]
# f(J) = [0.020053683596537853 .. 16.855420916644470]
# 0 at 1.57179632679490
# Monitored signal 0.00933718681335 sec
# Computed 16 flowpipes in 0.00535202026367 sec
# Prepared for plotting in 0.00450587272644 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = [[0.85911959678913785 .. 1.5727963267938965]]
#   J  = [0.00000000000000000 .. 0.85911959678913786]
# f(J) = [0.0059564842170644356 .. 16.590735122612998]
# 0 at 1.57179632679490
# Monitored signal 0.0065381526947 sec
# Computed 16 flowpipes in 0.00536298751831 sec
# Prepared for plotting in 0.00507283210754 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = [[1.3355495901948972 .. 1.5727963267938956]]
#   J  = [0.00000000000000000 .. 1.3355495901948973]
# f(J) = [0.10150723020689182 .. 16.503760069794606]
# 0 at 1.57179632679490
# Monitored signal 0.00628519058228 sec
# Computed 16 flowpipes in 0.00582695007324 sec
# Prepared for plotting in 0.00397872924805 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = []
#   J  = [0.00000000000000000 .. 1.5717963267948972]
# f(J) = [0.97696097806529236 .. 16.033656230068264]
# Monitored signal 0.00555229187012 sec
# Computed 16 flowpipes in 0.00597715377808 sec
# Prepared for plotting in 0.00404071807861 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = [[1.3853340015789046 .. 1.5727963267938956]]
#   J  = [0.00000000000000000 .. 1.3853340015789047]
# f(J) = [0.0076668892920997216 .. 15.871069905796534]
# 0 at 1.57179632679490
# Monitored signal 0.00641012191772 sec
# Computed 16 flowpipes in 0.00497508049011 sec
# Prepared for plotting in 0.00406670570374 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = [[1.5315216586099897 .. 1.5727963267938952]]
#   J  = [0.00000000000000000 .. 1.5315216586099898]
# f(J) = [0.016293127159051574 .. 15.853453601812952]
# 0 at 1.57179632679490
# Monitored signal 0.00790238380432 sec
# Computed 16 flowpipes in 0.00749492645264 sec
# Prepared for plotting in 0.00532388687134 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = [[1.3936347326790499 .. 1.3999999999999995],
#  [1.4008752724628548 .. 1.5727963267938956]]
#   J  = [0.00000000000000000 .. 1.3936347326790500]
# f(J) = [0.0060787889989807955 .. 15.592092700022916]
#   J  = [1.3999999999999994 .. 1.4008752724628549]
# f(J) = [-0.093555372600724607 .. 3.9259817878480523]
# 0 at 1.57179632679490
# Monitored signal 0.010026216507 sec
# Computed 16 flowpipes in 0.00595903396606 sec
# Prepared for plotting in 0.00593876838684 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = [[0.86097681803601455 .. 1.5176355699467905]]
#   J  = [0.00000000000000000 .. 0.86097681803601456]
# f(J) = [0.0046756730752821112 .. 15.054891424789315]
#   J  = [1.5176355699467904 .. 1.5717963267948972]
# f(J) = [-6.0942677567278585 .. 0.0023986726774978388]
# Monitored signal 0.00956535339355 sec
# Computed 16 flowpipes in 0.00682497024536 sec
# Prepared for plotting in 0.00496673583984 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = [[0.56185347401316754 .. 1.5727963267938970]]
#   J  = [0.00000000000000000 .. 0.56185347401316755]
# f(J) = [0.0070418102553810460 .. 13.634601962970568]
# 0 at 1.57179632679490
# Monitored signal 0.0080783367157 sec
# Computed 16 flowpipes in 0.00536584854126 sec
# Prepared for plotting in 0.00415873527527 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = [[0.57236318516581086 .. 1.5727963267938970]]
#   J  = [0.00000000000000000 .. 0.57236318516581087]
# f(J) = [0.0077637822452124409 .. 9.3999601370564481]
# 0 at 1.57179632679490
# Monitored signal 0.00736141204834 sec
# Computed 16 flowpipes in 0.00568103790283 sec
# Prepared for plotting in 0.0054337978363 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = [[0.64476197843630755 .. 1.4412188190680416]]
#   J  = [0.00000000000000000 .. 0.64476197843630756]
# f(J) = [0.032219990921693961 .. 9.0241
# <b>limit_output extension: Maximum message size of 10000 exceeded with 11577 characters</b>

# %%
sig.plot()
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# ## Differential context!

# %%
sig = ({y: RIF(9,10)} % P).signal_for_system(odes, initials, 4*pi)
# Out:
# Computed 126 flowpipes in 0.0431661605835 sec
# Prepared for plotting in 0.046288728714 sec
# Computed 2 flowpipes in 0.00220704078674 sec
# Prepared for plotting in 0.000882863998413 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.0019999999990000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00265026092529 sec
# Computed 2 flowpipes in 0.00172996520996 sec
# Prepared for plotting in 0.000586748123169 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.0019999999990000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00276732444763 sec
# Computed 2 flowpipes in 0.00183892250061 sec
# Prepared for plotting in 0.00130891799927 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.0019999999990000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00288414955139 sec
# Computed 2 flowpipes in 0.00165605545044 sec
# Prepared for plotting in 0.000903606414795 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.0019999999990000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00178933143616 sec
# Computed 2 flowpipes in 0.00173306465149 sec
# Prepared for plotting in 0.000635623931885 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.0019999999990000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.002765417099 sec
# Computed 2 flowpipes in 0.00219988822937 sec
# Prepared for plotting in 0.000755786895752 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.0019999999990000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00248432159424 sec
# Computed 2 flowpipes in 0.0019690990448 sec
# Prepared for plotting in 0.000592708587646 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.0019999999990000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00236535072327 sec
# Computed 2 flowpipes in 0.00181603431702 sec
# Prepared for plotting in 0.00081467628479 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = []
#   J  = [0.00000000000000000 .. 0.0010000000000000001]
# f(J) = [-5.0813013798770666 .. -0.11146977072675889]
# Monitored signal 0.00223827362061 sec
# Computed 2 flowpipes in 0.00175189971924 sec
# Prepared for plotting in 0.000554800033569 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = []
#   J  = [0.00000000000000000 .. 0.0010000000000000001]
# f(J) = [-8.5034819364024906 .. -3.9230789501595717]
# Monitored signal 0.00183820724487 sec
# Computed 2 flowpipes in 0.00178813934326 sec
# Prepared for plotting in 0.000610589981079 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.0019999999990000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00296425819397 sec
# Computed 2 flowpipes in 0.00177788734436 sec
# Prepared for plotting in 0.000694751739502 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = []
#   J  = [0.00000000000000000 .. 0.0010000000000000001]
# f(J) = [-8.0422532269308871 .. -0.93645449911208578]
# Monitored signal 0.001873254776 sec
# Computed 2 flowpipes in 0.00178694725037 sec
# Prepared for plotting in 0.000634908676147 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.0019999999990000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00226426124573 sec
# Computed 2 flowpipes in 0.00191020965576 sec
# Prepared for plotting in 0.000573635101318 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.0019999999990000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00196719169617 sec
# Computed 2 flowpipes in 0.00184798240662 sec
# Prepared for plotting in 0.000542879104614 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.0019999999990000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00207018852234 sec
# Computed 2 flowpipes in 0.00180792808533 sec
# Prepared for plotting in 0.000621795654297 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.0019999999990000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00197124481201 sec
# Computed 2 flowpipes in 0.00182414054871 sec
# Prepared for plotting in 0.000582695007324 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = []
#   J  = [0.00000000000000000 .. 0.0010000000000000001]
# f(J) = [0.46467750394064344 .. 2.5034481414361754]
# Monitored signal 0.00522112846375 sec
# Computed 2 flowpipes in 0.00279402732849 sec
# Prepared for plotting in 0.000884771347046 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.0019999999990000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.0019953250885 sec
# Computed 2 flowpipes in 0.00190281867981 sec
# Prepared for plotting in 0.000598907470703 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.0019999999990000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.0026581287384 sec
# Computed 2 flowpipes in 0.00180721282959 sec
# Prepared for plotting in 0.000609636306763 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.0019999999990000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00191831588745 sec
# Computed 2 flowpipes in 0.00165104866028 sec
# Prepared for plotting in 0.000693798065186 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.0019999999990000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00234222412109 sec
# Computed 2 flowpipes in 0.00215196609497 sec
# Prepared for plotting in 0.00108575820923 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.0019999999990000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00265836715698 sec
# Computed 2 flowpipes in 0.00258803367615 sec
# Prepared for plotting in 0.000925779342651 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.0019999999990000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00232529640198 sec
# Computed 2 flowpipes in 0.00162220001221 sec
# Prepared for plotting in 0.000636577606201 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = []
#   J  = [0.00000000000000000 .. 0.0010000000000000001]
# f(J) = [-5.0653005594662047 .. -0.12499519205102460]
# Monitored signal 0.00232625007629 sec
# Computed 2 flowpipes in 0.00179886817932 sec
# Prepared for plotting in 0.000699758529663 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = []
#   J  = [0.00000000000000000 .. 0.0010000000000000001]
# f(J) = [-8.4998948928735648 .. -3.9424638597061338]
# Monitored signal 0.00202035903931 sec
# Computed 2 flowpipes in 0.00265288352966 sec
# Prepared for plotting in 0.000804901123047 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.0019999999990000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00283217430115 sec
# Computed 2 flowpipes in 0.00178718566895 sec
# Prepared for plotting in 0.000587701797485 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = []
#   J  = [0.00000000000000000 .. 0.0010000000000000001]
# f(J) = [-8.0243704792531823 .. -0.88688861318896083]
# Monitored signal 0.00269031524658 sec
# Computed 2 flowpipes in 0.0027129650116 sec
# Prepared for plotting in 0.00161385536194 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.0019999999990000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00308704376221 sec
# Computed 2 flowpipes in 0.00203418731689 sec
# Prepared for plotting in 0.000978708267212 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.0019999999990000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00291419029236 sec
# Computed 2 flowpipes in 0.00259590148926 sec
# Prepared for plotting in 0.000795841217041 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.0019999999990000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00286412239075 sec
# Computed 2 flowpipes in 0.00187587738037 sec
# Prepared for plotting in 0.000678777694702 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.0019999999990000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00205731391907 sec
# Computed 2 flowpipes in 0.00188493728638 sec
# Prepared for plotting in 0.000549793243408 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = []
#   J  = [0.00000000000000000 .. 0.0010000000000000001]
# f(J) = [0.47392695947129448 .. 2.5037123238471431]
# Monitored signal 0.00228714942932 sec
# Monitored signal 0.263804197311 sec

# %%
sig = ({y: RIF(0.5,0.6)} % P).signal_for_system(odes, initials, 4*pi, verbosity=10)
# Out:
# Computed 126 flowpipes in 0.0456399917603 sec
# Prepared for plotting in 0.0465617179871 sec
# Computed 1 flowpipes in 0.00139403343201 sec
# Prepared for plotting in 0.000336885452271 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.012500000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00219416618347 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# I  = [0.00000000000000000 .. 12.567370614359174]
# fI = ['[-5.4984031964855867 .. 5.5008287124739575]', '[-5.4993515684232799 .. 5.5009063678660049]']
# C || f(I) = ['[-5.4984031964855867 .. 5.5008287124739575]', '[-5.4993515684232799 .. 5.5009063678660049]']
#      odes = [-y, x]
# D || odes = [-y, x + 0.6?]
# phi(D || odes, C || f(I)) = None
# bisecting [0.00000000000000000 .. 12.567370614359174] -> [0.00000000000000000 .. 6.2836853071795869], [6.2836853071795868 .. 12.567370614359174]
# Computed 1 flowpipes in 0.00139904022217 sec
# Prepared for plotting in 0.00030779838562 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.012500000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.0036301612854 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 1 flowpipes in 0.00133800506592 sec
# Prepared for plotting in 0.000494956970215 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.012500000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00166606903076 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 1 flowpipes in 0.00130605697632 sec
# Prepared for plotting in 0.000296592712402 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.012500000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00207924842834 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 1 flowpipes in 0.00139594078064 sec
# Prepared for plotting in 0.000314712524414 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.012500000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00170016288757 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 1 flowpipes in 0.00125694274902 sec
# Prepared for plotting in 0.000293731689453 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.012500000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00161933898926 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 1 flowpipes in 0.00143909454346 sec
# Prepared for plotting in 0.000309705734253 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.012500000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00181031227112 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 1 flowpipes in 0.00131392478943 sec
# Prepared for plotting in 0.000328779220581 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = []
#   J  = [0.00000000000000000 .. 0.0010000000000000001]
# f(J) = [-5.0813034979152443 .. -0.11146317768858127]
# Monitored signal 0.00243711471558 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [([0.00000000000000000 .. 0.0010000000000000001], False)])
# sig(0) = False
# Computed 1 flowpipes in 0.00157809257507 sec
# Prepared for plotting in 0.00112366676331 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = []
#   J  = [0.00000000000000000 .. 0.0010000000000000001]
# f(J) = [-8.5034842416622390 .. -3.9230698820742575]
# Monitored signal 0.002197265625 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [([0.00000000000000000 .. 0.0010000000000000001], False)])
# sig(0) = False
# Computed 1 flowpipes in 0.00228691101074 sec
# Prepared for plotting in 0.000783920288086 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.012500000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00238704681396 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 1 flowpipes in 0.00188398361206 sec
# Prepared for plotting in 0.00124979019165 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = []
#   J  = [0.00000000000000000 .. 0.0010000000000000001]
# f(J) = [-8.0422598199690647 .. -0.93644565994790518]
# Monitored signal 0.00244522094727 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [([0.00000000000000000 .. 0.0010000000000000001], False)])
# sig(0) = False
# Computed 1 flowpipes in 0.00189399719238 sec
# Prepared for plotting in 0.00051474571228 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.012500000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00258040428162 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 1 flowpipes in 0.00143909454346 sec
# Prepared for plotting in 0.000338792800903 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.012500000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00393223762512 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 1 flowpipes in 0.00160193443298 sec
# Prepared for plotting in 0.000507831573486 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.012500000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00396132469177 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 1 flowpipes in 0.00145411491394 sec
# Prepared for plotting in 0.000462770462036 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.012500000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00320816040039 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 1 flowpipes in 0.00185418128967 sec
# Prepared for plotting in 0.000640630722046 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = []
#   J  = [0.00000000000000000 .. 0.0010000000000000001]
# f(J) = [0.46467538590246570 .. 2.5034547344743530]
# Monitored signal 0.00249528884888 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [([0.00000000000000000 .. 0.0010000000000000001], True)])
# sig(0) = True
# Computed 1 flowpipes in 0.00320506095886 sec
# Prepared for plotting in 0.000500679016113 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.012500000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00259923934937 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 1 flowpipes in 0.00210213661194 sec
# Prepared for plotting in 0.000508785247803 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.012500000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00222110748291 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 1 flowpipes in 0.00193405151367 sec
# Prepared for plotting in 0.00123286247253 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.012500000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00239014625549 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 1 flowpipes in 0.00158214569092 sec
# Prepared for plotting in 0.000864744186401 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.012500000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00265312194824 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 1 flowpipes in 0.0016450881958 sec
# Prepared for plotting in 0.000348806381226 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.012500000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00231719017029 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 1 flowpipes in 0.00166392326355 sec
# Prepared for plotting in 0.00099778175354 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.012500000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00209617614746 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 1 flowpipes in 0.00160217285156 sec
# Prepared for plotting in 0.000503778457642 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = []
#   J  = [0.00000000000000000 .. 0.0010000000000000001]
# f(J) = [-5.0653026775043824 .. -0.12498859901284697]
# Monitored signal 0.00260210037231 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [([0.00000000000000000 .. 0.0010000000000000001], False)])
# sig(0) = False
# Computed 1 flowpipes in 0.00184798240662 sec
# Prepared for plotting in 0.000359773635864 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = []
#   J  = [0.00000000000000000 .. 0.0010000000000000001]
# f(J) = [-8.4998972078206663 .. -3.9424547934082232]
# Monitored signal 0.00272727012634 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [([0.00000000000000000 .. 0.0010000000000000001], False)])
# sig(0) = False
# Computed 1 flowpipes in 0.00181984901428 sec
# Prepared for plotting in 0.000472784042358 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.012500000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00192737579346 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 1 flowpipes in 0.00173997879028 sec
# Prepared for plotting in 0.00115990638733 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = []
#   J
# <b>limit_output extension: Maximum message size of 10000 exceeded with 12146 characters</b>

# %%
({y: RIF(9,10)} % P)
# Out:
# D({y: [9 .. 10]}, Atomic(x - 3))

# %%
sig.plot()
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
sig = ({y: RIF(0.5, 0.6)} % G(RIF(0, 5), P)
       ).signal_for_system(odes, initials, 4*pi, verbosity=10)
# Out:
# Computed 126 flowpipes in 0.047651052475 sec
# Prepared for plotting in 0.0425357818604 sec
# Computed 355 flowpipes in 0.134757995605 sec
# Prepared for plotting in 0.0973846912384 sec
# domain = [0.00000000000000000 .. 5.0010000000000013]
# roots = [[0.00000000000000000 .. 5.0019999999990006]]
# 0 at 5.00100000000001
# Monitored signal 0.155094146729 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# I  = [0.00000000000000000 .. 12.567370614359174]
# fI = ['[-5.4984031964855867 .. 5.5008287124739575]', '[-5.4993515684232799 .. 5.5009063678660049]']
# C || f(I) = ['[-5.4984031964855867 .. 5.5008287124739575]', '[-5.4993515684232799 .. 5.5009063678660049]']
#      odes = [-y, x]
# D || odes = [-y, x + 0.6?]
# phi(D || odes, C || f(I)) = None
# bisecting [0.00000000000000000 .. 12.567370614359174] -> [0.00000000000000000 .. 6.2836853071795869], [6.2836853071795868 .. 12.567370614359174]
# Computed 355 flowpipes in 0.122503995895 sec
# Prepared for plotting in 0.0957057476044 sec
# domain = [0.00000000000000000 .. 5.0010000000000013]
# roots = [[0.00000000000000000 .. 5.0019999999990006]]
# 0 at 5.00100000000001
# Monitored signal 0.137212276459 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 355 flowpipes in 0.119754076004 sec
# Prepared for plotting in 0.100574731827 sec
# domain = [0.00000000000000000 .. 5.0010000000000013]
# roots = [[0.00000000000000000 .. 1.2989702951483120],
#  [1.3066254718620424 .. 1.3087798003978491],
#  [1.8693280010382149 .. 5.0019999999990006]]
#   J  = [1.2989702951483119 .. 1.3066254718620425]
# f(J) = [-10.407077903375472 .. 0.13906746975795770]
#   J  = [1.3087798003978490 .. 1.8693280010382150]
# f(J) = [-10.579712831442480 .. 0.011277482703899278]
# 0 at 5.00100000000001
# Monitored signal 0.150239229202 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [([0.00000000000000000 .. 0.0010000000000000001], False)])
# sig(0) = False
# Computed 355 flowpipes in 0.130316019058 sec
# Prepared for plotting in 0.101240634918 sec
# domain = [0.00000000000000000 .. 5.0010000000000013]
# roots = [[0.00000000000000000 .. 5.0019999999990006]]
# 0 at 5.00100000000001
# Monitored signal 0.144416332245 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 355 flowpipes in 0.122577190399 sec
# Prepared for plotting in 0.102617740631 sec
# domain = [0.00000000000000000 .. 5.0010000000000013]
# roots = [[0.17822001758884969 .. 3.9880842920781597]]
#   J  = [0.00000000000000000 .. 0.17822001758884970]
# f(J) = [-8.0422598199690647 .. -0.000040420159176157710]
#   J  = [3.9880842920781596 .. 5.0010000000000013]
# f(J) = [-13.595777531570127 .. 0.019414816502550725]
# Monitored signal 0.129473209381 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [([0.00000000000000000 .. 0.0010000000000000001], False)])
# sig(0) = False
# Computed 355 flowpipes in 0.11964392662 sec
# Prepared for plotting in 0.0962388515472 sec
# domain = [0.00000000000000000 .. 5.0010000000000013]
# roots = [[0.00000000000000000 .. 2.1427538124242261],
#  [4.4188663079912799 .. 5.0019999999990006]]
#   J  = [2.1427538124242260 .. 4.4188663079912800]
# f(J) = [-12.629693702782321 .. 0.036516993875656212]
# 0 at 5.00100000000001
# Monitored signal 0.127847194672 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [([0.00000000000000000 .. 0.0010000000000000001], False)])
# sig(0) = False
# Computed 355 flowpipes in 0.120396852493 sec
# Prepared for plotting in 0.109339952469 sec
# domain = [0.00000000000000000 .. 5.0010000000000013]
# roots = [[0.00000000000000000 .. 5.0019999999990006]]
# 0 at 5.00100000000001
# Monitored signal 0.138155221939 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 355 flowpipes in 0.122137069702 sec
# Prepared for plotting in 0.101983785629 sec
# domain = [0.00000000000000000 .. 5.0010000000000013]
# roots = [[0.00000000000000000 .. 1.2989702951483120],
#  [1.3050969184665059 .. 1.3087798003978491],
#  [1.8717283360747871 .. 5.0019999999990006]]
#   J  = [1.2989702951483119 .. 1.3050969184665060]
# f(J) = [-10.406697246885422 .. 0.14888317350898995]
#   J  = [1.3087798003978490 .. 1.8717283360747872]
# f(J) = [-10.618645812129993 .. 0.019605070939765934]
# 0 at 5.00100000000001
# Monitored signal 0.141231060028 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [([0.00000000000000000 .. 0.0010000000000000001], False)])
# sig(0) = False
# Computed 355 flowpipes in 0.123723983765 sec
# Prepared for plotting in 0.0983526706696 sec
# domain = [0.00000000000000000 .. 5.0010000000000013]
# roots = [[0.00000000000000000 .. 5.0019999999990006]]
# 0 at 5.00100000000001
# Monitored signal 0.135647296906 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [])
# sig(0) = None
# Computed 355 flowpipes in 0.117083072662 sec
# Prepared for plotting in 0.0956676006317 sec
# domain = [0.00000000000000000 .. 5.0010000000000013]
# roots = [[0.16689869283165215 .. 3.9773819852752373]]
#   J  = [0.00000000000000000 .. 0.16689869283165216]
# f(J) = [-8.0243770722913599 .. -0.00015281343586392992]
#   J  = [3.9773819852752372 .. 5.0010000000000013]
# f(J) = [-13.593496524190198 .. 0.067790481397283387]
# Monitored signal 0.13099527359 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [([0.00000000000000000 .. 0.0010000000000000001], False)])
# sig(0) = False
# Computed 355 flowpipes in 0.121081113815 sec
# Prepared for plotting in 0.0966105461121 sec
# domain = [0.00000000000000000 .. 5.0010000000000013]
# roots = [[0.00000000000000000 .. 2.1813723871869728],
#  [4.4177161961481008 .. 5.0019999999990006]]
#   J  = [2.1813723871869727 .. 4.4177161961481009]
# f(J) = [-12.695836880478816 .. 0.024762502820049548]
# 0 at 5.00100000000001
# Monitored signal 0.122986316681 sec
# sig    = Signal([0.00000000000000000 .. 0.0010000000000000001], [([0.00000000000000000 .. 0.0010000000000000001], False)])
# sig(0) = False
# Monitored signal 4.15010619164 sec

# %%
sig.plot()
# Out:
# Graphics object consisting of 2 graphics primitives
