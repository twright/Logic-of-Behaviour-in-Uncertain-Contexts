# %% [markdown]
# # Tests

# %% [markdown]
# ## Example 1: Simple

# %%
from flowstar.reachability import Reach
from flowstar.poly import Poly
from ulbc import *

# %%
R.<x,y> = RIF[]

# %%
odes = [
    -y,
    x,
]
initials = [(4,5), (1,2)]
reach = Reach(odes, [(4,5), (1,2)], 2*pi, 0.1, order=10)

# %%
def plot_signal(sig):
    return sig.to_domain(RIF(0,2*pi)).plot().show(
        ticks=[pi/2, 1], tick_formatter=pi, aspect_ratio=2/3)

# %%
reach.res
# Out:
# 2

# %%
P = Atomic(x - 3); P
# Out:
# Atomic(x - 3)

# %%
P.signal(reach, odes).plot() + P.sage_plot(reach)
# Out:
# domain = [0.00000000000000000 .. 6.2821853071795868]
# roots = [[0.36442391108285443 .. 0.75322999900880539],
#  [4.9094498886890116 .. 5.3000000000000105]]
#   J  = [0.00000000000000000 .. 0.36442391108285444]
# f(J) = [0.0027202813179409979 .. 2.0000000000000009]
#   J  = [0.75322999900880538 .. 4.9094498886890117]
# f(J) = [-8.4984031964855867 .. -0.00016697542414467747]
#   J  = [5.3000000000000104 .. 6.2821853071795868]
# f(J) = [-0.0039940204023398707 .. 2.5005510818925254]
# Graphics object consisting of 4 graphics primitives

# %%
plot_signal( P.signal_for_system(odes, initials, 2*pi) )
# Out:
# Computed 63 flowpipes in 0.0415208339691 sec
# Prepared for plotting in 0.0336079597473 sec
# domain = [0.00000000000000000 .. 6.2831853071795872]
# roots = [[0.36442391108285443 .. 0.75322999900880539],
#  [4.9094498886890116 .. 5.3000000000000105]]
#   J  = [0.00000000000000000 .. 0.36442391108285444]
# f(J) = [0.0027202813179409979 .. 2.0000000000000009]
#   J  = [0.75322999900880538 .. 4.9094498886890117]
# f(J) = [-8.4984031964855867 .. -0.00016697542414467747]
#   J  = [5.3000000000000104 .. 6.2831853071795872]
# f(J) = [-0.0039940204023398707 .. 2.5005510818925254]
# Monitored signal 0.0410480499268 sec
# Graphics object consisting of 2 graphics primitives

# %%
Q = Atomic(3 - y); Q
# Out:
# Atomic(-y + 3)

# %%
Q.signal(reach, odes).plot() + Q.sage_plot(reach)
# Out:
# domain = [0.00000000000000000 .. 6.2821853071795868]
# roots = [[0.20000000000000001 .. 0.58848494710426814],
#  [1.9311141906428948 .. 2.3182023568246275]]
#   J  = [0.00000000000000000 .. 0.20000000000000002]
# f(J) = [0.023305845235470190 .. 2.0000000000000005]
#   J  = [0.58848494710426813 .. 1.9311141906428949]
# f(J) = [-2.5009063678660049 .. -0.0021143037956745658]
#   J  = [2.3182023568246274 .. 6.2821853071795868]
# f(J) = [0.000081063638504463852 .. 8.4963733382557046]
# Graphics object consisting of 4 graphics primitives

# %%
plot_signal( Q.signal_for_system(odes, initials, 2*pi) )
# Out:
# Computed 63 flowpipes in 0.0443739891052 sec
# Prepared for plotting in 0.0390975475311 sec
# domain = [0.00000000000000000 .. 6.2831853071795872]
# roots = [[0.20000000000000001 .. 0.58848494710426814],
#  [1.9311141906428948 .. 2.3182023568246275]]
#   J  = [0.00000000000000000 .. 0.20000000000000002]
# f(J) = [0.023305845235470190 .. 2.0000000000000005]
#   J  = [0.58848494710426813 .. 1.9311141906428949]
# f(J) = [-2.5009063678660049 .. -0.0021143037956745658]
#   J  = [2.3182023568246274 .. 6.2831853071795872]
# f(J) = [0.000081063638504463852 .. 8.4963733382557046]
# Monitored signal 0.0429284572601 sec
# Graphics object consisting of 2 graphics primitives

# %%
plot_signal( G(RIF(1,1.2), P).signal_for_system(odes, initials, 2*pi) )
# Out:
# Computed 75 flowpipes in 0.0519499778748 sec
# Prepared for plotting in 0.0449056625366 sec
# domain = [0.00000000000000000 .. 7.4831853071795873]
# roots = [[0.36442391108285443 .. 0.75322999900880539],
#  [4.9094498886890116 .. 5.3000000000000105],
#  [6.6497432568189269 .. 7.0331814940841380]]
#   J  = [0.00000000000000000 .. 0.36442391108285444]
# f(J) = [0.0027202813179409979 .. 2.0000000000000009]
#   J  = [0.75322999900880538 .. 4.9094498886890117]
# f(J) = [-8.4984031964855867 .. -0.00016697542414467747]
#   J  = [5.3000000000000104 .. 6.6497432568189270]
# f(J) = [-0.0039940204023398707 .. 2.5005510818925254]
#   J  = [7.0331814940841379 .. 7.4831853071795873]
# f(J) = [-3.4944620224989702 .. -0.00053751205010632574]
# Monitored signal 0.0536193847656 sec
# Graphics object consisting of 2 graphics primitives

# %%
plot_signal( F(RIF(3.5, 4), Q).signal_for_system(odes, initials, 2*pi) )
# Out:
# Computed 103 flowpipes in 0.0669720172882 sec
# Prepared for plotting in 0.0528869628906 sec
# domain = [0.00000000000000000 .. 10.283185307179589]
# roots = [[0.20000000000000001 .. 0.58848494710426814],
#  [1.9311141906428948 .. 2.3182023568246275],
#  [6.4892456363200734 .. 6.8667576512155782],
#  [8.2066212216718827 .. 8.6000000000000334]]
#   J  = [0.00000000000000000 .. 0.20000000000000002]
# f(J) = [0.023305845235470190 .. 2.0000000000000005]
#   J  = [0.58848494710426813 .. 1.9311141906428949]
# f(J) = [-2.5009063678660049 .. -0.0021143037956745658]
#   J  = [2.3182023568246274 .. 6.4892456363200735]
# f(J) = [-0.0019014547054210241 .. 8.4963733382557046]
#   J  = [6.8667576512155781 .. 8.2066212216718828]
# f(J) = [-2.5000379898895063 .. 0.0024387538136543264]
#   J  = [8.6000000000000333 .. 10.283185307179589]
# f(J) = [-0.060602264719935129 .. 8.1667675079350258]
# Monitored signal 0.0697672367096 sec
# Graphics object consisting of 2 graphics primitives

# %%
plot_signal( (G(RIF(1,1.2), P) | F(RIF(3.5,4), Q)).signal_for_system(odes, initials, 2*pi) )
# Out:
# Computed 103 flowpipes in 0.0620090961456 sec
# Prepared for plotting in 0.0537226200104 sec
# domain = [0.00000000000000000 .. 10.283185307179589]
# roots = [[0.36442391108285443 .. 0.75322999900880539],
#  [4.9094498886890116 .. 5.3000000000000105],
#  [6.6497432568189269 .. 7.0331814940841380]]
#   J  = [0.00000000000000000 .. 0.36442391108285444]
# f(J) = [0.0027202813179409979 .. 2.0000000000000009]
#   J  = [0.75322999900880538 .. 4.9094498886890117]
# f(J) = [-8.4984031964855867 .. -0.00016697542414467747]
#   J  = [5.3000000000000104 .. 6.6497432568189270]
# f(J) = [-0.0039940204023398707 .. 2.5005510818925254]
#   J  = [7.0331814940841379 .. 10.283185307179589]
# f(J) = [-8.4948345026507575 .. -0.00053751205010632574]
# domain = [0.00000000000000000 .. 10.283185307179589]
# roots = [[0.20000000000000001 .. 0.58848494710426814],
#  [1.9311141906428948 .. 2.3182023568246275],
#  [6.4892456363200734 .. 6.8667576512155782],
#  [8.2066212216718827 .. 8.6000000000000334]]
#   J  = [0.00000000000000000 .. 0.20000000000000002]
# f(J) = [0.023305845235470190 .. 2.0000000000000005]
#   J  = [0.58848494710426813 .. 1.9311141906428949]
# f(J) = [-2.5009063678660049 .. -0.0021143037956745658]
#   J  = [2.3182023568246274 .. 6.4892456363200735]
# f(J) = [-0.0019014547054210241 .. 8.4963733382557046]
#   J  = [6.8667576512155781 .. 8.2066212216718828]
# f(J) = [-2.5000379898895063 .. 0.0024387538136543264]
#   J  = [8.6000000000000333 .. 10.283185307179589]
# f(J) = [-0.060602264719935129 .. 8.1667675079350258]
# Monitored signal 0.134221315384 sec
# Graphics object consisting of 2 graphics primitives

# %%
(G(RIF(1,1.2), P) & F(RIF(3.5,4), Q)).signal_for_system(odes, initials, 2*pi).plot()
# Out:
# Computed 103 flowpipes in 0.0619490146637 sec
# Prepared for plotting in 0.0547337532043 sec
# domain = [0.00000000000000000 .. 10.283185307179589]
# roots = [[0.36442391108285443 .. 0.75322999900880539],
#  [4.9094498886890116 .. 5.3000000000000105],
#  [6.6497432568189269 .. 7.0331814940841380]]
#   J  = [0.00000000000000000 .. 0.36442391108285444]
# f(J) = [0.0027202813179409979 .. 2.0000000000000009]
#   J  = [0.75322999900880538 .. 4.9094498886890117]
# f(J) = [-8.4984031964855867 .. -0.00016697542414467747]
#   J  = [5.3000000000000104 .. 6.6497432568189270]
# f(J) = [-0.0039940204023398707 .. 2.5005510818925254]
#   J  = [7.0331814940841379 .. 10.283185307179589]
# f(J) = [-8.4948345026507575 .. -0.00053751205010632574]
# domain = [0.00000000000000000 .. 10.283185307179589]
# roots = [[0.20000000000000001 .. 0.58848494710426814],
#  [1.9311141906428948 .. 2.3182023568246275],
#  [6.4892456363200734 .. 6.8667576512155782],
#  [8.2066212216718827 .. 8.6000000000000334]]
#   J  = [0.00000000000000000 .. 0.20000000000000002]
# f(J) = [0.023305845235470190 .. 2.0000000000000005]
#   J  = [0.58848494710426813 .. 1.9311141906428949]
# f(J) = [-2.5009063678660049 .. -0.0021143037956745658]
#   J  = [2.3182023568246274 .. 6.4892456363200735]
# f(J) = [-0.0019014547054210241 .. 8.4963733382557046]
#   J  = [6.8667576512155781 .. 8.2066212216718828]
# f(J) = [-2.5000379898895063 .. 0.0024387538136543264]
#   J  = [8.6000000000000333 .. 10.283185307179589]
# f(J) = [-0.060602264719935129 .. 8.1667675079350258]
# Monitored signal 0.135567188263 sec
# Graphics object consisting of 2 graphics primitives

# %%
sig = U(G(RIF(1, 1.2), P), RIF(0.4, 0.5), F(RIF(3.5, 4), Q)).signal_for_system(
    odes, [RIF(4, 5), RIF(1, 2)], 2*pi)
plot_signal( sig )
# Out:
# Computed 120 flowpipes in 0.0484628677368 sec
# Prepared for plotting in 0.0298058986664 sec
# domain = [0.00000000000000000 .. 11.983185307179588]
# roots = [[0.36442391108285443 .. 0.75322999900880539],
#  [4.9094498886890116 .. 5.3000000000000105],
#  [6.6497432568189269 .. 7.0331814940841380],
#  [11.200000000000070 .. 11.582737468232921]]
#   J  = [0.00000000000000000 .. 0.36442391108285444]
# f(J) = [0.0027202813179409979 .. 2.0000000000000009]
#   J  = [0.75322999900880538 .. 4.9094498886890117]
# f(J) = [-8.4984031964855867 .. -0.00016697542414467747]
#   J  = [5.3000000000000104 .. 6.6497432568189270]
# f(J) = [-0.0039940204023398707 .. 2.5005510818925254]
#   J  = [7.0331814940841379 .. 11.200000000000071]
# f(J) = [-8.4948345026507575 .. -0.00053751205010632574]
#   J  = [11.582737468232920 .. 11.983185307179588]
# f(J) = [0.00065815528209167695 .. 2.3583359199431007]
# domain = [0.00000000000000000 .. 11.983185307179588]
# roots = [[0.20000000000000001 .. 0.58848494710426814],
#  [1.9311141906428948 .. 2.3182023568246275],
#  [6.4892456363200734 .. 6.8667576512155782],
#  [8.2066212216718827 .. 8.6000000000000334]]
#   J  = [0.00000000000000000 .. 0.20000000000000002]
# f(J) = [0.023305845235470190 .. 2.0000000000000005]
#   J  = [0.58848494710426813 .. 1.9311141906428949]
# f(J) = [-2.5009063678660049 .. -0.0021143037956745658]
#   J  = [2.3182023568246274 .. 6.4892456363200735]
# f(J) = [-0.0019014547054210241 .. 8.4963733382557046]
#   J  = [6.8667576512155781 .. 8.2066212216718828]
# f(J) = [-2.5000379898895063 .. 0.0024387538136543264]
#   J  = [8.6000000000000333 .. 11.983185307179588]
# f(J) = [-0.060602264719935129 .. 8.4993515684232808]
# Monitored signal 0.072270154953 sec
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# ## Context!

# %%
{y: RIF(9,10)} >> P
# Out:
# C({y: [9 .. 10]}, Atomic(x - 3))

# %%
sig = ({y: RIF(9,10)} >> P).signal_for_system(odes, initials, 4*pi)
# Out:
# Computed 126 flowpipes in 0.0372819900513 sec
# Prepared for plotting in 0.0330927371979 sec
# Computed 1 flowpipes in 0.000730037689209 sec
# Prepared for plotting in 0.000264167785645 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.10000000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00191402435303 sec
# Computed 1 flowpipes in 0.00065803527832 sec
# Prepared for plotting in 0.000245571136475 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.10000000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00223636627197 sec
# Computed 1 flowpipes in 0.000834941864014 sec
# Prepared for plotting in 0.000266075134277 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.10000000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00134301185608 sec
# Computed 1 flowpipes in 0.000631093978882 sec
# Prepared for plotting in 0.000257730484009 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.10000000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00242829322815 sec
# Computed 1 flowpipes in 0.000658988952637 sec
# Prepared for plotting in 0.000347852706909 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.10000000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00148510932922 sec
# Computed 1 flowpipes in 0.00065016746521 sec
# Prepared for plotting in 0.000243663787842 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.10000000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00188016891479 sec
# Computed 1 flowpipes in 0.000685930252075 sec
# Prepared for plotting in 0.000543117523193 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.10000000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00132298469543 sec
# Computed 1 flowpipes in 0.000653982162476 sec
# Prepared for plotting in 0.000243902206421 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = []
#   J  = [0.00000000000000000 .. 0.0010000000000000001]
# f(J) = [-5.0912954091700149 .. -0.11147099143372507]
# Monitored signal 0.00163817405701 sec
# Computed 1 flowpipes in 0.000629901885986 sec
# Prepared for plotting in 0.000255107879639 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = []
#   J  = [0.00000000000000000 .. 0.0010000000000000001]
# f(J) = [-8.5134764279164000 .. -3.9251246305378875]
# Monitored signal 0.0018789768219 sec
# Computed 1 flowpipes in 0.000635147094727 sec
# Prepared for plotting in 0.000244617462158 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.10000000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00124621391296 sec
# Computed 1 flowpipes in 0.00062108039856 sec
# Prepared for plotting in 0.000239849090576 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = []
#   J  = [0.00000000000000000 .. 0.0010000000000000001]
# f(J) = [-8.0512970239620714 .. -0.94195209316183392]
# Monitored signal 0.00144195556641 sec
# Computed 1 flowpipes in 0.000622987747192 sec
# Prepared for plotting in 0.00040078163147 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.10000000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00124025344849 sec
# Computed 1 flowpipes in 0.000626087188721 sec
# Prepared for plotting in 0.000247955322266 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.10000000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00121784210205 sec
# Computed 1 flowpipes in 0.000632047653198 sec
# Prepared for plotting in 0.00033974647522 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.10000000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00122213363647 sec
# Computed 1 flowpipes in 0.000619888305664 sec
# Prepared for plotting in 0.000241041183472 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.10000000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00118613243103 sec
# Computed 1 flowpipes in 0.000611066818237 sec
# Prepared for plotting in 0.000239610671997 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.026319357625073244 .. 0.10000000000000001]]
#   J  = [0.00000000000000000 .. 0.026319357625073245]
# f(J) = [0.14662921300538922 .. 2.5005510818785562]
#   J  = [0.0010000000000000000 .. 0.0010000000000000001]
# f(J) = [0.45468347615735993 .. 2.4944451893418345]
# Monitored signal 0.00189733505249 sec
# Computed 1 flowpipes in 0.000646114349365 sec
# Prepared for plotting in 0.000245094299316 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.10000000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00139594078064 sec
# Computed 1 flowpipes in 0.000620126724243 sec
# Prepared for plotting in 0.000234603881836 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.10000000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00119137763977 sec
# Computed 1 flowpipes in 0.00062084197998 sec
# Prepared for plotting in 0.000241041183472 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.10000000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00135707855225 sec
# Computed 1 flowpipes in 0.000641107559204 sec
# Prepared for plotting in 0.000241756439209 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.10000000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00123333930969 sec
# Computed 1 flowpipes in 0.000618934631348 sec
# Prepared for plotting in 0.000336885452271 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.10000000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00120902061462 sec
# Computed 1 flowpipes in 0.000615119934082 sec
# Prepared for plotting in 0.00024676322937 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.10000000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.0017352104187 sec
# Computed 1 flowpipes in 0.000629901885986 sec
# Prepared for plotting in 0.000241041183472 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = []
#   J  = [0.00000000000000000 .. 0.0010000000000000001]
# f(J) = [-5.0752945886793662 .. -0.12499641279639828]
# Monitored signal 0.00185799598694 sec
# Computed 1 flowpipes in 0.000635147094727 sec
# Prepared for plotting in 0.000251770019531 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = []
#   J  = [0.00000000000000000 .. 0.0010000000000000001]
# f(J) = [-8.5098893938380212 .. -3.9444942304402164]
# Monitored signal 0.00154113769531 sec
# Computed 1 flowpipes in 0.000633239746094 sec
# Prepared for plotting in 0.000539779663086 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.10000000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00130105018616 sec
# Computed 1 flowpipes in 0.000642061233521 sec
# Prepared for plotting in 0.000240802764893 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = []
#   J  = [0.00000000000000000 .. 0.0010000000000000001]
# f(J) = [-8.0333944231910924 .. -0.89238918679380008]
# Monitored signal 0.00159621238708 sec
# Computed 1 flowpipes in 0.000620126724243 sec
# Prepared for plotting in 0.000334024429321 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.10000000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00223898887634 sec
# Computed 1 flowpipes in 0.000723838806152 sec
# Prepared for plotting in 0.00024676322937 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.10000000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00268530845642 sec
# Computed 1 flowpipes in 0.00114512443542 sec
# Prepared for plotting in 0.000241994857788 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.10000000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00120496749878 sec
# Computed 1 flowpipes in 0.00061821937561 sec
# Prepared for plotting in 0.000239610671997 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.00000000000000000 .. 0.10000000000000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.00118923187256 sec
# Computed 1 flowpipes in 0.00061821937561 sec
# Prepared for plotting in 0.000242948532104 sec
# domain = [0.00000000000000000 .. 0.0010000000000000001]
# roots = [[0.028013549913825468 .. 0.10000000000000001]]
#   J  = [0.00000000000000000 .. 0.028013549913825469]
# f(J) = [0.13557901732241894 .. 2.5008287085301673]
#   J  = [0.0010000000000000000 .. 0.0010000000000000001]
# f(J) = [0.46393293442982663 .. 2.4947093632009354]
# Monitored signal 0.00270509719849 sec
# Monitored signal 0.157066345215 sec

# %%
sig.plot()
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
sig = ({y: RIF(9,10)} >> G(RIF(0, 5), P)).signal_for_system(odes, initials, 4*pi)
# Out:
# Computed 126 flowpipes in 0.0402429103851 sec
# Prepared for plotting in 0.0333120822906 sec
# Computed 51 flowpipes in 0.0156760215759 sec
# Prepared for plotting in 0.0137238502502 sec
# domain = [0.00000000000000000 .. 5.0010000000000013]
# roots = [[0.00000000000000000 .. 0.60000000000000020],
#  [2.4822037957511446 .. 4.7000000000000056],
#  [4.7698759271146302 .. 5.0019999999989989]]
#   J  = [0.60000000000000019 .. 2.4822037957511447]
# f(J) = [-20.514225737624880 .. 0.16953181737762302]
#   J  = [4.7000000000000055 .. 4.7698759271146303]
# f(J) = [-0.72676785280702250 .. 13.726834376519769]
# 0 at 5.00100000000001
# Monitored signal 0.0200049877167 sec
# Monitored signal 0.0653219223022 sec

# %%
sig.plot()
# Out:
# /usr/lib64/python2.7/site-packages/matplotlib/contour.py:1230: UserWarning: No contour levels were found within the data range.
#   warnings.warn("No contour levels were found"
# Graphics object consisting of 2 graphics primitives

# %%
sig = ({y: RIF(9,10)} >> G(RIF(0, pi/2), Atomic(y))).signal_for_system(odes, initials, 4*pi)
# Out:
# Computed 126 flowpipes in 0.0400779247284 sec
# Prepared for plotting in 0.0320680141449 sec
# Computed 16 flowpipes in 0.00469589233398 sec
# Prepared for plotting in 0.0039598941803 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = [[0.48976875451554086 .. 1.5727963267938972]]
#   J  = [0.00000000000000000 .. 0.48976875451554087]
# f(J) = [0.020031670462663842 .. 16.856250511787764]
# 0 at 1.57179632679490
# Monitored signal 0.00718402862549 sec
# Computed 16 flowpipes in 0.00462102890015 sec
# Prepared for plotting in 0.00380802154541 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = [[0.48998378304675066 .. 1.5727963267938972]]
#   J  = [0.00000000000000000 .. 0.48998378304675067]
# f(J) = [0.020067908071636941 .. 16.856053928589006]
# 0 at 1.57179632679490
# Monitored signal 0.00986886024475 sec
# Computed 16 flowpipes in 0.00481390953064 sec
# Prepared for plotting in 0.00447416305542 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = [[0.85830949637416265 .. 1.5727963267938967]]
#   J  = [0.00000000000000000 .. 0.85830949637416266]
# f(J) = [0.0054489278887244587 .. 16.558300474072479]
# 0 at 1.57179632679490
# Monitored signal 0.00745701789856 sec
# Computed 16 flowpipes in 0.00462293624878 sec
# Prepared for plotting in 0.00462698936462 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = [[1.3366343237330746 .. 1.5727963267938963]]
#   J  = [0.00000000000000000 .. 1.3366343237330747]
# f(J) = [0.10131233640116685 .. 16.476630869492841]
# 0 at 1.57179632679490
# Monitored signal 0.00753498077393 sec
# Computed 16 flowpipes in 0.00464987754822 sec
# Prepared for plotting in 0.00448107719421 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = []
#   J  = [0.00000000000000000 .. 1.5717963267948972]
# f(J) = [0.97271708457101013 .. 16.011326963574103]
# Monitored signal 0.0080509185791 sec
# Computed 16 flowpipes in 0.00458192825317 sec
# Prepared for plotting in 0.0047881603241 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = [[1.3841807072496639 .. 1.5727963267938963]]
#   J  = [0.00000000000000000 .. 1.3841807072496640]
# f(J) = [0.0075605104019628409 .. 15.874732577291983]
# 0 at 1.57179632679490
# Monitored signal 0.00786995887756 sec
# Computed 16 flowpipes in 0.00466895103455 sec
# Prepared for plotting in 0.00393605232239 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = [[1.5303714965960373 .. 1.5727963267938961]]
#   J  = [0.00000000000000000 .. 1.5303714965960374]
# f(J) = [0.020177306343115330 .. 15.847924401319852]
# 0 at 1.57179632679490
# Monitored signal 0.00724482536316 sec
# Computed 16 flowpipes in 0.00456213951111 sec
# Prepared for plotting in 0.00407886505127 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = [[1.3923712010375639 .. 1.5727963267938963]]
#   J  = [0.00000000000000000 .. 1.3923712010375640]
# f(J) = [0.0060541017422183840 .. 15.591524203832775]
# 0 at 1.57179632679490
# Monitored signal 0.00746297836304 sec
# Computed 16 flowpipes in 0.00462007522583 sec
# Prepared for plotting in 0.00401496887207 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = [[0.86006538426181045 .. 1.5206754703497965]]
#   J  = [0.00000000000000000 .. 0.86006538426181046]
# f(J) = [0.0043352245123613646 .. 15.073231431533529]
#   J  = [1.5206754703497964 .. 1.5717963267948972]
# f(J) = [-6.1002773969576989 .. 0.0026087793972485851]
# Monitored signal 0.00746297836304 sec
# Computed 16 flowpipes in 0.00481200218201 sec
# Prepared for plotting in 0.00409078598022 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = [[0.56120942771677695 .. 1.5727963267938970]]
#   J  = [0.00000000000000000 .. 0.56120942771677696]
# f(J) = [0.0067145908141855352 .. 13.649325196987784]
# 0 at 1.57179632679490
# Monitored signal 0.00780200958252 sec
# Computed 16 flowpipes in 0.00564885139465 sec
# Prepared for plotting in 0.00466394424438 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = [[0.57155966864161911 .. 1.5727963267938972]]
#   J  = [0.00000000000000000 .. 0.57155966864161912]
# f(J) = [0.0075538905911017714 .. 9.4046781511437417]
# 0 at 1.57179632679490
# Monitored signal 0.00740313529968 sec
# Computed 16 flowpipes in 0.00589203834534 sec
# Prepared for plotting in 0.00919413566589 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = [[0.65028086630057213 .. 1.4400585080580753]]
#   J  = [0.00000000000000000 .. 0.65028086630057214]
# f(J) = [0.000022107821301376500 .. 9.0439887153219410]
#   J  = [1.4400585080580752 .. 1.5717963267948972]
# f(J) = [-5.4182473937643785 .. 0.0047671654116308131]
# Monitored signal 0.00983786582947 sec
# Computed 16 flowpipes in 0.00538992881775 sec
# Prepared for plotting in 0.00479102134705 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = [[0.85825406577082141 .. 1.5727963267938970]]
#   J  = [0.00000000000000000 .. 0.85825406577082142]
# f(J) = [0.0022479855610596961 .. 6.8997249066293680]
# 0 at 1.57179632679490
# Monitored signal 0.00779414176941 sec
# Computed 16 flowpipes in 0.00550198554993 sec
# Prepared for plotting in 0.00474214553833 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = [[0.85861773535208141 .. 1.5727963267938970]]
#   J  = [0.00000000000000000 .. 0.85861773535208142]
# f(J) = [0.0018275718600112523 .. 6.5218059307962167]
# 0 at 1.57179632679490
# Monitored signal 0.00829601287842 sec
# Computed 16 flowpipes in 0.00501203536987 sec
# Prepared for plotting in 0.0046660900116 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = [[1.2542205278905262 .. 1.5727963267938965]]
#   J  = [0.00000000000000000 .. 1.2542205278905263]
# f(J) = [0.00078120136220350777 .. 6.5217888306901700]
# 0 at 1.57179632679490
# Monitored signal 0.00815796852112 sec
# Computed 16 flowpipes in 0.00501799583435 sec
# Prepared for plotting in 0.00476002693176 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = []
#   J  = [0.00000000000000000 .. 1.5717963267948972]
# f(J) = [0.39016925797285667 .. 13.630466707704749]
# Monitored signal 0.00797200202942 sec
# Computed 16 flowpipes in 0.00517201423645 sec
# Prepared for plotting in 0.00442099571228 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = [[0.48990352439865730 .. 1.5727963267938972]]
#   J  = [0.00000000000000000 .. 0.48990352439865731]
# f(J) = [0.020053683583125741 .. 16.855420918687753]
# 0 at 1.57179632679490
# Monitored signal 0.0104310512543 sec
# Computed 16 flowpipes in 0.00871896743774 sec
# Prepared for plotting in 0.00798201560974 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = [[0.85911959675694815 .. 1.5727963267938970]]
#   J  = [0.00000000000000000 .. 0.85911959675694816]
# f(J) = [0.0059564841980799297 .. 16.590735122701617]
# 0 at 1.57179632679490
# Monitored signal 0.0135278701782 sec
# Computed 16 flowpipes in 0.00569295883179 sec
# Prepared for plotting in 0.00492095947266 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = [[1.3355495901813601 .. 1.5727963267938965]]
#   J  = [0.00000000000000000 .. 1.3355495901813602]
# f(J) = [0.10150723009208564 .. 16.503760069871206]
# 0 at 1.57179632679490
# Monitored signal 0.00957107543945 sec
# Computed 16 flowpipes in 0.00659489631653 sec
# Prepared for plotting in 0.00610399246216 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = []
#   J  = [0.00000000000000000 .. 1.5717963267948972]
# f(J) = [0.97696097801239767 .. 16.033656230123349]
# Monitored signal 0.0128209590912 sec
# Computed 16 flowpipes in 0.00536513328552 sec
# Prepared for plotting in 0.00488686561584 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = [[1.3853340015714352 .. 1.5727963267938963]]
#   J  = [0.00000000000000000 .. 1.3853340015714353]
# f(J) = [0.0076668892914020184 .. 15.871069905876603]
# 0 at 1.57179632679490
# Monitored signal 0.00904011726379 sec
# Computed 16 flowpipes in 0.00581097602844 sec
# Prepared for plotting in 0.00489687919617 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = [[1.5315216586037809 .. 1.5727963267938963]]
#   J  = [0.00000000000000000 .. 1.5315216586037810]
# f(J) = [0.016293127180467076 .. 15.853453601886587]
# 0 at 1.57179632679490
# Monitored signal 0.009526014328 sec
# Computed 16 flowpipes in 0.0055410861969 sec
# Prepared for plotting in 0.00492691993713 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = [[1.3936347326705018 .. 1.4000000000000004],
#  [1.4008752724524660 .. 1.5727963267938965]]
#   J  = [0.00000000000000000 .. 1.3936347326705019]
# f(J) = [0.0060787889987874857 .. 15.592092700100340]
#   J  = [1.4000000000000003 .. 1.4008752724524661]
# f(J) = [-0.093555372737995593 .. 3.9259817879470643]
# 0 at 1.57179632679490
# Monitored signal 0.00880694389343 sec
# Computed 16 flowpipes in 0.00536298751831 sec
# Prepared for plotting in 0.0045440196991 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = [[0.86097681800207204 .. 1.5176355699639026]]
#   J  = [0.00000000000000000 .. 0.86097681800207205]
# f(J) = [0.0046756730623630209 .. 15.054891424892797]
#   J  = [1.5176355699639025 .. 1.5717963267948972]
# f(J) = [-6.0942677570642854 .. 0.0023986726789822538]
# Monitored signal 0.0079619884491 sec
# Computed 16 flowpipes in 0.00485396385193 sec
# Prepared for plotting in 0.00427389144897 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = [[0.56185347388508954 .. 1.5727963267938972]]
#   J  = [0.00000000000000000 .. 0.56185347388508955]
# f(J) = [0.0070418101940845001 .. 13.634601971766785]
# 0 at 1.57179632679490
# Monitored signal 0.00698399543762 sec
# Computed 16 flowpipes in 0.00481390953064 sec
# Prepared for plotting in 0.00414609909058 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = [[0.57236318503338257 .. 1.5727963267938970]]
#   J  = [0.00000000000000000 .. 0.57236318503338258]
# f(J) = [0.0077637822136425727 .. 9.3999601379974394]
# 0 at 1.57179632679490
# Monitored signal 0.00673484802246 sec
# Computed 16 flowpipes in 0.00505590438843 sec
# Prepared for plotting in 0.00482296943665 sec
# domain = [0.00000000000000000 .. 1.5717963267948972]
# roots = [[0.64476197815693914 .. 1.4412188192997105]]
#   J  = [0.00000000000000000 .. 0.64476197815693915]
# f(J) = [0.032219992648777534 .. 9.02411
# <b>limit_output extension: Maximum message size of 10000 exceeded with 11576 characters</b>

# %%
sig.plot()
# Out:
# Graphics object consisting of 2 graphics primitives
