# %% [markdown]
# # Tests

# %% [markdown]
# ## Example 1: Simple

# %%
from flowstar.reachability import Reach
from flowstar.poly import Poly
from ulbc import *

# %%
R.<x,y> = RIF[]

# %%
odes = [
    -y,
    x,
]
initials = [(4,5), (1,2)]
reach = Reach(odes, [(4,5), (1,2)], 2*pi, 0.1, order=10)

# %%
def plot_signal(sig):
    return sig.to_domain(RIF(0,2*pi)).plot().show(
        ticks=[pi/2, 1], tick_formatter=pi, aspect_ratio=2/3)

# %%
reach.res
# Out:
# 2

# %%
P = Atomic(x - 3); P
# Out:
# Atomic(x - 3)

# %%
P.signal(reach, odes).plot() + P.sage_plot(reach)
# Out:
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# roots = [1.?, 5.?]
#   J  = [0.00000000000000000 .. 0.36442391108285444]
# f(J) = [0.0027202813179409979 .. 2.0000000000000009]
#   J  = [0.75322999900880505 .. 4.9094498886890019]
# f(J) = [-8.4984031964855867 .. -0.00016697542414378929]
# Graphics object consisting of 4 graphics primitives

# %%
plot_signal( P.signal_for_system(odes, initials, 2*pi) )
# Out:
# Computed 63 flowpipes in 0.087690114975 sec
# Prepared for plotting in 0.0679769515991 sec
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# roots = [1.?, 5.?]
#   J  = [0.00000000000000000 .. 0.36442391108285444]
# f(J) = [0.0027202813179409979 .. 2.0000000000000009]
#   J  = [0.75322999900880505 .. 4.9094498886890019]
# f(J) = [-8.4984031964855867 .. -0.00016697542414378929]
# Monitored signal 0.09428191185 sec
# Graphics object consisting of 2 graphics primitives

# %%
Q = Atomic(3 - y); Q
# Out:
# Atomic(-y + 3)

# %%
Q.signal(reach, odes).plot() + Q.sage_plot(reach)
# Out:
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# roots = [1.?, 2.?]
#   J  = [0.00000000000000000 .. 0.20000000000000002]
# f(J) = [0.023305845235470190 .. 2.0000000000000005]
#   J  = [0.58848494710426801 .. 1.9311141906428940]
# f(J) = [-2.5009063678660049 .. -0.0021143037956741217]
# Graphics object consisting of 4 graphics primitives

# %%
plot_signal( Q.signal_for_system(odes, initials, 2*pi) )
# Out:
# Computed 63 flowpipes in 0.0911619663239 sec
# Prepared for plotting in 0.0625450611115 sec
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# roots = [1.?, 2.?]
#   J  = [0.00000000000000000 .. 0.20000000000000002]
# f(J) = [0.023305845235470190 .. 2.0000000000000005]
#   J  = [0.58848494710426801 .. 1.9311141906428940]
# f(J) = [-2.5009063678660049 .. -0.0021143037956741217]
# Monitored signal 0.0842819213867 sec
# Graphics object consisting of 2 graphics primitives

# %%
plot_signal( G(RIF(1,1.2), P).signal_for_system(odes, initials, 2*pi) )
# Out:
# Computed 75 flowpipes in 0.111961841583 sec
# Prepared for plotting in 0.0723659992218 sec
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# roots = [1.?, 5.?, 7.?]
#   J  = [0.00000000000000000 .. 0.36442391108285444]
# f(J) = [0.0027202813179409979 .. 2.0000000000000009]
#   J  = [0.75322999900880505 .. 4.9094498886890019]
# f(J) = [-8.4984031964855867 .. -0.00016697542414378929]
#   J  = [5.2999999999999980 .. 6.6497432568189022]
# f(J) = [-0.0039940204023696247 .. 2.5005510818925254]
# Monitored signal 0.120661020279 sec
# Graphics object consisting of 2 graphics primitives

# %%
plot_signal( F(RIF(3.5, 4), Q).signal_for_system(odes, initials, 2*pi) )
# Out:
# Computed 103 flowpipes in 0.158686876297 sec
# Prepared for plotting in 0.109612941742 sec
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# roots = [1.?, 2.?, 7.?, 9.?]
#   J  = [0.00000000000000000 .. 0.20000000000000002]
# f(J) = [0.023305845235470190 .. 2.0000000000000005]
#   J  = [0.58848494710426801 .. 1.9311141906428940]
# f(J) = [-2.5009063678660049 .. -0.0021143037956741217]
#   J  = [2.3182023568246261 .. 6.4892456363200504]
# f(J) = [-0.0019014547053091136 .. 8.4963733382557046]
#   J  = [6.8667576512155514 .. 8.2066212216718420]
# f(J) = [-2.5000379898895063 .. 0.0024387538137147225]
# Monitored signal 0.180349111557 sec
# Graphics object consisting of 2 graphics primitives

# %%
plot_signal( (G(RIF(1,1.2), P) | F(RIF(3.5,4), Q)).signal_for_system(odes, initials, 2*pi) )
# Out:
# Computed 103 flowpipes in 0.157037973404 sec
# Prepared for plotting in 0.103422880173 sec
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# roots = [1.?, 5.?, 7.?]
#   J  = [0.00000000000000000 .. 0.36442391108285444]
# f(J) = [0.0027202813179409979 .. 2.0000000000000009]
#   J  = [0.75322999900880505 .. 4.9094498886890019]
# f(J) = [-8.4984031964855867 .. -0.00016697542414378929]
#   J  = [5.2999999999999980 .. 6.6497432568189022]
# f(J) = [-0.0039940204023696247 .. 2.5005510818925254]
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# roots = [1.?, 2.?, 7.?, 9.?]
#   J  = [0.00000000000000000 .. 0.20000000000000002]
# f(J) = [0.023305845235470190 .. 2.0000000000000005]
#   J  = [0.58848494710426801 .. 1.9311141906428940]
# f(J) = [-2.5009063678660049 .. -0.0021143037956741217]
#   J  = [2.3182023568246261 .. 6.4892456363200504]
# f(J) = [-0.0019014547053091136 .. 8.4963733382557046]
#   J  = [6.8667576512155514 .. 8.2066212216718420]
# f(J) = [-2.5000379898895063 .. 0.0024387538137147225]
# Monitored signal 0.33730506897 sec
# Graphics object consisting of 2 graphics primitives

# %%
(G(RIF(1,1.2), P) & F(RIF(3.5,4), Q)).signal_for_system(odes, initials, 2*pi).plot()
# Out:
# Computed 103 flowpipes in 0.15535902977 sec
# Prepared for plotting in 0.103441953659 sec
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# roots = [1.?, 5.?, 7.?]
#   J  = [0.00000000000000000 .. 0.36442391108285444]
# f(J) = [0.0027202813179409979 .. 2.0000000000000009]
#   J  = [0.75322999900880505 .. 4.9094498886890019]
# f(J) = [-8.4984031964855867 .. -0.00016697542414378929]
#   J  = [5.2999999999999980 .. 6.6497432568189022]
# f(J) = [-0.0039940204023696247 .. 2.5005510818925254]
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# roots = [1.?, 2.?, 7.?, 9.?]
#   J  = [0.00000000000000000 .. 0.20000000000000002]
# f(J) = [0.023305845235470190 .. 2.0000000000000005]
#   J  = [0.58848494710426801 .. 1.9311141906428940]
# f(J) = [-2.5009063678660049 .. -0.0021143037956741217]
#   J  = [2.3182023568246261 .. 6.4892456363200504]
# f(J) = [-0.0019014547053091136 .. 8.4963733382557046]
#   J  = [6.8667576512155514 .. 8.2066212216718420]
# f(J) = [-2.5000379898895063 .. 0.0024387538137147225]
# Monitored signal 0.335620880127 sec
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# ## Context!

# %%
{y: RIF(9,10)} >> P
# Out:
# C({y: [9 .. 10]}, Atomic(x - 3))

# %%
sig = ({y: RIF(9,10)} >> P).signal_for_system(odes, initials, 4*pi)
# Out:
# Computed 126 flowpipes in 0.179174184799 sec
# Prepared for plotting in 0.121936798096 sec
# Monitored signal 0.318464040756 sec

# %%
sig.plot()
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
sig = ({y: RIF(9,10)} >> G(RIF(0, 5), P)).signal_for_system(odes, initials, 4*pi)
# Out:
# Computed 126 flowpipes in 0.175508975983 sec
# Prepared for plotting in 0.121253013611 sec
# Computed 50 flowpipes in 0.0638070106506 sec
# Prepared for plotting in 0.0471580028534 sec
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# roots = [1.?, 1.?e1, 5.?]
#   J  = [0.60000000000000008 .. 2.4822037957995252]
# f(J) = [-20.514225737162644 .. 0.16953181235869197]
#   J  = [4.7000000000000001 .. 4.7698759272905545]
# f(J) = [-0.72676785106918685 .. 13.726834376009397]
# Monitored signal 0.065160036087 sec
# Monitored signal 0.24665594101 sec

# %%
sig.plot()
# Out:
# /usr/lib64/python2.7/site-packages/matplotlib/contour.py:1230: UserWarning: No contour levels were found within the data range.
#   warnings.warn("No contour levels were found"
# Graphics object consisting of 2 graphics primitives

# %%
sig = ({y: RIF(9,10)} >> G(RIF(0, pi/2), Atomic(y))).signal_for_system(odes, initials, 4*pi)
# Out:
# Computed 126 flowpipes in 0.188025951385 sec
# Prepared for plotting in 0.122131109238 sec
# Computed 16 flowpipes in 0.0211298465729 sec
# Prepared for plotting in 0.0156061649323 sec
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# roots = [1.?]
#   J  = [0.00000000000000000 .. 0.48976875460053882]
# f(J) = [0.020031670474434062 .. 16.856250509811777]
# Monitored signal 0.0243170261383 sec
# Computed 16 flowpipes in 0.0210990905762 sec
# Prepared for plotting in 0.0149490833282 sec
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# roots = [1.?]
#   J  = [0.00000000000000000 .. 0.48998378304691337]
# f(J) = [0.020067908071656651 .. 16.856053928583024]
# Monitored signal 0.0231490135193 sec
# Computed 16 flowpipes in 0.0214049816132 sec
# Prepared for plotting in 0.0155990123749 sec
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# roots = [1.?]
#   J  = [0.00000000000000000 .. 0.85836347342111097]
# f(J) = [0.0054812617998924581 .. 16.558262951597972]
# Monitored signal 0.0251309871674 sec
# Computed 16 flowpipes in 0.021152973175 sec
# Prepared for plotting in 0.0148808956146 sec
# root on boundary!
# root on boundary!
# root on boundary!
# roots = [2.?]
#   J  = [0.00000000000000000 .. 1.3367100074884682]
# f(J) = [0.10073906748271438 .. 16.476630869492909]
# Monitored signal 0.0275321006775 sec
# Computed 16 flowpipes in 0.0213558673859 sec
# Prepared for plotting in 0.0153501033783 sec
# roots = []
# Monitored signal 0.0174939632416 sec
# Computed 16 flowpipes in 0.0215139389038 sec
# Prepared for plotting in 0.0149490833282 sec
# roots = []
# Monitored signal 0.0178940296173 sec
# Computed 16 flowpipes in 0.0215110778809 sec
# Prepared for plotting in 0.0151009559631 sec
# roots = []
# Monitored signal 0.0177850723267 sec
# Computed 16 flowpipes in 0.0223748683929 sec
# Prepared for plotting in 0.0152521133423 sec
# root on boundary!
# root on boundary!
# root on boundary!
# roots = [2.?]
#   J  = [0.00000000000000000 .. 1.3842181303006811]
# f(J) = [0.0075648467910374734 .. 15.874776876725181]
# Monitored signal 0.0270359516144 sec
# Computed 16 flowpipes in 0.0211398601532 sec
# Prepared for plotting in 0.0150940418243 sec
# root on boundary!
# roots = [1.6?]
#   J  = [0.00000000000000000 .. 1.5306885515729452]
# f(J) = [0.015742089737844570 .. 15.847968700753038]
# Monitored signal 0.0268220901489 sec
# Computed 16 flowpipes in 0.0211458206177 sec
# Prepared for plotting in 0.0149371623993 sec
# root on boundary!
# root on boundary!
# root on boundary!
# roots = [2.?]
#   J  = [0.00000000000000000 .. 1.3924149276337324]
# f(J) = [0.0060562656582059098 .. 15.591580627584705]
# Monitored signal 0.0277209281921 sec
# Computed 16 flowpipes in 0.0215439796448 sec
# Prepared for plotting in 0.0150270462036 sec
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# roots = [1.?]
#   J  = [0.00000000000000000 .. 0.86012160848775266]
# f(J) = [0.0043574846088904268 .. 15.073347331644355]
# Monitored signal 0.0335910320282 sec
# Computed 16 flowpipes in 0.0233619213104 sec
# Prepared for plotting in 0.0161521434784 sec
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# roots = [2.?]
#   J  = [0.00000000000000000 .. 1.0887205304375667]
# f(J) = [0.0085464595483118743 .. 15.073347331644355]
# Monitored signal 0.0273389816284 sec
# Computed 16 flowpipes in 0.0212411880493 sec
# Prepared for plotting in 0.0150279998779 sec
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# roots = [2.?]
#   J  = [0.00000000000000000 .. 1.2504099891497964]
# f(J) = [-0.00014443229022685948 .. 15.073347331644355]
# Monitored signal 0.027489900589 sec
# Computed 16 flowpipes in 0.0215530395508 sec
# Prepared for plotting in 0.0163118839264 sec
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# roots = [1.10?, 2.?]
#   J  = [0.00000000000000000 .. 1.0932716811715404]
# f(J) = [0.0067401944753765442 .. 14.259931756135558]
#   J  = [1.1000000000000000 .. 1.1014840489844158]
# f(J) = [-0.094156511107767030 .. 4.6536479532963480]
# Monitored signal 0.0317180156708 sec
# Computed 16 flowpipes in 0.021586894989 sec
# Prepared for plotting in 0.0152790546417 sec
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# roots = [1.?]
#   J  = [0.00000000000000000 .. 0.86761927756340740]
# f(J) = [0.0045349515591556269 .. 12.868233527143984]
# Monitored signal 0.0267291069031 sec
# Computed 16 flowpipes in 0.0214810371399 sec
# Prepared for plotting in 0.0152950286865 sec
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# roots = [1.?]
#   J  = [0.00000000000000000 .. 0.97778197450666971]
# f(J) = [0.0050957916360228521 .. 12.868233527143984]
# Monitored signal 0.0281989574432 sec
# Computed 16 flowpipes in 0.0284450054169 sec
# Prepared for plotting in 0.0168778896332 sec
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# roots = [1.?]
#   J  = [0.00000000000000000 .. 0.87589908402786410]
# f(J) = [0.0045090535109886279 .. 11.035799416825768]
# Monitored signal 0.0264759063721 sec
# Computed 16 flowpipes in 0.0215399265289 sec
# Prepared for plotting in 0.0155820846558 sec
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# roots = [1.?]
#   J  = [0.00000000000000000 .. 0.56120539311750073]
# f(J) = [0.0067113536077139197 .. 13.646953976415926]
# Monitored signal 0.0235900878906 sec
# Computed 16 flowpipes in 0.0235061645508 sec
# Prepared for plotting in 0.0162270069122 sec
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# roots = [1.?]
#   J  = [0.00000000000000000 .. 0.57154242905130393]
# f(J) = [0.0075502389291437800 .. 9.4056430483473737]
# Monitored signal 0.0250239372253 sec
# Computed 16 flowpipes in 0.0237190723419 sec
# Prepared for plotting in 0.0159628391266 sec
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# roots = [1.?]
#   J  = [0.00000000000000000 .. 0.65026347044606248]
# f(J) = [0.000016303913329641787 .. 9.0449732374220844]
# Monitored signal 0.027214050293 sec
# Computed 16 flowpipes in 0.0250160694122 sec
# Prepared for plotting in 0.0185198783875 sec
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# roots = [1.?]
#   J  = [0.00000000000000000 .. 0.77524626638997108]
# f(J) = [0.0046377543576928527 .. 9.0449732374220844]
# Monitored signal 0.0290219783783 sec
# Computed 16 flowpipes in 0.0246300697327 sec
# Prepared for plotting in 0.0180130004883 sec
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# roots = [1.?]
#   J  = [0.00000000000000000 .. 0.73037263776809980]
# f(J) = [0.091507717065887062 .. 7.5624823491443545]
# Monitored signal 0.0313658714294 sec
# Computed 16 flowpipes in 0.0374119281769 sec
# Prepared for plotting in 0.0317730903625 sec
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# roots = [1.?]
#   J  = [0.00000000000000000 .. 0.85813668898723561]
# f(J) = [0.0022186649250334681 .. 6.9001165773381850]
# Monitored signal 0.033273935318 sec
# Computed 16 flowpipes in 0.0254240036011 sec
# Prepared for plotting in 0.0180099010468 sec
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# roots = [1.?]
#   J  = [0.00000000000000000 .. 0.85849866387638197]
# f(J) = [0.0018036361044041068 .. 6.5220198039587168]
# Monitored signal 0.0272569656372 sec
# Computed 16 flowpipes in 0.0252089500427 sec
# Prepared for plotting in 0.0179119110107 sec
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# roots = [2.?]
#   J  = [0.00000000000000000 .. 1.2540116721059305]
# f(J) = [0.00074166312040934150 .. 6.5217908894671917]
# Monitored signal 0.0306160449982 sec
# Computed 16 flowpipes in 0.0250928401947 sec
# Prepared for plotting in 0.0176219940186 sec
# roots = []
# Monitored signal 0.0175971984863 sec
# Computed 16 flowpipes in 0.0234520435333 sec
# Prepared for plotting in 0.0187470912933 sec
# roots = []
# Monitored signal 0.0177628993988 sec
# Computed 16 flowpipes in 0.023460149765 sec
# Prepared for plotting in 0.0168058872223 sec
# roots = []
# Monitored signal 0.0214359760284 sec
# Computed 16 flowpipes in 0.0241448879242 sec
# Prepared for plotting in 0.0168979167938 sec
# roots = []
# Monitored signal 0.0205919742584 sec
# Computed 16 flowpipes in 0.0235691070557 sec
# Prepared for plotting in 0.0175538063049 sec
# roots = []
# Monitored signal 0.0165240764618 sec
# Computed 16 flowpipes in 0.0227060317993 sec
# Prepared for plotting in 0.0162019729614 sec
# roots = []
# Monitored signal 0.0226690769196 sec
# Computed 16 flowpipes in 0.0244331359863 sec
# Prepared for plotting in 0.0163419246674 sec
# roots = []
# Monitored signal 0.0164439678192 sec
# Computed 16 flowpipes in 0.0230250358582 sec
# Prepared for plotting in 0.0162289142609 sec
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# root on boundary!
# roots = [1.?]
#   J  = [0.00000000000000000 .. 0.48990352449496677]
# f(J) = [0.020053683596536964 .. 16.855420
# <b>limit_output extension: Maximum message size of 10000 exceeded with 11406 characters</b>

# %%
sig.plot()
# Out:
# Graphics object consisting of 2 graphics primitives
