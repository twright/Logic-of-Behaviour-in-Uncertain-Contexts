# %% [markdown]
# # Tests

# %% [markdown]
# ## Example 1: Simple

# %%
from flowstar.reachability import Reach, Poly
from ULBC import *

# %%
R.<x,y> = RIF[]

# %%
odes = [
    -y,
    x,
]
initials = [(4,5), (1,2)]
reach = Reach(odes, [(4,5), (1,2)], 2*pi, 0.1, order=10)

# %%
def plot_signal(sig):
    return sig.to_domain(RIF(0,2*pi)).plot().show(
        ticks=[pi/2, 1], tick_formatter=pi, aspect_ratio=2/3)

# %%
reach.res
# Out:
# 2

# %%
P = Atomic(x - 3); P
# Out:
# Atomic(x - 3)

# %%
P.signal(reach, odes).plot() + P.sage_plot(reach)
# Out:
#   I  = [0.30000000000000004 .. 0.36519082611866372]
# f(I) = [-0.00010095855171199375 .. 1.5070862142314221]
#   I  = [4.9000000000000003 .. 4.9217847251475640]
# f(I) = [-1.2858321623772933 .. 0.00041625248816812289]
# Graphics object consisting of 4 graphics primitives

# %%
plot_signal( P.signal_for_system(odes, initials, 2*pi) )
# Out:
#   I  = [0.36999999999999999 .. 0.37165334307853943]
# f(I) = [3.5555425270672458e-7 .. 1.3036086029409697]
#   I  = [4.9199999999999999 .. 4.9226330785088353]
# f(I) = [-1.1990049139231598 .. 6.2609007107639059e-6]
# Graphics object consisting of 2 graphics primitives

# %%
Q = Atomic(3 - y); Q
# Out:
# Atomic(-y + 3)

# %%
Q.signal(reach, odes).plot() + Q.sage_plot(reach)
# Out:
#   I  = [0.20000000000000001 .. 0.20991307902148998]
# f(I) = [-0.000087772044803369199 .. 1.2408794724401760]
#   I  = [1.9000000000000001 .. 1.9385751890344354]
# f(I) = [-1.4370986582344437 .. 0.000020781821149729041]
# Graphics object consisting of 4 graphics primitives

# %%
plot_signal( Q.signal_for_system(odes, initials, 2*pi) )
# Out:
#   I  = [0.20000000000000001 .. 0.20991307902430840]
# f(I) = [-0.000087772059014223914 .. 1.2272033947531840]
#   I  = [0.21000099999999999 .. 0.21100100000000000]
# f(I) = [-0.0030477041415091222 .. 1.1881259921901675]
#   I  = [1.9399999999999999 .. 1.9423713525248339]
# f(I) = [-1.3057820199364701 .. -2.9725736139241121e-7]
# Graphics object consisting of 2 graphics primitives

# %%
plot_signal( G(RIF(1,1.2), P).signal_for_system(odes, initials, 2*pi) )
# Out:
#   I  = [0.36999999999999999 .. 0.37165334307853943]
# f(I) = [3.5555425270672458e-7 .. 1.3036086029409697]
#   I  = [4.9199999999999999 .. 4.9226330785088353]
# f(I) = [-1.1990049139231598 .. 6.2609007107639059e-6]
#   I  = [6.6500000000000003 .. 6.6545259904716137]
# f(I) = [1.2625203593685796e-7 .. 1.3122859110601910]
# Graphics object consisting of 2 graphics primitives

# %%
plot_signal( F(RIF(3.5, 4), Q).signal_for_system(odes, initials, 2*pi) )
# Out:
#   I  = [0.20000000000000001 .. 0.20991307902430840]
# f(I) = [-0.000087772059014223914 .. 1.2272033947531840]
#   I  = [0.21000099999999999 .. 0.21100100000000000]
# f(I) = [-0.0030477041415091222 .. 1.1881259921901675]
#   I  = [1.9399999999999999 .. 1.9423713525248339]
# f(I) = [-1.3057820199364701 .. -2.9725736139241121e-7]
#   I  = [6.4900000000000002 .. 6.4933943027788593]
# f(I) = [-0.000010392353393839926 .. 1.2019504300570905]
#   I  = [8.2200000000000006 .. 8.2252443822087500]
# f(I) = [-1.3144485070084313 .. -6.8264543795493182e-8]
# Graphics object consisting of 2 graphics primitives

# %%
plot_signal( (G(RIF(1,1.2), P) | F(RIF(3.5,4), Q)).signal_for_system(odes, initials, 2*pi) )
# Out:
#   I  = [0.36999999999999999 .. 0.37165334307853943]
# f(I) = [3.5555425270672458e-7 .. 1.3036086029409697]
#   I  = [4.9199999999999999 .. 4.9226330785088353]
# f(I) = [-1.1990049139231598 .. 6.2609007107639059e-6]
#   I  = [6.6500000000000003 .. 6.6545259904716137]
# f(I) = [1.2625203593685796e-7 .. 1.3122859110601910]
#   I  = [0.20000000000000001 .. 0.20991307902430840]
# f(I) = [-0.000087772059014223914 .. 1.2272033947531840]
#   I  = [0.21000099999999999 .. 0.21100100000000000]
# f(I) = [-0.0030477041415091222 .. 1.1881259921901675]
#   I  = [1.9399999999999999 .. 1.9423713525248339]
# f(I) = [-1.3057820199364701 .. -2.9725736139241121e-7]
#   I  = [6.4900000000000002 .. 6.4933943027788593]
# f(I) = [-0.000010392353393839926 .. 1.2019504300570905]
#   I  = [8.2200000000000006 .. 8.2252443822087500]
# f(I) = [-1.3144485070084313 .. -6.8264543795493182e-8]
# Graphics object consisting of 2 graphics primitives

# %%
(G(RIF(1,1.2), P) & F(RIF(3.5,4), Q)).signal_for_system(odes, initials, 2*pi).plot()
# Out:
#   I  = [0.36999999999999999 .. 0.37165334307853943]
# f(I) = [3.5555425270672458e-7 .. 1.3036086029409697]
#   I  = [4.9199999999999999 .. 4.9226330785088353]
# f(I) = [-1.1990049139231598 .. 6.2609007107639059e-6]
#   I  = [6.6500000000000003 .. 6.6545259904716137]
# f(I) = [1.2625203593685796e-7 .. 1.3122859110601910]
#   I  = [0.20000000000000001 .. 0.20991307902430840]
# f(I) = [-0.000087772059014223914 .. 1.2272033947531840]
#   I  = [0.21000099999999999 .. 0.21100100000000000]
# f(I) = [-0.0030477041415091222 .. 1.1881259921901675]
#   I  = [1.9399999999999999 .. 1.9423713525248339]
# f(I) = [-1.3057820199364701 .. -2.9725736139241121e-7]
#   I  = [6.4900000000000002 .. 6.4933943027788593]
# f(I) = [-0.000010392353393839926 .. 1.2019504300570905]
#   I  = [8.2200000000000006 .. 8.2252443822087500]
# f(I) = [-1.3144485070084313 .. -6.8264543795493182e-8]
# Graphics object consisting of 2 graphics primitives
