# %% [markdown]
# # Python / Bond Calculus integration

# %%
latex.add_to_preamble(r"\usepackage{amsmath}")
from matplotlib import rc
rc('text', usetex=True)
rc('text.latex', preamble=r'\usepackage{amsmath}')
from contextlib import contextmanager
import sys, os

@contextmanager
def suppress_stdout():
    with open(os.devnull, "w") as devnull:
        old_stdout = sys.stdout
        sys.stdout = devnull
        try:  
            yield
        finally:
            sys.stdout = old_stdout
            
            
import warnings
            
@contextmanager
def suppress_warnings():
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        yield

# %%
from ulbc.bondcalculus import *

# %%
m = BondModel("models/enzymeI.biocpi"); m
# Out:
# Running cmd: 'load "models/enzymeI.biocpi"' ...

# %%
p = BondProcess("Pi || [0.5 .. 0.6] E", m); p
# Out:
# BondProcess('Pi || [0.5 .. 0.6] E', <ulbc.bondcalculus.BondModel object at 0x7f1e4ad1b198>)

# %%
s = p.as_system; s
# Out:
# Running cmd: 'savesage "Pi || [0.5 .. 0.6] E" "/tmp/bond-script-7864027.py"' ...
# System(R, (x0, x1, x2, x3), [1, 0, [0.59999999999999997 .. 0.70000000000000007], 0], (-1.1?*x0*x2, 0.50000000000000000?*x3, -1.1?*x0*x2 + 0.50000000000000000?*x3, 1.1?*x0*x2 - 0.50000000000000000?*x3), varmap={'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3})

# %%
r = s.reach(4); r.successful
# Out:
# run = True
# vars = ['x0', 'x1', 'x2', 'x3']
# var = x0 type(var) = <class 'str'> var_str = x0
# var = x1 type(var) = <class 'str'> var_str = x1
# var = x2 type(var) = <class 'str'> var_str = x2
# var = x3 type(var) = <class 'str'> var_str = x3
# True

# %%
with suppress_stdout():
    res = graphics_array([r.sage_plot(x) for x in s.x], len(s.x), 1)
res
# Out:
# /usr/lib64/python3.7/site-packages/numpy/core/getlimits.py:400: UserWarning: Signature b'\x99\x99\x99\x99\x99\x99\xb9\xbf' for <class 'numpy.float64'> does not match any known type: falling back to type probe function
#   machar = _get_machar(dtype)
# Graphics Array of size 4 x 1

# %%
with suppress_stdout():
    res = r.sage_interval_plot('x0', 'x1')
res
# Out:
# Graphics object consisting of 40 graphics primitives

# %%
r.wplot(b"x0", b"x1")
# Out:
# <wand.image.Image: 40a290e 'PS' (720x504)>

# %%
from uuid import uuid4

uuid4().hex.encode().decode()
# Out:
# '23a1098b2c2140feaa412834f49fc809'

# %%
from ulbc.logic import *

# %%
with suppress_stdout(): 
    sig = Atomic(s.v('S') - 0.7).signal_for_system(s, 4)
sig.plot()
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
s
# Out:
# System(R, (x0, x1, x2, x3), [1, 0, [0.59999999999999997 .. 0.70000000000000007], 0], (-1.1?*x0*x2, 0.50000000000000000?*x3, -1.1?*x0*x2 + 0.50000000000000000?*x3, 1.1?*x0*x2 - 0.50000000000000000?*x3), varmap={'S': x0, 'P': x1, 'E': x2, 'new 0 in p@0->P | x@0->E': x3})

# %%
sigC = G(RIF(0,0.2), {s.v('E'): RIF(0, 10)} >> Atomic(s.v('S') - 0.7)).signal_for_system(s, 4)
sigC
# Out:
# run = True
# vars = ['x0', 'x1', 'x2', 'x3']
# var = x0 type(var) = <class 'str'> var_str = x0

# doing normal eval
# fp_compo->has_value() = False
# composing fp
# orders = [10, 10, 10, 10]
# in loop
# [0.0..4.2010000000000005] overlaps [2.9436941467101896..2.982256009835163]
# doing normal eval
# fp_compo->has_value() = False
# composing fp
# orders = [10, 10, 10, 10]
# in loop
# [0.0..4.2010000000000005] overlaps [2.982256009835163..3.0246740592726336]
# doing normal eval
# fp_compo->has_value() = False
# composing fp
# orders = [10, 10, 10, 10]
# in loop
# [0.0..4.2010000000000005] overlaps [3.0246740592726336..3.0713339136538513]
# doing normal eval
# fp_compo->has_value() = False
# composing fp
# orders = [10, 10, 10, 10]
# in loop
# [0.0..4.2010000000000005] overlaps [3.0713339136538513..3.1226597534731906]
# doing normal eval
# fp_compo->has_value() = False
# composing fp
# orders = [10, 10, 10, 10]
# in loop
# [0.0..4.2010000000000005] overlaps [3.1226597534731906..3.179118177274464]
# doing normal eval
# fp_compo->has_value() = False
# composing fp
# orders = [10, 10, 10, 10]
# in loop
# [0.0..4.2010000000000005] overlaps [3.179118177274464..3.2412224434558645]
# doing normal eval
# fp_compo->has_value() = False
# composing fp
# orders = [10, 10, 10, 10]
# in loop
# [0.0..4.2010000000000005] overlaps [3.2412224434558645..3.3095371362554054]
# doing normal eval
# fp_compo->has_value() = False
# composing fp
# orders = [10, 10, 10, 10]
# in loop
# [0.0..4.2010000000000005] overlaps [3.3095371362554054..3.347110217295153]
# doing normal eval
# fp_compo->has_value() = False
# composing fp
# orders = [10, 10, 10, 10]
# in loop
# [0.0..4.2010000000000005] overlaps [3.347110217295153..3.388440606438875]
# doing normal eval
# fp_compo->has_value() = False
# composing fp
# orders = [10, 10, 10, 10]
# in loop
# [0.0..4.2010000000000005] overlaps [3.388440606438875..3.4339040344969693]
# doing normal eval
# fp_compo->has_value() = False
# composing fp
# orders = [10, 10, 10, 10]
# in loop
# [0.0..4.2010000000000005] overlaps [3.4339040344969693..3.4839138053608734]
# doing normal eval
# fp_compo->has_value() = False
# composing fp
# orders = [10, 10, 10, 10]
# in loop
# [0.0..4.2010000000000005] overlaps [3.4839138053608734..3.5389245533111677]
# doing normal eval
# fp_compo->has_value() = False
# composing fp
# orders = [10, 10, 10, 10]
# in loop
# [0.0..4.2010000000000005] overlaps [3.5389245533111677..3.599436376056491]
# doing normal eval
# fp_compo->has_value() = False
# composing fp
# orders = [10, 10, 10, 10]
# in loop
# [0.0..4.2010000000000005] overlaps [3.599436376056491..3.665999381076347]
# doing normal eval
# fp_compo->has_value() = False
# composing fp
# orders = [10, 10, 10, 10]
# in loop
# [0.0..4.2010000000000005] overlaps [3.665999381076347..3.702609033837268]
# doing normal eval
# fp_compo->has_value() = False
# composing fp
# orders = [10, 10, 10, 10]
# in loop
# [0.0..4.2010000000000005] overlaps [3.702609033837268..3.742879651874281]
# doing normal eval
# fp_compo->has_value() = False
# composing fp
# orders = [10, 10, 10, 10]
# in loop
# [0.0..4.2010000000000005] overlaps [3.742879651874281..3.7871773317149953]
# doing normal eval
# fp_compo->has_value() = False
# composing fp
# orders = [10, 10, 10, 10]
# in loop
# [0.0..4.2010000000000005] overlaps [3.7871773317149953..3.835904779539781]
# doing normal eval
# fp_compo->has_value() = False
# composing fp
# orders = [10, 10, 10, 10]
# in loop
# [0.0..4.2010000000000005] overlaps [3.835904779539781..3.889504972147045]
# doing normal eval
# fp_compo->has_value() = False
# composing fp
# orders = [10, 10, 10, 10]
# in loop
# [0.0..4.2010000000000005] overlaps [3.889504972147045..3.9484651840150358]
# doing normal eval
# fp_compo->has_value() = False
# composing fp
# orders = [10, 10, 10, 10]
# in loop
# [0.0..4.2010000000000005] overlaps [3.9484651840150358..4.013321417069825]
# doing normal eval
# fp_compo->has_value() = False
# composing fp
# orders = [10, 10, 10, 10]
# in loop
# [0.0..4.2010000000000005] overlaps [4.013321417069825..4.04899234524996]
# doing normal eval
# fp_compo->has_value() = False
# composing fp
# orders = [10, 10, 10, 10]
# in loop
# [0.0..4.2010000000000005] overlaps [4.04899234524996..4.0882303662481085]
# doing normal eval
# fp_compo->has_value() = False
# composing fp
# orders = [10, 10, 10, 10]
# in loop
# [0.0..4.2010000000000005] overlaps [4.0882303662481085..4.131392189346071]
# doing normal eval
# fp_compo->has_value() = False
# composing fp
# orders = [10, 10, 10, 10]
# in loop
# [0.0..4.2010000000000005] overlaps [4.131392189346071..4.178870194753831]
# doing normal eval
# fp_compo->has_value() = False
# composing fp
# orders = [10, 10, 10, 10]
# in loop
# [0.0..4.2010000000000005] overlaps [4.178870194753831..4.200999999999]
# doing normal eval
# fp_compo->has_value() = False
# composing fp
# orders = [10, 10, 10, 10]
# run = True
# vars = ['x0', 'x1', 'x2', 'x3']
# var = x0 type(var) = <class 'str'> var_str = x0
# var = x1 type(var) = <class 'str'> var_str = x1
# var = x2 type(var) = <class 'str'> var_str = x2
# var = x3 type(var) = <class 'str'> var_str = x3
# Computed 2 flowpipes in 0.7498984336853027 sec
# composing fp
# orders = [10, 10, 10, 10]
# composing fp
# orders = [10, 10, 10, 10]
# domain = [0.0000000000000000 .. 0.0010000000000000001]
# roots = [[0.0000000000000000 .. 0.0019999999990000001]]
# seg_domain = [0.0000000000000000 .. 0.0010000000000000001]
# roots = [[0.0000000000000000 .. 0.0019999999990000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.1549513339996338 sec
# in eval
# fp.size = 96
# fp_compo.size = 96
# flowpipesCompo.size = 0
# domains.size = 96
# in loop
# [0.0..2.1005000000000003] overlaps [0.0..0.025]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.0..2.1005000000000003] overlaps [0.025..0.03875000000000001]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.0..2.1005000000000003] overlaps [0.03875000000000001..0.05387500000000001]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.0..2.1005000000000003] overlaps [0.05387500000000001..0.07051250000000003]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.0..2.1005000000000003] overlaps [0.07051250000000003..0.08881375000000005]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.0..2.1005000000000003] overlaps [0.08881375000000005..0.10894512500000007]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.0..2.1005000000000003] overlaps [0.10894512500000007..0.1310896375000001]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.0..2.1005000000000003] overlaps [0.1310896375000001..0.15544860125000015]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.0..2.1005000000000003] overlaps [0.15544860125000015..0.1822434613750002]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.0..2.1005000000000003] overlaps [0.1822434613750002..0.21171780751250024]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.0..2.1005000000000003] overlaps [0.21171780751250024..0.24413958826375032]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.0..2.1005000000000003] overlaps [0.24413958826375032..0.2798035470901254]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.0..2.1005000000000003] overlaps [0.2798035470901254..0.2994187244446317]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.0..2.1005000000000003] overlaps [0.2994187244446317..0.32099541953458866]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.0..2.1005000000000003] overlaps [0.32099541953458866..0.3447297841335413]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.0..2.1005000000000003] overlaps [0.3447297841335413..0.3708375851923892]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.0..2.1005000000000003] overlaps [0.3708375851923892..0.3995561663571219]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.0..2.1005000000000003] overlaps [0.3995561663571219..0.43114660563832785]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.0..2.1005000000000003] overlaps [0.43114660563832785..0.46589608884765443]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.0..2.1005000000000003] overlaps [0.46589608884765443..0.5041205203779137]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.0..2.1005000000000003] overlaps [0.5041205203779137..0.5461673950611988]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.0..2.1005000000000003] overlaps [0.5461673950611988..0.5924189572128126]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.0..2.1005000000000003] overlaps [0.5924189572128126..0.6178573163962001]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.0..2.1005000000000003] overlaps [0.6178573163962001..0.6458395114979264]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.0..2.1005000000000003] overlaps [0.6458395114979264..0.6766199261098254]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.0..2.1005000000000003] overlaps [0.6766199261098254..0.7104783821829143]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.0..2.1005000000000003] overlaps [0.7104783821829143..0.747722683863312]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.0..2.1005000000000003] overlaps [0.747722683863312..0.7886914157117495]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.0..2.1005000000000003] overlaps [0.7886914157117495..0.8337570207450308]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.0..2.1005000000000003] overlaps [0

# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.0..1.0502500000000001] overlaps [1.037129308467248..1.0770475426264305]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# run = True
# vars = ['x0', 'x1', 'x2', 'x3']
# var = x0 type(var) = <class 'str'> var_str = x0
# var = x1 type(var) = <class 'str'> var_str = x1
# var = x2 type(var) = <class 'str'> var_str = x2
# var = x3 type(var) = <class 'str'> var_str = x3
# Computed 2 flowpipes in 1.2037687301635742 sec
# composing fp
# orders = [10, 10, 10, 10]
# composing fp
# orders = [10, 10, 10, 10]
# domain = [0.0000000000000000 .. 0.0010000000000000001]
# roots = [[0.0000000000000000 .. 0.0019999999990000001]]
# seg_domain = [0.0000000000000000 .. 0.0010000000000000001]
# roots = [[0.0000000000000000 .. 0.0019999999990000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.1271040439605713 sec
# in eval
# fp.size = 96
# fp_compo.size = 96
# flowpipesCompo.size = 0
# domains.size = 96
# in loop
# [0.0..0.5251250000000001] overlaps [0.0..0.025]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.0..0.5251250000000001] overlaps [0.025..0.03875000000000001]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.0..0.5251250000000001] overlaps [0.03875000000000001..0.05387500000000001]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.0..0.5251250000000001] overlaps [0.05387500000000001..0.07051250000000003]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.0..0.5251250000000001] overlaps [0.07051250000000003..0.08881375000000005]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.0..0.5251250000000001] overlaps [0.08881375000000005..0.10894512500000007]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.0..0.5251250000000001] overlaps [0.10894512500000007..0.1310896375000001]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.0..0.5251250000000001] overlaps [0.1310896375000001..0.15544860125000015]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.0..0.5251250000000001] overlaps [0.15544860125000015..0.1822434613750002]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.0..0.5251250000000001] overlaps [0.1822434613750002..0.21171780751250024]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.0..0.5251250000000001] overlaps [0.21171780751250024..0.24413958826375032]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.0..0.5251250000000001] overlaps [0.24413958826375032..0.2798035470901254]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.0..0.5251250000000001] overlaps [0.2798035470901254..0.2994187244446317]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.0..0.5251250000000001] overlaps [0.2994187244446317..0.32099541953458866]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.0..0.5251250000000001] overlaps [0.32099541953458866..0.3447297841335413]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.0..0.5251250000000001] overlaps [0.3447297841335413..0.3708375851923892]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.0..0.5251250000000001] overlaps [0.3708375851923892..0.3995561663571219]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.0..0.5251250000000001] overlaps [0.3995561663571219..0.43114660563832785]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.0..0.5251250000000001] overlaps [0.43114660563832785..0.46589608884765443]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.0..0.5251250000000001] overlaps [0.46589608884765443..0.5041205203779137]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.0..0.5251250000000001] overlaps [0.5041205203779137..0.5461673950611988]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# run = True
# vars = ['x0', 'x1', 'x2', 'x3']
# var = x0 type(var) = <class 'str'> var_str = x0
# var = x1 type(var) = <class 'str'> var_str = x1
# var = x2 type(var) = <class 'str'> var_str = x2
# var = x3 type(var) = <class 'str'> var_str = x3
# Computed 2 flowpipes in 1.0489811897277832 sec
# composing fp
# orders = [10, 10, 10, 10]
# composing fp
# orders = [10, 10, 10, 10]
# domain = [0.0000000000000000 .. 0.0010000000000000001]
# roots = [[0.0012387209294590232 .. 0.0019999999990000001]]
# seg_domain = [0.0000000000000000 .. 0.0010000000000000001]
# roots = [[0.0012387209294590232 .. 0.0019999999990000001]]
# Monitored signal 0.2404158115386963 sec
# in eval
# fp.size = 96
# fp_compo.size = 96
# flowpipesCompo.size = 0
# domains.size = 96
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# [0.5251250000000001..1.0502500000000001] overlaps [0.5041205203779137..0.5461673950611988]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.5251250000000001..1.0502500000000001] overlaps [0.5461673950611988..0.5924189572128126]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.5251250000000001..1.0502500000000001] overlaps [0.5924189572128126..0.6178573163962001]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.5251250000000001..1.0502500000000001] overlaps [0.6178573163962001..0.6458395114979264]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.5251250000000001..1.0502500000000001] overlaps [0.6458395114979264..0.6766199261098254]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.5251250000000001..1.0502500000000001] overlaps [0.6766199261098254..0.7104783821829143]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.5251250000000001..1.0502500000000001] overlaps [0.7104783821829143..0.747722683863312]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.5251250000000001..1.0502500000000001] overlaps [0.747722683863312..0.7886914157117495]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.5251250000000001..1.0502500000000001] overlaps [0.7886914157117495..0.8337570207450308]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.5251250000000001..1.0502500000000001] overlaps [0.8337570207450308..0.8833291862816401]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.5251250000000001..1.0502500000000001] overlaps [0.8833291862816401..0.9378585683719105]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.5251250000000001..1.0502500000000001] overlaps [0.9378585683719105..0.9678497285215593]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.5251250000000001..1.0502500000000001] overlaps [0.9678497285215593..1.000840004686173]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.5251250000000001..1.0502500000000001] overlaps [1.000840004686173..1.037129308467248]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.5251250000000001..1.0502500000000001] overlaps [1.037129308467248..1.0770475426264305]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# run = True
# vars = ['x0', 'x1', 'x2', 'x3']
# var = x0 type(var) = <class 'str'> var_str = x0
# var = x1 type(var) = <class 'str'> var_str = x1
# var = x2 type(var) = <class 'str'> var_str = x2
# var = x3 type(var) = <class 'str'> var_str = x3
# Computed 2 flowpipes in 1.324662208557129 sec
# composing fp
# orders = [10, 10, 10, 10]
# composing fp
# orders = [10, 10, 10, 10]
# domain = [0.0000000000000000 .. 0.0010000000000000001]
# roots = [[0.0000000000000000 .. 0.0019999999990000001]]
# seg_domain = [0.0000000000000000 .. 0.0010000000000000001]
# roots = [[0.0000000000000000 .. 0.0019999999990000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.12357521057128906 sec
# in eval
# fp.size = 96
# fp_compo.size = 96
# flowpipesCompo.size = 0
# domains.size = 96
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# [0.5251250000000001..0.7876875000000001] overlaps [0.5041205203779137..0.5461673950611988]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.5251250000000001..0.7876875000000001] overlaps [0.5461673950611988..0.5924189572128126]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.5251250000000001..0.7876875000000001] overlaps [0.5924189572128126..0.6178573163962001]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.5251250000000001..0.7876875000000001] overlaps [0.6178573163962001..0.6458395114979264]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.5251250000000001..0.7876875000000001] overlaps [0.6458395114979264..0.6766199261098254]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.5251250000000001..0.7876875000000001] overlaps [0.6766199261098254..0.7104783821829143]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.5251250000000001..0.7876875000000001] overlaps [0.7104783821829143..0.747722683863312]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.5251250000000001..0.7876875000000001] overlaps [0.747722683863312..0.7886914157117495]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# run = True
# vars = ['x0', 'x1', 'x2', 'x3']
# var = x0 type(var) = <class 'str'> var_str = x0
# var = x1 type(var) = <class 'str'> var_str = x1
# var = x2 type(var) = <class 'str'> var_str = x2
# var = x3 type(var) = <class 'str'> var_str = x3
# Computed 2 flowpipes in 0.9133045673370361 sec
# composing fp
# orders = [10, 10, 10, 10]
# composing fp
# orders = [10, 10, 10, 10]
# domain = [0.0000000000000000 .. 0.0010000000000000001]
# roots = [[0.0000000000000000 .. 0.0019999999990000001]]
# seg_domain = [0.0000000000000000 .. 0.0010000000000000001]
# roots = [[0.0000000000000000 .. 0.0019999999990000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.09583592414855957 sec
# in eval
# fp.size = 96
# fp_compo.size = 96
# flowpipesCompo.size = 0
# domains.size = 96
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# [0.7876875000000001..1.0502500000000001] overlaps [0.747722683863312..0.7886914157117495]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.7876875000000001..1.0502500000000001] overlaps [0.7886914157117495..0.8337570207450308]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.7876875000000001..1.0502500000000001] overlaps [0.8337570207450308..0.8833291862816401]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.7876875000000001..1.0502500000000001] overlaps [0.8833291862816401..0.9378585683719105]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.7876875000000001..1.0502500000000001] overlaps [0.9378585683719105..0.9678497285215593]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.7876875000000001..1.0502500000000001] overlaps [0.9678497285215593..1.000840004686173]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.7876875000000001..1.0502500000000001] overlaps [1.000840004686173..1.037129308467248]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [0.7876875000000001..1.0502500000000001] overlaps [1.037129308467248..1.0770475426264305]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# run = True
# vars = ['x0', 'x1', 'x2', 'x3']
# var = x0 type(var) = <class 'str'> var_str = x0
# var = x1 type(var) = <class 'str'> var_str = x1
# var = x2 type(var) = <class 'str'> var_str = x2
# var = x3 type(var) = <class 'str'> var_str = x3
# Computed 2 flowpipes in 0.8343250751495361 sec
# composing fp
# orders = [10, 10, 10, 10]
# composing fp
# orders = [10, 10, 10, 10]
# domain = [0.0000000000000000 .. 0.0010000000000000001]
# roots = [[0.0000000000000000 .. 0.0019999999990000001]]
# seg_domain = [0.0000000000000000 .. 0.0010000000000000001]
# roots = [[0.0000000000000000 .. 0.0019999999990000001]]
# 0 at 0.00100000000000001
# Monitored signal 0.09599924087524414 sec
# in eval
# fp.size = 96
# fp_compo.size = 96
# flowpipesCompo.size = 0
# domains.size = 96
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# [1.0502500000000001..2.1005000000000003] overlaps [1.037129308467248..1.0770475426264305]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [1.0502500000000001..2.1005000000000003] overlaps [1.0770475426264305..1.1209576002015313]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [1.0502500000000001..2.1005000000000003] overlaps [1.1209576002015313..1.1692586635341422]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [1.0502500000000001..2.1005000000000003] overlaps [1.1692586635341422..1.222389833200014]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [1.0502500000000001..2.1005000000000003] overlaps [1.222389833200014..1.280834119832473]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [1.0502500000000001..2.1005000000000003] overlaps [1.280834119832473..1.345122835128178]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [1.0502500000000001..2.1005000000000003] overlaps [1.345122835128178..1.380481628540816]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [1.0502500000000001..2.1005000000000003] overlaps [1.380481628540816..1.4193763012947176]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [1.0502500000000001..2.1005000000000003] overlaps [1.4193763012947176..1.4621604413240092]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [1.0502500000000001..2.1005000000000003] overlaps [1.4621604413240092..1.5092229953562302]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [1.0502500000000001..2.1005000000000003] overlaps [1.5092229953562302..1.560991804791673]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [1.0502500000000001..2.1005000000000003] overlaps [1.560991804791673..1.6179374951706604]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [1.0502500000000001..2.1005000000000003] overlaps [1.6179374951706604..1.6805777545875464]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [1.0502500000000001..2.1005000000000003] overlaps [1.6805777545875464..1.749482039946121]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [1.0502500000000001..2.1005000000000003] overlaps [1.749482039946121..1.7873793968933371]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [1.0502500000000001..2.1005000000000003] overlaps [1.7873793968933371..1.8290664895352748]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [1.0502500000000001..2.1005000000000003] overlaps [1.8290664895352748..1.8749222914414063]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [1.0502500000000001..2.1005000000000003] overlaps [1.8749222914414063..1.925363673538151]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [1.0502500000000001..2.1005000000000003] overlaps [1.925363673538151..1.98084919384457]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [1.0502500000000001..2.1005000000000003] overlaps [1.98084919384457..2.0418832661816313]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [1.0502500000000001..2.1005000000000003] overlaps [2.0418832661816313..2.1090207457523986]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# run = True
# vars = ['x0', 'x1', 'x2', 'x3']
# var = x0 type(var) = <class 'str'> var_str = x0
# var = x1 type(var) = <class 'str'> var_str = x1
# var = x2 type(var) = <class 'str'> var_str = x2
# var = x3 type(var) = <class 'str'> var_str = x3
# Computed 2 flowpipes in 0.933452844619751 sec
# composing fp
# orders = [10, 10, 10, 10]
# composing fp
# orders = [10, 10, 10, 10]
# domain = [0.0000000000000000 .. 0.0010000000000000001]
# roots = []
# seg_domain = [0.0000000000000000 .. 0.0010000000000000001]
# roots = []
# Monitored signal 0.0842888355255127 sec
# in eval
# fp.size = 96
# fp_compo.size = 96
# flowpipesCompo.size = 0
# domains.size = 96
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# [2.1005000000000003..4.2010000000000005] overlaps [2.0418832661816313..2.1090207457523986]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [2.1005000000000003..4.2010000000000005] overlaps [2.1090207457523986..2.1828719732802426]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [2.1005000000000003..4.2010000000000005] overlaps [2.1828719732802426..2.2234901484205567]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [2.1005000000000003..4.2010000000000005] overlaps [2.2234901484205567..2.2681701410749024]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [2.1005000000000003..4.2010000000000005] overlaps [2.2681701410749024..2.3173181329946826]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [2.1005000000000003..4.2010000000000005] overlaps [2.3173181329946826..2.371380924106441]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [2.1005000000000003..4.2010000000000005] overlaps [2.371380924106441..2.430849994329375]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [2.1005000000000003..4.2010000000000005] overlaps [2.430849994329375..2.4962659715746023]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [2.1005000000000003..4.2010000000000005] overlaps [2.4962659715746023..2.5682235465443526]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [2.1005000000000003..4.2010000000000005] overlaps [2.5682235465443526..2.607800212777715]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [2.1005000000000003..4.2010000000000005] overlaps [2.607800212777715..2.651334545634414]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [2.1005000000000003..4.2010000000000005] overlaps [2.651334545634414..2.699222311776783]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [2.1005000000000003..4.2010000000000005] overlaps [2.699222311776783..2.7518988545333887]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [2.1005000000000003..4.2010000000000005] overlaps [2.7518988545333887..2.8098430515656547]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [2.1005000000000003..4.2010000000000005] overlaps [2.8098430515656547..2.8735816683011475]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [2.1005000000000003..4.2010000000000005] overlaps [2.8735816683011475..2.9436941467101896]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [2.1005000000000003..4.2010000000000005] overlaps [2.9436941467101896..2.982256009835163]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [2.1005000000000003..4.2010000000000005] overlaps [2.982256009835163..3.0246740592726336]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [2.1005000000000003..4.2010000000000005] overlaps [3.0246740592726336..3.0713339136538513]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [2.1005000000000003..4.2010000000000005] overlaps [3.0713339136538513..3.1226597534731906]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [2.1005000000000003..4.2010000000000005] overlaps [3.1226597534731906..3.179118177274464]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [2.1005000000000003..4.2010000000000005] overlaps [3.179118177274464..3.2412224434558645]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [2.1005000000000003..4.2010000000000005] overlaps [3.2412224434558645..3.3095371362554054]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [2.1005000000000003..4.2010000000000005] overlaps [3.3095371362554054..3.347110217295153]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [2.1005000000000003..4.2010000000000005] overlaps [3.347110217295153..3.388440606438875]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [2.1005000000000003..4.2010000000000005] overlaps [3.388440606438875..3.4339040344969693]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [2.1005000000000003..4.2010000000000005] overlaps [3.4339040344969693..3.4839138053608734]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [2.1005000000000003..4.2010000000000005] overlaps [3.4839138053608734..3.5389245533111677]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [2.1005000000000003..4.2010000000000005] overlaps [3.5389245533111677..3.599436376056491]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [2.1005000000000003..4.2010000000000005] overlaps [3.599436376056491..3.665999381076347]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [2.1005000000000003..4.2010000000000005] overlaps [3.665999381076347..3.702609033837268]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [2.1005000000000003..4.2010000000000005] overlaps [3.702609033837268..3.742879651874281]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [2.1005000000000003..4.2010000000000005] overlaps [3.742879651874281..3.7871773317149953]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [2.1005000000000003..4.2010000000000005] overlaps [3.7871773317149953..3.835904779539781]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [2.1005000000000003..4.2010000000000005] overlaps [3.835904779539781..3.889504972147045]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [2.1005000000000003..4.2010000000000005] overlaps [3.889504972147045..3.9484651840150358]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [2.1005000000000003..4.2010000000000005] overlaps [3.9484651840150358..4.013321417069825]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [2.1005000000000003..4.2010000000000005] overlaps [4.013321417069825..4.04899234524996]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [2.1005000000000003..4.2010000000000005] overlaps [4.04899234524996..4.0882303662481085]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [2.1005000000000003..4.2010000000000005] overlaps [4.0882303662481085..4.131392189346071]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [2.1005000000000003..4.2010000000000005] overlaps [4.131392189346071..4.178870194753831]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# [2.1005000000000003..4.2010000000000005] overlaps [4.178870194753831..4.200999999999]
# doing normal eval
# fp_compo->has_value() = True
# run = True
# vars = ['x0', 'x1', 'x2', 'x3']
# var = x0 type(var) = <class 'str'> var_str = x0
# var = x1 type(var) = <class 'str'> var_str = x1
# var = x2 type(var) = <class 'str'> var_str = x2
# var = x3 type(var) = <class 'str'> var_str = x3
# Computed 1 flowpipes in 0.6838967800140381 sec
# composing fp
# orders = [10, 10, 10, 10]
# domain = [0.0000000000000000 .. 0.0010000000000000001]
# roots = []
# seg_domain = [0.0000000000000000 .. 0.0010000000000000001]
# roots = []
# Monitored signal 0.01835799217224121 sec
# Monitored signal 11.153960943222046 sec
# Signal([0.0000000000000000 .. 4.0000000000000000], [([0.0000000000000000 .. 0.32512500000000006], True), ([0.85025000000000017 .. 4.0000000000000000], False)], mask=None)

# %%
sigC.plot()
# Out:
# Graphics object consisting of 2 graphics primitives
