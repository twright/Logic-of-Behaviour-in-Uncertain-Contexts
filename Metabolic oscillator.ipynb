# %%
from roadrunner import *

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %%
r = RoadRunner("BIOMD0000000090.xml")

# %%
s.colnames
# Out:
# ['time',
#  '[oxy]',
#  '[A3c]',
#  '[aps]',
#  '[pap]',
#  '[sul]',
#  '[eth]',
#  '[hyd]',
#  '[cys]',
#  '[N2]',
#  '[aco]',
#  '[oah]',
#  '[S1]',
#  '[A3m]']

# %%
s = r.simulate(0,200,5000)
s[:,0]
# Out:
# [  0.00000000e+00   4.00080016e-02   8.00160032e-02 ...,   1.99919984e+02
#    1.99959992e+02   2.00000000e+02]

# %%
plt.plot(s[:,0],s[:,1:])
plt.legend(s.colnames[1:])
plt.xlim(0,100)
plt.ylim(0,20)
# Out:
# <img src="data:image/png;base64,..." width="936">
# (0, 20)
