# %% [markdown]
# # Tests

# %% [markdown]
# ## Example 1: Simple

# %%
from flowstar.reachability import Reach
from flowstar.poly import Poly
from ulbc import *

# %%
R.<t,x,y> = RIF[]

# %%
odes = [
    R(1),
    -y,
    x,
]
initials = [(0,0), (4,5), (1,2)]
reach = Reach(odes, initials, 2*pi, 0.1, order=10,
              precompose_taylor_models=True)
# Out:
# run = True
# vars = ['t', 'x', 'y']
# var = t type(var) = <class 'str'> var_str = t
# var = x type(var) = <class 'str'> var_str = x
# var = y type(var) = <class 'str'> var_str = y
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# composing fp
# orders = [10, 10, 10]
# Pre-composing Taylor models: 0.03728961944580078 sec

# %%
odes[0].parent().gens()
# Out:
# (t, x, y)

# %%
def plot_signal(sig):
    return sig.to_domain(RIF(0,2*pi)).plot().show(
        ticks=[pi/2, 1], tick_formatter=pi, aspect_ratio=2/3)

# %%
reach.res
# Out:
# 2

# %%
P = Atomic(x - 3); P
# Out:
# Atomic(x - 3)

# %%
P.signal(reach, odes).plot() + P.sage_plot(reach)
# Out:
# domain = [0.00000000000000000 .. 6.2821853071795859]
# roots = [[0.36442391108285426 .. 0.75322999900880539],
#  [4.9094498886889716 .. 5.3000000000000105]]
# seg_domain = [0.00000000000000000 .. 6.2821853071795859]
# roots = [[0.36442391108285426 .. 0.75322999900880539],
#  [4.9094498886889716 .. 5.3000000000000105]]
# in eval
# fp.size = 63
# fp_compo.size = 63
# flowpipesCompo.size = 0
# domains.size = 63
# in loop
# [0.0..0.0] overlaps [0.0..0.1]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in eval
# fp.size = 63
# fp_compo.size = 63
# flowpipesCompo.size = 0
# domains.size = 63
# in loop
# [0.04364212250443098..0.04364212250443098] overlaps [0.0..0.1]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in eval
# fp.size = 63
# fp_compo.size = 63
# flowpipesCompo.size = 0
# domains.size = 63
# in loop
# [0.05419181252525664..0.05419181252525664] overlaps [0.0..0.1]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in eval
# fp.size = 63
# fp_compo.size = 63
# flowpipesCompo.size = 0
# domains.size = 63
# in loop
# in loop
# [0.10893725730246398..0.10893725730246398] overlaps [0.1..0.2]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in eval
# fp.size = 63
# fp_compo.size = 63
# flowpipesCompo.size = 0
# domains.size = 63
# in loop
# in loop
# [0.13081153889260777..0.13081153889260777] overlaps [0.1..0.2]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in eval
# fp.size = 63
# fp_compo.size = 63
# flowpipesCompo.size = 0
# domains.size = 63
# in loop
# in loop
# [0.15228876017077161..0.15228876017077161] overlaps [0.1..0.2]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in eval
# fp.size = 63
# fp_compo.size = 63
# flowpipesCompo.size = 0
# domains.size = 63
# in loop
# in loop
# in loop
# [0.20364132017639477..0.20364132017639477] overlaps [0.2..0.30000000000000004]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in eval
# fp.size = 63
# fp_compo.size = 63
# flowpipesCompo.size = 0
# domains.size = 63
# in loop
# in loop
# in loop
# [0.23584495910877795..0.23584495910877795] overlaps [0.2..0.30000000000000004]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in eval
# fp.size = 63
# fp_compo.size = 63
# flowpipesCompo.size = 0
# domains.size = 63
# in loop
# in loop
# in loop
# [0.24613306713427566..0.24613306713427566] overlaps [0.2..0.30000000000000004]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in eval
# fp.size = 63
# fp_compo.size = 63
# flowpipesCompo.size = 0
# domains.size = 63
# in loop
# in loop
# in loop
# [0.2696622911559248..0.2696622911559248] overlaps [0.2..0.30000000000000004]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in eval
# fp.size = 63
# fp_compo.size = 63
# flowpipesCompo.size = 0
# domains.size = 63
# in loop
# in loop
# in loop
# in loop
# [0.3025663335529662..0.3025663335529662] overlaps [0.30000000000000004..0.4000000000000001]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in eval
# fp.size = 63
# fp_compo.size = 63
# flowpipesCompo.size = 0
# domains.size = 63
# in loop
# in loop
# in loop
# in loop
# [0.34386689856846897..0.34386689856846897] overlaps [0.30000000000000004..0.4000000000000001]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in eval
# fp.size = 63
# fp_compo.size = 63
# flowpipesCompo.size = 0
# domains.size = 63
# in loop
# in loop
# in loop
# in loop
# [0.38101717213012753..0.38101717213012753] overlaps [0.30000000000000004..0.4000000000000001]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in eval
# fp.size = 63
# fp_compo.size = 63
# flowpipesCompo.size = 0
# domains.size = 63
# in loop
# in loop
# in loop
# in loop
# [0.3989198942592919..0.3989198942592919] overlaps [0.30000000000000004..0.4000000000000001]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in eval
# fp.size = 63
# fp_compo.size = 63
# flowpipesCompo.size = 0
# domains.size = 63
# in loop
# in loop
# in loop
# in loop
# in loop
# [0.43842428423626206..0.43842428423626206] overlaps [0.4000000000000001..0.5000000000000001]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in eval
# fp.size = 63
# fp_compo.size = 63
# flowpipesCompo.size = 0
# domains.size = 63
# in loop
# in loop
# in loop
# in loop
# in loop
# [0.46289969217825067..0.46289969217825067] overlaps [0.4000000000000001..0.5000000000000001]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in eval
# fp.size = 63
# fp_compo.size = 63
# flowpipesCompo.size = 0
# domains.size = 63
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# [0.503347217937961..0.503347217937961] overlaps [0.5000000000000001..0.6000000000000002]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in eval
# fp.size = 63
# fp_compo.size = 63
# flowpipesCompo.size = 0
# domains.size = 63
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# [0.527193705034184..0.527193705034184] overlaps [0.5000000000000001..0.6000000000000002]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in eval
# fp.size = 63
# fp_compo.size = 63
# flowpipesCompo.size = 0
# domains.size = 63
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# [0.557077477739196..0.557077477739196] overlaps [0.5000000000000001..0.6000000000000002]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in eval
# fp.size = 63
# fp_compo.size = 63
# flowpipesCompo.size = 0
# domains.size = 63
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# [0.5954532475099009..0.5954532475099009] overlaps [0.5000000000000001..0.6000000000000002]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in eval
# fp.size = 63
# fp_compo.size = 63
# flowpipesCompo.size = 0
# domains.size = 63
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# [0.6250192995526456..0.6250192995526456] overlaps [0.6000000000000002..0.7000000000000003]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in eval
# fp.size = 63
# fp_compo.size = 63
# flowpipesCompo.size = 0
# domains.size = 63
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# [0.6499842427846524..0.6499842427846524] overlaps [0.6000000000000002..0.7000000000000003]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in eval
# fp.size = 63
# fp_compo.size = 63
# flowpipesCompo.size = 0
# domains.size = 63
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# [0.7016285832193507..0.7016285832193507] overlaps [0.7000000000000003..0.8000000000000004]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in eval
# fp.size = 63
# fp_compo.size = 63
# flowpipesCompo.size = 0
# domains.size = 63
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# [0.7302325422197818..0.7302325422197818] overlaps [0.7000000000000003..0.8000000000000004]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in eval
# fp.size = 63
# fp_compo.size = 63
# flowpipesCompo.size = 0
# domains.size = 63
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# [0.7590785817030004..0.7590785817030004] overlaps [0.7000000000000003..0.8000000000000004]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in eval
# fp.size = 63
# fp_compo.size = 63
# flowpipesCompo.size = 0
# domains.size = 63
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# [0.801314225200429..0.801314225200429] overlaps [0.8000000000000004..0.9000000000000005]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in eval
# fp.size = 63
# fp_compo.size = 63
# flowpipesCompo.size = 0
# domains.size = 63
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# [0.819850596952322..0.819850596952322] overlaps [0.8000000000000004..0.9000000000000005]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in eval
# fp.size = 63
# fp_compo.size = 63
# flowpipesCompo.size = 0
# domains.size = 63
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# [0.8398383747380072..0.8398383747380072] overlaps [0.8000000000000004..0.9000000000000005]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in eval
# fp.size = 63
# fp_compo.size = 63
# flowpipesCompo.size = 0
# domains.size = 63
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# [0

# doing normal eval
# fp_compo->has_value() = True
# in loop
# in eval
# fp.size = 63
# fp_compo.size = 63
# flowpipesCompo.size = 0
# domains.size = 63
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# [6.166030493835462..6.166030493835462] overlaps [6.100000000000015..6.200000000000015]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# in eval
# fp.size = 63
# fp_compo.size = 63
# flowpipesCompo.size = 0
# domains.size = 63
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# [6.202281978917942..6.202281978917942] overlaps [6.200000000000015..6.300000000000016]
# doing normal eval
# fp_compo->has_value() = True
# in eval
# fp.size = 63
# fp_compo.size = 63
# flowpipesCompo.size = 0
# domains.size = 63
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# [6.187733476357704..6.187733476357704] overlaps [6.100000000000015..6.200000000000015]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# in eval
# fp.size = 63
# fp_compo.size = 63
# flowpipesCompo.size = 0
# domains.size = 63
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# [6.180459225077585..6.180459225077585] overlaps [6.100000000000015..6.200000000000015]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# in eval
# fp.size = 63
# fp_compo.size = 63
# flowpipesCompo.size = 0
# domains.size = 63
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# [6.195007727637823..6.195007727637823] overlaps [6.100000000000015..6.200000000000015]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# in eval
# fp.size = 63
# fp_compo.size = 63
# flowpipesCompo.size = 0
# domains.size = 63
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# [6.191370601997764..6.191370601997764] overlaps [6.100000000000015..6.200000000000015]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# in eval
# fp.size = 63
# fp_compo.size = 63
# flowpipesCompo.size = 0
# domains.size = 63
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# [6.198644853277883..6.198644853277883] overlaps [6.100000000000015..6.200000000000015]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# in eval
# fp.size = 63
# fp_compo.size = 63
# flowpipesCompo.size = 0
# domains.size = 63
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# [6.196826290457853..6.196826290457853] overlaps [6.100000000000015..6.200000000000015]
# doing normal eval
# fp_compo->has_value() = True
# in loop
# in eval
# fp.size = 63
# fp_compo.size = 63
# flowpipesCompo.size = 0
# domains.size = 63
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# [6.200463416097913..6.200463416097913] overlaps [6.200000000000015..6.300000000000016]
# doing normal eval
# fp_compo->has_value() = True
# in eval
# fp.size = 63
# fp_compo.size = 63
# flowpipesCompo.size = 0
# domains.size = 63
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# [6.216830481478181..6.216830481478181] overlaps [6.200000000000015..6.300000000000016]
# doing normal eval
# fp_compo->has_value() = True
# in eval
# fp.size = 63
# fp_compo.size = 63
# flowpipesCompo.size = 0
# domains.size = 63
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# [6.209556230198062..6.209556230198062] overlaps [6.200000000000015..6.300000000000016]
# doing normal eval
# fp_compo->has_value() = True
# in eval
# fp.size = 63
# fp_compo.size = 63
# flowpipesCompo.size = 0
# domains.size = 63
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# [6.2241047327583..6.2241047327583] overlaps [6.200000000000015..6.300000000000016]
# doing normal eval
# fp_compo->has_value() = True
# in eval
# fp.size = 63
# fp_compo.size = 63
# flowpipesCompo.size = 0
# domains.size = 63
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# [6.246366771339642..6.246366771339642] overlaps [6.200000000000015..6.300000000000016]
# doing normal eval
# fp_compo->has_value() = True
# in eval
# fp.size = 63
# fp_compo.size = 63
# flowpipesCompo.size = 0
# domains.size = 63
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# [6.2388728776890305..6.2388728776890305] overlaps [6.200000000000015..6.300000000000016]
# doing normal eval
# fp_compo->has_value() = True
# in eval
# fp.size = 63
# fp_compo.size = 63
# flowpipesCompo.size = 0
# domains.size = 63
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# [6.2538606649902535..6.2538606649902535] overlaps [6.200000000000015..6.300000000000016]
# doing normal eval
# fp_compo->has_value() = True
# in eval
# fp.size = 63
# fp_compo.size = 63
# flowpipesCompo.size = 0
# domains.size = 63
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# in loop
# [6.272269932910225..6.272269932910225] overlaps [6.200000000000015..6.300000000000016]
# doing normal eval
# fp_compo->has_value() = True
# Graphics object consisting of 4 graphics primitives

# %%
plot_signal( P.signal_for_system(odes, initials, 2*pi) )

# %%
Q = Atomic(3 - y); Q

# %%
Q.signal(reach, odes).plot() + Q.sage_plot(reach)

# %%
plot_signal( Q.signal_for_system(odes, initials, 2*pi) )

# %%
plot_signal( G(RIF(1,1.2), P).signal_for_system(odes, initials, 2*pi) )

# %%
plot_signal( F(RIF(3.5, 4), Q).signal_for_system(odes, initials, 2*pi) )

# %%
plot_signal( (G(RIF(1,1.2), P) | F(RIF(3.5,4), Q)).signal_for_system(odes, initials, 2*pi) )

# %%
(G(RIF(1,1.2), P) & F(RIF(3.5,4), Q)).signal_for_system(odes, initials, 2*pi).plot()

# %%
sig = U(G(RIF(1, 1.2), P), RIF(0.4, 0.5), F(RIF(3.5, 4), Q)).signal_for_system(
    odes, [RIF(4, 5), RIF(1, 2)], 2*pi)
plot_signal( sig )

# %% [markdown]
# ## Context!

# %%
{y: RIF(9,10)} >> P

# %%
sig = ({y: RIF(9,10)} >> P).signal_for_system(odes, initials, 4*pi)

# %%
sig.plot()

# %%
sig = ({y: RIF(9,10)} >> G(RIF(0, 5), P)).signal_for_system(odes, initials, 4*pi)

# %%
sig.plot()

# %%
sig = ({y: RIF(9,10)} >> G(RIF(0, pi/2), Atomic(y))).signal_for_system(odes, initials, 4*pi)

# %%
sig.plot()

# %% [markdown]
# ## Differential context!

# %%
sig = ({y: RIF(9,10)} % P).signal_for_system(odes, initials, 4*pi)

# %%
sig = ({y: RIF(0.5,0.6)} % P).signal_for_system(odes, initials, 4*pi, verbosity=10)

# %%
({y: RIF(9,10)} % P)

# %%
sig.plot()

# %%
sig = ({y: RIF(0.5, 0.6)} % G(RIF(0, 5), P)
       ).signal_for_system(odes, initials, 4*pi, verbosity=10)

# %%
sig.plot()
